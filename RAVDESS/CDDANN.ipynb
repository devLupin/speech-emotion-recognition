# %% [markdown]
# ### Model summary
# <hr>
#
# - GRU -> Multi-Head Self Attention - [Gradient Reversal](https://github.com/janfreyberg/pytorch-revgrad) - classification

# %%
import os
import torch

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'CDDANN'
data_name = 'RAVDESS'

minibatch = 128
num_epochs = 500
EARLY_CNT = 500

learning_rate = 1e-6

# model = Model(len(emotions_dict))
# print(summary(model, (1, 3, 224, 224)))

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm

from pytorch_revgrad import RevGrad

# %%
class FeatureEncoder(nn.Module):
    """Some Information about FeatureEncoder"""
    def __init__(self):
        super(FeatureEncoder, self).__init__()

        self.layer_norm = nn.LayerNorm(normalized_shape=256, eps=1e-08)

        self.lstm1 = nn.LSTM(input_size=224, hidden_size=128, num_layers=4, batch_first=True, dropout=0.5, bidirectional=True)
        self.lstm2 = nn.LSTM(input_size=224, hidden_size=128, num_layers=4, batch_first=True, dropout=0.5, bidirectional=True)
        self.lstm3 = nn.LSTM(input_size=224, hidden_size=128, num_layers=4, batch_first=True, dropout=0.5, bidirectional=True)
        
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=256,
            nhead=4,
            dim_feedforward=64,
            dropout=0.5,
            activation='relu'
        )
        self.transformer_encoder1 = torch.nn.Sequential(
            nn.TransformerEncoder(transformer_layer, num_layers=2),
            nn.LayerNorm(normalized_shape=256, eps=1e-08),
            RevGrad()
        )
        self.transformer_encoder2 = torch.nn.Sequential(
            nn.TransformerEncoder(transformer_layer, num_layers=2),
            nn.LayerNorm(normalized_shape=256, eps=1e-08),
            RevGrad()
        )
        self.transformer_encoder3 = torch.nn.Sequential(
            nn.TransformerEncoder(transformer_layer, num_layers=2),
            nn.LayerNorm(normalized_shape=256, eps=1e-08),
            RevGrad()
        )
        
    def forward(self, x):
        embd1 = x[:,0,:,:]
        embd2 = x[:,1,:,:]
        embd3 = x[:,2,:,:]

        gru_embd1, _ = self.lstm1(embd1)
        gru_embd1 = self.layer_norm(gru_embd1)
        gru_embd2, _ = self.lstm2(embd2)
        gru_embd2 = self.layer_norm(gru_embd2)
        gru_embd3, _ = self.lstm3(embd3)
        gru_embd3 = self.layer_norm(gru_embd3)
        
        transformer_out1 = self.transformer_encoder1(gru_embd1)
        transformer_out1 = torch.flatten(transformer_out1, start_dim=1)
        transformer_out2 = self.transformer_encoder2(gru_embd2)
        transformer_out2 = torch.flatten(transformer_out2, start_dim=1)
        transformer_out3 = self.transformer_encoder3(gru_embd3)
        transformer_out3 = torch.flatten(transformer_out3, start_dim=1)

        complete_embd = torch.cat([transformer_out1, transformer_out2, transformer_out3], dim=1)

        return complete_embd

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()
        
        self.feature_encoder = FeatureEncoder()
        
        self.linear = nn.Linear(172032, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        
        output = self.feature_encoder(x)
        
        
        output_logits = self.linear(output)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = '5-CV-augment'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    break
# Out:
# [*] model training - CDDANN
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:2.137, Epoch accuracy:11.18%, Validation loss:2.096, Validation accuracy:11.83%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:2.038, Epoch accuracy:12.85%, Validation loss:2.090, Validation accuracy:13.67%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:2.021, Epoch accuracy:12.63%, Validation loss:2.084, Validation accuracy:14.17%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:2.009, Epoch accuracy:13.51%, Validation loss:2.079, Validation accuracy:14.67%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:2.015, Epoch accuracy:14.25%, Validation loss:2.076, Validation accuracy:13.67%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:2.019, Epoch accuracy:12.94%, Validation loss:2.074, Validation accuracy:13.33%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:2.008, Epoch accuracy:13.73%, Validation loss:2.073, Validation accuracy:14.17%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:1.997, Epoch accuracy:13.64%, Validation loss:2.068, Validation accuracy:15.00%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:2.003, Epoch accuracy:13.86%, Validation loss:2.068, Validation accuracy:12.83%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:2.018, Epoch accuracy:13.51%, Validation loss:2.065, Validation accuracy:16.33%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:1.999, Epoch accuracy:14.39%, Validation loss:2.064, Validation accuracy:12.67%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:1.993, Epoch accuracy:15.18%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:1.989, Epoch accuracy:14.96%, Validation loss:2.060, Validation accuracy:13.83%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:1.984, Epoch accuracy:14.91%, Validation loss:2.057, Validation accuracy:16.50%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:1.994, Epoch accuracy:15.26%, Validation loss:2.056, Validation accuracy:15.83%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:1.977, Epoch accuracy:15.79%, Validation loss:2.057, Validation accuracy:14.67%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:1.987, Epoch accuracy:15.75%, Validation loss:2.054, Validation accuracy:15.83%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:1.989, Epoch accuracy:15.48%, Validation loss:2.052, Validation accuracy:15.50%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:1.987, Epoch accuracy:15.09%, Validation loss:2.051, Validation accuracy:15.67%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:1.983, Epoch accuracy:15.70%, Validation loss:2.052, Validation accuracy:15.83%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:1.966, Epoch accuracy:16.49%, Validation loss:2.052, Validation accuracy:17.17%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:1.986, Epoch accuracy:15.92%, Validation loss:2.049, Validation accuracy:16.00%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:1.973, Epoch accuracy:16.45%, Validation loss:2.052, Validation accuracy:16.17%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:1.968, Epoch accuracy:17.28%, Validation loss:2.048, Validation accuracy:14.67%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:1.962, Epoch accuracy:17.63%, Validation loss:2.048, Validation accuracy:16.83%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:1.963, Epoch accuracy:16.75%, Validation loss:2.047, Validation accuracy:17.00%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:1.986, Epoch accuracy:15.53%, Validation loss:2.048, Validation accuracy:16.33%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:1.975, Epoch accuracy:15.13%, Validation loss:2.046, Validation accuracy:17.67%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:1.960, Epoch accuracy:16.97%, Validation loss:2.049, Validation accuracy:17.50%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:1.968, Epoch accuracy:17.19%, Validation loss:2.044, Validation accuracy:16.50%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:1.949, Epoch accuracy:18.07%, Validation loss:2.046, Validation accuracy:16.17%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:1.960, Epoch accuracy:15.96%, Validation loss:2.043, Validation accuracy:18.67%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:1.956, Epoch accuracy:15.92%, Validation loss:2.046, Validation accuracy:17.50%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:1.943, Epoch accuracy:19.12%, Validation loss:2.046, Validation accuracy:16.83%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:1.975, Epoch accuracy:16.05%, Validation loss:2.042, Validation accuracy:18.67%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:1.957, Epoch accuracy:16.45%, Validation loss:2.041, Validation accuracy:17.33%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:1.958, Epoch accuracy:17.02%, Validation loss:2.043, Validation accuracy:16.33%
# Epoch 37: iteration 16/17
# Epoch 37 --- loss:1.953, Epoch accuracy:17.85%, Validation loss:2.043, Validation accuracy:17.00%
# Epoch 38: iteration 16/17
# Epoch 38 --- loss:1.953, Epoch accuracy:16.93%, Validation loss:2.040, Validation accuracy:17.67%
# Epoch 39: iteration 16/17
# Epoch 39 --- loss:1.963, Epoch accuracy:17.06%, Validation loss:2.044, Validation accuracy:16.00%
# Epoch 40: iteration 16/17
# Epoch 40 --- loss:1.939, Epoch accuracy:19.56%, Validation loss:2.043, Validation accuracy:18.33%
# Epoch 41: iteration 16/17
# Epoch 41 --- loss:1.941, Epoch accuracy:17.72%, Validation loss:2.041, Validation accuracy:17.00%
# Epoch 42: iteration 16/17
# Epoch 42 --- loss:1.944, Epoch accuracy:18.82%, Validation loss:2.041, Validation accuracy:18.50%
# Epoch 43: iteration 16/17
# Epoch 43 --- loss:1.935, Epoch accuracy:18.42%, Validation loss:2.042, Validation accuracy:17.33%
# Epoch 44: iteration 16/17
# Epoch 44 --- loss:1.941, Epoch accuracy:18.51%, Validation loss:2.040, Validation accuracy:17.17%
# Epoch 45: iteration 16/17
# Epoch 45 --- loss:1.948, Epoch accuracy:16.40%, Validation loss:2.040, Validation accuracy:17.17%
# Epoch 46: iteration 16/17
# Epoch 46 --- loss:1.946, Epoch accuracy:18.11%, Validation loss:2.039, Validation accuracy:18.33%
# Epoch 47: iteration 16/17
# Epoch 47 --- loss:1.927, Epoch accuracy:18.42%, Validation loss:2.039, Validation accuracy:17.67%
# Epoch 48: iteration 16/17
# Epoch 48 --- loss:1.943, Epoch accuracy:17.41%, Validation loss:2.040, Validation accuracy:17.67%
# Epoch 49: iteration 16/17
# Epoch 49 --- loss:1.932, Epoch accuracy:19.65%, Validation loss:2.043, Validation accuracy:17.50%
# Epoch 50: iteration 16/17
# Epoch 50 --- loss:1.946, Epoch accuracy:18.11%, Validation loss:2.040, Validation accuracy:18.33%
# Epoch 51: iteration 16/17
# Epoch 51 --- loss:1.945, Epoch accuracy:18.51%, Validation loss:2.038, Validation accuracy:18.00%
# Epoch 52: iteration 16/17
# Epoch 52 --- loss:1.933, Epoch accuracy:19.52%, Validation loss:2.041, Validation accuracy:18.17%
# Epoch 53: iteration 16/17
# Epoch 53 --- loss:1.926, Epoch accuracy:19.39%, Validation loss:2.037, Validation accuracy:17.83%
# Epoch 54: iteration 16/17
# Epoch 54 --- loss:1.925, Epoch accuracy:18.68%, Validation loss:2.040, Validation accuracy:17.33%
# Epoch 55: iteration 16/17
# Epoch 55 --- loss:1.921, Epoch accuracy:19.39%, Validation loss:2.039, Validation accuracy:17.83%
# Epoch 56: iteration 16/17
# Epoch 56 --- loss:1.919, Epoch accuracy:18.90%, Validation loss:2.039, Validation accuracy:18.33%
# Epoch 57: iteration 16/17
# Epoch 57 --- loss:1.927, Epoch accuracy:18.33%, Validation loss:2.041, Validation accuracy:18.17%
# Epoch 58: iteration 16/17
# Epoch 58 --- loss:1.934, Epoch accuracy:18.90%, Validation loss:2.038, Validation accuracy:18.17%
# Epoch 59: iteration 16/17
# Epoch 59 --- loss:1.931, Epoch accuracy:19.17%, Validation loss:2.038, Validation accuracy:18.83%
# Epoch 60: iteration 16/17
# Epoch 60 --- loss:1.922, Epoch accuracy:20.09%, Validation loss:2.039, Validation accuracy:18.33%
# Epoch 61: iteration 16/17
# Epoch 61 --- loss:1.935, Epoch accuracy:18.90%, Validation loss:2.039, Validation accuracy:17.83%
# Epoch 62: iteration 16/17
# Epoch 62 --- loss:1.929, Epoch accuracy:18.51%, Validation loss:2.041, Validation accuracy:18.83%
# Epoch 63: iteration 16/17
# Epoch 63 --- loss:1.922, Epoch accuracy:18.51%, Validation loss:2.039, Validation accuracy:18.67%
# Epoch 64: iteration 16/17
# Epoch 64 --- loss:1.927, Epoch accuracy:20.09%, Validation loss:2.039, Validation accuracy:18.17%
# Epoch 65: iteration 16/17
# Epoch 65 --- loss:1.922, Epoch accuracy:20.66%, Validation loss:2.039, Validation accuracy:17.33%
# Epoch 66: iteration 16/17
# Epoch 66 --- loss:1.912, Epoch accuracy:20.48%, Validation loss:2.042, Validation accuracy:19.00%
# Epoch 67: iteration 16/17
# Epoch 67 --- loss:1.928, Epoch accuracy:19.69%, Validation loss:2.037, Validation accuracy:17.50%
# Epoch 68: iteration 16/17
# Epoch 68 --- loss:1.922, Epoch accuracy:19.61%, Validation loss:2.038, Validation accuracy:17.67%
# Epoch 69: iteration 16/17
# Epoch 69 --- loss:1.925, Epoch accuracy:19.12%, Validation loss:2.038, Validation accuracy:18.33%
# Epoch 70: iteration 16/17
# Epoch 70 --- loss:1.924, Epoch accuracy:19.82%, Validation loss:2.040, Validation accuracy:18.17%
# Epoch 71: iteration 16/17
# Epoch 71 --- loss:1.933, Epoch accuracy:18.86%, Validation loss:2.038, Validation accuracy:19.67%
# Epoch 72: iteration 16/17
# Epoch 72 --- loss:1.925, Epoch accuracy:20.53%, Validation loss:2.038, Validation accuracy:17.67%
# Epoch 73: iteration 16/17
# Epoch 73 --- loss:1.907, Epoch accuracy:21.01%, Validation loss:2.040, Validation accuracy:17.17%
# Epoch 74: iteration 16/17
# Epoch 74 --- loss:1.920, Epoch accuracy:20.22%, Validation loss:2.041, Validation accuracy:17.50%
# Epoch 75: iteration 16/17
# Epoch 75 --- loss:1.931, Epoch accuracy:18.73%, Validation loss:2.039, Validation accuracy:17.83%
# Epoch 76: iteration 16/17
# Epoch 76 --- loss:1.915, Epoch accuracy:19.61%, Validation loss:2.039, Validation accuracy:17.50%
# Epoch 77: iteration 16/17
# Epoch 77 --- loss:1.915, Epoch accuracy:20.39%, Validation loss:2.040, Validation accuracy:17.83%
# Epoch 78: iteration 16/17
# Epoch 78 --- loss:1.914, Epoch accuracy:20.22%, Validation loss:2.040, Validation accuracy:18.33%
# Epoch 79: iteration 16/17
# Epoch 79 --- loss:1.919, Epoch accuracy:19.78%, Validation loss:2.040, Validation accuracy:19.00%
# Epoch 80: iteration 16/17
# Epoch 80 --- loss:1.922, Epoch accuracy:20.61%, Validation loss:2.039, Validation accuracy:18.67%
# Epoch 81: iteration 16/17
# Epoch 81 --- loss:1.931, Epoch accuracy:19.25%, Validation loss:2.040, Validation accuracy:17.33%
# Epoch 82: iteration 16/17
# Epoch 82 --- loss:1.925, Epoch accuracy:19.17%, Validation loss:2.043, Validation accuracy:17.67%
# Epoch 83: iteration 16/17
# Epoch 83 --- loss:1.909, Epoch accuracy:19.39%, Validation loss:2.039, Validation accuracy:18.17%
# Epoch 84: iteration 16/17
# Epoch 84 --- loss:1.917, Epoch accuracy:20.04%, Validation loss:2.041, Validation accuracy:17.00%
# Epoch 85: iteration 16/17
# Epoch 85 --- loss:1.923, Epoch accuracy:18.86%, Validation loss:2.040, Validation accuracy:18.67%
# Epoch 86: iteration 16/17
# Epoch 86 --- loss:1.920, Epoch accuracy:19.65%, Validation loss:2.043, Validation accuracy:17.00%
# Epoch 87: iteration 16/17
# Epoch 87 --- loss:1.915, Epoch accuracy:18.60%, Validation loss:2.039, Validation accuracy:19.17%
# Epoch 88: iteration 16/17
# Epoch 88 --- loss:1.902, Epoch accuracy:21.67%, Validation loss:2.040, Validation accuracy:17.50%
# Epoch 89: iteration 16/17
# Epoch 89 --- loss:1.908, Epoch accuracy:19.08%, Validation loss:2.039, Validation accuracy:18.33%
# Epoch 90: iteration 16/17
# Epoch 90 --- loss:1.929, Epoch accuracy:18.60%, Validation loss:2.042, Validation accuracy:18.33%
# Epoch 91: iteration 16/17
# Epoch 91 --- loss:1.916, Epoch accuracy:19.82%, Validation loss:2.040, Validation accuracy:17.17%
# Epoch 92: iteration 16/17
# Epoch 92 --- loss:1.914, Epoch accuracy:19.43%, Validation loss:2.042, Validation accuracy:17.67%
# Epoch 93: iteration 16/17
# Epoch 93 --- loss:1.916, Epoch accuracy:20.57%, Validation loss:2.040, Validation accuracy:19.67%
# Epoch 94: iteration 16/17
# Epoch 94 --- loss:1.915, Epoch accuracy:19.87%, Validation loss:2.044, Validation accuracy:18.00%
# Epoch 95: iteration 16/17
# Epoch 95 --- loss:1.926, Epoch accuracy:18.60%, Validation loss:2.041, Validation accuracy:19.00%
# Epoch 96: iteration 16/17
# Epoch 96 --- loss:1.919, Epoch accuracy:19.25%, Validation loss:2.045, Validation accuracy:19.00%
# Epoch 97: iteration 16/17
# Epoch 97 --- loss:1.929, Epoch accuracy:19.47%, Validation loss:2.043, Validation accuracy:16.67%
# Epoch 98: iteration 16/17
# Epoch 98 --- loss:1.916, Epoch accuracy:20.57%, Validation loss:2.043, Validation accuracy:19.33%
# Epoch 99: iteration 16/17
# Epoch 99 --- loss:1.902, Epoch accuracy:21.84%, Validation loss:2.045, Validation accuracy:15.83%
# Epoch 100: iteration 16/17
# Epoch 100 --- loss:1.909, Epoch accuracy:20.53%, Validation loss:2.042, Validation accuracy:17.67%
# Epoch 101: iteration 16/17
# Epoch 101 --- loss:1.900, Epoch accuracy:21.27%, Validation loss:2.043, Validation accuracy:17.50%
# Epoch 102: iteration 16/17
# Epoch 102 --- loss:1.904, Epoch accuracy:20.31%, Validation loss:2.043, Validation accuracy:17.33%
# Epoch 103: iteration 16/17
# Epoch 103 --- loss:1.908, Epoch accuracy:20.09%, Validation loss:2.044, Validation accuracy:17.33%
# Epoch 104: iteration 16/17
# Epoch 104 --- loss:1.902, Epoch accuracy:20.00%, Validation loss:2.045, Validation accuracy:17.00%
# Epoch 105: iteration 16/17
# Epoch 105 --- loss:1.911, Epoch accuracy:19.96%, Validation loss:2.043, Validation accuracy:19.00%
# Epoch 106: iteration 16/17
# Epoch 106 --- loss:1.902, Epoch accuracy:21.23%, Validation loss:2.048, Validation accuracy:17.67%
# Epoch 107: iteration 16/17
# Epoch 107 --- loss:1.893, Epoch accuracy:22.94%, Validation loss:2.042, Validation accuracy:18.33%
# Epoch 108: iteration 16/17
# Epoch 108 --- loss:1.915, Epoch accuracy:20.70%, Validation loss:2.044, Validation accuracy:16.67%
# Epoch 109: iteration 16/17
# Epoch 109 --- loss:1.906, Epoch accuracy:20.31%, Validation loss:2.045, Validation accuracy:17.17%
# Epoch 110: iteration 16/17
# Epoch 110 --- loss:1.917, Epoch accuracy:19.91%, Validation loss:2.048, Validation accuracy:18.67%
# Epoch 111: iteration 16/17
# Epoch 111 --- loss:1.896, Epoch accuracy:22.28%, Validation loss:2.046, Validation accuracy:16.67%
# Epoch 112: iteration 16/17
# Epoch 112 --- loss:1.894, Epoch accuracy:21.49%, Validation loss:2.044, Validation accuracy:17.67%
# Epoch 113: iteration 16/17
# Epoch 113 --- loss:1.915, Epoch accuracy:20.70%, Validation loss:2.046, Validation accuracy:17.00%
# Epoch 114: iteration 16/17
# Epoch 114 --- loss:1.904, Epoch accuracy:20.66%, Validation loss:2.043, Validation accuracy:18.33%
# Epoch 115: iteration 16/17
# Epoch 115 --- loss:1.908, Epoch accuracy:19.91%, Validation loss:2.049, Validation accuracy:16.83%
# Epoch 116: iteration 16/17
# Epoch 116 --- loss:1.907, Epoch accuracy:20.61%, Validation loss:2.044, Validation accuracy:18.67%
# Epoch 117: iteration 16/17
# Epoch 117 --- loss:1.914, Epoch accuracy:20.48%, Validation loss:2.045, Validation accuracy:19.00%
# Epoch 118: iteration 16/17
# Epoch 118 --- loss:1.911, Epoch accuracy:20.09%, Validation loss:2.049, Validation accuracy:16.50%
# Epoch 119: iteration 16/17
# Epoch 119 --- loss:1.903, Epoch accuracy:20.31%, Validation loss:2.045, Validation accuracy:18.67%
# Epoch 120: iteration 16/17
# Epoch 120 --- loss:1.906, Epoch accuracy:20.35%, Validation loss:2.047, Validation accuracy:15.83%
# Epoch 121: iteration 16/17
# Epoch 121 --- loss:1.908, Epoch accuracy:20.44%, Validation loss:2.047, Validation accuracy:17.17%
# Epoch 122: iteration 16/17
# Epoch 122 --- loss:1.917, Epoch accuracy:19.56%, Validation loss:2.047, Validation accuracy:17.17%
# Epoch 123: iteration 16/17
# Epoch 123 --- loss:1.905, Epoch accuracy:20.66%, Validation loss:2.047, Validation accuracy:17.17%
# Epoch 124: iteration 16/17
# Epoch 124 --- loss:1.908, Epoch accuracy:20.57%, Validation loss:2.051, Validation accuracy:18.17%
# Epoch 125: iteration 16/17
# Epoch 125 --- loss:1.915, Epoch accuracy:19.47%, Validation loss:2.048, Validation accuracy:18.00%
# Epoch 126: iteration 16/17
# Epoch 126 --- loss:1.920, Epoch accuracy:19.08%, Validation loss:2.048, Validation accuracy:17.67%
# Epoch 127: iteration 16/17
# Epoch 127 --- loss:1.901, Epoch accuracy:21.32%, Validation loss:2.047, Validation accuracy:18.17%
# Epoch 128: iteration 16/17
# Epoch 128 --- loss:1.910, Epoch accuracy:20.35%, Validation loss:2.057, Validation accuracy:18.50%
# Epoch 129: iteration 16/17
# Epoch 129 --- loss:1.898, Epoch accuracy:20.70%, Validation loss:2.050, Validation accuracy:16.67%
# Epoch 130: iteration 16/17
# Epoch 130 --- loss:1.912, Epoch accuracy:20.13%, Validation loss:2.050, Validation accuracy:17.33%
# Epoch 131: iteration 16/17
# Epoch 131 --- loss:1.900, Epoch accuracy:21.32%, Validation loss:2.047, Validation accuracy:18.00%
# Epoch 132: iteration 16/17
# Epoch 132 --- loss:1.905, Epoch accuracy:20.48%, Validation loss:2.052, Validation accuracy:15.83%
# Epoch 133: iteration 16/17
# Epoch 133 --- loss:1.914, Epoch accuracy:19.91%, Validation loss:2.052, Validation accuracy:18.00%
# Epoch 134: iteration 16/17
# Epoch 134 --- loss:1.914, Epoch accuracy:20.31%, Validation loss:2.052, Validation accuracy:17.33%
# Epoch 135: iteration 16/17
# Epoch 135 --- loss:1.918, Epoch accuracy:21.27%, Validation loss:2.049, Validation accuracy:18.17%
# Epoch 136: iteration 16/17
# Epoch 136 --- loss:1.911, Epoch accuracy:20.09%, Validation loss:2.050, Validation accuracy:17.17%
# Epoch 137: iteration 16/17
# Epoch 137 --- loss:1.897, Epoch accuracy:21.14%, Validation loss:2.053, Validation accuracy:18.33%
# Epoch 138: iteration 16/17
# Epoch 138 --- loss:1.920, Epoch accuracy:19.65%, Validation loss:2.052, Validation accuracy:16.67%
# Epoch 139: iteration 16/17
# Epoch 139 --- loss:1.918, Epoch accuracy:19.47%, Validation loss:2.052, Validation accuracy:16.83%
# Epoch 140: iteration 16/17
# Epoch 140 --- loss:1.917, Epoch accuracy:19.12%, Validation loss:2.052, Validation accuracy:18.17%
# Epoch 141: iteration 16/17
# Epoch 141 --- loss:1.910, Epoch accuracy:20.00%, Validation loss:2.055, Validation accuracy:16.83%
# Epoch 142: iteration 16/17
# Epoch 142 --- loss:1.908, Epoch accuracy:18.73%, Validation loss:2.054, Validation accuracy:18.67%
# Epoch 143: iteration 16/17
# Epoch 143 --- loss:1.904, Epoch accuracy:21.27%, Validation loss:2.053, Validation accuracy:15.83%
# Epoch 144: iteration 16/17
# Epoch 144 --- loss:1.911, Epoch accuracy:20.22%, Validation loss:2.056, Validation accuracy:17.17%
# Epoch 145: iteration 16/17
# Epoch 145 --- loss:1.913, Epoch accuracy:20.66%, Validation loss:2.050, Validation accuracy:18.33%
# Epoch 146: iteration 16/17
# Epoch 146 --- loss:1.912, Epoch accuracy:20.18%, Validation loss:2.056, Validation accuracy:18.50%
# Epoch 147: iteration 16/17
# Epoch 147 --- loss:1.914, Epoch accuracy:20.79%, Validation loss:2.053, Validation accuracy:16.00%
# Epoch 148: iteration 16/17
# Epoch 148 --- loss:1.909, Epoch accuracy:20.61%, Validation loss:2.058, Validation accuracy:16.67%
# Epoch 149: iteration 16/17
# Epoch 149 --- loss:1.901, Epoch accuracy:20.04%, Validation loss:2.055, Validation accuracy:18.17%
# Epoch 150: iteration 16/17
# Epoch 150 --- loss:1.913, Epoch accuracy:20.44%, Validation loss:2.053, Validation accuracy:18.00%
# Epoch 151: iteration 16/17
# Epoch 151 --- loss:1.902, Epoch accuracy:20.70%, Validation loss:2.057, Validation accuracy:16.50%
# Epoch 152: iteration 16/17
# Epoch 152 --- loss:1.911, Epoch accuracy:20.57%, Validation loss:2.053, Validation accuracy:17.00%
# Epoch 153: iteration 16/17
# Epoch 153 --- loss:1.899, Epoch accuracy:22.24%, Validation loss:2.059, Validation accuracy:16.33%
# Epoch 154: iteration 16/17
# Epoch 154 --- loss:1.909, Epoch accuracy:20.13%, Validation loss:2.056, Validation accuracy:17.33%
# Epoch 155: iteration 16/17
# Epoch 155 --- loss:1.918, Epoch accuracy:19.74%, Validation loss:2.055, Validation accuracy:17.83%
# Epoch 156: iteration 16/17
# Epoch 156 --- loss:1.902, Epoch accuracy:20.48%, Validation loss:2.057, Validation accuracy:17.00%
# Epoch 157: iteration 16/17
# Epoch 157 --- loss:1.904, Epoch accuracy:20.57%, Validation loss:2.057, Validation accuracy:16.83%
# Epoch 158: iteration 16/17
# Epoch 158 --- loss:1.916, Epoch accuracy:19.82%, Validation loss:2.058, Validation accuracy:18.17%
# Epoch 159: iteration 16/17
# Epoch 159 --- loss:1.907, Epoch accuracy:20.66%, Validation loss:2.059, Validation accuracy:16.17%
# Epoch 160: iteration 16/17
# Epoch 160 --- loss:1.926, Epoch accuracy:20.04%, Validation loss:2.057, Validation accuracy:16.33%
# Epoch 161: iteration 16/17
# Epoch 161 --- loss:1.901, Epoch accuracy:20.57%, Validation loss:2.058, Validation accuracy:17.17%
# Epoch 162: iteration 16/17
# Epoch 162 --- loss:1.910, Epoch accuracy:20.61%, Validation loss:2.056, Validation accuracy:16.67%
# Epoch 163: iteration 16/17
# Epoch 163 --- loss:1.925, Epoch accuracy:19.25%, Validation loss:2.058, Validation accuracy:16.33%
# Epoch 164: iteration 16/17
# Epoch 164 --- loss:1.906, Epoch accuracy:20.57%, Validation loss:2.062, Validation accuracy:17.33%
# Epoch 165: iteration 16/17
# Epoch 165 --- loss:1.920, Epoch accuracy:19.78%, Validation loss:2.054, Validation accuracy:17.50%
# Epoch 166: iteration 16/17
# Epoch 166 --- loss:1.905, Epoch accuracy:19.82%, Validation loss:2.063, Validation accuracy:17.33%
# Epoch 167: iteration 16/17
# Epoch 167 --- loss:1.916, Epoch accuracy:18.95%, Validation loss:2.053, Validation accuracy:17.83%
# Epoch 168: iteration 16/17
# Epoch 168 --- loss:1.915, Epoch accuracy:20.09%, Validation loss:2.060, Validation accuracy:15.67%
# Epoch 169: iteration 16/17
# Epoch 169 --- loss:1.899, Epoch accuracy:19.87%, Validation loss:2.056, Validation accuracy:18.50%
# Epoch 170: iteration 16/17
# Epoch 170 --- loss:1.909, Epoch accuracy:20.48%, Validation loss:2.061, Validation accuracy:16.33%
# Epoch 171: iteration 16/17
# Epoch 171 --- loss:1.910, Epoch accuracy:19.43%, Validation loss:2.058, Validation accuracy:16.67%
# Epoch 172: iteration 16/17
# Epoch 172 --- loss:1.917, Epoch accuracy:20.22%, Validation loss:2.062, Validation accuracy:18.00%
# Epoch 173: iteration 16/17
# Epoch 173 --- loss:1.910, Epoch accuracy:19.61%, Validation loss:2.057, Validation accuracy:17.50%
# Epoch 174: iteration 16/17
# Epoch 174 --- loss:1.909, Epoch accuracy:20.96%, Validation loss:2.059, Validation accuracy:16.67%
# Epoch 175: iteration 16/17
# Epoch 175 --- loss:1.921, Epoch accuracy:19.52%, Validation loss:2.059, Validation accuracy:17.33%
# Epoch 176: iteration 16/17
# Epoch 176 --- loss:1.910, Epoch accuracy:20.09%, Validation loss:2.062, Validation accuracy:16.50%
# Epoch 177: iteration 16/17
# Epoch 177 --- loss:1.913, Epoch accuracy:21.40%, Validation loss:2.058, Validation accuracy:19.17%
# Epoch 178: iteration 16/17
# Epoch 178 --- loss:1.916, Epoch accuracy:20.13%, Validation loss:2.060, Validation accuracy:15.83%
# Epoch 179: iteration 16/17
# Epoch 179 --- loss:1.915, Epoch accuracy:20.31%, Validation loss:2.058, Validation accuracy:16.33%
# Epoch 180: iteration 16/17
# Epoch 180 --- loss:1.920, Epoch accuracy:19.47%, Validation loss:2.057, Validation accuracy:17.33%
# Epoch 181: iteration 16/17
# Epoch 181 --- loss:1.908, Epoch accuracy:19.39%, Validation loss:2.067, Validation accuracy:17.50%
# Epoch 182: iteration 16/17
# Epoch 182 --- loss:1.914, Epoch accuracy:21.10%, Validation loss:2.060, Validation accuracy:15.67%
# Epoch 183: iteration 16/17
# Epoch 183 --- loss:1.916, Epoch accuracy:19.69%, Validation loss:2.060, Validation accuracy:18.00%
# Epoch 184: iteration 16/17
# Epoch 184 --- loss:1.910, Epoch accuracy:20.31%, Validation loss:2.065, Validation accuracy:16.00%
# Epoch 185: iteration 16/17
# Epoch 185 --- loss:1.915, Epoch accuracy:19.25%, Validation loss:2.057, Validation accuracy:17.83%
# Epoch 186: iteration 16/17
# Epoch 186 --- loss:1.907, Epoch accuracy:19.65%, Validation loss:2.061, Validation accuracy:16.50%
# Epoch 187: iteration 16/17
# Epoch 187 --- loss:1.922, Epoch accuracy:19.21%, Validation loss:2.063, Validation accuracy:17.83%
# Epoch 188: iteration 16/17
# Epoch 188 --- loss:1.899, Epoch accuracy:20.48%, Validation loss:2.061, Validation accuracy:15.83%
# Epoch 189: iteration 16/17
# Epoch 189 --- loss:1.921, Epoch accuracy:19.91%, Validation loss:2.061, Validation accuracy:17.00%
# Epoch 190: iteration 16/17
# Epoch 190 --- loss:1.914, Epoch accuracy:19.69%, Validation loss:2.059, Validation accuracy:16.17%
# Epoch 191: iteration 16/17
# Epoch 191 --- loss:1.914, Epoch accuracy:19.96%, Validation loss:2.062, Validation accuracy:16.67%
# Epoch 192: iteration 16/17
# Epoch 192 --- loss:1.924, Epoch accuracy:19.30%, Validation loss:2.060, Validation accuracy:18.00%
# Epoch 193: iteration 16/17
# Epoch 193 --- loss:1.916, Epoch accuracy:20.18%, Validation loss:2.059, Validation accuracy:15.83%
# Epoch 194: iteration 16/17
# Epoch 194 --- loss:1.912, Epoch accuracy:19.78%, Validation loss:2.071, Validation accuracy:16.50%
# Epoch 195: iteration 16/17
# Epoch 195 --- loss:1.916, Epoch accuracy:19.52%, Validation loss:2.058, Validation accuracy:15.67%
# Epoch 196: iteration 16/17
# Epoch 196 --- loss:1.927, Epoch accuracy:19.56%, Validation loss:2.065, Validation accuracy:16.33%
# Epoch 197: iteration 16/17
# Epoch 197 --- loss:1.921, Epoch accuracy:20.22%, Validation loss:2.063, Validation accuracy:18.00%
# Epoch 198: iteration 16/17
# Epoch 198 --- loss:1.915, Epoch accuracy:20.61%, Validation loss:2.061, Validation accuracy:16.83%
# Epoch 199: iteration 16/17
# Epoch 199 --- loss:1.915, Epoch accuracy:21.18%, Validation loss:2.058, Validation accuracy:17.00%
# Epoch 200: iteration 16/17
# Epoch 200 --- loss:1.910, Epoch accuracy:20.39%, Validation loss:2.065, Validation accuracy:16.00%
# Epoch 201: iteration 16/17
# Epoch 201 --- loss:1.919, Epoch accuracy:19.96%, Validation loss:2.065, Validation accuracy:17.83%
# Epoch 202: iteration 16/17
# Epoch 202 --- loss:1.925, Epoch accuracy:18.86%, Validation loss:2.060, Validation accuracy:17.83%
# Epoch 203: iteration 16/17
# Epoch 203 --- loss:1.919, Epoch accuracy:20.13%, Validation loss:2.063, Validation accuracy:17.67%
# Epoch 204: iteration 16/17
# Epoch 204 --- loss:1.913, Epoch accuracy:19.25%, Validation loss:2.058, Validation accuracy:17.67%
# Epoch 205: iteration 16/17
# Epoch 205 --- loss:1.921, Epoch accuracy:19.12%, Validation loss:2.062, Validation accuracy:16.17%
# Epoch 206: iteration 16/17
# Epoch 206 --- loss:1.922, Epoch accuracy:19.34%, Validation loss:2.060, Validation accuracy:17.67%
# Epoch 207: iteration 16/17
# Epoch 207 --- loss:1.919, Epoch accuracy:18.60%, Validation loss:2.063, Validation accuracy:17.17%
# Epoch 208: iteration 16/17
# Epoch 208 --- loss:1.901, Epoch accuracy:21.49%, Validation loss:2.061, Validation accuracy:17.00%
# Epoch 209: iteration 16/17
# Epoch 209 --- loss:1.923, Epoch accuracy:18.82%, Validation loss:2.061, Validation accuracy:16.83%
# Epoch 210: iteration 16/17
# Epoch 210 --- loss:1.914, Epoch accuracy:20.44%, Validation loss:2.070, Validation accuracy:17.67%
# Epoch 211: iteration 16/17
# Epoch 211 --- loss:1.913, Epoch accuracy:20.66%, Validation loss:2.066, Validation accuracy:16.50%
# Epoch 212: iteration 16/17
# Epoch 212 --- loss:1.914, Epoch accuracy:20.26%, Validation loss:2.059, Validation accuracy:16.17%
# Epoch 213: iteration 16/17
# Epoch 213 --- loss:1.914, Epoch accuracy:19.21%, Validation loss:2.064, Validation accuracy:16.50%
# Epoch 214: iteration 16/17
# Epoch 214 --- loss:1.919, Epoch accuracy:19.87%, Validation loss:2.061, Validation accuracy:16.00%
# Epoch 215: iteration 16/17
# Epoch 215 --- loss:1.920, Epoch accuracy:20.00%, Validation loss:2.062, Validation accuracy:16.83%
# Epoch 216: iteration 16/17
# Epoch 216 --- loss:1.913, Epoch accuracy:19.52%, Validation loss:2.063, Validation accuracy:18.00%
# Epoch 217: iteration 16/17
# Epoch 217 --- loss:1.922, Epoch accuracy:18.77%, Validation loss:2.062, Validation accuracy:17.50%
# Epoch 218: iteration 16/17
# Epoch 218 --- loss:1.917, Epoch accuracy:20.09%, Validation loss:2.062, Validation accuracy:16.00%
# Epoch 219: iteration 16/17
# Epoch 219 --- loss:1.908, Epoch accuracy:20.75%, Validation loss:2.070, Validation accuracy:15.83%
# Epoch 220: iteration 16/17
# Epoch 220 --- loss:1.919, Epoch accuracy:19.47%, Validation loss:2.065, Validation accuracy:16.83%
# Epoch 221: iteration 16/17
# Epoch 221 --- loss:1.919, Epoch accuracy:18.51%, Validation loss:2.063, Validation accuracy:16.83%
# Epoch 222: iteration 16/17
# Epoch 222 --- loss:1.910, Epoch accuracy:20.83%, Validation loss:2.060, Validation accuracy:17.17%
# Epoch 223: iteration 16/17
# Epoch 223 --- loss:1.913, Epoch accuracy:20.66%, Validation loss:2.065, Validation accuracy:16.67%
# Epoch 224: iteration 16/17
# Epoch 224 --- loss:1.925, Epoch accuracy:19.43%, Validation loss:2.065, Validation accuracy:16.67%
# Epoch 225: iteration 16/17
# Epoch 225 --- loss:1.925, Epoch accuracy:18.29%, Validation loss:2.058, Validation accuracy:17.17%
# Epoch 226: iteration 16/17
# Epoch 226 --- loss:1.925, Epoch accuracy:18.33%, Validation loss:2.067, Validation accuracy:16.00%
# Epoch 227: iteration 16/17
# Epoch 227 --- loss:1.909, Epoch accuracy:19.82%, Validation loss:2.063, Validation accuracy:17.33%
# Epoch 228: iteration 16/17
# Epoch 228 --- loss:1.931, Epoch accuracy:18.51%, Validation loss:2.062, Validation accuracy:16.50%
# Epoch 229: iteration 16/17
# Epoch 229 --- loss:1.921, Epoch accuracy:19.39%, Validation loss:2.062, Validation accuracy:16.17%
# Epoch 230: iteration 16/17
# Epoch 230 --- loss:1.916, Epoch accuracy:18.68%, Validation loss:2.067, Validation accuracy:16.83%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 20
#      17 model = Model(num_emotions=len(emotions_dict)).to('cuda')
#      18 optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
# ---> 20 train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
#      22 plt.title('Loss Curve')
#      23 plt.ylabel('Loss', fontsize=16)
#
# Cell In [9], line 35, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer)
#      32 train_indices = np.random.permutation(train_size)
#      34 # shuffle the training set for each epoch:
# ---> 35 X_train = X_train[train_indices, :, :, :]
#      36 Y_train = Y_train[train_indices]
#      38 # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    
    break

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    break
