# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'LIGHT-SERNET-ReduceLROnPlateau'
data_name = 'RAVDESS'

minibatch = 32
num_epochs = 500
EARLY_CNT = 99999

learning_rate = 1e-5
lr_patience = 50

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.cnn1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=[3,3], padding=[1,0]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        self.cnn2 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=[9,1], padding=[4,0]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        self.cnn3 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=[1,11]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        
        self.LFLB = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1]),
            
            nn.Conv2d(64, 96, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1]),
            
            nn.Conv2d(96, 128, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d([2,1], padding=[1,0]),
            
            nn.Conv2d(128, 160, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(160),
            nn.ReLU(),
            nn.MaxPool2d([2,1], padding=[1,0]),
            
            nn.Conv2d(160, 320, kernel_size=[1,1]),
            nn.BatchNorm2d(320),
            nn.ReLU()
        )
        
        self.fc = nn.Linear(320, num_emotions)

    def forward(self, x):
        
        embd1 = self.cnn1(x)
        embd2 = self.cnn2(x)
        embd3 = self.cnn3(x)
        concat_embd = torch.cat([embd1, embd2, embd3], dim=3)
        
        lflb_embd = self.LFLB(concat_embd)
        out = F.adaptive_avg_pool2d(lflb_embd, (1,1))
        out = nn.Dropout(0.3)(out)
        out = torch.flatten(out, start_dim=1)
        
        output_logits = self.fc(out)
        output_softmax = nn.Softmax(dim=1)(output_logits)
        
        return output_logits, output_softmax
    

model = Model(8)
print(summary(model, (1140, 1, 40, 184)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [1140, 8]                 --
# ├─Sequential: 1-1                        [1140, 32, 21, 92]        --
# │    └─Conv2d: 2-1                       [1140, 32, 40, 182]       320
# │    └─BatchNorm2d: 2-2                  [1140, 32, 40, 182]       64
# │    └─ReLU: 2-3                         [1140, 32, 40, 182]       --
# │    └─MaxPool2d: 2-4                    [1140, 32, 21, 92]        --
# ├─Sequential: 1-2                        [1140, 32, 21, 93]        --
# │    └─Conv2d: 2-5                       [1140, 32, 40, 184]       320
# │    └─BatchNorm2d: 2-6                  [1140, 32, 40, 184]       64
# │    └─ReLU: 2-7                         [1140, 32, 40, 184]       --
# │    └─MaxPool2d: 2-8                    [1140, 32, 21, 93]        --
# ├─Sequential: 1-3                        [1140, 32, 21, 88]        --
# │    └─Conv2d: 2-9                       [1140, 32, 40, 174]       384
# │    └─BatchNorm2d: 2-10                 [1140, 32, 40, 174]       64
# │    └─ReLU: 2-11                        [1140, 32, 40, 174]       --
# │    └─MaxPool2d: 2-12                   [1140, 32, 21, 88]        --
# ├─Sequential: 1-4                        [1140, 320, 3, 69]        --
# │    └─Conv2d: 2-13                      [1140, 64, 21, 273]       18,496
# │    └─BatchNorm2d: 2-14                 [1140, 64, 21, 273]       128
# │    └─ReLU: 2-15                        [1140, 64, 21, 273]       --
# │    └─MaxPool2d: 2-16                   [1140, 64, 11, 137]       --
# │    └─Conv2d: 2-17                      [1140, 96, 11, 137]       55,392
# │    └─BatchNorm2d: 2-18                 [1140, 96, 11, 137]       192
# │    └─ReLU: 2-19                        [1140, 96, 11, 137]       --
# │    └─MaxPool2d: 2-20                   [1140, 96, 6, 69]         --
# │    └─Conv2d: 2-21                      [1140, 128, 6, 69]        110,720
# │    └─BatchNorm2d: 2-22                 [1140, 128, 6, 69]        256
# │    └─ReLU: 2-23                        [1140, 128, 6, 69]        --
# │    └─MaxPool2d: 2-24                   [1140, 128, 4, 69]        --
# │    └─Conv2d: 2-25                      [1140, 160, 4, 69]        184,480
# │    └─BatchNorm2d: 2-26                 [1140, 160, 4, 69]        320
# │    └─ReLU: 2-27                        [1140, 160, 4, 69]        --
# │    └─MaxPool2d: 2-28                   [1140, 160, 3, 69]        --
# │    └─Conv2d: 2-29                      [1140, 320, 3, 69]        51,520
# │    └─BatchNorm2d: 2-30                 [1140, 320, 3, 69]        640
# │    └─ReLU: 2-31                        [1140, 320, 3, 69]        --
# ├─Linear: 1-5                            [1140, 8]                 2,568
# ==========================================================================================
# Total params: 425,928
# Trainable params: 425,928
# Non-trainable params: 0
# Total mult-adds (G): 346.90
# ==========================================================================================
# Input size (MB): 33.56
# Forward/backward pass size (MB): 24919.12
# Params size (MB): 1.70
# Estimated Total Size (MB): 24954.39
# ==========================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer, scheduler):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs)):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        scheduler.step(valid_loss)
        print(f"\nEpoch {epoch} --- lr: ", optimizer.param_groups[0]['lr'])
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'LIGHT-SERNET dataset'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=0.1, patience=lr_patience, min_lr=1e-6)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer, scheduler)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - LIGHT-SERNET-ReduceLROnPlateau
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 34/35
# Epoch 0 --- lr:  1e-05
# loss:2.053, Epoch accuracy:12.02%, Validation loss:2.074, Validation accuracy:13.67%
# Epoch 1: iteration 34/35
# Epoch 1 --- lr:  1e-05
# loss:2.025, Epoch accuracy:14.65%, Validation loss:2.049, Validation accuracy:13.67%
# Epoch 2: iteration 34/35
# Epoch 2 --- lr:  1e-05
# loss:2.005, Epoch accuracy:19.04%, Validation loss:2.038, Validation accuracy:18.00%
# Epoch 3: iteration 34/35
# Epoch 3 --- lr:  1e-05
# loss:1.993, Epoch accuracy:20.00%, Validation loss:2.029, Validation accuracy:18.33%
# Epoch 4: iteration 34/35
# Epoch 4 --- lr:  1e-05
# loss:1.969, Epoch accuracy:23.07%, Validation loss:2.001, Validation accuracy:24.00%
# Epoch 5: iteration 34/35
# Epoch 5 --- lr:  1e-05
# loss:1.955, Epoch accuracy:24.39%, Validation loss:1.985, Validation accuracy:23.33%
# Epoch 6: iteration 34/35
# Epoch 6 --- lr:  1e-05
# loss:1.941, Epoch accuracy:27.63%, Validation loss:1.976, Validation accuracy:24.67%
# Epoch 7: iteration 34/35
# Epoch 7 --- lr:  1e-05
# loss:1.922, Epoch accuracy:26.05%, Validation loss:1.941, Validation accuracy:26.33%
# Epoch 8: iteration 34/35
# Epoch 8 --- lr:  1e-05
# loss:1.891, Epoch accuracy:28.68%, Validation loss:1.925, Validation accuracy:27.00%
# Epoch 9: iteration 34/35
# Epoch 9 --- lr:  1e-05
# loss:1.879, Epoch accuracy:28.68%, Validation loss:1.916, Validation accuracy:24.33%
# Epoch 10: iteration 34/35
# Epoch 10 --- lr:  1e-05
# loss:1.864, Epoch accuracy:28.68%, Validation loss:1.901, Validation accuracy:27.00%
# Epoch 11: iteration 34/35
# Epoch 11 --- lr:  1e-05
# loss:1.842, Epoch accuracy:32.72%, Validation loss:1.894, Validation accuracy:24.67%
# Epoch 12: iteration 34/35
# Epoch 12 --- lr:  1e-05
# loss:1.830, Epoch accuracy:30.18%, Validation loss:1.852, Validation accuracy:30.00%
# Epoch 13: iteration 34/35
# Epoch 13 --- lr:  1e-05
# loss:1.812, Epoch accuracy:33.25%, Validation loss:1.845, Validation accuracy:30.00%
# Epoch 14: iteration 34/35
# Epoch 14 --- lr:  1e-05
# loss:1.796, Epoch accuracy:33.60%, Validation loss:1.830, Validation accuracy:32.67%
# Epoch 15: iteration 34/35
# Epoch 15 --- lr:  1e-05
# loss:1.783, Epoch accuracy:33.16%, Validation loss:1.820, Validation accuracy:29.67%
# Epoch 16: iteration 34/35
# Epoch 16 --- lr:  1e-05
# loss:1.773, Epoch accuracy:34.47%, Validation loss:1.825, Validation accuracy:29.67%
# Epoch 17: iteration 34/35
# Epoch 17 --- lr:  1e-05
# loss:1.757, Epoch accuracy:35.00%, Validation loss:1.799, Validation accuracy:32.33%
# Epoch 18: iteration 34/35
# Epoch 18 --- lr:  1e-05
# loss:1.734, Epoch accuracy:35.96%, Validation loss:1.784, Validation accuracy:36.33%
# Epoch 19: iteration 34/35
# Epoch 19 --- lr:  1e-05
# loss:1.732, Epoch accuracy:38.07%, Validation loss:1.773, Validation accuracy:32.00%
# Epoch 20: iteration 34/35
# Epoch 20 --- lr:  1e-05
# loss:1.702, Epoch accuracy:38.25%, Validation loss:1.777, Validation accuracy:34.00%
# Epoch 21: iteration 34/35
# Epoch 21 --- lr:  1e-05
# loss:1.702, Epoch accuracy:38.68%, Validation loss:1.749, Validation accuracy:36.67%
# Epoch 22: iteration 34/35
# Epoch 22 --- lr:  1e-05
# loss:1.689, Epoch accuracy:40.79%, Validation loss:1.701, Validation accuracy:41.33%
# Epoch 23: iteration 34/35
# Epoch 23 --- lr:  1e-05
# loss:1.668, Epoch accuracy:41.93%, Validation loss:1.721, Validation accuracy:37.67%
# Epoch 24: iteration 34/35
# Epoch 24 --- lr:  1e-05
# loss:1.649, Epoch accuracy:40.26%, Validation loss:1.725, Validation accuracy:35.33%
# Epoch 25: iteration 34/35
# Epoch 25 --- lr:  1e-05
# loss:1.635, Epoch accuracy:42.37%, Validation loss:1.732, Validation accuracy:31.67%
# Epoch 26: iteration 34/35
# Epoch 26 --- lr:  1e-05
# loss:1.643, Epoch accuracy:42.37%, Validation loss:1.688, Validation accuracy:39.67%
# Epoch 27: iteration 34/35
# Epoch 27 --- lr:  1e-05
# loss:1.621, Epoch accuracy:42.98%, Validation loss:1.686, Validation accuracy:39.00%
# Epoch 28: iteration 34/35
# Epoch 28 --- lr:  1e-05
# loss:1.602, Epoch accuracy:44.04%, Validation loss:1.678, Validation accuracy:40.33%
# Epoch 29: iteration 34/35
# Epoch 29 --- lr:  1e-05
# loss:1.588, Epoch accuracy:45.35%, Validation loss:1.633, Validation accuracy:43.67%
# Epoch 30: iteration 34/35
# Epoch 30 --- lr:  1e-05
# loss:1.585, Epoch accuracy:45.26%, Validation loss:1.657, Validation accuracy:40.67%
# Epoch 31: iteration 34/35
# Epoch 31 --- lr:  1e-05
# loss:1.563, Epoch accuracy:45.88%, Validation loss:1.632, Validation accuracy:45.00%
# Epoch 32: iteration 34/35
# Epoch 32 --- lr:  1e-05
# loss:1.553, Epoch accuracy:46.14%, Validation loss:1.632, Validation accuracy:42.67%
# Epoch 33: iteration 34/35
# Epoch 33 --- lr:  1e-05
# loss:1.536, Epoch accuracy:48.68%, Validation loss:1.649, Validation accuracy:40.33%
# Epoch 34: iteration 34/35
# Epoch 34 --- lr:  1e-05
# loss:1.533, Epoch accuracy:49.30%, Validation loss:1.662, Validation accuracy:35.33%
# Epoch 35: iteration 34/35
# Epoch 35 --- lr:  1e-05
# loss:1.510, Epoch accuracy:48.95%, Validation loss:1.633, Validation accuracy:40.00%
# Epoch 36: iteration 34/35
# Epoch 36 --- lr:  1e-05
# loss:1.509, Epoch accuracy:49.47%, Validation loss:1.594, Validation accuracy:46.67%
# Epoch 37: iteration 34/35
# Epoch 37 --- lr:  1e-05
# loss:1.494, Epoch accuracy:49.21%, Validation loss:1.555, Validation accuracy:49.67%
# Epoch 38: iteration 34/35
# Epoch 38 --- lr:  1e-05
# loss:1.483, Epoch accuracy:50.00%, Validation loss:1.554, Validation accuracy:48.67%
# Epoch 39: iteration 34/35
# Epoch 39 --- lr:  1e-05
# loss:1.471, Epoch accuracy:50.09%, Validation loss:1.629, Validation accuracy:40.33%
# Epoch 40: iteration 34/35
# Epoch 40 --- lr:  1e-05
# loss:1.456, Epoch accuracy:50.09%, Validation loss:1.576, Validation accuracy:42.00%
# Epoch 41: iteration 34/35
# Epoch 41 --- lr:  1e-05
# loss:1.438, Epoch accuracy:50.88%, Validation loss:1.565, Validation accuracy:42.33%
# Epoch 42: iteration 34/35
# Epoch 42 --- lr:  1e-05
# loss:1.428, Epoch accuracy:53.60%, Validation loss:1.540, Validation accuracy:46.67%
# Epoch 43: iteration 34/35
# Epoch 43 --- lr:  1e-05
# loss:1.423, Epoch accuracy:53.60%, Validation loss:1.554, Validation accuracy:44.00%
# Epoch 44: iteration 34/35
# Epoch 44 --- lr:  1e-05
# loss:1.418, Epoch accuracy:52.72%, Validation loss:1.551, Validation accuracy:44.33%
# Epoch 45: iteration 34/35
# Epoch 45 --- lr:  1e-05
# loss:1.404, Epoch accuracy:53.60%, Validation loss:1.598, Validation accuracy:39.67%
# Epoch 46: iteration 34/35
# Epoch 46 --- lr:  1e-05
# loss:1.387, Epoch accuracy:52.81%, Validation loss:1.578, Validation accuracy:43.00%
# Epoch 47: iteration 34/35
# Epoch 47 --- lr:  1e-05
# loss:1.384, Epoch accuracy:52.89%, Validation loss:1.501, Validation accuracy:49.67%
# Epoch 48: iteration 34/35
# Epoch 48 --- lr:  1e-05
# loss:1.370, Epoch accuracy:53.86%, Validation loss:1.531, Validation accuracy:43.00%
# Epoch 49: iteration 34/35
# Epoch 49 --- lr:  1e-05
# loss:1.364, Epoch accuracy:54.47%, Validation loss:1.490, Validation accuracy:49.67%
# Epoch 50: iteration 34/35
# Epoch 50 --- lr:  1e-05
# loss:1.342, Epoch accuracy:54.74%, Validation loss:1.517, Validation accuracy:46.00%
# Epoch 51: iteration 34/35
# Epoch 51 --- lr:  1e-05
# loss:1.345, Epoch accuracy:55.18%, Validation loss:1.489, Validation accuracy:47.00%
# Epoch 52: iteration 34/35
# Epoch 52 --- lr:  1e-05
# loss:1.321, Epoch accuracy:55.35%, Validation loss:1.526, Validation accuracy:44.00%
# Epoch 53: iteration 34/35
# Epoch 53 --- lr:  1e-05
# loss:1.320, Epoch accuracy:55.35%, Validation loss:1.494, Validation accuracy:45.67%
# Epoch 54: iteration 34/35
# Epoch 54 --- lr:  1e-05
# loss:1.297, Epoch accuracy:58.25%, Validation loss:1.564, Validation accuracy:43.67%
# Epoch 55: iteration 34/35
# Epoch 55 --- lr:  1e-05
# loss:1.294, Epoch accuracy:54.30%, Validation loss:1.446, Validation accuracy:48.33%
# Epoch 56: iteration 34/35
# Epoch 56 --- lr:  1e-05
# loss:1.288, Epoch accuracy:55.53%, Validation loss:1.491, Validation accuracy:45.67%
# Epoch 57: iteration 34/35
# Epoch 57 --- lr:  1e-05
# loss:1.280, Epoch accuracy:57.46%, Validation loss:1.509, Validation accuracy:45.67%
# Epoch 58: iteration 34/35
# Epoch 58 --- lr:  1e-05
# loss:1.273, Epoch accuracy:56.58%, Validation loss:1.451, Validation accuracy:47.67%
# Epoch 59: iteration 34/35
# Epoch 59 --- lr:  1e-05
# loss:1.270, Epoch accuracy:57.54%, Validation loss:1.565, Validation accuracy:41.00%
# Epoch 60: iteration 34/35
# Epoch 60 --- lr:  1e-05
# loss:1.267, Epoch accuracy:56.84%, Validation loss:1.477, Validation accuracy:46.00%
# Epoch 61: iteration 34/35
# Epoch 61 --- lr:  1e-05
# loss:1.244, Epoch accuracy:58.77%, Validation loss:1.436, Validation accuracy:51.00%
# Epoch 62: iteration 34/35
# Epoch 62 --- lr:  1e-05
# loss:1.241, Epoch accuracy:58.07%, Validation loss:1.475, Validation accuracy:46.67%
# Epoch 63: iteration 34/35
# Epoch 63 --- lr:  1e-05
# loss:1.234, Epoch accuracy:58.51%, Validation loss:1.464, Validation accuracy:47.67%
# Epoch 64: iteration 34/35
# Epoch 64 --- lr:  1e-05
# loss:1.234, Epoch accuracy:57.81%, Validation loss:1.465, Validation accuracy:47.33%
# Epoch 65: iteration 34/35
# Epoch 65 --- lr:  1e-05
# loss:1.215, Epoch accuracy:59.04%, Validation loss:1.389, Validation accuracy:52.67%
# Epoch 66: iteration 34/35
# Epoch 66 --- lr:  1e-05
# loss:1.203, Epoch accuracy:58.42%, Validation loss:1.431, Validation accuracy:49.00%
# Epoch 67: iteration 34/35
# Epoch 67 --- lr:  1e-05
# loss:1.209, Epoch accuracy:59.74%, Validation loss:1.498, Validation accuracy:46.33%
# Epoch 68: iteration 34/35
# Epoch 68 --- lr:  1e-05
# loss:1.194, Epoch accuracy:60.00%, Validation loss:1.446, Validation accuracy:47.00%
# Epoch 69: iteration 34/35
# Epoch 69 --- lr:  1e-05
# loss:1.189, Epoch accuracy:60.35%, Validation loss:1.492, Validation accuracy:44.00%
# Epoch 70: iteration 34/35
# Epoch 70 --- lr:  1e-05
# loss:1.182, Epoch accuracy:60.53%, Validation loss:1.567, Validation accuracy:42.00%
# Epoch 71: iteration 34/35
# Epoch 71 --- lr:  1e-05
# loss:1.178, Epoch accuracy:61.49%, Validation loss:1.458, Validation accuracy:46.00%
# Epoch 72: iteration 34/35
# Epoch 72 --- lr:  1e-05
# loss:1.164, Epoch accuracy:61.58%, Validation loss:1.427, Validation accuracy:48.33%
# Epoch 73: iteration 34/35
# Epoch 73 --- lr:  1e-05
# loss:1.157, Epoch accuracy:61.49%, Validation loss:1.464, Validation accuracy:46.33%
# Epoch 74: iteration 34/35
# Epoch 74 --- lr:  1e-05
# loss:1.151, Epoch accuracy:62.63%, Validation loss:1.459, Validation accuracy:47.33%
# Epoch 75: iteration 34/35
# Epoch 75 --- lr:  1e-05
# loss:1.158, Epoch accuracy:61.32%, Validation loss:1.407, Validation accuracy:47.00%
# Epoch 76: iteration 34/35
# Epoch 76 --- lr:  1e-05
# loss:1.144, Epoch accuracy:60.70%, Validation loss:1.402, Validation accuracy:49.67%
# Epoch 77: iteration 34/35
# Epoch 77 --- lr:  1e-05
# loss:1.139, Epoch accuracy:62.72%, Validation loss:1.377, Validation accuracy:52.33%
# Epoch 78: iteration 34/35
# Epoch 78 --- lr:  1e-05
# loss:1.126, Epoch accuracy:62.11%, Validation loss:1.367, Validation accuracy:50.33%
# Epoch 79: iteration 34/35
# Epoch 79 --- lr:  1e-05
# loss:1.119, Epoch accuracy:63.33%, Validation loss:1.562, Validation accuracy:43.67%
# Epoch 80: iteration 34/35
# Epoch 80 --- lr:  1e-05
# loss:1.117, Epoch accuracy:62.11%, Validation loss:1.403, Validation accuracy:49.67%
# Epoch 81: iteration 34/35
# Epoch 81 --- lr:  1e-05
# loss:1.110, Epoch accuracy:62.37%, Validation loss:1.497, Validation accuracy:45.00%
# Epoch 82: iteration 34/35
# Epoch 82 --- lr:  1e-05
# loss:1.100, Epoch accuracy:63.60%, Validation loss:1.391, Validation accuracy:50.00%
# Epoch 83: iteration 34/35
# Epoch 83 --- lr:  1e-05
# loss:1.092, Epoch accuracy:63.77%, Validation loss:1.386, Validation accuracy:49.00%
# Epoch 84: iteration 34/35
# Epoch 84 --- lr:  1e-05
# loss:1.096, Epoch accuracy:63.77%, Validation loss:1.353, Validation accuracy:51.00%
# Epoch 85: iteration 34/35
# Epoch 85 --- lr:  1e-05
# loss:1.078, Epoch accuracy:63.68%, Validation loss:1.556, Validation accuracy:43.33%
# Epoch 86: iteration 34/35
# Epoch 86 --- lr:  1e-05
# loss:1.090, Epoch accuracy:64.56%, Validation loss:1.488, Validation accuracy:46.33%
# Epoch 87: iteration 34/35
# Epoch 87 --- lr:  1e-05
# loss:1.078, Epoch accuracy:64.82%, Validation loss:1.473, Validation accuracy:45.33%
# Epoch 88: iteration 34/35
# Epoch 88 --- lr:  1e-05
# loss:1.074, Epoch accuracy:63.68%, Validation loss:1.330, Validation accuracy:52.00%
# Epoch 89: iteration 34/35
# Epoch 89 --- lr:  1e-05
# loss:1.076, Epoch accuracy:64.65%, Validation loss:1.300, Validation accuracy:55.33%
# Epoch 90: iteration 34/35
# Epoch 90 --- lr:  1e-05
# loss:1.065, Epoch accuracy:65.44%, Validation loss:1.533, Validation accuracy:42.33%
# Epoch 91: iteration 34/35
# Epoch 91 --- lr:  1e-05
# loss:1.046, Epoch accuracy:66.05%, Validation loss:1.453, Validation accuracy:48.00%
# Epoch 92: iteration 34/35
# Epoch 92 --- lr:  1e-05
# loss:1.042, Epoch accuracy:64.91%, Validation loss:1.357, Validation accuracy:52.67%
# Epoch 93: iteration 34/35
# Epoch 93 --- lr:  1e-05
# loss:1.039, Epoch accuracy:65.53%, Validation loss:1.415, Validation accuracy:46.00%
# Epoch 94: iteration 34/35
# Epoch 94 --- lr:  1e-05
# loss:1.033, Epoch accuracy:64.39%, Validation loss:1.288, Validation accuracy:56.33%
# Epoch 95: iteration 34/35
# Epoch 95 --- lr:  1e-05
# loss:1.035, Epoch accuracy:66.05%, Validation loss:1.460, Validation accuracy:45.00%
# Epoch 96: iteration 34/35
# Epoch 96 --- lr:  1e-05
# loss:1.026, Epoch accuracy:65.70%, Validation loss:1.403, Validation accuracy:49.00%
# Epoch 97: iteration 34/35
# Epoch 97 --- lr:  1e-05
# loss:1.005, Epoch accuracy:67.63%, Validation loss:1.354, Validation accuracy:52.33%
# Epoch 98: iteration 34/35
# Epoch 98 --- lr:  1e-05
# loss:1.015, Epoch accuracy:67.28%, Validation loss:1.398, Validation accuracy:46.33%
# Epoch 99: iteration 34/35
# Epoch 99 --- lr:  1e-05
# loss:1.010, Epoch accuracy:68.07%, Validation loss:1.337, Validation accuracy:50.00%
# Epoch 100: iteration 34/35
# Epoch 100 --- lr:  1e-05
# loss:1.002, Epoch accuracy:67.63%, Validation loss:1.332, Validation accuracy:51.33%
# Epoch 101: iteration 34/35
# Epoch 101 --- lr:  1e-05
# loss:0.982, Epoch accuracy:68.51%, Validation loss:1.313, Validation accuracy:53.67%
# Epoch 102: iteration 34/35
# Epoch 102 --- lr:  1e-05
# loss:0.989, Epoch accuracy:68.25%, Validation loss:1.440, Validation accuracy:46.33%
# Epoch 103: iteration 34/35
# Epoch 103 --- lr:  1e-05
# loss:0.981, Epoch accuracy:69.65%, Validation loss:1.450, Validation accuracy:44.67%
# Epoch 104: iteration 34/35
# Epoch 104 --- lr:  1e-05
# loss:0.988, Epoch accuracy:67.81%, Validation loss:1.487, Validation accuracy:46.00%
# Epoch 105: iteration 34/35
# Epoch 105 --- lr:  1e-05
# loss:0.993, Epoch accuracy:69.56%, Validation loss:1.475, Validation accuracy:46.33%
# Epoch 106: iteration 34/35
# Epoch 106 --- lr:  1e-05
# loss:0.978, Epoch accuracy:67.81%, Validation loss:1.405, Validation accuracy:47.67%
# Epoch 107: iteration 34/35
# Epoch 107 --- lr:  1e-05
# loss:0.963, Epoch accuracy:69.91%, Validation loss:1.341, Validation accuracy:52.33%
# Epoch 108: iteration 34/35
# Epoch 108 --- lr:  1e-05
# loss:0.959, Epoch accuracy:69.04%, Validation loss:1.404, Validation accuracy:47.00%
# Epoch 109: iteration 34/35
# Epoch 109 --- lr:  1e-05
# loss:0.958, Epoch accuracy:69.82%, Validation loss:1.398, Validation accuracy:47.67%
# Epoch 110: iteration 34/35
# Epoch 110 --- lr:  1e-05
# loss:0.963, Epoch accuracy:69.30%, Validation loss:1.418, Validation accuracy:45.33%
# Epoch 111: iteration 34/35
# Epoch 111 --- lr:  1e-05
# loss:0.947, Epoch accuracy:70.00%, Validation loss:1.338, Validation accuracy:51.00%
# Epoch 112: iteration 34/35
# Epoch 112 --- lr:  1e-05
# loss:0.948, Epoch accuracy:70.44%, Validation loss:1.291, Validation accuracy:54.67%
# Epoch 113: iteration 34/35
# Epoch 113 --- lr:  1e-05
# loss:0.947, Epoch accuracy:70.18%, Validation loss:1.405, Validation accuracy:49.33%
# Epoch 114: iteration 34/35
# Epoch 114 --- lr:  1e-05
# loss:0.931, Epoch accuracy:71.49%, Validation loss:1.302, Validation accuracy:53.00%
# Epoch 115: iteration 34/35
# Epoch 115 --- lr:  1e-05
# loss:0.929, Epoch accuracy:71.40%, Validation loss:1.393, Validation accuracy:48.33%
# Epoch 116: iteration 34/35
# Epoch 116 --- lr:  1e-05
# loss:0.929, Epoch accuracy:70.96%, Validation loss:1.352, Validation accuracy:49.33%
# Epoch 117: iteration 34/35
# Epoch 117 --- lr:  1e-05
# loss:0.914, Epoch accuracy:71.32%, Validation loss:1.407, Validation accuracy:47.00%
# Epoch 118: iteration 34/35
# Epoch 118 --- lr:  1e-05
# loss:0.913, Epoch accuracy:71.67%, Validation loss:1.388, Validation accuracy:48.33%
# Epoch 119: iteration 34/35
# Epoch 119 --- lr:  1e-05
# loss:0.915, Epoch accuracy:71.32%, Validation loss:1.367, Validation accuracy:49.00%
# Epoch 120: iteration 34/35
# Epoch 120 --- lr:  1e-05
# loss:0.903, Epoch accuracy:72.37%, Validation loss:1.337, Validation accuracy:49.33%
# Epoch 121: iteration 34/35
# Epoch 121 --- lr:  1e-05
# loss:0.891, Epoch accuracy:73.86%, Validation loss:1.271, Validation accuracy:52.67%
# Epoch 122: iteration 34/35
# Epoch 122 --- lr:  1e-05
# loss:0.897, Epoch accuracy:72.02%, Validation loss:1.300, Validation accuracy:53.67%
# Epoch 123: iteration 34/35
# Epoch 123 --- lr:  1e-05
# loss:0.889, Epoch accuracy:73.51%, Validation loss:1.338, Validation accuracy:53.00%
# Epoch 124: iteration 34/35
# Epoch 124 --- lr:  1e-05
# loss:0.878, Epoch accuracy:72.89%, Validation loss:1.293, Validation accuracy:53.33%
# Epoch 125: iteration 34/35
# Epoch 125 --- lr:  1e-05
# loss:0.875, Epoch accuracy:73.42%, Validation loss:1.393, Validation accuracy:48.67%
# Epoch 126: iteration 34/35
# Epoch 126 --- lr:  1e-05
# loss:0.874, Epoch accuracy:73.16%, Validation loss:1.242, Validation accuracy:56.00%
# Epoch 127: iteration 34/35
# Epoch 127 --- lr:  1e-05
# loss:0.865, Epoch accuracy:74.04%, Validation loss:1.300, Validation accuracy:53.33%
# Epoch 128: iteration 34/35
# Epoch 128 --- lr:  1e-05
# loss:0.870, Epoch accuracy:72.46%, Validation loss:1.295, Validation accuracy:54.00%
# Epoch 129: iteration 34/35
# Epoch 129 --- lr:  1e-05
# loss:0.861, Epoch accuracy:75.44%, Validation loss:1.346, Validation accuracy:52.33%
# Epoch 130: iteration 34/35
# Epoch 130 --- lr:  1e-05
# loss:0.856, Epoch accuracy:73.95%, Validation loss:1.244, Validation accuracy:53.67%
# Epoch 131: iteration 34/35
# Epoch 131 --- lr:  1e-05
# loss:0.849, Epoch accuracy:75.09%, Validation loss:1.398, Validation accuracy:48.67%
# Epoch 132: iteration 34/35
# Epoch 132 --- lr:  1e-05
# loss:0.858, Epoch accuracy:74.74%, Validation loss:1.304, Validation accuracy:51.00%
# Epoch 133: iteration 34/35
# Epoch 133 --- lr:  1e-05
# loss:0.842, Epoch accuracy:74.82%, Validation loss:1.280, Validation accuracy:54.67%
# Epoch 134: iteration 34/35
# Epoch 134 --- lr:  1e-05
# loss:0.842, Epoch accuracy:74.91%, Validation loss:1.428, Validation accuracy:45.00%
# Epoch 135: iteration 34/35
# Epoch 135 --- lr:  1e-05
# loss:0.847, Epoch accuracy:75.26%, Validation loss:1.389, Validation accuracy:47.00%
# Epoch 136: iteration 34/35
# Epoch 136 --- lr:  1e-05
# loss:0.836, Epoch accuracy:75.18%, Validation loss:1.214, Validation accuracy:58.00%
# Epoch 137: iteration 34/35
# Epoch 137 --- lr:  1e-05
# loss:0.838, Epoch accuracy:74.47%, Validation loss:1.309, Validation accuracy:51.00%
# Epoch 138: iteration 34/35
# Epoch 138 --- lr:  1e-05
# loss:0.829, Epoch accuracy:75.96%, Validation loss:1.272, Validation accuracy:54.00%
# Epoch 139: iteration 34/35
# Epoch 139 --- lr:  1e-05
# loss:0.826, Epoch accuracy:76.49%, Validation loss:1.342, Validation accuracy:47.33%
# Epoch 140: iteration 34/35
# Epoch 140 --- lr:  1e-05
# loss:0.817, Epoch accuracy:77.11%, Validation loss:1.211, Validation accuracy:58.00%
# Epoch 141: iteration 34/35
# Epoch 141 --- lr:  1e-05
# loss:0.826, Epoch accuracy:75.18%, Validation loss:1.447, Validation accuracy:47.00%
# Epoch 142: iteration 34/35
# Epoch 142 --- lr:  1e-05
# loss:0.802, Epoch accuracy:77.28%, Validation loss:1.375, Validation accuracy:47.33%
# Epoch 143: iteration 34/35
# Epoch 143 --- lr:  1e-05
# loss:0.801, Epoch accuracy:76.40%, Validation loss:1.266, Validation accuracy:55.00%
# Epoch 144: iteration 34/35
# Epoch 144 --- lr:  1e-05
# loss:0.793, Epoch accuracy:76.75%, Validation loss:1.267, Validation accuracy:53.33%
# Epoch 145: iteration 34/35
# Epoch 145 --- lr:  1e-05
# loss:0.789, Epoch accuracy:77.63%, Validation loss:1.201, Validation accuracy:57.00%
# Epoch 146: iteration 34/35
# Epoch 146 --- lr:  1e-05
# loss:0.791, Epoch accuracy:76.84%, Validation loss:1.236, Validation accuracy:54.67%
# Epoch 147: iteration 34/35
# Epoch 147 --- lr:  1e-05
# loss:0.785, Epoch accuracy:77.28%, Validation loss:1.334, Validation accuracy:49.33%
# Epoch 148: iteration 34/35
# Epoch 148 --- lr:  1e-05
# loss:0.778, Epoch accuracy:77.11%, Validation loss:1.397, Validation accuracy:47.67%
# Epoch 149: iteration 34/35
# Epoch 149 --- lr:  1e-05
# loss:0.768, Epoch accuracy:77.89%, Validation loss:1.210, Validation accuracy:56.00%
# Epoch 150: iteration 34/35
# Epoch 150 --- lr:  1e-05
# loss:0.765, Epoch accuracy:77.81%, Validation loss:1.251, Validation accuracy:52.67%
# Epoch 151: iteration 34/35
# Epoch 151 --- lr:  1e-05
# loss:0.760, Epoch accuracy:78.60%, Validation loss:1.316, Validation accuracy:53.33%
# Epoch 152: iteration 34/35
# Epoch 152 --- lr:  1e-05
# loss:0.754, Epoch accuracy:79.39%, Validation loss:1.204, Validation accuracy:57.00%
# Epoch 153: iteration 34/35
# Epoch 153 --- lr:  1e-05
# loss:0.760, Epoch accuracy:78.33%, Validation loss:1.180, Validation accuracy:59.33%
# Epoch 154: iteration 34/35
# Epoch 154 --- lr:  1e-05
# loss:0.745, Epoch accuracy:80.88%, Validation loss:1.189, Validation accuracy:57.67%
# Epoch 155: iteration 34/35
# Epoch 155 --- lr:  1e-05
# loss:0.738, Epoch accuracy:80.61%, Validation loss:1.160, Validation accuracy:60.00%
# Epoch 156: iteration 34/35
# Epoch 156 --- lr:  1e-05
# loss:0.746, Epoch accuracy:78.51%, Validation loss:1.348, Validation accuracy:49.00%
# Epoch 157: iteration 34/35
# Epoch 157 --- lr:  1e-05
# loss:0.752, Epoch accuracy:78.42%, Validation loss:1.309, Validation accuracy:51.00%
# Epoch 158: iteration 34/35
# Epoch 158 --- lr:  1e-05
# loss:0.744, Epoch accuracy:79.21%, Validation loss:1.247, Validation accuracy:53.33%
# Epoch 159: iteration 34/35
# Epoch 159 --- lr:  1e-05
# loss:0.735, Epoch accuracy:80.00%, Validation loss:1.281, Validation accuracy:52.00%
# Epoch 160: iteration 34/35
# Epoch 160 --- lr:  1e-05
# loss:0.725, Epoch accuracy:79.56%, Validation loss:1.273, Validation accuracy:55.67%
# Epoch 161: iteration 34/35
# Epoch 161 --- lr:  1e-05
# loss:0.724, Epoch accuracy:80.61%, Validation loss:1.233, Validation accuracy:54.67%
# Epoch 162: iteration 34/35
# Epoch 162 --- lr:  1e-05
# loss:0.708, Epoch accuracy:81.14%, Validation loss:1.266, Validation accuracy:50.67%
# Epoch 163: iteration 34/35
# Epoch 163 --- lr:  1e-05
# loss:0.711, Epoch accuracy:81.58%, Validation loss:1.250, Validation accuracy:54.00%
# Epoch 164: iteration 34/35
# Epoch 164 --- lr:  1e-05
# loss:0.712, Epoch accuracy:81.05%, Validation loss:1.345, Validation accuracy:49.33%
# Epoch 165: iteration 34/35
# Epoch 165 --- lr:  1e-05
# loss:0.699, Epoch accuracy:82.37%, Validation loss:1.184, Validation accuracy:59.33%
# Epoch 166: iteration 34/35
# Epoch 166 --- lr:  1e-05
# loss:0.701, Epoch accuracy:80.44%, Validation loss:1.364, Validation accuracy:50.00%
# Epoch 167: iteration 34/35
# Epoch 167 --- lr:  1e-05
# loss:0.689, Epoch accuracy:82.89%, Validation loss:1.355, Validation accuracy:50.00%
# Epoch 168: iteration 34/35
# Epoch 168 --- lr:  1e-05
# loss:0.704, Epoch accuracy:81.40%, Validation loss:1.255, Validation accuracy:54.33%
# Epoch 169: iteration 34/35
# Epoch 169 --- lr:  1e-05
# loss:0.689, Epoch accuracy:81.49%, Validation loss:1.210, Validation accuracy:55.67%
# Epoch 170: iteration 34/35
# Epoch 170 --- lr:  1e-05
# loss:0.690, Epoch accuracy:82.63%, Validation loss:1.220, Validation accuracy:54.67%
# Epoch 171: iteration 34/35
# Epoch 171 --- lr:  1e-05
# loss:0.694, Epoch accuracy:81.23%, Validation loss:1.303, Validation accuracy:51.00%
# Epoch 172: iteration 34/35
# Epoch 172 --- lr:  1e-05
# loss:0.670, Epoch accuracy:82.98%, Validation loss:1.214, Validation accuracy:56.33%
# Epoch 173: iteration 34/35
# Epoch 173 --- lr:  1e-05
# loss:0.679, Epoch accuracy:82.98%, Validation loss:1.331, Validation accuracy:49.33%
# Epoch 174: iteration 34/35
# Epoch 174 --- lr:  1e-05
# loss:0.682, Epoch accuracy:81.75%, Validation loss:1.428, Validation accuracy:47.00%
# Epoch 175: iteration 34/35
# Epoch 175 --- lr:  1e-05
# loss:0.667, Epoch accuracy:82.81%, Validation loss:1.239, Validation accuracy:55.67%
# Epoch 176: iteration 34/35
# Epoch 176 --- lr:  1e-05
# loss:0.676, Epoch accuracy:83.60%, Validation loss:1.314, Validation accuracy:50.00%
# Epoch 177: iteration 34/35
# Epoch 177 --- lr:  1e-05
# loss:0.658, Epoch accuracy:85.09%, Validation loss:1.211, Validation accuracy:56.33%
# Epoch 178: iteration 34/35
# Epoch 178 --- lr:  1e-05
# loss:0.661, Epoch accuracy:83.33%, Validation loss:1.261, Validation accuracy:51.67%
# Epoch 179: iteration 34/35
# Epoch 179 --- lr:  1e-05
# loss:0.657, Epoch accuracy:83.16%, Validation loss:1.286, Validation accuracy:51.33%
# Epoch 180: iteration 34/35
# Epoch 180 --- lr:  1e-05
# loss:0.651, Epoch accuracy:84.47%, Validation loss:1.261, Validation accuracy:53.67%
# Epoch 181: iteration 34/35
# Epoch 181 --- lr:  1e-05
# loss:0.640, Epoch accuracy:83.77%, Validation loss:1.264, Validation accuracy:53.00%
# Epoch 182: iteration 34/35
# Epoch 182 --- lr:  1e-05
# loss:0.638, Epoch accuracy:84.65%, Validation loss:1.265, Validation accuracy:53.67%
# Epoch 183: iteration 34/35
# Epoch 183 --- lr:  1e-05
# loss:0.650, Epoch accuracy:83.95%, Validation loss:1.175, Validation accuracy:57.00%
# Epoch 184: iteration 34/35
# Epoch 184 --- lr:  1e-05
# loss:0.628, Epoch accuracy:85.53%, Validation loss:1.345, Validation accuracy:48.00%
# Epoch 185: iteration 34/35
# Epoch 185 --- lr:  1e-05
# loss:0.630, Epoch accuracy:84.04%, Validation loss:1.306, Validation accuracy:50.67%
# Epoch 186: iteration 34/35
# Epoch 186 --- lr:  1e-05
# loss:0.642, Epoch accuracy:83.86%, Validation loss:1.434, Validation accuracy:47.67%
# Epoch 187: iteration 34/35
# Epoch 187 --- lr:  1e-05
# loss:0.626, Epoch accuracy:85.44%, Validation loss:1.347, Validation accuracy:48.33%
# Epoch 188: iteration 34/35
# Epoch 188 --- lr:  1e-05
# loss:0.628, Epoch accuracy:85.09%, Validation loss:1.159, Validation accuracy:57.33%
# Epoch 189: iteration 34/35
# Epoch 189 --- lr:  1e-05
# loss:0.617, Epoch accuracy:85.44%, Validation loss:1.305, Validation accuracy:52.33%
# Epoch 190: iteration 34/35
# Epoch 190 --- lr:  1e-05
# loss:0.613, Epoch accuracy:85.79%, Validation loss:1.293, Validation accuracy:53.00%
# Epoch 191: iteration 34/35
# Epoch 191 --- lr:  1e-05
# loss:0.609, Epoch accuracy:86.23%, Validation loss:1.310, Validation accuracy:50.67%
# Epoch 192: iteration 34/35
# Epoch 192 --- lr:  1e-05
# loss:0.615, Epoch accuracy:85.79%, Validation loss:1.277, Validation accuracy:51.33%
# Epoch 193: iteration 34/35
# Epoch 193 --- lr:  1e-05
# loss:0.612, Epoch accuracy:85.35%, Validation loss:1.275, Validation accuracy:52.33%
# Epoch 194: iteration 34/35
# Epoch 194 --- lr:  1e-05
# loss:0.599, Epoch accuracy:85.53%, Validation loss:1.202, Validation accuracy:54.67%
# Epoch 195: iteration 34/35
# Epoch 195 --- lr:  1e-05
# loss:0.598, Epoch accuracy:85.79%, Validation loss:1.223, Validation accuracy:55.00%
# Epoch 196: iteration 34/35
# Epoch 196 --- lr:  1e-05
# loss:0.589, Epoch accuracy:86.75%, Validation loss:1.183, Validation accuracy:56.67%
# Epoch 197: iteration 34/35
# Epoch 197 --- lr:  1e-05
# loss:0.579, Epoch accuracy:86.49%, Validation loss:1.204, Validation accuracy:55.33%
# Epoch 198: iteration 34/35
# Epoch 198 --- lr:  1e-05
# loss:0.578, Epoch accuracy:86.49%, Validation loss:1.164, Validation accuracy:59.00%
# Epoch 199: iteration 34/35
# Epoch 199 --- lr:  1e-05
# loss:0.595, Epoch accuracy:85.61%, Validation loss:1.391, Validation accuracy:48.00%
# Epoch 200: iteration 34/35
# Epoch 200 --- lr:  1e-05
# loss:0.578, Epoch accuracy:86.40%, Validation loss:1.267, Validation accuracy:51.67%
# Epoch 201: iteration 34/35
# Epoch 201 --- lr:  1e-05
# loss:0.572, Epoch accuracy:87.37%, Validation loss:1.362, Validation accuracy:49.33%
# Epoch 202: iteration 34/35
# Epoch 202 --- lr:  1e-05
# loss:0.564, Epoch accuracy:88.07%, Validation loss:1.230, Validation accuracy:55.33%
# Epoch 203: iteration 34/35
# Epoch 203 --- lr:  1e-05
# loss:0.561, Epoch accuracy:87.19%, Validation loss:1.274, Validation accuracy:52.67%
# Epoch 204: iteration 34/35
# Epoch 204 --- lr:  1e-05
# loss:0.575, Epoch accuracy:87.02%, Validation loss:1.172, Validation accuracy:55.67%
# Epoch 205: iteration 34/35
# Epoch 205 --- lr:  1e-05
# loss:0.554, Epoch accuracy:88.60%, Validation loss:1.067, Validation accuracy:63.33%
# Epoch 206: iteration 34/35
# Epoch 206 --- lr:  1e-05
# loss:0.567, Epoch accuracy:87.02%, Validation loss:1.352, Validation accuracy:49.00%
# Epoch 207: iteration 34/35
# Epoch 207 --- lr:  1e-05
# loss:0.557, Epoch accuracy:87.28%, Validation loss:1.278, Validation accuracy:54.67%
# Epoch 208: iteration 34/35
# Epoch 208 --- lr:  1e-05
# loss:0.560, Epoch accuracy:87.63%, Validation loss:1.220, Validation accuracy:53.67%
# Epoch 209: iteration 34/35
# Epoch 209 --- lr:  1e-05
# loss:0.552, Epoch accuracy:87.72%, Validation loss:1.333, Validation accuracy:49.67%
# Epoch 210: iteration 34/35
# Epoch 210 --- lr:  1e-05
# loss:0.551, Epoch accuracy:87.98%, Validation loss:1.207, Validation accuracy:56.67%
# Epoch 211: iteration 34/35
# Epoch 211 --- lr:  1e-05
# loss:0.553, Epoch accuracy:87.72%, Validation loss:1.173, Validation accuracy:55.33%
# Epoch 212: iteration 34/35
# Epoch 212 --- lr:  1e-05
# loss:0.544, Epoch accuracy:88.68%, Validation loss:1.264, Validation accuracy:50.00%
# Epoch 213: iteration 34/35
# Epoch 213 --- lr:  1e-05
# loss:0.532, Epoch accuracy:87.89%, Validation loss:1.296, Validation accuracy:52.67%
# Epoch 214: iteration 34/35
# Epoch 214 --- lr:  1e-05
# loss:0.552, Epoch accuracy:88.07%, Validation loss:1.147, Validation accuracy:57.33%
# Epoch 215: iteration 34/35
# Epoch 215 --- lr:  1e-05
# loss:0.524, Epoch accuracy:88.77%, Validation loss:1.213, Validation accuracy:56.00%
# Epoch 216: iteration 34/35
# Epoch 216 --- lr:  1e-05
# loss:0.532, Epoch accuracy:88.42%, Validation loss:1.164, Validation accuracy:58.33%
# Epoch 217: iteration 34/35
# Epoch 217 --- lr:  1e-05
# loss:0.535, Epoch accuracy:88.07%, Validation loss:1.288, Validation accuracy:51.67%
# Epoch 218: iteration 34/35
# Epoch 218 --- lr:  1e-05
# loss:0.517, Epoch accuracy:89.30%, Validation loss:1.231, Validation accuracy:54.67%
# Epoch 219: iteration 34/35
# Epoch 219 --- lr:  1e-05
# loss:0.521, Epoch accuracy:89.39%, Validation loss:1.310, Validation accuracy:50.67%
# Epoch 220: iteration 34/35
# Epoch 220 --- lr:  1e-05
# loss:0.514, Epoch accuracy:89.39%, Validation loss:1.221, Validation accuracy:52.33%
# Epoch 221: iteration 34/35
# Epoch 221 --- lr:  1e-05
# loss:0.518, Epoch accuracy:88.07%, Validation loss:1.208, Validation accuracy:55.67%
# Epoch 222: iteration 34/35
# Epoch 222 --- lr:  1e-05
# loss:0.500, Epoch accuracy:89.56%, Validation loss:1.263, Validation accuracy:52.00%
# Epoch 223: iteration 34/35
# Epoch 223 --- lr:  1e-05
# loss:0.492, Epoch accuracy:89.91%, Validation loss:1.099, Validation accuracy:62.00%
# Epoch 224: iteration 34/35
# Epoch 224 --- lr:  1e-05
# loss:0.507, Epoch accuracy:88.25%, Validation loss:1.245, Validation accuracy:51.67%
# Epoch 225: iteration 34/35
# Epoch 225 --- lr:  1e-05
# loss:0.503, Epoch accuracy:89.47%, Validation loss:1.327, Validation accuracy:51.33%
# Epoch 226: iteration 34/35
# Epoch 226 --- lr:  1e-05
# loss:0.485, Epoch accuracy:90.53%, Validation loss:1.174, Validation accuracy:58.33%
# Epoch 227: iteration 34/35
# Epoch 227 --- lr:  1e-05
# loss:0.494, Epoch accuracy:89.47%, Validation loss:1.228, Validation accuracy:53.00%
# Epoch 228: iteration 34/35
# Epoch 228 --- lr:  1e-05
# loss:0.482, Epoch accuracy:90.26%, Validation loss:1.242, Validation accuracy:53.00%
# Epoch 229: iteration 34/35
# Epoch 229 --- lr:  1e-05
# loss:0.485, Epoch accuracy:90.61%, Validation loss:1.139, Validation accuracy:60.67%
# Epoch 230: iteration 34/35
# Epoch 230 --- lr:  1e-05
# loss:0.477, Epoch accuracy:90.35%, Validation loss:1.243, Validation accuracy:52.33%
# Epoch 231: iteration 34/35
# Epoch 231 --- lr:  1e-05
# loss:0.473, Epoch accuracy:90.53%, Validation loss:1.240, Validation accuracy:52.00%
# Epoch 232: iteration 34/35
# Epoch 232 --- lr:  1e-05
# loss:0.488, Epoch accuracy:90.26%, Validation loss:1.288, Validation accuracy:53.00%
# Epoch 233: iteration 34/35
# Epoch 233 --- lr:  1e-05
# loss:0.476, Epoch accuracy:90.53%, Validation loss:1.204, Validation accuracy:55.67%
# Epoch 234: iteration 34/35
# Epoch 234 --- lr:  1e-05
# loss:0.466, Epoch accuracy:90.26%, Validation loss:1.310, Validation accuracy:50.67%
# Epoch 235: iteration 34/35
# Epoch 235 --- lr:  1e-05
# loss:0.463, Epoch accuracy:91.67%, Validation loss:1.400, Validation accuracy:46.67%
# Epoch 236: iteration 34/35
# Epoch 236 --- lr:  1e-05
# loss:0.462, Epoch accuracy:91.93%, Validation loss:1.174, Validation accuracy:57.00%
# Epoch 237: iteration 34/35
# Epoch 237 --- lr:  1e-05
# loss:0.463, Epoch accuracy:91.75%, Validation loss:1.191, Validation accuracy:53.00%
# Epoch 238: iteration 34/35
# Epoch 238 --- lr:  1e-05
# loss:0.462, Epoch accuracy:89.91%, Validation loss:1.292, Validation accuracy:52.00%
# Epoch 239: iteration 34/35
# Epoch 239 --- lr:  1e-05
# loss:0.460, Epoch accuracy:91.23%, Validation loss:1.099, Validation accuracy:59.33%
# Epoch 240: iteration 34/35
# Epoch 240 --- lr:  1e-05
# loss:0.444, Epoch accuracy:91.40%, Validation loss:1.101, Validation accuracy:59.67%
# Epoch 241: iteration 34/35
# Epoch 241 --- lr:  1e-05
# loss:0.451, Epoch accuracy:91.40%, Validation loss:1.159, Validation accuracy:56.00%
# Epoch 242: iteration 34/35
# Epoch 242 --- lr:  1e-05
# loss:0.455, Epoch accuracy:91.58%, Validation loss:1.369, Validation accuracy:50.00%
# Epoch 243: iteration 34/35
# Epoch 243 --- lr:  1e-05
# loss:0.444, Epoch accuracy:91.93%, Validation loss:1.294, Validation accuracy:51.33%
# Epoch 244: iteration 34/35
# Epoch 244 --- lr:  1e-05
# loss:0.442, Epoch accuracy:92.19%, Validation loss:1.219, Validation accuracy:54.33%
# Epoch 245: iteration 34/35
# Epoch 245 --- lr:  1e-05
# loss:0.439, Epoch accuracy:91.93%, Validation loss:1.218, Validation accuracy:57.00%
# Epoch 246: iteration 34/35
# Epoch 246 --- lr:  1e-05
# loss:0.446, Epoch accuracy:91.93%, Validation loss:1.209, Validation accuracy:59.00%
# Epoch 247: iteration 34/35
# Epoch 247 --- lr:  1e-05
# loss:0.443, Epoch accuracy:91.75%, Validation loss:1.543, Validation accuracy:46.67%
# Epoch 248: iteration 34/35
# Epoch 248 --- lr:  1e-05
# loss:0.430, Epoch accuracy:92.19%, Validation loss:1.149, Validation accuracy:60.00%
# Epoch 249: iteration 34/35
# Epoch 249 --- lr:  1e-05
# loss:0.440, Epoch accuracy:91.93%, Validation loss:1.122, Validation accuracy:60.00%
# Epoch 250: iteration 34/35
# Epoch 250 --- lr:  1e-05
# loss:0.436, Epoch accuracy:91.93%, Validation loss:1.285, Validation accuracy:51.00%
# Epoch 251: iteration 34/35
# Epoch 251 --- lr:  1e-05
# loss:0.441, Epoch accuracy:89.91%, Validation loss:1.110, Validation accuracy:61.33%
# Epoch 252: iteration 34/35
# Epoch 252 --- lr:  1e-05
# loss:0.416, Epoch accuracy:91.93%, Validation loss:1.467, Validation accuracy:47.67%
# Epoch 253: iteration 34/35
# Epoch 253 --- lr:  1e-05
# loss:0.431, Epoch accuracy:92.37%, Validation loss:1.210, Validation accuracy:55.33%
# Epoch 254: iteration 34/35
# Epoch 254 --- lr:  1e-05
# loss:0.420, Epoch accuracy:92.02%, Validation loss:1.094, Validation accuracy:60.67%
# Epoch 255: iteration 34/35
# Epoch 255 --- lr:  1e-05
# loss:0.407, Epoch accuracy:93.07%, Validation loss:1.234, Validation accuracy:51.00%
# Epoch 256: iteration 34/35
# Epoch 256 --- lr:  1.0000000000000002e-06
# loss:0.422, Epoch accuracy:92.11%, Validation loss:1.122, Validation accuracy:57.00%
# Epoch 257: iteration 34/35
# Epoch 257 --- lr:  1.0000000000000002e-06
# loss:0.400, Epoch accuracy:93.60%, Validation loss:1.152, Validation accuracy:56.33%
# Epoch 258: iteration 34/35
# Epoch 258 --- lr:  1.0000000000000002e-06
# loss:0.406, Epoch accuracy:93.68%, Validation loss:1.136, Validation accuracy:58.33%
# Epoch 259: iteration 34/35
# Epoch 259 --- lr:  1.0000000000000002e-06
# loss:0.394, Epoch accuracy:93.86%, Validation loss:1.173, Validation accuracy:55.67%
# Epoch 260: iteration 34/35
# Epoch 260 --- lr:  1.0000000000000002e-06
# loss:0.404, Epoch accuracy:93.60%, Validation loss:1.159, Validation accuracy:54.00%
# Epoch 261: iteration 34/35
# Epoch 261 --- lr:  1.0000000000000002e-06
# loss:0.404, Epoch accuracy:93.07%, Validation loss:1.132, Validation accuracy:60.67%
# Epoch 262: iteration 34/35
# Epoch 262 --- lr:  1.0000000000000002e-06
# loss:0.400, Epoch accuracy:93.42%, Validation loss:1.150, Validation accuracy:57.00%
# Epoch 263: iteration 34/35
# Epoch 263 --- lr:  1.0000000000000002e-06
# loss:0.389, Epoch accuracy:94.39%, Validation loss:1.147, Validation accuracy:56.33%
# Epoch 264: iteration 34/35
# Epoch 264 --- lr:  1.0000000000000002e-06
# loss:0.394, Epoch accuracy:93.77%, Validation loss:1.118, Validation accuracy:58.67%
# Epoch 265: iteration 34/35
# Epoch 265 --- lr:  1.0000000000000002e-06
# loss:0.399, Epoch accuracy:93.33%, Validation loss:1.165, Validation accuracy:56.00%
# Epoch 266: iteration 34/35
# Epoch 266 --- lr:  1.0000000000000002e-06
# loss:0.405, Epoch accuracy:92.81%, Validation loss:1.160, Validation accuracy:56.00%
# Epoch 267: iteration 34/35
# Epoch 267 --- lr:  1.0000000000000002e-06
# loss:0.398, Epoch accuracy:93.60%, Validation loss:1.168, Validation accuracy:56.67%
# Epoch 268: iteration 34/35
# Epoch 268 --- lr:  1.0000000000000002e-06
# loss:0.402, Epoch accuracy:93.86%, Validation loss:1.150, Validation accuracy:55.00%
# Epoch 269: iteration 34/35
# Epoch 269 --- lr:  1.0000000000000002e-06
# loss:0.406, Epoch accuracy:93.25%, Validation loss:1.121, Validation accuracy:59.67%
# Epoch 270: iteration 34/35
# Epoch 270 --- lr:  1.0000000000000002e-06
# loss:0.396, Epoch accuracy:93.68%, Validation loss:1.146, Validation accuracy:56.00%
# Epoch 271: iteration 34/35
# Epoch 271 --- lr:  1.0000000000000002e-06
# loss:0.404, Epoch accuracy:93.25%, Validation loss:1.152, Validation accuracy:57.67%
# Epoch 272: iteration 34/35
# Epoch 272 --- lr:  1.0000000000000002e-06
# loss:0.404, Epoch accuracy:93.51%, Validation loss:1.144, Validation accuracy:60.33%
# Epoch 273: iteration 34/35
# Epoch 273 --- lr:  1.0000000000000002e-06
# loss:0.388, Epoch accuracy:93.68%, Validation loss:1.148, Validation accuracy:54.67%
# Epoch 274: iteration 34/35
# Epoch 274 --- lr:  1.0000000000000002e-06
# loss:0.393, Epoch accuracy:93.86%, Validation loss:1.183, Validation accuracy:55.67%
# Epoch 275: iteration 34/35
# Epoch 275 --- lr:  1.0000000000000002e-06
# loss:0.399, Epoch accuracy:93.60%, Validation loss:1.144, Validation accuracy:57.00%
# Epoch 276: iteration 34/35
# Epoch 276 --- lr:  1.0000000000000002e-06
# loss:0.401, Epoch accuracy:93.60%, Validation loss:1.169, Validation accuracy:56.33%
# Epoch 277: iteration 34/35
# Epoch 277 --- lr:  1.0000000000000002e-06
# loss:0.395, Epoch accuracy:93.33%, Validation loss:1.144, Validation accuracy:59.00%
# Epoch 278: iteration 34/35
# Epoch 278 --- lr:  1.0000000000000002e-06
# loss:0.391, Epoch accuracy:94.04%, Validation loss:1.132, Validation accuracy:56.33%
# Epoch 279: iteration 34/35
# Epoch 279 --- lr:  1.0000000000000002e-06
# loss:0.409, Epoch accuracy:92.81%, Validation loss:1.147, Validation accuracy:56.33%
# Epoch 280: iteration 34/35
# Epoch 280 --- lr:  1.0000000000000002e-06
# loss:0.405, Epoch accuracy:92.81%, Validation loss:1.160, Validation accuracy:57.00%
# Epoch 281: iteration 34/35
# Epoch 281 --- lr:  1.0000000000000002e-06
# loss:0.392, Epoch accuracy:93.77%, Validation loss:1.140, Validation accuracy:58.33%
# Epoch 282: iteration 34/35
# Epoch 282 --- lr:  1.0000000000000002e-06
# loss:0.399, Epoch accuracy:92.98%, Validation loss:1.132, Validation accuracy:57.00%
# Epoch 283: iteration 34/35
# Epoch 283 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:93.68%, Validation loss:1.126, Validation accuracy:59.00%
# Epoch 284: iteration 34/35
# Epoch 284 --- lr:  1.0000000000000002e-06
# loss:0.397, Epoch accuracy:94.74%, Validation loss:1.159, Validation accuracy:57.67%
# Epoch 285: iteration 34/35
# Epoch 285 --- lr:  1.0000000000000002e-06
# loss:0.406, Epoch accuracy:93.68%, Validation loss:1.182, Validation accuracy:55.33%
# Epoch 286: iteration 34/35
# Epoch 286 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:93.16%, Validation loss:1.150, Validation accuracy:56.67%
# Epoch 287: iteration 34/35
# Epoch 287 --- lr:  1.0000000000000002e-06
# loss:0.381, Epoch accuracy:94.12%, Validation loss:1.127, Validation accuracy:57.33%
# Epoch 288: iteration 34/35
# Epoch 288 --- lr:  1.0000000000000002e-06
# loss:0.395, Epoch accuracy:93.33%, Validation loss:1.111, Validation accuracy:60.67%
# Epoch 289: iteration 34/35
# Epoch 289 --- lr:  1.0000000000000002e-06
# loss:0.391, Epoch accuracy:93.95%, Validation loss:1.138, Validation accuracy:58.33%
# Epoch 290: iteration 34/35
# Epoch 290 --- lr:  1.0000000000000002e-06
# loss:0.392, Epoch accuracy:93.16%, Validation loss:1.141, Validation accuracy:56.67%
# Epoch 291: iteration 34/35
# Epoch 291 --- lr:  1.0000000000000002e-06
# loss:0.382, Epoch accuracy:94.47%, Validation loss:1.147, Validation accuracy:58.00%
# Epoch 292: iteration 34/35
# Epoch 292 --- lr:  1.0000000000000002e-06
# loss:0.394, Epoch accuracy:93.42%, Validation loss:1.147, Validation accuracy:58.00%
# Epoch 293: iteration 34/35
# Epoch 293 --- lr:  1.0000000000000002e-06
# loss:0.392, Epoch accuracy:93.68%, Validation loss:1.156, Validation accuracy:57.00%
# Epoch 294: iteration 34/35
# Epoch 294 --- lr:  1.0000000000000002e-06
# loss:0.386, Epoch accuracy:93.77%, Validation loss:1.150, Validation accuracy:57.33%
# Epoch 295: iteration 34/35
# Epoch 295 --- lr:  1.0000000000000002e-06
# loss:0.382, Epoch accuracy:93.60%, Validation loss:1.120, Validation accuracy:56.00%
# Epoch 296: iteration 34/35
# Epoch 296 --- lr:  1.0000000000000002e-06
# loss:0.388, Epoch accuracy:93.95%, Validation loss:1.139, Validation accuracy:55.67%
# Epoch 297: iteration 34/35
# Epoch 297 --- lr:  1.0000000000000002e-06
# loss:0.391, Epoch accuracy:93.77%, Validation loss:1.128, Validation accuracy:59.00%
# Epoch 298: iteration 34/35
# Epoch 298 --- lr:  1.0000000000000002e-06
# loss:0.402, Epoch accuracy:92.81%, Validation loss:1.156, Validation accuracy:56.00%
# Epoch 299: iteration 34/35
# Epoch 299 --- lr:  1.0000000000000002e-06
# loss:0.389, Epoch accuracy:92.98%, Validation loss:1.127, Validation accuracy:57.33%
# Epoch 300: iteration 34/35
# Epoch 300 --- lr:  1.0000000000000002e-06
# loss:0.385, Epoch accuracy:94.39%, Validation loss:1.127, Validation accuracy:60.67%
# Epoch 301: iteration 34/35
# Epoch 301 --- lr:  1.0000000000000002e-06
# loss:0.381, Epoch accuracy:93.86%, Validation loss:1.127, Validation accuracy:58.67%
# Epoch 302: iteration 34/35
# Epoch 302 --- lr:  1.0000000000000002e-06
# loss:0.383, Epoch accuracy:94.91%, Validation loss:1.142, Validation accuracy:56.33%
# Epoch 303: iteration 34/35
# Epoch 303 --- lr:  1.0000000000000002e-06
# loss:0.383, Epoch accuracy:94.04%, Validation loss:1.136, Validation accuracy:56.67%
# Epoch 304: iteration 34/35
# Epoch 304 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:93.86%, Validation loss:1.136, Validation accuracy:58.00%
# Epoch 305: iteration 34/35
# Epoch 305 --- lr:  1.0000000000000002e-06
# loss:0.388, Epoch accuracy:92.98%, Validation loss:1.158, Validation accuracy:55.67%
# Epoch 306: iteration 34/35
# Epoch 306 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:93.77%, Validation loss:1.154, Validation accuracy:56.00%
# Epoch 307: iteration 34/35
# Epoch 307 --- lr:  1.0000000000000002e-06
# loss:0.389, Epoch accuracy:93.51%, Validation loss:1.156, Validation accuracy:57.33%
# Epoch 308: iteration 34/35
# Epoch 308 --- lr:  1.0000000000000002e-06
# loss:0.394, Epoch accuracy:93.33%, Validation loss:1.172, Validation accuracy:54.67%
# Epoch 309: iteration 34/35
# Epoch 309 --- lr:  1.0000000000000002e-06
# loss:0.384, Epoch accuracy:94.82%, Validation loss:1.187, Validation accuracy:56.33%
# Epoch 310: iteration 34/35
# Epoch 310 --- lr:  1.0000000000000002e-06
# loss:0.393, Epoch accuracy:94.12%, Validation loss:1.158, Validation accuracy:55.67%
# Epoch 311: iteration 34/35
# Epoch 311 --- lr:  1.0000000000000002e-06
# loss:0.398, Epoch accuracy:93.51%, Validation loss:1.151, Validation accuracy:55.67%
# Epoch 312: iteration 34/35
# Epoch 312 --- lr:  1.0000000000000002e-06
# loss:0.392, Epoch accuracy:93.25%, Validation loss:1.142, Validation accuracy:57.67%
# Epoch 313: iteration 34/35
# Epoch 313 --- lr:  1.0000000000000002e-06
# loss:0.399, Epoch accuracy:93.95%, Validation loss:1.136, Validation accuracy:57.00%
# Epoch 314: iteration 34/35
# Epoch 314 --- lr:  1.0000000000000002e-06
# loss:0.389, Epoch accuracy:94.12%, Validation loss:1.124, Validation accuracy:57.33%
# Epoch 315: iteration 34/35
# Epoch 315 --- lr:  1.0000000000000002e-06
# loss:0.380, Epoch accuracy:94.30%, Validation loss:1.132, Validation accuracy:59.67%
# Epoch 316: iteration 34/35
# Epoch 316 --- lr:  1.0000000000000002e-06
# loss:0.386, Epoch accuracy:93.60%, Validation loss:1.129, Validation accuracy:55.67%
# Epoch 317: iteration 34/35
# Epoch 317 --- lr:  1.0000000000000002e-06
# loss:0.372, Epoch accuracy:94.30%, Validation loss:1.135, Validation accuracy:57.67%
# Epoch 318: iteration 34/35
# Epoch 318 --- lr:  1.0000000000000002e-06
# loss:0.394, Epoch accuracy:92.46%, Validation loss:1.130, Validation accuracy:58.00%
# Epoch 319: iteration 34/35
# Epoch 319 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:93.86%, Validation loss:1.128, Validation accuracy:58.67%
# Epoch 320: iteration 34/35
# Epoch 320 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:93.86%, Validation loss:1.156, Validation accuracy:55.33%
# Epoch 321: iteration 34/35
# Epoch 321 --- lr:  1.0000000000000002e-06
# loss:0.386, Epoch accuracy:93.77%, Validation loss:1.135, Validation accuracy:58.67%
# Epoch 322: iteration 34/35
# Epoch 322 --- lr:  1.0000000000000002e-06
# loss:0.384, Epoch accuracy:93.95%, Validation loss:1.114, Validation accuracy:58.33%
# Epoch 323: iteration 34/35
# Epoch 323 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:94.30%, Validation loss:1.167, Validation accuracy:57.33%
# Epoch 324: iteration 34/35
# Epoch 324 --- lr:  1.0000000000000002e-06
# loss:0.400, Epoch accuracy:92.89%, Validation loss:1.143, Validation accuracy:56.33%
# Epoch 325: iteration 34/35
# Epoch 325 --- lr:  1.0000000000000002e-06
# loss:0.382, Epoch accuracy:93.86%, Validation loss:1.157, Validation accuracy:58.00%
# Epoch 326: iteration 34/35
# Epoch 326 --- lr:  1.0000000000000002e-06
# loss:0.375, Epoch accuracy:94.12%, Validation loss:1.163, Validation accuracy:57.33%
# Epoch 327: iteration 34/35
# Epoch 327 --- lr:  1.0000000000000002e-06
# loss:0.390, Epoch accuracy:93.95%, Validation loss:1.146, Validation accuracy:59.33%
# Epoch 328: iteration 34/35
# Epoch 328 --- lr:  1.0000000000000002e-06
# loss:0.393, Epoch accuracy:93.68%, Validation loss:1.140, Validation accuracy:57.33%
# Epoch 329: iteration 34/35
# Epoch 329 --- lr:  1.0000000000000002e-06
# loss:0.391, Epoch accuracy:93.60%, Validation loss:1.139, Validation accuracy:60.33%
# Epoch 330: iteration 34/35
# Epoch 330 --- lr:  1.0000000000000002e-06
# loss:0.365, Epoch accuracy:94.56%, Validation loss:1.108, Validation accuracy:59.00%
# Epoch 331: iteration 34/35
# Epoch 331 --- lr:  1.0000000000000002e-06
# loss:0.388, Epoch accuracy:93.60%, Validation loss:1.137, Validation accuracy:56.33%
# Epoch 332: iteration 34/35
# Epoch 332 --- lr:  1.0000000000000002e-06
# loss:0.398, Epoch accuracy:93.86%, Validation loss:1.123, Validation accuracy:58.33%
# Epoch 333: iteration 34/35
# Epoch 333 --- lr:  1.0000000000000002e-06
# loss:0.376, Epoch accuracy:93.95%, Validation loss:1.124, Validation accuracy:56.00%
# Epoch 334: iteration 34/35
# Epoch 334 --- lr:  1.0000000000000002e-06
# loss:0.387, Epoch accuracy:93.77%, Validation loss:1.146, Validation accuracy:56.33%
# Epoch 335: iteration 34/35
# Epoch 335 --- lr:  1.0000000000000002e-06
# loss:0.385, Epoch accuracy:93.68%, Validation loss:1.143, Validation accuracy:57.00%
# Epoch 336: iteration 34/35
# Epoch 336 --- lr:  1.0000000000000002e-06
# loss:0.383, Epoch accuracy:93.95%, Validation loss:1.159, Validation accuracy:58.67%
# Epoch 337: iteration 34/35
# Epoch 337 --- lr:  1.0000000000000002e-06
# loss:0.385, Epoch accuracy:94.21%, Validation loss:1.100, Validation accuracy:59.33%
# Epoch 338: iteration 34/35
# Epoch 338 --- lr:  1.0000000000000002e-06
# loss:0.384, Epoch accuracy:94.04%, Validation loss:1.134, Validation accuracy:57.67%
# Epoch 339: iteration 34/35
# Epoch 339 --- lr:  1.0000000000000002e-06
# loss:0.377, Epoch accuracy:93.95%, Validation loss:1.124, Validation accuracy:59.67%
# Epoch 340: iteration 34/35
# Epoch 340 --- lr:  1.0000000000000002e-06
# ...
# Epoch 397: iteration 36/37
# Epoch 397 --- lr:  1.0000000000000002e-06
# loss:0.370, Epoch accuracy:93.33%, Validation loss:1.380, Validation accuracy:57.50%
# Epoch 398: iteration 36/37
# Epoch 398 --- lr:  1.0000000000000002e-06
# loss:0.359, Epoch accuracy:93.83%, Validation loss:1.387, Validation accuracy:58.75%
# Epoch 399: iteration 36/37
# Epoch 399 --- lr:  1.0000000000000002e-06
# loss:0.369, Epoch accuracy:93.58%, Validation loss:1.394, Validation accuracy:56.25%
# Epoch 400: iteration 36/37
# Epoch 400 --- lr:  1.0000000000000002e-06
# loss:0.372, Epoch accuracy:93.00%, Validation loss:1.414, Validation accuracy:55.00%
# Epoch 401: iteration 36/37
# Epoch 401 --- lr:  1.0000000000000002e-06
# loss:0.365, Epoch accuracy:93.75%, Validation loss:1.411, Validation accuracy:55.00%
# Epoch 402: iteration 36/37
# Epoch 402 --- lr:  1.0000000000000002e-06
# loss:0.367, Epoch accuracy:94.42%, Validation loss:1.371, Validation accuracy:59.17%
# Epoch 403: iteration 36/37
# Epoch 403 --- lr:  1.0000000000000002e-06
# loss:0.356, Epoch accuracy:94.33%, Validation loss:1.389, Validation accuracy:55.00%
# Epoch 404: iteration 36/37
# Epoch 404 --- lr:  1.0000000000000002e-06
# loss:0.374, Epoch accuracy:92.42%, Validation loss:1.405, Validation accuracy:54.17%
# Epoch 405: iteration 36/37
# Epoch 405 --- lr:  1.0000000000000002e-06
# loss:0.375, Epoch accuracy:93.17%, Validation loss:1.364, Validation accuracy:58.33%
# Epoch 406: iteration 36/37
# Epoch 406 --- lr:  1.0000000000000002e-06
# loss:0.369, Epoch accuracy:93.92%, Validation loss:1.408, Validation accuracy:57.08%
# Epoch 407: iteration 36/37
# Epoch 407 --- lr:  1.0000000000000002e-06
# loss:0.361, Epoch accuracy:93.17%, Validation loss:1.401, Validation accuracy:57.08%
# Epoch 408: iteration 36/37
# Epoch 408 --- lr:  1.0000000000000002e-06
# loss:0.377, Epoch accuracy:93.33%, Validation loss:1.417, Validation accuracy:54.17%
# Epoch 409: iteration 36/37
# Epoch 409 --- lr:  1.0000000000000002e-06
# loss:0.368, Epoch accuracy:93.33%, Validation loss:1.405, Validation accuracy:53.75%
# Epoch 410: iteration 36/37
# Epoch 410 --- lr:  1.0000000000000002e-06
# loss:0.375, Epoch accuracy:93.17%, Validation loss:1.382, Validation accuracy:56.67%
# Epoch 411: iteration 36/37
# Epoch 411 --- lr:  1.0000000000000002e-06
# loss:0.369, Epoch accuracy:94.58%, Validation loss:1.377, Validation accuracy:57.92%
# Epoch 412: iteration 36/37
# Epoch 412 --- lr:  1.0000000000000002e-06
# loss:0.365, Epoch accuracy:94.67%, Validation loss:1.392, Validation accuracy:57.92%
# Epoch 413: iteration 36/37
# Epoch 413 --- lr:  1.0000000000000002e-06
# loss:0.360, Epoch accuracy:94.33%, Validation loss:1.428, Validation accuracy:57.50%
# Epoch 414: iteration 36/37
# Epoch 414 --- lr:  1.0000000000000002e-06
# loss:0.358, Epoch accuracy:94.08%, Validation loss:1.398, Validation accuracy:55.42%
# Epoch 415: iteration 36/37
# Epoch 415 --- lr:  1.0000000000000002e-06
# loss:0.372, Epoch accuracy:92.83%, Validation loss:1.391, Validation accuracy:53.75%
# Epoch 416: iteration 36/37
# Epoch 416 --- lr:  1.0000000000000002e-06
# loss:0.362, Epoch accuracy:94.50%, Validation loss:1.387, Validation accuracy:55.83%
# Epoch 417: iteration 36/37
# Epoch 417 --- lr:  1.0000000000000002e-06
# loss:0.360, Epoch accuracy:94.17%, Validation loss:1.364, Validation accuracy:59.17%
# Epoch 418: iteration 36/37
# Epoch 418 --- lr:  1.0000000000000002e-06
# loss:0.365, Epoch accuracy:94.33%, Validation loss:1.409, Validation accuracy:56.25%
# Epoch 419: iteration 36/37
# Epoch 419 --- lr:  1.0000000000000002e-06
# loss:0.368, Epoch accuracy:94.17%, Validation loss:1.400, Validation accuracy:55.83%
# Epoch 420: iteration 36/37
# Epoch 420 --- lr:  1.0000000000000002e-06
# loss:0.372, Epoch accuracy:93.17%, Validation loss:1.379, Validation accuracy:55.83%
# Epoch 421: iteration 36/37
# Epoch 421 --- lr:  1.0000000000000002e-06
# loss:0.365, Epoch accuracy:93.92%, Validation loss:1.368, Validation accuracy:56.25%
# Epoch 422: iteration 36/37
# Epoch 422 --- lr:  1.0000000000000002e-06
# loss:0.375, Epoch accuracy:93.42%, Validation loss:1.370, Validation accuracy:56.25%
# Epoch 423: iteration 36/37
# Epoch 423 --- lr:  1.0000000000000002e-06
# loss:0.371, Epoch accuracy:93.75%, Validation loss:1.398, Validation accuracy:58.75%
# Epoch 424: iteration 36/37
# Epoch 424 --- lr:  1.0000000000000002e-06
# loss:0.372, Epoch accuracy:93.25%, Validation loss:1.388, Validation accuracy:56.25%
# Epoch 425: iteration 36/37
# Epoch 425 --- lr:  1.0000000000000002e-06
# loss:0.363, Epoch accuracy:93.58%, Validation loss:1.382, Validation accuracy:55.00%
# Epoch 426: iteration 36/37
# Epoch 426 --- lr:  1.0000000000000002e-06
# loss:0.369, Epoch accuracy:93.75%, Validation loss:1.413, Validation accuracy:58.33%
# Epoch 427: iteration 36/37
# Epoch 427 --- lr:  1.0000000000000002e-06
# loss:0.370, Epoch accuracy:93.75%, Validation loss:1.414, Validation accuracy:56.67%
# Epoch 428: iteration 36/37
# Epoch 428 --- lr:  1.0000000000000002e-06
# loss:0.366, Epoch accuracy:94.50%, Validation loss:1.401, Validation accuracy:59.58%
# Epoch 429: iteration 36/37
# Epoch 429 --- lr:  1.0000000000000002e-06
# loss:0.367, Epoch accuracy:93.67%, Validation loss:1.425, Validation accuracy:57.92%
# Epoch 430: iteration 36/37
# Epoch 430 --- lr:  1.0000000000000002e-06
# loss:0.369, Epoch accuracy:93.17%, Validation loss:1.393, Validation accuracy:56.25%
# Epoch 431: iteration 36/37
# Epoch 431 --- lr:  1.0000000000000002e-06
# loss:0.365, Epoch accuracy:93.42%, Validation loss:1.431, Validation accuracy:55.83%
# Epoch 432: iteration 36/37
# Epoch 432 --- lr:  1.0000000000000002e-06
# loss:0.367, Epoch accuracy:94.08%, Validation loss:1.464, Validation accuracy:55.42%
# Epoch 433: iteration 36/37
# Epoch 433 --- lr:  1.0000000000000002e-06
# loss:0.366, Epoch accuracy:94.08%, Validation loss:1.387, Validation accuracy:56.25%
# Epoch 434: iteration 36/37
# Epoch 434 --- lr:  1.0000000000000002e-06
# loss:0.370, Epoch accuracy:93.50%, Validation loss:1.396, Validation accuracy:56.25%
# Epoch 435: iteration 36/37
# Epoch 435 --- lr:  1.0000000000000002e-06
# loss:0.362, Epoch accuracy:93.92%, Validation loss:1.362, Validation accuracy:56.67%
# Epoch 436: iteration 36/37
# Epoch 436 --- lr:  1.0000000000000002e-06
# loss:0.368, Epoch accuracy:93.92%, Validation loss:1.399, Validation accuracy:55.00%
# Epoch 437: iteration 36/37
# Epoch 437 --- lr:  1.0000000000000002e-06
# loss:0.362, Epoch accuracy:94.42%, Validation loss:1.422, Validation accuracy:55.83%
# Epoch 438: iteration 36/37
# Epoch 438 --- lr:  1.0000000000000002e-06
# loss:0.357, Epoch accuracy:94.33%, Validation loss:1.422, Validation accuracy:57.08%
# Epoch 439: iteration 36/37
# Epoch 439 --- lr:  1.0000000000000002e-06
# loss:0.362, Epoch accuracy:93.92%, Validation loss:1.378, Validation accuracy:56.67%
# Epoch 440: iteration 36/37
# Epoch 440 --- lr:  1.0000000000000002e-06
# loss:0.363, Epoch accuracy:94.00%, Validation loss:1.399, Validation accuracy:57.08%
# Epoch 441: iteration 36/37
# Epoch 441 --- lr:  1.0000000000000002e-06
# loss:0.360, Epoch accuracy:94.50%, Validation loss:1.368, Validation accuracy:57.50%
# Epoch 442: iteration 36/37
# Epoch 442 --- lr:  1.0000000000000002e-06
# loss:0.369, Epoch accuracy:93.50%, Validation loss:1.378, Validation accuracy:57.92%
# Epoch 443: iteration 36/37
# Epoch 443 --- lr:  1.0000000000000002e-06
# loss:0.355, Epoch accuracy:94.33%, Validation loss:1.378, Validation accuracy:55.42%
# Epoch 444: iteration 36/37
# Epoch 444 --- lr:  1.0000000000000002e-06
# loss:0.354, Epoch accuracy:95.25%, Validation loss:1.402, Validation accuracy:56.25%
# Epoch 445: iteration 36/37
# Epoch 445 --- lr:  1.0000000000000002e-06
# loss:0.364, Epoch accuracy:93.50%, Validation loss:1.389, Validation accuracy:56.25%
# Epoch 446: iteration 36/37
# Epoch 446 --- lr:  1.0000000000000002e-06
# loss:0.349, Epoch accuracy:94.50%, Validation loss:1.376, Validation accuracy:58.33%
# Epoch 447: iteration 36/37
# Epoch 447 --- lr:  1.0000000000000002e-06
# loss:0.356, Epoch accuracy:94.17%, Validation loss:1.443, Validation accuracy:55.42%
# Epoch 448: iteration 36/37
# Epoch 448 --- lr:  1.0000000000000002e-06
# loss:0.360, Epoch accuracy:93.42%, Validation loss:1.423, Validation accuracy:58.33%
# Epoch 449: iteration 36/37
# Epoch 449 --- lr:  1.0000000000000002e-06
# loss:0.358, Epoch accuracy:94.08%, Validation loss:1.410, Validation accuracy:55.00%
# Epoch 450: iteration 36/37
# Epoch 450 --- lr:  1.0000000000000002e-06
# loss:0.351, Epoch accuracy:94.75%, Validation loss:1.362, Validation accuracy:56.25%
# Epoch 451: iteration 36/37
# Epoch 451 --- lr:  1.0000000000000002e-06
# loss:0.359, Epoch accuracy:94.17%, Validation loss:1.377, Validation accuracy:55.42%
# Epoch 452: iteration 36/37
# Epoch 452 --- lr:  1.0000000000000002e-06
# loss:0.367, Epoch accuracy:94.08%, Validation loss:1.376, Validation accuracy:56.67%
# Epoch 453: iteration 36/37
# Epoch 453 --- lr:  1.0000000000000002e-06
# loss:0.366, Epoch accuracy:93.67%, Validation loss:1.425, Validation accuracy:57.08%
# Epoch 454: iteration 36/37
# Epoch 454 --- lr:  1.0000000000000002e-06
# loss:0.343, Epoch accuracy:94.92%, Validation loss:1.375, Validation accuracy:56.67%
# Epoch 455: iteration 36/37
# Epoch 455 --- lr:  1.0000000000000002e-06
# loss:0.356, Epoch accuracy:93.17%, Validation loss:1.406, Validation accuracy:55.42%
# Epoch 456: iteration 36/37
# Epoch 456 --- lr:  1.0000000000000002e-06
# loss:0.344, Epoch accuracy:94.08%, Validation loss:1.363, Validation accuracy:58.75%
# Epoch 457: iteration 36/37
# Epoch 457 --- lr:  1.0000000000000002e-06
# loss:0.367, Epoch accuracy:93.50%, Validation loss:1.404, Validation accuracy:53.33%
# Epoch 458: iteration 36/37
# Epoch 458 --- lr:  1.0000000000000002e-06
# loss:0.353, Epoch accuracy:94.17%, Validation loss:1.402, Validation accuracy:58.33%
# Epoch 459: iteration 36/37
# Epoch 459 --- lr:  1.0000000000000002e-06
# loss:0.343, Epoch accuracy:94.33%, Validation loss:1.403, Validation accuracy:54.58%
# Epoch 460: iteration 36/37
# Epoch 460 --- lr:  1.0000000000000002e-06
# loss:0.361, Epoch accuracy:93.33%, Validation loss:1.440, Validation accuracy:56.67%
# Epoch 461: iteration 36/37
# Epoch 461 --- lr:  1.0000000000000002e-06
# loss:0.355, Epoch accuracy:94.08%, Validation loss:1.364, Validation accuracy:56.25%
# Epoch 462: iteration 36/37
# Epoch 462 --- lr:  1.0000000000000002e-06
# loss:0.357, Epoch accuracy:94.00%, Validation loss:1.405, Validation accuracy:56.67%
# Epoch 463: iteration 36/37
# Epoch 463 --- lr:  1.0000000000000002e-06
# loss:0.364, Epoch accuracy:93.67%, Validation loss:1.390, Validation accuracy:55.42%
# Epoch 464: iteration 36/37
# Epoch 464 --- lr:  1.0000000000000002e-06
# loss:0.356, Epoch accuracy:93.83%, Validation loss:1.368, Validation accuracy:58.33%
# Epoch 465: iteration 36/37
# Epoch 465 --- lr:  1.0000000000000002e-06
# loss:0.361, Epoch accuracy:93.00%, Validation loss:1.337, Validation accuracy:58.75%
# Epoch 466: iteration 36/37
# Epoch 466 --- lr:  1.0000000000000002e-06
# loss:0.361, Epoch accuracy:93.67%, Validation loss:1.385, Validation accuracy:58.75%
# Epoch 467: iteration 36/37
# Epoch 467 --- lr:  1.0000000000000002e-06
# loss:0.348, Epoch accuracy:94.33%, Validation loss:1.425, Validation accuracy:56.25%
# Epoch 468: iteration 36/37
# Epoch 468 --- lr:  1.0000000000000002e-06
# loss:0.357, Epoch accuracy:94.50%, Validation loss:1.428, Validation accuracy:54.17%
# Epoch 469: iteration 36/37
# Epoch 469 --- lr:  1.0000000000000002e-06
# loss:0.368, Epoch accuracy:94.00%, Validation loss:1.417, Validation accuracy:57.08%
# Epoch 470: iteration 36/37
# Epoch 470 --- lr:  1.0000000000000002e-06
# loss:0.347, Epoch accuracy:94.75%, Validation loss:1.397, Validation accuracy:57.92%
# Epoch 471: iteration 36/37
# Epoch 471 --- lr:  1.0000000000000002e-06
# loss:0.347, Epoch accuracy:94.92%, Validation loss:1.407, Validation accuracy:55.00%
# Epoch 472: iteration 36/37
# Epoch 472 --- lr:  1.0000000000000002e-06
# loss:0.370, Epoch accuracy:93.17%, Validation loss:1.388, Validation accuracy:57.92%
# Epoch 473: iteration 36/37
# Epoch 473 --- lr:  1.0000000000000002e-06
# loss:0.349, Epoch accuracy:94.75%, Validation loss:1.388, Validation accuracy:56.25%
# Epoch 474: iteration 36/37
# Epoch 474 --- lr:  1.0000000000000002e-06
# loss:0.362, Epoch accuracy:93.92%, Validation loss:1.442, Validation accuracy:55.83%
# Epoch 475: iteration 36/37
# Epoch 475 --- lr:  1.0000000000000002e-06
# loss:0.348, Epoch accuracy:94.25%, Validation loss:1.386, Validation accuracy:58.33%
# Epoch 476: iteration 36/37
# Epoch 476 --- lr:  1.0000000000000002e-06
# loss:0.349, Epoch accuracy:94.42%, Validation loss:1.402, Validation accuracy:53.75%
# Epoch 477: iteration 36/37
# Epoch 477 --- lr:  1.0000000000000002e-06
# loss:0.357, Epoch accuracy:93.92%, Validation loss:1.371, Validation accuracy:58.75%
# Epoch 478: iteration 36/37
# Epoch 478 --- lr:  1.0000000000000002e-06
# loss:0.367, Epoch accuracy:92.67%, Validation loss:1.422, Validation accuracy:56.67%
# Epoch 479: iteration 36/37
# Epoch 479 --- lr:  1.0000000000000002e-06
# loss:0.356, Epoch accuracy:94.67%, Validation loss:1.355, Validation accuracy:57.50%
# Epoch 480: iteration 36/37
# Epoch 480 --- lr:  1.0000000000000002e-06
# loss:0.343, Epoch accuracy:95.17%, Validation loss:1.412, Validation accuracy:55.00%
# Epoch 481: iteration 36/37
# Epoch 481 --- lr:  1.0000000000000002e-06
# loss:0.355, Epoch accuracy:93.83%, Validation loss:1.418, Validation accuracy:56.25%
# Epoch 482: iteration 36/37
# Epoch 482 --- lr:  1.0000000000000002e-06
# loss:0.340, Epoch accuracy:95.00%, Validation loss:1.415, Validation accuracy:56.25%
# Epoch 483: iteration 36/37
# Epoch 483 --- lr:  1.0000000000000002e-06
# loss:0.365, Epoch accuracy:93.33%, Validation loss:1.367, Validation accuracy:56.25%
# Epoch 484: iteration 36/37
# Epoch 484 --- lr:  1.0000000000000002e-06
# loss:0.345, Epoch accuracy:95.17%, Validation loss:1.392, Validation accuracy:56.25%
# Epoch 485: iteration 36/37
# Epoch 485 --- lr:  1.0000000000000002e-06
# loss:0.355, Epoch accuracy:93.83%, Validation loss:1.412, Validation accuracy:57.92%
# Epoch 486: iteration 36/37
# Epoch 486 --- lr:  1.0000000000000002e-06
# loss:0.357, Epoch accuracy:94.33%, Validation loss:1.393, Validation accuracy:56.25%
# Epoch 487: iteration 36/37
# Epoch 487 --- lr:  1.0000000000000002e-06
# loss:0.350, Epoch accuracy:94.50%, Validation loss:1.380, Validation accuracy:54.58%
# Epoch 488: iteration 36/37
# Epoch 488 --- lr:  1.0000000000000002e-06
# loss:0.356, Epoch accuracy:94.58%, Validation loss:1.379, Validation accuracy:57.08%
# Epoch 489: iteration 36/37
# Epoch 489 --- lr:  1.0000000000000002e-06
# loss:0.362, Epoch accuracy:94.00%, Validation loss:1.429, Validation accuracy:55.83%
# Epoch 490: iteration 36/37
# Epoch 490 --- lr:  1.0000000000000002e-06
# loss:0.339, Epoch accuracy:94.08%, Validation loss:1.409, Validation accuracy:55.00%
# Epoch 491: iteration 36/37
# Epoch 491 --- lr:  1.0000000000000002e-06
# loss:0.343, Epoch accuracy:94.67%, Validation loss:1.394, Validation accuracy:58.33%
# Epoch 492: iteration 36/37
# Epoch 492 --- lr:  1.0000000000000002e-06
# loss:0.347, Epoch accuracy:94.33%, Validation loss:1.386, Validation accuracy:56.25%
# Epoch 493: iteration 36/37
# Epoch 493 --- lr:  1.0000000000000002e-06
# loss:0.356, Epoch accuracy:94.00%, Validation loss:1.383, Validation accuracy:55.83%
# Epoch 494: iteration 36/37
# Epoch 494 --- lr:  1.0000000000000002e-06
# loss:0.346, Epoch accuracy:93.92%, Validation loss:1.391, Validation accuracy:55.42%
# Epoch 495: iteration 36/37
# Epoch 495 --- lr:  1.0000000000000002e-06
# loss:0.363, Epoch accuracy:94.42%, Validation loss:1.425, Validation accuracy:55.83%
# Epoch 496: iteration 36/37
# Epoch 496 --- lr:  1.0000000000000002e-06
# loss:0.351, Epoch accuracy:94.58%, Validation loss:1.388, Validation accuracy:58.75%
# Epoch 497: iteration 36/37
# Epoch 497 --- lr:  1.0000000000000002e-06
# loss:0.353, Epoch accuracy:93.67%, Validation loss:1.392, Validation accuracy:57.08%
# Epoch 498: iteration 36/37
# Epoch 498 --- lr:  1.0000000000000002e-06
# loss:0.350, Epoch accuracy:94.42%, Validation loss:1.430, Validation accuracy:59.17%
# Epoch 499: iteration 36/37
# Epoch 499 --- lr:  1.0000000000000002e-06
# loss:0.343, Epoch accuracy:94.92%, Validation loss:1.387, Validation accuracy:57.08%
#
#
# [*] done !
# [*] Best training loss - 0.33941769282023115
# [*] Best validation loss - 1.2660863399505615

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
# Out:
# [*] 0 Test accuracy is 65.00%
# [*] 1 Test accuracy is 62.33%
# [*] 2 Test accuracy is 58.33%
# [*] 3 Test accuracy is 59.33%
# [*] 4 Test accuracy is 55.00%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 65.00%
# [*] Worst fold acc : 55.00%
# [*] Average fold acc : 60.00%

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
# Out:
# [*] 0 Test accuracy is 64.33%
#               precision    recall  f1-score   support
#
#            0       0.62      0.25      0.36        20
#            1       0.74      0.88      0.80        40
#            2       0.66      0.68      0.67        40
#            3       0.39      0.42      0.40        40
#            4       0.78      0.88      0.82        40
#            5       0.85      0.55      0.67        40
#            6       0.52      0.60      0.56        40
#            7       0.65      0.70      0.67        40
#
#     accuracy                           0.64       300
#    macro avg       0.65      0.62      0.62       300
# weighted avg       0.65      0.64      0.64       300
#
# [*] 1 Test accuracy is 64.00%
#               precision    recall  f1-score   support
#
#            0       0.18      0.20      0.19        20
#            1       0.67      0.75      0.71        40
#            2       0.59      0.65      0.62        40
#            3       0.70      0.40      0.51        40
#            4       0.81      0.72      0.76        40
#            5       0.65      0.60      0.62        40
#            6       0.68      0.70      0.69        40
#            7       0.67      0.88      0.76        40
#
#     accuracy                           0.64       300
#    macro avg       0.62      0.61      0.61       300
# weighted avg       0.65      0.64      0.64       300
#
# [*] 2 Test accuracy is 58.67%
#               precision    recall  f1-score   support
#
#            0       0.57      0.20      0.30        20
#            1       0.71      0.72      0.72        40
#            2       0.51      0.47      0.49        40
#            3       0.29      0.38      0.33        40
#            4       0.73      0.68      0.70        40
#            5       0.61      0.55      0.58        40
#            6       0.66      0.78      0.71        40
#            7       0.67      0.72      0.70        40
#
#     accuracy                           0.59       300
#    macro avg       0.59      0.56      0.57       300
# weighted avg       0.60      0.59      0.58       300
#
# [*] 3 Test accuracy is 59.00%
#               precision    recall  f1-score   support
#
#            0       0.71      0.25      0.37        20
#            1       0.68      0.70      0.69        40
#            2       0.50      0.38      0.43        40
#            3       0.33      0.38      0.35        40
#            4       0.68      0.75      0.71        40
#            5       0.49      0.68      0.57        40
#            6       0.72      0.70      0.71        40
#            7       0.74      0.72      0.73        40
#
#     accuracy                           0.59       300
#    macro avg       0.61      0.57      0.57       300
# weighted avg       0.60      0.59      0.58       300
#
# [*] 4 Test accuracy is 57.08%
#               precision    recall  f1-score   support
#
#            0       0.50      0.06      0.11        16
#            1       0.48      0.62      0.54        32
#            2       0.61      0.53      0.57        32
#            3       0.39      0.50      0.44        32
#            4       0.72      0.66      0.69        32
#            5       0.57      0.75      0.65        32
#            6       0.81      0.53      0.64        32
#            7       0.60      0.66      0.63        32
#
#     accuracy                           0.57       240
#    macro avg       0.58      0.54      0.53       240
# weighted avg       0.59      0.57      0.56       240
