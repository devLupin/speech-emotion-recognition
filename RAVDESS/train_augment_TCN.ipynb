# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torch.autograd import Variable
from torchinfo import summary
from tqdm.auto import tqdm

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f'Device : {device}')
print(f'Count of using GPUs : {torch.cuda.device_count()}')
print(f'Current cuda device : {torch.cuda.current_device()}\n')

# %%
class _LayerNorm(nn.Module):
    """Layer Normalization base class."""

    def __init__(self, channel_size):
        super(_LayerNorm, self).__init__()
        self.channel_size = channel_size
        self.gamma = nn.Parameter(torch.ones(channel_size),
                                  requires_grad=True)
        self.beta = nn.Parameter(torch.zeros(channel_size),
                                 requires_grad=True)

    def apply_gain_and_bias(self, normed_x):
        """ Assumes input of size `[batch, chanel, *]`. """
        return (self.gamma * normed_x.transpose(1, -1) +
                self.beta).transpose(1, -1)


EPS = 1e-8


class GlobLN(_LayerNorm):
    """Global Layer Normalization (globLN)."""

    def forward(self, x):
        """ Applies forward pass.
        Works for any input size > 2D.
        Args:
            x (:class:`torch.Tensor`): Shape `[batch, chan, *]`
        Returns:
            :class:`torch.Tensor`: gLN_x `[batch, chan, *]`
        """
        dims = list(range(1, len(x.shape)))
        mean = x.mean(dim=dims, keepdim=True)
        var = torch.pow(x - mean, 2).mean(dim=dims, keepdim=True)
        return self.apply_gain_and_bias((x - mean) / (var + EPS).sqrt())


class Conv1DBlock(nn.Module):
    """One dimensional convolutional block, as proposed in [1].
    Args:
        in_chan (int): Number of input channels.
        hid_chan (int): Number of hidden channels in the depth-wise
            convolution.
        skip_out_chan (int): Number of channels in the skip convolution.
            If 0 or None, `Conv1DBlock` won't have any skip connections.
            Corresponds to the the block in v1 or the paper. The `forward`
            return res instead of [res, skip] in this case.
        kernel_size (int): Size of the depth-wise convolutional kernel.
        padding (int): Padding of the depth-wise convolution.
        dilation (int): Dilation of the depth-wise convolution.
        norm_type (str, optional): Type of normalization to use. To choose from
            -  ``'gLN'``: global Layernorm
            -  ``'cLN'``: channelwise Layernorm
            -  ``'cgLN'``: cumulative global Layernorm
    References:
        [1] : "Conv-TasNet: Surpassing ideal time-frequency magnitude masking
        for speech separation" TASLP 2019 Yi Luo, Nima Mesgarani
        https://arxiv.org/abs/1809.07454
    """

    def __init__(self, in_chan, hid_chan, kernel_size, padding,
                 dilation, ):
        super(Conv1DBlock, self).__init__()
        conv_norm = GlobLN
        in_conv1d = nn.Conv1d(in_chan, hid_chan, 1)
        depth_conv1d = nn.Conv1d(hid_chan, hid_chan, kernel_size,
                                 padding=padding, dilation=dilation,
                                 groups=hid_chan)
        self.shared_block = nn.Sequential(in_conv1d, nn.PReLU(),
                                          conv_norm(hid_chan), depth_conv1d,
                                          nn.PReLU(), conv_norm(hid_chan))
        self.res_conv = nn.Conv1d(hid_chan, in_chan, 1)

    def forward(self, x):
        """ Input shape [batch, feats, seq]"""
        shared_out = self.shared_block(x)
        res_out = self.res_conv(shared_out)
        return res_out


class TCN(nn.Module):
    # n blocks --> receptive field increases , n_repeats increases capacity mostly
    def __init__(self, in_chan=40, n_src=1, out_chan=8, n_blocks=5, n_repeats=2, 
                 bn_chan=64, hid_chan=128, kernel_size=3, dropout_prob=0.2 ):
        super(TCN, self).__init__()
        self.in_chan = in_chan
        self.n_src = n_src
        out_chan = out_chan if out_chan else in_chan
        self.out_chan = out_chan
        self.n_blocks = n_blocks
        self.n_repeats = n_repeats
        self.bn_chan = bn_chan
        self.hid_chan = hid_chan
        self.kernel_size = kernel_size

        self.dropout = nn.Dropout(p=dropout_prob)

        layer_norm = GlobLN(in_chan)
        bottleneck_conv = nn.Conv1d(in_chan, bn_chan, 1)
        self.bottleneck = nn.Sequential(layer_norm, bottleneck_conv)
        # Succession of Conv1DBlock with exponentially increasing dilation.
        self.TCN = nn.ModuleList()
        for r in range(n_repeats):       #ripetizioni 2
            for x in range(n_blocks):     #5 layers convoluzionali
                padding = (kernel_size - 1) * 2 ** x // 2
                self.TCN.append(Conv1DBlock(bn_chan, hid_chan,
                                            kernel_size, padding=padding,
                                            dilation=2 ** x))

        out_conv = nn.Linear(bn_chan, n_src * out_chan)
        self.out = nn.Sequential(nn.PReLU(), out_conv)
        
        self.softmax_out = nn.Softmax(dim=1)

    # self.out = nn.Linear(bn_chan, n_src*out_chan)
    # self.out = nn.Linear(800, n_src*out_chan)

    # Get activation function.
    def forward(self, mixture_w):
        output = self.dropout(self.bottleneck(mixture_w))
        for i in range(len(self.TCN)):
            residual = self.TCN[i](output)
            output = output + residual
        output = self.dropout(output)

        output_logits = self.out(self.dropout(output.mean(-1)))
        output_softmax = self.softmax_out(output_logits)
        
        return output_logits, output_softmax
        
        return logits

# %%
from torchinfo import summary

emotions_dict = {
    '0': 'surprised',
    '1': 'neutral',
    '2': 'calm',
    '3': 'happy',
    '4': 'sad',
    '5': 'angry',
    '6': 'fearful',
    '7': 'disgust'
}

model = TCN().to('cuda')
sub_name = 'TCN'
data_name = 'RAVDESS'

EARLY_CNT=500
minibatch = 128
num_epochs = 500
print(summary(model, input_size=(minibatch, 40, 282)))

optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TCN                                      [128, 8]                  --
# ├─Dropout: 1-5                           [128, 64]                 --
# ├─Sequential: 1-2                        [128, 64, 282]            --
# │    └─GlobLN: 2-1                       [128, 40, 282]            80
# │    └─Conv1d: 2-2                       [128, 64, 282]            2,624
# ├─Dropout: 1-3                           [128, 64, 282]            --
# ├─ModuleList: 1                          --                        --
# │    └─Conv1DBlock: 2-3                  [128, 64, 282]            --
# │    │    └─Sequential: 3-1              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-2                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-4                  [128, 64, 282]            --
# │    │    └─Sequential: 3-3              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-4                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-5                  [128, 64, 282]            --
# │    │    └─Sequential: 3-5              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-6                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-6                  [128, 64, 282]            --
# │    │    └─Sequential: 3-7              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-8                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-7                  [128, 64, 282]            --
# │    │    └─Sequential: 3-9              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-10                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-8                  [128, 64, 282]            --
# │    │    └─Sequential: 3-11             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-12                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-9                  [128, 64, 282]            --
# │    │    └─Sequential: 3-13             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-14                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-10                 [128, 64, 282]            --
# │    │    └─Sequential: 3-15             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-16                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-11                 [128, 64, 282]            --
# │    │    └─Sequential: 3-17             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-18                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-12                 [128, 64, 282]            --
# │    │    └─Sequential: 3-19             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-20                 [128, 64, 282]            8,256
# ├─Dropout: 1-4                           [128, 64, 282]            --
# ├─Dropout: 1-5                           [128, 64]                 --
# ├─Sequential: 1-6                        [128, 8]                  --
# │    └─PReLU: 2-13                       [128, 64]                 1
# │    └─Linear: 2-14                      [128, 8]                  520
# ├─Softmax: 1-7                           [128, 8]                  --
# ==========================================================================================
# Total params: 179,245
# Trainable params: 179,245
# Non-trainable params: 0
# Total mult-adds (G): 6.26
# ==========================================================================================
# Input size (MB): 5.78
# Forward/backward pass size (MB): 2432.66
# Params size (MB): 0.72
# Estimated Total Size (MB): 2439.15
# ==========================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

class FocalLoss(nn.Module):
    def __init__(self, gamma=0, alpha=None, size_average=True):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.alpha = alpha
        if isinstance(alpha,(float,int,long)): self.alpha = torch.Tensor([alpha,1-alpha])
        if isinstance(alpha,list): self.alpha = torch.Tensor(alpha)
        self.size_average = size_average

    def forward(self, input, target):
        if input.dim()>2:
            input = input.view(input.size(0),input.size(1),-1)  # N,C,H,W => N,C,H*W
            input = input.transpose(1,2)    # N,C,H*W => N,H*W,C
            input = input.contiguous().view(-1,input.size(2))   # N,H*W,C => N*H*W,C
        target = target.view(-1,1)

        logpt = F.log_softmax(input)
        logpt = logpt.gather(1,target)
        logpt = logpt.view(-1)
        pt = Variable(logpt.data.exp())

        if self.alpha is not None:
            if self.alpha.type()!=input.data.type():
                self.alpha = self.alpha.type_as(input.data)
            at = self.alpha.gather(0,target.data.view(-1))
            logpt = logpt * Variable(at)

        loss = -1 * (1-pt)**self.gamma * logpt
        if self.size_average: return loss.mean()
        else: return loss.sum()

def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

npy_path = './numpy_48k_1d'
all_npy = os.listdir(npy_path)

print(f'[*] model training - {sub_name}')
for fold in all_npy:
    npy = os.path.join(npy_path, fold)
    
    with open(npy, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
        
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - TCN
# 0.npy:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 25/26
# Epoch 0 --- loss:2.173, Epoch accuracy:12.98%, Validation loss:2.117, Validation accuracy:13.56%
# Epoch 1: iteration 25/26
# Epoch 1 --- loss:2.065, Epoch accuracy:12.16%, Validation loss:2.084, Validation accuracy:13.89%
# Epoch 2: iteration 25/26
# Epoch 2 --- loss:2.046, Epoch accuracy:12.37%, Validation loss:2.066, Validation accuracy:15.67%
# Epoch 3: iteration 25/26
# Epoch 3 --- loss:2.041, Epoch accuracy:12.87%, Validation loss:2.058, Validation accuracy:13.78%
# Epoch 4: iteration 25/26
# Epoch 4 --- loss:2.027, Epoch accuracy:14.09%, Validation loss:2.054, Validation accuracy:13.89%
# Epoch 5: iteration 25/26
# Epoch 5 --- loss:2.027, Epoch accuracy:13.63%, Validation loss:2.053, Validation accuracy:14.00%
# Epoch 6: iteration 25/26
# Epoch 6 --- loss:2.013, Epoch accuracy:15.18%, Validation loss:2.052, Validation accuracy:15.67%
# Epoch 7: iteration 25/26
# Epoch 7 --- loss:2.014, Epoch accuracy:14.56%, Validation loss:2.045, Validation accuracy:19.89%
# Epoch 8: iteration 25/26
# Epoch 8 --- loss:2.010, Epoch accuracy:15.41%, Validation loss:2.044, Validation accuracy:15.89%
# Epoch 9: iteration 25/26
# Epoch 9 --- loss:2.005, Epoch accuracy:15.38%, Validation loss:2.040, Validation accuracy:16.44%
# Epoch 10: iteration 25/26
# Epoch 10 --- loss:2.001, Epoch accuracy:16.64%, Validation loss:2.036, Validation accuracy:16.56%
# Epoch 11: iteration 25/26
# Epoch 11 --- loss:2.000, Epoch accuracy:16.05%, Validation loss:2.030, Validation accuracy:17.33%
# Epoch 12: iteration 25/26
# Epoch 12 --- loss:1.993, Epoch accuracy:16.81%, Validation loss:2.025, Validation accuracy:18.44%
# Epoch 13: iteration 25/26
# Epoch 13 --- loss:1.989, Epoch accuracy:18.01%, Validation loss:2.019, Validation accuracy:18.22%
# Epoch 14: iteration 25/26
# Epoch 14 --- loss:1.979, Epoch accuracy:18.83%, Validation loss:2.014, Validation accuracy:23.33%
# Epoch 15: iteration 25/26
# Epoch 15 --- loss:1.977, Epoch accuracy:18.98%, Validation loss:2.007, Validation accuracy:23.33%
# Epoch 16: iteration 25/26
# Epoch 16 --- loss:1.973, Epoch accuracy:19.01%, Validation loss:1.999, Validation accuracy:27.22%
# Epoch 17: iteration 25/26
# Epoch 17 --- loss:1.969, Epoch accuracy:19.77%, Validation loss:1.996, Validation accuracy:21.33%
# Epoch 18: iteration 25/26
# Epoch 18 --- loss:1.966, Epoch accuracy:20.09%, Validation loss:1.984, Validation accuracy:25.56%
# Epoch 19: iteration 25/26
# Epoch 19 --- loss:1.960, Epoch accuracy:19.71%, Validation loss:1.982, Validation accuracy:22.22%
# Epoch 20: iteration 25/26
# Epoch 20 --- loss:1.950, Epoch accuracy:21.05%, Validation loss:1.965, Validation accuracy:26.22%
# Epoch 21: iteration 25/26
# Epoch 21 --- loss:1.940, Epoch accuracy:21.02%, Validation loss:1.953, Validation accuracy:26.44%
# Epoch 22: iteration 25/26
# Epoch 22 --- loss:1.933, Epoch accuracy:20.64%, Validation loss:1.951, Validation accuracy:23.56%
# Epoch 23: iteration 25/26
# Epoch 23 --- loss:1.926, Epoch accuracy:21.26%, Validation loss:1.937, Validation accuracy:23.78%
# Epoch 24: iteration 25/26
# Epoch 24 --- loss:1.919, Epoch accuracy:20.64%, Validation loss:1.922, Validation accuracy:25.56%
# Epoch 25: iteration 25/26
# Epoch 25 --- loss:1.905, Epoch accuracy:22.22%, Validation loss:1.912, Validation accuracy:26.67%
# Epoch 26: iteration 25/26
# Epoch 26 --- loss:1.900, Epoch accuracy:23.07%, Validation loss:1.925, Validation accuracy:23.56%
# Epoch 27: iteration 25/26
# Epoch 27 --- loss:1.893, Epoch accuracy:23.16%, Validation loss:1.907, Validation accuracy:24.56%
# Epoch 28: iteration 25/26
# Epoch 28 --- loss:1.885, Epoch accuracy:23.13%, Validation loss:1.917, Validation accuracy:23.44%
# Epoch 29: iteration 25/26
# Epoch 29 --- loss:1.881, Epoch accuracy:22.89%, Validation loss:1.899, Validation accuracy:24.78%
# Epoch 30: iteration 25/26
# Epoch 30 --- loss:1.871, Epoch accuracy:24.09%, Validation loss:1.865, Validation accuracy:28.22%
# Epoch 31: iteration 25/26
# Epoch 31 --- loss:1.865, Epoch accuracy:24.04%, Validation loss:1.852, Validation accuracy:29.44%
# Epoch 32: iteration 25/26
# Epoch 32 --- loss:1.862, Epoch accuracy:23.83%, Validation loss:1.855, Validation accuracy:28.78%
# Epoch 33: iteration 25/26
# Epoch 33 --- loss:1.849, Epoch accuracy:25.79%, Validation loss:1.850, Validation accuracy:29.11%
# Epoch 34: iteration 25/26
# Epoch 34 --- loss:1.851, Epoch accuracy:24.94%, Validation loss:1.852, Validation accuracy:28.11%
# Epoch 35: iteration 25/26
# Epoch 35 --- loss:1.843, Epoch accuracy:25.58%, Validation loss:1.836, Validation accuracy:28.22%
# Epoch 36: iteration 25/26
# Epoch 36 --- loss:1.839, Epoch accuracy:25.32%, Validation loss:1.824, Validation accuracy:28.89%
# Epoch 37: iteration 25/26
# Epoch 37 --- loss:1.830, Epoch accuracy:26.17%, Validation loss:1.826, Validation accuracy:29.44%
# Epoch 38: iteration 25/26
# Epoch 38 --- loss:1.822, Epoch accuracy:27.16%, Validation loss:1.812, Validation accuracy:29.89%
# Epoch 39: iteration 25/26
# Epoch 39 --- loss:1.821, Epoch accuracy:25.56%, Validation loss:1.818, Validation accuracy:29.56%
# Epoch 40: iteration 25/26
# Epoch 40 --- loss:1.816, Epoch accuracy:27.34%, Validation loss:1.805, Validation accuracy:29.67%
# Epoch 41: iteration 25/26
# Epoch 41 --- loss:1.815, Epoch accuracy:26.02%, Validation loss:1.818, Validation accuracy:30.33%
# Epoch 42: iteration 25/26
# Epoch 42 --- loss:1.811, Epoch accuracy:26.75%, Validation loss:1.790, Validation accuracy:29.67%
# Epoch 43: iteration 25/26
# Epoch 43 --- loss:1.805, Epoch accuracy:26.17%, Validation loss:1.800, Validation accuracy:29.00%
# Epoch 44: iteration 25/26
# Epoch 44 --- loss:1.803, Epoch accuracy:26.11%, Validation loss:1.791, Validation accuracy:30.00%
# Epoch 45: iteration 25/26
# Epoch 45 --- loss:1.795, Epoch accuracy:26.02%, Validation loss:1.801, Validation accuracy:29.56%
# Epoch 46: iteration 25/26
# Epoch 46 --- loss:1.788, Epoch accuracy:27.54%, Validation loss:1.779, Validation accuracy:31.11%
# Epoch 47: iteration 25/26
# Epoch 47 --- loss:1.782, Epoch accuracy:27.81%, Validation loss:1.788, Validation accuracy:29.89%
# Epoch 48: iteration 25/26
# Epoch 48 --- loss:1.775, Epoch accuracy:28.39%, Validation loss:1.779, Validation accuracy:30.56%
# Epoch 49: iteration 25/26
# Epoch 49 --- loss:1.774, Epoch accuracy:28.07%, Validation loss:1.784, Validation accuracy:30.00%
# Epoch 50: iteration 25/26
# Epoch 50 --- loss:1.779, Epoch accuracy:28.27%, Validation loss:1.777, Validation accuracy:30.00%
# Epoch 51: iteration 25/26
# Epoch 51 --- loss:1.766, Epoch accuracy:27.72%, Validation loss:1.779, Validation accuracy:30.11%
# Epoch 52: iteration 25/26
# Epoch 52 --- loss:1.767, Epoch accuracy:28.63%, Validation loss:1.779, Validation accuracy:30.56%
# Epoch 53: iteration 25/26
# Epoch 53 --- loss:1.765, Epoch accuracy:28.71%, Validation loss:1.769, Validation accuracy:31.00%
# Epoch 54: iteration 25/26
# Epoch 54 --- loss:1.757, Epoch accuracy:27.98%, Validation loss:1.763, Validation accuracy:30.67%
# Epoch 55: iteration 25/26
# Epoch 55 --- loss:1.755, Epoch accuracy:28.39%, Validation loss:1.760, Validation accuracy:30.44%
# Epoch 56: iteration 25/26
# Epoch 56 --- loss:1.753, Epoch accuracy:28.48%, Validation loss:1.763, Validation accuracy:30.67%
# Epoch 57: iteration 25/26
# Epoch 57 --- loss:1.754, Epoch accuracy:27.87%, Validation loss:1.764, Validation accuracy:30.89%
# Epoch 58: iteration 25/26
# Epoch 58 --- loss:1.748, Epoch accuracy:28.48%, Validation loss:1.753, Validation accuracy:30.22%
# Epoch 59: iteration 25/26
# Epoch 59 --- loss:1.744, Epoch accuracy:29.21%, Validation loss:1.749, Validation accuracy:31.22%
# Epoch 60: iteration 25/26
# Epoch 60 --- loss:1.744, Epoch accuracy:28.77%, Validation loss:1.768, Validation accuracy:30.22%
# Epoch 61: iteration 25/26
# Epoch 61 --- loss:1.741, Epoch accuracy:29.18%, Validation loss:1.756, Validation accuracy:30.44%
# Epoch 62: iteration 25/26
# Epoch 62 --- loss:1.734, Epoch accuracy:29.36%, Validation loss:1.752, Validation accuracy:31.44%
# Epoch 63: iteration 25/26
# Epoch 63 --- loss:1.731, Epoch accuracy:29.74%, Validation loss:1.755, Validation accuracy:31.33%
# Epoch 64: iteration 25/26
# Epoch 64 --- loss:1.731, Epoch accuracy:30.35%, Validation loss:1.762, Validation accuracy:30.89%
# Epoch 65: iteration 25/26
# Epoch 65 --- loss:1.728, Epoch accuracy:30.44%, Validation loss:1.754, Validation accuracy:31.22%
# Epoch 66: iteration 25/26
# Epoch 66 --- loss:1.720, Epoch accuracy:29.39%, Validation loss:1.747, Validation accuracy:31.67%
# Epoch 67: iteration 25/26
# Epoch 67 --- loss:1.724, Epoch accuracy:29.39%, Validation loss:1.760, Validation accuracy:30.44%
# Epoch 68: iteration 25/26
# Epoch 68 --- loss:1.719, Epoch accuracy:30.09%, Validation loss:1.745, Validation accuracy:30.56%
# Epoch 69: iteration 25/26
# Epoch 69 --- loss:1.723, Epoch accuracy:30.26%, Validation loss:1.745, Validation accuracy:31.33%
# Epoch 70: iteration 25/26
# Epoch 70 --- loss:1.719, Epoch accuracy:30.56%, Validation loss:1.763, Validation accuracy:30.00%
# Epoch 71: iteration 25/26
# Epoch 71 --- loss:1.718, Epoch accuracy:30.12%, Validation loss:1.735, Validation accuracy:31.89%
# Epoch 72: iteration 25/26
# Epoch 72 --- loss:1.717, Epoch accuracy:30.03%, Validation loss:1.753, Validation accuracy:29.78%
# Epoch 73: iteration 25/26
# Epoch 73 --- loss:1.719, Epoch accuracy:30.09%, Validation loss:1.732, Validation accuracy:32.00%
# Epoch 74: iteration 25/26
# Epoch 74 --- loss:1.716, Epoch accuracy:29.65%, Validation loss:1.730, Validation accuracy:31.89%
# Epoch 75: iteration 25/26
# Epoch 75 --- loss:1.708, Epoch accuracy:29.62%, Validation loss:1.736, Validation accuracy:31.44%
# Epoch 76: iteration 25/26
# Epoch 76 --- loss:1.699, Epoch accuracy:30.70%, Validation loss:1.736, Validation accuracy:31.33%
# Epoch 77: iteration 25/26
# Epoch 77 --- loss:1.705, Epoch accuracy:30.58%, Validation loss:1.734, Validation accuracy:31.56%
# Epoch 78: iteration 25/26
# Epoch 78 --- loss:1.701, Epoch accuracy:30.50%, Validation loss:1.737, Validation accuracy:30.89%
# Epoch 79: iteration 25/26
# Epoch 79 --- loss:1.700, Epoch accuracy:30.58%, Validation loss:1.741, Validation accuracy:30.44%
# Epoch 80: iteration 25/26
# Epoch 80 --- loss:1.700, Epoch accuracy:30.64%, Validation loss:1.743, Validation accuracy:30.67%
# Epoch 81: iteration 25/26
# Epoch 81 --- loss:1.703, Epoch accuracy:30.79%, Validation loss:1.732, Validation accuracy:31.33%
# Epoch 82: iteration 25/26
# Epoch 82 --- loss:1.693, Epoch accuracy:30.64%, Validation loss:1.736, Validation accuracy:31.22%
# Epoch 83: iteration 25/26
# Epoch 83 --- loss:1.692, Epoch accuracy:31.37%, Validation loss:1.749, Validation accuracy:31.00%
# Epoch 84: iteration 25/26
# Epoch 84 --- loss:1.698, Epoch accuracy:30.64%, Validation loss:1.740, Validation accuracy:31.22%
# Epoch 85: iteration 25/26
# Epoch 85 --- loss:1.687, Epoch accuracy:31.84%, Validation loss:1.728, Validation accuracy:31.67%
# Epoch 86: iteration 25/26
# Epoch 86 --- loss:1.694, Epoch accuracy:30.41%, Validation loss:1.747, Validation accuracy:31.33%
# Epoch 87: iteration 25/26
# Epoch 87 --- loss:1.683, Epoch accuracy:30.67%, Validation loss:1.730, Validation accuracy:31.11%
# Epoch 88: iteration 25/26
# Epoch 88 --- loss:1.696, Epoch accuracy:30.79%, Validation loss:1.746, Validation accuracy:31.11%
# Epoch 89: iteration 25/26
# Epoch 89 --- loss:1.685, Epoch accuracy:31.90%, Validation loss:1.730, Validation accuracy:32.00%
# Epoch 90: iteration 25/26
# Epoch 90 --- loss:1.676, Epoch accuracy:32.78%, Validation loss:1.745, Validation accuracy:31.22%
# Epoch 91: iteration 25/26
# Epoch 91 --- loss:1.681, Epoch accuracy:31.70%, Validation loss:1.724, Validation accuracy:31.33%
# Epoch 92: iteration 25/26
# Epoch 92 --- loss:1.678, Epoch accuracy:32.02%, Validation loss:1.746, Validation accuracy:31.11%
# Epoch 93: iteration 25/26
# Epoch 93 --- loss:1.675, Epoch accuracy:31.58%, Validation loss:1.724, Validation accuracy:32.00%
# Epoch 94: iteration 25/26
# Epoch 94 --- loss:1.684, Epoch accuracy:30.82%, Validation loss:1.768, Validation accuracy:30.11%
# Epoch 95: iteration 25/26
# Epoch 95 --- loss:1.679, Epoch accuracy:31.81%, Validation loss:1.730, Validation accuracy:31.67%
# Epoch 96: iteration 25/26
# Epoch 96 --- loss:1.677, Epoch accuracy:31.93%, Validation loss:1.747, Validation accuracy:31.11%
# Epoch 97: iteration 25/26
# Epoch 97 --- loss:1.668, Epoch accuracy:32.13%, Validation loss:1.721, Validation accuracy:32.00%
# Epoch 98: iteration 25/26
# Epoch 98 --- loss:1.675, Epoch accuracy:31.58%, Validation loss:1.760, Validation accuracy:30.22%
# Epoch 99: iteration 25/26
# Epoch 99 --- loss:1.660, Epoch accuracy:32.40%, Validation loss:1.749, Validation accuracy:31.44%
# Epoch 100: iteration 25/26
# Epoch 100 --- loss:1.663, Epoch accuracy:33.19%, Validation loss:1.723, Validation accuracy:31.89%
# Epoch 101: iteration 25/26
# Epoch 101 --- loss:1.661, Epoch accuracy:31.96%, Validation loss:1.744, Validation accuracy:31.67%
# Epoch 102: iteration 25/26
# Epoch 102 --- loss:1.657, Epoch accuracy:32.75%, Validation loss:1.763, Validation accuracy:30.78%
# Epoch 103: iteration 25/26
# Epoch 103 --- loss:1.667, Epoch accuracy:31.81%, Validation loss:1.711, Validation accuracy:32.56%
# Epoch 104: iteration 25/26
# Epoch 104 --- loss:1.654, Epoch accuracy:32.89%, Validation loss:1.799, Validation accuracy:29.56%
# Epoch 105: iteration 25/26
# Epoch 105 --- loss:1.662, Epoch accuracy:32.84%, Validation loss:1.722, Validation accuracy:32.00%
# Epoch 106: iteration 25/26
# Epoch 106 --- loss:1.659, Epoch accuracy:32.25%, Validation loss:1.756, Validation accuracy:30.89%
# Epoch 107: iteration 25/26
# Epoch 107 --- loss:1.652, Epoch accuracy:32.60%, Validation loss:1.780, Validation accuracy:29.89%
# Epoch 108: iteration 25/26
# Epoch 108 --- loss:1.651, Epoch accuracy:32.92%, Validation loss:1.783, Validation accuracy:29.78%
# Epoch 109: iteration 25/26
# Epoch 109 --- loss:1.654, Epoch accuracy:33.33%, Validation loss:1.776, Validation accuracy:30.44%
# Epoch 110: iteration 25/26
# Epoch 110 --- loss:1.647, Epoch accuracy:32.69%, Validation loss:1.745, Validation accuracy:31.33%
# Epoch 111: iteration 25/26
# Epoch 111 --- loss:1.646, Epoch accuracy:34.24%, Validation loss:1.732, Validation accuracy:31.44%
# Epoch 112: iteration 25/26
# Epoch 112 --- loss:1.650, Epoch accuracy:33.16%, Validation loss:1.792, Validation accuracy:29.33%
# Epoch 113: iteration 25/26
# Epoch 113 --- loss:1.647, Epoch accuracy:33.63%, Validation loss:1.805, Validation accuracy:29.44%
# Epoch 114: iteration 25/26
# Epoch 114 --- loss:1.646, Epoch accuracy:33.30%, Validation loss:1.757, Validation accuracy:30.67%
# Epoch 115: iteration 25/26
# Epoch 115 --- loss:1.647, Epoch accuracy:33.42%, Validation loss:1.809, Validation accuracy:28.67%
# Epoch 116: iteration 25/26
# Epoch 116 --- loss:1.639, Epoch accuracy:33.10%, Validation loss:1.759, Validation accuracy:30.44%
# Epoch 117: iteration 25/26
# Epoch 117 --- loss:1.632, Epoch accuracy:33.74%, Validation loss:1.850, Validation accuracy:27.00%
# Epoch 118: iteration 25/26
# Epoch 118 --- loss:1.650, Epoch accuracy:33.27%, Validation loss:1.751, Validation accuracy:31.56%
# Epoch 119: iteration 25/26
# Epoch 119 --- loss:1.636, Epoch accuracy:34.50%, Validation loss:1.747, Validation accuracy:31.00%
# Epoch 120: iteration 25/26
# Epoch 120 --- loss:1.640, Epoch accuracy:33.33%, Validation loss:1.810, Validation accuracy:29.33%
# Epoch 121: iteration 25/26
# Epoch 121 --- loss:1.637, Epoch accuracy:33.63%, Validation loss:1.774, Validation accuracy:30.56%
# Epoch 122: iteration 25/26
# Epoch 122 --- loss:1.632, Epoch accuracy:33.89%, Validation loss:1.767, Validation accuracy:29.89%
# Epoch 123: iteration 25/26
# Epoch 123 --- loss:1.637, Epoch accuracy:33.86%, Validation loss:1.749, Validation accuracy:31.44%
# Epoch 124: iteration 25/26
# Epoch 124 --- loss:1.624, Epoch accuracy:33.30%, Validation loss:1.801, Validation accuracy:28.89%
# Epoch 125: iteration 25/26
# Epoch 125 --- loss:1.626, Epoch accuracy:34.42%, Validation loss:1.779, Validation accuracy:29.33%
# Epoch 126: iteration 25/26
# Epoch 126 --- loss:1.624, Epoch accuracy:34.06%, Validation loss:1.806, Validation accuracy:29.44%
# Epoch 127: iteration 25/26
# Epoch 127 --- loss:1.620, Epoch accuracy:34.50%, Validation loss:1.799, Validation accuracy:29.22%
# Epoch 128: iteration 25/26
# Epoch 128 --- loss:1.621, Epoch accuracy:34.21%, Validation loss:1.792, Validation accuracy:30.00%
# Epoch 129: iteration 25/26
# Epoch 129 --- loss:1.615, Epoch accuracy:35.53%, Validation loss:1.829, Validation accuracy:28.78%
# Epoch 130: iteration 25/26
# Epoch 130 --- loss:1.619, Epoch accuracy:34.56%, Validation loss:1.807, Validation accuracy:29.56%
# Epoch 131: iteration 25/26
# Epoch 131 --- loss:1.624, Epoch accuracy:34.44%, Validation loss:1.802, Validation accuracy:29.78%
# Epoch 132: iteration 25/26
# Epoch 132 --- loss:1.621, Epoch accuracy:34.21%, Validation loss:1.817, Validation accuracy:30.22%
# Epoch 133: iteration 25/26
# Epoch 133 --- loss:1.617, Epoch accuracy:34.71%, Validation loss:1.823, Validation accuracy:29.67%
# Epoch 134: iteration 25/26
# Epoch 134 --- loss:1.609, Epoch accuracy:34.53%, Validation loss:1.878, Validation accuracy:28.11%
# Epoch 135: iteration 25/26
# Epoch 135 --- loss:1.610, Epoch accuracy:34.59%, Validation loss:1.797, Validation accuracy:29.78%
# Epoch 136: iteration 25/26
# Epoch 136 --- loss:1.610, Epoch accuracy:34.24%, Validation loss:1.778, Validation accuracy:31.44%
# Epoch 137: iteration 25/26
# Epoch 137 --- loss:1.609, Epoch accuracy:34.53%, Validation loss:1.800, Validation accuracy:30.67%
# Epoch 138: iteration 25/26
# Epoch 138 --- loss:1.604, Epoch accuracy:33.98%, Validation loss:1.808, Validation accuracy:29.00%
# Epoch 139: iteration 25/26
# Epoch 139 --- loss:1.615, Epoch accuracy:35.29%, Validation loss:1.885, Validation accuracy:27.89%
# Epoch 140: iteration 25/26
# Epoch 140 --- loss:1.599, Epoch accuracy:35.06%, Validation loss:1.818, Validation accuracy:30.00%
# Epoch 141: iteration 25/26
# Epoch 141 --- loss:1.597, Epoch accuracy:35.82%, Validation loss:1.855, Validation accuracy:27.89%
# Epoch 142: iteration 25/26
# Epoch 142 --- loss:1.600, Epoch accuracy:36.40%, Validation loss:1.778, Validation accuracy:31.11%
# Epoch 143: iteration 25/26
# Epoch 143 --- loss:1.594, Epoch accuracy:36.67%, Validation loss:1.801, Validation accuracy:31.11%
# Epoch 144: iteration 25/26
# Epoch 144 --- loss:1.606, Epoch accuracy:35.35%, Validation loss:1.858, Validation accuracy:28.78%
# Epoch 145: iteration 25/26
# Epoch 145 --- loss:1.599, Epoch accuracy:36.11%, Validation loss:1.786, Validation accuracy:31.67%
# Epoch 146: iteration 25/26
# Epoch 146 --- loss:1.597, Epoch accuracy:35.73%, Validation loss:1.853, Validation accuracy:28.78%
# Epoch 147: iteration 25/26
# Epoch 147 --- loss:1.599, Epoch accuracy:35.53%, Validation loss:1.829, Validation accuracy:29.22%
# Epoch 148: iteration 25/26
# Epoch 148 --- loss:1.585, Epoch accuracy:36.29%, Validation loss:1.832, Validation accuracy:29.78%
# Epoch 149: iteration 25/26
# Epoch 149 --- loss:1.580, Epoch accuracy:36.26%, Validation loss:1.832, Validation accuracy:28.89%
# Epoch 150: iteration 25/26
# Epoch 150 --- loss:1.593, Epoch accuracy:35.64%, Validation loss:1.829, Validation accuracy:29.56%
# Epoch 151: iteration 25/26
# Epoch 151 --- loss:1.592, Epoch accuracy:36.08%, Validation loss:1.865, Validation accuracy:28.44%
# Epoch 152: iteration 25/26
# Epoch 152 --- loss:1.581, Epoch accuracy:36.08%, Validation loss:1.808, Validation accuracy:30.33%
# Epoch 153: iteration 25/26
# Epoch 153 --- loss:1.588, Epoch accuracy:35.32%, Validation loss:1.817, Validation accuracy:30.00%
# Epoch 154: iteration 25/26
# Epoch 154 --- loss:1.574, Epoch accuracy:36.87%, Validation loss:1.836, Validation accuracy:28.89%
# Epoch 155: iteration 25/26
# Epoch 155 --- loss:1.586, Epoch accuracy:35.64%, Validation loss:1.862, Validation accuracy:28.67%
# Epoch 156: iteration 25/26
# Epoch 156 --- loss:1.573, Epoch accuracy:36.26%, Validation loss:1.801, Validation accuracy:30.78%
# Epoch 157: iteration 25/26
# Epoch 157 --- loss:1.579, Epoch accuracy:36.08%, Validation loss:1.854, Validation accuracy:28.89%
# Epoch 158: iteration 25/26
# Epoch 158 --- loss:1.574, Epoch accuracy:36.49%, Validation loss:1.861, Validation accuracy:29.44%
# Epoch 159: iteration 25/26
# Epoch 159 --- loss:1.568, Epoch accuracy:37.43%, Validation loss:1.809, Validation accuracy:31.00%
# Epoch 160: iteration 25/26
# Epoch 160 --- loss:1.566, Epoch accuracy:36.40%, Validation loss:1.930, Validation accuracy:26.56%
# Epoch 161: iteration 25/26
# Epoch 161 --- loss:1.575, Epoch accuracy:37.28%, Validation loss:1.834, Validation accuracy:29.00%
# Epoch 162: iteration 25/26
# Epoch 162 --- loss:1.574, Epoch accuracy:36.23%, Validation loss:1.879, Validation accuracy:28.00%
# Epoch 163: iteration 25/26
# Epoch 163 --- loss:1.561, Epoch accuracy:36.93%, Validation loss:1.829, Validation accuracy:30.56%
# Epoch 164: iteration 25/26
# Epoch 164 --- loss:1.560, Epoch accuracy:37.40%, Validation loss:1.888, Validation accuracy:27.56%
# Epoch 165: iteration 25/26
# Epoch 165 --- loss:1.568, Epoch accuracy:36.75%, Validation loss:1.869, Validation accuracy:29.11%
# Epoch 166: iteration 25/26
# Epoch 166 --- loss:1.564, Epoch accuracy:36.64%, Validation loss:1.856, Validation accuracy:28.89%
# Epoch 167: iteration 25/26
# Epoch 167 --- loss:1.555, Epoch accuracy:37.84%, Validation loss:1.918, Validation accuracy:27.00%
# Epoch 168: iteration 25/26
# Epoch 168 --- loss:1.554, Epoch accuracy:38.10%, Validation loss:1.906, Validation accuracy:27.78%
# Epoch 169: iteration 25/26
# Epoch 169 --- loss:1.548, Epoch accuracy:37.95%, Validation loss:1.890, Validation accuracy:27.67%
# Epoch 170: iteration 25/26
# Epoch 170 --- loss:1.553, Epoch accuracy:37.11%, Validation loss:1.833, Validation accuracy:30.22%
# Epoch 171: iteration 25/26
# Epoch 171 --- loss:1.556, Epoch accuracy:37.13%, Validation loss:1.822, Validation accuracy:29.78%
# Epoch 172: iteration 25/26
# Epoch 172 --- loss:1.558, Epoch accuracy:37.11%, Validation loss:1.909, Validation accuracy:27.33%
# Epoch 173: iteration 25/26
# Epoch 173 --- loss:1.556, Epoch accuracy:37.25%, Validation loss:1.868, Validation accuracy:30.22%
# Epoch 174: iteration 25/26
# Epoch 174 --- loss:1.544, Epoch accuracy:37.05%, Validation loss:1.932, Validation accuracy:26.44%
# Epoch 175: iteration 25/26
# Epoch 175 --- loss:1.540, Epoch accuracy:37.89%, Validation loss:1.861, Validation accuracy:29.00%
# Epoch 176: iteration 25/26
# Epoch 176 --- loss:1.555, Epoch accuracy:37.49%, Validation loss:1.921, Validation accuracy:27.22%
# Epoch 177: iteration 25/26
# Epoch 177 --- loss:1.544, Epoch accuracy:37.95%, Validation loss:1.882, Validation accuracy:29.00%
# Epoch 178: iteration 25/26
# Epoch 178 --- loss:1.535, Epoch accuracy:37.63%, Validation loss:1.900, Validation accuracy:28.33%
# Epoch 179: iteration 25/26
# Epoch 179 --- loss:1.543, Epoch accuracy:37.66%, Validation loss:1.894, Validation accuracy:28.89%
# Epoch 180: iteration 25/26
# Epoch 180 --- loss:1.540, Epoch accuracy:38.04%, Validation loss:1.863, Validation accuracy:29.22%
# Epoch 181: iteration 25/26
# Epoch 181 --- loss:1.536, Epoch accuracy:37.31%, Validation loss:1.938, Validation accuracy:27.00%
# Epoch 182: iteration 25/26
# Epoch 182 --- loss:1.522, Epoch accuracy:38.51%, Validation loss:1.947, Validation accuracy:26.67%
# Epoch 183: iteration 25/26
# Epoch 183 --- loss:1.527, Epoch accuracy:38.83%, Validation loss:1.832, Validation accuracy:30.56%
# Epoch 184: iteration 25/26
# Epoch 184 --- loss:1.526, Epoch accuracy:38.39%, Validation loss:1.926, Validation accuracy:27.78%
# Epoch 185: iteration 25/26
# Epoch 185 --- loss:1.528, Epoch accuracy:37.87%, Validation loss:1.931, Validation accuracy:27.44%
# Epoch 186: iteration 25/26
# Epoch 186 --- loss:1.527, Epoch accuracy:37.43%, Validation loss:1.901, Validation accuracy:28.78%
# Epoch 187: iteration 25/26
# Epoch 187 --- loss:1.521, Epoch accuracy:38.10%, Validation loss:1.946, Validation accuracy:26.56%
# Epoch 188: iteration 25/26
# Epoch 188 --- loss:1.525, Epoch accuracy:39.04%, Validation loss:1.895, Validation accuracy:29.33%
# Epoch 189: iteration 25/26
# Epoch 189 --- loss:1.524, Epoch accuracy:38.63%, Validation loss:1.921, Validation accuracy:28.00%
# Epoch 190: iteration 25/26
# Epoch 190 --- loss:1.523, Epoch accuracy:39.36%, Validation loss:1.884, Validation accuracy:29.22%
# Epoch 191: iteration 25/26
# Epoch 191 --- loss:1.529, Epoch accuracy:38.10%, Validation loss:1.942, Validation accuracy:27.67%
# Epoch 192: iteration 25/26
# Epoch 192 --- loss:1.514, Epoch accuracy:39.88%, Validation loss:1.905, Validation accuracy:28.00%
# Epoch 193: iteration 25/26
# Epoch 193 --- loss:1.519, Epoch accuracy:37.89%, Validation loss:1.940, Validation accuracy:27.56%
# Epoch 194: iteration 25/26
# Epoch 194 --- loss:1.513, Epoch accuracy:39.21%, Validation loss:1.912, Validation accuracy:28.56%
# Epoch 195: iteration 25/26
# Epoch 195 --- loss:1.511, Epoch accuracy:39.59%, Validation loss:1.943, Validation accuracy:27.11%
# Epoch 196: iteration 25/26
# Epoch 196 --- loss:1.511, Epoch accuracy:39.44%, Validation loss:1.949, Validation accuracy:26.78%
# Epoch 197: iteration 25/26
# Epoch 197 --- loss:1.520, Epoch accuracy:38.36%, Validation loss:1.899, Validation accuracy:29.11%
# Epoch 198: iteration 25/26
# Epoch 198 --- loss:1.504, Epoch accuracy:39.91%, Validation loss:1.976, Validation accuracy:26.11%
# Epoch 199: iteration 25/26
# Epoch 199 --- loss:1.504, Epoch accuracy:40.61%, Validation loss:1.888, Validation accuracy:29.11%
# Epoch 200: iteration 25/26
# Epoch 200 --- loss:1.516, Epoch accuracy:39.36%, Validation loss:2.000, Validation accuracy:25.11%
# Epoch 201: iteration 25/26
# Epoch 201 --- loss:1.512, Epoch accuracy:39.24%, Validation loss:1.868, Validation accuracy:30.67%
# Epoch 202: iteration 25/26
# Epoch 202 --- loss:1.500, Epoch accuracy:40.56%, Validation loss:1.939, Validation accuracy:27.89%
# Epoch 203: iteration 25/26
# Epoch 203 --- loss:1.499, Epoch accuracy:40.79%, Validation loss:1.918, Validation accuracy:27.67%
# Epoch 204: iteration 25/26
# Epoch 204 --- loss:1.499, Epoch accuracy:39.82%, Validation loss:1.893, Validation accuracy:29.89%
# Epoch 205: iteration 25/26
# Epoch 205 --- loss:1.483, Epoch accuracy:41.02%, Validation loss:1.945, Validation accuracy:26.89%
# Epoch 206: iteration 25/26
# Epoch 206 --- loss:1.492, Epoch accuracy:39.91%, Validation loss:1.841, Validation accuracy:31.89%
# Epoch 207: iteration 25/26
# Epoch 207 --- loss:1.489, Epoch accuracy:40.47%, Validation loss:1.979, Validation accuracy:25.56%
# Epoch 208: iteration 25/26
# Epoch 208 --- loss:1.507, Epoch accuracy:39.47%, Validation loss:1.925, Validation accuracy:28.44%
# Epoch 209: iteration 25/26
# Epoch 209 --- loss:1.481, Epoch accuracy:40.58%, Validation loss:1.952, Validation accuracy:26.56%
# Epoch 210: iteration 25/26
# Epoch 210 --- loss:1.486, Epoch accuracy:40.82%, Validation loss:1.977, Validation accuracy:25.67%
# Epoch 211: iteration 25/26
# Epoch 211 --- loss:1.482, Epoch accuracy:40.79%, Validation loss:1.924, Validation accuracy:28.44%
# Epoch 212: iteration 25/26
# Epoch 212 --- loss:1.482, Epoch accuracy:41.52%, Validation loss:1.881, Validation accuracy:30.67%
# Epoch 213: iteration 25/26
# Epoch 213 --- loss:1.491, Epoch accuracy:39.94%, Validation loss:1.935, Validation accuracy:27.33%
# Epoch 214: iteration 25/26
# Epoch 214 --- loss:1.477, Epoch accuracy:40.88%, Validation loss:1.956, Validation accuracy:25.78%
# Epoch 215: iteration 25/26
# Epoch 215 --- loss:1.473, Epoch accuracy:40.53%, Validation loss:1.983, Validation accuracy:26.11%
# Epoch 216: iteration 25/26
# Epoch 216 --- loss:1.469, Epoch accuracy:41.40%, Validation loss:1.943, Validation accuracy:27.56%
# Epoch 217: iteration 25/26
# Epoch 217 --- loss:1.465, Epoch accuracy:41.14%, Validation loss:1.950, Validation accuracy:27.11%
# Epoch 218: iteration 25/26
# Epoch 218 --- loss:1.471, Epoch accuracy:41.11%, Validation loss:1.958, Validation accuracy:27.67%
# Epoch 219: iteration 25/26
# Epoch 219 --- loss:1.476, Epoch accuracy:40.26%, Validation loss:1.941, Validation accuracy:27.33%
# Epoch 220: iteration 25/26
# Epoch 220 --- loss:1.469, Epoch accuracy:40.96%, Validation loss:1.938, Validation accuracy:28.11%
# Epoch 221: iteration 25/26
# Epoch 221 --- loss:1.468, Epoch accuracy:41.20%, Validation loss:1.992, Validation accuracy:26.11%
# Epoch 222: iteration 25/26
# Epoch 222 --- loss:1.452, Epoch accuracy:41.20%, Validation loss:1.935, Validation accuracy:27.78%
# Epoch 223: iteration 25/26
# Epoch 223 --- loss:1.472, Epoch accuracy:41.52%, Validation loss:1.972, Validation accuracy:26.33%
# Epoch 224: iteration 25/26
# Epoch 224 --- loss:1.463, Epoch accuracy:41.26%, Validation loss:1.925, Validation accuracy:28.11%
# Epoch 225: iteration 25/26
# Epoch 225 --- loss:1.448, Epoch accuracy:41.93%, Validation loss:1.953, Validation accuracy:26.89%
# Epoch 226: iteration 25/26
# Epoch 226 --- loss:1.458, Epoch accuracy:40.61%, Validation loss:1.949, Validation accuracy:27.56%
# Epoch 227: iteration 25/26
# Epoch 227 --- loss:1.451, Epoch accuracy:41.81%, Validation loss:1.933, Validation accuracy:27.89%
# Epoch 228: iteration 25/26
# Epoch 228 --- loss:1.452, Epoch accuracy:42.05%, Validation loss:1.872, Validation accuracy:30.78%
# Epoch 229: iteration 25/26
# Epoch 229 --- loss:1.458, Epoch accuracy:41.35%, Validation loss:1.927, Validation accuracy:28.89%
# Epoch 230: iteration 25/26
# Epoch 230 --- loss:1.457, Epoch accuracy:42.31%, Validation loss:1.841, Validation accuracy:32.44%
# Epoch 231: iteration 25/26
# Epoch 231 --- loss:1.453, Epoch accuracy:41.81%, Validation loss:2.035, Validation accuracy:25.00%
# Epoch 232: iteration 25/26
# Epoch 232 --- loss:1.459, Epoch accuracy:41.17%, Validation loss:1.879, Validation accuracy:31.00%
# Epoch 233: iteration 25/26
# Epoch 233 --- loss:1.453, Epoch accuracy:40.41%, Validation loss:2.022, Validation accuracy:24.56%
# Epoch 234: iteration 25/26
# Epoch 234 --- loss:1.448, Epoch accuracy:42.19%, Validation loss:1.894, Validation accuracy:29.89%
# Epoch 235: iteration 25/26
# Epoch 235 --- loss:1.445, Epoch accuracy:42.57%, Validation loss:1.987, Validation accuracy:26.00%
# Epoch 236: iteration 25/26
# Epoch 236 --- loss:1.435, Epoch accuracy:43.30%, Validation loss:1.911, Validation accuracy:28.89%
# Epoch 237: iteration 25/26
# Epoch 237 --- loss:1.435, Epoch accuracy:43.48%, Validation loss:1.920, Validation accuracy:28.78%
# Epoch 238: iteration 25/26
# Epoch 238 --- loss:1.444, Epoch accuracy:41.52%, Validation loss:1.958, Validation accuracy:27.11%
# Epoch 239: iteration 25/26
# Epoch 239 --- loss:1.440, Epoch accuracy:42.25%, Validation loss:1.872, Validation accuracy:30.78%
# Epoch 240: iteration 25/26
# Epoch 240 --- loss:1.434, Epoch accuracy:42.13%, Validation loss:1.944, Validation accuracy:27.67%
# Epoch 241: iteration 25/26
# Epoch 241 --- loss:1.432, Epoch accuracy:43.25%, Validation loss:1.951, Validation accuracy:27.78%
# Epoch 242: iteration 25/26
# Epoch 242 --- loss:1.434, Epoch accuracy:42.69%, Validation loss:2.012, Validation accuracy:25.56%
# Epoch 243: iteration 25/26
# Epoch 243 --- loss:1.436, Epoch accuracy:42.63%, Validation loss:1.931, Validation accuracy:28.22%
# Epoch 244: iteration 25/26
# Epoch 244 --- loss:1.434, Epoch accuracy:42.98%, Validation loss:1.997, Validation accuracy:25.00%
# Epoch 245: iteration 25/26
# Epoch 245 --- loss:1.425, Epoch accuracy:42.95%, Validation loss:1.987, Validation accuracy:26.44%
# Epoch 246: iteration 25/26
# Epoch 246 --- loss:1.420, Epoch accuracy:43.48%, Validation loss:1.929, Validation accuracy:28.67%
# Epoch 247: iteration 25/26
# Epoch 247 --- loss:1.422, Epoch accuracy:43.63%, Validation loss:1.929, Validation accuracy:28.67%
# Epoch 248: iteration 25/26
# Epoch 248 --- loss:1.418, Epoch accuracy:44.21%, Validation loss:2.046, Validation accuracy:24.67%
# Epoch 249: iteration 25/26
# Epoch 249 --- loss:1.423, Epoch accuracy:42.81%, Validation loss:1.935, Validation accuracy:28.44%
# Epoch 250: iteration 25/26
# Epoch 250 --- loss:1.421, Epoch accuracy:43.48%, Validation loss:1.910, Validation accuracy:29.00%
# Epoch 251: iteration 25/26
# Epoch 251 --- loss:1.423, Epoch accuracy:43.51%, Validation loss:1.922, Validation accuracy:27.89%
# Epoch 252: iteration 25/26
# Epoch 252 --- loss:1.412, Epoch accuracy:44.50%, Validation loss:2.033, Validation accuracy:24.78%
# Epoch 253: iteration 25/26
# Epoch 253 --- loss:1.409, Epoch accuracy:44.68%, Validation loss:1.955, Validation accuracy:27.56%
# Epoch 254: iteration 25/26
# Epoch 254 --- loss:1.405, Epoch accuracy:43.22%, Validation loss:1.998, Validation accuracy:25.56%
# Epoch 255: iteration 25/26
# Epoch 255 --- loss:1.406, Epoch accuracy:42.89%, Validation loss:1.981, Validation accuracy:25.89%
# Epoch 256: iteration 25/26
# Epoch 256 --- loss:1.401, Epoch accuracy:44.62%, Validation loss:1.927, Validation accuracy:28.44%
# Epoch 257: iteration 25/26
# Epoch 257 --- loss:1.406, Epoch accuracy:44.71%, Validation loss:2.017, Validation accuracy:25.44%
# Epoch 258: iteration 25/26
# Epoch 258 --- loss:1.412, Epoch accuracy:42.51%, Validation loss:1.941, Validation accuracy:27.00%
# Epoch 259: iteration 25/26
# Epoch 259 --- loss:1.410, Epoch accuracy:44.30%, Validation loss:1.900, Validation accuracy:29.56%
# Epoch 260: iteration 25/26
# Epoch 260 --- loss:1.399, Epoch accuracy:44.47%, Validation loss:1.946, Validation accuracy:28.11%
# Epoch 261: iteration 25/26
# Epoch 261 --- loss:1.394, Epoch accuracy:43.48%, Validation loss:1.998, Validation accuracy:25.89%
# Epoch 262: iteration 25/26
# Epoch 262 --- loss:1.402, Epoch accuracy:44.15%, Validation loss:1.972, Validation accuracy:26.22%
# Epoch 263: iteration 25/26
# Epoch 263 --- loss:1.400, Epoch accuracy:43.98%, Validation loss:1.990, Validation accuracy:26.00%
# Epoch 264: iteration 25/26
# Epoch 264 --- loss:1.396, Epoch accuracy:44.65%, Validation loss:1.985, Validation accuracy:26.33%
# Epoch 265: iteration 25/26
# Epoch 265 --- loss:1.403, Epoch accuracy:43.45%, Validation loss:2.012, Validation accuracy:25.44%
# Epoch 266: iteration 25/26
# Epoch 266 --- loss:1.386, Epoch accuracy:45.79%, Validation loss:1.894, Validation accuracy:30.00%
# Epoch 267: iteration 25/26
# Epoch 267 --- loss:1.384, Epoch accuracy:45.29%, Validation loss:1.976, Validation accuracy:26.44%
# Epoch 268: iteration 25/26
# Epoch 268 --- loss:1.378, Epoch accuracy:44.21%, Validation loss:1.915, Validation accuracy:29.56%
# Epoch 269: iteration 25/26
# Epoch 269 --- loss:1.391, Epoch accuracy:44.44%, Validation loss:1.928, Validation accuracy:28.33%
# Epoch 270: iteration 25/26
# Epoch 270 --- loss:1.382, Epoch accuracy:44.85%, Validation loss:2.010, Validation accuracy:25.56%
# Epoch 271: iteration 25/26
# Epoch 271 --- loss:1.384, Epoch accuracy:45.53%, Validation loss:1.975, Validation accuracy:26.44%
# Epoch 272: iteration 25/26
# Epoch 272 --- loss:1.380, Epoch accuracy:44.71%, Validation loss:1.960, Validation accuracy:27.00%
# Epoch 273: iteration 25/26
# Epoch 273 --- loss:1.381, Epoch accuracy:44.91%, Validation loss:1.972, Validation accuracy:27.00%
# Epoch 274: iteration 25/26
# Epoch 274 --- loss:1.376, Epoch accuracy:45.06%, Validation loss:1.998, Validation accuracy:26.22%
# Epoch 275: iteration 25/26
# Epoch 275 --- loss:1.373, Epoch accuracy:45.91%, Validation loss:1.968, Validation accuracy:26.56%
# Epoch 276: iteration 25/26
# Epoch 276 --- loss:1.367, Epoch accuracy:44.59%, Validation loss:2.015, Validation accuracy:25.89%
# Epoch 277: iteration 25/26
# Epoch 277 --- loss:1.380, Epoch accuracy:44.12%, Validation loss:1.975, Validation accuracy:27.22%
# Epoch 278: iteration 25/26
# Epoch 278 --- loss:1.381, Epoch accuracy:44.71%, Validation loss:1.983, Validation accuracy:26.89%
# Epoch 279: iteration 25/26
# Epoch 279 --- loss:1.364, Epoch accuracy:44.85%, Validation loss:1.997, Validation accuracy:26.00%
# Epoch 280: iteration 25/26
# Epoch 280 --- loss:1.373, Epoch accuracy:44.85%, Validation loss:1.967, Validation accuracy:27.33%
# Epoch 281: iteration 25/26
# Epoch 281 --- loss:1.364, Epoch accuracy:45.18%, Validation loss:1.919, Validation accuracy:29.33%
# Epoch 282: iteration 25/26
# Epoch 282 --- loss:1.365, Epoch accuracy:45.20%, Validation loss:1.921, Validation accuracy:28.56%
# Epoch 283: iteration 25/26
# Epoch 283 --- loss:1.374, Epoch accuracy:45.50%, Validation loss:2.024, Validation accuracy:24.78%
# Epoch 284: iteration 25/26
# Epoch 284 --- loss:1.361, Epoch accuracy:45.23%, Validation loss:1.983, Validation accuracy:26.56%
# Epoch 285: iteration 25/26
# Epoch 285 --- loss:1.365, Epoch accuracy:46.17%, Validation loss:1.984, Validation accuracy:25.67%
# Epoch 286: iteration 25/26
# Epoch 286 --- loss:1.359, Epoch accuracy:46.11%, Validation loss:1.966, Validation accuracy:27.56%
# Epoch 287: iteration 25/26
# Epoch 287 --- loss:1.367, Epoch accuracy:45.15%, Validation loss:1.935, Validation accuracy:29.00%
# Epoch 288: iteration 25/26
# Epoch 288 --- loss:1.361, Epoch accuracy:45.38%, Validation loss:2.033, Validation accuracy:24.56%
# Epoch 289: iteration 25/26
# Epoch 289 --- loss:1.345, Epoch accuracy:46.96%, Validation loss:1.974, Validation accuracy:26.67%
# Epoch 290: iteration 25/26
# Epoch 290 --- loss:1.347, Epoch accuracy:46.96%, Validation loss:1.901, Validation accuracy:29.67%
# Epoch 291: iteration 25/26
# Epoch 291 --- loss:1.368, Epoch accuracy:45.35%, Validation loss:1.943, Validation accuracy:28.22%
# Epoch 292: iteration 25/26
# Epoch 292 --- loss:1.361, Epoch accuracy:45.67%, Validation loss:1.909, Validation accuracy:29.56%
# Epoch 293: iteration 25/26
# Epoch 293 --- loss:1.355, Epoch accuracy:46.35%, Validation loss:1.937, Validation accuracy:28.11%
# Epoch 294: iteration 25/26
# Epoch 294 --- loss:1.352, Epoch accuracy:45.85%, Validation loss:1.980, Validation accuracy:26.67%
# Epoch 295: iteration 25/26
# Epoch 295 --- loss:1.350, Epoch accuracy:46.29%, Validation loss:2.017, Validation accuracy:25.22%
# Epoch 296: iteration 25/26
# Epoch 296 --- loss:1.349, Epoch accuracy:46.02%, Validation loss:1.995, Validation accuracy:25.33%
# Epoch 297: iteration 25/26
# Epoch 297 --- loss:1.357, Epoch accuracy:45.20%, Validation loss:1.938, Validation accuracy:29.22%
# Epoch 298: iteration 25/26
# Epoch 298 --- loss:1.347, Epoch accuracy:46.17%, Validation loss:1.964, Validation accuracy:28.00%
# Epoch 299: iteration 25/26
# Epoch 299 --- loss:1.355, Epoch accuracy:46.23%, Validation loss:1.988, Validation accuracy:26.11%
# Epoch 300: iteration 25/26
# Epoch 300 --- loss:1.344, Epoch accuracy:46.11%, Validation loss:2.007, Validation accuracy:25.67%
# Epoch 301: iteration 25/26
# Epoch 301 --- loss:1.342, Epoch accuracy:46.32%, Validation loss:1.946, Validation accuracy:28.33%
# Epoch 302: iteration 25/26
# Epoch 302 --- loss:1.338, Epoch accuracy:46.99%, Validation loss:1.968, Validation accuracy:26.78%
# Epoch 303: iteration 25/26
# Epoch 303 --- loss:1.334, Epoch accuracy:46.23%, Validation loss:1.933, Validation accuracy:28.44%
# Epoch 304: iteration 25/26
# Epoch 304 --- loss:1.327, Epoch accuracy:47.25%, Validation loss:1.998, Validation accuracy:25.44%
# Epoch 305: iteration 25/26
# Epoch 305 --- loss:1.329, Epoch accuracy:47.78%, Validation loss:1.957, Validation accuracy:28.56%
# Epoch 306: iteration 25/26
# Epoch 306 --- loss:1.332, Epoch accuracy:46.78%, Validation loss:1.894, Validation accuracy:28.89%
# Epoch 307: iteration 25/26
# Epoch 307 --- loss:1.335, Epoch accuracy:46.52%, Validation loss:1.950, Validation accuracy:27.67%
# Epoch 308: iteration 25/26
# Epoch 308 --- loss:1.326, Epoch accuracy:46.67%, Validation loss:2.002, Validation accuracy:26.22%
# Epoch 309: iteration 25/26
# Epoch 309 --- loss:1.320, Epoch accuracy:47.31%, Validation loss:1.940, Validation accuracy:28.00%
# Epoch 310: iteration 25/26
# Epoch 310 --- loss:1.314, Epoch accuracy:48.16%, Validation loss:2.021, Validation accuracy:26.11%
# Epoch 311: iteration 25/26
# Epoch 311 --- loss:1.324, Epoch accuracy:47.05%, Validation loss:1.991, Validation accuracy:27.22%
# Epoch 312: iteration 25/26
# Epoch 312 --- loss:1.321, Epoch accuracy:47.78%, Validation loss:1.976, Validation accuracy:27.44%
# Epoch 313: iteration 25/26
# Epoch 313 --- loss:1.326, Epoch accuracy:47.37%, Validation loss:2.007, Validation accuracy:25.67%
# Epoch 314: iteration 25/26
# Epoch 314 --- loss:1.318, Epoch accuracy:48.22%, Validation loss:1.933, Validation accuracy:28.56%
# Epoch 315: iteration 25/26
# Epoch 315 --- loss:1.306, Epoch accuracy:47.95%, Validation loss:1.912, Validation accuracy:29.00%
# Epoch 316: iteration 25/26
# Epoch 316 --- loss:1.319, Epoch accuracy:48.39%, Validation loss:1.973, Validation accuracy:27.11%
# Epoch 317: iteration 25/26
# Epoch 317 --- loss:1.311, Epoch accuracy:47.28%, Validation loss:1.950, Validation accuracy:27.56%
# Epoch 318: iteration 25/26
# Epoch 318 --- loss:1.321, Epoch accuracy:47.19%, Validation loss:1.996, Validation accuracy:26.89%
# Epoch 319: iteration 25/26
# Epoch 319 --- loss:1.315, Epoch accuracy:47.54%, Validation loss:1.920, Validation accuracy:29.33%
# Epoch 320: iteration 25/26
# Epoch 320 --- loss:1.320, Epoch accuracy:47.43%, Validation loss:2.071, Validation accuracy:25.11%
# Epoch 321: iteration 25/26
# Epoch 321 --- loss:1.310, Epoch accuracy:47.31%, Validation loss:1.905, Validation accuracy:29.33%
# Epoch 322: iteration 25/26
# Epoch 322 --- loss:1.300, Epoch accuracy:48.13%, Validation loss:1.893, Validation accuracy:29.67%
# Epoch 323: iteration 25/26
# Epoch 323 --- loss:1.311, Epoch accuracy:47.95%, Validation loss:2.017, Validation accuracy:26.89%
# Epoch 324: iteration 25/26
# Epoch 324 --- loss:1.310, Epoch accuracy:47.95%, Validation loss:1.946, Validation accuracy:27.67%
# Epoch 325: iteration 25/26
# Epoch 325 --- loss:1.311, Epoch accuracy:48.13%, Validation loss:1.943, Validation accuracy:29.33%
# Epoch 326: iteration 25/26
# Epoch 326 --- loss:1.309, Epoch accuracy:47.98%, Validation loss:1.968, Validation accuracy:28.00%
# Epoch 327: iteration 25/26
# Epoch 327 --- loss:1.309, Epoch accuracy:48.27%, Validation loss:1.893, Validation accuracy:29.44%
# Epoch 328: iteration 25/26
# Epoch 328 --- loss:1.310, Epoch accuracy:47.92%, Validation loss:2.102, Validation accuracy:24.89%
# Epoch 329: iteration 25/26
# Epoch 329 --- loss:1.304, Epoch accuracy:47.84%, Validation loss:2.013, Validation accuracy:25.89%
# Epoch 330: iteration 25/26
# Epoch 330 --- loss:1.302, Epoch accuracy:48.36%, Validation loss:1.997, Validation accuracy:26.89%
# Epoch 331: iteration 25/26
# Epoch 331 --- loss:1.299, Epoch accuracy:49.04%, Validation loss:1.942, Validation accuracy:28.78%
# Epoch 332: iteration 25/26
# Epoch 332 --- loss:1.301, Epoch accuracy:47.72%, Validation loss:1.985, Validation accuracy:28.00%
# Epoch 333: iteration 25/26
# Epoch 333 --- loss:1.300, Epoch accuracy:48.04%, Validation loss:1.992, Validation accuracy:27.78%
# Epoch 334: iteration 25/26
# Epoch 334 --- loss:1.289, Epoch accuracy:49.21%, Validation loss:1.909, Validation accuracy:29.44%
# Epoch 335: iteration 25/26
# Epoch 335 --- loss:1.295, Epoch accuracy:48.33%, Validation loss:1.947, Validation accuracy:28.89%
# Epoch 336: iteration 25/26
# Epoch 336 --- loss:1.299, Epoch accuracy:48.10%, Validation loss:1.894, Validation accuracy:29.56%
# Epoch 337: iteration 25/26
# Epoch 337 --- loss:1.290, Epoch accuracy:48.86%, Validation loss:1.976, Validation accuracy:28.00%
# Epoch 338: iteration 25/26
# Epoch 338 --- loss:1.294, Epoch accuracy:47.98%, Validation loss:2.002, Validation accuracy:28.22%
# Epoch 339: iteration 25/26
# Epoch 339 --- loss:1.296, Epoch accuracy:48.25%, Validation loss:1.974, Validation accuracy:28.89%
# Epoch 340: iteration 25/26
# Epoch 340 --- loss:1.280, Epoch accuracy:49.44%, Validation loss:1.878, Validation accuracy:30.00%
# Epoch 341: iteration 25/26
# Epoch 341 --- loss:1.279, Epoch accuracy:48.65%, Validation loss:1.919, Validation accuracy:29.89%
# Epoch 342: iteration 25/26
# Epoch 342 --- loss:1.288, Epoch accuracy:48.68%, Validation loss:1.914, Validation accuracy:29.78%
# Epoch 343: iteration 25/26
# Epoch 343 --- loss:1.291, Epoch accuracy:48.68%, Validation loss:1.966, Validation accuracy:28.00%
# Epoch 344: iteration 25/26
# Epoch 344 --- loss:1.285, Epoch accuracy:48.51%, Validation loss:1.977, Validation accuracy:27.78%
# Epoch 345: iteration 25/26
# Epoch 345 --- loss:1.271, Epoch accuracy:48.83%, Validation loss:1.983, Validation accuracy:27.67%
# Epoch 346: iteration 25/26
# Epoch 346 --- loss:1.271, Epoch accuracy:50.96%, Validation loss:1.925, Validation accuracy:29.11%
# Epoch 347: iteration 25/26
# Epoch 347 --- loss:1.286, Epoch accuracy:48.22%, Validation loss:1.968, Validation accuracy:28.22%
# Epoch 348: iteration 25/26
# Epoch 348 --- loss:1.281, Epoch accuracy:48.86%, Validation loss:1.921, Validation accuracy:29.56%
# Epoch 349: iteration 25/26
# Epoch 349 --- loss:1.276, Epoch accuracy:49.21%, Validation loss:1.887, Validation accuracy:29.89%
# Epoch 350: iteration 25/26
# Epoch 350 --- loss:1.274, Epoch accuracy:49.68%, Validation loss:1.946, Validation accuracy:28.33%
# Epoch 351: iteration 25/26
# Epoch 351 --- loss:1.274, Epoch accuracy:48.77%, Validation loss:2.014, Validation accuracy:26.89%
# Epoch 352: iteration 25/26
# Epoch 352 --- loss:1.272, Epoch accuracy:49.44%, Validation loss:1.884, Validation accuracy:30.11%
# Epoch 353: iteration 25/26
# Epoch 353 --- loss:1.271, Epoch accuracy:49.59%, Validation loss:1.927, Validation accuracy:29.67%
# Epoch 354: iteration 25/26
# Epoch 354 --- loss:1.267, Epoch accuracy:49.91%, Validation loss:1.852, Validation accuracy:31.44%
# Epoch 355: iteration 25/26
# Epoch 355 --- loss:1.264, Epoch accuracy:50.23%, Validation loss:1.902, Validation accuracy:30.22%
# Epoch 356: iteration 25/26
# Epoch 356 --- loss:1.268, Epoch accuracy:50.58%, Validation loss:2.009, Validation accuracy:27.44%
# Epoch 357: iteration 25/26
# Epoch 357 --- loss:1.274, Epoch accuracy:49.21%, Validation loss:1.886, Validation accuracy:30.78%
# Epoch 358: iteration 25/26
# Epoch 358 --- loss:1.270, Epoch accuracy:49.62%, Validation loss:1.946, Validation accuracy:29.56%
# Epoch 359: iteration 25/26
# Epoch 359 --- loss:1.263, Epoch accuracy:50.38%, Validation loss:1.966, Validation accuracy:28.89%
# Epoch 360: iteration 25/26
# Epoch 360 --- loss:1.256, Epoch accuracy:49.91%, Validation loss:1.895, Validation accuracy:30.22%
# Epoch 361: iteration 25/26
# Epoch 361 --- loss:1.260, Epoch accuracy:50.00%, Validation loss:1.912, Validation accuracy:29.67%
# Epoch 362: iteration 25/26
# Epoch 362 --- loss:1.268, Epoch accuracy:48.60%, Validation loss:1.956, Validation accuracy:28.44%
# Epoch 363: iteration 25/26
# Epoch 363 --- loss:1.263, Epoch accuracy:49.39%, Validation loss:1.914, Validation accuracy:29.89%
# Epoch 364: iteration 25/26
# Epoch 364 --- loss:1.260, Epoch accuracy:49.94%, Validation loss:1.938, Validation accuracy:29.11%
# Epoch 365: iteration 25/26
# Epoch 365 --- loss:1.247, Epoch accuracy:49.94%, Validation loss:1.887, Validation accuracy:31.11%
# Epoch 366: iteration 25/26
# Epoch 366 --- loss:1.259, Epoch accuracy:49.04%, Validation loss:1.950, Validation accuracy:29.22%
# Epoch 367: iteration 25/26
# Epoch 367 --- loss:1.250, Epoch accuracy:50.09%, Validation loss:1.942, Validation accuracy:30.22%
# Epoch 368: iteration 25/26
# Epoch 368 --- loss:1.259, Epoch accuracy:49.85%, Validation loss:1.909, Validation accuracy:30.44%
# Epoch 369: iteration 25/26
# Epoch 369 --- loss:1.263, Epoch accuracy:50.32%, Validation loss:1.885, Validation accuracy:30.67%
# Epoch 370: iteration 25/26
# Epoch 370 --- loss:1.249, Epoch accuracy:50.18%, Validation loss:1.929, Validation accuracy:29.67%
# Epoch 371: iteration 25/26
# Epoch 371 --- loss:1.251, Epoch accuracy:50.58%, Validation loss:1.937, Validation accuracy:30.22%
# Epoch 372: iteration 25/26
# Epoch 372 --- loss:1.258, Epoch accuracy:50.29%, Validation loss:1.940, Validation accuracy:29.78%
# Epoch 373: iteration 25/26
# Epoch 373 --- loss:1.265, Epoch accuracy:50.18%, Validation loss:1.823, Validation accuracy:32.89%
# Epoch 374: iteration 25/26
# Epoch 374 --- loss:1.251, Epoch accuracy:50.85%, Validation loss:1.934, Validation accuracy:30.44%
# Epoch 375: iteration 25/26
# Epoch 375 --- loss:1.259, Epoch accuracy:50.35%, Validation loss:1.842, Validation accuracy:32.33%
# Epoch 376: iteration 25/26
# Epoch 376 --- loss:1.248, Epoch accuracy:50.26%, Validation loss:1.959, Validation accuracy:29.78%
# Epoch 377: iteration 25/26
# Epoch 377 --- loss:1.247, Epoch accuracy:50.18%, Validation loss:1.933, Validation accuracy:30.33%
# Epoch 378: iteration 25/26
# Epoch 378 --- loss:1.250, Epoch accuracy:49.77%, Validation loss:1.918, Validation accuracy:30.11%
# Epoch 379: iteration 25/26
# Epoch 379 --- loss:1.238, Epoch accuracy:50.56%, Validation loss:1.847, Validation accuracy:31.78%
# Epoch 380: iteration 25/26
# Epoch 380 --- loss:1.246, Epoch accuracy:50.50%, Validation loss:1.978, Validation accuracy:28.78%
# Epoch 381: iteration 25/26
# Epoch 381 --- loss:1.244, Epoch accuracy:50.64%, Validation loss:1.848, Validation accuracy:33.00%
# ...
# Epoch 374: iteration 27/28
# Epoch 374 --- loss:0.041, Epoch accuracy:98.97%, Validation loss:0.861, Validation accuracy:79.44%
# Epoch 375: iteration 27/28
# Epoch 375 --- loss:0.049, Epoch accuracy:98.42%, Validation loss:0.912, Validation accuracy:78.19%
# Epoch 376: iteration 27/28
# Epoch 376 --- loss:0.050, Epoch accuracy:98.47%, Validation loss:0.685, Validation accuracy:81.11%
# Epoch 377: iteration 27/28
# Epoch 377 --- loss:0.047, Epoch accuracy:98.47%, Validation loss:0.898, Validation accuracy:78.19%
# Epoch 378: iteration 27/28
# Epoch 378 --- loss:0.048, Epoch accuracy:98.47%, Validation loss:0.721, Validation accuracy:80.00%
# Epoch 379: iteration 27/28
# Epoch 379 --- loss:0.046, Epoch accuracy:98.72%, Validation loss:0.839, Validation accuracy:78.75%
# Epoch 380: iteration 27/28
# Epoch 380 --- loss:0.048, Epoch accuracy:98.69%, Validation loss:0.755, Validation accuracy:80.14%
# Epoch 381: iteration 27/28
# Epoch 381 --- loss:0.051, Epoch accuracy:98.22%, Validation loss:0.682, Validation accuracy:80.83%
# Epoch 382: iteration 27/28
# Epoch 382 --- loss:0.049, Epoch accuracy:98.47%, Validation loss:0.903, Validation accuracy:78.47%
# Epoch 383: iteration 27/28
# Epoch 383 --- loss:0.049, Epoch accuracy:98.53%, Validation loss:1.021, Validation accuracy:76.25%
# Epoch 384: iteration 27/28
# Epoch 384 --- loss:0.050, Epoch accuracy:98.28%, Validation loss:0.776, Validation accuracy:79.31%
# Epoch 385: iteration 27/28
# Epoch 385 --- loss:0.049, Epoch accuracy:98.39%, Validation loss:0.678, Validation accuracy:80.69%
# Epoch 386: iteration 27/28
# Epoch 386 --- loss:0.045, Epoch accuracy:98.50%, Validation loss:0.798, Validation accuracy:80.14%
# Epoch 387: iteration 27/28
# Epoch 387 --- loss:0.047, Epoch accuracy:98.39%, Validation loss:0.821, Validation accuracy:78.61%
# Epoch 388: iteration 27/28
# Epoch 388 --- loss:0.044, Epoch accuracy:98.50%, Validation loss:0.759, Validation accuracy:80.00%
# Epoch 389: iteration 27/28
# Epoch 389 --- loss:0.045, Epoch accuracy:98.61%, Validation loss:0.705, Validation accuracy:80.14%
# Epoch 390: iteration 27/28
# Epoch 390 --- loss:0.044, Epoch accuracy:98.69%, Validation loss:0.965, Validation accuracy:77.78%
# Epoch 391: iteration 27/28
# Epoch 391 --- loss:0.043, Epoch accuracy:98.81%, Validation loss:0.711, Validation accuracy:80.83%
# Epoch 392: iteration 27/28
# Epoch 392 --- loss:0.046, Epoch accuracy:98.72%, Validation loss:0.970, Validation accuracy:77.78%
# Epoch 393: iteration 27/28
# Epoch 393 --- loss:0.049, Epoch accuracy:98.28%, Validation loss:0.797, Validation accuracy:80.00%
# Epoch 394: iteration 27/28
# Epoch 394 --- loss:0.046, Epoch accuracy:98.53%, Validation loss:0.749, Validation accuracy:79.17%
# Epoch 395: iteration 27/28
# Epoch 395 --- loss:0.042, Epoch accuracy:98.69%, Validation loss:0.771, Validation accuracy:79.44%
# Epoch 396: iteration 27/28
# Epoch 396 --- loss:0.044, Epoch accuracy:98.58%, Validation loss:0.849, Validation accuracy:79.17%
# Epoch 397: iteration 27/28
# Epoch 397 --- loss:0.047, Epoch accuracy:98.22%, Validation loss:0.878, Validation accuracy:79.03%
# Epoch 398: iteration 27/28
# Epoch 398 --- loss:0.046, Epoch accuracy:98.56%, Validation loss:0.719, Validation accuracy:80.97%
# Epoch 399: iteration 27/28
# Epoch 399 --- loss:0.049, Epoch accuracy:98.47%, Validation loss:0.832, Validation accuracy:79.86%
# Epoch 400: iteration 27/28
# Epoch 400 --- loss:0.044, Epoch accuracy:98.67%, Validation loss:0.784, Validation accuracy:80.00%
# Epoch 401: iteration 27/28
# Epoch 401 --- loss:0.046, Epoch accuracy:98.47%, Validation loss:0.823, Validation accuracy:79.17%
# Epoch 402: iteration 27/28
# Epoch 402 --- loss:0.046, Epoch accuracy:98.44%, Validation loss:0.758, Validation accuracy:79.17%
# Epoch 403: iteration 27/28
# Epoch 403 --- loss:0.042, Epoch accuracy:98.81%, Validation loss:0.821, Validation accuracy:79.17%
# Epoch 404: iteration 27/28
# Epoch 404 --- loss:0.040, Epoch accuracy:98.83%, Validation loss:0.762, Validation accuracy:80.28%
# Epoch 405: iteration 27/28
# Epoch 405 --- loss:0.042, Epoch accuracy:98.92%, Validation loss:0.833, Validation accuracy:79.44%
# Epoch 406: iteration 27/28
# Epoch 406 --- loss:0.043, Epoch accuracy:98.81%, Validation loss:0.797, Validation accuracy:79.03%
# Epoch 407: iteration 27/28
# Epoch 407 --- loss:0.043, Epoch accuracy:98.81%, Validation loss:0.767, Validation accuracy:80.42%
# Epoch 408: iteration 27/28
# Epoch 408 --- loss:0.042, Epoch accuracy:98.64%, Validation loss:0.713, Validation accuracy:80.00%
# Epoch 409: iteration 27/28
# Epoch 409 --- loss:0.043, Epoch accuracy:98.47%, Validation loss:0.933, Validation accuracy:77.92%
# Epoch 410: iteration 27/28
# Epoch 410 --- loss:0.046, Epoch accuracy:98.47%, Validation loss:0.805, Validation accuracy:79.03%
# Epoch 411: iteration 27/28
# Epoch 411 --- loss:0.043, Epoch accuracy:98.72%, Validation loss:0.790, Validation accuracy:79.86%
# Epoch 412: iteration 27/28
# Epoch 412 --- loss:0.042, Epoch accuracy:98.69%, Validation loss:0.850, Validation accuracy:78.33%
# Epoch 413: iteration 27/28
# Epoch 413 --- loss:0.044, Epoch accuracy:98.72%, Validation loss:0.803, Validation accuracy:79.44%
# Epoch 414: iteration 27/28
# Epoch 414 --- loss:0.044, Epoch accuracy:98.61%, Validation loss:0.827, Validation accuracy:78.89%
# Epoch 415: iteration 27/28
# Epoch 415 --- loss:0.044, Epoch accuracy:98.69%, Validation loss:0.761, Validation accuracy:79.58%
# Epoch 416: iteration 27/28
# Epoch 416 --- loss:0.044, Epoch accuracy:98.56%, Validation loss:0.846, Validation accuracy:79.03%
# Epoch 417: iteration 27/28
# Epoch 417 --- loss:0.041, Epoch accuracy:98.61%, Validation loss:0.824, Validation accuracy:78.75%
# Epoch 418: iteration 27/28
# Epoch 418 --- loss:0.044, Epoch accuracy:98.58%, Validation loss:0.785, Validation accuracy:80.56%
# Epoch 419: iteration 27/28
# Epoch 419 --- loss:0.041, Epoch accuracy:98.78%, Validation loss:0.764, Validation accuracy:79.31%
# Epoch 420: iteration 27/28
# Epoch 420 --- loss:0.042, Epoch accuracy:98.69%, Validation loss:0.855, Validation accuracy:79.03%
# Epoch 421: iteration 27/28
# Epoch 421 --- loss:0.044, Epoch accuracy:98.72%, Validation loss:0.836, Validation accuracy:79.31%
# Epoch 422: iteration 27/28
# Epoch 422 --- loss:0.045, Epoch accuracy:98.56%, Validation loss:0.870, Validation accuracy:78.75%
# Epoch 423: iteration 27/28
# Epoch 423 --- loss:0.044, Epoch accuracy:98.53%, Validation loss:0.771, Validation accuracy:80.28%
# Epoch 424: iteration 27/28
# Epoch 424 --- loss:0.044, Epoch accuracy:98.44%, Validation loss:0.876, Validation accuracy:79.31%
# Epoch 425: iteration 27/28
# Epoch 425 --- loss:0.039, Epoch accuracy:98.89%, Validation loss:0.852, Validation accuracy:78.33%
# Epoch 426: iteration 27/28
# Epoch 426 --- loss:0.046, Epoch accuracy:98.47%, Validation loss:0.742, Validation accuracy:80.00%
# Epoch 427: iteration 27/28
# Epoch 427 --- loss:0.046, Epoch accuracy:98.58%, Validation loss:0.864, Validation accuracy:78.89%
# Epoch 428: iteration 27/28
# Epoch 428 --- loss:0.042, Epoch accuracy:98.64%, Validation loss:0.695, Validation accuracy:80.97%
# Epoch 429: iteration 27/28
# Epoch 429 --- loss:0.043, Epoch accuracy:98.64%, Validation loss:0.859, Validation accuracy:80.00%
# Epoch 430: iteration 27/28
# Epoch 430 --- loss:0.042, Epoch accuracy:98.61%, Validation loss:0.715, Validation accuracy:80.83%
# Epoch 431: iteration 27/28
# Epoch 431 --- loss:0.041, Epoch accuracy:98.61%, Validation loss:0.797, Validation accuracy:79.72%
# Epoch 432: iteration 27/28
# Epoch 432 --- loss:0.039, Epoch accuracy:99.00%, Validation loss:0.826, Validation accuracy:78.47%
# Epoch 433: iteration 27/28
# Epoch 433 --- loss:0.042, Epoch accuracy:98.64%, Validation loss:0.770, Validation accuracy:79.72%
# Epoch 434: iteration 27/28
# Epoch 434 --- loss:0.037, Epoch accuracy:98.86%, Validation loss:0.972, Validation accuracy:78.19%
# Epoch 435: iteration 27/28
# Epoch 435 --- loss:0.043, Epoch accuracy:98.58%, Validation loss:0.992, Validation accuracy:78.47%
# Epoch 436: iteration 27/28
# Epoch 436 --- loss:0.045, Epoch accuracy:98.44%, Validation loss:0.673, Validation accuracy:80.97%
# Epoch 437: iteration 27/28
# Epoch 437 --- loss:0.041, Epoch accuracy:98.69%, Validation loss:0.806, Validation accuracy:79.44%
# Epoch 438: iteration 27/28
# Epoch 438 --- loss:0.041, Epoch accuracy:98.64%, Validation loss:0.913, Validation accuracy:78.61%
# Epoch 439: iteration 27/28
# Epoch 439 --- loss:0.042, Epoch accuracy:98.83%, Validation loss:0.771, Validation accuracy:79.58%
# Epoch 440: iteration 27/28
# Epoch 440 --- loss:0.038, Epoch accuracy:98.89%, Validation loss:0.845, Validation accuracy:79.44%
# Epoch 441: iteration 27/28
# Epoch 441 --- loss:0.043, Epoch accuracy:98.58%, Validation loss:0.737, Validation accuracy:80.28%
# Epoch 442: iteration 27/28
# Epoch 442 --- loss:0.041, Epoch accuracy:98.56%, Validation loss:0.819, Validation accuracy:79.58%
# Epoch 443: iteration 27/28
# Epoch 443 --- loss:0.040, Epoch accuracy:98.81%, Validation loss:0.832, Validation accuracy:79.58%
# Epoch 444: iteration 27/28
# Epoch 444 --- loss:0.040, Epoch accuracy:98.75%, Validation loss:0.717, Validation accuracy:81.39%
# Epoch 445: iteration 27/28
# Epoch 445 --- loss:0.046, Epoch accuracy:98.58%, Validation loss:0.860, Validation accuracy:79.72%
# Epoch 446: iteration 27/28
# Epoch 446 --- loss:0.040, Epoch accuracy:98.81%, Validation loss:0.736, Validation accuracy:80.42%
# Epoch 447: iteration 27/28
# Epoch 447 --- loss:0.041, Epoch accuracy:98.53%, Validation loss:0.841, Validation accuracy:79.72%
# Epoch 448: iteration 27/28
# Epoch 448 --- loss:0.039, Epoch accuracy:98.78%, Validation loss:0.896, Validation accuracy:78.47%
# Epoch 449: iteration 27/28
# Epoch 449 --- loss:0.042, Epoch accuracy:98.67%, Validation loss:0.980, Validation accuracy:77.78%
# Epoch 450: iteration 27/28
# Epoch 450 --- loss:0.040, Epoch accuracy:98.72%, Validation loss:0.825, Validation accuracy:78.89%
# Epoch 451: iteration 27/28
# Epoch 451 --- loss:0.036, Epoch accuracy:99.00%, Validation loss:0.867, Validation accuracy:79.86%
# Epoch 452: iteration 27/28
# Epoch 452 --- loss:0.035, Epoch accuracy:98.94%, Validation loss:0.784, Validation accuracy:78.89%
# Epoch 453: iteration 27/28
# Epoch 453 --- loss:0.036, Epoch accuracy:98.83%, Validation loss:0.824, Validation accuracy:78.75%
# Epoch 454: iteration 27/28
# Epoch 454 --- loss:0.037, Epoch accuracy:98.83%, Validation loss:0.893, Validation accuracy:78.47%
# Epoch 455: iteration 27/28
# Epoch 455 --- loss:0.033, Epoch accuracy:99.00%, Validation loss:0.924, Validation accuracy:78.61%
# Epoch 456: iteration 27/28
# Epoch 456 --- loss:0.036, Epoch accuracy:98.86%, Validation loss:0.896, Validation accuracy:79.03%
# Epoch 457: iteration 27/28
# Epoch 457 --- loss:0.043, Epoch accuracy:98.44%, Validation loss:0.814, Validation accuracy:79.31%
# Epoch 458: iteration 27/28
# Epoch 458 --- loss:0.039, Epoch accuracy:98.75%, Validation loss:0.894, Validation accuracy:78.47%
# Epoch 459: iteration 27/28
# Epoch 459 --- loss:0.041, Epoch accuracy:98.50%, Validation loss:0.853, Validation accuracy:79.03%
# Epoch 460: iteration 27/28
# Epoch 460 --- loss:0.038, Epoch accuracy:98.61%, Validation loss:0.893, Validation accuracy:78.61%
# Epoch 461: iteration 27/28
# Epoch 461 --- loss:0.041, Epoch accuracy:98.75%, Validation loss:0.773, Validation accuracy:80.00%
# Epoch 462: iteration 27/28
# Epoch 462 --- loss:0.040, Epoch accuracy:98.61%, Validation loss:0.759, Validation accuracy:79.72%
# Epoch 463: iteration 27/28
# Epoch 463 --- loss:0.041, Epoch accuracy:98.67%, Validation loss:0.910, Validation accuracy:78.61%
# Epoch 464: iteration 27/28
# Epoch 464 --- loss:0.040, Epoch accuracy:98.58%, Validation loss:0.966, Validation accuracy:78.33%
# Epoch 465: iteration 27/28
# Epoch 465 --- loss:0.041, Epoch accuracy:98.61%, Validation loss:0.907, Validation accuracy:78.19%
# Epoch 466: iteration 27/28
# Epoch 466 --- loss:0.039, Epoch accuracy:98.75%, Validation loss:0.870, Validation accuracy:78.06%
# Epoch 467: iteration 27/28
# Epoch 467 --- loss:0.040, Epoch accuracy:98.61%, Validation loss:0.933, Validation accuracy:77.36%
# Epoch 468: iteration 27/28
# Epoch 468 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:0.850, Validation accuracy:79.44%
# Epoch 469: iteration 27/28
# Epoch 469 --- loss:0.039, Epoch accuracy:98.83%, Validation loss:0.812, Validation accuracy:79.31%
# Epoch 470: iteration 27/28
# Epoch 470 --- loss:0.041, Epoch accuracy:98.86%, Validation loss:0.864, Validation accuracy:79.72%
# Epoch 471: iteration 27/28
# Epoch 471 --- loss:0.037, Epoch accuracy:98.92%, Validation loss:0.972, Validation accuracy:77.08%
# Epoch 472: iteration 27/28
# Epoch 472 --- loss:0.035, Epoch accuracy:99.11%, Validation loss:0.767, Validation accuracy:80.00%
# Epoch 473: iteration 27/28
# Epoch 473 --- loss:0.037, Epoch accuracy:98.78%, Validation loss:0.995, Validation accuracy:77.36%
# Epoch 474: iteration 27/28
# Epoch 474 --- loss:0.035, Epoch accuracy:98.89%, Validation loss:0.780, Validation accuracy:79.86%
# Epoch 475: iteration 27/28
# Epoch 475 --- loss:0.038, Epoch accuracy:98.64%, Validation loss:0.816, Validation accuracy:80.00%
# Epoch 476: iteration 27/28
# Epoch 476 --- loss:0.040, Epoch accuracy:98.58%, Validation loss:0.804, Validation accuracy:79.31%
# Epoch 477: iteration 27/28
# Epoch 477 --- loss:0.038, Epoch accuracy:98.83%, Validation loss:0.758, Validation accuracy:80.56%
# Epoch 478: iteration 27/28
# Epoch 478 --- loss:0.035, Epoch accuracy:99.03%, Validation loss:0.801, Validation accuracy:79.03%
# Epoch 479: iteration 27/28
# Epoch 479 --- loss:0.034, Epoch accuracy:99.03%, Validation loss:0.862, Validation accuracy:78.19%
# Epoch 480: iteration 27/28
# Epoch 480 --- loss:0.039, Epoch accuracy:98.94%, Validation loss:0.737, Validation accuracy:80.00%
# Epoch 481: iteration 27/28
# Epoch 481 --- loss:0.036, Epoch accuracy:98.81%, Validation loss:0.813, Validation accuracy:79.03%
# Epoch 482: iteration 27/28
# Epoch 482 --- loss:0.036, Epoch accuracy:98.72%, Validation loss:0.859, Validation accuracy:79.03%
# Epoch 483: iteration 27/28
# Epoch 483 --- loss:0.034, Epoch accuracy:98.97%, Validation loss:0.914, Validation accuracy:78.89%
# Epoch 484: iteration 27/28
# Epoch 484 --- loss:0.038, Epoch accuracy:98.72%, Validation loss:0.883, Validation accuracy:78.75%
# Epoch 485: iteration 27/28
# Epoch 485 --- loss:0.038, Epoch accuracy:98.83%, Validation loss:0.859, Validation accuracy:79.03%
# Epoch 486: iteration 27/28
# Epoch 486 --- loss:0.041, Epoch accuracy:98.47%, Validation loss:0.903, Validation accuracy:79.03%
# Epoch 487: iteration 27/28
# Epoch 487 --- loss:0.033, Epoch accuracy:99.00%, Validation loss:0.840, Validation accuracy:80.28%
# Epoch 488: iteration 27/28
# Epoch 488 --- loss:0.035, Epoch accuracy:98.83%, Validation loss:0.898, Validation accuracy:79.31%
# Epoch 489: iteration 27/28
# Epoch 489 --- loss:0.034, Epoch accuracy:98.97%, Validation loss:0.816, Validation accuracy:79.31%
# Epoch 490: iteration 27/28
# Epoch 490 --- loss:0.035, Epoch accuracy:98.83%, Validation loss:0.766, Validation accuracy:80.14%
# Epoch 491: iteration 27/28
# Epoch 491 --- loss:0.035, Epoch accuracy:98.81%, Validation loss:0.910, Validation accuracy:78.75%
# Epoch 492: iteration 27/28
# Epoch 492 --- loss:0.034, Epoch accuracy:98.86%, Validation loss:0.877, Validation accuracy:78.89%
# Epoch 493: iteration 27/28
# Epoch 493 --- loss:0.039, Epoch accuracy:98.81%, Validation loss:0.721, Validation accuracy:80.69%
# Epoch 494: iteration 27/28
# Epoch 494 --- loss:0.037, Epoch accuracy:98.78%, Validation loss:0.757, Validation accuracy:80.69%
# Epoch 495: iteration 27/28
# Epoch 495 --- loss:0.036, Epoch accuracy:98.83%, Validation loss:0.958, Validation accuracy:79.03%
# Epoch 496: iteration 27/28
# Epoch 496 --- loss:0.034, Epoch accuracy:98.69%, Validation loss:0.767, Validation accuracy:79.58%
# Epoch 497: iteration 27/28
# Epoch 497 --- loss:0.034, Epoch accuracy:98.92%, Validation loss:0.898, Validation accuracy:79.44%
# Epoch 498: iteration 27/28
# Epoch 498 --- loss:0.041, Epoch accuracy:98.50%, Validation loss:0.670, Validation accuracy:82.36%
# Epoch 499: iteration 27/28
# Epoch 499 --- loss:0.038, Epoch accuracy:98.81%, Validation loss:0.872, Validation accuracy:79.44%
#
#
# [*] done !
# [*] Best training loss - 0.03271502051088545
# [*] Best validation loss - 0.36429160833358765

# %%
import csv
import cv2
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(cur_fold_path):
    X_train, y_train, X_test, y_test = [], [], [], []
    
    train_f = open(os.path.join(cur_fold_path, 'train.csv'), 'r')
    test_f = open(os.path.join(cur_fold_path, 'test.csv'), 'r')
    
    train_reader = csv.reader(train_f)
    for r in train_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_train.append(image)
        y_train.append(int(r[1]))
        
    test_reader = csv.reader(test_f)
    for r in test_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_test.append(image)
        y_test.append(int(r[1]))
    
    return np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

# %%
all_fold_dataset = []

for fold in tqdm(range(5), desc='load melspectrogram fold dataset'):
    cur_fold_path = os.path.join('melspectrogram_fold', str(fold))
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    all_fold_dataset.append([X_train, y_train, X_test, y_test])
# Out:
# load melspectrogram fold dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'melspectrogram_fold'

for fold in range(5):
    cur = all_fold_dataset[fold]
    
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - TCN
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [12], line 17
#      13 cur = all_fold_dataset[fold]
#      16 pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
# ---> 17 train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
#      19 plt.title('Loss Curve')
#      20 plt.ylabel('Loss', fontsize=16)
#
# Cell In [8], line 65, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold)
#      62 Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
#      64 # Pass input tensors thru 1 training step (fwd+backwards pass)
# ---> 65 loss, acc = train_step(X_tensor, Y_tensor)
#      67 # aggregate batch accuracy to measure progress of entire epoch
#      68 epoch_acc += acc * actual_batch_size / train_size
#
# Cell In [4], line 7, in make_train_step.<locals>.train_step(X, Y)
#       4 def train_step(X, Y):
#       5
#       6     # forward pass
# ----> 7     output_logits, output_softmax = model(X)
#       8     predictions = torch.argmax(output_softmax, dim=1)
#       9     accuracy = torch.sum(Y == predictions)/float(len(Y))
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# Cell In [2], line 120, in TCN.forward(self, mixture_w)
#     119 def forward(self, mixture_w):
# --> 120     output = self.dropout(self.bottleneck(mixture_w))
#     121     for i in range(len(self.TCN)):
#     122         residual = self.TCN[i](output)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\container.py:119, in Sequential.forward(self, input)
#     117 def forward(self, input):
#     118     for module in self:
# --> 119         input = module(input)
#     120     return input
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# Cell In [2], line 35, in GlobLN.forward(self, x)
#      33 mean = x.mean(dim=dims, keepdim=True)
#      34 var = torch.pow(x - mean, 2).mean(dim=dims, keepdim=True)
# ---> 35 return self.apply_gain_and_bias((x - mean) / (var + EPS).sqrt())
#
# Cell In [2], line 14, in _LayerNorm.apply_gain_and_bias(self, normed_x)
#      12 def apply_gain_and_bias(self, normed_x):
#      13     """ Assumes input of size `[batch, chanel, *]`. """
# ---> 14     return (self.gamma * normed_x.transpose(1, -1) +
#      15             self.beta).transpose(1, -1)
#
# RuntimeError: The size of tensor a (40) must match the size of tensor b (224) at non-singleton dimension 3

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
