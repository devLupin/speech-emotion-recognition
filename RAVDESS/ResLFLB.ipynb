# %%
from cv2 import transform
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
from einops import rearrange

# %% [markdown]
# ## LFLB (N Filter)
#
# Speech emotion recognition using deep 1d & 2d cnn lstm networks. Biomedical Signal Processing and Control 47, 312–323 (2019)

# %%
class LFLB(nn.Module):
    """Some Information about LFLB"""
    def __init__(self, in_chan, out_chan, kernel=[2, 2], stride=[1, 1], pad=1):
        super(LFLB, self).__init__()

        self.cnn = nn.Conv2d(in_channels=in_chan, out_channels=out_chan, kernel_size=kernel, stride=stride, padding=pad)
        self.bn = nn.BatchNorm2d(out_chan)
        self.relu = nn.ReLU()
        self.max_pool =  nn.MaxPool2d(kernel_size=kernel, stride=[2, 2])

    def forward(self, x):
        cnn_embd = self.cnn(x)
        cnn_embd = self.bn(cnn_embd)
        cnn_embd = self.relu(cnn_embd)
        output = self.max_pool(cnn_embd)

        return output

# %% [markdown]
# ## NAC Unit
#
# [1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun, Identity Mappings in Deep Residual Networks. arXiv:1603.05027
# https://github.com/kuangliu/pytorch-cifar/blob/master/models/preact_resnet.py

# %%
class NACUnit(nn.Module):
    '''Pre-activation version of the BasicBlock.'''
    expansion = 1

    def __init__(self, in_planes, planes, kernel, stride=1, pad=0):
        super(NACUnit, self).__init__()
        
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=kernel, stride=stride, padding=pad, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=kernel, stride=1, padding=1, bias=False)

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        return out

# %%
class ResLFLB(nn.Module):
    def __init__(self, in_chan, n_filters, kernel):
        super(ResLFLB, self).__init__()
        
        self.lflb = LFLB(in_chan=in_chan, out_chan=n_filters)
        
        self.nac_unit1 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1, pad=1)
        self.nac_unit2 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit3 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit4 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit5 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1)

    def forward(self, x):
        lflb_embd = self.lflb(x)
        
        nac_embd = self.nac_unit1(lflb_embd)
        nac_embd = self.nac_unit2(nac_embd)
        nac_embd = self.nac_unit3(nac_embd)
        nac_embd = self.nac_unit4(nac_embd)
        nac_embd = self.nac_unit5(nac_embd)
        
        output = lflb_embd + nac_embd

        return output

# %%
class Model(nn.Module):
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.MFL = LFLB(3, 32)
        
        self.res_lflb1 = ResLFLB(32, 32, [3, 3])
        self.res_lflb2 = ResLFLB(32, 32, [3, 3])
        self.res_lflb3 = ResLFLB(32, 32, [3, 3])
        self.res_lflb4 = ResLFLB(32, 64, [3, 3])
        self.res_lflb5 = ResLFLB(64, 128, [3, 3])
        
        self.relu = nn.ReLU()
        self.max_pool = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2])
        self.dropout = nn.Dropout(0.25)
        self.linear = nn.Linear(512, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        MFL_embd = self.MFL(x)
        
        res_lflb_embd = self.res_lflb1(MFL_embd)
        res_lflb_embd = self.res_lflb2(res_lflb_embd)
        res_lflb_embd = self.res_lflb3(res_lflb_embd)
        res_lflb_embd = self.res_lflb4(res_lflb_embd)
        res_lflb_embd = self.res_lflb5(res_lflb_embd)
        
        mlp = self.relu(res_lflb_embd)
        mlp = self.max_pool(mlp)
        mlp = self.dropout(mlp)
        mlp = torch.flatten(mlp, start_dim=1)
        output_logits = self.linear(mlp)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'surprised',
    '1': 'neutral',
    '2': 'calm',
    '3': 'happy',
    '4': 'sad',
    '5': 'angry',
    '6': 'fearful',
    '7': 'disgust'
}


sub_name = 'ADCRNN'
data_name = 'RAVDESS'
EARLY_CNT = 500

minibatch = 32
num_epochs = 500

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = '5-CV'

for fold in range(5):
    cur_fold_path = os.path.join('5-CV', 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - ADCRNN
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:2.349, Epoch accuracy:14.12%, Validation loss:2.105, Validation accuracy:13.00%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:2.360, Epoch accuracy:11.67%, Validation loss:2.223, Validation accuracy:14.00%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:2.324, Epoch accuracy:12.89%, Validation loss:2.207, Validation accuracy:13.33%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:2.294, Epoch accuracy:13.33%, Validation loss:2.194, Validation accuracy:13.67%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:2.310, Epoch accuracy:11.14%, Validation loss:2.191, Validation accuracy:14.00%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:2.345, Epoch accuracy:13.16%, Validation loss:2.185, Validation accuracy:13.33%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:2.282, Epoch accuracy:14.56%, Validation loss:2.182, Validation accuracy:14.00%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:2.266, Epoch accuracy:14.30%, Validation loss:2.179, Validation accuracy:15.67%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:2.251, Epoch accuracy:14.12%, Validation loss:2.157, Validation accuracy:15.67%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:2.297, Epoch accuracy:13.25%, Validation loss:2.154, Validation accuracy:14.33%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:2.259, Epoch accuracy:13.42%, Validation loss:2.142, Validation accuracy:13.33%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:2.254, Epoch accuracy:14.82%, Validation loss:2.135, Validation accuracy:16.33%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:2.275, Epoch accuracy:14.21%, Validation loss:2.143, Validation accuracy:15.00%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:2.254, Epoch accuracy:12.54%, Validation loss:2.136, Validation accuracy:15.00%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:2.263, Epoch accuracy:13.77%, Validation loss:2.140, Validation accuracy:13.00%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:2.199, Epoch accuracy:15.88%, Validation loss:2.134, Validation accuracy:16.67%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:2.267, Epoch accuracy:14.47%, Validation loss:2.134, Validation accuracy:13.33%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:2.251, Epoch accuracy:13.25%, Validation loss:2.136, Validation accuracy:15.00%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:2.256, Epoch accuracy:13.77%, Validation loss:2.126, Validation accuracy:14.67%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:2.218, Epoch accuracy:12.89%, Validation loss:2.110, Validation accuracy:14.00%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:2.229, Epoch accuracy:14.82%, Validation loss:2.108, Validation accuracy:14.67%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:2.203, Epoch accuracy:15.35%, Validation loss:2.121, Validation accuracy:16.00%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:2.238, Epoch accuracy:13.68%, Validation loss:2.120, Validation accuracy:15.33%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:2.227, Epoch accuracy:14.21%, Validation loss:2.115, Validation accuracy:15.00%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:2.230, Epoch accuracy:13.86%, Validation loss:2.104, Validation accuracy:15.00%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:2.206, Epoch accuracy:14.91%, Validation loss:2.115, Validation accuracy:14.67%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:2.192, Epoch accuracy:13.33%, Validation loss:2.103, Validation accuracy:15.67%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:2.165, Epoch accuracy:15.09%, Validation loss:2.105, Validation accuracy:13.33%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:2.214, Epoch accuracy:14.47%, Validation loss:2.123, Validation accuracy:13.67%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:2.223, Epoch accuracy:13.86%, Validation loss:2.115, Validation accuracy:15.67%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:2.174, Epoch accuracy:15.96%, Validation loss:2.110, Validation accuracy:14.33%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:2.233, Epoch accuracy:14.12%, Validation loss:2.085, Validation accuracy:14.67%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:2.171, Epoch accuracy:14.65%, Validation loss:2.094, Validation accuracy:15.00%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:2.176, Epoch accuracy:14.39%, Validation loss:2.090, Validation accuracy:14.67%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:2.204, Epoch accuracy:13.16%, Validation loss:2.108, Validation accuracy:14.00%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:2.183, Epoch accuracy:13.51%, Validation loss:2.090, Validation accuracy:15.33%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:2.168, Epoch accuracy:14.74%, Validation loss:2.087, Validation accuracy:16.33%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:2.191, Epoch accuracy:12.89%, Validation loss:2.089, Validation accuracy:15.33%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:2.201, Epoch accuracy:14.30%, Validation loss:2.092, Validation accuracy:14.00%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:2.173, Epoch accuracy:14.91%, Validation loss:2.087, Validation accuracy:15.00%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:2.213, Epoch accuracy:13.51%, Validation loss:2.083, Validation accuracy:15.67%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:2.187, Epoch accuracy:15.53%, Validation loss:2.072, Validation accuracy:15.67%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:2.199, Epoch accuracy:14.56%, Validation loss:2.063, Validation accuracy:18.33%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:2.169, Epoch accuracy:14.82%, Validation loss:2.089, Validation accuracy:13.33%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:2.140, Epoch accuracy:17.81%, Validation loss:2.063, Validation accuracy:15.00%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:2.159, Epoch accuracy:15.18%, Validation loss:2.065, Validation accuracy:17.00%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:2.177, Epoch accuracy:15.09%, Validation loss:2.076, Validation accuracy:17.67%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:2.201, Epoch accuracy:13.86%, Validation loss:2.072, Validation accuracy:16.00%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:2.157, Epoch accuracy:16.49%, Validation loss:2.072, Validation accuracy:17.33%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:2.164, Epoch accuracy:16.49%, Validation loss:2.086, Validation accuracy:14.67%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:2.181, Epoch accuracy:14.74%, Validation loss:2.091, Validation accuracy:14.33%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:2.129, Epoch accuracy:17.02%, Validation loss:2.079, Validation accuracy:16.33%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:2.192, Epoch accuracy:14.56%, Validation loss:2.059, Validation accuracy:18.00%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:2.147, Epoch accuracy:16.58%, Validation loss:2.080, Validation accuracy:14.67%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:2.129, Epoch accuracy:15.88%, Validation loss:2.074, Validation accuracy:17.00%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:2.168, Epoch accuracy:16.67%, Validation loss:2.064, Validation accuracy:15.00%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:2.177, Epoch accuracy:15.96%, Validation loss:2.076, Validation accuracy:13.00%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:2.163, Epoch accuracy:15.26%, Validation loss:2.077, Validation accuracy:16.00%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:2.165, Epoch accuracy:14.39%, Validation loss:2.086, Validation accuracy:15.67%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:2.146, Epoch accuracy:14.56%, Validation loss:2.064, Validation accuracy:15.33%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:2.128, Epoch accuracy:17.37%, Validation loss:2.077, Validation accuracy:14.67%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:2.178, Epoch accuracy:14.82%, Validation loss:2.068, Validation accuracy:18.33%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:2.163, Epoch accuracy:14.65%, Validation loss:2.065, Validation accuracy:16.00%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:2.133, Epoch accuracy:16.40%, Validation loss:2.060, Validation accuracy:17.00%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:2.148, Epoch accuracy:15.44%, Validation loss:2.071, Validation accuracy:14.00%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:2.159, Epoch accuracy:15.53%, Validation loss:2.058, Validation accuracy:17.00%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:2.166, Epoch accuracy:15.26%, Validation loss:2.071, Validation accuracy:16.33%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:2.128, Epoch accuracy:17.63%, Validation loss:2.060, Validation accuracy:18.00%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:2.148, Epoch accuracy:15.88%, Validation loss:2.063, Validation accuracy:18.33%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:2.122, Epoch accuracy:17.11%, Validation loss:2.065, Validation accuracy:20.00%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:2.122, Epoch accuracy:16.75%, Validation loss:2.063, Validation accuracy:16.33%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:2.142, Epoch accuracy:16.14%, Validation loss:2.053, Validation accuracy:18.67%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:2.106, Epoch accuracy:18.16%, Validation loss:2.060, Validation accuracy:16.67%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:2.158, Epoch accuracy:15.00%, Validation loss:2.068, Validation accuracy:15.67%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:2.143, Epoch accuracy:16.05%, Validation loss:2.064, Validation accuracy:15.00%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:2.126, Epoch accuracy:17.46%, Validation loss:2.061, Validation accuracy:16.00%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:2.107, Epoch accuracy:16.14%, Validation loss:2.056, Validation accuracy:17.67%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:2.128, Epoch accuracy:17.19%, Validation loss:2.050, Validation accuracy:17.67%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:2.146, Epoch accuracy:15.44%, Validation loss:2.052, Validation accuracy:16.67%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:2.128, Epoch accuracy:17.46%, Validation loss:2.064, Validation accuracy:17.33%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:2.134, Epoch accuracy:15.35%, Validation loss:2.060, Validation accuracy:17.00%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:2.151, Epoch accuracy:15.61%, Validation loss:2.054, Validation accuracy:18.33%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:2.086, Epoch accuracy:17.89%, Validation loss:2.045, Validation accuracy:17.67%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:2.109, Epoch accuracy:17.37%, Validation loss:2.046, Validation accuracy:18.33%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:2.118, Epoch accuracy:17.28%, Validation loss:2.043, Validation accuracy:17.67%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:2.135, Epoch accuracy:16.75%, Validation loss:2.053, Validation accuracy:16.33%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:2.092, Epoch accuracy:17.37%, Validation loss:2.064, Validation accuracy:15.00%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:2.148, Epoch accuracy:15.96%, Validation loss:2.046, Validation accuracy:17.67%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:2.109, Epoch accuracy:17.37%, Validation loss:2.049, Validation accuracy:19.33%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:2.140, Epoch accuracy:16.93%, Validation loss:2.047, Validation accuracy:17.67%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:2.121, Epoch accuracy:18.33%, Validation loss:2.054, Validation accuracy:13.00%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:2.100, Epoch accuracy:17.98%, Validation loss:2.045, Validation accuracy:17.33%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:2.087, Epoch accuracy:16.75%, Validation loss:2.037, Validation accuracy:19.33%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:2.100, Epoch accuracy:17.98%, Validation loss:2.046, Validation accuracy:19.00%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:2.094, Epoch accuracy:18.68%, Validation loss:2.041, Validation accuracy:16.33%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:2.133, Epoch accuracy:16.84%, Validation loss:2.039, Validation accuracy:19.67%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:2.122, Epoch accuracy:18.25%, Validation loss:2.036, Validation accuracy:18.67%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:2.088, Epoch accuracy:18.07%, Validation loss:2.045, Validation accuracy:20.67%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:2.085, Epoch accuracy:17.46%, Validation loss:2.038, Validation accuracy:18.67%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:2.089, Epoch accuracy:17.37%, Validation loss:2.045, Validation accuracy:18.33%
# Epoch 100: iteration 34/35
# Epoch 100 --- loss:2.092, Epoch accuracy:17.98%, Validation loss:2.039, Validation accuracy:17.67%
# Epoch 101: iteration 34/35
# Epoch 101 --- loss:2.088, Epoch accuracy:16.93%, Validation loss:2.040, Validation accuracy:17.00%
# Epoch 102: iteration 34/35
# Epoch 102 --- loss:2.099, Epoch accuracy:17.81%, Validation loss:2.027, Validation accuracy:17.00%
# Epoch 103: iteration 34/35
# Epoch 103 --- loss:2.095, Epoch accuracy:16.32%, Validation loss:2.025, Validation accuracy:17.33%
# Epoch 104: iteration 34/35
# Epoch 104 --- loss:2.086, Epoch accuracy:17.11%, Validation loss:2.040, Validation accuracy:20.00%
# Epoch 105: iteration 34/35
# Epoch 105 --- loss:2.098, Epoch accuracy:17.19%, Validation loss:2.040, Validation accuracy:19.33%
# Epoch 106: iteration 34/35
# Epoch 106 --- loss:2.092, Epoch accuracy:18.33%, Validation loss:2.027, Validation accuracy:16.33%
# Epoch 107: iteration 34/35
# Epoch 107 --- loss:2.101, Epoch accuracy:17.02%, Validation loss:2.037, Validation accuracy:20.67%
# Epoch 108: iteration 34/35
# Epoch 108 --- loss:2.058, Epoch accuracy:18.33%, Validation loss:2.050, Validation accuracy:17.67%
# Epoch 109: iteration 34/35
# Epoch 109 --- loss:2.066, Epoch accuracy:20.00%, Validation loss:2.041, Validation accuracy:19.67%
# Epoch 110: iteration 34/35
# Epoch 110 --- loss:2.103, Epoch accuracy:18.07%, Validation loss:2.035, Validation accuracy:21.00%
# Epoch 111: iteration 34/35
# Epoch 111 --- loss:2.052, Epoch accuracy:18.25%, Validation loss:2.027, Validation accuracy:19.00%
# Epoch 112: iteration 34/35
# Epoch 112 --- loss:2.083, Epoch accuracy:17.98%, Validation loss:2.010, Validation accuracy:20.00%
# Epoch 113: iteration 34/35
# Epoch 113 --- loss:2.060, Epoch accuracy:19.39%, Validation loss:2.037, Validation accuracy:19.00%
# Epoch 114: iteration 34/35
# Epoch 114 --- loss:2.098, Epoch accuracy:17.11%, Validation loss:2.021, Validation accuracy:17.67%
# Epoch 115: iteration 34/35
# Epoch 115 --- loss:2.077, Epoch accuracy:17.89%, Validation loss:2.016, Validation accuracy:20.00%
# Epoch 116: iteration 34/35
# Epoch 116 --- loss:2.062, Epoch accuracy:20.79%, Validation loss:2.016, Validation accuracy:20.67%
# Epoch 117: iteration 34/35
# Epoch 117 --- loss:2.067, Epoch accuracy:19.30%, Validation loss:2.023, Validation accuracy:17.33%
# Epoch 118: iteration 34/35
# Epoch 118 --- loss:2.077, Epoch accuracy:18.42%, Validation loss:2.021, Validation accuracy:18.67%
# Epoch 119: iteration 34/35
# Epoch 119 --- loss:2.104, Epoch accuracy:17.37%, Validation loss:2.015, Validation accuracy:21.33%
# Epoch 120: iteration 34/35
# Epoch 120 --- loss:2.046, Epoch accuracy:19.91%, Validation loss:2.016, Validation accuracy:20.00%
# Epoch 121: iteration 34/35
# Epoch 121 --- loss:2.053, Epoch accuracy:20.09%, Validation loss:2.012, Validation accuracy:20.33%
# Epoch 122: iteration 34/35
# Epoch 122 --- loss:2.075, Epoch accuracy:17.72%, Validation loss:2.016, Validation accuracy:20.67%
# Epoch 123: iteration 34/35
# Epoch 123 --- loss:2.072, Epoch accuracy:18.95%, Validation loss:2.010, Validation accuracy:18.67%
# Epoch 124: iteration 34/35
# Epoch 124 --- loss:2.080, Epoch accuracy:17.46%, Validation loss:2.022, Validation accuracy:20.00%
# Epoch 125: iteration 34/35
# Epoch 125 --- loss:2.053, Epoch accuracy:19.12%, Validation loss:2.006, Validation accuracy:21.33%
# Epoch 126: iteration 34/35
# Epoch 126 --- loss:2.108, Epoch accuracy:17.46%, Validation loss:2.014, Validation accuracy:21.33%
# Epoch 127: iteration 34/35
# Epoch 127 --- loss:2.038, Epoch accuracy:20.18%, Validation loss:2.015, Validation accuracy:19.00%
# Epoch 128: iteration 34/35
# Epoch 128 --- loss:2.057, Epoch accuracy:18.60%, Validation loss:2.018, Validation accuracy:18.00%
# Epoch 129: iteration 34/35
# Epoch 129 --- loss:2.074, Epoch accuracy:19.04%, Validation loss:2.024, Validation accuracy:20.67%
# Epoch 130: iteration 34/35
# Epoch 130 --- loss:2.090, Epoch accuracy:18.68%, Validation loss:2.018, Validation accuracy:22.00%
# Epoch 131: iteration 34/35
# Epoch 131 --- loss:2.081, Epoch accuracy:17.54%, Validation loss:2.017, Validation accuracy:19.00%
# Epoch 132: iteration 34/35
# Epoch 132 --- loss:2.071, Epoch accuracy:17.72%, Validation loss:2.014, Validation accuracy:21.33%
# Epoch 133: iteration 34/35
# Epoch 133 --- loss:2.086, Epoch accuracy:17.54%, Validation loss:2.027, Validation accuracy:18.67%
# Epoch 134: iteration 34/35
# Epoch 134 --- loss:2.062, Epoch accuracy:19.56%, Validation loss:2.009, Validation accuracy:22.67%
# Epoch 135: iteration 34/35
# Epoch 135 --- loss:2.088, Epoch accuracy:17.89%, Validation loss:2.008, Validation accuracy:21.67%
# Epoch 136: iteration 34/35
# Epoch 136 --- loss:2.048, Epoch accuracy:20.26%, Validation loss:2.029, Validation accuracy:21.33%
# Epoch 137: iteration 34/35
# Epoch 137 --- loss:2.044, Epoch accuracy:19.91%, Validation loss:2.015, Validation accuracy:20.67%
# Epoch 138: iteration 34/35
# Epoch 138 --- loss:2.073, Epoch accuracy:19.47%, Validation loss:2.017, Validation accuracy:21.33%
# Epoch 139: iteration 34/35
# Epoch 139 --- loss:2.049, Epoch accuracy:18.86%, Validation loss:2.011, Validation accuracy:19.67%
# Epoch 140: iteration 34/35
# Epoch 140 --- loss:2.075, Epoch accuracy:19.82%, Validation loss:2.011, Validation accuracy:20.33%
# Epoch 141: iteration 34/35
# Epoch 141 --- loss:2.025, Epoch accuracy:21.32%, Validation loss:2.017, Validation accuracy:21.67%
# Epoch 142: iteration 34/35
# Epoch 142 --- loss:2.056, Epoch accuracy:18.25%, Validation loss:2.012, Validation accuracy:21.00%
# Epoch 143: iteration 34/35
# Epoch 143 --- loss:2.047, Epoch accuracy:20.44%, Validation loss:2.036, Validation accuracy:16.67%
# Epoch 144: iteration 34/35
# Epoch 144 --- loss:2.056, Epoch accuracy:18.07%, Validation loss:2.011, Validation accuracy:20.33%
# Epoch 145: iteration 34/35
# Epoch 145 --- loss:2.063, Epoch accuracy:17.81%, Validation loss:2.018, Validation accuracy:19.33%
# Epoch 146: iteration 34/35
# Epoch 146 --- loss:2.062, Epoch accuracy:19.39%, Validation loss:2.012, Validation accuracy:20.33%
# Epoch 147: iteration 34/35
# Epoch 147 --- loss:2.063, Epoch accuracy:18.95%, Validation loss:2.001, Validation accuracy:22.00%
# Epoch 148: iteration 34/35
# Epoch 148 --- loss:2.044, Epoch accuracy:19.91%, Validation loss:2.010, Validation accuracy:21.00%
# Epoch 149: iteration 34/35
# Epoch 149 --- loss:2.029, Epoch accuracy:19.65%, Validation loss:2.017, Validation accuracy:17.67%
# Epoch 150: iteration 34/35
# Epoch 150 --- loss:2.052, Epoch accuracy:20.00%, Validation loss:2.015, Validation accuracy:18.33%
# Epoch 151: iteration 34/35
# Epoch 151 --- loss:2.034, Epoch accuracy:19.21%, Validation loss:2.005, Validation accuracy:22.00%
# Epoch 152: iteration 34/35
# Epoch 152 --- loss:2.048, Epoch accuracy:19.74%, Validation loss:2.007, Validation accuracy:20.00%
# Epoch 153: iteration 34/35
# Epoch 153 --- loss:2.045, Epoch accuracy:19.30%, Validation loss:2.006, Validation accuracy:21.00%
# Epoch 154: iteration 34/35
# Epoch 154 --- loss:2.040, Epoch accuracy:19.74%, Validation loss:2.035, Validation accuracy:18.00%
# Epoch 155: iteration 34/35
# Epoch 155 --- loss:2.059, Epoch accuracy:19.65%, Validation loss:2.010, Validation accuracy:21.33%
# Epoch 156: iteration 34/35
# Epoch 156 --- loss:2.048, Epoch accuracy:20.61%, Validation loss:2.006, Validation accuracy:20.33%
# Epoch 157: iteration 34/35
# Epoch 157 --- loss:2.047, Epoch accuracy:19.91%, Validation loss:2.007, Validation accuracy:22.00%
# Epoch 158: iteration 34/35
# Epoch 158 --- loss:2.067, Epoch accuracy:19.21%, Validation loss:2.039, Validation accuracy:17.67%
# Epoch 159: iteration 34/35
# Epoch 159 --- loss:2.054, Epoch accuracy:19.12%, Validation loss:2.007, Validation accuracy:23.00%
# Epoch 160: iteration 34/35
# Epoch 160 --- loss:2.067, Epoch accuracy:16.93%, Validation loss:2.019, Validation accuracy:17.67%
# Epoch 161: iteration 34/35
# Epoch 161 --- loss:2.029, Epoch accuracy:20.96%, Validation loss:2.035, Validation accuracy:19.33%
# Epoch 162: iteration 34/35
# Epoch 162 --- loss:2.049, Epoch accuracy:18.25%, Validation loss:2.009, Validation accuracy:21.67%
# Epoch 163: iteration 34/35
# Epoch 163 --- loss:2.042, Epoch accuracy:19.04%, Validation loss:2.014, Validation accuracy:20.33%
# Epoch 164: iteration 34/35
# Epoch 164 --- loss:2.064, Epoch accuracy:18.68%, Validation loss:1.996, Validation accuracy:21.33%
# Epoch 165: iteration 34/35
# Epoch 165 --- loss:2.055, Epoch accuracy:19.65%, Validation loss:2.005, Validation accuracy:22.00%
# Epoch 166: iteration 34/35
# Epoch 166 --- loss:2.082, Epoch accuracy:18.16%, Validation loss:2.010, Validation accuracy:20.00%
# Epoch 167: iteration 34/35
# Epoch 167 --- loss:2.073, Epoch accuracy:18.68%, Validation loss:2.006, Validation accuracy:19.33%
# Epoch 168: iteration 34/35
# Epoch 168 --- loss:2.055, Epoch accuracy:18.86%, Validation loss:2.003, Validation accuracy:21.67%
# Epoch 169: iteration 34/35
# Epoch 169 --- loss:2.049, Epoch accuracy:20.35%, Validation loss:2.007, Validation accuracy:22.00%
# Epoch 170: iteration 34/35
# Epoch 170 --- loss:2.020, Epoch accuracy:19.12%, Validation loss:1.995, Validation accuracy:18.33%
# Epoch 171: iteration 34/35
# Epoch 171 --- loss:2.037, Epoch accuracy:20.44%, Validation loss:2.005, Validation accuracy:24.67%
# Epoch 172: iteration 34/35
# Epoch 172 --- loss:2.041, Epoch accuracy:21.93%, Validation loss:2.008, Validation accuracy:22.67%
# Epoch 173: iteration 34/35
# Epoch 173 --- loss:2.036, Epoch accuracy:19.65%, Validation loss:2.011, Validation accuracy:21.00%
# Epoch 174: iteration 34/35
# Epoch 174 --- loss:2.029, Epoch accuracy:20.44%, Validation loss:1.996, Validation accuracy:21.33%
# Epoch 175: iteration 34/35
# Epoch 175 --- loss:2.016, Epoch accuracy:21.40%, Validation loss:2.003, Validation accuracy:20.00%
# Epoch 176: iteration 34/35
# Epoch 176 --- loss:2.024, Epoch accuracy:20.79%, Validation loss:1.989, Validation accuracy:19.00%
# Epoch 177: iteration 34/35
# Epoch 177 --- loss:2.041, Epoch accuracy:20.35%, Validation loss:2.003, Validation accuracy:20.00%
# Epoch 178: iteration 34/35
# Epoch 178 --- loss:2.047, Epoch accuracy:18.77%, Validation loss:1.999, Validation accuracy:19.33%
# Epoch 179: iteration 34/35
# Epoch 179 --- loss:2.022, Epoch accuracy:20.44%, Validation loss:1.995, Validation accuracy:22.33%
# Epoch 180: iteration 34/35
# Epoch 180 --- loss:2.007, Epoch accuracy:20.44%, Validation loss:2.001, Validation accuracy:20.33%
# Epoch 181: iteration 34/35
# Epoch 181 --- loss:2.056, Epoch accuracy:19.82%, Validation loss:2.007, Validation accuracy:20.33%
# Epoch 182: iteration 34/35
# Epoch 182 --- loss:2.019, Epoch accuracy:20.70%, Validation loss:2.013, Validation accuracy:18.67%
# Epoch 183: iteration 34/35
# Epoch 183 --- loss:2.001, Epoch accuracy:20.18%, Validation loss:2.003, Validation accuracy:20.00%
# Epoch 184: iteration 15/35

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join('5-CV', 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join('5-CV', 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
