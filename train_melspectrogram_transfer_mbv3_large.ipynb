# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange

class mbv3_large_transfer(nn.Module):
    def __init__(self, num_emotions) -> None:
        super().__init__()
    
        self.model_ft = models.mobilenet_v3_large(pretrained=True)
        self.model_ft.classifier[-1] = nn.Linear(1280, num_emotions)
        
        self.softmax_out = nn.Softmax(dim=1)
    
    def forward(self, x):
        output_logits = self.model_ft(x)
        output_softmax = self.softmax_out(output_logits)
        
        return output_logits, output_softmax

# %%
import os
import torch
import numpy as np
from torchinfo import summary
from tqdm.auto import tqdm

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

emotions_dict = {
    0: 'Neutral',
    1: 'Calm',
    2: 'Happy',
    3: 'Sad',
    4: 'Angry',
    5: 'Fear',
    6: 'Disgust',
    7: 'Surprise'
}

model = mbv3_large_transfer(num_emotions=len(emotions_dict)).to('cuda')
sub_name = 'mbv3_large_transfer'
data_name = 'RAVDESS'
EARLY_CNT = 30

minibatch = 64
num_epochs = 150
optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)

print(summary(model, input_size=(minibatch, 3, 224, 224)))
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# mbv3_large_transfer                                [64, 8]                   --
# ├─MobileNetV3: 1-1                                 [64, 8]                   --
# │    └─Sequential: 2-1                             [64, 960, 7, 7]           --
# │    │    └─ConvBNActivation: 3-1                  [64, 16, 112, 112]        464
# │    │    └─InvertedResidual: 3-2                  [64, 16, 112, 112]        464
# │    │    └─InvertedResidual: 3-3                  [64, 24, 56, 56]          3,440
# │    │    └─InvertedResidual: 3-4                  [64, 24, 56, 56]          4,440
# │    │    └─InvertedResidual: 3-5                  [64, 40, 28, 28]          10,328
# │    │    └─InvertedResidual: 3-6                  [64, 40, 28, 28]          20,992
# │    │    └─InvertedResidual: 3-7                  [64, 40, 28, 28]          20,992
# │    │    └─InvertedResidual: 3-8                  [64, 80, 14, 14]          32,080
# │    │    └─InvertedResidual: 3-9                  [64, 80, 14, 14]          34,760
# │    │    └─InvertedResidual: 3-10                 [64, 80, 14, 14]          31,992
# │    │    └─InvertedResidual: 3-11                 [64, 80, 14, 14]          31,992
# │    │    └─InvertedResidual: 3-12                 [64, 112, 14, 14]         214,424
# │    │    └─InvertedResidual: 3-13                 [64, 112, 14, 14]         386,120
# │    │    └─InvertedResidual: 3-14                 [64, 160, 7, 7]           429,224
# │    │    └─InvertedResidual: 3-15                 [64, 160, 7, 7]           797,360
# │    │    └─InvertedResidual: 3-16                 [64, 160, 7, 7]           797,360
# │    │    └─ConvBNActivation: 3-17                 [64, 960, 7, 7]           155,520
# │    └─AdaptiveAvgPool2d: 2-2                      [64, 960, 1, 1]           --
# │    └─Sequential: 2-3                             [64, 8]                   --
# │    │    └─Linear: 3-18                           [64, 1280]                1,230,080
# │    │    └─Hardswish: 3-19                        [64, 1280]                --
# │    │    └─Dropout: 3-20                          [64, 1280]                --
# │    │    └─Linear: 3-21                           [64, 8]                   10,248
# ├─Softmax: 1-2                                     [64, 8]                   --
# ====================================================================================================
# Total params: 4,212,280
# Trainable params: 4,212,280
# Non-trainable params: 0
# Total mult-adds (G): 13.78
# ====================================================================================================
# Input size (MB): 38.54
# Forward/backward pass size (MB): 4508.66
# Params size (MB): 16.85
# Estimated Total Size (MB): 4564.05
# ====================================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            X_tensor = X_tensor.permute(0, 3, 1, 2)
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        X_valid_tensor = X_valid_tensor.permute(0, 3, 1, 2)
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import cv2
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(cur_fold_path):
    X_train, y_train, X_test, y_test = [], [], [], []
    
    train_f = open(os.path.join(cur_fold_path, 'train.csv'), 'r')
    test_f = open(os.path.join(cur_fold_path, 'test.csv'), 'r')
    
    train_reader = csv.reader(train_f)
    for r in train_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_train.append(image)
        y_train.append(int(r[1]))
        
    test_reader = csv.reader(test_f)
    for r in test_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_test.append(image)
        y_test.append(int(r[1]))
    
    return np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

# %%
all_fold_dataset = []

for fold in tqdm(range(5), desc='load melspectrogram fold dataset'):
    cur_fold_path = os.path.join('melspectrogram_fold', str(fold))
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    all_fold_dataset.append([X_train, y_train, X_test, y_test])
# Out:
# load melspectrogram fold dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'melspectrogram_fold'

for fold in range(5):
    cur = all_fold_dataset[fold]
    
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - mbv3_large_transfer
# 0:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:1.994, Epoch accuracy:12.81%, Validation loss:2.095, Validation accuracy:11.33%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:1.991, Epoch accuracy:13.77%, Validation loss:2.093, Validation accuracy:10.33%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:1.982, Epoch accuracy:14.56%, Validation loss:2.093, Validation accuracy:11.67%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:1.986, Epoch accuracy:14.39%, Validation loss:2.097, Validation accuracy:11.00%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:1.969, Epoch accuracy:14.65%, Validation loss:2.102, Validation accuracy:13.33%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:1.972, Epoch accuracy:14.30%, Validation loss:2.107, Validation accuracy:14.67%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:1.967, Epoch accuracy:13.86%, Validation loss:2.107, Validation accuracy:16.00%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:1.964, Epoch accuracy:15.09%, Validation loss:2.102, Validation accuracy:16.67%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:1.965, Epoch accuracy:15.88%, Validation loss:2.094, Validation accuracy:17.00%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:1.951, Epoch accuracy:16.67%, Validation loss:2.087, Validation accuracy:16.00%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:1.949, Epoch accuracy:17.28%, Validation loss:2.081, Validation accuracy:16.33%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:1.945, Epoch accuracy:17.81%, Validation loss:2.077, Validation accuracy:17.33%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:1.940, Epoch accuracy:19.82%, Validation loss:2.075, Validation accuracy:17.33%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:1.929, Epoch accuracy:20.79%, Validation loss:2.074, Validation accuracy:14.67%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:1.932, Epoch accuracy:20.09%, Validation loss:2.073, Validation accuracy:16.33%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:1.933, Epoch accuracy:19.30%, Validation loss:2.074, Validation accuracy:17.33%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:1.922, Epoch accuracy:19.65%, Validation loss:2.074, Validation accuracy:16.33%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:1.917, Epoch accuracy:20.88%, Validation loss:2.073, Validation accuracy:16.33%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:1.912, Epoch accuracy:21.67%, Validation loss:2.069, Validation accuracy:18.67%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:1.909, Epoch accuracy:22.28%, Validation loss:2.062, Validation accuracy:18.33%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:1.905, Epoch accuracy:22.19%, Validation loss:2.054, Validation accuracy:19.00%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:1.896, Epoch accuracy:23.60%, Validation loss:2.046, Validation accuracy:19.33%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:1.889, Epoch accuracy:23.16%, Validation loss:2.039, Validation accuracy:18.67%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:1.891, Epoch accuracy:23.07%, Validation loss:2.031, Validation accuracy:19.67%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:1.888, Epoch accuracy:25.79%, Validation loss:2.024, Validation accuracy:18.67%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:1.885, Epoch accuracy:24.39%, Validation loss:2.019, Validation accuracy:20.33%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:1.875, Epoch accuracy:24.65%, Validation loss:2.015, Validation accuracy:20.00%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:1.880, Epoch accuracy:24.56%, Validation loss:2.011, Validation accuracy:20.00%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:1.877, Epoch accuracy:25.35%, Validation loss:2.008, Validation accuracy:19.67%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:1.864, Epoch accuracy:26.58%, Validation loss:2.003, Validation accuracy:22.00%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:1.866, Epoch accuracy:28.33%, Validation loss:1.996, Validation accuracy:24.00%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:1.860, Epoch accuracy:27.89%, Validation loss:1.989, Validation accuracy:28.33%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:1.846, Epoch accuracy:28.60%, Validation loss:1.983, Validation accuracy:29.00%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:1.853, Epoch accuracy:28.95%, Validation loss:1.977, Validation accuracy:29.67%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:1.848, Epoch accuracy:30.61%, Validation loss:1.972, Validation accuracy:30.33%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:1.841, Epoch accuracy:28.68%, Validation loss:1.966, Validation accuracy:30.67%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:1.833, Epoch accuracy:32.54%, Validation loss:1.962, Validation accuracy:30.33%
# Epoch 37: iteration 16/17
# Epoch 37 --- loss:1.829, Epoch accuracy:32.02%, Validation loss:1.957, Validation accuracy:29.67%
# Epoch 38: iteration 16/17
# Epoch 38 --- loss:1.824, Epoch accuracy:31.93%, Validation loss:1.953, Validation accuracy:30.67%
# Epoch 39: iteration 16/17
# Epoch 39 --- loss:1.820, Epoch accuracy:32.37%, Validation loss:1.949, Validation accuracy:30.67%
# Epoch 40: iteration 16/17
# Epoch 40 --- loss:1.818, Epoch accuracy:31.67%, Validation loss:1.946, Validation accuracy:31.67%
# Epoch 41: iteration 16/17
# Epoch 41 --- loss:1.818, Epoch accuracy:32.81%, Validation loss:1.942, Validation accuracy:33.00%
# Epoch 86: iteration 16/17
# Epoch 86 --- loss:1.613, Epoch accuracy:48.95%, Validation loss:1.798, Validation accuracy:42.67%
# Epoch 87: iteration 16/17
# Epoch 87 --- loss:1.612, Epoch accuracy:47.98%, Validation loss:1.795, Validation accuracy:42.67%
# Epoch 88: iteration 16/17
# Epoch 88 --- loss:1.610, Epoch accuracy:48.25%, Validation loss:1.791, Validation accuracy:43.00%
# Epoch 89: iteration 16/17
# Epoch 89 --- loss:1.610, Epoch accuracy:49.30%, Validation loss:1.788, Validation accuracy:43.00%
# Epoch 90: iteration 16/17
# Epoch 90 --- loss:1.601, Epoch accuracy:50.00%, Validation loss:1.785, Validation accuracy:42.67%
# Epoch 91: iteration 16/17
# Epoch 91 --- loss:1.592, Epoch accuracy:48.42%, Validation loss:1.782, Validation accuracy:42.67%
# Epoch 92: iteration 16/17
# Epoch 92 --- loss:1.588, Epoch accuracy:49.65%, Validation loss:1.778, Validation accuracy:42.67%
# Epoch 93: iteration 16/17
# Epoch 93 --- loss:1.584, Epoch accuracy:50.70%, Validation loss:1.775, Validation accuracy:43.00%
# Epoch 94: iteration 16/17
# Epoch 94 --- loss:1.578, Epoch accuracy:50.88%, Validation loss:1.772, Validation accuracy:43.00%
# Epoch 95: iteration 16/17
# Epoch 95 --- loss:1.579, Epoch accuracy:49.30%, Validation loss:1.769, Validation accuracy:43.33%
# Epoch 96: iteration 16/17
# Epoch 96 --- loss:1.575, Epoch accuracy:50.53%, Validation loss:1.765, Validation accuracy:43.33%
# Epoch 97: iteration 16/17
# Epoch 97 --- loss:1.566, Epoch accuracy:50.61%, Validation loss:1.762, Validation accuracy:43.00%
# Epoch 98: iteration 16/17
# Epoch 98 --- loss:1.564, Epoch accuracy:49.21%, Validation loss:1.759, Validation accuracy:43.33%
# Epoch 99: iteration 16/17
# Epoch 99 --- loss:1.557, Epoch accuracy:50.61%, Validation loss:1.755, Validation accuracy:43.33%
# Epoch 100: iteration 16/17
# Epoch 100 --- loss:1.548, Epoch accuracy:51.23%, Validation loss:1.752, Validation accuracy:43.67%
# Epoch 101: iteration 16/17
# Epoch 101 --- loss:1.549, Epoch accuracy:50.88%, Validation loss:1.749, Validation accuracy:43.67%
# Epoch 102: iteration 16/17
# Epoch 102 --- loss:1.546, Epoch accuracy:51.40%, Validation loss:1.745, Validation accuracy:43.67%
# Epoch 103: iteration 16/17
# Epoch 103 --- loss:1.538, Epoch accuracy:51.58%, Validation loss:1.742, Validation accuracy:43.67%
# Epoch 104: iteration 16/17
# Epoch 104 --- loss:1.540, Epoch accuracy:50.26%, Validation loss:1.739, Validation accuracy:43.33%
# Epoch 105: iteration 16/17
# Epoch 105 --- loss:1.528, Epoch accuracy:51.75%, Validation loss:1.736, Validation accuracy:43.67%
# Epoch 106: iteration 16/17
# Epoch 106 --- loss:1.523, Epoch accuracy:51.49%, Validation loss:1.732, Validation accuracy:43.67%
# Epoch 107: iteration 16/17
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:1.310, Epoch accuracy:55.88%, Validation loss:1.300, Validation accuracy:62.00%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:1.286, Epoch accuracy:59.04%, Validation loss:1.298, Validation accuracy:62.00%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:1.275, Epoch accuracy:59.04%, Validation loss:1.296, Validation accuracy:62.00%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:1.280, Epoch accuracy:57.98%, Validation loss:1.294, Validation accuracy:61.67%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:1.271, Epoch accuracy:58.77%, Validation loss:1.292, Validation accuracy:62.00%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:1.269, Epoch accuracy:60.09%, Validation loss:1.290, Validation accuracy:62.00%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:1.267, Epoch accuracy:58.33%, Validation loss:1.289, Validation accuracy:61.33%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:1.256, Epoch accuracy:59.30%, Validation loss:1.286, Validation accuracy:61.33%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:1.260, Epoch accuracy:59.04%, Validation loss:1.284, Validation accuracy:61.00%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:1.259, Epoch accuracy:58.33%, Validation loss:1.283, Validation accuracy:61.00%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:1.240, Epoch accuracy:61.14%, Validation loss:1.281, Validation accuracy:61.00%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:1.251, Epoch accuracy:59.47%, Validation loss:1.279, Validation accuracy:61.00%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:1.242, Epoch accuracy:60.26%, Validation loss:1.277, Validation accuracy:61.33%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:1.237, Epoch accuracy:58.95%, Validation loss:1.275, Validation accuracy:61.33%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:1.236, Epoch accuracy:60.61%, Validation loss:1.273, Validation accuracy:61.33%
# Epoch 37: iteration 16/17
# Epoch 37 --- loss:1.229, Epoch accuracy:60.35%, Validation loss:1.272, Validation accuracy:61.67%
# Epoch 38: iteration 16/17
# Epoch 38 --- loss:1.232, Epoch accuracy:60.70%, Validation loss:1.270, Validation accuracy:61.67%
# Epoch 39: iteration 16/17
# Epoch 39 --- loss:1.225, Epoch accuracy:60.61%, Validation loss:1.268, Validation accuracy:61.33%
# Epoch 40: iteration 16/17
# Epoch 40 --- loss:1.213, Epoch accuracy:61.58%, Validation loss:1.266, Validation accuracy:61.33%
# Epoch 41: iteration 16/17
# Epoch 41 --- loss:1.210, Epoch accuracy:61.67%, Validation loss:1.265, Validation accuracy:61.33%
# Epoch 42: iteration 16/17
# Epoch 42 --- loss:1.210, Epoch accuracy:60.61%, Validation loss:1.263, Validation accuracy:61.33%
# Epoch 43: iteration 16/17
# Epoch 43 --- loss:1.218, Epoch accuracy:60.18%, Validation loss:1.261, Validation accuracy:61.33%
# Epoch 131: iteration 16/17
# Epoch 131 --- loss:0.877, Epoch accuracy:74.47%, Validation loss:1.149, Validation accuracy:60.00%
# Epoch 132: iteration 16/17
# Epoch 132 --- loss:0.878, Epoch accuracy:73.25%, Validation loss:1.147, Validation accuracy:59.67%
# Epoch 133: iteration 16/17
# Epoch 133 --- loss:0.865, Epoch accuracy:73.51%, Validation loss:1.147, Validation accuracy:59.67%
# Epoch 134: iteration 16/17
# Epoch 134 --- loss:0.856, Epoch accuracy:74.91%, Validation loss:1.146, Validation accuracy:59.67%
# Epoch 135: iteration 16/17
# Epoch 135 --- loss:0.863, Epoch accuracy:74.39%, Validation loss:1.145, Validation accuracy:60.00%
# Epoch 136: iteration 16/17
# Epoch 136 --- loss:0.854, Epoch accuracy:74.74%, Validation loss:1.144, Validation accuracy:59.67%
# Epoch 137: iteration 16/17
# Epoch 137 --- loss:0.831, Epoch accuracy:75.70%, Validation loss:1.143, Validation accuracy:59.67%
# Epoch 138: iteration 16/17
# Epoch 138 --- loss:0.855, Epoch accuracy:74.30%, Validation loss:1.143, Validation accuracy:59.67%
# Epoch 139: iteration 16/17
# Epoch 139 --- loss:0.851, Epoch accuracy:75.00%, Validation loss:1.142, Validation accuracy:59.67%
# Epoch 140: iteration 16/17
# Epoch 140 --- loss:0.847, Epoch accuracy:75.00%, Validation loss:1.141, Validation accuracy:59.33%
# Epoch 141: iteration 16/17
# Epoch 141 --- loss:0.834, Epoch accuracy:75.61%, Validation loss:1.140, Validation accuracy:59.67%
# Epoch 142: iteration 16/17
# Epoch 142 --- loss:0.839, Epoch accuracy:75.53%, Validation loss:1.140, Validation accuracy:59.67%
# Epoch 143: iteration 16/17
# Epoch 143 --- loss:0.831, Epoch accuracy:75.18%, Validation loss:1.138, Validation accuracy:59.67%
# Epoch 144: iteration 16/17
# Epoch 144 --- loss:0.831, Epoch accuracy:74.74%, Validation loss:1.138, Validation accuracy:59.67%
# Epoch 145: iteration 16/17
# Epoch 145 --- loss:0.824, Epoch accuracy:75.88%, Validation loss:1.137, Validation accuracy:59.67%
# Epoch 146: iteration 16/17
# Epoch 146 --- loss:0.810, Epoch accuracy:76.05%, Validation loss:1.137, Validation accuracy:59.33%
# Epoch 147: iteration 16/17
# Epoch 147 --- loss:0.823, Epoch accuracy:74.74%, Validation loss:1.136, Validation accuracy:59.67%
# Epoch 148: iteration 16/17
# Epoch 148 --- loss:0.813, Epoch accuracy:75.35%, Validation loss:1.135, Validation accuracy:59.67%
# Epoch 149: iteration 16/17
# Epoch 149 --- loss:0.809, Epoch accuracy:75.79%, Validation loss:1.134, Validation accuracy:59.33%
#
#
# [*] done !
# [*] Best training loss - 0.8093160227725381
# [*] Best validation loss - 1.1344128847122192
# 2:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:0.879, Epoch accuracy:72.89%, Validation loss:0.807, Validation accuracy:80.67%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:0.884, Epoch accuracy:71.84%, Validation loss:0.806, Validation accuracy:80.67%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:0.890, Epoch accuracy:71.67%, Validation loss:0.806, Validation accuracy:81.00%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:0.886, Epoch accuracy:71.58%, Validation loss:0.805, Validation accuracy:81.33%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:0.881, Epoch accuracy:71.40%, Validation loss:0.804, Validation accuracy:81.67%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:0.867, Epoch accuracy:72.37%, Validation loss:0.804, Validation accuracy:81.33%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:0.861, Epoch accuracy:73.16%, Validation loss:0.803, Validation accuracy:81.33%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:0.875, Epoch accuracy:72.54%, Validation loss:0.802, Validation accuracy:81.00%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:0.868, Epoch accuracy:71.58%, Validation loss:0.802, Validation accuracy:81.00%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:0.861, Epoch accuracy:73.16%, Validation loss:0.801, Validation accuracy:81.00%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:0.846, Epoch accuracy:73.07%, Validation loss:0.801, Validation accuracy:80.33%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:0.856, Epoch accuracy:73.86%, Validation loss:0.800, Validation accuracy:80.67%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:0.856, Epoch accuracy:72.72%, Validation loss:0.799, Validation accuracy:80.67%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:0.845, Epoch accuracy:72.54%, Validation loss:0.799, Validation accuracy:80.33%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:0.840, Epoch accuracy:74.65%, Validation loss:0.798, Validation accuracy:80.33%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:0.834, Epoch accuracy:74.30%, Validation loss:0.798, Validation accuracy:80.33%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:0.833, Epoch accuracy:73.86%, Validation loss:0.797, Validation accuracy:80.33%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:0.835, Epoch accuracy:73.25%, Validation loss:0.796, Validation accuracy:80.33%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:0.829, Epoch accuracy:74.56%, Validation loss:0.795, Validation accuracy:80.33%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:0.828, Epoch accuracy:74.21%, Validation loss:0.794, Validation accuracy:80.33%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:0.821, Epoch accuracy:74.21%, Validation loss:0.793, Validation accuracy:80.00%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:0.819, Epoch accuracy:73.86%, Validation loss:0.792, Validation accuracy:80.00%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:0.811, Epoch accuracy:74.21%, Validation loss:0.791, Validation accuracy:80.00%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:0.809, Epoch accuracy:74.21%, Validation loss:0.791, Validation accuracy:79.67%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:0.808, Epoch accuracy:75.26%, Validation loss:0.790, Validation accuracy:80.00%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:0.802, Epoch accuracy:75.09%, Validation loss:0.790, Validation accuracy:80.00%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:0.808, Epoch accuracy:74.91%, Validation loss:0.789, Validation accuracy:80.33%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:0.798, Epoch accuracy:75.18%, Validation loss:0.788, Validation accuracy:80.33%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:0.796, Epoch accuracy:75.96%, Validation loss:0.787, Validation accuracy:80.00%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:0.789, Epoch accuracy:74.91%, Validation loss:0.787, Validation accuracy:80.00%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:0.788, Epoch accuracy:76.32%, Validation loss:0.786, Validation accuracy:80.00%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:0.780, Epoch accuracy:76.14%, Validation loss:0.785, Validation accuracy:80.00%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:0.790, Epoch accuracy:74.65%, Validation loss:0.784, Validation accuracy:80.00%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:0.777, Epoch accuracy:76.32%, Validation loss:0.784, Validation accuracy:80.00%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:0.781, Epoch accuracy:75.79%, Validation loss:0.783, Validation accuracy:80.00%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:0.783, Epoch accuracy:75.09%, Validation loss:0.783, Validation accuracy:80.00%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:0.775, Epoch accuracy:76.14%, Validation loss:0.782, Validation accuracy:80.00%
# Epoch 37: iteration 16/17
# Epoch 37 --- loss:0.768, Epoch accuracy:75.79%, Validation loss:0.781, Validation accuracy:80.00%
# Epoch 38: iteration 16/17
# Epoch 38 --- loss:0.753, Epoch accuracy:76.75%, Validation loss:0.780, Validation accuracy:80.00%
# Epoch 39: iteration 16/17
# Epoch 39 --- loss:0.758, Epoch accuracy:76.67%, Validation loss:0.780, Validation accuracy:80.33%
# Epoch 40: iteration 16/17
# Epoch 40 --- loss:0.738, Epoch accuracy:76.93%, Validation loss:0.779, Validation accuracy:80.33%
# Epoch 41: iteration 16/17
# Epoch 41 --- loss:0.755, Epoch accuracy:77.72%, Validation loss:0.778, Validation accuracy:80.33%
# Epoch 42: iteration 16/17
# Epoch 42 --- loss:0.746, Epoch accuracy:76.49%, Validation loss:0.778, Validation accuracy:80.33%
# Epoch 43: iteration 16/17
# Epoch 43 --- loss:0.737, Epoch accuracy:77.63%, Validation loss:0.777, Validation accuracy:80.00%
# Epoch 44: iteration 16/17
# Epoch 44 --- loss:0.744, Epoch accuracy:76.67%, Validation loss:0.777, Validation accuracy:80.00%
# Epoch 45: iteration 16/17
# Epoch 45 --- loss:0.748, Epoch accuracy:76.84%, Validation loss:0.776, Validation accuracy:80.00%
# Epoch 46: iteration 16/17
# Epoch 46 --- loss:0.737, Epoch accuracy:77.02%, Validation loss:0.775, Validation accuracy:80.00%
# Epoch 47: iteration 16/17
# Epoch 47 --- loss:0.740, Epoch accuracy:77.81%, Validation loss:0.775, Validation accuracy:80.00%
# Epoch 48: iteration 16/17
# Epoch 48 --- loss:0.728, Epoch accuracy:77.28%, Validation loss:0.774, Validation accuracy:80.00%
# Epoch 49: iteration 16/17
# Epoch 49 --- loss:0.720, Epoch accuracy:78.16%, Validation loss:0.774, Validation accuracy:80.00%
# Epoch 50: iteration 16/17
# Epoch 50 --- loss:0.726, Epoch accuracy:76.67%, Validation loss:0.773, Validation accuracy:79.67%
# Epoch 51: iteration 16/17
# Epoch 51 --- loss:0.723, Epoch accuracy:77.89%, Validation loss:0.772, Validation accuracy:79.67%
# Epoch 52: iteration 16/17
# Epoch 52 --- loss:0.716, Epoch accuracy:78.77%, Validation loss:0.771, Validation accuracy:79.67%
# Epoch 53: iteration 16/17
# Epoch 53 --- loss:0.707, Epoch accuracy:79.12%, Validation loss:0.771, Validation accuracy:79.67%
# Epoch 54: iteration 16/17
# Epoch 54 --- loss:0.716, Epoch accuracy:78.07%, Validation loss:0.770, Validation accuracy:80.00%
# Epoch 55: iteration 16/17
# Epoch 55 --- loss:0.715, Epoch accuracy:76.75%, Validation loss:0.770, Validation accuracy:80.00%
# Epoch 56: iteration 16/17
# Epoch 56 --- loss:0.703, Epoch accuracy:78.33%, Validation loss:0.769, Validation accuracy:79.67%
# Epoch 57: iteration 16/17
# Epoch 57 --- loss:0.700, Epoch accuracy:78.68%, Validation loss:0.768, Validation accuracy:79.67%
# Epoch 58: iteration 16/17
# Epoch 58 --- loss:0.688, Epoch accuracy:79.04%, Validation loss:0.768, Validation accuracy:79.00%
# Epoch 59: iteration 16/17
# Epoch 59 --- loss:0.712, Epoch accuracy:77.37%, Validation loss:0.767, Validation accuracy:79.33%
# Epoch 60: iteration 16/17
# Epoch 60 --- loss:0.695, Epoch accuracy:78.25%, Validation loss:0.766, Validation accuracy:79.00%
# Epoch 61: iteration 16/17
# Epoch 61 --- loss:0.709, Epoch accuracy:78.07%, Validation loss:0.766, Validation accuracy:79.33%
# Epoch 62: iteration 16/17
# Epoch 62 --- loss:0.691, Epoch accuracy:77.72%, Validation loss:0.765, Validation accuracy:79.00%
# Epoch 63: iteration 16/17
# Epoch 63 --- loss:0.676, Epoch accuracy:80.00%, Validation loss:0.765, Validation accuracy:79.00%
# Epoch 64: iteration 16/17
# Epoch 64 --- loss:0.684, Epoch accuracy:79.65%, Validation loss:0.764, Validation accuracy:79.00%
# Epoch 65: iteration 16/17
# Epoch 65 --- loss:0.681, Epoch accuracy:78.95%, Validation loss:0.764, Validation accuracy:79.00%
# Epoch 66: iteration 16/17
# Epoch 66 --- loss:0.681, Epoch accuracy:78.86%, Validation loss:0.763, Validation accuracy:79.00%
# Epoch 67: iteration 16/17
# Epoch 67 --- loss:0.680, Epoch accuracy:79.12%, Validation loss:0.762, Validation accuracy:79.00%
# Epoch 68: iteration 16/17
# Epoch 68 --- loss:0.690, Epoch accuracy:77.02%, Validation loss:0.762, Validation accuracy:79.00%
# Epoch 69: iteration 16/17
# Epoch 69 --- loss:0.666, Epoch accuracy:79.12%, Validation loss:0.761, Validation accuracy:79.00%
# Epoch 70: iteration 16/17
# Epoch 70 --- loss:0.665, Epoch accuracy:79.30%, Validation loss:0.761, Validation accuracy:79.00%
# Epoch 71: iteration 16/17
# Epoch 71 --- loss:0.674, Epoch accuracy:78.42%, Validation loss:0.761, Validation accuracy:79.33%
# Epoch 72: iteration 16/17
# Epoch 72 --- loss:0.653, Epoch accuracy:80.44%, Validation loss:0.760, Validation accuracy:79.33%
# Epoch 73: iteration 16/17
# Epoch 73 --- loss:0.667, Epoch accuracy:79.82%, Validation loss:0.760, Validation accuracy:79.33%
# Epoch 74: iteration 16/17
# Epoch 74 --- loss:0.655, Epoch accuracy:79.47%, Validation loss:0.759, Validation accuracy:79.00%
# Epoch 75: iteration 16/17
# Epoch 75 --- loss:0.658, Epoch accuracy:79.65%, Validation loss:0.759, Validation accuracy:79.00%
# Epoch 76: iteration 16/17
# Epoch 76 --- loss:0.657, Epoch accuracy:79.82%, Validation loss:0.758, Validation accuracy:79.00%
# Epoch 77: iteration 16/17
# Epoch 77 --- loss:0.654, Epoch accuracy:80.00%, Validation loss:0.758, Validation accuracy:79.00%
# Epoch 78: iteration 16/17
# Epoch 78 --- loss:0.645, Epoch accuracy:80.96%, Validation loss:0.758, Validation accuracy:79.00%
# Epoch 79: iteration 16/17
# Epoch 79 --- loss:0.642, Epoch accuracy:81.14%, Validation loss:0.757, Validation accuracy:78.67%
# Epoch 80: iteration 16/17
# Epoch 80 --- loss:0.645, Epoch accuracy:80.26%, Validation loss:0.757, Validation accuracy:78.67%
# Epoch 81: iteration 16/17
# Epoch 81 --- loss:0.642, Epoch accuracy:80.88%, Validation loss:0.757, Validation accuracy:78.67%
# Epoch 82: iteration 16/17
# ...
# Epoch 94: iteration 16/17
# Epoch 94 --- loss:0.607, Epoch accuracy:82.72%, Validation loss:0.750, Validation accuracy:77.67%
# Epoch 95: iteration 16/17
# Epoch 95 --- loss:0.594, Epoch accuracy:81.58%, Validation loss:0.750, Validation accuracy:78.00%
# Epoch 96: iteration 16/17
# Epoch 96 --- loss:0.592, Epoch accuracy:83.16%, Validation loss:0.749, Validation accuracy:77.67%
# Epoch 97: iteration 16/17
# Epoch 97 --- loss:0.589, Epoch accuracy:81.14%, Validation loss:0.749, Validation accuracy:78.00%
# Epoch 98: iteration 16/17
# Epoch 98 --- loss:0.600, Epoch accuracy:80.96%, Validation loss:0.749, Validation accuracy:78.00%
# Epoch 99: iteration 16/17
# Epoch 99 --- loss:0.597, Epoch accuracy:82.46%, Validation loss:0.749, Validation accuracy:78.00%
# Epoch 100: iteration 16/17
# Epoch 100 --- loss:0.598, Epoch accuracy:81.05%, Validation loss:0.749, Validation accuracy:77.67%
# Epoch 101: iteration 16/17
# Epoch 101 --- loss:0.582, Epoch accuracy:81.84%, Validation loss:0.748, Validation accuracy:77.67%
# Epoch 102: iteration 16/17
# Epoch 102 --- loss:0.592, Epoch accuracy:81.32%, Validation loss:0.747, Validation accuracy:77.67%
# Epoch 103: iteration 16/17
# Epoch 103 --- loss:0.581, Epoch accuracy:81.84%, Validation loss:0.747, Validation accuracy:77.67%
# Epoch 104: iteration 16/17
# Epoch 104 --- loss:0.574, Epoch accuracy:82.98%, Validation loss:0.747, Validation accuracy:77.67%
# Epoch 105: iteration 16/17
# Epoch 105 --- loss:0.585, Epoch accuracy:81.84%, Validation loss:0.746, Validation accuracy:77.33%
# Epoch 106: iteration 16/17
# Epoch 106 --- loss:0.571, Epoch accuracy:82.63%, Validation loss:0.746, Validation accuracy:77.33%
# Epoch 107: iteration 16/17
# Epoch 107 --- loss:0.557, Epoch accuracy:83.25%, Validation loss:0.746, Validation accuracy:77.33%
# Epoch 108: iteration 16/17
# Epoch 108 --- loss:0.560, Epoch accuracy:83.16%, Validation loss:0.746, Validation accuracy:77.33%
# Epoch 109: iteration 16/17
# Epoch 109 --- loss:0.560, Epoch accuracy:82.98%, Validation loss:0.745, Validation accuracy:77.33%
# Epoch 110: iteration 16/17
# Epoch 110 --- loss:0.555, Epoch accuracy:82.72%, Validation loss:0.745, Validation accuracy:77.33%
# Epoch 111: iteration 16/17
# Epoch 111 --- loss:0.550, Epoch accuracy:84.47%, Validation loss:0.744, Validation accuracy:77.33%
# Epoch 112: iteration 16/17
# Epoch 112 --- loss:0.562, Epoch accuracy:83.68%, Validation loss:0.743, Validation accuracy:77.33%
# Epoch 113: iteration 16/17
# Epoch 113 --- loss:0.558, Epoch accuracy:82.63%, Validation loss:0.744, Validation accuracy:77.33%
# Epoch 114: iteration 16/17
# Epoch 114 --- loss:0.544, Epoch accuracy:83.68%, Validation loss:0.743, Validation accuracy:77.33%
# Epoch 115: iteration 16/17
# Epoch 115 --- loss:0.551, Epoch accuracy:82.89%, Validation loss:0.743, Validation accuracy:77.33%
# Epoch 116: iteration 16/17
# Epoch 116 --- loss:0.557, Epoch accuracy:83.25%, Validation loss:0.743, Validation accuracy:77.33%
# Epoch 117: iteration 16/17
# Epoch 117 --- loss:0.559, Epoch accuracy:82.28%, Validation loss:0.743, Validation accuracy:77.33%
# Epoch 118: iteration 16/17
# Epoch 118 --- loss:0.536, Epoch accuracy:84.82%, Validation loss:0.742, Validation accuracy:77.33%
# Epoch 119: iteration 16/17
# Epoch 119 --- loss:0.548, Epoch accuracy:83.77%, Validation loss:0.742, Validation accuracy:77.00%
# Epoch 120: iteration 16/17
# Epoch 120 --- loss:0.532, Epoch accuracy:83.86%, Validation loss:0.741, Validation accuracy:77.00%
# Epoch 121: iteration 16/17
# Epoch 121 --- loss:0.530, Epoch accuracy:84.30%, Validation loss:0.741, Validation accuracy:77.00%
# Epoch 122: iteration 16/17
# Epoch 122 --- loss:0.528, Epoch accuracy:84.30%, Validation loss:0.741, Validation accuracy:76.67%
# Epoch 123: iteration 16/17
# Epoch 123 --- loss:0.533, Epoch accuracy:84.30%, Validation loss:0.740, Validation accuracy:76.67%
# Epoch 124: iteration 16/17
# Epoch 124 --- loss:0.530, Epoch accuracy:83.51%, Validation loss:0.740, Validation accuracy:76.67%
# Epoch 125: iteration 16/17
# Epoch 125 --- loss:0.527, Epoch accuracy:84.30%, Validation loss:0.740, Validation accuracy:76.67%
# Epoch 126: iteration 16/17
# Epoch 126 --- loss:0.522, Epoch accuracy:82.72%, Validation loss:0.739, Validation accuracy:76.67%
# Epoch 127: iteration 16/17
# Epoch 127 --- loss:0.513, Epoch accuracy:84.82%, Validation loss:0.740, Validation accuracy:77.00%
# Epoch 128: iteration 16/17
# Epoch 128 --- loss:0.514, Epoch accuracy:84.39%, Validation loss:0.739, Validation accuracy:76.67%
# Epoch 129: iteration 16/17
# Epoch 129 --- loss:0.516, Epoch accuracy:85.09%, Validation loss:0.739, Validation accuracy:77.00%
# Epoch 130: iteration 16/17
# Epoch 130 --- loss:0.507, Epoch accuracy:84.56%, Validation loss:0.739, Validation accuracy:77.00%
# Epoch 131: iteration 16/17
# Epoch 131 --- loss:0.512, Epoch accuracy:83.60%, Validation loss:0.738, Validation accuracy:77.00%
# Epoch 132: iteration 16/17
# Epoch 132 --- loss:0.502, Epoch accuracy:85.70%, Validation loss:0.738, Validation accuracy:77.00%
# Epoch 133: iteration 16/17
# Epoch 133 --- loss:0.507, Epoch accuracy:84.39%, Validation loss:0.738, Validation accuracy:77.33%
# Epoch 134: iteration 16/17
# Epoch 134 --- loss:0.506, Epoch accuracy:83.86%, Validation loss:0.737, Validation accuracy:77.33%
# Epoch 135: iteration 16/17
# Epoch 135 --- loss:0.489, Epoch accuracy:85.96%, Validation loss:0.737, Validation accuracy:76.67%
# Epoch 136: iteration 16/17
# Epoch 136 --- loss:0.496, Epoch accuracy:84.74%, Validation loss:0.737, Validation accuracy:76.67%
# Epoch 137: iteration 16/17
# Epoch 137 --- loss:0.499, Epoch accuracy:85.09%, Validation loss:0.737, Validation accuracy:76.33%
# Epoch 138: iteration 16/17
# Epoch 138 --- loss:0.497, Epoch accuracy:84.74%, Validation loss:0.737, Validation accuracy:76.33%
# Epoch 139: iteration 16/17
# Epoch 139 --- loss:0.501, Epoch accuracy:85.53%, Validation loss:0.737, Validation accuracy:76.33%
# Epoch 140: iteration 16/17
# Epoch 140 --- loss:0.488, Epoch accuracy:84.91%, Validation loss:0.737, Validation accuracy:76.33%
# Epoch 141: iteration 16/17
# Epoch 141 --- loss:0.483, Epoch accuracy:85.26%, Validation loss:0.737, Validation accuracy:76.33%
# Epoch 142: iteration 16/17
# Epoch 142 --- loss:0.483, Epoch accuracy:85.44%, Validation loss:0.736, Validation accuracy:76.33%
# Epoch 143: iteration 16/17
# Epoch 143 --- loss:0.479, Epoch accuracy:85.96%, Validation loss:0.736, Validation accuracy:76.33%
# Epoch 144: iteration 16/17
# Epoch 144 --- loss:0.480, Epoch accuracy:85.53%, Validation loss:0.736, Validation accuracy:76.33%
# Epoch 145: iteration 16/17
# Epoch 145 --- loss:0.478, Epoch accuracy:85.70%, Validation loss:0.736, Validation accuracy:76.33%
# Epoch 146: iteration 16/17
# Epoch 146 --- loss:0.472, Epoch accuracy:86.40%, Validation loss:0.735, Validation accuracy:76.33%
# Epoch 147: iteration 16/17
# Epoch 147 --- loss:0.466, Epoch accuracy:86.75%, Validation loss:0.735, Validation accuracy:76.33%
# Epoch 148: iteration 16/17
# Epoch 148 --- loss:0.475, Epoch accuracy:85.70%, Validation loss:0.735, Validation accuracy:76.33%
# Epoch 149: iteration 16/17
# Epoch 149 --- loss:0.469, Epoch accuracy:86.14%, Validation loss:0.735, Validation accuracy:76.33%
#
#
# [*] done !
# [*] Best training loss - 0.4658130863256621
# [*] Best validation loss - 0.7349607944488525
# 3:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:0.560, Epoch accuracy:80.79%, Validation loss:0.363, Validation accuracy:96.33%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:0.550, Epoch accuracy:80.61%, Validation loss:0.362, Validation accuracy:96.33%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:0.552, Epoch accuracy:80.96%, Validation loss:0.363, Validation accuracy:96.00%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:0.554, Epoch accuracy:80.96%, Validation loss:0.363, Validation accuracy:96.00%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:0.547, Epoch accuracy:80.88%, Validation loss:0.363, Validation accuracy:96.00%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:0.552, Epoch accuracy:81.32%, Validation loss:0.363, Validation accuracy:96.00%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:0.543, Epoch accuracy:82.02%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:0.531, Epoch accuracy:82.28%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:0.537, Epoch accuracy:82.63%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:0.532, Epoch accuracy:80.35%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:0.540, Epoch accuracy:80.70%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:0.518, Epoch accuracy:82.11%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:0.523, Epoch accuracy:82.89%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:0.537, Epoch accuracy:82.19%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:0.518, Epoch accuracy:82.46%, Validation loss:0.364, Validation accuracy:95.67%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:0.511, Epoch accuracy:83.60%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:0.509, Epoch accuracy:83.95%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:0.511, Epoch accuracy:82.81%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:0.523, Epoch accuracy:81.75%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:0.507, Epoch accuracy:83.16%, Validation loss:0.364, Validation accuracy:95.33%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:0.507, Epoch accuracy:83.42%, Validation loss:0.363, Validation accuracy:95.67%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:0.498, Epoch accuracy:83.51%, Validation loss:0.363, Validation accuracy:95.33%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:0.507, Epoch accuracy:84.04%, Validation loss:0.364, Validation accuracy:95.33%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:0.492, Epoch accuracy:84.39%, Validation loss:0.363, Validation accuracy:95.33%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:0.486, Epoch accuracy:83.77%, Validation loss:0.363, Validation accuracy:95.33%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:0.483, Epoch accuracy:84.65%, Validation loss:0.363, Validation accuracy:95.33%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:0.489, Epoch accuracy:83.42%, Validation loss:0.362, Validation accuracy:95.33%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:0.486, Epoch accuracy:84.04%, Validation loss:0.362, Validation accuracy:95.00%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:0.483, Epoch accuracy:83.60%, Validation loss:0.362, Validation accuracy:95.00%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:0.489, Epoch accuracy:83.33%, Validation loss:0.362, Validation accuracy:95.00%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:0.479, Epoch accuracy:84.39%, Validation loss:0.363, Validation accuracy:95.00%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:0.488, Epoch accuracy:84.39%, Validation loss:0.362, Validation accuracy:95.00%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:0.457, Epoch accuracy:85.53%, Validation loss:0.362, Validation accuracy:95.00%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:0.481, Epoch accuracy:83.33%, Validation loss:0.362, Validation accuracy:95.00%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:0.475, Epoch accuracy:84.91%, Validation loss:0.362, Validation accuracy:95.00%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:0.460, Epoch accuracy:85.26%, Validation loss:0.361, Validation accuracy:95.00%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:0.470, Epoch accuracy:84.82%, Validation loss:0.361, Validation accuracy:95.00%
#
#
# [*] done !
# [*] Best training loss - 0.4574345521759569
# [*] Best validation loss - 0.36124011874198914
# 4:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 17/18
# Epoch 0 --- loss:0.467, Epoch accuracy:85.67%, Validation loss:0.333, Validation accuracy:97.08%
# Epoch 1: iteration 17/18
# Epoch 1 --- loss:0.485, Epoch accuracy:84.00%, Validation loss:0.333, Validation accuracy:97.08%
# Epoch 2: iteration 17/18
# Epoch 2 --- loss:0.472, Epoch accuracy:85.75%, Validation loss:0.333, Validation accuracy:97.08%
# Epoch 3: iteration 17/18
# Epoch 3 --- loss:0.460, Epoch accuracy:85.92%, Validation loss:0.334, Validation accuracy:96.67%
# Epoch 4: iteration 17/18
# Epoch 4 --- loss:0.460, Epoch accuracy:85.17%, Validation loss:0.334, Validation accuracy:96.67%
# Epoch 5: iteration 17/18
# Epoch 5 --- loss:0.457, Epoch accuracy:86.33%, Validation loss:0.334, Validation accuracy:96.67%
# Epoch 6: iteration 17/18
# Epoch 6 --- loss:0.458, Epoch accuracy:85.58%, Validation loss:0.335, Validation accuracy:96.25%
# Epoch 7: iteration 17/18
# Epoch 7 --- loss:0.457, Epoch accuracy:86.00%, Validation loss:0.335, Validation accuracy:96.25%
# Epoch 8: iteration 17/18
# Epoch 8 --- loss:0.456, Epoch accuracy:86.00%, Validation loss:0.335, Validation accuracy:96.25%
# Epoch 9: iteration 17/18
# Epoch 9 --- loss:0.442, Epoch accuracy:86.92%, Validation loss:0.335, Validation accuracy:95.83%
# Epoch 10: iteration 17/18
# Epoch 10 --- loss:0.440, Epoch accuracy:86.58%, Validation loss:0.335, Validation accuracy:95.42%
# Epoch 11: iteration 17/18
# Epoch 11 --- loss:0.436, Epoch accuracy:86.58%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 12: iteration 17/18
# Epoch 12 --- loss:0.436, Epoch accuracy:86.42%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 13: iteration 17/18
# Epoch 13 --- loss:0.448, Epoch accuracy:86.58%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 14: iteration 17/18
# Epoch 14 --- loss:0.444, Epoch accuracy:86.58%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 15: iteration 17/18
# Epoch 15 --- loss:0.426, Epoch accuracy:87.92%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 16: iteration 17/18
# Epoch 16 --- loss:0.429, Epoch accuracy:87.08%, Validation loss:0.337, Validation accuracy:95.00%
# Epoch 17: iteration 17/18
# Epoch 17 --- loss:0.424, Epoch accuracy:88.50%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 18: iteration 17/18
# Epoch 18 --- loss:0.420, Epoch accuracy:86.92%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 19: iteration 17/18
# Epoch 19 --- loss:0.418, Epoch accuracy:86.75%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 20: iteration 17/18
# Epoch 20 --- loss:0.413, Epoch accuracy:88.42%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 21: iteration 17/18
# Epoch 21 --- loss:0.421, Epoch accuracy:88.33%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 22: iteration 17/18
# Epoch 22 --- loss:0.426, Epoch accuracy:86.58%, Validation loss:0.336, Validation accuracy:95.00%
# Epoch 23: iteration 17/18
# Epoch 23 --- loss:0.412, Epoch accuracy:87.58%, Validation loss:0.336, Validation accuracy:94.58%
# Epoch 24: iteration 17/18
# Epoch 24 --- loss:0.416, Epoch accuracy:87.83%, Validation loss:0.336, Validation accuracy:94.58%
# Epoch 25: iteration 17/18
# Epoch 25 --- loss:0.399, Epoch accuracy:88.08%, Validation loss:0.336, Validation accuracy:94.17%
# Epoch 26: iteration 17/18
# Epoch 26 --- loss:0.410, Epoch accuracy:88.25%, Validation loss:0.336, Validation accuracy:94.17%
# Epoch 27: iteration 17/18
# Epoch 27 --- loss:0.413, Epoch accuracy:87.33%, Validation loss:0.336, Validation accuracy:94.17%
# Epoch 28: iteration 17/18
# Epoch 28 --- loss:0.398, Epoch accuracy:88.50%, Validation loss:0.336, Validation accuracy:94.17%
# Epoch 29: iteration 17/18
# Epoch 29 --- loss:0.403, Epoch accuracy:87.67%, Validation loss:0.336, Validation accuracy:94.17%
# Epoch 30: iteration 17/18
# Epoch 30 --- loss:0.392, Epoch accuracy:88.58%, Validation loss:0.336, Validation accuracy:94.17%
# Epoch 31: iteration 17/18
# Epoch 31 --- loss:0.386, Epoch accuracy:88.17%, Validation loss:0.335, Validation accuracy:94.17%
#
#
# [*] done !
# [*] Best training loss - 0.3858740822474162
# [*] Best validation loss - 0.3327825665473938

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
# Out:
# [*] 0 Test accuracy is 46.33%
# [*] 1 Test accuracy is 59.33%
# [*] 2 Test accuracy is 76.33%
# [*] 3 Test accuracy is 95.00%
# [*] 4 Test accuracy is 97.08%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 97.08%
# [*] Worst fold acc : 46.33%
# [*] Average fold acc : 74.82%
