# %% [markdown]
# # Model summary
# <hr>
#
# ### ResLFLB + ResNet18

# %%
from cv2 import transform
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
from einops import rearrange
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %% [markdown]
# ## LFLB (N Filter)
#
# Speech emotion recognition using deep 1d & 2d cnn lstm networks. Biomedical Signal Processing and Control 47, 312–323 (2019)

# %%
class LFLB(nn.Module):
    """Some Information about LFLB"""
    def __init__(self, in_chan, out_chan, kernel=[2, 2], stride=[1, 1], pad=1):
        super(LFLB, self).__init__()

        self.cnn = nn.Conv2d(in_channels=in_chan, out_channels=out_chan, kernel_size=kernel, stride=stride, padding=pad)
        self.bn = nn.BatchNorm2d(out_chan)
        self.relu = nn.ReLU()
        self.max_pool =  nn.MaxPool2d(kernel_size=kernel, stride=[2, 2])

    def forward(self, x):
        cnn_embd = self.cnn(x)
        cnn_embd = self.bn(cnn_embd)
        cnn_embd = self.relu(cnn_embd)
        output = self.max_pool(cnn_embd)

        return output

# %% [markdown]
# ## NAC Unit
#
# [1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun, Identity Mappings in Deep Residual Networks. arXiv:1603.05027
# https://github.com/kuangliu/pytorch-cifar/blob/master/models/preact_resnet.py

# %%
class NACUnit(nn.Module):
    '''Pre-activation version of the BasicBlock.'''
    expansion = 1

    def __init__(self, in_planes, planes, kernel, stride=1, pad=0):
        super(NACUnit, self).__init__()
        
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=kernel, stride=stride, padding=pad, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=kernel, stride=1, padding=1, bias=False)

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        return out

# %%
class ResLFLB(nn.Module):
    def __init__(self, in_chan, n_filters, kernel):
        super(ResLFLB, self).__init__()
        
        self.lflb = LFLB(in_chan=in_chan, out_chan=n_filters)
        
        self.nac_unit1 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1, pad=1)
        self.nac_unit2 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit3 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit4 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit5 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1)

    def forward(self, x):
        lflb_embd = self.lflb(x)
        
        nac_embd = self.nac_unit1(lflb_embd)
        nac_embd = self.nac_unit2(nac_embd)
        nac_embd = self.nac_unit3(nac_embd)
        nac_embd = self.nac_unit4(nac_embd)
        nac_embd = self.nac_unit5(nac_embd)
        
        output = lflb_embd + nac_embd

        return output

# %%
from torchvision.models import ResNet18_Weights

class resnet18_finetune(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        
        self.model_ft = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        self.model_ft = nn.Sequential(*(list(self.model_ft.children())[:-1]))
        
        for name, param in self.model_ft[:5].named_parameters():
            param.requires_grad=False
    
    def forward(self, x):
        embd = self.model_ft(x)
        output = torch.flatten(embd, start_dim=1)
        
        return output

# %%
class SpatialModel(nn.Module):
    def __init__(self):
        super(SpatialModel, self).__init__()

        self.resnet = resnet18_finetune()

        self.MFL = LFLB(3, 32)
        
        self.res_lflb1 = ResLFLB(32, 32, [3, 3])
        self.res_lflb2 = ResLFLB(32, 32, [3, 3])
        self.res_lflb3 = ResLFLB(32, 32, [3, 3])
        self.res_lflb4 = ResLFLB(32, 64, [3, 3])
        self.res_lflb5 = ResLFLB(64, 128, [3, 3])
        
        self.relu = nn.ReLU()
        self.max_pool = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2])
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        res_embd = self.resnet(x)
        
        MFL_embd = self.MFL(x)
        
        res_lflb_embd = self.res_lflb1(MFL_embd)
        res_lflb_embd = self.res_lflb2(res_lflb_embd)
        res_lflb_embd = self.res_lflb3(res_lflb_embd)
        res_lflb_embd = self.res_lflb4(res_lflb_embd)
        res_lflb_embd = self.res_lflb5(res_lflb_embd)
        
        mlp = self.relu(res_lflb_embd)
        mlp = self.max_pool(mlp)
        mlp = self.dropout(mlp)
        mlp = torch.flatten(mlp, start_dim=1)
        
        output = mlp + res_embd
        
        return output

# %%
class TimeseriesModel(nn.Module):
    """Some Information about nna"""
    def __init__(self):
        super(TimeseriesModel, self).__init__()

        self.spatial = SpatialModel()

    def forward(self, x):
        spatial_embd = self.spatial(x)
        
        return spatial_embd

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()
        
        self.timeseries = TimeseriesModel()
        
        self.linear = nn.Linear(512, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        timeseries_embd = self.timeseries(x)
        
        output_logits = self.linear(timeseries_embd)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'ResLFLB-ResNet18'
data_name = 'RAVDESS'

minibatch = 32
num_epochs = 200
EARLY_CNT = 500

learning_rate = 1e-5

# model = Model(len(emotions_dict))
# print(summary(model, (1, 3, 224, 224)))

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'fold-{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = '5-CV'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - ResLFLB-ResNet18
# A Jupyter Widget
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:2.935, Epoch accuracy:12.98%, Validation loss:2.078, Validation accuracy:17.33%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:2.492, Epoch accuracy:17.46%, Validation loss:1.892, Validation accuracy:28.67%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:2.164, Epoch accuracy:24.91%, Validation loss:1.759, Validation accuracy:37.67%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:1.952, Epoch accuracy:28.33%, Validation loss:1.645, Validation accuracy:44.67%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:1.789, Epoch accuracy:34.56%, Validation loss:1.553, Validation accuracy:46.67%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:1.608, Epoch accuracy:40.53%, Validation loss:1.478, Validation accuracy:49.33%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:1.486, Epoch accuracy:47.02%, Validation loss:1.416, Validation accuracy:53.33%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:1.259, Epoch accuracy:52.63%, Validation loss:1.364, Validation accuracy:54.67%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:1.173, Epoch accuracy:57.63%, Validation loss:1.330, Validation accuracy:55.67%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:1.135, Epoch accuracy:57.11%, Validation loss:1.284, Validation accuracy:56.33%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:1.018, Epoch accuracy:62.81%, Validation loss:1.274, Validation accuracy:56.67%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:0.889, Epoch accuracy:67.11%, Validation loss:1.240, Validation accuracy:57.33%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:0.776, Epoch accuracy:72.11%, Validation loss:1.216, Validation accuracy:57.67%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:0.727, Epoch accuracy:72.11%, Validation loss:1.204, Validation accuracy:58.33%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:0.612, Epoch accuracy:78.95%, Validation loss:1.187, Validation accuracy:57.33%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:0.567, Epoch accuracy:80.53%, Validation loss:1.179, Validation accuracy:57.00%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:0.521, Epoch accuracy:81.67%, Validation loss:1.172, Validation accuracy:58.67%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:0.440, Epoch accuracy:86.58%, Validation loss:1.154, Validation accuracy:58.67%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:0.375, Epoch accuracy:88.33%, Validation loss:1.181, Validation accuracy:57.33%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:0.319, Epoch accuracy:90.26%, Validation loss:1.166, Validation accuracy:58.33%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:0.295, Epoch accuracy:92.02%, Validation loss:1.158, Validation accuracy:56.67%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:0.271, Epoch accuracy:92.46%, Validation loss:1.167, Validation accuracy:57.00%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:0.256, Epoch accuracy:93.68%, Validation loss:1.150, Validation accuracy:57.00%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:0.213, Epoch accuracy:94.74%, Validation loss:1.127, Validation accuracy:58.67%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:0.201, Epoch accuracy:94.04%, Validation loss:1.157, Validation accuracy:57.00%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:0.164, Epoch accuracy:95.35%, Validation loss:1.163, Validation accuracy:58.67%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:0.166, Epoch accuracy:95.79%, Validation loss:1.161, Validation accuracy:58.33%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:0.132, Epoch accuracy:96.67%, Validation loss:1.145, Validation accuracy:57.33%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:0.132, Epoch accuracy:96.58%, Validation loss:1.163, Validation accuracy:57.33%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:0.117, Epoch accuracy:97.11%, Validation loss:1.157, Validation accuracy:56.33%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:0.102, Epoch accuracy:96.93%, Validation loss:1.155, Validation accuracy:58.33%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:0.106, Epoch accuracy:96.93%, Validation loss:1.168, Validation accuracy:57.33%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:0.083, Epoch accuracy:97.63%, Validation loss:1.147, Validation accuracy:57.00%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:0.081, Epoch accuracy:97.37%, Validation loss:1.150, Validation accuracy:59.67%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:0.070, Epoch accuracy:97.63%, Validation loss:1.173, Validation accuracy:58.33%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:0.069, Epoch accuracy:97.81%, Validation loss:1.177, Validation accuracy:57.00%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:0.067, Epoch accuracy:97.81%, Validation loss:1.150, Validation accuracy:58.33%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:0.066, Epoch accuracy:97.89%, Validation loss:1.155, Validation accuracy:58.00%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:0.058, Epoch accuracy:97.72%, Validation loss:1.151, Validation accuracy:56.33%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:0.057, Epoch accuracy:97.89%, Validation loss:1.165, Validation accuracy:56.00%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:0.053, Epoch accuracy:97.81%, Validation loss:1.174, Validation accuracy:56.67%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:0.049, Epoch accuracy:97.89%, Validation loss:1.175, Validation accuracy:57.00%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:0.050, Epoch accuracy:98.16%, Validation loss:1.175, Validation accuracy:55.67%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:0.044, Epoch accuracy:98.07%, Validation loss:1.176, Validation accuracy:56.67%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:0.049, Epoch accuracy:97.98%, Validation loss:1.207, Validation accuracy:56.67%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:0.043, Epoch accuracy:98.07%, Validation loss:1.150, Validation accuracy:57.67%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:0.040, Epoch accuracy:98.07%, Validation loss:1.162, Validation accuracy:58.00%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:0.045, Epoch accuracy:97.81%, Validation loss:1.193, Validation accuracy:56.67%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:0.039, Epoch accuracy:98.16%, Validation loss:1.184, Validation accuracy:58.33%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:0.040, Epoch accuracy:97.89%, Validation loss:1.202, Validation accuracy:56.67%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:0.035, Epoch accuracy:98.16%, Validation loss:1.171, Validation accuracy:57.00%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:0.040, Epoch accuracy:98.07%, Validation loss:1.198, Validation accuracy:56.00%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:0.032, Epoch accuracy:97.98%, Validation loss:1.209, Validation accuracy:57.33%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:0.030, Epoch accuracy:98.07%, Validation loss:1.186, Validation accuracy:57.33%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:0.024, Epoch accuracy:98.25%, Validation loss:1.193, Validation accuracy:58.00%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:0.031, Epoch accuracy:97.98%, Validation loss:1.196, Validation accuracy:58.00%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:0.028, Epoch accuracy:98.25%, Validation loss:1.178, Validation accuracy:56.33%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:0.027, Epoch accuracy:98.07%, Validation loss:1.198, Validation accuracy:57.67%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:0.029, Epoch accuracy:97.98%, Validation loss:1.185, Validation accuracy:56.00%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:0.027, Epoch accuracy:98.07%, Validation loss:1.169, Validation accuracy:56.33%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:0.029, Epoch accuracy:98.16%, Validation loss:1.198, Validation accuracy:58.00%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:0.027, Epoch accuracy:98.16%, Validation loss:1.155, Validation accuracy:59.67%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:0.024, Epoch accuracy:97.98%, Validation loss:1.188, Validation accuracy:57.00%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:0.026, Epoch accuracy:98.16%, Validation loss:1.181, Validation accuracy:59.00%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:0.023, Epoch accuracy:98.16%, Validation loss:1.172, Validation accuracy:57.67%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:0.022, Epoch accuracy:98.16%, Validation loss:1.185, Validation accuracy:59.33%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:0.020, Epoch accuracy:98.25%, Validation loss:1.180, Validation accuracy:57.00%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:0.021, Epoch accuracy:98.25%, Validation loss:1.173, Validation accuracy:60.00%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:0.018, Epoch accuracy:98.25%, Validation loss:1.200, Validation accuracy:56.33%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:0.022, Epoch accuracy:98.25%, Validation loss:1.172, Validation accuracy:59.67%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:0.020, Epoch accuracy:98.16%, Validation loss:1.192, Validation accuracy:58.67%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:0.017, Epoch accuracy:98.25%, Validation loss:1.198, Validation accuracy:57.33%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:0.022, Epoch accuracy:98.16%, Validation loss:1.224, Validation accuracy:58.00%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:0.019, Epoch accuracy:98.25%, Validation loss:1.185, Validation accuracy:58.67%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:0.016, Epoch accuracy:98.25%, Validation loss:1.201, Validation accuracy:57.67%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:0.018, Epoch accuracy:98.25%, Validation loss:1.172, Validation accuracy:60.67%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:0.016, Epoch accuracy:98.25%, Validation loss:1.192, Validation accuracy:58.67%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:0.017, Epoch accuracy:98.25%, Validation loss:1.215, Validation accuracy:58.67%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:0.016, Epoch accuracy:98.25%, Validation loss:1.183, Validation accuracy:58.00%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:0.014, Epoch accuracy:98.25%, Validation loss:1.215, Validation accuracy:59.00%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:0.017, Epoch accuracy:98.25%, Validation loss:1.186, Validation accuracy:59.00%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:0.018, Epoch accuracy:98.16%, Validation loss:1.216, Validation accuracy:58.67%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:0.015, Epoch accuracy:98.25%, Validation loss:1.204, Validation accuracy:57.00%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.193, Validation accuracy:58.33%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:0.017, Epoch accuracy:98.25%, Validation loss:1.198, Validation accuracy:57.67%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:0.014, Epoch accuracy:98.25%, Validation loss:1.203, Validation accuracy:57.67%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:0.016, Epoch accuracy:98.25%, Validation loss:1.185, Validation accuracy:59.33%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:0.015, Epoch accuracy:98.25%, Validation loss:1.198, Validation accuracy:57.67%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.193, Validation accuracy:59.33%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.192, Validation accuracy:58.00%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:0.015, Epoch accuracy:98.25%, Validation loss:1.212, Validation accuracy:59.67%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.202, Validation accuracy:57.33%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:0.012, Epoch accuracy:98.25%, Validation loss:1.209, Validation accuracy:57.67%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.222, Validation accuracy:57.33%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:0.013, Epoch accuracy:98.16%, Validation loss:1.216, Validation accuracy:58.00%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.223, Validation accuracy:57.00%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.245, Validation accuracy:57.00%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.227, Validation accuracy:57.33%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:0.014, Epoch accuracy:98.25%, Validation loss:1.231, Validation accuracy:58.67%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:0.013, Epoch accuracy:98.16%, Validation loss:1.226, Validation accuracy:58.00%
# Epoch 100: iteration 34/35
# Epoch 100 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.238, Validation accuracy:58.67%
# Epoch 101: iteration 34/35
# Epoch 101 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.221, Validation accuracy:60.33%
# Epoch 102: iteration 34/35
# Epoch 102 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.234, Validation accuracy:59.00%
# Epoch 103: iteration 34/35
# Epoch 103 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.190, Validation accuracy:59.67%
# Epoch 104: iteration 34/35
# Epoch 104 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.213, Validation accuracy:60.33%
# Epoch 105: iteration 34/35
# Epoch 105 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.252, Validation accuracy:58.67%
# Epoch 106: iteration 34/35
# Epoch 106 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.229, Validation accuracy:59.33%
# Epoch 107: iteration 34/35
# Epoch 107 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.238, Validation accuracy:57.67%
# Epoch 108: iteration 34/35
# Epoch 108 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.206, Validation accuracy:60.67%
# Epoch 109: iteration 34/35
# Epoch 109 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.210, Validation accuracy:58.67%
# Epoch 110: iteration 34/35
# Epoch 110 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.216, Validation accuracy:60.67%
# Epoch 111: iteration 34/35
# Epoch 111 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.242, Validation accuracy:59.00%
# Epoch 112: iteration 34/35
# Epoch 112 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.222, Validation accuracy:58.33%
# Epoch 113: iteration 34/35
# Epoch 113 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.245, Validation accuracy:57.67%
# Epoch 114: iteration 34/35
# Epoch 114 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.211, Validation accuracy:58.00%
# Epoch 115: iteration 34/35
# Epoch 115 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.205, Validation accuracy:61.67%
# Epoch 116: iteration 34/35
# Epoch 116 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.253, Validation accuracy:59.00%
# Epoch 117: iteration 34/35
# Epoch 117 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.219, Validation accuracy:58.00%
# Epoch 118: iteration 34/35
# Epoch 118 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.239, Validation accuracy:58.67%
# Epoch 119: iteration 34/35
# Epoch 119 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.251, Validation accuracy:57.67%
# Epoch 120: iteration 34/35
# Epoch 120 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.237, Validation accuracy:57.00%
# Epoch 121: iteration 34/35
# Epoch 121 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.243, Validation accuracy:57.00%
# Epoch 122: iteration 34/35
# Epoch 122 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.216, Validation accuracy:57.67%
# Epoch 123: iteration 34/35
# Epoch 123 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.225, Validation accuracy:59.67%
# Epoch 124: iteration 34/35
# Epoch 124 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.229, Validation accuracy:59.00%
# Epoch 125: iteration 34/35
# Epoch 125 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.256, Validation accuracy:57.67%
# Epoch 126: iteration 34/35
# Epoch 126 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.219, Validation accuracy:59.67%
# Epoch 127: iteration 34/35
# Epoch 127 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.203, Validation accuracy:60.00%
# Epoch 128: iteration 34/35
# Epoch 128 --- loss:0.009, Epoch accuracy:98.16%, Validation loss:1.219, Validation accuracy:57.33%
# Epoch 129: iteration 34/35
# Epoch 129 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.224, Validation accuracy:59.33%
# Epoch 130: iteration 34/35
# Epoch 130 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.207, Validation accuracy:60.00%
# Epoch 131: iteration 34/35
# Epoch 131 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.203, Validation accuracy:60.00%
# Epoch 132: iteration 34/35
# Epoch 132 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.210, Validation accuracy:59.33%
# Epoch 133: iteration 34/35
# Epoch 133 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.233, Validation accuracy:59.00%
# Epoch 134: iteration 34/35
# Epoch 134 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.195, Validation accuracy:58.33%
# Epoch 135: iteration 34/35
# Epoch 135 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.217, Validation accuracy:58.00%
# Epoch 136: iteration 34/35
# Epoch 136 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.256, Validation accuracy:59.00%
# Epoch 137: iteration 34/35
# Epoch 137 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.245, Validation accuracy:58.33%
# Epoch 138: iteration 34/35
# Epoch 138 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.244, Validation accuracy:58.67%
# Epoch 139: iteration 34/35
# Epoch 139 --- loss:0.013, Epoch accuracy:98.16%, Validation loss:1.230, Validation accuracy:57.67%
# Epoch 140: iteration 34/35
# Epoch 140 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.249, Validation accuracy:57.33%
# Epoch 141: iteration 34/35
# Epoch 141 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.251, Validation accuracy:58.67%
# Epoch 142: iteration 34/35
# Epoch 142 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.262, Validation accuracy:56.00%
# Epoch 143: iteration 34/35
# Epoch 143 --- loss:0.009, Epoch accuracy:98.16%, Validation loss:1.247, Validation accuracy:57.33%
# Epoch 144: iteration 34/35
# Epoch 144 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.223, Validation accuracy:59.33%
# Epoch 145: iteration 34/35
# Epoch 145 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.230, Validation accuracy:59.67%
# Epoch 146: iteration 34/35
# Epoch 146 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.248, Validation accuracy:58.67%
# Epoch 147: iteration 34/35
# Epoch 147 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.250, Validation accuracy:58.33%
# Epoch 148: iteration 34/35
# Epoch 148 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.264, Validation accuracy:57.33%
# Epoch 149: iteration 34/35
# Epoch 149 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.220, Validation accuracy:59.00%
# Epoch 150: iteration 34/35
# Epoch 150 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.253, Validation accuracy:58.67%
# Epoch 151: iteration 34/35
# Epoch 151 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.237, Validation accuracy:58.33%
# Epoch 152: iteration 34/35
# Epoch 152 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.242, Validation accuracy:59.67%
# Epoch 153: iteration 34/35
# Epoch 153 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.251, Validation accuracy:58.33%
# Epoch 154: iteration 34/35
# Epoch 154 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.232, Validation accuracy:60.67%
# Epoch 155: iteration 34/35
# Epoch 155 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.237, Validation accuracy:58.67%
# Epoch 156: iteration 34/35
# Epoch 156 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.210, Validation accuracy:60.67%
# Epoch 157: iteration 34/35
# Epoch 157 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.208, Validation accuracy:61.00%
# Epoch 158: iteration 34/35
# Epoch 158 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.232, Validation accuracy:59.33%
# Epoch 159: iteration 34/35
# Epoch 159 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.229, Validation accuracy:60.00%
# Epoch 160: iteration 34/35
# Epoch 160 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.278, Validation accuracy:57.00%
# Epoch 161: iteration 34/35
# Epoch 161 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.265, Validation accuracy:60.00%
# Epoch 162: iteration 34/35
# Epoch 162 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.228, Validation accuracy:58.33%
# Epoch 163: iteration 34/35
# Epoch 163 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.230, Validation accuracy:61.00%
# Epoch 164: iteration 34/35
# Epoch 164 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.227, Validation accuracy:59.33%
# Epoch 165: iteration 34/35
# Epoch 165 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.268, Validation accuracy:57.00%
# Epoch 166: iteration 34/35
# Epoch 166 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.213, Validation accuracy:58.67%
# Epoch 167: iteration 34/35
# Epoch 167 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.222, Validation accuracy:58.00%
# Epoch 168: iteration 34/35
# Epoch 168 --- loss:0.007, Epoch accuracy:98.16%, Validation loss:1.224, Validation accuracy:58.33%
# Epoch 169: iteration 34/35
# Epoch 169 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.232, Validation accuracy:58.33%
# Epoch 170: iteration 34/35
# Epoch 170 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.222, Validation accuracy:58.67%
# Epoch 171: iteration 34/35
# Epoch 171 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.220, Validation accuracy:59.33%
# Epoch 172: iteration 34/35
# Epoch 172 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.224, Validation accuracy:59.67%
# Epoch 173: iteration 34/35
# Epoch 173 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.243, Validation accuracy:58.33%
# Epoch 174: iteration 34/35
# Epoch 174 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.232, Validation accuracy:58.67%
# Epoch 175: iteration 34/35
# Epoch 175 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.257, Validation accuracy:58.67%
# Epoch 176: iteration 34/35
# Epoch 176 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.222, Validation accuracy:61.00%
# Epoch 177: iteration 34/35
# Epoch 177 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.228, Validation accuracy:60.67%
# Epoch 178: iteration 34/35
# Epoch 178 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.234, Validation accuracy:59.33%
# Epoch 179: iteration 34/35
# Epoch 179 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.218, Validation accuracy:60.00%
# Epoch 180: iteration 34/35
# Epoch 180 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.226, Validation accuracy:59.67%
# Epoch 181: iteration 34/35
# Epoch 181 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.248, Validation accuracy:57.67%
# Epoch 182: iteration 34/35
# Epoch 182 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.235, Validation accuracy:60.00%
# Epoch 183: iteration 34/35
# Epoch 183 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.203, Validation accuracy:60.00%
# Epoch 184: iteration 34/35
# Epoch 184 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.247, Validation accuracy:59.33%
# Epoch 185: iteration 34/35
# Epoch 185 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.227, Validation accuracy:59.67%
# Epoch 186: iteration 34/35
# Epoch 186 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.229, Validation accuracy:59.00%
# Epoch 187: iteration 34/35
# Epoch 187 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.229, Validation accuracy:60.00%
# Epoch 188: iteration 34/35
# Epoch 188 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.265, Validation accuracy:59.33%
# Epoch 189: iteration 34/35
# Epoch 189 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.251, Validation accuracy:59.00%
# Epoch 190: iteration 34/35
# Epoch 190 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.242, Validation accuracy:58.00%
# Epoch 191: iteration 34/35
# Epoch 191 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.234, Validation accuracy:59.00%
# Epoch 192: iteration 34/35
# Epoch 192 --- loss:0.004, Epoch accuracy:98.25%, Validation loss:1.244, Validation accuracy:59.33%
# Epoch 193: iteration 34/35
# Epoch 193 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.259, Validation accuracy:59.00%
# Epoch 194: iteration 34/35
# Epoch 194 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.280, Validation accuracy:58.67%
# Epoch 195: iteration 34/35
# Epoch 195 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.271, Validation accuracy:58.67%
# Epoch 196: iteration 34/35
# Epoch 196 --- loss:0.004, Epoch accuracy:98.25%, Validation loss:1.279, Validation accuracy:58.33%
# Epoch 197: iteration 34/35
# Epoch 197 --- loss:0.004, Epoch accuracy:98.25%, Validation loss:1.250, Validation accuracy:59.67%
# Epoch 198: iteration 34/35
# Epoch 198 --- loss:0.004, Epoch accuracy:98.25%, Validation loss:1.271, Validation accuracy:59.33%
# Epoch 199: iteration 34/35
# Epoch 199 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.244, Validation accuracy:58.67%
#
#
# [*] done !
# [*] Best training loss - 0.004032113488044654
# [*] Best validation loss - 1.1272079944610596
# A Jupyter Widget
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:3.170, Epoch accuracy:14.91%, Validation loss:2.203, Validation accuracy:21.67%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:2.637, Epoch accuracy:20.44%, Validation loss:2.104, Validation accuracy:25.67%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:2.196, Epoch accuracy:24.39%, Validation loss:1.843, Validation accuracy:31.00%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:1.881, Epoch accuracy:32.63%, Validation loss:1.643, Validation accuracy:41.00%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:1.621, Epoch accuracy:39.21%, Validation loss:1.542, Validation accuracy:43.00%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:1.479, Epoch accuracy:44.82%, Validation loss:1.456, Validation accuracy:43.00%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:1.369, Epoch accuracy:50.00%, Validation loss:1.427, Validation accuracy:46.00%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:1.218, Epoch accuracy:56.84%, Validation loss:1.381, Validation accuracy:48.67%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:1.091, Epoch accuracy:59.39%, Validation loss:1.379, Validation accuracy:47.67%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:0.960, Epoch accuracy:65.53%, Validation loss:1.346, Validation accuracy:52.33%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:0.871, Epoch accuracy:70.00%, Validation loss:1.328, Validation accuracy:52.67%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:0.785, Epoch accuracy:71.58%, Validation loss:1.310, Validation accuracy:49.33%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:0.683, Epoch accuracy:75.44%, Validation loss:1.316, Validation accuracy:54.00%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:0.600, Epoch accuracy:80.18%, Validation loss:1.316, Validation accuracy:53.33%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:0.527, Epoch accuracy:82.72%, Validation loss:1.320, Validation accuracy:54.33%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:0.475, Epoch accuracy:84.56%, Validation loss:1.295, Validation accuracy:55.00%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:0.405, Epoch accuracy:87.37%, Validation loss:1.322, Validation accuracy:51.67%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:0.370, Epoch accuracy:88.33%, Validation loss:1.311, Validation accuracy:55.00%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:0.315, Epoch accuracy:91.93%, Validation loss:1.314, Validation accuracy:53.00%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:0.312, Epoch accuracy:90.09%, Validation loss:1.313, Validation accuracy:51.67%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:0.266, Epoch accuracy:92.81%, Validation loss:1.325, Validation accuracy:53.67%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:0.236, Epoch accuracy:93.95%, Validation loss:1.350, Validation accuracy:51.67%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:0.205, Epoch accuracy:94.56%, Validation loss:1.322, Validation accuracy:54.33%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:0.174, Epoch accuracy:95.09%, Validation loss:1.342, Validation accuracy:52.33%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:0.156, Epoch accuracy:96.32%, Validation loss:1.329, Validation accuracy:54.00%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:0.146, Epoch accuracy:96.14%, Validation loss:1.353, Validation accuracy:53.67%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:0.127, Epoch accuracy:97.11%, Validation loss:1.362, Validation accuracy:53.33%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:0.123, Epoch accuracy:97.11%, Validation loss:1.357, Validation accuracy:54.67%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:0.112, Epoch accuracy:97.19%, Validation loss:1.375, Validation accuracy:53.00%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:0.102, Epoch accuracy:97.37%, Validation loss:1.389, Validation accuracy:52.33%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:0.104, Epoch accuracy:97.02%, Validation loss:1.382, Validation accuracy:53.33%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:0.082, Epoch accuracy:97.54%, Validation loss:1.379, Validation accuracy:52.33%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:0.087, Epoch accuracy:97.46%, Validation loss:1.386, Validation accuracy:53.33%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:0.079, Epoch accuracy:97.46%, Validation loss:1.378, Validation accuracy:53.00%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:0.066, Epoch accuracy:97.89%, Validation loss:1.385, Validation accuracy:52.33%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:0.067, Epoch accuracy:97.89%, Validation loss:1.378, Validation accuracy:52.67%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:0.065, Epoch accuracy:97.63%, Validation loss:1.382, Validation accuracy:53.67%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:0.054, Epoch accuracy:97.89%, Validation loss:1.401, Validation accuracy:52.00%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:0.052, Epoch accuracy:98.07%, Validation loss:1.397, Validation accuracy:52.00%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:0.059, Epoch accuracy:97.54%, Validation loss:1.411, Validation accuracy:52.00%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:0.047, Epoch accuracy:98.07%, Validation loss:1.407, Validation accuracy:51.67%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:0.047, Epoch accuracy:97.98%, Validation loss:1.413, Validation accuracy:52.00%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:0.042, Epoch accuracy:98.07%, Validation loss:1.424, Validation accuracy:51.67%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:0.046, Epoch accuracy:98.16%, Validation loss:1.428, Validation accuracy:52.00%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:0.039, Epoch accuracy:98.25%, Validation loss:1.448, Validation accuracy:51.00%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:0.042, Epoch accuracy:97.98%, Validation loss:1.418, Validation accuracy:51.67%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:0.033, Epoch accuracy:98.16%, Validation loss:1.433, Validation accuracy:51.67%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:0.039, Epoch accuracy:98.16%, Validation loss:1.419, Validation accuracy:52.00%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:0.036, Epoch accuracy:98.16%, Validation loss:1.422, Validation accuracy:52.33%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:0.037, Epoch accuracy:98.07%, Validation loss:1.411, Validation accuracy:52.33%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:0.033, Epoch accuracy:98.16%, Validation loss:1.424, Validation accuracy:52.67%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:0.035, Epoch accuracy:98.16%, Validation loss:1.424, Validation accuracy:52.67%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:0.033, Epoch accuracy:98.16%, Validation loss:1.418, Validation accuracy:52.67%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:0.026, Epoch accuracy:98.25%, Validation loss:1.438, Validation accuracy:51.00%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:0.025, Epoch accuracy:98.07%, Validation loss:1.439, Validation accuracy:52.67%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:0.027, Epoch accuracy:98.16%, Validation loss:1.434, Validation accuracy:52.00%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:0.028, Epoch accuracy:98.16%, Validation loss:1.441, Validation accuracy:51.67%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:0.028, Epoch accuracy:98.07%, Validation loss:1.436, Validation accuracy:51.67%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:0.024, Epoch accuracy:98.25%, Validation loss:1.441, Validation accuracy:51.67%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:0.021, Epoch accuracy:98.25%, Validation loss:1.450, Validation accuracy:52.00%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:0.023, Epoch accuracy:98.16%, Validation loss:1.433, Validation accuracy:53.00%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:0.020, Epoch accuracy:98.16%, Validation loss:1.447, Validation accuracy:52.00%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:0.022, Epoch accuracy:98.25%, Validation loss:1.448, Validation accuracy:52.00%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:0.023, Epoch accuracy:98.25%, Validation loss:1.465, Validation accuracy:51.67%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:0.022, Epoch accuracy:98.16%, Validation loss:1.450, Validation accuracy:52.00%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:0.019, Epoch accuracy:98.25%, Validation loss:1.463, Validation accuracy:52.33%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:0.020, Epoch accuracy:98.25%, Validation loss:1.445, Validation accuracy:51.67%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:0.018, Epoch accuracy:98.25%, Validation loss:1.472, Validation accuracy:50.67%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:0.019, Epoch accuracy:98.25%, Validation loss:1.476, Validation accuracy:51.33%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:0.019, Epoch accuracy:98.25%, Validation loss:1.468, Validation accuracy:51.00%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:0.019, Epoch accuracy:98.25%, Validation loss:1.466, Validation accuracy:51.67%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:0.016, Epoch accuracy:98.25%, Validation loss:1.455, Validation accuracy:52.00%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:0.017, Epoch accuracy:98.25%, Validation loss:1.464, Validation accuracy:51.00%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:0.016, Epoch accuracy:98.25%, Validation loss:1.457, Validation accuracy:52.33%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:0.017, Epoch accuracy:98.25%, Validation loss:1.468, Validation accuracy:52.67%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:0.014, Epoch accuracy:98.25%, Validation loss:1.467, Validation accuracy:51.33%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:0.015, Epoch accuracy:98.16%, Validation loss:1.458, Validation accuracy:53.00%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:0.017, Epoch accuracy:98.07%, Validation loss:1.490, Validation accuracy:51.00%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:0.018, Epoch accuracy:98.16%, Validation loss:1.506, Validation accuracy:52.00%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.503, Validation accuracy:50.67%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:0.012, Epoch accuracy:98.25%, Validation loss:1.499, Validation accuracy:50.00%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.482, Validation accuracy:52.00%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.482, Validation accuracy:50.67%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:0.017, Epoch accuracy:98.16%, Validation loss:1.481, Validation accuracy:50.67%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.475, Validation accuracy:52.67%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:0.016, Epoch accuracy:98.16%, Validation loss:1.497, Validation accuracy:50.67%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:0.014, Epoch accuracy:98.25%, Validation loss:1.497, Validation accuracy:50.67%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:0.014, Epoch accuracy:98.25%, Validation loss:1.507, Validation accuracy:50.33%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.488, Validation accuracy:51.67%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:0.013, Epoch accuracy:98.16%, Validation loss:1.496, Validation accuracy:50.67%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:0.012, Epoch accuracy:98.25%, Validation loss:1.482, Validation accuracy:51.00%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:0.012, Epoch accuracy:98.25%, Validation loss:1.492, Validation accuracy:51.00%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:0.012, Epoch accuracy:98.25%, Validation loss:1.476, Validation accuracy:52.67%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.500, Validation accuracy:52.33%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.507, Validation accuracy:51.00%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.496, Validation accuracy:52.33%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.515, Validation accuracy:51.33%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.485, Validation accuracy:51.67%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:0.014, Epoch accuracy:98.25%, Validation loss:1.504, Validation accuracy:50.33%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:0.013, Epoch accuracy:98.25%, Validation loss:1.490, Validation accuracy:52.00%
# Epoch 100: iteration 34/35
# Epoch 100 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.507, Validation accuracy:51.67%
# Epoch 101: iteration 34/35
# Epoch 101 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.518, Validation accuracy:50.67%
# Epoch 102: iteration 34/35
# Epoch 102 --- loss:0.014, Epoch accuracy:98.16%, Validation loss:1.516, Validation accuracy:50.00%
# Epoch 103: iteration 34/35
# Epoch 103 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.491, Validation accuracy:51.33%
# Epoch 104: iteration 34/35
# Epoch 104 --- loss:0.012, Epoch accuracy:98.25%, Validation loss:1.508, Validation accuracy:51.67%
# Epoch 105: iteration 34/35
# Epoch 105 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.503, Validation accuracy:51.67%
# Epoch 106: iteration 34/35
# Epoch 106 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.502, Validation accuracy:52.00%
# Epoch 107: iteration 34/35
# Epoch 107 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.510, Validation accuracy:51.33%
# Epoch 108: iteration 34/35
# Epoch 108 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.526, Validation accuracy:51.67%
# Epoch 109: iteration 34/35
# Epoch 109 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.494, Validation accuracy:52.00%
# Epoch 110: iteration 34/35
# Epoch 110 --- loss:0.009, Epoch accuracy:98.25%, Validation loss:1.508, Validation accuracy:52.33%
# Epoch 111: iteration 34/35
# Epoch 111 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.519, Validation accuracy:50.67%
# Epoch 112: iteration 34/35
# Epoch 112 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.499, Validation accuracy:50.67%
# Epoch 113: iteration 34/35
# Epoch 113 --- loss:0.010, Epoch accuracy:98.16%, Validation loss:1.510, Validation accuracy:51.00%
# Epoch 114: iteration 34/35
# Epoch 114 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.498, Validation accuracy:51.67%
# Epoch 115: iteration 34/35
# Epoch 115 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.498, Validation accuracy:52.00%
# Epoch 116: iteration 34/35
# Epoch 116 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.505, Validation accuracy:51.33%
# Epoch 117: iteration 34/35
# Epoch 117 --- loss:0.010, Epoch accuracy:98.25%, Validation loss:1.502, Validation accuracy:51.67%
# Epoch 118: iteration 34/35
# Epoch 118 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.510, Validation accuracy:52.33%
# Epoch 119: iteration 34/35
# Epoch 119 --- loss:0.011, Epoch accuracy:98.25%, Validation loss:1.491, Validation accuracy:51.67%
# Epoch 120: iteration 34/35
# Epoch 120 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.514, Validation accuracy:52.00%
# Epoch 121: iteration 34/35
# Epoch 121 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.508, Validation accuracy:53.00%
# Epoch 122: iteration 34/35
# Epoch 122 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.512, Validation accuracy:52.00%
# Epoch 123: iteration 34/35
# Epoch 123 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.512, Validation accuracy:52.00%
# Epoch 124: iteration 34/35
# Epoch 124 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.500, Validation accuracy:51.00%
# Epoch 125: iteration 34/35
# Epoch 125 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.514, Validation accuracy:52.67%
# Epoch 126: iteration 34/35
# Epoch 126 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.514, Validation accuracy:53.00%
# Epoch 127: iteration 34/35
# Epoch 127 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.509, Validation accuracy:51.33%
# Epoch 128: iteration 34/35
# Epoch 128 --- loss:0.010, Epoch accuracy:98.16%, Validation loss:1.497, Validation accuracy:52.33%
# Epoch 129: iteration 34/35
# Epoch 129 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.509, Validation accuracy:53.00%
# Epoch 130: iteration 34/35
# Epoch 130 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.494, Validation accuracy:52.67%
# Epoch 131: iteration 34/35
# Epoch 131 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.503, Validation accuracy:52.00%
# Epoch 132: iteration 34/35
# Epoch 132 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.505, Validation accuracy:53.00%
# Epoch 133: iteration 34/35
# Epoch 133 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.538, Validation accuracy:52.33%
# Epoch 134: iteration 34/35
# Epoch 134 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.500, Validation accuracy:52.33%
# Epoch 135: iteration 34/35
# Epoch 135 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.516, Validation accuracy:53.33%
# Epoch 136: iteration 34/35
# Epoch 136 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.520, Validation accuracy:52.67%
# Epoch 137: iteration 34/35
# Epoch 137 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.526, Validation accuracy:52.00%
# Epoch 138: iteration 34/35
# Epoch 138 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.524, Validation accuracy:52.00%
# Epoch 139: iteration 34/35
# Epoch 139 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.532, Validation accuracy:52.00%
# Epoch 140: iteration 34/35
# Epoch 140 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.508, Validation accuracy:53.67%
# Epoch 141: iteration 34/35
# Epoch 141 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.496, Validation accuracy:52.33%
# Epoch 142: iteration 34/35
# Epoch 142 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.523, Validation accuracy:52.00%
# Epoch 143: iteration 34/35
# Epoch 143 --- loss:0.006, Epoch accuracy:98.16%, Validation loss:1.521, Validation accuracy:51.67%
# Epoch 144: iteration 34/35
# Epoch 144 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.532, Validation accuracy:52.00%
# Epoch 145: iteration 34/35
# Epoch 145 --- loss:0.007, Epoch accuracy:98.16%, Validation loss:1.534, Validation accuracy:52.33%
# Epoch 146: iteration 34/35
# Epoch 146 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.515, Validation accuracy:52.33%
# Epoch 147: iteration 34/35
# Epoch 147 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.524, Validation accuracy:51.67%
# Epoch 148: iteration 34/35
# Epoch 148 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.528, Validation accuracy:52.00%
# Epoch 149: iteration 34/35
# Epoch 149 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.528, Validation accuracy:51.67%
# Epoch 150: iteration 34/35
# Epoch 150 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.521, Validation accuracy:52.33%
# Epoch 151: iteration 34/35
# Epoch 151 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.524, Validation accuracy:50.67%
# Epoch 152: iteration 34/35
# Epoch 152 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.535, Validation accuracy:52.00%
# Epoch 153: iteration 34/35
# Epoch 153 --- loss:0.006, Epoch accuracy:98.16%, Validation loss:1.520, Validation accuracy:51.67%
# Epoch 154: iteration 34/35
# Epoch 154 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.541, Validation accuracy:52.00%
# Epoch 155: iteration 34/35
# Epoch 155 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.520, Validation accuracy:52.67%
# Epoch 156: iteration 34/35
# Epoch 156 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.537, Validation accuracy:51.33%
# Epoch 157: iteration 34/35
# Epoch 157 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.528, Validation accuracy:52.00%
# Epoch 158: iteration 34/35
# Epoch 158 --- loss:0.006, Epoch accuracy:98.16%, Validation loss:1.528, Validation accuracy:52.00%
# Epoch 159: iteration 34/35
# Epoch 159 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.512, Validation accuracy:52.67%
# Epoch 160: iteration 34/35
# Epoch 160 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.535, Validation accuracy:51.67%
# Epoch 161: iteration 34/35
# Epoch 161 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.526, Validation accuracy:52.33%
# Epoch 162: iteration 34/35
# Epoch 162 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.524, Validation accuracy:51.33%
# Epoch 163: iteration 34/35
# Epoch 163 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.539, Validation accuracy:52.00%
# Epoch 164: iteration 34/35
# Epoch 164 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.516, Validation accuracy:51.33%
# Epoch 165: iteration 34/35
# Epoch 165 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.518, Validation accuracy:52.00%
# Epoch 166: iteration 34/35
# Epoch 166 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.538, Validation accuracy:51.00%
# Epoch 167: iteration 34/35
# Epoch 167 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.524, Validation accuracy:51.33%
# Epoch 168: iteration 34/35
# Epoch 168 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.521, Validation accuracy:51.33%
# Epoch 169: iteration 34/35
# Epoch 169 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.532, Validation accuracy:51.33%
# Epoch 170: iteration 34/35
# Epoch 170 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.548, Validation accuracy:52.67%
# Epoch 171: iteration 34/35
# Epoch 171 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.518, Validation accuracy:51.67%
# Epoch 172: iteration 34/35
# Epoch 172 --- loss:0.007, Epoch accuracy:98.25%, Validation loss:1.518, Validation accuracy:51.33%
# Epoch 173: iteration 34/35
# Epoch 173 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.495, Validation accuracy:52.67%
# Epoch 174: iteration 34/35
# Epoch 174 --- loss:0.008, Epoch accuracy:98.25%, Validation loss:1.524, Validation accuracy:51.00%
# Epoch 175: iteration 34/35
# Epoch 175 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.513, Validation accuracy:53.33%
# Epoch 176: iteration 34/35
# Epoch 176 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.506, Validation accuracy:52.67%
# Epoch 177: iteration 34/35
# Epoch 177 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.541, Validation accuracy:52.00%
# Epoch 178: iteration 34/35
# Epoch 178 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.525, Validation accuracy:52.33%
# Epoch 179: iteration 34/35
# Epoch 179 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.539, Validation accuracy:50.67%
# Epoch 180: iteration 34/35
# Epoch 180 --- loss:0.005, Epoch accuracy:98.25%, Validation loss:1.520, Validation accuracy:52.67%
# Epoch 181: iteration 34/35
# Epoch 181 --- loss:0.004, Epoch accuracy:98.25%, Validation loss:1.534, Validation accuracy:51.67%
# Epoch 182: iteration 34/35
# Epoch 182 --- loss:0.006, Epoch accuracy:98.25%, Validation loss:1.525, Validation accuracy:50.67%
# ...
# Epoch 74: iteration 36/37
# Epoch 74 --- loss:0.022, Epoch accuracy:98.42%, Validation loss:1.474, Validation accuracy:51.25%
# Epoch 75: iteration 36/37
# Epoch 75 --- loss:0.017, Epoch accuracy:98.67%, Validation loss:1.479, Validation accuracy:51.67%
# Epoch 76: iteration 36/37
# Epoch 76 --- loss:0.016, Epoch accuracy:98.67%, Validation loss:1.480, Validation accuracy:50.42%
# Epoch 77: iteration 36/37
# Epoch 77 --- loss:0.016, Epoch accuracy:98.67%, Validation loss:1.461, Validation accuracy:52.50%
# Epoch 78: iteration 36/37
# Epoch 78 --- loss:0.014, Epoch accuracy:98.67%, Validation loss:1.477, Validation accuracy:52.08%
# Epoch 79: iteration 36/37
# Epoch 79 --- loss:0.016, Epoch accuracy:98.58%, Validation loss:1.475, Validation accuracy:52.92%
# Epoch 80: iteration 36/37
# Epoch 80 --- loss:0.015, Epoch accuracy:98.67%, Validation loss:1.468, Validation accuracy:51.67%
# Epoch 81: iteration 36/37
# Epoch 81 --- loss:0.018, Epoch accuracy:98.58%, Validation loss:1.483, Validation accuracy:50.83%
# Epoch 82: iteration 36/37
# Epoch 82 --- loss:0.017, Epoch accuracy:98.67%, Validation loss:1.472, Validation accuracy:52.92%
# Epoch 83: iteration 36/37
# Epoch 83 --- loss:0.014, Epoch accuracy:98.67%, Validation loss:1.469, Validation accuracy:52.50%
# Epoch 84: iteration 36/37
# Epoch 84 --- loss:0.015, Epoch accuracy:98.67%, Validation loss:1.482, Validation accuracy:51.67%
# Epoch 85: iteration 36/37
# Epoch 85 --- loss:0.013, Epoch accuracy:98.67%, Validation loss:1.483, Validation accuracy:51.67%
# Epoch 86: iteration 36/37
# Epoch 86 --- loss:0.013, Epoch accuracy:98.67%, Validation loss:1.466, Validation accuracy:53.75%
# Epoch 87: iteration 36/37
# Epoch 87 --- loss:0.013, Epoch accuracy:98.67%, Validation loss:1.443, Validation accuracy:53.75%
# Epoch 88: iteration 36/37
# Epoch 88 --- loss:0.012, Epoch accuracy:98.67%, Validation loss:1.449, Validation accuracy:53.75%
# Epoch 89: iteration 36/37
# Epoch 89 --- loss:0.014, Epoch accuracy:98.67%, Validation loss:1.475, Validation accuracy:54.17%
# Epoch 90: iteration 36/37
# Epoch 90 --- loss:0.014, Epoch accuracy:98.67%, Validation loss:1.469, Validation accuracy:55.00%
# Epoch 91: iteration 36/37
# Epoch 91 --- loss:0.012, Epoch accuracy:98.58%, Validation loss:1.468, Validation accuracy:50.83%
# Epoch 92: iteration 36/37
# Epoch 92 --- loss:0.014, Epoch accuracy:98.67%, Validation loss:1.456, Validation accuracy:53.33%
# Epoch 93: iteration 36/37
# Epoch 93 --- loss:0.013, Epoch accuracy:98.67%, Validation loss:1.470, Validation accuracy:54.17%
# Epoch 94: iteration 36/37
# Epoch 94 --- loss:0.014, Epoch accuracy:98.67%, Validation loss:1.511, Validation accuracy:50.83%
# Epoch 95: iteration 36/37
# Epoch 95 --- loss:0.012, Epoch accuracy:98.67%, Validation loss:1.475, Validation accuracy:52.08%
# Epoch 96: iteration 36/37
# Epoch 96 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.494, Validation accuracy:52.50%
# Epoch 97: iteration 36/37
# Epoch 97 --- loss:0.012, Epoch accuracy:98.58%, Validation loss:1.471, Validation accuracy:52.92%
# Epoch 98: iteration 36/37
# Epoch 98 --- loss:0.012, Epoch accuracy:98.67%, Validation loss:1.448, Validation accuracy:53.75%
# Epoch 99: iteration 36/37
# Epoch 99 --- loss:0.012, Epoch accuracy:98.67%, Validation loss:1.471, Validation accuracy:51.25%
# Epoch 100: iteration 36/37
# Epoch 100 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.489, Validation accuracy:51.67%
# Epoch 101: iteration 36/37
# Epoch 101 --- loss:0.014, Epoch accuracy:98.67%, Validation loss:1.465, Validation accuracy:52.92%
# Epoch 102: iteration 36/37
# Epoch 102 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.437, Validation accuracy:54.58%
# Epoch 103: iteration 36/37
# Epoch 103 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.463, Validation accuracy:51.67%
# Epoch 104: iteration 36/37
# Epoch 104 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.489, Validation accuracy:52.92%
# Epoch 105: iteration 36/37
# Epoch 105 --- loss:0.012, Epoch accuracy:98.67%, Validation loss:1.485, Validation accuracy:51.67%
# Epoch 106: iteration 36/37
# Epoch 106 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.460, Validation accuracy:53.75%
# Epoch 107: iteration 36/37
# Epoch 107 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.490, Validation accuracy:53.33%
# Epoch 108: iteration 36/37
# Epoch 108 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.483, Validation accuracy:51.67%
# Epoch 109: iteration 36/37
# Epoch 109 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.493, Validation accuracy:51.67%
# Epoch 110: iteration 36/37
# Epoch 110 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.478, Validation accuracy:51.67%
# Epoch 111: iteration 36/37
# Epoch 111 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.477, Validation accuracy:52.50%
# Epoch 112: iteration 36/37
# Epoch 112 --- loss:0.013, Epoch accuracy:98.67%, Validation loss:1.483, Validation accuracy:51.25%
# Epoch 113: iteration 36/37
# Epoch 113 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.496, Validation accuracy:51.25%
# Epoch 114: iteration 36/37
# Epoch 114 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.477, Validation accuracy:53.75%
# Epoch 115: iteration 36/37
# Epoch 115 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.486, Validation accuracy:52.92%
# Epoch 116: iteration 36/37
# Epoch 116 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.498, Validation accuracy:52.92%
# Epoch 117: iteration 36/37
# Epoch 117 --- loss:0.011, Epoch accuracy:98.67%, Validation loss:1.512, Validation accuracy:50.83%
# Epoch 118: iteration 36/37
# Epoch 118 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.494, Validation accuracy:51.25%
# Epoch 119: iteration 36/37
# Epoch 119 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.486, Validation accuracy:54.17%
# Epoch 120: iteration 36/37
# Epoch 120 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.496, Validation accuracy:50.83%
# Epoch 121: iteration 36/37
# Epoch 121 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.508, Validation accuracy:52.50%
# Epoch 122: iteration 36/37
# Epoch 122 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.508, Validation accuracy:52.08%
# Epoch 123: iteration 36/37
# Epoch 123 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.507, Validation accuracy:52.92%
# Epoch 124: iteration 36/37
# Epoch 124 --- loss:0.010, Epoch accuracy:98.67%, Validation loss:1.497, Validation accuracy:54.17%
# Epoch 125: iteration 36/37
# Epoch 125 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.503, Validation accuracy:52.92%
# Epoch 126: iteration 36/37
# Epoch 126 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.528, Validation accuracy:52.92%
# Epoch 127: iteration 36/37
# Epoch 127 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.501, Validation accuracy:51.67%
# Epoch 128: iteration 36/37
# Epoch 128 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.490, Validation accuracy:53.75%
# Epoch 129: iteration 36/37
# Epoch 129 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.488, Validation accuracy:52.08%
# Epoch 130: iteration 36/37
# Epoch 130 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.498, Validation accuracy:50.00%
# Epoch 131: iteration 36/37
# Epoch 131 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.522, Validation accuracy:51.67%
# Epoch 132: iteration 36/37
# Epoch 132 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.499, Validation accuracy:52.92%
# Epoch 133: iteration 36/37
# Epoch 133 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.524, Validation accuracy:52.50%
# Epoch 134: iteration 36/37
# Epoch 134 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.499, Validation accuracy:52.50%
# Epoch 135: iteration 36/37
# Epoch 135 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.476, Validation accuracy:54.17%
# Epoch 136: iteration 36/37
# Epoch 136 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.504, Validation accuracy:52.50%
# Epoch 137: iteration 36/37
# Epoch 137 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.487, Validation accuracy:53.33%
# Epoch 138: iteration 36/37
# Epoch 138 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.498, Validation accuracy:50.83%
# Epoch 139: iteration 36/37
# Epoch 139 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.509, Validation accuracy:52.08%
# Epoch 140: iteration 36/37
# Epoch 140 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.506, Validation accuracy:53.75%
# Epoch 141: iteration 36/37
# Epoch 141 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.507, Validation accuracy:52.92%
# Epoch 142: iteration 36/37
# Epoch 142 --- loss:0.009, Epoch accuracy:98.67%, Validation loss:1.477, Validation accuracy:53.33%
# Epoch 143: iteration 36/37
# Epoch 143 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.527, Validation accuracy:52.08%
# Epoch 144: iteration 36/37
# Epoch 144 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.496, Validation accuracy:52.92%
# Epoch 145: iteration 36/37
# Epoch 145 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.520, Validation accuracy:51.67%
# Epoch 146: iteration 36/37
# Epoch 146 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.504, Validation accuracy:53.75%
# Epoch 147: iteration 36/37
# Epoch 147 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.522, Validation accuracy:53.75%
# Epoch 148: iteration 36/37
# Epoch 148 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.498, Validation accuracy:53.33%
# Epoch 149: iteration 36/37
# Epoch 149 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.487, Validation accuracy:53.75%
# Epoch 150: iteration 36/37
# Epoch 150 --- loss:0.008, Epoch accuracy:98.67%, Validation loss:1.538, Validation accuracy:51.67%
# Epoch 151: iteration 36/37
# Epoch 151 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.496, Validation accuracy:52.92%
# Epoch 152: iteration 36/37
# Epoch 152 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.502, Validation accuracy:53.75%
# Epoch 153: iteration 36/37
# Epoch 153 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.526, Validation accuracy:51.67%
# Epoch 154: iteration 36/37
# Epoch 154 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.545, Validation accuracy:50.42%
# Epoch 155: iteration 36/37
# Epoch 155 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.503, Validation accuracy:54.58%
# Epoch 156: iteration 36/37
# Epoch 156 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.500, Validation accuracy:53.33%
# Epoch 157: iteration 36/37
# Epoch 157 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.509, Validation accuracy:52.92%
# Epoch 158: iteration 36/37
# Epoch 158 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.505, Validation accuracy:52.92%
# Epoch 159: iteration 36/37
# Epoch 159 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.497, Validation accuracy:52.50%
# Epoch 160: iteration 36/37
# Epoch 160 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.505, Validation accuracy:53.33%
# Epoch 161: iteration 36/37
# Epoch 161 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.501, Validation accuracy:53.33%
# Epoch 162: iteration 36/37
# Epoch 162 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.516, Validation accuracy:52.92%
# Epoch 163: iteration 36/37
# Epoch 163 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.506, Validation accuracy:53.33%
# Epoch 164: iteration 36/37
# Epoch 164 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.530, Validation accuracy:51.67%
# Epoch 165: iteration 36/37
# Epoch 165 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.514, Validation accuracy:51.67%
# Epoch 166: iteration 36/37
# Epoch 166 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.506, Validation accuracy:53.33%
# Epoch 167: iteration 36/37
# Epoch 167 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.513, Validation accuracy:52.50%
# Epoch 168: iteration 36/37
# Epoch 168 --- loss:0.006, Epoch accuracy:98.58%, Validation loss:1.520, Validation accuracy:53.75%
# Epoch 169: iteration 36/37
# Epoch 169 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.537, Validation accuracy:52.50%
# Epoch 170: iteration 36/37
# Epoch 170 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.491, Validation accuracy:55.00%
# Epoch 171: iteration 36/37
# Epoch 171 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.536, Validation accuracy:50.42%
# Epoch 172: iteration 36/37
# Epoch 172 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.530, Validation accuracy:52.08%
# Epoch 173: iteration 36/37
# Epoch 173 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.541, Validation accuracy:51.67%
# Epoch 174: iteration 36/37
# Epoch 174 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.527, Validation accuracy:52.50%
# Epoch 175: iteration 36/37
# Epoch 175 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.537, Validation accuracy:52.92%
# Epoch 176: iteration 36/37
# Epoch 176 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.535, Validation accuracy:52.92%
# Epoch 177: iteration 36/37
# Epoch 177 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.519, Validation accuracy:50.83%
# Epoch 178: iteration 36/37
# Epoch 178 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.512, Validation accuracy:54.17%
# Epoch 179: iteration 36/37
# Epoch 179 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.530, Validation accuracy:53.33%
# Epoch 180: iteration 36/37
# Epoch 180 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.507, Validation accuracy:50.83%
# Epoch 181: iteration 36/37
# Epoch 181 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.509, Validation accuracy:52.92%
# Epoch 182: iteration 36/37
# Epoch 182 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.525, Validation accuracy:50.83%
# Epoch 183: iteration 36/37
# Epoch 183 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.540, Validation accuracy:50.83%
# Epoch 184: iteration 36/37
# Epoch 184 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.527, Validation accuracy:51.67%
# Epoch 185: iteration 36/37
# Epoch 185 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.501, Validation accuracy:52.92%
# Epoch 186: iteration 36/37
# Epoch 186 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.540, Validation accuracy:51.25%
# Epoch 187: iteration 36/37
# Epoch 187 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.527, Validation accuracy:52.08%
# Epoch 188: iteration 36/37
# Epoch 188 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.513, Validation accuracy:52.50%
# Epoch 189: iteration 36/37
# Epoch 189 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.521, Validation accuracy:52.92%
# Epoch 190: iteration 36/37
# Epoch 190 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.497, Validation accuracy:52.08%
# Epoch 191: iteration 36/37
# Epoch 191 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.516, Validation accuracy:52.50%
# Epoch 192: iteration 36/37
# Epoch 192 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.545, Validation accuracy:52.92%
# Epoch 193: iteration 36/37
# Epoch 193 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.553, Validation accuracy:53.33%
# Epoch 194: iteration 36/37
# Epoch 194 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.510, Validation accuracy:52.08%
# Epoch 195: iteration 36/37
# Epoch 195 --- loss:0.006, Epoch accuracy:98.67%, Validation loss:1.547, Validation accuracy:54.17%
# Epoch 196: iteration 36/37
# Epoch 196 --- loss:0.004, Epoch accuracy:98.67%, Validation loss:1.512, Validation accuracy:54.58%
# Epoch 197: iteration 36/37
# Epoch 197 --- loss:0.005, Epoch accuracy:98.67%, Validation loss:1.515, Validation accuracy:52.92%
# Epoch 198: iteration 36/37
# Epoch 198 --- loss:0.004, Epoch accuracy:98.67%, Validation loss:1.522, Validation accuracy:54.17%
# Epoch 199: iteration 36/37
# Epoch 199 --- loss:0.007, Epoch accuracy:98.67%, Validation loss:1.550, Validation accuracy:52.92%
#
#
# [*] done !
# [*] Best training loss - 0.004059201211978993
# [*] Best validation loss - 1.375924825668335

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
from sklearn.metrics import classification_report

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    
    print("="*40)
    print(f'[*] Fold-{fold}')
    print(f'Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    print("="*40)
# Out:
# ========================================
# [*] Fold-0
# Test accuracy is 58.67%
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        20
#            1       0.85      0.57      0.69        40
#            2       0.52      0.42      0.47        40
#            3       0.33      0.38      0.35        40
#            4       0.55      0.78      0.65        40
#            5       0.62      0.72      0.67        40
#            6       0.70      0.47      0.57        40
#            7       0.73      0.80      0.76        40
#
#     accuracy                           0.59       300
#    macro avg       0.60      0.58      0.58       300
# weighted avg       0.61      0.59      0.59       300
# ========================================
# ========================================
# [*] Fold-1
# Test accuracy is 55.00%
#               precision    recall  f1-score   support
#
#            0       0.50      0.30      0.37        20
#            1       0.67      0.75      0.71        40
#            2       0.32      0.33      0.32        40
#            3       0.56      0.35      0.43        40
#            4       0.73      0.55      0.63        40
#            5       0.51      0.55      0.53        40
#            6       0.53      0.62      0.57        40
#            7       0.58      0.82      0.68        40
#
#     accuracy                           0.55       300
#    macro avg       0.55      0.53      0.53       300
# weighted avg       0.55      0.55      0.54       300
# ========================================
# ========================================
# [*] Fold-2
# Test accuracy is 51.00%
#               precision    recall  f1-score   support
#
#            0       0.38      0.15      0.21        20
#            1       0.60      0.80      0.69        40
#            2       0.31      0.42      0.36        40
#            3       0.32      0.30      0.31        40
#            4       0.65      0.65      0.65        40
#            5       0.38      0.42      0.40        40
#            6       0.72      0.65      0.68        40
#            7       0.74      0.50      0.60        40
#
#     accuracy                           0.51       300
#    macro avg       0.51      0.49      0.49       300
# weighted avg       0.52      0.51      0.51       300
# ========================================
# ========================================
# [*] Fold-3
# Test accuracy is 47.33%
#               precision    recall  f1-score   support
#
#            0       0.33      0.25      0.29        20
#            1       0.44      0.60      0.51        40
#            2       0.36      0.23      0.28        40
#            3       0.11      0.07      0.09        40
#            4       0.59      0.47      0.53        40
#            5       0.52      0.35      0.42        40
#            6       0.52      0.88      0.65        40
#            7       0.63      0.82      0.72        40
#
#     accuracy                           0.47       300
#    macro avg       0.44      0.46      0.43       300
# weighted avg       0.45      0.47      0.44       300
# ========================================
# ========================================
# [*] Fold-4
# Test accuracy is 52.92%
#               precision    recall  f1-score   support
#
#            0       0.10      0.06      0.08        16
#            1       0.65      0.75      0.70        32
#            2       0.44      0.44      0.44        32
#            3       0.35      0.44      0.39        32
#            4       0.59      0.72      0.65        32
#            5       0.64      0.56      0.60        32
#            6       0.43      0.41      0.42        32
#            7       0.83      0.62      0.71        32
#
#     accuracy                           0.53       240
#    macro avg       0.50      0.50      0.50       240
# weighted avg       0.53      0.53      0.53       240
# ========================================

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 58.67%
# [*] Worst fold acc : 47.33%
# [*] Average fold acc : 52.98%
