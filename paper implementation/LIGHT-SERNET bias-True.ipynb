# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

emotions_dict = {
    'anger': 0,
    'anxiety_fear': 1,
    'boredom': 2,
    'disgust': 3,
    'happiness': 4,
    'neutral': 5,
    'sadness': 6
}


sub_name = 'LIGHT-SERNET'
data_name = 'EMODB'
fold_path = sub_name + ' dataset'

sub_name += '_bias-true'

minibatch = 16
num_epochs = 300
EARLY_CNT = 99999

learning_rate = 10e-4

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class Model(nn.Module):
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=[11,1], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )
        self.conv2 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=[1,9], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )
        self.conv3 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )
        
        self.LFLB = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=[3,3], stride=1, padding='same'),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,1]),
            
            nn.Conv2d(64, 96, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(96, 128, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(128, 160, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(160),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(160, 320, kernel_size=[1,1], stride=[1,1], padding='same'),
            nn.BatchNorm2d(320),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,0])
        )
        
        self.fc = nn.Linear(320, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        conv_embd1 = self.conv1(x)
        conv_embd2 = self.conv2(x)
        conv_embd3 = self.conv3(x)
        
        feature_extractor = torch.cat([conv_embd1, conv_embd2, conv_embd3], dim=-1)
        
        lflb_embd = self.LFLB(feature_extractor)
        out = F.adaptive_avg_pool2d(lflb_embd, (1,1))
        out = nn.Dropout(0.3)(out)
        out = torch.flatten(out, start_dim=1)
        
        output_logits = self.fc(out)
        output_softmax = self.softmax(output_logits)

        return output_logits, output_softmax
    
# model = Model(len(emotions_dict))
# print(summary(model, (32, 1, 184, 40)))

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)
        
        # LFLB_children = list(model.children())[-3]
        
        # for i in range(len(LFLB_children)):
        #     try:
        #         norm = torch.norm(LFLB_children[i].weight, p=2)
        #     except AttributeError:
        #         continue
        #     loss = loss + norm
        
        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'Fold-{fold+1}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i+1}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import numpy as np

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

for fold in tqdm(range(10)):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=10e-6, amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - LIGHT-SERNET_bias-true
# A Jupyter Widget
# A Jupyter Widget
# Epoch 0: iteration 30/30
# Epoch 0 --- loss:1.598, Epoch accuracy:31.89%, Validation loss:1.412, Validation accuracy:44.90%
# Epoch 1: iteration 30/30
# Epoch 1 --- loss:1.384, Epoch accuracy:42.39%, Validation loss:1.194, Validation accuracy:57.14%
# Epoch 2: iteration 30/30
# Epoch 2 --- loss:1.221, Epoch accuracy:53.70%, Validation loss:1.315, Validation accuracy:40.82%
# Epoch 3: iteration 30/30
# Epoch 3 --- loss:1.194, Epoch accuracy:53.09%, Validation loss:1.700, Validation accuracy:32.65%
# Epoch 4: iteration 30/30
# Epoch 4 --- loss:1.084, Epoch accuracy:57.41%, Validation loss:1.530, Validation accuracy:32.65%
# Epoch 5: iteration 30/30
# Epoch 5 --- loss:1.005, Epoch accuracy:65.23%, Validation loss:1.926, Validation accuracy:20.41%
# Epoch 6: iteration 30/30
# Epoch 6 --- loss:0.990, Epoch accuracy:62.96%, Validation loss:1.241, Validation accuracy:42.86%
# Epoch 7: iteration 30/30
# Epoch 7 --- loss:0.940, Epoch accuracy:63.58%, Validation loss:1.404, Validation accuracy:48.98%
# Epoch 8: iteration 30/30
# Epoch 8 --- loss:0.864, Epoch accuracy:67.08%, Validation loss:1.786, Validation accuracy:44.90%
# Epoch 9: iteration 30/30
# Epoch 9 --- loss:0.855, Epoch accuracy:67.90%, Validation loss:1.958, Validation accuracy:26.53%
# Epoch 10: iteration 30/30
# Epoch 10 --- loss:0.784, Epoch accuracy:71.19%, Validation loss:0.984, Validation accuracy:67.35%
# Epoch 11: iteration 30/30
# Epoch 11 --- loss:0.787, Epoch accuracy:68.72%, Validation loss:1.338, Validation accuracy:65.31%
# Epoch 12: iteration 30/30
# Epoch 12 --- loss:0.796, Epoch accuracy:69.96%, Validation loss:1.432, Validation accuracy:55.10%
# Epoch 13: iteration 30/30
# Epoch 13 --- loss:0.828, Epoch accuracy:68.93%, Validation loss:1.773, Validation accuracy:46.94%
# Epoch 14: iteration 30/30
# Epoch 14 --- loss:0.759, Epoch accuracy:72.43%, Validation loss:1.890, Validation accuracy:36.73%
# Epoch 15: iteration 30/30
# Epoch 15 --- loss:0.678, Epoch accuracy:74.69%, Validation loss:1.586, Validation accuracy:46.94%
# Epoch 16: iteration 30/30
# Epoch 16 --- loss:0.700, Epoch accuracy:72.22%, Validation loss:5.103, Validation accuracy:28.57%
# Epoch 17: iteration 30/30
# Epoch 17 --- loss:0.689, Epoch accuracy:72.22%, Validation loss:1.919, Validation accuracy:38.78%
# Epoch 18: iteration 30/30
# Epoch 18 --- loss:0.667, Epoch accuracy:76.54%, Validation loss:4.008, Validation accuracy:18.37%
# Epoch 19: iteration 30/30
# Epoch 19 --- loss:0.708, Epoch accuracy:74.49%, Validation loss:1.034, Validation accuracy:46.94%
# Epoch 20: iteration 30/30
# Epoch 20 --- loss:0.676, Epoch accuracy:76.54%, Validation loss:1.351, Validation accuracy:57.14%
# Epoch 21: iteration 30/30
# Epoch 21 --- loss:0.613, Epoch accuracy:75.72%, Validation loss:3.455, Validation accuracy:16.33%
# Epoch 22: iteration 30/30
# Epoch 22 --- loss:0.555, Epoch accuracy:79.42%, Validation loss:1.866, Validation accuracy:46.94%
# Epoch 23: iteration 30/30
# Epoch 23 --- loss:0.569, Epoch accuracy:78.19%, Validation loss:1.891, Validation accuracy:42.86%
# Epoch 24: iteration 30/30
# Epoch 24 --- loss:0.592, Epoch accuracy:79.22%, Validation loss:0.994, Validation accuracy:61.22%
# Epoch 25: iteration 30/30
# Epoch 25 --- loss:0.549, Epoch accuracy:79.63%, Validation loss:2.710, Validation accuracy:34.69%
# Epoch 26: iteration 30/30
# Epoch 26 --- loss:0.556, Epoch accuracy:80.45%, Validation loss:2.463, Validation accuracy:34.69%
# Epoch 27: iteration 30/30
# Epoch 27 --- loss:0.530, Epoch accuracy:79.42%, Validation loss:5.281, Validation accuracy:30.61%
# Epoch 28: iteration 30/30
# Epoch 28 --- loss:0.514, Epoch accuracy:81.07%, Validation loss:1.979, Validation accuracy:34.69%
# Epoch 29: iteration 30/30
# Epoch 29 --- loss:0.460, Epoch accuracy:83.33%, Validation loss:1.001, Validation accuracy:73.47%
# Epoch 30: iteration 30/30
# Epoch 30 --- loss:0.484, Epoch accuracy:82.10%, Validation loss:1.264, Validation accuracy:57.14%
# Epoch 31: iteration 30/30
# Epoch 31 --- loss:0.482, Epoch accuracy:81.89%, Validation loss:0.606, Validation accuracy:75.51%
# Epoch 32: iteration 30/30
# Epoch 32 --- loss:0.437, Epoch accuracy:82.92%, Validation loss:2.359, Validation accuracy:40.82%
# Epoch 33: iteration 30/30
# Epoch 33 --- loss:0.469, Epoch accuracy:82.10%, Validation loss:0.997, Validation accuracy:63.27%
# Epoch 34: iteration 30/30
# Epoch 34 --- loss:0.409, Epoch accuracy:86.83%, Validation loss:1.494, Validation accuracy:55.10%
# Epoch 35: iteration 30/30
# Epoch 35 --- loss:0.357, Epoch accuracy:87.86%, Validation loss:2.895, Validation accuracy:30.61%
# Epoch 36: iteration 30/30
# Epoch 36 --- loss:0.389, Epoch accuracy:84.57%, Validation loss:2.116, Validation accuracy:42.86%
# Epoch 37: iteration 30/30
# Epoch 37 --- loss:0.404, Epoch accuracy:84.57%, Validation loss:1.510, Validation accuracy:42.86%
# Epoch 38: iteration 30/30
# Epoch 38 --- loss:0.354, Epoch accuracy:87.86%, Validation loss:3.864, Validation accuracy:24.49%
# Epoch 39: iteration 30/30
# Epoch 39 --- loss:0.344, Epoch accuracy:87.65%, Validation loss:3.051, Validation accuracy:32.65%
# Epoch 40: iteration 30/30
# Epoch 40 --- loss:0.341, Epoch accuracy:88.07%, Validation loss:1.343, Validation accuracy:44.90%
# Epoch 41: iteration 30/30
# Epoch 41 --- loss:0.376, Epoch accuracy:86.42%, Validation loss:3.513, Validation accuracy:28.57%
# Epoch 42: iteration 30/30
# Epoch 42 --- loss:0.394, Epoch accuracy:83.74%, Validation loss:6.177, Validation accuracy:28.57%
# Epoch 43: iteration 30/30
# Epoch 43 --- loss:0.320, Epoch accuracy:88.48%, Validation loss:1.353, Validation accuracy:53.06%
# Epoch 44: iteration 30/30
# Epoch 44 --- loss:0.263, Epoch accuracy:91.56%, Validation loss:4.655, Validation accuracy:18.37%
# Epoch 45: iteration 30/30
# Epoch 45 --- loss:0.315, Epoch accuracy:88.48%, Validation loss:2.213, Validation accuracy:46.94%
# Epoch 46: iteration 30/30
# Epoch 46 --- loss:0.307, Epoch accuracy:88.89%, Validation loss:1.937, Validation accuracy:63.27%
# Epoch 47: iteration 30/30
# Epoch 47 --- loss:0.287, Epoch accuracy:89.92%, Validation loss:2.072, Validation accuracy:59.18%
# Epoch 48: iteration 30/30
# Epoch 48 --- loss:0.275, Epoch accuracy:89.09%, Validation loss:1.587, Validation accuracy:57.14%
# Epoch 49: iteration 30/30
# Epoch 49 --- loss:0.296, Epoch accuracy:89.09%, Validation loss:0.731, Validation accuracy:67.35%
# Epoch 50: iteration 30/30
# Epoch 50 --- loss:0.298, Epoch accuracy:88.68%, Validation loss:5.211, Validation accuracy:44.90%
# Epoch 51: iteration 30/30
# Epoch 51 --- loss:0.251, Epoch accuracy:92.18%, Validation loss:1.924, Validation accuracy:46.94%
# Epoch 52: iteration 30/30
# Epoch 52 --- loss:0.259, Epoch accuracy:90.74%, Validation loss:4.947, Validation accuracy:30.61%
# Epoch 53: iteration 30/30
# Epoch 53 --- loss:0.218, Epoch accuracy:92.80%, Validation loss:0.867, Validation accuracy:69.39%
# Epoch 54: iteration 30/30
# Epoch 54 --- loss:0.254, Epoch accuracy:90.33%, Validation loss:4.053, Validation accuracy:28.57%
# Epoch 55: iteration 30/30
# Epoch 55 --- loss:0.324, Epoch accuracy:88.68%, Validation loss:2.632, Validation accuracy:61.22%
# Epoch 56: iteration 30/30
# Epoch 56 --- loss:0.246, Epoch accuracy:92.59%, Validation loss:8.581, Validation accuracy:14.29%
# Epoch 57: iteration 30/30
# Epoch 57 --- loss:0.201, Epoch accuracy:92.80%, Validation loss:1.255, Validation accuracy:75.51%
# Epoch 58: iteration 30/30
# Epoch 58 --- loss:0.163, Epoch accuracy:95.06%, Validation loss:3.525, Validation accuracy:55.10%
# Epoch 59: iteration 30/30
# Epoch 59 --- loss:0.260, Epoch accuracy:90.74%, Validation loss:6.067, Validation accuracy:38.78%
# Epoch 60: iteration 30/30
# Epoch 60 --- loss:0.269, Epoch accuracy:89.51%, Validation loss:3.748, Validation accuracy:40.82%
# Epoch 61: iteration 30/30
# Epoch 61 --- loss:0.199, Epoch accuracy:93.42%, Validation loss:2.692, Validation accuracy:40.82%
# Epoch 62: iteration 30/30
# Epoch 62 --- loss:0.165, Epoch accuracy:94.65%, Validation loss:3.507, Validation accuracy:46.94%
# Epoch 63: iteration 30/30
# Epoch 63 --- loss:0.225, Epoch accuracy:92.59%, Validation loss:5.135, Validation accuracy:14.29%
# Epoch 64: iteration 30/30
# Epoch 64 --- loss:0.162, Epoch accuracy:94.44%, Validation loss:1.325, Validation accuracy:59.18%
# Epoch 65: iteration 30/30
# Epoch 65 --- loss:0.156, Epoch accuracy:95.88%, Validation loss:2.181, Validation accuracy:46.94%
# Epoch 66: iteration 30/30
# Epoch 66 --- loss:0.167, Epoch accuracy:94.86%, Validation loss:5.560, Validation accuracy:42.86%
# Epoch 67: iteration 30/30
# Epoch 67 --- loss:0.180, Epoch accuracy:94.86%, Validation loss:1.164, Validation accuracy:59.18%
# Epoch 68: iteration 30/30
# Epoch 68 --- loss:0.201, Epoch accuracy:94.03%, Validation loss:3.027, Validation accuracy:48.98%
# Epoch 69: iteration 30/30
# Epoch 69 --- loss:0.211, Epoch accuracy:91.98%, Validation loss:2.318, Validation accuracy:55.10%
# Epoch 70: iteration 30/30
# Epoch 70 --- loss:0.134, Epoch accuracy:95.88%, Validation loss:4.058, Validation accuracy:32.65%
# Epoch 71: iteration 30/30
# Epoch 71 --- loss:0.142, Epoch accuracy:95.06%, Validation loss:1.530, Validation accuracy:59.18%
# Epoch 72: iteration 30/30
# Epoch 72 --- loss:0.181, Epoch accuracy:94.03%, Validation loss:7.483, Validation accuracy:18.37%
# Epoch 73: iteration 30/30
# Epoch 73 --- loss:0.163, Epoch accuracy:95.68%, Validation loss:4.156, Validation accuracy:42.86%
# Epoch 74: iteration 30/30
# Epoch 74 --- loss:0.116, Epoch accuracy:97.33%, Validation loss:2.483, Validation accuracy:40.82%
# Epoch 75: iteration 30/30
# Epoch 75 --- loss:0.115, Epoch accuracy:96.50%, Validation loss:5.217, Validation accuracy:26.53%
# Epoch 76: iteration 30/30
# Epoch 76 --- loss:0.189, Epoch accuracy:93.00%, Validation loss:6.775, Validation accuracy:16.33%
# Epoch 77: iteration 30/30
# Epoch 77 --- loss:0.142, Epoch accuracy:94.65%, Validation loss:0.749, Validation accuracy:79.59%
# Epoch 78: iteration 30/30
# Epoch 78 --- loss:0.104, Epoch accuracy:96.09%, Validation loss:6.109, Validation accuracy:26.53%
# Epoch 79: iteration 30/30
# Epoch 79 --- loss:0.115, Epoch accuracy:96.50%, Validation loss:3.161, Validation accuracy:44.90%
# Epoch 80: iteration 30/30
# Epoch 80 --- loss:0.122, Epoch accuracy:96.09%, Validation loss:2.151, Validation accuracy:57.14%
# Epoch 81: iteration 30/30
# Epoch 81 --- loss:0.103, Epoch accuracy:96.91%, Validation loss:2.331, Validation accuracy:46.94%
# Epoch 82: iteration 30/30
# Epoch 82 --- loss:0.124, Epoch accuracy:95.68%, Validation loss:0.521, Validation accuracy:79.59%
# Epoch 83: iteration 30/30
# Epoch 83 --- loss:0.118, Epoch accuracy:95.47%, Validation loss:1.067, Validation accuracy:67.35%
# Epoch 84: iteration 30/30
# Epoch 84 --- loss:0.100, Epoch accuracy:96.50%, Validation loss:3.460, Validation accuracy:44.90%
# Epoch 85: iteration 30/30
# Epoch 85 --- loss:0.162, Epoch accuracy:93.83%, Validation loss:4.047, Validation accuracy:44.90%
# Epoch 86: iteration 30/30
# Epoch 86 --- loss:0.152, Epoch accuracy:96.09%, Validation loss:5.060, Validation accuracy:30.61%
# Epoch 87: iteration 30/30
# Epoch 87 --- loss:0.098, Epoch accuracy:96.91%, Validation loss:3.156, Validation accuracy:46.94%
# Epoch 88: iteration 30/30
# Epoch 88 --- loss:0.078, Epoch accuracy:97.12%, Validation loss:1.702, Validation accuracy:57.14%
# Epoch 89: iteration 30/30
# Epoch 89 --- loss:0.086, Epoch accuracy:97.74%, Validation loss:0.758, Validation accuracy:65.31%
# Epoch 90: iteration 30/30
# Epoch 90 --- loss:0.128, Epoch accuracy:94.86%, Validation loss:5.661, Validation accuracy:32.65%
# Epoch 91: iteration 30/30
# Epoch 91 --- loss:0.109, Epoch accuracy:97.12%, Validation loss:2.523, Validation accuracy:46.94%
# Epoch 92: iteration 30/30
# Epoch 92 --- loss:0.108, Epoch accuracy:95.47%, Validation loss:1.975, Validation accuracy:55.10%
# Epoch 93: iteration 30/30
# Epoch 93 --- loss:0.123, Epoch accuracy:95.27%, Validation loss:3.472, Validation accuracy:65.31%
# Epoch 94: iteration 30/30
# Epoch 94 --- loss:0.121, Epoch accuracy:95.47%, Validation loss:4.295, Validation accuracy:36.73%
# Epoch 95: iteration 30/30
# Epoch 95 --- loss:0.113, Epoch accuracy:95.47%, Validation loss:0.984, Validation accuracy:77.55%
# Epoch 96: iteration 30/30
# Epoch 96 --- loss:0.097, Epoch accuracy:96.50%, Validation loss:1.048, Validation accuracy:65.31%
# Epoch 97: iteration 30/30
# Epoch 97 --- loss:0.083, Epoch accuracy:97.53%, Validation loss:1.709, Validation accuracy:61.22%
# Epoch 98: iteration 30/30
# Epoch 98 --- loss:0.116, Epoch accuracy:95.47%, Validation loss:14.223, Validation accuracy:28.57%
# Epoch 99: iteration 30/30
# Epoch 99 --- loss:0.118, Epoch accuracy:95.27%, Validation loss:2.101, Validation accuracy:55.10%
# Epoch 100: iteration 30/30
# Epoch 100 --- loss:0.113, Epoch accuracy:95.88%, Validation loss:1.567, Validation accuracy:51.02%
# Epoch 101: iteration 30/30
# Epoch 101 --- loss:0.088, Epoch accuracy:96.30%, Validation loss:1.841, Validation accuracy:55.10%
# Epoch 102: iteration 30/30
# Epoch 102 --- loss:0.076, Epoch accuracy:97.74%, Validation loss:0.729, Validation accuracy:71.43%
# Epoch 103: iteration 30/30
# Epoch 103 --- loss:0.099, Epoch accuracy:96.30%, Validation loss:1.070, Validation accuracy:67.35%
# Epoch 104: iteration 30/30
# Epoch 104 --- loss:0.099, Epoch accuracy:96.30%, Validation loss:3.391, Validation accuracy:55.10%
# Epoch 105: iteration 30/30
# Epoch 105 --- loss:0.110, Epoch accuracy:94.86%, Validation loss:5.943, Validation accuracy:42.86%
# Epoch 106: iteration 30/30
# Epoch 106 --- loss:0.116, Epoch accuracy:96.30%, Validation loss:1.708, Validation accuracy:55.10%
# Epoch 107: iteration 30/30
# Epoch 107 --- loss:0.061, Epoch accuracy:98.15%, Validation loss:0.765, Validation accuracy:67.35%
# Epoch 108: iteration 30/30
# Epoch 108 --- loss:0.040, Epoch accuracy:98.35%, Validation loss:1.095, Validation accuracy:69.39%
# Epoch 109: iteration 30/30
# Epoch 109 --- loss:0.051, Epoch accuracy:97.74%, Validation loss:0.932, Validation accuracy:65.31%
# Epoch 110: iteration 30/30
# Epoch 110 --- loss:0.063, Epoch accuracy:97.74%, Validation loss:2.876, Validation accuracy:40.82%
# Epoch 111: iteration 30/30
# Epoch 111 --- loss:0.046, Epoch accuracy:98.15%, Validation loss:1.202, Validation accuracy:61.22%
# Epoch 112: iteration 30/30
# Epoch 112 --- loss:0.053, Epoch accuracy:97.74%, Validation loss:2.036, Validation accuracy:44.90%
# Epoch 113: iteration 30/30
# Epoch 113 --- loss:0.067, Epoch accuracy:97.12%, Validation loss:2.351, Validation accuracy:51.02%
# Epoch 114: iteration 30/30
# Epoch 114 --- loss:0.053, Epoch accuracy:97.74%, Validation loss:4.154, Validation accuracy:44.90%
# Epoch 115: iteration 30/30
# Epoch 115 --- loss:0.058, Epoch accuracy:97.33%, Validation loss:4.608, Validation accuracy:40.82%
# Epoch 116: iteration 30/30
# Epoch 116 --- loss:0.051, Epoch accuracy:97.94%, Validation loss:0.999, Validation accuracy:67.35%
# Epoch 117: iteration 30/30
# Epoch 117 --- loss:0.034, Epoch accuracy:98.15%, Validation loss:1.618, Validation accuracy:59.18%
# Epoch 118: iteration 30/30
# Epoch 118 --- loss:0.033, Epoch accuracy:98.35%, Validation loss:2.020, Validation accuracy:42.86%
# Epoch 119: iteration 30/30
# Epoch 119 --- loss:0.040, Epoch accuracy:98.15%, Validation loss:2.997, Validation accuracy:46.94%
# Epoch 120: iteration 30/30
# Epoch 120 --- loss:0.055, Epoch accuracy:97.53%, Validation loss:1.925, Validation accuracy:55.10%
# Epoch 121: iteration 30/30
# Epoch 121 --- loss:0.042, Epoch accuracy:97.94%, Validation loss:1.426, Validation accuracy:53.06%
# Epoch 122: iteration 30/30
# Epoch 122 --- loss:0.032, Epoch accuracy:98.35%, Validation loss:2.456, Validation accuracy:55.10%
# Epoch 123: iteration 30/30
# Epoch 123 --- loss:0.054, Epoch accuracy:97.33%, Validation loss:2.341, Validation accuracy:38.78%
# Epoch 124: iteration 30/30
# Epoch 124 --- loss:0.055, Epoch accuracy:97.33%, Validation loss:2.105, Validation accuracy:53.06%
# Epoch 125: iteration 30/30
# Epoch 125 --- loss:0.059, Epoch accuracy:96.71%, Validation loss:2.949, Validation accuracy:46.94%
# Epoch 126: iteration 30/30
# Epoch 126 --- loss:0.082, Epoch accuracy:96.30%, Validation loss:1.834, Validation accuracy:63.27%
# Epoch 127: iteration 30/30
# Epoch 127 --- loss:0.079, Epoch accuracy:96.91%, Validation loss:10.289, Validation accuracy:38.78%
# Epoch 128: iteration 30/30
# Epoch 128 --- loss:0.095, Epoch accuracy:95.88%, Validation loss:1.526, Validation accuracy:59.18%
# Epoch 129: iteration 30/30
# Epoch 129 --- loss:0.076, Epoch accuracy:96.71%, Validation loss:1.947, Validation accuracy:55.10%
# Epoch 130: iteration 30/30
# Epoch 130 --- loss:0.052, Epoch accuracy:97.53%, Validation loss:1.038, Validation accuracy:63.27%
# Epoch 131: iteration 30/30
# Epoch 131 --- loss:0.045, Epoch accuracy:97.74%, Validation loss:2.423, Validation accuracy:55.10%
# Epoch 132: iteration 30/30
# Epoch 132 --- loss:0.040, Epoch accuracy:97.94%, Validation loss:2.435, Validation accuracy:53.06%
# Epoch 133: iteration 30/30
# Epoch 133 --- loss:0.047, Epoch accuracy:97.74%, Validation loss:0.977, Validation accuracy:81.63%
# Epoch 134: iteration 30/30
# Epoch 134 --- loss:0.038, Epoch accuracy:97.94%, Validation loss:2.084, Validation accuracy:53.06%
# Epoch 135: iteration 30/30
# Epoch 135 --- loss:0.028, Epoch accuracy:98.35%, Validation loss:0.775, Validation accuracy:71.43%
# Epoch 136: iteration 30/30
# Epoch 136 --- loss:0.030, Epoch accuracy:98.56%, Validation loss:0.971, Validation accuracy:73.47%
# Epoch 137: iteration 30/30
# Epoch 137 --- loss:0.021, Epoch accuracy:98.77%, Validation loss:0.617, Validation accuracy:75.51%
# Epoch 138: iteration 30/30
# Epoch 138 --- loss:0.031, Epoch accuracy:98.35%, Validation loss:1.812, Validation accuracy:73.47%
# Epoch 139: iteration 30/30
# Epoch 139 --- loss:0.035, Epoch accuracy:98.15%, Validation loss:2.432, Validation accuracy:53.06%
# Epoch 140: iteration 30/30
# Epoch 140 --- loss:0.045, Epoch accuracy:97.53%, Validation loss:2.202, Validation accuracy:46.94%
# Epoch 141: iteration 30/30
# Epoch 141 --- loss:0.055, Epoch accuracy:97.74%, Validation loss:2.343, Validation accuracy:32.65%
# Epoch 142: iteration 30/30
# Epoch 142 --- loss:0.041, Epoch accuracy:98.15%, Validation loss:1.507, Validation accuracy:71.43%
# Epoch 143: iteration 30/30
# Epoch 143 --- loss:0.053, Epoch accuracy:96.71%, Validation loss:2.200, Validation accuracy:48.98%
# Epoch 144: iteration 30/30
# Epoch 144 --- loss:0.036, Epoch accuracy:98.15%, Validation loss:1.159, Validation accuracy:71.43%
# Epoch 145: iteration 30/30
# Epoch 145 --- loss:0.076, Epoch accuracy:95.88%, Validation loss:7.560, Validation accuracy:36.73%
# Epoch 146: iteration 30/30
# Epoch 146 --- loss:0.133, Epoch accuracy:94.65%, Validation loss:5.213, Validation accuracy:30.61%
# Epoch 147: iteration 30/30
# Epoch 147 --- loss:0.127, Epoch accuracy:94.24%, Validation loss:8.830, Validation accuracy:36.73%
# Epoch 148: iteration 30/30
# Epoch 148 --- loss:0.087, Epoch accuracy:96.71%, Validation loss:4.329, Validation accuracy:36.73%
# Epoch 149: iteration 30/30
# Epoch 149 --- loss:0.055, Epoch accuracy:97.33%, Validation loss:1.741, Validation accuracy:69.39%
# Epoch 150: iteration 30/30
# Epoch 150 --- loss:0.023, Epoch accuracy:98.77%, Validation loss:1.677, Validation accuracy:55.10%
# Epoch 151: iteration 30/30
# Epoch 151 --- loss:0.026, Epoch accuracy:98.56%, Validation loss:2.336, Validation accuracy:55.10%
# Epoch 152: iteration 30/30
# Epoch 152 --- loss:0.067, Epoch accuracy:96.50%, Validation loss:1.549, Validation accuracy:61.22%
# Epoch 153: iteration 30/30
# Epoch 153 --- loss:0.046, Epoch accuracy:97.74%, Validation loss:6.482, Validation accuracy:24.49%
# Epoch 154: iteration 30/30
# Epoch 154 --- loss:0.058, Epoch accuracy:97.53%, Validation loss:1.663, Validation accuracy:55.10%
# Epoch 155: iteration 30/30
# Epoch 155 --- loss:0.036, Epoch accuracy:97.74%, Validation loss:1.098, Validation accuracy:61.22%
# Epoch 156: iteration 30/30
# Epoch 156 --- loss:0.051, Epoch accuracy:97.74%, Validation loss:1.100, Validation accuracy:65.31%
# Epoch 157: iteration 30/30
# Epoch 157 --- loss:0.057, Epoch accuracy:96.30%, Validation loss:3.875, Validation accuracy:44.90%
# Epoch 158: iteration 30/30
# Epoch 158 --- loss:0.053, Epoch accuracy:97.53%, Validation loss:1.588, Validation accuracy:59.18%
# Epoch 159: iteration 30/30
# Epoch 159 --- loss:0.056, Epoch accuracy:96.91%, Validation loss:1.180, Validation accuracy:65.31%
# Epoch 160: iteration 30/30
# Epoch 160 --- loss:0.053, Epoch accuracy:97.33%, Validation loss:4.309, Validation accuracy:46.94%
# Epoch 161: iteration 30/30
# Epoch 161 --- loss:0.045, Epoch accuracy:97.94%, Validation loss:1.702, Validation accuracy:53.06%
# Epoch 162: iteration 30/30
# Epoch 162 --- loss:0.034, Epoch accuracy:98.15%, Validation loss:2.582, Validation accuracy:57.14%
# Epoch 163: iteration 30/30
# Epoch 163 --- loss:0.036, Epoch accuracy:98.15%, Validation loss:1.473, Validation accuracy:51.02%
# Epoch 164: iteration 30/30
# Epoch 164 --- loss:0.068, Epoch accuracy:96.91%, Validation loss:8.032, Validation accuracy:18.37%
# Epoch 165: iteration 30/30
# Epoch 165 --- loss:0.068, Epoch accuracy:97.33%, Validation loss:4.399, Validation accuracy:40.82%
# Epoch 166: iteration 30/30
# Epoch 166 --- loss:0.054, Epoch accuracy:97.53%, Validation loss:3.534, Validation accuracy:30.61%
# Epoch 167: iteration 30/30
# Epoch 167 --- loss:0.058, Epoch accuracy:97.12%, Validation loss:5.043, Validation accuracy:51.02%
# Epoch 168: iteration 30/30
# Epoch 168 --- loss:0.033, Epoch accuracy:98.35%, Validation loss:2.065, Validation accuracy:61.22%
# Epoch 169: iteration 30/30
# Epoch 169 --- loss:0.019, Epoch accuracy:98.77%, Validation loss:0.955, Validation accuracy:73.47%
# Epoch 170: iteration 30/30
# Epoch 170 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:0.774, Validation accuracy:79.59%
# Epoch 171: iteration 30/30
# Epoch 171 --- loss:0.013, Epoch accuracy:98.56%, Validation loss:0.612, Validation accuracy:77.55%
# Epoch 172: iteration 30/30
# Epoch 172 --- loss:0.018, Epoch accuracy:98.35%, Validation loss:1.482, Validation accuracy:61.22%
# Epoch 173: iteration 30/30
# Epoch 173 --- loss:0.017, Epoch accuracy:98.35%, Validation loss:0.481, Validation accuracy:83.67%
# Epoch 174: iteration 30/30
# Epoch 174 --- loss:0.014, Epoch accuracy:98.56%, Validation loss:0.764, Validation accuracy:75.51%
# Epoch 175: iteration 30/30
# Epoch 175 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:1.415, Validation accuracy:57.14%
# Epoch 176: iteration 30/30
# Epoch 176 --- loss:0.017, Epoch accuracy:98.56%, Validation loss:0.901, Validation accuracy:77.55%
# Epoch 177: iteration 30/30
# Epoch 177 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:0.545, Validation accuracy:83.67%
# Epoch 178: iteration 30/30
# Epoch 178 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:1.581, Validation accuracy:55.10%
# Epoch 179: iteration 30/30
# Epoch 179 --- loss:0.025, Epoch accuracy:98.56%, Validation loss:3.276, Validation accuracy:55.10%
# Epoch 180: iteration 30/30
# Epoch 180 --- loss:0.029, Epoch accuracy:97.94%, Validation loss:2.109, Validation accuracy:48.98%
# Epoch 181: iteration 30/30
# Epoch 181 --- loss:0.030, Epoch accuracy:97.74%, Validation loss:1.712, Validation accuracy:69.39%
# Epoch 182: iteration 30/30
# Epoch 182 --- loss:0.022, Epoch accuracy:98.56%, Validation loss:1.405, Validation accuracy:67.35%
# Epoch 183: iteration 30/30
# Epoch 183 --- loss:0.018, Epoch accuracy:98.56%, Validation loss:1.315, Validation accuracy:63.27%
# Epoch 184: iteration 30/30
# Epoch 184 --- loss:0.021, Epoch accuracy:98.35%, Validation loss:2.294, Validation accuracy:46.94%
# Epoch 185: iteration 30/30
# Epoch 185 --- loss:0.020, Epoch accuracy:98.35%, Validation loss:1.999, Validation accuracy:53.06%
# Epoch 186: iteration 30/30
# Epoch 186 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.924, Validation accuracy:73.47%
# Epoch 187: iteration 30/30
# Epoch 187 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.744, Validation accuracy:73.47%
# Epoch 188: iteration 30/30
# Epoch 188 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.520, Validation accuracy:81.63%
# Epoch 189: iteration 30/30
# Epoch 189 --- loss:0.015, Epoch accuracy:98.56%, Validation loss:0.646, Validation accuracy:85.71%
# Epoch 190: iteration 30/30
# Epoch 190 --- loss:0.042, Epoch accuracy:97.53%, Validation loss:3.490, Validation accuracy:42.86%
# Epoch 191: iteration 30/30
# Epoch 191 --- loss:0.068, Epoch accuracy:96.91%, Validation loss:4.737, Validation accuracy:34.69%
# Epoch 192: iteration 30/30
# Epoch 192 --- loss:0.052, Epoch accuracy:97.53%, Validation loss:4.444, Validation accuracy:40.82%
# Epoch 193: iteration 30/30
# Epoch 193 --- loss:0.037, Epoch accuracy:98.35%, Validation loss:2.142, Validation accuracy:38.78%
# Epoch 194: iteration 30/30
# Epoch 194 --- loss:0.034, Epoch accuracy:98.15%, Validation loss:1.493, Validation accuracy:69.39%
# Epoch 195: iteration 30/30
# Epoch 195 --- loss:0.018, Epoch accuracy:98.35%, Validation loss:1.583, Validation accuracy:55.10%
# Epoch 196: iteration 30/30
# Epoch 196 --- loss:0.022, Epoch accuracy:98.56%, Validation loss:0.594, Validation accuracy:77.55%
# Epoch 197: iteration 30/30
# Epoch 197 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:0.853, Validation accuracy:79.59%
# Epoch 198: iteration 30/30
# Epoch 198 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.633, Validation accuracy:77.55%
# Epoch 199: iteration 30/30
# Epoch 199 --- loss:0.014, Epoch accuracy:98.35%, Validation loss:1.613, Validation accuracy:61.22%
# Epoch 200: iteration 30/30
# Epoch 200 --- loss:0.023, Epoch accuracy:98.35%, Validation loss:1.229, Validation accuracy:69.39%
# Epoch 201: iteration 30/30
# Epoch 201 --- loss:0.035, Epoch accuracy:97.33%, Validation loss:0.861, Validation accuracy:59.18%
# Epoch 202: iteration 30/30
# Epoch 202 --- loss:0.038, Epoch accuracy:98.15%, Validation loss:5.699, Validation accuracy:24.49%
# Epoch 203: iteration 30/30
# Epoch 203 --- loss:0.033, Epoch accuracy:98.15%, Validation loss:3.396, Validation accuracy:51.02%
# Epoch 204: iteration 30/30
# Epoch 204 --- loss:0.035, Epoch accuracy:97.74%, Validation loss:3.051, Validation accuracy:44.90%
# Epoch 205: iteration 30/30
# Epoch 205 --- loss:0.017, Epoch accuracy:98.56%, Validation loss:1.407, Validation accuracy:69.39%
# Epoch 206: iteration 30/30
# Epoch 206 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:2.930, Validation accuracy:53.06%
# Epoch 207: iteration 30/30
# Epoch 207 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.666, Validation accuracy:83.67%
# Epoch 208: iteration 30/30
# Epoch 208 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.999, Validation accuracy:71.43%
# Epoch 209: iteration 30/30
# Epoch 209 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.635, Validation accuracy:73.47%
# Epoch 210: iteration 30/30
# Epoch 210 --- loss:0.018, Epoch accuracy:98.35%, Validation loss:1.056, Validation accuracy:75.51%
# Epoch 211: iteration 30/30
# Epoch 211 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.763, Validation accuracy:61.22%
# Epoch 212: iteration 30/30
# Epoch 212 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.664, Validation accuracy:81.63%
# Epoch 213: iteration 30/30
# Epoch 213 --- loss:0.015, Epoch accuracy:98.35%, Validation loss:0.794, Validation accuracy:79.59%
# Epoch 214: iteration 30/30
# Epoch 214 --- loss:0.015, Epoch accuracy:98.35%, Validation loss:1.513, Validation accuracy:53.06%
# Epoch 215: iteration 30/30
# Epoch 215 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.830, Validation accuracy:79.59%
# Epoch 216: iteration 30/30
# Epoch 216 --- loss:0.013, Epoch accuracy:98.56%, Validation loss:0.707, Validation accuracy:77.55%
# Epoch 217: iteration 30/30
# Epoch 217 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.839, Validation accuracy:77.55%
# Epoch 218: iteration 30/30
# Epoch 218 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.705, Validation accuracy:79.59%
# Epoch 219: iteration 30/30
# Epoch 219 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.995, Validation accuracy:71.43%
# Epoch 220: iteration 30/30
# Epoch 220 --- loss:0.018, Epoch accuracy:98.35%, Validation loss:1.612, Validation accuracy:57.14%
# Epoch 221: iteration 30/30
# Epoch 221 --- loss:0.019, Epoch accuracy:98.35%, Validation loss:2.475, Validation accuracy:44.90%
# Epoch 222: iteration 30/30
# Epoch 222 --- loss:0.022, Epoch accuracy:98.15%, Validation loss:12.039, Validation accuracy:14.29%
# Epoch 223: iteration 30/30
# Epoch 223 --- loss:0.017, Epoch accuracy:98.56%, Validation loss:2.157, Validation accuracy:59.18%
# Epoch 224: iteration 30/30
# Epoch 224 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:0.568, Validation accuracy:85.71%
# Epoch 225: iteration 30/30
# Epoch 225 --- loss:0.016, Epoch accuracy:98.35%, Validation loss:1.801, Validation accuracy:63.27%
# Epoch 226: iteration 30/30
# Epoch 226 --- loss:0.017, Epoch accuracy:98.77%, Validation loss:0.868, Validation accuracy:75.51%
# Epoch 227: iteration 30/30
# Epoch 227 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.625, Validation accuracy:79.59%
# Epoch 228: iteration 30/30
# Epoch 228 --- loss:0.022, Epoch accuracy:98.15%, Validation loss:2.367, Validation accuracy:46.94%
# Epoch 229: iteration 30/30
# Epoch 229 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.075, Validation accuracy:69.39%
# Epoch 230: iteration 30/30
# Epoch 230 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.498, Validation accuracy:83.67%
# Epoch 231: iteration 30/30
# Epoch 231 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.638, Validation accuracy:81.63%
# Epoch 232: iteration 30/30
# Epoch 232 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.734, Validation accuracy:79.59%
# Epoch 233: iteration 30/30
# Epoch 233 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:1.075, Validation accuracy:71.43%
# Epoch 234: iteration 30/30
# Epoch 234 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.732, Validation accuracy:75.51%
# Epoch 235: iteration 30/30
# Epoch 235 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.781, Validation accuracy:73.47%
# Epoch 236: iteration 30/30
# Epoch 236 --- loss:0.011, Epoch accuracy:98.56%, Validation loss:0.555, Validation accuracy:83.67%
# Epoch 237: iteration 30/30
# Epoch 237 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.708, Validation accuracy:79.59%
# Epoch 238: iteration 30/30
# Epoch 238 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:1.113, Validation accuracy:69.39%
# Epoch 239: iteration 30/30
# Epoch 239 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.639, Validation accuracy:77.55%
# Epoch 240: iteration 30/30
# Epoch 240 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.894, Validation accuracy:71.43%
# Epoch 241: iteration 30/30
# Epoch 241 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:2.119, Validation accuracy:69.39%
# Epoch 242: iteration 30/30
# Epoch 242 --- loss:0.015, Epoch accuracy:98.35%, Validation loss:2.051, Validation accuracy:61.22%
# Epoch 243: iteration 30/30
# Epoch 243 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:0.707, Validation accuracy:75.51%
# Epoch 244: iteration 30/30
# Epoch 244 --- loss:0.018, Epoch accuracy:98.15%, Validation loss:3.382, Validation accuracy:51.02%
# Epoch 245: iteration 30/30
# Epoch 245 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.923, Validation accuracy:73.47%
# Epoch 246: iteration 30/30
# Epoch 246 --- loss:0.008, Epoch accuracy:98.56%, Validation loss:1.278, Validation accuracy:61.22%
# Epoch 247: iteration 30/30
# Epoch 247 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.590, Validation accuracy:83.67%
# Epoch 248: iteration 30/30
# Epoch 248 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:1.849, Validation accuracy:53.06%
# Epoch 249: iteration 30/30
# Epoch 249 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:6.435, Validation accuracy:28.57%
# Epoch 250: iteration 30/30
# Epoch 250 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:1.117, Validation accuracy:73.47%
# Epoch 251: iteration 30/30
# Epoch 251 --- loss:0.011, Epoch accuracy:98.56%, Validation loss:6.184, Validation accuracy:36.73%
# Epoch 252: iteration 30/30
# Epoch 252 --- loss:0.023, Epoch accuracy:98.56%, Validation loss:5.247, Validation accuracy:36.73%
# Epoch 253: iteration 30/30
# Epoch 253 --- loss:0.020, Epoch accuracy:98.35%, Validation loss:1.844, Validation accuracy:61.22%
# Epoch 254: iteration 30/30
# Epoch 254 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:1.925, Validation accuracy:53.06%
# Epoch 255: iteration 30/30
# Epoch 255 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:2.668, Validation accuracy:55.10%
# Epoch 256: iteration 30/30
# Epoch 256 --- loss:0.014, Epoch accuracy:98.56%, Validation loss:1.145, Validation accuracy:73.47%
# Epoch 257: iteration 30/30
# Epoch 257 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:1.734, Validation accuracy:61.22%
# Epoch 258: iteration 30/30
# Epoch 258 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:1.254, Validation accuracy:63.27%
# Epoch 259: iteration 30/30
# Epoch 259 --- loss:0.024, Epoch accuracy:98.15%, Validation loss:7.741, Validation accuracy:34.69%
# Epoch 260: iteration 30/30
# Epoch 260 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:1.432, Validation accuracy:63.27%
# Epoch 261: iteration 30/30
# Epoch 261 --- loss:0.045, Epoch accuracy:97.94%, Validation loss:0.736, Validation accuracy:77.55%
# Epoch 262: iteration 30/30
# Epoch 262 --- loss:0.017, Epoch accuracy:98.77%, Validation loss:1.329, Validation accuracy:63.27%
# Epoch 263: iteration 30/30
# Epoch 263 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.680, Validation accuracy:81.63%
# Epoch 264: iteration 30/30
# Epoch 264 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.751, Validation accuracy:81.63%
# Epoch 265: iteration 30/30
# Epoch 265 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.698, Validation accuracy:79.59%
# Epoch 266: iteration 30/30
# Epoch 266 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.993, Validation accuracy:71.43%
# Epoch 267: iteration 30/30
# Epoch 267 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.462, Validation accuracy:83.67%
# Epoch 268: iteration 30/30
# Epoch 268 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.812, Validation accuracy:75.51%
# Epoch 269: iteration 30/30
# Epoch 269 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.420, Validation accuracy:85.71%
# Epoch 270: iteration 30/30
# Epoch 270 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.619, Validation accuracy:75.51%
# Epoch 271: iteration 30/30
# Epoch 271 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:2.565, Validation accuracy:61.22%
# Epoch 272: iteration 30/30
# Epoch 272 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.627, Validation accuracy:87.76%
# Epoch 273: iteration 30/30
# Epoch 273 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:1.308, Validation accuracy:71.43%
# Epoch 274: iteration 30/30
# Epoch 274 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:1.147, Validation accuracy:69.39%
# Epoch 275: iteration 30/30
# Epoch 275 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.706, Validation accuracy:73.47%
# Epoch 276: iteration 30/30
# Epoch 276 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.568, Validation accuracy:83.67%
# Epoch 277: iteration 30/30
# Epoch 277 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.732, Validation accuracy:77.55%
# Epoch 278: iteration 30/30
# Epoch 278 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.716, Validation accuracy:79.59%
# Epoch 279: iteration 30/30
# Epoch 279 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.585, Validation accuracy:81.63%
# Epoch 280: iteration 30/30
# Epoch 280 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.696, Validation accuracy:83.67%
# Epoch 281: iteration 30/30
# Epoch 281 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.974, Validation accuracy:73.47%
# Epoch 282: iteration 30/30
# Epoch 282 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.749, Validation accuracy:83.67%
# Epoch 283: iteration 30/30
# Epoch 283 --- loss:0.007, Epoch accuracy:98.56%, Validation loss:1.315, Validation accuracy:71.43%
# Epoch 284: iteration 30/30
# Epoch 284 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.838, Validation accuracy:73.47%
# Epoch 285: iteration 30/30
# Epoch 285 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.586, Validation accuracy:77.55%
# Epoch 286: iteration 30/30
# Epoch 286 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:1.065, Validation accuracy:75.51%
# Epoch 287: iteration 30/30
# Epoch 287 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.963, Validation accuracy:69.39%
# Epoch 288: iteration 30/30
# Epoch 288 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.648, Validation accuracy:79.59%
# Epoch 289: iteration 30/30
# Epoch 289 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.648, Validation accuracy:85.71%
# Epoch 290: iteration 30/30
# Epoch 290 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.652, Validation accuracy:81.63%
# Epoch 291: iteration 30/30
# Epoch 291 --- loss:0.008, Epoch accuracy:98.56%, Validation loss:1.179, Validation accuracy:67.35%
# Epoch 292: iteration 30/30
# Epoch 292 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.815, Validation accuracy:73.47%
# Epoch 293: iteration 30/30
# Epoch 293 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.921, Validation accuracy:65.31%
# Epoch 294: iteration 30/30
# Epoch 294 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.736, Validation accuracy:75.51%
# Epoch 295: iteration 30/30
# Epoch 295 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.688, Validation accuracy:75.51%
# Epoch 296: iteration 30/30
# Epoch 296 --- loss:0.002, Epoch accuracy:98.77%, Validation loss:0.726, Validation accuracy:83.67%
# Epoch 297: iteration 30/30
# Epoch 297 --- loss:0.002, Epoch accuracy:98.77%, Validation loss:0.667, Validation accuracy:81.63%
# Epoch 298: iteration 30/30
# Epoch 298 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.645, Validation accuracy:79.59%
# Epoch 299: iteration 30/30
# Epoch 299 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.705, Validation accuracy:77.55%
#
#
# [*] done !
# [*] Best training loss - 0.0020150430395110765
# [*] Best validation loss - 0.4204741418361664
# A Jupyter Widget
# Epoch 0: iteration 29/29
# Epoch 0 --- loss:1.599, Epoch accuracy:32.70%, Validation loss:1.963, Validation accuracy:24.14%
# Epoch 1: iteration 29/29
# Epoch 1 --- loss:1.317, Epoch accuracy:44.23%, Validation loss:1.425, Validation accuracy:43.10%
# Epoch 2: iteration 29/29
# Epoch 2 --- loss:1.221, Epoch accuracy:46.96%, Validation loss:1.156, Validation accuracy:48.28%
# Epoch 3: iteration 29/29
# Epoch 3 --- loss:1.201, Epoch accuracy:51.36%, Validation loss:3.403, Validation accuracy:20.69%
# Epoch 4: iteration 29/29
# Epoch 4 --- loss:1.091, Epoch accuracy:57.02%, Validation loss:1.325, Validation accuracy:51.72%
# Epoch 5: iteration 29/29
# Epoch 5 --- loss:1.028, Epoch accuracy:60.17%, Validation loss:1.037, Validation accuracy:60.34%
# Epoch 6: iteration 29/29
# Epoch 6 --- loss:0.949, Epoch accuracy:63.31%, Validation loss:2.923, Validation accuracy:22.41%
# Epoch 7: iteration 29/29
# Epoch 7 --- loss:0.933, Epoch accuracy:65.41%, Validation loss:2.369, Validation accuracy:34.48%
# Epoch 8: iteration 29/29
# Epoch 8 --- loss:0.887, Epoch accuracy:65.62%, Validation loss:2.651, Validation accuracy:31.03%
# Epoch 9: iteration 29/29
# Epoch 9 --- loss:0.893, Epoch accuracy:66.25%, Validation loss:1.734, Validation accuracy:50.00%
# Epoch 10: iteration 29/29
# Epoch 10 --- loss:0.828, Epoch accuracy:66.67%, Validation loss:2.822, Validation accuracy:29.31%
# Epoch 11: iteration 29/29
# Epoch 11 --- loss:0.826, Epoch accuracy:66.25%, Validation loss:0.927, Validation accuracy:62.07%
# Epoch 12: iteration 29/29
# Epoch 12 --- loss:0.766, Epoch accuracy:66.04%, Validation loss:4.033, Validation accuracy:36.21%
# Epoch 13: iteration 29/29
# Epoch 13 --- loss:0.741, Epoch accuracy:70.02%, Validation loss:0.827, Validation accuracy:70.69%
# Epoch 14: iteration 29/29
# Epoch 14 --- loss:0.680, Epoch accuracy:75.05%, Validation loss:1.960, Validation accuracy:37.93%
# Epoch 15: iteration 29/29
# Epoch 15 --- loss:0.688, Epoch accuracy:73.79%, Validation loss:6.021, Validation accuracy:25.86%
# Epoch 16: iteration 29/29
# Epoch 16 --- loss:0.722, Epoch accuracy:71.28%, Validation loss:1.585, Validation accuracy:56.90%
# Epoch 17: iteration 29/29
# Epoch 17 --- loss:0.701, Epoch accuracy:72.54%, Validation loss:2.694, Validation accuracy:31.03%
# Epoch 18: iteration 29/29
# Epoch 18 --- loss:0.624, Epoch accuracy:75.47%, Validation loss:1.556, Validation accuracy:43.10%
# Epoch 19: iteration 29/29
# Epoch 19 --- loss:0.620, Epoch accuracy:74.84%, Validation loss:4.248, Validation accuracy:25.86%
# Epoch 20: iteration 29/29
# Epoch 20 --- loss:0.631, Epoch accuracy:73.38%, Validation loss:1.104, Validation accuracy:58.62%
# Epoch 21: iteration 29/29
# Epoch 21 --- loss:0.537, Epoch accuracy:76.94%, Validation loss:1.122, Validation accuracy:58.62%
# Epoch 22: iteration 29/29
# Epoch 22 --- loss:0.634, Epoch accuracy:74.00%, Validation loss:8.216, Validation accuracy:22.41%
# Epoch 23: iteration 29/29
# Epoch 23 --- loss:0.588, Epoch accuracy:76.73%, Validation loss:2.179, Validation accuracy:39.66%
# Epoch 24: iteration 29/29
# Epoch 24 --- loss:0.511, Epoch accuracy:80.08%, Validation loss:3.467, Validation accuracy:34.48%
# Epoch 25: iteration 29/29
# Epoch 25 --- loss:0.501, Epoch accuracy:80.50%, Validation loss:1.340, Validation accuracy:48.28%
# Epoch 26: iteration 29/29
# Epoch 26 --- loss:0.496, Epoch accuracy:79.87%, Validation loss:0.976, Validation accuracy:56.90%
# Epoch 27: iteration 29/29
# Epoch 27 --- loss:0.464, Epoch accuracy:81.76%, Validation loss:0.956, Validation accuracy:63.79%
# Epoch 28: iteration 29/29
# Epoch 28 --- loss:0.467, Epoch accuracy:80.29%, Validation loss:0.814, Validation accuracy:68.97%
# Epoch 29: iteration 29/29
# Epoch 29 --- loss:0.490, Epoch accuracy:80.50%, Validation loss:2.287, Validation accuracy:46.55%
# Epoch 30: iteration 29/29
# Epoch 30 --- loss:0.504, Epoch accuracy:77.78%, Validation loss:0.805, Validation accuracy:62.07%
# Epoch 31: iteration 29/29
# Epoch 31 --- loss:0.456, Epoch accuracy:82.18%, Validation loss:1.467, Validation accuracy:51.72%
# Epoch 32: iteration 29/29
# Epoch 32 --- loss:0.433, Epoch accuracy:81.97%, Validation loss:3.773, Validation accuracy:27.59%
# Epoch 33: iteration 29/29
# Epoch 33 --- loss:0.455, Epoch accuracy:80.50%, Validation loss:0.767, Validation accuracy:74.14%
# Epoch 34: iteration 29/29
# Epoch 34 --- loss:0.425, Epoch accuracy:83.02%, Validation loss:3.697, Validation accuracy:24.14%
# Epoch 35: iteration 29/29
# Epoch 35 --- loss:0.432, Epoch accuracy:83.86%, Validation loss:3.882, Validation accuracy:39.66%
# Epoch 36: iteration 29/29
# Epoch 36 --- loss:0.357, Epoch accuracy:85.12%, Validation loss:1.634, Validation accuracy:56.90%
# Epoch 37: iteration 29/29
# Epoch 37 --- loss:0.370, Epoch accuracy:85.95%, Validation loss:2.316, Validation accuracy:43.10%
# Epoch 38: iteration 29/29
# Epoch 38 --- loss:0.374, Epoch accuracy:85.12%, Validation loss:6.515, Validation accuracy:18.97%
# Epoch 39: iteration 29/29
# Epoch 39 --- loss:0.336, Epoch accuracy:87.84%, Validation loss:1.168, Validation accuracy:56.90%
# Epoch 40: iteration 29/29
# Epoch 40 --- loss:0.346, Epoch accuracy:86.37%, Validation loss:0.612, Validation accuracy:75.86%
# Epoch 41: iteration 29/29
# Epoch 41 --- loss:0.361, Epoch accuracy:85.32%, Validation loss:3.098, Validation accuracy:36.21%
# Epoch 42: iteration 29/29
# Epoch 42 --- loss:0.307, Epoch accuracy:87.21%, Validation loss:2.657, Validation accuracy:37.93%
# Epoch 43: iteration 29/29
# Epoch 43 --- loss:0.345, Epoch accuracy:84.70%, Validation loss:19.851, Validation accuracy:20.69%
# Epoch 44: iteration 29/29
# Epoch 44 --- loss:0.316, Epoch accuracy:88.47%, Validation loss:2.401, Validation accuracy:43.10%
# Epoch 45: iteration 29/29
# Epoch 45 --- loss:0.305, Epoch accuracy:88.05%, Validation loss:3.866, Validation accuracy:31.03%
# Epoch 46: iteration 29/29
# Epoch 46 --- loss:0.281, Epoch accuracy:88.89%, Validation loss:1.037, Validation accuracy:63.79%
# Epoch 47: iteration 29/29
# Epoch 47 --- loss:0.304, Epoch accuracy:87.84%, Validation loss:1.972, Validation accuracy:37.93%
# Epoch 48: iteration 29/29
# Epoch 48 --- loss:0.289, Epoch accuracy:88.26%, Validation loss:3.061, Validation accuracy:36.21%
# Epoch 49: iteration 29/29
# Epoch 49 --- loss:0.314, Epoch accuracy:86.79%, Validation loss:2.043, Validation accuracy:50.00%
# Epoch 50: iteration 29/29
# Epoch 50 --- loss:0.244, Epoch accuracy:90.57%, Validation loss:4.786, Validation accuracy:25.86%
# Epoch 51: iteration 29/29
# Epoch 51 --- loss:0.346, Epoch accuracy:85.53%, Validation loss:6.024, Validation accuracy:18.97%
# Epoch 52: iteration 29/29
# Epoch 52 --- loss:0.314, Epoch accuracy:86.37%, Validation loss:1.328, Validation accuracy:50.00%
# Epoch 53: iteration 29/29
# Epoch 53 --- loss:0.274, Epoch accuracy:89.10%, Validation loss:2.156, Validation accuracy:48.28%
# Epoch 54: iteration 29/29
# Epoch 54 --- loss:0.238, Epoch accuracy:90.78%, Validation loss:7.509, Validation accuracy:18.97%
# Epoch 55: iteration 29/29
# Epoch 55 --- loss:0.248, Epoch accuracy:92.03%, Validation loss:3.262, Validation accuracy:36.21%
# Epoch 56: iteration 29/29
# Epoch 56 --- loss:0.206, Epoch accuracy:92.66%, Validation loss:2.523, Validation accuracy:34.48%
# Epoch 57: iteration 29/29
# Epoch 57 --- loss:0.233, Epoch accuracy:91.40%, Validation loss:11.325, Validation accuracy:24.14%
# Epoch 58: iteration 29/29
# Epoch 58 --- loss:0.225, Epoch accuracy:90.57%, Validation loss:2.684, Validation accuracy:44.83%
# Epoch 59: iteration 29/29
# Epoch 59 --- loss:0.279, Epoch accuracy:88.68%, Validation loss:2.061, Validation accuracy:43.10%
# Epoch 60: iteration 29/29
# Epoch 60 --- loss:0.200, Epoch accuracy:93.08%, Validation loss:4.813, Validation accuracy:44.83%
# Epoch 61: iteration 29/29
# Epoch 61 --- loss:0.220, Epoch accuracy:92.03%, Validation loss:2.207, Validation accuracy:37.93%
# Epoch 62: iteration 29/29
# Epoch 62 --- loss:0.182, Epoch accuracy:92.66%, Validation loss:0.729, Validation accuracy:72.41%
# Epoch 63: iteration 29/29
# Epoch 63 --- loss:0.199, Epoch accuracy:91.82%, Validation loss:1.818, Validation accuracy:37.93%
# Epoch 64: iteration 29/29
# Epoch 64 --- loss:0.179, Epoch accuracy:93.29%, Validation loss:0.830, Validation accuracy:63.79%
# Epoch 65: iteration 29/29
# Epoch 65 --- loss:0.142, Epoch accuracy:94.34%, Validation loss:2.584, Validation accuracy:48.28%
# Epoch 66: iteration 29/29
# Epoch 66 --- loss:0.163, Epoch accuracy:93.50%, Validation loss:2.207, Validation accuracy:50.00%
# Epoch 67: iteration 29/29
# Epoch 67 --- loss:0.179, Epoch accuracy:92.66%, Validation loss:3.310, Validation accuracy:36.21%
# Epoch 68: iteration 29/29
# Epoch 68 --- loss:0.179, Epoch accuracy:92.66%, Validation loss:3.549, Validation accuracy:37.93%
# Epoch 69: iteration 29/29
# Epoch 69 --- loss:0.172, Epoch accuracy:92.45%, Validation loss:5.906, Validation accuracy:20.69%
# Epoch 70: iteration 29/29
# Epoch 70 --- loss:0.167, Epoch accuracy:92.03%, Validation loss:2.802, Validation accuracy:27.59%
# Epoch 71: iteration 29/29
# Epoch 71 --- loss:0.167, Epoch accuracy:92.45%, Validation loss:3.502, Validation accuracy:37.93%
# Epoch 72: iteration 29/29
# Epoch 72 --- loss:0.229, Epoch accuracy:89.94%, Validation loss:11.486, Validation accuracy:32.76%
# Epoch 73: iteration 29/29
# Epoch 73 --- loss:0.178, Epoch accuracy:93.08%, Validation loss:2.497, Validation accuracy:48.28%
# Epoch 74: iteration 29/29
# Epoch 74 --- loss:0.120, Epoch accuracy:94.97%, Validation loss:2.074, Validation accuracy:50.00%
# Epoch 75: iteration 29/29
# Epoch 75 --- loss:0.120, Epoch accuracy:94.55%, Validation loss:1.439, Validation accuracy:53.45%
# Epoch 76: iteration 29/29
# Epoch 76 --- loss:0.151, Epoch accuracy:93.71%, Validation loss:3.745, Validation accuracy:46.55%
# Epoch 77: iteration 29/29
# Epoch 77 --- loss:0.131, Epoch accuracy:94.76%, Validation loss:2.937, Validation accuracy:27.59%
# Epoch 78: iteration 29/29
# Epoch 78 --- loss:0.129, Epoch accuracy:94.34%, Validation loss:1.876, Validation accuracy:46.55%
# Epoch 79: iteration 29/29
# Epoch 79 --- loss:0.099, Epoch accuracy:96.02%, Validation loss:1.663, Validation accuracy:48.28%
# Epoch 80: iteration 29/29
# Epoch 80 --- loss:0.106, Epoch accuracy:94.34%, Validation loss:1.721, Validation accuracy:50.00%
# Epoch 81: iteration 29/29
# Epoch 81 --- loss:0.115, Epoch accuracy:94.55%, Validation loss:3.515, Validation accuracy:27.59%
# Epoch 82: iteration 29/29
# ...
# Epoch 174 --- loss:0.033, Epoch accuracy:99.35%, Validation loss:6.238, Validation accuracy:25.35%
# Epoch 175: iteration 29/29
# Epoch 175 --- loss:0.049, Epoch accuracy:98.49%, Validation loss:5.268, Validation accuracy:43.66%
# Epoch 176: iteration 29/29
# Epoch 176 --- loss:0.088, Epoch accuracy:97.20%, Validation loss:1.683, Validation accuracy:52.11%
# Epoch 177: iteration 29/29
# Epoch 177 --- loss:0.043, Epoch accuracy:99.78%, Validation loss:3.286, Validation accuracy:45.07%
# Epoch 178: iteration 29/29
# Epoch 178 --- loss:0.020, Epoch accuracy:99.78%, Validation loss:7.099, Validation accuracy:32.39%
# Epoch 179: iteration 29/29
# Epoch 179 --- loss:0.045, Epoch accuracy:98.06%, Validation loss:9.170, Validation accuracy:46.48%
# Epoch 180: iteration 29/29
# Epoch 180 --- loss:0.060, Epoch accuracy:98.28%, Validation loss:4.667, Validation accuracy:38.03%
# Epoch 181: iteration 29/29
# Epoch 181 --- loss:0.072, Epoch accuracy:97.84%, Validation loss:1.933, Validation accuracy:53.52%
# Epoch 182: iteration 29/29
# Epoch 182 --- loss:0.049, Epoch accuracy:98.71%, Validation loss:2.959, Validation accuracy:57.75%
# Epoch 183: iteration 29/29
# Epoch 183 --- loss:0.036, Epoch accuracy:99.57%, Validation loss:1.347, Validation accuracy:66.20%
# Epoch 184: iteration 29/29
# Epoch 184 --- loss:0.033, Epoch accuracy:99.57%, Validation loss:3.309, Validation accuracy:46.48%
# Epoch 185: iteration 29/29
# Epoch 185 --- loss:0.018, Epoch accuracy:99.78%, Validation loss:1.557, Validation accuracy:56.34%
# Epoch 186: iteration 29/29
# Epoch 186 --- loss:0.026, Epoch accuracy:99.78%, Validation loss:4.867, Validation accuracy:28.17%
# Epoch 187: iteration 29/29
# Epoch 187 --- loss:0.026, Epoch accuracy:99.57%, Validation loss:1.348, Validation accuracy:73.24%
# Epoch 188: iteration 29/29
# Epoch 188 --- loss:0.016, Epoch accuracy:100.00%, Validation loss:2.197, Validation accuracy:43.66%
# Epoch 189: iteration 29/29
# Epoch 189 --- loss:0.018, Epoch accuracy:100.00%, Validation loss:1.644, Validation accuracy:52.11%
# Epoch 190: iteration 29/29
# Epoch 190 --- loss:0.018, Epoch accuracy:100.00%, Validation loss:1.599, Validation accuracy:59.15%
# Epoch 191: iteration 29/29
# Epoch 191 --- loss:0.012, Epoch accuracy:99.78%, Validation loss:2.180, Validation accuracy:54.93%
# Epoch 192: iteration 29/29
# Epoch 192 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:1.316, Validation accuracy:60.56%
# Epoch 193: iteration 29/29
# Epoch 193 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:2.218, Validation accuracy:53.52%
# Epoch 194: iteration 29/29
# Epoch 194 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.588, Validation accuracy:50.70%
# Epoch 195: iteration 29/29
# Epoch 195 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:1.404, Validation accuracy:61.97%
# Epoch 196: iteration 29/29
# Epoch 196 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:2.543, Validation accuracy:52.11%
# Epoch 197: iteration 29/29
# Epoch 197 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.894, Validation accuracy:53.52%
# Epoch 198: iteration 29/29
# Epoch 198 --- loss:0.008, Epoch accuracy:99.78%, Validation loss:2.142, Validation accuracy:49.30%
# Epoch 199: iteration 29/29
# Epoch 199 --- loss:0.018, Epoch accuracy:100.00%, Validation loss:3.493, Validation accuracy:43.66%
# Epoch 200: iteration 29/29
# Epoch 200 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.813, Validation accuracy:57.75%
# Epoch 201: iteration 29/29
# Epoch 201 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.060, Validation accuracy:59.15%
# Epoch 202: iteration 29/29
# Epoch 202 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:2.017, Validation accuracy:56.34%
# Epoch 203: iteration 29/29
# Epoch 203 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.105, Validation accuracy:53.52%
# Epoch 204: iteration 29/29
# Epoch 204 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.800, Validation accuracy:57.75%
# Epoch 205: iteration 29/29
# Epoch 205 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:2.107, Validation accuracy:53.52%
# Epoch 206: iteration 29/29
# Epoch 206 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:2.026, Validation accuracy:57.75%
# Epoch 207: iteration 29/29
# Epoch 207 --- loss:0.027, Epoch accuracy:99.78%, Validation loss:4.182, Validation accuracy:42.25%
# Epoch 208: iteration 29/29
# Epoch 208 --- loss:0.052, Epoch accuracy:98.28%, Validation loss:3.550, Validation accuracy:50.70%
# Epoch 209: iteration 29/29
# Epoch 209 --- loss:0.032, Epoch accuracy:99.35%, Validation loss:2.553, Validation accuracy:59.15%
# Epoch 210: iteration 29/29
# Epoch 210 --- loss:0.025, Epoch accuracy:99.57%, Validation loss:2.748, Validation accuracy:46.48%
# Epoch 211: iteration 29/29
# Epoch 211 --- loss:0.048, Epoch accuracy:98.92%, Validation loss:2.048, Validation accuracy:52.11%
# Epoch 212: iteration 29/29
# Epoch 212 --- loss:0.034, Epoch accuracy:99.35%, Validation loss:2.219, Validation accuracy:52.11%
# Epoch 213: iteration 29/29
# Epoch 213 --- loss:0.040, Epoch accuracy:99.14%, Validation loss:3.006, Validation accuracy:46.48%
# Epoch 214: iteration 29/29
# Epoch 214 --- loss:0.018, Epoch accuracy:99.78%, Validation loss:2.040, Validation accuracy:47.89%
# Epoch 215: iteration 29/29
# Epoch 215 --- loss:0.017, Epoch accuracy:100.00%, Validation loss:1.678, Validation accuracy:59.15%
# Epoch 216: iteration 29/29
# Epoch 216 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:2.050, Validation accuracy:52.11%
# Epoch 217: iteration 29/29
# Epoch 217 --- loss:0.027, Epoch accuracy:99.35%, Validation loss:1.992, Validation accuracy:53.52%
# Epoch 218: iteration 29/29
# Epoch 218 --- loss:0.020, Epoch accuracy:99.57%, Validation loss:1.095, Validation accuracy:69.01%
# Epoch 219: iteration 29/29
# Epoch 219 --- loss:0.026, Epoch accuracy:99.57%, Validation loss:2.182, Validation accuracy:49.30%
# Epoch 220: iteration 29/29
# Epoch 220 --- loss:0.021, Epoch accuracy:99.35%, Validation loss:2.044, Validation accuracy:57.75%
# Epoch 221: iteration 29/29
# Epoch 221 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:3.542, Validation accuracy:43.66%
# Epoch 222: iteration 29/29
# Epoch 222 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:0.957, Validation accuracy:70.42%
# Epoch 223: iteration 29/29
# Epoch 223 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.972, Validation accuracy:56.34%
# Epoch 224: iteration 29/29
# Epoch 224 --- loss:0.013, Epoch accuracy:99.78%, Validation loss:2.482, Validation accuracy:56.34%
# Epoch 225: iteration 29/29
# Epoch 225 --- loss:0.019, Epoch accuracy:99.35%, Validation loss:0.931, Validation accuracy:73.24%
# Epoch 226: iteration 29/29
# Epoch 226 --- loss:0.018, Epoch accuracy:99.78%, Validation loss:3.852, Validation accuracy:38.03%
# Epoch 227: iteration 29/29
# Epoch 227 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:4.030, Validation accuracy:47.89%
# Epoch 228: iteration 29/29
# Epoch 228 --- loss:0.011, Epoch accuracy:99.78%, Validation loss:2.501, Validation accuracy:52.11%
# Epoch 229: iteration 29/29
# Epoch 229 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.797, Validation accuracy:53.52%
# Epoch 230: iteration 29/29
# Epoch 230 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:1.541, Validation accuracy:66.20%
# Epoch 231: iteration 29/29
# Epoch 231 --- loss:0.012, Epoch accuracy:99.78%, Validation loss:1.243, Validation accuracy:66.20%
# Epoch 232: iteration 29/29
# Epoch 232 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.118, Validation accuracy:57.75%
# Epoch 233: iteration 29/29
# Epoch 233 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:2.177, Validation accuracy:63.38%
# Epoch 234: iteration 29/29
# Epoch 234 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.606, Validation accuracy:63.38%
# Epoch 235: iteration 29/29
# Epoch 235 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.144, Validation accuracy:56.34%
# Epoch 236: iteration 29/29
# Epoch 236 --- loss:0.016, Epoch accuracy:99.57%, Validation loss:1.802, Validation accuracy:53.52%
# Epoch 237: iteration 29/29
# Epoch 237 --- loss:0.035, Epoch accuracy:98.92%, Validation loss:1.382, Validation accuracy:60.56%
# Epoch 238: iteration 29/29
# Epoch 238 --- loss:0.020, Epoch accuracy:99.78%, Validation loss:2.926, Validation accuracy:39.44%
# Epoch 239: iteration 29/29
# Epoch 239 --- loss:0.018, Epoch accuracy:99.57%, Validation loss:1.705, Validation accuracy:50.70%
# Epoch 240: iteration 29/29
# Epoch 240 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:3.155, Validation accuracy:43.66%
# Epoch 241: iteration 29/29
# Epoch 241 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.644, Validation accuracy:60.56%
# Epoch 242: iteration 29/29
# Epoch 242 --- loss:0.006, Epoch accuracy:99.78%, Validation loss:1.401, Validation accuracy:63.38%
# Epoch 243: iteration 29/29
# Epoch 243 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.879, Validation accuracy:56.34%
# Epoch 244: iteration 29/29
# Epoch 244 --- loss:0.013, Epoch accuracy:99.35%, Validation loss:5.036, Validation accuracy:45.07%
# Epoch 245: iteration 29/29
# Epoch 245 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:2.085, Validation accuracy:61.97%
# Epoch 246: iteration 29/29
# Epoch 246 --- loss:0.022, Epoch accuracy:99.35%, Validation loss:5.279, Validation accuracy:40.85%
# Epoch 247: iteration 29/29
# Epoch 247 --- loss:0.027, Epoch accuracy:99.57%, Validation loss:2.213, Validation accuracy:63.38%
# Epoch 248: iteration 29/29
# Epoch 248 --- loss:0.028, Epoch accuracy:99.14%, Validation loss:1.171, Validation accuracy:71.83%
# Epoch 249: iteration 29/29
# Epoch 249 --- loss:0.026, Epoch accuracy:99.78%, Validation loss:3.636, Validation accuracy:49.30%
# Epoch 250: iteration 29/29
# Epoch 250 --- loss:0.017, Epoch accuracy:99.78%, Validation loss:1.197, Validation accuracy:69.01%
# Epoch 251: iteration 29/29
# Epoch 251 --- loss:0.011, Epoch accuracy:99.78%, Validation loss:3.882, Validation accuracy:45.07%
# Epoch 252: iteration 29/29
# Epoch 252 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:1.690, Validation accuracy:61.97%
# Epoch 253: iteration 29/29
# Epoch 253 --- loss:0.059, Epoch accuracy:98.49%, Validation loss:18.169, Validation accuracy:19.72%
# Epoch 254: iteration 29/29
# Epoch 254 --- loss:0.068, Epoch accuracy:98.06%, Validation loss:1.520, Validation accuracy:67.61%
# Epoch 255: iteration 29/29
# Epoch 255 --- loss:0.061, Epoch accuracy:97.84%, Validation loss:2.706, Validation accuracy:47.89%
# Epoch 256: iteration 29/29
# Epoch 256 --- loss:0.047, Epoch accuracy:98.92%, Validation loss:5.735, Validation accuracy:29.58%
# Epoch 257: iteration 29/29
# Epoch 257 --- loss:0.055, Epoch accuracy:98.28%, Validation loss:3.025, Validation accuracy:39.44%
# Epoch 258: iteration 29/29
# Epoch 258 --- loss:0.038, Epoch accuracy:99.35%, Validation loss:8.006, Validation accuracy:36.62%
# Epoch 259: iteration 29/29
# Epoch 259 --- loss:0.061, Epoch accuracy:98.28%, Validation loss:2.359, Validation accuracy:40.85%
# Epoch 260: iteration 29/29
# Epoch 260 --- loss:0.021, Epoch accuracy:99.78%, Validation loss:2.002, Validation accuracy:53.52%
# Epoch 261: iteration 29/29
# Epoch 261 --- loss:0.024, Epoch accuracy:99.57%, Validation loss:1.627, Validation accuracy:63.38%
# Epoch 262: iteration 29/29
# Epoch 262 --- loss:0.019, Epoch accuracy:99.78%, Validation loss:3.292, Validation accuracy:53.52%
# Epoch 263: iteration 29/29
# Epoch 263 --- loss:0.028, Epoch accuracy:99.57%, Validation loss:2.640, Validation accuracy:42.25%
# Epoch 264: iteration 29/29
# Epoch 264 --- loss:0.036, Epoch accuracy:99.14%, Validation loss:2.830, Validation accuracy:47.89%
# Epoch 265: iteration 29/29
# Epoch 265 --- loss:0.039, Epoch accuracy:99.14%, Validation loss:3.557, Validation accuracy:43.66%
# Epoch 266: iteration 29/29
# Epoch 266 --- loss:0.028, Epoch accuracy:99.35%, Validation loss:3.281, Validation accuracy:46.48%
# Epoch 267: iteration 29/29
# Epoch 267 --- loss:0.021, Epoch accuracy:99.57%, Validation loss:1.468, Validation accuracy:61.97%
# Epoch 268: iteration 29/29
# Epoch 268 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.304, Validation accuracy:61.97%
# Epoch 269: iteration 29/29
# Epoch 269 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.261, Validation accuracy:66.20%
# Epoch 270: iteration 29/29
# Epoch 270 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:1.872, Validation accuracy:52.11%
# Epoch 271: iteration 29/29
# Epoch 271 --- loss:0.014, Epoch accuracy:99.57%, Validation loss:1.368, Validation accuracy:66.20%
# Epoch 272: iteration 29/29
# Epoch 272 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:1.875, Validation accuracy:53.52%
# Epoch 273: iteration 29/29
# Epoch 273 --- loss:0.005, Epoch accuracy:100.00%, Validation loss:2.065, Validation accuracy:57.75%
# Epoch 274: iteration 29/29
# Epoch 274 --- loss:0.015, Epoch accuracy:99.57%, Validation loss:3.606, Validation accuracy:42.25%
# Epoch 275: iteration 29/29
# Epoch 275 --- loss:0.024, Epoch accuracy:99.35%, Validation loss:1.662, Validation accuracy:63.38%
# Epoch 276: iteration 29/29
# Epoch 276 --- loss:0.018, Epoch accuracy:99.57%, Validation loss:5.324, Validation accuracy:43.66%
# Epoch 277: iteration 29/29
# Epoch 277 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:1.215, Validation accuracy:66.20%
# Epoch 278: iteration 29/29
# Epoch 278 --- loss:0.010, Epoch accuracy:99.78%, Validation loss:2.313, Validation accuracy:53.52%
# Epoch 279: iteration 29/29
# Epoch 279 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:2.223, Validation accuracy:52.11%
# Epoch 280: iteration 29/29
# Epoch 280 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:2.464, Validation accuracy:54.93%
# Epoch 281: iteration 29/29
# Epoch 281 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:1.727, Validation accuracy:53.52%
# Epoch 282: iteration 29/29
# Epoch 282 --- loss:0.003, Epoch accuracy:100.00%, Validation loss:1.950, Validation accuracy:57.75%
# Epoch 283: iteration 29/29
# Epoch 283 --- loss:0.008, Epoch accuracy:99.78%, Validation loss:2.206, Validation accuracy:59.15%
# Epoch 284: iteration 29/29
# Epoch 284 --- loss:0.004, Epoch accuracy:100.00%, Validation loss:2.049, Validation accuracy:60.56%
# Epoch 285: iteration 29/29
# Epoch 285 --- loss:0.005, Epoch accuracy:100.00%, Validation loss:1.675, Validation accuracy:56.34%
# Epoch 286: iteration 29/29
# Epoch 286 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.874, Validation accuracy:52.11%
# Epoch 287: iteration 29/29
# Epoch 287 --- loss:0.004, Epoch accuracy:100.00%, Validation loss:2.932, Validation accuracy:50.70%
# Epoch 288: iteration 29/29
# Epoch 288 --- loss:0.004, Epoch accuracy:100.00%, Validation loss:1.527, Validation accuracy:57.75%
# Epoch 289: iteration 29/29
# Epoch 289 --- loss:0.004, Epoch accuracy:100.00%, Validation loss:2.675, Validation accuracy:49.30%
# Epoch 290: iteration 29/29
# Epoch 290 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.604, Validation accuracy:56.34%
# Epoch 291: iteration 29/29
# Epoch 291 --- loss:0.022, Epoch accuracy:99.35%, Validation loss:5.111, Validation accuracy:49.30%
# Epoch 292: iteration 29/29
# Epoch 292 --- loss:0.063, Epoch accuracy:98.06%, Validation loss:4.071, Validation accuracy:47.89%
# Epoch 293: iteration 29/29
# Epoch 293 --- loss:0.015, Epoch accuracy:100.00%, Validation loss:1.672, Validation accuracy:60.56%
# Epoch 294: iteration 29/29
# Epoch 294 --- loss:0.046, Epoch accuracy:98.49%, Validation loss:3.785, Validation accuracy:49.30%
# Epoch 295: iteration 29/29
# Epoch 295 --- loss:0.114, Epoch accuracy:96.98%, Validation loss:5.321, Validation accuracy:36.62%
# Epoch 296: iteration 29/29
# Epoch 296 --- loss:0.113, Epoch accuracy:96.12%, Validation loss:4.421, Validation accuracy:26.76%
# Epoch 297: iteration 29/29
# Epoch 297 --- loss:0.034, Epoch accuracy:98.92%, Validation loss:1.178, Validation accuracy:69.01%
# Epoch 298: iteration 29/29
# Epoch 298 --- loss:0.035, Epoch accuracy:98.28%, Validation loss:10.920, Validation accuracy:30.99%
# Epoch 299: iteration 29/29
# Epoch 299 --- loss:0.018, Epoch accuracy:99.57%, Validation loss:2.747, Validation accuracy:47.89%
#
#
# [*] done !
# [*] Best training loss - 0.00274458484611763
# [*] Best validation loss - 0.9313833713531494

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(10):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    
    print("="*80)
    print(f'[*] Fold-{fold+1}')
    print(f'Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # print(conf_matrix)

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    print("="*80)
# Out:
# ================================================================================
# [*] Fold-1
# Test accuracy is 79.59%
#               precision    recall  f1-score   support
#
#            0       0.81      0.93      0.87        14
#            1       0.25      0.25      0.25         4
#            2       0.67      0.80      0.73         5
#            3       1.00      1.00      1.00         1
#            4       0.80      0.57      0.67         7
#            5       0.92      1.00      0.96        11
#            6       1.00      0.71      0.83         7
#
#     accuracy                           0.80        49
#    macro avg       0.78      0.75      0.76        49
# weighted avg       0.80      0.80      0.79        49
# ================================================================================
# ================================================================================
# [*] Fold-2
# Test accuracy is 77.59%
#               precision    recall  f1-score   support
#
#            0       0.88      0.58      0.70        12
#            1       0.67      0.67      0.67         6
#            2       1.00      0.90      0.95        10
#            3       0.00      0.00      0.00         0
#            4       0.53      0.82      0.64        11
#            5       0.88      0.70      0.78        10
#            6       1.00      1.00      1.00         9
#
#     accuracy                           0.78        58
#    macro avg       0.71      0.67      0.68        58
# weighted avg       0.83      0.78      0.79        58
# c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ================================================================================
# ================================================================================
# [*] Fold-3
# Test accuracy is 86.05%
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86        13
#            1       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         4
#            3       1.00      0.50      0.67         8
#            4       0.50      0.75      0.60         4
#            5       1.00      1.00      1.00         9
#            6       1.00      1.00      1.00         4
#
#     accuracy                           0.86        43
#    macro avg       0.90      0.88      0.87        43
# weighted avg       0.89      0.86      0.86        43
# ================================================================================
# ================================================================================
# [*] Fold-4
# Test accuracy is 92.11%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         8
#            2       0.86      0.75      0.80         8
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         4
#            5       0.60      0.75      0.67         4
#            6       1.00      1.00      1.00         3
#
#     accuracy                           0.92        38
#    macro avg       0.92      0.93      0.92        38
# weighted avg       0.93      0.92      0.92        38
# ================================================================================
# ================================================================================
# [*] Fold-5
# Test accuracy is 70.91%
#               precision    recall  f1-score   support
#
#            0       0.89      0.73      0.80        11
#            1       0.69      0.90      0.78        10
#            2       0.75      0.38      0.50         8
#            3       0.00      0.00      0.00         2
#            4       1.00      0.50      0.67         8
#            5       0.89      0.89      0.89         9
#            6       0.64      1.00      0.78         7
#
#     accuracy                           0.71        55
#    macro avg       0.69      0.63      0.63        55
# weighted avg       0.78      0.71      0.72        55
# ================================================================================
# ================================================================================
# [*] Fold-6
# Test accuracy is 80.00%
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89        12
#            1       1.00      0.50      0.67         6
#            2       1.00      1.00      1.00         5
#            3       1.00      0.50      0.67         2
#            4       0.00      0.00      0.00         2
#            5       0.60      0.75      0.67         4
#            6       0.80      1.00      0.89         4
#
#     accuracy                           0.80        35
#    macro avg       0.74      0.68      0.68        35
# weighted avg       0.81      0.80      0.78        35
# ================================================================================
# ================================================================================
# [*] Fold-7
# Test accuracy is 86.89%
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        12
#            1       1.00      0.86      0.92         7
#            2       0.77      1.00      0.87        10
#            3       1.00      0.75      0.86         8
#            4       0.89      0.80      0.84        10
#            5       0.86      0.67      0.75         9
#            6       0.83      1.00      0.91         5
#
#     accuracy                           0.87        61
#    macro avg       0.89      0.87      0.87        61
# weighted avg       0.88      0.87      0.87        61
# ================================================================================
# ================================================================================
# [*] Fold-8
# Test accuracy is 85.51%
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91        16
#            1       0.89      0.67      0.76        12
#            2       0.78      0.88      0.82         8
#            3       1.00      1.00      1.00         8
#            4       0.60      0.75      0.67         8
#            5       0.88      1.00      0.93         7
#            6       1.00      0.80      0.89        10
#
#     accuracy                           0.86        69
#    macro avg       0.86      0.86      0.85        69
# weighted avg       0.87      0.86      0.86        69
# ================================================================================
# ================================================================================
# [*] Fold-9
# Test accuracy is 83.93%
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        13
#            1       1.00      0.50      0.67         8
#            2       0.78      0.78      0.78         9
#            3       0.57      0.80      0.67         5
#            4       0.75      1.00      0.86         6
#            5       1.00      0.91      0.95        11
#            6       0.67      1.00      0.80         4
#
#     accuracy                           0.84        56
#    macro avg       0.82      0.84      0.81        56
# weighted avg       0.88      0.84      0.84        56
# ================================================================================
# ================================================================================
# [*] Fold-10
# Test accuracy is 67.61%
#               precision    recall  f1-score   support
#
#            0       0.65      0.93      0.76        14
#            1       0.75      0.43      0.55         7
#            2       0.62      0.71      0.67        14
#            3       0.50      0.18      0.27        11
#            4       0.67      0.55      0.60        11
#            5       0.71      1.00      0.83         5
#            6       0.82      1.00      0.90         9
#
#     accuracy                           0.68        71
#    macro avg       0.67      0.69      0.65        71
# weighted avg       0.66      0.68      0.64        71
# ================================================================================

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 92.11%
# [*] Worst fold acc : 67.61%
# [*] Average fold acc : 81.02%
