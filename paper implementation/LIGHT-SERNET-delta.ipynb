# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'LIGHT-SERNET-scaling-delta'
data_name = 'RAVDESS'
fold_path = sub_name + ' dataset'

minibatch = 32
num_epochs = 500
EARLY_CNT = 99999

learning_rate = 1e-5

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
from sklearn.metrics import classification_report
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.cnn1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[3,3], padding=[1,0]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        self.cnn2 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[9,1], padding=[4,0]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        self.cnn3 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[1,11]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        
        self.LFLB = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1]),
            
            nn.Conv2d(64, 96, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1]),
            
            nn.Conv2d(96, 128, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d([2,1], padding=[1,0]),
            
            nn.Conv2d(128, 160, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(160),
            nn.ReLU(),
            nn.MaxPool2d([2,1], padding=[1,0]),
            
            nn.Conv2d(160, 320, kernel_size=[1,1]),
            nn.BatchNorm2d(320),
            nn.ReLU()
        )
        
        self.fc = nn.Linear(320, num_emotions)

    def forward(self, x):
        embd1 = self.cnn1(x)
        embd2 = self.cnn2(x)
        embd3 = self.cnn3(x)
        concat_embd = torch.cat([embd1, embd2, embd3], dim=3)
        
        lflb_embd = self.LFLB(concat_embd)
        out = F.adaptive_avg_pool2d(lflb_embd, (1,1))
        out = nn.Dropout(0.3)(out)
        out = torch.flatten(out, start_dim=1)
        
        output_logits = self.fc(out)
        output_softmax = nn.Softmax(dim=1)(output_logits)
        
        return output_logits, output_softmax
    

model = Model(8)
print(summary(model, (1140, 3, 40, 184)))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model                                    [1140, 8]                 --
# ├─Sequential: 1-1                        [1140, 32, 21, 92]        --
# │    └─Conv2d: 2-1                       [1140, 32, 40, 182]       896
# │    └─BatchNorm2d: 2-2                  [1140, 32, 40, 182]       64
# │    └─ReLU: 2-3                         [1140, 32, 40, 182]       --
# │    └─MaxPool2d: 2-4                    [1140, 32, 21, 92]        --
# ├─Sequential: 1-2                        [1140, 32, 21, 93]        --
# │    └─Conv2d: 2-5                       [1140, 32, 40, 184]       896
# │    └─BatchNorm2d: 2-6                  [1140, 32, 40, 184]       64
# │    └─ReLU: 2-7                         [1140, 32, 40, 184]       --
# │    └─MaxPool2d: 2-8                    [1140, 32, 21, 93]        --
# ├─Sequential: 1-3                        [1140, 32, 21, 88]        --
# │    └─Conv2d: 2-9                       [1140, 32, 40, 174]       1,088
# │    └─BatchNorm2d: 2-10                 [1140, 32, 40, 174]       64
# │    └─ReLU: 2-11                        [1140, 32, 40, 174]       --
# │    └─MaxPool2d: 2-12                   [1140, 32, 21, 88]        --
# ├─Sequential: 1-4                        [1140, 320, 3, 69]        --
# │    └─Conv2d: 2-13                      [1140, 64, 21, 273]       18,496
# │    └─BatchNorm2d: 2-14                 [1140, 64, 21, 273]       128
# │    └─ReLU: 2-15                        [1140, 64, 21, 273]       --
# │    └─MaxPool2d: 2-16                   [1140, 64, 11, 137]       --
# │    └─Conv2d: 2-17                      [1140, 96, 11, 137]       55,392
# │    └─BatchNorm2d: 2-18                 [1140, 96, 11, 137]       192
# │    └─ReLU: 2-19                        [1140, 96, 11, 137]       --
# │    └─MaxPool2d: 2-20                   [1140, 96, 6, 69]         --
# │    └─Conv2d: 2-21                      [1140, 128, 6, 69]        110,720
# │    └─BatchNorm2d: 2-22                 [1140, 128, 6, 69]        256
# │    └─ReLU: 2-23                        [1140, 128, 6, 69]        --
# │    └─MaxPool2d: 2-24                   [1140, 128, 4, 69]        --
# │    └─Conv2d: 2-25                      [1140, 160, 4, 69]        184,480
# │    └─BatchNorm2d: 2-26                 [1140, 160, 4, 69]        320
# │    └─ReLU: 2-27                        [1140, 160, 4, 69]        --
# │    └─MaxPool2d: 2-28                   [1140, 160, 3, 69]        --
# │    └─Conv2d: 2-29                      [1140, 320, 3, 69]        51,520
# │    └─BatchNorm2d: 2-30                 [1140, 320, 3, 69]        640
# │    └─ReLU: 2-31                        [1140, 320, 3, 69]        --
# ├─Linear: 1-5                            [1140, 8]                 2,568
# ==========================================================================================
# Total params: 427,784
# Trainable params: 427,784
# Non-trainable params: 0
# Total mult-adds (G): 362.09
# ==========================================================================================
# Input size (MB): 100.68
# Forward/backward pass size (MB): 24919.12
# Params size (MB): 1.71
# Estimated Total Size (MB): 25021.52
# ==========================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'Fold-{fold} training.....'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nloss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=10e-6, amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - LIGHT-SERNET-scaling-delta
# Fold-0 training.....:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 34/35
# loss:2.056, Epoch accuracy:14.21%, Validation loss:2.080, Validation accuracy:16.33%
# Epoch 1: iteration 34/35
# loss:2.047, Epoch accuracy:15.44%, Validation loss:2.080, Validation accuracy:18.00%
# Epoch 2: iteration 34/35
# loss:2.028, Epoch accuracy:18.25%, Validation loss:2.067, Validation accuracy:16.00%
# Epoch 3: iteration 34/35
# loss:2.017, Epoch accuracy:19.56%, Validation loss:2.065, Validation accuracy:19.00%
# Epoch 4: iteration 34/35
# loss:2.015, Epoch accuracy:19.91%, Validation loss:2.049, Validation accuracy:18.67%
# Epoch 5: iteration 34/35
# loss:2.002, Epoch accuracy:18.86%, Validation loss:2.042, Validation accuracy:19.00%
# Epoch 6: iteration 34/35
# loss:1.983, Epoch accuracy:20.96%, Validation loss:2.046, Validation accuracy:19.33%
# Epoch 7: iteration 34/35
# loss:1.975, Epoch accuracy:22.02%, Validation loss:2.032, Validation accuracy:17.00%
# Epoch 8: iteration 34/35
# loss:1.970, Epoch accuracy:22.02%, Validation loss:2.002, Validation accuracy:23.67%
# Epoch 9: iteration 34/35
# loss:1.954, Epoch accuracy:21.58%, Validation loss:2.014, Validation accuracy:22.00%
# Epoch 10: iteration 34/35
# loss:1.946, Epoch accuracy:21.93%, Validation loss:2.007, Validation accuracy:20.00%
# Epoch 11: iteration 34/35
# loss:1.945, Epoch accuracy:22.89%, Validation loss:1.967, Validation accuracy:23.67%
# Epoch 12: iteration 34/35
# loss:1.934, Epoch accuracy:23.86%, Validation loss:1.976, Validation accuracy:24.00%
# Epoch 13: iteration 34/35
# loss:1.913, Epoch accuracy:25.53%, Validation loss:1.947, Validation accuracy:27.00%
# Epoch 14: iteration 34/35
# loss:1.911, Epoch accuracy:24.04%, Validation loss:1.935, Validation accuracy:26.67%
# Epoch 15: iteration 34/35
# loss:1.898, Epoch accuracy:26.32%, Validation loss:1.931, Validation accuracy:23.67%
# Epoch 16: iteration 34/35
# loss:1.896, Epoch accuracy:26.67%, Validation loss:1.918, Validation accuracy:28.00%
# Epoch 17: iteration 34/35
# loss:1.887, Epoch accuracy:26.32%, Validation loss:1.911, Validation accuracy:27.33%
# Epoch 18: iteration 34/35
# loss:1.879, Epoch accuracy:25.61%, Validation loss:1.903, Validation accuracy:28.33%
# Epoch 19: iteration 34/35
# loss:1.873, Epoch accuracy:28.42%, Validation loss:1.900, Validation accuracy:30.33%
# Epoch 20: iteration 34/35
# loss:1.852, Epoch accuracy:27.98%, Validation loss:1.889, Validation accuracy:29.00%
# Epoch 21: iteration 34/35
# loss:1.853, Epoch accuracy:29.39%, Validation loss:1.880, Validation accuracy:31.00%
# Epoch 22: iteration 34/35
# loss:1.837, Epoch accuracy:30.35%, Validation loss:1.888, Validation accuracy:29.33%
# Epoch 23: iteration 34/35
# loss:1.834, Epoch accuracy:30.79%, Validation loss:1.865, Validation accuracy:32.67%
# Epoch 24: iteration 34/35
# loss:1.839, Epoch accuracy:30.35%, Validation loss:1.858, Validation accuracy:31.00%
# Epoch 25: iteration 34/35
# loss:1.813, Epoch accuracy:32.37%, Validation loss:1.875, Validation accuracy:30.67%
# Epoch 26: iteration 34/35
# loss:1.811, Epoch accuracy:30.96%, Validation loss:1.842, Validation accuracy:34.00%
# Epoch 27: iteration 34/35
# loss:1.805, Epoch accuracy:32.28%, Validation loss:1.829, Validation accuracy:37.00%
# Epoch 28: iteration 34/35
# loss:1.787, Epoch accuracy:33.16%, Validation loss:1.834, Validation accuracy:35.00%
# Epoch 29: iteration 34/35
# loss:1.774, Epoch accuracy:35.09%, Validation loss:1.805, Validation accuracy:35.67%
# Epoch 30: iteration 34/35
# loss:1.778, Epoch accuracy:33.25%, Validation loss:1.822, Validation accuracy:32.33%
# Epoch 31: iteration 34/35
# loss:1.766, Epoch accuracy:34.56%, Validation loss:1.781, Validation accuracy:39.33%
# Epoch 32: iteration 34/35
# loss:1.755, Epoch accuracy:35.26%, Validation loss:1.796, Validation accuracy:34.33%
# Epoch 33: iteration 34/35
# loss:1.740, Epoch accuracy:36.40%, Validation loss:1.766, Validation accuracy:39.00%
# Epoch 34: iteration 34/35
# loss:1.738, Epoch accuracy:35.53%, Validation loss:1.770, Validation accuracy:34.67%
# Epoch 35: iteration 34/35
# loss:1.725, Epoch accuracy:36.40%, Validation loss:1.775, Validation accuracy:34.67%
# Epoch 36: iteration 34/35
# loss:1.717, Epoch accuracy:37.28%, Validation loss:1.763, Validation accuracy:37.67%
# Epoch 37: iteration 34/35
# loss:1.707, Epoch accuracy:36.05%, Validation loss:1.769, Validation accuracy:34.67%
# Epoch 38: iteration 34/35
# loss:1.703, Epoch accuracy:36.32%, Validation loss:1.730, Validation accuracy:39.33%
# Epoch 39: iteration 34/35
# loss:1.693, Epoch accuracy:36.93%, Validation loss:1.722, Validation accuracy:43.67%
# Epoch 40: iteration 34/35
# loss:1.679, Epoch accuracy:38.25%, Validation loss:1.724, Validation accuracy:41.67%
# Epoch 41: iteration 34/35
# loss:1.672, Epoch accuracy:37.19%, Validation loss:1.711, Validation accuracy:41.33%
# Epoch 42: iteration 34/35
# loss:1.663, Epoch accuracy:39.12%, Validation loss:1.731, Validation accuracy:35.00%
# Epoch 43: iteration 34/35
# loss:1.655, Epoch accuracy:38.51%, Validation loss:1.696, Validation accuracy:41.33%
# Epoch 44: iteration 34/35
# loss:1.654, Epoch accuracy:38.77%, Validation loss:1.680, Validation accuracy:39.33%
# Epoch 45: iteration 34/35
# loss:1.649, Epoch accuracy:38.16%, Validation loss:1.678, Validation accuracy:42.00%
# Epoch 46: iteration 34/35
# loss:1.642, Epoch accuracy:39.04%, Validation loss:1.681, Validation accuracy:41.67%
# Epoch 47: iteration 34/35
# loss:1.628, Epoch accuracy:39.12%, Validation loss:1.662, Validation accuracy:43.00%
# Epoch 48: iteration 34/35
# loss:1.627, Epoch accuracy:37.98%, Validation loss:1.671, Validation accuracy:43.33%
# Epoch 49: iteration 34/35
# loss:1.619, Epoch accuracy:38.51%, Validation loss:1.659, Validation accuracy:42.33%
# Epoch 50: iteration 34/35
# loss:1.604, Epoch accuracy:39.74%, Validation loss:1.650, Validation accuracy:41.67%
# Epoch 51: iteration 34/35
# loss:1.610, Epoch accuracy:40.44%, Validation loss:1.708, Validation accuracy:36.00%
# Epoch 52: iteration 34/35
# loss:1.598, Epoch accuracy:40.96%, Validation loss:1.672, Validation accuracy:37.00%
# Epoch 53: iteration 34/35
# loss:1.592, Epoch accuracy:41.14%, Validation loss:1.659, Validation accuracy:42.00%
# Epoch 54: iteration 34/35
# loss:1.574, Epoch accuracy:42.02%, Validation loss:1.620, Validation accuracy:45.00%
# Epoch 55: iteration 34/35
# loss:1.577, Epoch accuracy:40.26%, Validation loss:1.637, Validation accuracy:44.67%
# Epoch 56: iteration 34/35
# loss:1.563, Epoch accuracy:40.61%, Validation loss:1.628, Validation accuracy:40.67%
# Epoch 57: iteration 34/35
# loss:1.560, Epoch accuracy:43.25%, Validation loss:1.618, Validation accuracy:43.67%
# Epoch 58: iteration 34/35
# loss:1.562, Epoch accuracy:40.70%, Validation loss:1.616, Validation accuracy:42.67%
# Epoch 59: iteration 34/35
# loss:1.550, Epoch accuracy:41.67%, Validation loss:1.620, Validation accuracy:44.67%
# Epoch 60: iteration 34/35
# loss:1.558, Epoch accuracy:42.46%, Validation loss:1.585, Validation accuracy:49.33%
# Epoch 61: iteration 34/35
# loss:1.544, Epoch accuracy:43.33%, Validation loss:1.661, Validation accuracy:39.00%
# Epoch 62: iteration 34/35
# loss:1.534, Epoch accuracy:42.98%, Validation loss:1.588, Validation accuracy:45.67%
# Epoch 63: iteration 34/35
# loss:1.527, Epoch accuracy:44.65%, Validation loss:1.592, Validation accuracy:43.67%
# Epoch 64: iteration 34/35
# loss:1.521, Epoch accuracy:43.60%, Validation loss:1.589, Validation accuracy:48.00%
# Epoch 65: iteration 34/35
# loss:1.520, Epoch accuracy:44.39%, Validation loss:1.608, Validation accuracy:42.33%
# Epoch 66: iteration 34/35
# loss:1.497, Epoch accuracy:45.61%, Validation loss:1.570, Validation accuracy:46.67%
# Epoch 67: iteration 34/35
# loss:1.506, Epoch accuracy:46.40%, Validation loss:1.588, Validation accuracy:45.00%
# Epoch 68: iteration 34/35
# loss:1.489, Epoch accuracy:46.32%, Validation loss:1.580, Validation accuracy:43.33%
# Epoch 69: iteration 34/35
# loss:1.485, Epoch accuracy:46.49%, Validation loss:1.551, Validation accuracy:47.33%
# Epoch 70: iteration 34/35
# loss:1.490, Epoch accuracy:45.35%, Validation loss:1.576, Validation accuracy:47.67%
# Epoch 71: iteration 34/35
# loss:1.475, Epoch accuracy:46.23%, Validation loss:1.592, Validation accuracy:43.67%
# Epoch 72: iteration 34/35
# loss:1.488, Epoch accuracy:45.44%, Validation loss:1.541, Validation accuracy:47.33%
# Epoch 73: iteration 34/35
# loss:1.474, Epoch accuracy:46.58%, Validation loss:1.603, Validation accuracy:42.67%
# Epoch 74: iteration 34/35
# loss:1.476, Epoch accuracy:47.11%, Validation loss:1.546, Validation accuracy:48.67%
# Epoch 75: iteration 34/35
# loss:1.468, Epoch accuracy:47.46%, Validation loss:1.551, Validation accuracy:47.00%
# Epoch 76: iteration 34/35
# loss:1.462, Epoch accuracy:46.84%, Validation loss:1.559, Validation accuracy:47.00%
# Epoch 77: iteration 34/35
# loss:1.450, Epoch accuracy:48.07%, Validation loss:1.547, Validation accuracy:48.00%
# Epoch 78: iteration 34/35
# loss:1.433, Epoch accuracy:49.82%, Validation loss:1.536, Validation accuracy:46.67%
# Epoch 79: iteration 34/35
# loss:1.426, Epoch accuracy:49.56%, Validation loss:1.525, Validation accuracy:50.00%
# Epoch 80: iteration 34/35
# loss:1.428, Epoch accuracy:49.21%, Validation loss:1.524, Validation accuracy:51.33%
# Epoch 81: iteration 34/35
# loss:1.432, Epoch accuracy:47.98%, Validation loss:1.519, Validation accuracy:49.67%
# Epoch 82: iteration 34/35
# loss:1.417, Epoch accuracy:49.12%, Validation loss:1.561, Validation accuracy:45.67%
# Epoch 83: iteration 34/35
# loss:1.411, Epoch accuracy:50.35%, Validation loss:1.512, Validation accuracy:47.33%
# Epoch 84: iteration 34/35
# loss:1.415, Epoch accuracy:50.09%, Validation loss:1.516, Validation accuracy:48.00%
# Epoch 85: iteration 34/35
# loss:1.398, Epoch accuracy:49.47%, Validation loss:1.520, Validation accuracy:46.67%
# Epoch 86: iteration 34/35
# loss:1.397, Epoch accuracy:50.88%, Validation loss:1.512, Validation accuracy:49.67%
# Epoch 87: iteration 34/35
# loss:1.395, Epoch accuracy:51.14%, Validation loss:1.495, Validation accuracy:49.33%
# Epoch 88: iteration 34/35
# loss:1.398, Epoch accuracy:49.30%, Validation loss:1.486, Validation accuracy:51.33%
# Epoch 89: iteration 34/35
# loss:1.393, Epoch accuracy:51.75%, Validation loss:1.487, Validation accuracy:51.33%
# Epoch 90: iteration 34/35
# loss:1.390, Epoch accuracy:51.40%, Validation loss:1.486, Validation accuracy:50.33%
# Epoch 91: iteration 34/35
# loss:1.363, Epoch accuracy:53.51%, Validation loss:1.525, Validation accuracy:44.33%
# Epoch 92: iteration 34/35
# loss:1.372, Epoch accuracy:52.46%, Validation loss:1.474, Validation accuracy:54.33%
# Epoch 93: iteration 34/35
# loss:1.350, Epoch accuracy:53.95%, Validation loss:1.465, Validation accuracy:51.67%
# Epoch 94: iteration 34/35
# loss:1.354, Epoch accuracy:52.63%, Validation loss:1.504, Validation accuracy:47.33%
# Epoch 95: iteration 34/35
# loss:1.348, Epoch accuracy:53.86%, Validation loss:1.493, Validation accuracy:48.00%
# Epoch 96: iteration 34/35
# loss:1.341, Epoch accuracy:53.95%, Validation loss:1.450, Validation accuracy:51.67%
# Epoch 97: iteration 34/35
# loss:1.328, Epoch accuracy:53.86%, Validation loss:1.487, Validation accuracy:48.00%
# Epoch 98: iteration 34/35
# loss:1.341, Epoch accuracy:52.28%, Validation loss:1.482, Validation accuracy:49.33%
# Epoch 99: iteration 34/35
# loss:1.320, Epoch accuracy:54.82%, Validation loss:1.459, Validation accuracy:52.33%
# Epoch 100: iteration 34/35
# loss:1.326, Epoch accuracy:54.21%, Validation loss:1.506, Validation accuracy:46.33%
# Epoch 101: iteration 34/35
# loss:1.303, Epoch accuracy:56.40%, Validation loss:1.443, Validation accuracy:52.33%
# Epoch 102: iteration 34/35
# loss:1.309, Epoch accuracy:55.09%, Validation loss:1.452, Validation accuracy:52.00%
# Epoch 103: iteration 34/35
# loss:1.308, Epoch accuracy:54.30%, Validation loss:1.449, Validation accuracy:55.00%
# Epoch 104: iteration 34/35
# loss:1.294, Epoch accuracy:56.14%, Validation loss:1.457, Validation accuracy:53.67%
# Epoch 105: iteration 34/35
# loss:1.304, Epoch accuracy:54.65%, Validation loss:1.427, Validation accuracy:51.00%
# Epoch 106: iteration 34/35
# loss:1.285, Epoch accuracy:57.37%, Validation loss:1.459, Validation accuracy:50.67%
# Epoch 107: iteration 34/35
# loss:1.293, Epoch accuracy:55.35%, Validation loss:1.445, Validation accuracy:50.67%
# Epoch 108: iteration 34/35
# loss:1.280, Epoch accuracy:55.44%, Validation loss:1.475, Validation accuracy:48.67%
# Epoch 109: iteration 34/35
# loss:1.275, Epoch accuracy:57.46%, Validation loss:1.435, Validation accuracy:54.00%
# Epoch 110: iteration 34/35
# loss:1.278, Epoch accuracy:56.58%, Validation loss:1.430, Validation accuracy:50.67%
# Epoch 111: iteration 34/35
# loss:1.261, Epoch accuracy:56.49%, Validation loss:1.397, Validation accuracy:57.67%
# Epoch 112: iteration 34/35
# loss:1.257, Epoch accuracy:57.72%, Validation loss:1.476, Validation accuracy:46.67%
# Epoch 113: iteration 34/35
# loss:1.252, Epoch accuracy:57.89%, Validation loss:1.436, Validation accuracy:52.33%
# Epoch 114: iteration 34/35
# loss:1.242, Epoch accuracy:58.07%, Validation loss:1.437, Validation accuracy:50.00%
# Epoch 115: iteration 34/35
# loss:1.248, Epoch accuracy:56.75%, Validation loss:1.415, Validation accuracy:55.33%
# Epoch 116: iteration 34/35
# loss:1.253, Epoch accuracy:58.07%, Validation loss:1.423, Validation accuracy:51.00%
# Epoch 117: iteration 34/35
# loss:1.235, Epoch accuracy:59.56%, Validation loss:1.412, Validation accuracy:54.00%
# Epoch 118: iteration 34/35
# loss:1.244, Epoch accuracy:57.89%, Validation loss:1.412, Validation accuracy:51.33%
# Epoch 119: iteration 34/35
# loss:1.221, Epoch accuracy:58.86%, Validation loss:1.391, Validation accuracy:51.67%
# Epoch 120: iteration 34/35
# loss:1.224, Epoch accuracy:58.51%, Validation loss:1.563, Validation accuracy:39.67%
# Epoch 121: iteration 34/35
# loss:1.215, Epoch accuracy:59.04%, Validation loss:1.413, Validation accuracy:49.00%
# Epoch 122: iteration 34/35
# loss:1.217, Epoch accuracy:59.04%, Validation loss:1.407, Validation accuracy:53.67%
# Epoch 123: iteration 34/35
# loss:1.210, Epoch accuracy:61.05%, Validation loss:1.387, Validation accuracy:55.67%
# Epoch 124: iteration 34/35
# loss:1.192, Epoch accuracy:60.00%, Validation loss:1.374, Validation accuracy:52.00%
# Epoch 125: iteration 34/35
# loss:1.203, Epoch accuracy:59.30%, Validation loss:1.389, Validation accuracy:53.33%
# Epoch 126: iteration 34/35
# loss:1.202, Epoch accuracy:60.61%, Validation loss:1.402, Validation accuracy:52.00%
# Epoch 127: iteration 34/35
# loss:1.180, Epoch accuracy:60.70%, Validation loss:1.406, Validation accuracy:51.33%
# Epoch 128: iteration 34/35
# loss:1.195, Epoch accuracy:59.74%, Validation loss:1.422, Validation accuracy:50.00%
# Epoch 129: iteration 34/35
# loss:1.188, Epoch accuracy:60.96%, Validation loss:1.433, Validation accuracy:48.33%
# Epoch 130: iteration 34/35
# loss:1.186, Epoch accuracy:59.56%, Validation loss:1.375, Validation accuracy:53.67%
# Epoch 131: iteration 34/35
# loss:1.169, Epoch accuracy:59.82%, Validation loss:1.372, Validation accuracy:56.00%
# Epoch 132: iteration 34/35
# loss:1.181, Epoch accuracy:60.88%, Validation loss:1.390, Validation accuracy:50.67%
# Epoch 133: iteration 34/35
# loss:1.171, Epoch accuracy:61.49%, Validation loss:1.402, Validation accuracy:50.67%
# Epoch 134: iteration 34/35
# loss:1.155, Epoch accuracy:61.58%, Validation loss:1.362, Validation accuracy:55.33%
# Epoch 135: iteration 34/35
# loss:1.158, Epoch accuracy:61.84%, Validation loss:1.372, Validation accuracy:54.00%
# Epoch 136: iteration 34/35
# loss:1.154, Epoch accuracy:61.67%, Validation loss:1.385, Validation accuracy:52.67%
# Epoch 137: iteration 34/35
# loss:1.146, Epoch accuracy:62.89%, Validation loss:1.430, Validation accuracy:48.33%
# Epoch 138: iteration 34/35
# loss:1.144, Epoch accuracy:63.86%, Validation loss:1.442, Validation accuracy:47.67%
# Epoch 139: iteration 34/35
# loss:1.141, Epoch accuracy:62.98%, Validation loss:1.469, Validation accuracy:45.67%
# Epoch 140: iteration 34/35
# loss:1.136, Epoch accuracy:62.11%, Validation loss:1.356, Validation accuracy:55.67%
# Epoch 141: iteration 34/35
# loss:1.143, Epoch accuracy:62.81%, Validation loss:1.478, Validation accuracy:45.67%
# Epoch 142: iteration 34/35
# loss:1.127, Epoch accuracy:62.54%, Validation loss:1.346, Validation accuracy:58.33%
# Epoch 143: iteration 34/35
# loss:1.125, Epoch accuracy:64.12%, Validation loss:1.366, Validation accuracy:52.33%
# Epoch 144: iteration 34/35
# loss:1.128, Epoch accuracy:63.33%, Validation loss:1.424, Validation accuracy:47.33%
# Epoch 145: iteration 34/35
# loss:1.111, Epoch accuracy:63.60%, Validation loss:1.362, Validation accuracy:53.00%
# Epoch 146: iteration 34/35
# loss:1.106, Epoch accuracy:64.91%, Validation loss:1.330, Validation accuracy:54.67%
# Epoch 147: iteration 34/35
# loss:1.112, Epoch accuracy:62.81%, Validation loss:1.348, Validation accuracy:57.00%
# Epoch 148: iteration 34/35
# loss:1.112, Epoch accuracy:63.68%, Validation loss:1.373, Validation accuracy:51.33%
# Epoch 149: iteration 34/35
# loss:1.097, Epoch accuracy:65.00%, Validation loss:1.404, Validation accuracy:49.33%
# Epoch 150: iteration 34/35
# loss:1.093, Epoch accuracy:65.88%, Validation loss:1.344, Validation accuracy:53.67%
# Epoch 151: iteration 34/35
# loss:1.084, Epoch accuracy:65.53%, Validation loss:1.345, Validation accuracy:55.33%
# Epoch 152: iteration 34/35
# loss:1.084, Epoch accuracy:64.91%, Validation loss:1.355, Validation accuracy:54.33%
# Epoch 153: iteration 34/35
# loss:1.088, Epoch accuracy:65.53%, Validation loss:1.408, Validation accuracy:48.67%
# Epoch 154: iteration 34/35
# loss:1.074, Epoch accuracy:65.44%, Validation loss:1.353, Validation accuracy:51.67%
# Epoch 155: iteration 34/35
# loss:1.072, Epoch accuracy:66.14%, Validation loss:1.392, Validation accuracy:51.33%
# Epoch 156: iteration 34/35
# loss:1.077, Epoch accuracy:65.26%, Validation loss:1.478, Validation accuracy:44.33%
# Epoch 157: iteration 34/35
# loss:1.083, Epoch accuracy:64.47%, Validation loss:1.305, Validation accuracy:54.67%
# Epoch 158: iteration 34/35
# loss:1.065, Epoch accuracy:65.18%, Validation loss:1.339, Validation accuracy:56.00%
# Epoch 159: iteration 34/35
# loss:1.063, Epoch accuracy:66.40%, Validation loss:1.362, Validation accuracy:50.00%
# Epoch 160: iteration 34/35
# loss:1.049, Epoch accuracy:66.67%, Validation loss:1.309, Validation accuracy:57.00%
# Epoch 161: iteration 34/35
# loss:1.046, Epoch accuracy:66.23%, Validation loss:1.374, Validation accuracy:51.33%
# Epoch 162: iteration 34/35
# loss:1.038, Epoch accuracy:66.58%, Validation loss:1.324, Validation accuracy:55.67%
# Epoch 163: iteration 34/35
# loss:1.038, Epoch accuracy:69.30%, Validation loss:1.341, Validation accuracy:53.00%
# Epoch 164: iteration 34/35
# loss:1.038, Epoch accuracy:67.19%, Validation loss:1.364, Validation accuracy:51.00%
# Epoch 165: iteration 34/35
# loss:1.020, Epoch accuracy:69.04%, Validation loss:1.398, Validation accuracy:47.33%
# Epoch 166: iteration 34/35
# loss:1.024, Epoch accuracy:68.16%, Validation loss:1.308, Validation accuracy:58.00%
# Epoch 167: iteration 34/35
# loss:1.014, Epoch accuracy:68.51%, Validation loss:1.380, Validation accuracy:50.67%
# Epoch 168: iteration 34/35
# loss:1.029, Epoch accuracy:68.07%, Validation loss:1.325, Validation accuracy:56.33%
# Epoch 169: iteration 34/35
# loss:1.015, Epoch accuracy:68.51%, Validation loss:1.380, Validation accuracy:49.00%
# Epoch 170: iteration 34/35
# loss:1.010, Epoch accuracy:67.89%, Validation loss:1.336, Validation accuracy:53.67%
# Epoch 171: iteration 34/35
# loss:1.005, Epoch accuracy:69.21%, Validation loss:1.324, Validation accuracy:52.33%
# Epoch 172: iteration 34/35
# loss:0.997, Epoch accuracy:69.74%, Validation loss:1.310, Validation accuracy:56.67%
# Epoch 173: iteration 34/35
# loss:0.994, Epoch accuracy:70.53%, Validation loss:1.371, Validation accuracy:50.00%
# Epoch 174: iteration 34/35
# loss:1.018, Epoch accuracy:68.68%, Validation loss:1.354, Validation accuracy:52.33%
# Epoch 175: iteration 34/35
# loss:0.987, Epoch accuracy:70.53%, Validation loss:1.300, Validation accuracy:56.00%
# Epoch 176: iteration 34/35
# loss:1.015, Epoch accuracy:67.19%, Validation loss:1.343, Validation accuracy:50.33%
# Epoch 177: iteration 34/35
# loss:0.977, Epoch accuracy:70.09%, Validation loss:1.303, Validation accuracy:55.00%
# Epoch 178: iteration 34/35
# loss:0.983, Epoch accuracy:68.86%, Validation loss:1.322, Validation accuracy:54.67%
# Epoch 179: iteration 34/35
# loss:0.978, Epoch accuracy:69.65%, Validation loss:1.289, Validation accuracy:54.00%
# Epoch 180: iteration 34/35
# loss:0.975, Epoch accuracy:69.74%, Validation loss:1.341, Validation accuracy:49.33%
# Epoch 181: iteration 34/35
# loss:0.973, Epoch accuracy:70.18%, Validation loss:1.373, Validation accuracy:48.33%
# Epoch 182: iteration 34/35
# loss:0.963, Epoch accuracy:70.53%, Validation loss:1.278, Validation accuracy:60.33%
# Epoch 183: iteration 34/35
# loss:0.975, Epoch accuracy:69.30%, Validation loss:1.410, Validation accuracy:46.67%
# Epoch 184: iteration 34/35
# loss:0.963, Epoch accuracy:70.35%, Validation loss:1.378, Validation accuracy:49.33%
# Epoch 185: iteration 34/35
# loss:0.949, Epoch accuracy:72.11%, Validation loss:1.290, Validation accuracy:52.67%
# Epoch 186: iteration 34/35
# loss:0.965, Epoch accuracy:69.04%, Validation loss:1.452, Validation accuracy:43.33%
# Epoch 187: iteration 34/35
# loss:0.953, Epoch accuracy:71.67%, Validation loss:1.326, Validation accuracy:55.00%
# Epoch 188: iteration 34/35
# loss:0.953, Epoch accuracy:70.26%, Validation loss:1.308, Validation accuracy:54.67%
# Epoch 189: iteration 34/35
# loss:0.940, Epoch accuracy:71.40%, Validation loss:1.357, Validation accuracy:48.33%
# Epoch 190: iteration 34/35
# loss:0.944, Epoch accuracy:70.61%, Validation loss:1.298, Validation accuracy:55.67%
# Epoch 191: iteration 34/35
# loss:0.930, Epoch accuracy:72.81%, Validation loss:1.313, Validation accuracy:52.67%
# Epoch 192: iteration 34/35
# loss:0.931, Epoch accuracy:71.75%, Validation loss:1.310, Validation accuracy:53.00%
# Epoch 193: iteration 34/35
# loss:0.945, Epoch accuracy:72.28%, Validation loss:1.294, Validation accuracy:54.33%
# Epoch 194: iteration 34/35
# loss:0.922, Epoch accuracy:72.46%, Validation loss:1.277, Validation accuracy:55.00%
# Epoch 195: iteration 34/35
# loss:0.921, Epoch accuracy:72.19%, Validation loss:1.301, Validation accuracy:52.67%
# Epoch 196: iteration 34/35
# loss:0.919, Epoch accuracy:72.89%, Validation loss:1.282, Validation accuracy:55.33%
# Epoch 197: iteration 34/35
# loss:0.913, Epoch accuracy:73.16%, Validation loss:1.276, Validation accuracy:55.33%
# Epoch 198: iteration 34/35
# loss:0.893, Epoch accuracy:72.72%, Validation loss:1.410, Validation accuracy:46.33%
# Epoch 199: iteration 34/35
# loss:0.922, Epoch accuracy:72.28%, Validation loss:1.301, Validation accuracy:53.67%
# Epoch 200: iteration 34/35
# loss:0.908, Epoch accuracy:71.93%, Validation loss:1.290, Validation accuracy:56.33%
# Epoch 201: iteration 34/35
# loss:0.897, Epoch accuracy:72.54%, Validation loss:1.281, Validation accuracy:54.00%
# Epoch 202: iteration 34/35
# loss:0.878, Epoch accuracy:74.74%, Validation loss:1.349, Validation accuracy:51.00%
# Epoch 203: iteration 34/35
# loss:0.884, Epoch accuracy:73.95%, Validation loss:1.261, Validation accuracy:56.67%
# Epoch 204: iteration 34/35
# loss:0.899, Epoch accuracy:73.25%, Validation loss:1.266, Validation accuracy:56.67%
# Epoch 205: iteration 34/35
# loss:0.886, Epoch accuracy:75.26%, Validation loss:1.254, Validation accuracy:57.33%
# Epoch 206: iteration 34/35
# loss:0.880, Epoch accuracy:74.74%, Validation loss:1.431, Validation accuracy:43.67%
# Epoch 207: iteration 34/35
# loss:0.882, Epoch accuracy:74.30%, Validation loss:1.291, Validation accuracy:54.33%
# Epoch 208: iteration 34/35
# loss:0.876, Epoch accuracy:75.79%, Validation loss:1.265, Validation accuracy:57.33%
# Epoch 209: iteration 34/35
# loss:0.882, Epoch accuracy:74.56%, Validation loss:1.317, Validation accuracy:50.67%
# Epoch 210: iteration 34/35
# loss:0.870, Epoch accuracy:74.21%, Validation loss:1.287, Validation accuracy:55.33%
# Epoch 211: iteration 34/35
# loss:0.873, Epoch accuracy:74.82%, Validation loss:1.263, Validation accuracy:57.67%
# Epoch 212: iteration 34/35
# loss:0.865, Epoch accuracy:75.09%, Validation loss:1.252, Validation accuracy:56.33%
# Epoch 213: iteration 34/35
# loss:0.851, Epoch accuracy:74.21%, Validation loss:1.297, Validation accuracy:54.33%
# Epoch 214: iteration 34/35
# loss:0.874, Epoch accuracy:75.35%, Validation loss:1.271, Validation accuracy:54.00%
# Epoch 215: iteration 34/35
# loss:0.843, Epoch accuracy:76.14%, Validation loss:1.266, Validation accuracy:57.00%
# Epoch 216: iteration 34/35
# loss:0.856, Epoch accuracy:74.82%, Validation loss:1.282, Validation accuracy:53.67%
# Epoch 217: iteration 34/35
# loss:0.861, Epoch accuracy:75.61%, Validation loss:1.361, Validation accuracy:51.33%
# Epoch 218: iteration 34/35
# loss:0.838, Epoch accuracy:76.67%, Validation loss:1.246, Validation accuracy:59.67%
# Epoch 219: iteration 34/35
# loss:0.838, Epoch accuracy:76.93%, Validation loss:1.257, Validation accuracy:57.67%
# Epoch 220: iteration 34/35
# loss:0.838, Epoch accuracy:76.40%, Validation loss:1.291, Validation accuracy:54.33%
# Epoch 221: iteration 34/35
# loss:0.829, Epoch accuracy:76.75%, Validation loss:1.246, Validation accuracy:57.00%
# Epoch 222: iteration 34/35
# loss:0.815, Epoch accuracy:77.54%, Validation loss:1.260, Validation accuracy:54.67%
# Epoch 223: iteration 34/35
# loss:0.813, Epoch accuracy:77.46%, Validation loss:1.257, Validation accuracy:58.67%
# Epoch 224: iteration 34/35
# loss:0.823, Epoch accuracy:76.75%, Validation loss:1.272, Validation accuracy:55.00%
# Epoch 225: iteration 34/35
# loss:0.814, Epoch accuracy:77.46%, Validation loss:1.263, Validation accuracy:54.67%
# Epoch 226: iteration 34/35
# loss:0.809, Epoch accuracy:77.72%, Validation loss:1.254, Validation accuracy:58.33%
# Epoch 227: iteration 34/35
# loss:0.809, Epoch accuracy:77.89%, Validation loss:1.292, Validation accuracy:53.00%
# Epoch 228: iteration 34/35
# loss:0.800, Epoch accuracy:78.33%, Validation loss:1.245, Validation accuracy:56.67%
# Epoch 229: iteration 34/35
# loss:0.797, Epoch accuracy:78.07%, Validation loss:1.281, Validation accuracy:57.33%
# Epoch 230: iteration 34/35
# loss:0.793, Epoch accuracy:78.95%, Validation loss:1.245, Validation accuracy:57.67%
# Epoch 231: iteration 34/35
# loss:0.794, Epoch accuracy:77.89%, Validation loss:1.429, Validation accuracy:47.00%
# Epoch 232: iteration 34/35
# loss:0.807, Epoch accuracy:78.25%, Validation loss:1.291, Validation accuracy:55.33%
# Epoch 233: iteration 34/35
# loss:0.789, Epoch accuracy:78.77%, Validation loss:1.257, Validation accuracy:57.33%
# Epoch 234: iteration 34/35
# loss:0.784, Epoch accuracy:79.30%, Validation loss:1.268, Validation accuracy:52.67%
# Epoch 235: iteration 34/35
# loss:0.782, Epoch accuracy:77.46%, Validation loss:1.472, Validation accuracy:45.67%
# Epoch 236: iteration 34/35
# loss:0.776, Epoch accuracy:80.35%, Validation loss:1.276, Validation accuracy:53.67%
# Epoch 237: iteration 34/35
# loss:0.766, Epoch accuracy:80.18%, Validation loss:1.320, Validation accuracy:54.00%
# Epoch 238: iteration 34/35
# loss:0.775, Epoch accuracy:79.04%, Validation loss:1.287, Validation accuracy:57.00%
# Epoch 239: iteration 34/35
# loss:0.766, Epoch accuracy:79.04%, Validation loss:1.314, Validation accuracy:54.33%
# Epoch 240: iteration 34/35
# loss:0.760, Epoch accuracy:79.21%, Validation loss:1.325, Validation accuracy:53.00%
# Epoch 241: iteration 34/35
# loss:0.766, Epoch accuracy:79.74%, Validation loss:1.299, Validation accuracy:53.67%
# Epoch 242: iteration 34/35
# loss:0.764, Epoch accuracy:79.56%, Validation loss:1.253, Validation accuracy:57.67%
# Epoch 243: iteration 34/35
# loss:0.756, Epoch accuracy:81.23%, Validation loss:1.324, Validation accuracy:52.67%
# Epoch 244: iteration 34/35
# loss:0.751, Epoch accuracy:80.53%, Validation loss:1.223, Validation accuracy:56.67%
# Epoch 245: iteration 34/35
# loss:0.748, Epoch accuracy:80.09%, Validation loss:1.251, Validation accuracy:53.33%
# Epoch 246: iteration 34/35
# loss:0.757, Epoch accuracy:79.82%, Validation loss:1.353, Validation accuracy:50.33%
# Epoch 247: iteration 34/35
# loss:0.746, Epoch accuracy:81.32%, Validation loss:1.208, Validation accuracy:59.67%
# Epoch 248: iteration 34/35
# loss:0.750, Epoch accuracy:80.88%, Validation loss:1.234, Validation accuracy:57.33%
# Epoch 249: iteration 34/35
# loss:0.743, Epoch accuracy:80.44%, Validation loss:1.223, Validation accuracy:57.00%
# Epoch 250: iteration 34/35
# loss:0.726, Epoch accuracy:81.84%, Validation loss:1.251, Validation accuracy:58.67%
# Epoch 251: iteration 34/35
# loss:0.734, Epoch accuracy:80.18%, Validation loss:1.257, Validation accuracy:59.00%
# Epoch 252: iteration 34/35
# loss:0.726, Epoch accuracy:82.63%, Validation loss:1.333, Validation accuracy:46.33%
# Epoch 253: iteration 34/35
# loss:0.732, Epoch accuracy:81.58%, Validation loss:1.288, Validation accuracy:55.67%
# Epoch 254: iteration 34/35
# loss:0.723, Epoch accuracy:81.32%, Validation loss:1.239, Validation accuracy:55.33%
# Epoch 255: iteration 34/35
# loss:0.697, Epoch accuracy:83.60%, Validation loss:1.320, Validation accuracy:54.33%
# Epoch 256: iteration 34/35
# loss:0.721, Epoch accuracy:81.05%, Validation loss:1.518, Validation accuracy:45.00%
# Epoch 257: iteration 34/35
# loss:0.714, Epoch accuracy:82.63%, Validation loss:1.246, Validation accuracy:54.33%
# Epoch 258: iteration 34/35
# loss:0.716, Epoch accuracy:81.23%, Validation loss:1.243, Validation accuracy:56.33%
# Epoch 259: iteration 34/35
# loss:0.702, Epoch accuracy:82.11%, Validation loss:1.240, Validation accuracy:58.67%
# Epoch 260: iteration 34/35
# loss:0.710, Epoch accuracy:80.88%, Validation loss:1.248, Validation accuracy:53.67%
# Epoch 261: iteration 34/35
# loss:0.701, Epoch accuracy:82.11%, Validation loss:1.227, Validation accuracy:57.67%
# Epoch 262: iteration 34/35
# loss:0.690, Epoch accuracy:81.67%, Validation loss:1.338, Validation accuracy:49.67%
# Epoch 263: iteration 34/35
# loss:0.688, Epoch accuracy:84.21%, Validation loss:1.251, Validation accuracy:56.67%
# Epoch 264: iteration 34/35
# loss:0.685, Epoch accuracy:83.42%, Validation loss:1.253, Validation accuracy:55.67%
# Epoch 265: iteration 34/35
# loss:0.680, Epoch accuracy:83.25%, Validation loss:1.233, Validation accuracy:59.33%
# Epoch 266: iteration 34/35
# loss:0.684, Epoch accuracy:83.25%, Validation loss:1.244, Validation accuracy:56.67%
# Epoch 267: iteration 34/35
# loss:0.680, Epoch accuracy:83.25%, Validation loss:1.210, Validation accuracy:59.00%
# Epoch 268: iteration 34/35
# loss:0.673, Epoch accuracy:83.33%, Validation loss:1.250, Validation accuracy:53.33%
# Epoch 269: iteration 34/35
# loss:0.680, Epoch accuracy:83.33%, Validation loss:1.473, Validation accuracy:46.67%
# Epoch 270: iteration 34/35
# loss:0.681, Epoch accuracy:82.72%, Validation loss:1.325, Validation accuracy:51.67%
# Epoch 271: iteration 34/35
# loss:0.687, Epoch accuracy:82.63%, Validation loss:1.360, Validation accuracy:49.67%
# Epoch 272: iteration 34/35
# loss:0.667, Epoch accuracy:84.74%, Validation loss:1.190, Validation accuracy:62.33%
# Epoch 273: iteration 34/35
# loss:0.655, Epoch accuracy:84.12%, Validation loss:1.335, Validation accuracy:51.33%
# Epoch 274: iteration 34/35
# loss:0.659, Epoch accuracy:83.95%, Validation loss:1.245, Validation accuracy:57.67%
# Epoch 275: iteration 34/35
# loss:0.664, Epoch accuracy:83.16%, Validation loss:1.345, Validation accuracy:49.33%
# Epoch 276: iteration 34/35
# loss:0.656, Epoch accuracy:82.89%, Validation loss:1.271, Validation accuracy:53.00%
# Epoch 277: iteration 34/35
# loss:0.641, Epoch accuracy:84.21%, Validation loss:1.331, Validation accuracy:50.00%
# Epoch 278: iteration 34/35
# loss:0.650, Epoch accuracy:85.53%, Validation loss:1.215, Validation accuracy:58.00%
# Epoch 279: iteration 34/35
# loss:0.645, Epoch accuracy:85.18%, Validation loss:1.229, Validation accuracy:55.33%
# Epoch 280: iteration 34/35
# loss:0.641, Epoch accuracy:85.53%, Validation loss:1.344, Validation accuracy:50.67%
# Epoch 281: iteration 34/35
# loss:0.641, Epoch accuracy:85.26%, Validation loss:1.378, Validation accuracy:47.33%
# Epoch 282: iteration 34/35
# loss:0.651, Epoch accuracy:84.39%, Validation loss:1.262, Validation accuracy:52.00%
# Epoch 283: iteration 34/35
# loss:0.637, Epoch accuracy:85.70%, Validation loss:1.302, Validation accuracy:50.67%
# Epoch 284: iteration 34/35
# loss:0.638, Epoch accuracy:85.35%, Validation loss:1.206, Validation accuracy:60.00%
# Epoch 285: iteration 34/35
# loss:0.643, Epoch accuracy:84.65%, Validation loss:1.278, Validation accuracy:55.33%
# Epoch 286: iteration 34/35
# loss:0.626, Epoch accuracy:86.58%, Validation loss:1.242, Validation accuracy:57.00%
# Epoch 287: iteration 34/35
# loss:0.613, Epoch accuracy:87.37%, Validation loss:1.223, Validation accuracy:57.67%
# Epoch 288: iteration 34/35
# loss:0.614, Epoch accuracy:86.67%, Validation loss:1.281, Validation accuracy:54.33%
# Epoch 289: iteration 34/35
# loss:0.614, Epoch accuracy:85.70%, Validation loss:1.209, Validation accuracy:58.33%
# Epoch 290: iteration 34/35
# loss:0.613, Epoch accuracy:86.75%, Validation loss:1.215, Validation accuracy:59.33%
# Epoch 291: iteration 34/35
# loss:0.600, Epoch accuracy:87.11%, Validation loss:1.214, Validation accuracy:60.00%
# Epoch 292: iteration 34/35
# loss:0.612, Epoch accuracy:86.49%, Validation loss:1.362, Validation accuracy:47.33%
# Epoch 293: iteration 34/35
# loss:0.603, Epoch accuracy:85.35%, Validation loss:1.232, Validation accuracy:59.67%
# Epoch 294: iteration 34/35
# loss:0.603, Epoch accuracy:87.81%, Validation loss:1.253, Validation accuracy:54.00%
# Epoch 295: iteration 34/35
# loss:0.601, Epoch accuracy:86.40%, Validation loss:1.199, Validation accuracy:58.00%
# Epoch 296: iteration 34/35
# loss:0.600, Epoch accuracy:87.11%, Validation loss:1.225, Validation accuracy:58.33%
# Epoch 297: iteration 34/35
# loss:0.598, Epoch accuracy:87.02%, Validation loss:1.340, Validation accuracy:45.67%
# Epoch 298: iteration 34/35
# loss:0.609, Epoch accuracy:87.19%, Validation loss:1.219, Validation accuracy:58.33%
# Epoch 299: iteration 34/35
# loss:0.590, Epoch accuracy:86.67%, Validation loss:1.337, Validation accuracy:51.67%
# Epoch 300: iteration 34/35
# loss:0.585, Epoch accuracy:87.19%, Validation loss:1.247, Validation accuracy:55.33%
# Epoch 301: iteration 34/35
# loss:0.567, Epoch accuracy:88.33%, Validation loss:1.280, Validation accuracy:53.00%
# Epoch 302: iteration 34/35
# loss:0.577, Epoch accuracy:87.28%, Validation loss:1.229, Validation accuracy:57.33%
# Epoch 303: iteration 34/35
# loss:0.571, Epoch accuracy:88.60%, Validation loss:1.387, Validation accuracy:47.33%
# Epoch 304: iteration 34/35
# loss:0.571, Epoch accuracy:87.72%, Validation loss:1.223, Validation accuracy:57.67%
# Epoch 305: iteration 34/35
# loss:0.562, Epoch accuracy:88.25%, Validation loss:1.294, Validation accuracy:50.00%
# Epoch 306: iteration 34/35
# loss:0.559, Epoch accuracy:88.33%, Validation loss:1.350, Validation accuracy:49.33%
# Epoch 307: iteration 34/35
# loss:0.567, Epoch accuracy:88.42%, Validation loss:1.212, Validation accuracy:58.67%
# Epoch 308: iteration 34/35
# loss:0.572, Epoch accuracy:88.33%, Validation loss:1.250, Validation accuracy:58.67%
# Epoch 309: iteration 34/35
# loss:0.567, Epoch accuracy:87.81%, Validation loss:1.303, Validation accuracy:56.00%
# Epoch 310: iteration 34/35
# loss:0.567, Epoch accuracy:88.16%, Validation loss:1.272, Validation accuracy:56.67%
# Epoch 311: iteration 34/35
# loss:0.563, Epoch accuracy:87.46%, Validation loss:1.330, Validation accuracy:52.00%
# Epoch 312: iteration 34/35
# loss:0.559, Epoch accuracy:88.07%, Validation loss:1.200, Validation accuracy:58.67%
# Epoch 313: iteration 34/35
# loss:0.567, Epoch accuracy:88.77%, Validation loss:1.243, Validation accuracy:55.33%
# Epoch 314: iteration 34/35
# loss:0.555, Epoch accuracy:88.60%, Validation loss:1.214, Validation accuracy:57.67%
# Epoch 315: iteration 34/35
# loss:0.539, Epoch accuracy:88.95%, Validation loss:1.248, Validation accuracy:54.00%
# Epoch 316: iteration 34/35
# loss:0.545, Epoch accuracy:88.33%, Validation loss:1.252, Validation accuracy:55.33%
# Epoch 317: iteration 34/35
# loss:0.536, Epoch accuracy:89.47%, Validation loss:1.502, Validation accuracy:41.33%
# Epoch 318: iteration 34/35
# loss:0.542, Epoch accuracy:88.51%, Validation loss:1.324, Validation accuracy:50.67%
# Epoch 319: iteration 34/35
# loss:0.544, Epoch accuracy:89.74%, Validation loss:1.248, Validation accuracy:58.33%
# Epoch 320: iteration 34/35
# loss:0.530, Epoch accuracy:89.91%, Validation loss:1.226, Validation accuracy:58.33%
# Epoch 321: iteration 34/35
# loss:0.534, Epoch accuracy:89.12%, Validation loss:1.200, Validation accuracy:59.33%
# Epoch 322: iteration 34/35
# loss:0.530, Epoch accuracy:89.47%, Validation loss:1.217, Validation accuracy:56.67%
# Epoch 323: iteration 34/35
# loss:0.537, Epoch accuracy:88.68%, Validation loss:1.243, Validation accuracy:58.00%
# Epoch 324: iteration 34/35
# loss:0.534, Epoch accuracy:88.86%, Validation loss:1.207, Validation accuracy:59.00%
# Epoch 325: iteration 34/35
# loss:0.521, Epoch accuracy:89.91%, Validation loss:1.226, Validation accuracy:59.67%
# Epoch 326: iteration 34/35
# loss:0.511, Epoch accuracy:89.12%, Validation loss:1.271, Validation accuracy:56.00%
# Epoch 327: iteration 34/35
# loss:0.521, Epoch accuracy:90.96%, Validation loss:1.262, Validation accuracy:54.33%
# Epoch 328: iteration 34/35
# loss:0.521, Epoch accuracy:89.65%, Validation loss:1.269, Validation accuracy:56.00%
# Epoch 329: iteration 34/35
# loss:0.518, Epoch accuracy:91.05%, Validation loss:1.291, Validation accuracy:52.67%
# Epoch 330: iteration 34/35
# loss:0.495, Epoch accuracy:90.79%, Validation loss:1.291, Validation accuracy:51.67%
# Epoch 331: iteration 34/35
# loss:0.514, Epoch accuracy:89.65%, Validation loss:1.237, Validation accuracy:55.33%
# Epoch 332: iteration 34/35
# loss:0.509, Epoch accuracy:89.39%, Validation loss:1.239, Validation accuracy:58.67%
# Epoch 333: iteration 34/35
# loss:0.495, Epoch accuracy:89.65%, Validation loss:1.314, Validation accuracy:50.33%
# Epoch 334: iteration 34/35
# loss:0.500, Epoch accuracy:90.26%, Validation loss:1.348, Validation accuracy:50.00%
# Epoch 335: iteration 34/35
# loss:0.497, Epoch accuracy:91.49%, Validation loss:1.185, Validation accuracy:62.33%
# Epoch 336: iteration 34/35
# loss:0.488, Epoch accuracy:91.93%, Validation loss:1.272, Validation accuracy:55.67%
# Epoch 337: iteration 34/35
# loss:0.494, Epoch accuracy:90.88%, Validation loss:1.269, Validation accuracy:52.00%
# Epoch 338: iteration 34/35
# loss:0.480, Epoch accuracy:90.44%, Validation loss:1.220, Validation accuracy:57.00%
# Epoch 339: iteration 34/35
# loss:0.472, Epoch accuracy:90.96%, Validation loss:1.202, Validation accuracy:59.00%
# Epoch 340: iteration 34/35
# loss:0.483, Epoch accuracy:90.88%, Validation loss:1.220, Validation accuracy:57.00%
# Epoch 341: iteration 34/35
# loss:0.484, Epoch accuracy:90.96%, Validation loss:1.205, Validation accuracy:60.00%
# Epoch 342: iteration 34/35
# loss:0.483, Epoch accuracy:92.28%, Validation loss:1.243, Validation accuracy:55.33%
# Epoch 343: iteration 34/35
# loss:0.483, Epoch accuracy:90.26%, Validation loss:1.168, Validation accuracy:62.67%
# Epoch 344: iteration 34/35
# loss:0.476, Epoch accuracy:91.23%, Validation loss:1.311, Validation accuracy:52.33%
# Epoch 345: iteration 34/35
# loss:0.453, Epoch accuracy:91.67%, Validation loss:1.168, Validation accuracy:61.67%
# Epoch 346: iteration 34/35
# loss:0.473, Epoch accuracy:91.23%, Validation loss:1.302, Validation accuracy:55.00%
# Epoch 347: iteration 34/35
# loss:0.473, Epoch accuracy:91.40%, Validation loss:1.263, Validation accuracy:52.67%
# Epoch 348: iteration 34/35
# loss:0.464, Epoch accuracy:91.93%, Validation loss:1.432, Validation accuracy:49.00%
# Epoch 349: iteration 34/35
# loss:0.466, Epoch accuracy:92.46%, Validation loss:1.175, Validation accuracy:63.00%
# Epoch 350: iteration 34/35
# loss:0.455, Epoch accuracy:92.37%, Validation loss:1.211, Validation accuracy:58.33%
# Epoch 351: iteration 34/35
# loss:0.450, Epoch accuracy:92.46%, Validation loss:1.188, Validation accuracy:58.00%
# Epoch 352: iteration 34/35
# loss:0.449, Epoch accuracy:92.54%, Validation loss:1.237, Validation accuracy:58.67%
# Epoch 353: iteration 34/35
# loss:0.460, Epoch accuracy:90.53%, Validation loss:1.222, Validation accuracy:57.67%
# Epoch 354: iteration 34/35
# loss:0.457, Epoch accuracy:92.28%, Validation loss:1.216, Validation accuracy:57.00%
# Epoch 355: iteration 34/35
# loss:0.450, Epoch accuracy:91.93%, Validation loss:1.280, Validation accuracy:52.33%
# Epoch 356: iteration 34/35
# loss:0.441, Epoch accuracy:92.11%, Validation loss:1.206, Validation accuracy:57.33%
# Epoch 357: iteration 34/35
# loss:0.452, Epoch accuracy:91.75%, Validation loss:1.204, Validation accuracy:56.00%
# Epoch 358: iteration 34/35
# loss:0.453, Epoch accuracy:92.11%, Validation loss:1.189, Validation accuracy:58.33%
# Epoch 359: iteration 34/35
# loss:0.439, Epoch accuracy:92.98%, Validation loss:1.214, Validation accuracy:58.00%
# Epoch 360: iteration 34/35
# loss:0.436, Epoch accuracy:92.28%, Validation loss:1.297, Validation accuracy:51.67%
# Epoch 361: iteration 34/35
# loss:0.442, Epoch accuracy:92.37%, Validation loss:1.191, Validation accuracy:61.33%
# Epoch 362: iteration 34/35
# loss:0.447, Epoch accuracy:92.81%, Validation loss:1.230, Validation accuracy:57.67%
# Epoch 363: iteration 34/35
# loss:0.437, Epoch accuracy:92.46%, Validation loss:1.322, Validation accuracy:50.33%
# Epoch 364: iteration 34/35
# loss:0.418, Epoch accuracy:93.68%, Validation loss:1.250, Validation accuracy:52.33%
# Epoch 365: iteration 34/35
# loss:0.437, Epoch accuracy:93.07%, Validation loss:1.289, Validation accuracy:53.00%
# Epoch 366: iteration 34/35
# loss:0.414, Epoch accuracy:93.16%, Validation loss:1.212, Validation accuracy:58.67%
# Epoch 367: iteration 34/35
# loss:0.417, Epoch accuracy:93.33%, Validation loss:1.206, Validation accuracy:59.33%
# Epoch 368: iteration 34/35
# loss:0.425, Epoch accuracy:92.63%, Validation loss:1.200, Validation accuracy:58.00%
# Epoch 369: iteration 34/35
# loss:0.417, Epoch accuracy:92.98%, Validation loss:1.308, Validation accuracy:53.33%
# Epoch 370: iteration 34/35
# loss:0.416, Epoch accuracy:93.25%, Validation loss:1.267, Validation accuracy:53.67%
# Epoch 371: iteration 34/35
# loss:0.415, Epoch accuracy:92.28%, Validation loss:1.187, Validation accuracy:61.00%
# Epoch 372: iteration 34/35
# loss:0.421, Epoch accuracy:92.37%, Validation loss:1.227, Validation accuracy:57.00%
# Epoch 373: iteration 34/35
# loss:0.416, Epoch accuracy:92.72%, Validation loss:1.228, Validation accuracy:56.67%
# Epoch 374: iteration 34/35
# loss:0.413, Epoch accuracy:93.33%, Validation loss:1.301, Validation accuracy:53.00%
# Epoch 375: iteration 34/35
# loss:0.421, Epoch accuracy:92.81%, Validation loss:1.167, Validation accuracy:58.33%
# Epoch 376: iteration 34/35
# loss:0.405, Epoch accuracy:93.16%, Validation loss:1.195, Validation accuracy:60.33%
# Epoch 377: iteration 34/35
# loss:0.403, Epoch accuracy:93.60%, Validation loss:1.248, Validation accuracy:56.00%
# Epoch 378: iteration 34/35
# loss:0.406, Epoch accuracy:93.42%, Validation loss:1.329, Validation accuracy:49.00%
# Epoch 379: iteration 34/35
# loss:0.395, Epoch accuracy:93.07%, Validation loss:1.289, Validation accuracy:53.33%
# Epoch 380: iteration 34/35
# loss:0.404, Epoch accuracy:93.77%, Validation loss:1.227, Validation accuracy:57.67%
# Epoch 381: iteration 34/35
# loss:0.398, Epoch accuracy:94.47%, Validation loss:1.255, Validation accuracy:55.00%
# Epoch 382: iteration 34/35
# loss:0.389, Epoch accuracy:94.30%, Validation loss:1.201, Validation accuracy:59.00%
# Epoch 383: iteration 34/35
# loss:0.391, Epoch accuracy:93.77%, Validation loss:1.235, Validation accuracy:59.33%
# Epoch 384: iteration 34/35
# loss:0.374, Epoch accuracy:93.95%, Validation loss:1.170, Validation accuracy:64.33%
# Epoch 385: iteration 34/35
# loss:0.377, Epoch accuracy:94.39%, Validation loss:1.269, Validation accuracy:56.00%
# Epoch 386: iteration 34/35
# loss:0.388, Epoch accuracy:94.04%, Validation loss:1.267, Validation accuracy:52.67%
# Epoch 387: iteration 34/35
# loss:0.381, Epoch accuracy:94.21%, Validation loss:1.219, Validation accuracy:55.00%
# Epoch 388: iteration 34/35
# loss:0.376, Epoch accuracy:93.95%, Validation loss:1.225, Validation accuracy:58.00%
# Epoch 389: iteration 34/35
# loss:0.381, Epoch accuracy:94.21%, Validation loss:1.232, Validation accuracy:59.33%
# Epoch 390: iteration 34/35
# loss:0.381, Epoch accuracy:93.77%, Validation loss:1.336, Validation accuracy:53.00%
# Epoch 391: iteration 34/35
# loss:0.364, Epoch accuracy:95.26%, Validation loss:1.219, Validation accuracy:55.33%
# Epoch 392: iteration 34/35
# loss:0.370, Epoch accuracy:94.82%, Validation loss:1.249, Validation accuracy:54.67%
# Epoch 393: iteration 34/35
# loss:0.361, Epoch accuracy:94.74%, Validation loss:1.190, Validation accuracy:59.33%
# Epoch 394: iteration 34/35
# loss:0.358, Epoch accuracy:95.44%, Validation loss:1.233, Validation accuracy:56.67%
# Epoch 395: iteration 34/35
# loss:0.367, Epoch accuracy:94.39%, Validation loss:1.242, Validation accuracy:53.00%
# Epoch 396: iteration 34/35
# loss:0.364, Epoch accuracy:95.44%, Validation loss:1.218, Validation accuracy:58.33%
# Epoch 397: iteration 34/35
# loss:0.356, Epoch accuracy:95.00%, Validation loss:1.199, Validation accuracy:59.33%
# Epoch 398: iteration 34/35
# loss:0.361, Epoch accuracy:94.82%, Validation loss:1.182, Validation accuracy:56.33%
# Epoch 399: iteration 34/35
# loss:0.361, Epoch accuracy:94.39%, Validation loss:1.333, Validation accuracy:52.33%
# Epoch 400: iteration 34/35
# loss:0.347, Epoch accuracy:95.88%, Validation loss:1.349, Validation accuracy:51.33%
# Epoch 401: iteration 34/35
# loss:0.353, Epoch accuracy:94.56%, Validation loss:1.272, Validation accuracy:53.67%
# Epoch 402: iteration 34/35
# loss:0.358, Epoch accuracy:94.65%, Validation loss:1.234, Validation accuracy:55.33%
# Epoch 403: iteration 34/35
# loss:0.358, Epoch accuracy:94.91%, Validation loss:1.202, Validation accuracy:59.00%
# Epoch 404: iteration 34/35
# loss:0.353, Epoch accuracy:95.09%, Validation loss:1.219, Validation accuracy:54.00%
# Epoch 405: iteration 34/35
# loss:0.343, Epoch accuracy:95.53%, Validation loss:1.192, Validation accuracy:59.67%
# Epoch 406: iteration 34/35
# loss:0.352, Epoch accuracy:95.00%, Validation loss:1.204, Validation accuracy:59.33%
# Epoch 407: iteration 34/35
# loss:0.342, Epoch accuracy:95.35%, Validation loss:1.276, Validation accuracy:52.67%
# Epoch 408: iteration 34/35
# loss:0.330, Epoch accuracy:95.61%, Validation loss:1.206, Validation accuracy:61.00%
# Epoch 409: iteration 34/35
# loss:0.327, Epoch accuracy:95.44%, Validation loss:1.193, Validation accuracy:59.00%
# Epoch 410: iteration 34/35
# loss:0.349, Epoch accuracy:95.00%, Validation loss:1.327, Validation accuracy:51.00%
# Epoch 411: iteration 34/35
# loss:0.336, Epoch accuracy:95.53%, Validation loss:1.246, Validation accuracy:55.67%
# Epoch 412: iteration 34/35
# loss:0.331, Epoch accuracy:95.00%, Validation loss:1.215, Validation accuracy:57.33%
# Epoch 413: iteration 34/35
# loss:0.332, Epoch accuracy:95.09%, Validation loss:1.187, Validation accuracy:58.00%
# Epoch 414: iteration 34/35
# loss:0.336, Epoch accuracy:94.82%, Validation loss:1.247, Validation accuracy:55.67%
# Epoch 415: iteration 34/35
# loss:0.328, Epoch accuracy:95.35%, Validation loss:1.185, Validation accuracy:60.00%
# Epoch 416: iteration 34/35
# loss:0.316, Epoch accuracy:96.05%, Validation loss:1.301, Validation accuracy:52.00%
# Epoch 417: iteration 34/35
# loss:0.337, Epoch accuracy:95.70%, Validation loss:1.180, Validation accuracy:60.00%
# Epoch 418: iteration 34/35
# loss:0.315, Epoch accuracy:95.61%, Validation loss:1.210, Validation accuracy:57.67%
# Epoch 419: iteration 34/35
# loss:0.317, Epoch accuracy:95.79%, Validation loss:1.311, Validation accuracy:56.33%
# Epoch 420: iteration 34/35
# loss:0.318, Epoch accuracy:95.61%, Validation loss:1.200, Validation accuracy:58.67%
# Epoch 421: iteration 34/35
# loss:0.314, Epoch accuracy:95.61%, Validation loss:1.233, Validation accuracy:55.67%
# Epoch 422: iteration 34/35
# loss:0.319, Epoch accuracy:95.79%, Validation loss:1.364, Validation accuracy:48.33%
# Epoch 423: iteration 34/35
# loss:0.311, Epoch accuracy:96.49%, Validation loss:1.462, Validation accuracy:44.67%
# Epoch 424: iteration 34/35
# loss:0.314, Epoch accuracy:95.26%, Validation loss:1.288, Validation accuracy:53.33%
# Epoch 425: iteration 34/35
# loss:0.305, Epoch accuracy:95.70%, Validation loss:1.198, Validation accuracy:57.67%
# Epoch 426: iteration 34/35
# loss:0.315, Epoch accuracy:95.96%, Validation loss:1.279, Validation accuracy:50.33%
# Epoch 427: iteration 34/35
# loss:0.312, Epoch accuracy:96.05%, Validation loss:1.250, Validation accuracy:53.67%
# Epoch 428: iteration 34/35
# ...
# loss:0.449, Epoch accuracy:91.75%, Validation loss:1.424, Validation accuracy:50.00%
# Epoch 359: iteration 36/37
# loss:0.461, Epoch accuracy:91.33%, Validation loss:1.435, Validation accuracy:50.00%
# Epoch 360: iteration 36/37
# loss:0.449, Epoch accuracy:91.75%, Validation loss:1.349, Validation accuracy:51.25%
# Epoch 361: iteration 36/37
# loss:0.448, Epoch accuracy:91.08%, Validation loss:1.412, Validation accuracy:45.42%
# Epoch 362: iteration 36/37
# loss:0.451, Epoch accuracy:91.17%, Validation loss:1.379, Validation accuracy:52.50%
# Epoch 363: iteration 36/37
# loss:0.445, Epoch accuracy:91.33%, Validation loss:1.413, Validation accuracy:47.08%
# Epoch 364: iteration 36/37
# loss:0.433, Epoch accuracy:92.00%, Validation loss:1.429, Validation accuracy:52.50%
# Epoch 365: iteration 36/37
# loss:0.431, Epoch accuracy:92.33%, Validation loss:1.448, Validation accuracy:48.33%
# Epoch 366: iteration 36/37
# loss:0.442, Epoch accuracy:92.00%, Validation loss:1.430, Validation accuracy:48.75%
# Epoch 367: iteration 36/37
# loss:0.435, Epoch accuracy:91.58%, Validation loss:1.439, Validation accuracy:50.42%
# Epoch 368: iteration 36/37
# loss:0.439, Epoch accuracy:92.42%, Validation loss:1.413, Validation accuracy:50.83%
# Epoch 369: iteration 36/37
# loss:0.421, Epoch accuracy:92.17%, Validation loss:1.415, Validation accuracy:51.67%
# Epoch 370: iteration 36/37
# loss:0.414, Epoch accuracy:92.42%, Validation loss:1.423, Validation accuracy:48.75%
# Epoch 371: iteration 36/37
# loss:0.414, Epoch accuracy:92.75%, Validation loss:1.526, Validation accuracy:50.42%
# Epoch 372: iteration 36/37
# loss:0.428, Epoch accuracy:92.92%, Validation loss:1.482, Validation accuracy:50.83%
# Epoch 373: iteration 36/37
# loss:0.423, Epoch accuracy:93.42%, Validation loss:1.376, Validation accuracy:50.83%
# Epoch 374: iteration 36/37
# loss:0.413, Epoch accuracy:92.25%, Validation loss:1.547, Validation accuracy:46.25%
# Epoch 375: iteration 36/37
# loss:0.421, Epoch accuracy:92.42%, Validation loss:1.438, Validation accuracy:50.42%
# Epoch 376: iteration 36/37
# loss:0.413, Epoch accuracy:92.50%, Validation loss:1.410, Validation accuracy:46.25%
# Epoch 377: iteration 36/37
# loss:0.429, Epoch accuracy:91.00%, Validation loss:1.419, Validation accuracy:47.08%
# Epoch 378: iteration 36/37
# loss:0.424, Epoch accuracy:91.83%, Validation loss:1.421, Validation accuracy:48.33%
# Epoch 379: iteration 36/37
# loss:0.405, Epoch accuracy:93.33%, Validation loss:1.493, Validation accuracy:49.58%
# Epoch 380: iteration 36/37
# loss:0.404, Epoch accuracy:92.58%, Validation loss:1.491, Validation accuracy:51.67%
# Epoch 381: iteration 36/37
# loss:0.404, Epoch accuracy:93.67%, Validation loss:1.458, Validation accuracy:45.83%
# Epoch 382: iteration 36/37
# loss:0.414, Epoch accuracy:93.33%, Validation loss:1.371, Validation accuracy:51.67%
# Epoch 383: iteration 36/37
# loss:0.413, Epoch accuracy:93.33%, Validation loss:1.362, Validation accuracy:50.42%
# Epoch 384: iteration 36/37
# loss:0.401, Epoch accuracy:93.58%, Validation loss:1.379, Validation accuracy:52.92%
# Epoch 385: iteration 36/37
# loss:0.411, Epoch accuracy:92.92%, Validation loss:1.553, Validation accuracy:49.17%
# Epoch 386: iteration 36/37
# loss:0.408, Epoch accuracy:93.50%, Validation loss:1.377, Validation accuracy:52.08%
# Epoch 387: iteration 36/37
# loss:0.390, Epoch accuracy:93.83%, Validation loss:1.760, Validation accuracy:37.08%
# Epoch 388: iteration 36/37
# loss:0.392, Epoch accuracy:93.33%, Validation loss:1.562, Validation accuracy:50.42%
# Epoch 389: iteration 36/37
# loss:0.413, Epoch accuracy:92.17%, Validation loss:1.439, Validation accuracy:51.25%
# Epoch 390: iteration 36/37
# loss:0.398, Epoch accuracy:93.17%, Validation loss:1.493, Validation accuracy:47.08%
# Epoch 391: iteration 36/37
# loss:0.381, Epoch accuracy:93.67%, Validation loss:1.402, Validation accuracy:50.83%
# Epoch 392: iteration 36/37
# loss:0.382, Epoch accuracy:93.92%, Validation loss:1.422, Validation accuracy:52.92%
# Epoch 393: iteration 36/37
# loss:0.390, Epoch accuracy:93.50%, Validation loss:1.419, Validation accuracy:49.58%
# Epoch 394: iteration 36/37
# loss:0.386, Epoch accuracy:93.58%, Validation loss:1.433, Validation accuracy:48.75%
# Epoch 395: iteration 36/37
# loss:0.385, Epoch accuracy:94.00%, Validation loss:1.560, Validation accuracy:49.58%
# Epoch 396: iteration 36/37
# loss:0.389, Epoch accuracy:93.25%, Validation loss:1.425, Validation accuracy:50.83%
# Epoch 397: iteration 36/37
# loss:0.375, Epoch accuracy:94.33%, Validation loss:1.426, Validation accuracy:50.83%
# Epoch 398: iteration 36/37
# loss:0.367, Epoch accuracy:94.25%, Validation loss:1.439, Validation accuracy:49.58%
# Epoch 399: iteration 36/37
# loss:0.371, Epoch accuracy:94.17%, Validation loss:1.400, Validation accuracy:50.42%
# Epoch 400: iteration 36/37
# loss:0.371, Epoch accuracy:94.42%, Validation loss:1.552, Validation accuracy:47.92%
# Epoch 401: iteration 36/37
# loss:0.370, Epoch accuracy:93.92%, Validation loss:1.432, Validation accuracy:47.92%
# Epoch 402: iteration 36/37
# loss:0.365, Epoch accuracy:94.42%, Validation loss:1.440, Validation accuracy:52.08%
# Epoch 403: iteration 36/37
# loss:0.356, Epoch accuracy:94.75%, Validation loss:1.383, Validation accuracy:53.33%
# Epoch 404: iteration 36/37
# loss:0.368, Epoch accuracy:94.33%, Validation loss:1.455, Validation accuracy:48.33%
# Epoch 405: iteration 36/37
# loss:0.365, Epoch accuracy:94.33%, Validation loss:1.453, Validation accuracy:47.92%
# Epoch 406: iteration 36/37
# loss:0.363, Epoch accuracy:94.08%, Validation loss:1.354, Validation accuracy:50.83%
# Epoch 407: iteration 36/37
# loss:0.349, Epoch accuracy:94.42%, Validation loss:1.409, Validation accuracy:50.42%
# Epoch 408: iteration 36/37
# loss:0.365, Epoch accuracy:94.33%, Validation loss:1.560, Validation accuracy:46.67%
# Epoch 409: iteration 36/37
# loss:0.359, Epoch accuracy:94.67%, Validation loss:1.512, Validation accuracy:44.58%
# Epoch 410: iteration 36/37
# loss:0.369, Epoch accuracy:93.58%, Validation loss:1.391, Validation accuracy:51.67%
# Epoch 411: iteration 36/37
# loss:0.358, Epoch accuracy:94.75%, Validation loss:1.426, Validation accuracy:49.58%
# Epoch 412: iteration 36/37
# loss:0.352, Epoch accuracy:94.75%, Validation loss:1.668, Validation accuracy:51.25%
# Epoch 413: iteration 36/37
# loss:0.341, Epoch accuracy:95.08%, Validation loss:1.408, Validation accuracy:48.33%
# Epoch 414: iteration 36/37
# loss:0.332, Epoch accuracy:96.17%, Validation loss:1.464, Validation accuracy:50.83%
# Epoch 415: iteration 36/37
# loss:0.349, Epoch accuracy:94.67%, Validation loss:1.454, Validation accuracy:50.42%
# Epoch 416: iteration 36/37
# loss:0.331, Epoch accuracy:95.17%, Validation loss:1.488, Validation accuracy:47.50%
# Epoch 417: iteration 36/37
# loss:0.334, Epoch accuracy:95.33%, Validation loss:1.531, Validation accuracy:50.42%
# Epoch 418: iteration 36/37
# loss:0.336, Epoch accuracy:95.25%, Validation loss:1.444, Validation accuracy:50.00%
# Epoch 419: iteration 36/37
# loss:0.354, Epoch accuracy:94.75%, Validation loss:1.461, Validation accuracy:48.75%
# Epoch 420: iteration 36/37
# loss:0.337, Epoch accuracy:94.83%, Validation loss:1.588, Validation accuracy:42.50%
# Epoch 421: iteration 36/37
# loss:0.343, Epoch accuracy:94.67%, Validation loss:1.515, Validation accuracy:47.50%
# Epoch 422: iteration 36/37
# loss:0.336, Epoch accuracy:94.33%, Validation loss:1.412, Validation accuracy:47.08%
# Epoch 423: iteration 36/37
# loss:0.344, Epoch accuracy:94.83%, Validation loss:1.634, Validation accuracy:42.08%
# Epoch 424: iteration 36/37
# loss:0.332, Epoch accuracy:95.25%, Validation loss:1.529, Validation accuracy:47.50%
# Epoch 425: iteration 36/37
# loss:0.338, Epoch accuracy:94.58%, Validation loss:1.501, Validation accuracy:48.75%
# Epoch 426: iteration 36/37
# loss:0.324, Epoch accuracy:95.83%, Validation loss:1.362, Validation accuracy:52.50%
# Epoch 427: iteration 36/37
# loss:0.330, Epoch accuracy:95.17%, Validation loss:1.413, Validation accuracy:50.42%
# Epoch 428: iteration 36/37
# loss:0.331, Epoch accuracy:95.33%, Validation loss:1.641, Validation accuracy:44.58%
# Epoch 429: iteration 36/37
# loss:0.322, Epoch accuracy:94.83%, Validation loss:1.610, Validation accuracy:50.00%
# Epoch 430: iteration 36/37
# loss:0.334, Epoch accuracy:95.00%, Validation loss:1.385, Validation accuracy:52.50%
# Epoch 431: iteration 36/37
# loss:0.317, Epoch accuracy:95.83%, Validation loss:1.480, Validation accuracy:47.50%
# Epoch 432: iteration 36/37
# loss:0.322, Epoch accuracy:95.42%, Validation loss:1.409, Validation accuracy:50.00%
# Epoch 433: iteration 36/37
# loss:0.320, Epoch accuracy:96.42%, Validation loss:1.515, Validation accuracy:41.25%
# Epoch 434: iteration 36/37
# loss:0.319, Epoch accuracy:95.92%, Validation loss:1.377, Validation accuracy:50.00%
# Epoch 435: iteration 36/37
# loss:0.317, Epoch accuracy:95.83%, Validation loss:1.449, Validation accuracy:48.33%
# Epoch 436: iteration 36/37
# loss:0.310, Epoch accuracy:95.58%, Validation loss:1.419, Validation accuracy:52.08%
# Epoch 437: iteration 36/37
# loss:0.315, Epoch accuracy:95.92%, Validation loss:1.464, Validation accuracy:50.42%
# Epoch 438: iteration 36/37
# loss:0.304, Epoch accuracy:95.92%, Validation loss:1.415, Validation accuracy:49.58%
# Epoch 439: iteration 36/37
# loss:0.311, Epoch accuracy:95.58%, Validation loss:1.422, Validation accuracy:51.25%
# Epoch 440: iteration 36/37
# loss:0.306, Epoch accuracy:95.83%, Validation loss:1.458, Validation accuracy:49.58%
# Epoch 441: iteration 36/37
# loss:0.307, Epoch accuracy:95.92%, Validation loss:1.451, Validation accuracy:49.17%
# Epoch 442: iteration 36/37
# loss:0.308, Epoch accuracy:95.17%, Validation loss:1.574, Validation accuracy:42.92%
# Epoch 443: iteration 36/37
# loss:0.298, Epoch accuracy:96.17%, Validation loss:1.407, Validation accuracy:50.83%
# Epoch 444: iteration 36/37
# loss:0.292, Epoch accuracy:96.33%, Validation loss:1.399, Validation accuracy:52.08%
# Epoch 445: iteration 36/37
# loss:0.314, Epoch accuracy:95.17%, Validation loss:1.423, Validation accuracy:50.42%
# Epoch 446: iteration 36/37
# loss:0.292, Epoch accuracy:96.58%, Validation loss:1.410, Validation accuracy:49.58%
# Epoch 447: iteration 36/37
# loss:0.291, Epoch accuracy:96.17%, Validation loss:1.424, Validation accuracy:49.58%
# Epoch 448: iteration 36/37
# loss:0.293, Epoch accuracy:96.67%, Validation loss:1.492, Validation accuracy:50.00%
# Epoch 449: iteration 36/37
# loss:0.289, Epoch accuracy:96.08%, Validation loss:1.471, Validation accuracy:49.58%
# Epoch 450: iteration 36/37
# loss:0.286, Epoch accuracy:96.75%, Validation loss:1.473, Validation accuracy:49.58%
# Epoch 451: iteration 36/37
# loss:0.294, Epoch accuracy:96.00%, Validation loss:1.629, Validation accuracy:48.33%
# Epoch 452: iteration 36/37
# loss:0.297, Epoch accuracy:96.67%, Validation loss:1.465, Validation accuracy:45.83%
# Epoch 453: iteration 36/37
# loss:0.297, Epoch accuracy:95.67%, Validation loss:1.484, Validation accuracy:49.17%
# Epoch 454: iteration 36/37
# loss:0.283, Epoch accuracy:96.17%, Validation loss:1.453, Validation accuracy:47.08%
# Epoch 455: iteration 36/37
# loss:0.282, Epoch accuracy:96.50%, Validation loss:1.531, Validation accuracy:46.25%
# Epoch 456: iteration 36/37
# loss:0.268, Epoch accuracy:96.92%, Validation loss:1.461, Validation accuracy:50.83%
# Epoch 457: iteration 36/37
# loss:0.298, Epoch accuracy:96.25%, Validation loss:1.405, Validation accuracy:50.83%
# Epoch 458: iteration 36/37
# loss:0.279, Epoch accuracy:96.00%, Validation loss:1.410, Validation accuracy:50.83%
# Epoch 459: iteration 36/37
# loss:0.265, Epoch accuracy:96.58%, Validation loss:1.420, Validation accuracy:49.17%
# Epoch 460: iteration 36/37
# loss:0.281, Epoch accuracy:96.25%, Validation loss:1.430, Validation accuracy:50.00%
# Epoch 461: iteration 36/37
# loss:0.280, Epoch accuracy:96.42%, Validation loss:1.417, Validation accuracy:54.17%
# Epoch 462: iteration 36/37
# loss:0.273, Epoch accuracy:96.67%, Validation loss:1.539, Validation accuracy:50.00%
# Epoch 463: iteration 36/37
# loss:0.284, Epoch accuracy:96.42%, Validation loss:1.385, Validation accuracy:51.25%
# Epoch 464: iteration 36/37
# loss:0.268, Epoch accuracy:97.25%, Validation loss:1.397, Validation accuracy:52.92%
# Epoch 465: iteration 36/37
# loss:0.275, Epoch accuracy:95.75%, Validation loss:1.415, Validation accuracy:50.42%
# Epoch 466: iteration 36/37
# loss:0.272, Epoch accuracy:96.08%, Validation loss:1.479, Validation accuracy:51.67%
# Epoch 467: iteration 36/37
# loss:0.266, Epoch accuracy:96.75%, Validation loss:1.554, Validation accuracy:50.42%
# Epoch 468: iteration 36/37
# loss:0.270, Epoch accuracy:96.75%, Validation loss:1.463, Validation accuracy:49.17%
# Epoch 469: iteration 36/37
# loss:0.284, Epoch accuracy:95.67%, Validation loss:1.444, Validation accuracy:49.58%
# Epoch 470: iteration 36/37
# loss:0.257, Epoch accuracy:96.75%, Validation loss:1.462, Validation accuracy:48.75%
# Epoch 471: iteration 36/37
# loss:0.262, Epoch accuracy:96.92%, Validation loss:1.448, Validation accuracy:52.92%
# Epoch 472: iteration 36/37
# loss:0.285, Epoch accuracy:95.92%, Validation loss:1.534, Validation accuracy:45.00%
# Epoch 473: iteration 36/37
# loss:0.257, Epoch accuracy:97.00%, Validation loss:1.495, Validation accuracy:52.08%
# Epoch 474: iteration 36/37
# loss:0.263, Epoch accuracy:96.75%, Validation loss:1.619, Validation accuracy:44.58%
# Epoch 475: iteration 36/37
# loss:0.250, Epoch accuracy:97.08%, Validation loss:1.679, Validation accuracy:46.67%
# Epoch 476: iteration 36/37
# loss:0.265, Epoch accuracy:96.58%, Validation loss:1.722, Validation accuracy:45.83%
# Epoch 477: iteration 36/37
# loss:0.261, Epoch accuracy:96.33%, Validation loss:1.736, Validation accuracy:47.50%
# Epoch 478: iteration 36/37
# loss:0.266, Epoch accuracy:96.17%, Validation loss:1.451, Validation accuracy:49.58%
# Epoch 479: iteration 36/37
# loss:0.258, Epoch accuracy:96.67%, Validation loss:1.468, Validation accuracy:49.58%
# Epoch 480: iteration 36/37
# loss:0.246, Epoch accuracy:97.33%, Validation loss:1.452, Validation accuracy:50.83%
# Epoch 481: iteration 36/37
# loss:0.256, Epoch accuracy:96.83%, Validation loss:1.465, Validation accuracy:44.58%
# Epoch 482: iteration 36/37
# loss:0.246, Epoch accuracy:96.50%, Validation loss:1.461, Validation accuracy:52.92%
# Epoch 483: iteration 36/37
# loss:0.254, Epoch accuracy:97.50%, Validation loss:1.477, Validation accuracy:52.50%
# Epoch 484: iteration 36/37
# loss:0.246, Epoch accuracy:96.67%, Validation loss:1.443, Validation accuracy:51.67%
# Epoch 485: iteration 36/37
# loss:0.248, Epoch accuracy:97.50%, Validation loss:1.403, Validation accuracy:51.67%
# Epoch 486: iteration 36/37
# loss:0.261, Epoch accuracy:96.75%, Validation loss:1.554, Validation accuracy:48.75%
# Epoch 487: iteration 36/37
# loss:0.247, Epoch accuracy:97.33%, Validation loss:1.502, Validation accuracy:47.92%
# Epoch 488: iteration 36/37
# loss:0.251, Epoch accuracy:97.25%, Validation loss:1.471, Validation accuracy:46.67%
# Epoch 489: iteration 36/37
# loss:0.250, Epoch accuracy:97.25%, Validation loss:1.484, Validation accuracy:50.83%
# Epoch 490: iteration 36/37
# loss:0.231, Epoch accuracy:97.33%, Validation loss:1.513, Validation accuracy:49.17%
# Epoch 491: iteration 36/37
# loss:0.238, Epoch accuracy:96.92%, Validation loss:1.567, Validation accuracy:43.33%
# Epoch 492: iteration 36/37
# loss:0.232, Epoch accuracy:97.08%, Validation loss:1.396, Validation accuracy:49.58%
# Epoch 493: iteration 36/37
# loss:0.237, Epoch accuracy:96.75%, Validation loss:1.487, Validation accuracy:48.33%
# Epoch 494: iteration 36/37
# loss:0.237, Epoch accuracy:97.08%, Validation loss:1.439, Validation accuracy:47.08%
# Epoch 495: iteration 36/37
# loss:0.245, Epoch accuracy:97.00%, Validation loss:1.517, Validation accuracy:49.17%
# Epoch 496: iteration 36/37
# loss:0.234, Epoch accuracy:97.83%, Validation loss:1.422, Validation accuracy:49.58%
# Epoch 497: iteration 36/37
# loss:0.236, Epoch accuracy:97.42%, Validation loss:1.412, Validation accuracy:50.83%
# Epoch 498: iteration 36/37
# loss:0.238, Epoch accuracy:97.08%, Validation loss:1.584, Validation accuracy:46.25%
# Epoch 499: iteration 36/37
# loss:0.227, Epoch accuracy:97.25%, Validation loss:1.485, Validation accuracy:48.75%
#
#
# [*] done !
# [*] Best training loss - 0.22652082641919455
# [*] Best validation loss - 1.321410059928894

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    
    print("="*40)
    print(f'[*] Fold-{fold}')
    print(f'Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    print("="*40)
# Out:
# ========================================
# [*] Fold-0
# Test accuracy is 59.33%
#               precision    recall  f1-score   support
#
#            0       0.40      0.30      0.34        20
#            1       0.81      0.62      0.70        40
#            2       0.53      0.40      0.46        40
#            3       0.34      0.50      0.40        40
#            4       0.78      0.72      0.75        40
#            5       0.56      0.57      0.57        40
#            6       0.58      0.65      0.61        40
#            7       0.79      0.82      0.80        40
#
#     accuracy                           0.59       300
#    macro avg       0.60      0.57      0.58       300
# weighted avg       0.61      0.59      0.60       300
# ========================================
# ========================================
# [*] Fold-1
# Test accuracy is 44.67%
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        20
#            1       0.59      0.65      0.62        40
#            2       0.26      0.25      0.25        40
#            3       0.36      0.40      0.38        40
#            4       0.53      0.53      0.53        40
#            5       0.28      0.28      0.28        40
#            6       0.50      0.57      0.53        40
#            7       0.64      0.68      0.66        40
#
#     accuracy                           0.45       300
#    macro avg       0.40      0.42      0.41       300
# weighted avg       0.42      0.45      0.43       300
# ========================================
# ========================================
# [*] Fold-2
# Test accuracy is 49.00%
#               precision    recall  f1-score   support
#
#            0       0.67      0.10      0.17        20
#            1       0.57      0.75      0.65        40
#            2       0.38      0.45      0.41        40
#            3       0.39      0.35      0.37        40
#            4       0.51      0.60      0.55        40
#            5       0.49      0.62      0.55        40
#            6       0.45      0.47      0.46        40
#            7       0.71      0.38      0.49        40
#
#     accuracy                           0.49       300
#    macro avg       0.52      0.47      0.46       300
# weighted avg       0.51      0.49      0.48       300
# ========================================
# ========================================
# [*] Fold-3
# Test accuracy is 53.33%
#               precision    recall  f1-score   support
#
#            0       0.44      0.55      0.49        20
#            1       0.58      0.80      0.67        40
#            2       0.43      0.25      0.32        40
#            3       0.31      0.20      0.24        40
#            4       0.58      0.65      0.61        40
#            5       0.41      0.47      0.44        40
#            6       0.65      0.65      0.65        40
#            7       0.70      0.70      0.70        40
#
#     accuracy                           0.53       300
#    macro avg       0.51      0.53      0.52       300
# weighted avg       0.52      0.53      0.52       300
# ========================================
# ========================================
# [*] Fold-4
# Test accuracy is 52.08%
#               precision    recall  f1-score   support
#
#            0       0.60      0.19      0.29        16
#            1       0.56      0.69      0.62        32
#            2       0.44      0.44      0.44        32
#            3       0.33      0.56      0.42        32
#            4       0.64      0.66      0.65        32
#            5       0.61      0.34      0.44        32
#            6       0.56      0.59      0.58        32
#            7       0.68      0.53      0.60        32
#
#     accuracy                           0.52       240
#    macro avg       0.55      0.50      0.50       240
# weighted avg       0.55      0.52      0.52       240
# ========================================

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f' - Best fold acc : {max(test_accs):.2f}%')
print(f' - Worst fold acc : {min(test_accs):.2f}%')
print(f' - Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
#  - Best fold acc : 59.33%
#  - Worst fold acc : 44.67%
#  - Average fold acc : 51.68%
