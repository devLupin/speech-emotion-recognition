# %%
from cv2 import transform
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
from einops import rearrange

# %% [markdown]
# ## LFLB (N Filter)
#
# Speech emotion recognition using deep 1d & 2d cnn lstm networks. Biomedical Signal Processing and Control 47, 312–323 (2019)

# %%
class LFLB(nn.Module):
    """Some Information about LFLB"""
    def __init__(self, in_chan, out_chan, kernel=[2, 2], stride=[1, 1], pad=1):
        super(LFLB, self).__init__()

        self.cnn = nn.Conv2d(in_channels=in_chan, out_channels=out_chan, kernel_size=kernel, stride=stride, padding=pad)
        self.bn = nn.BatchNorm2d(out_chan)
        self.relu = nn.ReLU()
        self.max_pool =  nn.MaxPool2d(kernel_size=kernel, stride=[2, 2])

    def forward(self, x):
        cnn_embd = self.cnn(x)
        cnn_embd = self.bn(cnn_embd)
        cnn_embd = self.relu(cnn_embd)
        output = self.max_pool(cnn_embd)

        return output

# %% [markdown]
# ## NAC Unit
#
# [1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun, Identity Mappings in Deep Residual Networks. arXiv:1603.05027
# https://github.com/kuangliu/pytorch-cifar/blob/master/models/preact_resnet.py

# %%
class NACUnit(nn.Module):
    '''Pre-activation version of the BasicBlock.'''
    expansion = 1

    def __init__(self, in_planes, planes, kernel, stride=1, pad=0):
        super(NACUnit, self).__init__()
        
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=kernel, stride=stride, padding=pad, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=kernel, stride=1, padding=1, bias=False)

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        return out

# %%
class ResLFLB(nn.Module):
    def __init__(self, in_chan, n_filters, kernel):
        super(ResLFLB, self).__init__()
        
        self.lflb = LFLB(in_chan=in_chan, out_chan=n_filters)
        
        self.nac_unit1 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1, pad=1)
        self.nac_unit2 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit3 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit4 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit5 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1)

    def forward(self, x):
        lflb_embd = self.lflb(x)
        
        nac_embd = self.nac_unit1(lflb_embd)
        nac_embd = self.nac_unit2(nac_embd)
        nac_embd = self.nac_unit3(nac_embd)
        nac_embd = self.nac_unit4(nac_embd)
        nac_embd = self.nac_unit5(nac_embd)
        
        output = lflb_embd + nac_embd

        return output

# %%
class Model(nn.Module):
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.MFL = LFLB(3, 32)
        
        self.res_lflb1 = ResLFLB(32, 32, [3, 3])
        self.res_lflb2 = ResLFLB(32, 32, [3, 3])
        self.res_lflb3 = ResLFLB(32, 32, [3, 3])
        self.res_lflb4 = ResLFLB(32, 64, [3, 3])
        self.res_lflb5 = ResLFLB(64, 128, [3, 3])
        
        self.relu = nn.ReLU()
        self.max_pool = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2])
        self.dropout = nn.Dropout(0.25)
        self.linear = nn.Linear(512, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        MFL_embd = self.MFL(x)
        
        res_lflb_embd = self.res_lflb1(MFL_embd)
        res_lflb_embd = self.res_lflb2(res_lflb_embd)
        res_lflb_embd = self.res_lflb3(res_lflb_embd)
        res_lflb_embd = self.res_lflb4(res_lflb_embd)
        res_lflb_embd = self.res_lflb5(res_lflb_embd)
        
        mlp = self.relu(res_lflb_embd)
        mlp = self.max_pool(mlp)
        mlp = self.dropout(mlp)
        mlp = torch.flatten(mlp, start_dim=1)
        output_logits = self.linear(mlp)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'surprised',
    '1': 'neutral',
    '2': 'calm',
    '3': 'happy',
    '4': 'sad',
    '5': 'angry',
    '6': 'fearful',
    '7': 'disgust'
}


sub_name = 'ResLFLB'
data_name = 'RAVDESS'

minibatch = 32
num_epochs = 1000
EARLY_CNT = 1000

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = '5-CV-augment'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - ResLFLB
# 0:   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 0: iteration 70/71
# Epoch 0 --- loss:2.601, Epoch accuracy:11.67%, Validation loss:2.254, Validation accuracy:13.00%
# Epoch 1: iteration 70/71
# Epoch 1 --- loss:2.361, Epoch accuracy:11.97%, Validation loss:2.142, Validation accuracy:16.67%
# Epoch 2: iteration 70/71
# Epoch 2 --- loss:2.254, Epoch accuracy:15.31%, Validation loss:2.084, Validation accuracy:14.67%
# Epoch 3: iteration 70/71
# Epoch 3 --- loss:2.239, Epoch accuracy:13.77%, Validation loss:2.051, Validation accuracy:17.00%
# Epoch 4: iteration 70/71
# Epoch 4 --- loss:2.230, Epoch accuracy:15.53%, Validation loss:2.049, Validation accuracy:17.33%
# Epoch 5: iteration 70/71
# Epoch 5 --- loss:2.171, Epoch accuracy:18.07%, Validation loss:2.030, Validation accuracy:21.33%
# Epoch 6: iteration 70/71
# Epoch 6 --- loss:2.177, Epoch accuracy:16.01%, Validation loss:2.036, Validation accuracy:19.33%
# Epoch 7: iteration 70/71
# Epoch 7 --- loss:2.177, Epoch accuracy:17.02%, Validation loss:2.037, Validation accuracy:18.67%
# Epoch 8: iteration 70/71
# Epoch 8 --- loss:2.176, Epoch accuracy:16.05%, Validation loss:2.016, Validation accuracy:19.33%
# Epoch 9: iteration 70/71
# Epoch 9 --- loss:2.142, Epoch accuracy:18.46%, Validation loss:2.035, Validation accuracy:18.67%
# Epoch 10: iteration 70/71
# Epoch 10 --- loss:2.125, Epoch accuracy:18.73%, Validation loss:2.020, Validation accuracy:17.00%
# Epoch 11: iteration 70/71
# Epoch 11 --- loss:2.142, Epoch accuracy:17.06%, Validation loss:1.998, Validation accuracy:19.67%
# Epoch 12: iteration 70/71
# Epoch 12 --- loss:2.096, Epoch accuracy:19.56%, Validation loss:2.019, Validation accuracy:18.67%
# Epoch 13: iteration 70/71
# Epoch 13 --- loss:2.106, Epoch accuracy:17.46%, Validation loss:1.991, Validation accuracy:20.00%
# Epoch 14: iteration 70/71
# Epoch 14 --- loss:2.096, Epoch accuracy:19.52%, Validation loss:1.984, Validation accuracy:21.67%
# Epoch 15: iteration 70/71
# Epoch 15 --- loss:2.083, Epoch accuracy:19.91%, Validation loss:1.992, Validation accuracy:22.33%
# Epoch 16: iteration 70/71
# Epoch 16 --- loss:2.082, Epoch accuracy:20.09%, Validation loss:1.992, Validation accuracy:20.67%
# Epoch 17: iteration 70/71
# Epoch 17 --- loss:2.059, Epoch accuracy:19.96%, Validation loss:1.974, Validation accuracy:23.33%
# Epoch 18: iteration 70/71
# Epoch 18 --- loss:2.056, Epoch accuracy:20.70%, Validation loss:1.986, Validation accuracy:23.00%
# Epoch 19: iteration 70/71
# Epoch 19 --- loss:2.033, Epoch accuracy:22.54%, Validation loss:1.986, Validation accuracy:22.00%
# Epoch 20: iteration 70/71
# Epoch 20 --- loss:2.023, Epoch accuracy:22.19%, Validation loss:1.980, Validation accuracy:25.67%
# Epoch 21: iteration 70/71
# Epoch 21 --- loss:2.026, Epoch accuracy:21.62%, Validation loss:1.970, Validation accuracy:25.33%
# Epoch 22: iteration 70/71
# Epoch 22 --- loss:2.011, Epoch accuracy:23.55%, Validation loss:1.968, Validation accuracy:25.67%
# Epoch 23: iteration 70/71
# Epoch 23 --- loss:2.006, Epoch accuracy:21.80%, Validation loss:1.962, Validation accuracy:24.33%
# Epoch 24: iteration 70/71
# Epoch 24 --- loss:1.983, Epoch accuracy:23.16%, Validation loss:1.957, Validation accuracy:25.67%
# Epoch 25: iteration 70/71
# Epoch 25 --- loss:1.997, Epoch accuracy:23.03%, Validation loss:1.950, Validation accuracy:25.67%
# Epoch 26: iteration 70/71
# Epoch 26 --- loss:1.975, Epoch accuracy:23.90%, Validation loss:1.952, Validation accuracy:24.67%
# Epoch 27: iteration 70/71
# Epoch 27 --- loss:1.971, Epoch accuracy:24.30%, Validation loss:1.942, Validation accuracy:25.00%
# Epoch 28: iteration 70/71
# Epoch 28 --- loss:1.953, Epoch accuracy:24.12%, Validation loss:1.900, Validation accuracy:27.33%
# Epoch 29: iteration 70/71
# Epoch 29 --- loss:1.952, Epoch accuracy:24.82%, Validation loss:1.907, Validation accuracy:26.00%
# Epoch 30: iteration 70/71
# Epoch 30 --- loss:1.921, Epoch accuracy:26.05%, Validation loss:1.908, Validation accuracy:28.33%
# Epoch 31: iteration 70/71
# Epoch 31 --- loss:1.929, Epoch accuracy:25.79%, Validation loss:1.893, Validation accuracy:27.33%
# Epoch 32: iteration 70/71
# Epoch 32 --- loss:1.923, Epoch accuracy:26.14%, Validation loss:1.886, Validation accuracy:26.00%
# Epoch 33: iteration 70/71
# Epoch 33 --- loss:1.916, Epoch accuracy:26.49%, Validation loss:1.880, Validation accuracy:28.33%
# Epoch 34: iteration 70/71
# Epoch 34 --- loss:1.877, Epoch accuracy:28.51%, Validation loss:1.864, Validation accuracy:29.67%
# Epoch 35: iteration 70/71
# Epoch 35 --- loss:1.874, Epoch accuracy:29.82%, Validation loss:1.838, Validation accuracy:32.00%
# Epoch 36: iteration 70/71
# Epoch 36 --- loss:1.849, Epoch accuracy:29.39%, Validation loss:1.852, Validation accuracy:28.33%
# Epoch 37: iteration 70/71
# Epoch 37 --- loss:1.860, Epoch accuracy:28.42%, Validation loss:1.839, Validation accuracy:32.00%
# Epoch 38: iteration 70/71
# Epoch 38 --- loss:1.828, Epoch accuracy:30.66%, Validation loss:1.861, Validation accuracy:29.00%
# Epoch 39: iteration 70/71
# Epoch 39 --- loss:1.828, Epoch accuracy:30.31%, Validation loss:1.852, Validation accuracy:29.67%
# Epoch 40: iteration 70/71
# Epoch 40 --- loss:1.827, Epoch accuracy:31.01%, Validation loss:1.846, Validation accuracy:27.00%
# Epoch 41: iteration 70/71
# Epoch 41 --- loss:1.803, Epoch accuracy:32.11%, Validation loss:1.834, Validation accuracy:30.33%
# Epoch 42: iteration 70/71
# Epoch 42 --- loss:1.783, Epoch accuracy:31.23%, Validation loss:1.824, Validation accuracy:35.00%
# Epoch 43: iteration 70/71
# Epoch 43 --- loss:1.778, Epoch accuracy:32.50%, Validation loss:1.821, Validation accuracy:29.00%
# Epoch 44: iteration 70/71
# Epoch 44 --- loss:1.774, Epoch accuracy:32.59%, Validation loss:1.801, Validation accuracy:32.67%
# Epoch 45: iteration 70/71
# Epoch 45 --- loss:1.767, Epoch accuracy:33.46%, Validation loss:1.791, Validation accuracy:34.33%
# Epoch 46: iteration 70/71
# Epoch 46 --- loss:1.748, Epoch accuracy:33.90%, Validation loss:1.804, Validation accuracy:31.67%
# Epoch 47: iteration 70/71
# Epoch 47 --- loss:1.723, Epoch accuracy:34.30%, Validation loss:1.799, Validation accuracy:31.67%
# Epoch 48: iteration 70/71
# Epoch 48 --- loss:1.728, Epoch accuracy:34.91%, Validation loss:1.779, Validation accuracy:32.00%
# Epoch 49: iteration 70/71
# Epoch 49 --- loss:1.712, Epoch accuracy:35.18%, Validation loss:1.753, Validation accuracy:34.00%
# Epoch 50: iteration 70/71
# Epoch 50 --- loss:1.710, Epoch accuracy:34.78%, Validation loss:1.766, Validation accuracy:31.67%
# Epoch 51: iteration 70/71
# Epoch 51 --- loss:1.687, Epoch accuracy:36.40%, Validation loss:1.765, Validation accuracy:33.67%
# Epoch 52: iteration 70/71
# Epoch 52 --- loss:1.659, Epoch accuracy:37.94%, Validation loss:1.774, Validation accuracy:32.33%
# Epoch 53: iteration 70/71
# Epoch 53 --- loss:1.673, Epoch accuracy:37.19%, Validation loss:1.757, Validation accuracy:33.00%
# Epoch 54: iteration 70/71
# Epoch 54 --- loss:1.622, Epoch accuracy:38.46%, Validation loss:1.767, Validation accuracy:30.00%
# Epoch 55: iteration 70/71
# Epoch 55 --- loss:1.636, Epoch accuracy:38.16%, Validation loss:1.743, Validation accuracy:33.67%
# Epoch 56: iteration 70/71
# Epoch 56 --- loss:1.601, Epoch accuracy:40.09%, Validation loss:1.755, Validation accuracy:34.33%
# Epoch 57: iteration 70/71
# Epoch 57 --- loss:1.580, Epoch accuracy:40.66%, Validation loss:1.748, Validation accuracy:35.67%
# Epoch 58: iteration 70/71
# Epoch 58 --- loss:1.585, Epoch accuracy:41.54%, Validation loss:1.755, Validation accuracy:34.33%
# Epoch 59: iteration 70/71
# Epoch 59 --- loss:1.540, Epoch accuracy:41.58%, Validation loss:1.761, Validation accuracy:34.33%
# Epoch 60: iteration 70/71
# Epoch 60 --- loss:1.543, Epoch accuracy:42.85%, Validation loss:1.753, Validation accuracy:32.33%
# Epoch 61: iteration 70/71
# Epoch 61 --- loss:1.521, Epoch accuracy:42.85%, Validation loss:1.743, Validation accuracy:33.67%
# Epoch 62: iteration 70/71
# Epoch 62 --- loss:1.518, Epoch accuracy:43.29%, Validation loss:1.735, Validation accuracy:33.33%
# Epoch 63: iteration 70/71
# Epoch 63 --- loss:1.499, Epoch accuracy:45.13%, Validation loss:1.739, Validation accuracy:33.33%
# Epoch 64: iteration 70/71
# Epoch 64 --- loss:1.489, Epoch accuracy:44.34%, Validation loss:1.719, Validation accuracy:37.00%
# Epoch 65: iteration 70/71
# Epoch 65 --- loss:1.461, Epoch accuracy:46.14%, Validation loss:1.697, Validation accuracy:37.33%
# Epoch 66: iteration 70/71
# Epoch 66 --- loss:1.446, Epoch accuracy:46.14%, Validation loss:1.732, Validation accuracy:32.33%
# Epoch 67: iteration 70/71
# Epoch 67 --- loss:1.413, Epoch accuracy:48.20%, Validation loss:1.731, Validation accuracy:34.33%
# Epoch 68: iteration 70/71
# Epoch 68 --- loss:1.426, Epoch accuracy:46.84%, Validation loss:1.731, Validation accuracy:36.33%
# Epoch 69: iteration 70/71
# Epoch 69 --- loss:1.376, Epoch accuracy:50.31%, Validation loss:1.773, Validation accuracy:35.00%
# Epoch 70: iteration 70/71
# Epoch 70 --- loss:1.346, Epoch accuracy:51.58%, Validation loss:1.754, Validation accuracy:36.00%
# Epoch 71: iteration 70/71
# Epoch 71 --- loss:1.343, Epoch accuracy:51.18%, Validation loss:1.753, Validation accuracy:34.33%
# Epoch 72: iteration 70/71
# Epoch 72 --- loss:1.332, Epoch accuracy:51.89%, Validation loss:1.723, Validation accuracy:35.33%
# Epoch 73: iteration 70/71
# Epoch 73 --- loss:1.322, Epoch accuracy:51.32%, Validation loss:1.746, Validation accuracy:34.00%
# Epoch 74: iteration 70/71
# Epoch 74 --- loss:1.274, Epoch accuracy:54.25%, Validation loss:1.724, Validation accuracy:37.67%
# Epoch 75: iteration 70/71
# Epoch 75 --- loss:1.280, Epoch accuracy:53.90%, Validation loss:1.729, Validation accuracy:37.67%
# Epoch 76: iteration 70/71
# Epoch 76 --- loss:1.249, Epoch accuracy:54.04%, Validation loss:1.759, Validation accuracy:32.33%
# Epoch 77: iteration 70/71
# Epoch 77 --- loss:1.207, Epoch accuracy:57.28%, Validation loss:1.730, Validation accuracy:38.00%
# Epoch 78: iteration 70/71
# Epoch 78 --- loss:1.197, Epoch accuracy:57.68%, Validation loss:1.780, Validation accuracy:37.00%
# Epoch 79: iteration 70/71
# Epoch 79 --- loss:1.184, Epoch accuracy:58.07%, Validation loss:1.714, Validation accuracy:36.00%
# Epoch 80: iteration 70/71
# Epoch 80 --- loss:1.165, Epoch accuracy:58.86%, Validation loss:1.724, Validation accuracy:33.33%
# Epoch 81: iteration 70/71
# Epoch 81 --- loss:1.138, Epoch accuracy:59.25%, Validation loss:1.730, Validation accuracy:35.00%
# Epoch 82: iteration 70/71
# Epoch 82 --- loss:1.138, Epoch accuracy:59.56%, Validation loss:1.769, Validation accuracy:35.67%
# Epoch 83: iteration 70/71
# Epoch 83 --- loss:1.115, Epoch accuracy:60.53%, Validation loss:1.763, Validation accuracy:33.00%
# Epoch 84: iteration 70/71
# Epoch 84 --- loss:1.052, Epoch accuracy:63.77%, Validation loss:1.767, Validation accuracy:34.33%
# Epoch 85: iteration 70/71
# Epoch 85 --- loss:1.063, Epoch accuracy:62.76%, Validation loss:1.763, Validation accuracy:35.33%
# Epoch 86: iteration 70/71
# Epoch 86 --- loss:1.039, Epoch accuracy:65.13%, Validation loss:1.835, Validation accuracy:36.33%
# Epoch 87: iteration 70/71
# Epoch 87 --- loss:0.988, Epoch accuracy:66.40%, Validation loss:1.779, Validation accuracy:36.33%
# Epoch 88: iteration 70/71
# Epoch 88 --- loss:0.979, Epoch accuracy:66.84%, Validation loss:1.805, Validation accuracy:37.00%
# Epoch 89: iteration 70/71
# Epoch 89 --- loss:0.931, Epoch accuracy:69.08%, Validation loss:1.772, Validation accuracy:36.33%
# Epoch 90: iteration 70/71
# Epoch 90 --- loss:0.914, Epoch accuracy:69.69%, Validation loss:1.807, Validation accuracy:34.67%
# Epoch 91: iteration 70/71
# Epoch 91 --- loss:0.888, Epoch accuracy:71.67%, Validation loss:1.819, Validation accuracy:37.33%
# Epoch 92: iteration 70/71
# Epoch 92 --- loss:0.877, Epoch accuracy:71.05%, Validation loss:1.847, Validation accuracy:35.67%
# Epoch 93: iteration 70/71
# Epoch 93 --- loss:0.856, Epoch accuracy:71.45%, Validation loss:1.808, Validation accuracy:35.33%
# Epoch 94: iteration 70/71
# Epoch 94 --- loss:0.843, Epoch accuracy:73.07%, Validation loss:1.846, Validation accuracy:34.33%
# Epoch 95: iteration 70/71
# Epoch 95 --- loss:0.829, Epoch accuracy:73.29%, Validation loss:1.811, Validation accuracy:37.33%
# Epoch 96: iteration 70/71
# Epoch 96 --- loss:0.784, Epoch accuracy:75.48%, Validation loss:1.839, Validation accuracy:34.33%
# Epoch 97: iteration 70/71
# Epoch 97 --- loss:0.749, Epoch accuracy:77.06%, Validation loss:1.946, Validation accuracy:33.33%
# Epoch 98: iteration 70/71
# Epoch 98 --- loss:0.745, Epoch accuracy:76.32%, Validation loss:1.825, Validation accuracy:34.33%
# Epoch 99: iteration 70/71
# Epoch 99 --- loss:0.707, Epoch accuracy:77.02%, Validation loss:1.941, Validation accuracy:34.33%
# Epoch 100: iteration 70/71
# Epoch 100 --- loss:0.737, Epoch accuracy:76.80%, Validation loss:1.957, Validation accuracy:36.67%
# Epoch 101: iteration 70/71
# Epoch 101 --- loss:0.678, Epoch accuracy:79.17%, Validation loss:1.921, Validation accuracy:36.67%
# Epoch 102: iteration 70/71
# Epoch 102 --- loss:0.694, Epoch accuracy:78.11%, Validation loss:1.987, Validation accuracy:34.67%
# Epoch 103: iteration 70/71
# Epoch 103 --- loss:0.658, Epoch accuracy:79.25%, Validation loss:1.928, Validation accuracy:37.33%
# Epoch 104: iteration 70/71
# Epoch 104 --- loss:0.627, Epoch accuracy:80.35%, Validation loss:1.894, Validation accuracy:36.33%
# Epoch 105: iteration 70/71
# Epoch 105 --- loss:0.628, Epoch accuracy:80.57%, Validation loss:1.894, Validation accuracy:36.33%
# Epoch 106: iteration 70/71
# Epoch 106 --- loss:0.575, Epoch accuracy:82.41%, Validation loss:1.979, Validation accuracy:35.00%
# Epoch 107: iteration 70/71
# Epoch 107 --- loss:0.572, Epoch accuracy:83.51%, Validation loss:1.956, Validation accuracy:38.00%
# Epoch 108: iteration 70/71
# Epoch 108 --- loss:0.540, Epoch accuracy:84.56%, Validation loss:1.986, Validation accuracy:36.33%
# Epoch 109: iteration 70/71
# Epoch 109 --- loss:0.541, Epoch accuracy:84.04%, Validation loss:1.946, Validation accuracy:34.33%
# Epoch 110: iteration 70/71
# Epoch 110 --- loss:0.524, Epoch accuracy:83.95%, Validation loss:1.978, Validation accuracy:36.33%
# Epoch 111: iteration 70/71
# Epoch 111 --- loss:0.507, Epoch accuracy:85.57%, Validation loss:2.000, Validation accuracy:32.67%
# Epoch 112: iteration 70/71
# Epoch 112 --- loss:0.493, Epoch accuracy:86.10%, Validation loss:1.961, Validation accuracy:35.67%
# Epoch 113: iteration 70/71
# Epoch 113 --- loss:0.453, Epoch accuracy:87.68%, Validation loss:1.953, Validation accuracy:34.00%
# Epoch 114: iteration 70/71
# Epoch 114 --- loss:0.472, Epoch accuracy:86.40%, Validation loss:2.009, Validation accuracy:37.00%
# Epoch 115: iteration 70/71
# Epoch 115 --- loss:0.469, Epoch accuracy:86.54%, Validation loss:2.057, Validation accuracy:32.67%
# Epoch 116: iteration 70/71
# Epoch 116 --- loss:0.441, Epoch accuracy:87.81%, Validation loss:2.070, Validation accuracy:32.33%
# Epoch 117: iteration 70/71
# Epoch 117 --- loss:0.407, Epoch accuracy:90.18%, Validation loss:2.022, Validation accuracy:35.67%
# Epoch 118: iteration 70/71
# Epoch 118 --- loss:0.407, Epoch accuracy:88.77%, Validation loss:2.027, Validation accuracy:33.00%
# Epoch 119: iteration 70/71
# Epoch 119 --- loss:0.394, Epoch accuracy:89.78%, Validation loss:2.116, Validation accuracy:32.00%
# Epoch 120: iteration 70/71
# Epoch 120 --- loss:0.352, Epoch accuracy:90.92%, Validation loss:2.069, Validation accuracy:34.33%
# Epoch 121: iteration 70/71
# Epoch 121 --- loss:0.344, Epoch accuracy:91.45%, Validation loss:2.124, Validation accuracy:34.67%
# Epoch 122: iteration 70/71
# Epoch 122 --- loss:0.350, Epoch accuracy:90.66%, Validation loss:2.127, Validation accuracy:34.00%
# Epoch 123: iteration 70/71
# Epoch 123 --- loss:0.322, Epoch accuracy:91.93%, Validation loss:2.108, Validation accuracy:34.67%
# Epoch 124: iteration 70/71
# Epoch 124 --- loss:0.351, Epoch accuracy:90.88%, Validation loss:2.089, Validation accuracy:34.00%
# Epoch 125: iteration 70/71
# Epoch 125 --- loss:0.321, Epoch accuracy:91.67%, Validation loss:2.101, Validation accuracy:33.67%
# Epoch 126: iteration 70/71
# Epoch 126 --- loss:0.281, Epoch accuracy:93.38%, Validation loss:2.182, Validation accuracy:32.33%
# Epoch 127: iteration 70/71
# Epoch 127 --- loss:0.307, Epoch accuracy:92.68%, Validation loss:2.185, Validation accuracy:33.33%
# Epoch 128: iteration 70/71
# Epoch 128 --- loss:0.312, Epoch accuracy:91.71%, Validation loss:2.157, Validation accuracy:35.33%
# Epoch 129: iteration 70/71
# Epoch 129 --- loss:0.277, Epoch accuracy:93.51%, Validation loss:2.174, Validation accuracy:31.33%
# Epoch 130: iteration 70/71
# Epoch 130 --- loss:0.263, Epoch accuracy:94.30%, Validation loss:2.145, Validation accuracy:36.00%
# Epoch 131: iteration 70/71
# Epoch 131 --- loss:0.278, Epoch accuracy:92.63%, Validation loss:2.258, Validation accuracy:31.00%
# Epoch 132: iteration 70/71
# Epoch 132 --- loss:0.258, Epoch accuracy:93.64%, Validation loss:2.232, Validation accuracy:35.33%
# Epoch 133: iteration 70/71
# Epoch 133 --- loss:0.252, Epoch accuracy:93.99%, Validation loss:2.154, Validation accuracy:34.00%
# Epoch 134: iteration 70/71
# Epoch 134 --- loss:0.229, Epoch accuracy:94.91%, Validation loss:2.209, Validation accuracy:33.67%
# Epoch 135: iteration 70/71
# Epoch 135 --- loss:0.222, Epoch accuracy:94.69%, Validation loss:2.208, Validation accuracy:36.00%
# Epoch 136: iteration 70/71
# Epoch 136 --- loss:0.237, Epoch accuracy:94.17%, Validation loss:2.231, Validation accuracy:34.00%
# Epoch 137: iteration 70/71
# Epoch 137 --- loss:0.202, Epoch accuracy:95.88%, Validation loss:2.235, Validation accuracy:36.67%
# Epoch 138: iteration 70/71
# Epoch 138 --- loss:0.210, Epoch accuracy:94.74%, Validation loss:2.299, Validation accuracy:35.33%
# Epoch 139: iteration 70/71
# Epoch 139 --- loss:0.186, Epoch accuracy:96.27%, Validation loss:2.237, Validation accuracy:34.67%
# Epoch 140: iteration 70/71
# Epoch 140 --- loss:0.201, Epoch accuracy:95.79%, Validation loss:2.194, Validation accuracy:34.67%
# Epoch 141: iteration 70/71
# Epoch 141 --- loss:0.197, Epoch accuracy:95.09%, Validation loss:2.291, Validation accuracy:32.00%
# Epoch 142: iteration 70/71
# Epoch 142 --- loss:0.161, Epoch accuracy:96.54%, Validation loss:2.258, Validation accuracy:34.67%
# Epoch 143: iteration 70/71
# Epoch 143 --- loss:0.184, Epoch accuracy:95.88%, Validation loss:2.311, Validation accuracy:34.67%
# Epoch 144: iteration 70/71
# Epoch 144 --- loss:0.183, Epoch accuracy:95.79%, Validation loss:2.276, Validation accuracy:35.00%
# Epoch 145: iteration 70/71
# Epoch 145 --- loss:0.157, Epoch accuracy:96.54%, Validation loss:2.313, Validation accuracy:35.00%
# Epoch 146: iteration 70/71
# Epoch 146 --- loss:0.159, Epoch accuracy:96.71%, Validation loss:2.302, Validation accuracy:36.67%
# Epoch 147: iteration 70/71
# Epoch 147 --- loss:0.148, Epoch accuracy:96.45%, Validation loss:2.211, Validation accuracy:35.67%
# Epoch 148: iteration 70/71
# Epoch 148 --- loss:0.156, Epoch accuracy:96.80%, Validation loss:2.201, Validation accuracy:33.67%
# Epoch 149: iteration 70/71
# Epoch 149 --- loss:0.143, Epoch accuracy:96.93%, Validation loss:2.228, Validation accuracy:36.67%
# Epoch 150: iteration 70/71
# Epoch 150 --- loss:0.144, Epoch accuracy:97.02%, Validation loss:2.247, Validation accuracy:34.00%
# Epoch 151: iteration 70/71
# Epoch 151 --- loss:0.136, Epoch accuracy:97.06%, Validation loss:2.176, Validation accuracy:37.33%
# Epoch 152: iteration 70/71
# Epoch 152 --- loss:0.125, Epoch accuracy:97.50%, Validation loss:2.305, Validation accuracy:35.67%
# Epoch 153: iteration 70/71
# Epoch 153 --- loss:0.132, Epoch accuracy:97.28%, Validation loss:2.296, Validation accuracy:35.67%
# Epoch 154: iteration 70/71
# Epoch 154 --- loss:0.125, Epoch accuracy:97.11%, Validation loss:2.313, Validation accuracy:36.33%
# Epoch 155: iteration 70/71
# Epoch 155 --- loss:0.137, Epoch accuracy:96.71%, Validation loss:2.304, Validation accuracy:32.67%
# Epoch 156: iteration 70/71
# Epoch 156 --- loss:0.143, Epoch accuracy:96.40%, Validation loss:2.443, Validation accuracy:35.00%
# Epoch 157: iteration 70/71
# Epoch 157 --- loss:0.110, Epoch accuracy:97.59%, Validation loss:2.376, Validation accuracy:33.67%
# Epoch 158: iteration 70/71
# Epoch 158 --- loss:0.116, Epoch accuracy:97.59%, Validation loss:2.369, Validation accuracy:35.67%
# Epoch 159: iteration 70/71
# Epoch 159 --- loss:0.118, Epoch accuracy:97.28%, Validation loss:2.469, Validation accuracy:38.33%
# Epoch 160: iteration 70/71
# Epoch 160 --- loss:0.112, Epoch accuracy:97.63%, Validation loss:2.330, Validation accuracy:36.00%
# Epoch 161: iteration 70/71
# Epoch 161 --- loss:0.100, Epoch accuracy:97.98%, Validation loss:2.398, Validation accuracy:35.33%
# Epoch 162: iteration 70/71
# Epoch 162 --- loss:0.125, Epoch accuracy:97.11%, Validation loss:2.336, Validation accuracy:37.67%
# Epoch 163: iteration 70/71
# Epoch 163 --- loss:0.103, Epoch accuracy:97.81%, Validation loss:2.451, Validation accuracy:35.00%
# Epoch 164: iteration 70/71
# Epoch 164 --- loss:0.094, Epoch accuracy:98.07%, Validation loss:2.414, Validation accuracy:35.00%
# Epoch 165: iteration 70/71
# Epoch 165 --- loss:0.094, Epoch accuracy:97.98%, Validation loss:2.446, Validation accuracy:34.67%
# Epoch 166: iteration 70/71
# Epoch 166 --- loss:0.093, Epoch accuracy:98.07%, Validation loss:2.385, Validation accuracy:35.67%
# Epoch 167: iteration 70/71
# Epoch 167 --- loss:0.099, Epoch accuracy:97.89%, Validation loss:2.303, Validation accuracy:36.33%
# Epoch 168: iteration 70/71
# Epoch 168 --- loss:0.084, Epoch accuracy:98.51%, Validation loss:2.383, Validation accuracy:35.67%
# Epoch 169: iteration 70/71
# Epoch 169 --- loss:0.087, Epoch accuracy:98.11%, Validation loss:2.420, Validation accuracy:33.67%
# Epoch 170: iteration 70/71
# Epoch 170 --- loss:0.082, Epoch accuracy:98.55%, Validation loss:2.487, Validation accuracy:34.00%
# Epoch 171: iteration 70/71
# Epoch 171 --- loss:0.076, Epoch accuracy:98.25%, Validation loss:2.432, Validation accuracy:33.00%
# Epoch 172: iteration 70/71
# Epoch 172 --- loss:0.088, Epoch accuracy:98.03%, Validation loss:2.416, Validation accuracy:35.00%
# Epoch 173: iteration 70/71
# Epoch 173 --- loss:0.076, Epoch accuracy:98.29%, Validation loss:2.412, Validation accuracy:34.33%
# Epoch 174: iteration 70/71
# Epoch 174 --- loss:0.072, Epoch accuracy:98.77%, Validation loss:2.529, Validation accuracy:33.67%
# Epoch 175: iteration 70/71
# Epoch 175 --- loss:0.068, Epoch accuracy:98.68%, Validation loss:2.401, Validation accuracy:34.33%
# Epoch 176: iteration 70/71
# Epoch 176 --- loss:0.073, Epoch accuracy:98.60%, Validation loss:2.440, Validation accuracy:34.67%
# Epoch 177: iteration 70/71
# Epoch 177 --- loss:0.071, Epoch accuracy:98.60%, Validation loss:2.456, Validation accuracy:32.67%
# Epoch 178: iteration 70/71
# Epoch 178 --- loss:0.078, Epoch accuracy:98.51%, Validation loss:2.489, Validation accuracy:34.67%
# Epoch 179: iteration 70/71
# Epoch 179 --- loss:0.064, Epoch accuracy:98.82%, Validation loss:2.534, Validation accuracy:33.33%
# Epoch 180: iteration 70/71
# Epoch 180 --- loss:0.067, Epoch accuracy:98.55%, Validation loss:2.443, Validation accuracy:34.33%
# Epoch 181: iteration 70/71
# Epoch 181 --- loss:0.072, Epoch accuracy:98.20%, Validation loss:2.453, Validation accuracy:36.33%
# Epoch 182: iteration 70/71
# Epoch 182 --- loss:0.070, Epoch accuracy:98.33%, Validation loss:2.463, Validation accuracy:35.67%
# Epoch 183: iteration 70/71
# Epoch 183 --- loss:0.059, Epoch accuracy:98.90%, Validation loss:2.535, Validation accuracy:34.00%
# Epoch 184: iteration 70/71
# Epoch 184 --- loss:0.084, Epoch accuracy:97.85%, Validation loss:2.607, Validation accuracy:32.33%
# Epoch 185: iteration 70/71
# Epoch 185 --- loss:0.069, Epoch accuracy:98.55%, Validation loss:2.525, Validation accuracy:35.00%
# Epoch 186: iteration 70/71
# Epoch 186 --- loss:0.057, Epoch accuracy:98.82%, Validation loss:2.498, Validation accuracy:35.00%
# Epoch 187: iteration 70/71
# Epoch 187 --- loss:0.062, Epoch accuracy:98.82%, Validation loss:2.458, Validation accuracy:36.67%
# Epoch 188: iteration 70/71
# Epoch 188 --- loss:0.062, Epoch accuracy:98.51%, Validation loss:2.610, Validation accuracy:34.67%
# Epoch 189: iteration 70/71
# Epoch 189 --- loss:0.057, Epoch accuracy:98.73%, Validation loss:2.461, Validation accuracy:37.33%
# Epoch 190: iteration 70/71
# Epoch 190 --- loss:0.055, Epoch accuracy:98.82%, Validation loss:2.614, Validation accuracy:33.67%
# Epoch 191: iteration 70/71
# Epoch 191 --- loss:0.059, Epoch accuracy:98.60%, Validation loss:2.391, Validation accuracy:36.33%
# Epoch 192: iteration 70/71
# Epoch 192 --- loss:0.058, Epoch accuracy:98.68%, Validation loss:2.388, Validation accuracy:36.00%
# Epoch 193: iteration 70/71
# Epoch 193 --- loss:0.063, Epoch accuracy:98.55%, Validation loss:2.637, Validation accuracy:33.67%
# Epoch 194: iteration 70/71
# Epoch 194 --- loss:0.060, Epoch accuracy:98.68%, Validation loss:2.566, Validation accuracy:35.33%
# Epoch 195: iteration 70/71
# Epoch 195 --- loss:0.045, Epoch accuracy:99.17%, Validation loss:2.580, Validation accuracy:32.33%
# Epoch 196: iteration 70/71
# Epoch 196 --- loss:0.050, Epoch accuracy:98.99%, Validation loss:2.524, Validation accuracy:36.67%
# Epoch 197: iteration 70/71
# Epoch 197 --- loss:0.062, Epoch accuracy:98.77%, Validation loss:2.633, Validation accuracy:33.00%
# Epoch 198: iteration 70/71
# Epoch 198 --- loss:0.056, Epoch accuracy:98.55%, Validation loss:2.544, Validation accuracy:36.00%
# Epoch 199: iteration 70/71
# Epoch 199 --- loss:0.049, Epoch accuracy:98.90%, Validation loss:2.606, Validation accuracy:31.33%
# Epoch 200: iteration 70/71
# Epoch 200 --- loss:0.042, Epoch accuracy:99.08%, Validation loss:2.713, Validation accuracy:34.33%
# Epoch 201: iteration 70/71
# Epoch 201 --- loss:0.048, Epoch accuracy:98.82%, Validation loss:2.591, Validation accuracy:33.00%
# Epoch 202: iteration 70/71
# Epoch 202 --- loss:0.063, Epoch accuracy:98.51%, Validation loss:2.617, Validation accuracy:32.00%
# Epoch 203: iteration 70/71
# Epoch 203 --- loss:0.049, Epoch accuracy:99.04%, Validation loss:2.643, Validation accuracy:30.33%
# Epoch 204: iteration 70/71
# Epoch 204 --- loss:0.060, Epoch accuracy:98.60%, Validation loss:2.640, Validation accuracy:33.67%
# Epoch 205: iteration 70/71
# Epoch 205 --- loss:0.045, Epoch accuracy:99.12%, Validation loss:2.597, Validation accuracy:36.00%
# Epoch 206: iteration 70/71
# Epoch 206 --- loss:0.038, Epoch accuracy:99.30%, Validation loss:2.612, Validation accuracy:37.00%
# Epoch 207: iteration 70/71
# Epoch 207 --- loss:0.044, Epoch accuracy:99.17%, Validation loss:2.533, Validation accuracy:37.33%
# Epoch 208: iteration 70/71
# Epoch 208 --- loss:0.048, Epoch accuracy:98.90%, Validation loss:2.589, Validation accuracy:36.33%
# Epoch 209: iteration 70/71
# Epoch 209 --- loss:0.044, Epoch accuracy:98.99%, Validation loss:2.660, Validation accuracy:33.67%
# Epoch 210: iteration 70/71
# Epoch 210 --- loss:0.047, Epoch accuracy:98.82%, Validation loss:2.684, Validation accuracy:35.33%
# Epoch 211: iteration 70/71
# Epoch 211 --- loss:0.042, Epoch accuracy:99.12%, Validation loss:2.591, Validation accuracy:36.00%
# Epoch 212: iteration 70/71
# Epoch 212 --- loss:0.038, Epoch accuracy:99.17%, Validation loss:2.599, Validation accuracy:35.33%
# Epoch 213: iteration 70/71
# Epoch 213 --- loss:0.036, Epoch accuracy:99.12%, Validation loss:2.564, Validation accuracy:33.67%
# Epoch 214: iteration 70/71
# Epoch 214 --- loss:0.037, Epoch accuracy:99.25%, Validation loss:2.676, Validation accuracy:34.00%
# Epoch 215: iteration 70/71
# Epoch 215 --- loss:0.032, Epoch accuracy:99.34%, Validation loss:2.628, Validation accuracy:34.33%
# Epoch 216: iteration 70/71
# Epoch 216 --- loss:0.033, Epoch accuracy:99.30%, Validation loss:2.585, Validation accuracy:33.67%
# Epoch 217: iteration 70/71
# Epoch 217 --- loss:0.032, Epoch accuracy:99.34%, Validation loss:2.618, Validation accuracy:33.67%
# Epoch 218: iteration 70/71
# Epoch 218 --- loss:0.037, Epoch accuracy:99.17%, Validation loss:2.682, Validation accuracy:32.33%
# Epoch 219: iteration 70/71
# Epoch 219 --- loss:0.035, Epoch accuracy:99.30%, Validation loss:2.677, Validation accuracy:33.67%
# Epoch 220: iteration 70/71
# Epoch 220 --- loss:0.033, Epoch accuracy:99.25%, Validation loss:2.759, Validation accuracy:33.00%
# Epoch 221: iteration 70/71
# Epoch 221 --- loss:0.044, Epoch accuracy:98.68%, Validation loss:2.644, Validation accuracy:36.00%
# Epoch 222: iteration 70/71
# Epoch 222 --- loss:0.040, Epoch accuracy:99.08%, Validation loss:2.699, Validation accuracy:35.67%
# Epoch 223: iteration 70/71
# Epoch 223 --- loss:0.038, Epoch accuracy:98.99%, Validation loss:2.611, Validation accuracy:34.00%
# Epoch 224: iteration 70/71
# Epoch 224 --- loss:0.041, Epoch accuracy:98.90%, Validation loss:2.618, Validation accuracy:34.33%
# Epoch 225: iteration 70/71
# Epoch 225 --- loss:0.027, Epoch accuracy:99.47%, Validation loss:2.678, Validation accuracy:34.00%
# Epoch 226: iteration 70/71
# Epoch 226 --- loss:0.043, Epoch accuracy:98.90%, Validation loss:2.723, Validation accuracy:32.67%
# Epoch 227: iteration 70/71
# Epoch 227 --- loss:0.033, Epoch accuracy:99.21%, Validation loss:2.733, Validation accuracy:32.00%
# Epoch 228: iteration 70/71
# Epoch 228 --- loss:0.043, Epoch accuracy:98.95%, Validation loss:2.687, Validation accuracy:30.33%
# Epoch 229: iteration 70/71
# Epoch 229 --- loss:0.036, Epoch accuracy:99.08%, Validation loss:2.642, Validation accuracy:33.33%
# Epoch 230: iteration 70/71
# Epoch 230 --- loss:0.035, Epoch accuracy:99.04%, Validation loss:2.589, Validation accuracy:34.00%
# Epoch 231: iteration 70/71
# Epoch 231 --- loss:0.035, Epoch accuracy:99.08%, Validation loss:2.686, Validation accuracy:33.33%
# Epoch 232: iteration 70/71
# Epoch 232 --- loss:0.026, Epoch accuracy:99.43%, Validation loss:2.636, Validation accuracy:33.67%
# Epoch 233: iteration 70/71
# Epoch 233 --- loss:0.031, Epoch accuracy:99.08%, Validation loss:2.707, Validation accuracy:34.00%
# Epoch 234: iteration 70/71
# Epoch 234 --- loss:0.034, Epoch accuracy:99.04%, Validation loss:2.702, Validation accuracy:33.67%
# Epoch 235: iteration 70/71
# Epoch 235 --- loss:0.037, Epoch accuracy:99.12%, Validation loss:2.758, Validation accuracy:33.33%
# Epoch 236: iteration 70/71
# Epoch 236 --- loss:0.031, Epoch accuracy:99.25%, Validation loss:2.875, Validation accuracy:32.67%
# Epoch 237: iteration 70/71
# Epoch 237 --- loss:0.030, Epoch accuracy:99.39%, Validation loss:2.741, Validation accuracy:35.33%
# Epoch 238: iteration 70/71
# Epoch 238 --- loss:0.034, Epoch accuracy:99.17%, Validation loss:2.718, Validation accuracy:32.67%
# Epoch 239: iteration 70/71
# Epoch 239 --- loss:0.037, Epoch accuracy:98.99%, Validation loss:2.757, Validation accuracy:34.67%
# Epoch 240: iteration 70/71
# Epoch 240 --- loss:0.037, Epoch accuracy:99.04%, Validation loss:2.643, Validation accuracy:33.67%
# Epoch 241: iteration 70/71
# Epoch 241 --- loss:0.031, Epoch accuracy:99.25%, Validation loss:2.739, Validation accuracy:34.00%
# Epoch 242: iteration 70/71
# Epoch 242 --- loss:0.028, Epoch accuracy:99.30%, Validation loss:2.619, Validation accuracy:36.67%
# Epoch 243: iteration 70/71
# Epoch 243 --- loss:0.032, Epoch accuracy:99.12%, Validation loss:2.693, Validation accuracy:33.00%
# Epoch 244: iteration 70/71
# Epoch 244 --- loss:0.031, Epoch accuracy:99.08%, Validation loss:2.659, Validation accuracy:33.33%
# Epoch 245: iteration 70/71
# Epoch 245 --- loss:0.028, Epoch accuracy:99.21%, Validation loss:2.732, Validation accuracy:31.67%
# Epoch 246: iteration 70/71
# Epoch 246 --- loss:0.028, Epoch accuracy:99.34%, Validation loss:2.696, Validation accuracy:34.00%
# Epoch 247: iteration 70/71
# Epoch 247 --- loss:0.024, Epoch accuracy:99.52%, Validation loss:2.725, Validation accuracy:33.33%
# Epoch 248: iteration 70/71
# Epoch 248 --- loss:0.033, Epoch accuracy:99.12%, Validation loss:2.714, Validation accuracy:34.33%
# Epoch 249: iteration 70/71
# Epoch 249 --- loss:0.023, Epoch accuracy:99.30%, Validation loss:2.672, Validation accuracy:32.33%
# Epoch 250: iteration 70/71
# Epoch 250 --- loss:0.027, Epoch accuracy:99.21%, Validation loss:2.708, Validation accuracy:35.67%
# Epoch 251: iteration 70/71
# Epoch 251 --- loss:0.024, Epoch accuracy:99.39%, Validation loss:2.719, Validation accuracy:36.33%
# Epoch 252: iteration 70/71
# Epoch 252 --- loss:0.025, Epoch accuracy:99.25%, Validation loss:2.691, Validation accuracy:35.67%
# Epoch 253: iteration 70/71
# Epoch 253 --- loss:0.030, Epoch accuracy:99.25%, Validation loss:2.694, Validation accuracy:35.67%
# Epoch 254: iteration 70/71
# Epoch 254 --- loss:0.034, Epoch accuracy:99.08%, Validation loss:2.720, Validation accuracy:35.33%
# Epoch 255: iteration 70/71
# Epoch 255 --- loss:0.021, Epoch accuracy:99.43%, Validation loss:2.688, Validation accuracy:36.33%
# Epoch 256: iteration 70/71
# Epoch 256 --- loss:0.028, Epoch accuracy:99.17%, Validation loss:2.681, Validation accuracy:35.00%
# Epoch 257: iteration 70/71
# Epoch 257 --- loss:0.027, Epoch accuracy:99.21%, Validation loss:2.652, Validation accuracy:35.00%
# Epoch 258: iteration 70/71
# Epoch 258 --- loss:0.021, Epoch accuracy:99.39%, Validation loss:2.776, Validation accuracy:35.67%
# Epoch 259: iteration 70/71
# Epoch 259 --- loss:0.024, Epoch accuracy:99.30%, Validation loss:2.703, Validation accuracy:33.33%
# Epoch 260: iteration 70/71
# Epoch 260 --- loss:0.020, Epoch accuracy:99.39%, Validation loss:2.636, Validation accuracy:35.00%
# Epoch 261: iteration 70/71
# Epoch 261 --- loss:0.028, Epoch accuracy:99.12%, Validation loss:2.692, Validation accuracy:34.67%
# Epoch 262: iteration 70/71
# Epoch 262 --- loss:0.021, Epoch accuracy:99.47%, Validation loss:2.761, Validation accuracy:35.67%
# Epoch 263: iteration 70/71
# Epoch 263 --- loss:0.020, Epoch accuracy:99.47%, Validation loss:2.631, Validation accuracy:31.67%
# Epoch 264: iteration 70/71
# Epoch 264 --- loss:0.022, Epoch accuracy:99.34%, Validation loss:2.741, Validation accuracy:35.33%
# Epoch 265: iteration 70/71
# Epoch 265 --- loss:0.025, Epoch accuracy:99.21%, Validation loss:2.706, Validation accuracy:36.33%
# Epoch 266: iteration 70/71
# Epoch 266 --- loss:0.027, Epoch accuracy:99.25%, Validation loss:2.759, Validation accuracy:34.00%
# Epoch 267: iteration 70/71
# Epoch 267 --- loss:0.022, Epoch accuracy:99.43%, Validation loss:2.738, Validation accuracy:34.67%
# Epoch 268: iteration 70/71
# Epoch 268 --- loss:0.020, Epoch accuracy:99.52%, Validation loss:2.671, Validation accuracy:33.33%
# Epoch 269: iteration 70/71
# Epoch 269 --- loss:0.026, Epoch accuracy:99.21%, Validation loss:2.754, Validation accuracy:34.00%
# Epoch 270: iteration 70/71
# Epoch 270 --- loss:0.018, Epoch accuracy:99.47%, Validation loss:2.743, Validation accuracy:34.67%
# Epoch 271: iteration 70/71
# Epoch 271 --- loss:0.023, Epoch accuracy:99.39%, Validation loss:2.811, Validation accuracy:35.67%
# Epoch 272: iteration 70/71
# Epoch 272 --- loss:0.020, Epoch accuracy:99.34%, Validation loss:2.711, Validation accuracy:35.00%
# Epoch 273: iteration 70/71
# Epoch 273 --- loss:0.020, Epoch accuracy:99.34%, Validation loss:2.694, Validation accuracy:35.33%
# Epoch 274: iteration 70/71
# Epoch 274 --- loss:0.018, Epoch accuracy:99.52%, Validation loss:2.684, Validation accuracy:38.00%
# Epoch 275: iteration 70/71
# Epoch 275 --- loss:0.019, Epoch accuracy:99.43%, Validation loss:2.772, Validation accuracy:34.33%
# Epoch 276: iteration 70/71
# Epoch 276 --- loss:0.017, Epoch accuracy:99.43%, Validation loss:2.697, Validation accuracy:34.33%
# Epoch 277: iteration 70/71
# Epoch 277 --- loss:0.018, Epoch accuracy:99.56%, Validation loss:2.697, Validation accuracy:39.33%
# Epoch 278: iteration 70/71
# Epoch 278 --- loss:0.018, Epoch accuracy:99.47%, Validation loss:2.723, Validation accuracy:35.33%
# Epoch 279: iteration 70/71
# Epoch 279 --- loss:0.019, Epoch accuracy:99.34%, Validation loss:2.707, Validation accuracy:37.00%
# Epoch 280: iteration 70/71
# Epoch 280 --- loss:0.029, Epoch accuracy:99.12%, Validation loss:2.736, Validation accuracy:34.33%
# Epoch 281: iteration 70/71
# Epoch 281 --- loss:0.029, Epoch accuracy:99.08%, Validation loss:2.727, Validation accuracy:36.33%
# Epoch 282: iteration 70/71
# Epoch 282 --- loss:0.020, Epoch accuracy:99.47%, Validation loss:2.731, Validation accuracy:36.00%
# Epoch 283: iteration 70/71
# Epoch 283 --- loss:0.022, Epoch accuracy:99.43%, Validation loss:2.772, Validation accuracy:34.67%
# Epoch 284: iteration 70/71
# Epoch 284 --- loss:0.021, Epoch accuracy:99.34%, Validation loss:2.723, Validation accuracy:36.00%
# Epoch 285: iteration 70/71
# Epoch 285 --- loss:0.024, Epoch accuracy:99.17%, Validation loss:2.753, Validation accuracy:38.00%
# Epoch 286: iteration 70/71
# Epoch 286 --- loss:0.024, Epoch accuracy:99.21%, Validation loss:2.747, Validation accuracy:34.33%
# Epoch 287: iteration 70/71
# Epoch 287 --- loss:0.020, Epoch accuracy:99.34%, Validation loss:2.753, Validation accuracy:35.33%
# Epoch 288: iteration 70/71
# Epoch 288 --- loss:0.020, Epoch accuracy:99.34%, Validation loss:2.717, Validation accuracy:36.67%
# Epoch 289: iteration 70/71
# Epoch 289 --- loss:0.017, Epoch accuracy:99.43%, Validation loss:2.738, Validation accuracy:35.00%
# Epoch 290: iteration 70/71
# Epoch 290 --- loss:0.015, Epoch accuracy:99.52%, Validation loss:2.814, Validation accuracy:33.33%
# Epoch 291: iteration 70/71
# Epoch 291 --- loss:0.019, Epoch accuracy:99.30%, Validation loss:2.785, Validation accuracy:33.00%
# Epoch 292: iteration 70/71
# Epoch 292 --- loss:0.024, Epoch accuracy:99.21%, Validation loss:2.796, Validation accuracy:34.33%
# Epoch 293: iteration 70/71
# Epoch 293 --- loss:0.018, Epoch accuracy:99.43%, Validation loss:2.768, Validation accuracy:32.67%
# Epoch 294: iteration 70/71
# Epoch 294 --- loss:0.022, Epoch accuracy:99.30%, Validation loss:2.802, Validation accuracy:33.33%
# Epoch 295: iteration 70/71
# Epoch 295 --- loss:0.016, Epoch accuracy:99.52%, Validation loss:2.771, Validation accuracy:35.00%
# Epoch 296: iteration 70/71
# Epoch 296 --- loss:0.023, Epoch accuracy:99.21%, Validation loss:2.789, Validation accuracy:35.00%
# Epoch 297: iteration 8/71
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 20
#      17 model = Model(num_emotions=len(emotions_dict)).to('cuda')
#      18 optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
# ---> 20 train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
#      22 plt.title('Loss Curve')
#      23 plt.ylabel('Loss', fontsize=16)
#
# Cell In [11], line 65, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer)
#      62 Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
#      64 # Pass input tensors thru 1 training step (fwd+backwards pass)
# ---> 65 loss, acc = train_step(X_tensor, Y_tensor)
#      67 # aggregate batch accuracy to measure progress of entire epoch
#      68 epoch_acc += acc * actual_batch_size / train_size
#
# Cell In [7], line 7, in make_train_step.<locals>.train_step(X, Y)
#       4 def train_step(X, Y):
#       5
#       6     # forward pass
# ----> 7     output_logits, output_softmax = model(X)
#       8     predictions = torch.argmax(output_softmax, dim=1)
#       9     accuracy = torch.sum(Y == predictions)/float(len(Y))
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [5], line 25, in Model.forward(self, x)
#      23 res_lflb_embd = self.res_lflb2(res_lflb_embd)
#      24 res_lflb_embd = self.res_lflb3(res_lflb_embd)
# ---> 25 res_lflb_embd = self.res_lflb4(res_lflb_embd)
#      26 res_lflb_embd = self.res_lflb5(res_lflb_embd)
#      28 mlp = self.relu(res_lflb_embd)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [4], line 17, in ResLFLB.forward(self, x)
#      14 lflb_embd = self.lflb(x)
#      16 nac_embd = self.nac_unit1(lflb_embd)
# ---> 17 nac_embd = self.nac_unit2(nac_embd)
#      18 nac_embd = self.nac_unit3(nac_embd)
#      19 nac_embd = self.nac_unit4(nac_embd)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [3], line 17, in NACUnit.forward(self, x)
#      15 shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
#      16 out = self.conv1(out)
# ---> 17 out = self.conv2(F.relu(self.bn2(out)))
#      18 return out
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\conv.py:457, in Conv2d.forward(self, input)
#     456 def forward(self, input: Tensor) -> Tensor:
# --> 457     return self._conv_forward(input, self.weight, self.bias)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\conv.py:453, in Conv2d._conv_forward(self, input, weight, bias)
#     449 if self.padding_mode != 'zeros':
#     450     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     451                     weight, bias, self.stride,
#     452                     _pair(0), self.dilation, self.groups)
# --> 453 return F.conv2d(input, weight, bias, self.stride,
#     454                 self.padding, self.dilation, self.groups)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
