# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'MLT-DNet'
data_name = 'RAVDESS'

minibatch = 32
num_epochs = 500
EARLY_CNT = 500

learning_rate = 4e-3

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.dcnn = nn.Sequential(
            nn.Conv1d(1, 1, kernel_size=3, stride=1, dilation=3, padding=get_padding(kernel_size=3, stride=1, dilation=3)),
            nn.Dropout(0.25)
        )
        
        self.rbsc = nn.Sequential(
            nn.Conv1d(1, 1, kernel_size=3, stride=1, dilation=3, padding=get_padding(kernel_size=3, stride=1, dilation=3)),
            nn.BatchNorm1d(1),
            nn.LeakyReLU(),
            
            nn.Conv1d(1, 1, kernel_size=3, stride=1, dilation=3, padding=get_padding(kernel_size=3, stride=1, dilation=3)),
            nn.BatchNorm1d(1),
            nn.LeakyReLU(),
            
            nn.Conv1d(1, 1, kernel_size=3, stride=1, dilation=3, padding=get_padding(kernel_size=3, stride=1, dilation=3)),
            nn.BatchNorm1d(1),
            nn.LeakyReLU(),
        )
        
        self.gru1 = nn.GRU(input_size=15000, hidden_size=1024, num_layers=4, batch_first=True, bidirectional=True, dropout=0.25)
        self.gru2 = nn.GRU(input_size=2048, hidden_size=1024, num_layers=4, batch_first=True, bidirectional=True, dropout=0.25)
        self.gru3 = nn.GRU(input_size=2048, hidden_size=1024, num_layers=4, batch_first=True, bidirectional=True, dropout=0.25)
        
        
        self.fcn = nn.Sequential(
            nn.Linear(17048, num_emotions),
            nn.LeakyReLU(),
            nn.Dropout(0.25)
        )
        
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        dcnn_out = self.dcnn(x)
        
        rbsc_out = self.rbsc(dcnn_out)
        rbsc_out += dcnn_out
        
        gru_out, _ = self.gru1(dcnn_out)
        gru_out, _ = self.gru2(gru_out)
        gru_out, _ = self.gru3(gru_out)
        
        rbsc_out = rbsc_out.squeeze(1)
        gru_out = gru_out.squeeze(1)
        
        complete_embd = torch.cat([rbsc_out, gru_out], dim=1)
        
        output_logits = self.fcn(complete_embd)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'PCNSE-SADRN-CTC dataset/1d_'

for fold in range(5):
    cur_fold_path = fold_path + 'fold'+str(fold)+'.npy'
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_train = np.expand_dims(X_train, axis=1)
    X_test = np.expand_dims(X_test, axis=1)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    break
# Out:
# [*] model training - MLT-DNet
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:269.815, Epoch accuracy:12.81%, Validation loss:197.940, Validation accuracy:14.67%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:97.466, Epoch accuracy:26.93%, Validation loss:52.770, Validation accuracy:13.67%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:12.034, Epoch accuracy:28.77%, Validation loss:11.909, Validation accuracy:13.33%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:6.027, Epoch accuracy:28.42%, Validation loss:5.900, Validation accuracy:14.00%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:3.872, Epoch accuracy:26.84%, Validation loss:4.769, Validation accuracy:13.33%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:3.533, Epoch accuracy:27.28%, Validation loss:4.381, Validation accuracy:13.67%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:3.524, Epoch accuracy:26.32%, Validation loss:4.134, Validation accuracy:14.00%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:3.312, Epoch accuracy:27.72%, Validation loss:4.302, Validation accuracy:13.00%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:3.132, Epoch accuracy:28.42%, Validation loss:4.264, Validation accuracy:13.67%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:3.281, Epoch accuracy:28.07%, Validation loss:4.161, Validation accuracy:13.67%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:3.344, Epoch accuracy:27.37%, Validation loss:4.007, Validation accuracy:14.67%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:3.362, Epoch accuracy:27.11%, Validation loss:3.822, Validation accuracy:14.33%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:3.108, Epoch accuracy:27.81%, Validation loss:3.639, Validation accuracy:14.00%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:3.013, Epoch accuracy:27.19%, Validation loss:3.734, Validation accuracy:14.67%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:2.924, Epoch accuracy:28.07%, Validation loss:3.790, Validation accuracy:14.33%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:2.953, Epoch accuracy:27.28%, Validation loss:3.674, Validation accuracy:14.33%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:2.791, Epoch accuracy:27.98%, Validation loss:3.618, Validation accuracy:14.33%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:2.793, Epoch accuracy:28.68%, Validation loss:3.420, Validation accuracy:14.33%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:2.744, Epoch accuracy:28.25%, Validation loss:3.513, Validation accuracy:14.00%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:2.712, Epoch accuracy:29.04%, Validation loss:3.647, Validation accuracy:14.00%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:2.531, Epoch accuracy:28.42%, Validation loss:3.757, Validation accuracy:14.00%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:2.572, Epoch accuracy:27.46%, Validation loss:3.808, Validation accuracy:13.67%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:2.401, Epoch accuracy:30.09%, Validation loss:3.977, Validation accuracy:13.33%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:2.380, Epoch accuracy:30.61%, Validation loss:4.099, Validation accuracy:13.33%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:2.610, Epoch accuracy:28.95%, Validation loss:3.693, Validation accuracy:13.33%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:2.352, Epoch accuracy:30.53%, Validation loss:3.783, Validation accuracy:13.33%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:2.286, Epoch accuracy:30.79%, Validation loss:3.994, Validation accuracy:14.00%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:2.241, Epoch accuracy:31.32%, Validation loss:4.089, Validation accuracy:14.00%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:2.216, Epoch accuracy:30.18%, Validation loss:4.089, Validation accuracy:14.00%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:2.072, Epoch accuracy:31.58%, Validation loss:4.344, Validation accuracy:14.00%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:2.066, Epoch accuracy:34.04%, Validation loss:4.414, Validation accuracy:13.67%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:2.081, Epoch accuracy:32.63%, Validation loss:4.638, Validation accuracy:12.67%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:2.223, Epoch accuracy:35.09%, Validation loss:4.089, Validation accuracy:14.00%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:1.852, Epoch accuracy:36.49%, Validation loss:4.381, Validation accuracy:13.67%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:1.876, Epoch accuracy:35.18%, Validation loss:4.361, Validation accuracy:13.67%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:1.916, Epoch accuracy:34.12%, Validation loss:3.969, Validation accuracy:13.67%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:1.916, Epoch accuracy:33.77%, Validation loss:4.284, Validation accuracy:13.33%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:1.834, Epoch accuracy:35.96%, Validation loss:4.380, Validation accuracy:13.67%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:1.763, Epoch accuracy:36.40%, Validation loss:4.601, Validation accuracy:13.33%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:1.628, Epoch accuracy:37.54%, Validation loss:4.803, Validation accuracy:12.67%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:1.675, Epoch accuracy:35.88%, Validation loss:4.443, Validation accuracy:13.00%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:1.631, Epoch accuracy:37.72%, Validation loss:4.465, Validation accuracy:13.00%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:1.589, Epoch accuracy:40.00%, Validation loss:5.409, Validation accuracy:14.00%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:1.599, Epoch accuracy:39.47%, Validation loss:5.320, Validation accuracy:14.00%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:1.644, Epoch accuracy:40.26%, Validation loss:5.191, Validation accuracy:13.00%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:1.529, Epoch accuracy:38.60%, Validation loss:5.439, Validation accuracy:13.00%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:1.403, Epoch accuracy:42.11%, Validation loss:6.808, Validation accuracy:13.00%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:1.457, Epoch accuracy:41.84%, Validation loss:6.788, Validation accuracy:13.33%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:1.550, Epoch accuracy:43.16%, Validation loss:5.010, Validation accuracy:12.67%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:1.460, Epoch accuracy:42.19%, Validation loss:5.183, Validation accuracy:13.00%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:1.364, Epoch accuracy:43.07%, Validation loss:5.288, Validation accuracy:12.33%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:1.257, Epoch accuracy:44.12%, Validation loss:5.293, Validation accuracy:12.00%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:1.235, Epoch accuracy:43.60%, Validation loss:6.344, Validation accuracy:12.33%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:1.262, Epoch accuracy:48.68%, Validation loss:6.436, Validation accuracy:13.33%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:1.368, Epoch accuracy:46.05%, Validation loss:6.016, Validation accuracy:13.33%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:1.211, Epoch accuracy:46.32%, Validation loss:6.088, Validation accuracy:14.33%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:1.290, Epoch accuracy:47.54%, Validation loss:5.961, Validation accuracy:13.00%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:1.183, Epoch accuracy:46.40%, Validation loss:6.194, Validation accuracy:13.00%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:1.126, Epoch accuracy:50.70%, Validation loss:6.294, Validation accuracy:12.33%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:1.097, Epoch accuracy:51.23%, Validation loss:6.995, Validation accuracy:13.00%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:1.196, Epoch accuracy:49.21%, Validation loss:5.623, Validation accuracy:12.67%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:1.172, Epoch accuracy:49.30%, Validation loss:6.090, Validation accuracy:13.67%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:1.041, Epoch accuracy:49.04%, Validation loss:6.791, Validation accuracy:14.00%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:1.194, Epoch accuracy:50.88%, Validation loss:5.965, Validation accuracy:14.00%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:1.310, Epoch accuracy:47.81%, Validation loss:5.272, Validation accuracy:14.33%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:1.034, Epoch accuracy:50.09%, Validation loss:5.692, Validation accuracy:13.67%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:0.978, Epoch accuracy:52.37%, Validation loss:6.375, Validation accuracy:13.67%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:1.095, Epoch accuracy:51.14%, Validation loss:5.002, Validation accuracy:13.67%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:1.041, Epoch accuracy:49.30%, Validation loss:4.592, Validation accuracy:14.00%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:0.995, Epoch accuracy:51.40%, Validation loss:5.341, Validation accuracy:14.67%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:1.104, Epoch accuracy:54.65%, Validation loss:4.961, Validation accuracy:14.00%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:1.082, Epoch accuracy:48.77%, Validation loss:4.193, Validation accuracy:14.33%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:1.039, Epoch accuracy:53.77%, Validation loss:5.352, Validation accuracy:15.00%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:0.944, Epoch accuracy:53.95%, Validation loss:5.132, Validation accuracy:13.33%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:0.891, Epoch accuracy:56.32%, Validation loss:6.314, Validation accuracy:14.33%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:0.983, Epoch accuracy:55.88%, Validation loss:5.093, Validation accuracy:14.33%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:0.958, Epoch accuracy:53.95%, Validation loss:5.632, Validation accuracy:14.67%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:0.893, Epoch accuracy:56.14%, Validation loss:5.908, Validation accuracy:13.33%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:0.928, Epoch accuracy:59.12%, Validation loss:6.551, Validation accuracy:13.33%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:0.884, Epoch accuracy:58.42%, Validation loss:6.400, Validation accuracy:14.00%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:0.708, Epoch accuracy:61.23%, Validation loss:9.107, Validation accuracy:13.00%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:0.943, Epoch accuracy:61.49%, Validation loss:7.029, Validation accuracy:13.33%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:0.833, Epoch accuracy:61.23%, Validation loss:7.868, Validation accuracy:12.33%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:0.829, Epoch accuracy:63.60%, Validation loss:8.115, Validation accuracy:12.67%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:0.844, Epoch accuracy:63.33%, Validation loss:6.707, Validation accuracy:13.67%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:0.813, Epoch accuracy:60.26%, Validation loss:6.825, Validation accuracy:13.67%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:0.706, Epoch accuracy:61.49%, Validation loss:7.647, Validation accuracy:12.00%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:0.840, Epoch accuracy:64.30%, Validation loss:8.117, Validation accuracy:13.67%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:0.811, Epoch accuracy:61.84%, Validation loss:6.114, Validation accuracy:14.00%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:0.853, Epoch accuracy:62.02%, Validation loss:6.784, Validation accuracy:14.33%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:0.691, Epoch accuracy:63.95%, Validation loss:7.623, Validation accuracy:13.67%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:0.775, Epoch accuracy:64.82%, Validation loss:7.396, Validation accuracy:14.00%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:0.659, Epoch accuracy:65.96%, Validation loss:8.760, Validation accuracy:14.33%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:0.744, Epoch accuracy:63.07%, Validation loss:6.623, Validation accuracy:15.67%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:0.730, Epoch accuracy:62.72%, Validation loss:6.035, Validation accuracy:15.67%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:0.682, Epoch accuracy:62.98%, Validation loss:7.205, Validation accuracy:14.67%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:0.687, Epoch accuracy:66.75%, Validation loss:6.911, Validation accuracy:15.00%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:0.651, Epoch accuracy:63.07%, Validation loss:8.095, Validation accuracy:14.33%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:0.729, Epoch accuracy:65.88%, Validation loss:7.887, Validation accuracy:14.33%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:0.721, Epoch accuracy:64.56%, Validation loss:7.978, Validation accuracy:14.67%
# Epoch 100: iteration 34/35
# Epoch 100 --- loss:0.622, Epoch accuracy:67.02%, Validation loss:8.660, Validation accuracy:15.00%
# Epoch 101: iteration 34/35
# Epoch 101 --- loss:0.760, Epoch accuracy:66.05%, Validation loss:7.151, Validation accuracy:14.33%
# Epoch 102: iteration 34/35
# Epoch 102 --- loss:0.577, Epoch accuracy:67.28%, Validation loss:6.951, Validation accuracy:15.33%
# Epoch 103: iteration 34/35
# Epoch 103 --- loss:0.736, Epoch accuracy:64.12%, Validation loss:6.747, Validation accuracy:16.00%
# Epoch 104: iteration 34/35
# Epoch 104 --- loss:0.690, Epoch accuracy:64.21%, Validation loss:6.922, Validation accuracy:15.67%
# Epoch 105: iteration 34/35
# Epoch 105 --- loss:0.622, Epoch accuracy:66.14%, Validation loss:7.161, Validation accuracy:15.00%
# Epoch 106: iteration 34/35
# Epoch 106 --- loss:0.697, Epoch accuracy:66.75%, Validation loss:6.771, Validation accuracy:15.33%
# Epoch 107: iteration 34/35
# Epoch 107 --- loss:0.597, Epoch accuracy:66.49%, Validation loss:7.615, Validation accuracy:14.33%
# Epoch 108: iteration 34/35
# Epoch 108 --- loss:0.637, Epoch accuracy:70.35%, Validation loss:9.497, Validation accuracy:15.33%
# Epoch 109: iteration 34/35
# Epoch 109 --- loss:0.608, Epoch accuracy:68.95%, Validation loss:8.746, Validation accuracy:14.00%
# Epoch 110: iteration 34/35
# Epoch 110 --- loss:0.530, Epoch accuracy:70.88%, Validation loss:10.624, Validation accuracy:15.00%
# Epoch 111: iteration 34/35
# Epoch 111 --- loss:0.716, Epoch accuracy:72.37%, Validation loss:11.576, Validation accuracy:13.00%
# Epoch 112: iteration 34/35
# Epoch 112 --- loss:0.660, Epoch accuracy:71.75%, Validation loss:8.420, Validation accuracy:15.67%
# Epoch 113: iteration 34/35
# Epoch 113 --- loss:0.487, Epoch accuracy:71.84%, Validation loss:9.209, Validation accuracy:14.33%
# Epoch 114: iteration 34/35
# Epoch 114 --- loss:0.502, Epoch accuracy:74.30%, Validation loss:10.399, Validation accuracy:12.67%
# Epoch 115: iteration 34/35
# Epoch 115 --- loss:0.567, Epoch accuracy:73.25%, Validation loss:8.293, Validation accuracy:13.67%
# Epoch 116: iteration 34/35
# Epoch 116 --- loss:0.741, Epoch accuracy:69.47%, Validation loss:6.938, Validation accuracy:13.33%
# Epoch 117: iteration 34/35
# Epoch 117 --- loss:0.507, Epoch accuracy:71.75%, Validation loss:7.185, Validation accuracy:13.67%
# Epoch 118: iteration 34/35
# Epoch 118 --- loss:0.610, Epoch accuracy:71.14%, Validation loss:6.121, Validation accuracy:14.33%
# Epoch 119: iteration 34/35
# Epoch 119 --- loss:0.501, Epoch accuracy:71.05%, Validation loss:6.357, Validation accuracy:14.33%
# Epoch 120: iteration 34/35
# Epoch 120 --- loss:0.475, Epoch accuracy:72.81%, Validation loss:8.345, Validation accuracy:13.67%
# Epoch 121: iteration 34/35
# Epoch 121 --- loss:0.608, Epoch accuracy:72.46%, Validation loss:7.548, Validation accuracy:13.00%
# Epoch 122: iteration 34/35
# Epoch 122 --- loss:0.575, Epoch accuracy:73.68%, Validation loss:7.639, Validation accuracy:14.33%
# Epoch 123: iteration 34/35
# Epoch 123 --- loss:0.537, Epoch accuracy:71.32%, Validation loss:6.608, Validation accuracy:13.67%
# Epoch 124: iteration 34/35
# Epoch 124 --- loss:0.577, Epoch accuracy:70.00%, Validation loss:6.523, Validation accuracy:12.00%
# Epoch 125: iteration 34/35
# Epoch 125 --- loss:0.521, Epoch accuracy:71.75%, Validation loss:6.944, Validation accuracy:12.00%
# Epoch 126: iteration 34/35
# Epoch 126 --- loss:0.511, Epoch accuracy:70.88%, Validation loss:7.760, Validation accuracy:12.00%
# Epoch 127: iteration 34/35
# Epoch 127 --- loss:0.667, Epoch accuracy:69.04%, Validation loss:4.843, Validation accuracy:12.00%
# Epoch 128: iteration 34/35
# Epoch 128 --- loss:0.520, Epoch accuracy:69.74%, Validation loss:5.087, Validation accuracy:12.00%
# Epoch 129: iteration 34/35
# Epoch 129 --- loss:0.599, Epoch accuracy:70.88%, Validation loss:6.092, Validation accuracy:13.00%
# Epoch 130: iteration 34/35
# Epoch 130 --- loss:0.446, Epoch accuracy:71.93%, Validation loss:7.369, Validation accuracy:13.00%
# Epoch 131: iteration 34/35
# Epoch 131 --- loss:0.613, Epoch accuracy:74.21%, Validation loss:6.101, Validation accuracy:12.00%
# Epoch 132: iteration 34/35
# Epoch 132 --- loss:0.487, Epoch accuracy:71.32%, Validation loss:6.345, Validation accuracy:12.00%
# Epoch 133: iteration 34/35
# Epoch 133 --- loss:0.646, Epoch accuracy:73.77%, Validation loss:7.097, Validation accuracy:12.67%
# Epoch 134: iteration 34/35
# Epoch 134 --- loss:0.536, Epoch accuracy:72.19%, Validation loss:6.962, Validation accuracy:12.00%
# Epoch 135: iteration 34/35
# Epoch 135 --- loss:0.493, Epoch accuracy:73.33%, Validation loss:7.364, Validation accuracy:12.67%
# Epoch 136: iteration 34/35
# Epoch 136 --- loss:0.435, Epoch accuracy:74.82%, Validation loss:8.117, Validation accuracy:12.00%
# Epoch 137: iteration 34/35
# Epoch 137 --- loss:0.480, Epoch accuracy:74.65%, Validation loss:7.657, Validation accuracy:12.33%
# Epoch 138: iteration 34/35
# Epoch 138 --- loss:0.398, Epoch accuracy:76.40%, Validation loss:7.932, Validation accuracy:12.33%
# Epoch 139: iteration 34/35
# Epoch 139 --- loss:0.438, Epoch accuracy:74.91%, Validation loss:8.681, Validation accuracy:11.67%
# Epoch 140: iteration 34/35
# Epoch 140 --- loss:0.407, Epoch accuracy:76.40%, Validation loss:9.263, Validation accuracy:11.67%
# Epoch 141: iteration 34/35
# Epoch 141 --- loss:0.490, Epoch accuracy:77.19%, Validation loss:8.453, Validation accuracy:11.67%
# Epoch 142: iteration 34/35
# Epoch 142 --- loss:0.414, Epoch accuracy:75.53%, Validation loss:8.406, Validation accuracy:12.33%
# Epoch 143: iteration 34/35
# Epoch 143 --- loss:0.386, Epoch accuracy:77.46%, Validation loss:8.248, Validation accuracy:11.33%
# Epoch 144: iteration 34/35
# Epoch 144 --- loss:0.527, Epoch accuracy:77.54%, Validation loss:8.364, Validation accuracy:12.33%
# Epoch 145: iteration 34/35
# Epoch 145 --- loss:0.446, Epoch accuracy:75.79%, Validation loss:7.618, Validation accuracy:12.67%
# Epoch 146: iteration 34/35
# Epoch 146 --- loss:0.498, Epoch accuracy:74.47%, Validation loss:7.008, Validation accuracy:14.67%
# Epoch 147: iteration 34/35
# Epoch 147 --- loss:0.440, Epoch accuracy:72.54%, Validation loss:6.675, Validation accuracy:13.67%
# Epoch 148: iteration 34/35
# Epoch 148 --- loss:0.435, Epoch accuracy:74.56%, Validation loss:6.084, Validation accuracy:12.00%
# Epoch 149: iteration 34/35
# Epoch 149 --- loss:0.437, Epoch accuracy:74.04%, Validation loss:8.550, Validation accuracy:12.00%
# Epoch 150: iteration 34/35
# Epoch 150 --- loss:0.519, Epoch accuracy:77.54%, Validation loss:7.699, Validation accuracy:12.67%
# Epoch 151: iteration 34/35
# Epoch 151 --- loss:0.573, Epoch accuracy:75.26%, Validation loss:5.653, Validation accuracy:12.33%
# Epoch 152: iteration 34/35
# Epoch 152 --- loss:0.425, Epoch accuracy:74.82%, Validation loss:5.795, Validation accuracy:13.33%
# Epoch 153: iteration 34/35
# Epoch 153 --- loss:0.446, Epoch accuracy:76.23%, Validation loss:6.501, Validation accuracy:12.67%
# Epoch 154: iteration 34/35
# Epoch 154 --- loss:0.401, Epoch accuracy:74.91%, Validation loss:6.974, Validation accuracy:13.00%
# Epoch 155: iteration 34/35
# Epoch 155 --- loss:0.447, Epoch accuracy:76.93%, Validation loss:7.383, Validation accuracy:12.33%
# Epoch 156: iteration 34/35
# Epoch 156 --- loss:0.376, Epoch accuracy:76.40%, Validation loss:6.977, Validation accuracy:13.00%
# Epoch 157: iteration 34/35
# Epoch 157 --- loss:0.568, Epoch accuracy:73.07%, Validation loss:5.458, Validation accuracy:12.33%
# Epoch 158: iteration 34/35
# Epoch 158 --- loss:0.496, Epoch accuracy:75.18%, Validation loss:5.415, Validation accuracy:11.67%
# Epoch 159: iteration 34/35
# Epoch 159 --- loss:0.394, Epoch accuracy:76.93%, Validation loss:6.294, Validation accuracy:13.33%
# Epoch 160: iteration 34/35
# Epoch 160 --- loss:0.426, Epoch accuracy:77.63%, Validation loss:6.093, Validation accuracy:13.00%
# Epoch 161: iteration 34/35
# Epoch 161 --- loss:0.389, Epoch accuracy:76.23%, Validation loss:7.342, Validation accuracy:13.33%
# Epoch 162: iteration 34/35
# Epoch 162 --- loss:0.364, Epoch accuracy:77.63%, Validation loss:7.825, Validation accuracy:13.00%
# Epoch 163: iteration 34/35
# Epoch 163 --- loss:0.451, Epoch accuracy:78.16%, Validation loss:8.242, Validation accuracy:12.33%
# Epoch 164: iteration 34/35
# Epoch 164 --- loss:0.404, Epoch accuracy:76.40%, Validation loss:8.243, Validation accuracy:12.00%
# Epoch 165: iteration 34/35
# Epoch 165 --- loss:0.327, Epoch accuracy:80.00%, Validation loss:8.826, Validation accuracy:12.33%
# Epoch 166: iteration 34/35
# Epoch 166 --- loss:0.514, Epoch accuracy:78.07%, Validation loss:8.473, Validation accuracy:11.67%
# Epoch 167: iteration 34/35
# Epoch 167 --- loss:0.343, Epoch accuracy:78.77%, Validation loss:7.122, Validation accuracy:13.00%
# Epoch 168: iteration 34/35
# Epoch 168 --- loss:0.367, Epoch accuracy:77.28%, Validation loss:8.504, Validation accuracy:14.00%
# Epoch 169: iteration 34/35
# Epoch 169 --- loss:0.406, Epoch accuracy:80.00%, Validation loss:8.286, Validation accuracy:13.67%
# Epoch 170: iteration 34/35
# Epoch 170 --- loss:0.475, Epoch accuracy:79.47%, Validation loss:7.264, Validation accuracy:12.33%
# Epoch 171: iteration 34/35
# Epoch 171 --- loss:0.386, Epoch accuracy:79.47%, Validation loss:6.724, Validation accuracy:13.67%
# Epoch 172: iteration 34/35
# Epoch 172 --- loss:0.499, Epoch accuracy:78.60%, Validation loss:6.831, Validation accuracy:14.00%
# Epoch 173: iteration 34/35
# Epoch 173 --- loss:0.373, Epoch accuracy:78.16%, Validation loss:7.940, Validation accuracy:14.00%
# Epoch 174: iteration 34/35
# Epoch 174 --- loss:0.331, Epoch accuracy:79.47%, Validation loss:8.032, Validation accuracy:14.00%
# Epoch 175: iteration 34/35
# Epoch 175 --- loss:0.348, Epoch accuracy:78.51%, Validation loss:7.161, Validation accuracy:14.00%
# Epoch 176: iteration 34/35
# Epoch 176 --- loss:0.436, Epoch accuracy:78.77%, Validation loss:6.811, Validation accuracy:14.67%
# Epoch 177: iteration 34/35
# Epoch 177 --- loss:0.345, Epoch accuracy:80.26%, Validation loss:7.547, Validation accuracy:13.67%
# Epoch 178: iteration 34/35
# Epoch 178 --- loss:0.389, Epoch accuracy:77.89%, Validation loss:8.097, Validation accuracy:14.33%
# Epoch 179: iteration 34/35
# Epoch 179 --- loss:0.366, Epoch accuracy:80.09%, Validation loss:9.292, Validation accuracy:13.33%
# Epoch 180: iteration 34/35
# Epoch 180 --- loss:0.424, Epoch accuracy:80.44%, Validation loss:6.345, Validation accuracy:15.00%
# Epoch 181: iteration 34/35
# Epoch 181 --- loss:0.413, Epoch accuracy:77.72%, Validation loss:6.912, Validation accuracy:15.00%
# Epoch 182: iteration 34/35
# Epoch 182 --- loss:0.484, Epoch accuracy:74.65%, Validation loss:6.200, Validation accuracy:13.00%
# Epoch 183: iteration 34/35
# Epoch 183 --- loss:0.337, Epoch accuracy:78.77%, Validation loss:7.169, Validation accuracy:12.67%
# Epoch 184: iteration 34/35
# Epoch 184 --- loss:0.405, Epoch accuracy:78.51%, Validation loss:6.601, Validation accuracy:13.33%
# Epoch 185: iteration 34/35
# Epoch 185 --- loss:0.403, Epoch accuracy:79.12%, Validation loss:5.558, Validation accuracy:13.67%
# Epoch 186: iteration 34/35
# Epoch 186 --- loss:0.370, Epoch accuracy:75.00%, Validation loss:5.385, Validation accuracy:14.33%
# Epoch 187: iteration 34/35
# Epoch 187 --- loss:0.439, Epoch accuracy:79.56%, Validation loss:5.780, Validation accuracy:14.67%
# Epoch 188: iteration 34/35
# Epoch 188 --- loss:0.426, Epoch accuracy:77.19%, Validation loss:5.766, Validation accuracy:14.33%
# Epoch 189: iteration 34/35
# Epoch 189 --- loss:0.347, Epoch accuracy:78.25%, Validation loss:6.083, Validation accuracy:14.00%
# Epoch 190: iteration 34/35
# Epoch 190 --- loss:0.391, Epoch accuracy:75.70%, Validation loss:7.278, Validation accuracy:14.67%
# Epoch 191: iteration 34/35
# Epoch 191 --- loss:0.323, Epoch accuracy:80.44%, Validation loss:7.879, Validation accuracy:14.67%
# Epoch 192: iteration 34/35
# Epoch 192 --- loss:0.337, Epoch accuracy:80.09%, Validation loss:7.922, Validation accuracy:12.33%
# Epoch 193: iteration 34/35
# Epoch 193 --- loss:0.381, Epoch accuracy:78.60%, Validation loss:6.819, Validation accuracy:13.33%
# Epoch 194: iteration 34/35
# Epoch 194 --- loss:0.305, Epoch accuracy:80.35%, Validation loss:8.633, Validation accuracy:13.33%
# Epoch 195: iteration 34/35
# Epoch 195 --- loss:0.390, Epoch accuracy:78.42%, Validation loss:8.525, Validation accuracy:13.00%
# Epoch 196: iteration 34/35
# Epoch 196 --- loss:0.297, Epoch accuracy:80.88%, Validation loss:8.748, Validation accuracy:14.00%
# Epoch 197: iteration 34/35
# Epoch 197 --- loss:0.287, Epoch accuracy:81.67%, Validation loss:9.442, Validation accuracy:13.67%
# Epoch 198: iteration 34/35
# Epoch 198 --- loss:0.357, Epoch accuracy:81.32%, Validation loss:9.598, Validation accuracy:13.00%
# Epoch 199: iteration 34/35
# Epoch 199 --- loss:0.422, Epoch accuracy:81.67%, Validation loss:8.232, Validation accuracy:13.67%
# Epoch 200: iteration 34/35
# Epoch 200 --- loss:0.328, Epoch accuracy:78.25%, Validation loss:8.157, Validation accuracy:13.33%
# Epoch 201: iteration 34/35
# Epoch 201 --- loss:0.356, Epoch accuracy:79.56%, Validation loss:9.341, Validation accuracy:13.67%
# Epoch 202: iteration 34/35
# Epoch 202 --- loss:0.316, Epoch accuracy:80.79%, Validation loss:8.528, Validation accuracy:14.67%
# Epoch 203: iteration 34/35
# Epoch 203 --- loss:0.337, Epoch accuracy:80.44%, Validation loss:9.311, Validation accuracy:12.00%
# Epoch 204: iteration 34/35
# Epoch 204 --- loss:0.356, Epoch accuracy:80.35%, Validation loss:8.255, Validation accuracy:13.67%
# Epoch 205: iteration 34/35
# Epoch 205 --- loss:0.356, Epoch accuracy:80.61%, Validation loss:9.091, Validation accuracy:15.00%
# Epoch 206: iteration 34/35
# Epoch 206 --- loss:0.288, Epoch accuracy:81.67%, Validation loss:9.810, Validation accuracy:15.33%
# Epoch 207: iteration 34/35
# Epoch 207 --- loss:0.315, Epoch accuracy:80.53%, Validation loss:9.534, Validation accuracy:13.67%
# Epoch 208: iteration 34/35
# Epoch 208 --- loss:0.307, Epoch accuracy:81.14%, Validation loss:9.395, Validation accuracy:16.33%
# Epoch 209: iteration 34/35
# Epoch 209 --- loss:0.296, Epoch accuracy:80.88%, Validation loss:8.974, Validation accuracy:15.00%
# Epoch 210: iteration 34/35
# Epoch 210 --- loss:0.304, Epoch accuracy:79.91%, Validation loss:8.460, Validation accuracy:14.33%
# Epoch 211: iteration 34/35
# Epoch 211 --- loss:0.348, Epoch accuracy:81.23%, Validation loss:7.502, Validation accuracy:13.67%
# Epoch 212: iteration 34/35
# Epoch 212 --- loss:0.333, Epoch accuracy:80.00%, Validation loss:8.094, Validation accuracy:15.67%
# Epoch 213: iteration 34/35
# Epoch 213 --- loss:0.347, Epoch accuracy:79.39%, Validation loss:8.573, Validation accuracy:14.67%
# Epoch 214: iteration 34/35
# Epoch 214 --- loss:0.302, Epoch accuracy:80.79%, Validation loss:8.578, Validation accuracy:14.67%
# Epoch 215: iteration 34/35
# Epoch 215 --- loss:0.362, Epoch accuracy:79.39%, Validation loss:7.840, Validation accuracy:15.33%
# Epoch 216: iteration 34/35
# Epoch 216 --- loss:0.306, Epoch accuracy:79.65%, Validation loss:8.039, Validation accuracy:15.33%
# Epoch 217: iteration 34/35
# Epoch 217 --- loss:0.325, Epoch accuracy:80.88%, Validation loss:8.661, Validation accuracy:16.33%
# Epoch 218: iteration 34/35
# Epoch 218 --- loss:0.295, Epoch accuracy:80.70%, Validation loss:10.397, Validation accuracy:15.67%
# Epoch 219: iteration 34/35
# Epoch 219 --- loss:0.379, Epoch accuracy:81.05%, Validation loss:9.273, Validation accuracy:16.33%
# Epoch 220: iteration 34/35
# Epoch 220 --- loss:0.286, Epoch accuracy:81.40%, Validation loss:8.624, Validation accuracy:16.67%
# Epoch 221: iteration 34/35
# Epoch 221 --- loss:0.383, Epoch accuracy:80.79%, Validation loss:7.570, Validation accuracy:15.00%
# Epoch 222: iteration 34/35
# Epoch 222 --- loss:0.364, Epoch accuracy:81.14%, Validation loss:7.443, Validation accuracy:15.33%
# Epoch 223: iteration 34/35
# Epoch 223 --- loss:0.312, Epoch accuracy:80.88%, Validation loss:7.047, Validation accuracy:15.67%
# Epoch 224: iteration 34/35
# Epoch 224 --- loss:0.348, Epoch accuracy:78.51%, Validation loss:6.207, Validation accuracy:16.00%
# Epoch 225: iteration 34/35
# Epoch 225 --- loss:0.345, Epoch accuracy:78.60%, Validation loss:5.731, Validation accuracy:16.00%
# Epoch 226: iteration 34/35
# Epoch 226 --- loss:0.289, Epoch accuracy:81.05%, Validation loss:6.656, Validation accuracy:14.67%
# Epoch 227: iteration 34/35
# Epoch 227 --- loss:0.286, Epoch accuracy:81.05%, Validation loss:7.648, Validation accuracy:15.33%
# Epoch 228: iteration 34/35
# Epoch 228 --- loss:0.345, Epoch accuracy:80.09%, Validation loss:8.022, Validation accuracy:15.33%
# Epoch 229: iteration 34/35
# Epoch 229 --- loss:0.352, Epoch accuracy:81.93%, Validation loss:8.040, Validation accuracy:15.33%
# Epoch 230: iteration 34/35
# Epoch 230 --- loss:0.349, Epoch accuracy:81.93%, Validation loss:6.751, Validation accuracy:15.00%
# Epoch 231: iteration 34/35
# Epoch 231 --- loss:0.298, Epoch accuracy:80.61%, Validation loss:7.590, Validation accuracy:14.00%
# Epoch 232: iteration 34/35
# Epoch 232 --- loss:0.294, Epoch accuracy:81.93%, Validation loss:8.171, Validation accuracy:16.33%
# Epoch 233: iteration 34/35
# Epoch 233 --- loss:0.282, Epoch accuracy:81.75%, Validation loss:8.138, Validation accuracy:17.00%
# Epoch 234: iteration 34/35
# Epoch 234 --- loss:0.294, Epoch accuracy:80.53%, Validation loss:9.339, Validation accuracy:16.33%
# Epoch 235: iteration 34/35
# Epoch 235 --- loss:0.330, Epoch accuracy:79.91%, Validation loss:9.158, Validation accuracy:16.00%
# Epoch 236: iteration 34/35
# Epoch 236 --- loss:0.309, Epoch accuracy:80.70%, Validation loss:9.496, Validation accuracy:16.33%
# Epoch 237: iteration 34/35
# Epoch 237 --- loss:0.263, Epoch accuracy:82.81%, Validation loss:8.979, Validation accuracy:16.33%
# Epoch 238: iteration 34/35
# Epoch 238 --- loss:0.296, Epoch accuracy:82.72%, Validation loss:8.160, Validation accuracy:16.67%
# Epoch 239: iteration 34/35
# Epoch 239 --- loss:0.310, Epoch accuracy:80.70%, Validation loss:7.853, Validation accuracy:16.00%
# Epoch 240: iteration 34/35
# Epoch 240 --- loss:0.275, Epoch accuracy:82.89%, Validation loss:7.630, Validation accuracy:16.00%
# Epoch 241: iteration 34/35
# Epoch 241 --- loss:0.293, Epoch accuracy:81.40%, Validation loss:7.950, Validation accuracy:15.67%
# Epoch 242: iteration 34/35
# Epoch 242 --- loss:0.343, Epoch accuracy:82.89%, Validation loss:7.893, Validation accuracy:16.67%
# Epoch 243: iteration 34/35
# Epoch 243 --- loss:0.360, Epoch accuracy:82.19%, Validation loss:7.623, Validation accuracy:16.67%
# Epoch 244: iteration 34/35
# Epoch 244 --- loss:0.268, Epoch accuracy:81.93%, Validation loss:7.855, Validation accuracy:16.67%
# Epoch 245: iteration 34/35
# Epoch 245 --- loss:0.276, Epoch accuracy:82.02%, Validation loss:8.136, Validation accuracy:16.00%
# Epoch 246: iteration 34/35
# Epoch 246 --- loss:0.286, Epoch accuracy:81.49%, Validation loss:8.041, Validation accuracy:16.00%
# Epoch 247: iteration 34/35
# Epoch 247 --- loss:0.325, Epoch accuracy:81.93%, Validation loss:7.999, Validation accuracy:15.33%
# Epoch 248: iteration 34/35
# Epoch 248 --- loss:0.297, Epoch accuracy:81.05%, Validation loss:8.251, Validation accuracy:15.00%
# Epoch 249: iteration 34/35
# Epoch 249 --- loss:0.304, Epoch accuracy:80.18%, Validation loss:7.907, Validation accuracy:16.33%
# Epoch 250: iteration 34/35
# Epoch 250 --- loss:0.400, Epoch accuracy:79.21%, Validation loss:6.543, Validation accuracy:16.00%
# Epoch 251: iteration 34/35
# Epoch 251 --- loss:0.322, Epoch accuracy:78.51%, Validation loss:6.793, Validation accuracy:16.33%
# Epoch 252: iteration 34/35
# Epoch 252 --- loss:0.308, Epoch accuracy:80.70%, Validation loss:6.355, Validation accuracy:15.67%
# Epoch 253: iteration 34/35
# Epoch 253 --- loss:0.276, Epoch accuracy:81.49%, Validation loss:6.396, Validation accuracy:14.67%
# Epoch 254: iteration 34/35
# Epoch 254 --- loss:0.385, Epoch accuracy:78.60%, Validation loss:5.488, Validation accuracy:16.33%
# Epoch 255: iteration 34/35
# Epoch 255 --- loss:0.264, Epoch accuracy:81.32%, Validation loss:5.294, Validation accuracy:15.33%
# Epoch 256: iteration 34/35
# Epoch 256 --- loss:0.281, Epoch accuracy:82.37%, Validation loss:6.251, Validation accuracy:16.67%
# Epoch 257: iteration 34/35
# Epoch 257 --- loss:0.298, Epoch accuracy:83.25%, Validation loss:7.194, Validation accuracy:16.67%
# Epoch 258: iteration 34/35
# Epoch 258 --- loss:0.254, Epoch accuracy:84.21%, Validation loss:6.719, Validation accuracy:16.67%
# Epoch 259: iteration 34/35
# Epoch 259 --- loss:0.288, Epoch accuracy:82.28%, Validation loss:6.438, Validation accuracy:15.33%
# Epoch 260: iteration 34/35
# Epoch 260 --- loss:0.277, Epoch accuracy:80.61%, Validation loss:6.605, Validation accuracy:16.00%
# Epoch 261: iteration 34/35
# Epoch 261 --- loss:0.277, Epoch accuracy:81.40%, Validation loss:6.697, Validation accuracy:16.00%
# Epoch 262: iteration 34/35
# Epoch 262 --- loss:0.279, Epoch accuracy:81.05%, Validation loss:6.808, Validation accuracy:16.00%
# Epoch 263: iteration 34/35
# Epoch 263 --- loss:0.271, Epoch accuracy:82.89%, Validation loss:7.140, Validation accuracy:15.67%
# Epoch 264: iteration 34/35
# Epoch 264 --- loss:0.299, Epoch accuracy:81.14%, Validation loss:8.548, Validation accuracy:15.67%
# Epoch 265: iteration 34/35
# Epoch 265 --- loss:0.284, Epoch accuracy:81.58%, Validation loss:8.714, Validation accuracy:15.67%
# Epoch 266: iteration 34/35
# Epoch 266 --- loss:0.268, Epoch accuracy:82.72%, Validation loss:7.671, Validation accuracy:16.00%
# Epoch 267: iteration 34/35
# Epoch 267 --- loss:0.350, Epoch accuracy:81.23%, Validation loss:7.860, Validation accuracy:15.00%
# Epoch 268: iteration 34/35
# Epoch 268 --- loss:0.277, Epoch accuracy:82.11%, Validation loss:6.883, Validation accuracy:14.33%
# Epoch 269: iteration 34/35
# Epoch 269 --- loss:0.470, Epoch accuracy:81.40%, Validation loss:5.403, Validation accuracy:15.33%
# Epoch 270: iteration 34/35
# Epoch 270 --- loss:0.324, Epoch accuracy:79.21%, Validation loss:5.544, Validation accuracy:16.33%
# Epoch 271: iteration 34/35
# Epoch 271 --- loss:0.272, Epoch accuracy:82.54%, Validation loss:5.539, Validation accuracy:16.33%
# Epoch 272: iteration 34/35
# Epoch 272 --- loss:0.301, Epoch accuracy:81.67%, Validation loss:5.475, Validation accuracy:16.00%
# Epoch 273: iteration 34/35
# Epoch 273 --- loss:0.285, Epoch accuracy:81.32%, Validation loss:5.542, Validation accuracy:16.00%
# Epoch 274: iteration 34/35
# Epoch 274 --- loss:0.276, Epoch accuracy:81.58%, Validation loss:6.344, Validation accuracy:15.67%
# Epoch 275: iteration 34/35
# Epoch 275 --- loss:0.295, Epoch accuracy:80.35%, Validation loss:6.950, Validation accuracy:14.33%
# Epoch 276: iteration 34/35
# Epoch 276 --- loss:0.373, Epoch accuracy:79.56%, Validation loss:6.006, Validation accuracy:15.33%
# Epoch 277: iteration 34/35
# Epoch 277 --- loss:0.297, Epoch accuracy:81.05%, Validation loss:6.297, Validation accuracy:15.00%
# Epoch 278: iteration 34/35
# Epoch 278 --- loss:0.302, Epoch accuracy:81.93%, Validation loss:6.053, Validation accuracy:15.33%
# Epoch 279: iteration 34/35
# Epoch 279 --- loss:0.285, Epoch accuracy:80.09%, Validation loss:6.003, Validation accuracy:15.00%
# Epoch 280: iteration 34/35
# Epoch 280 --- loss:0.252, Epoch accuracy:84.21%, Validation loss:6.314, Validation accuracy:15.00%
# Epoch 281: iteration 34/35
# Epoch 281 --- loss:0.286, Epoch accuracy:81.58%, Validation loss:6.436, Validation accuracy:14.67%
# Epoch 282: iteration 34/35
# Epoch 282 --- loss:0.263, Epoch accuracy:82.98%, Validation loss:6.463, Validation accuracy:14.67%
# Epoch 283: iteration 34/35
# Epoch 283 --- loss:0.327, Epoch accuracy:80.79%, Validation loss:6.283, Validation accuracy:15.00%
# Epoch 284: iteration 34/35
# Epoch 284 --- loss:0.253, Epoch accuracy:83.68%, Validation loss:6.310, Validation accuracy:14.67%
# Epoch 285: iteration 34/35
# Epoch 285 --- loss:0.354, Epoch accuracy:81.32%, Validation loss:6.140, Validation accuracy:14.67%
# Epoch 286: iteration 34/35
# Epoch 286 --- loss:0.292, Epoch accuracy:81.49%, Validation loss:5.808, Validation accuracy:13.67%
# Epoch 287: iteration 34/35
# Epoch 287 --- loss:0.269, Epoch accuracy:82.63%, Validation loss:5.892, Validation accuracy:14.33%
# Epoch 288: iteration 34/35
# Epoch 288 --- loss:0.262, Epoch accuracy:82.81%, Validation loss:6.101, Validation accuracy:13.67%
# Epoch 289: iteration 34/35
# Epoch 289 --- loss:0.329, Epoch accuracy:80.61%, Validation loss:5.404, Validation accuracy:14.00%
# Epoch 290: iteration 34/35
# Epoch 290 --- loss:0.287, Epoch accuracy:81.49%, Validation loss:5.398, Validation accuracy:14.00%
# Epoch 291: iteration 34/35
# Epoch 291 --- loss:0.263, Epoch accuracy:82.81%, Validation loss:5.676, Validation accuracy:14.33%
# Epoch 292: iteration 31/35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [11], line 23
#      20 model = Model(num_emotions=len(emotions_dict)).to('cuda')
#      21 optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
# ---> 23 train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
#      25 plt.title('Loss Curve')
#      26 plt.ylabel('Loss', fontsize=16)
#
# Cell In [9], line 65, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer)
#      62 Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
#      64 # Pass input tensors thru 1 training step (fwd+backwards pass)
# ---> 65 loss, acc = train_step(X_tensor, Y_tensor)
#      67 # aggregate batch accuracy to measure progress of entire epoch
#      68 epoch_acc += acc * actual_batch_size / train_size
#
# Cell In [5], line 15, in make_train_step.<locals>.train_step(X, Y)
#      12 loss = criterion(output_logits, Y)
#      14 # compute gradients for the optimizer to use
# ---> 15 loss.backward()
#      17 # update network parameters based on gradient stored (by calling loss.backward())
#      18 optimizer.step()
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    
    break

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    break
