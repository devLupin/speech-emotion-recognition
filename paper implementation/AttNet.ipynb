# %%
import os
import torch

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'AttNet'
data_name = 'RAVDESS'

minibatch = 512
num_epochs = 500
EARLY_CNT = 1000

learning_rate = 1e-6

# model = Model(len(emotions_dict))
# print(summary(model, (1, 3, 224, 224)))

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm

from pytorch_revgrad import RevGrad

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class LW_CNN(nn.Module):
    """Some Information about LW_CNN"""
    def __init__(self):
        super(LW_CNN, self).__init__()

        self.max_pool = nn.MaxPool1d(kernel_size=3, stride=1)

        self.conv1 = nn.Conv1d(in_channels=224, out_channels=120, kernel_size=11, stride=4, padding=get_padding(kernel_size=11, stride=4, dilation=1))
        self.conv2 = nn.Conv1d(in_channels=120, out_channels=256, kernel_size=5, stride=1, padding=get_padding(kernel_size=5, stride=1, dilation=1))
        self.conv3 = nn.Conv1d(in_channels=256, out_channels=384, kernel_size=3, stride=1, padding=get_padding(kernel_size=3, stride=1, dilation=1))
        
        self.relu = nn.ReLU()
        self.bn = nn.BatchNorm1d(num_features=384)

    def forward(self, x):
        conv_embd = self.conv1(x)
        conv_embd = self.max_pool(conv_embd)
        
        conv_embd = self.conv2(conv_embd)
        conv_embd = self.max_pool(conv_embd)
        
        conv_embd = self.conv3(conv_embd)
        conv_embd = self.max_pool(conv_embd)
        conv_embd = self.relu(conv_embd)
        conv_embd = self.bn(conv_embd)
        
        return conv_embd

# %%
class SAM(nn.Module):
    """Some Information about SAM"""
    def __init__(self):
        super(SAM, self).__init__()
        
        self.max_pool = nn.MaxPool1d(kernel_size=3, stride=1)
        
        self.channel_attention = nn.Sequential(
            nn.Linear(384, 256),
            nn.Linear(256, 148),
            nn.BatchNorm1d(num_features=148)
        )
        
        self.spatial_attention = nn.Sequential(
            nn.Conv1d(in_channels=384, out_channels=512, kernel_size=1, stride=1, dilation=1, padding=get_padding(kernel_size=1, stride=1, dilation=1)),
            nn.Conv1d(in_channels=512, out_channels=256, kernel_size=3, stride=1, dilation=2, padding=get_padding(kernel_size=3, stride=1, dilation=2)),
            nn.Conv1d(in_channels=256, out_channels=148, kernel_size=1, stride=1, dilation=1, padding=get_padding(kernel_size=1, stride=1, dilation=1)),
            nn.BatchNorm1d(num_features=148)
        )
        
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        chan_att = F.avg_pool1d(x, x.size()[2:])
        chan_att = torch.flatten(chan_att, start_dim=1)
        chan_att = self.channel_attention(chan_att)
        
        spa_att = self.spatial_attention(x)
        spa_att, _ = torch.max(spa_att, -1)

        output = chan_att + spa_att
        return self.sigmoid(output)

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.lw_cnn_model = LW_CNN()
        self.sam_model = SAM()
        
        self.linear1 = nn.Linear(56832, 512)
        self.linear2 = nn.Linear(512, num_emotions)
        
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        
        cnn_embd = self.lw_cnn_model(x)
        att_embd = self.sam_model(cnn_embd)

        att_embd = att_embd.unsqueeze(1)

        complete_embd = cnn_embd * att_embd
        complete_embd = torch.flatten(complete_embd, start_dim=1)
        
        output = self.linear1(complete_embd)
        
        output_logits = self.linear2(output)
        output_softmax = self.softmax(output_logits)

        return output_logits, output_softmax
    
# model = Model(8)
# print(summary(model, (128, 224, 614)))

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = '5-CV-augment'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_train = X_train[:,0,:,:]
    X_test = X_test[:,0,:,:]
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    break
# Out:
# [*] model training - AttNet
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 3/4
# Epoch 0 --- loss:1.888, Epoch accuracy:13.16%, Validation loss:2.075, Validation accuracy:16.67%
# Epoch 1: iteration 3/4
# Epoch 1 --- loss:1.827, Epoch accuracy:16.62%, Validation loss:2.039, Validation accuracy:17.17%
# Epoch 2: iteration 3/4
# Epoch 2 --- loss:1.807, Epoch accuracy:18.33%, Validation loss:2.020, Validation accuracy:19.00%
# Epoch 3: iteration 3/4
# Epoch 3 --- loss:1.786, Epoch accuracy:20.13%, Validation loss:2.007, Validation accuracy:20.67%
# Epoch 4: iteration 3/4
# Epoch 4 --- loss:1.766, Epoch accuracy:22.68%, Validation loss:1.995, Validation accuracy:21.67%
# Epoch 5: iteration 3/4
# Epoch 5 --- loss:1.742, Epoch accuracy:24.17%, Validation loss:1.988, Validation accuracy:23.00%
# Epoch 6: iteration 3/4
# Epoch 6 --- loss:1.731, Epoch accuracy:24.52%, Validation loss:1.983, Validation accuracy:23.33%
# Epoch 7: iteration 3/4
# Epoch 7 --- loss:1.715, Epoch accuracy:25.70%, Validation loss:1.977, Validation accuracy:22.83%
# Epoch 8: iteration 3/4
# Epoch 8 --- loss:1.705, Epoch accuracy:26.32%, Validation loss:1.968, Validation accuracy:22.50%
# Epoch 9: iteration 3/4
# Epoch 9 --- loss:1.694, Epoch accuracy:26.97%, Validation loss:1.961, Validation accuracy:23.50%
# Epoch 10: iteration 3/4
# Epoch 10 --- loss:1.677, Epoch accuracy:28.16%, Validation loss:1.953, Validation accuracy:23.83%
# Epoch 11: iteration 3/4
# Epoch 11 --- loss:1.670, Epoch accuracy:29.04%, Validation loss:1.947, Validation accuracy:25.50%
# Epoch 12: iteration 3/4
# Epoch 12 --- loss:1.658, Epoch accuracy:29.47%, Validation loss:1.942, Validation accuracy:25.50%
# Epoch 13: iteration 3/4
# Epoch 13 --- loss:1.643, Epoch accuracy:31.18%, Validation loss:1.936, Validation accuracy:26.17%
# Epoch 14: iteration 3/4
# Epoch 14 --- loss:1.636, Epoch accuracy:31.10%, Validation loss:1.929, Validation accuracy:27.33%
# Epoch 15: iteration 3/4
# Epoch 15 --- loss:1.630, Epoch accuracy:31.27%, Validation loss:1.922, Validation accuracy:27.17%
# Epoch 16: iteration 3/4
# Epoch 16 --- loss:1.614, Epoch accuracy:31.93%, Validation loss:1.919, Validation accuracy:27.17%
# Epoch 17: iteration 3/4
# Epoch 17 --- loss:1.602, Epoch accuracy:32.68%, Validation loss:1.916, Validation accuracy:27.00%
# Epoch 18: iteration 3/4
# Epoch 18 --- loss:1.594, Epoch accuracy:33.07%, Validation loss:1.910, Validation accuracy:27.17%
# Epoch 19: iteration 3/4
# Epoch 19 --- loss:1.585, Epoch accuracy:32.85%, Validation loss:1.902, Validation accuracy:27.83%
# Epoch 20: iteration 3/4
# Epoch 20 --- loss:1.577, Epoch accuracy:33.60%, Validation loss:1.898, Validation accuracy:27.83%
# Epoch 21: iteration 3/4
# Epoch 21 --- loss:1.566, Epoch accuracy:33.60%, Validation loss:1.893, Validation accuracy:28.67%
# Epoch 22: iteration 3/4
# Epoch 22 --- loss:1.559, Epoch accuracy:34.69%, Validation loss:1.889, Validation accuracy:28.33%
# Epoch 23: iteration 3/4
# Epoch 23 --- loss:1.552, Epoch accuracy:34.78%, Validation loss:1.888, Validation accuracy:28.67%
# Epoch 24: iteration 3/4
# Epoch 24 --- loss:1.542, Epoch accuracy:35.09%, Validation loss:1.883, Validation accuracy:28.33%
# Epoch 25: iteration 3/4
# Epoch 25 --- loss:1.531, Epoch accuracy:36.01%, Validation loss:1.876, Validation accuracy:29.00%
# Epoch 26: iteration 3/4
# Epoch 26 --- loss:1.528, Epoch accuracy:35.88%, Validation loss:1.870, Validation accuracy:29.50%
# Epoch 27: iteration 3/4
# Epoch 27 --- loss:1.518, Epoch accuracy:36.45%, Validation loss:1.870, Validation accuracy:29.83%
# Epoch 28: iteration 3/4
# Epoch 28 --- loss:1.507, Epoch accuracy:36.97%, Validation loss:1.870, Validation accuracy:29.00%
# Epoch 29: iteration 3/4
# Epoch 29 --- loss:1.499, Epoch accuracy:37.32%, Validation loss:1.868, Validation accuracy:28.67%
# Epoch 30: iteration 3/4
# Epoch 30 --- loss:1.491, Epoch accuracy:38.11%, Validation loss:1.860, Validation accuracy:28.67%
# Epoch 31: iteration 3/4
# Epoch 31 --- loss:1.488, Epoch accuracy:37.76%, Validation loss:1.853, Validation accuracy:30.00%
# Epoch 32: iteration 3/4
# Epoch 32 --- loss:1.481, Epoch accuracy:37.72%, Validation loss:1.852, Validation accuracy:30.67%
# Epoch 33: iteration 3/4
# Epoch 33 --- loss:1.470, Epoch accuracy:38.90%, Validation loss:1.849, Validation accuracy:30.50%
# Epoch 34: iteration 3/4
# Epoch 34 --- loss:1.472, Epoch accuracy:38.82%, Validation loss:1.846, Validation accuracy:29.83%
# Epoch 35: iteration 3/4
# Epoch 35 --- loss:1.452, Epoch accuracy:40.18%, Validation loss:1.843, Validation accuracy:29.83%
# Epoch 36: iteration 3/4
# Epoch 36 --- loss:1.456, Epoch accuracy:38.60%, Validation loss:1.838, Validation accuracy:30.17%
# Epoch 37: iteration 3/4
# Epoch 37 --- loss:1.441, Epoch accuracy:40.18%, Validation loss:1.834, Validation accuracy:31.00%
# Epoch 38: iteration 3/4
# Epoch 38 --- loss:1.434, Epoch accuracy:40.44%, Validation loss:1.831, Validation accuracy:31.00%
# Epoch 39: iteration 3/4
# Epoch 39 --- loss:1.426, Epoch accuracy:40.88%, Validation loss:1.829, Validation accuracy:31.00%
# Epoch 40: iteration 3/4
# Epoch 40 --- loss:1.422, Epoch accuracy:41.27%, Validation loss:1.826, Validation accuracy:30.83%
# Epoch 41: iteration 3/4
# Epoch 41 --- loss:1.415, Epoch accuracy:41.54%, Validation loss:1.822, Validation accuracy:32.00%
# Epoch 42: iteration 3/4
# Epoch 42 --- loss:1.406, Epoch accuracy:42.59%, Validation loss:1.820, Validation accuracy:30.67%
# Epoch 43: iteration 3/4
# Epoch 43 --- loss:1.402, Epoch accuracy:42.06%, Validation loss:1.815, Validation accuracy:31.33%
# Epoch 44: iteration 3/4
# Epoch 44 --- loss:1.392, Epoch accuracy:43.16%, Validation loss:1.814, Validation accuracy:30.83%
# Epoch 45: iteration 3/4
# Epoch 45 --- loss:1.391, Epoch accuracy:42.59%, Validation loss:1.811, Validation accuracy:31.83%
# Epoch 46: iteration 3/4
# Epoch 46 --- loss:1.385, Epoch accuracy:42.98%, Validation loss:1.806, Validation accuracy:32.00%
# Epoch 47: iteration 3/4
# Epoch 47 --- loss:1.377, Epoch accuracy:43.25%, Validation loss:1.803, Validation accuracy:31.83%
# Epoch 48: iteration 3/4
# Epoch 48 --- loss:1.369, Epoch accuracy:43.86%, Validation loss:1.801, Validation accuracy:31.67%
# Epoch 49: iteration 3/4
# Epoch 49 --- loss:1.358, Epoch accuracy:44.52%, Validation loss:1.802, Validation accuracy:32.00%
# Epoch 50: iteration 3/4
# Epoch 50 --- loss:1.360, Epoch accuracy:43.99%, Validation loss:1.800, Validation accuracy:32.67%
# Epoch 51: iteration 3/4
# Epoch 51 --- loss:1.349, Epoch accuracy:45.35%, Validation loss:1.798, Validation accuracy:32.33%
# Epoch 52: iteration 3/4
# Epoch 52 --- loss:1.350, Epoch accuracy:44.74%, Validation loss:1.794, Validation accuracy:32.50%
# Epoch 53: iteration 3/4
# Epoch 53 --- loss:1.341, Epoch accuracy:45.31%, Validation loss:1.792, Validation accuracy:32.67%
# Epoch 54: iteration 3/4
# Epoch 54 --- loss:1.335, Epoch accuracy:45.48%, Validation loss:1.792, Validation accuracy:32.33%
# Epoch 55: iteration 3/4
# Epoch 55 --- loss:1.325, Epoch accuracy:46.05%, Validation loss:1.789, Validation accuracy:32.33%
# Epoch 56: iteration 3/4
# Epoch 56 --- loss:1.322, Epoch accuracy:46.01%, Validation loss:1.784, Validation accuracy:32.67%
# Epoch 57: iteration 3/4
# Epoch 57 --- loss:1.321, Epoch accuracy:46.10%, Validation loss:1.784, Validation accuracy:32.67%
# Epoch 58: iteration 3/4
# Epoch 58 --- loss:1.309, Epoch accuracy:47.54%, Validation loss:1.783, Validation accuracy:33.17%
# Epoch 59: iteration 3/4
# Epoch 59 --- loss:1.303, Epoch accuracy:47.06%, Validation loss:1.780, Validation accuracy:33.67%
# Epoch 60: iteration 3/4
# Epoch 60 --- loss:1.293, Epoch accuracy:47.63%, Validation loss:1.775, Validation accuracy:33.67%
# Epoch 61: iteration 3/4
# Epoch 61 --- loss:1.292, Epoch accuracy:47.11%, Validation loss:1.776, Validation accuracy:33.17%
# Epoch 62: iteration 3/4
# Epoch 62 --- loss:1.284, Epoch accuracy:48.16%, Validation loss:1.775, Validation accuracy:33.83%
# Epoch 63: iteration 3/4
# Epoch 63 --- loss:1.283, Epoch accuracy:48.20%, Validation loss:1.769, Validation accuracy:34.17%
# Epoch 64: iteration 3/4
# Epoch 64 --- loss:1.274, Epoch accuracy:48.82%, Validation loss:1.772, Validation accuracy:33.83%
# Epoch 65: iteration 3/4
# Epoch 65 --- loss:1.269, Epoch accuracy:48.42%, Validation loss:1.772, Validation accuracy:34.33%
# Epoch 66: iteration 3/4
# Epoch 66 --- loss:1.265, Epoch accuracy:48.68%, Validation loss:1.769, Validation accuracy:33.83%
# Epoch 67: iteration 3/4
# Epoch 67 --- loss:1.261, Epoch accuracy:48.82%, Validation loss:1.768, Validation accuracy:34.00%
# Epoch 68: iteration 3/4
# Epoch 68 --- loss:1.251, Epoch accuracy:49.56%, Validation loss:1.768, Validation accuracy:34.00%
# Epoch 69: iteration 3/4
# Epoch 69 --- loss:1.248, Epoch accuracy:49.56%, Validation loss:1.767, Validation accuracy:34.17%
# Epoch 70: iteration 3/4
# Epoch 70 --- loss:1.236, Epoch accuracy:50.79%, Validation loss:1.762, Validation accuracy:34.17%
# Epoch 71: iteration 3/4
# Epoch 71 --- loss:1.237, Epoch accuracy:50.31%, Validation loss:1.759, Validation accuracy:34.50%
# Epoch 72: iteration 3/4
# Epoch 72 --- loss:1.231, Epoch accuracy:50.39%, Validation loss:1.757, Validation accuracy:34.00%
# Epoch 73: iteration 3/4
# Epoch 73 --- loss:1.221, Epoch accuracy:51.23%, Validation loss:1.757, Validation accuracy:34.50%
# Epoch 74: iteration 3/4
# Epoch 74 --- loss:1.215, Epoch accuracy:51.05%, Validation loss:1.759, Validation accuracy:34.17%
# Epoch 75: iteration 3/4
# Epoch 75 --- loss:1.218, Epoch accuracy:51.18%, Validation loss:1.756, Validation accuracy:34.00%
# Epoch 76: iteration 3/4
# Epoch 76 --- loss:1.210, Epoch accuracy:51.71%, Validation loss:1.752, Validation accuracy:34.67%
# Epoch 77: iteration 3/4
# Epoch 77 --- loss:1.204, Epoch accuracy:51.97%, Validation loss:1.748, Validation accuracy:35.00%
# Epoch 78: iteration 3/4
# Epoch 78 --- loss:1.196, Epoch accuracy:52.37%, Validation loss:1.747, Validation accuracy:35.17%
# Epoch 79: iteration 3/4
# Epoch 79 --- loss:1.188, Epoch accuracy:52.19%, Validation loss:1.751, Validation accuracy:35.00%
# Epoch 80: iteration 3/4
# Epoch 80 --- loss:1.190, Epoch accuracy:52.50%, Validation loss:1.745, Validation accuracy:35.33%
# Epoch 81: iteration 3/4
# Epoch 81 --- loss:1.175, Epoch accuracy:53.07%, Validation loss:1.741, Validation accuracy:35.50%
# Epoch 82: iteration 3/4
# Epoch 82 --- loss:1.170, Epoch accuracy:53.46%, Validation loss:1.742, Validation accuracy:35.33%
# Epoch 83: iteration 3/4
# Epoch 83 --- loss:1.172, Epoch accuracy:53.55%, Validation loss:1.743, Validation accuracy:35.17%
# Epoch 84: iteration 3/4
# Epoch 84 --- loss:1.168, Epoch accuracy:53.07%, Validation loss:1.740, Validation accuracy:35.33%
# Epoch 85: iteration 3/4
# Epoch 85 --- loss:1.157, Epoch accuracy:54.08%, Validation loss:1.740, Validation accuracy:35.67%
# Epoch 86: iteration 3/4
# Epoch 86 --- loss:1.153, Epoch accuracy:53.38%, Validation loss:1.742, Validation accuracy:34.67%
# Epoch 87: iteration 3/4
# Epoch 87 --- loss:1.150, Epoch accuracy:53.90%, Validation loss:1.738, Validation accuracy:35.00%
# Epoch 88: iteration 3/4
# Epoch 88 --- loss:1.142, Epoch accuracy:54.43%, Validation loss:1.738, Validation accuracy:35.17%
# Epoch 89: iteration 3/4
# Epoch 89 --- loss:1.143, Epoch accuracy:54.65%, Validation loss:1.733, Validation accuracy:35.83%
# Epoch 90: iteration 3/4
# Epoch 90 --- loss:1.130, Epoch accuracy:54.65%, Validation loss:1.731, Validation accuracy:35.67%
# Epoch 91: iteration 3/4
# Epoch 91 --- loss:1.119, Epoch accuracy:55.83%, Validation loss:1.733, Validation accuracy:35.00%
# Epoch 92: iteration 3/4
# Epoch 92 --- loss:1.120, Epoch accuracy:55.57%, Validation loss:1.728, Validation accuracy:35.33%
# Epoch 93: iteration 3/4
# Epoch 93 --- loss:1.118, Epoch accuracy:56.32%, Validation loss:1.731, Validation accuracy:35.33%
# Epoch 94: iteration 3/4
# Epoch 94 --- loss:1.115, Epoch accuracy:56.18%, Validation loss:1.730, Validation accuracy:36.17%
# Epoch 95: iteration 3/4
# Epoch 95 --- loss:1.110, Epoch accuracy:56.14%, Validation loss:1.729, Validation accuracy:35.83%
# Epoch 96: iteration 3/4
# Epoch 96 --- loss:1.102, Epoch accuracy:56.18%, Validation loss:1.728, Validation accuracy:35.17%
# Epoch 97: iteration 3/4
# Epoch 97 --- loss:1.098, Epoch accuracy:56.49%, Validation loss:1.723, Validation accuracy:36.00%
# Epoch 98: iteration 3/4
# Epoch 98 --- loss:1.090, Epoch accuracy:57.54%, Validation loss:1.724, Validation accuracy:36.00%
# Epoch 99: iteration 3/4
# Epoch 99 --- loss:1.091, Epoch accuracy:56.36%, Validation loss:1.722, Validation accuracy:36.00%
# Epoch 100: iteration 3/4
# Epoch 100 --- loss:1.080, Epoch accuracy:56.89%, Validation loss:1.724, Validation accuracy:36.17%
# Epoch 101: iteration 3/4
# Epoch 101 --- loss:1.075, Epoch accuracy:57.59%, Validation loss:1.720, Validation accuracy:36.00%
# Epoch 102: iteration 3/4
# Epoch 102 --- loss:1.072, Epoch accuracy:58.16%, Validation loss:1.723, Validation accuracy:35.83%
# Epoch 103: iteration 3/4
# Epoch 103 --- loss:1.066, Epoch accuracy:57.41%, Validation loss:1.721, Validation accuracy:35.83%
# Epoch 104: iteration 3/4
# Epoch 104 --- loss:1.063, Epoch accuracy:58.07%, Validation loss:1.716, Validation accuracy:35.67%
# Epoch 105: iteration 3/4
# Epoch 105 --- loss:1.059, Epoch accuracy:57.85%, Validation loss:1.718, Validation accuracy:35.33%
# Epoch 106: iteration 3/4
# Epoch 106 --- loss:1.053, Epoch accuracy:58.38%, Validation loss:1.717, Validation accuracy:36.33%
# Epoch 107: iteration 3/4
# Epoch 107 --- loss:1.048, Epoch accuracy:59.17%, Validation loss:1.715, Validation accuracy:36.67%
# Epoch 108: iteration 3/4
# Epoch 108 --- loss:1.051, Epoch accuracy:59.34%, Validation loss:1.711, Validation accuracy:36.17%
# Epoch 109: iteration 3/4
# Epoch 109 --- loss:1.046, Epoch accuracy:58.64%, Validation loss:1.710, Validation accuracy:35.83%
# Epoch 110: iteration 3/4
# Epoch 110 --- loss:1.029, Epoch accuracy:59.91%, Validation loss:1.714, Validation accuracy:35.83%
# Epoch 111: iteration 3/4
# Epoch 111 --- loss:1.035, Epoch accuracy:59.25%, Validation loss:1.713, Validation accuracy:35.83%
# Epoch 112: iteration 3/4
# Epoch 112 --- loss:1.026, Epoch accuracy:59.78%, Validation loss:1.715, Validation accuracy:35.67%
# Epoch 113: iteration 3/4
# Epoch 113 --- loss:1.026, Epoch accuracy:59.91%, Validation loss:1.712, Validation accuracy:35.67%
# Epoch 114: iteration 3/4
# Epoch 114 --- loss:1.019, Epoch accuracy:60.13%, Validation loss:1.708, Validation accuracy:36.50%
# Epoch 115: iteration 3/4
# Epoch 115 --- loss:1.007, Epoch accuracy:61.18%, Validation loss:1.707, Validation accuracy:36.17%
# Epoch 116: iteration 3/4
# Epoch 116 --- loss:1.009, Epoch accuracy:61.05%, Validation loss:1.710, Validation accuracy:36.00%
# Epoch 117: iteration 3/4
# Epoch 117 --- loss:1.006, Epoch accuracy:60.92%, Validation loss:1.712, Validation accuracy:35.50%
# Epoch 118: iteration 3/4
# Epoch 118 --- loss:0.996, Epoch accuracy:61.58%, Validation loss:1.707, Validation accuracy:36.33%
# Epoch 119: iteration 3/4
# Epoch 119 --- loss:0.988, Epoch accuracy:62.06%, Validation loss:1.704, Validation accuracy:36.83%
# Epoch 120: iteration 3/4
# Epoch 120 --- loss:0.979, Epoch accuracy:62.94%, Validation loss:1.705, Validation accuracy:36.50%
# Epoch 121: iteration 3/4
# Epoch 121 --- loss:0.978, Epoch accuracy:62.85%, Validation loss:1.710, Validation accuracy:36.33%
# Epoch 122: iteration 3/4
# Epoch 122 --- loss:0.975, Epoch accuracy:62.54%, Validation loss:1.706, Validation accuracy:36.00%
# Epoch 123: iteration 3/4
# Epoch 123 --- loss:0.975, Epoch accuracy:62.81%, Validation loss:1.704, Validation accuracy:36.50%
# Epoch 124: iteration 3/4
# Epoch 124 --- loss:0.961, Epoch accuracy:63.42%, Validation loss:1.701, Validation accuracy:36.83%
# Epoch 125: iteration 3/4
# Epoch 125 --- loss:0.959, Epoch accuracy:63.68%, Validation loss:1.704, Validation accuracy:36.50%
# Epoch 126: iteration 3/4
# Epoch 126 --- loss:0.956, Epoch accuracy:63.20%, Validation loss:1.705, Validation accuracy:36.33%
# Epoch 127: iteration 3/4
# Epoch 127 --- loss:0.954, Epoch accuracy:63.77%, Validation loss:1.699, Validation accuracy:36.00%
# Epoch 128: iteration 3/4
# Epoch 128 --- loss:0.951, Epoch accuracy:63.82%, Validation loss:1.694, Validation accuracy:37.00%
# Epoch 129: iteration 3/4
# Epoch 129 --- loss:0.939, Epoch accuracy:64.96%, Validation loss:1.696, Validation accuracy:36.83%
# Epoch 130: iteration 3/4
# Epoch 130 --- loss:0.943, Epoch accuracy:64.12%, Validation loss:1.704, Validation accuracy:36.83%
# Epoch 131: iteration 3/4
# Epoch 131 --- loss:0.936, Epoch accuracy:64.04%, Validation loss:1.698, Validation accuracy:36.67%
# Epoch 132: iteration 3/4
# Epoch 132 --- loss:0.937, Epoch accuracy:64.52%, Validation loss:1.693, Validation accuracy:36.83%
# Epoch 133: iteration 3/4
# Epoch 133 --- loss:0.921, Epoch accuracy:65.92%, Validation loss:1.700, Validation accuracy:36.17%
# Epoch 134: iteration 3/4
# Epoch 134 --- loss:0.924, Epoch accuracy:64.96%, Validation loss:1.699, Validation accuracy:37.17%
# Epoch 135: iteration 3/4
# Epoch 135 --- loss:0.915, Epoch accuracy:65.35%, Validation loss:1.697, Validation accuracy:36.67%
# Epoch 136: iteration 3/4
# Epoch 136 --- loss:0.913, Epoch accuracy:65.26%, Validation loss:1.704, Validation accuracy:36.33%
# Epoch 137: iteration 3/4
# Epoch 137 --- loss:0.910, Epoch accuracy:65.39%, Validation loss:1.702, Validation accuracy:37.50%
# Epoch 138: iteration 3/4
# Epoch 138 --- loss:0.909, Epoch accuracy:65.22%, Validation loss:1.708, Validation accuracy:36.17%
# Epoch 139: iteration 3/4
# Epoch 139 --- loss:0.906, Epoch accuracy:65.79%, Validation loss:1.691, Validation accuracy:37.33%
# Epoch 140: iteration 3/4
# Epoch 140 --- loss:0.894, Epoch accuracy:66.62%, Validation loss:1.688, Validation accuracy:37.33%
# Epoch 141: iteration 3/4
# Epoch 141 --- loss:0.890, Epoch accuracy:66.62%, Validation loss:1.696, Validation accuracy:36.50%
# Epoch 142: iteration 3/4
# Epoch 142 --- loss:0.893, Epoch accuracy:65.70%, Validation loss:1.703, Validation accuracy:36.17%
# Epoch 143: iteration 3/4
# Epoch 143 --- loss:0.884, Epoch accuracy:66.97%, Validation loss:1.701, Validation accuracy:37.00%
# Epoch 144: iteration 3/4
# Epoch 144 --- loss:0.881, Epoch accuracy:67.24%, Validation loss:1.695, Validation accuracy:37.00%
# Epoch 145: iteration 3/4
# Epoch 145 --- loss:0.881, Epoch accuracy:66.67%, Validation loss:1.691, Validation accuracy:37.17%
# Epoch 146: iteration 3/4
# Epoch 146 --- loss:0.870, Epoch accuracy:67.19%, Validation loss:1.690, Validation accuracy:37.17%
# Epoch 147: iteration 3/4
# Epoch 147 --- loss:0.868, Epoch accuracy:67.24%, Validation loss:1.694, Validation accuracy:37.00%
# Epoch 148: iteration 3/4
# Epoch 148 --- loss:0.865, Epoch accuracy:68.20%, Validation loss:1.693, Validation accuracy:37.50%
# Epoch 149: iteration 3/4
# Epoch 149 --- loss:0.866, Epoch accuracy:67.59%, Validation loss:1.693, Validation accuracy:37.00%
# Epoch 150: iteration 3/4
# Epoch 150 --- loss:0.853, Epoch accuracy:67.81%, Validation loss:1.693, Validation accuracy:37.17%
# Epoch 151: iteration 3/4
# Epoch 151 --- loss:0.853, Epoch accuracy:68.55%, Validation loss:1.694, Validation accuracy:37.17%
# Epoch 152: iteration 3/4
# Epoch 152 --- loss:0.848, Epoch accuracy:67.94%, Validation loss:1.689, Validation accuracy:37.17%
# Epoch 153: iteration 3/4
# Epoch 153 --- loss:0.844, Epoch accuracy:68.95%, Validation loss:1.694, Validation accuracy:37.50%
# Epoch 154: iteration 3/4
# Epoch 154 --- loss:0.843, Epoch accuracy:68.82%, Validation loss:1.690, Validation accuracy:37.67%
# Epoch 155: iteration 3/4
# Epoch 155 --- loss:0.839, Epoch accuracy:68.95%, Validation loss:1.698, Validation accuracy:37.17%
# Epoch 156: iteration 3/4
# Epoch 156 --- loss:0.832, Epoch accuracy:69.17%, Validation loss:1.702, Validation accuracy:37.33%
# Epoch 157: iteration 3/4
# Epoch 157 --- loss:0.832, Epoch accuracy:68.82%, Validation loss:1.694, Validation accuracy:37.33%
# Epoch 158: iteration 3/4
# Epoch 158 --- loss:0.827, Epoch accuracy:69.08%, Validation loss:1.681, Validation accuracy:38.00%
# Epoch 159: iteration 3/4
# Epoch 159 --- loss:0.814, Epoch accuracy:70.04%, Validation loss:1.686, Validation accuracy:37.33%
# Epoch 160: iteration 3/4
# Epoch 160 --- loss:0.818, Epoch accuracy:70.13%, Validation loss:1.690, Validation accuracy:36.50%
# Epoch 161: iteration 3/4
# Epoch 161 --- loss:0.815, Epoch accuracy:70.44%, Validation loss:1.690, Validation accuracy:37.33%
# Epoch 162: iteration 3/4
# Epoch 162 --- loss:0.802, Epoch accuracy:70.83%, Validation loss:1.688, Validation accuracy:37.83%
# Epoch 163: iteration 3/4
# Epoch 163 --- loss:0.808, Epoch accuracy:69.91%, Validation loss:1.697, Validation accuracy:37.50%
# Epoch 164: iteration 3/4
# Epoch 164 --- loss:0.800, Epoch accuracy:70.39%, Validation loss:1.696, Validation accuracy:36.83%
# Epoch 165: iteration 3/4
# Epoch 165 --- loss:0.798, Epoch accuracy:71.18%, Validation loss:1.689, Validation accuracy:37.00%
# Epoch 166: iteration 3/4
# Epoch 166 --- loss:0.795, Epoch accuracy:71.23%, Validation loss:1.679, Validation accuracy:37.83%
# Epoch 167: iteration 3/4
# Epoch 167 --- loss:0.790, Epoch accuracy:71.89%, Validation loss:1.687, Validation accuracy:37.33%
# Epoch 168: iteration 3/4
# Epoch 168 --- loss:0.786, Epoch accuracy:72.11%, Validation loss:1.698, Validation accuracy:36.83%
# Epoch 169: iteration 3/4
# Epoch 169 --- loss:0.784, Epoch accuracy:71.75%, Validation loss:1.698, Validation accuracy:37.00%
# Epoch 170: iteration 3/4
# Epoch 170 --- loss:0.774, Epoch accuracy:72.19%, Validation loss:1.694, Validation accuracy:37.00%
# Epoch 171: iteration 3/4
# Epoch 171 --- loss:0.768, Epoch accuracy:73.03%, Validation loss:1.684, Validation accuracy:37.17%
# Epoch 172: iteration 3/4
# Epoch 172 --- loss:0.766, Epoch accuracy:73.11%, Validation loss:1.685, Validation accuracy:37.33%
# Epoch 173: iteration 3/4
# Epoch 173 --- loss:0.761, Epoch accuracy:73.11%, Validation loss:1.692, Validation accuracy:37.00%
# Epoch 174: iteration 3/4
# Epoch 174 --- loss:0.762, Epoch accuracy:73.03%, Validation loss:1.699, Validation accuracy:37.00%
# Epoch 175: iteration 3/4
# Epoch 175 --- loss:0.755, Epoch accuracy:72.76%, Validation loss:1.689, Validation accuracy:36.67%
# Epoch 176: iteration 3/4
# Epoch 176 --- loss:0.751, Epoch accuracy:73.20%, Validation loss:1.682, Validation accuracy:37.50%
# Epoch 177: iteration 3/4
# Epoch 177 --- loss:0.742, Epoch accuracy:73.90%, Validation loss:1.687, Validation accuracy:37.67%
# Epoch 178: iteration 3/4
# Epoch 178 --- loss:0.740, Epoch accuracy:73.77%, Validation loss:1.697, Validation accuracy:37.50%
# Epoch 179: iteration 3/4
# Epoch 179 --- loss:0.743, Epoch accuracy:73.73%, Validation loss:1.697, Validation accuracy:37.33%
# Epoch 180: iteration 3/4
# Epoch 180 --- loss:0.737, Epoch accuracy:73.46%, Validation loss:1.691, Validation accuracy:38.00%
# Epoch 181: iteration 3/4
# Epoch 181 --- loss:0.734, Epoch accuracy:73.77%, Validation loss:1.684, Validation accuracy:37.50%
# Epoch 182: iteration 3/4
# Epoch 182 --- loss:0.732, Epoch accuracy:73.95%, Validation loss:1.694, Validation accuracy:37.50%
# Epoch 183: iteration 3/4
# Epoch 183 --- loss:0.728, Epoch accuracy:74.25%, Validation loss:1.693, Validation accuracy:37.17%
# Epoch 184: iteration 3/4
# Epoch 184 --- loss:0.722, Epoch accuracy:74.69%, Validation loss:1.685, Validation accuracy:37.83%
# Epoch 185: iteration 3/4
# Epoch 185 --- loss:0.723, Epoch accuracy:73.95%, Validation loss:1.685, Validation accuracy:37.83%
# Epoch 186: iteration 3/4
# Epoch 186 --- loss:0.722, Epoch accuracy:73.86%, Validation loss:1.692, Validation accuracy:37.33%
# Epoch 187: iteration 3/4
# Epoch 187 --- loss:0.720, Epoch accuracy:74.30%, Validation loss:1.695, Validation accuracy:37.67%
# Epoch 188: iteration 3/4
# Epoch 188 --- loss:0.713, Epoch accuracy:74.52%, Validation loss:1.687, Validation accuracy:38.17%
# Epoch 189: iteration 3/4
# Epoch 189 --- loss:0.704, Epoch accuracy:75.35%, Validation loss:1.689, Validation accuracy:38.00%
# Epoch 190: iteration 3/4
# Epoch 190 --- loss:0.702, Epoch accuracy:75.35%, Validation loss:1.690, Validation accuracy:37.83%
# Epoch 191: iteration 3/4
# Epoch 191 --- loss:0.694, Epoch accuracy:75.70%, Validation loss:1.692, Validation accuracy:37.67%
# Epoch 192: iteration 3/4
# Epoch 192 --- loss:0.694, Epoch accuracy:76.10%, Validation loss:1.696, Validation accuracy:37.67%
# Epoch 193: iteration 3/4
# Epoch 193 --- loss:0.688, Epoch accuracy:76.36%, Validation loss:1.686, Validation accuracy:37.83%
# Epoch 194: iteration 3/4
# Epoch 194 --- loss:0.685, Epoch accuracy:75.70%, Validation loss:1.690, Validation accuracy:38.00%
# Epoch 195: iteration 3/4
# Epoch 195 --- loss:0.683, Epoch accuracy:76.14%, Validation loss:1.686, Validation accuracy:38.17%
# Epoch 196: iteration 3/4
# Epoch 196 --- loss:0.685, Epoch accuracy:76.36%, Validation loss:1.692, Validation accuracy:38.67%
# Epoch 197: iteration 3/4
# Epoch 197 --- loss:0.678, Epoch accuracy:76.36%, Validation loss:1.686, Validation accuracy:38.50%
# Epoch 198: iteration 3/4
# Epoch 198 --- loss:0.671, Epoch accuracy:76.97%, Validation loss:1.688, Validation accuracy:37.83%
# Epoch 199: iteration 3/4
# Epoch 199 --- loss:0.671, Epoch accuracy:77.19%, Validation loss:1.694, Validation accuracy:37.83%
# Epoch 200: iteration 3/4
# Epoch 200 --- loss:0.669, Epoch accuracy:76.80%, Validation loss:1.696, Validation accuracy:38.00%
# Epoch 201: iteration 3/4
# Epoch 201 --- loss:0.658, Epoch accuracy:77.41%, Validation loss:1.687, Validation accuracy:38.33%
# Epoch 202: iteration 3/4
# Epoch 202 --- loss:0.663, Epoch accuracy:77.63%, Validation loss:1.680, Validation accuracy:39.17%
# Epoch 203: iteration 3/4
# Epoch 203 --- loss:0.656, Epoch accuracy:77.06%, Validation loss:1.701, Validation accuracy:37.67%
# Epoch 204: iteration 3/4
# Epoch 204 --- loss:0.654, Epoch accuracy:77.50%, Validation loss:1.709, Validation accuracy:36.83%
# Epoch 205: iteration 3/4
# Epoch 205 --- loss:0.650, Epoch accuracy:77.89%, Validation loss:1.692, Validation accuracy:38.17%
# Epoch 206: iteration 3/4
# Epoch 206 --- loss:0.643, Epoch accuracy:77.50%, Validation loss:1.683, Validation accuracy:38.33%
# Epoch 207: iteration 3/4
# Epoch 207 --- loss:0.647, Epoch accuracy:77.15%, Validation loss:1.690, Validation accuracy:39.00%
# Epoch 208: iteration 3/4
# Epoch 208 --- loss:0.648, Epoch accuracy:77.37%, Validation loss:1.697, Validation accuracy:38.50%
# Epoch 209: iteration 3/4
# Epoch 209 --- loss:0.642, Epoch accuracy:77.68%, Validation loss:1.706, Validation accuracy:37.33%
# Epoch 210: iteration 3/4
# Epoch 210 --- loss:0.635, Epoch accuracy:78.11%, Validation loss:1.697, Validation accuracy:37.50%
# Epoch 211: iteration 3/4
# Epoch 211 --- loss:0.624, Epoch accuracy:78.90%, Validation loss:1.693, Validation accuracy:38.17%
# Epoch 212: iteration 3/4
# Epoch 212 --- loss:0.629, Epoch accuracy:78.25%, Validation loss:1.694, Validation accuracy:38.83%
# Epoch 213: iteration 3/4
# Epoch 213 --- loss:0.626, Epoch accuracy:78.33%, Validation loss:1.695, Validation accuracy:38.83%
# Epoch 214: iteration 3/4
# Epoch 214 --- loss:0.620, Epoch accuracy:78.60%, Validation loss:1.696, Validation accuracy:38.50%
# Epoch 215: iteration 3/4
# Epoch 215 --- loss:0.617, Epoch accuracy:78.82%, Validation loss:1.690, Validation accuracy:38.33%
# Epoch 216: iteration 3/4
# Epoch 216 --- loss:0.615, Epoch accuracy:78.82%, Validation loss:1.695, Validation accuracy:38.33%
# Epoch 217: iteration 3/4
# Epoch 217 --- loss:0.610, Epoch accuracy:79.08%, Validation loss:1.707, Validation accuracy:37.83%
# Epoch 218: iteration 3/4
# Epoch 218 --- loss:0.608, Epoch accuracy:78.86%, Validation loss:1.693, Validation accuracy:38.67%
# Epoch 219: iteration 3/4
# Epoch 219 --- loss:0.604, Epoch accuracy:79.30%, Validation loss:1.686, Validation accuracy:38.67%
# Epoch 220: iteration 3/4
# Epoch 220 --- loss:0.599, Epoch accuracy:79.43%, Validation loss:1.703, Validation accuracy:38.50%
# Epoch 221: iteration 3/4
# Epoch 221 --- loss:0.594, Epoch accuracy:79.56%, Validation loss:1.707, Validation accuracy:37.67%
# Epoch 222: iteration 3/4
# Epoch 222 --- loss:0.593, Epoch accuracy:80.09%, Validation loss:1.697, Validation accuracy:38.50%
# Epoch 223: iteration 3/4
# Epoch 223 --- loss:0.599, Epoch accuracy:79.12%, Validation loss:1.693, Validation accuracy:38.00%
# Epoch 224: iteration 3/4
# Epoch 224 --- loss:0.592, Epoch accuracy:79.74%, Validation loss:1.695, Validation accuracy:38.67%
# Epoch 225: iteration 3/4
# Epoch 225 --- loss:0.587, Epoch accuracy:80.13%, Validation loss:1.698, Validation accuracy:38.67%
# Epoch 226: iteration 3/4
# Epoch 226 --- loss:0.584, Epoch accuracy:79.91%, Validation loss:1.698, Validation accuracy:39.17%
# Epoch 227: iteration 3/4
# Epoch 227 --- loss:0.584, Epoch accuracy:80.35%, Validation loss:1.694, Validation accuracy:38.67%
# Epoch 228: iteration 3/4
# Epoch 228 --- loss:0.573, Epoch accuracy:80.22%, Validation loss:1.703, Validation accuracy:38.33%
# Epoch 229: iteration 3/4
# Epoch 229 --- loss:0.570, Epoch accuracy:80.53%, Validation loss:1.708, Validation accuracy:38.00%
# Epoch 230: iteration 3/4
# Epoch 230 --- loss:0.572, Epoch accuracy:80.96%, Validation loss:1.696, Validation accuracy:38.83%
# Epoch 231: iteration 3/4
# Epoch 231 --- loss:0.564, Epoch accuracy:81.14%, Validation loss:1.694, Validation accuracy:38.50%
# Epoch 232: iteration 3/4
# Epoch 232 --- loss:0.567, Epoch accuracy:80.83%, Validation loss:1.697, Validation accuracy:38.17%
# Epoch 233: iteration 3/4
# Epoch 233 --- loss:0.560, Epoch accuracy:81.45%, Validation loss:1.709, Validation accuracy:38.83%
# Epoch 234: iteration 3/4
# Epoch 234 --- loss:0.560, Epoch accuracy:80.92%, Validation loss:1.699, Validation accuracy:39.17%
# Epoch 235: iteration 3/4
# Epoch 235 --- loss:0.556, Epoch accuracy:81.49%, Validation loss:1.693, Validation accuracy:39.17%
# Epoch 236: iteration 3/4
# Epoch 236 --- loss:0.551, Epoch accuracy:81.71%, Validation loss:1.705, Validation accuracy:38.50%
# Epoch 237: iteration 3/4
# Epoch 237 --- loss:0.547, Epoch accuracy:81.80%, Validation loss:1.696, Validation accuracy:39.00%
# Epoch 238: iteration 3/4
# Epoch 238 --- loss:0.552, Epoch accuracy:81.18%, Validation loss:1.697, Validation accuracy:38.67%
# Epoch 239: iteration 3/4
# Epoch 239 --- loss:0.540, Epoch accuracy:82.19%, Validation loss:1.707, Validation accuracy:39.33%
# Epoch 240: iteration 3/4
# Epoch 240 --- loss:0.540, Epoch accuracy:82.02%, Validation loss:1.711, Validation accuracy:39.17%
# Epoch 241: iteration 3/4
# Epoch 241 --- loss:0.536, Epoch accuracy:81.97%, Validation loss:1.703, Validation accuracy:38.33%
# Epoch 242: iteration 3/4
# Epoch 242 --- loss:0.531, Epoch accuracy:82.19%, Validation loss:1.698, Validation accuracy:38.83%
# Epoch 243: iteration 3/4
# Epoch 243 --- loss:0.532, Epoch accuracy:82.19%, Validation loss:1.699, Validation accuracy:39.17%
# Epoch 244: iteration 3/4
# Epoch 244 --- loss:0.532, Epoch accuracy:82.46%, Validation loss:1.701, Validation accuracy:39.67%
# Epoch 245: iteration 3/4
# Epoch 245 --- loss:0.526, Epoch accuracy:82.68%, Validation loss:1.703, Validation accuracy:38.83%
# Epoch 246: iteration 3/4
# Epoch 246 --- loss:0.523, Epoch accuracy:82.68%, Validation loss:1.705, Validation accuracy:38.83%
# Epoch 247: iteration 3/4
# Epoch 247 --- loss:0.525, Epoch accuracy:82.59%, Validation loss:1.715, Validation accuracy:38.33%
# Epoch 248: iteration 3/4
# Epoch 248 --- loss:0.518, Epoch accuracy:82.94%, Validation loss:1.710, Validation accuracy:38.83%
# Epoch 249: iteration 3/4
# Epoch 249 --- loss:0.516, Epoch accuracy:83.03%, Validation loss:1.691, Validation accuracy:39.17%
# Epoch 250: iteration 3/4
# Epoch 250 --- loss:0.515, Epoch accuracy:82.63%, Validation loss:1.701, Validation accuracy:39.67%
# Epoch 251: iteration 3/4
# Epoch 251 --- loss:0.509, Epoch accuracy:83.46%, Validation loss:1.717, Validation accuracy:39.00%
# Epoch 252: iteration 3/4
# Epoch 252 --- loss:0.508, Epoch accuracy:83.16%, Validation loss:1.710, Validation accuracy:39.00%
# Epoch 253: iteration 3/4
# Epoch 253 --- loss:0.501, Epoch accuracy:83.55%, Validation loss:1.701, Validation accuracy:39.17%
# Epoch 254: iteration 3/4
# Epoch 254 --- loss:0.500, Epoch accuracy:83.51%, Validation loss:1.707, Validation accuracy:39.83%
# Epoch 255: iteration 3/4
# Epoch 255 --- loss:0.504, Epoch accuracy:83.55%, Validation loss:1.721, Validation accuracy:39.00%
# Epoch 256: iteration 3/4
# Epoch 256 --- loss:0.501, Epoch accuracy:83.29%, Validation loss:1.709, Validation accuracy:39.33%
# Epoch 257: iteration 3/4
# Epoch 257 --- loss:0.497, Epoch accuracy:83.90%, Validation loss:1.698, Validation accuracy:39.17%
# Epoch 258: iteration 3/4
# Epoch 258 --- loss:0.491, Epoch accuracy:83.73%, Validation loss:1.703, Validation accuracy:38.83%
# Epoch 259: iteration 3/4
# Epoch 259 --- loss:0.492, Epoch accuracy:83.99%, Validation loss:1.712, Validation accuracy:39.00%
# Epoch 260: iteration 3/4
# Epoch 260 --- loss:0.489, Epoch accuracy:84.34%, Validation loss:1.715, Validation accuracy:39.33%
# Epoch 261: iteration 3/4
# Epoch 261 --- loss:0.486, Epoch accuracy:83.90%, Validation loss:1.700, Validation accuracy:40.00%
# Epoch 262: iteration 3/4
# Epoch 262 --- loss:0.479, Epoch accuracy:84.25%, Validation loss:1.710, Validation accuracy:39.50%
# Epoch 263: iteration 3/4
# Epoch 263 --- loss:0.479, Epoch accuracy:84.43%, Validation loss:1.714, Validation accuracy:38.50%
# Epoch 264: iteration 3/4
# Epoch 264 --- loss:0.481, Epoch accuracy:84.34%, Validation loss:1.715, Validation accuracy:38.17%
# Epoch 265: iteration 3/4
# Epoch 265 --- loss:0.473, Epoch accuracy:84.78%, Validation loss:1.711, Validation accuracy:39.17%
# Epoch 266: iteration 3/4
# Epoch 266 --- loss:0.471, Epoch accuracy:84.74%, Validation loss:1.701, Validation accuracy:39.50%
# Epoch 267: iteration 3/4
# Epoch 267 --- loss:0.468, Epoch accuracy:84.61%, Validation loss:1.702, Validation accuracy:39.33%
# Epoch 268: iteration 3/4
# Epoch 268 --- loss:0.464, Epoch accuracy:84.65%, Validation loss:1.718, Validation accuracy:39.00%
# Epoch 269: iteration 3/4
# Epoch 269 --- loss:0.464, Epoch accuracy:84.78%, Validation loss:1.726, Validation accuracy:38.67%
# Epoch 270: iteration 3/4
# Epoch 270 --- loss:0.461, Epoch accuracy:85.53%, Validation loss:1.719, Validation accuracy:39.17%
# Epoch 271: iteration 3/4
# Epoch 271 --- loss:0.461, Epoch accuracy:84.69%, Validation loss:1.700, Validation accuracy:39.50%
# Epoch 272: iteration 3/4
# Epoch 272 --- loss:0.457, Epoch accuracy:85.00%, Validation loss:1.702, Validation accuracy:39.17%
# Epoch 273: iteration 3/4
# Epoch 273 --- loss:0.449, Epoch accuracy:85.04%, Validation loss:1.727, Validation accuracy:38.67%
# Epoch 274: iteration 3/4
# Epoch 274 --- loss:0.448, Epoch accuracy:85.44%, Validation loss:1.749, Validation accuracy:37.83%
# Epoch 275: iteration 3/4
# Epoch 275 --- loss:0.448, Epoch accuracy:85.09%, Validation loss:1.721, Validation accuracy:38.83%
# Epoch 276: iteration 3/4
# Epoch 276 --- loss:0.450, Epoch accuracy:85.61%, Validation loss:1.697, Validation accuracy:39.83%
# Epoch 277: iteration 3/4
# Epoch 277 --- loss:0.446, Epoch accuracy:85.53%, Validation loss:1.710, Validation accuracy:39.33%
# Epoch 278: iteration 3/4
# Epoch 278 --- loss:0.442, Epoch accuracy:85.48%, Validation loss:1.726, Validation accuracy:38.33%
# Epoch 279: iteration 3/4
# Epoch 279 --- loss:0.439, Epoch accuracy:85.61%, Validation loss:1.725, Validation accuracy:38.83%
# Epoch 280: iteration 3/4
# Epoch 280 --- loss:0.439, Epoch accuracy:86.18%, Validation loss:1.709, Validation accuracy:39.00%
# Epoch 281: iteration 3/4
# Epoch 281 --- loss:0.430, Epoch accuracy:86.36%, Validation loss:1.710, Validation accuracy:39.00%
# Epoch 282: iteration 3/4
# Epoch 282 --- loss:0.432, Epoch accuracy:85.79%, Validation loss:1.720, Validation accuracy:39.17%
# Epoch 283: iteration 3/4
# Epoch 283 --- loss:0.432, Epoch accuracy:85.79%, Validation loss:1.723, Validation accuracy:39.00%
# Epoch 284: iteration 3/4
# Epoch 284 --- loss:0.427, Epoch accuracy:85.92%, Validation loss:1.728, Validation accuracy:38.50%
# Epoch 285: iteration 3/4
# Epoch 285 --- loss:0.424, Epoch accuracy:85.88%, Validation loss:1.719, Validation accuracy:38.67%
# Epoch 286: iteration 3/4
# Epoch 286 --- loss:0.421, Epoch accuracy:86.32%, Validation loss:1.721, Validation accuracy:39.17%
# Epoch 287: iteration 3/4
# Epoch 287 --- loss:0.422, Epoch accuracy:86.27%, Validation loss:1.723, Validation accuracy:38.33%
# Epoch 288: iteration 3/4
# Epoch 288 --- loss:0.415, Epoch accuracy:86.18%, Validation loss:1.715, Validation accuracy:39.33%
# Epoch 289: iteration 3/4
# Epoch 289 --- loss:0.419, Epoch accuracy:86.05%, Validation loss:1.720, Validation accuracy:39.50%
# Epoch 290: iteration 3/4
# Epoch 290 --- loss:0.413, Epoch accuracy:86.62%, Validation loss:1.726, Validation accuracy:39.00%
# Epoch 291: iteration 3/4
# Epoch 291 --- loss:0.413, Epoch accuracy:86.45%, Validation loss:1.718, Validation accuracy:38.17%
# Epoch 292: iteration 3/4
# Epoch 292 --- loss:0.410, Epoch accuracy:86.32%, Validation loss:1.719, Validation accuracy:39.67%
# Epoch 293: iteration 3/4
# Epoch 293 --- loss:0.406, Epoch accuracy:86.71%, Validation loss:1.739, Validation accuracy:39.00%
# Epoch 294: iteration 3/4
# Epoch 294 --- loss:0.406, Epoch accuracy:86.62%, Validation loss:1.730, Validation accuracy:39.00%
# Epoch 295: iteration 3/4
# Epoch 295 --- loss:0.403, Epoch accuracy:86.89%, Validation loss:1.721, Validation accuracy:39.50%
# Epoch 296: iteration 3/4
# Epoch 296 --- loss:0.397, Epoch accuracy:86.97%, Validation loss:1.715, Validation accuracy:39.67%
# Epoch 297: iteration 3/4
# Epoch 297 --- loss:0.396, Epoch accuracy:86.89%, Validation loss:1.731, Validation accuracy:38.83%
# Epoch 298: iteration 3/4
# Epoch 298 --- loss:0.396, Epoch accuracy:86.89%, Validation loss:1.741, Validation accuracy:38.17%
# Epoch 299: iteration 3/4
# Epoch 299 --- loss:0.397, Epoch accuracy:86.97%, Validation loss:1.726, Validation accuracy:39.83%
# Epoch 300: iteration 3/4
# Epoch 300 --- loss:0.392, Epoch accuracy:86.89%, Validation loss:1.725, Validation accuracy:38.83%
# Epoch 301: iteration 3/4
# Epoch 301 --- loss:0.389, Epoch accuracy:87.02%, Validation loss:1.732, Validation accuracy:38.83%
# Epoch 302: iteration 3/4
# Epoch 302 --- loss:0.384, Epoch accuracy:87.24%, Validation loss:1.733, Validation accuracy:39.00%
# Epoch 303: iteration 3/4
# Epoch 303 --- loss:0.386, Epoch accuracy:87.28%, Validation loss:1.730, Validation accuracy:39.33%
# Epoch 304: iteration 3/4
# Epoch 304 --- loss:0.381, Epoch accuracy:87.28%, Validation loss:1.728, Validation accuracy:39.67%
# Epoch 305: iteration 3/4
# Epoch 305 --- loss:0.381, Epoch accuracy:87.37%, Validation loss:1.725, Validation accuracy:39.50%
# Epoch 306: iteration 3/4
# Epoch 306 --- loss:0.380, Epoch accuracy:87.32%, Validation loss:1.736, Validation accuracy:38.50%
# Epoch 307: iteration 3/4
# Epoch 307 --- loss:0.378, Epoch accuracy:87.46%, Validation loss:1.740, Validation accuracy:38.17%
# Epoch 308: iteration 3/4
# Epoch 308 --- loss:0.377, Epoch accuracy:87.54%, Validation loss:1.728, Validation accuracy:38.67%
# Epoch 309: iteration 3/4
# Epoch 309 --- loss:0.370, Epoch accuracy:87.46%, Validation loss:1.725, Validation accuracy:39.33%
# Epoch 310: iteration 3/4
# Epoch 310 --- loss:0.374, Epoch accuracy:87.50%, Validation loss:1.726, Validation accuracy:39.83%
# Epoch 311: iteration 3/4
# Epoch 311 --- loss:0.371, Epoch accuracy:87.50%, Validation loss:1.745, Validation accuracy:38.33%
# Epoch 312: iteration 3/4
# Epoch 312 --- loss:0.366, Epoch accuracy:87.68%, Validation loss:1.735, Validation accuracy:38.83%
# Epoch 313: iteration 3/4
# Epoch 313 --- loss:0.362, Epoch accuracy:87.98%, Validation loss:1.727, Validation accuracy:39.33%
# Epoch 314: iteration 3/4
# Epoch 314 --- loss:0.363, Epoch accuracy:87.89%, Validation loss:1.727, Validation accuracy:39.67%
# Epoch 315: iteration 3/4
# Epoch 315 --- loss:0.364, Epoch accuracy:87.72%, Validation loss:1.736, Validation accuracy:39.17%
# Epoch 316: iteration 3/4
# Epoch 316 --- loss:0.360, Epoch accuracy:87.85%, Validation loss:1.737, Validation accuracy:38.67%
# Epoch 317: iteration 3/4
# Epoch 317 --- loss:0.358, Epoch accuracy:87.81%, Validation loss:1.740, Validation accuracy:39.00%
# Epoch 318: iteration 3/4
# Epoch 318 --- loss:0.357, Epoch accuracy:87.68%, Validation loss:1.737, Validation accuracy:39.50%
# Epoch 319: iteration 3/4
# Epoch 319 --- loss:0.354, Epoch accuracy:87.89%, Validation loss:1.751, Validation accuracy:38.33%
# Epoch 320: iteration 3/4
# Epoch 320 --- loss:0.348, Epoch accuracy:87.81%, Validation loss:1.754, Validation accuracy:38.17%
# Epoch 321: iteration 3/4
# Epoch 321 --- loss:0.350, Epoch accuracy:88.16%, Validation loss:1.731, Validation accuracy:39.67%
# Epoch 322: iteration 3/4
# Epoch 322 --- loss:0.344, Epoch accuracy:88.11%, Validation loss:1.738, Validation accuracy:39.33%
# Epoch 323: iteration 3/4
# Epoch 323 --- loss:0.346, Epoch accuracy:88.03%, Validation loss:1.747, Validation accuracy:38.33%
# Epoch 324: iteration 3/4
# Epoch 324 --- loss:0.341, Epoch accuracy:88.07%, Validation loss:1.731, Validation accuracy:40.17%
# Epoch 325: iteration 3/4
# Epoch 325 --- loss:0.343, Epoch accuracy:88.11%, Validation loss:1.740, Validation accuracy:39.50%
# Epoch 326: iteration 3/4
# Epoch 326 --- loss:0.339, Epoch accuracy:88.16%, Validation loss:1.748, Validation accuracy:38.67%
# Epoch 327: iteration 3/4
# Epoch 327 --- loss:0.338, Epoch accuracy:88.20%, Validation loss:1.740, Validation accuracy:39.33%
# Epoch 328: iteration 3/4
# Epoch 328 --- loss:0.335, Epoch accuracy:88.03%, Validation loss:1.742, Validation accuracy:39.67%
# Epoch 329: iteration 3/4
# Epoch 329 --- loss:0.335, Epoch accuracy:88.20%, Validation loss:1.744, Validation accuracy:39.50%
# Epoch 330: iteration 3/4
# Epoch 330 --- loss:0.333, Epoch accuracy:88.20%, Validation loss:1.746, Validation accuracy:39.50%
# Epoch 331: iteration 3/4
# Epoch 331 --- loss:0.331, Epoch accuracy:88.20%, Validation loss:1.750, Validation accuracy:38.67%
# Epoch 332: iteration 3/4
# Epoch 332 --- loss:0.329, Epoch accuracy:88.55%, Validation loss:1.751, Validation accuracy:38.83%
# Epoch 333: iteration 3/4
# Epoch 333 --- loss:0.326, Epoch accuracy:88.33%, Validation loss:1.749, Validation accuracy:39.00%
# Epoch 334: iteration 3/4
# Epoch 334 --- loss:0.325, Epoch accuracy:88.20%, Validation loss:1.750, Validation accuracy:38.83%
# Epoch 335: iteration 3/4
# Epoch 335 --- loss:0.320, Epoch accuracy:88.46%, Validation loss:1.741, Validation accuracy:39.67%
# Epoch 336: iteration 3/4
# Epoch 336 --- loss:0.322, Epoch accuracy:88.38%, Validation loss:1.751, Validation accuracy:39.17%
# Epoch 337: iteration 3/4
# Epoch 337 --- loss:0.319, Epoch accuracy:88.64%, Validation loss:1.763, Validation accuracy:37.83%
# Epoch 338: iteration 3/4
# Epoch 338 --- loss:0.317, Epoch accuracy:88.46%, Validation loss:1.758, Validation accuracy:38.50%
# Epoch 339: iteration 3/4
# Epoch 339 --- loss:0.314, Epoch accuracy:88.64%, Validation loss:1.742, Validation accuracy:39.67%
# Epoch 340: iteration 3/4
# Epoch 340 --- loss:0.312, Epoch accuracy:88.73%, Validation loss:1.747, Validation accuracy:39.33%
# Epoch 341: iteration 3/4
# Epoch 341 --- loss:0.311, Epoch accuracy:88.60%, Validation loss:1.753, Validation accuracy:38.67%
# Epoch 342: iteration 3/4
# Epoch 342 --- loss:0.311, Epoch accuracy:88.55%, Validation loss:1.753, Validation accuracy:39.17%
# Epoch 343: iteration 3/4
# Epoch 343 --- loss:0.312, Epoch accuracy:88.73%, Validation loss:1.756, Validation accuracy:38.83%
# Epoch 344: iteration 3/4
# Epoch 344 --- loss:0.311, Epoch accuracy:88.51%, Validation loss:1.751, Validation accuracy:39.00%
# Epoch 345: iteration 3/4
# Epoch 345 --- loss:0.303, Epoch accuracy:88.68%, Validation loss:1.756, Validation accuracy:38.83%
# Epoch 346: iteration 3/4
# Epoch 346 --- loss:0.304, Epoch accuracy:88.86%, Validation loss:1.755, Validation accuracy:39.17%
# Epoch 347: iteration 3/4
# Epoch 347 --- loss:0.303, Epoch accuracy:88.68%, Validation loss:1.754, Validation accuracy:39.00%
# Epoch 348: iteration 3/4
# Epoch 348 --- loss:0.299, Epoch accuracy:88.64%, Validation loss:1.749, Validation accuracy:39.83%
# Epoch 349: iteration 3/4
# Epoch 349 --- loss:0.299, Epoch accuracy:88.90%, Validation loss:1.752, Validation accuracy:39.17%
# Epoch 350: iteration 3/4
# Epoch 350 --- loss:0.299, Epoch accuracy:88.77%, Validation loss:1.759, Validation accuracy:39.00%
# Epoch 351: iteration 3/4
# Epoch 351 --- loss:0.292, Epoch accuracy:88.99%, Validation loss:1.767, Validation accuracy:39.00%
# Epoch 352: iteration 3/4
# Epoch 352 --- loss:0.293, Epoch accuracy:88.86%, Validation loss:1.755, Validation accuracy:39.17%
# Epoch 353: iteration 3/4
# Epoch 353 --- loss:0.293, Epoch accuracy:88.90%, Validation loss:1.758, Validation accuracy:38.83%
# Epoch 354: iteration 3/4
# Epoch 354 --- loss:0.292, Epoch accuracy:88.73%, Validation loss:1.762, Validation accuracy:39.17%
# Epoch 355: iteration 3/4
# Epoch 355 --- loss:0.288, Epoch accuracy:88.86%, Validation loss:1.765, Validation accuracy:38.83%
# Epoch 356: iteration 3/4
# Epoch 356 --- loss:0.291, Epoch accuracy:88.90%, Validation loss:1.766, Validation accuracy:39.00%
# Epoch 357: iteration 3/4
# Epoch 357 --- loss:0.286, Epoch accuracy:88.99%, Validation loss:1.761, Validation accuracy:39.17%
# Epoch 358: iteration 3/4
# Epoch 358 --- loss:0.282, Epoch accuracy:88.95%, Validation loss:1.766, Validation accuracy:39.00%
# Epoch 359: iteration 3/4
# Epoch 359 --- loss:0.284, Epoch accuracy:88.99%, Validation loss:1.761, Validation accuracy:39.33%
# Epoch 360: iteration 3/4
# Epoch 360 --- loss:0.284, Epoch accuracy:88.95%, Validation loss:1.766, Validation accuracy:39.00%
# Epoch 361: iteration 3/4
# Epoch 361 --- loss:0.278, Epoch accuracy:89.08%, Validation loss:1.772, Validation accuracy:38.67%
# Epoch 362: iteration 3/4
# Epoch 362 --- loss:0.280, Epoch accuracy:89.04%, Validation loss:1.771, Validation accuracy:39.00%
# Epoch 363: iteration 3/4
# Epoch 363 --- loss:0.275, Epoch accuracy:89.21%, Validation loss:1.768, Validation accuracy:38.67%
# Epoch 364: iteration 3/4
# Epoch 364 --- loss:0.277, Epoch accuracy:89.12%, Validation loss:1.762, Validation accuracy:39.17%
# Epoch 365: iteration 3/4
# Epoch 365 --- loss:0.276, Epoch accuracy:89.21%, Validation loss:1.771, Validation accuracy:39.00%
# Epoch 366: iteration 3/4
# Epoch 366 --- loss:0.275, Epoch accuracy:89.08%, Validation loss:1.777, Validation accuracy:38.67%
# Epoch 367: iteration 3/4
# Epoch 367 --- loss:0.271, Epoch accuracy:89.17%, Validation loss:1.774, Validation accuracy:39.33%
# Epoch 368: iteration 3/4
# Epoch 368 --- loss:0.272, Epoch accuracy:89.21%, Validation loss:1.768, Validation accuracy:39.33%
# Epoch 369: iteration 3/4
# Epoch 369 --- loss:0.270, Epoch accuracy:89.12%, Validation loss:1.751, Validation accuracy:39.83%
# Epoch 370: iteration 3/4
# Epoch 370 --- loss:0.267, Epoch accuracy:89.25%, Validation loss:1.751, Validation accuracy:39.83%
# Epoch 371: iteration 3/4
# Epoch 371 --- loss:0.264, Epoch accuracy:89.39%, Validation loss:1.786, Validation accuracy:38.83%
# Epoch 372: iteration 3/4
# Epoch 372 --- loss:0.266, Epoch accuracy:89.25%, Validation loss:1.787, Validation accuracy:38.83%
# Epoch 373: iteration 3/4
# Epoch 373 --- loss:0.263, Epoch accuracy:89.34%, Validation loss:1.762, Validation accuracy:39.50%
# Epoch 374: iteration 3/4
# Epoch 374 --- loss:0.262, Epoch accuracy:89.25%, Validation loss:1.761, Validation accuracy:39.50%
# Epoch 375: iteration 3/4
# Epoch 375 --- loss:0.261, Epoch accuracy:89.30%, Validation loss:1.766, Validation accuracy:39.67%
# Epoch 376: iteration 3/4
# Epoch 376 --- loss:0.260, Epoch accuracy:89.30%, Validation loss:1.771, Validation accuracy:39.67%
# Epoch 377: iteration 3/4
# Epoch 377 --- loss:0.259, Epoch accuracy:89.12%, Validation loss:1.780, Validation accuracy:39.17%
# Epoch 378: iteration 3/4
# Epoch 378 --- loss:0.257, Epoch accuracy:89.21%, Validation loss:1.783, Validation accuracy:39.17%
# Epoch 379: iteration 3/4
# Epoch 379 --- loss:0.257, Epoch accuracy:89.21%, Validation loss:1.779, Validation accuracy:39.33%
# Epoch 380: iteration 3/4
# Epoch 380 --- loss:0.255, Epoch accuracy:89.25%, Validation loss:1.764, Validation accuracy:40.00%
# Epoch 381: iteration 3/4
# Epoch 381 --- loss:0.252, Epoch accuracy:89.39%, Validation loss:1.771, Validation accuracy:39.50%
# Epoch 382: iteration 3/4
# Epoch 382 --- loss:0.251, Epoch accuracy:89.43%, Validation loss:1.782, Validation accuracy:39.33%
# Epoch 383: iteration 3/4
# Epoch 383 --- loss:0.253, Epoch accuracy:89.34%, Validation loss:1.783, Validation accuracy:38.83%
# Epoch 384: iteration 3/4
# Epoch 384 --- loss:0.247, Epoch accuracy:89.34%, Validation loss:1.768, Validation accuracy:39.83%
# Epoch 385: iteration 3/4
# Epoch 385 --- loss:0.250, Epoch accuracy:89.25%, Validation loss:1.773, Validation accuracy:38.67%
# Epoch 386: iteration 3/4
# Epoch 386 --- loss:0.246, Epoch accuracy:89.30%, Validation loss:1.778, Validation accuracy:39.00%
# Epoch 387: iteration 3/4
# Epoch 387 --- loss:0.243, Epoch accuracy:89.39%, Validation loss:1.786, Validation accuracy:38.83%
# Epoch 388: iteration 3/4
# Epoch 388 --- loss:0.243, Epoch accuracy:89.34%, Validation loss:1.781, Validation accuracy:38.83%
# Epoch 389: iteration 3/4
# Epoch 389 --- loss:0.242, Epoch accuracy:89.34%, Validation loss:1.776, Validation accuracy:39.33%
# Epoch 390: iteration 3/4
# Epoch 390 --- loss:0.238, Epoch accuracy:89.39%, Validation loss:1.771, Validation accuracy:39.67%
# Epoch 391: iteration 3/4
# Epoch 391 --- loss:0.240, Epoch accuracy:89.34%, Validation loss:1.778, Validation accuracy:39.67%
# Epoch 392: iteration 3/4
# Epoch 392 --- loss:0.239, Epoch accuracy:89.25%, Validation loss:1.782, Validation accuracy:39.33%
# Epoch 393: iteration 3/4
# Epoch 393 --- loss:0.237, Epoch accuracy:89.47%, Validation loss:1.792, Validation accuracy:39.00%
# Epoch 394: iteration 3/4
# Epoch 394 --- loss:0.234, Epoch accuracy:89.39%, Validation loss:1.780, Validation accuracy:39.33%
# Epoch 395: iteration 3/4
# Epoch 395 --- loss:0.234, Epoch accuracy:89.47%, Validation loss:1.780, Validation accuracy:39.33%
# Epoch 396: iteration 3/4
# Epoch 396 --- loss:0.233, Epoch accuracy:89.43%, Validation loss:1.780, Validation accuracy:39.67%
# Epoch 397: iteration 3/4
# Epoch 397 --- loss:0.232, Epoch accuracy:89.43%, Validation loss:1.778, Validation accuracy:39.67%
# Epoch 398: iteration 3/4
# Epoch 398 --- loss:0.232, Epoch accuracy:89.43%, Validation loss:1.787, Validation accuracy:39.33%
# Epoch 399: iteration 3/4
# Epoch 399 --- loss:0.230, Epoch accuracy:89.52%, Validation loss:1.802, Validation accuracy:38.33%
# Epoch 400: iteration 3/4
# Epoch 400 --- loss:0.229, Epoch accuracy:89.39%, Validation loss:1.779, Validation accuracy:39.50%
# Epoch 401: iteration 3/4
# Epoch 401 --- loss:0.226, Epoch accuracy:89.52%, Validation loss:1.776, Validation accuracy:39.50%
# Epoch 402: iteration 3/4
# Epoch 402 --- loss:0.227, Epoch accuracy:89.39%, Validation loss:1.785, Validation accuracy:39.67%
# Epoch 403: iteration 3/4
# Epoch 403 --- loss:0.225, Epoch accuracy:89.43%, Validation loss:1.798, Validation accuracy:39.00%
# Epoch 404: iteration 3/4
# Epoch 404 --- loss:0.225, Epoch accuracy:89.43%, Validation loss:1.789, Validation accuracy:39.83%
# Epoch 405: iteration 3/4
# Epoch 405 --- loss:0.225, Epoch accuracy:89.52%, Validation loss:1.776, Validation accuracy:39.83%
# Epoch 406: iteration 3/4
# Epoch 406 --- loss:0.222, Epoch accuracy:89.52%, Validation loss:1.790, Validation accuracy:39.67%
# Epoch 407: iteration 3/4
# Epoch 407 --- loss:0.221, Epoch accuracy:89.47%, Validation loss:1.799, Validation accuracy:39.00%
# Epoch 408: iteration 3/4
# Epoch 408 --- loss:0.219, Epoch accuracy:89.43%, Validation loss:1.796, Validation accuracy:39.50%
# Epoch 409: iteration 3/4
# Epoch 409 --- loss:0.219, Epoch accuracy:89.43%, Validation loss:1.784, Validation accuracy:39.33%
# Epoch 410: iteration 3/4
# Epoch 410 --- loss:0.218, Epoch accuracy:89.43%, Validation loss:1.789, Validation accuracy:39.33%
# Epoch 411: iteration 3/4
# Epoch 411 --- loss:0.219, Epoch accuracy:89.47%, Validation loss:1.802, Validation accuracy:39.17%
# Epoch 412: iteration 3/4
# Epoch 412 --- loss:0.215, Epoch accuracy:89.43%, Validation loss:1.796, Validation accuracy:39.50%
# Epoch 413: iteration 3/4
# Epoch 413 --- loss:0.212, Epoch accuracy:89.56%, Validation loss:1.791, Validation accuracy:39.83%
# Epoch 414: iteration 3/4
# Epoch 414 --- loss:0.212, Epoch accuracy:89.47%, Validation loss:1.790, Validation accuracy:39.50%
# Epoch 415: iteration 3/4
# Epoch 415 --- loss:0.213, Epoch accuracy:89.61%, Validation loss:1.798, Validation accuracy:39.33%
# Epoch 416: iteration 3/4
# Epoch 416 --- loss:0.210, Epoch accuracy:89.56%, Validation loss:1.798, Validation accuracy:39.67%
# Epoch 417: iteration 3/4
# Epoch 417 --- loss:0.211, Epoch accuracy:89.52%, Validation loss:1.794, Validation accuracy:40.17%
# Epoch 418: iteration 3/4
# Epoch 418 --- loss:0.211, Epoch accuracy:89.52%, Validation loss:1.789, Validation accuracy:39.83%
# Epoch 419: iteration 3/4
# Epoch 419 --- loss:0.207, Epoch accuracy:89.52%, Validation loss:1.805, Validation accuracy:39.33%
# Epoch 420: iteration 3/4
# Epoch 420 --- loss:0.205, Epoch accuracy:89.56%, Validation loss:1.797, Validation accuracy:39.33%
# Epoch 421: iteration 3/4
# Epoch 421 --- loss:0.203, Epoch accuracy:89.69%, Validation loss:1.807, Validation accuracy:39.50%
# Epoch 422: iteration 3/4
# Epoch 422 --- loss:0.203, Epoch accuracy:89.65%, Validation loss:1.798, Validation accuracy:40.17%
# Epoch 423: iteration 3/4
# Epoch 423 --- loss:0.203, Epoch accuracy:89.56%, Validation loss:1.796, Validation accuracy:39.67%
# Epoch 424: iteration 3/4
# Epoch 424 --- loss:0.201, Epoch accuracy:89.65%, Validation loss:1.801, Validation accuracy:39.33%
# Epoch 425: iteration 3/4
# Epoch 425 --- loss:0.201, Epoch accuracy:89.61%, Validation loss:1.812, Validation accuracy:39.33%
# Epoch 426: iteration 3/4
# Epoch 426 --- loss:0.202, Epoch accuracy:89.61%, Validation loss:1.800, Validation accuracy:39.67%
# Epoch 427: iteration 3/4
# Epoch 427 --- loss:0.198, Epoch accuracy:89.69%, Validation loss:1.789, Validation accuracy:40.50%
# Epoch 428: iteration 3/4
# Epoch 428 --- loss:0.198, Epoch accuracy:89.74%, Validation loss:1.808, Validation accuracy:39.00%
# Epoch 429: iteration 3/4
# Epoch 429 --- loss:0.195, Epoch accuracy:89.69%, Validation loss:1.812, Validation accuracy:39.17%
# Epoch 430: iteration 3/4
# Epoch 430 --- loss:0.197, Epoch accuracy:89.69%, Validation loss:1.797, Validation accuracy:40.50%
# Epoch 431: iteration 3/4
# Epoch 431 --- loss:0.194, Epoch accuracy:89.69%, Validation loss:1.804, Validation accuracy:39.50%
# Epoch 432: iteration 3/4
# Epoch 432 --- loss:0.196, Epoch accuracy:89.65%, Validation loss:1.813, Validation accuracy:39.33%
# Epoch 433: iteration 3/4
# Epoch 433 --- loss:0.192, Epoch accuracy:89.65%, Validation loss:1.807, Validation accuracy:39.17%
# Epoch 434: iteration 3/4
# Epoch 434 --- loss:0.193, Epoch accuracy:89.69%, Validation loss:1.800, Validation accuracy:40.00%
# Epoch 435: iteration 3/4
# Epoch 435 --- loss:0.192, Epoch accuracy:89.69%, Validation loss:1.808, Validation accuracy:39.83%
# Epoch 436: iteration 3/4
# Epoch 436 --- loss:0.190, Epoch accuracy:89.69%, Validation loss:1.813, Validation accuracy:39.67%
# Epoch 437: iteration 3/4
# Epoch 437 --- loss:0.191, Epoch accuracy:89.65%, Validation loss:1.817, Validation accuracy:39.50%
# Epoch 438: iteration 3/4
# Epoch 438 --- loss:0.190, Epoch accuracy:89.69%, Validation loss:1.811, Validation accuracy:39.67%
# Epoch 439: iteration 3/4
# Epoch 439 --- loss:0.187, Epoch accuracy:89.74%, Validation loss:1.814, Validation accuracy:39.67%
# Epoch 440: iteration 3/4
# Epoch 440 --- loss:0.186, Epoch accuracy:89.65%, Validation loss:1.810, Validation accuracy:39.33%
# Epoch 441: iteration 3/4
# Epoch 441 --- loss:0.186, Epoch accuracy:89.69%, Validation loss:1.806, Validation accuracy:39.67%
# Epoch 442: iteration 3/4
# Epoch 442 --- loss:0.185, Epoch accuracy:89.69%, Validation loss:1.812, Validation accuracy:39.50%
# Epoch 443: iteration 3/4
# Epoch 443 --- loss:0.186, Epoch accuracy:89.74%, Validation loss:1.819, Validation accuracy:39.33%
# Epoch 444: iteration 3/4
# Epoch 444 --- loss:0.181, Epoch accuracy:89.74%, Validation loss:1.804, Validation accuracy:40.17%
# Epoch 445: iteration 3/4
# Epoch 445 --- loss:0.182, Epoch accuracy:89.69%, Validation loss:1.815, Validation accuracy:39.33%
# Epoch 446: iteration 3/4
# Epoch 446 --- loss:0.182, Epoch accuracy:89.69%, Validation loss:1.828, Validation accuracy:39.33%
# Epoch 447: iteration 3/4
# Epoch 447 --- loss:0.179, Epoch accuracy:89.69%, Validation loss:1.817, Validation accuracy:39.83%
# Epoch 448: iteration 3/4
# Epoch 448 --- loss:0.180, Epoch accuracy:89.69%, Validation loss:1.806, Validation accuracy:40.00%
# Epoch 449: iteration 3/4
# Epoch 449 --- loss:0.176, Epoch accuracy:89.74%, Validation loss:1.808, Validation accuracy:40.17%
# Epoch 450: iteration 3/4
# Epoch 450 --- loss:0.178, Epoch accuracy:89.74%, Validation loss:1.815, Validation accuracy:39.83%
# Epoch 451: iteration 3/4
# Epoch 451 --- loss:0.176, Epoch accuracy:89.69%, Validation loss:1.821, Validation accuracy:39.67%
# Epoch 452: iteration 3/4
# Epoch 452 --- loss:0.177, Epoch accuracy:89.74%, Validation loss:1.825, Validation accuracy:39.17%
# Epoch 453: iteration 3/4
# Epoch 453 --- loss:0.175, Epoch accuracy:89.74%, Validation loss:1.811, Validation accuracy:39.83%
# Epoch 454: iteration 3/4
# Epoch 454 --- loss:0.172, Epoch accuracy:89.69%, Validation loss:1.814, Validation accuracy:40.17%
# Epoch 455: iteration 3/4
# Epoch 455 --- loss:0.174, Epoch accuracy:89.69%, Validation loss:1.823, Validation accuracy:40.17%
# Epoch 456: iteration 3/4
# Epoch 456 --- loss:0.173, Epoch accuracy:89.74%, Validation loss:1.817, Validation accuracy:39.67%
# Epoch 457: iteration 3/4
# Epoch 457 --- loss:0.171, Epoch accuracy:89.74%, Validation loss:1.817, Validation accuracy:39.50%
# Epoch 458: iteration 3/4
# Epoch 458 --- loss:0.172, Epoch accuracy:89.74%, Validation loss:1.826, Validation accuracy:39.33%
# Epoch 459: iteration 3/4
# Epoch 459 --- loss:0.170, Epoch accuracy:89.69%, Validation loss:1.826, Validation accuracy:39.50%
# Epoch 460: iteration 3/4
# Epoch 460 --- loss:0.168, Epoch accuracy:89.69%, Validation loss:1.838, Validation accuracy:39.17%
# Epoch 461: iteration 3/4
# Epoch 461 --- loss:0.170, Epoch accuracy:89.74%, Validation loss:1.819, Validation accuracy:40.00%
# Epoch 462: iteration 3/4
# Epoch 462 --- loss:0.166, Epoch accuracy:89.78%, Validation loss:1.813, Validation accuracy:40.33%
# Epoch 463: iteration 3/4
# Epoch 463 --- loss:0.169, Epoch accuracy:89.74%, Validation loss:1.823, Validation accuracy:40.17%
# Epoch 464: iteration 3/4
# Epoch 464 --- loss:0.167, Epoch accuracy:89.74%, Validation loss:1.839, Validation accuracy:39.33%
# Epoch 465: iteration 3/4
# Epoch 465 --- loss:0.165, Epoch accuracy:89.78%, Validation loss:1.826, Validation accuracy:39.83%
# Epoch 466: iteration 3/4
# Epoch 466 --- loss:0.164, Epoch accuracy:89.74%, Validation loss:1.813, Validation accuracy:40.17%
# Epoch 467: iteration 3/4
# Epoch 467 --- loss:0.164, Epoch accuracy:89.74%, Validation loss:1.816, Validation accuracy:40.50%
# Epoch 468: iteration 3/4
# Epoch 468 --- loss:0.162, Epoch accuracy:89.78%, Validation loss:1.837, Validation accuracy:39.67%
# Epoch 469: iteration 3/4
# Epoch 469 --- loss:0.163, Epoch accuracy:89.74%, Validation loss:1.837, Validation accuracy:39.50%
# Epoch 470: iteration 3/4
# Epoch 470 --- loss:0.162, Epoch accuracy:89.74%, Validation loss:1.818, Validation accuracy:39.67%
# Epoch 471: iteration 3/4
# Epoch 471 --- loss:0.161, Epoch accuracy:89.69%, Validation loss:1.830, Validation accuracy:40.17%
# Epoch 472: iteration 3/4
# Epoch 472 --- loss:0.159, Epoch accuracy:89.78%, Validation loss:1.841, Validation accuracy:39.33%
# Epoch 473: iteration 3/4
# Epoch 473 --- loss:0.160, Epoch accuracy:89.69%, Validation loss:1.843, Validation accuracy:39.83%
# Epoch 474: iteration 3/4
# Epoch 474 --- loss:0.160, Epoch accuracy:89.74%, Validation loss:1.825, Validation accuracy:40.33%
# Epoch 475: iteration 3/4
# Epoch 475 --- loss:0.157, Epoch accuracy:89.74%, Validation loss:1.822, Validation accuracy:40.00%
# Epoch 476: iteration 3/4
# Epoch 476 --- loss:0.158, Epoch accuracy:89.74%, Validation loss:1.830, Validation accuracy:40.17%
# Epoch 477: iteration 3/4
# Epoch 477 --- loss:0.157, Epoch accuracy:89.74%, Validation loss:1.846, Validation accuracy:39.33%
# Epoch 478: iteration 3/4
# Epoch 478 --- loss:0.154, Epoch accuracy:89.74%, Validation loss:1.840, Validation accuracy:39.50%
# Epoch 479: iteration 3/4
# Epoch 479 --- loss:0.155, Epoch accuracy:89.74%, Validation loss:1.832, Validation accuracy:39.67%
# Epoch 480: iteration 3/4
# Epoch 480 --- loss:0.154, Epoch accuracy:89.74%, Validation loss:1.834, Validation accuracy:40.00%
# Epoch 481: iteration 3/4
# Epoch 481 --- loss:0.153, Epoch accuracy:89.78%, Validation loss:1.841, Validation accuracy:40.00%
# Epoch 482: iteration 3/4
# Epoch 482 --- loss:0.154, Epoch accuracy:89.74%, Validation loss:1.837, Validation accuracy:39.83%
# Epoch 483: iteration 3/4
# Epoch 483 --- loss:0.151, Epoch accuracy:89.78%, Validation loss:1.827, Validation accuracy:40.17%
# Epoch 484: iteration 3/4
# Epoch 484 --- loss:0.150, Epoch accuracy:89.78%, Validation loss:1.829, Validation accuracy:40.67%
# Epoch 485: iteration 3/4
# Epoch 485 --- loss:0.151, Epoch accuracy:89.78%, Validation loss:1.838, Validation accuracy:40.17%
# Epoch 486: iteration 3/4
# Epoch 486 --- loss:0.150, Epoch accuracy:89.82%, Validation loss:1.850, Validation accuracy:39.50%
# Epoch 487: iteration 3/4
# Epoch 487 --- loss:0.150, Epoch accuracy:89.74%, Validation loss:1.837, Validation accuracy:40.00%
# Epoch 488: iteration 3/4
# Epoch 488 --- loss:0.149, Epoch accuracy:89.74%, Validation loss:1.832, Validation accuracy:40.67%
# Epoch 489: iteration 3/4
# Epoch 489 --- loss:0.149, Epoch accuracy:89.74%, Validation loss:1.829, Validation accuracy:40.50%
# Epoch 490: iteration 3/4
# Epoch 490 --- loss:0.147, Epoch accuracy:89.74%, Validation loss:1.849, Validation accuracy:40.00%
# Epoch 491: iteration 3/4
# Epoch 491 --- loss:0.145, Epoch accuracy:89.74%, Validation loss:1.847, Validation accuracy:40.33%
# Epoch 492: iteration 3/4
# Epoch 492 --- loss:0.148, Epoch accuracy:89.74%, Validation loss:1.847, Validation accuracy:40.00%
# Epoch 493: iteration 3/4
# Epoch 493 --- loss:0.144, Epoch accuracy:89.78%, Validation loss:1.838, Validation accuracy:40.33%
# Epoch 494: iteration 3/4
# Epoch 494 --- loss:0.144, Epoch accuracy:89.78%, Validation loss:1.836, Validation accuracy:40.33%
# Epoch 495: iteration 3/4
# Epoch 495 --- loss:0.143, Epoch accuracy:89.74%, Validation loss:1.840, Validation accuracy:40.50%
# Epoch 496: iteration 3/4
# Epoch 496 --- loss:0.143, Epoch accuracy:89.74%, Validation loss:1.848, Validation accuracy:40.33%
# Epoch 497: iteration 3/4
# Epoch 497 --- loss:0.142, Epoch accuracy:89.74%, Validation loss:1.856, Validation accuracy:39.17%
# Epoch 498: iteration 3/4
# Epoch 498 --- loss:0.143, Epoch accuracy:89.74%, Validation loss:1.856, Validation accuracy:39.33%
# Epoch 499: iteration 3/4
# Epoch 499 --- loss:0.140, Epoch accuracy:89.74%, Validation loss:1.842, Validation accuracy:40.67%
#
#
# [*] done !
# [*] Best training loss - 0.14018573760986325
# [*] Best validation loss - 1.6793185472488403

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    
    break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [14], line 26
#      23 # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
#      24 y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
# ---> 26 test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
#      27 print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
#      28 test_accs.append(test_acc)
#
# Cell In [8], line 12, in make_validate_fnc.<locals>.validate(X, Y)
#       9 model.eval()
#      11 # get the model's predictions on the validation set
# ---> 12 output_logits, output_softmax = model(X)
#      13 predictions = torch.argmax(output_softmax, dim=1)
#      15 # calculate the mean accuracy over the entire validation set
#
# File c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [6], line 16, in Model.forward(self, x)
#      14 def forward(self, x):
# ---> 16     cnn_embd = self.lw_cnn_model(x)
#      17     att_embd = self.sam_model(cnn_embd)
#      19     att_embd = att_embd.unsqueeze(1)
#
# File c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In [4], line 16, in LW_CNN.forward(self, x)
#      15 def forward(self, x):
# ---> 16     conv_embd = self.conv1(x)
#      17     conv_embd = self.max_pool(conv_embd)
#      19     conv_embd = self.conv2(conv_embd)
#
# File c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\torch\nn\modules\conv.py:307, in Conv1d.forward(self, input)
#     306 def forward(self, input: Tensor) -> Tensor:
# --> 307     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\devLupin\Miniconda3\envs\ser\lib\site-packages\torch\nn\modules\conv.py:303, in Conv1d._conv_forward(self, input, weight, bias)
#     299 if self.padding_mode != 'zeros':
#     300     return F.conv1d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     301                     weight, bias, self.stride,
#     302                     _single(0), self.dilation, self.groups)
# --> 303 return F.conv1d(input, weight, bias, self.stride,
#     304                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Expected 2D (unbatched) or 3D (batched) input to conv1d, but got input of size: [600, 3, 224, 614]

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    break
