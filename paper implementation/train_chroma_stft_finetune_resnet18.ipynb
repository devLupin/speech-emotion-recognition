# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F

class resnet18_finetune(nn.Module):
    def __init__(self, num_emotions) -> None:
        super().__init__()
        
        self.model_ft = models.resnet18(pretrained=True)
        self.model_ft = nn.Sequential(*(list(self.model_ft.children())[:-1]))
        
        for name, param in self.model_ft[:4].named_parameters():
            param.requires_grad=False
        
        self.fc_linear = nn.Linear(512, 8)
        
        self.softmax_out = nn.Softmax(dim=1)
    
    def forward(self, x):
        
        output = self.model_ft(x)
        output = torch.flatten(output, start_dim=1)
        output_logits = self.fc_linear(output)
        output_softmax = self.softmax_out(output_logits)
        
        return output_logits, output_softmax

# %%
import os
import torch
import numpy as np
from torchinfo import summary
from tqdm.auto import tqdm

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

emotions_dict = {
    0: 'Neutral',
    1: 'Calm',
    2: 'Happy',
    3: 'Sad',
    4: 'Angry',
    5: 'Fear',
    6: 'Disgust',
    7: 'Surprise'
}

model = resnet18_finetune(num_emotions=len(emotions_dict)).to('cuda')
sub_name = 'resnet_18_finetune'
data_name = 'RAVDESS'
EARLY_CNT = 500

minibatch = 128
num_epochs = 500
optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)

print(summary(model, input_size=(minibatch, 3, 224, 224)))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# resnet18_finetune                             [128, 8]                  --
# ├─Sequential: 1-1                             [128, 512, 1, 1]          --
# │    └─Conv2d: 2-1                            [128, 64, 112, 112]       (9,408)
# │    └─BatchNorm2d: 2-2                       [128, 64, 112, 112]       (128)
# │    └─ReLU: 2-3                              [128, 64, 112, 112]       --
# │    └─MaxPool2d: 2-4                         [128, 64, 56, 56]         --
# │    └─Sequential: 2-5                        [128, 64, 56, 56]         --
# │    │    └─BasicBlock: 3-1                   [128, 64, 56, 56]         73,984
# │    │    └─BasicBlock: 3-2                   [128, 64, 56, 56]         73,984
# │    └─Sequential: 2-6                        [128, 128, 28, 28]        --
# │    │    └─BasicBlock: 3-3                   [128, 128, 28, 28]        230,144
# │    │    └─BasicBlock: 3-4                   [128, 128, 28, 28]        295,424
# │    └─Sequential: 2-7                        [128, 256, 14, 14]        --
# │    │    └─BasicBlock: 3-5                   [128, 256, 14, 14]        919,040
# │    │    └─BasicBlock: 3-6                   [128, 256, 14, 14]        1,180,672
# │    └─Sequential: 2-8                        [128, 512, 7, 7]          --
# │    │    └─BasicBlock: 3-7                   [128, 512, 7, 7]          3,673,088
# │    │    └─BasicBlock: 3-8                   [128, 512, 7, 7]          4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [128, 512, 1, 1]          --
# ├─Linear: 1-2                                 [128, 8]                  4,104
# ├─Softmax: 1-3                                [128, 8]                  --
# ===============================================================================================
# Total params: 11,180,616
# Trainable params: 11,171,080
# Non-trainable params: 9,536
# Total mult-adds (G): 232.14
# ===============================================================================================
# Input size (MB): 77.07
# Forward/backward pass size (MB): 5086.65
# Params size (MB): 44.72
# Estimated Total Size (MB): 5208.44
# ===============================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            X_tensor = X_tensor.permute(0, 3, 1, 2)
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        X_valid_tensor = X_valid_tensor.permute(0, 3, 1, 2)
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import cv2
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(cur_fold_path):
    X_train, y_train, X_test, y_test = [], [], [], []
    
    train_f = open(os.path.join(cur_fold_path, 'train.csv'), 'r')
    test_f = open(os.path.join(cur_fold_path, 'test.csv'), 'r')
    
    train_reader = csv.reader(train_f)
    for r in train_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_train.append(image)
        y_train.append(int(r[1]))
        
    test_reader = csv.reader(test_f)
    for r in test_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_test.append(image)
        y_test.append(int(r[1]))
    
    return np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

# %%
all_fold_dataset = []

for fold in tqdm(range(5), desc='load chroma_stft fold dataset'):
    cur_fold_path = os.path.join('chroma_stft_fold', str(fold))
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    all_fold_dataset.append([X_train, y_train, X_test, y_test])
# Out:
# load chroma_stft fold dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'chroma_stft_fold'

for fold in range(5):
    cur = all_fold_dataset[fold]
    
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - resnet_18_finetune
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 7/8
# Epoch 0 --- loss:2.090, Epoch accuracy:10.44%, Validation loss:2.202, Validation accuracy:13.00%
# Epoch 1: iteration 7/8
# Epoch 1 --- loss:2.072, Epoch accuracy:11.05%, Validation loss:2.314, Validation accuracy:11.67%
# Epoch 2: iteration 7/8
# Epoch 2 --- loss:2.062, Epoch accuracy:10.96%, Validation loss:2.391, Validation accuracy:10.00%
# Epoch 3: iteration 7/8
# Epoch 3 --- loss:2.047, Epoch accuracy:11.75%, Validation loss:2.383, Validation accuracy:10.67%
# Epoch 4: iteration 7/8
# Epoch 4 --- loss:2.023, Epoch accuracy:12.19%, Validation loss:2.355, Validation accuracy:13.33%
# Epoch 5: iteration 7/8
# Epoch 5 --- loss:2.026, Epoch accuracy:12.19%, Validation loss:2.331, Validation accuracy:14.33%
# Epoch 6: iteration 7/8
# Epoch 6 --- loss:2.012, Epoch accuracy:12.63%, Validation loss:2.316, Validation accuracy:14.00%
# Epoch 7: iteration 7/8
# Epoch 7 --- loss:2.009, Epoch accuracy:13.60%, Validation loss:2.310, Validation accuracy:13.67%
# Epoch 8: iteration 7/8
# Epoch 8 --- loss:1.980, Epoch accuracy:13.51%, Validation loss:2.309, Validation accuracy:14.33%
# Epoch 9: iteration 7/8
# Epoch 9 --- loss:1.973, Epoch accuracy:14.04%, Validation loss:2.306, Validation accuracy:14.33%
# Epoch 10: iteration 7/8
# Epoch 10 --- loss:1.963, Epoch accuracy:14.65%, Validation loss:2.303, Validation accuracy:14.00%
# Epoch 11: iteration 7/8
# Epoch 11 --- loss:1.957, Epoch accuracy:14.30%, Validation loss:2.299, Validation accuracy:14.00%
# Epoch 12: iteration 7/8
# Epoch 12 --- loss:1.924, Epoch accuracy:16.05%, Validation loss:2.296, Validation accuracy:14.00%
# Epoch 13: iteration 7/8
# Epoch 13 --- loss:1.934, Epoch accuracy:15.88%, Validation loss:2.292, Validation accuracy:13.67%
# Epoch 14: iteration 7/8
# Epoch 14 --- loss:1.921, Epoch accuracy:16.32%, Validation loss:2.289, Validation accuracy:13.67%
# Epoch 15: iteration 7/8
# Epoch 15 --- loss:1.905, Epoch accuracy:16.32%, Validation loss:2.286, Validation accuracy:13.67%
# Epoch 16: iteration 7/8
# Epoch 16 --- loss:1.906, Epoch accuracy:17.02%, Validation loss:2.284, Validation accuracy:14.00%
# Epoch 17: iteration 7/8
# Epoch 17 --- loss:1.885, Epoch accuracy:17.11%, Validation loss:2.280, Validation accuracy:14.00%
# Epoch 18: iteration 7/8
# Epoch 18 --- loss:1.875, Epoch accuracy:17.81%, Validation loss:2.276, Validation accuracy:14.33%
# Epoch 19: iteration 7/8
# Epoch 19 --- loss:1.853, Epoch accuracy:19.12%, Validation loss:2.273, Validation accuracy:14.33%
# Epoch 20: iteration 7/8
# Epoch 20 --- loss:1.849, Epoch accuracy:18.95%, Validation loss:2.269, Validation accuracy:14.00%
# Epoch 21: iteration 7/8
# Epoch 21 --- loss:1.846, Epoch accuracy:19.65%, Validation loss:2.266, Validation accuracy:14.00%
# Epoch 22: iteration 7/8
# Epoch 22 --- loss:1.843, Epoch accuracy:19.65%, Validation loss:2.263, Validation accuracy:14.33%
# Epoch 23: iteration 7/8
# Epoch 23 --- loss:1.820, Epoch accuracy:20.44%, Validation loss:2.260, Validation accuracy:14.33%
# Epoch 24: iteration 7/8
# Epoch 24 --- loss:1.817, Epoch accuracy:20.53%, Validation loss:2.257, Validation accuracy:14.67%
# Epoch 25: iteration 7/8
# Epoch 25 --- loss:1.794, Epoch accuracy:21.58%, Validation loss:2.254, Validation accuracy:14.67%
# Epoch 26: iteration 7/8
# Epoch 26 --- loss:1.777, Epoch accuracy:22.63%, Validation loss:2.250, Validation accuracy:14.67%
# Epoch 27: iteration 7/8
# Epoch 27 --- loss:1.778, Epoch accuracy:22.72%, Validation loss:2.248, Validation accuracy:14.67%
# Epoch 28: iteration 7/8
# Epoch 28 --- loss:1.769, Epoch accuracy:23.33%, Validation loss:2.245, Validation accuracy:14.67%
# Epoch 29: iteration 7/8
# Epoch 29 --- loss:1.755, Epoch accuracy:23.68%, Validation loss:2.241, Validation accuracy:14.67%
# Epoch 30: iteration 7/8
# Epoch 30 --- loss:1.755, Epoch accuracy:22.98%, Validation loss:2.238, Validation accuracy:14.67%
# Epoch 31: iteration 7/8
# Epoch 31 --- loss:1.736, Epoch accuracy:24.47%, Validation loss:2.235, Validation accuracy:14.67%
# Epoch 32: iteration 7/8
# Epoch 32 --- loss:1.730, Epoch accuracy:25.09%, Validation loss:2.233, Validation accuracy:14.67%
# Epoch 33: iteration 7/8
# Epoch 33 --- loss:1.711, Epoch accuracy:25.61%, Validation loss:2.231, Validation accuracy:15.00%
# Epoch 34: iteration 7/8
# Epoch 34 --- loss:1.712, Epoch accuracy:26.58%, Validation loss:2.228, Validation accuracy:14.67%
# Epoch 35: iteration 7/8
# Epoch 35 --- loss:1.704, Epoch accuracy:25.53%, Validation loss:2.225, Validation accuracy:15.00%
# Epoch 36: iteration 7/8
# Epoch 36 --- loss:1.688, Epoch accuracy:26.32%, Validation loss:2.222, Validation accuracy:15.00%
# Epoch 37: iteration 7/8
# Epoch 37 --- loss:1.679, Epoch accuracy:27.37%, Validation loss:2.220, Validation accuracy:15.33%
# Epoch 38: iteration 7/8
# Epoch 38 --- loss:1.675, Epoch accuracy:27.72%, Validation loss:2.218, Validation accuracy:15.33%
# Epoch 39: iteration 7/8
# Epoch 39 --- loss:1.667, Epoch accuracy:27.98%, Validation loss:2.215, Validation accuracy:15.00%
# Epoch 40: iteration 7/8
# Epoch 40 --- loss:1.642, Epoch accuracy:29.74%, Validation loss:2.211, Validation accuracy:15.67%
# Epoch 41: iteration 7/8
# Epoch 41 --- loss:1.635, Epoch accuracy:29.56%, Validation loss:2.208, Validation accuracy:16.33%
# Epoch 42: iteration 7/8
# Epoch 42 --- loss:1.630, Epoch accuracy:29.82%, Validation loss:2.207, Validation accuracy:16.67%
# Epoch 43: iteration 7/8
# Epoch 43 --- loss:1.621, Epoch accuracy:30.61%, Validation loss:2.205, Validation accuracy:16.67%
# Epoch 44: iteration 7/8
# Epoch 44 --- loss:1.605, Epoch accuracy:32.02%, Validation loss:2.202, Validation accuracy:16.67%
# Epoch 45: iteration 7/8
# Epoch 45 --- loss:1.596, Epoch accuracy:31.49%, Validation loss:2.199, Validation accuracy:16.67%
# Epoch 46: iteration 7/8
# Epoch 46 --- loss:1.592, Epoch accuracy:31.93%, Validation loss:2.196, Validation accuracy:17.00%
# Epoch 47: iteration 7/8
# Epoch 47 --- loss:1.583, Epoch accuracy:33.07%, Validation loss:2.194, Validation accuracy:17.00%
# Epoch 48: iteration 7/8
# Epoch 48 --- loss:1.579, Epoch accuracy:33.42%, Validation loss:2.191, Validation accuracy:17.00%
# Epoch 49: iteration 7/8
# Epoch 49 --- loss:1.559, Epoch accuracy:34.47%, Validation loss:2.189, Validation accuracy:17.33%
# Epoch 50: iteration 7/8
# Epoch 50 --- loss:1.542, Epoch accuracy:36.32%, Validation loss:2.187, Validation accuracy:17.33%
# Epoch 51: iteration 7/8
# Epoch 51 --- loss:1.548, Epoch accuracy:34.12%, Validation loss:2.184, Validation accuracy:17.67%
# Epoch 52: iteration 7/8
# Epoch 52 --- loss:1.533, Epoch accuracy:36.75%, Validation loss:2.184, Validation accuracy:17.33%
# Epoch 53: iteration 7/8
# Epoch 53 --- loss:1.529, Epoch accuracy:36.58%, Validation loss:2.180, Validation accuracy:18.33%
# Epoch 54: iteration 7/8
# Epoch 54 --- loss:1.517, Epoch accuracy:37.72%, Validation loss:2.178, Validation accuracy:18.33%
# Epoch 55: iteration 7/8
# Epoch 55 --- loss:1.502, Epoch accuracy:38.33%, Validation loss:2.175, Validation accuracy:18.67%
# Epoch 56: iteration 7/8
# Epoch 56 --- loss:1.496, Epoch accuracy:38.07%, Validation loss:2.173, Validation accuracy:18.67%
# Epoch 57: iteration 7/8
# Epoch 57 --- loss:1.488, Epoch accuracy:39.39%, Validation loss:2.169, Validation accuracy:18.67%
# Epoch 58: iteration 7/8
# Epoch 58 --- loss:1.481, Epoch accuracy:38.86%, Validation loss:2.168, Validation accuracy:18.67%
# Epoch 59: iteration 7/8
# Epoch 59 --- loss:1.472, Epoch accuracy:40.61%, Validation loss:2.166, Validation accuracy:18.67%
# Epoch 60: iteration 7/8
# Epoch 60 --- loss:1.465, Epoch accuracy:40.61%, Validation loss:2.163, Validation accuracy:18.67%
# Epoch 61: iteration 7/8
# Epoch 61 --- loss:1.448, Epoch accuracy:42.37%, Validation loss:2.160, Validation accuracy:19.00%
# Epoch 62: iteration 7/8
# Epoch 62 --- loss:1.446, Epoch accuracy:42.46%, Validation loss:2.159, Validation accuracy:19.33%
# Epoch 63: iteration 7/8
# Epoch 63 --- loss:1.430, Epoch accuracy:41.93%, Validation loss:2.156, Validation accuracy:19.00%
# Epoch 64: iteration 7/8
# Epoch 64 --- loss:1.430, Epoch accuracy:42.54%, Validation loss:2.155, Validation accuracy:19.33%
# Epoch 65: iteration 7/8
# Epoch 65 --- loss:1.422, Epoch accuracy:44.82%, Validation loss:2.152, Validation accuracy:19.33%
# Epoch 66: iteration 7/8
# Epoch 66 --- loss:1.417, Epoch accuracy:44.04%, Validation loss:2.150, Validation accuracy:19.00%
# Epoch 67: iteration 7/8
# Epoch 67 --- loss:1.397, Epoch accuracy:45.70%, Validation loss:2.148, Validation accuracy:19.33%
# Epoch 68: iteration 7/8
# Epoch 68 --- loss:1.391, Epoch accuracy:46.84%, Validation loss:2.145, Validation accuracy:19.33%
# Epoch 69: iteration 7/8
# Epoch 69 --- loss:1.382, Epoch accuracy:47.89%, Validation loss:2.144, Validation accuracy:19.33%
# Epoch 70: iteration 7/8
# Epoch 70 --- loss:1.374, Epoch accuracy:46.93%, Validation loss:2.141, Validation accuracy:19.67%
# Epoch 71: iteration 7/8
# Epoch 71 --- loss:1.357, Epoch accuracy:48.77%, Validation loss:2.140, Validation accuracy:19.67%
# Epoch 72: iteration 7/8
# Epoch 72 --- loss:1.356, Epoch accuracy:48.60%, Validation loss:2.137, Validation accuracy:20.00%
# Epoch 73: iteration 7/8
# Epoch 73 --- loss:1.342, Epoch accuracy:50.26%, Validation loss:2.136, Validation accuracy:20.00%
# Epoch 74: iteration 7/8
# Epoch 74 --- loss:1.331, Epoch accuracy:50.26%, Validation loss:2.133, Validation accuracy:20.00%
# Epoch 75: iteration 7/8
# Epoch 75 --- loss:1.334, Epoch accuracy:49.39%, Validation loss:2.131, Validation accuracy:20.00%
# Epoch 76: iteration 7/8
# Epoch 76 --- loss:1.317, Epoch accuracy:51.14%, Validation loss:2.130, Validation accuracy:20.00%
# Epoch 77: iteration 7/8
# Epoch 77 --- loss:1.315, Epoch accuracy:52.72%, Validation loss:2.128, Validation accuracy:20.00%
# Epoch 78: iteration 7/8
# Epoch 78 --- loss:1.304, Epoch accuracy:52.54%, Validation loss:2.125, Validation accuracy:20.00%
# Epoch 79: iteration 7/8
# Epoch 79 --- loss:1.296, Epoch accuracy:53.33%, Validation loss:2.124, Validation accuracy:20.33%
# Epoch 80: iteration 7/8
# Epoch 80 --- loss:1.283, Epoch accuracy:54.39%, Validation loss:2.122, Validation accuracy:20.33%
# Epoch 81: iteration 7/8
# Epoch 81 --- loss:1.275, Epoch accuracy:54.47%, Validation loss:2.120, Validation accuracy:20.33%
# Epoch 82: iteration 7/8
# Epoch 82 --- loss:1.266, Epoch accuracy:55.61%, Validation loss:2.118, Validation accuracy:20.67%
# Epoch 83: iteration 7/8
# Epoch 83 --- loss:1.264, Epoch accuracy:55.44%, Validation loss:2.117, Validation accuracy:20.67%
# Epoch 84: iteration 7/8
# Epoch 84 --- loss:1.243, Epoch accuracy:56.40%, Validation loss:2.113, Validation accuracy:21.00%
# Epoch 85: iteration 7/8
# Epoch 85 --- loss:1.243, Epoch accuracy:57.46%, Validation loss:2.112, Validation accuracy:20.67%
# Epoch 86: iteration 7/8
# Epoch 86 --- loss:1.235, Epoch accuracy:57.28%, Validation loss:2.111, Validation accuracy:21.00%
# Epoch 87: iteration 7/8
# Epoch 87 --- loss:1.221, Epoch accuracy:58.07%, Validation loss:2.108, Validation accuracy:20.67%
# Epoch 88: iteration 7/8
# Epoch 88 --- loss:1.218, Epoch accuracy:58.16%, Validation loss:2.107, Validation accuracy:20.67%
# Epoch 89: iteration 7/8
# Epoch 89 --- loss:1.216, Epoch accuracy:58.60%, Validation loss:2.106, Validation accuracy:21.33%
# Epoch 90: iteration 7/8
# Epoch 90 --- loss:1.200, Epoch accuracy:60.09%, Validation loss:2.102, Validation accuracy:21.67%
# Epoch 91: iteration 7/8
# Epoch 91 --- loss:1.194, Epoch accuracy:59.82%, Validation loss:2.101, Validation accuracy:22.00%
# Epoch 92: iteration 7/8
# Epoch 92 --- loss:1.181, Epoch accuracy:61.75%, Validation loss:2.098, Validation accuracy:22.00%
# Epoch 93: iteration 7/8
# Epoch 93 --- loss:1.177, Epoch accuracy:61.40%, Validation loss:2.097, Validation accuracy:22.33%
# Epoch 94: iteration 7/8
# Epoch 94 --- loss:1.176, Epoch accuracy:61.58%, Validation loss:2.096, Validation accuracy:22.33%
# Epoch 95: iteration 7/8
# Epoch 95 --- loss:1.158, Epoch accuracy:63.33%, Validation loss:2.095, Validation accuracy:22.67%
# Epoch 96: iteration 7/8
# Epoch 96 --- loss:1.154, Epoch accuracy:62.72%, Validation loss:2.092, Validation accuracy:23.00%
# Epoch 97: iteration 7/8
# Epoch 97 --- loss:1.139, Epoch accuracy:64.65%, Validation loss:2.090, Validation accuracy:23.00%
# Epoch 98: iteration 7/8
# Epoch 98 --- loss:1.135, Epoch accuracy:63.95%, Validation loss:2.088, Validation accuracy:23.00%
# Epoch 99: iteration 7/8
# Epoch 99 --- loss:1.139, Epoch accuracy:64.21%, Validation loss:2.088, Validation accuracy:23.33%
# Epoch 100: iteration 7/8
# Epoch 100 --- loss:1.125, Epoch accuracy:65.09%, Validation loss:2.085, Validation accuracy:23.33%
# Epoch 101: iteration 7/8
# Epoch 101 --- loss:1.115, Epoch accuracy:66.67%, Validation loss:2.083, Validation accuracy:23.67%
# Epoch 102: iteration 7/8
# Epoch 102 --- loss:1.103, Epoch accuracy:67.28%, Validation loss:2.081, Validation accuracy:23.67%
# Epoch 103: iteration 7/8
# Epoch 103 --- loss:1.099, Epoch accuracy:66.93%, Validation loss:2.079, Validation accuracy:23.67%
# Epoch 104: iteration 7/8
# Epoch 104 --- loss:1.087, Epoch accuracy:67.81%, Validation loss:2.078, Validation accuracy:23.67%
# Epoch 105: iteration 7/8
# Epoch 105 --- loss:1.087, Epoch accuracy:67.72%, Validation loss:2.077, Validation accuracy:24.00%
# Epoch 106: iteration 7/8
# Epoch 106 --- loss:1.067, Epoch accuracy:68.95%, Validation loss:2.074, Validation accuracy:24.00%
# Epoch 107: iteration 7/8
# Epoch 107 --- loss:1.067, Epoch accuracy:69.30%, Validation loss:2.073, Validation accuracy:24.00%
# Epoch 108: iteration 7/8
# Epoch 108 --- loss:1.057, Epoch accuracy:70.09%, Validation loss:2.071, Validation accuracy:24.33%
# Epoch 109: iteration 7/8
# Epoch 109 --- loss:1.057, Epoch accuracy:69.56%, Validation loss:2.070, Validation accuracy:24.33%
# Epoch 110: iteration 7/8
# Epoch 110 --- loss:1.050, Epoch accuracy:70.53%, Validation loss:2.069, Validation accuracy:24.67%
# Epoch 111: iteration 7/8
# Epoch 111 --- loss:1.033, Epoch accuracy:72.28%, Validation loss:2.066, Validation accuracy:24.67%
# Epoch 112: iteration 7/8
# Epoch 112 --- loss:1.024, Epoch accuracy:72.28%, Validation loss:2.065, Validation accuracy:25.00%
# Epoch 113: iteration 7/8
# Epoch 113 --- loss:1.008, Epoch accuracy:72.98%, Validation loss:2.063, Validation accuracy:25.00%
# Epoch 114: iteration 7/8
# Epoch 114 --- loss:1.012, Epoch accuracy:72.98%, Validation loss:2.062, Validation accuracy:25.33%
# Epoch 115: iteration 7/8
# Epoch 115 --- loss:0.998, Epoch accuracy:73.51%, Validation loss:2.060, Validation accuracy:25.00%
# Epoch 116: iteration 7/8
# Epoch 116 --- loss:1.001, Epoch accuracy:74.12%, Validation loss:2.059, Validation accuracy:26.00%
# Epoch 117: iteration 7/8
# Epoch 117 --- loss:0.990, Epoch accuracy:74.91%, Validation loss:2.058, Validation accuracy:26.33%
# Epoch 118: iteration 7/8
# Epoch 118 --- loss:0.991, Epoch accuracy:74.21%, Validation loss:2.056, Validation accuracy:26.33%
# Epoch 119: iteration 7/8
# Epoch 119 --- loss:0.977, Epoch accuracy:75.35%, Validation loss:2.055, Validation accuracy:26.33%
# Epoch 120: iteration 7/8
# Epoch 120 --- loss:0.971, Epoch accuracy:75.26%, Validation loss:2.053, Validation accuracy:26.33%
# Epoch 121: iteration 7/8
# Epoch 121 --- loss:0.960, Epoch accuracy:76.58%, Validation loss:2.052, Validation accuracy:26.33%
# Epoch 122: iteration 7/8
# Epoch 122 --- loss:0.951, Epoch accuracy:76.49%, Validation loss:2.050, Validation accuracy:26.33%
# Epoch 123: iteration 7/8
# Epoch 123 --- loss:0.954, Epoch accuracy:76.93%, Validation loss:2.049, Validation accuracy:26.33%
# Epoch 124: iteration 7/8
# Epoch 124 --- loss:0.940, Epoch accuracy:78.25%, Validation loss:2.048, Validation accuracy:26.33%
# Epoch 125: iteration 7/8
# Epoch 125 --- loss:0.935, Epoch accuracy:77.98%, Validation loss:2.046, Validation accuracy:26.67%
# Epoch 126: iteration 7/8
# Epoch 126 --- loss:0.930, Epoch accuracy:78.51%, Validation loss:2.046, Validation accuracy:26.67%
# Epoch 127: iteration 7/8
# Epoch 127 --- loss:0.920, Epoch accuracy:78.86%, Validation loss:2.045, Validation accuracy:27.00%
# Epoch 128: iteration 7/8
# Epoch 128 --- loss:0.913, Epoch accuracy:79.12%, Validation loss:2.042, Validation accuracy:27.33%
# Epoch 129: iteration 7/8
# Epoch 129 --- loss:0.912, Epoch accuracy:79.39%, Validation loss:2.041, Validation accuracy:27.33%
# Epoch 130: iteration 7/8
# Epoch 130 --- loss:0.898, Epoch accuracy:80.88%, Validation loss:2.040, Validation accuracy:27.67%
# Epoch 131: iteration 7/8
# Epoch 131 --- loss:0.886, Epoch accuracy:80.96%, Validation loss:2.041, Validation accuracy:27.33%
# Epoch 132: iteration 7/8
# Epoch 132 --- loss:0.884, Epoch accuracy:80.88%, Validation loss:2.038, Validation accuracy:28.00%
# Epoch 133: iteration 7/8
# Epoch 133 --- loss:0.877, Epoch accuracy:82.11%, Validation loss:2.037, Validation accuracy:28.00%
# Epoch 134: iteration 7/8
# Epoch 134 --- loss:0.870, Epoch accuracy:82.46%, Validation loss:2.035, Validation accuracy:28.00%
# Epoch 135: iteration 7/8
# Epoch 135 --- loss:0.860, Epoch accuracy:82.19%, Validation loss:2.032, Validation accuracy:28.00%
# Epoch 136: iteration 7/8
# Epoch 136 --- loss:0.846, Epoch accuracy:82.63%, Validation loss:2.032, Validation accuracy:27.67%
# Epoch 137: iteration 7/8
# Epoch 137 --- loss:0.856, Epoch accuracy:83.25%, Validation loss:2.031, Validation accuracy:28.00%
# Epoch 138: iteration 7/8
# Epoch 138 --- loss:0.844, Epoch accuracy:83.68%, Validation loss:2.029, Validation accuracy:28.00%
# Epoch 139: iteration 7/8
# Epoch 139 --- loss:0.840, Epoch accuracy:83.16%, Validation loss:2.027, Validation accuracy:28.00%
# Epoch 140: iteration 7/8
# Epoch 140 --- loss:0.826, Epoch accuracy:83.51%, Validation loss:2.027, Validation accuracy:27.67%
# Epoch 141: iteration 7/8
# Epoch 141 --- loss:0.819, Epoch accuracy:83.86%, Validation loss:2.026, Validation accuracy:28.00%
# Epoch 142: iteration 7/8
# Epoch 142 --- loss:0.815, Epoch accuracy:84.30%, Validation loss:2.025, Validation accuracy:28.00%
# Epoch 143: iteration 7/8
# Epoch 143 --- loss:0.801, Epoch accuracy:84.74%, Validation loss:2.024, Validation accuracy:28.67%
# Epoch 144: iteration 7/8
# Epoch 144 --- loss:0.797, Epoch accuracy:85.53%, Validation loss:2.023, Validation accuracy:29.00%
# Epoch 145: iteration 7/8
# Epoch 145 --- loss:0.798, Epoch accuracy:85.09%, Validation loss:2.023, Validation accuracy:28.67%
# Epoch 146: iteration 7/8
# Epoch 146 --- loss:0.792, Epoch accuracy:85.18%, Validation loss:2.020, Validation accuracy:28.67%
# Epoch 147: iteration 7/8
# Epoch 147 --- loss:0.787, Epoch accuracy:86.05%, Validation loss:2.020, Validation accuracy:28.33%
# Epoch 148: iteration 7/8
# Epoch 148 --- loss:0.780, Epoch accuracy:85.35%, Validation loss:2.019, Validation accuracy:29.00%
# Epoch 149: iteration 7/8
# Epoch 149 --- loss:0.771, Epoch accuracy:86.40%, Validation loss:2.018, Validation accuracy:28.67%
# Epoch 150: iteration 7/8
# Epoch 150 --- loss:0.762, Epoch accuracy:86.49%, Validation loss:2.016, Validation accuracy:28.33%
# Epoch 151: iteration 7/8
# Epoch 151 --- loss:0.750, Epoch accuracy:86.67%, Validation loss:2.015, Validation accuracy:28.33%
# Epoch 152: iteration 7/8
# Epoch 152 --- loss:0.750, Epoch accuracy:86.67%, Validation loss:2.015, Validation accuracy:28.67%
# Epoch 153: iteration 7/8
# Epoch 153 --- loss:0.740, Epoch accuracy:86.58%, Validation loss:2.013, Validation accuracy:28.67%
# Epoch 154: iteration 7/8
# Epoch 154 --- loss:0.745, Epoch accuracy:86.67%, Validation loss:2.014, Validation accuracy:28.67%
# Epoch 155: iteration 7/8
# Epoch 155 --- loss:0.729, Epoch accuracy:86.93%, Validation loss:2.012, Validation accuracy:28.33%
# Epoch 156: iteration 7/8
# Epoch 156 --- loss:0.727, Epoch accuracy:86.93%, Validation loss:2.009, Validation accuracy:28.67%
# Epoch 157: iteration 7/8
# Epoch 157 --- loss:0.718, Epoch accuracy:87.19%, Validation loss:2.008, Validation accuracy:28.67%
# Epoch 158: iteration 7/8
# Epoch 158 --- loss:0.711, Epoch accuracy:87.63%, Validation loss:2.007, Validation accuracy:28.33%
# Epoch 159: iteration 7/8
# Epoch 159 --- loss:0.705, Epoch accuracy:87.37%, Validation loss:2.006, Validation accuracy:28.00%
# Epoch 160: iteration 7/8
# Epoch 160 --- loss:0.704, Epoch accuracy:87.63%, Validation loss:2.006, Validation accuracy:28.00%
# Epoch 161: iteration 7/8
# Epoch 161 --- loss:0.696, Epoch accuracy:87.46%, Validation loss:2.007, Validation accuracy:28.33%
# Epoch 162: iteration 7/8
# Epoch 162 --- loss:0.696, Epoch accuracy:87.81%, Validation loss:2.004, Validation accuracy:28.00%
# Epoch 163: iteration 7/8
# Epoch 163 --- loss:0.683, Epoch accuracy:88.16%, Validation loss:2.004, Validation accuracy:28.67%
# Epoch 164: iteration 7/8
# Epoch 164 --- loss:0.674, Epoch accuracy:87.89%, Validation loss:2.003, Validation accuracy:28.67%
# Epoch 165: iteration 7/8
# Epoch 165 --- loss:0.677, Epoch accuracy:88.07%, Validation loss:2.002, Validation accuracy:28.33%
# Epoch 166: iteration 7/8
# Epoch 166 --- loss:0.661, Epoch accuracy:88.33%, Validation loss:2.001, Validation accuracy:28.33%
# Epoch 167: iteration 7/8
# Epoch 167 --- loss:0.660, Epoch accuracy:88.60%, Validation loss:2.000, Validation accuracy:28.67%
# Epoch 168: iteration 7/8
# Epoch 168 --- loss:0.657, Epoch accuracy:88.51%, Validation loss:2.000, Validation accuracy:28.67%
# Epoch 169: iteration 7/8
# Epoch 169 --- loss:0.649, Epoch accuracy:88.95%, Validation loss:1.997, Validation accuracy:28.33%
# Epoch 170: iteration 7/8
# Epoch 170 --- loss:0.640, Epoch accuracy:88.95%, Validation loss:1.996, Validation accuracy:28.33%
# Epoch 171: iteration 7/8
# Epoch 171 --- loss:0.637, Epoch accuracy:88.60%, Validation loss:1.997, Validation accuracy:28.67%
# Epoch 172: iteration 7/8
# Epoch 172 --- loss:0.635, Epoch accuracy:88.86%, Validation loss:1.995, Validation accuracy:28.33%
# Epoch 173: iteration 7/8
# Epoch 173 --- loss:0.631, Epoch accuracy:88.60%, Validation loss:1.994, Validation accuracy:28.33%
# Epoch 174: iteration 7/8
# Epoch 174 --- loss:0.619, Epoch accuracy:89.04%, Validation loss:1.995, Validation accuracy:28.67%
# Epoch 175: iteration 7/8
# Epoch 175 --- loss:0.617, Epoch accuracy:89.04%, Validation loss:1.994, Validation accuracy:29.00%
# Epoch 176: iteration 7/8
# Epoch 176 --- loss:0.610, Epoch accuracy:89.21%, Validation loss:1.992, Validation accuracy:29.33%
# Epoch 177: iteration 7/8
# Epoch 177 --- loss:0.606, Epoch accuracy:89.04%, Validation loss:1.989, Validation accuracy:29.67%
# Epoch 178: iteration 7/8
# Epoch 178 --- loss:0.601, Epoch accuracy:89.12%, Validation loss:1.989, Validation accuracy:29.33%
# Epoch 179: iteration 7/8
# Epoch 179 --- loss:0.592, Epoch accuracy:89.12%, Validation loss:1.988, Validation accuracy:29.00%
# Epoch 180: iteration 7/8
# Epoch 180 --- loss:0.591, Epoch accuracy:89.39%, Validation loss:1.988, Validation accuracy:29.33%
# Epoch 181: iteration 7/8
# Epoch 181 --- loss:0.584, Epoch accuracy:89.30%, Validation loss:1.986, Validation accuracy:29.00%
# Epoch 182: iteration 7/8
# Epoch 182 --- loss:0.579, Epoch accuracy:89.39%, Validation loss:1.985, Validation accuracy:29.00%
# Epoch 183: iteration 7/8
# Epoch 183 --- loss:0.575, Epoch accuracy:89.04%, Validation loss:1.985, Validation accuracy:29.00%
# Epoch 184: iteration 7/8
# Epoch 184 --- loss:0.567, Epoch accuracy:89.39%, Validation loss:1.985, Validation accuracy:29.00%
# Epoch 185: iteration 7/8
# Epoch 185 --- loss:0.563, Epoch accuracy:89.56%, Validation loss:1.985, Validation accuracy:28.67%
# Epoch 186: iteration 7/8
# Epoch 186 --- loss:0.560, Epoch accuracy:89.56%, Validation loss:1.985, Validation accuracy:29.33%
# Epoch 187: iteration 7/8
# Epoch 187 --- loss:0.553, Epoch accuracy:89.04%, Validation loss:1.983, Validation accuracy:29.33%
# Epoch 188: iteration 7/8
# Epoch 188 --- loss:0.555, Epoch accuracy:89.47%, Validation loss:1.983, Validation accuracy:29.33%
# Epoch 189: iteration 7/8
# Epoch 189 --- loss:0.542, Epoch accuracy:89.47%, Validation loss:1.982, Validation accuracy:29.67%
# Epoch 190: iteration 7/8
# Epoch 190 --- loss:0.543, Epoch accuracy:89.56%, Validation loss:1.981, Validation accuracy:29.67%
# Epoch 191: iteration 7/8
# Epoch 191 --- loss:0.539, Epoch accuracy:89.39%, Validation loss:1.980, Validation accuracy:29.67%
# Epoch 192: iteration 7/8
# Epoch 192 --- loss:0.527, Epoch accuracy:89.39%, Validation loss:1.980, Validation accuracy:29.67%
# Epoch 193: iteration 7/8
# Epoch 193 --- loss:0.528, Epoch accuracy:89.39%, Validation loss:1.981, Validation accuracy:29.67%
# Epoch 194: iteration 7/8
# Epoch 194 --- loss:0.523, Epoch accuracy:89.65%, Validation loss:1.980, Validation accuracy:29.67%
# Epoch 195: iteration 7/8
# Epoch 195 --- loss:0.522, Epoch accuracy:89.65%, Validation loss:1.979, Validation accuracy:29.67%
# Epoch 196: iteration 7/8
# Epoch 196 --- loss:0.512, Epoch accuracy:89.47%, Validation loss:1.979, Validation accuracy:29.67%
# Epoch 197: iteration 7/8
# Epoch 197 --- loss:0.510, Epoch accuracy:89.65%, Validation loss:1.978, Validation accuracy:30.00%
# Epoch 198: iteration 7/8
# Epoch 198 --- loss:0.500, Epoch accuracy:89.65%, Validation loss:1.977, Validation accuracy:29.67%
# Epoch 199: iteration 7/8
# Epoch 199 --- loss:0.502, Epoch accuracy:89.39%, Validation loss:1.976, Validation accuracy:30.00%
# Epoch 200: iteration 7/8
# Epoch 200 --- loss:0.495, Epoch accuracy:89.65%, Validation loss:1.975, Validation accuracy:29.67%
# Epoch 201: iteration 7/8
# Epoch 201 --- loss:0.499, Epoch accuracy:89.74%, Validation loss:1.977, Validation accuracy:29.67%
# Epoch 202: iteration 7/8
# Epoch 202 --- loss:0.486, Epoch accuracy:89.74%, Validation loss:1.976, Validation accuracy:29.67%
# Epoch 203: iteration 7/8
# Epoch 203 --- loss:0.474, Epoch accuracy:89.65%, Validation loss:1.974, Validation accuracy:30.00%
# Epoch 204: iteration 7/8
# Epoch 204 --- loss:0.477, Epoch accuracy:89.65%, Validation loss:1.973, Validation accuracy:29.67%
# Epoch 205: iteration 7/8
# Epoch 205 --- loss:0.471, Epoch accuracy:89.74%, Validation loss:1.972, Validation accuracy:29.67%
# Epoch 206: iteration 7/8
# Epoch 206 --- loss:0.470, Epoch accuracy:89.39%, Validation loss:1.973, Validation accuracy:29.67%
# Epoch 207: iteration 7/8
# Epoch 207 --- loss:0.460, Epoch accuracy:89.65%, Validation loss:1.972, Validation accuracy:30.00%
# Epoch 208: iteration 7/8
# Epoch 208 --- loss:0.459, Epoch accuracy:89.82%, Validation loss:1.971, Validation accuracy:30.00%
# Epoch 209: iteration 7/8
# Epoch 209 --- loss:0.459, Epoch accuracy:89.74%, Validation loss:1.972, Validation accuracy:30.00%
# Epoch 210: iteration 7/8
# Epoch 210 --- loss:0.457, Epoch accuracy:89.74%, Validation loss:1.972, Validation accuracy:30.33%
# Epoch 211: iteration 7/8
# Epoch 211 --- loss:0.453, Epoch accuracy:89.74%, Validation loss:1.971, Validation accuracy:30.00%
# Epoch 212: iteration 7/8
# Epoch 212 --- loss:0.446, Epoch accuracy:89.74%, Validation loss:1.970, Validation accuracy:29.67%
# Epoch 213: iteration 7/8
# Epoch 213 --- loss:0.437, Epoch accuracy:89.82%, Validation loss:1.971, Validation accuracy:30.00%
# Epoch 214: iteration 7/8
# Epoch 214 --- loss:0.448, Epoch accuracy:89.74%, Validation loss:1.970, Validation accuracy:30.00%
# Epoch 215: iteration 7/8
# Epoch 215 --- loss:0.433, Epoch accuracy:89.82%, Validation loss:1.969, Validation accuracy:30.33%
# Epoch 216: iteration 7/8
# Epoch 216 --- loss:0.426, Epoch accuracy:89.74%, Validation loss:1.970, Validation accuracy:30.00%
# Epoch 217: iteration 7/8
# Epoch 217 --- loss:0.423, Epoch accuracy:89.74%, Validation loss:1.970, Validation accuracy:29.67%
# Epoch 218: iteration 7/8
# Epoch 218 --- loss:0.424, Epoch accuracy:89.82%, Validation loss:1.967, Validation accuracy:30.33%
# Epoch 219: iteration 7/8
# Epoch 219 --- loss:0.417, Epoch accuracy:89.82%, Validation loss:1.966, Validation accuracy:30.33%
# Epoch 220: iteration 7/8
# Epoch 220 --- loss:0.411, Epoch accuracy:89.82%, Validation loss:1.967, Validation accuracy:30.00%
# Epoch 221: iteration 7/8
# Epoch 221 --- loss:0.409, Epoch accuracy:89.74%, Validation loss:1.967, Validation accuracy:30.67%
# Epoch 222: iteration 7/8
# Epoch 222 --- loss:0.405, Epoch accuracy:89.74%, Validation loss:1.964, Validation accuracy:30.33%
# Epoch 223: iteration 7/8
# Epoch 223 --- loss:0.406, Epoch accuracy:89.74%, Validation loss:1.964, Validation accuracy:30.67%
# Epoch 224: iteration 7/8
# Epoch 224 --- loss:0.403, Epoch accuracy:89.74%, Validation loss:1.964, Validation accuracy:30.67%
# Epoch 225: iteration 7/8
# Epoch 225 --- loss:0.395, Epoch accuracy:89.74%, Validation loss:1.964, Validation accuracy:30.67%
# Epoch 226: iteration 7/8
# Epoch 226 --- loss:0.388, Epoch accuracy:89.82%, Validation loss:1.964, Validation accuracy:31.00%
# Epoch 227: iteration 7/8
# Epoch 227 --- loss:0.390, Epoch accuracy:89.82%, Validation loss:1.964, Validation accuracy:30.00%
# Epoch 228: iteration 7/8
# Epoch 228 --- loss:0.384, Epoch accuracy:89.82%, Validation loss:1.963, Validation accuracy:30.67%
# Epoch 229: iteration 7/8
# Epoch 229 --- loss:0.379, Epoch accuracy:89.82%, Validation loss:1.961, Validation accuracy:30.33%
# Epoch 230: iteration 7/8
# Epoch 230 --- loss:0.381, Epoch accuracy:89.74%, Validation loss:1.961, Validation accuracy:30.67%
# Epoch 231: iteration 7/8
# Epoch 231 --- loss:0.378, Epoch accuracy:89.74%, Validation loss:1.960, Validation accuracy:31.00%
# Epoch 232: iteration 7/8
# Epoch 232 --- loss:0.371, Epoch accuracy:89.82%, Validation loss:1.960, Validation accuracy:30.67%
# Epoch 233: iteration 7/8
# Epoch 233 --- loss:0.369, Epoch accuracy:89.82%, Validation loss:1.961, Validation accuracy:31.33%
# Epoch 234: iteration 7/8
# Epoch 234 --- loss:0.369, Epoch accuracy:89.82%, Validation loss:1.961, Validation accuracy:31.00%
# Epoch 235: iteration 7/8
# Epoch 235 --- loss:0.367, Epoch accuracy:89.82%, Validation loss:1.960, Validation accuracy:31.67%
# Epoch 236: iteration 7/8
# Epoch 236 --- loss:0.367, Epoch accuracy:89.82%, Validation loss:1.959, Validation accuracy:30.33%
# Epoch 237: iteration 7/8
# Epoch 237 --- loss:0.358, Epoch accuracy:89.82%, Validation loss:1.959, Validation accuracy:30.33%
# Epoch 238: iteration 7/8
# Epoch 238 --- loss:0.356, Epoch accuracy:89.82%, Validation loss:1.960, Validation accuracy:31.33%
# Epoch 239: iteration 7/8
# Epoch 239 --- loss:0.355, Epoch accuracy:89.74%, Validation loss:1.960, Validation accuracy:31.33%
# Epoch 240: iteration 7/8
# Epoch 240 --- loss:0.351, Epoch accuracy:89.82%, Validation loss:1.959, Validation accuracy:30.67%
# Epoch 241: iteration 7/8
# Epoch 241 --- loss:0.346, Epoch accuracy:89.82%, Validation loss:1.959, Validation accuracy:31.00%
# Epoch 242: iteration 7/8
# Epoch 242 --- loss:0.339, Epoch accuracy:89.82%, Validation loss:1.958, Validation accuracy:30.67%
# Epoch 243: iteration 7/8
# Epoch 243 --- loss:0.340, Epoch accuracy:89.82%, Validation loss:1.959, Validation accuracy:31.00%
# Epoch 244: iteration 7/8
# Epoch 244 --- loss:0.338, Epoch accuracy:89.82%, Validation loss:1.958, Validation accuracy:31.00%
# Epoch 245: iteration 7/8
# Epoch 245 --- loss:0.329, Epoch accuracy:89.82%, Validation loss:1.957, Validation accuracy:31.33%
# Epoch 246: iteration 7/8
# Epoch 246 --- loss:0.328, Epoch accuracy:89.82%, Validation loss:1.958, Validation accuracy:31.33%
# Epoch 247: iteration 7/8
# Epoch 247 --- loss:0.330, Epoch accuracy:89.82%, Validation loss:1.956, Validation accuracy:31.00%
# Epoch 248: iteration 7/8
# Epoch 248 --- loss:0.326, Epoch accuracy:89.82%, Validation loss:1.957, Validation accuracy:30.67%
# Epoch 249: iteration 7/8
# Epoch 249 --- loss:0.320, Epoch accuracy:89.82%, Validation loss:1.956, Validation accuracy:30.67%
# Epoch 250: iteration 7/8
# Epoch 250 --- loss:0.320, Epoch accuracy:89.82%, Validation loss:1.956, Validation accuracy:31.33%
# Epoch 251: iteration 7/8
# Epoch 251 --- loss:0.319, Epoch accuracy:89.74%, Validation loss:1.955, Validation accuracy:31.00%
# Epoch 252: iteration 7/8
# Epoch 252 --- loss:0.314, Epoch accuracy:89.82%, Validation loss:1.955, Validation accuracy:31.00%
# Epoch 253: iteration 7/8
# Epoch 253 --- loss:0.313, Epoch accuracy:89.82%, Validation loss:1.955, Validation accuracy:30.67%
# Epoch 254: iteration 7/8
# Epoch 254 --- loss:0.309, Epoch accuracy:89.82%, Validation loss:1.954, Validation accuracy:30.67%
# Epoch 255: iteration 7/8
# Epoch 255 --- loss:0.303, Epoch accuracy:89.82%, Validation loss:1.954, Validation accuracy:30.67%
# Epoch 256: iteration 7/8
# Epoch 256 --- loss:0.308, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.67%
# Epoch 257: iteration 7/8
# Epoch 257 --- loss:0.305, Epoch accuracy:89.82%, Validation loss:1.954, Validation accuracy:30.33%
# Epoch 258: iteration 7/8
# Epoch 258 --- loss:0.297, Epoch accuracy:89.82%, Validation loss:1.954, Validation accuracy:30.33%
# Epoch 259: iteration 7/8
# Epoch 259 --- loss:0.301, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.00%
# Epoch 260: iteration 7/8
# Epoch 260 --- loss:0.293, Epoch accuracy:89.82%, Validation loss:1.952, Validation accuracy:30.33%
# Epoch 261: iteration 7/8
# Epoch 261 --- loss:0.291, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.33%
# Epoch 262: iteration 7/8
# Epoch 262 --- loss:0.287, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.33%
# Epoch 263: iteration 7/8
# Epoch 263 --- loss:0.289, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.33%
# Epoch 264: iteration 7/8
# Epoch 264 --- loss:0.286, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.33%
# Epoch 265: iteration 7/8
# Epoch 265 --- loss:0.281, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.67%
# Epoch 266: iteration 7/8
# Epoch 266 --- loss:0.284, Epoch accuracy:89.82%, Validation loss:1.954, Validation accuracy:31.00%
# Epoch 267: iteration 7/8
# Epoch 267 --- loss:0.283, Epoch accuracy:89.82%, Validation loss:1.952, Validation accuracy:30.67%
# Epoch 268: iteration 7/8
# Epoch 268 --- loss:0.279, Epoch accuracy:89.82%, Validation loss:1.952, Validation accuracy:31.00%
# Epoch 269: iteration 7/8
# Epoch 269 --- loss:0.274, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:30.67%
# Epoch 270: iteration 7/8
# Epoch 270 --- loss:0.270, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.33%
# Epoch 271: iteration 7/8
# Epoch 271 --- loss:0.273, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:30.67%
# Epoch 272: iteration 7/8
# Epoch 272 --- loss:0.264, Epoch accuracy:89.82%, Validation loss:1.953, Validation accuracy:31.00%
# Epoch 273: iteration 7/8
# Epoch 273 --- loss:0.263, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:30.67%
# Epoch 274: iteration 7/8
# Epoch 274 --- loss:0.260, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:31.00%
# Epoch 275: iteration 7/8
# Epoch 275 --- loss:0.260, Epoch accuracy:89.82%, Validation loss:1.952, Validation accuracy:30.67%
# Epoch 276: iteration 7/8
# Epoch 276 --- loss:0.257, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:30.33%
# Epoch 277: iteration 7/8
# Epoch 277 --- loss:0.256, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.33%
# Epoch 278: iteration 7/8
# Epoch 278 --- loss:0.256, Epoch accuracy:89.82%, Validation loss:1.952, Validation accuracy:30.67%
# Epoch 279: iteration 7/8
# Epoch 279 --- loss:0.250, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:31.33%
# Epoch 280: iteration 7/8
# Epoch 280 --- loss:0.250, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:30.67%
# Epoch 281: iteration 7/8
# Epoch 281 --- loss:0.253, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:30.67%
# Epoch 282: iteration 7/8
# Epoch 282 --- loss:0.251, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:31.00%
# Epoch 283: iteration 7/8
# Epoch 283 --- loss:0.247, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:30.33%
# Epoch 284: iteration 7/8
# Epoch 284 --- loss:0.240, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.00%
# Epoch 285: iteration 7/8
# Epoch 285 --- loss:0.240, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:30.67%
# Epoch 286: iteration 7/8
# Epoch 286 --- loss:0.244, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.33%
# Epoch 287: iteration 7/8
# Epoch 287 --- loss:0.237, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:30.00%
# Epoch 288: iteration 7/8
# Epoch 288 --- loss:0.234, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.67%
# Epoch 289: iteration 7/8
# Epoch 289 --- loss:0.232, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.67%
# Epoch 290: iteration 7/8
# Epoch 290 --- loss:0.232, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:30.67%
# Epoch 291: iteration 7/8
# Epoch 291 --- loss:0.232, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.67%
# Epoch 292: iteration 7/8
# Epoch 292 --- loss:0.227, Epoch accuracy:89.82%, Validation loss:1.951, Validation accuracy:30.67%
# Epoch 293: iteration 7/8
# Epoch 293 --- loss:0.228, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:31.00%
# Epoch 294: iteration 7/8
# Epoch 294 --- loss:0.224, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.67%
# Epoch 295: iteration 7/8
# Epoch 295 --- loss:0.225, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.67%
# Epoch 296: iteration 7/8
# Epoch 296 --- loss:0.221, Epoch accuracy:89.82%, Validation loss:1.952, Validation accuracy:31.33%
# Epoch 297: iteration 7/8
# Epoch 297 --- loss:0.220, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:31.67%
# Epoch 298: iteration 7/8
# Epoch 298 --- loss:0.214, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:31.00%
# Epoch 299: iteration 7/8
# Epoch 299 --- loss:0.217, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:31.00%
# Epoch 300: iteration 7/8
# Epoch 300 --- loss:0.216, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 301: iteration 7/8
# Epoch 301 --- loss:0.210, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:30.67%
# Epoch 302: iteration 7/8
# Epoch 302 --- loss:0.209, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:30.67%
# Epoch 303: iteration 7/8
# Epoch 303 --- loss:0.210, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:30.67%
# Epoch 304: iteration 7/8
# Epoch 304 --- loss:0.213, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:30.33%
# Epoch 305: iteration 7/8
# Epoch 305 --- loss:0.205, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:30.67%
# Epoch 306: iteration 7/8
# Epoch 306 --- loss:0.204, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 307: iteration 7/8
# Epoch 307 --- loss:0.204, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.33%
# Epoch 308: iteration 7/8
# Epoch 308 --- loss:0.202, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:30.67%
# Epoch 309: iteration 7/8
# Epoch 309 --- loss:0.204, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:30.33%
# Epoch 310: iteration 7/8
# Epoch 310 --- loss:0.197, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:31.33%
# Epoch 311: iteration 7/8
# Epoch 311 --- loss:0.199, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:30.67%
# Epoch 312: iteration 7/8
# Epoch 312 --- loss:0.196, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 313: iteration 7/8
# Epoch 313 --- loss:0.196, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 314: iteration 7/8
# Epoch 314 --- loss:0.192, Epoch accuracy:89.82%, Validation loss:1.950, Validation accuracy:30.67%
# Epoch 315: iteration 7/8
# Epoch 315 --- loss:0.193, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:30.67%
# Epoch 316: iteration 7/8
# Epoch 316 --- loss:0.194, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.00%
# Epoch 317: iteration 7/8
# Epoch 317 --- loss:0.191, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:31.33%
# Epoch 318: iteration 7/8
# Epoch 318 --- loss:0.188, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:30.67%
# Epoch 319: iteration 7/8
# Epoch 319 --- loss:0.189, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.00%
# Epoch 320: iteration 7/8
# Epoch 320 --- loss:0.191, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.33%
# Epoch 321: iteration 7/8
# Epoch 321 --- loss:0.182, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.33%
# Epoch 322: iteration 7/8
# Epoch 322 --- loss:0.182, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:30.67%
# Epoch 323: iteration 7/8
# Epoch 323 --- loss:0.182, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.33%
# Epoch 324: iteration 7/8
# Epoch 324 --- loss:0.178, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.00%
# Epoch 325: iteration 7/8
# Epoch 325 --- loss:0.181, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.33%
# Epoch 326: iteration 7/8
# Epoch 326 --- loss:0.177, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:31.00%
# Epoch 327: iteration 7/8
# Epoch 327 --- loss:0.176, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:31.67%
# Epoch 328: iteration 7/8
# Epoch 328 --- loss:0.178, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.33%
# Epoch 329: iteration 7/8
# Epoch 329 --- loss:0.174, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 330: iteration 7/8
# Epoch 330 --- loss:0.172, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:31.00%
# Epoch 331: iteration 7/8
# Epoch 331 --- loss:0.170, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 332: iteration 7/8
# Epoch 332 --- loss:0.171, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:30.67%
# Epoch 333: iteration 7/8
# Epoch 333 --- loss:0.172, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:30.67%
# Epoch 334: iteration 7/8
# Epoch 334 --- loss:0.169, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.00%
# Epoch 335: iteration 7/8
# Epoch 335 --- loss:0.167, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 336: iteration 7/8
# Epoch 336 --- loss:0.169, Epoch accuracy:89.82%, Validation loss:1.949, Validation accuracy:31.33%
# Epoch 337: iteration 7/8
# Epoch 337 --- loss:0.162, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:31.33%
# Epoch 338: iteration 7/8
# Epoch 338 --- loss:0.164, Epoch accuracy:89.82%, Validation loss:1.948, Validation accuracy:30.67%
# Epoch 339: iteration 7/8
# Epoch 339 --- loss:0.164, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 340: iteration 7/8
# Epoch 340 --- loss:0.161, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:30.67%
# Epoch 341: iteration 7/8
# Epoch 341 --- loss:0.162, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:30.67%
# Epoch 342: iteration 7/8
# Epoch 342 --- loss:0.161, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:30.67%
# Epoch 343: iteration 7/8
# Epoch 343 --- loss:0.162, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 344: iteration 7/8
# Epoch 344 --- loss:0.157, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:30.67%
# Epoch 345: iteration 7/8
# Epoch 345 --- loss:0.157, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:30.67%
# Epoch 346: iteration 7/8
# Epoch 346 --- loss:0.157, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 347: iteration 7/8
# Epoch 347 --- loss:0.157, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:30.67%
# Epoch 348: iteration 7/8
# Epoch 348 --- loss:0.154, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 349: iteration 7/8
# Epoch 349 --- loss:0.154, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.33%
# Epoch 350: iteration 7/8
# Epoch 350 --- loss:0.152, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 351: iteration 7/8
# Epoch 351 --- loss:0.151, Epoch accuracy:89.82%, Validation loss:1.943, Validation accuracy:30.33%
# Epoch 352: iteration 7/8
# Epoch 352 --- loss:0.149, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:30.67%
# Epoch 353: iteration 7/8
# Epoch 353 --- loss:0.150, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:30.67%
# Epoch 354: iteration 7/8
# Epoch 354 --- loss:0.149, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:30.67%
# Epoch 355: iteration 7/8
# Epoch 355 --- loss:0.146, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.33%
# Epoch 356: iteration 7/8
# Epoch 356 --- loss:0.149, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 357: iteration 7/8
# Epoch 357 --- loss:0.145, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:30.67%
# Epoch 358: iteration 7/8
# Epoch 358 --- loss:0.144, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 359: iteration 7/8
# Epoch 359 --- loss:0.144, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:31.33%
# Epoch 360: iteration 7/8
# Epoch 360 --- loss:0.141, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 361: iteration 7/8
# Epoch 361 --- loss:0.144, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:30.67%
# Epoch 362: iteration 7/8
# Epoch 362 --- loss:0.140, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 363: iteration 7/8
# Epoch 363 --- loss:0.141, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:30.67%
# Epoch 364: iteration 7/8
# Epoch 364 --- loss:0.141, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.33%
# Epoch 365: iteration 7/8
# Epoch 365 --- loss:0.139, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 366: iteration 7/8
# Epoch 366 --- loss:0.139, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:30.33%
# Epoch 367: iteration 7/8
# Epoch 367 --- loss:0.136, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.33%
# Epoch 368: iteration 7/8
# Epoch 368 --- loss:0.138, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.33%
# Epoch 369: iteration 7/8
# Epoch 369 --- loss:0.135, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:31.33%
# Epoch 370: iteration 7/8
# Epoch 370 --- loss:0.135, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:31.33%
# Epoch 371: iteration 7/8
# Epoch 371 --- loss:0.134, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:30.67%
# Epoch 372: iteration 7/8
# Epoch 372 --- loss:0.131, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 373: iteration 7/8
# Epoch 373 --- loss:0.134, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 374: iteration 7/8
# Epoch 374 --- loss:0.132, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.00%
# Epoch 375: iteration 7/8
# Epoch 375 --- loss:0.131, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:31.00%
# Epoch 376: iteration 7/8
# Epoch 376 --- loss:0.127, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 377: iteration 7/8
# Epoch 377 --- loss:0.129, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:31.00%
# Epoch 378: iteration 7/8
# Epoch 378 --- loss:0.129, Epoch accuracy:89.82%, Validation loss:1.943, Validation accuracy:31.33%
# Epoch 379: iteration 7/8
# Epoch 379 --- loss:0.126, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.33%
# Epoch 380: iteration 7/8
# Epoch 380 --- loss:0.129, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.33%
# Epoch 381: iteration 7/8
# Epoch 381 --- loss:0.127, Epoch accuracy:89.82%, Validation loss:1.946, Validation accuracy:31.33%
# Epoch 382: iteration 7/8
# Epoch 382 --- loss:0.125, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.33%
# Epoch 383: iteration 7/8
# Epoch 383 --- loss:0.126, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:31.00%
# Epoch 384: iteration 7/8
# Epoch 384 --- loss:0.123, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.00%
# Epoch 385: iteration 7/8
# Epoch 385 --- loss:0.124, Epoch accuracy:89.82%, Validation loss:1.947, Validation accuracy:31.00%
# Epoch 386: iteration 7/8
# Epoch 386 --- loss:0.122, Epoch accuracy:89.82%, Validation loss:1.944, Validation accuracy:31.00%
# Epoch 387: iteration 7/8
# Epoch 387 --- loss:0.121, Epoch accuracy:89.82%, Validation loss:1.945, Validation accuracy:31.33%
# Epoch 388: iteration 7/8
# ...
# Epoch 119 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 120: iteration 7/8
# Epoch 120 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 121: iteration 7/8
# Epoch 121 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 122: iteration 7/8
# Epoch 122 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 123: iteration 7/8
# Epoch 123 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 124: iteration 7/8
# Epoch 124 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 125: iteration 7/8
# Epoch 125 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 126: iteration 7/8
# Epoch 126 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 127: iteration 7/8
# Epoch 127 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 128: iteration 7/8
# Epoch 128 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 129: iteration 7/8
# Epoch 129 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 130: iteration 7/8
# Epoch 130 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 131: iteration 7/8
# Epoch 131 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 132: iteration 7/8
# Epoch 132 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 133: iteration 7/8
# Epoch 133 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 134: iteration 7/8
# Epoch 134 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 135: iteration 7/8
# Epoch 135 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 136: iteration 7/8
# Epoch 136 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 137: iteration 7/8
# Epoch 137 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 138: iteration 7/8
# Epoch 138 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 139: iteration 7/8
# Epoch 139 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 140: iteration 7/8
# Epoch 140 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 141: iteration 7/8
# Epoch 141 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 142: iteration 7/8
# Epoch 142 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 143: iteration 7/8
# Epoch 143 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 144: iteration 7/8
# Epoch 144 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 145: iteration 7/8
# Epoch 145 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 146: iteration 7/8
# Epoch 146 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 147: iteration 7/8
# Epoch 147 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 148: iteration 7/8
# Epoch 148 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 149: iteration 7/8
# Epoch 149 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 150: iteration 7/8
# Epoch 150 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 151: iteration 7/8
# Epoch 151 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 152: iteration 7/8
# Epoch 152 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 153: iteration 7/8
# Epoch 153 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 154: iteration 7/8
# Epoch 154 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 155: iteration 7/8
# Epoch 155 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 156: iteration 7/8
# Epoch 156 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 157: iteration 7/8
# Epoch 157 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 158: iteration 7/8
# Epoch 158 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 159: iteration 7/8
# Epoch 159 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 160: iteration 7/8
# Epoch 160 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 161: iteration 7/8
# Epoch 161 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 162: iteration 7/8
# Epoch 162 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 163: iteration 7/8
# Epoch 163 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 164: iteration 7/8
# Epoch 164 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 165: iteration 7/8
# Epoch 165 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 166: iteration 7/8
# Epoch 166 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 167: iteration 7/8
# Epoch 167 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 168: iteration 7/8
# Epoch 168 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 169: iteration 7/8
# Epoch 169 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 170: iteration 7/8
# Epoch 170 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 171: iteration 7/8
# Epoch 171 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 172: iteration 7/8
# Epoch 172 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 173: iteration 7/8
# Epoch 173 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 174: iteration 7/8
# Epoch 174 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 175: iteration 7/8
# Epoch 175 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 176: iteration 7/8
# Epoch 176 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 177: iteration 7/8
# Epoch 177 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 178: iteration 7/8
# Epoch 178 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 179: iteration 7/8
# Epoch 179 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 180: iteration 7/8
# Epoch 180 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 181: iteration 7/8
# Epoch 181 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 182: iteration 7/8
# Epoch 182 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 183: iteration 7/8
# Epoch 183 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 184: iteration 7/8
# Epoch 184 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 185: iteration 7/8
# Epoch 185 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 186: iteration 7/8
# Epoch 186 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 187: iteration 7/8
# Epoch 187 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 188: iteration 7/8
# Epoch 188 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 189: iteration 7/8
# Epoch 189 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 190: iteration 7/8
# Epoch 190 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 191: iteration 7/8
# Epoch 191 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 192: iteration 7/8
# Epoch 192 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 193: iteration 7/8
# Epoch 193 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 194: iteration 7/8
# Epoch 194 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 195: iteration 7/8
# Epoch 195 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 196: iteration 7/8
# Epoch 196 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 197: iteration 7/8
# Epoch 197 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 198: iteration 7/8
# Epoch 198 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 199: iteration 7/8
# Epoch 199 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 200: iteration 7/8
# Epoch 200 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 201: iteration 7/8
# Epoch 201 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 202: iteration 7/8
# Epoch 202 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.019, Validation accuracy:100.00%
# Epoch 203: iteration 7/8
# Epoch 203 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 204: iteration 7/8
# Epoch 204 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 205: iteration 7/8
# Epoch 205 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 206: iteration 7/8
# Epoch 206 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 207: iteration 7/8
# Epoch 207 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 208: iteration 7/8
# Epoch 208 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 209: iteration 7/8
# Epoch 209 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 210: iteration 7/8
# Epoch 210 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 211: iteration 7/8
# Epoch 211 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 212: iteration 7/8
# Epoch 212 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 213: iteration 7/8
# Epoch 213 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 214: iteration 7/8
# Epoch 214 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 215: iteration 7/8
# Epoch 215 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 216: iteration 7/8
# Epoch 216 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 217: iteration 7/8
# Epoch 217 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 218: iteration 7/8
# Epoch 218 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 219: iteration 7/8
# Epoch 219 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 220: iteration 7/8
# Epoch 220 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 221: iteration 7/8
# Epoch 221 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 222: iteration 7/8
# Epoch 222 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 223: iteration 7/8
# Epoch 223 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 224: iteration 7/8
# Epoch 224 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 225: iteration 7/8
# Epoch 225 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 226: iteration 7/8
# Epoch 226 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 227: iteration 7/8
# Epoch 227 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 228: iteration 7/8
# Epoch 228 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 229: iteration 7/8
# Epoch 229 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 230: iteration 7/8
# Epoch 230 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 231: iteration 7/8
# Epoch 231 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 232: iteration 7/8
# Epoch 232 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 233: iteration 7/8
# Epoch 233 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 234: iteration 7/8
# Epoch 234 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 235: iteration 7/8
# Epoch 235 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 236: iteration 7/8
# Epoch 236 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 237: iteration 7/8
# Epoch 237 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 238: iteration 7/8
# Epoch 238 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 239: iteration 7/8
# Epoch 239 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 240: iteration 7/8
# Epoch 240 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 241: iteration 7/8
# Epoch 241 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 242: iteration 7/8
# Epoch 242 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 243: iteration 7/8
# Epoch 243 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 244: iteration 7/8
# Epoch 244 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 245: iteration 7/8
# Epoch 245 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 246: iteration 7/8
# Epoch 246 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.018, Validation accuracy:100.00%
# Epoch 247: iteration 4/8

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
