# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

emotions_dict = {
    'anger': 0,
    'anxiety_fear': 1,
    'boredom': 2,
    'disgust': 3,
    'happiness': 4,
    'neutral': 5,
    'sadness': 6
}


sub_name = 'LIGHT-SERNET'
data_name = 'EMODB'
fold_path = sub_name + ' dataset'

sub_name += '_deltas bias-True'
loss_name = 'CE loss'

minibatch = 16
num_epochs = 300
EARLY_CNT = 99999

learning_rate = 10e-4

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class Model(nn.Module):
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[11,1], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )
        self.conv2 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[1,9], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )
        self.conv3 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )

        self.LFLB = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=[3,3], stride=1, padding='same'),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,1]),
            
            nn.Conv2d(64, 96, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(96, 128, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(128, 160, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(160),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(160, 320, kernel_size=[1,1], stride=[1,1], padding='same'),
            nn.BatchNorm2d(320),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,0])
        )
        
        self.fc = nn.Linear(320, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        conv_embd1 = self.conv1(x)
        conv_embd2 = self.conv2(x)
        conv_embd3 = self.conv3(x)
        
        feature_extractor = torch.cat([conv_embd1, conv_embd2, conv_embd3], dim=-1)
        
        lflb_embd = self.LFLB(feature_extractor)
        out = F.adaptive_avg_pool2d(lflb_embd, (1,1))
        out = nn.Dropout(0.3)(out)
        out = torch.flatten(out, start_dim=1)
        
        output_logits = self.fc(out)
        output_softmax = self.softmax(output_logits)

        return output_logits, output_softmax
    
# model = Model(len(emotions_dict))
# print(summary(model, (32, 1, 184, 40)))

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'Fold-{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import numpy as np

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

for fold in tqdm(range(10)):
    cur_fold_path = os.path.join(fold_path,  f'delta-fold{fold}.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=10e-6, amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - LIGHT-SERNET_deltas bias-True
# A Jupyter Widget
# A Jupyter Widget
# Epoch 0: iteration 29/30
# Epoch 0 --- loss:1.613, Epoch accuracy:32.10%, Validation loss:1.504, Validation accuracy:44.90%
# Epoch 1: iteration 29/30
# Epoch 1 --- loss:1.405, Epoch accuracy:40.12%, Validation loss:1.896, Validation accuracy:24.49%
# Epoch 2: iteration 29/30
# Epoch 2 --- loss:1.241, Epoch accuracy:48.15%, Validation loss:1.289, Validation accuracy:40.82%
# Epoch 3: iteration 29/30
# Epoch 3 --- loss:1.218, Epoch accuracy:51.65%, Validation loss:1.458, Validation accuracy:42.86%
# Epoch 4: iteration 29/30
# Epoch 4 --- loss:1.094, Epoch accuracy:58.02%, Validation loss:0.956, Validation accuracy:61.22%
# Epoch 5: iteration 29/30
# Epoch 5 --- loss:1.016, Epoch accuracy:62.35%, Validation loss:1.081, Validation accuracy:61.22%
# Epoch 6: iteration 29/30
# Epoch 6 --- loss:1.000, Epoch accuracy:61.52%, Validation loss:1.239, Validation accuracy:46.94%
# Epoch 7: iteration 29/30
# Epoch 7 --- loss:0.932, Epoch accuracy:65.64%, Validation loss:1.503, Validation accuracy:34.69%
# Epoch 8: iteration 29/30
# Epoch 8 --- loss:0.873, Epoch accuracy:66.87%, Validation loss:2.280, Validation accuracy:36.73%
# Epoch 9: iteration 29/30
# Epoch 9 --- loss:0.857, Epoch accuracy:69.75%, Validation loss:2.505, Validation accuracy:32.65%
# Epoch 10: iteration 29/30
# Epoch 10 --- loss:0.768, Epoch accuracy:72.02%, Validation loss:1.052, Validation accuracy:61.22%
# Epoch 11: iteration 29/30
# Epoch 11 --- loss:0.778, Epoch accuracy:71.19%, Validation loss:0.808, Validation accuracy:69.39%
# Epoch 12: iteration 29/30
# Epoch 12 --- loss:0.764, Epoch accuracy:73.25%, Validation loss:1.044, Validation accuracy:63.27%
# Epoch 13: iteration 29/30
# Epoch 13 --- loss:0.831, Epoch accuracy:69.55%, Validation loss:2.013, Validation accuracy:44.90%
# Epoch 14: iteration 29/30
# Epoch 14 --- loss:0.724, Epoch accuracy:74.28%, Validation loss:0.894, Validation accuracy:63.27%
# Epoch 15: iteration 29/30
# Epoch 15 --- loss:0.685, Epoch accuracy:73.25%, Validation loss:3.898, Validation accuracy:18.37%
# Epoch 16: iteration 29/30
# Epoch 16 --- loss:0.671, Epoch accuracy:74.49%, Validation loss:2.891, Validation accuracy:34.69%
# Epoch 17: iteration 29/30
# Epoch 17 --- loss:0.635, Epoch accuracy:76.95%, Validation loss:2.864, Validation accuracy:32.65%
# Epoch 18: iteration 29/30
# Epoch 18 --- loss:0.680, Epoch accuracy:75.72%, Validation loss:1.581, Validation accuracy:51.02%
# Epoch 19: iteration 29/30
# Epoch 19 --- loss:0.661, Epoch accuracy:73.25%, Validation loss:2.310, Validation accuracy:51.02%
# Epoch 20: iteration 29/30
# Epoch 20 --- loss:0.662, Epoch accuracy:75.10%, Validation loss:1.012, Validation accuracy:67.35%
# Epoch 21: iteration 29/30
# Epoch 21 --- loss:0.579, Epoch accuracy:76.54%, Validation loss:1.031, Validation accuracy:48.98%
# Epoch 22: iteration 29/30
# Epoch 22 --- loss:0.551, Epoch accuracy:80.86%, Validation loss:0.623, Validation accuracy:81.63%
# Epoch 23: iteration 29/30
# Epoch 23 --- loss:0.539, Epoch accuracy:79.22%, Validation loss:0.909, Validation accuracy:73.47%
# Epoch 24: iteration 29/30
# Epoch 24 --- loss:0.569, Epoch accuracy:78.81%, Validation loss:0.828, Validation accuracy:69.39%
# Epoch 25: iteration 29/30
# Epoch 25 --- loss:0.561, Epoch accuracy:78.81%, Validation loss:3.048, Validation accuracy:14.29%
# Epoch 26: iteration 29/30
# Epoch 26 --- loss:0.546, Epoch accuracy:80.45%, Validation loss:0.647, Validation accuracy:73.47%
# Epoch 27: iteration 29/30
# Epoch 27 --- loss:0.545, Epoch accuracy:78.81%, Validation loss:1.555, Validation accuracy:48.98%
# Epoch 28: iteration 29/30
# Epoch 28 --- loss:0.480, Epoch accuracy:80.86%, Validation loss:1.466, Validation accuracy:55.10%
# Epoch 29: iteration 29/30
# Epoch 29 --- loss:0.441, Epoch accuracy:85.19%, Validation loss:0.594, Validation accuracy:81.63%
# Epoch 30: iteration 29/30
# Epoch 30 --- loss:0.481, Epoch accuracy:81.69%, Validation loss:1.727, Validation accuracy:48.98%
# Epoch 31: iteration 29/30
# Epoch 31 --- loss:0.477, Epoch accuracy:81.89%, Validation loss:0.785, Validation accuracy:73.47%
# Epoch 32: iteration 29/30
# Epoch 32 --- loss:0.398, Epoch accuracy:84.98%, Validation loss:5.179, Validation accuracy:30.61%
# Epoch 33: iteration 29/30
# Epoch 33 --- loss:0.427, Epoch accuracy:84.36%, Validation loss:1.575, Validation accuracy:48.98%
# Epoch 34: iteration 29/30
# Epoch 34 --- loss:0.373, Epoch accuracy:87.86%, Validation loss:1.085, Validation accuracy:73.47%
# Epoch 35: iteration 29/30
# Epoch 35 --- loss:0.344, Epoch accuracy:87.45%, Validation loss:2.918, Validation accuracy:28.57%
# Epoch 36: iteration 29/30
# Epoch 36 --- loss:0.361, Epoch accuracy:86.42%, Validation loss:2.776, Validation accuracy:38.78%
# Epoch 37: iteration 29/30
# Epoch 37 --- loss:0.418, Epoch accuracy:83.95%, Validation loss:3.572, Validation accuracy:48.98%
# Epoch 38: iteration 29/30
# Epoch 38 --- loss:0.370, Epoch accuracy:86.63%, Validation loss:9.175, Validation accuracy:28.57%
# Epoch 39: iteration 29/30
# Epoch 39 --- loss:0.342, Epoch accuracy:88.48%, Validation loss:1.176, Validation accuracy:53.06%
# Epoch 40: iteration 29/30
# Epoch 40 --- loss:0.333, Epoch accuracy:89.71%, Validation loss:1.848, Validation accuracy:36.73%
# Epoch 41: iteration 29/30
# Epoch 41 --- loss:0.368, Epoch accuracy:87.65%, Validation loss:6.114, Validation accuracy:48.98%
# Epoch 42: iteration 29/30
# Epoch 42 --- loss:0.400, Epoch accuracy:84.57%, Validation loss:1.383, Validation accuracy:61.22%
# Epoch 43: iteration 29/30
# Epoch 43 --- loss:0.362, Epoch accuracy:85.39%, Validation loss:4.657, Validation accuracy:34.69%
# Epoch 44: iteration 29/30
# Epoch 44 --- loss:0.289, Epoch accuracy:89.51%, Validation loss:3.401, Validation accuracy:22.45%
# Epoch 45: iteration 29/30
# Epoch 45 --- loss:0.314, Epoch accuracy:87.86%, Validation loss:2.120, Validation accuracy:40.82%
# Epoch 46: iteration 29/30
# Epoch 46 --- loss:0.271, Epoch accuracy:89.71%, Validation loss:1.057, Validation accuracy:63.27%
# Epoch 47: iteration 29/30
# Epoch 47 --- loss:0.271, Epoch accuracy:90.53%, Validation loss:3.369, Validation accuracy:38.78%
# Epoch 48: iteration 29/30
# Epoch 48 --- loss:0.256, Epoch accuracy:91.36%, Validation loss:1.424, Validation accuracy:55.10%
# Epoch 49: iteration 29/30
# Epoch 49 --- loss:0.315, Epoch accuracy:89.30%, Validation loss:1.264, Validation accuracy:67.35%
# Epoch 50: iteration 29/30
# Epoch 50 --- loss:0.304, Epoch accuracy:87.86%, Validation loss:3.165, Validation accuracy:32.65%
# Epoch 51: iteration 29/30
# Epoch 51 --- loss:0.220, Epoch accuracy:93.00%, Validation loss:1.536, Validation accuracy:57.14%
# Epoch 52: iteration 29/30
# Epoch 52 --- loss:0.280, Epoch accuracy:89.71%, Validation loss:2.368, Validation accuracy:42.86%
# Epoch 53: iteration 29/30
# Epoch 53 --- loss:0.204, Epoch accuracy:93.62%, Validation loss:1.644, Validation accuracy:57.14%
# Epoch 54: iteration 29/30
# Epoch 54 --- loss:0.294, Epoch accuracy:88.48%, Validation loss:3.730, Validation accuracy:34.69%
# Epoch 55: iteration 29/30
# Epoch 55 --- loss:0.301, Epoch accuracy:88.89%, Validation loss:1.832, Validation accuracy:38.78%
# Epoch 56: iteration 29/30
# Epoch 56 --- loss:0.251, Epoch accuracy:91.36%, Validation loss:0.967, Validation accuracy:69.39%
# Epoch 57: iteration 29/30
# Epoch 57 --- loss:0.188, Epoch accuracy:94.86%, Validation loss:1.980, Validation accuracy:69.39%
# Epoch 58: iteration 29/30
# Epoch 58 --- loss:0.176, Epoch accuracy:93.42%, Validation loss:2.822, Validation accuracy:46.94%
# Epoch 59: iteration 29/30
# Epoch 59 --- loss:0.211, Epoch accuracy:94.44%, Validation loss:2.616, Validation accuracy:44.90%
# Epoch 60: iteration 29/30
# Epoch 60 --- loss:0.286, Epoch accuracy:88.27%, Validation loss:2.930, Validation accuracy:44.90%
# Epoch 61: iteration 29/30
# Epoch 61 --- loss:0.243, Epoch accuracy:92.18%, Validation loss:1.674, Validation accuracy:51.02%
# Epoch 62: iteration 29/30
# Epoch 62 --- loss:0.197, Epoch accuracy:91.98%, Validation loss:2.158, Validation accuracy:40.82%
# Epoch 63: iteration 29/30
# Epoch 63 --- loss:0.225, Epoch accuracy:90.53%, Validation loss:1.139, Validation accuracy:53.06%
# Epoch 64: iteration 29/30
# Epoch 64 --- loss:0.184, Epoch accuracy:93.00%, Validation loss:2.151, Validation accuracy:48.98%
# Epoch 65: iteration 29/30
# Epoch 65 --- loss:0.172, Epoch accuracy:94.65%, Validation loss:2.599, Validation accuracy:40.82%
# Epoch 66: iteration 29/30
# Epoch 66 --- loss:0.186, Epoch accuracy:93.00%, Validation loss:1.312, Validation accuracy:73.47%
# Epoch 67: iteration 29/30
# Epoch 67 --- loss:0.199, Epoch accuracy:93.00%, Validation loss:1.311, Validation accuracy:57.14%
# Epoch 68: iteration 29/30
# Epoch 68 --- loss:0.215, Epoch accuracy:90.33%, Validation loss:5.262, Validation accuracy:34.69%
# Epoch 69: iteration 29/30
# Epoch 69 --- loss:0.194, Epoch accuracy:93.42%, Validation loss:1.981, Validation accuracy:38.78%
# Epoch 70: iteration 29/30
# Epoch 70 --- loss:0.124, Epoch accuracy:95.88%, Validation loss:0.980, Validation accuracy:67.35%
# Epoch 71: iteration 29/30
# Epoch 71 --- loss:0.132, Epoch accuracy:94.86%, Validation loss:0.977, Validation accuracy:69.39%
# Epoch 72: iteration 29/30
# Epoch 72 --- loss:0.176, Epoch accuracy:93.00%, Validation loss:0.878, Validation accuracy:75.51%
# Epoch 73: iteration 29/30
# Epoch 73 --- loss:0.199, Epoch accuracy:92.80%, Validation loss:4.251, Validation accuracy:34.69%
# Epoch 74: iteration 29/30
# Epoch 74 --- loss:0.176, Epoch accuracy:93.42%, Validation loss:4.567, Validation accuracy:28.57%
# Epoch 75: iteration 29/30
# Epoch 75 --- loss:0.128, Epoch accuracy:95.47%, Validation loss:1.693, Validation accuracy:48.98%
# Epoch 76: iteration 29/30
# Epoch 76 --- loss:0.130, Epoch accuracy:95.68%, Validation loss:1.229, Validation accuracy:69.39%
# Epoch 77: iteration 29/30
# Epoch 77 --- loss:0.109, Epoch accuracy:96.50%, Validation loss:1.003, Validation accuracy:65.31%
# Epoch 78: iteration 29/30
# Epoch 78 --- loss:0.122, Epoch accuracy:95.27%, Validation loss:2.840, Validation accuracy:42.86%
# Epoch 79: iteration 29/30
# Epoch 79 --- loss:0.137, Epoch accuracy:95.68%, Validation loss:1.328, Validation accuracy:61.22%
# Epoch 80: iteration 29/30
# Epoch 80 --- loss:0.109, Epoch accuracy:96.09%, Validation loss:3.032, Validation accuracy:46.94%
# Epoch 81: iteration 29/30
# Epoch 81 --- loss:0.109, Epoch accuracy:97.53%, Validation loss:0.513, Validation accuracy:81.63%
# Epoch 82: iteration 29/30
# Epoch 82 --- loss:0.132, Epoch accuracy:95.68%, Validation loss:1.238, Validation accuracy:71.43%
# Epoch 83: iteration 29/30
# Epoch 83 --- loss:0.124, Epoch accuracy:96.09%, Validation loss:25.175, Validation accuracy:22.45%
# Epoch 84: iteration 29/30
# Epoch 84 --- loss:0.141, Epoch accuracy:94.86%, Validation loss:5.365, Validation accuracy:30.61%
# Epoch 85: iteration 29/30
# Epoch 85 --- loss:0.232, Epoch accuracy:91.36%, Validation loss:21.004, Validation accuracy:28.57%
# Epoch 86: iteration 29/30
# Epoch 86 --- loss:0.167, Epoch accuracy:94.03%, Validation loss:2.754, Validation accuracy:40.82%
# Epoch 87: iteration 29/30
# Epoch 87 --- loss:0.146, Epoch accuracy:94.86%, Validation loss:1.859, Validation accuracy:59.18%
# Epoch 88: iteration 29/30
# Epoch 88 --- loss:0.114, Epoch accuracy:95.68%, Validation loss:2.226, Validation accuracy:53.06%
# Epoch 89: iteration 29/30
# Epoch 89 --- loss:0.096, Epoch accuracy:95.88%, Validation loss:1.932, Validation accuracy:44.90%
# Epoch 90: iteration 29/30
# Epoch 90 --- loss:0.109, Epoch accuracy:96.09%, Validation loss:0.509, Validation accuracy:81.63%
# Epoch 91: iteration 29/30
# Epoch 91 --- loss:0.075, Epoch accuracy:97.53%, Validation loss:0.835, Validation accuracy:75.51%
# Epoch 92: iteration 29/30
# Epoch 92 --- loss:0.153, Epoch accuracy:94.65%, Validation loss:13.987, Validation accuracy:22.45%
# Epoch 93: iteration 29/30
# Epoch 93 --- loss:0.165, Epoch accuracy:93.21%, Validation loss:3.847, Validation accuracy:28.57%
# Epoch 94: iteration 29/30
# Epoch 94 --- loss:0.147, Epoch accuracy:94.03%, Validation loss:2.520, Validation accuracy:44.90%
# Epoch 95: iteration 29/30
# Epoch 95 --- loss:0.120, Epoch accuracy:94.44%, Validation loss:1.815, Validation accuracy:53.06%
# Epoch 96: iteration 29/30
# Epoch 96 --- loss:0.120, Epoch accuracy:95.47%, Validation loss:2.079, Validation accuracy:51.02%
# Epoch 97: iteration 29/30
# Epoch 97 --- loss:0.106, Epoch accuracy:96.30%, Validation loss:3.282, Validation accuracy:34.69%
# Epoch 98: iteration 29/30
# Epoch 98 --- loss:0.105, Epoch accuracy:95.88%, Validation loss:0.958, Validation accuracy:65.31%
# Epoch 99: iteration 29/30
# Epoch 99 --- loss:0.098, Epoch accuracy:97.12%, Validation loss:4.471, Validation accuracy:36.73%
# Epoch 100: iteration 29/30
# Epoch 100 --- loss:0.101, Epoch accuracy:95.88%, Validation loss:2.547, Validation accuracy:51.02%
# Epoch 101: iteration 29/30
# Epoch 101 --- loss:0.061, Epoch accuracy:97.94%, Validation loss:1.872, Validation accuracy:57.14%
# Epoch 102: iteration 29/30
# Epoch 102 --- loss:0.086, Epoch accuracy:97.33%, Validation loss:1.715, Validation accuracy:48.98%
# Epoch 103: iteration 29/30
# Epoch 103 --- loss:0.098, Epoch accuracy:96.09%, Validation loss:3.165, Validation accuracy:40.82%
# Epoch 104: iteration 29/30
# Epoch 104 --- loss:0.066, Epoch accuracy:97.12%, Validation loss:4.808, Validation accuracy:42.86%
# Epoch 105: iteration 29/30
# Epoch 105 --- loss:0.055, Epoch accuracy:97.74%, Validation loss:0.544, Validation accuracy:81.63%
# Epoch 106: iteration 29/30
# Epoch 106 --- loss:0.070, Epoch accuracy:97.53%, Validation loss:1.160, Validation accuracy:67.35%
# Epoch 107: iteration 29/30
# Epoch 107 --- loss:0.059, Epoch accuracy:97.53%, Validation loss:1.882, Validation accuracy:57.14%
# Epoch 108: iteration 29/30
# Epoch 108 --- loss:0.056, Epoch accuracy:98.35%, Validation loss:3.352, Validation accuracy:42.86%
# Epoch 109: iteration 29/30
# Epoch 109 --- loss:0.067, Epoch accuracy:97.53%, Validation loss:1.963, Validation accuracy:53.06%
# Epoch 110: iteration 29/30
# Epoch 110 --- loss:0.115, Epoch accuracy:95.88%, Validation loss:2.872, Validation accuracy:48.98%
# Epoch 111: iteration 29/30
# Epoch 111 --- loss:0.056, Epoch accuracy:97.53%, Validation loss:0.781, Validation accuracy:79.59%
# Epoch 112: iteration 29/30
# Epoch 112 --- loss:0.080, Epoch accuracy:96.71%, Validation loss:10.323, Validation accuracy:30.61%
# Epoch 113: iteration 29/30
# Epoch 113 --- loss:0.114, Epoch accuracy:95.68%, Validation loss:1.653, Validation accuracy:65.31%
# Epoch 114: iteration 29/30
# Epoch 114 --- loss:0.076, Epoch accuracy:97.33%, Validation loss:1.546, Validation accuracy:57.14%
# Epoch 115: iteration 29/30
# Epoch 115 --- loss:0.058, Epoch accuracy:97.74%, Validation loss:2.887, Validation accuracy:46.94%
# Epoch 116: iteration 29/30
# Epoch 116 --- loss:0.038, Epoch accuracy:98.35%, Validation loss:0.450, Validation accuracy:83.67%
# Epoch 117: iteration 29/30
# Epoch 117 --- loss:0.036, Epoch accuracy:98.35%, Validation loss:0.601, Validation accuracy:83.67%
# Epoch 118: iteration 29/30
# Epoch 118 --- loss:0.031, Epoch accuracy:98.56%, Validation loss:0.462, Validation accuracy:85.71%
# Epoch 119: iteration 29/30
# Epoch 119 --- loss:0.042, Epoch accuracy:98.35%, Validation loss:1.103, Validation accuracy:73.47%
# Epoch 120: iteration 29/30
# Epoch 120 --- loss:0.037, Epoch accuracy:98.35%, Validation loss:0.594, Validation accuracy:79.59%
# Epoch 121: iteration 29/30
# Epoch 121 --- loss:0.052, Epoch accuracy:97.33%, Validation loss:0.480, Validation accuracy:83.67%
# Epoch 122: iteration 29/30
# Epoch 122 --- loss:0.038, Epoch accuracy:97.94%, Validation loss:1.791, Validation accuracy:57.14%
# Epoch 123: iteration 29/30
# Epoch 123 --- loss:0.042, Epoch accuracy:97.94%, Validation loss:2.699, Validation accuracy:59.18%
# Epoch 124: iteration 29/30
# Epoch 124 --- loss:0.042, Epoch accuracy:98.15%, Validation loss:4.284, Validation accuracy:36.73%
# Epoch 125: iteration 29/30
# Epoch 125 --- loss:0.034, Epoch accuracy:98.56%, Validation loss:3.701, Validation accuracy:40.82%
# Epoch 126: iteration 29/30
# Epoch 126 --- loss:0.051, Epoch accuracy:97.74%, Validation loss:1.010, Validation accuracy:69.39%
# Epoch 127: iteration 29/30
# Epoch 127 --- loss:0.059, Epoch accuracy:97.33%, Validation loss:1.573, Validation accuracy:55.10%
# Epoch 128: iteration 29/30
# Epoch 128 --- loss:0.090, Epoch accuracy:95.88%, Validation loss:4.855, Validation accuracy:26.53%
# Epoch 129: iteration 29/30
# Epoch 129 --- loss:0.091, Epoch accuracy:96.50%, Validation loss:2.282, Validation accuracy:59.18%
# Epoch 130: iteration 29/30
# Epoch 130 --- loss:0.054, Epoch accuracy:97.94%, Validation loss:0.416, Validation accuracy:85.71%
# Epoch 131: iteration 29/30
# Epoch 131 --- loss:0.035, Epoch accuracy:98.56%, Validation loss:2.542, Validation accuracy:48.98%
# Epoch 132: iteration 29/30
# Epoch 132 --- loss:0.022, Epoch accuracy:98.77%, Validation loss:0.861, Validation accuracy:79.59%
# Epoch 133: iteration 29/30
# Epoch 133 --- loss:0.041, Epoch accuracy:98.15%, Validation loss:0.470, Validation accuracy:85.71%
# Epoch 134: iteration 29/30
# Epoch 134 --- loss:0.061, Epoch accuracy:96.91%, Validation loss:3.795, Validation accuracy:44.90%
# Epoch 135: iteration 29/30
# Epoch 135 --- loss:0.050, Epoch accuracy:98.15%, Validation loss:0.705, Validation accuracy:77.55%
# Epoch 136: iteration 29/30
# Epoch 136 --- loss:0.035, Epoch accuracy:98.56%, Validation loss:0.783, Validation accuracy:75.51%
# Epoch 137: iteration 29/30
# Epoch 137 --- loss:0.030, Epoch accuracy:98.35%, Validation loss:0.567, Validation accuracy:81.63%
# Epoch 138: iteration 29/30
# Epoch 138 --- loss:0.051, Epoch accuracy:97.53%, Validation loss:1.393, Validation accuracy:61.22%
# Epoch 139: iteration 29/30
# Epoch 139 --- loss:0.064, Epoch accuracy:97.12%, Validation loss:0.799, Validation accuracy:77.55%
# Epoch 140: iteration 29/30
# Epoch 140 --- loss:0.043, Epoch accuracy:97.94%, Validation loss:2.286, Validation accuracy:57.14%
# Epoch 141: iteration 29/30
# Epoch 141 --- loss:0.076, Epoch accuracy:96.50%, Validation loss:4.912, Validation accuracy:30.61%
# Epoch 142: iteration 29/30
# Epoch 142 --- loss:0.047, Epoch accuracy:97.94%, Validation loss:3.799, Validation accuracy:44.90%
# Epoch 143: iteration 29/30
# Epoch 143 --- loss:0.058, Epoch accuracy:97.53%, Validation loss:1.482, Validation accuracy:65.31%
# Epoch 144: iteration 29/30
# Epoch 144 --- loss:0.032, Epoch accuracy:97.94%, Validation loss:0.997, Validation accuracy:67.35%
# Epoch 145: iteration 29/30
# Epoch 145 --- loss:0.021, Epoch accuracy:98.77%, Validation loss:1.133, Validation accuracy:63.27%
# Epoch 146: iteration 29/30
# Epoch 146 --- loss:0.025, Epoch accuracy:98.56%, Validation loss:1.422, Validation accuracy:61.22%
# Epoch 147: iteration 29/30
# Epoch 147 --- loss:0.046, Epoch accuracy:97.94%, Validation loss:2.174, Validation accuracy:53.06%
# Epoch 148: iteration 29/30
# Epoch 148 --- loss:0.087, Epoch accuracy:96.30%, Validation loss:2.786, Validation accuracy:48.98%
# Epoch 149: iteration 29/30
# Epoch 149 --- loss:0.074, Epoch accuracy:96.09%, Validation loss:3.612, Validation accuracy:34.69%
# Epoch 150: iteration 29/30
# Epoch 150 --- loss:0.036, Epoch accuracy:98.15%, Validation loss:0.830, Validation accuracy:79.59%
# Epoch 151: iteration 29/30
# Epoch 151 --- loss:0.037, Epoch accuracy:98.15%, Validation loss:1.554, Validation accuracy:65.31%
# Epoch 152: iteration 29/30
# Epoch 152 --- loss:0.049, Epoch accuracy:97.12%, Validation loss:3.227, Validation accuracy:46.94%
# Epoch 153: iteration 29/30
# Epoch 153 --- loss:0.027, Epoch accuracy:98.56%, Validation loss:0.415, Validation accuracy:83.67%
# Epoch 154: iteration 29/30
# Epoch 154 --- loss:0.028, Epoch accuracy:98.56%, Validation loss:1.008, Validation accuracy:71.43%
# Epoch 155: iteration 29/30
# Epoch 155 --- loss:0.019, Epoch accuracy:98.56%, Validation loss:0.819, Validation accuracy:73.47%
# Epoch 156: iteration 29/30
# Epoch 156 --- loss:0.044, Epoch accuracy:97.53%, Validation loss:2.447, Validation accuracy:57.14%
# Epoch 157: iteration 29/30
# Epoch 157 --- loss:0.046, Epoch accuracy:97.74%, Validation loss:5.072, Validation accuracy:42.86%
# Epoch 158: iteration 29/30
# Epoch 158 --- loss:0.052, Epoch accuracy:97.12%, Validation loss:2.375, Validation accuracy:42.86%
# Epoch 159: iteration 29/30
# Epoch 159 --- loss:0.048, Epoch accuracy:97.94%, Validation loss:6.303, Validation accuracy:38.78%
# Epoch 160: iteration 29/30
# Epoch 160 --- loss:0.034, Epoch accuracy:98.35%, Validation loss:2.892, Validation accuracy:40.82%
# Epoch 161: iteration 29/30
# Epoch 161 --- loss:0.023, Epoch accuracy:98.56%, Validation loss:1.524, Validation accuracy:63.27%
# Epoch 162: iteration 29/30
# Epoch 162 --- loss:0.025, Epoch accuracy:98.35%, Validation loss:0.530, Validation accuracy:81.63%
# Epoch 163: iteration 29/30
# Epoch 163 --- loss:0.072, Epoch accuracy:96.30%, Validation loss:2.525, Validation accuracy:53.06%
# Epoch 164: iteration 29/30
# Epoch 164 --- loss:0.119, Epoch accuracy:95.06%, Validation loss:7.912, Validation accuracy:32.65%
# Epoch 165: iteration 29/30
# Epoch 165 --- loss:0.121, Epoch accuracy:95.47%, Validation loss:4.002, Validation accuracy:51.02%
# Epoch 166: iteration 29/30
# Epoch 166 --- loss:0.068, Epoch accuracy:96.91%, Validation loss:6.191, Validation accuracy:20.41%
# Epoch 167: iteration 29/30
# Epoch 167 --- loss:0.057, Epoch accuracy:97.33%, Validation loss:2.119, Validation accuracy:46.94%
# Epoch 168: iteration 29/30
# Epoch 168 --- loss:0.045, Epoch accuracy:97.94%, Validation loss:2.309, Validation accuracy:55.10%
# Epoch 169: iteration 29/30
# Epoch 169 --- loss:0.025, Epoch accuracy:98.77%, Validation loss:0.779, Validation accuracy:73.47%
# Epoch 170: iteration 29/30
# Epoch 170 --- loss:0.019, Epoch accuracy:98.56%, Validation loss:0.886, Validation accuracy:77.55%
# Epoch 171: iteration 29/30
# Epoch 171 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:0.631, Validation accuracy:77.55%
# Epoch 172: iteration 29/30
# Epoch 172 --- loss:0.017, Epoch accuracy:98.56%, Validation loss:1.570, Validation accuracy:63.27%
# Epoch 173: iteration 29/30
# Epoch 173 --- loss:0.018, Epoch accuracy:98.77%, Validation loss:0.658, Validation accuracy:83.67%
# Epoch 174: iteration 29/30
# Epoch 174 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.671, Validation accuracy:79.59%
# Epoch 175: iteration 29/30
# Epoch 175 --- loss:0.016, Epoch accuracy:98.77%, Validation loss:0.522, Validation accuracy:79.59%
# Epoch 176: iteration 29/30
# Epoch 176 --- loss:0.022, Epoch accuracy:98.56%, Validation loss:4.563, Validation accuracy:40.82%
# Epoch 177: iteration 29/30
# Epoch 177 --- loss:0.018, Epoch accuracy:98.56%, Validation loss:0.593, Validation accuracy:79.59%
# Epoch 178: iteration 29/30
# Epoch 178 --- loss:0.019, Epoch accuracy:98.56%, Validation loss:1.080, Validation accuracy:77.55%
# Epoch 179: iteration 29/30
# Epoch 179 --- loss:0.020, Epoch accuracy:98.77%, Validation loss:1.577, Validation accuracy:57.14%
# Epoch 180: iteration 29/30
# Epoch 180 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:0.737, Validation accuracy:79.59%
# Epoch 181: iteration 29/30
# Epoch 181 --- loss:0.045, Epoch accuracy:97.53%, Validation loss:2.287, Validation accuracy:57.14%
# Epoch 182: iteration 29/30
# Epoch 182 --- loss:0.051, Epoch accuracy:97.12%, Validation loss:1.456, Validation accuracy:63.27%
# Epoch 183: iteration 29/30
# Epoch 183 --- loss:0.056, Epoch accuracy:97.12%, Validation loss:0.928, Validation accuracy:79.59%
# Epoch 184: iteration 29/30
# Epoch 184 --- loss:0.026, Epoch accuracy:98.35%, Validation loss:0.798, Validation accuracy:79.59%
# Epoch 185: iteration 29/30
# Epoch 185 --- loss:0.027, Epoch accuracy:98.15%, Validation loss:2.702, Validation accuracy:55.10%
# Epoch 186: iteration 29/30
# Epoch 186 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.919, Validation accuracy:69.39%
# Epoch 187: iteration 29/30
# Epoch 187 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:0.781, Validation accuracy:73.47%
# Epoch 188: iteration 29/30
# Epoch 188 --- loss:0.016, Epoch accuracy:98.15%, Validation loss:1.500, Validation accuracy:69.39%
# Epoch 189: iteration 29/30
# Epoch 189 --- loss:0.038, Epoch accuracy:97.74%, Validation loss:0.659, Validation accuracy:69.39%
# Epoch 190: iteration 29/30
# Epoch 190 --- loss:0.029, Epoch accuracy:98.35%, Validation loss:1.696, Validation accuracy:63.27%
# Epoch 191: iteration 29/30
# Epoch 191 --- loss:0.098, Epoch accuracy:95.06%, Validation loss:7.264, Validation accuracy:32.65%
# Epoch 192: iteration 29/30
# Epoch 192 --- loss:0.074, Epoch accuracy:96.09%, Validation loss:3.957, Validation accuracy:46.94%
# Epoch 193: iteration 29/30
# Epoch 193 --- loss:0.092, Epoch accuracy:95.68%, Validation loss:7.129, Validation accuracy:24.49%
# Epoch 194: iteration 29/30
# Epoch 194 --- loss:0.071, Epoch accuracy:97.12%, Validation loss:2.874, Validation accuracy:40.82%
# Epoch 195: iteration 29/30
# Epoch 195 --- loss:0.049, Epoch accuracy:97.94%, Validation loss:5.591, Validation accuracy:22.45%
# Epoch 196: iteration 29/30
# Epoch 196 --- loss:0.025, Epoch accuracy:98.56%, Validation loss:0.464, Validation accuracy:81.63%
# Epoch 197: iteration 29/30
# Epoch 197 --- loss:0.021, Epoch accuracy:98.35%, Validation loss:1.352, Validation accuracy:63.27%
# Epoch 198: iteration 29/30
# Epoch 198 --- loss:0.014, Epoch accuracy:98.56%, Validation loss:1.249, Validation accuracy:67.35%
# Epoch 199: iteration 29/30
# Epoch 199 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.316, Validation accuracy:65.31%
# Epoch 200: iteration 29/30
# Epoch 200 --- loss:0.016, Epoch accuracy:98.56%, Validation loss:1.001, Validation accuracy:67.35%
# Epoch 201: iteration 29/30
# Epoch 201 --- loss:0.029, Epoch accuracy:98.35%, Validation loss:0.665, Validation accuracy:79.59%
# Epoch 202: iteration 29/30
# Epoch 202 --- loss:0.019, Epoch accuracy:98.35%, Validation loss:5.067, Validation accuracy:18.37%
# Epoch 203: iteration 29/30
# Epoch 203 --- loss:0.029, Epoch accuracy:98.15%, Validation loss:3.555, Validation accuracy:57.14%
# Epoch 204: iteration 29/30
# Epoch 204 --- loss:0.019, Epoch accuracy:98.56%, Validation loss:1.004, Validation accuracy:63.27%
# Epoch 205: iteration 29/30
# Epoch 205 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.783, Validation accuracy:69.39%
# Epoch 206: iteration 29/30
# Epoch 206 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:1.037, Validation accuracy:69.39%
# Epoch 207: iteration 29/30
# Epoch 207 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:1.675, Validation accuracy:61.22%
# Epoch 208: iteration 29/30
# Epoch 208 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.548, Validation accuracy:81.63%
# Epoch 209: iteration 29/30
# Epoch 209 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.581, Validation accuracy:75.51%
# Epoch 210: iteration 29/30
# Epoch 210 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.752, Validation accuracy:77.55%
# Epoch 211: iteration 29/30
# Epoch 211 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.792, Validation accuracy:77.55%
# Epoch 212: iteration 29/30
# Epoch 212 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.451, Validation accuracy:83.67%
# Epoch 213: iteration 29/30
# Epoch 213 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.656, Validation accuracy:77.55%
# Epoch 214: iteration 29/30
# Epoch 214 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.680, Validation accuracy:83.67%
# Epoch 215: iteration 29/30
# Epoch 215 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.510, Validation accuracy:85.71%
# Epoch 216: iteration 29/30
# Epoch 216 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.608, Validation accuracy:81.63%
# Epoch 217: iteration 29/30
# Epoch 217 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.611, Validation accuracy:71.43%
# Epoch 218: iteration 29/30
# Epoch 218 --- loss:0.011, Epoch accuracy:98.35%, Validation loss:1.470, Validation accuracy:65.31%
# Epoch 219: iteration 29/30
# Epoch 219 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:1.122, Validation accuracy:75.51%
# Epoch 220: iteration 29/30
# Epoch 220 --- loss:0.016, Epoch accuracy:98.56%, Validation loss:4.137, Validation accuracy:48.98%
# Epoch 221: iteration 29/30
# Epoch 221 --- loss:0.030, Epoch accuracy:97.94%, Validation loss:0.565, Validation accuracy:79.59%
# Epoch 222: iteration 29/30
# Epoch 222 --- loss:0.024, Epoch accuracy:97.94%, Validation loss:2.176, Validation accuracy:59.18%
# Epoch 223: iteration 29/30
# Epoch 223 --- loss:0.022, Epoch accuracy:98.77%, Validation loss:1.643, Validation accuracy:59.18%
# Epoch 224: iteration 29/30
# Epoch 224 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:1.277, Validation accuracy:59.18%
# Epoch 225: iteration 29/30
# Epoch 225 --- loss:0.026, Epoch accuracy:98.15%, Validation loss:1.560, Validation accuracy:51.02%
# Epoch 226: iteration 29/30
# Epoch 226 --- loss:0.052, Epoch accuracy:97.12%, Validation loss:2.246, Validation accuracy:53.06%
# Epoch 227: iteration 29/30
# Epoch 227 --- loss:0.027, Epoch accuracy:98.35%, Validation loss:0.654, Validation accuracy:73.47%
# Epoch 228: iteration 29/30
# Epoch 228 --- loss:0.060, Epoch accuracy:96.71%, Validation loss:1.365, Validation accuracy:69.39%
# Epoch 229: iteration 29/30
# Epoch 229 --- loss:0.019, Epoch accuracy:98.77%, Validation loss:1.927, Validation accuracy:61.22%
# Epoch 230: iteration 29/30
# Epoch 230 --- loss:0.019, Epoch accuracy:98.35%, Validation loss:0.769, Validation accuracy:65.31%
# Epoch 231: iteration 29/30
# Epoch 231 --- loss:0.034, Epoch accuracy:97.53%, Validation loss:3.730, Validation accuracy:34.69%
# Epoch 232: iteration 29/30
# Epoch 232 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.605, Validation accuracy:73.47%
# Epoch 233: iteration 29/30
# Epoch 233 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.532, Validation accuracy:83.67%
# Epoch 234: iteration 29/30
# Epoch 234 --- loss:0.016, Epoch accuracy:98.35%, Validation loss:0.994, Validation accuracy:71.43%
# Epoch 235: iteration 29/30
# Epoch 235 --- loss:0.014, Epoch accuracy:98.56%, Validation loss:0.328, Validation accuracy:91.84%
# Epoch 236: iteration 29/30
# Epoch 236 --- loss:0.016, Epoch accuracy:98.35%, Validation loss:1.252, Validation accuracy:67.35%
# Epoch 237: iteration 29/30
# Epoch 237 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.744, Validation accuracy:71.43%
# Epoch 238: iteration 29/30
# Epoch 238 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.447, Validation accuracy:83.67%
# Epoch 239: iteration 29/30
# Epoch 239 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.633, Validation accuracy:81.63%
# Epoch 240: iteration 29/30
# Epoch 240 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:0.580, Validation accuracy:79.59%
# Epoch 241: iteration 29/30
# Epoch 241 --- loss:0.017, Epoch accuracy:98.56%, Validation loss:0.764, Validation accuracy:73.47%
# Epoch 242: iteration 29/30
# Epoch 242 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.982, Validation accuracy:71.43%
# Epoch 243: iteration 29/30
# Epoch 243 --- loss:0.011, Epoch accuracy:98.56%, Validation loss:0.557, Validation accuracy:75.51%
# Epoch 244: iteration 29/30
# Epoch 244 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.408, Validation accuracy:83.67%
# Epoch 245: iteration 29/30
# Epoch 245 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.539, Validation accuracy:85.71%
# Epoch 246: iteration 29/30
# Epoch 246 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.512, Validation accuracy:83.67%
# Epoch 247: iteration 29/30
# Epoch 247 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.734, Validation accuracy:71.43%
# Epoch 248: iteration 29/30
# Epoch 248 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.831, Validation accuracy:75.51%
# Epoch 249: iteration 29/30
# Epoch 249 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.601, Validation accuracy:85.71%
# Epoch 250: iteration 29/30
# Epoch 250 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.434, Validation accuracy:83.67%
# Epoch 251: iteration 29/30
# Epoch 251 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.593, Validation accuracy:79.59%
# Epoch 252: iteration 29/30
# Epoch 252 --- loss:0.013, Epoch accuracy:98.56%, Validation loss:0.616, Validation accuracy:77.55%
# Epoch 253: iteration 29/30
# Epoch 253 --- loss:0.021, Epoch accuracy:98.15%, Validation loss:1.179, Validation accuracy:75.51%
# Epoch 254: iteration 29/30
# Epoch 254 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.899, Validation accuracy:71.43%
# Epoch 255: iteration 29/30
# Epoch 255 --- loss:0.017, Epoch accuracy:98.35%, Validation loss:3.551, Validation accuracy:51.02%
# Epoch 256: iteration 29/30
# Epoch 256 --- loss:0.120, Epoch accuracy:95.88%, Validation loss:1.184, Validation accuracy:77.55%
# Epoch 257: iteration 29/30
# Epoch 257 --- loss:0.048, Epoch accuracy:96.50%, Validation loss:5.237, Validation accuracy:26.53%
# Epoch 258: iteration 29/30
# Epoch 258 --- loss:0.023, Epoch accuracy:98.35%, Validation loss:0.667, Validation accuracy:77.55%
# Epoch 259: iteration 29/30
# Epoch 259 --- loss:0.038, Epoch accuracy:97.94%, Validation loss:2.582, Validation accuracy:48.98%
# Epoch 260: iteration 29/30
# Epoch 260 --- loss:0.018, Epoch accuracy:98.77%, Validation loss:1.294, Validation accuracy:67.35%
# Epoch 261: iteration 29/30
# Epoch 261 --- loss:0.059, Epoch accuracy:97.53%, Validation loss:2.123, Validation accuracy:61.22%
# Epoch 262: iteration 29/30
# Epoch 262 --- loss:0.022, Epoch accuracy:98.35%, Validation loss:0.563, Validation accuracy:81.63%
# Epoch 263: iteration 29/30
# Epoch 263 --- loss:0.017, Epoch accuracy:98.35%, Validation loss:3.080, Validation accuracy:36.73%
# Epoch 264: iteration 29/30
# Epoch 264 --- loss:0.020, Epoch accuracy:98.35%, Validation loss:3.425, Validation accuracy:51.02%
# Epoch 265: iteration 29/30
# Epoch 265 --- loss:0.019, Epoch accuracy:98.35%, Validation loss:0.877, Validation accuracy:75.51%
# Epoch 266: iteration 29/30
# Epoch 266 --- loss:0.027, Epoch accuracy:98.15%, Validation loss:1.695, Validation accuracy:63.27%
# Epoch 267: iteration 29/30
# Epoch 267 --- loss:0.023, Epoch accuracy:98.35%, Validation loss:0.799, Validation accuracy:81.63%
# Epoch 268: iteration 29/30
# Epoch 268 --- loss:0.040, Epoch accuracy:97.53%, Validation loss:4.782, Validation accuracy:30.61%
# Epoch 269: iteration 29/30
# Epoch 269 --- loss:0.028, Epoch accuracy:98.35%, Validation loss:1.068, Validation accuracy:77.55%
# Epoch 270: iteration 29/30
# Epoch 270 --- loss:0.053, Epoch accuracy:97.33%, Validation loss:4.055, Validation accuracy:48.98%
# Epoch 271: iteration 29/30
# Epoch 271 --- loss:0.045, Epoch accuracy:97.33%, Validation loss:3.657, Validation accuracy:48.98%
# Epoch 272: iteration 29/30
# Epoch 272 --- loss:0.018, Epoch accuracy:98.77%, Validation loss:1.191, Validation accuracy:67.35%
# Epoch 273: iteration 29/30
# Epoch 273 --- loss:0.016, Epoch accuracy:98.35%, Validation loss:2.560, Validation accuracy:51.02%
# Epoch 274: iteration 29/30
# Epoch 274 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:0.811, Validation accuracy:75.51%
# Epoch 275: iteration 29/30
# Epoch 275 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.656, Validation accuracy:77.55%
# Epoch 276: iteration 29/30
# Epoch 276 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.685, Validation accuracy:77.55%
# Epoch 277: iteration 29/30
# Epoch 277 --- loss:0.009, Epoch accuracy:98.56%, Validation loss:1.335, Validation accuracy:59.18%
# Epoch 278: iteration 29/30
# Epoch 278 --- loss:0.018, Epoch accuracy:98.15%, Validation loss:1.275, Validation accuracy:63.27%
# Epoch 279: iteration 29/30
# Epoch 279 --- loss:0.009, Epoch accuracy:98.56%, Validation loss:1.214, Validation accuracy:67.35%
# Epoch 280: iteration 29/30
# Epoch 280 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.606, Validation accuracy:79.59%
# Epoch 281: iteration 29/30
# Epoch 281 --- loss:0.015, Epoch accuracy:98.56%, Validation loss:1.039, Validation accuracy:79.59%
# Epoch 282: iteration 29/30
# Epoch 282 --- loss:0.023, Epoch accuracy:98.15%, Validation loss:0.612, Validation accuracy:79.59%
# Epoch 283: iteration 29/30
# Epoch 283 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:1.025, Validation accuracy:65.31%
# Epoch 284: iteration 29/30
# Epoch 284 --- loss:0.009, Epoch accuracy:98.56%, Validation loss:0.792, Validation accuracy:77.55%
# Epoch 285: iteration 29/30
# Epoch 285 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:0.626, Validation accuracy:81.63%
# Epoch 286: iteration 29/30
# Epoch 286 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.802, Validation accuracy:77.55%
# Epoch 287: iteration 29/30
# Epoch 287 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.561, Validation accuracy:81.63%
# Epoch 288: iteration 29/30
# Epoch 288 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.504, Validation accuracy:81.63%
# Epoch 289: iteration 29/30
# Epoch 289 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:0.852, Validation accuracy:77.55%
# Epoch 290: iteration 29/30
# Epoch 290 --- loss:0.021, Epoch accuracy:98.35%, Validation loss:0.869, Validation accuracy:65.31%
# Epoch 291: iteration 29/30
# Epoch 291 --- loss:0.036, Epoch accuracy:97.74%, Validation loss:1.665, Validation accuracy:65.31%
# Epoch 292: iteration 29/30
# Epoch 292 --- loss:0.053, Epoch accuracy:96.71%, Validation loss:3.486, Validation accuracy:42.86%
# Epoch 293: iteration 29/30
# Epoch 293 --- loss:0.059, Epoch accuracy:96.50%, Validation loss:1.335, Validation accuracy:46.94%
# Epoch 294: iteration 29/30
# Epoch 294 --- loss:0.052, Epoch accuracy:97.33%, Validation loss:11.759, Validation accuracy:12.24%
# Epoch 295: iteration 29/30
# Epoch 295 --- loss:0.030, Epoch accuracy:97.94%, Validation loss:0.626, Validation accuracy:79.59%
# Epoch 296: iteration 29/30
# Epoch 296 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:0.705, Validation accuracy:81.63%
# Epoch 297: iteration 29/30
# Epoch 297 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.818, Validation accuracy:79.59%
# Epoch 298: iteration 29/30
# Epoch 298 --- loss:0.008, Epoch accuracy:98.56%, Validation loss:0.746, Validation accuracy:75.51%
# Epoch 299: iteration 29/30
# Epoch 299 --- loss:0.027, Epoch accuracy:98.15%, Validation loss:1.493, Validation accuracy:63.27%
#
#
# [*] done !
# [*] Best training loss - 0.0033982261908029826
# [*] Best validation loss - 0.3275957405567169
# A Jupyter Widget
# Epoch 0: iteration 28/29
# Epoch 0 --- loss:1.583, Epoch accuracy:30.82%, Validation loss:2.204, Validation accuracy:18.97%
# Epoch 1: iteration 28/29
# Epoch 1 --- loss:1.335, Epoch accuracy:43.61%, Validation loss:1.862, Validation accuracy:27.59%
# Epoch 2: iteration 28/29
# Epoch 2 --- loss:1.213, Epoch accuracy:46.96%, Validation loss:1.127, Validation accuracy:58.62%
# Epoch 3: iteration 28/29
# Epoch 3 --- loss:1.195, Epoch accuracy:49.48%, Validation loss:3.147, Validation accuracy:22.41%
# Epoch 4: iteration 28/29
# Epoch 4 --- loss:1.089, Epoch accuracy:58.07%, Validation loss:1.143, Validation accuracy:58.62%
# Epoch 5: iteration 28/29
# Epoch 5 --- loss:1.017, Epoch accuracy:61.64%, Validation loss:1.723, Validation accuracy:31.03%
# Epoch 6: iteration 28/29
# Epoch 6 --- loss:0.964, Epoch accuracy:59.54%, Validation loss:1.198, Validation accuracy:53.45%
# Epoch 7: iteration 28/29
# Epoch 7 --- loss:0.897, Epoch accuracy:65.41%, Validation loss:2.720, Validation accuracy:31.03%
# Epoch 8: iteration 28/29
# Epoch 8 --- loss:0.894, Epoch accuracy:64.78%, Validation loss:6.454, Validation accuracy:20.69%
# Epoch 9: iteration 28/29
# Epoch 9 --- loss:0.868, Epoch accuracy:68.55%, Validation loss:2.234, Validation accuracy:32.76%
# Epoch 10: iteration 28/29
# Epoch 10 --- loss:0.804, Epoch accuracy:66.04%, Validation loss:1.536, Validation accuracy:41.38%
# Epoch 11: iteration 28/29
# Epoch 11 --- loss:0.782, Epoch accuracy:70.44%, Validation loss:1.705, Validation accuracy:39.66%
# Epoch 12: iteration 28/29
# Epoch 12 --- loss:0.743, Epoch accuracy:71.49%, Validation loss:1.673, Validation accuracy:36.21%
# Epoch 13: iteration 28/29
# Epoch 13 --- loss:0.703, Epoch accuracy:70.23%, Validation loss:3.837, Validation accuracy:34.48%
# Epoch 14: iteration 28/29
# Epoch 14 --- loss:0.678, Epoch accuracy:74.21%, Validation loss:5.208, Validation accuracy:20.69%
# Epoch 15: iteration 28/29
# Epoch 15 --- loss:0.713, Epoch accuracy:71.49%, Validation loss:1.580, Validation accuracy:51.72%
# Epoch 16: iteration 28/29
# Epoch 16 --- loss:0.713, Epoch accuracy:71.28%, Validation loss:1.307, Validation accuracy:48.28%
# Epoch 17: iteration 28/29
# Epoch 17 --- loss:0.704, Epoch accuracy:70.44%, Validation loss:1.462, Validation accuracy:44.83%
# Epoch 18: iteration 28/29
# Epoch 18 --- loss:0.607, Epoch accuracy:76.52%, Validation loss:1.339, Validation accuracy:53.45%
# Epoch 19: iteration 28/29
# Epoch 19 --- loss:0.622, Epoch accuracy:74.21%, Validation loss:3.007, Validation accuracy:37.93%
# Epoch 20: iteration 28/29
# Epoch 20 --- loss:0.614, Epoch accuracy:75.89%, Validation loss:1.106, Validation accuracy:60.34%
# Epoch 21: iteration 28/29
# Epoch 21 --- loss:0.516, Epoch accuracy:77.57%, Validation loss:1.274, Validation accuracy:43.10%
# Epoch 22: iteration 28/29
# Epoch 22 --- loss:0.648, Epoch accuracy:74.00%, Validation loss:8.578, Validation accuracy:22.41%
# Epoch 23: iteration 28/29
# Epoch 23 --- loss:0.537, Epoch accuracy:79.66%, Validation loss:2.383, Validation accuracy:36.21%
# Epoch 24: iteration 28/29
# Epoch 24 --- loss:0.491, Epoch accuracy:81.55%, Validation loss:1.442, Validation accuracy:58.62%
# Epoch 25: iteration 28/29
# Epoch 25 --- loss:0.480, Epoch accuracy:79.87%, Validation loss:1.458, Validation accuracy:51.72%
# Epoch 26: iteration 28/29
# Epoch 26 --- loss:0.486, Epoch accuracy:79.87%, Validation loss:1.868, Validation accuracy:36.21%
# Epoch 27: iteration 28/29
# Epoch 27 --- loss:0.441, Epoch accuracy:83.44%, Validation loss:1.782, Validation accuracy:44.83%
# Epoch 28: iteration 28/29
# Epoch 28 --- loss:0.424, Epoch accuracy:84.49%, Validation loss:1.092, Validation accuracy:58.62%
# Epoch 29: iteration 28/29
# Epoch 29 --- loss:0.457, Epoch accuracy:81.55%, Validation loss:2.472, Validation accuracy:41.38%
# Epoch 30: iteration 28/29
# Epoch 30 --- loss:0.469, Epoch accuracy:80.29%, Validation loss:1.987, Validation accuracy:48.28%
# Epoch 31: iteration 28/29
# Epoch 31 --- loss:0.500, Epoch accuracy:80.92%, Validation loss:2.252, Validation accuracy:55.17%
# Epoch 32: iteration 28/29
# Epoch 32 --- loss:0.428, Epoch accuracy:83.65%, Validation loss:1.767, Validation accuracy:46.55%
# Epoch 33: iteration 28/29
# Epoch 33 --- loss:0.413, Epoch accuracy:81.34%, Validation loss:0.901, Validation accuracy:55.17%
# Epoch 34: iteration 28/29
# Epoch 34 --- loss:0.386, Epoch accuracy:84.91%, Validation loss:0.845, Validation accuracy:65.52%
# Epoch 35: iteration 28/29
# Epoch 35 --- loss:0.412, Epoch accuracy:84.07%, Validation loss:2.403, Validation accuracy:51.72%
# Epoch 36: iteration 28/29
# Epoch 36 --- loss:0.351, Epoch accuracy:86.79%, Validation loss:2.352, Validation accuracy:48.28%
# Epoch 37: iteration 28/29
# Epoch 37 --- loss:0.354, Epoch accuracy:86.37%, Validation loss:1.215, Validation accuracy:79.31%
# Epoch 38: iteration 28/29
# Epoch 38 --- loss:0.368, Epoch accuracy:85.32%, Validation loss:2.679, Validation accuracy:50.00%
# Epoch 39: iteration 28/29
# Epoch 39 --- loss:0.308, Epoch accuracy:89.31%, Validation loss:2.643, Validation accuracy:39.66%
# Epoch 40: iteration 28/29
# Epoch 40 --- loss:0.331, Epoch accuracy:86.58%, Validation loss:5.763, Validation accuracy:25.86%
# Epoch 41: iteration 28/29
# Epoch 41 --- loss:0.317, Epoch accuracy:87.21%, Validation loss:5.625, Validation accuracy:34.48%
# Epoch 42: iteration 28/29
# Epoch 42 --- loss:0.297, Epoch accuracy:87.63%, Validation loss:2.916, Validation accuracy:44.83%
# Epoch 43: iteration 28/29
# Epoch 43 --- loss:0.303, Epoch accuracy:87.42%, Validation loss:5.183, Validation accuracy:27.59%
# Epoch 44: iteration 28/29
# Epoch 44 --- loss:0.295, Epoch accuracy:88.89%, Validation loss:1.959, Validation accuracy:41.38%
# Epoch 45: iteration 28/29
# Epoch 45 --- loss:0.282, Epoch accuracy:88.05%, Validation loss:1.893, Validation accuracy:37.93%
# Epoch 46: iteration 28/29
# Epoch 46 --- loss:0.256, Epoch accuracy:90.15%, Validation loss:4.551, Validation accuracy:32.76%
# Epoch 47: iteration 28/29
# Epoch 47 --- loss:0.291, Epoch accuracy:88.26%, Validation loss:10.104, Validation accuracy:25.86%
# Epoch 48: iteration 28/29
# Epoch 48 --- loss:0.250, Epoch accuracy:90.15%, Validation loss:2.003, Validation accuracy:37.93%
# Epoch 49: iteration 28/29
# Epoch 49 --- loss:0.336, Epoch accuracy:85.12%, Validation loss:3.247, Validation accuracy:46.55%
# Epoch 50: iteration 28/29
# Epoch 50 --- loss:0.260, Epoch accuracy:89.94%, Validation loss:3.940, Validation accuracy:32.76%
# Epoch 51: iteration 28/29
# Epoch 51 --- loss:0.324, Epoch accuracy:87.00%, Validation loss:5.541, Validation accuracy:36.21%
# Epoch 52: iteration 28/29
# Epoch 52 --- loss:0.250, Epoch accuracy:90.57%, Validation loss:7.570, Validation accuracy:20.69%
# Epoch 53: iteration 28/29
# Epoch 53 --- loss:0.214, Epoch accuracy:93.29%, Validation loss:1.595, Validation accuracy:48.28%
# Epoch 54: iteration 28/29
# Epoch 54 --- loss:0.256, Epoch accuracy:88.26%, Validation loss:5.955, Validation accuracy:29.31%
# Epoch 55: iteration 28/29
# Epoch 55 --- loss:0.207, Epoch accuracy:92.66%, Validation loss:1.467, Validation accuracy:53.45%
# Epoch 56: iteration 28/29
# Epoch 56 --- loss:0.172, Epoch accuracy:93.29%, Validation loss:0.996, Validation accuracy:63.79%
# Epoch 57: iteration 28/29
# Epoch 57 --- loss:0.173, Epoch accuracy:93.92%, Validation loss:4.771, Validation accuracy:34.48%
# Epoch 58: iteration 28/29
# Epoch 58 --- loss:0.168, Epoch accuracy:92.24%, Validation loss:3.697, Validation accuracy:39.66%
# Epoch 59: iteration 28/29
# Epoch 59 --- loss:0.215, Epoch accuracy:91.82%, Validation loss:15.001, Validation accuracy:25.86%
# Epoch 60: iteration 28/29
# Epoch 60 --- loss:0.163, Epoch accuracy:92.66%, Validation loss:2.356, Validation accuracy:46.55%
# Epoch 61: iteration 28/29
# Epoch 61 --- loss:0.201, Epoch accuracy:90.78%, Validation loss:2.149, Validation accuracy:60.34%
# Epoch 62: iteration 28/29
# Epoch 62 --- loss:0.158, Epoch accuracy:93.29%, Validation loss:4.919, Validation accuracy:29.31%
# Epoch 63: iteration 28/29
# Epoch 63 --- loss:0.125, Epoch accuracy:94.76%, Validation loss:0.907, Validation accuracy:63.79%
# Epoch 64: iteration 28/29
# Epoch 64 --- loss:0.135, Epoch accuracy:94.55%, Validation loss:4.049, Validation accuracy:37.93%
# Epoch 65: iteration 28/29
# Epoch 65 --- loss:0.109, Epoch accuracy:95.60%, Validation loss:2.018, Validation accuracy:55.17%
# Epoch 66: iteration 28/29
# Epoch 66 --- loss:0.145, Epoch accuracy:92.66%, Validation loss:2.743, Validation accuracy:39.66%
# Epoch 67: iteration 28/29
# Epoch 67 --- loss:0.171, Epoch accuracy:92.03%, Validation loss:3.662, Validation accuracy:27.59%
# Epoch 68: iteration 28/29
# Epoch 68 --- loss:0.171, Epoch accuracy:93.71%, Validation loss:6.868, Validation accuracy:46.55%
# Epoch 69: iteration 28/29
# Epoch 69 --- loss:0.167, Epoch accuracy:92.03%, Validation loss:2.913, Validation accuracy:36.21%
# Epoch 70: iteration 28/29
# Epoch 70 --- loss:0.158, Epoch accuracy:93.08%, Validation loss:1.736, Validation accuracy:51.72%
# Epoch 71: iteration 28/29
# Epoch 71 --- loss:0.209, Epoch accuracy:90.15%, Validation loss:6.293, Validation accuracy:36.21%
# Epoch 72: iteration 28/29
# Epoch 72 --- loss:0.261, Epoch accuracy:88.26%, Validation loss:8.042, Validation accuracy:32.76%
# Epoch 73: iteration 28/29
# Epoch 73 --- loss:0.162, Epoch accuracy:92.66%, Validation loss:2.059, Validation accuracy:43.10%
# Epoch 74: iteration 28/29
# Epoch 74 --- loss:0.101, Epoch accuracy:94.76%, Validation loss:2.765, Validation accuracy:46.55%
# Epoch 75: iteration 28/29
# Epoch 75 --- loss:0.091, Epoch accuracy:95.60%, Validation loss:2.412, Validation accuracy:39.66%
# Epoch 76: iteration 28/29
# Epoch 76 --- loss:0.142, Epoch accuracy:93.92%, Validation loss:3.614, Validation accuracy:55.17%
# Epoch 77: iteration 28/29
# Epoch 77 --- loss:0.132, Epoch accuracy:93.92%, Validation loss:3.679, Validation accuracy:32.76%
# Epoch 78: iteration 28/29
# Epoch 78 --- loss:0.146, Epoch accuracy:93.29%, Validation loss:5.599, Validation accuracy:29.31%
# Epoch 79: iteration 28/29
# Epoch 79 --- loss:0.141, Epoch accuracy:94.34%, Validation loss:1.459, Validation accuracy:51.72%
# Epoch 80: iteration 28/29
# Epoch 80 --- loss:0.084, Epoch accuracy:95.18%, Validation loss:9.327, Validation accuracy:24.14%
# Epoch 81: iteration 28/29
# Epoch 81 --- loss:0.088, Epoch accuracy:96.02%, Validation loss:7.103, Validation accuracy:22.41%
# Epoch 82: iteration 28/29
# ...
# Epoch 175: iteration 28/29
# Epoch 175 --- loss:0.031, Epoch accuracy:99.78%, Validation loss:2.135, Validation accuracy:53.52%
# Epoch 176: iteration 28/29
# Epoch 176 --- loss:0.055, Epoch accuracy:98.28%, Validation loss:4.553, Validation accuracy:25.35%
# Epoch 177: iteration 28/29
# Epoch 177 --- loss:0.029, Epoch accuracy:99.78%, Validation loss:1.311, Validation accuracy:67.61%
# Epoch 178: iteration 28/29
# Epoch 178 --- loss:0.014, Epoch accuracy:100.00%, Validation loss:1.568, Validation accuracy:59.15%
# Epoch 179: iteration 28/29
# Epoch 179 --- loss:0.036, Epoch accuracy:99.35%, Validation loss:3.102, Validation accuracy:47.89%
# Epoch 180: iteration 28/29
# Epoch 180 --- loss:0.054, Epoch accuracy:98.92%, Validation loss:2.490, Validation accuracy:57.75%
# Epoch 181: iteration 28/29
# Epoch 181 --- loss:0.038, Epoch accuracy:99.35%, Validation loss:1.505, Validation accuracy:52.11%
# Epoch 182: iteration 28/29
# Epoch 182 --- loss:0.019, Epoch accuracy:99.78%, Validation loss:1.822, Validation accuracy:50.70%
# Epoch 183: iteration 28/29
# Epoch 183 --- loss:0.030, Epoch accuracy:99.35%, Validation loss:2.507, Validation accuracy:50.70%
# Epoch 184: iteration 28/29
# Epoch 184 --- loss:0.042, Epoch accuracy:99.35%, Validation loss:3.453, Validation accuracy:35.21%
# Epoch 185: iteration 28/29
# Epoch 185 --- loss:0.015, Epoch accuracy:100.00%, Validation loss:2.782, Validation accuracy:52.11%
# Epoch 186: iteration 28/29
# Epoch 186 --- loss:0.020, Epoch accuracy:99.78%, Validation loss:5.261, Validation accuracy:43.66%
# Epoch 187: iteration 28/29
# Epoch 187 --- loss:0.026, Epoch accuracy:99.78%, Validation loss:1.807, Validation accuracy:63.38%
# Epoch 188: iteration 28/29
# Epoch 188 --- loss:0.028, Epoch accuracy:99.57%, Validation loss:3.139, Validation accuracy:47.89%
# Epoch 189: iteration 28/29
# Epoch 189 --- loss:0.014, Epoch accuracy:100.00%, Validation loss:3.069, Validation accuracy:43.66%
# Epoch 190: iteration 28/29
# Epoch 190 --- loss:0.028, Epoch accuracy:99.57%, Validation loss:1.984, Validation accuracy:63.38%
# Epoch 191: iteration 28/29
# Epoch 191 --- loss:0.019, Epoch accuracy:100.00%, Validation loss:2.776, Validation accuracy:50.70%
# Epoch 192: iteration 28/29
# Epoch 192 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.222, Validation accuracy:63.38%
# Epoch 193: iteration 28/29
# Epoch 193 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:1.582, Validation accuracy:53.52%
# Epoch 194: iteration 28/29
# Epoch 194 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.617, Validation accuracy:60.56%
# Epoch 195: iteration 28/29
# Epoch 195 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.571, Validation accuracy:56.34%
# Epoch 196: iteration 28/29
# Epoch 196 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.636, Validation accuracy:60.56%
# Epoch 197: iteration 28/29
# Epoch 197 --- loss:0.013, Epoch accuracy:99.78%, Validation loss:1.620, Validation accuracy:59.15%
# Epoch 198: iteration 28/29
# Epoch 198 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.444, Validation accuracy:47.89%
# Epoch 199: iteration 28/29
# Epoch 199 --- loss:0.017, Epoch accuracy:99.78%, Validation loss:1.472, Validation accuracy:63.38%
# Epoch 200: iteration 28/29
# Epoch 200 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.663, Validation accuracy:57.75%
# Epoch 201: iteration 28/29
# Epoch 201 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:1.931, Validation accuracy:53.52%
# Epoch 202: iteration 28/29
# Epoch 202 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:3.089, Validation accuracy:49.30%
# Epoch 203: iteration 28/29
# Epoch 203 --- loss:0.018, Epoch accuracy:99.57%, Validation loss:2.683, Validation accuracy:59.15%
# Epoch 204: iteration 28/29
# Epoch 204 --- loss:0.033, Epoch accuracy:98.92%, Validation loss:6.131, Validation accuracy:25.35%
# Epoch 205: iteration 28/29
# Epoch 205 --- loss:0.077, Epoch accuracy:97.20%, Validation loss:9.253, Validation accuracy:25.35%
# Epoch 206: iteration 28/29
# Epoch 206 --- loss:0.104, Epoch accuracy:97.20%, Validation loss:3.813, Validation accuracy:43.66%
# Epoch 207: iteration 28/29
# Epoch 207 --- loss:0.058, Epoch accuracy:98.71%, Validation loss:3.474, Validation accuracy:35.21%
# Epoch 208: iteration 28/29
# Epoch 208 --- loss:0.051, Epoch accuracy:98.92%, Validation loss:9.145, Validation accuracy:33.80%
# Epoch 209: iteration 28/29
# Epoch 209 --- loss:0.104, Epoch accuracy:96.12%, Validation loss:2.056, Validation accuracy:54.93%
# Epoch 210: iteration 28/29
# Epoch 210 --- loss:0.057, Epoch accuracy:98.28%, Validation loss:2.891, Validation accuracy:39.44%
# Epoch 211: iteration 28/29
# Epoch 211 --- loss:0.137, Epoch accuracy:94.18%, Validation loss:8.395, Validation accuracy:36.62%
# Epoch 212: iteration 28/29
# Epoch 212 --- loss:0.074, Epoch accuracy:97.63%, Validation loss:2.576, Validation accuracy:54.93%
# Epoch 213: iteration 28/29
# Epoch 213 --- loss:0.040, Epoch accuracy:99.14%, Validation loss:4.460, Validation accuracy:43.66%
# Epoch 214: iteration 28/29
# Epoch 214 --- loss:0.019, Epoch accuracy:99.78%, Validation loss:2.032, Validation accuracy:43.66%
# Epoch 215: iteration 28/29
# Epoch 215 --- loss:0.041, Epoch accuracy:98.92%, Validation loss:2.403, Validation accuracy:53.52%
# Epoch 216: iteration 28/29
# Epoch 216 --- loss:0.016, Epoch accuracy:100.00%, Validation loss:2.389, Validation accuracy:49.30%
# Epoch 217: iteration 28/29
# Epoch 217 --- loss:0.018, Epoch accuracy:99.78%, Validation loss:1.604, Validation accuracy:66.20%
# Epoch 218: iteration 28/29
# Epoch 218 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:1.744, Validation accuracy:59.15%
# Epoch 219: iteration 28/29
# Epoch 219 --- loss:0.022, Epoch accuracy:99.57%, Validation loss:3.125, Validation accuracy:50.70%
# Epoch 220: iteration 28/29
# Epoch 220 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:2.045, Validation accuracy:57.75%
# Epoch 221: iteration 28/29
# Epoch 221 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.440, Validation accuracy:52.11%
# Epoch 222: iteration 28/29
# Epoch 222 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:1.696, Validation accuracy:57.75%
# Epoch 223: iteration 28/29
# Epoch 223 --- loss:0.013, Epoch accuracy:99.78%, Validation loss:1.566, Validation accuracy:60.56%
# Epoch 224: iteration 28/29
# Epoch 224 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:3.302, Validation accuracy:52.11%
# Epoch 225: iteration 28/29
# Epoch 225 --- loss:0.042, Epoch accuracy:98.92%, Validation loss:10.671, Validation accuracy:35.21%
# Epoch 226: iteration 28/29
# Epoch 226 --- loss:0.027, Epoch accuracy:99.35%, Validation loss:2.377, Validation accuracy:54.93%
# Epoch 227: iteration 28/29
# Epoch 227 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:4.882, Validation accuracy:28.17%
# Epoch 228: iteration 28/29
# Epoch 228 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:3.254, Validation accuracy:53.52%
# Epoch 229: iteration 28/29
# Epoch 229 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:2.122, Validation accuracy:56.34%
# Epoch 230: iteration 28/29
# Epoch 230 --- loss:0.011, Epoch accuracy:99.78%, Validation loss:1.442, Validation accuracy:69.01%
# Epoch 231: iteration 28/29
# Epoch 231 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:1.817, Validation accuracy:54.93%
# Epoch 232: iteration 28/29
# Epoch 232 --- loss:0.010, Epoch accuracy:99.78%, Validation loss:3.653, Validation accuracy:52.11%
# Epoch 233: iteration 28/29
# Epoch 233 --- loss:0.022, Epoch accuracy:99.57%, Validation loss:1.322, Validation accuracy:66.20%
# Epoch 234: iteration 28/29
# Epoch 234 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:3.648, Validation accuracy:39.44%
# Epoch 235: iteration 28/29
# Epoch 235 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:3.263, Validation accuracy:56.34%
# Epoch 236: iteration 28/29
# Epoch 236 --- loss:0.023, Epoch accuracy:99.57%, Validation loss:1.271, Validation accuracy:66.20%
# Epoch 237: iteration 28/29
# Epoch 237 --- loss:0.030, Epoch accuracy:99.35%, Validation loss:2.435, Validation accuracy:56.34%
# Epoch 238: iteration 28/29
# Epoch 238 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.772, Validation accuracy:47.89%
# Epoch 239: iteration 28/29
# Epoch 239 --- loss:0.010, Epoch accuracy:99.78%, Validation loss:2.125, Validation accuracy:60.56%
# Epoch 240: iteration 28/29
# Epoch 240 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:2.070, Validation accuracy:60.56%
# Epoch 241: iteration 28/29
# Epoch 241 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:2.530, Validation accuracy:46.48%
# Epoch 242: iteration 28/29
# Epoch 242 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:1.583, Validation accuracy:59.15%
# Epoch 243: iteration 28/29
# Epoch 243 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.904, Validation accuracy:57.75%
# Epoch 244: iteration 28/29
# Epoch 244 --- loss:0.016, Epoch accuracy:99.57%, Validation loss:8.512, Validation accuracy:26.76%
# Epoch 245: iteration 28/29
# Epoch 245 --- loss:0.048, Epoch accuracy:98.71%, Validation loss:3.949, Validation accuracy:46.48%
# Epoch 246: iteration 28/29
# Epoch 246 --- loss:0.045, Epoch accuracy:98.92%, Validation loss:1.284, Validation accuracy:63.38%
# Epoch 247: iteration 28/29
# Epoch 247 --- loss:0.026, Epoch accuracy:99.57%, Validation loss:1.954, Validation accuracy:59.15%
# Epoch 248: iteration 28/29
# Epoch 248 --- loss:0.022, Epoch accuracy:99.78%, Validation loss:1.425, Validation accuracy:61.97%
# Epoch 249: iteration 28/29
# Epoch 249 --- loss:0.028, Epoch accuracy:99.57%, Validation loss:1.418, Validation accuracy:59.15%
# Epoch 250: iteration 28/29
# Epoch 250 --- loss:0.025, Epoch accuracy:99.35%, Validation loss:3.919, Validation accuracy:50.70%
# Epoch 251: iteration 28/29
# Epoch 251 --- loss:0.012, Epoch accuracy:99.35%, Validation loss:4.796, Validation accuracy:40.85%
# Epoch 252: iteration 28/29
# Epoch 252 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:1.435, Validation accuracy:67.61%
# Epoch 253: iteration 28/29
# Epoch 253 --- loss:0.053, Epoch accuracy:98.49%, Validation loss:13.340, Validation accuracy:21.13%
# Epoch 254: iteration 28/29
# Epoch 254 --- loss:0.043, Epoch accuracy:99.35%, Validation loss:3.640, Validation accuracy:54.93%
# Epoch 255: iteration 28/29
# Epoch 255 --- loss:0.019, Epoch accuracy:99.78%, Validation loss:1.716, Validation accuracy:59.15%
# Epoch 256: iteration 28/29
# Epoch 256 --- loss:0.014, Epoch accuracy:100.00%, Validation loss:1.567, Validation accuracy:61.97%
# Epoch 257: iteration 28/29
# Epoch 257 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:1.711, Validation accuracy:53.52%
# Epoch 258: iteration 28/29
# Epoch 258 --- loss:0.026, Epoch accuracy:99.57%, Validation loss:6.146, Validation accuracy:47.89%
# Epoch 259: iteration 28/29
# Epoch 259 --- loss:0.028, Epoch accuracy:99.35%, Validation loss:3.148, Validation accuracy:43.66%
# Epoch 260: iteration 28/29
# Epoch 260 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:1.298, Validation accuracy:66.20%
# Epoch 261: iteration 28/29
# Epoch 261 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:1.715, Validation accuracy:64.79%
# Epoch 262: iteration 28/29
# Epoch 262 --- loss:0.020, Epoch accuracy:99.35%, Validation loss:4.181, Validation accuracy:45.07%
# Epoch 263: iteration 28/29
# Epoch 263 --- loss:0.024, Epoch accuracy:99.14%, Validation loss:3.443, Validation accuracy:42.25%
# Epoch 264: iteration 28/29
# Epoch 264 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:2.723, Validation accuracy:47.89%
# Epoch 265: iteration 28/29
# Epoch 265 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:2.892, Validation accuracy:56.34%
# Epoch 266: iteration 28/29
# Epoch 266 --- loss:0.016, Epoch accuracy:100.00%, Validation loss:2.082, Validation accuracy:59.15%
# Epoch 267: iteration 28/29
# Epoch 267 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.436, Validation accuracy:52.11%
# Epoch 268: iteration 28/29
# Epoch 268 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.860, Validation accuracy:53.52%
# Epoch 269: iteration 28/29
# Epoch 269 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:1.143, Validation accuracy:64.79%
# Epoch 270: iteration 28/29
# Epoch 270 --- loss:0.036, Epoch accuracy:98.92%, Validation loss:7.478, Validation accuracy:23.94%
# Epoch 271: iteration 28/29
# Epoch 271 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:1.909, Validation accuracy:59.15%
# Epoch 272: iteration 28/29
# Epoch 272 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.683, Validation accuracy:54.93%
# Epoch 273: iteration 28/29
# Epoch 273 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.637, Validation accuracy:63.38%
# Epoch 274: iteration 28/29
# Epoch 274 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.821, Validation accuracy:56.34%
# Epoch 275: iteration 28/29
# Epoch 275 --- loss:0.005, Epoch accuracy:100.00%, Validation loss:1.380, Validation accuracy:60.56%
# Epoch 276: iteration 28/29
# Epoch 276 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:2.105, Validation accuracy:60.56%
# Epoch 277: iteration 28/29
# Epoch 277 --- loss:0.004, Epoch accuracy:100.00%, Validation loss:1.620, Validation accuracy:63.38%
# Epoch 278: iteration 28/29
# Epoch 278 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.510, Validation accuracy:63.38%
# Epoch 279: iteration 28/29
# Epoch 279 --- loss:0.005, Epoch accuracy:100.00%, Validation loss:1.993, Validation accuracy:64.79%
# Epoch 280: iteration 28/29
# Epoch 280 --- loss:0.005, Epoch accuracy:100.00%, Validation loss:1.730, Validation accuracy:61.97%
# Epoch 281: iteration 28/29
# Epoch 281 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.196, Validation accuracy:76.06%
# Epoch 282: iteration 28/29
# Epoch 282 --- loss:0.004, Epoch accuracy:100.00%, Validation loss:3.661, Validation accuracy:57.75%
# Epoch 283: iteration 28/29
# Epoch 283 --- loss:0.008, Epoch accuracy:99.78%, Validation loss:4.634, Validation accuracy:45.07%
# Epoch 284: iteration 28/29
# Epoch 284 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:2.698, Validation accuracy:56.34%
# Epoch 285: iteration 28/29
# Epoch 285 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.480, Validation accuracy:63.38%
# Epoch 286: iteration 28/29
# Epoch 286 --- loss:0.010, Epoch accuracy:99.78%, Validation loss:1.404, Validation accuracy:63.38%
# Epoch 287: iteration 28/29
# Epoch 287 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:2.947, Validation accuracy:53.52%
# Epoch 288: iteration 28/29
# Epoch 288 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.420, Validation accuracy:60.56%
# Epoch 289: iteration 28/29
# Epoch 289 --- loss:0.005, Epoch accuracy:100.00%, Validation loss:1.561, Validation accuracy:64.79%
# Epoch 290: iteration 28/29
# Epoch 290 --- loss:0.008, Epoch accuracy:99.78%, Validation loss:1.854, Validation accuracy:63.38%
# Epoch 291: iteration 28/29
# Epoch 291 --- loss:0.023, Epoch accuracy:99.35%, Validation loss:10.990, Validation accuracy:30.99%
# Epoch 292: iteration 28/29
# Epoch 292 --- loss:0.070, Epoch accuracy:98.28%, Validation loss:5.801, Validation accuracy:23.94%
# Epoch 293: iteration 28/29
# Epoch 293 --- loss:0.030, Epoch accuracy:99.35%, Validation loss:4.405, Validation accuracy:43.66%
# Epoch 294: iteration 28/29
# Epoch 294 --- loss:0.030, Epoch accuracy:99.35%, Validation loss:1.768, Validation accuracy:57.75%
# Epoch 295: iteration 28/29
# Epoch 295 --- loss:0.028, Epoch accuracy:99.35%, Validation loss:1.935, Validation accuracy:54.93%
# Epoch 296: iteration 28/29
# Epoch 296 --- loss:0.028, Epoch accuracy:99.35%, Validation loss:1.700, Validation accuracy:60.56%
# Epoch 297: iteration 28/29
# Epoch 297 --- loss:0.032, Epoch accuracy:99.35%, Validation loss:9.357, Validation accuracy:22.54%
# Epoch 298: iteration 28/29
# Epoch 298 --- loss:0.027, Epoch accuracy:99.14%, Validation loss:5.095, Validation accuracy:36.62%
# Epoch 299: iteration 28/29
# Epoch 299 --- loss:0.017, Epoch accuracy:99.78%, Validation loss:6.560, Validation accuracy:42.25%
#
#
# [*] done !
# [*] Best training loss - 0.003950641189444939
# [*] Best validation loss - 0.8508897423744202

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

for fold in range(10):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, f'delta-fold{fold}.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    
    test_accs.append(test_acc)
    
    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, emotions_groundtruth)
    predicted_emotions_list = np.append(predicted_emotions_list, predicted_emotions)

# %%
os.makedirs('result', exist_ok=True)

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)
print(Report)

with open(f"result/{sub_name}_{loss_name}_Report.txt", "w") as f:
    f.write(Report)

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f"result/{sub_name}_{loss_name}_confmatrix.pdf")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.83      0.85       127
#          1.0       0.75      0.74      0.74        69
#          2.0       0.78      0.83      0.80        81
#          3.0       0.72      0.72      0.72        46
#          4.0       0.59      0.66      0.63        71
#          5.0       0.83      0.76      0.79        79
#          6.0       0.90      0.92      0.91        62
#
#     accuracy                           0.79       535
#    macro avg       0.78      0.78      0.78       535
# weighted avg       0.79      0.79      0.79       535

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 86.84%
# [*] Worst fold acc : 65.45%
# [*] Average fold acc : 79.36%
