# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F

class resnet18_finetune(nn.Module):
    def __init__(self, num_emotions) -> None:
        super().__init__()
        
        self.model_ft = models.resnet18(pretrained=True)
        self.model_ft = nn.Sequential(*(list(self.model_ft.children())[:-1]))
        
        for name, param in self.model_ft[:4].named_parameters():
            param.requires_grad=False
        
        self.fc_linear = nn.Linear(512, 8)
        
        self.softmax_out = nn.Softmax(dim=1)
    
    def forward(self, x):
        
        output = self.model_ft(x)
        output = torch.flatten(output, start_dim=1)
        output_logits = self.fc_linear(output)
        output_softmax = self.softmax_out(output_logits)
        
        return output_logits, output_softmax

# %%
import os
import torch
import numpy as np
from torchinfo import summary
from tqdm.auto import tqdm

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

emotions_dict = {
    0: 'Neutral',
    1: 'Calm',
    2: 'Happy',
    3: 'Sad',
    4: 'Angry',
    5: 'Fear',
    6: 'Disgust',
    7: 'Surprise'
}

model = resnet18_finetune(num_emotions=len(emotions_dict)).to('cuda')
sub_name = 'resnet_18_finetune'
data_name = 'RAVDESS'
EARLY_CNT = 500

minibatch = 128
num_epochs = 500
optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)

print(summary(model, input_size=(minibatch, 3, 224, 224)))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# resnet18_finetune                             [128, 8]                  --
# ├─Sequential: 1-1                             [128, 512, 1, 1]          --
# │    └─Conv2d: 2-1                            [128, 64, 112, 112]       (9,408)
# │    └─BatchNorm2d: 2-2                       [128, 64, 112, 112]       (128)
# │    └─ReLU: 2-3                              [128, 64, 112, 112]       --
# │    └─MaxPool2d: 2-4                         [128, 64, 56, 56]         --
# │    └─Sequential: 2-5                        [128, 64, 56, 56]         --
# │    │    └─BasicBlock: 3-1                   [128, 64, 56, 56]         73,984
# │    │    └─BasicBlock: 3-2                   [128, 64, 56, 56]         73,984
# │    └─Sequential: 2-6                        [128, 128, 28, 28]        --
# │    │    └─BasicBlock: 3-3                   [128, 128, 28, 28]        230,144
# │    │    └─BasicBlock: 3-4                   [128, 128, 28, 28]        295,424
# │    └─Sequential: 2-7                        [128, 256, 14, 14]        --
# │    │    └─BasicBlock: 3-5                   [128, 256, 14, 14]        919,040
# │    │    └─BasicBlock: 3-6                   [128, 256, 14, 14]        1,180,672
# │    └─Sequential: 2-8                        [128, 512, 7, 7]          --
# │    │    └─BasicBlock: 3-7                   [128, 512, 7, 7]          3,673,088
# │    │    └─BasicBlock: 3-8                   [128, 512, 7, 7]          4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [128, 512, 1, 1]          --
# ├─Linear: 1-2                                 [128, 8]                  4,104
# ├─Softmax: 1-3                                [128, 8]                  --
# ===============================================================================================
# Total params: 11,180,616
# Trainable params: 11,171,080
# Non-trainable params: 9,536
# Total mult-adds (G): 232.14
# ===============================================================================================
# Input size (MB): 77.07
# Forward/backward pass size (MB): 5086.65
# Params size (MB): 44.72
# Estimated Total Size (MB): 5208.44
# ===============================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
from typing import Optional

def label_to_one_hot_label(
    labels: torch.Tensor,
    num_classes: int,
    device: Optional[torch.device] = None,
    dtype: Optional[torch.dtype] = None,
    eps: float = 1e-6,
    ignore_index=255,
) -> torch.Tensor:

    shape = labels.shape
    # one hot : (B, C=ignore_index+1, H, W)
    one_hot = torch.zeros((shape[0], ignore_index+1) + shape[1:], device=device, dtype=dtype)
    
    # labels : (B, H, W)
    # labels.unsqueeze(1) : (B, C=1, H, W)
    # one_hot : (B, C=ignore_index+1, H, W)
    one_hot = one_hot.scatter_(1, labels.unsqueeze(1), 1.0) + eps
    
    # ret : (B, C=num_classes, H, W)
    ret = torch.split(one_hot, [num_classes, ignore_index+1-num_classes], dim=1)[0]
    
    return ret


def focal_loss(input, target, alpha, gamma, reduction, eps, ignore_index):
    
    if not isinstance(input, torch.Tensor):
        raise TypeError(f"Input type is not a torch.Tensor. Got {type(input)}")

    if not len(input.shape) >= 2:
        raise ValueError(f"Invalid input shape, we expect BxCx*. Got: {input.shape}")

    if input.size(0) != target.size(0):
        raise ValueError(f'Expected input batch_size ({input.size(0)}) to match target batch_size ({target.size(0)}).')    
        
    # compute softmax over the classes axis
    # input_soft : (B, C, H, W)
    input_soft = F.softmax(input, dim=1) + eps
    
    # create the labels one hot tensor
    # target_one_hot : (B, C, H, W)
    target_one_hot = label_to_one_hot_label(target.long(), num_classes=input.shape[1], device=input.device, dtype=input.dtype, ignore_index=ignore_index)

    # compute the actual focal loss
    weight = torch.pow(1.0 - input_soft, gamma)
    
    # alpha, weight, input_soft : (B, C, H, W)
    # focal : (B, C, H, W)
    focal = -alpha * weight * torch.log(input_soft)
    
    # loss_tmp : (B, H, W)
    loss_tmp = torch.sum(target_one_hot * focal, dim=1)

    if reduction == 'none':
        # loss : (B, H, W)
        loss = loss_tmp
    elif reduction == 'mean':
        # loss : scalar
        loss = torch.mean(loss_tmp)
    elif reduction == 'sum':
        # loss : scalar
        loss = torch.sum(loss_tmp)
    else:
        raise NotImplementedError(f"Invalid reduction mode: {reduction}")
    return loss

class FocalLoss(nn.Module):
    def __init__(self, alpha, gamma = 2.0, reduction = 'mean', eps = 1e-8, ignore_index=30):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        self.eps = eps
        self.ignore_index = ignore_index

    def forward(self, input, target):
        return focal_loss(input, target, self.alpha, self.gamma, self.reduction, self.eps, self.ignore_index)


def criterion(predictions, targets):
    return FocalLoss(alpha=0.5, gamma=2.0, reduction='mean')(predictions, targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            X_tensor = X_tensor.permute(0, 3, 1, 2)
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        X_valid_tensor = X_valid_tensor.permute(0, 3, 1, 2)
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import cv2
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(cur_fold_path):
    X_train, y_train, X_test, y_test = [], [], [], []
    
    train_f = open(os.path.join(cur_fold_path, 'train.csv'), 'r')
    test_f = open(os.path.join(cur_fold_path, 'test.csv'), 'r')
    
    train_reader = csv.reader(train_f)
    for r in train_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_train.append(image)
        y_train.append(int(r[1]))
        
    test_reader = csv.reader(test_f)
    for r in test_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_test.append(image)
        y_test.append(int(r[1]))
    
    return np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

# %%
all_fold_dataset = []

for fold in tqdm(range(5), desc='load melspectrogram fold dataset'):
    cur_fold_path = os.path.join('melspectrogram_fold', str(fold))
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    all_fold_dataset.append([X_train, y_train, X_test, y_test])
# Out:
# load melspectrogram fold dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'melspectrogram_fold'

for fold in range(5):
    cur = all_fold_dataset[fold]
    
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - resnet_18_finetune
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 7/8
# Epoch 0 --- loss:0.812, Epoch accuracy:11.93%, Validation loss:0.881, Validation accuracy:12.00%
# Epoch 1: iteration 7/8
# Epoch 1 --- loss:0.799, Epoch accuracy:12.81%, Validation loss:0.860, Validation accuracy:14.00%
# Epoch 2: iteration 7/8
# Epoch 2 --- loss:0.787, Epoch accuracy:13.33%, Validation loss:0.868, Validation accuracy:14.00%
# Epoch 3: iteration 7/8
# Epoch 3 --- loss:0.780, Epoch accuracy:13.33%, Validation loss:0.883, Validation accuracy:14.33%
# Epoch 4: iteration 7/8
# Epoch 4 --- loss:0.769, Epoch accuracy:13.42%, Validation loss:0.892, Validation accuracy:15.00%
# Epoch 5: iteration 7/8
# Epoch 5 --- loss:0.757, Epoch accuracy:14.30%, Validation loss:0.873, Validation accuracy:16.33%
# Epoch 6: iteration 7/8
# Epoch 6 --- loss:0.752, Epoch accuracy:13.60%, Validation loss:0.860, Validation accuracy:17.33%
# Epoch 7: iteration 7/8
# Epoch 7 --- loss:0.747, Epoch accuracy:12.89%, Validation loss:0.850, Validation accuracy:17.00%
# Epoch 8: iteration 7/8
# Epoch 8 --- loss:0.730, Epoch accuracy:14.65%, Validation loss:0.844, Validation accuracy:16.67%
# Epoch 9: iteration 7/8
# Epoch 9 --- loss:0.726, Epoch accuracy:14.21%, Validation loss:0.838, Validation accuracy:16.67%
# Epoch 10: iteration 7/8
# Epoch 10 --- loss:0.715, Epoch accuracy:14.74%, Validation loss:0.832, Validation accuracy:16.67%
# Epoch 11: iteration 7/8
# Epoch 11 --- loss:0.708, Epoch accuracy:14.65%, Validation loss:0.826, Validation accuracy:16.67%
# Epoch 12: iteration 7/8
# Epoch 12 --- loss:0.694, Epoch accuracy:16.05%, Validation loss:0.821, Validation accuracy:16.67%
# Epoch 13: iteration 7/8
# Epoch 13 --- loss:0.690, Epoch accuracy:15.96%, Validation loss:0.816, Validation accuracy:16.33%
# Epoch 14: iteration 7/8
# Epoch 14 --- loss:0.677, Epoch accuracy:15.61%, Validation loss:0.811, Validation accuracy:16.33%
# Epoch 15: iteration 7/8
# Epoch 15 --- loss:0.670, Epoch accuracy:16.75%, Validation loss:0.806, Validation accuracy:16.67%
# Epoch 16: iteration 7/8
# Epoch 16 --- loss:0.663, Epoch accuracy:17.11%, Validation loss:0.801, Validation accuracy:16.67%
# Epoch 17: iteration 7/8
# Epoch 17 --- loss:0.654, Epoch accuracy:17.46%, Validation loss:0.797, Validation accuracy:16.67%
# Epoch 18: iteration 7/8
# Epoch 18 --- loss:0.649, Epoch accuracy:16.49%, Validation loss:0.791, Validation accuracy:16.67%
# Epoch 19: iteration 7/8
# Epoch 19 --- loss:0.641, Epoch accuracy:17.46%, Validation loss:0.787, Validation accuracy:16.67%
# Epoch 20: iteration 7/8
# Epoch 20 --- loss:0.631, Epoch accuracy:17.89%, Validation loss:0.783, Validation accuracy:16.67%
# Epoch 21: iteration 7/8
# Epoch 21 --- loss:0.621, Epoch accuracy:18.68%, Validation loss:0.779, Validation accuracy:16.67%
# Epoch 22: iteration 7/8
# Epoch 22 --- loss:0.617, Epoch accuracy:19.21%, Validation loss:0.775, Validation accuracy:16.67%
# Epoch 23: iteration 7/8
# Epoch 23 --- loss:0.612, Epoch accuracy:19.74%, Validation loss:0.770, Validation accuracy:16.67%
# Epoch 24: iteration 7/8
# Epoch 24 --- loss:0.600, Epoch accuracy:20.35%, Validation loss:0.766, Validation accuracy:17.67%
# Epoch 25: iteration 7/8
# Epoch 25 --- loss:0.590, Epoch accuracy:21.84%, Validation loss:0.761, Validation accuracy:17.67%
# Epoch 26: iteration 7/8
# Epoch 26 --- loss:0.584, Epoch accuracy:22.37%, Validation loss:0.757, Validation accuracy:18.00%
# Epoch 27: iteration 7/8
# Epoch 27 --- loss:0.580, Epoch accuracy:22.54%, Validation loss:0.753, Validation accuracy:18.00%
# Epoch 28: iteration 7/8
# Epoch 28 --- loss:0.570, Epoch accuracy:23.25%, Validation loss:0.749, Validation accuracy:18.67%
# Epoch 29: iteration 7/8
# Epoch 29 --- loss:0.562, Epoch accuracy:23.51%, Validation loss:0.745, Validation accuracy:18.33%
# Epoch 30: iteration 7/8
# Epoch 30 --- loss:0.555, Epoch accuracy:24.65%, Validation loss:0.740, Validation accuracy:19.33%
# Epoch 31: iteration 7/8
# Epoch 31 --- loss:0.551, Epoch accuracy:25.44%, Validation loss:0.736, Validation accuracy:19.33%
# Epoch 32: iteration 7/8
# Epoch 32 --- loss:0.542, Epoch accuracy:26.05%, Validation loss:0.732, Validation accuracy:19.33%
# Epoch 33: iteration 7/8
# Epoch 33 --- loss:0.534, Epoch accuracy:26.58%, Validation loss:0.728, Validation accuracy:20.00%
# Epoch 34: iteration 7/8
# Epoch 34 --- loss:0.528, Epoch accuracy:28.07%, Validation loss:0.724, Validation accuracy:20.00%
# Epoch 35: iteration 7/8
# Epoch 35 --- loss:0.523, Epoch accuracy:27.54%, Validation loss:0.721, Validation accuracy:20.00%
# Epoch 36: iteration 7/8
# Epoch 36 --- loss:0.515, Epoch accuracy:29.39%, Validation loss:0.717, Validation accuracy:20.33%
# Epoch 37: iteration 7/8
# Epoch 37 --- loss:0.511, Epoch accuracy:29.39%, Validation loss:0.713, Validation accuracy:20.33%
# Epoch 38: iteration 7/8
# Epoch 38 --- loss:0.501, Epoch accuracy:31.58%, Validation loss:0.709, Validation accuracy:20.33%
# Epoch 39: iteration 7/8
# Epoch 39 --- loss:0.495, Epoch accuracy:32.46%, Validation loss:0.706, Validation accuracy:20.33%
# Epoch 40: iteration 7/8
# Epoch 40 --- loss:0.490, Epoch accuracy:32.98%, Validation loss:0.702, Validation accuracy:20.33%
# Epoch 41: iteration 7/8
# Epoch 41 --- loss:0.488, Epoch accuracy:33.33%, Validation loss:0.699, Validation accuracy:20.33%
# Epoch 42: iteration 7/8
# Epoch 42 --- loss:0.478, Epoch accuracy:34.30%, Validation loss:0.695, Validation accuracy:20.33%
# Epoch 43: iteration 7/8
# Epoch 43 --- loss:0.475, Epoch accuracy:35.79%, Validation loss:0.693, Validation accuracy:21.00%
# Epoch 44: iteration 7/8
# Epoch 44 --- loss:0.464, Epoch accuracy:37.81%, Validation loss:0.688, Validation accuracy:21.67%
# Epoch 45: iteration 7/8
# Epoch 45 --- loss:0.459, Epoch accuracy:38.60%, Validation loss:0.685, Validation accuracy:22.67%
# Epoch 46: iteration 7/8
# Epoch 46 --- loss:0.455, Epoch accuracy:39.21%, Validation loss:0.682, Validation accuracy:22.67%
# Epoch 47: iteration 7/8
# Epoch 47 --- loss:0.448, Epoch accuracy:40.61%, Validation loss:0.679, Validation accuracy:23.33%
# Epoch 48: iteration 7/8
# Epoch 48 --- loss:0.442, Epoch accuracy:41.40%, Validation loss:0.676, Validation accuracy:23.33%
# Epoch 49: iteration 7/8
# Epoch 49 --- loss:0.437, Epoch accuracy:43.60%, Validation loss:0.673, Validation accuracy:24.67%
# Epoch 50: iteration 7/8
# Epoch 50 --- loss:0.433, Epoch accuracy:43.77%, Validation loss:0.670, Validation accuracy:25.33%
# Epoch 51: iteration 7/8
# Epoch 51 --- loss:0.427, Epoch accuracy:45.53%, Validation loss:0.665, Validation accuracy:26.00%
# Epoch 52: iteration 7/8
# Epoch 52 --- loss:0.420, Epoch accuracy:46.93%, Validation loss:0.663, Validation accuracy:25.67%
# Epoch 53: iteration 7/8
# Epoch 53 --- loss:0.421, Epoch accuracy:45.96%, Validation loss:0.661, Validation accuracy:25.67%
# Epoch 54: iteration 7/8
# Epoch 54 --- loss:0.412, Epoch accuracy:47.72%, Validation loss:0.658, Validation accuracy:26.00%
# Epoch 55: iteration 7/8
# Epoch 55 --- loss:0.406, Epoch accuracy:49.04%, Validation loss:0.655, Validation accuracy:25.33%
# Epoch 56: iteration 7/8
# Epoch 56 --- loss:0.399, Epoch accuracy:49.91%, Validation loss:0.652, Validation accuracy:26.00%
# Epoch 57: iteration 7/8
# Epoch 57 --- loss:0.399, Epoch accuracy:50.35%, Validation loss:0.649, Validation accuracy:26.67%
# Epoch 58: iteration 7/8
# Epoch 58 --- loss:0.387, Epoch accuracy:53.25%, Validation loss:0.647, Validation accuracy:26.67%
# Epoch 59: iteration 7/8
# Epoch 59 --- loss:0.386, Epoch accuracy:52.89%, Validation loss:0.643, Validation accuracy:26.67%
# Epoch 60: iteration 7/8
# Epoch 60 --- loss:0.386, Epoch accuracy:53.16%, Validation loss:0.641, Validation accuracy:27.33%
# Epoch 61: iteration 7/8
# Epoch 61 --- loss:0.378, Epoch accuracy:54.04%, Validation loss:0.638, Validation accuracy:28.33%
# Epoch 62: iteration 7/8
# Epoch 62 --- loss:0.371, Epoch accuracy:55.88%, Validation loss:0.635, Validation accuracy:28.67%
# Epoch 63: iteration 7/8
# Epoch 63 --- loss:0.369, Epoch accuracy:55.44%, Validation loss:0.633, Validation accuracy:29.33%
# Epoch 64: iteration 7/8
# Epoch 64 --- loss:0.362, Epoch accuracy:56.49%, Validation loss:0.630, Validation accuracy:30.33%
# Epoch 65: iteration 7/8
# Epoch 65 --- loss:0.360, Epoch accuracy:57.19%, Validation loss:0.627, Validation accuracy:31.67%
# Epoch 66: iteration 7/8
# Epoch 66 --- loss:0.350, Epoch accuracy:60.00%, Validation loss:0.624, Validation accuracy:33.00%
# Epoch 67: iteration 7/8
# Epoch 67 --- loss:0.344, Epoch accuracy:61.32%, Validation loss:0.623, Validation accuracy:33.00%
# Epoch 68: iteration 7/8
# Epoch 68 --- loss:0.344, Epoch accuracy:59.91%, Validation loss:0.620, Validation accuracy:33.00%
# Epoch 69: iteration 7/8
# Epoch 69 --- loss:0.338, Epoch accuracy:60.53%, Validation loss:0.618, Validation accuracy:33.33%
# Epoch 70: iteration 7/8
# Epoch 70 --- loss:0.336, Epoch accuracy:62.11%, Validation loss:0.616, Validation accuracy:33.33%
# Epoch 71: iteration 7/8
# Epoch 71 --- loss:0.329, Epoch accuracy:62.46%, Validation loss:0.613, Validation accuracy:34.00%
# Epoch 72: iteration 7/8
# Epoch 72 --- loss:0.325, Epoch accuracy:64.12%, Validation loss:0.611, Validation accuracy:34.00%
# Epoch 73: iteration 7/8
# Epoch 73 --- loss:0.320, Epoch accuracy:65.26%, Validation loss:0.609, Validation accuracy:34.00%
# Epoch 74: iteration 7/8
# Epoch 74 --- loss:0.320, Epoch accuracy:64.56%, Validation loss:0.606, Validation accuracy:34.67%
# Epoch 75: iteration 7/8
# Epoch 75 --- loss:0.315, Epoch accuracy:65.88%, Validation loss:0.604, Validation accuracy:34.33%
# Epoch 76: iteration 7/8
# Epoch 76 --- loss:0.311, Epoch accuracy:67.11%, Validation loss:0.602, Validation accuracy:34.33%
# Epoch 77: iteration 7/8
# Epoch 77 --- loss:0.306, Epoch accuracy:65.96%, Validation loss:0.600, Validation accuracy:35.00%
# Epoch 78: iteration 7/8
# Epoch 78 --- loss:0.303, Epoch accuracy:67.19%, Validation loss:0.598, Validation accuracy:35.33%
# Epoch 79: iteration 7/8
# Epoch 79 --- loss:0.300, Epoch accuracy:67.89%, Validation loss:0.596, Validation accuracy:36.00%
# Epoch 80: iteration 7/8
# Epoch 80 --- loss:0.297, Epoch accuracy:68.77%, Validation loss:0.593, Validation accuracy:36.33%
# Epoch 81: iteration 7/8
# Epoch 81 --- loss:0.295, Epoch accuracy:68.33%, Validation loss:0.591, Validation accuracy:36.33%
# Epoch 82: iteration 7/8
# Epoch 82 --- loss:0.289, Epoch accuracy:70.09%, Validation loss:0.589, Validation accuracy:37.33%
# Epoch 83: iteration 7/8
# Epoch 83 --- loss:0.288, Epoch accuracy:70.00%, Validation loss:0.588, Validation accuracy:37.33%
# Epoch 84: iteration 7/8
# Epoch 84 --- loss:0.282, Epoch accuracy:71.84%, Validation loss:0.586, Validation accuracy:37.67%
# Epoch 85: iteration 7/8
# Epoch 85 --- loss:0.276, Epoch accuracy:71.75%, Validation loss:0.584, Validation accuracy:39.00%
# Epoch 86: iteration 7/8
# Epoch 86 --- loss:0.274, Epoch accuracy:72.37%, Validation loss:0.582, Validation accuracy:39.67%
# Epoch 87: iteration 7/8
# Epoch 87 --- loss:0.271, Epoch accuracy:73.07%, Validation loss:0.580, Validation accuracy:39.33%
# Epoch 88: iteration 7/8
# Epoch 88 --- loss:0.263, Epoch accuracy:74.47%, Validation loss:0.578, Validation accuracy:39.67%
# Epoch 89: iteration 7/8
# Epoch 89 --- loss:0.261, Epoch accuracy:73.33%, Validation loss:0.577, Validation accuracy:39.00%
# Epoch 90: iteration 7/8
# Epoch 90 --- loss:0.258, Epoch accuracy:75.00%, Validation loss:0.575, Validation accuracy:39.67%
# Epoch 91: iteration 7/8
# Epoch 91 --- loss:0.256, Epoch accuracy:75.00%, Validation loss:0.573, Validation accuracy:39.67%
# Epoch 92: iteration 7/8
# Epoch 92 --- loss:0.254, Epoch accuracy:75.09%, Validation loss:0.571, Validation accuracy:39.67%
# Epoch 93: iteration 7/8
# Epoch 93 --- loss:0.251, Epoch accuracy:75.35%, Validation loss:0.569, Validation accuracy:40.33%
# Epoch 94: iteration 7/8
# Epoch 94 --- loss:0.249, Epoch accuracy:75.26%, Validation loss:0.568, Validation accuracy:41.00%
# Epoch 95: iteration 7/8
# Epoch 95 --- loss:0.244, Epoch accuracy:75.70%, Validation loss:0.566, Validation accuracy:41.33%
# Epoch 96: iteration 7/8
# Epoch 96 --- loss:0.242, Epoch accuracy:76.23%, Validation loss:0.565, Validation accuracy:42.00%
# Epoch 97: iteration 7/8
# Epoch 97 --- loss:0.237, Epoch accuracy:77.46%, Validation loss:0.563, Validation accuracy:42.33%
# Epoch 98: iteration 7/8
# Epoch 98 --- loss:0.235, Epoch accuracy:77.37%, Validation loss:0.561, Validation accuracy:42.33%
# Epoch 99: iteration 7/8
# Epoch 99 --- loss:0.232, Epoch accuracy:77.89%, Validation loss:0.560, Validation accuracy:42.67%
# Epoch 100: iteration 7/8
# Epoch 100 --- loss:0.230, Epoch accuracy:78.51%, Validation loss:0.559, Validation accuracy:42.00%
# Epoch 101: iteration 7/8
# Epoch 101 --- loss:0.225, Epoch accuracy:79.04%, Validation loss:0.557, Validation accuracy:42.67%
# Epoch 102: iteration 7/8
# Epoch 102 --- loss:0.221, Epoch accuracy:79.65%, Validation loss:0.555, Validation accuracy:42.67%
# Epoch 103: iteration 7/8
# Epoch 103 --- loss:0.218, Epoch accuracy:79.65%, Validation loss:0.553, Validation accuracy:43.67%
# Epoch 104: iteration 7/8
# Epoch 104 --- loss:0.220, Epoch accuracy:78.86%, Validation loss:0.553, Validation accuracy:43.67%
# Epoch 105: iteration 7/8
# Epoch 105 --- loss:0.215, Epoch accuracy:79.21%, Validation loss:0.552, Validation accuracy:43.33%
# Epoch 106: iteration 7/8
# Epoch 106 --- loss:0.210, Epoch accuracy:80.70%, Validation loss:0.551, Validation accuracy:43.67%
# Epoch 107: iteration 7/8
# Epoch 107 --- loss:0.210, Epoch accuracy:80.09%, Validation loss:0.550, Validation accuracy:43.33%
# Epoch 108: iteration 7/8
# Epoch 108 --- loss:0.205, Epoch accuracy:80.96%, Validation loss:0.548, Validation accuracy:44.00%
# Epoch 109: iteration 7/8
# Epoch 109 --- loss:0.203, Epoch accuracy:81.84%, Validation loss:0.546, Validation accuracy:44.00%
# Epoch 110: iteration 7/8
# Epoch 110 --- loss:0.201, Epoch accuracy:80.88%, Validation loss:0.545, Validation accuracy:44.33%
# Epoch 111: iteration 7/8
# Epoch 111 --- loss:0.199, Epoch accuracy:81.05%, Validation loss:0.544, Validation accuracy:44.00%
# Epoch 112: iteration 7/8
# Epoch 112 --- loss:0.194, Epoch accuracy:81.75%, Validation loss:0.543, Validation accuracy:44.33%
# Epoch 113: iteration 7/8
# Epoch 113 --- loss:0.194, Epoch accuracy:82.37%, Validation loss:0.541, Validation accuracy:44.33%
# Epoch 114: iteration 7/8
# Epoch 114 --- loss:0.189, Epoch accuracy:82.81%, Validation loss:0.540, Validation accuracy:44.00%
# Epoch 115: iteration 7/8
# Epoch 115 --- loss:0.190, Epoch accuracy:82.46%, Validation loss:0.538, Validation accuracy:44.67%
# Epoch 116: iteration 7/8
# Epoch 116 --- loss:0.186, Epoch accuracy:82.98%, Validation loss:0.538, Validation accuracy:44.67%
# Epoch 117: iteration 7/8
# Epoch 117 --- loss:0.182, Epoch accuracy:83.51%, Validation loss:0.537, Validation accuracy:44.67%
# Epoch 118: iteration 7/8
# Epoch 118 --- loss:0.179, Epoch accuracy:83.77%, Validation loss:0.536, Validation accuracy:44.33%
# Epoch 119: iteration 7/8
# Epoch 119 --- loss:0.178, Epoch accuracy:83.42%, Validation loss:0.534, Validation accuracy:44.67%
# Epoch 120: iteration 7/8
# Epoch 120 --- loss:0.175, Epoch accuracy:83.51%, Validation loss:0.533, Validation accuracy:44.33%
# Epoch 121: iteration 7/8
# Epoch 121 --- loss:0.174, Epoch accuracy:83.51%, Validation loss:0.532, Validation accuracy:44.33%
# Epoch 122: iteration 7/8
# Epoch 122 --- loss:0.171, Epoch accuracy:84.04%, Validation loss:0.531, Validation accuracy:45.33%
# Epoch 123: iteration 7/8
# Epoch 123 --- loss:0.169, Epoch accuracy:85.35%, Validation loss:0.530, Validation accuracy:45.33%
# Epoch 124: iteration 7/8
# Epoch 124 --- loss:0.168, Epoch accuracy:84.82%, Validation loss:0.529, Validation accuracy:45.00%
# Epoch 125: iteration 7/8
# Epoch 125 --- loss:0.163, Epoch accuracy:85.18%, Validation loss:0.528, Validation accuracy:44.67%
# Epoch 126: iteration 7/8
# Epoch 126 --- loss:0.167, Epoch accuracy:84.21%, Validation loss:0.527, Validation accuracy:44.67%
# Epoch 127: iteration 7/8
# Epoch 127 --- loss:0.159, Epoch accuracy:85.88%, Validation loss:0.526, Validation accuracy:45.00%
# Epoch 128: iteration 7/8
# Epoch 128 --- loss:0.158, Epoch accuracy:85.44%, Validation loss:0.525, Validation accuracy:44.67%
# Epoch 129: iteration 7/8
# Epoch 129 --- loss:0.158, Epoch accuracy:84.91%, Validation loss:0.523, Validation accuracy:44.67%
# Epoch 130: iteration 7/8
# Epoch 130 --- loss:0.155, Epoch accuracy:86.32%, Validation loss:0.524, Validation accuracy:44.67%
# Epoch 131: iteration 7/8
# Epoch 131 --- loss:0.151, Epoch accuracy:86.23%, Validation loss:0.523, Validation accuracy:45.00%
# Epoch 132: iteration 7/8
# Epoch 132 --- loss:0.151, Epoch accuracy:86.49%, Validation loss:0.522, Validation accuracy:44.67%
# Epoch 133: iteration 7/8
# Epoch 133 --- loss:0.151, Epoch accuracy:85.79%, Validation loss:0.521, Validation accuracy:44.00%
# Epoch 134: iteration 7/8
# Epoch 134 --- loss:0.147, Epoch accuracy:86.32%, Validation loss:0.520, Validation accuracy:45.33%
# Epoch 135: iteration 7/8
# Epoch 135 --- loss:0.147, Epoch accuracy:86.05%, Validation loss:0.519, Validation accuracy:45.00%
# Epoch 136: iteration 7/8
# Epoch 136 --- loss:0.143, Epoch accuracy:86.75%, Validation loss:0.518, Validation accuracy:45.33%
# Epoch 137: iteration 7/8
# Epoch 137 --- loss:0.140, Epoch accuracy:86.67%, Validation loss:0.516, Validation accuracy:45.00%
# Epoch 138: iteration 7/8
# Epoch 138 --- loss:0.140, Epoch accuracy:86.75%, Validation loss:0.516, Validation accuracy:45.33%
# Epoch 139: iteration 7/8
# Epoch 139 --- loss:0.136, Epoch accuracy:86.84%, Validation loss:0.516, Validation accuracy:45.33%
# Epoch 140: iteration 7/8
# Epoch 140 --- loss:0.134, Epoch accuracy:87.54%, Validation loss:0.516, Validation accuracy:45.67%
# Epoch 141: iteration 7/8
# Epoch 141 --- loss:0.134, Epoch accuracy:87.54%, Validation loss:0.514, Validation accuracy:46.00%
# Epoch 142: iteration 7/8
# Epoch 142 --- loss:0.132, Epoch accuracy:87.19%, Validation loss:0.514, Validation accuracy:46.33%
# Epoch 143: iteration 7/8
# Epoch 143 --- loss:0.130, Epoch accuracy:87.46%, Validation loss:0.513, Validation accuracy:46.00%
# Epoch 144: iteration 7/8
# Epoch 144 --- loss:0.128, Epoch accuracy:87.28%, Validation loss:0.511, Validation accuracy:45.67%
# Epoch 145: iteration 7/8
# Epoch 145 --- loss:0.129, Epoch accuracy:87.19%, Validation loss:0.510, Validation accuracy:46.33%
# Epoch 146: iteration 7/8
# Epoch 146 --- loss:0.127, Epoch accuracy:87.81%, Validation loss:0.511, Validation accuracy:46.33%
# Epoch 147: iteration 7/8
# Epoch 147 --- loss:0.124, Epoch accuracy:87.28%, Validation loss:0.511, Validation accuracy:46.33%
# Epoch 148: iteration 7/8
# Epoch 148 --- loss:0.123, Epoch accuracy:88.25%, Validation loss:0.509, Validation accuracy:46.00%
# Epoch 149: iteration 7/8
# Epoch 149 --- loss:0.120, Epoch accuracy:87.98%, Validation loss:0.508, Validation accuracy:46.33%
# Epoch 150: iteration 7/8
# Epoch 150 --- loss:0.120, Epoch accuracy:87.54%, Validation loss:0.508, Validation accuracy:46.33%
# Epoch 151: iteration 7/8
# Epoch 151 --- loss:0.117, Epoch accuracy:88.16%, Validation loss:0.506, Validation accuracy:46.00%
# Epoch 152: iteration 7/8
# Epoch 152 --- loss:0.118, Epoch accuracy:87.72%, Validation loss:0.505, Validation accuracy:46.33%
# Epoch 153: iteration 7/8
# Epoch 153 --- loss:0.116, Epoch accuracy:88.25%, Validation loss:0.506, Validation accuracy:45.67%
# Epoch 154: iteration 7/8
# Epoch 154 --- loss:0.112, Epoch accuracy:88.33%, Validation loss:0.505, Validation accuracy:45.67%
# Epoch 155: iteration 7/8
# Epoch 155 --- loss:0.113, Epoch accuracy:88.16%, Validation loss:0.504, Validation accuracy:46.00%
# Epoch 156: iteration 7/8
# Epoch 156 --- loss:0.113, Epoch accuracy:87.98%, Validation loss:0.504, Validation accuracy:46.00%
# Epoch 157: iteration 7/8
# Epoch 157 --- loss:0.108, Epoch accuracy:88.42%, Validation loss:0.503, Validation accuracy:46.33%
# Epoch 158: iteration 7/8
# Epoch 158 --- loss:0.110, Epoch accuracy:88.51%, Validation loss:0.503, Validation accuracy:46.67%
# Epoch 159: iteration 7/8
# Epoch 159 --- loss:0.109, Epoch accuracy:88.33%, Validation loss:0.502, Validation accuracy:46.67%
# Epoch 160: iteration 7/8
# Epoch 160 --- loss:0.105, Epoch accuracy:88.86%, Validation loss:0.501, Validation accuracy:47.00%
# Epoch 161: iteration 7/8
# Epoch 161 --- loss:0.104, Epoch accuracy:88.68%, Validation loss:0.502, Validation accuracy:46.33%
# Epoch 162: iteration 7/8
# Epoch 162 --- loss:0.102, Epoch accuracy:88.42%, Validation loss:0.501, Validation accuracy:46.33%
# Epoch 163: iteration 7/8
# Epoch 163 --- loss:0.102, Epoch accuracy:89.12%, Validation loss:0.501, Validation accuracy:46.33%
# Epoch 164: iteration 7/8
# Epoch 164 --- loss:0.099, Epoch accuracy:88.77%, Validation loss:0.500, Validation accuracy:46.33%
# Epoch 165: iteration 7/8
# Epoch 165 --- loss:0.101, Epoch accuracy:88.68%, Validation loss:0.500, Validation accuracy:47.33%
# Epoch 166: iteration 7/8
# Epoch 166 --- loss:0.096, Epoch accuracy:88.95%, Validation loss:0.499, Validation accuracy:47.00%
# Epoch 167: iteration 7/8
# Epoch 167 --- loss:0.096, Epoch accuracy:89.30%, Validation loss:0.498, Validation accuracy:47.00%
# Epoch 168: iteration 7/8
# Epoch 168 --- loss:0.094, Epoch accuracy:89.21%, Validation loss:0.498, Validation accuracy:47.33%
# Epoch 169: iteration 7/8
# Epoch 169 --- loss:0.092, Epoch accuracy:88.77%, Validation loss:0.497, Validation accuracy:47.33%
# Epoch 170: iteration 7/8
# Epoch 170 --- loss:0.093, Epoch accuracy:89.04%, Validation loss:0.497, Validation accuracy:47.33%
# Epoch 171: iteration 7/8
# Epoch 171 --- loss:0.091, Epoch accuracy:89.30%, Validation loss:0.496, Validation accuracy:47.33%
# Epoch 172: iteration 7/8
# Epoch 172 --- loss:0.091, Epoch accuracy:89.39%, Validation loss:0.496, Validation accuracy:47.67%
# Epoch 173: iteration 7/8
# Epoch 173 --- loss:0.088, Epoch accuracy:89.30%, Validation loss:0.495, Validation accuracy:47.67%
# Epoch 174: iteration 7/8
# Epoch 174 --- loss:0.089, Epoch accuracy:89.56%, Validation loss:0.495, Validation accuracy:47.67%
# Epoch 175: iteration 7/8
# Epoch 175 --- loss:0.087, Epoch accuracy:89.12%, Validation loss:0.494, Validation accuracy:47.67%
# Epoch 176: iteration 7/8
# Epoch 176 --- loss:0.085, Epoch accuracy:89.21%, Validation loss:0.494, Validation accuracy:48.00%
# Epoch 177: iteration 7/8
# Epoch 177 --- loss:0.084, Epoch accuracy:89.12%, Validation loss:0.493, Validation accuracy:48.00%
# Epoch 178: iteration 7/8
# Epoch 178 --- loss:0.083, Epoch accuracy:89.56%, Validation loss:0.493, Validation accuracy:47.67%
# Epoch 179: iteration 7/8
# Epoch 179 --- loss:0.082, Epoch accuracy:89.47%, Validation loss:0.492, Validation accuracy:47.33%
# Epoch 180: iteration 7/8
# Epoch 180 --- loss:0.081, Epoch accuracy:89.30%, Validation loss:0.492, Validation accuracy:47.67%
# Epoch 181: iteration 7/8
# Epoch 181 --- loss:0.080, Epoch accuracy:89.39%, Validation loss:0.491, Validation accuracy:47.67%
# Epoch 182: iteration 7/8
# Epoch 182 --- loss:0.081, Epoch accuracy:89.56%, Validation loss:0.490, Validation accuracy:48.33%
# Epoch 183: iteration 7/8
# Epoch 183 --- loss:0.077, Epoch accuracy:89.39%, Validation loss:0.490, Validation accuracy:48.33%
# Epoch 184: iteration 7/8
# Epoch 184 --- loss:0.079, Epoch accuracy:89.47%, Validation loss:0.489, Validation accuracy:48.33%
# Epoch 185: iteration 7/8
# Epoch 185 --- loss:0.077, Epoch accuracy:89.65%, Validation loss:0.490, Validation accuracy:48.00%
# Epoch 186: iteration 7/8
# Epoch 186 --- loss:0.076, Epoch accuracy:89.39%, Validation loss:0.489, Validation accuracy:48.33%
# Epoch 187: iteration 7/8
# Epoch 187 --- loss:0.075, Epoch accuracy:89.47%, Validation loss:0.489, Validation accuracy:48.00%
# Epoch 188: iteration 7/8
# Epoch 188 --- loss:0.074, Epoch accuracy:89.56%, Validation loss:0.488, Validation accuracy:48.00%
# Epoch 189: iteration 7/8
# Epoch 189 --- loss:0.072, Epoch accuracy:89.82%, Validation loss:0.487, Validation accuracy:48.33%
# Epoch 190: iteration 7/8
# Epoch 190 --- loss:0.072, Epoch accuracy:89.56%, Validation loss:0.488, Validation accuracy:48.00%
# Epoch 191: iteration 7/8
# Epoch 191 --- loss:0.070, Epoch accuracy:89.56%, Validation loss:0.488, Validation accuracy:48.33%
# Epoch 192: iteration 7/8
# Epoch 192 --- loss:0.070, Epoch accuracy:89.82%, Validation loss:0.488, Validation accuracy:48.33%
# Epoch 193: iteration 7/8
# Epoch 193 --- loss:0.068, Epoch accuracy:89.74%, Validation loss:0.487, Validation accuracy:48.00%
# Epoch 194: iteration 7/8
# Epoch 194 --- loss:0.069, Epoch accuracy:89.56%, Validation loss:0.486, Validation accuracy:48.00%
# Epoch 195: iteration 7/8
# Epoch 195 --- loss:0.070, Epoch accuracy:89.65%, Validation loss:0.486, Validation accuracy:48.33%
# Epoch 196: iteration 7/8
# Epoch 196 --- loss:0.068, Epoch accuracy:89.65%, Validation loss:0.485, Validation accuracy:48.00%
# Epoch 197: iteration 7/8
# Epoch 197 --- loss:0.068, Epoch accuracy:89.47%, Validation loss:0.484, Validation accuracy:48.33%
# Epoch 198: iteration 7/8
# Epoch 198 --- loss:0.067, Epoch accuracy:89.82%, Validation loss:0.485, Validation accuracy:48.00%
# Epoch 199: iteration 7/8
# Epoch 199 --- loss:0.065, Epoch accuracy:89.47%, Validation loss:0.484, Validation accuracy:48.33%
# Epoch 200: iteration 7/8
# Epoch 200 --- loss:0.066, Epoch accuracy:89.56%, Validation loss:0.484, Validation accuracy:48.33%
# Epoch 201: iteration 7/8
# Epoch 201 --- loss:0.063, Epoch accuracy:89.65%, Validation loss:0.485, Validation accuracy:47.67%
# Epoch 202: iteration 7/8
# Epoch 202 --- loss:0.063, Epoch accuracy:89.65%, Validation loss:0.484, Validation accuracy:48.00%
# Epoch 203: iteration 7/8
# Epoch 203 --- loss:0.062, Epoch accuracy:89.74%, Validation loss:0.483, Validation accuracy:48.00%
# Epoch 204: iteration 7/8
# Epoch 204 --- loss:0.061, Epoch accuracy:89.74%, Validation loss:0.484, Validation accuracy:48.67%
# Epoch 205: iteration 7/8
# Epoch 205 --- loss:0.060, Epoch accuracy:89.74%, Validation loss:0.483, Validation accuracy:48.67%
# Epoch 206: iteration 7/8
# Epoch 206 --- loss:0.060, Epoch accuracy:89.82%, Validation loss:0.482, Validation accuracy:48.00%
# Epoch 207: iteration 7/8
# Epoch 207 --- loss:0.059, Epoch accuracy:89.82%, Validation loss:0.481, Validation accuracy:48.00%
# Epoch 208: iteration 7/8
# Epoch 208 --- loss:0.060, Epoch accuracy:89.65%, Validation loss:0.481, Validation accuracy:48.67%
# Epoch 209: iteration 7/8
# Epoch 209 --- loss:0.059, Epoch accuracy:89.74%, Validation loss:0.482, Validation accuracy:48.33%
# Epoch 210: iteration 7/8
# Epoch 210 --- loss:0.058, Epoch accuracy:89.74%, Validation loss:0.482, Validation accuracy:48.33%
# Epoch 211: iteration 7/8
# Epoch 211 --- loss:0.057, Epoch accuracy:89.74%, Validation loss:0.481, Validation accuracy:48.67%
# Epoch 212: iteration 7/8
# Epoch 212 --- loss:0.055, Epoch accuracy:89.74%, Validation loss:0.481, Validation accuracy:49.00%
# Epoch 213: iteration 7/8
# Epoch 213 --- loss:0.056, Epoch accuracy:89.74%, Validation loss:0.482, Validation accuracy:48.67%
# Epoch 214: iteration 7/8
# Epoch 214 --- loss:0.056, Epoch accuracy:89.82%, Validation loss:0.481, Validation accuracy:48.67%
# Epoch 215: iteration 7/8
# Epoch 215 --- loss:0.054, Epoch accuracy:89.82%, Validation loss:0.481, Validation accuracy:48.33%
# Epoch 216: iteration 7/8
# Epoch 216 --- loss:0.053, Epoch accuracy:89.82%, Validation loss:0.480, Validation accuracy:48.33%
# Epoch 217: iteration 7/8
# Epoch 217 --- loss:0.052, Epoch accuracy:89.82%, Validation loss:0.479, Validation accuracy:48.00%
# Epoch 218: iteration 7/8
# Epoch 218 --- loss:0.054, Epoch accuracy:89.74%, Validation loss:0.481, Validation accuracy:48.00%
# Epoch 219: iteration 7/8
# Epoch 219 --- loss:0.053, Epoch accuracy:89.82%, Validation loss:0.481, Validation accuracy:48.33%
# Epoch 220: iteration 7/8
# Epoch 220 --- loss:0.051, Epoch accuracy:89.82%, Validation loss:0.480, Validation accuracy:48.33%
# Epoch 221: iteration 7/8
# Epoch 221 --- loss:0.051, Epoch accuracy:89.82%, Validation loss:0.480, Validation accuracy:48.33%
# Epoch 222: iteration 7/8
# Epoch 222 --- loss:0.051, Epoch accuracy:89.82%, Validation loss:0.478, Validation accuracy:48.00%
# Epoch 223: iteration 7/8
# Epoch 223 --- loss:0.050, Epoch accuracy:89.82%, Validation loss:0.478, Validation accuracy:47.67%
# Epoch 224: iteration 7/8
# Epoch 224 --- loss:0.049, Epoch accuracy:89.82%, Validation loss:0.478, Validation accuracy:47.67%
# Epoch 225: iteration 7/8
# Epoch 225 --- loss:0.048, Epoch accuracy:89.82%, Validation loss:0.478, Validation accuracy:47.67%
# Epoch 226: iteration 7/8
# Epoch 226 --- loss:0.048, Epoch accuracy:89.82%, Validation loss:0.477, Validation accuracy:48.33%
# Epoch 227: iteration 7/8
# Epoch 227 --- loss:0.048, Epoch accuracy:89.74%, Validation loss:0.476, Validation accuracy:48.67%
# Epoch 228: iteration 7/8
# Epoch 228 --- loss:0.047, Epoch accuracy:89.82%, Validation loss:0.477, Validation accuracy:48.67%
# Epoch 229: iteration 7/8
# Epoch 229 --- loss:0.048, Epoch accuracy:89.74%, Validation loss:0.477, Validation accuracy:48.67%
# Epoch 230: iteration 7/8
# Epoch 230 --- loss:0.046, Epoch accuracy:89.82%, Validation loss:0.475, Validation accuracy:48.67%
# Epoch 231: iteration 7/8
# Epoch 231 --- loss:0.047, Epoch accuracy:89.82%, Validation loss:0.475, Validation accuracy:48.67%
# Epoch 232: iteration 7/8
# Epoch 232 --- loss:0.044, Epoch accuracy:89.82%, Validation loss:0.477, Validation accuracy:48.33%
# Epoch 233: iteration 7/8
# Epoch 233 --- loss:0.045, Epoch accuracy:89.82%, Validation loss:0.477, Validation accuracy:48.00%
# Epoch 234: iteration 7/8
# Epoch 234 --- loss:0.045, Epoch accuracy:89.82%, Validation loss:0.476, Validation accuracy:49.00%
# Epoch 235: iteration 7/8
# Epoch 235 --- loss:0.044, Epoch accuracy:89.82%, Validation loss:0.476, Validation accuracy:47.67%
# Epoch 236: iteration 7/8
# Epoch 236 --- loss:0.043, Epoch accuracy:89.82%, Validation loss:0.476, Validation accuracy:48.33%
# Epoch 237: iteration 7/8
# Epoch 237 --- loss:0.043, Epoch accuracy:89.82%, Validation loss:0.476, Validation accuracy:47.67%
# Epoch 238: iteration 7/8
# Epoch 238 --- loss:0.043, Epoch accuracy:89.82%, Validation loss:0.476, Validation accuracy:48.00%
# Epoch 239: iteration 7/8
# Epoch 239 --- loss:0.043, Epoch accuracy:89.82%, Validation loss:0.475, Validation accuracy:48.00%
# Epoch 240: iteration 7/8
# Epoch 240 --- loss:0.041, Epoch accuracy:89.82%, Validation loss:0.475, Validation accuracy:49.00%
# Epoch 241: iteration 7/8
# Epoch 241 --- loss:0.041, Epoch accuracy:89.82%, Validation loss:0.474, Validation accuracy:48.33%
# Epoch 242: iteration 7/8
# Epoch 242 --- loss:0.041, Epoch accuracy:89.82%, Validation loss:0.475, Validation accuracy:48.00%
# Epoch 243: iteration 7/8
# Epoch 243 --- loss:0.041, Epoch accuracy:89.82%, Validation loss:0.475, Validation accuracy:48.00%
# Epoch 244: iteration 7/8
# Epoch 244 --- loss:0.041, Epoch accuracy:89.74%, Validation loss:0.475, Validation accuracy:48.67%
# Epoch 245: iteration 7/8
# Epoch 245 --- loss:0.040, Epoch accuracy:89.82%, Validation loss:0.474, Validation accuracy:49.00%
# Epoch 246: iteration 7/8
# Epoch 246 --- loss:0.039, Epoch accuracy:89.82%, Validation loss:0.474, Validation accuracy:48.00%
# Epoch 247: iteration 7/8
# Epoch 247 --- loss:0.039, Epoch accuracy:89.82%, Validation loss:0.473, Validation accuracy:48.33%
# Epoch 248: iteration 7/8
# Epoch 248 --- loss:0.039, Epoch accuracy:89.82%, Validation loss:0.473, Validation accuracy:48.00%
# Epoch 249: iteration 7/8
# Epoch 249 --- loss:0.039, Epoch accuracy:89.82%, Validation loss:0.475, Validation accuracy:48.00%
# Epoch 250: iteration 7/8
# Epoch 250 --- loss:0.038, Epoch accuracy:89.82%, Validation loss:0.473, Validation accuracy:47.67%
# Epoch 251: iteration 7/8
# Epoch 251 --- loss:0.037, Epoch accuracy:89.82%, Validation loss:0.473, Validation accuracy:48.00%
# Epoch 252: iteration 7/8
# Epoch 252 --- loss:0.038, Epoch accuracy:89.82%, Validation loss:0.473, Validation accuracy:48.00%
# Epoch 253: iteration 7/8
# Epoch 253 --- loss:0.039, Epoch accuracy:89.82%, Validation loss:0.470, Validation accuracy:48.00%
# Epoch 254: iteration 7/8
# Epoch 254 --- loss:0.036, Epoch accuracy:89.82%, Validation loss:0.470, Validation accuracy:48.33%
# Epoch 255: iteration 7/8
# Epoch 255 --- loss:0.035, Epoch accuracy:89.82%, Validation loss:0.472, Validation accuracy:48.33%
# Epoch 256: iteration 7/8
# Epoch 256 --- loss:0.035, Epoch accuracy:89.82%, Validation loss:0.471, Validation accuracy:48.67%
# Epoch 257: iteration 7/8
# Epoch 257 --- loss:0.035, Epoch accuracy:89.82%, Validation loss:0.472, Validation accuracy:48.67%
# Epoch 258: iteration 7/8
# Epoch 258 --- loss:0.036, Epoch accuracy:89.82%, Validation loss:0.473, Validation accuracy:48.00%
# Epoch 259: iteration 7/8
# Epoch 259 --- loss:0.035, Epoch accuracy:89.82%, Validation loss:0.473, Validation accuracy:48.00%
# Epoch 260: iteration 7/8
# Epoch 260 --- loss:0.035, Epoch accuracy:89.82%, Validation loss:0.472, Validation accuracy:48.33%
# Epoch 261: iteration 7/8
# Epoch 261 --- loss:0.034, Epoch accuracy:89.82%, Validation loss:0.472, Validation accuracy:48.00%
# Epoch 262: iteration 7/8
# Epoch 262 --- loss:0.034, Epoch accuracy:89.82%, Validation loss:0.472, Validation accuracy:48.33%
# Epoch 263: iteration 7/8
# Epoch 263 --- loss:0.034, Epoch accuracy:89.82%, Validation loss:0.471, Validation accuracy:48.00%
# Epoch 264: iteration 7/8
# Epoch 264 --- loss:0.033, Epoch accuracy:89.82%, Validation loss:0.471, Validation accuracy:48.33%
# Epoch 265: iteration 7/8
# Epoch 265 --- loss:0.033, Epoch accuracy:89.82%, Validation loss:0.471, Validation accuracy:48.00%
# Epoch 266: iteration 7/8
# Epoch 266 --- loss:0.033, Epoch accuracy:89.82%, Validation loss:0.471, Validation accuracy:48.00%
# Epoch 267: iteration 7/8
# Epoch 267 --- loss:0.033, Epoch accuracy:89.82%, Validation loss:0.471, Validation accuracy:48.33%
# Epoch 268: iteration 7/8
# Epoch 268 --- loss:0.033, Epoch accuracy:89.82%, Validation loss:0.470, Validation accuracy:48.33%
# Epoch 269: iteration 7/8
# Epoch 269 --- loss:0.033, Epoch accuracy:89.82%, Validation loss:0.471, Validation accuracy:48.33%
# Epoch 270: iteration 7/8
# Epoch 270 --- loss:0.030, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.33%
# Epoch 271: iteration 7/8
# Epoch 271 --- loss:0.032, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.00%
# Epoch 272: iteration 7/8
# Epoch 272 --- loss:0.031, Epoch accuracy:89.82%, Validation loss:0.470, Validation accuracy:48.33%
# Epoch 273: iteration 7/8
# Epoch 273 --- loss:0.030, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.33%
# Epoch 274: iteration 7/8
# Epoch 274 --- loss:0.030, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.33%
# Epoch 275: iteration 7/8
# Epoch 275 --- loss:0.030, Epoch accuracy:89.82%, Validation loss:0.470, Validation accuracy:48.33%
# Epoch 276: iteration 7/8
# Epoch 276 --- loss:0.029, Epoch accuracy:89.82%, Validation loss:0.470, Validation accuracy:48.33%
# Epoch 277: iteration 7/8
# Epoch 277 --- loss:0.030, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.33%
# Epoch 278: iteration 7/8
# Epoch 278 --- loss:0.030, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.67%
# Epoch 279: iteration 7/8
# Epoch 279 --- loss:0.029, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.33%
# Epoch 280: iteration 7/8
# Epoch 280 --- loss:0.029, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.33%
# Epoch 281: iteration 7/8
# Epoch 281 --- loss:0.028, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 282: iteration 7/8
# Epoch 282 --- loss:0.028, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.33%
# Epoch 283: iteration 7/8
# Epoch 283 --- loss:0.028, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.00%
# Epoch 284: iteration 7/8
# Epoch 284 --- loss:0.028, Epoch accuracy:89.82%, Validation loss:0.470, Validation accuracy:48.00%
# Epoch 285: iteration 7/8
# Epoch 285 --- loss:0.028, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.00%
# Epoch 286: iteration 7/8
# Epoch 286 --- loss:0.028, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.33%
# Epoch 287: iteration 7/8
# Epoch 287 --- loss:0.027, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 288: iteration 7/8
# Epoch 288 --- loss:0.027, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 289: iteration 7/8
# Epoch 289 --- loss:0.026, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 290: iteration 7/8
# Epoch 290 --- loss:0.027, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.00%
# Epoch 291: iteration 7/8
# Epoch 291 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.00%
# Epoch 292: iteration 7/8
# Epoch 292 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.469, Validation accuracy:48.33%
# Epoch 293: iteration 7/8
# Epoch 293 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.33%
# Epoch 294: iteration 7/8
# Epoch 294 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.33%
# Epoch 295: iteration 7/8
# Epoch 295 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.67%
# Epoch 296: iteration 7/8
# Epoch 296 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.33%
# Epoch 297: iteration 7/8
# Epoch 297 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.00%
# Epoch 298: iteration 7/8
# Epoch 298 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 299: iteration 7/8
# Epoch 299 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.00%
# Epoch 300: iteration 7/8
# Epoch 300 --- loss:0.025, Epoch accuracy:89.82%, Validation loss:0.468, Validation accuracy:48.00%
# Epoch 301: iteration 7/8
# Epoch 301 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 302: iteration 7/8
# Epoch 302 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 303: iteration 7/8
# Epoch 303 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.33%
# Epoch 304: iteration 7/8
# Epoch 304 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.00%
# Epoch 305: iteration 7/8
# Epoch 305 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.33%
# Epoch 306: iteration 7/8
# Epoch 306 --- loss:0.024, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.33%
# Epoch 307: iteration 7/8
# Epoch 307 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.33%
# Epoch 308: iteration 7/8
# Epoch 308 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.33%
# Epoch 309: iteration 7/8
# Epoch 309 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.00%
# Epoch 310: iteration 7/8
# Epoch 310 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.00%
# Epoch 311: iteration 7/8
# Epoch 311 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.00%
# Epoch 312: iteration 7/8
# Epoch 312 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 313: iteration 7/8
# Epoch 313 --- loss:0.023, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.33%
# Epoch 314: iteration 7/8
# Epoch 314 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 315: iteration 7/8
# Epoch 315 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.33%
# Epoch 316: iteration 7/8
# Epoch 316 --- loss:0.022, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 317: iteration 7/8
# Epoch 317 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 318: iteration 7/8
# Epoch 318 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.00%
# Epoch 319: iteration 7/8
# Epoch 319 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.33%
# Epoch 320: iteration 7/8
# Epoch 320 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.00%
# Epoch 321: iteration 7/8
# Epoch 321 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 322: iteration 7/8
# Epoch 322 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 323: iteration 7/8
# Epoch 323 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 324: iteration 7/8
# Epoch 324 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 325: iteration 7/8
# Epoch 325 --- loss:0.020, Epoch accuracy:89.82%, Validation loss:0.467, Validation accuracy:48.00%
# Epoch 326: iteration 7/8
# Epoch 326 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.466, Validation accuracy:48.00%
# Epoch 327: iteration 7/8
# Epoch 327 --- loss:0.021, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 328: iteration 7/8
# Epoch 328 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.00%
# Epoch 329: iteration 7/8
# Epoch 329 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.33%
# Epoch 330: iteration 7/8
# Epoch 330 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 331: iteration 7/8
# Epoch 331 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 332: iteration 7/8
# Epoch 332 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 333: iteration 7/8
# Epoch 333 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 334: iteration 7/8
# Epoch 334 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 335: iteration 7/8
# Epoch 335 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 336: iteration 7/8
# Epoch 336 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.33%
# Epoch 337: iteration 7/8
# Epoch 337 --- loss:0.019, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 338: iteration 7/8
# Epoch 338 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 339: iteration 7/8
# Epoch 339 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 340: iteration 7/8
# Epoch 340 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.33%
# Epoch 341: iteration 7/8
# Epoch 341 --- loss:0.017, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.67%
# Epoch 342: iteration 7/8
# Epoch 342 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.00%
# Epoch 343: iteration 7/8
# Epoch 343 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:48.00%
# Epoch 344: iteration 7/8
# Epoch 344 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 345: iteration 7/8
# Epoch 345 --- loss:0.017, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 346: iteration 7/8
# Epoch 346 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 347: iteration 7/8
# Epoch 347 --- loss:0.017, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.33%
# Epoch 348: iteration 7/8
# Epoch 348 --- loss:0.017, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:48.00%
# Epoch 349: iteration 7/8
# Epoch 349 --- loss:0.017, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.00%
# Epoch 350: iteration 7/8
# Epoch 350 --- loss:0.018, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.00%
# Epoch 351: iteration 7/8
# Epoch 351 --- loss:0.017, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.33%
# Epoch 352: iteration 7/8
# Epoch 352 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:47.33%
# Epoch 353: iteration 7/8
# Epoch 353 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 354: iteration 7/8
# Epoch 354 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.33%
# Epoch 355: iteration 7/8
# Epoch 355 --- loss:0.017, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.33%
# Epoch 356: iteration 7/8
# Epoch 356 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:47.67%
# Epoch 357: iteration 7/8
# Epoch 357 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.00%
# Epoch 358: iteration 7/8
# Epoch 358 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:47.33%
# Epoch 359: iteration 7/8
# Epoch 359 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.67%
# Epoch 360: iteration 7/8
# Epoch 360 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:47.67%
# Epoch 361: iteration 7/8
# Epoch 361 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.67%
# Epoch 362: iteration 7/8
# Epoch 362 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.67%
# Epoch 363: iteration 7/8
# Epoch 363 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:48.00%
# Epoch 364: iteration 7/8
# Epoch 364 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:48.00%
# Epoch 365: iteration 7/8
# Epoch 365 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:48.00%
# Epoch 366: iteration 7/8
# Epoch 366 --- loss:0.015, Epoch accuracy:89.82%, Validation loss:0.461, Validation accuracy:48.00%
# Epoch 367: iteration 7/8
# Epoch 367 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.461, Validation accuracy:48.00%
# Epoch 368: iteration 7/8
# Epoch 368 --- loss:0.015, Epoch accuracy:89.82%, Validation loss:0.461, Validation accuracy:48.33%
# Epoch 369: iteration 7/8
# Epoch 369 --- loss:0.015, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.00%
# Epoch 370: iteration 7/8
# Epoch 370 --- loss:0.016, Epoch accuracy:89.82%, Validation loss:0.465, Validation accuracy:47.67%
# Epoch 371: iteration 7/8
# Epoch 371 --- loss:0.015, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:47.67%
# Epoch 372: iteration 7/8
# Epoch 372 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.67%
# Epoch 373: iteration 7/8
# Epoch 373 --- loss:0.015, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:47.67%
# Epoch 374: iteration 7/8
# Epoch 374 --- loss:0.015, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:48.33%
# Epoch 375: iteration 7/8
# Epoch 375 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.464, Validation accuracy:48.00%
# Epoch 376: iteration 7/8
# Epoch 376 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:47.67%
# Epoch 377: iteration 7/8
# Epoch 377 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.67%
# Epoch 378: iteration 7/8
# Epoch 378 --- loss:0.015, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.67%
# Epoch 379: iteration 7/8
# Epoch 379 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.461, Validation accuracy:48.33%
# Epoch 380: iteration 7/8
# Epoch 380 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.461, Validation accuracy:48.33%
# Epoch 381: iteration 7/8
# Epoch 381 --- loss:0.013, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:47.67%
# Epoch 382: iteration 7/8
# Epoch 382 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.33%
# Epoch 383: iteration 7/8
# Epoch 383 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:48.00%
# Epoch 384: iteration 7/8
# Epoch 384 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.463, Validation accuracy:47.33%
# Epoch 385: iteration 7/8
# Epoch 385 --- loss:0.014, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:47.67%
# Epoch 386: iteration 7/8
# Epoch 386 --- loss:0.013, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:47.33%
# Epoch 387: iteration 7/8
# Epoch 387 --- loss:0.013, Epoch accuracy:89.82%, Validation loss:0.462, Validation accuracy:47.67%
# Epoch 388: iteration 7/8
# ...
# Epoch 373: iteration 8/9
# Epoch 373 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 374: iteration 8/9
# Epoch 374 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 375: iteration 8/9
# Epoch 375 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 376: iteration 8/9
# Epoch 376 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 377: iteration 8/9
# Epoch 377 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 378: iteration 8/9
# Epoch 378 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 379: iteration 8/9
# Epoch 379 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 380: iteration 8/9
# Epoch 380 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 381: iteration 8/9
# Epoch 381 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 382: iteration 8/9
# Epoch 382 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 383: iteration 8/9
# Epoch 383 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 384: iteration 8/9
# Epoch 384 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 385: iteration 8/9
# Epoch 385 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 386: iteration 8/9
# Epoch 386 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 387: iteration 8/9
# Epoch 387 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 388: iteration 8/9
# Epoch 388 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 389: iteration 8/9
# Epoch 389 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 390: iteration 8/9
# Epoch 390 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 391: iteration 8/9
# Epoch 391 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 392: iteration 8/9
# Epoch 392 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 393: iteration 8/9
# Epoch 393 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 394: iteration 8/9
# Epoch 394 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 395: iteration 8/9
# Epoch 395 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 396: iteration 8/9
# Epoch 396 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 397: iteration 8/9
# Epoch 397 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 398: iteration 8/9
# Epoch 398 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 399: iteration 8/9
# Epoch 399 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 400: iteration 8/9
# Epoch 400 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 401: iteration 8/9
# Epoch 401 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 402: iteration 8/9
# Epoch 402 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 403: iteration 8/9
# Epoch 403 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 404: iteration 8/9
# Epoch 404 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 405: iteration 8/9
# Epoch 405 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 406: iteration 8/9
# Epoch 406 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 407: iteration 8/9
# Epoch 407 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 408: iteration 8/9
# Epoch 408 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 409: iteration 8/9
# Epoch 409 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 410: iteration 8/9
# Epoch 410 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 411: iteration 8/9
# Epoch 411 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 412: iteration 8/9
# Epoch 412 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 413: iteration 8/9
# Epoch 413 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 414: iteration 8/9
# Epoch 414 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 415: iteration 8/9
# Epoch 415 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 416: iteration 8/9
# Epoch 416 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 417: iteration 8/9
# Epoch 417 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 418: iteration 8/9
# Epoch 418 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 419: iteration 8/9
# Epoch 419 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 420: iteration 8/9
# Epoch 420 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 421: iteration 8/9
# Epoch 421 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 422: iteration 8/9
# Epoch 422 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 423: iteration 8/9
# Epoch 423 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 424: iteration 8/9
# Epoch 424 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 425: iteration 8/9
# Epoch 425 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 426: iteration 8/9
# Epoch 426 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 427: iteration 8/9
# Epoch 427 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 428: iteration 8/9
# Epoch 428 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 429: iteration 8/9
# Epoch 429 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 430: iteration 8/9
# Epoch 430 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 431: iteration 8/9
# Epoch 431 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 432: iteration 8/9
# Epoch 432 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 433: iteration 8/9
# Epoch 433 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 434: iteration 8/9
# Epoch 434 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 435: iteration 8/9
# Epoch 435 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 436: iteration 8/9
# Epoch 436 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 437: iteration 8/9
# Epoch 437 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 438: iteration 8/9
# Epoch 438 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 439: iteration 8/9
# Epoch 439 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 440: iteration 8/9
# Epoch 440 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 441: iteration 8/9
# Epoch 441 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 442: iteration 8/9
# Epoch 442 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 443: iteration 8/9
# Epoch 443 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 444: iteration 8/9
# Epoch 444 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 445: iteration 8/9
# Epoch 445 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 446: iteration 8/9
# Epoch 446 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 447: iteration 8/9
# Epoch 447 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 448: iteration 8/9
# Epoch 448 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 449: iteration 8/9
# Epoch 449 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 450: iteration 8/9
# Epoch 450 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 451: iteration 8/9
# Epoch 451 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 452: iteration 8/9
# Epoch 452 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 453: iteration 8/9
# Epoch 453 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 454: iteration 8/9
# Epoch 454 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 455: iteration 8/9
# Epoch 455 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 456: iteration 8/9
# Epoch 456 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 457: iteration 8/9
# Epoch 457 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 458: iteration 8/9
# Epoch 458 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 459: iteration 8/9
# Epoch 459 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 460: iteration 8/9
# Epoch 460 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 461: iteration 8/9
# Epoch 461 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 462: iteration 8/9
# Epoch 462 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 463: iteration 8/9
# Epoch 463 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 464: iteration 8/9
# Epoch 464 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 465: iteration 8/9
# Epoch 465 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 466: iteration 8/9
# Epoch 466 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 467: iteration 8/9
# Epoch 467 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 468: iteration 8/9
# Epoch 468 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 469: iteration 8/9
# Epoch 469 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 470: iteration 8/9
# Epoch 470 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 471: iteration 8/9
# Epoch 471 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 472: iteration 8/9
# Epoch 472 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 473: iteration 8/9
# Epoch 473 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 474: iteration 8/9
# Epoch 474 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 475: iteration 8/9
# Epoch 475 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 476: iteration 8/9
# Epoch 476 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 477: iteration 8/9
# Epoch 477 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 478: iteration 8/9
# Epoch 478 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 479: iteration 8/9
# Epoch 479 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 480: iteration 8/9
# Epoch 480 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 481: iteration 8/9
# Epoch 481 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 482: iteration 8/9
# Epoch 482 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 483: iteration 8/9
# Epoch 483 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 484: iteration 8/9
# Epoch 484 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 485: iteration 8/9
# Epoch 485 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 486: iteration 8/9
# Epoch 486 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 487: iteration 8/9
# Epoch 487 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 488: iteration 8/9
# Epoch 488 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 489: iteration 8/9
# Epoch 489 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 490: iteration 8/9
# Epoch 490 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 491: iteration 8/9
# Epoch 491 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 492: iteration 8/9
# Epoch 492 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 493: iteration 8/9
# Epoch 493 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 494: iteration 8/9
# Epoch 494 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 495: iteration 8/9
# Epoch 495 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 496: iteration 8/9
# Epoch 496 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 497: iteration 8/9
# Epoch 497 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 498: iteration 8/9
# Epoch 498 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
# Epoch 499: iteration 8/9
# Epoch 499 --- loss:0.001, Epoch accuracy:96.00%, Validation loss:0.001, Validation accuracy:100.00%
#
#
# [*] done !
# [*] Best training loss - 0.0005908230567971866
# [*] Best validation loss - 0.0005891545442864299

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
# Out:
# [*] 0 Test accuracy is 48.00%
# [*] 1 Test accuracy is 100.00%
# [*] 2 Test accuracy is 100.00%
# [*] 3 Test accuracy is 100.00%
# [*] 4 Test accuracy is 100.00%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 100.00%
# [*] Worst fold acc : 48.00%
# [*] Average fold acc : 89.60%

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
# Out:
# [*] 0 Test accuracy is 48.00%
#               precision    recall  f1-score   support
#
#            0       0.50      0.20      0.29        20
#            1       0.59      0.33      0.42        40
#            2       0.50      0.03      0.05        40
#            3       0.32      0.45      0.37        40
#            4       0.40      0.78      0.53        40
#            5       0.71      0.68      0.69        40
#            6       0.54      0.62      0.58        40
#            7       0.50      0.62      0.56        40
#
#     accuracy                           0.48       300
#    macro avg       0.51      0.46      0.44       300
# weighted avg       0.51      0.48      0.45       300
#
# [*] 1 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 2 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 3 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 4 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        32
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        32
#            4       1.00      1.00      1.00        32
#            5       1.00      1.00      1.00        32
#            6       1.00      1.00      1.00        32
#            7       1.00      1.00      1.00        32
#
#     accuracy                           1.00       240
#    macro avg       1.00      1.00      1.00       240
# weighted avg       1.00      1.00      1.00       240
