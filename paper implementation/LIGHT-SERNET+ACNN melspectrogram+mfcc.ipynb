# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}

fold_path = 'scaling-spectrogram-mfcc dataset'
sub_name = 'LIGHT-SERNET+ACNN melspectrogram+mfcc'
data_name = 'RAVDESS'

minibatch = 32
num_epochs = 500
EARLY_CNT = 99999

learning_rate = 1e-5

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
from torchaudio.functional import compute_deltas
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class LIGHT_SERNET(nn.Module):
    def __init__(self):
        super(LIGHT_SERNET, self).__init__()

        self.cnn1 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=[3,3], padding=[1,0]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        self.cnn2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=[9,1], padding=[4,0]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        self.cnn3 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=[1,11]),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1])
        )
        
        self.LFLB = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1]),
            
            nn.Conv2d(64, 96, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d([2,2], padding=[1,1]),
            
            nn.Conv2d(96, 128, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d([2,1], padding=[1,0]),
            
            nn.Conv2d(128, 160, kernel_size=[3,3], padding=[1,1]),
            nn.BatchNorm2d(160),
            nn.ReLU(),
            nn.MaxPool2d([2,1], padding=[1,0]),
            
            nn.Conv2d(160, 320, kernel_size=[1,1]),
            nn.BatchNorm2d(320),
            nn.ReLU()
        )

    def forward(self, x):
        
        embd1 = self.cnn1(x)
        embd2 = self.cnn2(x)
        embd3 = self.cnn3(x)
        concat_embd = torch.cat([embd1, embd2, embd3], dim=3)
        
        lflb_embd = self.LFLB(concat_embd)
        out = F.adaptive_avg_pool2d(lflb_embd, (1,1))
        out = nn.Dropout(0.3)(out)
        out = torch.flatten(out, start_dim=1)
        
        return out

class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.mel_conv1a = nn.Conv2d(1, 8, kernel_size=[10,2], stride=1, padding=[5,1])
        self.mel_conv1b = nn.Conv2d(1, 8, kernel_size=[2,8], stride=1, padding=[1,4])

        self.mfcc_conv1a = nn.Conv2d(1, 8, kernel_size=[10,2], stride=1, padding=[5,1])
        self.mfcc_conv1b = nn.Conv2d(1, 8, kernel_size=[2,8], stride=1, padding=[1,4])

        self.mel = LIGHT_SERNET()
        self.mfcc = LIGHT_SERNET()
        
        self.fc = nn.Linear(320, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        mel = x[:,0,:,:]
        mel = mel.unsqueeze(1)
        a = self.mel_conv1a(mel)
        b = self.mel_conv1b(mel)
        mel_embd = torch.concat([a, b], dim=1)
        
        mfcc = x[:,1,:,:]
        mfcc = mfcc.unsqueeze(1)
        a = self.mfcc_conv1a(mfcc)
        b = self.mfcc_conv1b(mfcc)
        mfcc_embd = torch.concat([a, b], dim=1)

        mel_embd = self.mel(mel_embd)
        mfcc_embd = self.mfcc(mfcc_embd)
        
        output = torch.maximum(mel_embd, mfcc_embd)
        output_logits = self.fc(output)
        output_softmax = self.softmax(output_logits)

        return output_logits, output_softmax

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs)):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=10e-6, amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - LIGHT-SERNET+ACNN melspectrogram+mfcc
# A Jupyter Widget
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:2.015, Epoch accuracy:17.37%, Validation loss:2.046, Validation accuracy:20.00%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:1.984, Epoch accuracy:21.84%, Validation loss:2.011, Validation accuracy:22.67%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:1.963, Epoch accuracy:25.88%, Validation loss:1.982, Validation accuracy:28.00%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:1.930, Epoch accuracy:28.77%, Validation loss:1.950, Validation accuracy:29.67%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:1.907, Epoch accuracy:29.39%, Validation loss:1.925, Validation accuracy:29.67%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:1.877, Epoch accuracy:31.67%, Validation loss:1.902, Validation accuracy:29.33%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:1.860, Epoch accuracy:30.26%, Validation loss:1.871, Validation accuracy:34.33%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:1.831, Epoch accuracy:31.05%, Validation loss:1.850, Validation accuracy:34.00%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:1.809, Epoch accuracy:35.18%, Validation loss:1.838, Validation accuracy:34.33%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:1.794, Epoch accuracy:34.12%, Validation loss:1.819, Validation accuracy:36.33%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:1.773, Epoch accuracy:36.67%, Validation loss:1.799, Validation accuracy:38.00%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:1.759, Epoch accuracy:37.37%, Validation loss:1.771, Validation accuracy:38.67%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:1.740, Epoch accuracy:36.05%, Validation loss:1.765, Validation accuracy:39.33%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:1.728, Epoch accuracy:37.54%, Validation loss:1.734, Validation accuracy:43.33%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:1.701, Epoch accuracy:38.86%, Validation loss:1.722, Validation accuracy:41.33%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:1.692, Epoch accuracy:39.30%, Validation loss:1.710, Validation accuracy:44.33%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:1.672, Epoch accuracy:40.70%, Validation loss:1.694, Validation accuracy:38.67%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:1.653, Epoch accuracy:40.26%, Validation loss:1.678, Validation accuracy:44.33%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:1.641, Epoch accuracy:42.11%, Validation loss:1.658, Validation accuracy:48.00%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:1.626, Epoch accuracy:42.37%, Validation loss:1.645, Validation accuracy:46.33%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:1.609, Epoch accuracy:43.77%, Validation loss:1.635, Validation accuracy:47.67%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:1.599, Epoch accuracy:42.89%, Validation loss:1.620, Validation accuracy:46.67%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:1.581, Epoch accuracy:43.42%, Validation loss:1.608, Validation accuracy:47.00%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:1.564, Epoch accuracy:45.18%, Validation loss:1.586, Validation accuracy:48.00%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:1.549, Epoch accuracy:44.56%, Validation loss:1.589, Validation accuracy:45.33%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:1.535, Epoch accuracy:45.18%, Validation loss:1.568, Validation accuracy:48.67%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:1.534, Epoch accuracy:46.23%, Validation loss:1.550, Validation accuracy:51.00%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:1.514, Epoch accuracy:46.84%, Validation loss:1.558, Validation accuracy:51.00%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:1.495, Epoch accuracy:47.89%, Validation loss:1.563, Validation accuracy:44.67%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:1.481, Epoch accuracy:47.54%, Validation loss:1.530, Validation accuracy:49.67%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:1.473, Epoch accuracy:47.63%, Validation loss:1.522, Validation accuracy:48.00%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:1.449, Epoch accuracy:49.12%, Validation loss:1.514, Validation accuracy:50.67%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:1.435, Epoch accuracy:49.21%, Validation loss:1.491, Validation accuracy:50.33%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:1.417, Epoch accuracy:50.70%, Validation loss:1.522, Validation accuracy:45.67%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:1.410, Epoch accuracy:50.53%, Validation loss:1.514, Validation accuracy:46.00%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:1.395, Epoch accuracy:51.49%, Validation loss:1.499, Validation accuracy:47.00%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:1.383, Epoch accuracy:51.93%, Validation loss:1.503, Validation accuracy:48.00%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:1.374, Epoch accuracy:51.23%, Validation loss:1.468, Validation accuracy:50.33%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:1.360, Epoch accuracy:54.47%, Validation loss:1.489, Validation accuracy:47.00%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:1.342, Epoch accuracy:53.42%, Validation loss:1.476, Validation accuracy:46.00%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:1.332, Epoch accuracy:54.30%, Validation loss:1.472, Validation accuracy:47.67%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:1.317, Epoch accuracy:54.39%, Validation loss:1.429, Validation accuracy:52.00%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:1.306, Epoch accuracy:55.70%, Validation loss:1.466, Validation accuracy:47.00%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:1.299, Epoch accuracy:55.88%, Validation loss:1.419, Validation accuracy:51.67%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:1.292, Epoch accuracy:56.84%, Validation loss:1.463, Validation accuracy:50.00%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:1.283, Epoch accuracy:55.61%, Validation loss:1.431, Validation accuracy:52.33%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:1.266, Epoch accuracy:56.67%, Validation loss:1.428, Validation accuracy:49.67%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:1.254, Epoch accuracy:57.63%, Validation loss:1.450, Validation accuracy:48.33%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:1.250, Epoch accuracy:59.21%, Validation loss:1.392, Validation accuracy:53.67%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:1.234, Epoch accuracy:58.60%, Validation loss:1.391, Validation accuracy:51.67%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:1.212, Epoch accuracy:60.61%, Validation loss:1.451, Validation accuracy:47.67%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:1.222, Epoch accuracy:59.04%, Validation loss:1.387, Validation accuracy:52.33%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:1.193, Epoch accuracy:61.23%, Validation loss:1.360, Validation accuracy:54.33%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:1.187, Epoch accuracy:61.32%, Validation loss:1.420, Validation accuracy:49.00%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:1.165, Epoch accuracy:62.54%, Validation loss:1.421, Validation accuracy:48.67%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:1.157, Epoch accuracy:61.49%, Validation loss:1.418, Validation accuracy:50.33%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:1.152, Epoch accuracy:62.81%, Validation loss:1.393, Validation accuracy:51.67%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:1.139, Epoch accuracy:62.63%, Validation loss:1.341, Validation accuracy:52.33%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:1.138, Epoch accuracy:62.89%, Validation loss:1.360, Validation accuracy:52.67%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:1.123, Epoch accuracy:63.51%, Validation loss:1.376, Validation accuracy:48.33%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:1.119, Epoch accuracy:64.12%, Validation loss:1.361, Validation accuracy:52.67%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:1.109, Epoch accuracy:63.51%, Validation loss:1.357, Validation accuracy:52.33%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:1.094, Epoch accuracy:64.21%, Validation loss:1.368, Validation accuracy:50.33%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:1.092, Epoch accuracy:65.00%, Validation loss:1.336, Validation accuracy:53.00%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:1.090, Epoch accuracy:63.51%, Validation loss:1.458, Validation accuracy:47.00%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:1.076, Epoch accuracy:65.26%, Validation loss:1.314, Validation accuracy:52.33%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:1.043, Epoch accuracy:67.46%, Validation loss:1.338, Validation accuracy:53.00%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:1.062, Epoch accuracy:67.02%, Validation loss:1.295, Validation accuracy:56.00%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:1.040, Epoch accuracy:67.89%, Validation loss:1.333, Validation accuracy:52.67%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:1.032, Epoch accuracy:67.02%, Validation loss:1.290, Validation accuracy:54.00%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:1.026, Epoch accuracy:67.28%, Validation loss:1.303, Validation accuracy:54.33%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:1.012, Epoch accuracy:68.42%, Validation loss:1.438, Validation accuracy:47.33%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:1.011, Epoch accuracy:68.51%, Validation loss:1.386, Validation accuracy:50.00%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:1.006, Epoch accuracy:67.19%, Validation loss:1.275, Validation accuracy:55.33%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:0.997, Epoch accuracy:67.46%, Validation loss:1.355, Validation accuracy:51.67%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:0.990, Epoch accuracy:68.60%, Validation loss:1.327, Validation accuracy:53.67%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:0.970, Epoch accuracy:68.77%, Validation loss:1.321, Validation accuracy:55.67%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:0.974, Epoch accuracy:69.12%, Validation loss:1.295, Validation accuracy:53.00%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:0.955, Epoch accuracy:68.86%, Validation loss:1.340, Validation accuracy:52.67%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:0.941, Epoch accuracy:71.40%, Validation loss:1.281, Validation accuracy:53.00%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:0.952, Epoch accuracy:69.39%, Validation loss:1.223, Validation accuracy:56.67%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:0.942, Epoch accuracy:70.61%, Validation loss:1.306, Validation accuracy:55.00%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:0.931, Epoch accuracy:70.35%, Validation loss:1.442, Validation accuracy:47.33%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:0.910, Epoch accuracy:72.11%, Validation loss:1.225, Validation accuracy:57.33%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:0.921, Epoch accuracy:70.44%, Validation loss:1.314, Validation accuracy:52.67%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:0.898, Epoch accuracy:71.84%, Validation loss:1.364, Validation accuracy:53.67%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:0.911, Epoch accuracy:72.02%, Validation loss:1.411, Validation accuracy:49.33%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:0.898, Epoch accuracy:72.19%, Validation loss:1.369, Validation accuracy:53.00%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:0.892, Epoch accuracy:71.75%, Validation loss:1.286, Validation accuracy:54.00%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:0.894, Epoch accuracy:72.72%, Validation loss:1.308, Validation accuracy:50.00%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:0.885, Epoch accuracy:71.93%, Validation loss:1.335, Validation accuracy:51.67%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:0.863, Epoch accuracy:73.77%, Validation loss:1.331, Validation accuracy:53.00%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:0.858, Epoch accuracy:73.68%, Validation loss:1.221, Validation accuracy:55.33%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:0.844, Epoch accuracy:74.82%, Validation loss:1.254, Validation accuracy:53.67%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:0.841, Epoch accuracy:75.53%, Validation loss:1.324, Validation accuracy:54.00%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:0.843, Epoch accuracy:73.77%, Validation loss:1.350, Validation accuracy:49.33%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:0.835, Epoch accuracy:74.56%, Validation loss:1.198, Validation accuracy:57.33%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:0.814, Epoch accuracy:76.14%, Validation loss:1.303, Validation accuracy:53.33%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:0.836, Epoch accuracy:74.21%, Validation loss:1.326, Validation accuracy:53.33%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:0.814, Epoch accuracy:75.61%, Validation loss:1.310, Validation accuracy:53.67%
# Epoch 100: iteration 34/35
# Epoch 100 --- loss:0.811, Epoch accuracy:76.84%, Validation loss:1.473, Validation accuracy:48.33%
# Epoch 101: iteration 34/35
# Epoch 101 --- loss:0.783, Epoch accuracy:77.37%, Validation loss:1.243, Validation accuracy:56.33%
# Epoch 102: iteration 34/35
# Epoch 102 --- loss:0.799, Epoch accuracy:76.84%, Validation loss:1.254, Validation accuracy:56.00%
# Epoch 103: iteration 34/35
# Epoch 103 --- loss:0.786, Epoch accuracy:76.84%, Validation loss:1.167, Validation accuracy:59.67%
# Epoch 104: iteration 34/35
# Epoch 104 --- loss:0.785, Epoch accuracy:75.35%, Validation loss:1.188, Validation accuracy:58.67%
# Epoch 105: iteration 34/35
# Epoch 105 --- loss:0.794, Epoch accuracy:76.49%, Validation loss:1.297, Validation accuracy:52.00%
# Epoch 106: iteration 34/35
# Epoch 106 --- loss:0.777, Epoch accuracy:76.75%, Validation loss:1.282, Validation accuracy:54.00%
# Epoch 107: iteration 34/35
# Epoch 107 --- loss:0.763, Epoch accuracy:77.37%, Validation loss:1.206, Validation accuracy:57.00%
# Epoch 108: iteration 34/35
# Epoch 108 --- loss:0.768, Epoch accuracy:76.75%, Validation loss:1.288, Validation accuracy:54.00%
# Epoch 109: iteration 34/35
# Epoch 109 --- loss:0.766, Epoch accuracy:76.84%, Validation loss:1.221, Validation accuracy:56.33%
# Epoch 110: iteration 34/35
# Epoch 110 --- loss:0.756, Epoch accuracy:78.33%, Validation loss:1.329, Validation accuracy:53.33%
# Epoch 111: iteration 34/35
# Epoch 111 --- loss:0.734, Epoch accuracy:79.56%, Validation loss:1.263, Validation accuracy:55.00%
# Epoch 112: iteration 34/35
# Epoch 112 --- loss:0.730, Epoch accuracy:78.25%, Validation loss:1.202, Validation accuracy:54.67%
# Epoch 113: iteration 34/35
# Epoch 113 --- loss:0.740, Epoch accuracy:79.30%, Validation loss:1.138, Validation accuracy:60.33%
# Epoch 114: iteration 34/35
# Epoch 114 --- loss:0.734, Epoch accuracy:79.12%, Validation loss:1.212, Validation accuracy:54.67%
# Epoch 115: iteration 34/35
# Epoch 115 --- loss:0.722, Epoch accuracy:80.26%, Validation loss:1.294, Validation accuracy:53.33%
# Epoch 116: iteration 34/35
# Epoch 116 --- loss:0.731, Epoch accuracy:79.91%, Validation loss:1.351, Validation accuracy:53.00%
# Epoch 117: iteration 34/35
# Epoch 117 --- loss:0.707, Epoch accuracy:79.91%, Validation loss:1.184, Validation accuracy:60.00%
# Epoch 118: iteration 34/35
# Epoch 118 --- loss:0.710, Epoch accuracy:79.21%, Validation loss:1.280, Validation accuracy:54.67%
# Epoch 119: iteration 34/35
# Epoch 119 --- loss:0.701, Epoch accuracy:80.79%, Validation loss:1.334, Validation accuracy:51.33%
# Epoch 120: iteration 34/35
# Epoch 120 --- loss:0.693, Epoch accuracy:80.18%, Validation loss:1.131, Validation accuracy:59.67%
# Epoch 121: iteration 34/35
# Epoch 121 --- loss:0.696, Epoch accuracy:80.88%, Validation loss:1.289, Validation accuracy:53.33%
# Epoch 122: iteration 34/35
# Epoch 122 --- loss:0.678, Epoch accuracy:81.84%, Validation loss:1.221, Validation accuracy:58.67%
# Epoch 123: iteration 34/35
# Epoch 123 --- loss:0.682, Epoch accuracy:81.58%, Validation loss:1.247, Validation accuracy:56.00%
# Epoch 124: iteration 34/35
# Epoch 124 --- loss:0.669, Epoch accuracy:82.46%, Validation loss:1.232, Validation accuracy:56.67%
# Epoch 125: iteration 34/35
# Epoch 125 --- loss:0.675, Epoch accuracy:81.67%, Validation loss:1.195, Validation accuracy:56.00%
# Epoch 126: iteration 34/35
# Epoch 126 --- loss:0.669, Epoch accuracy:81.58%, Validation loss:1.166, Validation accuracy:56.67%
# Epoch 127: iteration 34/35
# Epoch 127 --- loss:0.656, Epoch accuracy:82.19%, Validation loss:1.168, Validation accuracy:57.00%
# Epoch 128: iteration 34/35
# Epoch 128 --- loss:0.660, Epoch accuracy:82.11%, Validation loss:1.257, Validation accuracy:55.67%
# Epoch 129: iteration 34/35
# Epoch 129 --- loss:0.653, Epoch accuracy:82.63%, Validation loss:1.344, Validation accuracy:49.67%
# Epoch 130: iteration 34/35
# Epoch 130 --- loss:0.646, Epoch accuracy:83.16%, Validation loss:1.235, Validation accuracy:57.00%
# Epoch 131: iteration 34/35
# Epoch 131 --- loss:0.641, Epoch accuracy:83.60%, Validation loss:1.123, Validation accuracy:59.00%
# Epoch 132: iteration 34/35
# Epoch 132 --- loss:0.640, Epoch accuracy:83.33%, Validation loss:1.261, Validation accuracy:56.67%
# Epoch 133: iteration 34/35
# Epoch 133 --- loss:0.636, Epoch accuracy:82.46%, Validation loss:1.277, Validation accuracy:54.67%
# Epoch 134: iteration 34/35
# Epoch 134 --- loss:0.629, Epoch accuracy:83.95%, Validation loss:1.187, Validation accuracy:57.00%
# Epoch 135: iteration 34/35
# Epoch 135 --- loss:0.628, Epoch accuracy:83.95%, Validation loss:1.196, Validation accuracy:56.00%
# Epoch 136: iteration 34/35
# Epoch 136 --- loss:0.629, Epoch accuracy:82.37%, Validation loss:1.146, Validation accuracy:58.00%
# Epoch 137: iteration 34/35
# Epoch 137 --- loss:0.620, Epoch accuracy:83.51%, Validation loss:1.172, Validation accuracy:58.67%
# Epoch 138: iteration 34/35
# Epoch 138 --- loss:0.609, Epoch accuracy:84.21%, Validation loss:1.382, Validation accuracy:49.00%
# Epoch 139: iteration 34/35
# Epoch 139 --- loss:0.610, Epoch accuracy:84.21%, Validation loss:1.350, Validation accuracy:54.67%
# Epoch 140: iteration 34/35
# Epoch 140 --- loss:0.595, Epoch accuracy:85.35%, Validation loss:1.271, Validation accuracy:54.67%
# Epoch 141: iteration 34/35
# Epoch 141 --- loss:0.602, Epoch accuracy:84.39%, Validation loss:1.170, Validation accuracy:56.33%
# Epoch 142: iteration 34/35
# Epoch 142 --- loss:0.580, Epoch accuracy:86.49%, Validation loss:1.175, Validation accuracy:56.67%
# Epoch 143: iteration 34/35
# Epoch 143 --- loss:0.578, Epoch accuracy:86.32%, Validation loss:1.287, Validation accuracy:54.00%
# Epoch 144: iteration 34/35
# Epoch 144 --- loss:0.579, Epoch accuracy:85.61%, Validation loss:1.235, Validation accuracy:54.33%
# Epoch 145: iteration 34/35
# Epoch 145 --- loss:0.562, Epoch accuracy:86.58%, Validation loss:1.165, Validation accuracy:57.33%
# Epoch 146: iteration 34/35
# Epoch 146 --- loss:0.568, Epoch accuracy:86.67%, Validation loss:1.249, Validation accuracy:54.00%
# Epoch 147: iteration 34/35
# Epoch 147 --- loss:0.562, Epoch accuracy:87.19%, Validation loss:1.094, Validation accuracy:58.00%
# Epoch 148: iteration 34/35
# Epoch 148 --- loss:0.555, Epoch accuracy:87.54%, Validation loss:1.146, Validation accuracy:57.67%
# Epoch 149: iteration 34/35
# Epoch 149 --- loss:0.547, Epoch accuracy:87.81%, Validation loss:1.284, Validation accuracy:55.67%
# Epoch 150: iteration 34/35
# Epoch 150 --- loss:0.547, Epoch accuracy:87.37%, Validation loss:1.149, Validation accuracy:59.00%
# Epoch 151: iteration 34/35
# Epoch 151 --- loss:0.536, Epoch accuracy:88.60%, Validation loss:1.244, Validation accuracy:57.00%
# Epoch 152: iteration 34/35
# Epoch 152 --- loss:0.529, Epoch accuracy:87.98%, Validation loss:1.168, Validation accuracy:56.67%
# Epoch 153: iteration 34/35
# Epoch 153 --- loss:0.531, Epoch accuracy:88.07%, Validation loss:1.243, Validation accuracy:55.33%
# Epoch 154: iteration 34/35
# Epoch 154 --- loss:0.519, Epoch accuracy:88.51%, Validation loss:1.282, Validation accuracy:56.00%
# Epoch 155: iteration 34/35
# Epoch 155 --- loss:0.518, Epoch accuracy:88.60%, Validation loss:1.132, Validation accuracy:58.00%
# Epoch 156: iteration 34/35
# Epoch 156 --- loss:0.521, Epoch accuracy:88.07%, Validation loss:1.094, Validation accuracy:62.67%
# Epoch 157: iteration 34/35
# Epoch 157 --- loss:0.523, Epoch accuracy:88.68%, Validation loss:1.251, Validation accuracy:57.33%
# Epoch 158: iteration 34/35
# Epoch 158 --- loss:0.506, Epoch accuracy:89.04%, Validation loss:1.230, Validation accuracy:57.33%
# Epoch 159: iteration 34/35
# Epoch 159 --- loss:0.513, Epoch accuracy:88.86%, Validation loss:1.078, Validation accuracy:62.33%
# Epoch 160: iteration 34/35
# Epoch 160 --- loss:0.495, Epoch accuracy:88.68%, Validation loss:1.143, Validation accuracy:58.67%
# Epoch 161: iteration 34/35
# Epoch 161 --- loss:0.495, Epoch accuracy:90.09%, Validation loss:1.205, Validation accuracy:55.67%
# Epoch 162: iteration 34/35
# Epoch 162 --- loss:0.480, Epoch accuracy:90.44%, Validation loss:1.156, Validation accuracy:54.33%
# Epoch 163: iteration 34/35
# Epoch 163 --- loss:0.483, Epoch accuracy:91.14%, Validation loss:1.100, Validation accuracy:59.67%
# Epoch 164: iteration 34/35
# Epoch 164 --- loss:0.480, Epoch accuracy:91.05%, Validation loss:1.186, Validation accuracy:56.00%
# Epoch 165: iteration 34/35
# Epoch 165 --- loss:0.468, Epoch accuracy:90.96%, Validation loss:1.120, Validation accuracy:58.33%
# Epoch 166: iteration 34/35
# Epoch 166 --- loss:0.474, Epoch accuracy:90.09%, Validation loss:1.123, Validation accuracy:58.00%
# Epoch 167: iteration 34/35
# Epoch 167 --- loss:0.461, Epoch accuracy:90.70%, Validation loss:1.288, Validation accuracy:56.33%
# Epoch 168: iteration 34/35
# Epoch 168 --- loss:0.475, Epoch accuracy:90.88%, Validation loss:1.068, Validation accuracy:62.33%
# Epoch 169: iteration 34/35
# Epoch 169 --- loss:0.457, Epoch accuracy:90.79%, Validation loss:1.243, Validation accuracy:55.00%
# Epoch 170: iteration 34/35
# Epoch 170 --- loss:0.456, Epoch accuracy:91.23%, Validation loss:1.079, Validation accuracy:64.00%
# Epoch 171: iteration 34/35
# Epoch 171 --- loss:0.457, Epoch accuracy:91.75%, Validation loss:1.137, Validation accuracy:57.33%
# Epoch 172: iteration 34/35
# Epoch 172 --- loss:0.443, Epoch accuracy:92.28%, Validation loss:1.180, Validation accuracy:60.00%
# Epoch 173: iteration 34/35
# Epoch 173 --- loss:0.441, Epoch accuracy:91.67%, Validation loss:1.153, Validation accuracy:57.33%
# Epoch 174: iteration 34/35
# Epoch 174 --- loss:0.440, Epoch accuracy:92.19%, Validation loss:1.122, Validation accuracy:58.33%
# Epoch 175: iteration 34/35
# Epoch 175 --- loss:0.435, Epoch accuracy:91.93%, Validation loss:1.122, Validation accuracy:60.00%
# Epoch 176: iteration 34/35
# Epoch 176 --- loss:0.433, Epoch accuracy:92.63%, Validation loss:1.127, Validation accuracy:59.00%
# Epoch 177: iteration 34/35
# Epoch 177 --- loss:0.419, Epoch accuracy:93.51%, Validation loss:1.123, Validation accuracy:61.00%
# Epoch 178: iteration 34/35
# Epoch 178 --- loss:0.426, Epoch accuracy:92.81%, Validation loss:1.128, Validation accuracy:58.00%
# Epoch 179: iteration 34/35
# Epoch 179 --- loss:0.422, Epoch accuracy:92.72%, Validation loss:1.097, Validation accuracy:62.00%
# Epoch 180: iteration 34/35
# Epoch 180 --- loss:0.413, Epoch accuracy:93.60%, Validation loss:1.067, Validation accuracy:63.00%
# Epoch 181: iteration 34/35
# Epoch 181 --- loss:0.406, Epoch accuracy:92.98%, Validation loss:1.125, Validation accuracy:57.33%
# Epoch 182: iteration 34/35
# Epoch 182 --- loss:0.403, Epoch accuracy:93.77%, Validation loss:1.128, Validation accuracy:59.67%
# Epoch 183: iteration 34/35
# Epoch 183 --- loss:0.404, Epoch accuracy:93.51%, Validation loss:1.142, Validation accuracy:61.67%
# Epoch 184: iteration 34/35
# Epoch 184 --- loss:0.393, Epoch accuracy:93.95%, Validation loss:1.128, Validation accuracy:57.00%
# Epoch 185: iteration 34/35
# Epoch 185 --- loss:0.394, Epoch accuracy:93.25%, Validation loss:1.113, Validation accuracy:60.00%
# Epoch 186: iteration 34/35
# Epoch 186 --- loss:0.398, Epoch accuracy:93.25%, Validation loss:1.145, Validation accuracy:59.67%
# Epoch 187: iteration 34/35
# Epoch 187 --- loss:0.386, Epoch accuracy:94.65%, Validation loss:1.133, Validation accuracy:60.00%
# Epoch 188: iteration 34/35
# Epoch 188 --- loss:0.382, Epoch accuracy:94.21%, Validation loss:1.163, Validation accuracy:55.33%
# Epoch 189: iteration 34/35
# Epoch 189 --- loss:0.376, Epoch accuracy:94.12%, Validation loss:1.125, Validation accuracy:60.67%
# Epoch 190: iteration 34/35
# Epoch 190 --- loss:0.373, Epoch accuracy:94.21%, Validation loss:1.140, Validation accuracy:59.33%
# Epoch 191: iteration 34/35
# Epoch 191 --- loss:0.373, Epoch accuracy:94.12%, Validation loss:1.052, Validation accuracy:65.33%
# Epoch 192: iteration 34/35
# Epoch 192 --- loss:0.365, Epoch accuracy:94.65%, Validation loss:1.100, Validation accuracy:61.67%
# Epoch 193: iteration 34/35
# Epoch 193 --- loss:0.365, Epoch accuracy:94.21%, Validation loss:1.067, Validation accuracy:62.00%
# Epoch 194: iteration 34/35
# Epoch 194 --- loss:0.356, Epoch accuracy:94.82%, Validation loss:1.099, Validation accuracy:60.67%
# Epoch 195: iteration 34/35
# Epoch 195 --- loss:0.366, Epoch accuracy:94.30%, Validation loss:1.310, Validation accuracy:52.67%
# Epoch 196: iteration 34/35
# Epoch 196 --- loss:0.349, Epoch accuracy:95.09%, Validation loss:1.229, Validation accuracy:57.33%
# Epoch 197: iteration 34/35
# Epoch 197 --- loss:0.329, Epoch accuracy:95.53%, Validation loss:1.211, Validation accuracy:53.67%
# Epoch 198: iteration 34/35
# Epoch 198 --- loss:0.329, Epoch accuracy:95.96%, Validation loss:1.240, Validation accuracy:55.00%
# Epoch 199: iteration 34/35
# Epoch 199 --- loss:0.355, Epoch accuracy:95.18%, Validation loss:1.127, Validation accuracy:61.33%
# Epoch 200: iteration 34/35
# Epoch 200 --- loss:0.339, Epoch accuracy:94.82%, Validation loss:1.131, Validation accuracy:60.00%
# Epoch 201: iteration 34/35
# Epoch 201 --- loss:0.334, Epoch accuracy:94.39%, Validation loss:1.109, Validation accuracy:59.00%
# Epoch 202: iteration 34/35
# Epoch 202 --- loss:0.325, Epoch accuracy:96.49%, Validation loss:1.124, Validation accuracy:61.00%
# Epoch 203: iteration 34/35
# Epoch 203 --- loss:0.324, Epoch accuracy:95.88%, Validation loss:1.036, Validation accuracy:63.67%
# Epoch 204: iteration 34/35
# Epoch 204 --- loss:0.337, Epoch accuracy:94.74%, Validation loss:1.062, Validation accuracy:63.67%
# Epoch 205: iteration 34/35
# Epoch 205 --- loss:0.322, Epoch accuracy:95.35%, Validation loss:1.112, Validation accuracy:59.33%
# Epoch 206: iteration 34/35
# Epoch 206 --- loss:0.323, Epoch accuracy:95.70%, Validation loss:1.098, Validation accuracy:60.67%
# Epoch 207: iteration 34/35
# Epoch 207 --- loss:0.312, Epoch accuracy:96.75%, Validation loss:1.127, Validation accuracy:56.00%
# Epoch 208: iteration 34/35
# Epoch 208 --- loss:0.317, Epoch accuracy:95.88%, Validation loss:1.107, Validation accuracy:59.00%
# Epoch 209: iteration 34/35
# Epoch 209 --- loss:0.308, Epoch accuracy:96.32%, Validation loss:1.062, Validation accuracy:63.33%
# Epoch 210: iteration 34/35
# Epoch 210 --- loss:0.304, Epoch accuracy:96.14%, Validation loss:1.142, Validation accuracy:59.33%
# Epoch 211: iteration 34/35
# Epoch 211 --- loss:0.310, Epoch accuracy:96.23%, Validation loss:1.099, Validation accuracy:59.33%
# Epoch 212: iteration 34/35
# Epoch 212 --- loss:0.311, Epoch accuracy:95.61%, Validation loss:1.118, Validation accuracy:61.67%
# Epoch 213: iteration 34/35
# Epoch 213 --- loss:0.286, Epoch accuracy:96.32%, Validation loss:1.102, Validation accuracy:60.00%
# Epoch 214: iteration 34/35
# Epoch 214 --- loss:0.307, Epoch accuracy:96.40%, Validation loss:1.046, Validation accuracy:63.00%
# Epoch 215: iteration 34/35
# Epoch 215 --- loss:0.281, Epoch accuracy:96.75%, Validation loss:1.182, Validation accuracy:56.33%
# Epoch 216: iteration 34/35
# Epoch 216 --- loss:0.292, Epoch accuracy:95.88%, Validation loss:1.219, Validation accuracy:58.33%
# Epoch 217: iteration 34/35
# Epoch 217 --- loss:0.285, Epoch accuracy:96.32%, Validation loss:1.199, Validation accuracy:57.00%
# Epoch 218: iteration 34/35
# Epoch 218 --- loss:0.271, Epoch accuracy:97.02%, Validation loss:1.112, Validation accuracy:59.33%
# Epoch 219: iteration 34/35
# Epoch 219 --- loss:0.279, Epoch accuracy:96.23%, Validation loss:1.110, Validation accuracy:61.00%
# Epoch 220: iteration 34/35
# Epoch 220 --- loss:0.265, Epoch accuracy:97.02%, Validation loss:1.031, Validation accuracy:65.00%
# Epoch 221: iteration 34/35
# Epoch 221 --- loss:0.275, Epoch accuracy:96.58%, Validation loss:1.250, Validation accuracy:55.67%
# Epoch 222: iteration 34/35
# Epoch 222 --- loss:0.264, Epoch accuracy:97.28%, Validation loss:1.272, Validation accuracy:56.67%
# Epoch 223: iteration 34/35
# Epoch 223 --- loss:0.260, Epoch accuracy:97.02%, Validation loss:1.053, Validation accuracy:60.33%
# Epoch 224: iteration 34/35
# Epoch 224 --- loss:0.267, Epoch accuracy:96.84%, Validation loss:1.099, Validation accuracy:60.67%
# Epoch 225: iteration 34/35
# Epoch 225 --- loss:0.258, Epoch accuracy:96.84%, Validation loss:1.044, Validation accuracy:64.33%
# Epoch 226: iteration 34/35
# Epoch 226 --- loss:0.247, Epoch accuracy:97.02%, Validation loss:1.016, Validation accuracy:65.67%
# Epoch 227: iteration 34/35
# Epoch 227 --- loss:0.248, Epoch accuracy:97.37%, Validation loss:1.055, Validation accuracy:63.33%
# Epoch 228: iteration 34/35
# Epoch 228 --- loss:0.247, Epoch accuracy:97.02%, Validation loss:1.063, Validation accuracy:59.67%
# Epoch 229: iteration 34/35
# Epoch 229 --- loss:0.246, Epoch accuracy:97.19%, Validation loss:1.249, Validation accuracy:56.67%
# Epoch 230: iteration 34/35
# Epoch 230 --- loss:0.247, Epoch accuracy:96.93%, Validation loss:1.088, Validation accuracy:60.33%
# Epoch 231: iteration 34/35
# Epoch 231 --- loss:0.239, Epoch accuracy:97.37%, Validation loss:1.090, Validation accuracy:61.67%
# Epoch 232: iteration 34/35
# Epoch 232 --- loss:0.245, Epoch accuracy:97.46%, Validation loss:1.020, Validation accuracy:64.67%
# Epoch 233: iteration 34/35
# Epoch 233 --- loss:0.237, Epoch accuracy:97.37%, Validation loss:1.157, Validation accuracy:58.67%
# Epoch 234: iteration 34/35
# Epoch 234 --- loss:0.227, Epoch accuracy:97.54%, Validation loss:1.027, Validation accuracy:64.00%
# Epoch 235: iteration 34/35
# Epoch 235 --- loss:0.227, Epoch accuracy:96.75%, Validation loss:1.046, Validation accuracy:64.00%
# Epoch 236: iteration 34/35
# Epoch 236 --- loss:0.225, Epoch accuracy:97.72%, Validation loss:1.062, Validation accuracy:61.00%
# Epoch 237: iteration 34/35
# Epoch 237 --- loss:0.226, Epoch accuracy:97.28%, Validation loss:1.199, Validation accuracy:59.00%
# Epoch 238: iteration 34/35
# Epoch 238 --- loss:0.222, Epoch accuracy:97.54%, Validation loss:1.067, Validation accuracy:63.67%
# Epoch 239: iteration 34/35
# Epoch 239 --- loss:0.223, Epoch accuracy:97.98%, Validation loss:1.044, Validation accuracy:63.33%
# Epoch 240: iteration 34/35
# Epoch 240 --- loss:0.210, Epoch accuracy:97.81%, Validation loss:1.128, Validation accuracy:60.00%
# Epoch 241: iteration 34/35
# Epoch 241 --- loss:0.214, Epoch accuracy:97.81%, Validation loss:1.140, Validation accuracy:59.33%
# Epoch 242: iteration 34/35
# Epoch 242 --- loss:0.219, Epoch accuracy:97.54%, Validation loss:1.162, Validation accuracy:60.33%
# Epoch 243: iteration 34/35
# Epoch 243 --- loss:0.209, Epoch accuracy:97.98%, Validation loss:1.158, Validation accuracy:61.33%
# Epoch 244: iteration 34/35
# Epoch 244 --- loss:0.212, Epoch accuracy:97.63%, Validation loss:1.095, Validation accuracy:61.00%
# Epoch 245: iteration 34/35
# Epoch 245 --- loss:0.207, Epoch accuracy:97.72%, Validation loss:1.126, Validation accuracy:60.67%
# Epoch 246: iteration 34/35
# Epoch 246 --- loss:0.210, Epoch accuracy:97.63%, Validation loss:1.020, Validation accuracy:64.67%
# Epoch 247: iteration 34/35
# Epoch 247 --- loss:0.207, Epoch accuracy:97.46%, Validation loss:1.093, Validation accuracy:62.33%
# Epoch 248: iteration 34/35
# Epoch 248 --- loss:0.202, Epoch accuracy:97.72%, Validation loss:1.065, Validation accuracy:61.00%
# Epoch 249: iteration 34/35
# Epoch 249 --- loss:0.202, Epoch accuracy:97.72%, Validation loss:1.111, Validation accuracy:60.00%
# Epoch 250: iteration 34/35
# Epoch 250 --- loss:0.197, Epoch accuracy:97.81%, Validation loss:1.045, Validation accuracy:63.00%
# Epoch 251: iteration 34/35
# Epoch 251 --- loss:0.197, Epoch accuracy:97.89%, Validation loss:1.065, Validation accuracy:62.33%
# Epoch 252: iteration 34/35
# Epoch 252 --- loss:0.192, Epoch accuracy:97.19%, Validation loss:1.146, Validation accuracy:60.67%
# Epoch 253: iteration 34/35
# Epoch 253 --- loss:0.191, Epoch accuracy:97.98%, Validation loss:1.231, Validation accuracy:57.67%
# Epoch 254: iteration 34/35
# Epoch 254 --- loss:0.194, Epoch accuracy:97.98%, Validation loss:1.045, Validation accuracy:65.00%
# Epoch 255: iteration 34/35
# Epoch 255 --- loss:0.180, Epoch accuracy:97.98%, Validation loss:1.053, Validation accuracy:62.33%
# Epoch 256: iteration 34/35
# Epoch 256 --- loss:0.191, Epoch accuracy:97.98%, Validation loss:1.052, Validation accuracy:62.67%
# Epoch 257: iteration 34/35
# Epoch 257 --- loss:0.180, Epoch accuracy:98.07%, Validation loss:1.085, Validation accuracy:62.33%
# Epoch 258: iteration 34/35
# Epoch 258 --- loss:0.188, Epoch accuracy:97.72%, Validation loss:1.150, Validation accuracy:62.67%
# Epoch 259: iteration 34/35
# Epoch 259 --- loss:0.183, Epoch accuracy:97.98%, Validation loss:1.039, Validation accuracy:65.33%
# Epoch 260: iteration 34/35
# Epoch 260 --- loss:0.184, Epoch accuracy:98.07%, Validation loss:1.275, Validation accuracy:57.00%
# Epoch 261: iteration 34/35
# Epoch 261 --- loss:0.179, Epoch accuracy:97.72%, Validation loss:1.116, Validation accuracy:60.33%
# Epoch 262: iteration 34/35
# Epoch 262 --- loss:0.168, Epoch accuracy:97.98%, Validation loss:0.996, Validation accuracy:64.00%
# Epoch 263: iteration 34/35
# Epoch 263 --- loss:0.169, Epoch accuracy:97.89%, Validation loss:1.115, Validation accuracy:61.33%
# Epoch 264: iteration 34/35
# Epoch 264 --- loss:0.170, Epoch accuracy:98.16%, Validation loss:1.070, Validation accuracy:62.67%
# Epoch 265: iteration 34/35
# Epoch 265 --- loss:0.165, Epoch accuracy:98.16%, Validation loss:1.014, Validation accuracy:65.00%
# Epoch 266: iteration 34/35
# Epoch 266 --- loss:0.174, Epoch accuracy:97.89%, Validation loss:1.056, Validation accuracy:64.67%
# Epoch 267: iteration 34/35
# Epoch 267 --- loss:0.171, Epoch accuracy:97.89%, Validation loss:1.046, Validation accuracy:63.00%
# Epoch 268: iteration 34/35
# Epoch 268 --- loss:0.169, Epoch accuracy:98.16%, Validation loss:1.098, Validation accuracy:61.00%
# Epoch 269: iteration 34/35
# Epoch 269 --- loss:0.168, Epoch accuracy:97.46%, Validation loss:0.996, Validation accuracy:65.67%
# Epoch 270: iteration 34/35
# Epoch 270 --- loss:0.165, Epoch accuracy:98.07%, Validation loss:1.015, Validation accuracy:67.00%
# Epoch 271: iteration 34/35
# Epoch 271 --- loss:0.169, Epoch accuracy:98.07%, Validation loss:0.971, Validation accuracy:66.67%
# Epoch 272: iteration 34/35
# Epoch 272 --- loss:0.161, Epoch accuracy:98.07%, Validation loss:1.145, Validation accuracy:61.67%
# Epoch 273: iteration 34/35
# Epoch 273 --- loss:0.147, Epoch accuracy:98.16%, Validation loss:1.204, Validation accuracy:55.00%
# Epoch 274: iteration 34/35
# Epoch 274 --- loss:0.155, Epoch accuracy:97.98%, Validation loss:1.137, Validation accuracy:58.67%
# Epoch 275: iteration 34/35
# Epoch 275 --- loss:0.154, Epoch accuracy:98.07%, Validation loss:1.037, Validation accuracy:64.00%
# Epoch 276: iteration 34/35
# Epoch 276 --- loss:0.157, Epoch accuracy:97.98%, Validation loss:1.051, Validation accuracy:63.67%
# Epoch 277: iteration 34/35
# Epoch 277 --- loss:0.149, Epoch accuracy:97.98%, Validation loss:1.006, Validation accuracy:66.33%
# Epoch 278: iteration 34/35
# Epoch 278 --- loss:0.147, Epoch accuracy:98.16%, Validation loss:1.009, Validation accuracy:66.33%
# Epoch 279: iteration 34/35
# Epoch 279 --- loss:0.151, Epoch accuracy:97.81%, Validation loss:1.010, Validation accuracy:66.67%
# Epoch 280: iteration 34/35
# Epoch 280 --- loss:0.147, Epoch accuracy:97.98%, Validation loss:1.276, Validation accuracy:58.00%
# Epoch 281: iteration 34/35
# Epoch 281 --- loss:0.143, Epoch accuracy:98.25%, Validation loss:1.077, Validation accuracy:60.67%
# Epoch 282: iteration 34/35
# Epoch 282 --- loss:0.154, Epoch accuracy:97.98%, Validation loss:1.126, Validation accuracy:58.33%
# Epoch 283: iteration 34/35
# Epoch 283 --- loss:0.140, Epoch accuracy:98.07%, Validation loss:1.053, Validation accuracy:64.00%
# Epoch 284: iteration 34/35
# Epoch 284 --- loss:0.145, Epoch accuracy:98.07%, Validation loss:1.061, Validation accuracy:63.67%
# Epoch 285: iteration 34/35
# Epoch 285 --- loss:0.146, Epoch accuracy:98.25%, Validation loss:0.960, Validation accuracy:68.00%
# Epoch 286: iteration 34/35
# Epoch 286 --- loss:0.140, Epoch accuracy:98.16%, Validation loss:1.161, Validation accuracy:56.67%
# Epoch 287: iteration 34/35
# Epoch 287 --- loss:0.137, Epoch accuracy:98.07%, Validation loss:1.022, Validation accuracy:64.67%
# Epoch 288: iteration 34/35
# Epoch 288 --- loss:0.136, Epoch accuracy:98.07%, Validation loss:1.077, Validation accuracy:62.00%
# Epoch 289: iteration 34/35
# Epoch 289 --- loss:0.131, Epoch accuracy:98.25%, Validation loss:1.091, Validation accuracy:63.33%
# Epoch 290: iteration 34/35
# Epoch 290 --- loss:0.131, Epoch accuracy:98.25%, Validation loss:1.062, Validation accuracy:64.00%
# Epoch 291: iteration 34/35
# Epoch 291 --- loss:0.124, Epoch accuracy:98.16%, Validation loss:1.018, Validation accuracy:63.00%
# Epoch 292: iteration 34/35
# Epoch 292 --- loss:0.130, Epoch accuracy:98.25%, Validation loss:1.120, Validation accuracy:61.00%
# Epoch 293: iteration 34/35
# Epoch 293 --- loss:0.130, Epoch accuracy:98.16%, Validation loss:1.029, Validation accuracy:65.33%
# Epoch 294: iteration 34/35
# Epoch 294 --- loss:0.123, Epoch accuracy:98.25%, Validation loss:1.095, Validation accuracy:60.67%
# Epoch 295: iteration 34/35
# Epoch 295 --- loss:0.121, Epoch accuracy:98.16%, Validation loss:1.091, Validation accuracy:62.00%
# Epoch 296: iteration 34/35
# Epoch 296 --- loss:0.127, Epoch accuracy:98.16%, Validation loss:1.099, Validation accuracy:60.67%
# Epoch 297: iteration 34/35
# Epoch 297 --- loss:0.126, Epoch accuracy:98.25%, Validation loss:1.121, Validation accuracy:62.00%
# Epoch 298: iteration 34/35
# Epoch 298 --- loss:0.132, Epoch accuracy:98.16%, Validation loss:0.964, Validation accuracy:67.33%
# Epoch 299: iteration 34/35
# Epoch 299 --- loss:0.120, Epoch accuracy:98.25%, Validation loss:0.944, Validation accuracy:68.33%
# Epoch 300: iteration 34/35
# Epoch 300 --- loss:0.118, Epoch accuracy:98.16%, Validation loss:1.006, Validation accuracy:65.67%
# Epoch 301: iteration 34/35
# Epoch 301 --- loss:0.113, Epoch accuracy:98.25%, Validation loss:1.048, Validation accuracy:61.33%
# Epoch 302: iteration 34/35
# Epoch 302 --- loss:0.116, Epoch accuracy:97.98%, Validation loss:1.053, Validation accuracy:64.33%
# Epoch 303: iteration 34/35
# Epoch 303 --- loss:0.117, Epoch accuracy:98.25%, Validation loss:1.002, Validation accuracy:68.67%
# Epoch 304: iteration 34/35
# Epoch 304 --- loss:0.120, Epoch accuracy:98.16%, Validation loss:1.062, Validation accuracy:62.67%
# Epoch 305: iteration 34/35
# Epoch 305 --- loss:0.111, Epoch accuracy:98.25%, Validation loss:1.052, Validation accuracy:62.67%
# Epoch 306: iteration 34/35
# Epoch 306 --- loss:0.109, Epoch accuracy:98.25%, Validation loss:1.051, Validation accuracy:60.33%
# Epoch 307: iteration 34/35
# Epoch 307 --- loss:0.112, Epoch accuracy:98.25%, Validation loss:1.131, Validation accuracy:59.67%
# Epoch 308: iteration 34/35
# Epoch 308 --- loss:0.118, Epoch accuracy:97.98%, Validation loss:1.055, Validation accuracy:65.67%
# Epoch 309: iteration 34/35
# Epoch 309 --- loss:0.109, Epoch accuracy:98.25%, Validation loss:1.172, Validation accuracy:59.67%
# Epoch 310: iteration 34/35
# Epoch 310 --- loss:0.114, Epoch accuracy:98.16%, Validation loss:1.045, Validation accuracy:62.00%
# Epoch 311: iteration 34/35
# Epoch 311 --- loss:0.117, Epoch accuracy:97.98%, Validation loss:1.045, Validation accuracy:61.00%
# Epoch 312: iteration 34/35
# Epoch 312 --- loss:0.108, Epoch accuracy:98.25%, Validation loss:1.006, Validation accuracy:64.33%
# Epoch 313: iteration 34/35
# Epoch 313 --- loss:0.115, Epoch accuracy:98.25%, Validation loss:0.991, Validation accuracy:65.33%
# Epoch 314: iteration 34/35
# Epoch 314 --- loss:0.107, Epoch accuracy:98.16%, Validation loss:1.031, Validation accuracy:66.00%
# Epoch 315: iteration 34/35
# Epoch 315 --- loss:0.103, Epoch accuracy:98.25%, Validation loss:1.129, Validation accuracy:62.67%
# Epoch 316: iteration 34/35
# Epoch 316 --- loss:0.102, Epoch accuracy:98.25%, Validation loss:0.999, Validation accuracy:64.00%
# Epoch 317: iteration 34/35
# Epoch 317 --- loss:0.097, Epoch accuracy:98.25%, Validation loss:1.095, Validation accuracy:61.67%
# Epoch 318: iteration 34/35
# Epoch 318 --- loss:0.104, Epoch accuracy:98.25%, Validation loss:1.023, Validation accuracy:66.33%
# Epoch 319: iteration 34/35
# Epoch 319 --- loss:0.108, Epoch accuracy:97.89%, Validation loss:0.966, Validation accuracy:68.33%
# Epoch 320: iteration 34/35
# Epoch 320 --- loss:0.109, Epoch accuracy:98.25%, Validation loss:1.066, Validation accuracy:61.00%
# Epoch 321: iteration 34/35
# Epoch 321 --- loss:0.105, Epoch accuracy:97.98%, Validation loss:1.223, Validation accuracy:60.00%
# Epoch 322: iteration 34/35
# Epoch 322 --- loss:0.099, Epoch accuracy:98.25%, Validation loss:0.963, Validation accuracy:68.33%
# Epoch 323: iteration 34/35
# Epoch 323 --- loss:0.105, Epoch accuracy:98.07%, Validation loss:1.042, Validation accuracy:65.00%
# Epoch 324: iteration 34/35
# Epoch 324 --- loss:0.104, Epoch accuracy:98.25%, Validation loss:1.103, Validation accuracy:64.00%
# Epoch 325: iteration 34/35
# Epoch 325 --- loss:0.096, Epoch accuracy:98.16%, Validation loss:1.073, Validation accuracy:64.00%
# Epoch 326: iteration 34/35
# Epoch 326 --- loss:0.091, Epoch accuracy:98.25%, Validation loss:0.990, Validation accuracy:67.33%
# Epoch 327: iteration 34/35
# Epoch 327 --- loss:0.101, Epoch accuracy:98.25%, Validation loss:1.070, Validation accuracy:63.67%
# Epoch 328: iteration 34/35
# Epoch 328 --- loss:0.100, Epoch accuracy:98.25%, Validation loss:1.050, Validation accuracy:64.67%
# Epoch 329: iteration 34/35
# Epoch 329 --- loss:0.094, Epoch accuracy:98.16%, Validation loss:1.018, Validation accuracy:66.00%
# Epoch 330: iteration 34/35
# Epoch 330 --- loss:0.090, Epoch accuracy:98.25%, Validation loss:1.175, Validation accuracy:61.00%
# Epoch 331: iteration 34/35
# Epoch 331 --- loss:0.099, Epoch accuracy:98.25%, Validation loss:0.997, Validation accuracy:66.00%
# Epoch 332: iteration 34/35
# Epoch 332 --- loss:0.096, Epoch accuracy:98.16%, Validation loss:1.021, Validation accuracy:64.67%
# Epoch 333: iteration 34/35
# Epoch 333 --- loss:0.084, Epoch accuracy:98.25%, Validation loss:0.972, Validation accuracy:68.00%
# Epoch 334: iteration 34/35
# Epoch 334 --- loss:0.091, Epoch accuracy:98.25%, Validation loss:1.018, Validation accuracy:66.67%
# Epoch 335: iteration 34/35
# Epoch 335 --- loss:0.092, Epoch accuracy:98.25%, Validation loss:0.989, Validation accuracy:65.67%
# Epoch 336: iteration 34/35
# Epoch 336 --- loss:0.083, Epoch accuracy:98.25%, Validation loss:1.090, Validation accuracy:61.33%
# Epoch 337: iteration 34/35
# Epoch 337 --- loss:0.088, Epoch accuracy:98.25%, Validation loss:1.052, Validation accuracy:61.67%
# Epoch 338: iteration 34/35
# Epoch 338 --- loss:0.087, Epoch accuracy:98.25%, Validation loss:1.006, Validation accuracy:65.00%
# Epoch 339: iteration 34/35
# Epoch 339 --- loss:0.085, Epoch accuracy:98.25%, Validation loss:1.047, Validation accuracy:63.33%
# Epoch 340: iteration 34/35
# Epoch 340 --- loss:0.084, Epoch accuracy:98.25%, Validation loss:1.008, Validation accuracy:66.00%
# Epoch 341: iteration 34/35
# Epoch 341 --- loss:0.089, Epoch accuracy:98.25%, Validation loss:1.081, Validation accuracy:60.67%
# Epoch 342: iteration 34/35
# Epoch 342 --- loss:0.083, Epoch accuracy:98.25%, Validation loss:1.058, Validation accuracy:62.33%
# Epoch 343: iteration 34/35
# Epoch 343 --- loss:0.083, Epoch accuracy:98.25%, Validation loss:1.065, Validation accuracy:63.33%
# Epoch 344: iteration 34/35
# Epoch 344 --- loss:0.085, Epoch accuracy:98.25%, Validation loss:1.071, Validation accuracy:65.00%
# Epoch 345: iteration 34/35
# Epoch 345 --- loss:0.077, Epoch accuracy:98.16%, Validation loss:0.939, Validation accuracy:68.33%
# Epoch 346: iteration 34/35
# Epoch 346 --- loss:0.084, Epoch accuracy:98.25%, Validation loss:1.060, Validation accuracy:64.00%
# Epoch 347: iteration 34/35
# Epoch 347 --- loss:0.082, Epoch accuracy:98.16%, Validation loss:1.112, Validation accuracy:58.00%
# Epoch 348: iteration 34/35
# Epoch 348 --- loss:0.080, Epoch accuracy:98.25%, Validation loss:0.987, Validation accuracy:64.00%
# Epoch 349: iteration 34/35
# Epoch 349 --- loss:0.082, Epoch accuracy:98.25%, Validation loss:1.074, Validation accuracy:62.33%
# Epoch 350: iteration 34/35
# Epoch 350 --- loss:0.082, Epoch accuracy:98.25%, Validation loss:0.990, Validation accuracy:64.00%
# Epoch 351: iteration 34/35
# Epoch 351 --- loss:0.080, Epoch accuracy:98.25%, Validation loss:1.085, Validation accuracy:60.33%
# Epoch 352: iteration 34/35
# Epoch 352 --- loss:0.081, Epoch accuracy:98.25%, Validation loss:0.999, Validation accuracy:66.33%
# Epoch 353: iteration 34/35
# Epoch 353 --- loss:0.080, Epoch accuracy:98.25%, Validation loss:1.022, Validation accuracy:67.00%
# Epoch 354: iteration 34/35
# Epoch 354 --- loss:0.081, Epoch accuracy:98.16%, Validation loss:1.055, Validation accuracy:63.33%
# Epoch 355: iteration 34/35
# Epoch 355 --- loss:0.076, Epoch accuracy:98.25%, Validation loss:1.031, Validation accuracy:63.67%
# Epoch 356: iteration 34/35
# Epoch 356 --- loss:0.074, Epoch accuracy:98.25%, Validation loss:1.025, Validation accuracy:64.67%
# Epoch 357: iteration 34/35
# Epoch 357 --- loss:0.077, Epoch accuracy:98.25%, Validation loss:0.996, Validation accuracy:64.33%
# Epoch 358: iteration 34/35
# Epoch 358 --- loss:0.084, Epoch accuracy:98.25%, Validation loss:1.042, Validation accuracy:63.33%
# Epoch 359: iteration 34/35
# Epoch 359 --- loss:0.075, Epoch accuracy:98.25%, Validation loss:1.029, Validation accuracy:63.00%
# Epoch 360: iteration 34/35
# Epoch 360 --- loss:0.076, Epoch accuracy:98.16%, Validation loss:1.078, Validation accuracy:63.00%
# Epoch 361: iteration 34/35
# Epoch 361 --- loss:0.075, Epoch accuracy:98.25%, Validation loss:1.028, Validation accuracy:64.67%
# Epoch 362: iteration 34/35
# Epoch 362 --- loss:0.076, Epoch accuracy:98.25%, Validation loss:1.018, Validation accuracy:65.33%
# Epoch 363: iteration 34/35
# Epoch 363 --- loss:0.077, Epoch accuracy:98.25%, Validation loss:1.086, Validation accuracy:61.00%
# Epoch 364: iteration 34/35
# Epoch 364 --- loss:0.072, Epoch accuracy:98.25%, Validation loss:0.962, Validation accuracy:68.33%
# Epoch 365: iteration 34/35
# Epoch 365 --- loss:0.073, Epoch accuracy:98.25%, Validation loss:1.022, Validation accuracy:65.00%
# Epoch 366: iteration 34/35
# Epoch 366 --- loss:0.066, Epoch accuracy:98.25%, Validation loss:1.005, Validation accuracy:66.00%
# Epoch 367: iteration 34/35
# Epoch 367 --- loss:0.071, Epoch accuracy:98.25%, Validation loss:1.015, Validation accuracy:64.00%
# Epoch 368: iteration 34/35
# Epoch 368 --- loss:0.075, Epoch accuracy:98.25%, Validation loss:1.016, Validation accuracy:65.67%
# Epoch 369: iteration 34/35
# Epoch 369 --- loss:0.069, Epoch accuracy:98.25%, Validation loss:1.011, Validation accuracy:64.33%
# Epoch 370: iteration 34/35
# Epoch 370 --- loss:0.068, Epoch accuracy:98.25%, Validation loss:1.034, Validation accuracy:62.67%
# Epoch 371: iteration 34/35
# Epoch 371 --- loss:0.068, Epoch accuracy:98.25%, Validation loss:1.030, Validation accuracy:63.00%
# Epoch 372: iteration 34/35
# Epoch 372 --- loss:0.070, Epoch accuracy:98.25%, Validation loss:0.994, Validation accuracy:67.67%
# Epoch 373: iteration 34/35
# Epoch 373 --- loss:0.068, Epoch accuracy:98.25%, Validation loss:0.988, Validation accuracy:66.00%
# Epoch 374: iteration 34/35
# Epoch 374 --- loss:0.068, Epoch accuracy:98.25%, Validation loss:1.019, Validation accuracy:64.67%
# Epoch 375: iteration 34/35
# Epoch 375 --- loss:0.075, Epoch accuracy:98.25%, Validation loss:1.060, Validation accuracy:63.00%
# Epoch 376: iteration 34/35
# Epoch 376 --- loss:0.067, Epoch accuracy:98.25%, Validation loss:1.000, Validation accuracy:66.67%
# Epoch 377: iteration 34/35
# Epoch 377 --- loss:0.065, Epoch accuracy:98.25%, Validation loss:1.019, Validation accuracy:68.00%
# Epoch 378: iteration 34/35
# Epoch 378 --- loss:0.065, Epoch accuracy:98.25%, Validation loss:1.091, Validation accuracy:61.67%
# Epoch 379: iteration 34/35
# Epoch 379 --- loss:0.069, Epoch accuracy:98.25%, Validation loss:1.026, Validation accuracy:65.67%
# Epoch 380: iteration 34/35
# Epoch 380 --- loss:0.068, Epoch accuracy:98.25%, Validation loss:1.033, Validation accuracy:62.33%
# Epoch 381: iteration 34/35
# Epoch 381 --- loss:0.067, Epoch accuracy:98.25%, Validation loss:1.070, Validation accuracy:61.33%
# ...
# Epoch 374: iteration 36/37
# Epoch 374 --- loss:0.056, Epoch accuracy:98.67%, Validation loss:1.409, Validation accuracy:61.25%
# Epoch 375: iteration 36/37
# Epoch 375 --- loss:0.062, Epoch accuracy:98.67%, Validation loss:1.366, Validation accuracy:59.58%
# Epoch 376: iteration 36/37
# Epoch 376 --- loss:0.056, Epoch accuracy:98.67%, Validation loss:1.449, Validation accuracy:59.58%
# Epoch 377: iteration 36/37
# Epoch 377 --- loss:0.063, Epoch accuracy:98.67%, Validation loss:1.368, Validation accuracy:59.17%
# Epoch 378: iteration 36/37
# Epoch 378 --- loss:0.063, Epoch accuracy:98.67%, Validation loss:1.494, Validation accuracy:58.75%
# Epoch 379: iteration 36/37
# Epoch 379 --- loss:0.059, Epoch accuracy:98.67%, Validation loss:1.465, Validation accuracy:61.67%
# Epoch 380: iteration 36/37
# Epoch 380 --- loss:0.059, Epoch accuracy:98.67%, Validation loss:1.418, Validation accuracy:61.67%
# Epoch 381: iteration 36/37
# Epoch 381 --- loss:0.059, Epoch accuracy:98.67%, Validation loss:1.419, Validation accuracy:60.42%
# Epoch 382: iteration 36/37
# Epoch 382 --- loss:0.057, Epoch accuracy:98.67%, Validation loss:1.392, Validation accuracy:60.42%
# Epoch 383: iteration 36/37
# Epoch 383 --- loss:0.061, Epoch accuracy:98.67%, Validation loss:1.391, Validation accuracy:61.25%
# Epoch 384: iteration 36/37
# Epoch 384 --- loss:0.054, Epoch accuracy:98.67%, Validation loss:1.421, Validation accuracy:60.83%
# Epoch 385: iteration 36/37
# Epoch 385 --- loss:0.066, Epoch accuracy:98.67%, Validation loss:1.302, Validation accuracy:60.42%
# Epoch 386: iteration 36/37
# Epoch 386 --- loss:0.061, Epoch accuracy:98.67%, Validation loss:1.400, Validation accuracy:62.08%
# Epoch 387: iteration 36/37
# Epoch 387 --- loss:0.056, Epoch accuracy:98.67%, Validation loss:1.546, Validation accuracy:58.75%
# Epoch 388: iteration 36/37
# Epoch 388 --- loss:0.058, Epoch accuracy:98.67%, Validation loss:1.593, Validation accuracy:60.00%
# Epoch 389: iteration 36/37
# Epoch 389 --- loss:0.062, Epoch accuracy:98.67%, Validation loss:1.518, Validation accuracy:60.42%
# Epoch 390: iteration 36/37
# Epoch 390 --- loss:0.058, Epoch accuracy:98.67%, Validation loss:1.343, Validation accuracy:61.25%
# Epoch 391: iteration 36/37
# Epoch 391 --- loss:0.052, Epoch accuracy:98.67%, Validation loss:1.368, Validation accuracy:61.25%
# Epoch 392: iteration 36/37
# Epoch 392 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.467, Validation accuracy:57.92%
# Epoch 393: iteration 36/37
# Epoch 393 --- loss:0.057, Epoch accuracy:98.67%, Validation loss:1.348, Validation accuracy:60.00%
# Epoch 394: iteration 36/37
# Epoch 394 --- loss:0.057, Epoch accuracy:98.67%, Validation loss:1.389, Validation accuracy:61.25%
# Epoch 395: iteration 36/37
# Epoch 395 --- loss:0.058, Epoch accuracy:98.67%, Validation loss:1.410, Validation accuracy:58.33%
# Epoch 396: iteration 36/37
# Epoch 396 --- loss:0.059, Epoch accuracy:98.67%, Validation loss:1.455, Validation accuracy:59.17%
# Epoch 397: iteration 36/37
# Epoch 397 --- loss:0.054, Epoch accuracy:98.67%, Validation loss:1.551, Validation accuracy:58.33%
# Epoch 398: iteration 36/37
# Epoch 398 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.345, Validation accuracy:60.42%
# Epoch 399: iteration 36/37
# Epoch 399 --- loss:0.050, Epoch accuracy:98.67%, Validation loss:1.438, Validation accuracy:60.42%
# Epoch 400: iteration 36/37
# Epoch 400 --- loss:0.056, Epoch accuracy:98.67%, Validation loss:1.387, Validation accuracy:60.83%
# Epoch 401: iteration 36/37
# Epoch 401 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.359, Validation accuracy:59.58%
# Epoch 402: iteration 36/37
# Epoch 402 --- loss:0.054, Epoch accuracy:98.67%, Validation loss:1.492, Validation accuracy:59.58%
# Epoch 403: iteration 36/37
# Epoch 403 --- loss:0.049, Epoch accuracy:98.67%, Validation loss:1.470, Validation accuracy:59.17%
# Epoch 404: iteration 36/37
# Epoch 404 --- loss:0.052, Epoch accuracy:98.67%, Validation loss:1.373, Validation accuracy:61.67%
# Epoch 405: iteration 36/37
# Epoch 405 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.459, Validation accuracy:61.67%
# Epoch 406: iteration 36/37
# Epoch 406 --- loss:0.050, Epoch accuracy:98.67%, Validation loss:1.487, Validation accuracy:60.42%
# Epoch 407: iteration 36/37
# Epoch 407 --- loss:0.045, Epoch accuracy:98.67%, Validation loss:1.449, Validation accuracy:58.75%
# Epoch 408: iteration 36/37
# Epoch 408 --- loss:0.054, Epoch accuracy:98.67%, Validation loss:1.374, Validation accuracy:61.25%
# Epoch 409: iteration 36/37
# Epoch 409 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.422, Validation accuracy:60.00%
# Epoch 410: iteration 36/37
# Epoch 410 --- loss:0.052, Epoch accuracy:98.58%, Validation loss:1.395, Validation accuracy:60.00%
# Epoch 411: iteration 36/37
# Epoch 411 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.355, Validation accuracy:58.33%
# Epoch 412: iteration 36/37
# Epoch 412 --- loss:0.054, Epoch accuracy:98.67%, Validation loss:1.524, Validation accuracy:59.17%
# Epoch 413: iteration 36/37
# Epoch 413 --- loss:0.047, Epoch accuracy:98.67%, Validation loss:1.413, Validation accuracy:60.42%
# Epoch 414: iteration 36/37
# Epoch 414 --- loss:0.046, Epoch accuracy:98.67%, Validation loss:1.444, Validation accuracy:58.33%
# Epoch 415: iteration 36/37
# Epoch 415 --- loss:0.050, Epoch accuracy:98.67%, Validation loss:1.326, Validation accuracy:61.67%
# Epoch 416: iteration 36/37
# Epoch 416 --- loss:0.046, Epoch accuracy:98.67%, Validation loss:1.602, Validation accuracy:56.25%
# Epoch 417: iteration 36/37
# Epoch 417 --- loss:0.046, Epoch accuracy:98.58%, Validation loss:1.496, Validation accuracy:61.67%
# Epoch 418: iteration 36/37
# Epoch 418 --- loss:0.045, Epoch accuracy:98.67%, Validation loss:1.545, Validation accuracy:58.33%
# Epoch 419: iteration 36/37
# Epoch 419 --- loss:0.052, Epoch accuracy:98.67%, Validation loss:1.403, Validation accuracy:58.75%
# Epoch 420: iteration 36/37
# Epoch 420 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.476, Validation accuracy:60.42%
# Epoch 421: iteration 36/37
# Epoch 421 --- loss:0.049, Epoch accuracy:98.67%, Validation loss:1.437, Validation accuracy:57.50%
# Epoch 422: iteration 36/37
# Epoch 422 --- loss:0.050, Epoch accuracy:98.67%, Validation loss:1.407, Validation accuracy:60.42%
# Epoch 423: iteration 36/37
# Epoch 423 --- loss:0.049, Epoch accuracy:98.67%, Validation loss:1.448, Validation accuracy:58.75%
# Epoch 424: iteration 36/37
# Epoch 424 --- loss:0.048, Epoch accuracy:98.67%, Validation loss:1.364, Validation accuracy:62.08%
# Epoch 425: iteration 36/37
# Epoch 425 --- loss:0.046, Epoch accuracy:98.67%, Validation loss:1.416, Validation accuracy:58.75%
# Epoch 426: iteration 36/37
# Epoch 426 --- loss:0.051, Epoch accuracy:98.67%, Validation loss:1.434, Validation accuracy:60.00%
# Epoch 427: iteration 36/37
# Epoch 427 --- loss:0.047, Epoch accuracy:98.67%, Validation loss:1.352, Validation accuracy:57.92%
# Epoch 428: iteration 36/37
# Epoch 428 --- loss:0.048, Epoch accuracy:98.67%, Validation loss:1.540, Validation accuracy:60.00%
# Epoch 429: iteration 36/37
# Epoch 429 --- loss:0.045, Epoch accuracy:98.67%, Validation loss:1.423, Validation accuracy:61.67%
# Epoch 430: iteration 36/37
# Epoch 430 --- loss:0.048, Epoch accuracy:98.67%, Validation loss:1.511, Validation accuracy:60.83%
# Epoch 431: iteration 36/37
# Epoch 431 --- loss:0.045, Epoch accuracy:98.67%, Validation loss:1.409, Validation accuracy:59.17%
# Epoch 432: iteration 36/37
# Epoch 432 --- loss:0.047, Epoch accuracy:98.67%, Validation loss:1.475, Validation accuracy:60.83%
# Epoch 433: iteration 36/37
# Epoch 433 --- loss:0.045, Epoch accuracy:98.67%, Validation loss:1.385, Validation accuracy:61.25%
# Epoch 434: iteration 36/37
# Epoch 434 --- loss:0.049, Epoch accuracy:98.67%, Validation loss:1.442, Validation accuracy:55.83%
# Epoch 435: iteration 36/37
# Epoch 435 --- loss:0.044, Epoch accuracy:98.67%, Validation loss:1.549, Validation accuracy:60.42%
# Epoch 436: iteration 36/37
# Epoch 436 --- loss:0.045, Epoch accuracy:98.67%, Validation loss:1.414, Validation accuracy:59.17%
# Epoch 437: iteration 36/37
# Epoch 437 --- loss:0.044, Epoch accuracy:98.67%, Validation loss:1.440, Validation accuracy:59.58%
# Epoch 438: iteration 36/37
# Epoch 438 --- loss:0.042, Epoch accuracy:98.67%, Validation loss:1.352, Validation accuracy:60.42%
# Epoch 439: iteration 36/37
# Epoch 439 --- loss:0.044, Epoch accuracy:98.67%, Validation loss:1.465, Validation accuracy:59.58%
# Epoch 440: iteration 36/37
# Epoch 440 --- loss:0.046, Epoch accuracy:98.67%, Validation loss:1.477, Validation accuracy:57.92%
# Epoch 441: iteration 36/37
# Epoch 441 --- loss:0.043, Epoch accuracy:98.67%, Validation loss:1.382, Validation accuracy:62.92%
# Epoch 442: iteration 36/37
# Epoch 442 --- loss:0.043, Epoch accuracy:98.67%, Validation loss:1.515, Validation accuracy:60.83%
# Epoch 443: iteration 36/37
# Epoch 443 --- loss:0.041, Epoch accuracy:98.67%, Validation loss:1.428, Validation accuracy:61.67%
# Epoch 444: iteration 36/37
# Epoch 444 --- loss:0.042, Epoch accuracy:98.67%, Validation loss:1.534, Validation accuracy:59.17%
# Epoch 445: iteration 36/37
# Epoch 445 --- loss:0.042, Epoch accuracy:98.67%, Validation loss:1.354, Validation accuracy:63.33%
# Epoch 446: iteration 36/37
# Epoch 446 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.384, Validation accuracy:62.50%
# Epoch 447: iteration 36/37
# Epoch 447 --- loss:0.040, Epoch accuracy:98.67%, Validation loss:1.468, Validation accuracy:59.58%
# Epoch 448: iteration 36/37
# Epoch 448 --- loss:0.041, Epoch accuracy:98.67%, Validation loss:1.355, Validation accuracy:61.67%
# Epoch 449: iteration 36/37
# Epoch 449 --- loss:0.040, Epoch accuracy:98.67%, Validation loss:1.366, Validation accuracy:62.92%
# Epoch 450: iteration 36/37
# Epoch 450 --- loss:0.039, Epoch accuracy:98.67%, Validation loss:1.484, Validation accuracy:58.33%
# Epoch 451: iteration 36/37
# Epoch 451 --- loss:0.043, Epoch accuracy:98.67%, Validation loss:1.343, Validation accuracy:62.08%
# Epoch 452: iteration 36/37
# Epoch 452 --- loss:0.041, Epoch accuracy:98.67%, Validation loss:1.401, Validation accuracy:60.42%
# Epoch 453: iteration 36/37
# Epoch 453 --- loss:0.044, Epoch accuracy:98.67%, Validation loss:1.410, Validation accuracy:60.83%
# Epoch 454: iteration 36/37
# Epoch 454 --- loss:0.036, Epoch accuracy:98.67%, Validation loss:1.390, Validation accuracy:59.58%
# Epoch 455: iteration 36/37
# Epoch 455 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.424, Validation accuracy:60.83%
# Epoch 456: iteration 36/37
# Epoch 456 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.384, Validation accuracy:57.92%
# Epoch 457: iteration 36/37
# Epoch 457 --- loss:0.043, Epoch accuracy:98.67%, Validation loss:1.389, Validation accuracy:61.67%
# Epoch 458: iteration 36/37
# Epoch 458 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.463, Validation accuracy:60.42%
# Epoch 459: iteration 36/37
# Epoch 459 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:1.407, Validation accuracy:62.50%
# Epoch 460: iteration 36/37
# Epoch 460 --- loss:0.040, Epoch accuracy:98.67%, Validation loss:1.363, Validation accuracy:62.50%
# Epoch 461: iteration 36/37
# Epoch 461 --- loss:0.041, Epoch accuracy:98.67%, Validation loss:1.441, Validation accuracy:60.83%
# Epoch 462: iteration 36/37
# Epoch 462 --- loss:0.039, Epoch accuracy:98.67%, Validation loss:1.397, Validation accuracy:59.58%
# Epoch 463: iteration 36/37
# Epoch 463 --- loss:0.041, Epoch accuracy:98.67%, Validation loss:1.416, Validation accuracy:60.42%
# Epoch 464: iteration 36/37
# Epoch 464 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.453, Validation accuracy:60.83%
# Epoch 465: iteration 36/37
# Epoch 465 --- loss:0.042, Epoch accuracy:98.67%, Validation loss:1.789, Validation accuracy:52.92%
# Epoch 466: iteration 36/37
# Epoch 466 --- loss:0.041, Epoch accuracy:98.67%, Validation loss:1.533, Validation accuracy:59.58%
# Epoch 467: iteration 36/37
# Epoch 467 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.414, Validation accuracy:60.83%
# Epoch 468: iteration 36/37
# Epoch 468 --- loss:0.036, Epoch accuracy:98.67%, Validation loss:1.407, Validation accuracy:60.83%
# Epoch 469: iteration 36/37
# Epoch 469 --- loss:0.046, Epoch accuracy:98.67%, Validation loss:1.575, Validation accuracy:57.50%
# Epoch 470: iteration 36/37
# Epoch 470 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:1.423, Validation accuracy:59.58%
# Epoch 471: iteration 36/37
# Epoch 471 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.521, Validation accuracy:59.58%
# Epoch 472: iteration 36/37
# Epoch 472 --- loss:0.044, Epoch accuracy:98.67%, Validation loss:1.416, Validation accuracy:59.58%
# Epoch 473: iteration 36/37
# Epoch 473 --- loss:0.036, Epoch accuracy:98.67%, Validation loss:1.502, Validation accuracy:60.42%
# Epoch 474: iteration 36/37
# Epoch 474 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:1.432, Validation accuracy:60.83%
# Epoch 475: iteration 36/37
# Epoch 475 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.412, Validation accuracy:61.67%
# Epoch 476: iteration 36/37
# Epoch 476 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.513, Validation accuracy:60.00%
# Epoch 477: iteration 36/37
# Epoch 477 --- loss:0.039, Epoch accuracy:98.67%, Validation loss:1.510, Validation accuracy:62.92%
# Epoch 478: iteration 36/37
# Epoch 478 --- loss:0.040, Epoch accuracy:98.67%, Validation loss:1.436, Validation accuracy:58.75%
# Epoch 479: iteration 36/37
# Epoch 479 --- loss:0.036, Epoch accuracy:98.67%, Validation loss:1.472, Validation accuracy:60.83%
# Epoch 480: iteration 36/37
# Epoch 480 --- loss:0.032, Epoch accuracy:98.67%, Validation loss:1.461, Validation accuracy:59.17%
# Epoch 481: iteration 36/37
# Epoch 481 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.352, Validation accuracy:62.50%
# Epoch 482: iteration 36/37
# Epoch 482 --- loss:0.032, Epoch accuracy:98.67%, Validation loss:1.427, Validation accuracy:62.50%
# Epoch 483: iteration 36/37
# Epoch 483 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.478, Validation accuracy:60.42%
# Epoch 484: iteration 36/37
# Epoch 484 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.470, Validation accuracy:61.25%
# Epoch 485: iteration 36/37
# Epoch 485 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.423, Validation accuracy:58.75%
# Epoch 486: iteration 36/37
# Epoch 486 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:1.534, Validation accuracy:58.75%
# Epoch 487: iteration 36/37
# Epoch 487 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.533, Validation accuracy:59.17%
# Epoch 488: iteration 36/37
# Epoch 488 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:1.433, Validation accuracy:61.25%
# Epoch 489: iteration 36/37
# Epoch 489 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.413, Validation accuracy:61.67%
# Epoch 490: iteration 36/37
# Epoch 490 --- loss:0.032, Epoch accuracy:98.67%, Validation loss:1.580, Validation accuracy:59.17%
# Epoch 491: iteration 36/37
# Epoch 491 --- loss:0.034, Epoch accuracy:98.67%, Validation loss:1.423, Validation accuracy:61.67%
# Epoch 492: iteration 36/37
# Epoch 492 --- loss:0.033, Epoch accuracy:98.67%, Validation loss:1.496, Validation accuracy:59.17%
# Epoch 493: iteration 36/37
# Epoch 493 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:1.457, Validation accuracy:58.33%
# Epoch 494: iteration 36/37
# Epoch 494 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.651, Validation accuracy:58.33%
# Epoch 495: iteration 36/37
# Epoch 495 --- loss:0.037, Epoch accuracy:98.67%, Validation loss:1.472, Validation accuracy:58.75%
# Epoch 496: iteration 36/37
# Epoch 496 --- loss:0.038, Epoch accuracy:98.67%, Validation loss:1.395, Validation accuracy:60.83%
# Epoch 497: iteration 36/37
# Epoch 497 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.539, Validation accuracy:61.25%
# Epoch 498: iteration 36/37
# Epoch 498 --- loss:0.035, Epoch accuracy:98.67%, Validation loss:1.360, Validation accuracy:62.50%
# Epoch 499: iteration 36/37
# Epoch 499 --- loss:0.032, Epoch accuracy:98.67%, Validation loss:1.455, Validation accuracy:59.17%
#
#
# [*] done !
# [*] Best training loss - 0.03152329320708912
# [*] Best validation loss - 1.2536579370498657

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
# Out:
# [*] 0 Test accuracy is 69.00%
# [*] 1 Test accuracy is 59.00%
# [*] 2 Test accuracy is 60.33%
# [*] 3 Test accuracy is 61.67%
# [*] 4 Test accuracy is 61.25%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 69.00%
# [*] Worst fold acc : 59.00%
# [*] Average fold acc : 62.25%

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
# Out:
# [*] 0 Test accuracy is 69.00%
#               precision    recall  f1-score   support
#
#            0       0.58      0.55      0.56        20
#            1       0.75      0.60      0.67        40
#            2       0.83      0.60      0.70        40
#            3       0.55      0.42      0.48        40
#            4       0.71      0.93      0.80        40
#            5       0.79      0.78      0.78        40
#            6       0.57      0.78      0.66        40
#            7       0.73      0.80      0.76        40
#
#     accuracy                           0.69       300
#    macro avg       0.69      0.68      0.68       300
# weighted avg       0.70      0.69      0.68       300
#
# [*] 1 Test accuracy is 59.33%
#               precision    recall  f1-score   support
#
#            0       0.33      0.30      0.32        20
#            1       0.62      0.60      0.61        40
#            2       0.61      0.55      0.58        40
#            3       0.62      0.40      0.48        40
#            4       0.72      0.70      0.71        40
#            5       0.48      0.62      0.54        40
#            6       0.57      0.62      0.60        40
#            7       0.70      0.80      0.74        40
#
#     accuracy                           0.59       300
#    macro avg       0.58      0.57      0.57       300
# weighted avg       0.60      0.59      0.59       300
#
# [*] 2 Test accuracy is 60.33%
#               precision    recall  f1-score   support
#
#            0       0.38      0.40      0.39        20
#            1       0.60      0.65      0.63        40
#            2       0.56      0.50      0.53        40
#            3       0.43      0.47      0.45        40
#            4       0.72      0.70      0.71        40
#            5       0.63      0.55      0.59        40
#            6       0.66      0.68      0.67        40
#            7       0.76      0.78      0.77        40
#
#     accuracy                           0.60       300
#    macro avg       0.59      0.59      0.59       300
# weighted avg       0.61      0.60      0.60       300
#
# [*] 3 Test accuracy is 59.00%
#               precision    recall  f1-score   support
#
#            0       0.53      0.40      0.46        20
#            1       0.65      0.75      0.70        40
#            2       0.50      0.40      0.44        40
#            3       0.47      0.35      0.40        40
#            4       0.68      0.65      0.67        40
#            5       0.45      0.50      0.48        40
#            6       0.67      0.80      0.73        40
#            7       0.66      0.78      0.71        40
#
#     accuracy                           0.59       300
#    macro avg       0.58      0.58      0.57       300
# weighted avg       0.58      0.59      0.58       300
#
# [*] 4 Test accuracy is 59.17%
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56        16
#            1       0.62      0.75      0.68        32
#            2       0.48      0.47      0.48        32
#            3       0.41      0.50      0.45        32
#            4       0.76      0.81      0.79        32
#            5       0.59      0.53      0.56        32
#            6       0.71      0.62      0.67        32
#            7       0.62      0.47      0.54        32
#
#     accuracy                           0.59       240
#    macro avg       0.60      0.59      0.59       240
# weighted avg       0.60      0.59      0.59       240
