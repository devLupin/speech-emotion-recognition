# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torch.autograd import Variable
from torchinfo import summary
from tqdm.auto import tqdm

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f'Device : {device}')
print(f'Count of using GPUs : {torch.cuda.device_count()}')
print(f'Current cuda device : {torch.cuda.current_device()}\n')
# Out:
# Device : cuda
# Count of using GPUs : 1
# Current cuda device : 0

# %%
class _LayerNorm(nn.Module):
    """Layer Normalization base class."""

    def __init__(self, channel_size):
        super(_LayerNorm, self).__init__()
        self.channel_size = channel_size
        self.gamma = nn.Parameter(torch.ones(channel_size),
                                  requires_grad=True)
        self.beta = nn.Parameter(torch.zeros(channel_size),
                                 requires_grad=True)

    def apply_gain_and_bias(self, normed_x):
        """ Assumes input of size `[batch, chanel, *]`. """
        return (self.gamma * normed_x.transpose(1, -1) +
                self.beta).transpose(1, -1)


EPS = 1e-8


class GlobLN(_LayerNorm):
    """Global Layer Normalization (globLN)."""

    def forward(self, x):
        """ Applies forward pass.
        Works for any input size > 2D.
        Args:
            x (:class:`torch.Tensor`): Shape `[batch, chan, *]`
        Returns:
            :class:`torch.Tensor`: gLN_x `[batch, chan, *]`
        """
        dims = list(range(1, len(x.shape)))
        mean = x.mean(dim=dims, keepdim=True)
        var = torch.pow(x - mean, 2).mean(dim=dims, keepdim=True)
        return self.apply_gain_and_bias((x - mean) / (var + EPS).sqrt())


class Conv1DBlock(nn.Module):
    """One dimensional convolutional block, as proposed in [1].
    Args:
        in_chan (int): Number of input channels.
        hid_chan (int): Number of hidden channels in the depth-wise
            convolution.
        skip_out_chan (int): Number of channels in the skip convolution.
            If 0 or None, `Conv1DBlock` won't have any skip connections.
            Corresponds to the the block in v1 or the paper. The `forward`
            return res instead of [res, skip] in this case.
        kernel_size (int): Size of the depth-wise convolutional kernel.
        padding (int): Padding of the depth-wise convolution.
        dilation (int): Dilation of the depth-wise convolution.
        norm_type (str, optional): Type of normalization to use. To choose from
            -  ``'gLN'``: global Layernorm
            -  ``'cLN'``: channelwise Layernorm
            -  ``'cgLN'``: cumulative global Layernorm
    References:
        [1] : "Conv-TasNet: Surpassing ideal time-frequency magnitude masking
        for speech separation" TASLP 2019 Yi Luo, Nima Mesgarani
        https://arxiv.org/abs/1809.07454
    """

    def __init__(self, in_chan, hid_chan, kernel_size, padding,
                 dilation, ):
        super(Conv1DBlock, self).__init__()
        conv_norm = GlobLN
        in_conv1d = nn.Conv1d(in_chan, hid_chan, 1)
        depth_conv1d = nn.Conv1d(hid_chan, hid_chan, kernel_size,
                                 padding=padding, dilation=dilation,
                                 groups=hid_chan)
        self.shared_block = nn.Sequential(in_conv1d, nn.PReLU(),
                                          conv_norm(hid_chan), depth_conv1d,
                                          nn.PReLU(), conv_norm(hid_chan))
        self.res_conv = nn.Conv1d(hid_chan, in_chan, 1)

    def forward(self, x):
        """ Input shape [batch, feats, seq]"""
        shared_out = self.shared_block(x)
        res_out = self.res_conv(shared_out)
        return res_out


class TCN(nn.Module):
    # n blocks --> receptive field increases , n_repeats increases capacity mostly
    def __init__(self, in_chan=40, n_src=1, out_chan=8, n_blocks=5, n_repeats=2, 
                 bn_chan=64, hid_chan=128, kernel_size=3, dropout_prob=0.2 ):
        super(TCN, self).__init__()
        self.in_chan = in_chan
        self.n_src = n_src
        out_chan = out_chan if out_chan else in_chan
        self.out_chan = out_chan
        self.n_blocks = n_blocks
        self.n_repeats = n_repeats
        self.bn_chan = bn_chan
        self.hid_chan = hid_chan
        self.kernel_size = kernel_size

        self.dropout = nn.Dropout(p=dropout_prob)

        layer_norm = GlobLN(in_chan)
        bottleneck_conv = nn.Conv1d(in_chan, bn_chan, 1)
        self.bottleneck = nn.Sequential(layer_norm, bottleneck_conv)
        # Succession of Conv1DBlock with exponentially increasing dilation.
        self.TCN = nn.ModuleList()
        for r in range(n_repeats):       #ripetizioni 2
            for x in range(n_blocks):     #5 layers convoluzionali
                padding = (kernel_size - 1) * 2 ** x // 2
                self.TCN.append(Conv1DBlock(bn_chan, hid_chan,
                                            kernel_size, padding=padding,
                                            dilation=2 ** x))

        out_conv = nn.Linear(bn_chan, n_src * out_chan)
        self.out = nn.Sequential(nn.PReLU(), out_conv)
        
        self.softmax_out = nn.Softmax(dim=1)

    # self.out = nn.Linear(bn_chan, n_src*out_chan)
    # self.out = nn.Linear(800, n_src*out_chan)

    # Get activation function.
    def forward(self, mixture_w):
        output = self.dropout(self.bottleneck(mixture_w))
        for i in range(len(self.TCN)):
            residual = self.TCN[i](output)
            output = output + residual
        output = self.dropout(output)

        output_logits = self.out(self.dropout(output.mean(-1)))
        output_softmax = self.softmax_out(output_logits)
        
        return output_logits, output_softmax
        
        return logits

# %%
from torchinfo import summary

emotions_dict = {
    '0': 'surprised',
    '1': 'neutral',
    '2': 'calm',
    '3': 'happy',
    '4': 'sad',
    '5': 'angry',
    '6': 'fearful',
    '7': 'disgust'
}

model = TCN().to('cuda')
sub_name = 'TCN'
data_name = 'RAVDESS'

EARLY_CNT=500
minibatch = 128
num_epochs = 500
print(summary(model, input_size=(minibatch, 40, 282)))

optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TCN                                      [128, 8]                  --
# ├─Dropout: 1-5                           [128, 64]                 --
# ├─Sequential: 1-2                        [128, 64, 282]            --
# │    └─GlobLN: 2-1                       [128, 40, 282]            80
# │    └─Conv1d: 2-2                       [128, 64, 282]            2,624
# ├─Dropout: 1-3                           [128, 64, 282]            --
# ├─ModuleList: 1                          --                        --
# │    └─Conv1DBlock: 2-3                  [128, 64, 282]            --
# │    │    └─Sequential: 3-1              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-2                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-4                  [128, 64, 282]            --
# │    │    └─Sequential: 3-3              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-4                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-5                  [128, 64, 282]            --
# │    │    └─Sequential: 3-5              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-6                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-6                  [128, 64, 282]            --
# │    │    └─Sequential: 3-7              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-8                  [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-7                  [128, 64, 282]            --
# │    │    └─Sequential: 3-9              [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-10                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-8                  [128, 64, 282]            --
# │    │    └─Sequential: 3-11             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-12                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-9                  [128, 64, 282]            --
# │    │    └─Sequential: 3-13             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-14                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-10                 [128, 64, 282]            --
# │    │    └─Sequential: 3-15             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-16                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-11                 [128, 64, 282]            --
# │    │    └─Sequential: 3-17             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-18                 [128, 64, 282]            8,256
# │    └─Conv1DBlock: 2-12                 [128, 64, 282]            --
# │    │    └─Sequential: 3-19             [128, 128, 282]           9,346
# │    │    └─Conv1d: 3-20                 [128, 64, 282]            8,256
# ├─Dropout: 1-4                           [128, 64, 282]            --
# ├─Dropout: 1-5                           [128, 64]                 --
# ├─Sequential: 1-6                        [128, 8]                  --
# │    └─PReLU: 2-13                       [128, 64]                 1
# │    └─Linear: 2-14                      [128, 8]                  520
# ├─Softmax: 1-7                           [128, 8]                  --
# ==========================================================================================
# Total params: 179,245
# Trainable params: 179,245
# Non-trainable params: 0
# Total mult-adds (G): 6.26
# ==========================================================================================
# Input size (MB): 5.78
# Forward/backward pass size (MB): 2432.66
# Params size (MB): 0.72
# Estimated Total Size (MB): 2439.15
# ==========================================================================================

# %%
from typing import Optional

def label_to_one_hot_label(
    labels: torch.Tensor,
    num_classes: int,
    device: Optional[torch.device] = None,
    dtype: Optional[torch.dtype] = None,
    eps: float = 1e-6,
    ignore_index=255,
) -> torch.Tensor:

    shape = labels.shape
    # one hot : (B, C=ignore_index+1, H, W)
    one_hot = torch.zeros((shape[0], ignore_index+1) + shape[1:], device=device, dtype=dtype)
    
    # labels : (B, H, W)
    # labels.unsqueeze(1) : (B, C=1, H, W)
    # one_hot : (B, C=ignore_index+1, H, W)
    one_hot = one_hot.scatter_(1, labels.unsqueeze(1), 1.0) + eps
    
    # ret : (B, C=num_classes, H, W)
    ret = torch.split(one_hot, [num_classes, ignore_index+1-num_classes], dim=1)[0]
    
    return ret


def focal_loss(input, target, alpha, gamma, reduction, eps, ignore_index):
    
    if not isinstance(input, torch.Tensor):
        raise TypeError(f"Input type is not a torch.Tensor. Got {type(input)}")

    if not len(input.shape) >= 2:
        raise ValueError(f"Invalid input shape, we expect BxCx*. Got: {input.shape}")

    if input.size(0) != target.size(0):
        raise ValueError(f'Expected input batch_size ({input.size(0)}) to match target batch_size ({target.size(0)}).')    
        
    # compute softmax over the classes axis
    # input_soft : (B, C, H, W)
    input_soft = F.softmax(input, dim=1) + eps
    
    # create the labels one hot tensor
    # target_one_hot : (B, C, H, W)
    target_one_hot = label_to_one_hot_label(target.long(), num_classes=input.shape[1], device=input.device, dtype=input.dtype, ignore_index=ignore_index)

    # compute the actual focal loss
    weight = torch.pow(1.0 - input_soft, gamma)
    
    # alpha, weight, input_soft : (B, C, H, W)
    # focal : (B, C, H, W)
    focal = -alpha * weight * torch.log(input_soft)
    
    # loss_tmp : (B, H, W)
    loss_tmp = torch.sum(target_one_hot * focal, dim=1)

    if reduction == 'none':
        # loss : (B, H, W)
        loss = loss_tmp
    elif reduction == 'mean':
        # loss : scalar
        loss = torch.mean(loss_tmp)
    elif reduction == 'sum':
        # loss : scalar
        loss = torch.sum(loss_tmp)
    else:
        raise NotImplementedError(f"Invalid reduction mode: {reduction}")
    return loss

class FocalLoss(nn.Module):
    def __init__(self, alpha, gamma = 2.0, reduction = 'mean', eps = 1e-8, ignore_index=30):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction
        self.eps = eps
        self.ignore_index = ignore_index

    def forward(self, input, target):
        return focal_loss(input, target, self.alpha, self.gamma, self.reduction, self.eps, self.ignore_index)


def criterion(predictions, targets):
    return FocalLoss(alpha=0.5, gamma=2.0, reduction='mean')(predictions, targets)

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

npy_path = './numpy_48k_1d'
all_npy = os.listdir(npy_path)

print(f'[*] model training - {sub_name}')
for fold in all_npy:
    npy = os.path.join(npy_path, fold)
    
    with open(npy, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
        
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - TCN
# 0.npy:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 25/26
# Epoch 0 --- loss:0.931, Epoch accuracy:11.29%, Validation loss:0.871, Validation accuracy:13.33%
# Epoch 1: iteration 25/26
# Epoch 1 --- loss:0.833, Epoch accuracy:12.95%, Validation loss:0.816, Validation accuracy:14.56%
# Epoch 2: iteration 25/26
# Epoch 2 --- loss:0.797, Epoch accuracy:11.90%, Validation loss:0.793, Validation accuracy:13.67%
# Epoch 3: iteration 25/26
# Epoch 3 --- loss:0.780, Epoch accuracy:13.30%, Validation loss:0.786, Validation accuracy:13.33%
# Epoch 4: iteration 25/26
# Epoch 4 --- loss:0.775, Epoch accuracy:14.50%, Validation loss:0.783, Validation accuracy:13.33%
# Epoch 5: iteration 25/26
# Epoch 5 --- loss:0.771, Epoch accuracy:13.71%, Validation loss:0.783, Validation accuracy:13.33%
# Epoch 6: iteration 25/26
# Epoch 6 --- loss:0.768, Epoch accuracy:14.42%, Validation loss:0.782, Validation accuracy:13.44%
# Epoch 7: iteration 25/26
# Epoch 7 --- loss:0.764, Epoch accuracy:14.42%, Validation loss:0.781, Validation accuracy:13.33%
# Epoch 8: iteration 25/26
# Epoch 8 --- loss:0.767, Epoch accuracy:13.86%, Validation loss:0.781, Validation accuracy:13.44%
# Epoch 9: iteration 25/26
# Epoch 9 --- loss:0.760, Epoch accuracy:16.61%, Validation loss:0.780, Validation accuracy:14.22%
# Epoch 10: iteration 25/26
# Epoch 10 --- loss:0.761, Epoch accuracy:15.41%, Validation loss:0.776, Validation accuracy:14.00%
# Epoch 11: iteration 25/26
# Epoch 11 --- loss:0.756, Epoch accuracy:15.88%, Validation loss:0.776, Validation accuracy:14.44%
# Epoch 12: iteration 25/26
# Epoch 12 --- loss:0.758, Epoch accuracy:16.75%, Validation loss:0.773, Validation accuracy:13.78%
# Epoch 13: iteration 25/26
# Epoch 13 --- loss:0.752, Epoch accuracy:17.92%, Validation loss:0.771, Validation accuracy:16.00%
# Epoch 14: iteration 25/26
# Epoch 14 --- loss:0.750, Epoch accuracy:17.25%, Validation loss:0.769, Validation accuracy:16.44%
# Epoch 15: iteration 25/26
# Epoch 15 --- loss:0.748, Epoch accuracy:17.13%, Validation loss:0.764, Validation accuracy:16.44%
# Epoch 16: iteration 25/26
# Epoch 16 --- loss:0.741, Epoch accuracy:19.97%, Validation loss:0.758, Validation accuracy:18.89%
# Epoch 17: iteration 25/26
# Epoch 17 --- loss:0.737, Epoch accuracy:20.67%, Validation loss:0.759, Validation accuracy:16.89%
# Epoch 18: iteration 25/26
# Epoch 18 --- loss:0.738, Epoch accuracy:20.73%, Validation loss:0.750, Validation accuracy:21.78%
# Epoch 19: iteration 25/26
# Epoch 19 --- loss:0.732, Epoch accuracy:21.43%, Validation loss:0.747, Validation accuracy:19.78%
# Epoch 20: iteration 25/26
# Epoch 20 --- loss:0.726, Epoch accuracy:23.13%, Validation loss:0.744, Validation accuracy:22.11%
# Epoch 21: iteration 25/26
# Epoch 21 --- loss:0.723, Epoch accuracy:20.76%, Validation loss:0.744, Validation accuracy:22.44%
# Epoch 22: iteration 25/26
# Epoch 22 --- loss:0.719, Epoch accuracy:21.43%, Validation loss:0.752, Validation accuracy:20.00%
# Epoch 23: iteration 25/26
# Epoch 23 --- loss:0.712, Epoch accuracy:22.89%, Validation loss:0.738, Validation accuracy:20.89%
# Epoch 24: iteration 25/26
# Epoch 24 --- loss:0.710, Epoch accuracy:23.57%, Validation loss:0.743, Validation accuracy:21.33%
# Epoch 25: iteration 25/26
# Epoch 25 --- loss:0.709, Epoch accuracy:22.40%, Validation loss:0.739, Validation accuracy:20.78%
# Epoch 26: iteration 25/26
# Epoch 26 --- loss:0.700, Epoch accuracy:23.30%, Validation loss:0.747, Validation accuracy:21.78%
# Epoch 27: iteration 25/26
# Epoch 27 --- loss:0.696, Epoch accuracy:23.45%, Validation loss:0.751, Validation accuracy:20.67%
# Epoch 28: iteration 25/26
# Epoch 28 --- loss:0.692, Epoch accuracy:24.12%, Validation loss:0.739, Validation accuracy:22.11%
# Epoch 29: iteration 25/26
# Epoch 29 --- loss:0.690, Epoch accuracy:24.77%, Validation loss:0.755, Validation accuracy:20.78%
# Epoch 30: iteration 25/26
# Epoch 30 --- loss:0.683, Epoch accuracy:24.71%, Validation loss:0.760, Validation accuracy:20.56%
# Epoch 31: iteration 25/26
# Epoch 31 --- loss:0.677, Epoch accuracy:25.61%, Validation loss:0.750, Validation accuracy:21.67%
# Epoch 32: iteration 25/26
# Epoch 32 --- loss:0.674, Epoch accuracy:25.23%, Validation loss:0.745, Validation accuracy:21.67%
# Epoch 33: iteration 25/26
# Epoch 33 --- loss:0.670, Epoch accuracy:25.50%, Validation loss:0.773, Validation accuracy:20.44%
# Epoch 34: iteration 25/26
# Epoch 34 --- loss:0.669, Epoch accuracy:26.08%, Validation loss:0.755, Validation accuracy:21.00%
# Epoch 35: iteration 25/26
# Epoch 35 --- loss:0.665, Epoch accuracy:26.61%, Validation loss:0.745, Validation accuracy:20.89%
# Epoch 36: iteration 25/26
# Epoch 36 --- loss:0.662, Epoch accuracy:26.61%, Validation loss:0.761, Validation accuracy:20.33%
# Epoch 37: iteration 25/26
# Epoch 37 --- loss:0.657, Epoch accuracy:26.61%, Validation loss:0.778, Validation accuracy:20.44%
# Epoch 38: iteration 25/26
# Epoch 38 --- loss:0.653, Epoch accuracy:27.22%, Validation loss:0.770, Validation accuracy:20.11%
# Epoch 39: iteration 25/26
# Epoch 39 --- loss:0.654, Epoch accuracy:27.08%, Validation loss:0.780, Validation accuracy:20.33%
# Epoch 40: iteration 25/26
# Epoch 40 --- loss:0.648, Epoch accuracy:26.37%, Validation loss:0.791, Validation accuracy:20.22%
# Epoch 41: iteration 25/26
# Epoch 41 --- loss:0.645, Epoch accuracy:26.99%, Validation loss:0.802, Validation accuracy:20.11%
# Epoch 42: iteration 25/26
# Epoch 42 --- loss:0.644, Epoch accuracy:27.87%, Validation loss:0.808, Validation accuracy:19.78%
# Epoch 43: iteration 25/26
# Epoch 43 --- loss:0.641, Epoch accuracy:27.72%, Validation loss:0.775, Validation accuracy:20.11%
# Epoch 44: iteration 25/26
# Epoch 44 --- loss:0.634, Epoch accuracy:29.18%, Validation loss:0.796, Validation accuracy:20.11%
# Epoch 45: iteration 25/26
# Epoch 45 --- loss:0.633, Epoch accuracy:28.80%, Validation loss:0.819, Validation accuracy:19.78%
# Epoch 46: iteration 25/26
# Epoch 46 --- loss:0.632, Epoch accuracy:28.48%, Validation loss:0.830, Validation accuracy:19.67%
# Epoch 47: iteration 25/26
# Epoch 47 --- loss:0.631, Epoch accuracy:28.83%, Validation loss:0.828, Validation accuracy:19.56%
# Epoch 48: iteration 25/26
# Epoch 48 --- loss:0.630, Epoch accuracy:28.83%, Validation loss:0.800, Validation accuracy:20.00%
# Epoch 49: iteration 25/26
# Epoch 49 --- loss:0.625, Epoch accuracy:29.47%, Validation loss:0.801, Validation accuracy:20.22%
# Epoch 50: iteration 25/26
# Epoch 50 --- loss:0.625, Epoch accuracy:29.18%, Validation loss:0.808, Validation accuracy:20.00%
# Epoch 51: iteration 25/26
# Epoch 51 --- loss:0.623, Epoch accuracy:28.22%, Validation loss:0.820, Validation accuracy:20.00%
# Epoch 52: iteration 25/26
# Epoch 52 --- loss:0.616, Epoch accuracy:30.12%, Validation loss:0.834, Validation accuracy:20.00%
# Epoch 53: iteration 25/26
# Epoch 53 --- loss:0.615, Epoch accuracy:28.92%, Validation loss:0.811, Validation accuracy:20.89%
# Epoch 54: iteration 25/26
# Epoch 54 --- loss:0.613, Epoch accuracy:29.82%, Validation loss:0.834, Validation accuracy:20.44%
# Epoch 55: iteration 25/26
# Epoch 55 --- loss:0.609, Epoch accuracy:30.29%, Validation loss:0.865, Validation accuracy:20.00%
# Epoch 56: iteration 25/26
# Epoch 56 --- loss:0.609, Epoch accuracy:31.05%, Validation loss:0.843, Validation accuracy:20.44%
# Epoch 57: iteration 25/26
# Epoch 57 --- loss:0.610, Epoch accuracy:30.35%, Validation loss:0.821, Validation accuracy:21.00%
# Epoch 58: iteration 25/26
# Epoch 58 --- loss:0.610, Epoch accuracy:29.82%, Validation loss:0.845, Validation accuracy:20.67%
# Epoch 59: iteration 25/26
# Epoch 59 --- loss:0.607, Epoch accuracy:31.26%, Validation loss:0.862, Validation accuracy:20.33%
# Epoch 60: iteration 25/26
# Epoch 60 --- loss:0.604, Epoch accuracy:30.53%, Validation loss:0.890, Validation accuracy:20.33%
# Epoch 61: iteration 25/26
# Epoch 61 --- loss:0.604, Epoch accuracy:30.82%, Validation loss:0.867, Validation accuracy:20.78%
# Epoch 62: iteration 25/26
# Epoch 62 --- loss:0.599, Epoch accuracy:30.35%, Validation loss:0.868, Validation accuracy:20.78%
# Epoch 63: iteration 25/26
# Epoch 63 --- loss:0.602, Epoch accuracy:30.96%, Validation loss:0.885, Validation accuracy:20.56%
# Epoch 64: iteration 25/26
# Epoch 64 --- loss:0.600, Epoch accuracy:30.61%, Validation loss:0.867, Validation accuracy:21.22%
# Epoch 65: iteration 25/26
# Epoch 65 --- loss:0.596, Epoch accuracy:30.94%, Validation loss:0.886, Validation accuracy:20.78%
# Epoch 66: iteration 25/26
# Epoch 66 --- loss:0.598, Epoch accuracy:30.53%, Validation loss:0.847, Validation accuracy:21.67%
# Epoch 67: iteration 25/26
# Epoch 67 --- loss:0.597, Epoch accuracy:31.43%, Validation loss:0.881, Validation accuracy:21.00%
# Epoch 68: iteration 25/26
# Epoch 68 --- loss:0.597, Epoch accuracy:31.29%, Validation loss:0.876, Validation accuracy:21.56%
# Epoch 69: iteration 25/26
# Epoch 69 --- loss:0.598, Epoch accuracy:32.13%, Validation loss:0.909, Validation accuracy:20.44%
# Epoch 70: iteration 25/26
# Epoch 70 --- loss:0.595, Epoch accuracy:31.40%, Validation loss:0.902, Validation accuracy:21.44%
# Epoch 71: iteration 25/26
# Epoch 71 --- loss:0.587, Epoch accuracy:31.93%, Validation loss:0.867, Validation accuracy:22.00%
# Epoch 72: iteration 25/26
# Epoch 72 --- loss:0.591, Epoch accuracy:32.13%, Validation loss:0.886, Validation accuracy:20.67%
# Epoch 73: iteration 25/26
# Epoch 73 --- loss:0.588, Epoch accuracy:32.40%, Validation loss:0.930, Validation accuracy:20.56%
# Epoch 74: iteration 25/26
# Epoch 74 --- loss:0.590, Epoch accuracy:30.73%, Validation loss:0.885, Validation accuracy:21.44%
# Epoch 75: iteration 25/26
# Epoch 75 --- loss:0.588, Epoch accuracy:32.49%, Validation loss:0.886, Validation accuracy:21.67%
# Epoch 76: iteration 25/26
# Epoch 76 --- loss:0.585, Epoch accuracy:32.46%, Validation loss:0.894, Validation accuracy:20.89%
# Epoch 77: iteration 25/26
# Epoch 77 --- loss:0.592, Epoch accuracy:31.08%, Validation loss:0.988, Validation accuracy:20.78%
# Epoch 78: iteration 25/26
# Epoch 78 --- loss:0.583, Epoch accuracy:31.90%, Validation loss:0.907, Validation accuracy:21.11%
# Epoch 79: iteration 25/26
# Epoch 79 --- loss:0.583, Epoch accuracy:32.72%, Validation loss:0.929, Validation accuracy:21.00%
# Epoch 80: iteration 25/26
# Epoch 80 --- loss:0.584, Epoch accuracy:32.66%, Validation loss:0.926, Validation accuracy:20.67%
# Epoch 81: iteration 25/26
# Epoch 81 --- loss:0.584, Epoch accuracy:32.63%, Validation loss:0.915, Validation accuracy:21.44%
# Epoch 82: iteration 25/26
# Epoch 82 --- loss:0.579, Epoch accuracy:32.89%, Validation loss:0.965, Validation accuracy:21.11%
# Epoch 83: iteration 25/26
# Epoch 83 --- loss:0.577, Epoch accuracy:32.98%, Validation loss:0.936, Validation accuracy:21.22%
# Epoch 84: iteration 25/26
# Epoch 84 --- loss:0.576, Epoch accuracy:33.27%, Validation loss:0.958, Validation accuracy:21.44%
# Epoch 85: iteration 25/26
# Epoch 85 --- loss:0.580, Epoch accuracy:32.51%, Validation loss:0.947, Validation accuracy:21.33%
# Epoch 86: iteration 25/26
# Epoch 86 --- loss:0.574, Epoch accuracy:34.12%, Validation loss:0.961, Validation accuracy:21.22%
# Epoch 87: iteration 25/26
# Epoch 87 --- loss:0.577, Epoch accuracy:31.73%, Validation loss:0.991, Validation accuracy:21.00%
# Epoch 88: iteration 25/26
# Epoch 88 --- loss:0.572, Epoch accuracy:33.57%, Validation loss:0.990, Validation accuracy:21.22%
# Epoch 89: iteration 25/26
# Epoch 89 --- loss:0.573, Epoch accuracy:33.04%, Validation loss:0.935, Validation accuracy:21.89%
# Epoch 90: iteration 25/26
# Epoch 90 --- loss:0.569, Epoch accuracy:34.50%, Validation loss:0.962, Validation accuracy:21.56%
# Epoch 91: iteration 25/26
# Epoch 91 --- loss:0.573, Epoch accuracy:33.71%, Validation loss:0.851, Validation accuracy:22.56%
# Epoch 92: iteration 25/26
# Epoch 92 --- loss:0.576, Epoch accuracy:32.89%, Validation loss:0.985, Validation accuracy:21.44%
# Epoch 93: iteration 25/26
# Epoch 93 --- loss:0.568, Epoch accuracy:33.45%, Validation loss:1.001, Validation accuracy:20.33%
# Epoch 94: iteration 25/26
# Epoch 94 --- loss:0.571, Epoch accuracy:33.83%, Validation loss:0.964, Validation accuracy:22.22%
# Epoch 95: iteration 25/26
# Epoch 95 --- loss:0.568, Epoch accuracy:32.66%, Validation loss:0.989, Validation accuracy:20.67%
# Epoch 96: iteration 25/26
# Epoch 96 --- loss:0.572, Epoch accuracy:32.66%, Validation loss:0.987, Validation accuracy:21.44%
# Epoch 97: iteration 25/26
# Epoch 97 --- loss:0.568, Epoch accuracy:33.83%, Validation loss:0.987, Validation accuracy:21.44%
# Epoch 98: iteration 25/26
# Epoch 98 --- loss:0.561, Epoch accuracy:34.18%, Validation loss:1.031, Validation accuracy:20.78%
# Epoch 99: iteration 25/26
# Epoch 99 --- loss:0.567, Epoch accuracy:34.39%, Validation loss:0.992, Validation accuracy:21.44%
# Epoch 100: iteration 25/26
# Epoch 100 --- loss:0.566, Epoch accuracy:33.33%, Validation loss:1.020, Validation accuracy:21.11%
# Epoch 101: iteration 25/26
# Epoch 101 --- loss:0.563, Epoch accuracy:34.04%, Validation loss:0.998, Validation accuracy:20.78%
# Epoch 102: iteration 25/26
# Epoch 102 --- loss:0.565, Epoch accuracy:33.98%, Validation loss:0.975, Validation accuracy:21.89%
# Epoch 103: iteration 25/26
# Epoch 103 --- loss:0.565, Epoch accuracy:33.92%, Validation loss:1.025, Validation accuracy:20.56%
# Epoch 104: iteration 25/26
# Epoch 104 --- loss:0.562, Epoch accuracy:34.33%, Validation loss:0.985, Validation accuracy:21.78%
# Epoch 105: iteration 25/26
# Epoch 105 --- loss:0.557, Epoch accuracy:35.20%, Validation loss:1.039, Validation accuracy:20.89%
# Epoch 106: iteration 25/26
# Epoch 106 --- loss:0.559, Epoch accuracy:34.88%, Validation loss:1.057, Validation accuracy:20.33%
# Epoch 107: iteration 25/26
# Epoch 107 --- loss:0.557, Epoch accuracy:34.06%, Validation loss:1.063, Validation accuracy:21.00%
# Epoch 108: iteration 25/26
# Epoch 108 --- loss:0.554, Epoch accuracy:34.65%, Validation loss:1.147, Validation accuracy:19.67%
# Epoch 109: iteration 25/26
# Epoch 109 --- loss:0.561, Epoch accuracy:33.60%, Validation loss:1.011, Validation accuracy:21.22%
# Epoch 110: iteration 25/26
# Epoch 110 --- loss:0.557, Epoch accuracy:35.15%, Validation loss:1.059, Validation accuracy:21.11%
# Epoch 111: iteration 25/26
# Epoch 111 --- loss:0.557, Epoch accuracy:34.74%, Validation loss:1.047, Validation accuracy:20.89%
# Epoch 112: iteration 25/26
# Epoch 112 --- loss:0.554, Epoch accuracy:34.65%, Validation loss:1.118, Validation accuracy:19.89%
# Epoch 113: iteration 25/26
# Epoch 113 --- loss:0.557, Epoch accuracy:33.98%, Validation loss:1.112, Validation accuracy:19.89%
# Epoch 114: iteration 25/26
# Epoch 114 --- loss:0.551, Epoch accuracy:34.97%, Validation loss:1.020, Validation accuracy:20.89%
# Epoch 115: iteration 25/26
# Epoch 115 --- loss:0.553, Epoch accuracy:34.80%, Validation loss:1.027, Validation accuracy:21.22%
# Epoch 116: iteration 25/26
# Epoch 116 --- loss:0.558, Epoch accuracy:33.74%, Validation loss:1.038, Validation accuracy:21.11%
# Epoch 117: iteration 25/26
# Epoch 117 --- loss:0.549, Epoch accuracy:34.82%, Validation loss:1.065, Validation accuracy:21.22%
# Epoch 118: iteration 25/26
# Epoch 118 --- loss:0.550, Epoch accuracy:34.68%, Validation loss:1.061, Validation accuracy:21.11%
# Epoch 119: iteration 25/26
# Epoch 119 --- loss:0.543, Epoch accuracy:34.44%, Validation loss:1.053, Validation accuracy:21.00%
# Epoch 120: iteration 25/26
# Epoch 120 --- loss:0.548, Epoch accuracy:35.35%, Validation loss:1.090, Validation accuracy:20.78%
# Epoch 121: iteration 25/26
# Epoch 121 --- loss:0.547, Epoch accuracy:35.32%, Validation loss:1.074, Validation accuracy:20.33%
# Epoch 122: iteration 25/26
# Epoch 122 --- loss:0.547, Epoch accuracy:35.23%, Validation loss:1.110, Validation accuracy:20.22%
# Epoch 123: iteration 25/26
# Epoch 123 --- loss:0.548, Epoch accuracy:34.77%, Validation loss:1.049, Validation accuracy:20.56%
# Epoch 124: iteration 25/26
# Epoch 124 --- loss:0.543, Epoch accuracy:34.80%, Validation loss:1.071, Validation accuracy:20.67%
# Epoch 125: iteration 25/26
# Epoch 125 --- loss:0.544, Epoch accuracy:35.82%, Validation loss:1.097, Validation accuracy:20.78%
# Epoch 126: iteration 25/26
# Epoch 126 --- loss:0.546, Epoch accuracy:34.56%, Validation loss:1.168, Validation accuracy:19.78%
# Epoch 127: iteration 25/26
# Epoch 127 --- loss:0.537, Epoch accuracy:36.93%, Validation loss:1.127, Validation accuracy:19.78%
# Epoch 128: iteration 25/26
# Epoch 128 --- loss:0.544, Epoch accuracy:35.53%, Validation loss:1.065, Validation accuracy:20.67%
# Epoch 129: iteration 25/26
# Epoch 129 --- loss:0.537, Epoch accuracy:37.22%, Validation loss:1.100, Validation accuracy:20.00%
# Epoch 130: iteration 25/26
# Epoch 130 --- loss:0.535, Epoch accuracy:36.02%, Validation loss:1.089, Validation accuracy:20.11%
# Epoch 131: iteration 25/26
# Epoch 131 --- loss:0.536, Epoch accuracy:36.43%, Validation loss:1.064, Validation accuracy:19.89%
# Epoch 132: iteration 25/26
# Epoch 132 --- loss:0.539, Epoch accuracy:35.12%, Validation loss:1.092, Validation accuracy:20.67%
# Epoch 133: iteration 25/26
# Epoch 133 --- loss:0.535, Epoch accuracy:36.17%, Validation loss:1.138, Validation accuracy:19.56%
# Epoch 134: iteration 25/26
# Epoch 134 --- loss:0.536, Epoch accuracy:35.96%, Validation loss:1.112, Validation accuracy:20.44%
# Epoch 135: iteration 25/26
# Epoch 135 --- loss:0.544, Epoch accuracy:35.23%, Validation loss:1.147, Validation accuracy:19.67%
# Epoch 136: iteration 25/26
# Epoch 136 --- loss:0.536, Epoch accuracy:37.63%, Validation loss:1.083, Validation accuracy:20.78%
# Epoch 137: iteration 25/26
# Epoch 137 --- loss:0.538, Epoch accuracy:35.76%, Validation loss:1.170, Validation accuracy:19.11%
# Epoch 138: iteration 25/26
# Epoch 138 --- loss:0.538, Epoch accuracy:36.52%, Validation loss:1.145, Validation accuracy:19.56%
# Epoch 139: iteration 25/26
# Epoch 139 --- loss:0.533, Epoch accuracy:37.22%, Validation loss:1.090, Validation accuracy:20.00%
# Epoch 140: iteration 25/26
# Epoch 140 --- loss:0.533, Epoch accuracy:35.82%, Validation loss:1.098, Validation accuracy:20.78%
# Epoch 141: iteration 25/26
# Epoch 141 --- loss:0.529, Epoch accuracy:36.37%, Validation loss:1.140, Validation accuracy:20.33%
# Epoch 142: iteration 25/26
# Epoch 142 --- loss:0.534, Epoch accuracy:35.94%, Validation loss:1.137, Validation accuracy:19.44%
# Epoch 143: iteration 25/26
# Epoch 143 --- loss:0.530, Epoch accuracy:36.55%, Validation loss:1.110, Validation accuracy:20.33%
# Epoch 144: iteration 25/26
# Epoch 144 --- loss:0.529, Epoch accuracy:36.46%, Validation loss:1.120, Validation accuracy:19.56%
# Epoch 145: iteration 25/26
# Epoch 145 --- loss:0.529, Epoch accuracy:36.20%, Validation loss:1.114, Validation accuracy:19.56%
# Epoch 146: iteration 25/26
# Epoch 146 --- loss:0.528, Epoch accuracy:37.40%, Validation loss:1.157, Validation accuracy:20.22%
# Epoch 147: iteration 25/26
# Epoch 147 --- loss:0.529, Epoch accuracy:36.11%, Validation loss:1.144, Validation accuracy:20.11%
# Epoch 148: iteration 25/26
# Epoch 148 --- loss:0.530, Epoch accuracy:35.67%, Validation loss:1.156, Validation accuracy:19.56%
# Epoch 149: iteration 25/26
# Epoch 149 --- loss:0.522, Epoch accuracy:37.05%, Validation loss:1.176, Validation accuracy:19.33%
# Epoch 150: iteration 25/26
# Epoch 150 --- loss:0.531, Epoch accuracy:36.84%, Validation loss:1.096, Validation accuracy:20.67%
# Epoch 151: iteration 25/26
# Epoch 151 --- loss:0.524, Epoch accuracy:35.85%, Validation loss:1.154, Validation accuracy:20.00%
# Epoch 152: iteration 25/26
# Epoch 152 --- loss:0.525, Epoch accuracy:37.22%, Validation loss:1.176, Validation accuracy:19.44%
# Epoch 153: iteration 25/26
# Epoch 153 --- loss:0.524, Epoch accuracy:37.22%, Validation loss:1.160, Validation accuracy:19.22%
# Epoch 154: iteration 25/26
# Epoch 154 --- loss:0.520, Epoch accuracy:37.66%, Validation loss:1.139, Validation accuracy:19.78%
# Epoch 155: iteration 25/26
# Epoch 155 --- loss:0.523, Epoch accuracy:36.35%, Validation loss:1.145, Validation accuracy:20.11%
# Epoch 156: iteration 25/26
# Epoch 156 --- loss:0.520, Epoch accuracy:37.31%, Validation loss:1.123, Validation accuracy:19.56%
# Epoch 157: iteration 25/26
# Epoch 157 --- loss:0.517, Epoch accuracy:38.07%, Validation loss:1.158, Validation accuracy:19.67%
# Epoch 158: iteration 25/26
# Epoch 158 --- loss:0.519, Epoch accuracy:37.78%, Validation loss:1.121, Validation accuracy:20.11%
# Epoch 159: iteration 25/26
# Epoch 159 --- loss:0.520, Epoch accuracy:36.43%, Validation loss:1.220, Validation accuracy:19.00%
# Epoch 160: iteration 25/26
# Epoch 160 --- loss:0.515, Epoch accuracy:37.46%, Validation loss:1.176, Validation accuracy:19.11%
# Epoch 161: iteration 25/26
# Epoch 161 --- loss:0.518, Epoch accuracy:37.89%, Validation loss:1.121, Validation accuracy:20.22%
# Epoch 162: iteration 25/26
# Epoch 162 --- loss:0.518, Epoch accuracy:37.46%, Validation loss:1.211, Validation accuracy:18.78%
# Epoch 163: iteration 25/26
# Epoch 163 --- loss:0.514, Epoch accuracy:37.78%, Validation loss:1.134, Validation accuracy:19.78%
# Epoch 164: iteration 25/26
# Epoch 164 --- loss:0.518, Epoch accuracy:37.84%, Validation loss:1.128, Validation accuracy:20.33%
# Epoch 165: iteration 25/26
# Epoch 165 --- loss:0.513, Epoch accuracy:37.49%, Validation loss:1.149, Validation accuracy:19.78%
# Epoch 166: iteration 25/26
# Epoch 166 --- loss:0.516, Epoch accuracy:37.31%, Validation loss:1.163, Validation accuracy:19.89%
# Epoch 167: iteration 25/26
# Epoch 167 --- loss:0.514, Epoch accuracy:37.46%, Validation loss:1.116, Validation accuracy:20.11%
# Epoch 168: iteration 25/26
# Epoch 168 --- loss:0.515, Epoch accuracy:37.57%, Validation loss:1.158, Validation accuracy:19.56%
# Epoch 169: iteration 25/26
# Epoch 169 --- loss:0.512, Epoch accuracy:37.69%, Validation loss:1.140, Validation accuracy:19.67%
# Epoch 170: iteration 25/26
# Epoch 170 --- loss:0.512, Epoch accuracy:38.51%, Validation loss:1.133, Validation accuracy:19.78%
# Epoch 171: iteration 25/26
# Epoch 171 --- loss:0.514, Epoch accuracy:38.22%, Validation loss:1.131, Validation accuracy:20.11%
# Epoch 172: iteration 25/26
# Epoch 172 --- loss:0.507, Epoch accuracy:38.74%, Validation loss:1.238, Validation accuracy:18.67%
# Epoch 173: iteration 25/26
# Epoch 173 --- loss:0.508, Epoch accuracy:38.04%, Validation loss:1.157, Validation accuracy:19.89%
# Epoch 174: iteration 25/26
# Epoch 174 --- loss:0.513, Epoch accuracy:37.54%, Validation loss:1.143, Validation accuracy:19.67%
# Epoch 175: iteration 25/26
# Epoch 175 --- loss:0.514, Epoch accuracy:36.73%, Validation loss:1.126, Validation accuracy:20.11%
# Epoch 176: iteration 25/26
# Epoch 176 --- loss:0.507, Epoch accuracy:38.27%, Validation loss:1.150, Validation accuracy:20.22%
# Epoch 177: iteration 25/26
# Epoch 177 --- loss:0.507, Epoch accuracy:38.48%, Validation loss:1.129, Validation accuracy:20.22%
# Epoch 178: iteration 17/26
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [32], line 20
#      17     y_test = np.load(f)
#      19 pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
# ---> 20 train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold)
#      22 plt.title('Loss Curve')
#      23 plt.ylabel('Loss', fontsize=16)
#
# Cell In [31], line 65, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold)
#      62 Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
#      64 # Pass input tensors thru 1 training step (fwd+backwards pass)
# ---> 65 loss, acc = train_step(X_tensor, Y_tensor)
#      67 # aggregate batch accuracy to measure progress of entire epoch
#      68 epoch_acc += acc * actual_batch_size / train_size
#
# Cell In [28], line 15, in make_train_step.<locals>.train_step(X, Y)
#      12 loss = criterion(output_logits, Y)
#      14 # compute gradients for the optimizer to use
# ---> 15 loss.backward()
#      17 # update network parameters based on gradient stored (by calling loss.backward())
#      18 optimizer.step()
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\tensor.py:245, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     236 if has_torch_function_unary(self):
#     237     return handle_torch_function(
#     238         Tensor.backward,
#     239         (self,),
#    (...)
#     243         create_graph=create_graph,
#     244         inputs=inputs)
# --> 245 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\autograd\__init__.py:145, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     142 if retain_graph is None:
#     143     retain_graph = create_graph
# --> 145 Variable._execution_engine.run_backward(
#     146     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
import csv
import cv2
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(cur_fold_path):
    X_train, y_train, X_test, y_test = [], [], [], []
    
    train_f = open(os.path.join(cur_fold_path, 'train.csv'), 'r')
    test_f = open(os.path.join(cur_fold_path, 'test.csv'), 'r')
    
    train_reader = csv.reader(train_f)
    for r in train_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_train.append(image)
        y_train.append(int(r[1]))
        
    test_reader = csv.reader(test_f)
    for r in test_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_test.append(image)
        y_test.append(int(r[1]))
    
    return np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

# %%
all_fold_dataset = []

for fold in tqdm(range(5), desc='load melspectrogram fold dataset'):
    cur_fold_path = os.path.join('melspectrogram_fold', str(fold))
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    all_fold_dataset.append([X_train, y_train, X_test, y_test])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'melspectrogram_fold'

for fold in range(5):
    cur = all_fold_dataset[fold]
    
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
