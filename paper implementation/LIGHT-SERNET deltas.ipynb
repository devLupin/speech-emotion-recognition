# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

emotions_dict = {
    'anger': 0,
    'anxiety_fear': 1,
    'boredom': 2,
    'disgust': 3,
    'happiness': 4,
    'neutral': 5,
    'sadness': 6
}


sub_name = 'LIGHT-SERNET'
data_name = 'EMODB'
fold_path = sub_name + ' dataset'

sub_name += '_deltas'
loss_name = 'CE loss'

minibatch = 16
num_epochs = 300
EARLY_CNT = 99999

learning_rate = 10e-4

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class Model(nn.Module):
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[11,1], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )
        self.conv2 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[1,9], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )
        self.conv3 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=[3,3], stride=[1,1], padding='same'),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=1, padding=[1,1])
            )

        self.LFLB = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=[3,3], stride=1, padding='same', bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,1]),
            
            nn.Conv2d(64, 96, kernel_size=[3,3], stride=[1,1], padding='same', bias=False),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(96, 128, kernel_size=[3,3], stride=[1,1], padding='same', bias=False),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(128, 160, kernel_size=[3,3], stride=[1,1], padding='same', bias=False),
            nn.BatchNorm2d(160),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1], stride=[1,1], padding=[1,0]),
            
            nn.Conv2d(160, 320, kernel_size=[1,1], stride=[1,1], padding='same', bias=False),
            nn.BatchNorm2d(320),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,2], stride=[1,1], padding=[1,0])
        )
        
        self.fc = nn.Linear(320, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        conv_embd1 = self.conv1(x)
        conv_embd2 = self.conv2(x)
        conv_embd3 = self.conv3(x)
        
        feature_extractor = torch.cat([conv_embd1, conv_embd2, conv_embd3], dim=-1)
        
        lflb_embd = self.LFLB(feature_extractor)
        out = F.adaptive_avg_pool2d(lflb_embd, (1,1))
        out = nn.Dropout(0.3)(out)
        out = torch.flatten(out, start_dim=1)
        
        output_logits = self.fc(out)
        output_softmax = self.softmax(output_logits)

        return output_logits, output_softmax
    
# model = Model(len(emotions_dict))
# print(summary(model, (32, 1, 184, 40)))

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'Fold-{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import numpy as np

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

for fold in tqdm(range(10)):
    cur_fold_path = os.path.join(fold_path,  f'delta-fold{fold}.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=10e-6, amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - LIGHT-SERNET_deltas
# A Jupyter Widget
# A Jupyter Widget
# Epoch 0: iteration 29/30
# Epoch 0 --- loss:1.630, Epoch accuracy:32.72%, Validation loss:1.335, Validation accuracy:48.98%
# Epoch 1: iteration 29/30
# Epoch 1 --- loss:1.418, Epoch accuracy:40.12%, Validation loss:1.376, Validation accuracy:44.90%
# Epoch 2: iteration 29/30
# Epoch 2 --- loss:1.248, Epoch accuracy:52.06%, Validation loss:1.064, Validation accuracy:59.18%
# Epoch 3: iteration 29/30
# Epoch 3 --- loss:1.191, Epoch accuracy:55.56%, Validation loss:1.798, Validation accuracy:34.69%
# Epoch 4: iteration 29/30
# Epoch 4 --- loss:1.087, Epoch accuracy:58.85%, Validation loss:0.973, Validation accuracy:61.22%
# Epoch 5: iteration 29/30
# Epoch 5 --- loss:1.020, Epoch accuracy:63.17%, Validation loss:2.936, Validation accuracy:32.65%
# Epoch 6: iteration 29/30
# Epoch 6 --- loss:0.998, Epoch accuracy:61.11%, Validation loss:1.271, Validation accuracy:51.02%
# Epoch 7: iteration 29/30
# Epoch 7 --- loss:0.967, Epoch accuracy:62.76%, Validation loss:1.073, Validation accuracy:55.10%
# Epoch 8: iteration 29/30
# Epoch 8 --- loss:0.895, Epoch accuracy:65.02%, Validation loss:3.238, Validation accuracy:32.65%
# Epoch 9: iteration 29/30
# Epoch 9 --- loss:0.850, Epoch accuracy:68.31%, Validation loss:3.277, Validation accuracy:12.24%
# Epoch 10: iteration 29/30
# Epoch 10 --- loss:0.800, Epoch accuracy:72.43%, Validation loss:1.239, Validation accuracy:48.98%
# Epoch 11: iteration 29/30
# Epoch 11 --- loss:0.778, Epoch accuracy:71.40%, Validation loss:1.212, Validation accuracy:46.94%
# Epoch 12: iteration 29/30
# Epoch 12 --- loss:0.763, Epoch accuracy:72.22%, Validation loss:1.398, Validation accuracy:38.78%
# Epoch 13: iteration 29/30
# Epoch 13 --- loss:0.813, Epoch accuracy:68.93%, Validation loss:1.002, Validation accuracy:59.18%
# Epoch 14: iteration 29/30
# Epoch 14 --- loss:0.728, Epoch accuracy:73.25%, Validation loss:1.338, Validation accuracy:55.10%
# Epoch 15: iteration 29/30
# Epoch 15 --- loss:0.705, Epoch accuracy:72.63%, Validation loss:6.184, Validation accuracy:10.20%
# Epoch 16: iteration 29/30
# Epoch 16 --- loss:0.719, Epoch accuracy:72.63%, Validation loss:6.498, Validation accuracy:28.57%
# Epoch 17: iteration 29/30
# Epoch 17 --- loss:0.655, Epoch accuracy:76.95%, Validation loss:1.813, Validation accuracy:32.65%
# Epoch 18: iteration 29/30
# Epoch 18 --- loss:0.651, Epoch accuracy:73.87%, Validation loss:1.407, Validation accuracy:42.86%
# Epoch 19: iteration 29/30
# Epoch 19 --- loss:0.689, Epoch accuracy:72.84%, Validation loss:2.382, Validation accuracy:26.53%
# Epoch 20: iteration 29/30
# Epoch 20 --- loss:0.653, Epoch accuracy:76.34%, Validation loss:1.292, Validation accuracy:63.27%
# Epoch 21: iteration 29/30
# Epoch 21 --- loss:0.583, Epoch accuracy:77.78%, Validation loss:1.835, Validation accuracy:32.65%
# Epoch 22: iteration 29/30
# Epoch 22 --- loss:0.511, Epoch accuracy:81.28%, Validation loss:1.336, Validation accuracy:48.98%
# Epoch 23: iteration 29/30
# Epoch 23 --- loss:0.533, Epoch accuracy:80.66%, Validation loss:0.852, Validation accuracy:67.35%
# Epoch 24: iteration 29/30
# Epoch 24 --- loss:0.556, Epoch accuracy:79.01%, Validation loss:3.392, Validation accuracy:26.53%
# Epoch 25: iteration 29/30
# Epoch 25 --- loss:0.546, Epoch accuracy:77.37%, Validation loss:4.138, Validation accuracy:34.69%
# Epoch 26: iteration 29/30
# Epoch 26 --- loss:0.545, Epoch accuracy:80.45%, Validation loss:3.427, Validation accuracy:51.02%
# Epoch 27: iteration 29/30
# Epoch 27 --- loss:0.545, Epoch accuracy:80.04%, Validation loss:8.548, Validation accuracy:32.65%
# Epoch 28: iteration 29/30
# Epoch 28 --- loss:0.509, Epoch accuracy:80.86%, Validation loss:3.221, Validation accuracy:20.41%
# Epoch 29: iteration 29/30
# Epoch 29 --- loss:0.412, Epoch accuracy:85.60%, Validation loss:1.359, Validation accuracy:69.39%
# Epoch 30: iteration 29/30
# Epoch 30 --- loss:0.472, Epoch accuracy:81.48%, Validation loss:0.787, Validation accuracy:73.47%
# Epoch 31: iteration 29/30
# Epoch 31 --- loss:0.502, Epoch accuracy:82.72%, Validation loss:1.245, Validation accuracy:51.02%
# Epoch 32: iteration 29/30
# Epoch 32 --- loss:0.425, Epoch accuracy:82.51%, Validation loss:1.893, Validation accuracy:59.18%
# Epoch 33: iteration 29/30
# Epoch 33 --- loss:0.434, Epoch accuracy:83.95%, Validation loss:1.786, Validation accuracy:46.94%
# Epoch 34: iteration 29/30
# Epoch 34 --- loss:0.379, Epoch accuracy:86.63%, Validation loss:1.244, Validation accuracy:51.02%
# Epoch 35: iteration 29/30
# Epoch 35 --- loss:0.345, Epoch accuracy:88.68%, Validation loss:1.547, Validation accuracy:46.94%
# Epoch 36: iteration 29/30
# Epoch 36 --- loss:0.368, Epoch accuracy:86.21%, Validation loss:0.915, Validation accuracy:67.35%
# Epoch 37: iteration 29/30
# Epoch 37 --- loss:0.410, Epoch accuracy:82.92%, Validation loss:18.742, Validation accuracy:10.20%
# Epoch 38: iteration 29/30
# Epoch 38 --- loss:0.371, Epoch accuracy:87.45%, Validation loss:4.845, Validation accuracy:14.29%
# Epoch 39: iteration 29/30
# Epoch 39 --- loss:0.320, Epoch accuracy:88.48%, Validation loss:1.308, Validation accuracy:53.06%
# Epoch 40: iteration 29/30
# Epoch 40 --- loss:0.321, Epoch accuracy:88.27%, Validation loss:1.250, Validation accuracy:63.27%
# Epoch 41: iteration 29/30
# Epoch 41 --- loss:0.402, Epoch accuracy:84.57%, Validation loss:2.271, Validation accuracy:48.98%
# Epoch 42: iteration 29/30
# Epoch 42 --- loss:0.396, Epoch accuracy:83.33%, Validation loss:2.477, Validation accuracy:53.06%
# Epoch 43: iteration 29/30
# Epoch 43 --- loss:0.329, Epoch accuracy:88.07%, Validation loss:1.284, Validation accuracy:51.02%
# Epoch 44: iteration 29/30
# Epoch 44 --- loss:0.264, Epoch accuracy:90.95%, Validation loss:2.288, Validation accuracy:51.02%
# Epoch 45: iteration 29/30
# Epoch 45 --- loss:0.307, Epoch accuracy:89.09%, Validation loss:2.683, Validation accuracy:26.53%
# Epoch 46: iteration 29/30
# Epoch 46 --- loss:0.316, Epoch accuracy:88.89%, Validation loss:1.462, Validation accuracy:46.94%
# Epoch 47: iteration 29/30
# Epoch 47 --- loss:0.271, Epoch accuracy:91.36%, Validation loss:1.939, Validation accuracy:42.86%
# Epoch 48: iteration 29/30
# Epoch 48 --- loss:0.301, Epoch accuracy:89.09%, Validation loss:1.107, Validation accuracy:55.10%
# Epoch 49: iteration 29/30
# Epoch 49 --- loss:0.319, Epoch accuracy:87.24%, Validation loss:1.015, Validation accuracy:59.18%
# Epoch 50: iteration 29/30
# Epoch 50 --- loss:0.280, Epoch accuracy:90.53%, Validation loss:6.498, Validation accuracy:24.49%
# Epoch 51: iteration 29/30
# Epoch 51 --- loss:0.235, Epoch accuracy:92.59%, Validation loss:1.033, Validation accuracy:51.02%
# Epoch 52: iteration 29/30
# Epoch 52 --- loss:0.240, Epoch accuracy:91.77%, Validation loss:1.241, Validation accuracy:57.14%
# Epoch 53: iteration 29/30
# Epoch 53 --- loss:0.188, Epoch accuracy:94.86%, Validation loss:4.184, Validation accuracy:34.69%
# Epoch 54: iteration 29/30
# Epoch 54 --- loss:0.247, Epoch accuracy:90.12%, Validation loss:1.305, Validation accuracy:59.18%
# Epoch 55: iteration 29/30
# Epoch 55 --- loss:0.299, Epoch accuracy:88.89%, Validation loss:0.711, Validation accuracy:65.31%
# Epoch 56: iteration 29/30
# Epoch 56 --- loss:0.236, Epoch accuracy:92.18%, Validation loss:4.932, Validation accuracy:26.53%
# Epoch 57: iteration 29/30
# Epoch 57 --- loss:0.204, Epoch accuracy:93.42%, Validation loss:2.468, Validation accuracy:42.86%
# Epoch 58: iteration 29/30
# Epoch 58 --- loss:0.193, Epoch accuracy:93.21%, Validation loss:3.770, Validation accuracy:55.10%
# Epoch 59: iteration 29/30
# Epoch 59 --- loss:0.253, Epoch accuracy:90.53%, Validation loss:3.256, Validation accuracy:48.98%
# Epoch 60: iteration 29/30
# Epoch 60 --- loss:0.267, Epoch accuracy:89.92%, Validation loss:2.265, Validation accuracy:40.82%
# Epoch 61: iteration 29/30
# Epoch 61 --- loss:0.174, Epoch accuracy:94.24%, Validation loss:1.148, Validation accuracy:57.14%
# Epoch 62: iteration 29/30
# Epoch 62 --- loss:0.159, Epoch accuracy:94.44%, Validation loss:3.572, Validation accuracy:40.82%
# Epoch 63: iteration 29/30
# Epoch 63 --- loss:0.266, Epoch accuracy:90.95%, Validation loss:4.979, Validation accuracy:20.41%
# Epoch 64: iteration 29/30
# Epoch 64 --- loss:0.220, Epoch accuracy:91.36%, Validation loss:1.866, Validation accuracy:42.86%
# Epoch 65: iteration 29/30
# Epoch 65 --- loss:0.172, Epoch accuracy:95.47%, Validation loss:1.346, Validation accuracy:57.14%
# Epoch 66: iteration 29/30
# Epoch 66 --- loss:0.178, Epoch accuracy:94.44%, Validation loss:2.947, Validation accuracy:40.82%
# Epoch 67: iteration 29/30
# Epoch 67 --- loss:0.195, Epoch accuracy:92.59%, Validation loss:3.085, Validation accuracy:55.10%
# Epoch 68: iteration 29/30
# Epoch 68 --- loss:0.196, Epoch accuracy:93.42%, Validation loss:1.009, Validation accuracy:67.35%
# Epoch 69: iteration 29/30
# Epoch 69 --- loss:0.181, Epoch accuracy:93.21%, Validation loss:4.136, Validation accuracy:42.86%
# Epoch 70: iteration 29/30
# Epoch 70 --- loss:0.144, Epoch accuracy:94.65%, Validation loss:5.465, Validation accuracy:26.53%
# Epoch 71: iteration 29/30
# Epoch 71 --- loss:0.169, Epoch accuracy:94.03%, Validation loss:11.125, Validation accuracy:30.61%
# Epoch 72: iteration 29/30
# Epoch 72 --- loss:0.152, Epoch accuracy:94.24%, Validation loss:3.383, Validation accuracy:42.86%
# Epoch 73: iteration 29/30
# Epoch 73 --- loss:0.185, Epoch accuracy:93.00%, Validation loss:4.811, Validation accuracy:46.94%
# Epoch 74: iteration 29/30
# Epoch 74 --- loss:0.142, Epoch accuracy:95.68%, Validation loss:5.114, Validation accuracy:26.53%
# Epoch 75: iteration 29/30
# Epoch 75 --- loss:0.108, Epoch accuracy:96.91%, Validation loss:2.104, Validation accuracy:61.22%
# Epoch 76: iteration 29/30
# Epoch 76 --- loss:0.092, Epoch accuracy:97.74%, Validation loss:1.649, Validation accuracy:48.98%
# Epoch 77: iteration 29/30
# Epoch 77 --- loss:0.094, Epoch accuracy:96.50%, Validation loss:1.586, Validation accuracy:73.47%
# Epoch 78: iteration 29/30
# Epoch 78 --- loss:0.145, Epoch accuracy:95.06%, Validation loss:18.373, Validation accuracy:26.53%
# Epoch 79: iteration 29/30
# Epoch 79 --- loss:0.147, Epoch accuracy:95.06%, Validation loss:2.221, Validation accuracy:55.10%
# Epoch 80: iteration 29/30
# Epoch 80 --- loss:0.100, Epoch accuracy:97.33%, Validation loss:2.407, Validation accuracy:42.86%
# Epoch 81: iteration 29/30
# Epoch 81 --- loss:0.135, Epoch accuracy:95.06%, Validation loss:4.690, Validation accuracy:46.94%
# Epoch 82: iteration 29/30
# Epoch 82 --- loss:0.129, Epoch accuracy:94.65%, Validation loss:2.151, Validation accuracy:51.02%
# Epoch 83: iteration 29/30
# Epoch 83 --- loss:0.131, Epoch accuracy:95.47%, Validation loss:4.270, Validation accuracy:44.90%
# Epoch 84: iteration 29/30
# Epoch 84 --- loss:0.163, Epoch accuracy:93.42%, Validation loss:2.931, Validation accuracy:46.94%
# Epoch 85: iteration 29/30
# Epoch 85 --- loss:0.226, Epoch accuracy:91.15%, Validation loss:2.886, Validation accuracy:38.78%
# Epoch 86: iteration 29/30
# Epoch 86 --- loss:0.176, Epoch accuracy:93.00%, Validation loss:1.372, Validation accuracy:69.39%
# Epoch 87: iteration 29/30
# Epoch 87 --- loss:0.120, Epoch accuracy:95.47%, Validation loss:1.747, Validation accuracy:44.90%
# Epoch 88: iteration 29/30
# Epoch 88 --- loss:0.088, Epoch accuracy:97.53%, Validation loss:2.182, Validation accuracy:40.82%
# Epoch 89: iteration 29/30
# Epoch 89 --- loss:0.120, Epoch accuracy:95.27%, Validation loss:0.773, Validation accuracy:73.47%
# Epoch 90: iteration 29/30
# Epoch 90 --- loss:0.098, Epoch accuracy:96.91%, Validation loss:0.995, Validation accuracy:77.55%
# Epoch 91: iteration 29/30
# Epoch 91 --- loss:0.073, Epoch accuracy:97.74%, Validation loss:1.351, Validation accuracy:61.22%
# Epoch 92: iteration 29/30
# Epoch 92 --- loss:0.119, Epoch accuracy:95.27%, Validation loss:1.828, Validation accuracy:53.06%
# Epoch 93: iteration 29/30
# Epoch 93 --- loss:0.089, Epoch accuracy:97.12%, Validation loss:2.172, Validation accuracy:53.06%
# Epoch 94: iteration 29/30
# Epoch 94 --- loss:0.107, Epoch accuracy:95.88%, Validation loss:1.844, Validation accuracy:61.22%
# Epoch 95: iteration 29/30
# Epoch 95 --- loss:0.071, Epoch accuracy:97.53%, Validation loss:2.531, Validation accuracy:42.86%
# Epoch 96: iteration 29/30
# Epoch 96 --- loss:0.088, Epoch accuracy:96.50%, Validation loss:1.594, Validation accuracy:67.35%
# Epoch 97: iteration 29/30
# Epoch 97 --- loss:0.089, Epoch accuracy:96.30%, Validation loss:3.583, Validation accuracy:30.61%
# Epoch 98: iteration 29/30
# Epoch 98 --- loss:0.084, Epoch accuracy:96.71%, Validation loss:2.311, Validation accuracy:51.02%
# Epoch 99: iteration 29/30
# Epoch 99 --- loss:0.079, Epoch accuracy:97.12%, Validation loss:2.959, Validation accuracy:42.86%
# Epoch 100: iteration 29/30
# Epoch 100 --- loss:0.097, Epoch accuracy:96.91%, Validation loss:1.310, Validation accuracy:65.31%
# Epoch 101: iteration 29/30
# Epoch 101 --- loss:0.062, Epoch accuracy:97.33%, Validation loss:1.628, Validation accuracy:57.14%
# Epoch 102: iteration 29/30
# Epoch 102 --- loss:0.062, Epoch accuracy:97.33%, Validation loss:0.937, Validation accuracy:67.35%
# Epoch 103: iteration 29/30
# Epoch 103 --- loss:0.065, Epoch accuracy:97.12%, Validation loss:1.129, Validation accuracy:69.39%
# Epoch 104: iteration 29/30
# Epoch 104 --- loss:0.054, Epoch accuracy:97.74%, Validation loss:4.567, Validation accuracy:30.61%
# Epoch 105: iteration 29/30
# Epoch 105 --- loss:0.059, Epoch accuracy:97.74%, Validation loss:1.144, Validation accuracy:69.39%
# Epoch 106: iteration 29/30
# Epoch 106 --- loss:0.063, Epoch accuracy:97.94%, Validation loss:0.974, Validation accuracy:73.47%
# Epoch 107: iteration 29/30
# Epoch 107 --- loss:0.071, Epoch accuracy:96.71%, Validation loss:1.675, Validation accuracy:65.31%
# Epoch 108: iteration 29/30
# Epoch 108 --- loss:0.039, Epoch accuracy:98.15%, Validation loss:2.101, Validation accuracy:57.14%
# Epoch 109: iteration 29/30
# Epoch 109 --- loss:0.049, Epoch accuracy:97.53%, Validation loss:1.317, Validation accuracy:59.18%
# Epoch 110: iteration 29/30
# Epoch 110 --- loss:0.091, Epoch accuracy:96.09%, Validation loss:5.095, Validation accuracy:30.61%
# Epoch 111: iteration 29/30
# Epoch 111 --- loss:0.075, Epoch accuracy:96.91%, Validation loss:2.344, Validation accuracy:38.78%
# Epoch 112: iteration 29/30
# Epoch 112 --- loss:0.055, Epoch accuracy:98.15%, Validation loss:0.721, Validation accuracy:77.55%
# Epoch 113: iteration 29/30
# Epoch 113 --- loss:0.072, Epoch accuracy:96.71%, Validation loss:1.571, Validation accuracy:63.27%
# Epoch 114: iteration 29/30
# Epoch 114 --- loss:0.048, Epoch accuracy:98.15%, Validation loss:2.653, Validation accuracy:34.69%
# Epoch 115: iteration 29/30
# Epoch 115 --- loss:0.068, Epoch accuracy:97.12%, Validation loss:3.268, Validation accuracy:36.73%
# Epoch 116: iteration 29/30
# Epoch 116 --- loss:0.071, Epoch accuracy:96.71%, Validation loss:1.616, Validation accuracy:44.90%
# Epoch 117: iteration 29/30
# Epoch 117 --- loss:0.034, Epoch accuracy:98.56%, Validation loss:0.754, Validation accuracy:75.51%
# Epoch 118: iteration 29/30
# Epoch 118 --- loss:0.028, Epoch accuracy:98.35%, Validation loss:1.024, Validation accuracy:71.43%
# Epoch 119: iteration 29/30
# Epoch 119 --- loss:0.032, Epoch accuracy:98.77%, Validation loss:1.390, Validation accuracy:65.31%
# Epoch 120: iteration 29/30
# Epoch 120 --- loss:0.028, Epoch accuracy:98.56%, Validation loss:0.992, Validation accuracy:63.27%
# Epoch 121: iteration 29/30
# Epoch 121 --- loss:0.060, Epoch accuracy:97.33%, Validation loss:4.054, Validation accuracy:48.98%
# Epoch 122: iteration 29/30
# Epoch 122 --- loss:0.046, Epoch accuracy:97.94%, Validation loss:1.516, Validation accuracy:61.22%
# Epoch 123: iteration 29/30
# Epoch 123 --- loss:0.047, Epoch accuracy:97.74%, Validation loss:1.020, Validation accuracy:65.31%
# Epoch 124: iteration 29/30
# Epoch 124 --- loss:0.056, Epoch accuracy:97.53%, Validation loss:9.707, Validation accuracy:16.33%
# Epoch 125: iteration 29/30
# Epoch 125 --- loss:0.069, Epoch accuracy:97.53%, Validation loss:2.799, Validation accuracy:40.82%
# Epoch 126: iteration 29/30
# Epoch 126 --- loss:0.068, Epoch accuracy:96.91%, Validation loss:2.869, Validation accuracy:44.90%
# Epoch 127: iteration 29/30
# Epoch 127 --- loss:0.203, Epoch accuracy:92.59%, Validation loss:10.355, Validation accuracy:24.49%
# Epoch 128: iteration 29/30
# Epoch 128 --- loss:0.171, Epoch accuracy:93.00%, Validation loss:1.366, Validation accuracy:67.35%
# Epoch 129: iteration 29/30
# Epoch 129 --- loss:0.082, Epoch accuracy:96.30%, Validation loss:6.309, Validation accuracy:26.53%
# Epoch 130: iteration 29/30
# Epoch 130 --- loss:0.080, Epoch accuracy:96.71%, Validation loss:2.368, Validation accuracy:44.90%
# Epoch 131: iteration 29/30
# Epoch 131 --- loss:0.050, Epoch accuracy:97.94%, Validation loss:1.548, Validation accuracy:59.18%
# Epoch 132: iteration 29/30
# Epoch 132 --- loss:0.031, Epoch accuracy:98.56%, Validation loss:1.356, Validation accuracy:65.31%
# Epoch 133: iteration 29/30
# Epoch 133 --- loss:0.042, Epoch accuracy:97.74%, Validation loss:1.700, Validation accuracy:57.14%
# Epoch 134: iteration 29/30
# Epoch 134 --- loss:0.032, Epoch accuracy:98.56%, Validation loss:0.660, Validation accuracy:79.59%
# Epoch 135: iteration 29/30
# Epoch 135 --- loss:0.037, Epoch accuracy:98.56%, Validation loss:0.686, Validation accuracy:87.76%
# Epoch 136: iteration 29/30
# Epoch 136 --- loss:0.040, Epoch accuracy:98.15%, Validation loss:2.126, Validation accuracy:57.14%
# Epoch 137: iteration 29/30
# Epoch 137 --- loss:0.043, Epoch accuracy:97.12%, Validation loss:0.989, Validation accuracy:63.27%
# Epoch 138: iteration 29/30
# Epoch 138 --- loss:0.066, Epoch accuracy:96.30%, Validation loss:1.090, Validation accuracy:71.43%
# Epoch 139: iteration 29/30
# Epoch 139 --- loss:0.075, Epoch accuracy:96.50%, Validation loss:4.015, Validation accuracy:57.14%
# Epoch 140: iteration 29/30
# Epoch 140 --- loss:0.063, Epoch accuracy:97.12%, Validation loss:1.496, Validation accuracy:46.94%
# Epoch 141: iteration 29/30
# Epoch 141 --- loss:0.082, Epoch accuracy:96.50%, Validation loss:6.969, Validation accuracy:24.49%
# Epoch 142: iteration 29/30
# Epoch 142 --- loss:0.056, Epoch accuracy:96.91%, Validation loss:3.509, Validation accuracy:51.02%
# Epoch 143: iteration 29/30
# Epoch 143 --- loss:0.128, Epoch accuracy:95.06%, Validation loss:23.796, Validation accuracy:22.45%
# Epoch 144: iteration 29/30
# Epoch 144 --- loss:0.069, Epoch accuracy:97.53%, Validation loss:2.589, Validation accuracy:42.86%
# Epoch 145: iteration 29/30
# Epoch 145 --- loss:0.046, Epoch accuracy:97.74%, Validation loss:3.237, Validation accuracy:40.82%
# Epoch 146: iteration 29/30
# Epoch 146 --- loss:0.077, Epoch accuracy:96.71%, Validation loss:1.300, Validation accuracy:65.31%
# Epoch 147: iteration 29/30
# Epoch 147 --- loss:0.061, Epoch accuracy:97.33%, Validation loss:4.025, Validation accuracy:30.61%
# Epoch 148: iteration 29/30
# Epoch 148 --- loss:0.056, Epoch accuracy:96.91%, Validation loss:1.299, Validation accuracy:63.27%
# Epoch 149: iteration 29/30
# Epoch 149 --- loss:0.068, Epoch accuracy:96.71%, Validation loss:2.123, Validation accuracy:42.86%
# Epoch 150: iteration 29/30
# Epoch 150 --- loss:0.043, Epoch accuracy:97.53%, Validation loss:3.809, Validation accuracy:38.78%
# Epoch 151: iteration 29/30
# Epoch 151 --- loss:0.029, Epoch accuracy:98.35%, Validation loss:1.165, Validation accuracy:69.39%
# Epoch 152: iteration 29/30
# Epoch 152 --- loss:0.029, Epoch accuracy:98.35%, Validation loss:2.610, Validation accuracy:53.06%
# Epoch 153: iteration 29/30
# Epoch 153 --- loss:0.026, Epoch accuracy:98.35%, Validation loss:0.918, Validation accuracy:67.35%
# Epoch 154: iteration 29/30
# Epoch 154 --- loss:0.027, Epoch accuracy:98.35%, Validation loss:1.191, Validation accuracy:71.43%
# Epoch 155: iteration 29/30
# Epoch 155 --- loss:0.027, Epoch accuracy:98.15%, Validation loss:2.100, Validation accuracy:57.14%
# Epoch 156: iteration 29/30
# Epoch 156 --- loss:0.028, Epoch accuracy:98.56%, Validation loss:0.650, Validation accuracy:71.43%
# Epoch 157: iteration 29/30
# Epoch 157 --- loss:0.028, Epoch accuracy:98.56%, Validation loss:1.510, Validation accuracy:67.35%
# Epoch 158: iteration 29/30
# Epoch 158 --- loss:0.037, Epoch accuracy:97.94%, Validation loss:0.767, Validation accuracy:79.59%
# Epoch 159: iteration 29/30
# Epoch 159 --- loss:0.041, Epoch accuracy:97.94%, Validation loss:1.595, Validation accuracy:46.94%
# Epoch 160: iteration 29/30
# Epoch 160 --- loss:0.047, Epoch accuracy:97.53%, Validation loss:0.542, Validation accuracy:71.43%
# Epoch 161: iteration 29/30
# Epoch 161 --- loss:0.028, Epoch accuracy:98.56%, Validation loss:1.039, Validation accuracy:69.39%
# Epoch 162: iteration 29/30
# Epoch 162 --- loss:0.017, Epoch accuracy:98.77%, Validation loss:0.578, Validation accuracy:77.55%
# Epoch 163: iteration 29/30
# Epoch 163 --- loss:0.029, Epoch accuracy:98.15%, Validation loss:0.489, Validation accuracy:79.59%
# Epoch 164: iteration 29/30
# Epoch 164 --- loss:0.022, Epoch accuracy:98.56%, Validation loss:0.908, Validation accuracy:71.43%
# Epoch 165: iteration 29/30
# Epoch 165 --- loss:0.068, Epoch accuracy:96.50%, Validation loss:0.801, Validation accuracy:79.59%
# Epoch 166: iteration 29/30
# Epoch 166 --- loss:0.068, Epoch accuracy:96.71%, Validation loss:2.019, Validation accuracy:48.98%
# Epoch 167: iteration 29/30
# Epoch 167 --- loss:0.070, Epoch accuracy:95.68%, Validation loss:5.114, Validation accuracy:38.78%
# Epoch 168: iteration 29/30
# Epoch 168 --- loss:0.050, Epoch accuracy:97.33%, Validation loss:2.911, Validation accuracy:44.90%
# Epoch 169: iteration 29/30
# Epoch 169 --- loss:0.033, Epoch accuracy:98.56%, Validation loss:0.759, Validation accuracy:75.51%
# Epoch 170: iteration 29/30
# Epoch 170 --- loss:0.019, Epoch accuracy:98.56%, Validation loss:2.032, Validation accuracy:63.27%
# Epoch 171: iteration 29/30
# Epoch 171 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:0.667, Validation accuracy:79.59%
# Epoch 172: iteration 29/30
# Epoch 172 --- loss:0.021, Epoch accuracy:98.35%, Validation loss:2.082, Validation accuracy:63.27%
# Epoch 173: iteration 29/30
# Epoch 173 --- loss:0.032, Epoch accuracy:98.35%, Validation loss:1.436, Validation accuracy:65.31%
# Epoch 174: iteration 29/30
# Epoch 174 --- loss:0.018, Epoch accuracy:98.56%, Validation loss:1.257, Validation accuracy:63.27%
# Epoch 175: iteration 29/30
# Epoch 175 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.052, Validation accuracy:69.39%
# Epoch 176: iteration 29/30
# Epoch 176 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.901, Validation accuracy:75.51%
# Epoch 177: iteration 29/30
# Epoch 177 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:1.578, Validation accuracy:59.18%
# Epoch 178: iteration 29/30
# Epoch 178 --- loss:0.018, Epoch accuracy:98.77%, Validation loss:2.094, Validation accuracy:51.02%
# Epoch 179: iteration 29/30
# Epoch 179 --- loss:0.022, Epoch accuracy:98.56%, Validation loss:1.150, Validation accuracy:67.35%
# Epoch 180: iteration 29/30
# Epoch 180 --- loss:0.014, Epoch accuracy:98.56%, Validation loss:1.245, Validation accuracy:67.35%
# Epoch 181: iteration 29/30
# Epoch 181 --- loss:0.021, Epoch accuracy:98.35%, Validation loss:1.237, Validation accuracy:71.43%
# Epoch 182: iteration 29/30
# Epoch 182 --- loss:0.025, Epoch accuracy:97.94%, Validation loss:0.929, Validation accuracy:77.55%
# Epoch 183: iteration 29/30
# Epoch 183 --- loss:0.029, Epoch accuracy:98.15%, Validation loss:1.119, Validation accuracy:71.43%
# Epoch 184: iteration 29/30
# Epoch 184 --- loss:0.019, Epoch accuracy:98.56%, Validation loss:2.033, Validation accuracy:59.18%
# Epoch 185: iteration 29/30
# Epoch 185 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.721, Validation accuracy:69.39%
# Epoch 186: iteration 29/30
# Epoch 186 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.668, Validation accuracy:81.63%
# Epoch 187: iteration 29/30
# Epoch 187 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.900, Validation accuracy:77.55%
# Epoch 188: iteration 29/30
# Epoch 188 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.689, Validation accuracy:79.59%
# Epoch 189: iteration 29/30
# Epoch 189 --- loss:0.019, Epoch accuracy:98.56%, Validation loss:2.120, Validation accuracy:55.10%
# Epoch 190: iteration 29/30
# Epoch 190 --- loss:0.013, Epoch accuracy:98.56%, Validation loss:0.934, Validation accuracy:73.47%
# Epoch 191: iteration 29/30
# Epoch 191 --- loss:0.024, Epoch accuracy:98.35%, Validation loss:1.415, Validation accuracy:57.14%
# Epoch 192: iteration 29/30
# Epoch 192 --- loss:0.043, Epoch accuracy:97.74%, Validation loss:3.053, Validation accuracy:36.73%
# Epoch 193: iteration 29/30
# Epoch 193 --- loss:0.042, Epoch accuracy:97.74%, Validation loss:1.325, Validation accuracy:75.51%
# Epoch 194: iteration 29/30
# Epoch 194 --- loss:0.041, Epoch accuracy:97.33%, Validation loss:1.449, Validation accuracy:53.06%
# Epoch 195: iteration 29/30
# Epoch 195 --- loss:0.038, Epoch accuracy:97.33%, Validation loss:4.557, Validation accuracy:28.57%
# Epoch 196: iteration 29/30
# Epoch 196 --- loss:0.024, Epoch accuracy:98.35%, Validation loss:0.810, Validation accuracy:71.43%
# Epoch 197: iteration 29/30
# Epoch 197 --- loss:0.016, Epoch accuracy:98.77%, Validation loss:0.813, Validation accuracy:75.51%
# Epoch 198: iteration 29/30
# Epoch 198 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:1.272, Validation accuracy:71.43%
# Epoch 199: iteration 29/30
# Epoch 199 --- loss:0.016, Epoch accuracy:98.56%, Validation loss:0.868, Validation accuracy:75.51%
# Epoch 200: iteration 29/30
# Epoch 200 --- loss:0.023, Epoch accuracy:98.35%, Validation loss:2.446, Validation accuracy:55.10%
# Epoch 201: iteration 29/30
# Epoch 201 --- loss:0.031, Epoch accuracy:98.15%, Validation loss:2.153, Validation accuracy:59.18%
# Epoch 202: iteration 29/30
# Epoch 202 --- loss:0.029, Epoch accuracy:97.74%, Validation loss:1.521, Validation accuracy:65.31%
# Epoch 203: iteration 29/30
# Epoch 203 --- loss:0.031, Epoch accuracy:97.12%, Validation loss:3.156, Validation accuracy:57.14%
# Epoch 204: iteration 29/30
# Epoch 204 --- loss:0.043, Epoch accuracy:97.53%, Validation loss:0.818, Validation accuracy:75.51%
# Epoch 205: iteration 29/30
# Epoch 205 --- loss:0.016, Epoch accuracy:98.77%, Validation loss:1.835, Validation accuracy:55.10%
# Epoch 206: iteration 29/30
# Epoch 206 --- loss:0.018, Epoch accuracy:98.56%, Validation loss:1.698, Validation accuracy:57.14%
# Epoch 207: iteration 29/30
# Epoch 207 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:0.637, Validation accuracy:81.63%
# Epoch 208: iteration 29/30
# Epoch 208 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:1.218, Validation accuracy:71.43%
# Epoch 209: iteration 29/30
# Epoch 209 --- loss:0.022, Epoch accuracy:98.15%, Validation loss:1.737, Validation accuracy:67.35%
# Epoch 210: iteration 29/30
# Epoch 210 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:1.675, Validation accuracy:63.27%
# Epoch 211: iteration 29/30
# Epoch 211 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:1.286, Validation accuracy:67.35%
# Epoch 212: iteration 29/30
# Epoch 212 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.670, Validation accuracy:81.63%
# Epoch 213: iteration 29/30
# Epoch 213 --- loss:0.014, Epoch accuracy:98.56%, Validation loss:1.062, Validation accuracy:67.35%
# Epoch 214: iteration 29/30
# Epoch 214 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.579, Validation accuracy:85.71%
# Epoch 215: iteration 29/30
# Epoch 215 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.804, Validation accuracy:71.43%
# Epoch 216: iteration 29/30
# Epoch 216 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.876, Validation accuracy:79.59%
# Epoch 217: iteration 29/30
# Epoch 217 --- loss:0.009, Epoch accuracy:98.77%, Validation loss:1.181, Validation accuracy:57.14%
# Epoch 218: iteration 29/30
# Epoch 218 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.589, Validation accuracy:85.71%
# Epoch 219: iteration 29/30
# Epoch 219 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:1.095, Validation accuracy:67.35%
# Epoch 220: iteration 29/30
# Epoch 220 --- loss:0.018, Epoch accuracy:98.56%, Validation loss:2.314, Validation accuracy:42.86%
# Epoch 221: iteration 29/30
# Epoch 221 --- loss:0.018, Epoch accuracy:98.35%, Validation loss:3.487, Validation accuracy:38.78%
# Epoch 222: iteration 29/30
# Epoch 222 --- loss:0.019, Epoch accuracy:98.35%, Validation loss:1.421, Validation accuracy:63.27%
# Epoch 223: iteration 29/30
# Epoch 223 --- loss:0.018, Epoch accuracy:98.56%, Validation loss:1.326, Validation accuracy:65.31%
# Epoch 224: iteration 29/30
# Epoch 224 --- loss:0.030, Epoch accuracy:97.74%, Validation loss:6.646, Validation accuracy:24.49%
# Epoch 225: iteration 29/30
# Epoch 225 --- loss:0.085, Epoch accuracy:95.88%, Validation loss:6.400, Validation accuracy:34.69%
# Epoch 226: iteration 29/30
# Epoch 226 --- loss:0.051, Epoch accuracy:97.33%, Validation loss:5.608, Validation accuracy:34.69%
# Epoch 227: iteration 29/30
# Epoch 227 --- loss:0.021, Epoch accuracy:98.56%, Validation loss:1.064, Validation accuracy:77.55%
# Epoch 228: iteration 29/30
# Epoch 228 --- loss:0.034, Epoch accuracy:97.33%, Validation loss:1.915, Validation accuracy:53.06%
# Epoch 229: iteration 29/30
# Epoch 229 --- loss:0.021, Epoch accuracy:98.56%, Validation loss:3.046, Validation accuracy:53.06%
# Epoch 230: iteration 29/30
# Epoch 230 --- loss:0.013, Epoch accuracy:98.56%, Validation loss:1.975, Validation accuracy:55.10%
# Epoch 231: iteration 29/30
# Epoch 231 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.347, Validation accuracy:63.27%
# Epoch 232: iteration 29/30
# Epoch 232 --- loss:0.017, Epoch accuracy:98.15%, Validation loss:1.103, Validation accuracy:65.31%
# Epoch 233: iteration 29/30
# Epoch 233 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.807, Validation accuracy:77.55%
# Epoch 234: iteration 29/30
# Epoch 234 --- loss:0.016, Epoch accuracy:98.56%, Validation loss:2.117, Validation accuracy:61.22%
# Epoch 235: iteration 29/30
# Epoch 235 --- loss:0.029, Epoch accuracy:97.94%, Validation loss:7.030, Validation accuracy:34.69%
# Epoch 236: iteration 29/30
# Epoch 236 --- loss:0.035, Epoch accuracy:97.74%, Validation loss:1.152, Validation accuracy:65.31%
# Epoch 237: iteration 29/30
# Epoch 237 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:1.000, Validation accuracy:57.14%
# Epoch 238: iteration 29/30
# Epoch 238 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:0.563, Validation accuracy:81.63%
# Epoch 239: iteration 29/30
# Epoch 239 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.692, Validation accuracy:77.55%
# Epoch 240: iteration 29/30
# Epoch 240 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.857, Validation accuracy:67.35%
# Epoch 241: iteration 29/30
# Epoch 241 --- loss:0.010, Epoch accuracy:98.56%, Validation loss:0.488, Validation accuracy:85.71%
# Epoch 242: iteration 29/30
# Epoch 242 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:1.025, Validation accuracy:67.35%
# Epoch 243: iteration 29/30
# Epoch 243 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.759, Validation accuracy:75.51%
# Epoch 244: iteration 29/30
# Epoch 244 --- loss:0.007, Epoch accuracy:98.56%, Validation loss:0.725, Validation accuracy:75.51%
# Epoch 245: iteration 29/30
# Epoch 245 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:0.907, Validation accuracy:75.51%
# Epoch 246: iteration 29/30
# Epoch 246 --- loss:0.006, Epoch accuracy:98.56%, Validation loss:1.315, Validation accuracy:65.31%
# Epoch 247: iteration 29/30
# Epoch 247 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.714, Validation accuracy:77.55%
# Epoch 248: iteration 29/30
# Epoch 248 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.896, Validation accuracy:67.35%
# Epoch 249: iteration 29/30
# Epoch 249 --- loss:0.018, Epoch accuracy:98.35%, Validation loss:2.465, Validation accuracy:42.86%
# Epoch 250: iteration 29/30
# Epoch 250 --- loss:0.010, Epoch accuracy:98.77%, Validation loss:1.317, Validation accuracy:67.35%
# Epoch 251: iteration 29/30
# Epoch 251 --- loss:0.010, Epoch accuracy:98.56%, Validation loss:3.840, Validation accuracy:42.86%
# Epoch 252: iteration 29/30
# Epoch 252 --- loss:0.018, Epoch accuracy:98.15%, Validation loss:2.604, Validation accuracy:57.14%
# Epoch 253: iteration 29/30
# Epoch 253 --- loss:0.034, Epoch accuracy:97.53%, Validation loss:1.835, Validation accuracy:61.22%
# Epoch 254: iteration 29/30
# Epoch 254 --- loss:0.024, Epoch accuracy:98.15%, Validation loss:2.898, Validation accuracy:42.86%
# Epoch 255: iteration 29/30
# Epoch 255 --- loss:0.032, Epoch accuracy:97.74%, Validation loss:6.980, Validation accuracy:36.73%
# Epoch 256: iteration 29/30
# Epoch 256 --- loss:0.103, Epoch accuracy:95.06%, Validation loss:2.091, Validation accuracy:59.18%
# Epoch 257: iteration 29/30
# Epoch 257 --- loss:0.030, Epoch accuracy:98.35%, Validation loss:2.770, Validation accuracy:51.02%
# Epoch 258: iteration 29/30
# Epoch 258 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.526, Validation accuracy:42.86%
# Epoch 259: iteration 29/30
# Epoch 259 --- loss:0.034, Epoch accuracy:97.53%, Validation loss:0.646, Validation accuracy:79.59%
# Epoch 260: iteration 29/30
# Epoch 260 --- loss:0.014, Epoch accuracy:98.77%, Validation loss:1.147, Validation accuracy:61.22%
# Epoch 261: iteration 29/30
# Epoch 261 --- loss:0.053, Epoch accuracy:96.91%, Validation loss:4.778, Validation accuracy:42.86%
# Epoch 262: iteration 29/30
# Epoch 262 --- loss:0.030, Epoch accuracy:97.74%, Validation loss:2.151, Validation accuracy:55.10%
# Epoch 263: iteration 29/30
# Epoch 263 --- loss:0.027, Epoch accuracy:98.15%, Validation loss:0.824, Validation accuracy:77.55%
# Epoch 264: iteration 29/30
# Epoch 264 --- loss:0.014, Epoch accuracy:98.56%, Validation loss:1.135, Validation accuracy:73.47%
# Epoch 265: iteration 29/30
# Epoch 265 --- loss:0.013, Epoch accuracy:98.56%, Validation loss:1.448, Validation accuracy:61.22%
# Epoch 266: iteration 29/30
# Epoch 266 --- loss:0.006, Epoch accuracy:98.77%, Validation loss:0.891, Validation accuracy:71.43%
# Epoch 267: iteration 29/30
# Epoch 267 --- loss:0.020, Epoch accuracy:98.15%, Validation loss:0.598, Validation accuracy:85.71%
# Epoch 268: iteration 29/30
# Epoch 268 --- loss:0.025, Epoch accuracy:98.35%, Validation loss:2.183, Validation accuracy:44.90%
# Epoch 269: iteration 29/30
# Epoch 269 --- loss:0.040, Epoch accuracy:97.53%, Validation loss:3.576, Validation accuracy:30.61%
# Epoch 270: iteration 29/30
# Epoch 270 --- loss:0.026, Epoch accuracy:97.74%, Validation loss:3.095, Validation accuracy:42.86%
# Epoch 271: iteration 29/30
# Epoch 271 --- loss:0.029, Epoch accuracy:97.94%, Validation loss:1.166, Validation accuracy:71.43%
# Epoch 272: iteration 29/30
# Epoch 272 --- loss:0.020, Epoch accuracy:98.35%, Validation loss:1.203, Validation accuracy:61.22%
# Epoch 273: iteration 29/30
# Epoch 273 --- loss:0.016, Epoch accuracy:98.56%, Validation loss:0.968, Validation accuracy:75.51%
# Epoch 274: iteration 29/30
# Epoch 274 --- loss:0.012, Epoch accuracy:98.35%, Validation loss:1.113, Validation accuracy:71.43%
# Epoch 275: iteration 29/30
# Epoch 275 --- loss:0.011, Epoch accuracy:98.35%, Validation loss:1.108, Validation accuracy:69.39%
# Epoch 276: iteration 29/30
# Epoch 276 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.783, Validation accuracy:73.47%
# Epoch 277: iteration 29/30
# Epoch 277 --- loss:0.018, Epoch accuracy:98.15%, Validation loss:0.377, Validation accuracy:85.71%
# Epoch 278: iteration 29/30
# Epoch 278 --- loss:0.013, Epoch accuracy:98.77%, Validation loss:1.209, Validation accuracy:71.43%
# Epoch 279: iteration 29/30
# Epoch 279 --- loss:0.011, Epoch accuracy:98.77%, Validation loss:0.903, Validation accuracy:77.55%
# Epoch 280: iteration 29/30
# Epoch 280 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.717, Validation accuracy:75.51%
# Epoch 281: iteration 29/30
# Epoch 281 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:1.129, Validation accuracy:77.55%
# Epoch 282: iteration 29/30
# Epoch 282 --- loss:0.012, Epoch accuracy:98.77%, Validation loss:0.781, Validation accuracy:71.43%
# Epoch 283: iteration 29/30
# Epoch 283 --- loss:0.023, Epoch accuracy:97.94%, Validation loss:1.513, Validation accuracy:57.14%
# Epoch 284: iteration 29/30
# Epoch 284 --- loss:0.007, Epoch accuracy:98.77%, Validation loss:0.978, Validation accuracy:73.47%
# Epoch 285: iteration 29/30
# Epoch 285 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.815, Validation accuracy:77.55%
# Epoch 286: iteration 29/30
# Epoch 286 --- loss:0.009, Epoch accuracy:98.56%, Validation loss:0.816, Validation accuracy:79.59%
# Epoch 287: iteration 29/30
# Epoch 287 --- loss:0.008, Epoch accuracy:98.56%, Validation loss:0.885, Validation accuracy:75.51%
# Epoch 288: iteration 29/30
# Epoch 288 --- loss:0.008, Epoch accuracy:98.77%, Validation loss:0.896, Validation accuracy:75.51%
# Epoch 289: iteration 29/30
# Epoch 289 --- loss:0.005, Epoch accuracy:98.77%, Validation loss:0.774, Validation accuracy:75.51%
# Epoch 290: iteration 29/30
# Epoch 290 --- loss:0.012, Epoch accuracy:98.56%, Validation loss:0.968, Validation accuracy:81.63%
# Epoch 291: iteration 29/30
# Epoch 291 --- loss:0.008, Epoch accuracy:98.56%, Validation loss:0.945, Validation accuracy:77.55%
# Epoch 292: iteration 29/30
# Epoch 292 --- loss:0.004, Epoch accuracy:98.77%, Validation loss:1.012, Validation accuracy:69.39%
# Epoch 293: iteration 29/30
# Epoch 293 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:1.069, Validation accuracy:71.43%
# Epoch 294: iteration 29/30
# Epoch 294 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.721, Validation accuracy:79.59%
# Epoch 295: iteration 29/30
# Epoch 295 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.912, Validation accuracy:73.47%
# Epoch 296: iteration 29/30
# Epoch 296 --- loss:0.002, Epoch accuracy:98.77%, Validation loss:0.785, Validation accuracy:75.51%
# Epoch 297: iteration 29/30
# Epoch 297 --- loss:0.002, Epoch accuracy:98.77%, Validation loss:0.761, Validation accuracy:79.59%
# Epoch 298: iteration 29/30
# Epoch 298 --- loss:0.002, Epoch accuracy:98.77%, Validation loss:0.771, Validation accuracy:77.55%
# Epoch 299: iteration 29/30
# Epoch 299 --- loss:0.003, Epoch accuracy:98.77%, Validation loss:0.881, Validation accuracy:77.55%
#
#
# [*] done !
# [*] Best training loss - 0.0016621047862778594
# [*] Best validation loss - 0.3771681487560272
# A Jupyter Widget
# Epoch 0: iteration 28/29
# Epoch 0 --- loss:1.605, Epoch accuracy:33.75%, Validation loss:1.848, Validation accuracy:29.31%
# Epoch 1: iteration 28/29
# Epoch 1 --- loss:1.319, Epoch accuracy:45.28%, Validation loss:1.697, Validation accuracy:34.48%
# Epoch 2: iteration 28/29
# Epoch 2 --- loss:1.191, Epoch accuracy:49.27%, Validation loss:2.222, Validation accuracy:27.59%
# Epoch 3: iteration 28/29
# Epoch 3 --- loss:1.165, Epoch accuracy:54.93%, Validation loss:1.311, Validation accuracy:41.38%
# Epoch 4: iteration 28/29
# Epoch 4 --- loss:1.075, Epoch accuracy:57.02%, Validation loss:1.252, Validation accuracy:48.28%
# Epoch 5: iteration 28/29
# Epoch 5 --- loss:1.027, Epoch accuracy:60.59%, Validation loss:1.167, Validation accuracy:50.00%
# Epoch 6: iteration 28/29
# Epoch 6 --- loss:0.976, Epoch accuracy:62.89%, Validation loss:1.239, Validation accuracy:43.10%
# Epoch 7: iteration 28/29
# Epoch 7 --- loss:0.925, Epoch accuracy:63.94%, Validation loss:1.463, Validation accuracy:46.55%
# Epoch 8: iteration 28/29
# Epoch 8 --- loss:0.876, Epoch accuracy:68.13%, Validation loss:2.704, Validation accuracy:20.69%
# Epoch 9: iteration 28/29
# Epoch 9 --- loss:0.900, Epoch accuracy:64.99%, Validation loss:2.079, Validation accuracy:32.76%
# Epoch 10: iteration 28/29
# Epoch 10 --- loss:0.835, Epoch accuracy:66.67%, Validation loss:1.586, Validation accuracy:58.62%
# Epoch 11: iteration 28/29
# Epoch 11 --- loss:0.831, Epoch accuracy:66.25%, Validation loss:1.678, Validation accuracy:37.93%
# Epoch 12: iteration 28/29
# Epoch 12 --- loss:0.769, Epoch accuracy:67.09%, Validation loss:1.241, Validation accuracy:50.00%
# Epoch 13: iteration 28/29
# Epoch 13 --- loss:0.754, Epoch accuracy:69.39%, Validation loss:4.218, Validation accuracy:27.59%
# Epoch 14: iteration 28/29
# Epoch 14 --- loss:0.686, Epoch accuracy:73.38%, Validation loss:2.802, Validation accuracy:39.66%
# Epoch 15: iteration 28/29
# Epoch 15 --- loss:0.699, Epoch accuracy:72.33%, Validation loss:0.632, Validation accuracy:81.03%
# Epoch 16: iteration 28/29
# Epoch 16 --- loss:0.701, Epoch accuracy:74.21%, Validation loss:0.848, Validation accuracy:70.69%
# Epoch 17: iteration 28/29
# Epoch 17 --- loss:0.731, Epoch accuracy:70.65%, Validation loss:0.787, Validation accuracy:70.69%
# Epoch 18: iteration 28/29
# Epoch 18 --- loss:0.653, Epoch accuracy:72.33%, Validation loss:1.875, Validation accuracy:53.45%
# Epoch 19: iteration 28/29
# Epoch 19 --- loss:0.633, Epoch accuracy:74.42%, Validation loss:4.374, Validation accuracy:25.86%
# Epoch 20: iteration 28/29
# Epoch 20 --- loss:0.657, Epoch accuracy:72.54%, Validation loss:3.492, Validation accuracy:25.86%
# Epoch 21: iteration 28/29
# Epoch 21 --- loss:0.549, Epoch accuracy:77.57%, Validation loss:2.038, Validation accuracy:41.38%
# Epoch 22: iteration 28/29
# Epoch 22 --- loss:0.683, Epoch accuracy:74.00%, Validation loss:4.213, Validation accuracy:32.76%
# Epoch 23: iteration 28/29
# Epoch 23 --- loss:0.564, Epoch accuracy:76.52%, Validation loss:1.407, Validation accuracy:39.66%
# Epoch 24: iteration 28/29
# Epoch 24 --- loss:0.542, Epoch accuracy:77.78%, Validation loss:1.760, Validation accuracy:50.00%
# Epoch 25: iteration 28/29
# Epoch 25 --- loss:0.525, Epoch accuracy:78.83%, Validation loss:3.649, Validation accuracy:32.76%
# Epoch 26: iteration 28/29
# Epoch 26 --- loss:0.515, Epoch accuracy:78.41%, Validation loss:0.965, Validation accuracy:63.79%
# Epoch 27: iteration 28/29
# Epoch 27 --- loss:0.474, Epoch accuracy:81.13%, Validation loss:0.936, Validation accuracy:65.52%
# Epoch 28: iteration 28/29
# Epoch 28 --- loss:0.463, Epoch accuracy:82.39%, Validation loss:1.099, Validation accuracy:62.07%
# Epoch 29: iteration 28/29
# Epoch 29 --- loss:0.478, Epoch accuracy:81.13%, Validation loss:1.439, Validation accuracy:53.45%
# Epoch 30: iteration 28/29
# Epoch 30 --- loss:0.468, Epoch accuracy:79.66%, Validation loss:0.627, Validation accuracy:81.03%
# Epoch 31: iteration 28/29
# Epoch 31 --- loss:0.474, Epoch accuracy:81.34%, Validation loss:2.438, Validation accuracy:36.21%
# Epoch 32: iteration 28/29
# Epoch 32 --- loss:0.480, Epoch accuracy:80.92%, Validation loss:1.601, Validation accuracy:48.28%
# Epoch 33: iteration 28/29
# Epoch 33 --- loss:0.495, Epoch accuracy:79.66%, Validation loss:2.233, Validation accuracy:41.38%
# Epoch 34: iteration 28/29
# Epoch 34 --- loss:0.554, Epoch accuracy:77.15%, Validation loss:0.627, Validation accuracy:67.24%
# Epoch 35: iteration 28/29
# Epoch 35 --- loss:0.481, Epoch accuracy:82.39%, Validation loss:0.917, Validation accuracy:56.90%
# Epoch 36: iteration 28/29
# Epoch 36 --- loss:0.395, Epoch accuracy:83.86%, Validation loss:1.625, Validation accuracy:37.93%
# Epoch 37: iteration 28/29
# Epoch 37 --- loss:0.387, Epoch accuracy:83.86%, Validation loss:1.236, Validation accuracy:58.62%
# Epoch 38: iteration 28/29
# Epoch 38 --- loss:0.387, Epoch accuracy:84.91%, Validation loss:8.322, Validation accuracy:24.14%
# Epoch 39: iteration 28/29
# Epoch 39 --- loss:0.349, Epoch accuracy:87.21%, Validation loss:0.898, Validation accuracy:65.52%
# Epoch 40: iteration 28/29
# Epoch 40 --- loss:0.371, Epoch accuracy:83.44%, Validation loss:2.338, Validation accuracy:43.10%
# Epoch 41: iteration 28/29
# Epoch 41 --- loss:0.335, Epoch accuracy:88.05%, Validation loss:3.342, Validation accuracy:34.48%
# Epoch 42: iteration 28/29
# Epoch 42 --- loss:0.322, Epoch accuracy:86.58%, Validation loss:3.067, Validation accuracy:31.03%
# Epoch 43: iteration 28/29
# Epoch 43 --- loss:0.354, Epoch accuracy:83.86%, Validation loss:3.685, Validation accuracy:32.76%
# Epoch 44: iteration 28/29
# Epoch 44 --- loss:0.343, Epoch accuracy:88.26%, Validation loss:9.203, Validation accuracy:29.31%
# Epoch 45: iteration 28/29
# Epoch 45 --- loss:0.361, Epoch accuracy:86.37%, Validation loss:3.863, Validation accuracy:27.59%
# Epoch 46: iteration 28/29
# Epoch 46 --- loss:0.293, Epoch accuracy:90.15%, Validation loss:1.528, Validation accuracy:48.28%
# Epoch 47: iteration 28/29
# Epoch 47 --- loss:0.305, Epoch accuracy:86.79%, Validation loss:4.442, Validation accuracy:29.31%
# Epoch 48: iteration 28/29
# Epoch 48 --- loss:0.277, Epoch accuracy:89.10%, Validation loss:3.624, Validation accuracy:36.21%
# Epoch 49: iteration 28/29
# Epoch 49 --- loss:0.350, Epoch accuracy:86.37%, Validation loss:1.030, Validation accuracy:62.07%
# Epoch 50: iteration 28/29
# Epoch 50 --- loss:0.277, Epoch accuracy:89.10%, Validation loss:2.994, Validation accuracy:29.31%
# Epoch 51: iteration 28/29
# Epoch 51 --- loss:0.358, Epoch accuracy:85.53%, Validation loss:4.515, Validation accuracy:20.69%
# Epoch 52: iteration 28/29
# Epoch 52 --- loss:0.309, Epoch accuracy:87.21%, Validation loss:3.359, Validation accuracy:43.10%
# Epoch 53: iteration 28/29
# Epoch 53 --- loss:0.268, Epoch accuracy:89.94%, Validation loss:0.760, Validation accuracy:70.69%
# Epoch 54: iteration 28/29
# Epoch 54 --- loss:0.266, Epoch accuracy:89.52%, Validation loss:1.370, Validation accuracy:60.34%
# Epoch 55: iteration 28/29
# Epoch 55 --- loss:0.223, Epoch accuracy:91.61%, Validation loss:3.666, Validation accuracy:22.41%
# Epoch 56: iteration 28/29
# Epoch 56 --- loss:0.213, Epoch accuracy:90.57%, Validation loss:4.048, Validation accuracy:34.48%
# Epoch 57: iteration 28/29
# Epoch 57 --- loss:0.226, Epoch accuracy:90.78%, Validation loss:2.213, Validation accuracy:60.34%
# Epoch 58: iteration 28/29
# Epoch 58 --- loss:0.235, Epoch accuracy:90.78%, Validation loss:1.456, Validation accuracy:51.72%
# Epoch 59: iteration 28/29
# Epoch 59 --- loss:0.234, Epoch accuracy:90.57%, Validation loss:4.468, Validation accuracy:27.59%
# Epoch 60: iteration 28/29
# Epoch 60 --- loss:0.212, Epoch accuracy:92.66%, Validation loss:3.730, Validation accuracy:53.45%
# Epoch 61: iteration 28/29
# Epoch 61 --- loss:0.261, Epoch accuracy:89.52%, Validation loss:2.581, Validation accuracy:48.28%
# Epoch 62: iteration 28/29
# Epoch 62 --- loss:0.215, Epoch accuracy:91.40%, Validation loss:1.087, Validation accuracy:67.24%
# Epoch 63: iteration 28/29
# Epoch 63 --- loss:0.186, Epoch accuracy:92.66%, Validation loss:1.549, Validation accuracy:56.90%
# Epoch 64: iteration 28/29
# Epoch 64 --- loss:0.146, Epoch accuracy:93.29%, Validation loss:1.097, Validation accuracy:63.79%
# Epoch 65: iteration 28/29
# Epoch 65 --- loss:0.160, Epoch accuracy:92.66%, Validation loss:3.784, Validation accuracy:51.72%
# Epoch 66: iteration 28/29
# Epoch 66 --- loss:0.155, Epoch accuracy:93.71%, Validation loss:0.989, Validation accuracy:68.97%
# Epoch 67: iteration 28/29
# Epoch 67 --- loss:0.199, Epoch accuracy:92.03%, Validation loss:5.578, Validation accuracy:29.31%
# Epoch 68: iteration 28/29
# Epoch 68 --- loss:0.214, Epoch accuracy:90.99%, Validation loss:1.933, Validation accuracy:50.00%
# Epoch 69: iteration 28/29
# Epoch 69 --- loss:0.198, Epoch accuracy:92.45%, Validation loss:5.983, Validation accuracy:34.48%
# Epoch 70: iteration 28/29
# Epoch 70 --- loss:0.174, Epoch accuracy:92.24%, Validation loss:1.722, Validation accuracy:46.55%
# Epoch 71: iteration 28/29
# Epoch 71 --- loss:0.169, Epoch accuracy:92.66%, Validation loss:10.939, Validation accuracy:31.03%
# Epoch 72: iteration 28/29
# Epoch 72 --- loss:0.181, Epoch accuracy:92.24%, Validation loss:2.210, Validation accuracy:50.00%
# Epoch 73: iteration 28/29
# Epoch 73 --- loss:0.148, Epoch accuracy:93.50%, Validation loss:2.143, Validation accuracy:51.72%
# Epoch 74: iteration 28/29
# Epoch 74 --- loss:0.111, Epoch accuracy:94.97%, Validation loss:5.023, Validation accuracy:32.76%
# Epoch 75: iteration 28/29
# Epoch 75 --- loss:0.135, Epoch accuracy:93.29%, Validation loss:2.516, Validation accuracy:46.55%
# Epoch 76: iteration 28/29
# Epoch 76 --- loss:0.177, Epoch accuracy:92.66%, Validation loss:5.774, Validation accuracy:37.93%
# Epoch 77: iteration 28/29
# Epoch 77 --- loss:0.159, Epoch accuracy:93.92%, Validation loss:4.014, Validation accuracy:43.10%
# Epoch 78: iteration 28/29
# Epoch 78 --- loss:0.144, Epoch accuracy:93.71%, Validation loss:2.355, Validation accuracy:34.48%
# Epoch 79: iteration 28/29
# Epoch 79 --- loss:0.118, Epoch accuracy:95.18%, Validation loss:1.007, Validation accuracy:60.34%
# Epoch 80: iteration 28/29
# Epoch 80 --- loss:0.088, Epoch accuracy:96.02%, Validation loss:1.456, Validation accuracy:53.45%
# Epoch 81: iteration 28/29
# Epoch 81 --- loss:0.112, Epoch accuracy:94.55%, Validation loss:4.355, Validation accuracy:34.48%
# Epoch 82: iteration 28/29
# ...
# Epoch 175: iteration 28/29
# Epoch 175 --- loss:0.031, Epoch accuracy:99.78%, Validation loss:1.148, Validation accuracy:67.61%
# Epoch 176: iteration 28/29
# Epoch 176 --- loss:0.022, Epoch accuracy:99.78%, Validation loss:2.291, Validation accuracy:42.25%
# Epoch 177: iteration 28/29
# Epoch 177 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:1.163, Validation accuracy:64.79%
# Epoch 178: iteration 28/29
# Epoch 178 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:1.757, Validation accuracy:54.93%
# Epoch 179: iteration 28/29
# Epoch 179 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:1.362, Validation accuracy:64.79%
# Epoch 180: iteration 28/29
# Epoch 180 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:1.764, Validation accuracy:52.11%
# Epoch 181: iteration 28/29
# Epoch 181 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.656, Validation accuracy:59.15%
# Epoch 182: iteration 28/29
# Epoch 182 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.267, Validation accuracy:70.42%
# Epoch 183: iteration 28/29
# Epoch 183 --- loss:0.013, Epoch accuracy:99.78%, Validation loss:1.409, Validation accuracy:57.75%
# Epoch 184: iteration 28/29
# Epoch 184 --- loss:0.022, Epoch accuracy:99.78%, Validation loss:1.484, Validation accuracy:63.38%
# Epoch 185: iteration 28/29
# Epoch 185 --- loss:0.015, Epoch accuracy:100.00%, Validation loss:1.601, Validation accuracy:50.70%
# Epoch 186: iteration 28/29
# Epoch 186 --- loss:0.017, Epoch accuracy:99.78%, Validation loss:3.455, Validation accuracy:46.48%
# Epoch 187: iteration 28/29
# Epoch 187 --- loss:0.019, Epoch accuracy:100.00%, Validation loss:2.941, Validation accuracy:45.07%
# Epoch 188: iteration 28/29
# Epoch 188 --- loss:0.037, Epoch accuracy:99.14%, Validation loss:3.896, Validation accuracy:38.03%
# Epoch 189: iteration 28/29
# Epoch 189 --- loss:0.019, Epoch accuracy:99.78%, Validation loss:1.643, Validation accuracy:60.56%
# Epoch 190: iteration 28/29
# Epoch 190 --- loss:0.022, Epoch accuracy:99.35%, Validation loss:4.187, Validation accuracy:45.07%
# Epoch 191: iteration 28/29
# Epoch 191 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:2.670, Validation accuracy:50.70%
# Epoch 192: iteration 28/29
# Epoch 192 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:1.422, Validation accuracy:59.15%
# Epoch 193: iteration 28/29
# Epoch 193 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:1.191, Validation accuracy:67.61%
# Epoch 194: iteration 28/29
# Epoch 194 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.581, Validation accuracy:57.75%
# Epoch 195: iteration 28/29
# Epoch 195 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.437, Validation accuracy:66.20%
# Epoch 196: iteration 28/29
# Epoch 196 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.624, Validation accuracy:57.75%
# Epoch 197: iteration 28/29
# Epoch 197 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:0.936, Validation accuracy:69.01%
# Epoch 198: iteration 28/29
# Epoch 198 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:3.401, Validation accuracy:38.03%
# Epoch 199: iteration 28/29
# Epoch 199 --- loss:0.020, Epoch accuracy:99.35%, Validation loss:3.167, Validation accuracy:54.93%
# Epoch 200: iteration 28/29
# Epoch 200 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:0.994, Validation accuracy:71.83%
# Epoch 201: iteration 28/29
# Epoch 201 --- loss:0.015, Epoch accuracy:100.00%, Validation loss:1.337, Validation accuracy:61.97%
# Epoch 202: iteration 28/29
# Epoch 202 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:2.145, Validation accuracy:50.70%
# Epoch 203: iteration 28/29
# Epoch 203 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:1.813, Validation accuracy:63.38%
# Epoch 204: iteration 28/29
# Epoch 204 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:1.202, Validation accuracy:66.20%
# Epoch 205: iteration 28/29
# Epoch 205 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:1.840, Validation accuracy:60.56%
# Epoch 206: iteration 28/29
# Epoch 206 --- loss:0.013, Epoch accuracy:99.78%, Validation loss:2.080, Validation accuracy:54.93%
# Epoch 207: iteration 28/29
# Epoch 207 --- loss:0.015, Epoch accuracy:99.78%, Validation loss:2.792, Validation accuracy:52.11%
# Epoch 208: iteration 28/29
# Epoch 208 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:1.244, Validation accuracy:59.15%
# Epoch 209: iteration 28/29
# Epoch 209 --- loss:0.030, Epoch accuracy:99.35%, Validation loss:2.840, Validation accuracy:46.48%
# Epoch 210: iteration 28/29
# Epoch 210 --- loss:0.036, Epoch accuracy:99.35%, Validation loss:1.967, Validation accuracy:56.34%
# Epoch 211: iteration 28/29
# Epoch 211 --- loss:0.068, Epoch accuracy:98.49%, Validation loss:7.570, Validation accuracy:23.94%
# Epoch 212: iteration 28/29
# Epoch 212 --- loss:0.039, Epoch accuracy:99.35%, Validation loss:1.214, Validation accuracy:64.79%
# Epoch 213: iteration 28/29
# Epoch 213 --- loss:0.033, Epoch accuracy:99.14%, Validation loss:4.615, Validation accuracy:36.62%
# Epoch 214: iteration 28/29
# Epoch 214 --- loss:0.017, Epoch accuracy:99.57%, Validation loss:1.008, Validation accuracy:67.61%
# Epoch 215: iteration 28/29
# Epoch 215 --- loss:0.020, Epoch accuracy:100.00%, Validation loss:1.150, Validation accuracy:66.20%
# Epoch 216: iteration 28/29
# Epoch 216 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.960, Validation accuracy:47.89%
# Epoch 217: iteration 28/29
# Epoch 217 --- loss:0.015, Epoch accuracy:99.78%, Validation loss:0.873, Validation accuracy:69.01%
# Epoch 218: iteration 28/29
# Epoch 218 --- loss:0.011, Epoch accuracy:99.78%, Validation loss:2.850, Validation accuracy:45.07%
# Epoch 219: iteration 28/29
# Epoch 219 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:2.563, Validation accuracy:52.11%
# Epoch 220: iteration 28/29
# Epoch 220 --- loss:0.012, Epoch accuracy:99.78%, Validation loss:1.316, Validation accuracy:66.20%
# Epoch 221: iteration 28/29
# Epoch 221 --- loss:0.016, Epoch accuracy:99.57%, Validation loss:1.432, Validation accuracy:61.97%
# Epoch 222: iteration 28/29
# Epoch 222 --- loss:0.011, Epoch accuracy:99.78%, Validation loss:1.317, Validation accuracy:66.20%
# Epoch 223: iteration 28/29
# Epoch 223 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:2.524, Validation accuracy:49.30%
# Epoch 224: iteration 28/29
# Epoch 224 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.919, Validation accuracy:53.52%
# Epoch 225: iteration 28/29
# Epoch 225 --- loss:0.029, Epoch accuracy:98.92%, Validation loss:2.707, Validation accuracy:54.93%
# Epoch 226: iteration 28/29
# Epoch 226 --- loss:0.028, Epoch accuracy:99.57%, Validation loss:1.547, Validation accuracy:60.56%
# Epoch 227: iteration 28/29
# Epoch 227 --- loss:0.017, Epoch accuracy:99.78%, Validation loss:4.057, Validation accuracy:49.30%
# Epoch 228: iteration 28/29
# Epoch 228 --- loss:0.017, Epoch accuracy:99.78%, Validation loss:1.055, Validation accuracy:66.20%
# Epoch 229: iteration 28/29
# Epoch 229 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.508, Validation accuracy:47.89%
# Epoch 230: iteration 28/29
# Epoch 230 --- loss:0.014, Epoch accuracy:99.78%, Validation loss:3.477, Validation accuracy:46.48%
# Epoch 231: iteration 28/29
# Epoch 231 --- loss:0.021, Epoch accuracy:99.78%, Validation loss:2.188, Validation accuracy:46.48%
# Epoch 232: iteration 28/29
# Epoch 232 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.065, Validation accuracy:53.52%
# Epoch 233: iteration 28/29
# Epoch 233 --- loss:0.014, Epoch accuracy:99.57%, Validation loss:2.012, Validation accuracy:57.75%
# Epoch 234: iteration 28/29
# Epoch 234 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:1.267, Validation accuracy:60.56%
# Epoch 235: iteration 28/29
# Epoch 235 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:3.560, Validation accuracy:42.25%
# Epoch 236: iteration 28/29
# Epoch 236 --- loss:0.013, Epoch accuracy:99.78%, Validation loss:1.507, Validation accuracy:59.15%
# Epoch 237: iteration 28/29
# Epoch 237 --- loss:0.016, Epoch accuracy:99.57%, Validation loss:1.401, Validation accuracy:60.56%
# Epoch 238: iteration 28/29
# Epoch 238 --- loss:0.046, Epoch accuracy:98.71%, Validation loss:1.832, Validation accuracy:52.11%
# Epoch 239: iteration 28/29
# Epoch 239 --- loss:0.027, Epoch accuracy:99.14%, Validation loss:4.762, Validation accuracy:45.07%
# Epoch 240: iteration 28/29
# Epoch 240 --- loss:0.028, Epoch accuracy:99.35%, Validation loss:1.541, Validation accuracy:60.56%
# Epoch 241: iteration 28/29
# Epoch 241 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:3.349, Validation accuracy:43.66%
# Epoch 242: iteration 28/29
# Epoch 242 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.258, Validation accuracy:69.01%
# Epoch 243: iteration 28/29
# Epoch 243 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:4.084, Validation accuracy:43.66%
# Epoch 244: iteration 28/29
# Epoch 244 --- loss:0.013, Epoch accuracy:99.78%, Validation loss:1.871, Validation accuracy:66.20%
# Epoch 245: iteration 28/29
# Epoch 245 --- loss:0.020, Epoch accuracy:99.57%, Validation loss:2.974, Validation accuracy:52.11%
# Epoch 246: iteration 28/29
# Epoch 246 --- loss:0.028, Epoch accuracy:99.35%, Validation loss:7.052, Validation accuracy:39.44%
# Epoch 247: iteration 28/29
# Epoch 247 --- loss:0.019, Epoch accuracy:99.78%, Validation loss:2.396, Validation accuracy:54.93%
# Epoch 248: iteration 28/29
# Epoch 248 --- loss:0.027, Epoch accuracy:98.92%, Validation loss:1.117, Validation accuracy:64.79%
# Epoch 249: iteration 28/29
# Epoch 249 --- loss:0.018, Epoch accuracy:100.00%, Validation loss:2.413, Validation accuracy:60.56%
# Epoch 250: iteration 28/29
# Epoch 250 --- loss:0.024, Epoch accuracy:99.35%, Validation loss:3.296, Validation accuracy:39.44%
# Epoch 251: iteration 28/29
# Epoch 251 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:2.648, Validation accuracy:47.89%
# Epoch 252: iteration 28/29
# Epoch 252 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.583, Validation accuracy:63.38%
# Epoch 253: iteration 28/29
# Epoch 253 --- loss:0.061, Epoch accuracy:98.49%, Validation loss:13.828, Validation accuracy:22.54%
# Epoch 254: iteration 28/29
# Epoch 254 --- loss:0.085, Epoch accuracy:97.20%, Validation loss:8.512, Validation accuracy:33.80%
# Epoch 255: iteration 28/29
# Epoch 255 --- loss:0.062, Epoch accuracy:97.63%, Validation loss:17.574, Validation accuracy:19.72%
# Epoch 256: iteration 28/29
# Epoch 256 --- loss:0.071, Epoch accuracy:98.28%, Validation loss:4.125, Validation accuracy:33.80%
# Epoch 257: iteration 28/29
# Epoch 257 --- loss:0.050, Epoch accuracy:99.14%, Validation loss:2.426, Validation accuracy:46.48%
# Epoch 258: iteration 28/29
# Epoch 258 --- loss:0.025, Epoch accuracy:99.78%, Validation loss:1.383, Validation accuracy:64.79%
# Epoch 259: iteration 28/29
# Epoch 259 --- loss:0.022, Epoch accuracy:99.57%, Validation loss:1.960, Validation accuracy:43.66%
# Epoch 260: iteration 28/29
# Epoch 260 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:0.842, Validation accuracy:73.24%
# Epoch 261: iteration 28/29
# Epoch 261 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.859, Validation accuracy:56.34%
# Epoch 262: iteration 28/29
# Epoch 262 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.108, Validation accuracy:67.61%
# Epoch 263: iteration 28/29
# Epoch 263 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.592, Validation accuracy:59.15%
# Epoch 264: iteration 28/29
# Epoch 264 --- loss:0.008, Epoch accuracy:100.00%, Validation loss:2.706, Validation accuracy:54.93%
# Epoch 265: iteration 28/29
# Epoch 265 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:1.639, Validation accuracy:57.75%
# Epoch 266: iteration 28/29
# Epoch 266 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.213, Validation accuracy:64.79%
# Epoch 267: iteration 28/29
# Epoch 267 --- loss:0.007, Epoch accuracy:99.78%, Validation loss:1.401, Validation accuracy:61.97%
# Epoch 268: iteration 28/29
# Epoch 268 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:2.076, Validation accuracy:52.11%
# Epoch 269: iteration 28/29
# Epoch 269 --- loss:0.007, Epoch accuracy:100.00%, Validation loss:1.936, Validation accuracy:53.52%
# Epoch 270: iteration 28/29
# Epoch 270 --- loss:0.021, Epoch accuracy:99.57%, Validation loss:2.444, Validation accuracy:52.11%
# Epoch 271: iteration 28/29
# Epoch 271 --- loss:0.019, Epoch accuracy:99.78%, Validation loss:2.450, Validation accuracy:45.07%
# Epoch 272: iteration 28/29
# Epoch 272 --- loss:0.026, Epoch accuracy:99.57%, Validation loss:18.024, Validation accuracy:19.72%
# Epoch 273: iteration 28/29
# Epoch 273 --- loss:0.013, Epoch accuracy:100.00%, Validation loss:1.872, Validation accuracy:53.52%
# Epoch 274: iteration 28/29
# Epoch 274 --- loss:0.011, Epoch accuracy:100.00%, Validation loss:2.980, Validation accuracy:47.89%
# Epoch 275: iteration 28/29
# Epoch 275 --- loss:0.011, Epoch accuracy:99.57%, Validation loss:1.381, Validation accuracy:63.38%
# Epoch 276: iteration 28/29
# Epoch 276 --- loss:0.013, Epoch accuracy:99.57%, Validation loss:2.545, Validation accuracy:43.66%
# Epoch 277: iteration 28/29
# Epoch 277 --- loss:0.010, Epoch accuracy:99.78%, Validation loss:1.592, Validation accuracy:60.56%
# Epoch 278: iteration 28/29
# Epoch 278 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:1.736, Validation accuracy:54.93%
# Epoch 279: iteration 28/29
# Epoch 279 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.365, Validation accuracy:69.01%
# Epoch 280: iteration 28/29
# Epoch 280 --- loss:0.009, Epoch accuracy:99.78%, Validation loss:2.243, Validation accuracy:54.93%
# Epoch 281: iteration 28/29
# Epoch 281 --- loss:0.009, Epoch accuracy:100.00%, Validation loss:2.708, Validation accuracy:46.48%
# Epoch 282: iteration 28/29
# Epoch 282 --- loss:0.004, Epoch accuracy:100.00%, Validation loss:1.579, Validation accuracy:61.97%
# Epoch 283: iteration 28/29
# Epoch 283 --- loss:0.030, Epoch accuracy:99.57%, Validation loss:3.732, Validation accuracy:46.48%
# Epoch 284: iteration 28/29
# Epoch 284 --- loss:0.023, Epoch accuracy:99.57%, Validation loss:2.746, Validation accuracy:46.48%
# Epoch 285: iteration 28/29
# Epoch 285 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.597, Validation accuracy:60.56%
# Epoch 286: iteration 28/29
# Epoch 286 --- loss:0.015, Epoch accuracy:99.78%, Validation loss:3.882, Validation accuracy:52.11%
# Epoch 287: iteration 28/29
# Epoch 287 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.316, Validation accuracy:63.38%
# Epoch 288: iteration 28/29
# Epoch 288 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.666, Validation accuracy:54.93%
# Epoch 289: iteration 28/29
# Epoch 289 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.271, Validation accuracy:66.20%
# Epoch 290: iteration 28/29
# Epoch 290 --- loss:0.013, Epoch accuracy:99.57%, Validation loss:1.901, Validation accuracy:54.93%
# Epoch 291: iteration 28/29
# Epoch 291 --- loss:0.016, Epoch accuracy:99.57%, Validation loss:1.875, Validation accuracy:59.15%
# Epoch 292: iteration 28/29
# Epoch 292 --- loss:0.027, Epoch accuracy:99.57%, Validation loss:2.888, Validation accuracy:39.44%
# Epoch 293: iteration 28/29
# Epoch 293 --- loss:0.028, Epoch accuracy:99.14%, Validation loss:2.021, Validation accuracy:60.56%
# Epoch 294: iteration 28/29
# Epoch 294 --- loss:0.012, Epoch accuracy:100.00%, Validation loss:2.076, Validation accuracy:49.30%
# Epoch 295: iteration 28/29
# Epoch 295 --- loss:0.016, Epoch accuracy:99.78%, Validation loss:2.203, Validation accuracy:57.75%
# Epoch 296: iteration 28/29
# Epoch 296 --- loss:0.016, Epoch accuracy:99.57%, Validation loss:2.629, Validation accuracy:52.11%
# Epoch 297: iteration 28/29
# Epoch 297 --- loss:0.021, Epoch accuracy:99.78%, Validation loss:2.114, Validation accuracy:45.07%
# Epoch 298: iteration 28/29
# Epoch 298 --- loss:0.010, Epoch accuracy:100.00%, Validation loss:1.187, Validation accuracy:59.15%
# Epoch 299: iteration 28/29
# Epoch 299 --- loss:0.006, Epoch accuracy:100.00%, Validation loss:1.889, Validation accuracy:57.75%
#
#
# [*] done !
# [*] Best training loss - 0.004331483213624371
# [*] Best validation loss - 0.6366270780563354

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

for fold in range(10):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, f'delta-fold{fold}.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    
    test_accs.append(test_acc)
    
    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, emotions_groundtruth)
    predicted_emotions_list = np.append(predicted_emotions_list, predicted_emotions)

# %%
os.makedirs('result', exist_ok=True)

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)
print(Report)

with open(f"result/{sub_name}_{loss_name}_Report.txt", "w") as f:
    f.write(Report)

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f"result/{sub_name}_{loss_name}_confmatrix.pdf")
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.87      0.88       127
#          1.0       0.89      0.72      0.80        69
#          2.0       0.81      0.84      0.82        81
#          3.0       0.78      0.67      0.72        46
#          4.0       0.63      0.75      0.68        71
#          5.0       0.78      0.86      0.82        79
#          6.0       0.92      0.89      0.90        62
#
#     accuracy                           0.81       535
#    macro avg       0.81      0.80      0.80       535
# weighted avg       0.82      0.81      0.82       535

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 89.47%
# [*] Worst fold acc : 70.91%
# [*] Average fold acc : 80.44%
