# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'Deep-Net'
data_name = 'RAVDESS'

minibatch = 32
num_epochs = 100
EARLY_CNT = 99999

learning_rate = 1e-6

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 10, kernel_size=[9,1], padding=(4,0)),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=[5,1], padding=(2,0)),
            nn.ReLU(),
            nn.Conv2d(10, 10, kernel_size=[3,1], padding=(1,0)),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[3,1], stride=1),
            nn.BatchNorm2d(10)
        )
        
        self.conv2 = nn.Sequential(
            nn.Conv2d(10, 40, kernel_size=[3,1], padding=(1,0)),
            nn.ReLU(),
            nn.Conv2d(40, 40, kernel_size=[3,1], padding=(1,0)),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1]),
            nn.BatchNorm2d(40)
        )
        
        self.conv3 = nn.Sequential(
            nn.Conv2d(40, 80, kernel_size=[10,1], padding=(5,0)),
            nn.ReLU(),
            nn.Conv2d(80, 80, kernel_size=[1,1]),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=[2,1]),
            nn.BatchNorm2d(80)
        )
        
        self.conv4 = nn.Sequential(
            nn.Conv2d(80, 80, kernel_size=[1,1]),
            nn.ReLU()
        )
        
        self.fc1 = nn.Linear(675840, 128)
        self.fc2 = nn.Linear(128, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):

        embd = self.conv1(x)
        embd = self.conv2(embd)
        embd = self.conv3(embd)
        embd = self.conv4(embd)
        
        embd = torch.flatten(embd, start_dim=1)
        
        out = self.fc1(embd)
        output_logits = self.fc2(out)
        output_softmax = self.softmax(output_logits)

        return output_logits, output_softmax

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs)):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'Deep-Net dataset'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    break
# Out:
# [*] model training - Deep-Net
# A Jupyter Widget
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:1.994, Epoch accuracy:20.35%, Validation loss:2.039, Validation accuracy:22.67%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:1.785, Epoch accuracy:38.16%, Validation loss:1.883, Validation accuracy:34.67%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:1.640, Epoch accuracy:49.30%, Validation loss:1.819, Validation accuracy:33.67%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:1.537, Epoch accuracy:54.21%, Validation loss:1.773, Validation accuracy:34.00%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:1.417, Epoch accuracy:61.49%, Validation loss:1.748, Validation accuracy:34.33%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:1.328, Epoch accuracy:65.88%, Validation loss:1.702, Validation accuracy:41.00%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:1.238, Epoch accuracy:71.40%, Validation loss:1.664, Validation accuracy:42.00%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:1.157, Epoch accuracy:74.91%, Validation loss:1.663, Validation accuracy:38.00%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:1.085, Epoch accuracy:78.33%, Validation loss:1.631, Validation accuracy:42.00%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:1.007, Epoch accuracy:82.02%, Validation loss:1.607, Validation accuracy:46.67%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:0.936, Epoch accuracy:85.26%, Validation loss:1.591, Validation accuracy:39.33%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:0.875, Epoch accuracy:87.98%, Validation loss:1.590, Validation accuracy:40.33%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:0.825, Epoch accuracy:88.25%, Validation loss:1.580, Validation accuracy:41.67%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:0.763, Epoch accuracy:91.67%, Validation loss:1.551, Validation accuracy:44.00%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:0.707, Epoch accuracy:92.81%, Validation loss:1.543, Validation accuracy:45.00%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:0.663, Epoch accuracy:94.82%, Validation loss:1.526, Validation accuracy:47.00%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:0.614, Epoch accuracy:95.79%, Validation loss:1.531, Validation accuracy:41.67%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:0.577, Epoch accuracy:95.53%, Validation loss:1.541, Validation accuracy:44.67%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:0.539, Epoch accuracy:96.32%, Validation loss:1.510, Validation accuracy:46.00%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:0.496, Epoch accuracy:97.54%, Validation loss:1.514, Validation accuracy:44.67%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:0.465, Epoch accuracy:97.89%, Validation loss:1.491, Validation accuracy:46.33%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:0.437, Epoch accuracy:97.81%, Validation loss:1.504, Validation accuracy:44.33%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:0.409, Epoch accuracy:98.25%, Validation loss:1.466, Validation accuracy:52.00%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:0.387, Epoch accuracy:97.98%, Validation loss:1.512, Validation accuracy:42.33%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:0.360, Epoch accuracy:98.16%, Validation loss:1.478, Validation accuracy:48.33%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:0.337, Epoch accuracy:98.25%, Validation loss:1.485, Validation accuracy:46.00%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:0.318, Epoch accuracy:98.25%, Validation loss:1.455, Validation accuracy:50.00%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:0.299, Epoch accuracy:98.25%, Validation loss:1.472, Validation accuracy:46.33%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:0.281, Epoch accuracy:98.16%, Validation loss:1.449, Validation accuracy:49.33%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:0.266, Epoch accuracy:98.25%, Validation loss:1.440, Validation accuracy:52.00%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:0.247, Epoch accuracy:98.25%, Validation loss:1.457, Validation accuracy:48.00%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:0.236, Epoch accuracy:98.25%, Validation loss:1.463, Validation accuracy:49.33%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:0.223, Epoch accuracy:98.25%, Validation loss:1.432, Validation accuracy:51.67%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:0.210, Epoch accuracy:98.25%, Validation loss:1.471, Validation accuracy:47.00%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:0.201, Epoch accuracy:98.25%, Validation loss:1.426, Validation accuracy:50.67%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:0.191, Epoch accuracy:98.25%, Validation loss:1.458, Validation accuracy:48.00%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:0.180, Epoch accuracy:98.25%, Validation loss:1.471, Validation accuracy:44.67%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:0.172, Epoch accuracy:98.25%, Validation loss:1.451, Validation accuracy:46.67%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:0.163, Epoch accuracy:98.25%, Validation loss:1.453, Validation accuracy:48.67%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:0.156, Epoch accuracy:98.25%, Validation loss:1.439, Validation accuracy:48.67%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:0.150, Epoch accuracy:98.25%, Validation loss:1.431, Validation accuracy:48.67%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:0.142, Epoch accuracy:98.25%, Validation loss:1.440, Validation accuracy:48.67%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:0.136, Epoch accuracy:98.25%, Validation loss:1.431, Validation accuracy:48.00%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:0.131, Epoch accuracy:98.25%, Validation loss:1.438, Validation accuracy:48.67%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:0.126, Epoch accuracy:98.25%, Validation loss:1.427, Validation accuracy:48.67%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:0.121, Epoch accuracy:98.25%, Validation loss:1.428, Validation accuracy:48.33%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:0.116, Epoch accuracy:98.25%, Validation loss:1.439, Validation accuracy:48.00%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:0.111, Epoch accuracy:98.25%, Validation loss:1.416, Validation accuracy:49.33%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:0.107, Epoch accuracy:98.25%, Validation loss:1.440, Validation accuracy:47.67%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:0.103, Epoch accuracy:98.25%, Validation loss:1.447, Validation accuracy:48.67%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:0.100, Epoch accuracy:98.25%, Validation loss:1.432, Validation accuracy:48.00%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:0.095, Epoch accuracy:98.25%, Validation loss:1.421, Validation accuracy:48.33%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:0.093, Epoch accuracy:98.25%, Validation loss:1.421, Validation accuracy:49.67%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:0.089, Epoch accuracy:98.25%, Validation loss:1.429, Validation accuracy:48.00%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:0.086, Epoch accuracy:98.25%, Validation loss:1.432, Validation accuracy:47.33%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:0.084, Epoch accuracy:98.25%, Validation loss:1.408, Validation accuracy:49.67%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:0.081, Epoch accuracy:98.25%, Validation loss:1.426, Validation accuracy:48.67%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:0.079, Epoch accuracy:98.25%, Validation loss:1.420, Validation accuracy:48.67%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:0.076, Epoch accuracy:98.25%, Validation loss:1.413, Validation accuracy:48.33%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:0.074, Epoch accuracy:98.25%, Validation loss:1.417, Validation accuracy:48.67%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:0.072, Epoch accuracy:98.25%, Validation loss:1.436, Validation accuracy:47.67%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:0.069, Epoch accuracy:98.25%, Validation loss:1.424, Validation accuracy:48.00%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:0.068, Epoch accuracy:98.25%, Validation loss:1.421, Validation accuracy:47.33%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:0.066, Epoch accuracy:98.25%, Validation loss:1.419, Validation accuracy:49.33%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:0.064, Epoch accuracy:98.25%, Validation loss:1.425, Validation accuracy:49.33%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:0.062, Epoch accuracy:98.25%, Validation loss:1.435, Validation accuracy:47.33%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:0.061, Epoch accuracy:98.25%, Validation loss:1.419, Validation accuracy:47.67%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:0.059, Epoch accuracy:98.25%, Validation loss:1.419, Validation accuracy:47.33%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:0.057, Epoch accuracy:98.25%, Validation loss:1.428, Validation accuracy:47.67%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:0.056, Epoch accuracy:98.25%, Validation loss:1.420, Validation accuracy:48.33%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:0.055, Epoch accuracy:98.25%, Validation loss:1.422, Validation accuracy:48.00%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:0.053, Epoch accuracy:98.25%, Validation loss:1.425, Validation accuracy:47.67%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:0.052, Epoch accuracy:98.25%, Validation loss:1.429, Validation accuracy:47.33%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:0.051, Epoch accuracy:98.25%, Validation loss:1.433, Validation accuracy:47.33%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:0.050, Epoch accuracy:98.25%, Validation loss:1.431, Validation accuracy:47.33%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:0.049, Epoch accuracy:98.25%, Validation loss:1.423, Validation accuracy:48.00%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:0.048, Epoch accuracy:98.25%, Validation loss:1.423, Validation accuracy:47.33%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:0.047, Epoch accuracy:98.25%, Validation loss:1.428, Validation accuracy:47.00%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:0.046, Epoch accuracy:98.25%, Validation loss:1.420, Validation accuracy:48.67%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:0.045, Epoch accuracy:98.25%, Validation loss:1.421, Validation accuracy:48.00%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:0.044, Epoch accuracy:98.25%, Validation loss:1.428, Validation accuracy:47.33%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:0.043, Epoch accuracy:98.25%, Validation loss:1.417, Validation accuracy:47.33%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:0.042, Epoch accuracy:98.25%, Validation loss:1.423, Validation accuracy:47.67%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:0.041, Epoch accuracy:98.25%, Validation loss:1.426, Validation accuracy:46.67%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:0.041, Epoch accuracy:98.25%, Validation loss:1.428, Validation accuracy:47.33%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:0.040, Epoch accuracy:98.25%, Validation loss:1.432, Validation accuracy:47.33%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:0.039, Epoch accuracy:98.25%, Validation loss:1.421, Validation accuracy:47.33%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:0.038, Epoch accuracy:98.25%, Validation loss:1.428, Validation accuracy:47.33%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:0.038, Epoch accuracy:98.25%, Validation loss:1.422, Validation accuracy:47.33%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:0.037, Epoch accuracy:98.25%, Validation loss:1.434, Validation accuracy:47.00%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:0.036, Epoch accuracy:98.25%, Validation loss:1.431, Validation accuracy:47.00%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:0.036, Epoch accuracy:98.25%, Validation loss:1.424, Validation accuracy:47.00%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:0.035, Epoch accuracy:98.25%, Validation loss:1.431, Validation accuracy:47.00%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:0.035, Epoch accuracy:98.25%, Validation loss:1.424, Validation accuracy:48.00%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:0.034, Epoch accuracy:98.25%, Validation loss:1.439, Validation accuracy:46.33%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:0.033, Epoch accuracy:98.25%, Validation loss:1.430, Validation accuracy:47.33%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:0.033, Epoch accuracy:98.25%, Validation loss:1.429, Validation accuracy:47.67%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:0.032, Epoch accuracy:98.25%, Validation loss:1.436, Validation accuracy:47.00%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:0.032, Epoch accuracy:98.25%, Validation loss:1.434, Validation accuracy:47.00%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:0.031, Epoch accuracy:98.25%, Validation loss:1.435, Validation accuracy:47.00%
#
#
# [*] done !
# [*] Best training loss - 0.03132020705624632
# [*] Best validation loss - 1.408421277999878

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    
    break
# Out:
# [*] 0 Test accuracy is 49.67%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 49.67%
# [*] Worst fold acc : 49.67%
# [*] Average fold acc : 49.67%

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    break
# Out:
# [*] 0 Test accuracy is 49.67%
#               precision    recall  f1-score   support
#
#            0       0.67      0.40      0.50        20
#            1       0.68      0.47      0.56        40
#            2       0.45      0.33      0.38        40
#            3       0.37      0.17      0.24        40
#            4       0.60      0.82      0.69        40
#            5       0.67      0.50      0.57        40
#            6       0.46      0.60      0.52        40
#            7       0.33      0.62      0.43        40
#
#     accuracy                           0.50       300
#    macro avg       0.53      0.49      0.49       300
# weighted avg       0.52      0.50      0.49       300
