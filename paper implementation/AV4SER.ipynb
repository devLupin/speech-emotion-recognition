# %% [markdown]
# ## https://github.com/Janie1996/AV4SER

# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'AV4SER'
fold_path = sub_name + ' dataset'
data_name = 'RAVDESS'

loss_name = 'CE loss'

minibatch = 32
num_epochs = 300
EARLY_CNT = 99999

learning_rate = 0.001

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
from sklearn.metrics import classification_report
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
class SeperableConv2d(nn.Module):
    def __init__(self, input_channels, output_channels, kernel_size, **kwargs):
        super().__init__()
        self.depthwise = nn.Conv2d(input_channels, input_channels, kernel_size,
                                   groups=input_channels,
                                   bias=False,
                                   **kwargs
                                   )

        self.pointwise = nn.Conv2d(input_channels, output_channels, 1, bias=False)

    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return x
    
class ChannelAttention(nn.Module):

    def __init__(self, n_channels_in, reduction_ratio=16):
        super(ChannelAttention, self).__init__()
        self.n_channels_in = n_channels_in
        self.reduction_ratio = reduction_ratio


        self.middle_layer_size = int(self.n_channels_in / float(self.reduction_ratio))

        self.bottleneck = nn.Sequential(
            nn.Linear(self.n_channels_in, self.middle_layer_size),
            nn.ReLU(),
            nn.Linear(self.middle_layer_size, self.n_channels_in)
        )

    def forward(self, x):
        kernel = (x.size()[2], x.size()[3])
        avg_pool = F.avg_pool2d(x, kernel)
        max_pool = F.max_pool2d(x, kernel)

        avg_pool = avg_pool.view(avg_pool.size()[0], -1)  # batch, channel
        max_pool = max_pool.view(max_pool.size()[0], -1)

        avg_pool_bck = self.bottleneck(avg_pool) # batch, channel
        max_pool_bck = self.bottleneck(max_pool)

        pool_sum = avg_pool_bck + max_pool_bck

        sig_pool = torch.sigmoid(pool_sum)
        sig_pool = sig_pool.unsqueeze(2).unsqueeze(3)
        out = sig_pool.repeat(1, 1, kernel[0], kernel[1])
        return out


class SpatialAttention(nn.Module):
    def __init__(self, kernel_size = 3):
        super(SpatialAttention, self).__init__()
        self.kernel_size = kernel_size

        assert kernel_size % 2 == 1, "Odd kernel size required"
        self.conv = nn.Conv2d(in_channels=2, out_channels=1, kernel_size=kernel_size,
                              padding=int((kernel_size - 1) / 2))
        # batchnorm

    def forward(self, x):
        max_pool = self.agg_channel(x, "max")
        avg_pool = self.agg_channel(x, "avg")
        pool = torch.cat([max_pool, avg_pool], dim=1)
        conv = self.conv(pool)
        conv = conv.repeat(1, x.size()[1], 1, 1)
        att = torch.sigmoid(conv)
        return att

    def agg_channel(self, x, pool="max"):
        b, c, h, w = x.size()
        x = x.view(b, c, h * w)
        x = x.permute(0, 2, 1)
        if pool == "max":
            x = F.max_pool1d(x, c)
        elif pool == "avg":
            x = F.avg_pool1d(x, c)
        x = x.permute(0, 2, 1)
        x = x.view(b, 1, h, w)
        return x

class Model(nn.Module):
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        self.conv3_residual = nn.Sequential(
            SeperableConv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            SeperableConv2d(128, 128, 3, padding=1),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(3, stride=2, padding=1),
        )
        self.conv3_shortcut = nn.Sequential(
            nn.Conv2d(64, 128, 1, stride=2),
            nn.BatchNorm2d(128),
        )
        self.conv4_residual = nn.Sequential(
            nn.ReLU(inplace=True),
            SeperableConv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            SeperableConv2d(256, 256, 3, padding=1),
            nn.BatchNorm2d(256),
            nn.MaxPool2d(3, stride=2, padding=1)
        )

        self.conv4_shortcut = nn.Sequential(
            nn.Conv2d(128, 256, 1, stride=2),
            nn.BatchNorm2d(256),
        )
        self.drop = nn.Dropout(p=0.5, inplace=True)

        # CASA
        self.c_attention = ChannelAttention(256)
        self.s_attention = SpatialAttention()
        
        transf_layer = nn.TransformerEncoderLayer(d_model=256, nhead=4, dim_feedforward=512, dropout=0.4)
        self.transf_encoder = nn.TransformerEncoder(transf_layer, num_layers=2)
        
        self.classifier = nn.Linear(57, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        
        residual = self.conv3_residual(x)
        shortcut = self.conv3_shortcut(x)
        # x = residual + shortcut
        x = self.drop(residual + shortcut)
        residual = self.conv4_residual(x)
        shortcut = self.conv4_shortcut(x)
        # x = residual + shortcut
        x = self.drop(residual + shortcut)
        
        c_attn = self.s_attention(x)
        c_attn_context = c_attn * x
        spat_att = self.c_attention(c_attn_context)
        cs_attn_context = spat_att * c_attn_context
        
        out = torch.flatten(cs_attn_context, start_dim=2)
        out = rearrange(out, 'b t f -> b f t')

        out = self.transf_encoder(out)
        attn_out = torch.mean(out, dim=2)
        
        output_logits = self.classifier(attn_out)
        output_softmax = self.softmax(output_logits)

        return output_logits, output_softmax

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'Fold-{fold+1} training.....'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i+1}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nloss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

for fold in tqdm(range(5)):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - AV4SER
# A Jupyter Widget
# A Jupyter Widget
# Epoch 0: iteration 35/35
# loss:2.044, Epoch accuracy:13.25%, Validation loss:2.077, Validation accuracy:13.33%
# Epoch 1: iteration 35/35
# loss:2.036, Epoch accuracy:12.98%, Validation loss:2.064, Validation accuracy:13.33%
# Epoch 2: iteration 35/35
# loss:2.026, Epoch accuracy:15.09%, Validation loss:2.054, Validation accuracy:19.00%
# Epoch 3: iteration 35/35
# loss:2.016, Epoch accuracy:17.98%, Validation loss:2.053, Validation accuracy:15.33%
# Epoch 4: iteration 35/35
# loss:2.010, Epoch accuracy:17.63%, Validation loss:2.063, Validation accuracy:13.33%
# Epoch 5: iteration 35/35
# loss:2.012, Epoch accuracy:15.35%, Validation loss:2.017, Validation accuracy:23.67%
# Epoch 6: iteration 35/35
# loss:1.984, Epoch accuracy:22.11%, Validation loss:2.008, Validation accuracy:18.33%
# Epoch 7: iteration 35/35
# loss:1.969, Epoch accuracy:23.68%, Validation loss:2.013, Validation accuracy:17.00%
# Epoch 8: iteration 35/35
# loss:1.992, Epoch accuracy:18.86%, Validation loss:2.015, Validation accuracy:20.67%
# Epoch 9: iteration 35/35
# loss:1.980, Epoch accuracy:20.26%, Validation loss:2.045, Validation accuracy:15.00%
# Epoch 10: iteration 35/35
# loss:2.008, Epoch accuracy:16.05%, Validation loss:2.028, Validation accuracy:17.33%
# Epoch 11: iteration 35/35
# loss:1.992, Epoch accuracy:18.60%, Validation loss:2.048, Validation accuracy:15.67%
# Epoch 12: iteration 35/35
# loss:1.978, Epoch accuracy:17.98%, Validation loss:2.000, Validation accuracy:16.00%
# Epoch 13: iteration 35/35
# loss:2.005, Epoch accuracy:15.26%, Validation loss:2.065, Validation accuracy:13.33%
# Epoch 14: iteration 35/35
# loss:2.025, Epoch accuracy:13.95%, Validation loss:2.065, Validation accuracy:13.33%
# Epoch 15: iteration 35/35
# loss:2.029, Epoch accuracy:13.25%, Validation loss:2.067, Validation accuracy:13.33%
# Epoch 16: iteration 35/35
# loss:2.029, Epoch accuracy:13.42%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 17: iteration 35/35
# loss:2.026, Epoch accuracy:11.93%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 18: iteration 35/35
# loss:2.028, Epoch accuracy:10.35%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 19: iteration 35/35
# loss:2.026, Epoch accuracy:12.81%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 20: iteration 35/35
# loss:2.026, Epoch accuracy:13.16%, Validation loss:2.064, Validation accuracy:13.67%
# Epoch 21: iteration 35/35
# loss:2.029, Epoch accuracy:11.84%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 22: iteration 35/35
# loss:2.026, Epoch accuracy:11.84%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 23: iteration 35/35
# loss:2.027, Epoch accuracy:12.72%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 24: iteration 35/35
# loss:2.025, Epoch accuracy:11.58%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 25: iteration 35/35
# loss:2.027, Epoch accuracy:12.72%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 26: iteration 35/35
# loss:2.027, Epoch accuracy:11.40%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 27: iteration 35/35
# loss:2.014, Epoch accuracy:16.14%, Validation loss:2.007, Validation accuracy:21.00%
# Epoch 28: iteration 35/35
# loss:1.967, Epoch accuracy:19.65%, Validation loss:1.961, Validation accuracy:25.00%
# Epoch 29: iteration 35/35
# loss:1.929, Epoch accuracy:24.39%, Validation loss:1.958, Validation accuracy:24.00%
# Epoch 30: iteration 35/35
# loss:1.899, Epoch accuracy:24.65%, Validation loss:1.994, Validation accuracy:23.33%
# Epoch 31: iteration 35/35
# loss:1.931, Epoch accuracy:21.84%, Validation loss:1.930, Validation accuracy:22.00%
# Epoch 32: iteration 35/35
# loss:1.871, Epoch accuracy:25.88%, Validation loss:1.934, Validation accuracy:24.00%
# Epoch 33: iteration 35/35
# loss:1.822, Epoch accuracy:28.60%, Validation loss:2.107, Validation accuracy:22.00%
# Epoch 34: iteration 35/35
# loss:1.833, Epoch accuracy:27.89%, Validation loss:1.938, Validation accuracy:24.67%
# Epoch 35: iteration 35/35
# loss:1.940, Epoch accuracy:21.05%, Validation loss:1.970, Validation accuracy:25.00%
# Epoch 36: iteration 35/35
# loss:1.889, Epoch accuracy:24.82%, Validation loss:2.041, Validation accuracy:18.00%
# Epoch 37: iteration 35/35
# loss:1.907, Epoch accuracy:23.42%, Validation loss:1.976, Validation accuracy:22.33%
# Epoch 38: iteration 35/35
# loss:1.885, Epoch accuracy:23.33%, Validation loss:1.935, Validation accuracy:21.33%
# Epoch 39: iteration 35/35
# loss:1.907, Epoch accuracy:22.37%, Validation loss:1.950, Validation accuracy:19.33%
# Epoch 40: iteration 35/35
# loss:1.906, Epoch accuracy:22.46%, Validation loss:1.959, Validation accuracy:22.00%
# Epoch 41: iteration 35/35
# loss:1.947, Epoch accuracy:20.09%, Validation loss:2.000, Validation accuracy:21.00%
# Epoch 42: iteration 35/35
# loss:1.900, Epoch accuracy:24.30%, Validation loss:1.932, Validation accuracy:23.33%
# Epoch 43: iteration 35/35
# loss:1.922, Epoch accuracy:21.40%, Validation loss:1.947, Validation accuracy:22.33%
# Epoch 44: iteration 35/35
# loss:1.919, Epoch accuracy:21.40%, Validation loss:1.979, Validation accuracy:20.00%
# Epoch 45: iteration 35/35
# loss:1.923, Epoch accuracy:22.02%, Validation loss:2.034, Validation accuracy:14.33%
# Epoch 46: iteration 35/35
# loss:1.901, Epoch accuracy:22.72%, Validation loss:2.032, Validation accuracy:21.33%
# Epoch 47: iteration 35/35
# loss:1.840, Epoch accuracy:26.75%, Validation loss:1.951, Validation accuracy:22.00%
# Epoch 48: iteration 35/35
# loss:1.835, Epoch accuracy:26.93%, Validation loss:2.086, Validation accuracy:22.67%
# Epoch 49: iteration 35/35
# loss:1.893, Epoch accuracy:23.95%, Validation loss:2.027, Validation accuracy:20.67%
# Epoch 50: iteration 35/35
# loss:1.855, Epoch accuracy:26.23%, Validation loss:1.968, Validation accuracy:23.00%
# Epoch 51: iteration 35/35
# loss:1.872, Epoch accuracy:24.39%, Validation loss:1.912, Validation accuracy:22.33%
# Epoch 52: iteration 35/35
# loss:1.824, Epoch accuracy:25.44%, Validation loss:2.015, Validation accuracy:25.33%
# Epoch 53: iteration 35/35
# loss:1.856, Epoch accuracy:24.74%, Validation loss:1.962, Validation accuracy:21.67%
# Epoch 54: iteration 35/35
# loss:1.918, Epoch accuracy:22.46%, Validation loss:2.100, Validation accuracy:15.00%
# Epoch 55: iteration 35/35
# loss:1.947, Epoch accuracy:20.79%, Validation loss:2.061, Validation accuracy:18.00%
# Epoch 56: iteration 35/35
# loss:1.928, Epoch accuracy:22.28%, Validation loss:1.983, Validation accuracy:23.33%
# Epoch 57: iteration 35/35
# loss:1.871, Epoch accuracy:25.18%, Validation loss:2.036, Validation accuracy:22.67%
# Epoch 58: iteration 35/35
# loss:1.888, Epoch accuracy:23.51%, Validation loss:2.024, Validation accuracy:22.67%
# Epoch 59: iteration 35/35
# loss:1.850, Epoch accuracy:27.02%, Validation loss:1.966, Validation accuracy:26.33%
# Epoch 60: iteration 35/35
# loss:1.840, Epoch accuracy:26.14%, Validation loss:1.953, Validation accuracy:25.67%
# Epoch 61: iteration 35/35
# loss:1.797, Epoch accuracy:29.65%, Validation loss:1.994, Validation accuracy:25.00%
# Epoch 62: iteration 35/35
# loss:1.798, Epoch accuracy:29.21%, Validation loss:1.945, Validation accuracy:24.00%
# Epoch 63: iteration 35/35
# loss:1.790, Epoch accuracy:28.68%, Validation loss:1.968, Validation accuracy:25.67%
# Epoch 64: iteration 35/35
# loss:1.774, Epoch accuracy:30.70%, Validation loss:1.949, Validation accuracy:24.33%
# Epoch 65: iteration 35/35
# loss:1.807, Epoch accuracy:28.07%, Validation loss:1.972, Validation accuracy:26.67%
# Epoch 66: iteration 35/35
# loss:1.819, Epoch accuracy:29.74%, Validation loss:1.943, Validation accuracy:24.67%
# Epoch 67: iteration 35/35
# loss:1.837, Epoch accuracy:26.75%, Validation loss:1.982, Validation accuracy:24.33%
# Epoch 68: iteration 35/35
# loss:1.832, Epoch accuracy:27.81%, Validation loss:2.056, Validation accuracy:23.67%
# Epoch 69: iteration 35/35
# loss:1.848, Epoch accuracy:26.05%, Validation loss:2.021, Validation accuracy:24.33%
# Epoch 70: iteration 35/35
# loss:1.784, Epoch accuracy:29.04%, Validation loss:1.984, Validation accuracy:25.00%
# Epoch 71: iteration 35/35
# loss:1.773, Epoch accuracy:31.84%, Validation loss:1.940, Validation accuracy:27.00%
# Epoch 72: iteration 35/35
# loss:1.784, Epoch accuracy:29.39%, Validation loss:1.921, Validation accuracy:23.33%
# Epoch 73: iteration 35/35
# loss:1.766, Epoch accuracy:29.56%, Validation loss:1.924, Validation accuracy:27.00%
# Epoch 74: iteration 35/35
# loss:1.752, Epoch accuracy:30.35%, Validation loss:2.025, Validation accuracy:24.00%
# Epoch 75: iteration 35/35
# loss:1.729, Epoch accuracy:32.19%, Validation loss:1.973, Validation accuracy:23.67%
# Epoch 76: iteration 35/35
# loss:1.712, Epoch accuracy:32.19%, Validation loss:1.961, Validation accuracy:23.00%
# Epoch 77: iteration 35/35
# loss:1.714, Epoch accuracy:34.04%, Validation loss:2.026, Validation accuracy:22.33%
# Epoch 78: iteration 35/35
# loss:1.715, Epoch accuracy:33.07%, Validation loss:2.035, Validation accuracy:21.00%
# Epoch 79: iteration 35/35
# loss:1.717, Epoch accuracy:34.47%, Validation loss:1.986, Validation accuracy:25.00%
# Epoch 80: iteration 35/35
# loss:1.710, Epoch accuracy:33.07%, Validation loss:1.961, Validation accuracy:23.67%
# Epoch 81: iteration 35/35
# loss:1.694, Epoch accuracy:33.60%, Validation loss:1.991, Validation accuracy:22.67%
# Epoch 82: iteration 35/35
# loss:1.682, Epoch accuracy:35.18%, Validation loss:2.011, Validation accuracy:24.33%
# Epoch 83: iteration 35/35
# loss:1.707, Epoch accuracy:33.42%, Validation loss:1.990, Validation accuracy:24.00%
# Epoch 84: iteration 35/35
# loss:1.719, Epoch accuracy:34.39%, Validation loss:2.007, Validation accuracy:25.33%
# Epoch 85: iteration 35/35
# loss:1.718, Epoch accuracy:33.25%, Validation loss:1.825, Validation accuracy:26.67%
# Epoch 86: iteration 35/35
# loss:1.743, Epoch accuracy:31.93%, Validation loss:1.877, Validation accuracy:27.67%
# Epoch 87: iteration 35/35
# loss:1.733, Epoch accuracy:31.93%, Validation loss:1.937, Validation accuracy:27.33%
# Epoch 88: iteration 35/35
# loss:1.732, Epoch accuracy:31.93%, Validation loss:1.887, Validation accuracy:26.00%
# Epoch 89: iteration 35/35
# loss:1.704, Epoch accuracy:32.37%, Validation loss:1.921, Validation accuracy:25.67%
# Epoch 90: iteration 35/35
# loss:1.660, Epoch accuracy:35.09%, Validation loss:2.005, Validation accuracy:24.00%
# Epoch 91: iteration 35/35
# loss:1.644, Epoch accuracy:37.19%, Validation loss:1.996, Validation accuracy:23.33%
# Epoch 92: iteration 35/35
# loss:1.687, Epoch accuracy:34.65%, Validation loss:2.028, Validation accuracy:23.00%
# Epoch 93: iteration 35/35
# loss:1.674, Epoch accuracy:33.86%, Validation loss:2.073, Validation accuracy:23.00%
# Epoch 94: iteration 35/35
# loss:1.654, Epoch accuracy:36.93%, Validation loss:2.045, Validation accuracy:22.33%
# Epoch 95: iteration 35/35
# loss:1.630, Epoch accuracy:37.89%, Validation loss:2.053, Validation accuracy:23.33%
# Epoch 96: iteration 35/35
# loss:1.652, Epoch accuracy:35.18%, Validation loss:2.082, Validation accuracy:24.33%
# Epoch 97: iteration 35/35
# loss:1.680, Epoch accuracy:34.30%, Validation loss:1.991, Validation accuracy:25.67%
# Epoch 98: iteration 35/35
# loss:1.704, Epoch accuracy:33.60%, Validation loss:1.965, Validation accuracy:23.67%
# Epoch 99: iteration 35/35
# loss:1.622, Epoch accuracy:36.14%, Validation loss:1.983, Validation accuracy:25.33%
# Epoch 100: iteration 35/35
# loss:1.655, Epoch accuracy:34.82%, Validation loss:1.986, Validation accuracy:25.00%
# Epoch 101: iteration 35/35
# loss:1.623, Epoch accuracy:36.40%, Validation loss:2.028, Validation accuracy:24.33%
# Epoch 102: iteration 35/35
# loss:1.630, Epoch accuracy:37.11%, Validation loss:2.008, Validation accuracy:26.00%
# Epoch 103: iteration 35/35
# loss:1.644, Epoch accuracy:36.05%, Validation loss:1.958, Validation accuracy:25.67%
# Epoch 104: iteration 35/35
# loss:1.641, Epoch accuracy:36.58%, Validation loss:2.000, Validation accuracy:25.67%
# Epoch 105: iteration 35/35
# loss:1.619, Epoch accuracy:37.89%, Validation loss:1.972, Validation accuracy:24.67%
# Epoch 106: iteration 35/35
# loss:1.598, Epoch accuracy:39.74%, Validation loss:2.031, Validation accuracy:23.00%
# Epoch 107: iteration 35/35
# loss:1.597, Epoch accuracy:37.81%, Validation loss:2.109, Validation accuracy:22.33%
# Epoch 108: iteration 35/35
# loss:1.615, Epoch accuracy:39.82%, Validation loss:2.125, Validation accuracy:22.00%
# Epoch 109: iteration 35/35
# loss:1.576, Epoch accuracy:39.74%, Validation loss:2.111, Validation accuracy:22.33%
# Epoch 110: iteration 35/35
# loss:1.570, Epoch accuracy:39.65%, Validation loss:2.056, Validation accuracy:23.67%
# Epoch 111: iteration 35/35
# loss:1.574, Epoch accuracy:40.18%, Validation loss:2.070, Validation accuracy:23.67%
# Epoch 112: iteration 35/35
# loss:1.581, Epoch accuracy:38.77%, Validation loss:2.074, Validation accuracy:24.67%
# Epoch 113: iteration 35/35
# loss:1.586, Epoch accuracy:39.04%, Validation loss:2.095, Validation accuracy:24.33%
# Epoch 114: iteration 35/35
# loss:1.585, Epoch accuracy:40.09%, Validation loss:2.141, Validation accuracy:23.67%
# Epoch 115: iteration 35/35
# loss:1.568, Epoch accuracy:40.79%, Validation loss:2.197, Validation accuracy:20.33%
# Epoch 116: iteration 35/35
# loss:1.561, Epoch accuracy:40.09%, Validation loss:2.124, Validation accuracy:23.33%
# Epoch 117: iteration 35/35
# loss:1.541, Epoch accuracy:41.84%, Validation loss:2.309, Validation accuracy:22.33%
# Epoch 118: iteration 35/35
# loss:1.573, Epoch accuracy:42.98%, Validation loss:2.190, Validation accuracy:24.00%
# Epoch 119: iteration 35/35
# loss:1.557, Epoch accuracy:41.49%, Validation loss:2.189, Validation accuracy:25.67%
# Epoch 120: iteration 35/35
# loss:1.558, Epoch accuracy:41.05%, Validation loss:2.164, Validation accuracy:21.67%
# Epoch 121: iteration 35/35
# loss:1.565, Epoch accuracy:41.32%, Validation loss:2.234, Validation accuracy:26.67%
# Epoch 122: iteration 35/35
# loss:1.570, Epoch accuracy:41.49%, Validation loss:2.138, Validation accuracy:27.33%
# Epoch 123: iteration 35/35
# loss:1.576, Epoch accuracy:40.88%, Validation loss:2.178, Validation accuracy:24.67%
# Epoch 124: iteration 35/35
# loss:1.538, Epoch accuracy:40.88%, Validation loss:2.151, Validation accuracy:27.00%
# Epoch 125: iteration 35/35
# loss:1.553, Epoch accuracy:40.53%, Validation loss:2.106, Validation accuracy:27.00%
# Epoch 126: iteration 35/35
# loss:1.538, Epoch accuracy:41.49%, Validation loss:2.133, Validation accuracy:23.67%
# Epoch 127: iteration 35/35
# loss:1.508, Epoch accuracy:42.72%, Validation loss:2.055, Validation accuracy:25.67%
# Epoch 128: iteration 35/35
# loss:1.518, Epoch accuracy:41.58%, Validation loss:2.179, Validation accuracy:25.67%
# Epoch 129: iteration 35/35
# loss:1.540, Epoch accuracy:41.93%, Validation loss:2.147, Validation accuracy:25.67%
# Epoch 130: iteration 35/35
# loss:1.529, Epoch accuracy:41.23%, Validation loss:2.171, Validation accuracy:22.67%
# Epoch 131: iteration 35/35
# loss:1.502, Epoch accuracy:43.33%, Validation loss:2.122, Validation accuracy:24.33%
# Epoch 132: iteration 35/35
# loss:1.497, Epoch accuracy:42.37%, Validation loss:2.189, Validation accuracy:23.33%
# Epoch 133: iteration 35/35
# loss:1.514, Epoch accuracy:42.63%, Validation loss:2.132, Validation accuracy:23.33%
# Epoch 134: iteration 35/35
# loss:1.530, Epoch accuracy:41.75%, Validation loss:1.986, Validation accuracy:27.00%
# Epoch 135: iteration 35/35
# loss:1.527, Epoch accuracy:41.40%, Validation loss:2.163, Validation accuracy:22.67%
# Epoch 136: iteration 35/35
# loss:1.488, Epoch accuracy:42.81%, Validation loss:2.151, Validation accuracy:25.00%
# Epoch 137: iteration 35/35
# loss:1.506, Epoch accuracy:42.19%, Validation loss:2.122, Validation accuracy:25.00%
# Epoch 138: iteration 35/35
# loss:1.500, Epoch accuracy:41.84%, Validation loss:2.120, Validation accuracy:24.33%
# Epoch 139: iteration 35/35
# loss:1.505, Epoch accuracy:40.44%, Validation loss:2.150, Validation accuracy:24.33%
# Epoch 140: iteration 35/35
# loss:1.480, Epoch accuracy:42.63%, Validation loss:2.138, Validation accuracy:24.33%
# Epoch 141: iteration 35/35
# loss:1.471, Epoch accuracy:44.65%, Validation loss:2.187, Validation accuracy:24.00%
# Epoch 142: iteration 35/35
# loss:1.466, Epoch accuracy:43.86%, Validation loss:2.168, Validation accuracy:28.00%
# Epoch 143: iteration 35/35
# loss:1.444, Epoch accuracy:44.74%, Validation loss:2.191, Validation accuracy:25.00%
# Epoch 144: iteration 35/35
# loss:1.469, Epoch accuracy:43.77%, Validation loss:2.125, Validation accuracy:24.33%
# Epoch 145: iteration 35/35
# loss:1.449, Epoch accuracy:45.26%, Validation loss:2.207, Validation accuracy:22.67%
# Epoch 146: iteration 35/35
# loss:1.454, Epoch accuracy:44.74%, Validation loss:2.142, Validation accuracy:26.00%
# Epoch 147: iteration 35/35
# loss:1.478, Epoch accuracy:43.60%, Validation loss:1.989, Validation accuracy:26.33%
# Epoch 148: iteration 35/35
# loss:1.400, Epoch accuracy:46.93%, Validation loss:2.300, Validation accuracy:27.67%
# Epoch 149: iteration 35/35
# loss:1.450, Epoch accuracy:45.18%, Validation loss:2.129, Validation accuracy:27.00%
# Epoch 150: iteration 35/35
# loss:1.411, Epoch accuracy:46.75%, Validation loss:2.106, Validation accuracy:26.00%
# Epoch 151: iteration 35/35
# loss:1.392, Epoch accuracy:47.46%, Validation loss:2.299, Validation accuracy:24.33%
# Epoch 152: iteration 35/35
# loss:1.408, Epoch accuracy:46.32%, Validation loss:2.153, Validation accuracy:26.00%
# Epoch 153: iteration 35/35
# loss:1.399, Epoch accuracy:47.46%, Validation loss:2.257, Validation accuracy:29.00%
# Epoch 154: iteration 35/35
# loss:1.421, Epoch accuracy:46.67%, Validation loss:2.130, Validation accuracy:25.67%
# Epoch 155: iteration 35/35
# loss:1.410, Epoch accuracy:47.63%, Validation loss:2.274, Validation accuracy:24.67%
# Epoch 156: iteration 35/35
# loss:1.399, Epoch accuracy:46.14%, Validation loss:2.306, Validation accuracy:26.67%
# Epoch 157: iteration 35/35
# loss:1.432, Epoch accuracy:43.95%, Validation loss:2.177, Validation accuracy:24.67%
# Epoch 158: iteration 35/35
# loss:1.536, Epoch accuracy:40.79%, Validation loss:2.149, Validation accuracy:26.00%
# Epoch 159: iteration 35/35
# loss:1.450, Epoch accuracy:43.86%, Validation loss:2.312, Validation accuracy:24.67%
# Epoch 160: iteration 35/35
# loss:1.469, Epoch accuracy:42.37%, Validation loss:2.101, Validation accuracy:27.67%
# Epoch 161: iteration 35/35
# loss:1.421, Epoch accuracy:44.74%, Validation loss:1.955, Validation accuracy:29.33%
# Epoch 162: iteration 35/35
# loss:1.437, Epoch accuracy:44.30%, Validation loss:2.227, Validation accuracy:24.67%
# Epoch 163: iteration 35/35
# loss:1.386, Epoch accuracy:46.93%, Validation loss:2.046, Validation accuracy:27.67%
# Epoch 164: iteration 35/35
# loss:1.402, Epoch accuracy:48.25%, Validation loss:2.136, Validation accuracy:26.67%
# Epoch 165: iteration 35/35
# loss:1.407, Epoch accuracy:45.26%, Validation loss:2.142, Validation accuracy:29.33%
# Epoch 166: iteration 35/35
# loss:1.398, Epoch accuracy:46.75%, Validation loss:2.182, Validation accuracy:27.67%
# Epoch 167: iteration 35/35
# loss:1.416, Epoch accuracy:45.44%, Validation loss:2.197, Validation accuracy:25.33%
# Epoch 168: iteration 35/35
# loss:1.416, Epoch accuracy:45.88%, Validation loss:2.247, Validation accuracy:25.67%
# Epoch 169: iteration 35/35
# loss:1.417, Epoch accuracy:47.46%, Validation loss:2.153, Validation accuracy:27.67%
# Epoch 170: iteration 35/35
# loss:1.382, Epoch accuracy:47.46%, Validation loss:2.182, Validation accuracy:29.33%
# Epoch 171: iteration 35/35
# loss:1.354, Epoch accuracy:48.42%, Validation loss:2.002, Validation accuracy:29.67%
# Epoch 172: iteration 35/35
# loss:1.384, Epoch accuracy:48.07%, Validation loss:2.222, Validation accuracy:27.67%
# Epoch 173: iteration 35/35
# loss:1.358, Epoch accuracy:45.35%, Validation loss:2.101, Validation accuracy:28.33%
# Epoch 174: iteration 35/35
# loss:1.356, Epoch accuracy:49.65%, Validation loss:2.148, Validation accuracy:29.33%
# Epoch 175: iteration 35/35
# loss:1.345, Epoch accuracy:47.19%, Validation loss:2.130, Validation accuracy:28.67%
# Epoch 176: iteration 35/35
# loss:1.348, Epoch accuracy:48.16%, Validation loss:2.123, Validation accuracy:26.33%
# Epoch 177: iteration 35/35
# loss:1.382, Epoch accuracy:48.33%, Validation loss:2.206, Validation accuracy:28.33%
# Epoch 178: iteration 35/35
# loss:1.346, Epoch accuracy:48.07%, Validation loss:2.131, Validation accuracy:28.33%
# Epoch 179: iteration 35/35
# loss:1.302, Epoch accuracy:50.09%, Validation loss:2.157, Validation accuracy:27.67%
# Epoch 180: iteration 35/35
# loss:1.328, Epoch accuracy:50.79%, Validation loss:2.446, Validation accuracy:25.00%
# Epoch 181: iteration 35/35
# loss:1.369, Epoch accuracy:49.47%, Validation loss:1.968, Validation accuracy:30.67%
# Epoch 182: iteration 35/35
# loss:1.633, Epoch accuracy:37.63%, Validation loss:2.014, Validation accuracy:29.33%
# Epoch 183: iteration 35/35
# loss:1.515, Epoch accuracy:39.74%, Validation loss:2.277, Validation accuracy:28.33%
# Epoch 184: iteration 35/35
# loss:1.508, Epoch accuracy:39.47%, Validation loss:2.392, Validation accuracy:27.33%
# Epoch 185: iteration 35/35
# loss:1.474, Epoch accuracy:41.75%, Validation loss:2.204, Validation accuracy:29.33%
# Epoch 186: iteration 35/35
# loss:1.419, Epoch accuracy:45.53%, Validation loss:2.319, Validation accuracy:28.00%
# Epoch 187: iteration 35/35
# loss:1.383, Epoch accuracy:47.02%, Validation loss:2.260, Validation accuracy:26.67%
# Epoch 188: iteration 35/35
# loss:1.396, Epoch accuracy:45.00%, Validation loss:2.184, Validation accuracy:28.00%
# Epoch 189: iteration 35/35
# loss:1.357, Epoch accuracy:47.72%, Validation loss:2.337, Validation accuracy:24.67%
# Epoch 190: iteration 35/35
# loss:1.352, Epoch accuracy:47.19%, Validation loss:2.272, Validation accuracy:25.67%
# Epoch 191: iteration 35/35
# loss:1.410, Epoch accuracy:45.79%, Validation loss:2.144, Validation accuracy:28.67%
# Epoch 192: iteration 35/35
# loss:1.432, Epoch accuracy:46.40%, Validation loss:2.239, Validation accuracy:25.67%
# Epoch 193: iteration 35/35
# loss:1.416, Epoch accuracy:46.05%, Validation loss:2.237, Validation accuracy:26.33%
# Epoch 194: iteration 35/35
# loss:1.365, Epoch accuracy:48.16%, Validation loss:2.291, Validation accuracy:26.00%
# Epoch 195: iteration 35/35
# loss:1.351, Epoch accuracy:49.21%, Validation loss:2.285, Validation accuracy:26.67%
# Epoch 196: iteration 35/35
# loss:1.337, Epoch accuracy:48.60%, Validation loss:2.421, Validation accuracy:25.33%
# Epoch 197: iteration 35/35
# loss:1.314, Epoch accuracy:47.81%, Validation loss:2.360, Validation accuracy:28.33%
# Epoch 198: iteration 35/35
# loss:1.278, Epoch accuracy:50.18%, Validation loss:2.406, Validation accuracy:26.67%
# Epoch 199: iteration 35/35
# loss:1.379, Epoch accuracy:46.67%, Validation loss:2.556, Validation accuracy:27.00%
# Epoch 200: iteration 35/35
# loss:1.442, Epoch accuracy:42.02%, Validation loss:2.447, Validation accuracy:24.33%
# Epoch 201: iteration 35/35
# loss:1.415, Epoch accuracy:45.79%, Validation loss:2.471, Validation accuracy:26.33%
# Epoch 202: iteration 35/35
# loss:1.383, Epoch accuracy:47.28%, Validation loss:2.421, Validation accuracy:26.67%
# Epoch 203: iteration 35/35
# loss:1.307, Epoch accuracy:49.56%, Validation loss:2.481, Validation accuracy:25.00%
# Epoch 204: iteration 35/35
# loss:1.330, Epoch accuracy:48.60%, Validation loss:2.258, Validation accuracy:27.33%
# Epoch 205: iteration 35/35
# loss:1.319, Epoch accuracy:49.39%, Validation loss:2.329, Validation accuracy:28.67%
# Epoch 206: iteration 35/35
# loss:1.299, Epoch accuracy:51.23%, Validation loss:2.326, Validation accuracy:27.00%
# Epoch 207: iteration 35/35
# loss:1.264, Epoch accuracy:53.16%, Validation loss:2.503, Validation accuracy:26.67%
# Epoch 208: iteration 35/35
# loss:1.245, Epoch accuracy:51.75%, Validation loss:2.433, Validation accuracy:26.33%
# Epoch 209: iteration 35/35
# loss:1.250, Epoch accuracy:50.79%, Validation loss:2.515, Validation accuracy:26.00%
# Epoch 210: iteration 35/35
# loss:1.262, Epoch accuracy:51.14%, Validation loss:2.200, Validation accuracy:31.33%
# Epoch 211: iteration 35/35
# loss:1.255, Epoch accuracy:50.26%, Validation loss:2.647, Validation accuracy:28.00%
# Epoch 212: iteration 35/35
# loss:1.300, Epoch accuracy:50.26%, Validation loss:2.404, Validation accuracy:26.33%
# Epoch 213: iteration 35/35
# loss:1.260, Epoch accuracy:51.75%, Validation loss:2.302, Validation accuracy:27.33%
# Epoch 214: iteration 35/35
# loss:1.263, Epoch accuracy:51.32%, Validation loss:2.447, Validation accuracy:26.67%
# Epoch 215: iteration 35/35
# loss:1.259, Epoch accuracy:52.37%, Validation loss:2.263, Validation accuracy:29.33%
# Epoch 216: iteration 35/35
# loss:1.265, Epoch accuracy:51.67%, Validation loss:2.399, Validation accuracy:26.67%
# Epoch 217: iteration 35/35
# loss:1.220, Epoch accuracy:54.30%, Validation loss:2.468, Validation accuracy:25.67%
# Epoch 218: iteration 35/35
# loss:1.222, Epoch accuracy:51.67%, Validation loss:2.291, Validation accuracy:27.67%
# Epoch 219: iteration 35/35
# loss:1.203, Epoch accuracy:53.68%, Validation loss:2.255, Validation accuracy:26.33%
# Epoch 220: iteration 35/35
# loss:1.219, Epoch accuracy:51.93%, Validation loss:2.328, Validation accuracy:27.00%
# Epoch 221: iteration 35/35
# loss:1.190, Epoch accuracy:53.86%, Validation loss:2.600, Validation accuracy:26.67%
# Epoch 222: iteration 35/35
# loss:1.194, Epoch accuracy:54.65%, Validation loss:2.485, Validation accuracy:28.00%
# Epoch 223: iteration 35/35
# loss:1.240, Epoch accuracy:52.19%, Validation loss:2.484, Validation accuracy:26.67%
# Epoch 224: iteration 35/35
# loss:1.180, Epoch accuracy:53.07%, Validation loss:2.676, Validation accuracy:25.00%
# Epoch 225: iteration 35/35
# loss:1.192, Epoch accuracy:54.30%, Validation loss:2.534, Validation accuracy:27.33%
# Epoch 226: iteration 35/35
# loss:1.181, Epoch accuracy:54.82%, Validation loss:2.593, Validation accuracy:26.67%
# Epoch 227: iteration 35/35
# loss:1.147, Epoch accuracy:56.05%, Validation loss:2.333, Validation accuracy:28.67%
# Epoch 228: iteration 35/35
# loss:1.157, Epoch accuracy:55.70%, Validation loss:2.323, Validation accuracy:28.33%
# Epoch 229: iteration 35/35
# loss:1.123, Epoch accuracy:55.79%, Validation loss:2.322, Validation accuracy:29.00%
# Epoch 230: iteration 35/35
# loss:1.152, Epoch accuracy:54.82%, Validation loss:2.361, Validation accuracy:29.00%
# Epoch 231: iteration 35/35
# loss:1.150, Epoch accuracy:56.58%, Validation loss:2.358, Validation accuracy:29.00%
# Epoch 232: iteration 35/35
# loss:1.179, Epoch accuracy:54.74%, Validation loss:2.336, Validation accuracy:26.67%
# Epoch 233: iteration 35/35
# loss:1.150, Epoch accuracy:54.30%, Validation loss:2.476, Validation accuracy:27.67%
# Epoch 234: iteration 35/35
# loss:1.123, Epoch accuracy:57.37%, Validation loss:2.588, Validation accuracy:28.33%
# Epoch 235: iteration 35/35
# loss:1.121, Epoch accuracy:57.11%, Validation loss:2.360, Validation accuracy:29.67%
# Epoch 236: iteration 35/35
# loss:1.142, Epoch accuracy:56.84%, Validation loss:2.428, Validation accuracy:26.67%
# Epoch 237: iteration 35/35
# loss:1.111, Epoch accuracy:57.37%, Validation loss:2.667, Validation accuracy:25.67%
# Epoch 238: iteration 35/35
# loss:1.071, Epoch accuracy:59.12%, Validation loss:2.300, Validation accuracy:29.33%
# Epoch 239: iteration 35/35
# loss:1.098, Epoch accuracy:56.84%, Validation loss:2.534, Validation accuracy:27.67%
# Epoch 240: iteration 35/35
# loss:1.083, Epoch accuracy:59.12%, Validation loss:2.755, Validation accuracy:27.33%
# Epoch 241: iteration 35/35
# loss:1.134, Epoch accuracy:56.23%, Validation loss:2.504, Validation accuracy:28.67%
# Epoch 242: iteration 35/35
# loss:1.113, Epoch accuracy:56.75%, Validation loss:2.715, Validation accuracy:29.00%
# Epoch 243: iteration 35/35
# loss:1.125, Epoch accuracy:58.33%, Validation loss:2.466, Validation accuracy:28.33%
# Epoch 244: iteration 35/35
# loss:1.068, Epoch accuracy:59.74%, Validation loss:2.460, Validation accuracy:28.00%
# Epoch 245: iteration 35/35
# loss:1.056, Epoch accuracy:61.32%, Validation loss:2.608, Validation accuracy:28.00%
# Epoch 246: iteration 35/35
# loss:1.042, Epoch accuracy:59.74%, Validation loss:2.515, Validation accuracy:28.67%
# Epoch 247: iteration 35/35
# loss:1.067, Epoch accuracy:59.04%, Validation loss:2.638, Validation accuracy:25.67%
# Epoch 248: iteration 35/35
# loss:1.039, Epoch accuracy:61.14%, Validation loss:2.594, Validation accuracy:26.00%
# Epoch 249: iteration 35/35
# loss:1.001, Epoch accuracy:61.67%, Validation loss:2.699, Validation accuracy:27.00%
# Epoch 250: iteration 35/35
# loss:1.074, Epoch accuracy:58.68%, Validation loss:2.536, Validation accuracy:28.00%
# Epoch 251: iteration 35/35
# loss:1.026, Epoch accuracy:61.84%, Validation loss:2.573, Validation accuracy:30.00%
# Epoch 252: iteration 35/35
# loss:0.990, Epoch accuracy:62.11%, Validation loss:2.536, Validation accuracy:25.67%
# Epoch 253: iteration 35/35
# loss:0.997, Epoch accuracy:60.53%, Validation loss:2.840, Validation accuracy:25.67%
# Epoch 254: iteration 35/35
# loss:0.956, Epoch accuracy:64.91%, Validation loss:2.745, Validation accuracy:26.00%
# Epoch 255: iteration 35/35
# loss:1.004, Epoch accuracy:59.82%, Validation loss:2.681, Validation accuracy:29.67%
# Epoch 256: iteration 35/35
# loss:0.915, Epoch accuracy:66.05%, Validation loss:2.760, Validation accuracy:28.67%
# Epoch 257: iteration 35/35
# loss:0.948, Epoch accuracy:64.39%, Validation loss:2.592, Validation accuracy:28.33%
# Epoch 258: iteration 35/35
# loss:0.913, Epoch accuracy:66.05%, Validation loss:2.610, Validation accuracy:27.33%
# Epoch 259: iteration 35/35
# loss:0.904, Epoch accuracy:64.74%, Validation loss:2.876, Validation accuracy:26.33%
# Epoch 260: iteration 35/35
# loss:0.899, Epoch accuracy:64.30%, Validation loss:2.904, Validation accuracy:26.00%
# Epoch 261: iteration 35/35
# loss:0.867, Epoch accuracy:65.88%, Validation loss:2.798, Validation accuracy:27.33%
# Epoch 262: iteration 35/35
# loss:0.856, Epoch accuracy:68.07%, Validation loss:2.880, Validation accuracy:29.00%
# Epoch 263: iteration 35/35
# loss:0.954, Epoch accuracy:61.93%, Validation loss:2.628, Validation accuracy:27.67%
# Epoch 264: iteration 35/35
# loss:0.847, Epoch accuracy:68.68%, Validation loss:2.855, Validation accuracy:27.00%
# Epoch 265: iteration 35/35
# loss:0.869, Epoch accuracy:65.18%, Validation loss:2.807, Validation accuracy:28.33%
# Epoch 266: iteration 35/35
# loss:0.885, Epoch accuracy:67.02%, Validation loss:2.830, Validation accuracy:27.33%
# Epoch 267: iteration 35/35
# loss:0.830, Epoch accuracy:68.07%, Validation loss:2.905, Validation accuracy:28.67%
# Epoch 268: iteration 35/35
# loss:0.824, Epoch accuracy:68.68%, Validation loss:2.868, Validation accuracy:29.00%
# Epoch 269: iteration 35/35
# loss:0.863, Epoch accuracy:65.96%, Validation loss:3.098, Validation accuracy:26.33%
# Epoch 270: iteration 35/35
# loss:0.828, Epoch accuracy:67.37%, Validation loss:2.984, Validation accuracy:28.67%
# Epoch 271: iteration 35/35
# loss:0.797, Epoch accuracy:69.39%, Validation loss:3.314, Validation accuracy:25.33%
# Epoch 272: iteration 35/35
# loss:0.801, Epoch accuracy:69.30%, Validation loss:3.147, Validation accuracy:26.33%
# Epoch 273: iteration 35/35
# loss:0.754, Epoch accuracy:71.14%, Validation loss:3.236, Validation accuracy:28.67%
# Epoch 274: iteration 35/35
# loss:0.762, Epoch accuracy:70.44%, Validation loss:2.816, Validation accuracy:29.33%
# Epoch 275: iteration 35/35
# loss:0.775, Epoch accuracy:69.56%, Validation loss:3.096, Validation accuracy:31.00%
# Epoch 276: iteration 35/35
# loss:0.764, Epoch accuracy:71.32%, Validation loss:3.124, Validation accuracy:28.00%
# Epoch 277: iteration 35/35
# loss:0.713, Epoch accuracy:72.72%, Validation loss:3.075, Validation accuracy:29.33%
# Epoch 278: iteration 35/35
# loss:0.724, Epoch accuracy:72.19%, Validation loss:3.108, Validation accuracy:29.33%
# Epoch 279: iteration 35/35
# loss:0.703, Epoch accuracy:73.60%, Validation loss:3.081, Validation accuracy:29.67%
# Epoch 280: iteration 35/35
# loss:0.665, Epoch accuracy:73.77%, Validation loss:3.338, Validation accuracy:28.00%
# Epoch 281: iteration 35/35
# loss:0.669, Epoch accuracy:74.21%, Validation loss:3.308, Validation accuracy:28.00%
# Epoch 282: iteration 35/35
# loss:0.697, Epoch accuracy:72.19%, Validation loss:2.989, Validation accuracy:29.67%
# Epoch 283: iteration 35/35
# loss:0.680, Epoch accuracy:74.04%, Validation loss:3.482, Validation accuracy:25.00%
# Epoch 284: iteration 35/35
# loss:0.719, Epoch accuracy:71.75%, Validation loss:3.374, Validation accuracy:25.33%
# Epoch 285: iteration 35/35
# loss:0.677, Epoch accuracy:74.39%, Validation loss:3.479, Validation accuracy:29.67%
# Epoch 286: iteration 35/35
# loss:0.693, Epoch accuracy:71.32%, Validation loss:3.620, Validation accuracy:29.00%
# Epoch 287: iteration 35/35
# loss:0.657, Epoch accuracy:72.72%, Validation loss:3.591, Validation accuracy:28.00%
# Epoch 288: iteration 35/35
# loss:0.686, Epoch accuracy:72.63%, Validation loss:2.966, Validation accuracy:32.00%
# Epoch 289: iteration 35/35
# loss:0.690, Epoch accuracy:73.33%, Validation loss:3.295, Validation accuracy:29.67%
# Epoch 290: iteration 35/35
# loss:0.629, Epoch accuracy:74.39%, Validation loss:3.313, Validation accuracy:28.00%
# Epoch 291: iteration 35/35
# loss:0.593, Epoch accuracy:77.63%, Validation loss:3.422, Validation accuracy:29.33%
# Epoch 292: iteration 35/35
# loss:0.622, Epoch accuracy:76.84%, Validation loss:3.517, Validation accuracy:28.33%
# Epoch 293: iteration 35/35
# loss:0.592, Epoch accuracy:76.14%, Validation loss:3.596, Validation accuracy:30.00%
# Epoch 294: iteration 35/35
# loss:0.639, Epoch accuracy:75.35%, Validation loss:3.261, Validation accuracy:31.33%
# Epoch 295: iteration 35/35
# loss:0.561, Epoch accuracy:78.16%, Validation loss:3.395, Validation accuracy:32.00%
# Epoch 296: iteration 35/35
# loss:0.545, Epoch accuracy:79.12%, Validation loss:3.437, Validation accuracy:30.33%
# Epoch 297: iteration 35/35
# loss:0.556, Epoch accuracy:77.89%, Validation loss:3.833, Validation accuracy:28.00%
# Epoch 298: iteration 35/35
# loss:0.585, Epoch accuracy:77.19%, Validation loss:3.592, Validation accuracy:29.33%
# Epoch 299: iteration 35/35
# loss:0.542, Epoch accuracy:78.33%, Validation loss:3.501, Validation accuracy:28.00%
#
#
# [*] done !
# [*] Best training loss - 0.5415458294383267
# [*] Best validation loss - 1.8246419429779053
# A Jupyter Widget
# Epoch 0: iteration 35/35
# loss:2.045, Epoch accuracy:13.25%, Validation loss:2.079, Validation accuracy:13.33%
# Epoch 1: iteration 35/35
# loss:2.036, Epoch accuracy:13.25%, Validation loss:2.066, Validation accuracy:13.33%
# Epoch 2: iteration 35/35
# loss:2.026, Epoch accuracy:12.54%, Validation loss:2.057, Validation accuracy:13.67%
# Epoch 3: iteration 35/35
# loss:2.021, Epoch accuracy:14.12%, Validation loss:2.045, Validation accuracy:21.33%
# Epoch 4: iteration 35/35
# loss:2.024, Epoch accuracy:13.07%, Validation loss:2.059, Validation accuracy:13.33%
# Epoch 5: iteration 35/35
# loss:2.019, Epoch accuracy:17.02%, Validation loss:2.032, Validation accuracy:18.33%
# Epoch 6: iteration 35/35
# loss:2.019, Epoch accuracy:15.70%, Validation loss:2.062, Validation accuracy:12.67%
# Epoch 7: iteration 35/35
# loss:2.024, Epoch accuracy:16.05%, Validation loss:2.044, Validation accuracy:21.00%
# Epoch 8: iteration 35/35
# loss:2.004, Epoch accuracy:18.60%, Validation loss:2.001, Validation accuracy:26.67%
# Epoch 9: iteration 35/35
# loss:1.964, Epoch accuracy:23.95%, Validation loss:1.939, Validation accuracy:28.00%
# Epoch 10: iteration 35/35
# loss:1.907, Epoch accuracy:27.37%, Validation loss:1.893, Validation accuracy:29.00%
# Epoch 11: iteration 35/35
# loss:1.869, Epoch accuracy:26.75%, Validation loss:1.891, Validation accuracy:25.33%
# Epoch 12: iteration 35/35
# loss:1.847, Epoch accuracy:26.67%, Validation loss:1.958, Validation accuracy:21.67%
# Epoch 13: iteration 35/35
# loss:1.791, Epoch accuracy:30.18%, Validation loss:1.926, Validation accuracy:24.67%
# Epoch 14: iteration 35/35
# loss:1.797, Epoch accuracy:29.30%, Validation loss:1.801, Validation accuracy:27.33%
# Epoch 15: iteration 35/35
# loss:1.801, Epoch accuracy:29.56%, Validation loss:2.067, Validation accuracy:23.33%
# Epoch 16: iteration 35/35
# loss:1.940, Epoch accuracy:23.68%, Validation loss:1.868, Validation accuracy:27.33%
# Epoch 17: iteration 35/35
# loss:1.866, Epoch accuracy:27.28%, Validation loss:1.966, Validation accuracy:23.67%
# Epoch 18: iteration 35/35
# loss:1.856, Epoch accuracy:27.81%, Validation loss:1.871, Validation accuracy:30.00%
# Epoch 19: iteration 35/35
# loss:1.834, Epoch accuracy:27.89%, Validation loss:1.850, Validation accuracy:29.33%
# Epoch 20: iteration 35/35
# loss:1.836, Epoch accuracy:27.28%, Validation loss:1.882, Validation accuracy:26.67%
# Epoch 21: iteration 35/35
# loss:1.904, Epoch accuracy:23.25%, Validation loss:2.077, Validation accuracy:20.33%
# Epoch 22: iteration 35/35
# loss:1.948, Epoch accuracy:21.23%, Validation loss:1.993, Validation accuracy:21.67%
# Epoch 23: iteration 35/35
# loss:1.915, Epoch accuracy:23.25%, Validation loss:1.940, Validation accuracy:26.67%
# Epoch 24: iteration 35/35
# loss:1.897, Epoch accuracy:25.53%, Validation loss:1.926, Validation accuracy:24.67%
# Epoch 25: iteration 35/35
# loss:1.863, Epoch accuracy:27.37%, Validation loss:1.903, Validation accuracy:29.33%
# Epoch 26: iteration 35/35
# loss:1.866, Epoch accuracy:26.67%, Validation loss:1.806, Validation accuracy:33.00%
# Epoch 27: iteration 35/35
# loss:1.862, Epoch accuracy:27.98%, Validation loss:1.894, Validation accuracy:26.33%
# Epoch 28: iteration 35/35
# loss:1.898, Epoch accuracy:26.05%, Validation loss:2.042, Validation accuracy:24.67%
# Epoch 29: iteration 35/35
# loss:1.891, Epoch accuracy:23.95%, Validation loss:2.238, Validation accuracy:13.00%
# Epoch 30: iteration 35/35
# loss:2.047, Epoch accuracy:16.05%, Validation loss:2.067, Validation accuracy:13.33%
# Epoch 31: iteration 35/35
# loss:2.011, Epoch accuracy:15.96%, Validation loss:2.055, Validation accuracy:15.67%
# Epoch 32: iteration 35/35
# loss:1.982, Epoch accuracy:18.60%, Validation loss:2.028, Validation accuracy:17.67%
# Epoch 33: iteration 35/35
# loss:1.978, Epoch accuracy:19.30%, Validation loss:2.040, Validation accuracy:17.67%
# Epoch 34: iteration 35/35
# loss:1.996, Epoch accuracy:18.07%, Validation loss:1.959, Validation accuracy:21.00%
# Epoch 35: iteration 35/35
# loss:1.961, Epoch accuracy:18.25%, Validation loss:2.056, Validation accuracy:18.33%
# Epoch 36: iteration 35/35
# loss:2.009, Epoch accuracy:18.16%, Validation loss:2.094, Validation accuracy:13.33%
# Epoch 37: iteration 35/35
# loss:2.023, Epoch accuracy:15.53%, Validation loss:2.063, Validation accuracy:13.33%
# Epoch 38: iteration 35/35
# loss:2.009, Epoch accuracy:15.79%, Validation loss:2.108, Validation accuracy:13.67%
# Epoch 39: iteration 35/35
# loss:2.003, Epoch accuracy:15.79%, Validation loss:2.102, Validation accuracy:15.67%
# Epoch 40: iteration 35/35
# loss:1.995, Epoch accuracy:18.25%, Validation loss:2.183, Validation accuracy:14.67%
# Epoch 41: iteration 35/35
# loss:2.004, Epoch accuracy:17.37%, Validation loss:2.055, Validation accuracy:15.67%
# Epoch 42: iteration 35/35
# loss:1.976, Epoch accuracy:18.95%, Validation loss:1.966, Validation accuracy:20.00%
# Epoch 43: iteration 35/35
# loss:1.946, Epoch accuracy:21.58%, Validation loss:1.941, Validation accuracy:23.33%
# Epoch 44: iteration 35/35
# loss:1.939, Epoch accuracy:20.88%, Validation loss:1.942, Validation accuracy:23.33%
# Epoch 45: iteration 35/35
# loss:1.889, Epoch accuracy:22.98%, Validation loss:1.928, Validation accuracy:26.33%
# Epoch 46: iteration 35/35
# loss:1.865, Epoch accuracy:24.74%, Validation loss:2.010, Validation accuracy:26.33%
# Epoch 47: iteration 35/35
# loss:1.831, Epoch accuracy:27.89%, Validation loss:1.967, Validation accuracy:24.00%
# Epoch 48: iteration 35/35
# loss:1.862, Epoch accuracy:25.35%, Validation loss:1.944, Validation accuracy:24.67%
# Epoch 49: iteration 35/35
# loss:1.837, Epoch accuracy:25.44%, Validation loss:1.843, Validation accuracy:29.33%
# Epoch 50: iteration 35/35
# loss:1.795, Epoch accuracy:27.54%, Validation loss:2.011, Validation accuracy:21.33%
# Epoch 51: iteration 35/35
# loss:1.811, Epoch accuracy:28.68%, Validation loss:1.959, Validation accuracy:24.33%
# Epoch 52: iteration 35/35
# loss:1.860, Epoch accuracy:26.84%, Validation loss:1.871, Validation accuracy:28.67%
# Epoch 53: iteration 35/35
# loss:1.846, Epoch accuracy:28.16%, Validation loss:2.042, Validation accuracy:23.33%
# Epoch 54: iteration 35/35
# loss:1.806, Epoch accuracy:28.25%, Validation loss:1.904, Validation accuracy:26.67%
# Epoch 55: iteration 35/35
# loss:1.832, Epoch accuracy:26.93%, Validation loss:1.857, Validation accuracy:27.33%
# Epoch 56: iteration 35/35
# loss:1.830, Epoch accuracy:28.95%, Validation loss:1.879, Validation accuracy:27.67%
# Epoch 57: iteration 35/35
# loss:1.824, Epoch accuracy:27.89%, Validation loss:2.136, Validation accuracy:23.67%
# Epoch 58: iteration 35/35
# loss:1.783, Epoch accuracy:30.44%, Validation loss:1.951, Validation accuracy:30.00%
# Epoch 59: iteration 35/35
# loss:1.795, Epoch accuracy:26.75%, Validation loss:1.947, Validation accuracy:27.33%
# Epoch 60: iteration 35/35
# loss:1.811, Epoch accuracy:26.14%, Validation loss:1.997, Validation accuracy:28.67%
# Epoch 61: iteration 35/35
# loss:1.795, Epoch accuracy:25.96%, Validation loss:1.989, Validation accuracy:28.33%
# Epoch 62: iteration 35/35
# loss:1.818, Epoch accuracy:27.02%, Validation loss:1.940, Validation accuracy:28.33%
# Epoch 63: iteration 35/35
# loss:1.817, Epoch accuracy:26.93%, Validation loss:1.947, Validation accuracy:25.67%
# Epoch 64: iteration 35/35
# loss:1.778, Epoch accuracy:28.33%, Validation loss:1.940, Validation accuracy:28.00%
# Epoch 65: iteration 35/35
# loss:1.734, Epoch accuracy:31.14%, Validation loss:1.908, Validation accuracy:28.33%
# Epoch 66: iteration 35/35
# loss:1.733, Epoch accuracy:31.32%, Validation loss:1.948, Validation accuracy:29.33%
# Epoch 67: iteration 35/35
# loss:1.732, Epoch accuracy:30.70%, Validation loss:1.985, Validation accuracy:30.00%
# Epoch 68: iteration 35/35
# loss:1.745, Epoch accuracy:30.88%, Validation loss:1.960, Validation accuracy:29.00%
# Epoch 69: iteration 35/35
# loss:1.692, Epoch accuracy:33.16%, Validation loss:1.982, Validation accuracy:27.67%
# Epoch 70: iteration 35/35
# loss:1.714, Epoch accuracy:31.49%, Validation loss:2.017, Validation accuracy:26.33%
# Epoch 71: iteration 35/35
# loss:1.670, Epoch accuracy:33.86%, Validation loss:2.050, Validation accuracy:27.33%
# Epoch 72: iteration 35/35
# loss:1.662, Epoch accuracy:32.28%, Validation loss:1.960, Validation accuracy:27.67%
# Epoch 73: iteration 35/35
# loss:1.640, Epoch accuracy:33.60%, Validation loss:2.041, Validation accuracy:26.67%
# Epoch 74: iteration 35/35
# loss:1.653, Epoch accuracy:33.77%, Validation loss:2.006, Validation accuracy:27.33%
# Epoch 75: iteration 35/35
# loss:1.645, Epoch accuracy:34.74%, Validation loss:1.985, Validation accuracy:29.00%
# Epoch 76: iteration 35/35
# loss:1.647, Epoch accuracy:34.47%, Validation loss:1.924, Validation accuracy:29.67%
# Epoch 77: iteration 35/35
# loss:1.665, Epoch accuracy:34.12%, Validation loss:1.954, Validation accuracy:28.67%
# Epoch 78: iteration 35/35
# loss:1.644, Epoch accuracy:35.79%, Validation loss:2.023, Validation accuracy:31.00%
# Epoch 79: iteration 35/35
# loss:1.703, Epoch accuracy:32.02%, Validation loss:2.039, Validation accuracy:30.00%
# Epoch 80: iteration 35/35
# loss:1.650, Epoch accuracy:34.65%, Validation loss:1.990, Validation accuracy:30.00%
# Epoch 81: iteration 35/35
# loss:1.676, Epoch accuracy:33.33%, Validation loss:2.056, Validation accuracy:28.00%
# Epoch 82: iteration 35/35
# loss:1.677, Epoch accuracy:32.72%, Validation loss:1.891, Validation accuracy:29.00%
# Epoch 83: iteration 35/35
# loss:1.671, Epoch accuracy:33.77%, Validation loss:1.949, Validation accuracy:29.67%
# Epoch 84: iteration 35/35
# loss:1.667, Epoch accuracy:35.00%, Validation loss:1.972, Validation accuracy:29.00%
# Epoch 85: iteration 35/35
# loss:1.702, Epoch accuracy:33.77%, Validation loss:2.035, Validation accuracy:32.00%
# Epoch 86: iteration 35/35
# loss:1.730, Epoch accuracy:30.70%, Validation loss:2.063, Validation accuracy:28.67%
# Epoch 87: iteration 35/35
# loss:1.688, Epoch accuracy:32.37%, Validation loss:1.866, Validation accuracy:27.67%
# Epoch 88: iteration 35/35
# loss:1.750, Epoch accuracy:28.95%, Validation loss:1.985, Validation accuracy:25.33%
# Epoch 89: iteration 35/35
# loss:1.716, Epoch accuracy:30.26%, Validation loss:2.234, Validation accuracy:24.00%
# Epoch 90: iteration 35/35
# loss:1.780, Epoch accuracy:28.42%, Validation loss:2.107, Validation accuracy:25.00%
# Epoch 91: iteration 35/35
# loss:1.782, Epoch accuracy:27.19%, Validation loss:2.075, Validation accuracy:26.33%
# Epoch 92: iteration 35/35
# loss:1.805, Epoch accuracy:24.91%, Validation loss:1.983, Validation accuracy:28.00%
# Epoch 93: iteration 35/35
# loss:1.804, Epoch accuracy:27.63%, Validation loss:1.970, Validation accuracy:26.67%
# Epoch 94: iteration 35/35
# loss:1.716, Epoch accuracy:30.79%, Validation loss:2.187, Validation accuracy:21.67%
# Epoch 95: iteration 35/35
# loss:1.743, Epoch accuracy:29.47%, Validation loss:2.077, Validation accuracy:22.33%
# Epoch 96: iteration 35/35
# loss:1.724, Epoch accuracy:31.93%, Validation loss:2.013, Validation accuracy:24.33%
# Epoch 97: iteration 35/35
# loss:1.706, Epoch accuracy:30.18%, Validation loss:2.049, Validation accuracy:24.33%
# Epoch 98: iteration 35/35
# loss:1.652, Epoch accuracy:34.65%, Validation loss:2.078, Validation accuracy:24.33%
# Epoch 99: iteration 35/35
# loss:1.645, Epoch accuracy:34.74%, Validation loss:2.037, Validation accuracy:28.00%
# Epoch 100: iteration 35/35
# loss:1.623, Epoch accuracy:34.21%, Validation loss:2.345, Validation accuracy:26.00%
# Epoch 101: iteration 35/35
# loss:1.670, Epoch accuracy:34.04%, Validation loss:2.301, Validation accuracy:26.00%
# Epoch 102: iteration 35/35
# loss:1.642, Epoch accuracy:32.37%, Validation loss:2.220, Validation accuracy:26.00%
# Epoch 103: iteration 35/35
# loss:1.690, Epoch accuracy:31.58%, Validation loss:2.125, Validation accuracy:26.67%
# Epoch 104: iteration 35/35
# loss:1.701, Epoch accuracy:32.46%, Validation loss:2.064, Validation accuracy:27.33%
# Epoch 105: iteration 35/35
# loss:1.719, Epoch accuracy:30.79%, Validation loss:2.123, Validation accuracy:23.33%
# Epoch 106: iteration 35/35
# loss:1.665, Epoch accuracy:34.47%, Validation loss:2.233, Validation accuracy:26.67%
# Epoch 107: iteration 35/35
# loss:1.655, Epoch accuracy:34.04%, Validation loss:2.046, Validation accuracy:26.67%
# Epoch 108: iteration 35/35
# loss:1.626, Epoch accuracy:35.18%, Validation loss:2.046, Validation accuracy:28.00%
# Epoch 109: iteration 35/35
# loss:1.619, Epoch accuracy:36.05%, Validation loss:2.043, Validation accuracy:29.67%
# Epoch 110: iteration 35/35
# loss:1.611, Epoch accuracy:36.84%, Validation loss:2.001, Validation accuracy:29.33%
# Epoch 111: iteration 35/35
# loss:1.633, Epoch accuracy:33.33%, Validation loss:2.051, Validation accuracy:26.67%
# Epoch 112: iteration 35/35
# loss:1.674, Epoch accuracy:34.12%, Validation loss:2.232, Validation accuracy:26.00%
# Epoch 113: iteration 35/35
# loss:1.671, Epoch accuracy:33.68%, Validation loss:2.080, Validation accuracy:26.33%
# Epoch 114: iteration 35/35
# loss:1.664, Epoch accuracy:33.25%, Validation loss:2.104, Validation accuracy:25.67%
# Epoch 115: iteration 35/35
# loss:1.684, Epoch accuracy:32.54%, Validation loss:2.043, Validation accuracy:25.00%
# Epoch 116: iteration 35/35
# loss:1.691, Epoch accuracy:34.74%, Validation loss:2.287, Validation accuracy:25.00%
# Epoch 117: iteration 35/35
# loss:1.699, Epoch accuracy:32.11%, Validation loss:2.187, Validation accuracy:24.00%
# Epoch 118: iteration 35/35
# loss:1.672, Epoch accuracy:33.86%, Validation loss:2.148, Validation accuracy:24.33%
# Epoch 119: iteration 35/35
# loss:1.637, Epoch accuracy:34.12%, Validation loss:2.096, Validation accuracy:28.67%
# Epoch 120: iteration 35/35
# loss:1.687, Epoch accuracy:32.98%, Validation loss:2.517, Validation accuracy:24.67%
# Epoch 121: iteration 35/35
# loss:1.743, Epoch accuracy:31.67%, Validation loss:2.138, Validation accuracy:25.67%
# Epoch 122: iteration 35/35
# loss:1.762, Epoch accuracy:31.32%, Validation loss:2.125, Validation accuracy:26.67%
# Epoch 123: iteration 35/35
# loss:1.730, Epoch accuracy:31.14%, Validation loss:2.133, Validation accuracy:26.67%
# Epoch 124: iteration 35/35
# loss:1.699, Epoch accuracy:32.02%, Validation loss:2.190, Validation accuracy:29.67%
# Epoch 125: iteration 35/35
# loss:1.677, Epoch accuracy:32.37%, Validation loss:2.047, Validation accuracy:26.67%
# Epoch 126: iteration 35/35
# loss:1.679, Epoch accuracy:31.67%, Validation loss:2.262, Validation accuracy:24.33%
# Epoch 127: iteration 35/35
# loss:1.679, Epoch accuracy:33.16%, Validation loss:2.017, Validation accuracy:28.67%
# Epoch 128: iteration 35/35
# ...
# loss:0.841, Epoch accuracy:68.25%, Validation loss:2.435, Validation accuracy:32.67%
# Epoch 279: iteration 35/35
# loss:0.834, Epoch accuracy:68.68%, Validation loss:2.439, Validation accuracy:36.00%
# Epoch 280: iteration 35/35
# loss:0.828, Epoch accuracy:68.51%, Validation loss:2.419, Validation accuracy:37.00%
# Epoch 281: iteration 35/35
# loss:0.803, Epoch accuracy:70.35%, Validation loss:2.492, Validation accuracy:34.67%
# Epoch 282: iteration 35/35
# loss:0.754, Epoch accuracy:72.46%, Validation loss:2.529, Validation accuracy:34.67%
# Epoch 283: iteration 35/35
# loss:0.740, Epoch accuracy:72.11%, Validation loss:2.685, Validation accuracy:32.33%
# Epoch 284: iteration 35/35
# loss:0.719, Epoch accuracy:72.46%, Validation loss:2.546, Validation accuracy:39.33%
# Epoch 285: iteration 35/35
# loss:0.745, Epoch accuracy:72.28%, Validation loss:2.557, Validation accuracy:36.00%
# Epoch 286: iteration 35/35
# loss:0.681, Epoch accuracy:74.74%, Validation loss:2.680, Validation accuracy:34.67%
# Epoch 287: iteration 35/35
# loss:0.701, Epoch accuracy:74.39%, Validation loss:2.735, Validation accuracy:34.33%
# Epoch 288: iteration 35/35
# loss:0.684, Epoch accuracy:75.53%, Validation loss:2.629, Validation accuracy:34.67%
# Epoch 289: iteration 35/35
# loss:0.637, Epoch accuracy:76.49%, Validation loss:2.751, Validation accuracy:34.67%
# Epoch 290: iteration 35/35
# loss:0.621, Epoch accuracy:77.11%, Validation loss:2.610, Validation accuracy:37.33%
# Epoch 291: iteration 35/35
# loss:0.604, Epoch accuracy:77.63%, Validation loss:2.713, Validation accuracy:36.67%
# Epoch 292: iteration 35/35
# loss:0.580, Epoch accuracy:78.86%, Validation loss:2.715, Validation accuracy:35.00%
# Epoch 293: iteration 35/35
# loss:0.621, Epoch accuracy:76.58%, Validation loss:2.849, Validation accuracy:35.67%
# Epoch 294: iteration 35/35
# loss:0.588, Epoch accuracy:79.04%, Validation loss:2.746, Validation accuracy:36.33%
# Epoch 295: iteration 35/35
# loss:0.546, Epoch accuracy:80.09%, Validation loss:2.688, Validation accuracy:36.33%
# Epoch 296: iteration 35/35
# loss:0.530, Epoch accuracy:81.67%, Validation loss:2.980, Validation accuracy:36.00%
# Epoch 297: iteration 35/35
# loss:0.548, Epoch accuracy:78.51%, Validation loss:2.718, Validation accuracy:36.33%
# Epoch 298: iteration 35/35
# loss:0.504, Epoch accuracy:80.53%, Validation loss:2.721, Validation accuracy:35.00%
# Epoch 299: iteration 35/35
# loss:0.506, Epoch accuracy:80.35%, Validation loss:2.791, Validation accuracy:36.00%
#
#
# [*] done !
# [*] Best training loss - 0.5036936985818964
# [*] Best validation loss - 1.8008840084075928
# A Jupyter Widget
# Epoch 0: iteration 35/35
# loss:2.043, Epoch accuracy:12.89%, Validation loss:2.076, Validation accuracy:13.33%
# Epoch 1: iteration 35/35
# loss:2.033, Epoch accuracy:13.16%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 2: iteration 35/35
# loss:2.007, Epoch accuracy:19.39%, Validation loss:2.027, Validation accuracy:21.67%
# Epoch 3: iteration 35/35
# loss:1.968, Epoch accuracy:22.89%, Validation loss:1.980, Validation accuracy:23.33%
# Epoch 4: iteration 35/35
# loss:1.915, Epoch accuracy:24.74%, Validation loss:1.909, Validation accuracy:27.33%
# Epoch 5: iteration 35/35
# loss:1.859, Epoch accuracy:24.56%, Validation loss:1.880, Validation accuracy:28.00%
# Epoch 6: iteration 35/35
# loss:1.825, Epoch accuracy:26.67%, Validation loss:1.872, Validation accuracy:24.00%
# Epoch 7: iteration 35/35
# loss:1.796, Epoch accuracy:27.19%, Validation loss:1.898, Validation accuracy:26.67%
# Epoch 8: iteration 35/35
# loss:1.746, Epoch accuracy:27.98%, Validation loss:1.836, Validation accuracy:27.00%
# Epoch 9: iteration 35/35
# loss:1.727, Epoch accuracy:30.26%, Validation loss:1.851, Validation accuracy:27.67%
# Epoch 10: iteration 35/35
# loss:1.712, Epoch accuracy:32.46%, Validation loss:1.765, Validation accuracy:33.33%
# Epoch 11: iteration 35/35
# loss:1.694, Epoch accuracy:32.98%, Validation loss:1.827, Validation accuracy:31.67%
# Epoch 12: iteration 35/35
# loss:1.797, Epoch accuracy:27.81%, Validation loss:1.891, Validation accuracy:24.33%
# Epoch 13: iteration 35/35
# loss:1.806, Epoch accuracy:28.51%, Validation loss:1.859, Validation accuracy:27.00%
# Epoch 14: iteration 35/35
# loss:1.817, Epoch accuracy:27.11%, Validation loss:1.917, Validation accuracy:21.67%
# Epoch 15: iteration 35/35
# loss:1.814, Epoch accuracy:28.42%, Validation loss:1.778, Validation accuracy:31.00%
# Epoch 16: iteration 35/35
# loss:1.796, Epoch accuracy:27.81%, Validation loss:1.844, Validation accuracy:27.67%
# Epoch 17: iteration 35/35
# loss:1.777, Epoch accuracy:30.53%, Validation loss:1.903, Validation accuracy:26.67%
# Epoch 18: iteration 35/35
# loss:1.725, Epoch accuracy:30.61%, Validation loss:1.879, Validation accuracy:29.33%
# Epoch 19: iteration 35/35
# loss:1.827, Epoch accuracy:26.58%, Validation loss:1.870, Validation accuracy:29.33%
# Epoch 20: iteration 35/35
# loss:1.916, Epoch accuracy:22.81%, Validation loss:1.996, Validation accuracy:24.00%
# Epoch 21: iteration 35/35
# loss:1.909, Epoch accuracy:21.49%, Validation loss:1.998, Validation accuracy:26.00%
# Epoch 22: iteration 35/35
# loss:1.875, Epoch accuracy:23.77%, Validation loss:1.840, Validation accuracy:30.67%
# Epoch 23: iteration 35/35
# loss:1.990, Epoch accuracy:18.42%, Validation loss:1.937, Validation accuracy:24.67%
# Epoch 24: iteration 35/35
# loss:1.992, Epoch accuracy:17.11%, Validation loss:2.141, Validation accuracy:13.33%
# Epoch 25: iteration 35/35
# loss:1.995, Epoch accuracy:18.07%, Validation loss:2.001, Validation accuracy:20.33%
# Epoch 26: iteration 35/35
# loss:1.968, Epoch accuracy:20.18%, Validation loss:1.881, Validation accuracy:29.67%
# Epoch 27: iteration 35/35
# loss:1.898, Epoch accuracy:22.63%, Validation loss:1.919, Validation accuracy:28.67%
# Epoch 28: iteration 35/35
# loss:1.963, Epoch accuracy:18.42%, Validation loss:1.903, Validation accuracy:24.00%
# Epoch 29: iteration 35/35
# loss:1.961, Epoch accuracy:19.30%, Validation loss:1.904, Validation accuracy:28.00%
# Epoch 30: iteration 35/35
# loss:2.010, Epoch accuracy:17.02%, Validation loss:2.087, Validation accuracy:12.67%
# Epoch 31: iteration 35/35
# loss:2.015, Epoch accuracy:16.40%, Validation loss:2.203, Validation accuracy:13.00%
# Epoch 32: iteration 35/35
# loss:1.994, Epoch accuracy:17.28%, Validation loss:1.877, Validation accuracy:29.33%
# Epoch 33: iteration 35/35
# loss:2.012, Epoch accuracy:18.60%, Validation loss:2.335, Validation accuracy:13.33%
# Epoch 34: iteration 35/35
# loss:2.027, Epoch accuracy:16.49%, Validation loss:1.988, Validation accuracy:22.67%
# Epoch 35: iteration 35/35
# loss:1.983, Epoch accuracy:19.39%, Validation loss:1.986, Validation accuracy:26.67%
# Epoch 36: iteration 35/35
# loss:2.019, Epoch accuracy:15.44%, Validation loss:2.307, Validation accuracy:13.33%
# Epoch 37: iteration 35/35
# loss:2.037, Epoch accuracy:12.37%, Validation loss:2.127, Validation accuracy:13.33%
# Epoch 38: iteration 35/35
# loss:2.038, Epoch accuracy:14.56%, Validation loss:2.129, Validation accuracy:13.33%
# Epoch 39: iteration 35/35
# loss:2.036, Epoch accuracy:12.46%, Validation loss:2.072, Validation accuracy:13.33%
# Epoch 40: iteration 35/35
# loss:2.030, Epoch accuracy:13.25%, Validation loss:2.063, Validation accuracy:13.33%
# Epoch 41: iteration 35/35
# loss:2.027, Epoch accuracy:13.60%, Validation loss:2.070, Validation accuracy:13.33%
# Epoch 42: iteration 35/35
# loss:2.024, Epoch accuracy:13.60%, Validation loss:2.091, Validation accuracy:13.33%
# Epoch 43: iteration 35/35
# loss:2.026, Epoch accuracy:14.04%, Validation loss:2.077, Validation accuracy:13.33%
# Epoch 44: iteration 35/35
# loss:2.028, Epoch accuracy:12.28%, Validation loss:2.088, Validation accuracy:13.33%
# Epoch 45: iteration 35/35
# loss:2.025, Epoch accuracy:13.42%, Validation loss:2.091, Validation accuracy:13.33%
# Epoch 46: iteration 35/35
# loss:2.026, Epoch accuracy:14.91%, Validation loss:2.073, Validation accuracy:13.33%
# Epoch 47: iteration 35/35
# loss:2.015, Epoch accuracy:15.26%, Validation loss:2.064, Validation accuracy:19.67%
# Epoch 48: iteration 35/35
# loss:2.030, Epoch accuracy:16.40%, Validation loss:2.076, Validation accuracy:13.33%
# Epoch 49: iteration 35/35
# loss:2.021, Epoch accuracy:15.00%, Validation loss:2.031, Validation accuracy:17.00%
# Epoch 50: iteration 35/35
# loss:2.001, Epoch accuracy:18.77%, Validation loss:2.020, Validation accuracy:17.00%
# Epoch 51: iteration 35/35
# loss:2.027, Epoch accuracy:14.74%, Validation loss:2.088, Validation accuracy:13.67%
# Epoch 52: iteration 35/35
# loss:2.008, Epoch accuracy:15.35%, Validation loss:2.117, Validation accuracy:13.33%
# Epoch 53: iteration 35/35
# loss:1.996, Epoch accuracy:16.75%, Validation loss:2.156, Validation accuracy:13.33%
# Epoch 54: iteration 35/35
# loss:2.005, Epoch accuracy:17.37%, Validation loss:2.087, Validation accuracy:13.33%
# Epoch 55: iteration 35/35
# loss:1.974, Epoch accuracy:23.33%, Validation loss:1.929, Validation accuracy:26.00%
# Epoch 56: iteration 35/35
# loss:1.959, Epoch accuracy:20.53%, Validation loss:2.226, Validation accuracy:13.33%
# Epoch 57: iteration 35/35
# loss:1.965, Epoch accuracy:20.88%, Validation loss:1.898, Validation accuracy:29.00%
# Epoch 58: iteration 35/35
# loss:1.943, Epoch accuracy:21.67%, Validation loss:1.842, Validation accuracy:29.00%
# Epoch 59: iteration 35/35
# loss:1.864, Epoch accuracy:24.82%, Validation loss:1.821, Validation accuracy:26.67%
# Epoch 60: iteration 35/35
# loss:1.857, Epoch accuracy:26.14%, Validation loss:1.956, Validation accuracy:26.67%
# Epoch 61: iteration 35/35
# loss:1.946, Epoch accuracy:20.96%, Validation loss:1.931, Validation accuracy:29.33%
# Epoch 62: iteration 35/35
# loss:1.895, Epoch accuracy:23.51%, Validation loss:1.950, Validation accuracy:27.00%
# Epoch 63: iteration 35/35
# loss:1.859, Epoch accuracy:26.58%, Validation loss:1.884, Validation accuracy:28.00%
# Epoch 64: iteration 35/35
# loss:1.899, Epoch accuracy:23.86%, Validation loss:1.989, Validation accuracy:24.00%
# Epoch 65: iteration 35/35
# loss:1.915, Epoch accuracy:21.75%, Validation loss:2.080, Validation accuracy:22.33%
# Epoch 66: iteration 35/35
# loss:2.081, Epoch accuracy:13.95%, Validation loss:2.239, Validation accuracy:13.00%
# Epoch 67: iteration 35/35
# loss:2.060, Epoch accuracy:10.53%, Validation loss:2.038, Validation accuracy:17.00%
# Epoch 68: iteration 35/35
# loss:2.028, Epoch accuracy:13.42%, Validation loss:2.214, Validation accuracy:9.33%
# Epoch 69: iteration 35/35
# loss:2.043, Epoch accuracy:12.37%, Validation loss:2.054, Validation accuracy:16.00%
# Epoch 70: iteration 35/35
# loss:2.028, Epoch accuracy:12.81%, Validation loss:2.055, Validation accuracy:20.00%
# Epoch 71: iteration 35/35
# loss:2.026, Epoch accuracy:13.16%, Validation loss:2.059, Validation accuracy:15.00%
# Epoch 72: iteration 35/35
# loss:2.031, Epoch accuracy:12.37%, Validation loss:2.057, Validation accuracy:19.67%
# Epoch 73: iteration 35/35
# loss:2.029, Epoch accuracy:13.60%, Validation loss:2.062, Validation accuracy:14.00%
# Epoch 74: iteration 35/35
# loss:2.028, Epoch accuracy:13.16%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 75: iteration 35/35
# loss:2.029, Epoch accuracy:12.72%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 76: iteration 35/35
# loss:2.029, Epoch accuracy:11.58%, Validation loss:2.064, Validation accuracy:13.33%
# Epoch 77: iteration 35/35
# loss:2.026, Epoch accuracy:13.07%, Validation loss:2.064, Validation accuracy:13.33%
# Epoch 78: iteration 35/35
# loss:2.026, Epoch accuracy:13.16%, Validation loss:2.062, Validation accuracy:11.67%
# Epoch 79: iteration 35/35
# loss:2.026, Epoch accuracy:13.07%, Validation loss:2.062, Validation accuracy:12.00%
# Epoch 80: iteration 35/35
# loss:2.027, Epoch accuracy:12.72%, Validation loss:2.064, Validation accuracy:13.00%
# Epoch 81: iteration 35/35
# loss:2.025, Epoch accuracy:12.89%, Validation loss:2.063, Validation accuracy:13.33%
# Epoch 82: iteration 35/35
# loss:2.027, Epoch accuracy:12.02%, Validation loss:2.064, Validation accuracy:13.00%
# Epoch 83: iteration 35/35
# loss:2.027, Epoch accuracy:12.72%, Validation loss:2.063, Validation accuracy:13.33%
# Epoch 84: iteration 35/35
# loss:2.029, Epoch accuracy:12.28%, Validation loss:2.063, Validation accuracy:13.33%
# Epoch 85: iteration 35/35
# loss:2.027, Epoch accuracy:12.98%, Validation loss:2.064, Validation accuracy:13.33%
# Epoch 86: iteration 35/35
# loss:2.025, Epoch accuracy:14.30%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 87: iteration 35/35
# loss:2.025, Epoch accuracy:12.89%, Validation loss:2.061, Validation accuracy:14.33%
# Epoch 88: iteration 35/35
# loss:2.025, Epoch accuracy:14.21%, Validation loss:2.060, Validation accuracy:18.00%
# Epoch 89: iteration 35/35
# loss:2.027, Epoch accuracy:12.46%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 90: iteration 35/35
# loss:2.025, Epoch accuracy:14.21%, Validation loss:2.060, Validation accuracy:15.33%
# Epoch 91: iteration 35/35
# loss:2.026, Epoch accuracy:12.11%, Validation loss:2.060, Validation accuracy:15.33%
# Epoch 92: iteration 35/35
# loss:2.027, Epoch accuracy:12.63%, Validation loss:2.062, Validation accuracy:13.33%
# Epoch 93: iteration 35/35
# loss:2.027, Epoch accuracy:12.89%, Validation loss:2.063, Validation accuracy:13.33%
# Epoch 94: iteration 35/35
# loss:2.027, Epoch accuracy:13.77%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 95: iteration 35/35
# loss:2.027, Epoch accuracy:12.98%, Validation loss:2.061, Validation accuracy:13.33%
# Epoch 96: iteration 35/35
# loss:2.025, Epoch accuracy:13.86%, Validation loss:2.059, Validation accuracy:18.33%
# Epoch 97: iteration 35/35
# loss:2.024, Epoch accuracy:14.39%, Validation loss:2.056, Validation accuracy:18.67%
# Epoch 98: iteration 35/35
# loss:2.025, Epoch accuracy:13.07%, Validation loss:2.049, Validation accuracy:17.67%
# Epoch 99: iteration 13/35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [12], line 18
#      15 model = Model(num_emotions=len(emotions_dict)).to('cuda')
#      16 optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
# ---> 18 train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
#      20 plt.title('Loss Curve')
#      21 plt.ylabel('Loss', fontsize=16)
#
# Cell In [10], line 65, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer)
#      62 Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
#      64 # Pass input tensors thru 1 training step (fwd+backwards pass)
# ---> 65 loss, acc = train_step(X_tensor, Y_tensor)
#      67 # aggregate batch accuracy to measure progress of entire epoch
#      68 epoch_acc += acc * actual_batch_size / train_size
#
# Cell In [6], line 15, in make_train_step.<locals>.train_step(X, Y)
#      12 loss = criterion(output_logits, Y)
#      14 # compute gradients for the optimizer to use
# ---> 15 loss.backward()
#      17 # update network parameters based on gradient stored (by calling loss.backward())
#      18 optimizer.step()
#
# File c:\Users\devLupin\miniconda3\envs\ser\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File c:\Users\devLupin\miniconda3\envs\ser\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, f'fold{fold}.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    
    test_accs.append(test_acc)
    
    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, emotions_groundtruth)
    predicted_emotions_list = np.append(predicted_emotions_list, predicted_emotions)

# %%
os.makedirs('result', exist_ok=True)

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)
print(Report)

with open(f"result/{sub_name}_{loss_name}_Report.txt", "w") as f:
    f.write(Report)

# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f"result/{sub_name}_{loss_name}_confmatrix.pdf")
plt.show()

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
