# %%
import os
import torch

os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'Deep and Acoustic Features'
data_name = 'RAVDESS'
fold_path = sub_name + ' dataset'

minibatch = 32
num_epochs = 500
EARLY_CNT = 99999

learning_rate = 1e-6

# %%
from cv2 import transform
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
import math
from torchaudio.functional import compute_deltas
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')
    
set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def get_padding(kernel_size: int, stride: int, dilation: int) -> int:
    if stride > 1 and dilation > 1:
        raise ValueError('Only stride OR dilation may be greater than 1')
    return (kernel_size // 2) * dilation

# %%
def get_deltas(feature):
    f = feature.unsqueeze(dim=1)
    
    delta = compute_deltas(f, win_length=7)
    delta2 = compute_deltas(delta, win_length=7)
    
    ret = torch.cat([f, delta, delta2], dim=1)
    
    return ret

# %%
from torchvision.models import ResNet18_Weights

class Model(nn.Module):
    def __init__(self, num_emotions):
        super(Model, self).__init__()

        self.resnet18 = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        self.resnet18 = nn.Sequential(*(list(self.resnet18.children())[:-1]))
        
        self.fc = nn.Linear(100864, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        melspectrogram = x[:,0]
        melspectrogram = get_deltas(melspectrogram)
        
        mfcc = x[:,1]
        mfcc = torch.flatten(mfcc, start_dim=1)
        
        chroma = x[:,2]
        chroma = torch.flatten(chroma, start_dim=1)
        
        res_embd = self.resnet18(melspectrogram)
        res_embd = torch.flatten(res_embd, start_dim=1)
        
        combine = torch.cat([mfcc, chroma, res_embd], dim=1)
        
        output_logits = self.fc(combine)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs)):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=10e-6, amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - Deep and Acoustic Features
#   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:27.988, Epoch accuracy:12.63%, Validation loss:21.466, Validation accuracy:11.00%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:15.919, Epoch accuracy:11.40%, Validation loss:12.185, Validation accuracy:10.00%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:8.459, Epoch accuracy:11.05%, Validation loss:6.687, Validation accuracy:11.67%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:5.704, Epoch accuracy:13.68%, Validation loss:5.811, Validation accuracy:12.33%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:5.311, Epoch accuracy:14.65%, Validation loss:5.605, Validation accuracy:14.67%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:4.994, Epoch accuracy:15.53%, Validation loss:5.445, Validation accuracy:15.33%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:4.694, Epoch accuracy:17.19%, Validation loss:5.284, Validation accuracy:15.67%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:4.459, Epoch accuracy:18.95%, Validation loss:5.167, Validation accuracy:15.33%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:4.208, Epoch accuracy:19.56%, Validation loss:5.001, Validation accuracy:16.67%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:4.017, Epoch accuracy:21.75%, Validation loss:4.934, Validation accuracy:17.00%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:3.801, Epoch accuracy:23.33%, Validation loss:4.813, Validation accuracy:16.67%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:3.614, Epoch accuracy:23.42%, Validation loss:4.814, Validation accuracy:18.33%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:3.446, Epoch accuracy:26.23%, Validation loss:4.653, Validation accuracy:18.67%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:3.294, Epoch accuracy:27.46%, Validation loss:4.573, Validation accuracy:19.33%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:3.127, Epoch accuracy:30.18%, Validation loss:4.525, Validation accuracy:19.67%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:3.001, Epoch accuracy:30.44%, Validation loss:4.442, Validation accuracy:19.67%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:2.826, Epoch accuracy:33.51%, Validation loss:4.409, Validation accuracy:19.67%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:2.692, Epoch accuracy:35.26%, Validation loss:4.330, Validation accuracy:21.00%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:2.599, Epoch accuracy:35.09%, Validation loss:4.308, Validation accuracy:21.33%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:2.435, Epoch accuracy:38.68%, Validation loss:4.251, Validation accuracy:19.67%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:2.345, Epoch accuracy:40.61%, Validation loss:4.212, Validation accuracy:21.67%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:2.230, Epoch accuracy:42.19%, Validation loss:4.186, Validation accuracy:20.67%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:2.137, Epoch accuracy:43.60%, Validation loss:4.129, Validation accuracy:20.67%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:2.024, Epoch accuracy:45.53%, Validation loss:4.163, Validation accuracy:20.00%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:1.952, Epoch accuracy:46.58%, Validation loss:4.120, Validation accuracy:20.67%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:1.834, Epoch accuracy:49.39%, Validation loss:4.068, Validation accuracy:20.67%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:1.748, Epoch accuracy:50.70%, Validation loss:3.984, Validation accuracy:21.00%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:1.688, Epoch accuracy:51.67%, Validation loss:3.972, Validation accuracy:21.67%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:1.610, Epoch accuracy:53.77%, Validation loss:4.008, Validation accuracy:22.33%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:1.524, Epoch accuracy:55.44%, Validation loss:3.976, Validation accuracy:21.33%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:1.461, Epoch accuracy:57.19%, Validation loss:3.946, Validation accuracy:22.00%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:1.371, Epoch accuracy:58.33%, Validation loss:3.906, Validation accuracy:22.33%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:1.309, Epoch accuracy:60.44%, Validation loss:3.905, Validation accuracy:22.33%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:1.262, Epoch accuracy:61.75%, Validation loss:3.914, Validation accuracy:23.00%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:1.203, Epoch accuracy:63.33%, Validation loss:3.838, Validation accuracy:24.00%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:1.138, Epoch accuracy:64.91%, Validation loss:3.839, Validation accuracy:23.33%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:1.080, Epoch accuracy:66.14%, Validation loss:3.836, Validation accuracy:23.33%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:1.036, Epoch accuracy:67.11%, Validation loss:3.871, Validation accuracy:24.00%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:0.995, Epoch accuracy:67.19%, Validation loss:3.821, Validation accuracy:23.67%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:0.924, Epoch accuracy:70.09%, Validation loss:3.754, Validation accuracy:24.00%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:0.897, Epoch accuracy:70.61%, Validation loss:3.759, Validation accuracy:24.33%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:0.842, Epoch accuracy:73.07%, Validation loss:3.756, Validation accuracy:23.67%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:0.797, Epoch accuracy:75.35%, Validation loss:3.742, Validation accuracy:24.67%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:0.774, Epoch accuracy:75.53%, Validation loss:3.705, Validation accuracy:25.00%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:0.735, Epoch accuracy:77.02%, Validation loss:3.737, Validation accuracy:24.67%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:0.694, Epoch accuracy:78.33%, Validation loss:3.694, Validation accuracy:24.33%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:0.663, Epoch accuracy:79.74%, Validation loss:3.798, Validation accuracy:24.00%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:0.639, Epoch accuracy:80.44%, Validation loss:3.694, Validation accuracy:24.33%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:0.605, Epoch accuracy:82.28%, Validation loss:3.641, Validation accuracy:24.00%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:0.578, Epoch accuracy:82.98%, Validation loss:3.643, Validation accuracy:26.33%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:0.549, Epoch accuracy:84.04%, Validation loss:3.672, Validation accuracy:25.00%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:0.529, Epoch accuracy:85.18%, Validation loss:3.658, Validation accuracy:24.33%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:0.499, Epoch accuracy:86.75%, Validation loss:3.635, Validation accuracy:25.67%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:0.480, Epoch accuracy:86.49%, Validation loss:3.616, Validation accuracy:25.33%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:0.455, Epoch accuracy:87.89%, Validation loss:3.637, Validation accuracy:25.67%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:0.436, Epoch accuracy:88.60%, Validation loss:3.641, Validation accuracy:25.00%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:0.419, Epoch accuracy:89.04%, Validation loss:3.634, Validation accuracy:25.00%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:0.393, Epoch accuracy:89.56%, Validation loss:3.602, Validation accuracy:25.67%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:0.375, Epoch accuracy:90.00%, Validation loss:3.588, Validation accuracy:25.33%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:0.366, Epoch accuracy:90.18%, Validation loss:3.626, Validation accuracy:25.00%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:0.348, Epoch accuracy:91.05%, Validation loss:3.610, Validation accuracy:25.67%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:0.333, Epoch accuracy:91.58%, Validation loss:3.590, Validation accuracy:25.67%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:0.317, Epoch accuracy:92.02%, Validation loss:3.590, Validation accuracy:26.33%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:0.303, Epoch accuracy:92.28%, Validation loss:3.578, Validation accuracy:25.67%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:0.291, Epoch accuracy:93.16%, Validation loss:3.573, Validation accuracy:25.33%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:0.282, Epoch accuracy:93.42%, Validation loss:3.574, Validation accuracy:25.67%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:0.271, Epoch accuracy:93.95%, Validation loss:3.593, Validation accuracy:26.00%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:0.255, Epoch accuracy:95.09%, Validation loss:3.553, Validation accuracy:25.33%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:0.248, Epoch accuracy:95.18%, Validation loss:3.569, Validation accuracy:25.33%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:0.239, Epoch accuracy:95.79%, Validation loss:3.540, Validation accuracy:25.67%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:0.230, Epoch accuracy:95.70%, Validation loss:3.562, Validation accuracy:26.00%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:0.222, Epoch accuracy:96.05%, Validation loss:3.544, Validation accuracy:25.67%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:0.213, Epoch accuracy:96.05%, Validation loss:3.537, Validation accuracy:26.33%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:0.206, Epoch accuracy:96.14%, Validation loss:3.553, Validation accuracy:26.33%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:0.198, Epoch accuracy:96.58%, Validation loss:3.527, Validation accuracy:26.33%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:0.191, Epoch accuracy:96.58%, Validation loss:3.521, Validation accuracy:26.00%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:0.184, Epoch accuracy:96.75%, Validation loss:3.520, Validation accuracy:26.33%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:0.175, Epoch accuracy:97.19%, Validation loss:3.525, Validation accuracy:26.33%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:0.173, Epoch accuracy:97.11%, Validation loss:3.511, Validation accuracy:26.33%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:0.167, Epoch accuracy:97.28%, Validation loss:3.524, Validation accuracy:26.67%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:0.161, Epoch accuracy:97.37%, Validation loss:3.518, Validation accuracy:26.00%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:0.156, Epoch accuracy:97.54%, Validation loss:3.515, Validation accuracy:26.00%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:0.152, Epoch accuracy:97.46%, Validation loss:3.508, Validation accuracy:26.67%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:0.148, Epoch accuracy:97.72%, Validation loss:3.518, Validation accuracy:26.00%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:0.144, Epoch accuracy:97.72%, Validation loss:3.502, Validation accuracy:26.67%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:0.140, Epoch accuracy:97.72%, Validation loss:3.504, Validation accuracy:26.33%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:0.136, Epoch accuracy:97.81%, Validation loss:3.496, Validation accuracy:26.33%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:0.132, Epoch accuracy:97.81%, Validation loss:3.499, Validation accuracy:26.00%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:0.130, Epoch accuracy:97.81%, Validation loss:3.518, Validation accuracy:25.67%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:0.126, Epoch accuracy:97.89%, Validation loss:3.490, Validation accuracy:27.00%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:0.122, Epoch accuracy:97.98%, Validation loss:3.493, Validation accuracy:26.00%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:0.119, Epoch accuracy:97.89%, Validation loss:3.481, Validation accuracy:26.00%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:0.116, Epoch accuracy:97.98%, Validation loss:3.484, Validation accuracy:26.33%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:0.112, Epoch accuracy:97.98%, Validation loss:3.476, Validation accuracy:27.33%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:0.110, Epoch accuracy:97.98%, Validation loss:3.498, Validation accuracy:26.67%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:0.108, Epoch accuracy:97.98%, Validation loss:3.479, Validation accuracy:26.67%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:0.106, Epoch accuracy:97.98%, Validation loss:3.476, Validation accuracy:26.33%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:0.103, Epoch accuracy:97.98%, Validation loss:3.479, Validation accuracy:26.33%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:0.101, Epoch accuracy:97.98%, Validation loss:3.468, Validation accuracy:27.00%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:0.098, Epoch accuracy:97.98%, Validation loss:3.468, Validation accuracy:27.33%
# Epoch 100: iteration 34/35
# Epoch 100 --- loss:0.097, Epoch accuracy:98.07%, Validation loss:3.470, Validation accuracy:27.00%
# Epoch 101: iteration 34/35
# Epoch 101 --- loss:0.095, Epoch accuracy:97.98%, Validation loss:3.474, Validation accuracy:27.00%
# Epoch 102: iteration 34/35
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [13], line 18
#      15 model = Model(num_emotions=len(emotions_dict)).to('cuda')
#      16 optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=10e-6, amsgrad=True)
# ---> 18 train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
#      20 plt.title('Loss Curve')
#      21 plt.ylabel('Loss', fontsize=16)
#
# Cell In [11], line 74, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer)
#      71     # keep track of the iteration to see if the model's too slow
#      72     print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')
# ---> 74 X_valid_tensor = torch.tensor(X_valid, device=device).float()
#      75 Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
#      77 # calculate validation metrics to keep track of progress; don't need predictions now
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
