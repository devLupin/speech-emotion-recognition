# %%
from cv2 import transform
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
from einops import rearrange

# %%
from torchvision.models import ResNet18_Weights

class resnet18_finetune(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        
        self.model_ft = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        self.model_ft = nn.Sequential(*(list(self.model_ft.children())[:-1]))
        
        for name, param in self.model_ft[:4].named_parameters():
            param.requires_grad=False
    
    def forward(self, x):
        embd = self.model_ft(x)
        output = torch.flatten(embd, start_dim=1)
        
        return output

# %%
class TimeseriesModel(nn.Module):
    """Some Information about nna"""
    def __init__(self):
        super(TimeseriesModel, self).__init__()

        self.resnet = resnet18_finetune()

        self.lstm = nn.LSTM(input_size=512, hidden_size=256, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
        self.lstm_ln = nn.LayerNorm(normalized_shape=512, eps=1e-08)
        
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=512,
            nhead=4,
            dim_feedforward=64,
            dropout=0.5,
            activation='relu'
        )
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=2)
        self.transformer_ln = nn.LayerNorm(normalized_shape=512, eps=1e-08)

    def forward(self, x):
        spatial_embd = self.resnet(x)
        
        lstm_embd, (h, c) = self.lstm(spatial_embd)
        transformer_embd = self.transformer_encoder(lstm_embd)
        
        return transformer_embd

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()
    
        self.timeseries = TimeseriesModel()
        
        self.linear = nn.Linear(512, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        timeseries_embd = self.timeseries(x)
        
        output_logits = self.linear(timeseries_embd)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'ResNet18-Timeseries'
data_name = 'RAVDESS'

minibatch = 256
num_epochs = 1000
EARLY_CNT = 1000

learning_rate = 1e-6

# model = Model(len(emotions_dict))
# print(summary(model, (1, 3, 224, 224)))

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = '5-CV-augment'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    break
# Out:
# [*] model training - ResNet18-Timeseries
# 0:   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 0: iteration 7/8
# Epoch 0 --- loss:2.127, Epoch accuracy:11.67%, Validation loss:2.297, Validation accuracy:11.17%
# Epoch 1: iteration 7/8
# Epoch 1 --- loss:2.092, Epoch accuracy:12.19%, Validation loss:2.298, Validation accuracy:13.33%
# Epoch 2: iteration 7/8
# Epoch 2 --- loss:2.045, Epoch accuracy:12.19%, Validation loss:2.288, Validation accuracy:13.33%
# Epoch 3: iteration 7/8
# Epoch 3 --- loss:2.011, Epoch accuracy:12.06%, Validation loss:2.256, Validation accuracy:13.33%
# Epoch 4: iteration 7/8
# Epoch 4 --- loss:2.004, Epoch accuracy:11.80%, Validation loss:2.221, Validation accuracy:13.33%
# Epoch 5: iteration 7/8
# Epoch 5 --- loss:1.998, Epoch accuracy:11.62%, Validation loss:2.189, Validation accuracy:13.33%
# Epoch 6: iteration 7/8
# Epoch 6 --- loss:1.955, Epoch accuracy:12.46%, Validation loss:2.164, Validation accuracy:13.17%
# Epoch 7: iteration 7/8
# Epoch 7 --- loss:1.958, Epoch accuracy:11.45%, Validation loss:2.141, Validation accuracy:13.00%
# Epoch 8: iteration 7/8
# Epoch 8 --- loss:1.940, Epoch accuracy:11.45%, Validation loss:2.124, Validation accuracy:13.67%
# Epoch 9: iteration 7/8
# Epoch 9 --- loss:1.937, Epoch accuracy:11.10%, Validation loss:2.109, Validation accuracy:15.00%
# Epoch 10: iteration 7/8
# Epoch 10 --- loss:1.917, Epoch accuracy:11.93%, Validation loss:2.097, Validation accuracy:16.50%
# Epoch 11: iteration 7/8
# Epoch 11 --- loss:1.908, Epoch accuracy:13.33%, Validation loss:2.088, Validation accuracy:16.50%
# Epoch 12: iteration 7/8
# Epoch 12 --- loss:1.905, Epoch accuracy:12.50%, Validation loss:2.080, Validation accuracy:17.50%
# Epoch 13: iteration 7/8
# Epoch 13 --- loss:1.913, Epoch accuracy:13.55%, Validation loss:2.073, Validation accuracy:18.00%
# Epoch 14: iteration 7/8
# Epoch 14 --- loss:1.892, Epoch accuracy:13.38%, Validation loss:2.067, Validation accuracy:16.33%
# Epoch 15: iteration 7/8
# Epoch 15 --- loss:1.883, Epoch accuracy:14.12%, Validation loss:2.062, Validation accuracy:16.17%
# Epoch 16: iteration 7/8
# Epoch 16 --- loss:1.905, Epoch accuracy:11.93%, Validation loss:2.059, Validation accuracy:15.83%
# Epoch 17: iteration 7/8
# Epoch 17 --- loss:1.900, Epoch accuracy:12.15%, Validation loss:2.055, Validation accuracy:16.50%
# Epoch 18: iteration 7/8
# Epoch 18 --- loss:1.885, Epoch accuracy:13.07%, Validation loss:2.052, Validation accuracy:16.67%
# Epoch 19: iteration 7/8
# Epoch 19 --- loss:1.895, Epoch accuracy:12.46%, Validation loss:2.049, Validation accuracy:16.50%
# Epoch 20: iteration 7/8
# Epoch 20 --- loss:1.887, Epoch accuracy:12.24%, Validation loss:2.047, Validation accuracy:17.17%
# Epoch 21: iteration 7/8
# Epoch 21 --- loss:1.892, Epoch accuracy:12.54%, Validation loss:2.044, Validation accuracy:17.83%
# Epoch 22: iteration 7/8
# Epoch 22 --- loss:1.883, Epoch accuracy:13.07%, Validation loss:2.041, Validation accuracy:18.67%
# Epoch 23: iteration 7/8
# Epoch 23 --- loss:1.882, Epoch accuracy:13.90%, Validation loss:2.039, Validation accuracy:17.83%
# Epoch 24: iteration 7/8
# Epoch 24 --- loss:1.888, Epoch accuracy:13.60%, Validation loss:2.037, Validation accuracy:18.50%
# Epoch 25: iteration 7/8
# Epoch 25 --- loss:1.889, Epoch accuracy:13.73%, Validation loss:2.035, Validation accuracy:18.50%
# Epoch 26: iteration 7/8
# Epoch 26 --- loss:1.883, Epoch accuracy:14.30%, Validation loss:2.032, Validation accuracy:18.83%
# Epoch 27: iteration 7/8
# Epoch 27 --- loss:1.879, Epoch accuracy:13.33%, Validation loss:2.030, Validation accuracy:18.33%
# Epoch 28: iteration 7/8
# Epoch 28 --- loss:1.883, Epoch accuracy:13.03%, Validation loss:2.028, Validation accuracy:18.33%
# Epoch 29: iteration 7/8
# Epoch 29 --- loss:1.883, Epoch accuracy:12.50%, Validation loss:2.025, Validation accuracy:18.33%
# Epoch 30: iteration 7/8
# Epoch 30 --- loss:1.876, Epoch accuracy:14.69%, Validation loss:2.022, Validation accuracy:18.33%
# Epoch 31: iteration 7/8
# Epoch 31 --- loss:1.873, Epoch accuracy:13.64%, Validation loss:2.020, Validation accuracy:18.83%
# Epoch 32: iteration 7/8
# Epoch 32 --- loss:1.869, Epoch accuracy:15.61%, Validation loss:2.018, Validation accuracy:19.67%
# Epoch 33: iteration 7/8
# Epoch 33 --- loss:1.869, Epoch accuracy:14.21%, Validation loss:2.015, Validation accuracy:20.17%
# Epoch 34: iteration 7/8
# Epoch 34 --- loss:1.869, Epoch accuracy:13.33%, Validation loss:2.013, Validation accuracy:20.17%
# Epoch 35: iteration 7/8
# Epoch 35 --- loss:1.867, Epoch accuracy:14.39%, Validation loss:2.011, Validation accuracy:21.00%
# Epoch 36: iteration 7/8
# Epoch 36 --- loss:1.865, Epoch accuracy:14.47%, Validation loss:2.009, Validation accuracy:20.17%
# Epoch 37: iteration 7/8
# Epoch 37 --- loss:1.875, Epoch accuracy:13.42%, Validation loss:2.007, Validation accuracy:20.33%
# Epoch 38: iteration 7/8
# Epoch 38 --- loss:1.856, Epoch accuracy:15.61%, Validation loss:2.004, Validation accuracy:21.33%
# Epoch 39: iteration 7/8
# Epoch 39 --- loss:1.852, Epoch accuracy:15.39%, Validation loss:2.002, Validation accuracy:22.00%
# Epoch 40: iteration 7/8
# Epoch 40 --- loss:1.858, Epoch accuracy:16.14%, Validation loss:1.999, Validation accuracy:21.67%
# Epoch 41: iteration 7/8
# Epoch 41 --- loss:1.859, Epoch accuracy:14.30%, Validation loss:1.997, Validation accuracy:21.67%
# Epoch 42: iteration 7/8
# Epoch 42 --- loss:1.856, Epoch accuracy:15.31%, Validation loss:1.994, Validation accuracy:22.50%
# Epoch 43: iteration 7/8
# Epoch 43 --- loss:1.863, Epoch accuracy:13.68%, Validation loss:1.992, Validation accuracy:22.83%
# Epoch 44: iteration 7/8
# Epoch 44 --- loss:1.865, Epoch accuracy:14.30%, Validation loss:1.989, Validation accuracy:23.17%
# Epoch 45: iteration 7/8
# Epoch 45 --- loss:1.856, Epoch accuracy:15.79%, Validation loss:1.986, Validation accuracy:23.50%
# Epoch 46: iteration 7/8
# Epoch 46 --- loss:1.853, Epoch accuracy:15.70%, Validation loss:1.984, Validation accuracy:23.67%
# Epoch 47: iteration 7/8
# Epoch 47 --- loss:1.849, Epoch accuracy:15.53%, Validation loss:1.981, Validation accuracy:24.00%
# Epoch 48: iteration 7/8
# Epoch 48 --- loss:1.857, Epoch accuracy:15.00%, Validation loss:1.979, Validation accuracy:24.17%
# Epoch 49: iteration 7/8
# Epoch 49 --- loss:1.850, Epoch accuracy:16.10%, Validation loss:1.977, Validation accuracy:25.67%
# Epoch 50: iteration 7/8
# Epoch 50 --- loss:1.841, Epoch accuracy:16.32%, Validation loss:1.974, Validation accuracy:25.17%
# Epoch 51: iteration 7/8
# Epoch 51 --- loss:1.859, Epoch accuracy:15.09%, Validation loss:1.972, Validation accuracy:25.33%
# Epoch 52: iteration 7/8
# Epoch 52 --- loss:1.851, Epoch accuracy:14.91%, Validation loss:1.969, Validation accuracy:26.17%
# Epoch 53: iteration 7/8
# Epoch 53 --- loss:1.853, Epoch accuracy:16.18%, Validation loss:1.966, Validation accuracy:25.83%
# Epoch 54: iteration 7/8
# Epoch 54 --- loss:1.844, Epoch accuracy:15.75%, Validation loss:1.963, Validation accuracy:25.83%
# Epoch 55: iteration 7/8
# Epoch 55 --- loss:1.841, Epoch accuracy:15.44%, Validation loss:1.961, Validation accuracy:26.00%
# Epoch 56: iteration 7/8
# Epoch 56 --- loss:1.838, Epoch accuracy:15.88%, Validation loss:1.958, Validation accuracy:25.83%
# Epoch 57: iteration 7/8
# Epoch 57 --- loss:1.847, Epoch accuracy:16.10%, Validation loss:1.956, Validation accuracy:26.00%
# Epoch 58: iteration 7/8
# Epoch 58 --- loss:1.849, Epoch accuracy:16.01%, Validation loss:1.953, Validation accuracy:26.50%
# Epoch 59: iteration 7/8
# Epoch 59 --- loss:1.835, Epoch accuracy:16.36%, Validation loss:1.951, Validation accuracy:26.50%
# Epoch 60: iteration 7/8
# Epoch 60 --- loss:1.841, Epoch accuracy:16.23%, Validation loss:1.948, Validation accuracy:26.83%
# Epoch 61: iteration 7/8
# Epoch 61 --- loss:1.855, Epoch accuracy:15.53%, Validation loss:1.945, Validation accuracy:26.33%
# Epoch 62: iteration 7/8
# Epoch 62 --- loss:1.839, Epoch accuracy:16.84%, Validation loss:1.942, Validation accuracy:27.17%
# Epoch 63: iteration 7/8
# Epoch 63 --- loss:1.829, Epoch accuracy:16.80%, Validation loss:1.939, Validation accuracy:28.33%
# Epoch 64: iteration 7/8
# Epoch 64 --- loss:1.836, Epoch accuracy:17.81%, Validation loss:1.936, Validation accuracy:28.50%
# Epoch 65: iteration 7/8
# Epoch 65 --- loss:1.842, Epoch accuracy:16.49%, Validation loss:1.934, Validation accuracy:27.83%
# Epoch 66: iteration 7/8
# Epoch 66 --- loss:1.834, Epoch accuracy:16.84%, Validation loss:1.931, Validation accuracy:28.17%
# Epoch 67: iteration 7/8
# Epoch 67 --- loss:1.831, Epoch accuracy:17.89%, Validation loss:1.928, Validation accuracy:28.67%
# Epoch 68: iteration 7/8
# Epoch 68 --- loss:1.822, Epoch accuracy:18.03%, Validation loss:1.925, Validation accuracy:29.67%
# Epoch 69: iteration 7/8
# Epoch 69 --- loss:1.821, Epoch accuracy:17.02%, Validation loss:1.923, Validation accuracy:29.83%
# Epoch 70: iteration 7/8
# Epoch 70 --- loss:1.824, Epoch accuracy:17.68%, Validation loss:1.919, Validation accuracy:30.50%
# Epoch 71: iteration 7/8
# Epoch 71 --- loss:1.818, Epoch accuracy:17.11%, Validation loss:1.916, Validation accuracy:30.33%
# Epoch 72: iteration 7/8
# Epoch 72 --- loss:1.826, Epoch accuracy:16.54%, Validation loss:1.913, Validation accuracy:31.00%
# Epoch 73: iteration 7/8
# Epoch 73 --- loss:1.808, Epoch accuracy:19.04%, Validation loss:1.910, Validation accuracy:31.67%
# Epoch 74: iteration 7/8
# Epoch 74 --- loss:1.814, Epoch accuracy:17.72%, Validation loss:1.907, Validation accuracy:31.00%
# Epoch 75: iteration 7/8
# Epoch 75 --- loss:1.820, Epoch accuracy:17.85%, Validation loss:1.904, Validation accuracy:32.33%
# Epoch 76: iteration 7/8
# Epoch 76 --- loss:1.810, Epoch accuracy:18.46%, Validation loss:1.901, Validation accuracy:32.33%
# Epoch 77: iteration 7/8
# Epoch 77 --- loss:1.814, Epoch accuracy:18.03%, Validation loss:1.898, Validation accuracy:32.67%
# Epoch 78: iteration 7/8
# Epoch 78 --- loss:1.805, Epoch accuracy:18.82%, Validation loss:1.895, Validation accuracy:32.33%
# Epoch 79: iteration 7/8
# Epoch 79 --- loss:1.812, Epoch accuracy:18.68%, Validation loss:1.891, Validation accuracy:33.50%
# Epoch 80: iteration 7/8
# Epoch 80 --- loss:1.838, Epoch accuracy:16.40%, Validation loss:1.888, Validation accuracy:34.00%
# Epoch 81: iteration 7/8
# Epoch 81 --- loss:1.814, Epoch accuracy:18.64%, Validation loss:1.885, Validation accuracy:34.00%
# Epoch 82: iteration 7/8
# Epoch 82 --- loss:1.804, Epoch accuracy:19.39%, Validation loss:1.882, Validation accuracy:33.50%
# Epoch 83: iteration 7/8
# Epoch 83 --- loss:1.811, Epoch accuracy:18.55%, Validation loss:1.879, Validation accuracy:34.33%
# Epoch 84: iteration 7/8
# Epoch 84 --- loss:1.806, Epoch accuracy:16.97%, Validation loss:1.875, Validation accuracy:34.50%
# Epoch 85: iteration 7/8
# Epoch 85 --- loss:1.802, Epoch accuracy:19.17%, Validation loss:1.871, Validation accuracy:34.83%
# Epoch 86: iteration 7/8
# Epoch 86 --- loss:1.793, Epoch accuracy:20.57%, Validation loss:1.868, Validation accuracy:35.17%
# Epoch 87: iteration 7/8
# Epoch 87 --- loss:1.797, Epoch accuracy:18.68%, Validation loss:1.864, Validation accuracy:35.33%
# Epoch 88: iteration 7/8
# Epoch 88 --- loss:1.792, Epoch accuracy:20.00%, Validation loss:1.861, Validation accuracy:35.67%
# Epoch 89: iteration 7/8
# Epoch 89 --- loss:1.793, Epoch accuracy:19.91%, Validation loss:1.857, Validation accuracy:35.50%
# Epoch 90: iteration 7/8
# Epoch 90 --- loss:1.787, Epoch accuracy:20.31%, Validation loss:1.853, Validation accuracy:36.33%
# Epoch 91: iteration 7/8
# Epoch 91 --- loss:1.784, Epoch accuracy:20.96%, Validation loss:1.849, Validation accuracy:37.17%
# Epoch 92: iteration 7/8
# Epoch 92 --- loss:1.803, Epoch accuracy:19.43%, Validation loss:1.846, Validation accuracy:37.83%
# Epoch 93: iteration 7/8
# Epoch 93 --- loss:1.783, Epoch accuracy:19.87%, Validation loss:1.843, Validation accuracy:37.83%
# Epoch 94: iteration 7/8
# Epoch 94 --- loss:1.783, Epoch accuracy:19.56%, Validation loss:1.839, Validation accuracy:39.17%
# Epoch 95: iteration 7/8
# Epoch 95 --- loss:1.776, Epoch accuracy:23.33%, Validation loss:1.836, Validation accuracy:39.67%
# Epoch 96: iteration 7/8
# Epoch 96 --- loss:1.787, Epoch accuracy:21.14%, Validation loss:1.832, Validation accuracy:39.17%
# Epoch 97: iteration 7/8
# Epoch 97 --- loss:1.772, Epoch accuracy:20.44%, Validation loss:1.829, Validation accuracy:38.67%
# Epoch 98: iteration 7/8
# Epoch 98 --- loss:1.786, Epoch accuracy:18.90%, Validation loss:1.826, Validation accuracy:39.00%
# Epoch 99: iteration 7/8
# Epoch 99 --- loss:1.785, Epoch accuracy:19.25%, Validation loss:1.822, Validation accuracy:39.17%
# Epoch 100: iteration 7/8
# Epoch 100 --- loss:1.781, Epoch accuracy:21.89%, Validation loss:1.818, Validation accuracy:40.00%
# Epoch 101: iteration 7/8
# Epoch 101 --- loss:1.762, Epoch accuracy:22.15%, Validation loss:1.815, Validation accuracy:40.00%
# Epoch 102: iteration 7/8
# Epoch 102 --- loss:1.766, Epoch accuracy:22.11%, Validation loss:1.810, Validation accuracy:39.83%
# Epoch 103: iteration 7/8
# Epoch 103 --- loss:1.767, Epoch accuracy:21.23%, Validation loss:1.806, Validation accuracy:40.17%
# Epoch 104: iteration 7/8
# Epoch 104 --- loss:1.765, Epoch accuracy:21.10%, Validation loss:1.802, Validation accuracy:40.67%
# Epoch 105: iteration 7/8
# Epoch 105 --- loss:1.779, Epoch accuracy:20.79%, Validation loss:1.798, Validation accuracy:40.67%
# Epoch 106: iteration 7/8
# Epoch 106 --- loss:1.774, Epoch accuracy:21.84%, Validation loss:1.794, Validation accuracy:41.67%
# Epoch 107: iteration 7/8
# Epoch 107 --- loss:1.773, Epoch accuracy:21.23%, Validation loss:1.790, Validation accuracy:42.33%
# Epoch 108: iteration 7/8
# Epoch 108 --- loss:1.747, Epoch accuracy:22.85%, Validation loss:1.787, Validation accuracy:42.00%
# Epoch 109: iteration 7/8
# Epoch 109 --- loss:1.759, Epoch accuracy:22.76%, Validation loss:1.783, Validation accuracy:42.17%
# Epoch 110: iteration 7/8
# Epoch 110 --- loss:1.769, Epoch accuracy:21.67%, Validation loss:1.779, Validation accuracy:42.33%
# Epoch 111: iteration 7/8
# Epoch 111 --- loss:1.763, Epoch accuracy:22.11%, Validation loss:1.775, Validation accuracy:42.50%
# Epoch 112: iteration 7/8
# Epoch 112 --- loss:1.748, Epoch accuracy:23.07%, Validation loss:1.770, Validation accuracy:43.00%
# Epoch 113: iteration 7/8
# Epoch 113 --- loss:1.741, Epoch accuracy:23.55%, Validation loss:1.766, Validation accuracy:43.50%
# Epoch 114: iteration 7/8
# Epoch 114 --- loss:1.755, Epoch accuracy:22.54%, Validation loss:1.762, Validation accuracy:43.17%
# Epoch 115: iteration 7/8
# Epoch 115 --- loss:1.744, Epoch accuracy:23.99%, Validation loss:1.759, Validation accuracy:43.00%
# Epoch 116: iteration 7/8
# Epoch 116 --- loss:1.746, Epoch accuracy:23.38%, Validation loss:1.754, Validation accuracy:43.17%
# Epoch 117: iteration 7/8
# Epoch 117 --- loss:1.735, Epoch accuracy:22.98%, Validation loss:1.751, Validation accuracy:43.33%
# Epoch 118: iteration 7/8
# Epoch 118 --- loss:1.748, Epoch accuracy:23.07%, Validation loss:1.746, Validation accuracy:43.17%
# Epoch 119: iteration 7/8
# Epoch 119 --- loss:1.736, Epoch accuracy:23.51%, Validation loss:1.742, Validation accuracy:43.50%
# Epoch 120: iteration 7/8
# Epoch 120 --- loss:1.733, Epoch accuracy:23.99%, Validation loss:1.739, Validation accuracy:43.67%
# Epoch 121: iteration 7/8
# Epoch 121 --- loss:1.736, Epoch accuracy:23.82%, Validation loss:1.733, Validation accuracy:43.50%
# Epoch 122: iteration 7/8
# Epoch 122 --- loss:1.729, Epoch accuracy:24.25%, Validation loss:1.729, Validation accuracy:43.83%
# Epoch 123: iteration 7/8
# Epoch 123 --- loss:1.734, Epoch accuracy:24.96%, Validation loss:1.726, Validation accuracy:43.50%
# Epoch 124: iteration 7/8
# Epoch 124 --- loss:1.712, Epoch accuracy:25.26%, Validation loss:1.720, Validation accuracy:43.50%
# Epoch 125: iteration 7/8
# Epoch 125 --- loss:1.739, Epoch accuracy:23.46%, Validation loss:1.717, Validation accuracy:43.50%
# Epoch 126: iteration 7/8
# Epoch 126 --- loss:1.716, Epoch accuracy:23.51%, Validation loss:1.712, Validation accuracy:43.67%
# Epoch 127: iteration 7/8
# Epoch 127 --- loss:1.715, Epoch accuracy:24.61%, Validation loss:1.708, Validation accuracy:43.83%
# Epoch 128: iteration 7/8
# Epoch 128 --- loss:1.717, Epoch accuracy:25.83%, Validation loss:1.704, Validation accuracy:44.00%
# Epoch 129: iteration 7/8
# Epoch 129 --- loss:1.712, Epoch accuracy:25.13%, Validation loss:1.698, Validation accuracy:44.17%
# Epoch 130: iteration 7/8
# Epoch 130 --- loss:1.711, Epoch accuracy:25.09%, Validation loss:1.694, Validation accuracy:45.00%
# Epoch 131: iteration 7/8
# Epoch 131 --- loss:1.708, Epoch accuracy:25.39%, Validation loss:1.690, Validation accuracy:45.33%
# Epoch 132: iteration 7/8
# Epoch 132 --- loss:1.697, Epoch accuracy:26.54%, Validation loss:1.686, Validation accuracy:44.50%
# Epoch 133: iteration 7/8
# Epoch 133 --- loss:1.697, Epoch accuracy:26.05%, Validation loss:1.681, Validation accuracy:44.67%
# Epoch 134: iteration 7/8
# Epoch 134 --- loss:1.700, Epoch accuracy:25.22%, Validation loss:1.675, Validation accuracy:45.00%
# Epoch 135: iteration 7/8
# Epoch 135 --- loss:1.697, Epoch accuracy:26.14%, Validation loss:1.671, Validation accuracy:45.17%
# Epoch 136: iteration 7/8
# Epoch 136 --- loss:1.690, Epoch accuracy:26.75%, Validation loss:1.666, Validation accuracy:45.50%
# Epoch 137: iteration 7/8
# Epoch 137 --- loss:1.704, Epoch accuracy:25.75%, Validation loss:1.662, Validation accuracy:45.50%
# Epoch 138: iteration 7/8
# Epoch 138 --- loss:1.682, Epoch accuracy:27.81%, Validation loss:1.658, Validation accuracy:45.50%
# Epoch 139: iteration 7/8
# Epoch 139 --- loss:1.690, Epoch accuracy:27.06%, Validation loss:1.654, Validation accuracy:45.33%
# Epoch 140: iteration 7/8
# Epoch 140 --- loss:1.674, Epoch accuracy:28.16%, Validation loss:1.650, Validation accuracy:45.17%
# Epoch 141: iteration 7/8
# Epoch 141 --- loss:1.676, Epoch accuracy:27.72%, Validation loss:1.645, Validation accuracy:45.33%
# Epoch 142: iteration 7/8
# Epoch 142 --- loss:1.683, Epoch accuracy:27.85%, Validation loss:1.640, Validation accuracy:45.33%
# Epoch 143: iteration 7/8
# Epoch 143 --- loss:1.670, Epoch accuracy:28.86%, Validation loss:1.637, Validation accuracy:45.00%
# Epoch 144: iteration 7/8
# Epoch 144 --- loss:1.670, Epoch accuracy:27.19%, Validation loss:1.632, Validation accuracy:45.33%
# Epoch 145: iteration 7/8
# Epoch 145 --- loss:1.671, Epoch accuracy:27.24%, Validation loss:1.628, Validation accuracy:44.83%
# Epoch 146: iteration 7/8
# Epoch 146 --- loss:1.671, Epoch accuracy:28.42%, Validation loss:1.624, Validation accuracy:45.00%
# Epoch 147: iteration 7/8
# Epoch 147 --- loss:1.659, Epoch accuracy:29.17%, Validation loss:1.619, Validation accuracy:45.50%
# Epoch 148: iteration 7/8
# Epoch 148 --- loss:1.640, Epoch accuracy:29.78%, Validation loss:1.614, Validation accuracy:45.67%
# Epoch 149: iteration 7/8
# Epoch 149 --- loss:1.676, Epoch accuracy:27.32%, Validation loss:1.608, Validation accuracy:46.00%
# Epoch 150: iteration 7/8
# Epoch 150 --- loss:1.663, Epoch accuracy:27.54%, Validation loss:1.604, Validation accuracy:46.00%
# Epoch 151: iteration 7/8
# Epoch 151 --- loss:1.652, Epoch accuracy:28.68%, Validation loss:1.600, Validation accuracy:46.33%
# Epoch 152: iteration 7/8
# Epoch 152 --- loss:1.653, Epoch accuracy:27.85%, Validation loss:1.599, Validation accuracy:45.67%
# Epoch 153: iteration 7/8
# Epoch 153 --- loss:1.652, Epoch accuracy:29.04%, Validation loss:1.595, Validation accuracy:45.67%
# Epoch 154: iteration 7/8
# Epoch 154 --- loss:1.649, Epoch accuracy:30.09%, Validation loss:1.592, Validation accuracy:45.33%
# Epoch 155: iteration 7/8
# Epoch 155 --- loss:1.651, Epoch accuracy:29.21%, Validation loss:1.587, Validation accuracy:45.83%
# Epoch 156: iteration 7/8
# Epoch 156 --- loss:1.638, Epoch accuracy:29.52%, Validation loss:1.582, Validation accuracy:46.33%
# Epoch 157: iteration 7/8
# Epoch 157 --- loss:1.634, Epoch accuracy:30.61%, Validation loss:1.578, Validation accuracy:46.17%
# Epoch 158: iteration 7/8
# Epoch 158 --- loss:1.644, Epoch accuracy:29.04%, Validation loss:1.572, Validation accuracy:46.17%
# Epoch 159: iteration 7/8
# Epoch 159 --- loss:1.620, Epoch accuracy:30.70%, Validation loss:1.569, Validation accuracy:46.33%
# Epoch 160: iteration 7/8
# Epoch 160 --- loss:1.632, Epoch accuracy:29.12%, Validation loss:1.564, Validation accuracy:46.50%
# Epoch 161: iteration 7/8
# Epoch 161 --- loss:1.618, Epoch accuracy:30.79%, Validation loss:1.560, Validation accuracy:46.33%
# Epoch 162: iteration 7/8
# Epoch 162 --- loss:1.611, Epoch accuracy:31.32%, Validation loss:1.558, Validation accuracy:45.83%
# Epoch 163: iteration 7/8
# Epoch 163 --- loss:1.614, Epoch accuracy:30.09%, Validation loss:1.551, Validation accuracy:46.33%
# Epoch 164: iteration 7/8
# Epoch 164 --- loss:1.608, Epoch accuracy:32.19%, Validation loss:1.547, Validation accuracy:46.50%
# Epoch 165: iteration 7/8
# Epoch 165 --- loss:1.623, Epoch accuracy:31.27%, Validation loss:1.541, Validation accuracy:47.50%
# Epoch 166: iteration 7/8
# Epoch 166 --- loss:1.614, Epoch accuracy:31.10%, Validation loss:1.540, Validation accuracy:47.17%
# Epoch 167: iteration 7/8
# Epoch 167 --- loss:1.623, Epoch accuracy:30.75%, Validation loss:1.534, Validation accuracy:48.17%
# Epoch 168: iteration 7/8
# Epoch 168 --- loss:1.606, Epoch accuracy:30.88%, Validation loss:1.535, Validation accuracy:47.50%
# Epoch 169: iteration 7/8
# Epoch 169 --- loss:1.600, Epoch accuracy:30.96%, Validation loss:1.529, Validation accuracy:47.17%
# Epoch 170: iteration 7/8
# Epoch 170 --- loss:1.599, Epoch accuracy:32.41%, Validation loss:1.522, Validation accuracy:48.17%
# Epoch 171: iteration 7/8
# Epoch 171 --- loss:1.578, Epoch accuracy:31.58%, Validation loss:1.520, Validation accuracy:48.17%
# Epoch 172: iteration 7/8
# Epoch 172 --- loss:1.593, Epoch accuracy:31.97%, Validation loss:1.515, Validation accuracy:48.00%
# Epoch 173: iteration 7/8
# Epoch 173 --- loss:1.582, Epoch accuracy:32.50%, Validation loss:1.513, Validation accuracy:48.33%
# Epoch 174: iteration 7/8
# Epoch 174 --- loss:1.580, Epoch accuracy:32.11%, Validation loss:1.511, Validation accuracy:48.17%
# Epoch 175: iteration 7/8
# Epoch 175 --- loss:1.592, Epoch accuracy:31.40%, Validation loss:1.505, Validation accuracy:48.50%
# Epoch 176: iteration 7/8
# Epoch 176 --- loss:1.569, Epoch accuracy:34.21%, Validation loss:1.503, Validation accuracy:48.33%
# Epoch 177: iteration 7/8
# Epoch 177 --- loss:1.579, Epoch accuracy:33.11%, Validation loss:1.500, Validation accuracy:48.33%
# Epoch 178: iteration 7/8
# Epoch 178 --- loss:1.578, Epoch accuracy:33.16%, Validation loss:1.493, Validation accuracy:48.83%
# Epoch 179: iteration 7/8
# Epoch 179 --- loss:1.561, Epoch accuracy:31.84%, Validation loss:1.488, Validation accuracy:49.17%
# Epoch 180: iteration 7/8
# Epoch 180 --- loss:1.560, Epoch accuracy:34.74%, Validation loss:1.485, Validation accuracy:48.17%
# Epoch 181: iteration 7/8
# Epoch 181 --- loss:1.553, Epoch accuracy:35.96%, Validation loss:1.481, Validation accuracy:48.00%
# Epoch 182: iteration 7/8
# Epoch 182 --- loss:1.571, Epoch accuracy:33.90%, Validation loss:1.481, Validation accuracy:48.00%
# Epoch 183: iteration 7/8
# Epoch 183 --- loss:1.561, Epoch accuracy:34.25%, Validation loss:1.476, Validation accuracy:48.33%
# Epoch 184: iteration 7/8
# Epoch 184 --- loss:1.542, Epoch accuracy:33.64%, Validation loss:1.473, Validation accuracy:48.83%
# Epoch 185: iteration 7/8
# Epoch 185 --- loss:1.546, Epoch accuracy:34.74%, Validation loss:1.468, Validation accuracy:48.83%
# Epoch 186: iteration 7/8
# Epoch 186 --- loss:1.558, Epoch accuracy:35.57%, Validation loss:1.465, Validation accuracy:48.83%
# Epoch 187: iteration 7/8
# Epoch 187 --- loss:1.545, Epoch accuracy:34.56%, Validation loss:1.461, Validation accuracy:49.67%
# Epoch 188: iteration 7/8
# Epoch 188 --- loss:1.547, Epoch accuracy:35.26%, Validation loss:1.458, Validation accuracy:49.83%
# Epoch 189: iteration 7/8
# Epoch 189 --- loss:1.545, Epoch accuracy:35.22%, Validation loss:1.456, Validation accuracy:49.83%
# Epoch 190: iteration 7/8
# Epoch 190 --- loss:1.532, Epoch accuracy:35.39%, Validation loss:1.449, Validation accuracy:49.33%
# Epoch 191: iteration 7/8
# Epoch 191 --- loss:1.513, Epoch accuracy:36.54%, Validation loss:1.448, Validation accuracy:49.67%
# Epoch 192: iteration 7/8
# Epoch 192 --- loss:1.519, Epoch accuracy:36.58%, Validation loss:1.443, Validation accuracy:49.33%
# Epoch 193: iteration 7/8
# Epoch 193 --- loss:1.509, Epoch accuracy:36.93%, Validation loss:1.443, Validation accuracy:49.17%
# Epoch 194: iteration 7/8
# Epoch 194 --- loss:1.518, Epoch accuracy:35.92%, Validation loss:1.441, Validation accuracy:49.67%
# Epoch 195: iteration 7/8
# Epoch 195 --- loss:1.517, Epoch accuracy:35.39%, Validation loss:1.437, Validation accuracy:49.67%
# Epoch 196: iteration 7/8
# Epoch 196 --- loss:1.501, Epoch accuracy:36.01%, Validation loss:1.434, Validation accuracy:49.33%
# Epoch 197: iteration 7/8
# Epoch 197 --- loss:1.521, Epoch accuracy:35.22%, Validation loss:1.429, Validation accuracy:50.00%
# Epoch 198: iteration 7/8
# Epoch 198 --- loss:1.497, Epoch accuracy:36.23%, Validation loss:1.429, Validation accuracy:50.00%
# Epoch 199: iteration 7/8
# Epoch 199 --- loss:1.507, Epoch accuracy:36.32%, Validation loss:1.421, Validation accuracy:50.17%
# Epoch 200: iteration 7/8
# Epoch 200 --- loss:1.492, Epoch accuracy:36.97%, Validation loss:1.418, Validation accuracy:50.33%
# Epoch 201: iteration 7/8
# Epoch 201 --- loss:1.491, Epoch accuracy:36.89%, Validation loss:1.416, Validation accuracy:50.17%
# Epoch 202: iteration 7/8
# Epoch 202 --- loss:1.493, Epoch accuracy:37.85%, Validation loss:1.415, Validation accuracy:50.00%
# Epoch 203: iteration 7/8
# Epoch 203 --- loss:1.500, Epoch accuracy:37.68%, Validation loss:1.411, Validation accuracy:50.50%
# Epoch 204: iteration 7/8
# Epoch 204 --- loss:1.488, Epoch accuracy:37.15%, Validation loss:1.408, Validation accuracy:51.00%
# Epoch 205: iteration 7/8
# Epoch 205 --- loss:1.477, Epoch accuracy:38.68%, Validation loss:1.406, Validation accuracy:51.00%
# Epoch 206: iteration 7/8
# Epoch 206 --- loss:1.491, Epoch accuracy:36.10%, Validation loss:1.407, Validation accuracy:50.33%
# Epoch 207: iteration 7/8
# Epoch 207 --- loss:1.471, Epoch accuracy:38.64%, Validation loss:1.402, Validation accuracy:50.83%
# Epoch 208: iteration 7/8
# Epoch 208 --- loss:1.469, Epoch accuracy:37.76%, Validation loss:1.398, Validation accuracy:50.67%
# Epoch 209: iteration 7/8
# Epoch 209 --- loss:1.466, Epoch accuracy:39.43%, Validation loss:1.395, Validation accuracy:51.00%
# Epoch 210: iteration 7/8
# Epoch 210 --- loss:1.483, Epoch accuracy:38.11%, Validation loss:1.396, Validation accuracy:51.50%
# Epoch 211: iteration 7/8
# Epoch 211 --- loss:1.458, Epoch accuracy:39.08%, Validation loss:1.393, Validation accuracy:50.67%
# Epoch 212: iteration 7/8
# Epoch 212 --- loss:1.460, Epoch accuracy:38.20%, Validation loss:1.387, Validation accuracy:51.50%
# Epoch 213: iteration 7/8
# Epoch 213 --- loss:1.459, Epoch accuracy:38.33%, Validation loss:1.389, Validation accuracy:51.50%
# Epoch 214: iteration 7/8
# Epoch 214 --- loss:1.452, Epoch accuracy:39.12%, Validation loss:1.383, Validation accuracy:51.83%
# Epoch 215: iteration 7/8
# Epoch 215 --- loss:1.444, Epoch accuracy:39.61%, Validation loss:1.382, Validation accuracy:51.67%
# Epoch 216: iteration 7/8
# Epoch 216 --- loss:1.449, Epoch accuracy:39.12%, Validation loss:1.379, Validation accuracy:51.50%
# Epoch 217: iteration 7/8
# Epoch 217 --- loss:1.450, Epoch accuracy:38.29%, Validation loss:1.378, Validation accuracy:51.67%
# Epoch 218: iteration 7/8
# Epoch 218 --- loss:1.455, Epoch accuracy:38.38%, Validation loss:1.368, Validation accuracy:51.83%
# Epoch 219: iteration 7/8
# Epoch 219 --- loss:1.442, Epoch accuracy:39.43%, Validation loss:1.366, Validation accuracy:51.83%
# Epoch 220: iteration 7/8
# Epoch 220 --- loss:1.438, Epoch accuracy:39.34%, Validation loss:1.360, Validation accuracy:52.67%
# Epoch 221: iteration 7/8
# Epoch 221 --- loss:1.448, Epoch accuracy:38.73%, Validation loss:1.366, Validation accuracy:52.00%
# Epoch 222: iteration 7/8
# Epoch 222 --- loss:1.424, Epoch accuracy:40.35%, Validation loss:1.359, Validation accuracy:52.33%
# Epoch 223: iteration 7/8
# Epoch 223 --- loss:1.419, Epoch accuracy:40.31%, Validation loss:1.352, Validation accuracy:52.67%
# Epoch 224: iteration 7/8
# Epoch 224 --- loss:1.417, Epoch accuracy:40.39%, Validation loss:1.348, Validation accuracy:52.83%
# Epoch 225: iteration 7/8
# Epoch 225 --- loss:1.401, Epoch accuracy:41.27%, Validation loss:1.344, Validation accuracy:53.17%
# Epoch 226: iteration 7/8
# Epoch 226 --- loss:1.404, Epoch accuracy:40.96%, Validation loss:1.348, Validation accuracy:53.33%
# Epoch 227: iteration 7/8
# Epoch 227 --- loss:1.394, Epoch accuracy:42.63%, Validation loss:1.347, Validation accuracy:53.33%
# Epoch 228: iteration 7/8
# Epoch 228 --- loss:1.405, Epoch accuracy:41.54%, Validation loss:1.343, Validation accuracy:53.50%
# Epoch 229: iteration 7/8
# Epoch 229 --- loss:1.394, Epoch accuracy:41.27%, Validation loss:1.347, Validation accuracy:52.83%
# Epoch 230: iteration 7/8
# Epoch 230 --- loss:1.395, Epoch accuracy:41.80%, Validation loss:1.341, Validation accuracy:53.33%
# Epoch 231: iteration 7/8
# Epoch 231 --- loss:1.386, Epoch accuracy:42.06%, Validation loss:1.338, Validation accuracy:53.17%
# Epoch 232: iteration 7/8
# Epoch 232 --- loss:1.378, Epoch accuracy:43.77%, Validation loss:1.330, Validation accuracy:53.67%
# Epoch 233: iteration 7/8
# Epoch 233 --- loss:1.391, Epoch accuracy:43.25%, Validation loss:1.334, Validation accuracy:54.17%
# Epoch 234: iteration 7/8
# Epoch 234 --- loss:1.385, Epoch accuracy:41.14%, Validation loss:1.328, Validation accuracy:54.00%
# Epoch 235: iteration 7/8
# Epoch 235 --- loss:1.381, Epoch accuracy:42.46%, Validation loss:1.327, Validation accuracy:54.00%
# Epoch 236: iteration 7/8
# Epoch 236 --- loss:1.374, Epoch accuracy:42.15%, Validation loss:1.321, Validation accuracy:54.33%
# Epoch 237: iteration 7/8
# Epoch 237 --- loss:1.358, Epoch accuracy:44.34%, Validation loss:1.320, Validation accuracy:54.00%
# Epoch 238: iteration 7/8
# Epoch 238 --- loss:1.369, Epoch accuracy:43.25%, Validation loss:1.328, Validation accuracy:53.67%
# Epoch 239: iteration 7/8
# Epoch 239 --- loss:1.352, Epoch accuracy:43.86%, Validation loss:1.328, Validation accuracy:53.50%
# Epoch 240: iteration 7/8
# Epoch 240 --- loss:1.372, Epoch accuracy:42.94%, Validation loss:1.323, Validation accuracy:53.67%
# Epoch 241: iteration 7/8
# Epoch 241 --- loss:1.354, Epoch accuracy:44.43%, Validation loss:1.319, Validation accuracy:53.50%
# Epoch 242: iteration 7/8
# Epoch 242 --- loss:1.355, Epoch accuracy:43.07%, Validation loss:1.319, Validation accuracy:53.67%
# Epoch 243: iteration 7/8
# Epoch 243 --- loss:1.351, Epoch accuracy:44.04%, Validation loss:1.314, Validation accuracy:54.00%
# Epoch 244: iteration 7/8
# Epoch 244 --- loss:1.333, Epoch accuracy:45.22%, Validation loss:1.308, Validation accuracy:54.17%
# Epoch 245: iteration 7/8
# Epoch 245 --- loss:1.349, Epoch accuracy:43.33%, Validation loss:1.304, Validation accuracy:54.33%
# Epoch 246: iteration 7/8
# Epoch 246 --- loss:1.348, Epoch accuracy:43.64%, Validation loss:1.310, Validation accuracy:54.00%
# Epoch 247: iteration 7/8
# Epoch 247 --- loss:1.349, Epoch accuracy:43.42%, Validation loss:1.305, Validation accuracy:53.83%
# Epoch 248: iteration 7/8
# Epoch 248 --- loss:1.326, Epoch accuracy:45.75%, Validation loss:1.298, Validation accuracy:54.00%
# Epoch 249: iteration 7/8
# Epoch 249 --- loss:1.319, Epoch accuracy:45.26%, Validation loss:1.296, Validation accuracy:54.00%
# Epoch 250: iteration 7/8
# Epoch 250 --- loss:1.312, Epoch accuracy:46.80%, Validation loss:1.300, Validation accuracy:53.50%
# Epoch 251: iteration 7/8
# Epoch 251 --- loss:1.300, Epoch accuracy:46.93%, Validation loss:1.297, Validation accuracy:53.50%
# Epoch 252: iteration 7/8
# Epoch 252 --- loss:1.312, Epoch accuracy:45.26%, Validation loss:1.288, Validation accuracy:54.00%
# Epoch 253: iteration 7/8
# Epoch 253 --- loss:1.309, Epoch accuracy:44.78%, Validation loss:1.285, Validation accuracy:53.83%
# Epoch 254: iteration 7/8
# Epoch 254 --- loss:1.307, Epoch accuracy:44.82%, Validation loss:1.287, Validation accuracy:53.50%
# Epoch 255: iteration 7/8
# Epoch 255 --- loss:1.301, Epoch accuracy:45.83%, Validation loss:1.287, Validation accuracy:54.00%
# Epoch 256: iteration 7/8
# Epoch 256 --- loss:1.307, Epoch accuracy:45.57%, Validation loss:1.285, Validation accuracy:54.00%
# Epoch 257: iteration 7/8
# Epoch 257 --- loss:1.286, Epoch accuracy:47.41%, Validation loss:1.287, Validation accuracy:53.83%
# Epoch 258: iteration 7/8
# Epoch 258 --- loss:1.288, Epoch accuracy:46.27%, Validation loss:1.280, Validation accuracy:54.00%
# Epoch 259: iteration 7/8
# Epoch 259 --- loss:1.297, Epoch accuracy:46.36%, Validation loss:1.284, Validation accuracy:53.67%
# Epoch 260: iteration 7/8
# Epoch 260 --- loss:1.302, Epoch accuracy:46.54%, Validation loss:1.286, Validation accuracy:54.17%
# Epoch 261: iteration 7/8
# Epoch 261 --- loss:1.300, Epoch accuracy:45.83%, Validation loss:1.281, Validation accuracy:53.83%
# Epoch 262: iteration 7/8
# Epoch 262 --- loss:1.280, Epoch accuracy:47.32%, Validation loss:1.285, Validation accuracy:53.67%
# Epoch 263: iteration 7/8
# Epoch 263 --- loss:1.288, Epoch accuracy:45.70%, Validation loss:1.284, Validation accuracy:53.17%
# Epoch 264: iteration 7/8
# Epoch 264 --- loss:1.267, Epoch accuracy:49.17%, Validation loss:1.279, Validation accuracy:53.33%
# Epoch 265: iteration 7/8
# Epoch 265 --- loss:1.272, Epoch accuracy:47.11%, Validation loss:1.281, Validation accuracy:53.50%
# Epoch 266: iteration 7/8
# Epoch 266 --- loss:1.255, Epoch accuracy:48.42%, Validation loss:1.280, Validation accuracy:53.50%
# Epoch 267: iteration 7/8
# Epoch 267 --- loss:1.260, Epoch accuracy:47.59%, Validation loss:1.272, Validation accuracy:54.17%
# Epoch 268: iteration 7/8
# Epoch 268 --- loss:1.251, Epoch accuracy:47.68%, Validation loss:1.271, Validation accuracy:54.17%
# Epoch 269: iteration 7/8
# Epoch 269 --- loss:1.257, Epoch accuracy:48.25%, Validation loss:1.267, Validation accuracy:54.50%
# Epoch 270: iteration 7/8
# Epoch 270 --- loss:1.255, Epoch accuracy:48.86%, Validation loss:1.277, Validation accuracy:54.17%
# Epoch 271: iteration 7/8
# Epoch 271 --- loss:1.253, Epoch accuracy:46.93%, Validation loss:1.270, Validation accuracy:54.67%
# Epoch 272: iteration 7/8
# Epoch 272 --- loss:1.256, Epoch accuracy:48.55%, Validation loss:1.261, Validation accuracy:54.83%
# Epoch 273: iteration 7/8
# Epoch 273 --- loss:1.255, Epoch accuracy:48.29%, Validation loss:1.259, Validation accuracy:54.67%
# Epoch 274: iteration 7/8
# Epoch 274 --- loss:1.234, Epoch accuracy:48.51%, Validation loss:1.261, Validation accuracy:55.00%
# Epoch 275: iteration 7/8
# Epoch 275 --- loss:1.237, Epoch accuracy:48.42%, Validation loss:1.264, Validation accuracy:54.67%
# Epoch 276: iteration 7/8
# Epoch 276 --- loss:1.229, Epoch accuracy:50.35%, Validation loss:1.263, Validation accuracy:54.67%
# Epoch 277: iteration 7/8
# Epoch 277 --- loss:1.235, Epoch accuracy:49.17%, Validation loss:1.259, Validation accuracy:55.00%
# Epoch 278: iteration 7/8
# Epoch 278 --- loss:1.226, Epoch accuracy:50.13%, Validation loss:1.258, Validation accuracy:54.83%
# Epoch 279: iteration 7/8
# Epoch 279 --- loss:1.227, Epoch accuracy:49.47%, Validation loss:1.258, Validation accuracy:55.33%
# Epoch 280: iteration 7/8
# Epoch 280 --- loss:1.227, Epoch accuracy:50.04%, Validation loss:1.256, Validation accuracy:55.33%
# Epoch 281: iteration 7/8
# Epoch 281 --- loss:1.219, Epoch accuracy:49.87%, Validation loss:1.252, Validation accuracy:55.00%
# Epoch 282: iteration 7/8
# Epoch 282 --- loss:1.196, Epoch accuracy:50.88%, Validation loss:1.242, Validation accuracy:55.50%
# Epoch 283: iteration 7/8
# Epoch 283 --- loss:1.203, Epoch accuracy:50.66%, Validation loss:1.244, Validation accuracy:55.50%
# Epoch 284: iteration 7/8
# Epoch 284 --- loss:1.221, Epoch accuracy:49.25%, Validation loss:1.244, Validation accuracy:55.00%
# Epoch 285: iteration 7/8
# Epoch 285 --- loss:1.207, Epoch accuracy:50.13%, Validation loss:1.243, Validation accuracy:55.17%
# Epoch 286: iteration 7/8
# Epoch 286 --- loss:1.202, Epoch accuracy:51.27%, Validation loss:1.236, Validation accuracy:55.33%
# Epoch 287: iteration 7/8
# Epoch 287 --- loss:1.190, Epoch accuracy:50.70%, Validation loss:1.237, Validation accuracy:55.83%
# Epoch 288: iteration 7/8
# Epoch 288 --- loss:1.186, Epoch accuracy:51.23%, Validation loss:1.234, Validation accuracy:56.33%
# Epoch 289: iteration 7/8
# Epoch 289 --- loss:1.180, Epoch accuracy:52.37%, Validation loss:1.236, Validation accuracy:56.33%
# Epoch 290: iteration 7/8
# Epoch 290 --- loss:1.207, Epoch accuracy:49.69%, Validation loss:1.238, Validation accuracy:56.17%
# Epoch 291: iteration 7/8
# Epoch 291 --- loss:1.184, Epoch accuracy:50.96%, Validation loss:1.231, Validation accuracy:56.50%
# Epoch 292: iteration 7/8
# Epoch 292 --- loss:1.174, Epoch accuracy:50.83%, Validation loss:1.225, Validation accuracy:56.17%
# Epoch 293: iteration 7/8
# Epoch 293 --- loss:1.186, Epoch accuracy:50.88%, Validation loss:1.228, Validation accuracy:55.83%
# Epoch 294: iteration 7/8
# Epoch 294 --- loss:1.162, Epoch accuracy:52.06%, Validation loss:1.226, Validation accuracy:56.50%
# Epoch 295: iteration 7/8
# Epoch 295 --- loss:1.159, Epoch accuracy:52.28%, Validation loss:1.224, Validation accuracy:56.83%
# Epoch 296: iteration 7/8
# Epoch 296 --- loss:1.172, Epoch accuracy:51.14%, Validation loss:1.228, Validation accuracy:57.17%
# Epoch 297: iteration 7/8
# Epoch 297 --- loss:1.169, Epoch accuracy:51.75%, Validation loss:1.226, Validation accuracy:57.17%
# Epoch 298: iteration 7/8
# Epoch 298 --- loss:1.146, Epoch accuracy:52.89%, Validation loss:1.220, Validation accuracy:57.17%
# Epoch 299: iteration 7/8
# Epoch 299 --- loss:1.146, Epoch accuracy:53.11%, Validation loss:1.226, Validation accuracy:56.83%
# Epoch 300: iteration 7/8
# Epoch 300 --- loss:1.136, Epoch accuracy:53.46%, Validation loss:1.227, Validation accuracy:56.83%
# Epoch 301: iteration 7/8
# Epoch 301 --- loss:1.143, Epoch accuracy:52.98%, Validation loss:1.223, Validation accuracy:57.50%
# Epoch 302: iteration 7/8
# Epoch 302 --- loss:1.133, Epoch accuracy:53.95%, Validation loss:1.228, Validation accuracy:57.33%
# Epoch 303: iteration 7/8
# Epoch 303 --- loss:1.141, Epoch accuracy:52.81%, Validation loss:1.216, Validation accuracy:57.50%
# Epoch 304: iteration 7/8
# Epoch 304 --- loss:1.146, Epoch accuracy:52.63%, Validation loss:1.211, Validation accuracy:58.00%
# Epoch 305: iteration 7/8
# Epoch 305 --- loss:1.123, Epoch accuracy:54.04%, Validation loss:1.210, Validation accuracy:58.17%
# Epoch 306: iteration 7/8
# Epoch 306 --- loss:1.126, Epoch accuracy:54.82%, Validation loss:1.208, Validation accuracy:57.67%
# Epoch 307: iteration 7/8
# Epoch 307 --- loss:1.119, Epoch accuracy:54.87%, Validation loss:1.213, Validation accuracy:57.17%
# Epoch 308: iteration 7/8
# Epoch 308 --- loss:1.124, Epoch accuracy:54.04%, Validation loss:1.210, Validation accuracy:57.50%
# Epoch 309: iteration 7/8
# Epoch 309 --- loss:1.112, Epoch accuracy:55.04%, Validation loss:1.212, Validation accuracy:57.67%
# Epoch 310: iteration 7/8
# Epoch 310 --- loss:1.109, Epoch accuracy:53.25%, Validation loss:1.210, Validation accuracy:57.67%
# Epoch 311: iteration 7/8
# Epoch 311 --- loss:1.110, Epoch accuracy:54.25%, Validation loss:1.204, Validation accuracy:57.00%
# Epoch 312: iteration 7/8
# Epoch 312 --- loss:1.102, Epoch accuracy:56.23%, Validation loss:1.212, Validation accuracy:57.17%
# Epoch 313: iteration 7/8
# Epoch 313 --- loss:1.106, Epoch accuracy:54.69%, Validation loss:1.210, Validation accuracy:57.33%
# Epoch 314: iteration 7/8
# Epoch 314 --- loss:1.085, Epoch accuracy:57.15%, Validation loss:1.214, Validation accuracy:56.83%
# Epoch 315: iteration 7/8
# Epoch 315 --- loss:1.096, Epoch accuracy:54.87%, Validation loss:1.216, Validation accuracy:57.00%
# Epoch 316: iteration 7/8
# Epoch 316 --- loss:1.084, Epoch accuracy:55.22%, Validation loss:1.216, Validation accuracy:57.00%
# Epoch 317: iteration 7/8
# Epoch 317 --- loss:1.095, Epoch accuracy:55.70%, Validation loss:1.215, Validation accuracy:56.83%
# Epoch 318: iteration 7/8
# Epoch 318 --- loss:1.075, Epoch accuracy:56.23%, Validation loss:1.205, Validation accuracy:57.83%
# Epoch 319: iteration 7/8
# Epoch 319 --- loss:1.077, Epoch accuracy:55.70%, Validation loss:1.217, Validation accuracy:56.50%
# Epoch 320: iteration 7/8
# Epoch 320 --- loss:1.076, Epoch accuracy:57.19%, Validation loss:1.217, Validation accuracy:56.67%
# Epoch 321: iteration 7/8
# Epoch 321 --- loss:1.076, Epoch accuracy:56.75%, Validation loss:1.212, Validation accuracy:56.33%
# Epoch 322: iteration 7/8
# Epoch 322 --- loss:1.083, Epoch accuracy:56.27%, Validation loss:1.206, Validation accuracy:57.33%
# Epoch 323: iteration 7/8
# Epoch 323 --- loss:1.042, Epoch accuracy:58.11%, Validation loss:1.197, Validation accuracy:57.67%
# Epoch 324: iteration 7/8
# Epoch 324 --- loss:1.071, Epoch accuracy:56.36%, Validation loss:1.190, Validation accuracy:57.50%
# Epoch 325: iteration 7/8
# Epoch 325 --- loss:1.063, Epoch accuracy:56.75%, Validation loss:1.200, Validation accuracy:57.17%
# Epoch 326: iteration 7/8
# Epoch 326 --- loss:1.056, Epoch accuracy:57.50%, Validation loss:1.196, Validation accuracy:57.83%
# Epoch 327: iteration 7/8
# Epoch 327 --- loss:1.046, Epoch accuracy:57.28%, Validation loss:1.204, Validation accuracy:57.50%
# Epoch 328: iteration 7/8
# Epoch 328 --- loss:1.055, Epoch accuracy:56.97%, Validation loss:1.202, Validation accuracy:57.50%
# Epoch 329: iteration 7/8
# Epoch 329 --- loss:1.041, Epoch accuracy:58.25%, Validation loss:1.203, Validation accuracy:57.17%
# Epoch 330: iteration 7/8
# Epoch 330 --- loss:1.026, Epoch accuracy:57.98%, Validation loss:1.193, Validation accuracy:57.50%
# Epoch 331: iteration 7/8
# Epoch 331 --- loss:1.037, Epoch accuracy:57.68%, Validation loss:1.200, Validation accuracy:57.33%
# Epoch 332: iteration 7/8
# Epoch 332 --- loss:1.042, Epoch accuracy:57.32%, Validation loss:1.199, Validation accuracy:57.17%
# Epoch 333: iteration 7/8
# Epoch 333 --- loss:1.038, Epoch accuracy:57.76%, Validation loss:1.200, Validation accuracy:57.33%
# Epoch 334: iteration 7/8
# Epoch 334 --- loss:1.031, Epoch accuracy:58.90%, Validation loss:1.202, Validation accuracy:57.00%
# Epoch 335: iteration 7/8
# Epoch 335 --- loss:1.023, Epoch accuracy:58.90%, Validation loss:1.190, Validation accuracy:57.33%
# Epoch 336: iteration 7/8
# Epoch 336 --- loss:1.020, Epoch accuracy:58.64%, Validation loss:1.198, Validation accuracy:57.17%
# Epoch 337: iteration 7/8
# Epoch 337 --- loss:1.033, Epoch accuracy:58.20%, Validation loss:1.193, Validation accuracy:57.17%
# Epoch 338: iteration 7/8
# Epoch 338 --- loss:1.002, Epoch accuracy:60.09%, Validation loss:1.194, Validation accuracy:57.00%
# Epoch 339: iteration 7/8
# Epoch 339 --- loss:1.001, Epoch accuracy:59.82%, Validation loss:1.197, Validation accuracy:57.00%
# Epoch 340: iteration 7/8
# Epoch 340 --- loss:1.001, Epoch accuracy:59.78%, Validation loss:1.198, Validation accuracy:56.50%
# Epoch 341: iteration 7/8
# Epoch 341 --- loss:0.993, Epoch accuracy:59.91%, Validation loss:1.199, Validation accuracy:56.33%
# Epoch 342: iteration 7/8
# Epoch 342 --- loss:0.994, Epoch accuracy:60.57%, Validation loss:1.202, Validation accuracy:56.17%
# Epoch 343: iteration 7/8
# Epoch 343 --- loss:0.987, Epoch accuracy:60.44%, Validation loss:1.202, Validation accuracy:56.17%
# Epoch 344: iteration 7/8
# Epoch 344 --- loss:0.984, Epoch accuracy:59.34%, Validation loss:1.204, Validation accuracy:56.17%
# Epoch 345: iteration 7/8
# Epoch 345 --- loss:0.985, Epoch accuracy:59.61%, Validation loss:1.201, Validation accuracy:56.00%
# Epoch 346: iteration 7/8
# Epoch 346 --- loss:0.979, Epoch accuracy:60.18%, Validation loss:1.199, Validation accuracy:56.50%
# Epoch 347: iteration 7/8
# Epoch 347 --- loss:0.978, Epoch accuracy:61.32%, Validation loss:1.195, Validation accuracy:57.17%
# Epoch 348: iteration 7/8
# Epoch 348 --- loss:0.981, Epoch accuracy:60.35%, Validation loss:1.188, Validation accuracy:56.67%
# Epoch 349: iteration 7/8
# Epoch 349 --- loss:0.974, Epoch accuracy:60.31%, Validation loss:1.193, Validation accuracy:56.50%
# Epoch 350: iteration 7/8
# Epoch 350 --- loss:0.966, Epoch accuracy:60.26%, Validation loss:1.200, Validation accuracy:56.17%
# Epoch 351: iteration 7/8
# Epoch 351 --- loss:0.971, Epoch accuracy:59.56%, Validation loss:1.201, Validation accuracy:56.00%
# Epoch 352: iteration 7/8
# Epoch 352 --- loss:0.961, Epoch accuracy:62.37%, Validation loss:1.201, Validation accuracy:56.50%
# Epoch 353: iteration 7/8
# Epoch 353 --- loss:0.972, Epoch accuracy:60.75%, Validation loss:1.202, Validation accuracy:56.17%
# Epoch 354: iteration 7/8
# Epoch 354 --- loss:0.960, Epoch accuracy:61.67%, Validation loss:1.197, Validation accuracy:56.00%
# Epoch 355: iteration 7/8
# Epoch 355 --- loss:0.970, Epoch accuracy:59.87%, Validation loss:1.197, Validation accuracy:56.33%
# Epoch 356: iteration 7/8
# Epoch 356 --- loss:0.953, Epoch accuracy:61.62%, Validation loss:1.193, Validation accuracy:56.50%
# Epoch 357: iteration 7/8
# Epoch 357 --- loss:0.952, Epoch accuracy:60.96%, Validation loss:1.189, Validation accuracy:56.83%
# Epoch 358: iteration 7/8
# Epoch 358 --- loss:0.934, Epoch accuracy:62.41%, Validation loss:1.191, Validation accuracy:56.17%
# Epoch 359: iteration 7/8
# Epoch 359 --- loss:0.945, Epoch accuracy:61.89%, Validation loss:1.197, Validation accuracy:55.67%
# Epoch 360: iteration 7/8
# Epoch 360 --- loss:0.935, Epoch accuracy:62.63%, Validation loss:1.193, Validation accuracy:56.33%
# Epoch 361: iteration 7/8
# Epoch 361 --- loss:0.921, Epoch accuracy:63.16%, Validation loss:1.196, Validation accuracy:56.17%
# Epoch 362: iteration 7/8
# Epoch 362 --- loss:0.926, Epoch accuracy:62.94%, Validation loss:1.197, Validation accuracy:56.00%
# Epoch 363: iteration 7/8
# Epoch 363 --- loss:0.934, Epoch accuracy:62.06%, Validation loss:1.192, Validation accuracy:56.33%
# Epoch 364: iteration 7/8
# Epoch 364 --- loss:0.906, Epoch accuracy:63.51%, Validation loss:1.198, Validation accuracy:56.17%
# Epoch 365: iteration 7/8
# Epoch 365 --- loss:0.907, Epoch accuracy:63.77%, Validation loss:1.192, Validation accuracy:56.83%
# Epoch 366: iteration 7/8
# Epoch 366 --- loss:0.920, Epoch accuracy:62.68%, Validation loss:1.197, Validation accuracy:56.33%
# Epoch 367: iteration 7/8
# Epoch 367 --- loss:0.924, Epoch accuracy:63.55%, Validation loss:1.200, Validation accuracy:55.83%
# Epoch 368: iteration 7/8
# Epoch 368 --- loss:0.888, Epoch accuracy:63.95%, Validation loss:1.200, Validation accuracy:55.83%
# Epoch 369: iteration 7/8
# Epoch 369 --- loss:0.918, Epoch accuracy:63.11%, Validation loss:1.196, Validation accuracy:56.50%
# Epoch 370: iteration 7/8
# Epoch 370 --- loss:0.896, Epoch accuracy:64.12%, Validation loss:1.191, Validation accuracy:56.83%
# Epoch 371: iteration 7/8
# Epoch 371 --- loss:0.889, Epoch accuracy:63.64%, Validation loss:1.198, Validation accuracy:56.17%
# Epoch 372: iteration 7/8
# Epoch 372 --- loss:0.891, Epoch accuracy:64.21%, Validation loss:1.194, Validation accuracy:56.33%
# Epoch 373: iteration 7/8
# Epoch 373 --- loss:0.895, Epoch accuracy:62.98%, Validation loss:1.186, Validation accuracy:56.50%
# Epoch 374: iteration 7/8
# Epoch 374 --- loss:0.898, Epoch accuracy:63.46%, Validation loss:1.196, Validation accuracy:56.33%
# Epoch 375: iteration 7/8
# Epoch 375 --- loss:0.885, Epoch accuracy:64.91%, Validation loss:1.192, Validation accuracy:56.17%
# Epoch 376: iteration 7/8
# Epoch 376 --- loss:0.889, Epoch accuracy:63.11%, Validation loss:1.188, Validation accuracy:56.50%
# Epoch 377: iteration 7/8
# Epoch 377 --- loss:0.870, Epoch accuracy:65.57%, Validation loss:1.193, Validation accuracy:55.83%
# Epoch 378: iteration 7/8
# Epoch 378 --- loss:0.888, Epoch accuracy:64.12%, Validation loss:1.192, Validation accuracy:56.50%
# Epoch 379: iteration 7/8
# Epoch 379 --- loss:0.872, Epoch accuracy:65.48%, Validation loss:1.190, Validation accuracy:56.50%
# Epoch 380: iteration 7/8
# Epoch 380 --- loss:0.878, Epoch accuracy:64.43%, Validation loss:1.192, Validation accuracy:56.17%
# Epoch 381: iteration 7/8
# Epoch 381 --- loss:0.862, Epoch accuracy:65.13%, Validation loss:1.194, Validation accuracy:55.83%
# Epoch 382: iteration 7/8
# Epoch 382 --- loss:0.841, Epoch accuracy:66.67%, Validation loss:1.189, Validation accuracy:55.83%
# Epoch 383: iteration 7/8
# Epoch 383 --- loss:0.854, Epoch accuracy:66.40%, Validation loss:1.187, Validation accuracy:56.33%
# Epoch 384: iteration 7/8
# Epoch 384 --- loss:0.850, Epoch accuracy:65.66%, Validation loss:1.190, Validation accuracy:56.00%
# Epoch 385: iteration 7/8
# Epoch 385 --- loss:0.842, Epoch accuracy:65.39%, Validation loss:1.190, Validation accuracy:56.33%
# Epoch 386: iteration 7/8
# Epoch 386 --- loss:0.834, Epoch accuracy:66.18%, Validation loss:1.188, Validation accuracy:56.00%
# Epoch 387: iteration 7/8
# Epoch 387 --- loss:0.852, Epoch accuracy:65.26%, Validation loss:1.188, Validation accuracy:56.33%
# ...
# Epoch 872: iteration 7/8
# Epoch 872 --- loss:0.094, Epoch accuracy:89.30%, Validation loss:1.620, Validation accuracy:51.83%
# Epoch 873: iteration 7/8
# Epoch 873 --- loss:0.098, Epoch accuracy:89.43%, Validation loss:1.636, Validation accuracy:51.50%
# Epoch 874: iteration 7/8
# Epoch 874 --- loss:0.093, Epoch accuracy:89.47%, Validation loss:1.633, Validation accuracy:51.50%
# Epoch 875: iteration 7/8
# Epoch 875 --- loss:0.096, Epoch accuracy:89.52%, Validation loss:1.633, Validation accuracy:51.67%
# Epoch 876: iteration 7/8
# Epoch 876 --- loss:0.096, Epoch accuracy:89.30%, Validation loss:1.631, Validation accuracy:51.67%
# Epoch 877: iteration 7/8
# Epoch 877 --- loss:0.092, Epoch accuracy:89.47%, Validation loss:1.628, Validation accuracy:51.67%
# Epoch 878: iteration 7/8
# Epoch 878 --- loss:0.090, Epoch accuracy:89.56%, Validation loss:1.636, Validation accuracy:51.50%
# Epoch 879: iteration 7/8
# Epoch 879 --- loss:0.093, Epoch accuracy:89.39%, Validation loss:1.628, Validation accuracy:51.67%
# Epoch 880: iteration 7/8
# Epoch 880 --- loss:0.092, Epoch accuracy:89.43%, Validation loss:1.638, Validation accuracy:51.33%
# Epoch 881: iteration 7/8
# Epoch 881 --- loss:0.090, Epoch accuracy:89.39%, Validation loss:1.639, Validation accuracy:51.50%
# Epoch 882: iteration 7/8
# Epoch 882 --- loss:0.094, Epoch accuracy:89.43%, Validation loss:1.634, Validation accuracy:51.33%
# Epoch 883: iteration 7/8
# Epoch 883 --- loss:0.091, Epoch accuracy:89.43%, Validation loss:1.642, Validation accuracy:51.00%
# Epoch 884: iteration 7/8
# Epoch 884 --- loss:0.092, Epoch accuracy:89.30%, Validation loss:1.645, Validation accuracy:51.17%
# Epoch 885: iteration 7/8
# Epoch 885 --- loss:0.095, Epoch accuracy:89.56%, Validation loss:1.643, Validation accuracy:51.67%
# Epoch 886: iteration 7/8
# Epoch 886 --- loss:0.091, Epoch accuracy:89.30%, Validation loss:1.636, Validation accuracy:51.83%
# Epoch 887: iteration 7/8
# Epoch 887 --- loss:0.091, Epoch accuracy:89.21%, Validation loss:1.640, Validation accuracy:51.67%
# Epoch 888: iteration 7/8
# Epoch 888 --- loss:0.091, Epoch accuracy:89.21%, Validation loss:1.637, Validation accuracy:51.83%
# Epoch 889: iteration 7/8
# Epoch 889 --- loss:0.087, Epoch accuracy:89.34%, Validation loss:1.645, Validation accuracy:51.67%
# Epoch 890: iteration 7/8
# Epoch 890 --- loss:0.093, Epoch accuracy:89.34%, Validation loss:1.636, Validation accuracy:51.83%
# Epoch 891: iteration 7/8
# Epoch 891 --- loss:0.093, Epoch accuracy:89.47%, Validation loss:1.637, Validation accuracy:52.00%
# Epoch 892: iteration 7/8
# Epoch 892 --- loss:0.091, Epoch accuracy:89.56%, Validation loss:1.640, Validation accuracy:52.00%
# Epoch 893: iteration 7/8
# Epoch 893 --- loss:0.087, Epoch accuracy:89.56%, Validation loss:1.638, Validation accuracy:51.83%
# Epoch 894: iteration 7/8
# Epoch 894 --- loss:0.091, Epoch accuracy:89.30%, Validation loss:1.642, Validation accuracy:51.33%
# Epoch 895: iteration 7/8
# Epoch 895 --- loss:0.089, Epoch accuracy:89.43%, Validation loss:1.636, Validation accuracy:51.83%
# Epoch 896: iteration 7/8
# Epoch 896 --- loss:0.090, Epoch accuracy:89.25%, Validation loss:1.639, Validation accuracy:51.67%
# Epoch 897: iteration 7/8
# Epoch 897 --- loss:0.087, Epoch accuracy:89.34%, Validation loss:1.647, Validation accuracy:51.83%
# Epoch 898: iteration 7/8
# Epoch 898 --- loss:0.086, Epoch accuracy:89.56%, Validation loss:1.645, Validation accuracy:51.50%
# Epoch 899: iteration 7/8
# Epoch 899 --- loss:0.087, Epoch accuracy:89.47%, Validation loss:1.650, Validation accuracy:51.00%
# Epoch 900: iteration 7/8
# Epoch 900 --- loss:0.088, Epoch accuracy:89.08%, Validation loss:1.652, Validation accuracy:51.00%
# Epoch 901: iteration 7/8
# Epoch 901 --- loss:0.085, Epoch accuracy:89.56%, Validation loss:1.657, Validation accuracy:51.17%
# Epoch 902: iteration 7/8
# Epoch 902 --- loss:0.089, Epoch accuracy:89.52%, Validation loss:1.646, Validation accuracy:51.67%
# Epoch 903: iteration 7/8
# Epoch 903 --- loss:0.084, Epoch accuracy:89.52%, Validation loss:1.648, Validation accuracy:51.83%
# Epoch 904: iteration 7/8
# Epoch 904 --- loss:0.088, Epoch accuracy:89.56%, Validation loss:1.653, Validation accuracy:51.50%
# Epoch 905: iteration 7/8
# Epoch 905 --- loss:0.081, Epoch accuracy:89.61%, Validation loss:1.654, Validation accuracy:51.83%
# Epoch 906: iteration 7/8
# Epoch 906 --- loss:0.085, Epoch accuracy:89.56%, Validation loss:1.650, Validation accuracy:51.83%
# Epoch 907: iteration 7/8
# Epoch 907 --- loss:0.085, Epoch accuracy:89.43%, Validation loss:1.666, Validation accuracy:51.33%
# Epoch 908: iteration 7/8
# Epoch 908 --- loss:0.083, Epoch accuracy:89.61%, Validation loss:1.668, Validation accuracy:51.50%
# Epoch 909: iteration 7/8
# Epoch 909 --- loss:0.088, Epoch accuracy:89.39%, Validation loss:1.659, Validation accuracy:51.50%
# Epoch 910: iteration 7/8
# Epoch 910 --- loss:0.084, Epoch accuracy:89.43%, Validation loss:1.663, Validation accuracy:51.50%
# Epoch 911: iteration 7/8
# Epoch 911 --- loss:0.083, Epoch accuracy:89.61%, Validation loss:1.665, Validation accuracy:51.67%
# Epoch 912: iteration 7/8
# Epoch 912 --- loss:0.085, Epoch accuracy:89.43%, Validation loss:1.669, Validation accuracy:51.33%
# Epoch 913: iteration 7/8
# Epoch 913 --- loss:0.083, Epoch accuracy:89.56%, Validation loss:1.662, Validation accuracy:51.50%
# Epoch 914: iteration 7/8
# Epoch 914 --- loss:0.079, Epoch accuracy:89.61%, Validation loss:1.665, Validation accuracy:51.33%
# Epoch 915: iteration 7/8
# Epoch 915 --- loss:0.081, Epoch accuracy:89.47%, Validation loss:1.669, Validation accuracy:51.17%
# Epoch 916: iteration 7/8
# Epoch 916 --- loss:0.084, Epoch accuracy:89.39%, Validation loss:1.675, Validation accuracy:51.33%
# Epoch 917: iteration 7/8
# Epoch 917 --- loss:0.083, Epoch accuracy:89.69%, Validation loss:1.670, Validation accuracy:51.50%
# Epoch 918: iteration 7/8
# Epoch 918 --- loss:0.086, Epoch accuracy:89.47%, Validation loss:1.672, Validation accuracy:51.50%
# Epoch 919: iteration 7/8
# Epoch 919 --- loss:0.081, Epoch accuracy:89.47%, Validation loss:1.677, Validation accuracy:51.33%
# Epoch 920: iteration 7/8
# Epoch 920 --- loss:0.079, Epoch accuracy:89.74%, Validation loss:1.672, Validation accuracy:51.33%
# Epoch 921: iteration 7/8
# Epoch 921 --- loss:0.081, Epoch accuracy:89.61%, Validation loss:1.667, Validation accuracy:51.83%
# Epoch 922: iteration 7/8
# Epoch 922 --- loss:0.080, Epoch accuracy:89.43%, Validation loss:1.667, Validation accuracy:51.33%
# Epoch 923: iteration 7/8
# Epoch 923 --- loss:0.082, Epoch accuracy:89.25%, Validation loss:1.665, Validation accuracy:51.17%
# Epoch 924: iteration 7/8
# Epoch 924 --- loss:0.077, Epoch accuracy:89.65%, Validation loss:1.670, Validation accuracy:50.83%
# Epoch 925: iteration 7/8
# Epoch 925 --- loss:0.078, Epoch accuracy:89.61%, Validation loss:1.668, Validation accuracy:51.50%
# Epoch 926: iteration 7/8
# Epoch 926 --- loss:0.085, Epoch accuracy:89.43%, Validation loss:1.671, Validation accuracy:51.50%
# Epoch 927: iteration 7/8
# Epoch 927 --- loss:0.082, Epoch accuracy:89.52%, Validation loss:1.667, Validation accuracy:51.67%
# Epoch 928: iteration 7/8
# Epoch 928 --- loss:0.080, Epoch accuracy:89.47%, Validation loss:1.668, Validation accuracy:51.83%
# Epoch 929: iteration 7/8
# Epoch 929 --- loss:0.081, Epoch accuracy:89.43%, Validation loss:1.677, Validation accuracy:51.33%
# Epoch 930: iteration 7/8
# Epoch 930 --- loss:0.078, Epoch accuracy:89.56%, Validation loss:1.681, Validation accuracy:51.33%
# Epoch 931: iteration 7/8
# Epoch 931 --- loss:0.075, Epoch accuracy:89.61%, Validation loss:1.674, Validation accuracy:51.50%
# Epoch 932: iteration 7/8
# Epoch 932 --- loss:0.076, Epoch accuracy:89.65%, Validation loss:1.681, Validation accuracy:51.33%
# Epoch 933: iteration 7/8
# Epoch 933 --- loss:0.083, Epoch accuracy:89.52%, Validation loss:1.676, Validation accuracy:51.17%
# Epoch 934: iteration 7/8
# Epoch 934 --- loss:0.079, Epoch accuracy:89.56%, Validation loss:1.676, Validation accuracy:51.67%
# Epoch 935: iteration 7/8
# Epoch 935 --- loss:0.075, Epoch accuracy:89.69%, Validation loss:1.687, Validation accuracy:51.67%
# Epoch 936: iteration 7/8
# Epoch 936 --- loss:0.079, Epoch accuracy:89.56%, Validation loss:1.682, Validation accuracy:51.67%
# Epoch 937: iteration 7/8
# Epoch 937 --- loss:0.081, Epoch accuracy:89.56%, Validation loss:1.689, Validation accuracy:51.33%
# Epoch 938: iteration 7/8
# Epoch 938 --- loss:0.079, Epoch accuracy:89.56%, Validation loss:1.674, Validation accuracy:51.83%
# Epoch 939: iteration 7/8
# Epoch 939 --- loss:0.076, Epoch accuracy:89.52%, Validation loss:1.681, Validation accuracy:51.33%
# Epoch 940: iteration 7/8
# Epoch 940 --- loss:0.080, Epoch accuracy:89.47%, Validation loss:1.689, Validation accuracy:51.17%
# Epoch 941: iteration 7/8
# Epoch 941 --- loss:0.076, Epoch accuracy:89.56%, Validation loss:1.688, Validation accuracy:50.83%
# Epoch 942: iteration 7/8
# Epoch 942 --- loss:0.078, Epoch accuracy:89.52%, Validation loss:1.687, Validation accuracy:51.67%
# Epoch 943: iteration 7/8
# Epoch 943 --- loss:0.080, Epoch accuracy:89.43%, Validation loss:1.693, Validation accuracy:51.50%
# Epoch 944: iteration 7/8
# Epoch 944 --- loss:0.079, Epoch accuracy:89.52%, Validation loss:1.689, Validation accuracy:51.33%
# Epoch 945: iteration 7/8
# Epoch 945 --- loss:0.074, Epoch accuracy:89.56%, Validation loss:1.688, Validation accuracy:51.33%
# Epoch 946: iteration 7/8
# Epoch 946 --- loss:0.077, Epoch accuracy:89.65%, Validation loss:1.692, Validation accuracy:51.17%
# Epoch 947: iteration 7/8
# Epoch 947 --- loss:0.076, Epoch accuracy:89.69%, Validation loss:1.687, Validation accuracy:51.17%
# Epoch 948: iteration 7/8
# Epoch 948 --- loss:0.077, Epoch accuracy:89.25%, Validation loss:1.687, Validation accuracy:51.33%
# Epoch 949: iteration 7/8
# Epoch 949 --- loss:0.071, Epoch accuracy:89.74%, Validation loss:1.690, Validation accuracy:51.00%
# Epoch 950: iteration 7/8
# Epoch 950 --- loss:0.075, Epoch accuracy:89.47%, Validation loss:1.705, Validation accuracy:51.00%
# Epoch 951: iteration 7/8
# Epoch 951 --- loss:0.072, Epoch accuracy:89.61%, Validation loss:1.703, Validation accuracy:50.67%
# Epoch 952: iteration 7/8
# Epoch 952 --- loss:0.070, Epoch accuracy:89.69%, Validation loss:1.693, Validation accuracy:51.17%
# Epoch 953: iteration 7/8
# Epoch 953 --- loss:0.073, Epoch accuracy:89.69%, Validation loss:1.701, Validation accuracy:50.83%
# Epoch 954: iteration 7/8
# Epoch 954 --- loss:0.074, Epoch accuracy:89.56%, Validation loss:1.707, Validation accuracy:51.17%
# Epoch 955: iteration 7/8
# Epoch 955 --- loss:0.076, Epoch accuracy:89.61%, Validation loss:1.700, Validation accuracy:50.50%
# Epoch 956: iteration 7/8
# Epoch 956 --- loss:0.072, Epoch accuracy:89.52%, Validation loss:1.696, Validation accuracy:51.33%
# Epoch 957: iteration 7/8
# Epoch 957 --- loss:0.073, Epoch accuracy:89.65%, Validation loss:1.706, Validation accuracy:51.33%
# Epoch 958: iteration 7/8
# Epoch 958 --- loss:0.073, Epoch accuracy:89.47%, Validation loss:1.705, Validation accuracy:51.17%
# Epoch 959: iteration 7/8
# Epoch 959 --- loss:0.072, Epoch accuracy:89.56%, Validation loss:1.708, Validation accuracy:51.17%
# Epoch 960: iteration 7/8
# Epoch 960 --- loss:0.069, Epoch accuracy:89.69%, Validation loss:1.705, Validation accuracy:51.00%
# Epoch 961: iteration 7/8
# Epoch 961 --- loss:0.072, Epoch accuracy:89.65%, Validation loss:1.689, Validation accuracy:51.83%
# Epoch 962: iteration 7/8
# Epoch 962 --- loss:0.074, Epoch accuracy:89.52%, Validation loss:1.696, Validation accuracy:51.83%
# Epoch 963: iteration 7/8
# Epoch 963 --- loss:0.069, Epoch accuracy:89.56%, Validation loss:1.700, Validation accuracy:51.50%
# Epoch 964: iteration 7/8
# Epoch 964 --- loss:0.074, Epoch accuracy:89.47%, Validation loss:1.700, Validation accuracy:51.50%
# Epoch 965: iteration 7/8
# Epoch 965 --- loss:0.074, Epoch accuracy:89.56%, Validation loss:1.699, Validation accuracy:51.67%
# Epoch 966: iteration 7/8
# Epoch 966 --- loss:0.070, Epoch accuracy:89.74%, Validation loss:1.707, Validation accuracy:51.33%
# Epoch 967: iteration 7/8
# Epoch 967 --- loss:0.070, Epoch accuracy:89.69%, Validation loss:1.698, Validation accuracy:51.50%
# Epoch 968: iteration 7/8
# Epoch 968 --- loss:0.070, Epoch accuracy:89.69%, Validation loss:1.705, Validation accuracy:51.33%
# Epoch 969: iteration 7/8
# Epoch 969 --- loss:0.070, Epoch accuracy:89.61%, Validation loss:1.700, Validation accuracy:51.50%
# Epoch 970: iteration 7/8
# Epoch 970 --- loss:0.070, Epoch accuracy:89.56%, Validation loss:1.709, Validation accuracy:50.83%
# Epoch 971: iteration 7/8
# Epoch 971 --- loss:0.073, Epoch accuracy:89.39%, Validation loss:1.703, Validation accuracy:51.33%
# Epoch 972: iteration 7/8
# Epoch 972 --- loss:0.068, Epoch accuracy:89.56%, Validation loss:1.711, Validation accuracy:51.33%
# Epoch 973: iteration 7/8
# Epoch 973 --- loss:0.073, Epoch accuracy:89.65%, Validation loss:1.704, Validation accuracy:51.67%
# Epoch 974: iteration 7/8
# Epoch 974 --- loss:0.069, Epoch accuracy:89.56%, Validation loss:1.708, Validation accuracy:51.50%
# Epoch 975: iteration 7/8
# Epoch 975 --- loss:0.072, Epoch accuracy:89.56%, Validation loss:1.718, Validation accuracy:50.83%
# Epoch 976: iteration 7/8
# Epoch 976 --- loss:0.069, Epoch accuracy:89.61%, Validation loss:1.713, Validation accuracy:51.00%
# Epoch 977: iteration 7/8
# Epoch 977 --- loss:0.068, Epoch accuracy:89.65%, Validation loss:1.707, Validation accuracy:51.50%
# Epoch 978: iteration 7/8
# Epoch 978 --- loss:0.069, Epoch accuracy:89.56%, Validation loss:1.709, Validation accuracy:50.83%
# Epoch 979: iteration 7/8
# Epoch 979 --- loss:0.071, Epoch accuracy:89.52%, Validation loss:1.714, Validation accuracy:51.00%
# Epoch 980: iteration 7/8
# Epoch 980 --- loss:0.068, Epoch accuracy:89.56%, Validation loss:1.722, Validation accuracy:51.33%
# Epoch 981: iteration 7/8
# Epoch 981 --- loss:0.069, Epoch accuracy:89.47%, Validation loss:1.723, Validation accuracy:50.67%
# Epoch 982: iteration 7/8
# Epoch 982 --- loss:0.065, Epoch accuracy:89.69%, Validation loss:1.720, Validation accuracy:51.00%
# Epoch 983: iteration 7/8
# Epoch 983 --- loss:0.065, Epoch accuracy:89.69%, Validation loss:1.729, Validation accuracy:50.67%
# Epoch 984: iteration 7/8
# Epoch 984 --- loss:0.070, Epoch accuracy:89.56%, Validation loss:1.717, Validation accuracy:51.00%
# Epoch 985: iteration 7/8
# Epoch 985 --- loss:0.071, Epoch accuracy:89.47%, Validation loss:1.703, Validation accuracy:51.67%
# Epoch 986: iteration 7/8
# Epoch 986 --- loss:0.070, Epoch accuracy:89.47%, Validation loss:1.707, Validation accuracy:51.83%
# Epoch 987: iteration 7/8
# Epoch 987 --- loss:0.067, Epoch accuracy:89.56%, Validation loss:1.713, Validation accuracy:51.33%
# Epoch 988: iteration 7/8
# Epoch 988 --- loss:0.070, Epoch accuracy:89.65%, Validation loss:1.715, Validation accuracy:51.17%
# Epoch 989: iteration 7/8
# Epoch 989 --- loss:0.066, Epoch accuracy:89.69%, Validation loss:1.724, Validation accuracy:51.33%
# Epoch 990: iteration 7/8
# Epoch 990 --- loss:0.069, Epoch accuracy:89.78%, Validation loss:1.735, Validation accuracy:51.00%
# Epoch 991: iteration 7/8
# Epoch 991 --- loss:0.069, Epoch accuracy:89.47%, Validation loss:1.726, Validation accuracy:51.33%
# Epoch 992: iteration 7/8
# Epoch 992 --- loss:0.066, Epoch accuracy:89.65%, Validation loss:1.731, Validation accuracy:51.50%
# Epoch 993: iteration 7/8
# Epoch 993 --- loss:0.067, Epoch accuracy:89.65%, Validation loss:1.726, Validation accuracy:51.33%
# Epoch 994: iteration 7/8
# Epoch 994 --- loss:0.067, Epoch accuracy:89.47%, Validation loss:1.735, Validation accuracy:51.67%
# Epoch 995: iteration 7/8
# Epoch 995 --- loss:0.066, Epoch accuracy:89.52%, Validation loss:1.738, Validation accuracy:50.83%
# Epoch 996: iteration 7/8
# Epoch 996 --- loss:0.068, Epoch accuracy:89.61%, Validation loss:1.742, Validation accuracy:50.67%
# Epoch 997: iteration 7/8
# Epoch 997 --- loss:0.070, Epoch accuracy:89.52%, Validation loss:1.734, Validation accuracy:51.17%
# Epoch 998: iteration 7/8
# Epoch 998 --- loss:0.065, Epoch accuracy:89.74%, Validation loss:1.733, Validation accuracy:51.17%
# Epoch 999: iteration 7/8
# Epoch 999 --- loss:0.068, Epoch accuracy:89.56%, Validation loss:1.741, Validation accuracy:50.67%
#
#
# [*] done !
# [*] Best training loss - 0.06452748106237044
# [*] Best validation loss - 1.183164119720459

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    
    break
# Out:
# [*] 0 Test accuracy is 56.50%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 56.50%
# [*] Worst fold acc : 56.50%
# [*] Average fold acc : 56.50%

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    break
# Out:
# [*] 0 Test accuracy is 56.50%
#               precision    recall  f1-score   support
#
#            0       0.48      0.53      0.50        40
#            1       0.75      0.34      0.47        80
#            2       0.63      0.30      0.41        80
#            3       0.45      0.46      0.45        80
#            4       0.53      0.72      0.61        80
#            5       0.70      0.66      0.68        80
#            6       0.55      0.60      0.57        80
#            7       0.56      0.89      0.69        80
#
#     accuracy                           0.56       600
#    macro avg       0.58      0.56      0.55       600
# weighted avg       0.59      0.56      0.55       600
