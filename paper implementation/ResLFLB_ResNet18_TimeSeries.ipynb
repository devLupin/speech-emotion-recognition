# %% [markdown]
# # Model summary
# <hr>
#
# ### ResLFLB + ResNet18 --> TimeSeries
# - TimeSeries configuration
#   - LSTM --> Transformer

# %%
from cv2 import transform
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm
from einops import rearrange
import random

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(2022)
# Out:
# # SEEDING DONE : seed is 2022

# %%
def set_seed(seed_value):
    random.seed(seed_value) # Python
    np.random.seed(seed_value) # cpu vars
    torch.manual_seed(seed_value) # cpu  vars    
    if torch.cuda.is_available(): 
        torch.cuda.manual_seed(seed_value)
        torch.cuda.manual_seed_all(seed_value) # gpu vars
    if torch.backends.cudnn.is_available:
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    print(f'# SEEDING DONE : seed is {seed_value} ')

set_seed(19950424)
# Out:
# # SEEDING DONE : seed is 19950424

# %% [markdown]
# ## LFLB (N Filter)
#
# Speech emotion recognition using deep 1d & 2d cnn lstm networks. Biomedical Signal Processing and Control 47, 312–323 (2019)

# %%
class LFLB(nn.Module):
    """Some Information about LFLB"""
    def __init__(self, in_chan, out_chan, kernel=[2, 2], stride=[1, 1], pad=1):
        super(LFLB, self).__init__()

        self.cnn = nn.Conv2d(in_channels=in_chan, out_channels=out_chan, kernel_size=kernel, stride=stride, padding=pad)
        self.bn = nn.BatchNorm2d(out_chan)
        self.relu = nn.ReLU()
        self.max_pool =  nn.MaxPool2d(kernel_size=kernel, stride=[2, 2])

    def forward(self, x):
        cnn_embd = self.cnn(x)
        cnn_embd = self.bn(cnn_embd)
        cnn_embd = self.relu(cnn_embd)
        output = self.max_pool(cnn_embd)

        return output

# %% [markdown]
# ## NAC Unit
#
# [1] Kaiming He, Xiangyu Zhang, Shaoqing Ren, Jian Sun, Identity Mappings in Deep Residual Networks. arXiv:1603.05027
# https://github.com/kuangliu/pytorch-cifar/blob/master/models/preact_resnet.py

# %%
class NACUnit(nn.Module):
    '''Pre-activation version of the BasicBlock.'''
    expansion = 1

    def __init__(self, in_planes, planes, kernel, stride=1, pad=0):
        super(NACUnit, self).__init__()
        
        self.bn1 = nn.BatchNorm2d(in_planes)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=kernel, stride=stride, padding=pad, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=kernel, stride=1, padding=1, bias=False)

    def forward(self, x):
        out = F.relu(self.bn1(x))
        shortcut = self.shortcut(out) if hasattr(self, 'shortcut') else x
        out = self.conv1(out)
        out = self.conv2(F.relu(self.bn2(out)))
        return out

# %%
class ResLFLB(nn.Module):
    def __init__(self, in_chan, n_filters, kernel):
        super(ResLFLB, self).__init__()
        
        self.lflb = LFLB(in_chan=in_chan, out_chan=n_filters)
        
        self.nac_unit1 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1, pad=1)
        self.nac_unit2 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit3 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit4 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=kernel, stride=1)
        self.nac_unit5 = NACUnit(in_planes=n_filters, planes=n_filters, kernel=1, stride=1)

    def forward(self, x):
        lflb_embd = self.lflb(x)
        
        nac_embd = self.nac_unit1(lflb_embd)
        nac_embd = self.nac_unit2(nac_embd)
        nac_embd = self.nac_unit3(nac_embd)
        nac_embd = self.nac_unit4(nac_embd)
        nac_embd = self.nac_unit5(nac_embd)
        
        output = lflb_embd + nac_embd

        return output

# %%
from torchvision.models import ResNet18_Weights

class resnet18_finetune(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        
        self.model_ft = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        self.model_ft = nn.Sequential(*(list(self.model_ft.children())[:-1]))
        
        for name, param in self.model_ft[:4].named_parameters():
            param.requires_grad=False
    
    def forward(self, x):
        embd = self.model_ft(x)
        output = torch.flatten(embd, start_dim=1)
        
        return output

# %%
class SpatialModel(nn.Module):
    def __init__(self):
        super(SpatialModel, self).__init__()

        self.resnet = resnet18_finetune()

        self.MFL = LFLB(3, 32)
        
        self.res_lflb1 = ResLFLB(32, 32, [3, 3])
        self.res_lflb2 = ResLFLB(32, 32, [3, 3])
        self.res_lflb3 = ResLFLB(32, 32, [3, 3])
        self.res_lflb4 = ResLFLB(32, 64, [3, 3])
        self.res_lflb5 = ResLFLB(64, 128, [3, 3])
        
        self.relu = nn.ReLU()
        self.max_pool = nn.MaxPool2d(kernel_size=[2, 2], stride=[2, 2])
        self.dropout = nn.Dropout(0.5)

    def forward(self, x):
        res_embd = self.resnet(x)
        
        MFL_embd = self.MFL(x)
        
        res_lflb_embd = self.res_lflb1(MFL_embd)
        res_lflb_embd = self.res_lflb2(res_lflb_embd)
        res_lflb_embd = self.res_lflb3(res_lflb_embd)
        res_lflb_embd = self.res_lflb4(res_lflb_embd)
        res_lflb_embd = self.res_lflb5(res_lflb_embd)
        
        mlp = self.relu(res_lflb_embd)
        mlp = self.max_pool(mlp)
        mlp = self.dropout(mlp)
        mlp = torch.flatten(mlp, start_dim=1)
        
        output = mlp + res_embd
        
        return output

# %%
class TimeseriesModel(nn.Module):
    """Some Information about nna"""
    def __init__(self):
        super(TimeseriesModel, self).__init__()

        self.spatial = SpatialModel()

        self.lstm = nn.LSTM(input_size=512, hidden_size=256, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
        self.lstm_ln = nn.LayerNorm(normalized_shape=512, eps=1e-08)
        
        transformer_layer = nn.TransformerEncoderLayer(
            d_model=512,
            nhead=4,
            dim_feedforward=64,
            dropout=0.5,
            activation='relu'
        )
        self.transformer_encoder = nn.TransformerEncoder(transformer_layer, num_layers=2)
        self.transformer_ln = nn.LayerNorm(normalized_shape=512, eps=1e-08)

    def forward(self, x):
        spatial_embd = self.spatial(x)
        
        lstm_embd, (h, c) = self.lstm(spatial_embd)
        transformer_embd = self.transformer_encoder(lstm_embd)
        
        return transformer_embd

# %%
class Model(nn.Module):
    """Some Information about Model"""
    def __init__(self, num_emotions):
        super(Model, self).__init__()
        
        self.timeseries = TimeseriesModel()
        
        self.linear = nn.Linear(512, num_emotions)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        timeseries_embd = self.timeseries(x)
        
        output_logits = self.linear(timeseries_embd)
        output_softmax = self.softmax(output_logits)
        
        return output_logits, output_softmax

# %%
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


emotions_dict = {
    '0': 'neutral',
    '1': 'calm',
    '2': 'happy',
    '3': 'sad',
    '4': 'angry',
    '5': 'fearful',
    '6': 'disgust',
    '7': 'surprised'
}


sub_name = 'ResLFLB-ResNet18-Timeseries-DataAugment-masking'
data_name = 'RAVDESS'

minibatch = 32
num_epochs = 500
EARLY_CNT = 500

learning_rate = 1e-6

# model = Model(len(emotions_dict))
# print(summary(model, (1, 3, 224, 224)))

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold, optimizer):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(npy_name):
    with open(npy_name, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
    
    return X_train, y_train, X_test, y_test

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = '5-CV'

for fold in range(5):
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    model = Model(num_emotions=len(emotions_dict)).to('cuda')
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold, optimizer)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - ResLFLB-ResNet18-Timeseries-DataAugment-masking
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 34/35
# Epoch 0 --- loss:2.123, Epoch accuracy:14.47%, Validation loss:2.152, Validation accuracy:10.67%
# Epoch 1: iteration 34/35
# Epoch 1 --- loss:2.135, Epoch accuracy:10.70%, Validation loss:2.101, Validation accuracy:14.33%
# Epoch 2: iteration 34/35
# Epoch 2 --- loss:2.104, Epoch accuracy:14.04%, Validation loss:2.079, Validation accuracy:13.67%
# Epoch 3: iteration 34/35
# Epoch 3 --- loss:2.112, Epoch accuracy:13.33%, Validation loss:2.065, Validation accuracy:13.67%
# Epoch 4: iteration 34/35
# Epoch 4 --- loss:2.091, Epoch accuracy:14.65%, Validation loss:2.062, Validation accuracy:16.00%
# Epoch 5: iteration 34/35
# Epoch 5 --- loss:2.115, Epoch accuracy:12.63%, Validation loss:2.051, Validation accuracy:15.00%
# Epoch 6: iteration 34/35
# Epoch 6 --- loss:2.122, Epoch accuracy:11.14%, Validation loss:2.053, Validation accuracy:14.67%
# Epoch 7: iteration 34/35
# Epoch 7 --- loss:2.093, Epoch accuracy:12.98%, Validation loss:2.058, Validation accuracy:14.67%
# Epoch 8: iteration 34/35
# Epoch 8 --- loss:2.110, Epoch accuracy:12.28%, Validation loss:2.051, Validation accuracy:16.00%
# Epoch 9: iteration 34/35
# Epoch 9 --- loss:2.104, Epoch accuracy:12.11%, Validation loss:2.043, Validation accuracy:16.67%
# Epoch 10: iteration 34/35
# Epoch 10 --- loss:2.094, Epoch accuracy:13.33%, Validation loss:2.046, Validation accuracy:14.67%
# Epoch 11: iteration 34/35
# Epoch 11 --- loss:2.078, Epoch accuracy:14.65%, Validation loss:2.038, Validation accuracy:19.33%
# Epoch 12: iteration 34/35
# Epoch 12 --- loss:2.094, Epoch accuracy:14.56%, Validation loss:2.037, Validation accuracy:18.00%
# Epoch 13: iteration 34/35
# Epoch 13 --- loss:2.096, Epoch accuracy:12.63%, Validation loss:2.044, Validation accuracy:17.33%
# Epoch 14: iteration 34/35
# Epoch 14 --- loss:2.096, Epoch accuracy:12.81%, Validation loss:2.037, Validation accuracy:19.00%
# Epoch 15: iteration 34/35
# Epoch 15 --- loss:2.095, Epoch accuracy:13.51%, Validation loss:2.037, Validation accuracy:19.33%
# Epoch 16: iteration 34/35
# Epoch 16 --- loss:2.083, Epoch accuracy:12.46%, Validation loss:2.039, Validation accuracy:17.33%
# Epoch 17: iteration 34/35
# Epoch 17 --- loss:2.097, Epoch accuracy:14.04%, Validation loss:2.037, Validation accuracy:18.00%
# Epoch 18: iteration 34/35
# Epoch 18 --- loss:2.088, Epoch accuracy:13.68%, Validation loss:2.033, Validation accuracy:19.00%
# Epoch 19: iteration 34/35
# Epoch 19 --- loss:2.078, Epoch accuracy:13.51%, Validation loss:2.027, Validation accuracy:19.33%
# Epoch 20: iteration 34/35
# Epoch 20 --- loss:2.091, Epoch accuracy:14.65%, Validation loss:2.034, Validation accuracy:19.00%
# Epoch 21: iteration 34/35
# Epoch 21 --- loss:2.093, Epoch accuracy:14.04%, Validation loss:2.025, Validation accuracy:20.33%
# Epoch 22: iteration 34/35
# Epoch 22 --- loss:2.092, Epoch accuracy:15.35%, Validation loss:2.030, Validation accuracy:19.00%
# Epoch 23: iteration 34/35
# Epoch 23 --- loss:2.081, Epoch accuracy:11.93%, Validation loss:2.027, Validation accuracy:19.33%
# Epoch 24: iteration 34/35
# Epoch 24 --- loss:2.061, Epoch accuracy:15.26%, Validation loss:2.028, Validation accuracy:17.00%
# Epoch 25: iteration 34/35
# Epoch 25 --- loss:2.079, Epoch accuracy:16.14%, Validation loss:2.034, Validation accuracy:18.00%
# Epoch 26: iteration 34/35
# Epoch 26 --- loss:2.081, Epoch accuracy:14.74%, Validation loss:2.026, Validation accuracy:21.33%
# Epoch 27: iteration 34/35
# Epoch 27 --- loss:2.103, Epoch accuracy:12.28%, Validation loss:2.020, Validation accuracy:18.67%
# Epoch 28: iteration 34/35
# Epoch 28 --- loss:2.088, Epoch accuracy:12.72%, Validation loss:2.024, Validation accuracy:20.00%
# Epoch 29: iteration 34/35
# Epoch 29 --- loss:2.081, Epoch accuracy:12.72%, Validation loss:2.024, Validation accuracy:20.33%
# Epoch 30: iteration 34/35
# Epoch 30 --- loss:2.081, Epoch accuracy:13.60%, Validation loss:2.022, Validation accuracy:21.33%
# Epoch 31: iteration 34/35
# Epoch 31 --- loss:2.083, Epoch accuracy:13.86%, Validation loss:2.016, Validation accuracy:19.00%
# Epoch 32: iteration 34/35
# Epoch 32 --- loss:2.077, Epoch accuracy:13.68%, Validation loss:2.012, Validation accuracy:22.67%
# Epoch 33: iteration 34/35
# Epoch 33 --- loss:2.062, Epoch accuracy:14.47%, Validation loss:2.007, Validation accuracy:22.33%
# Epoch 34: iteration 34/35
# Epoch 34 --- loss:2.070, Epoch accuracy:14.21%, Validation loss:2.016, Validation accuracy:19.67%
# Epoch 35: iteration 34/35
# Epoch 35 --- loss:2.074, Epoch accuracy:15.26%, Validation loss:2.014, Validation accuracy:20.67%
# Epoch 36: iteration 34/35
# Epoch 36 --- loss:2.096, Epoch accuracy:12.81%, Validation loss:2.010, Validation accuracy:24.00%
# Epoch 37: iteration 34/35
# Epoch 37 --- loss:2.067, Epoch accuracy:14.30%, Validation loss:2.005, Validation accuracy:23.33%
# Epoch 38: iteration 34/35
# Epoch 38 --- loss:2.059, Epoch accuracy:13.86%, Validation loss:2.003, Validation accuracy:24.00%
# Epoch 39: iteration 34/35
# Epoch 39 --- loss:2.079, Epoch accuracy:14.21%, Validation loss:2.003, Validation accuracy:23.67%
# Epoch 40: iteration 34/35
# Epoch 40 --- loss:2.066, Epoch accuracy:14.47%, Validation loss:2.008, Validation accuracy:23.33%
# Epoch 41: iteration 34/35
# Epoch 41 --- loss:2.066, Epoch accuracy:14.74%, Validation loss:2.002, Validation accuracy:25.67%
# Epoch 42: iteration 34/35
# Epoch 42 --- loss:2.061, Epoch accuracy:16.40%, Validation loss:2.002, Validation accuracy:24.67%
# Epoch 43: iteration 34/35
# Epoch 43 --- loss:2.075, Epoch accuracy:13.68%, Validation loss:2.008, Validation accuracy:24.33%
# Epoch 44: iteration 34/35
# Epoch 44 --- loss:2.053, Epoch accuracy:15.00%, Validation loss:1.996, Validation accuracy:25.00%
# Epoch 45: iteration 34/35
# Epoch 45 --- loss:2.063, Epoch accuracy:17.46%, Validation loss:1.999, Validation accuracy:26.00%
# Epoch 46: iteration 34/35
# Epoch 46 --- loss:2.059, Epoch accuracy:15.09%, Validation loss:1.996, Validation accuracy:26.33%
# Epoch 47: iteration 34/35
# Epoch 47 --- loss:2.073, Epoch accuracy:14.65%, Validation loss:1.999, Validation accuracy:23.33%
# Epoch 48: iteration 34/35
# Epoch 48 --- loss:2.051, Epoch accuracy:14.39%, Validation loss:1.993, Validation accuracy:24.33%
# Epoch 49: iteration 34/35
# Epoch 49 --- loss:2.076, Epoch accuracy:12.72%, Validation loss:1.990, Validation accuracy:26.33%
# Epoch 50: iteration 34/35
# Epoch 50 --- loss:2.053, Epoch accuracy:15.70%, Validation loss:1.990, Validation accuracy:28.00%
# Epoch 51: iteration 34/35
# Epoch 51 --- loss:2.063, Epoch accuracy:14.12%, Validation loss:1.990, Validation accuracy:26.33%
# Epoch 52: iteration 34/35
# Epoch 52 --- loss:2.066, Epoch accuracy:14.21%, Validation loss:1.984, Validation accuracy:27.33%
# Epoch 53: iteration 34/35
# Epoch 53 --- loss:2.060, Epoch accuracy:14.91%, Validation loss:1.984, Validation accuracy:27.33%
# Epoch 54: iteration 34/35
# Epoch 54 --- loss:2.057, Epoch accuracy:16.67%, Validation loss:1.986, Validation accuracy:27.33%
# Epoch 55: iteration 34/35
# Epoch 55 --- loss:2.043, Epoch accuracy:15.61%, Validation loss:1.983, Validation accuracy:25.67%
# Epoch 56: iteration 34/35
# Epoch 56 --- loss:2.064, Epoch accuracy:15.09%, Validation loss:1.984, Validation accuracy:23.67%
# Epoch 57: iteration 34/35
# Epoch 57 --- loss:2.059, Epoch accuracy:16.32%, Validation loss:1.982, Validation accuracy:26.33%
# Epoch 58: iteration 34/35
# Epoch 58 --- loss:2.040, Epoch accuracy:14.82%, Validation loss:1.977, Validation accuracy:28.00%
# Epoch 59: iteration 34/35
# Epoch 59 --- loss:2.050, Epoch accuracy:14.65%, Validation loss:1.977, Validation accuracy:26.00%
# Epoch 60: iteration 34/35
# Epoch 60 --- loss:2.029, Epoch accuracy:15.79%, Validation loss:1.971, Validation accuracy:27.33%
# Epoch 61: iteration 34/35
# Epoch 61 --- loss:2.054, Epoch accuracy:14.30%, Validation loss:1.967, Validation accuracy:27.00%
# Epoch 62: iteration 34/35
# Epoch 62 --- loss:2.054, Epoch accuracy:15.44%, Validation loss:1.970, Validation accuracy:27.33%
# Epoch 63: iteration 34/35
# Epoch 63 --- loss:2.049, Epoch accuracy:15.35%, Validation loss:1.967, Validation accuracy:27.33%
# Epoch 64: iteration 34/35
# Epoch 64 --- loss:2.026, Epoch accuracy:16.75%, Validation loss:1.962, Validation accuracy:27.33%
# Epoch 65: iteration 34/35
# Epoch 65 --- loss:2.032, Epoch accuracy:17.63%, Validation loss:1.962, Validation accuracy:26.33%
# Epoch 66: iteration 34/35
# Epoch 66 --- loss:2.047, Epoch accuracy:14.82%, Validation loss:1.958, Validation accuracy:28.67%
# Epoch 67: iteration 34/35
# Epoch 67 --- loss:2.029, Epoch accuracy:15.61%, Validation loss:1.952, Validation accuracy:30.00%
# Epoch 68: iteration 34/35
# Epoch 68 --- loss:2.049, Epoch accuracy:16.49%, Validation loss:1.962, Validation accuracy:23.67%
# Epoch 69: iteration 34/35
# Epoch 69 --- loss:2.061, Epoch accuracy:15.96%, Validation loss:1.952, Validation accuracy:29.33%
# Epoch 70: iteration 34/35
# Epoch 70 --- loss:2.061, Epoch accuracy:14.91%, Validation loss:1.951, Validation accuracy:28.33%
# Epoch 71: iteration 34/35
# Epoch 71 --- loss:2.035, Epoch accuracy:17.28%, Validation loss:1.950, Validation accuracy:28.67%
# Epoch 72: iteration 34/35
# Epoch 72 --- loss:2.035, Epoch accuracy:16.14%, Validation loss:1.946, Validation accuracy:28.33%
# Epoch 73: iteration 34/35
# Epoch 73 --- loss:2.028, Epoch accuracy:16.75%, Validation loss:1.941, Validation accuracy:29.67%
# Epoch 74: iteration 34/35
# Epoch 74 --- loss:2.035, Epoch accuracy:16.40%, Validation loss:1.944, Validation accuracy:27.00%
# Epoch 75: iteration 34/35
# Epoch 75 --- loss:2.044, Epoch accuracy:16.49%, Validation loss:1.945, Validation accuracy:30.67%
# Epoch 76: iteration 34/35
# Epoch 76 --- loss:2.039, Epoch accuracy:16.40%, Validation loss:1.937, Validation accuracy:32.67%
# Epoch 77: iteration 34/35
# Epoch 77 --- loss:2.039, Epoch accuracy:16.14%, Validation loss:1.933, Validation accuracy:29.67%
# Epoch 78: iteration 34/35
# Epoch 78 --- loss:2.027, Epoch accuracy:17.37%, Validation loss:1.933, Validation accuracy:30.67%
# Epoch 79: iteration 34/35
# Epoch 79 --- loss:2.007, Epoch accuracy:17.98%, Validation loss:1.933, Validation accuracy:29.67%
# Epoch 80: iteration 34/35
# Epoch 80 --- loss:2.039, Epoch accuracy:16.75%, Validation loss:1.925, Validation accuracy:30.67%
# Epoch 81: iteration 34/35
# Epoch 81 --- loss:2.030, Epoch accuracy:16.75%, Validation loss:1.927, Validation accuracy:30.67%
# Epoch 82: iteration 34/35
# Epoch 82 --- loss:2.036, Epoch accuracy:17.11%, Validation loss:1.920, Validation accuracy:32.33%
# Epoch 83: iteration 34/35
# Epoch 83 --- loss:2.041, Epoch accuracy:16.58%, Validation loss:1.928, Validation accuracy:29.33%
# Epoch 84: iteration 34/35
# Epoch 84 --- loss:2.029, Epoch accuracy:16.40%, Validation loss:1.916, Validation accuracy:32.33%
# Epoch 85: iteration 34/35
# Epoch 85 --- loss:2.020, Epoch accuracy:16.49%, Validation loss:1.918, Validation accuracy:30.33%
# Epoch 86: iteration 34/35
# Epoch 86 --- loss:2.028, Epoch accuracy:16.05%, Validation loss:1.921, Validation accuracy:29.67%
# Epoch 87: iteration 34/35
# Epoch 87 --- loss:2.004, Epoch accuracy:19.21%, Validation loss:1.913, Validation accuracy:29.33%
# Epoch 88: iteration 34/35
# Epoch 88 --- loss:2.002, Epoch accuracy:18.60%, Validation loss:1.912, Validation accuracy:30.67%
# Epoch 89: iteration 34/35
# Epoch 89 --- loss:2.031, Epoch accuracy:16.67%, Validation loss:1.910, Validation accuracy:31.67%
# Epoch 90: iteration 34/35
# Epoch 90 --- loss:2.003, Epoch accuracy:18.95%, Validation loss:1.903, Validation accuracy:33.00%
# Epoch 91: iteration 34/35
# Epoch 91 --- loss:2.030, Epoch accuracy:17.72%, Validation loss:1.908, Validation accuracy:31.00%
# Epoch 92: iteration 34/35
# Epoch 92 --- loss:2.004, Epoch accuracy:17.46%, Validation loss:1.901, Validation accuracy:31.33%
# Epoch 93: iteration 34/35
# Epoch 93 --- loss:2.004, Epoch accuracy:19.47%, Validation loss:1.900, Validation accuracy:31.33%
# Epoch 94: iteration 34/35
# Epoch 94 --- loss:2.013, Epoch accuracy:18.33%, Validation loss:1.902, Validation accuracy:29.33%
# Epoch 95: iteration 34/35
# Epoch 95 --- loss:2.018, Epoch accuracy:17.11%, Validation loss:1.898, Validation accuracy:31.33%
# Epoch 96: iteration 34/35
# Epoch 96 --- loss:2.000, Epoch accuracy:18.33%, Validation loss:1.892, Validation accuracy:32.33%
# Epoch 97: iteration 34/35
# Epoch 97 --- loss:2.018, Epoch accuracy:16.84%, Validation loss:1.892, Validation accuracy:33.33%
# Epoch 98: iteration 34/35
# Epoch 98 --- loss:2.008, Epoch accuracy:16.67%, Validation loss:1.890, Validation accuracy:32.00%
# Epoch 99: iteration 34/35
# Epoch 99 --- loss:1.989, Epoch accuracy:18.95%, Validation loss:1.892, Validation accuracy:32.00%
# Epoch 100: iteration 34/35
# Epoch 100 --- loss:2.007, Epoch accuracy:17.98%, Validation loss:1.875, Validation accuracy:34.00%
# Epoch 101: iteration 34/35
# Epoch 101 --- loss:2.001, Epoch accuracy:17.37%, Validation loss:1.878, Validation accuracy:31.00%
# Epoch 102: iteration 34/35
# Epoch 102 --- loss:1.995, Epoch accuracy:20.09%, Validation loss:1.871, Validation accuracy:33.67%
# Epoch 103: iteration 34/35
# Epoch 103 --- loss:2.006, Epoch accuracy:19.21%, Validation loss:1.876, Validation accuracy:35.33%
# Epoch 104: iteration 34/35
# Epoch 104 --- loss:1.994, Epoch accuracy:19.04%, Validation loss:1.869, Validation accuracy:32.67%
# Epoch 105: iteration 34/35
# Epoch 105 --- loss:1.984, Epoch accuracy:20.00%, Validation loss:1.867, Validation accuracy:35.33%
# Epoch 106: iteration 34/35
# Epoch 106 --- loss:1.990, Epoch accuracy:20.53%, Validation loss:1.862, Validation accuracy:35.33%
# Epoch 107: iteration 34/35
# Epoch 107 --- loss:1.994, Epoch accuracy:18.60%, Validation loss:1.868, Validation accuracy:34.33%
# Epoch 108: iteration 34/35
# Epoch 108 --- loss:2.014, Epoch accuracy:17.98%, Validation loss:1.863, Validation accuracy:33.33%
# Epoch 109: iteration 34/35
# Epoch 109 --- loss:2.020, Epoch accuracy:16.49%, Validation loss:1.861, Validation accuracy:33.33%
# Epoch 110: iteration 34/35
# Epoch 110 --- loss:1.982, Epoch accuracy:20.96%, Validation loss:1.862, Validation accuracy:32.67%
# Epoch 111: iteration 34/35
# Epoch 111 --- loss:2.001, Epoch accuracy:19.12%, Validation loss:1.853, Validation accuracy:35.67%
# Epoch 112: iteration 34/35
# Epoch 112 --- loss:1.985, Epoch accuracy:20.79%, Validation loss:1.856, Validation accuracy:33.33%
# Epoch 113: iteration 34/35
# Epoch 113 --- loss:1.979, Epoch accuracy:20.26%, Validation loss:1.849, Validation accuracy:34.67%
# Epoch 114: iteration 34/35
# Epoch 114 --- loss:1.971, Epoch accuracy:21.49%, Validation loss:1.848, Validation accuracy:34.67%
# Epoch 115: iteration 34/35
# Epoch 115 --- loss:1.992, Epoch accuracy:19.39%, Validation loss:1.840, Validation accuracy:35.67%
# Epoch 116: iteration 34/35
# Epoch 116 --- loss:1.984, Epoch accuracy:20.26%, Validation loss:1.838, Validation accuracy:36.00%
# Epoch 117: iteration 34/35
# Epoch 117 --- loss:1.984, Epoch accuracy:19.74%, Validation loss:1.838, Validation accuracy:33.67%
# Epoch 118: iteration 34/35
# Epoch 118 --- loss:1.993, Epoch accuracy:18.25%, Validation loss:1.832, Validation accuracy:38.00%
# Epoch 119: iteration 34/35
# Epoch 119 --- loss:1.979, Epoch accuracy:20.26%, Validation loss:1.831, Validation accuracy:36.33%
# Epoch 120: iteration 34/35
# Epoch 120 --- loss:1.966, Epoch accuracy:20.26%, Validation loss:1.819, Validation accuracy:36.67%
# Epoch 121: iteration 34/35
# Epoch 121 --- loss:1.961, Epoch accuracy:21.67%, Validation loss:1.823, Validation accuracy:37.00%
# Epoch 122: iteration 34/35
# Epoch 122 --- loss:1.980, Epoch accuracy:21.05%, Validation loss:1.819, Validation accuracy:37.33%
# Epoch 123: iteration 34/35
# Epoch 123 --- loss:1.967, Epoch accuracy:20.53%, Validation loss:1.820, Validation accuracy:34.00%
# Epoch 124: iteration 34/35
# Epoch 124 --- loss:1.981, Epoch accuracy:20.53%, Validation loss:1.819, Validation accuracy:35.00%
# Epoch 125: iteration 34/35
# Epoch 125 --- loss:1.975, Epoch accuracy:19.56%, Validation loss:1.807, Validation accuracy:35.33%
# Epoch 126: iteration 34/35
# Epoch 126 --- loss:1.954, Epoch accuracy:20.88%, Validation loss:1.807, Validation accuracy:35.33%
# Epoch 127: iteration 34/35
# Epoch 127 --- loss:1.955, Epoch accuracy:22.37%, Validation loss:1.802, Validation accuracy:36.00%
# Epoch 128: iteration 34/35
# Epoch 128 --- loss:1.956, Epoch accuracy:22.46%, Validation loss:1.795, Validation accuracy:38.67%
# Epoch 129: iteration 34/35
# Epoch 129 --- loss:1.974, Epoch accuracy:19.82%, Validation loss:1.797, Validation accuracy:39.00%
# Epoch 130: iteration 34/35
# Epoch 130 --- loss:1.957, Epoch accuracy:20.96%, Validation loss:1.794, Validation accuracy:36.67%
# Epoch 131: iteration 34/35
# Epoch 131 --- loss:1.950, Epoch accuracy:21.67%, Validation loss:1.783, Validation accuracy:39.00%
# Epoch 132: iteration 34/35
# Epoch 132 --- loss:1.976, Epoch accuracy:19.39%, Validation loss:1.791, Validation accuracy:37.33%
# Epoch 133: iteration 34/35
# Epoch 133 --- loss:1.933, Epoch accuracy:26.05%, Validation loss:1.782, Validation accuracy:39.00%
# Epoch 134: iteration 34/35
# Epoch 134 --- loss:1.957, Epoch accuracy:20.44%, Validation loss:1.784, Validation accuracy:36.67%
# Epoch 135: iteration 34/35
# Epoch 135 --- loss:1.952, Epoch accuracy:20.61%, Validation loss:1.777, Validation accuracy:38.67%
# Epoch 136: iteration 34/35
# Epoch 136 --- loss:1.949, Epoch accuracy:20.88%, Validation loss:1.774, Validation accuracy:39.00%
# Epoch 137: iteration 34/35
# Epoch 137 --- loss:1.953, Epoch accuracy:20.35%, Validation loss:1.769, Validation accuracy:39.00%
# Epoch 138: iteration 34/35
# Epoch 138 --- loss:1.965, Epoch accuracy:22.37%, Validation loss:1.774, Validation accuracy:37.33%
# Epoch 139: iteration 34/35
# Epoch 139 --- loss:1.930, Epoch accuracy:22.89%, Validation loss:1.771, Validation accuracy:36.67%
# Epoch 140: iteration 34/35
# Epoch 140 --- loss:1.923, Epoch accuracy:23.07%, Validation loss:1.763, Validation accuracy:39.67%
# Epoch 141: iteration 34/35
# Epoch 141 --- loss:1.934, Epoch accuracy:23.60%, Validation loss:1.757, Validation accuracy:38.67%
# Epoch 142: iteration 34/35
# Epoch 142 --- loss:1.929, Epoch accuracy:22.98%, Validation loss:1.759, Validation accuracy:38.33%
# Epoch 143: iteration 34/35
# Epoch 143 --- loss:1.924, Epoch accuracy:24.47%, Validation loss:1.763, Validation accuracy:38.00%
# Epoch 144: iteration 34/35
# Epoch 144 --- loss:1.930, Epoch accuracy:24.56%, Validation loss:1.755, Validation accuracy:37.33%
# Epoch 145: iteration 34/35
# Epoch 145 --- loss:1.941, Epoch accuracy:22.63%, Validation loss:1.758, Validation accuracy:37.67%
# Epoch 146: iteration 34/35
# Epoch 146 --- loss:1.928, Epoch accuracy:24.04%, Validation loss:1.749, Validation accuracy:39.00%
# Epoch 147: iteration 34/35
# Epoch 147 --- loss:1.933, Epoch accuracy:24.12%, Validation loss:1.749, Validation accuracy:38.33%
# Epoch 148: iteration 34/35
# Epoch 148 --- loss:1.929, Epoch accuracy:23.42%, Validation loss:1.733, Validation accuracy:40.00%
# Epoch 149: iteration 34/35
# Epoch 149 --- loss:1.895, Epoch accuracy:26.49%, Validation loss:1.734, Validation accuracy:39.33%
# Epoch 150: iteration 34/35
# Epoch 150 --- loss:1.914, Epoch accuracy:22.89%, Validation loss:1.728, Validation accuracy:40.33%
# Epoch 151: iteration 34/35
# Epoch 151 --- loss:1.917, Epoch accuracy:24.74%, Validation loss:1.719, Validation accuracy:40.67%
# Epoch 152: iteration 34/35
# Epoch 152 --- loss:1.912, Epoch accuracy:25.00%, Validation loss:1.714, Validation accuracy:40.33%
# Epoch 153: iteration 34/35
# Epoch 153 --- loss:1.913, Epoch accuracy:23.60%, Validation loss:1.720, Validation accuracy:39.67%
# Epoch 154: iteration 34/35
# Epoch 154 --- loss:1.912, Epoch accuracy:23.68%, Validation loss:1.714, Validation accuracy:40.00%
# Epoch 155: iteration 34/35
# Epoch 155 --- loss:1.892, Epoch accuracy:25.26%, Validation loss:1.712, Validation accuracy:41.00%
# Epoch 156: iteration 34/35
# Epoch 156 --- loss:1.898, Epoch accuracy:25.35%, Validation loss:1.707, Validation accuracy:40.33%
# Epoch 157: iteration 34/35
# Epoch 157 --- loss:1.891, Epoch accuracy:24.12%, Validation loss:1.711, Validation accuracy:40.33%
# Epoch 158: iteration 34/35
# Epoch 158 --- loss:1.895, Epoch accuracy:25.61%, Validation loss:1.715, Validation accuracy:38.67%
# Epoch 159: iteration 34/35
# Epoch 159 --- loss:1.903, Epoch accuracy:25.00%, Validation loss:1.698, Validation accuracy:42.33%
# Epoch 160: iteration 34/35
# Epoch 160 --- loss:1.885, Epoch accuracy:26.14%, Validation loss:1.703, Validation accuracy:38.67%
# Epoch 161: iteration 34/35
# Epoch 161 --- loss:1.898, Epoch accuracy:27.72%, Validation loss:1.686, Validation accuracy:40.00%
# Epoch 162: iteration 34/35
# Epoch 162 --- loss:1.888, Epoch accuracy:26.67%, Validation loss:1.683, Validation accuracy:41.00%
# Epoch 163: iteration 34/35
# Epoch 163 --- loss:1.881, Epoch accuracy:25.96%, Validation loss:1.698, Validation accuracy:38.67%
# Epoch 164: iteration 34/35
# Epoch 164 --- loss:1.888, Epoch accuracy:26.84%, Validation loss:1.689, Validation accuracy:40.33%
# Epoch 165: iteration 34/35
# Epoch 165 --- loss:1.884, Epoch accuracy:27.28%, Validation loss:1.685, Validation accuracy:41.33%
# Epoch 166: iteration 34/35
# Epoch 166 --- loss:1.886, Epoch accuracy:26.84%, Validation loss:1.673, Validation accuracy:41.67%
# Epoch 167: iteration 34/35
# Epoch 167 --- loss:1.875, Epoch accuracy:27.02%, Validation loss:1.677, Validation accuracy:40.00%
# Epoch 168: iteration 34/35
# Epoch 168 --- loss:1.899, Epoch accuracy:24.04%, Validation loss:1.665, Validation accuracy:40.00%
# Epoch 169: iteration 34/35
# Epoch 169 --- loss:1.879, Epoch accuracy:25.35%, Validation loss:1.663, Validation accuracy:41.33%
# Epoch 170: iteration 34/35
# Epoch 170 --- loss:1.892, Epoch accuracy:24.39%, Validation loss:1.658, Validation accuracy:41.00%
# Epoch 171: iteration 34/35
# Epoch 171 --- loss:1.891, Epoch accuracy:27.63%, Validation loss:1.670, Validation accuracy:40.67%
# Epoch 172: iteration 34/35
# Epoch 172 --- loss:1.863, Epoch accuracy:26.49%, Validation loss:1.663, Validation accuracy:40.33%
# Epoch 173: iteration 34/35
# Epoch 173 --- loss:1.877, Epoch accuracy:26.14%, Validation loss:1.648, Validation accuracy:42.00%
# Epoch 174: iteration 34/35
# Epoch 174 --- loss:1.857, Epoch accuracy:28.16%, Validation loss:1.653, Validation accuracy:41.00%
# Epoch 175: iteration 34/35
# Epoch 175 --- loss:1.865, Epoch accuracy:27.72%, Validation loss:1.648, Validation accuracy:42.00%
# Epoch 176: iteration 34/35
# Epoch 176 --- loss:1.869, Epoch accuracy:28.33%, Validation loss:1.635, Validation accuracy:42.33%
# Epoch 177: iteration 34/35
# Epoch 177 --- loss:1.850, Epoch accuracy:28.33%, Validation loss:1.638, Validation accuracy:40.67%
# Epoch 178: iteration 34/35
# Epoch 178 --- loss:1.843, Epoch accuracy:29.04%, Validation loss:1.623, Validation accuracy:42.00%
# Epoch 179: iteration 34/35
# Epoch 179 --- loss:1.843, Epoch accuracy:29.21%, Validation loss:1.631, Validation accuracy:42.00%
# Epoch 180: iteration 34/35
# Epoch 180 --- loss:1.844, Epoch accuracy:28.68%, Validation loss:1.634, Validation accuracy:42.33%
# Epoch 181: iteration 34/35
# Epoch 181 --- loss:1.859, Epoch accuracy:27.81%, Validation loss:1.624, Validation accuracy:41.67%
# Epoch 182: iteration 34/35
# Epoch 182 --- loss:1.852, Epoch accuracy:28.42%, Validation loss:1.636, Validation accuracy:42.33%
# Epoch 183: iteration 34/35
# Epoch 183 --- loss:1.843, Epoch accuracy:28.16%, Validation loss:1.612, Validation accuracy:42.33%
# Epoch 184: iteration 34/35
# Epoch 184 --- loss:1.815, Epoch accuracy:30.35%, Validation loss:1.603, Validation accuracy:43.00%
# Epoch 185: iteration 34/35
# Epoch 185 --- loss:1.846, Epoch accuracy:29.91%, Validation loss:1.606, Validation accuracy:42.67%
# Epoch 186: iteration 34/35
# Epoch 186 --- loss:1.825, Epoch accuracy:29.30%, Validation loss:1.592, Validation accuracy:42.67%
# Epoch 187: iteration 34/35
# Epoch 187 --- loss:1.827, Epoch accuracy:29.47%, Validation loss:1.593, Validation accuracy:43.33%
# Epoch 188: iteration 34/35
# Epoch 188 --- loss:1.815, Epoch accuracy:29.91%, Validation loss:1.593, Validation accuracy:44.00%
# Epoch 189: iteration 34/35
# Epoch 189 --- loss:1.809, Epoch accuracy:30.96%, Validation loss:1.590, Validation accuracy:44.33%
# Epoch 190: iteration 34/35
# Epoch 190 --- loss:1.823, Epoch accuracy:29.39%, Validation loss:1.581, Validation accuracy:43.33%
# Epoch 191: iteration 34/35
# Epoch 191 --- loss:1.818, Epoch accuracy:32.37%, Validation loss:1.563, Validation accuracy:45.33%
# Epoch 192: iteration 34/35
# Epoch 192 --- loss:1.817, Epoch accuracy:31.58%, Validation loss:1.579, Validation accuracy:43.00%
# Epoch 193: iteration 34/35
# Epoch 193 --- loss:1.801, Epoch accuracy:31.23%, Validation loss:1.568, Validation accuracy:45.00%
# Epoch 194: iteration 34/35
# Epoch 194 --- loss:1.808, Epoch accuracy:29.47%, Validation loss:1.570, Validation accuracy:45.00%
# Epoch 195: iteration 34/35
# Epoch 195 --- loss:1.814, Epoch accuracy:29.04%, Validation loss:1.544, Validation accuracy:46.00%
# Epoch 196: iteration 34/35
# Epoch 196 --- loss:1.792, Epoch accuracy:32.89%, Validation loss:1.555, Validation accuracy:45.33%
# Epoch 197: iteration 34/35
# Epoch 197 --- loss:1.786, Epoch accuracy:31.49%, Validation loss:1.562, Validation accuracy:42.67%
# Epoch 198: iteration 34/35
# Epoch 198 --- loss:1.791, Epoch accuracy:32.46%, Validation loss:1.553, Validation accuracy:45.00%
# Epoch 199: iteration 34/35
# Epoch 199 --- loss:1.781, Epoch accuracy:31.49%, Validation loss:1.536, Validation accuracy:46.67%
# Epoch 200: iteration 34/35
# Epoch 200 --- loss:1.788, Epoch accuracy:31.49%, Validation loss:1.539, Validation accuracy:46.67%
# Epoch 201: iteration 34/35
# Epoch 201 --- loss:1.797, Epoch accuracy:31.40%, Validation loss:1.520, Validation accuracy:47.33%
# Epoch 202: iteration 34/35
# Epoch 202 --- loss:1.781, Epoch accuracy:33.77%, Validation loss:1.534, Validation accuracy:46.00%
# Epoch 203: iteration 34/35
# Epoch 203 --- loss:1.773, Epoch accuracy:32.54%, Validation loss:1.548, Validation accuracy:44.33%
# Epoch 204: iteration 34/35
# Epoch 204 --- loss:1.791, Epoch accuracy:30.79%, Validation loss:1.536, Validation accuracy:45.67%
# Epoch 205: iteration 34/35
# Epoch 205 --- loss:1.784, Epoch accuracy:32.72%, Validation loss:1.515, Validation accuracy:45.00%
# Epoch 206: iteration 34/35
# Epoch 206 --- loss:1.778, Epoch accuracy:31.67%, Validation loss:1.500, Validation accuracy:47.00%
# Epoch 207: iteration 34/35
# Epoch 207 --- loss:1.754, Epoch accuracy:33.86%, Validation loss:1.509, Validation accuracy:44.67%
# Epoch 208: iteration 34/35
# Epoch 208 --- loss:1.760, Epoch accuracy:32.46%, Validation loss:1.500, Validation accuracy:47.00%
# Epoch 209: iteration 34/35
# Epoch 209 --- loss:1.744, Epoch accuracy:35.88%, Validation loss:1.513, Validation accuracy:45.00%
# Epoch 210: iteration 34/35
# Epoch 210 --- loss:1.761, Epoch accuracy:32.37%, Validation loss:1.497, Validation accuracy:47.67%
# Epoch 211: iteration 34/35
# Epoch 211 --- loss:1.791, Epoch accuracy:29.04%, Validation loss:1.483, Validation accuracy:48.67%
# Epoch 212: iteration 34/35
# Epoch 212 --- loss:1.752, Epoch accuracy:35.26%, Validation loss:1.493, Validation accuracy:47.67%
# Epoch 213: iteration 34/35
# Epoch 213 --- loss:1.747, Epoch accuracy:33.42%, Validation loss:1.474, Validation accuracy:47.00%
# Epoch 214: iteration 34/35
# Epoch 214 --- loss:1.738, Epoch accuracy:35.35%, Validation loss:1.510, Validation accuracy:45.33%
# Epoch 215: iteration 34/35
# Epoch 215 --- loss:1.733, Epoch accuracy:35.79%, Validation loss:1.463, Validation accuracy:47.33%
# Epoch 216: iteration 34/35
# Epoch 216 --- loss:1.708, Epoch accuracy:36.23%, Validation loss:1.476, Validation accuracy:48.00%
# Epoch 217: iteration 34/35
# Epoch 217 --- loss:1.727, Epoch accuracy:35.44%, Validation loss:1.468, Validation accuracy:46.67%
# Epoch 218: iteration 34/35
# Epoch 218 --- loss:1.727, Epoch accuracy:34.12%, Validation loss:1.450, Validation accuracy:47.67%
# Epoch 219: iteration 34/35
# Epoch 219 --- loss:1.739, Epoch accuracy:34.65%, Validation loss:1.458, Validation accuracy:48.33%
# Epoch 220: iteration 34/35
# Epoch 220 --- loss:1.711, Epoch accuracy:36.40%, Validation loss:1.465, Validation accuracy:48.33%
# Epoch 221: iteration 34/35
# Epoch 221 --- loss:1.711, Epoch accuracy:36.67%, Validation loss:1.458, Validation accuracy:48.67%
# Epoch 222: iteration 34/35
# Epoch 222 --- loss:1.712, Epoch accuracy:37.02%, Validation loss:1.456, Validation accuracy:48.67%
# Epoch 223: iteration 34/35
# Epoch 223 --- loss:1.702, Epoch accuracy:36.05%, Validation loss:1.438, Validation accuracy:49.00%
# Epoch 224: iteration 34/35
# Epoch 224 --- loss:1.727, Epoch accuracy:34.12%, Validation loss:1.433, Validation accuracy:49.67%
# Epoch 225: iteration 34/35
# Epoch 225 --- loss:1.707, Epoch accuracy:34.91%, Validation loss:1.440, Validation accuracy:48.67%
# Epoch 226: iteration 34/35
# Epoch 226 --- loss:1.694, Epoch accuracy:37.37%, Validation loss:1.431, Validation accuracy:49.33%
# Epoch 227: iteration 34/35
# Epoch 227 --- loss:1.704, Epoch accuracy:37.02%, Validation loss:1.414, Validation accuracy:49.67%
# Epoch 228: iteration 34/35
# Epoch 228 --- loss:1.679, Epoch accuracy:39.04%, Validation loss:1.434, Validation accuracy:49.67%
# Epoch 229: iteration 34/35
# Epoch 229 --- loss:1.700, Epoch accuracy:36.93%, Validation loss:1.431, Validation accuracy:49.67%
# Epoch 230: iteration 34/35
# Epoch 230 --- loss:1.692, Epoch accuracy:37.63%, Validation loss:1.393, Validation accuracy:50.67%
# Epoch 231: iteration 34/35
# Epoch 231 --- loss:1.691, Epoch accuracy:36.75%, Validation loss:1.400, Validation accuracy:50.00%
# Epoch 232: iteration 34/35
# Epoch 232 --- loss:1.677, Epoch accuracy:39.04%, Validation loss:1.388, Validation accuracy:51.00%
# Epoch 233: iteration 34/35
# Epoch 233 --- loss:1.680, Epoch accuracy:38.33%, Validation loss:1.389, Validation accuracy:50.33%
# Epoch 234: iteration 34/35
# Epoch 234 --- loss:1.672, Epoch accuracy:38.42%, Validation loss:1.397, Validation accuracy:49.67%
# Epoch 235: iteration 34/35
# Epoch 235 --- loss:1.692, Epoch accuracy:38.07%, Validation loss:1.384, Validation accuracy:51.00%
# Epoch 236: iteration 34/35
# Epoch 236 --- loss:1.681, Epoch accuracy:37.98%, Validation loss:1.381, Validation accuracy:51.67%
# Epoch 237: iteration 34/35
# Epoch 237 --- loss:1.678, Epoch accuracy:37.19%, Validation loss:1.378, Validation accuracy:51.33%
# Epoch 238: iteration 34/35
# Epoch 238 --- loss:1.655, Epoch accuracy:37.81%, Validation loss:1.407, Validation accuracy:49.33%
# Epoch 239: iteration 34/35
# Epoch 239 --- loss:1.669, Epoch accuracy:37.54%, Validation loss:1.394, Validation accuracy:50.00%
# Epoch 240: iteration 34/35
# Epoch 240 --- loss:1.673, Epoch accuracy:37.98%, Validation loss:1.378, Validation accuracy:50.33%
# Epoch 241: iteration 34/35
# Epoch 241 --- loss:1.661, Epoch accuracy:38.25%, Validation loss:1.386, Validation accuracy:49.33%
# Epoch 242: iteration 34/35
# Epoch 242 --- loss:1.644, Epoch accuracy:38.95%, Validation loss:1.398, Validation accuracy:50.33%
# Epoch 243: iteration 34/35
# Epoch 243 --- loss:1.662, Epoch accuracy:37.19%, Validation loss:1.343, Validation accuracy:54.33%
# Epoch 244: iteration 34/35
# Epoch 244 --- loss:1.634, Epoch accuracy:40.70%, Validation loss:1.358, Validation accuracy:52.00%
# Epoch 245: iteration 34/35
# Epoch 245 --- loss:1.632, Epoch accuracy:41.75%, Validation loss:1.341, Validation accuracy:54.33%
# Epoch 246: iteration 34/35
# Epoch 246 --- loss:1.615, Epoch accuracy:41.67%, Validation loss:1.347, Validation accuracy:52.67%
# Epoch 247: iteration 34/35
# Epoch 247 --- loss:1.626, Epoch accuracy:40.09%, Validation loss:1.319, Validation accuracy:55.33%
# Epoch 248: iteration 34/35
# Epoch 248 --- loss:1.651, Epoch accuracy:39.39%, Validation loss:1.348, Validation accuracy:52.33%
# Epoch 249: iteration 34/35
# Epoch 249 --- loss:1.614, Epoch accuracy:40.53%, Validation loss:1.329, Validation accuracy:54.00%
# Epoch 250: iteration 34/35
# Epoch 250 --- loss:1.622, Epoch accuracy:41.58%, Validation loss:1.318, Validation accuracy:55.67%
# Epoch 251: iteration 34/35
# Epoch 251 --- loss:1.604, Epoch accuracy:41.75%, Validation loss:1.305, Validation accuracy:55.00%
# Epoch 252: iteration 34/35
# Epoch 252 --- loss:1.620, Epoch accuracy:39.82%, Validation loss:1.330, Validation accuracy:53.33%
# Epoch 253: iteration 34/35
# Epoch 253 --- loss:1.593, Epoch accuracy:42.98%, Validation loss:1.326, Validation accuracy:53.33%
# Epoch 254: iteration 34/35
# Epoch 254 --- loss:1.622, Epoch accuracy:41.40%, Validation loss:1.309, Validation accuracy:55.67%
# Epoch 255: iteration 34/35
# Epoch 255 --- loss:1.581, Epoch accuracy:42.46%, Validation loss:1.318, Validation accuracy:53.67%
# Epoch 256: iteration 34/35
# Epoch 256 --- loss:1.588, Epoch accuracy:43.95%, Validation loss:1.323, Validation accuracy:53.00%
# Epoch 257: iteration 34/35
# Epoch 257 --- loss:1.598, Epoch accuracy:43.25%, Validation loss:1.295, Validation accuracy:54.67%
# Epoch 258: iteration 34/35
# Epoch 258 --- loss:1.585, Epoch accuracy:44.12%, Validation loss:1.292, Validation accuracy:54.33%
# Epoch 259: iteration 34/35
# Epoch 259 --- loss:1.551, Epoch accuracy:46.58%, Validation loss:1.296, Validation accuracy:53.00%
# Epoch 260: iteration 34/35
# Epoch 260 --- loss:1.587, Epoch accuracy:43.42%, Validation loss:1.301, Validation accuracy:55.00%
# Epoch 261: iteration 34/35
# Epoch 261 --- loss:1.581, Epoch accuracy:43.86%, Validation loss:1.280, Validation accuracy:56.33%
# Epoch 262: iteration 34/35
# Epoch 262 --- loss:1.552, Epoch accuracy:44.47%, Validation loss:1.285, Validation accuracy:54.33%
# Epoch 263: iteration 34/35
# Epoch 263 --- loss:1.565, Epoch accuracy:44.04%, Validation loss:1.297, Validation accuracy:55.00%
# Epoch 264: iteration 34/35
# Epoch 264 --- loss:1.567, Epoch accuracy:41.84%, Validation loss:1.265, Validation accuracy:56.33%
# Epoch 265: iteration 34/35
# Epoch 265 --- loss:1.544, Epoch accuracy:42.81%, Validation loss:1.305, Validation accuracy:53.67%
# Epoch 266: iteration 34/35
# Epoch 266 --- loss:1.570, Epoch accuracy:44.30%, Validation loss:1.270, Validation accuracy:54.67%
# Epoch 267: iteration 34/35
# Epoch 267 --- loss:1.535, Epoch accuracy:44.82%, Validation loss:1.282, Validation accuracy:54.33%
# Epoch 268: iteration 34/35
# Epoch 268 --- loss:1.542, Epoch accuracy:44.82%, Validation loss:1.265, Validation accuracy:55.33%
# Epoch 269: iteration 34/35
# Epoch 269 --- loss:1.518, Epoch accuracy:46.84%, Validation loss:1.244, Validation accuracy:57.00%
# Epoch 270: iteration 34/35
# Epoch 270 --- loss:1.529, Epoch accuracy:47.81%, Validation loss:1.255, Validation accuracy:55.00%
# Epoch 271: iteration 34/35
# Epoch 271 --- loss:1.523, Epoch accuracy:48.33%, Validation loss:1.229, Validation accuracy:57.67%
# Epoch 272: iteration 34/35
# Epoch 272 --- loss:1.509, Epoch accuracy:46.40%, Validation loss:1.247, Validation accuracy:56.67%
# Epoch 273: iteration 34/35
# Epoch 273 --- loss:1.530, Epoch accuracy:44.12%, Validation loss:1.249, Validation accuracy:56.33%
# Epoch 274: iteration 34/35
# Epoch 274 --- loss:1.510, Epoch accuracy:46.49%, Validation loss:1.239, Validation accuracy:56.33%
# Epoch 275: iteration 34/35
# Epoch 275 --- loss:1.503, Epoch accuracy:45.61%, Validation loss:1.222, Validation accuracy:57.33%
# Epoch 276: iteration 34/35
# Epoch 276 --- loss:1.484, Epoch accuracy:46.75%, Validation loss:1.223, Validation accuracy:58.33%
# Epoch 277: iteration 34/35
# Epoch 277 --- loss:1.506, Epoch accuracy:48.60%, Validation loss:1.220, Validation accuracy:57.67%
# Epoch 278: iteration 34/35
# Epoch 278 --- loss:1.519, Epoch accuracy:47.37%, Validation loss:1.203, Validation accuracy:58.00%
# Epoch 279: iteration 34/35
# Epoch 279 --- loss:1.511, Epoch accuracy:45.35%, Validation loss:1.242, Validation accuracy:56.67%
# Epoch 280: iteration 34/35
# Epoch 280 --- loss:1.499, Epoch accuracy:48.07%, Validation loss:1.219, Validation accuracy:58.33%
# Epoch 281: iteration 34/35
# Epoch 281 --- loss:1.477, Epoch accuracy:48.33%, Validation loss:1.189, Validation accuracy:58.67%
# Epoch 282: iteration 34/35
# Epoch 282 --- loss:1.483, Epoch accuracy:47.89%, Validation loss:1.196, Validation accuracy:58.00%
# Epoch 283: iteration 34/35
# Epoch 283 --- loss:1.471, Epoch accuracy:48.25%, Validation loss:1.217, Validation accuracy:57.67%
# Epoch 284: iteration 34/35
# Epoch 284 --- loss:1.455, Epoch accuracy:48.77%, Validation loss:1.226, Validation accuracy:57.33%
# Epoch 285: iteration 34/35
# Epoch 285 --- loss:1.470, Epoch accuracy:48.42%, Validation loss:1.193, Validation accuracy:58.33%
# Epoch 286: iteration 34/35
# Epoch 286 --- loss:1.447, Epoch accuracy:49.47%, Validation loss:1.198, Validation accuracy:58.33%
# Epoch 287: iteration 34/35
# Epoch 287 --- loss:1.449, Epoch accuracy:50.00%, Validation loss:1.190, Validation accuracy:57.33%
# Epoch 288: iteration 34/35
# Epoch 288 --- loss:1.472, Epoch accuracy:47.54%, Validation loss:1.187, Validation accuracy:58.33%
# Epoch 289: iteration 34/35
# Epoch 289 --- loss:1.459, Epoch accuracy:47.98%, Validation loss:1.167, Validation accuracy:58.33%
# Epoch 290: iteration 34/35
# Epoch 290 --- loss:1.443, Epoch accuracy:50.53%, Validation loss:1.196, Validation accuracy:57.00%
# Epoch 291: iteration 34/35
# Epoch 291 --- loss:1.427, Epoch accuracy:51.32%, Validation loss:1.197, Validation accuracy:59.00%
# Epoch 292: iteration 34/35
# Epoch 292 --- loss:1.441, Epoch accuracy:50.35%, Validation loss:1.187, Validation accuracy:59.33%
# Epoch 293: iteration 34/35
# Epoch 293 --- loss:1.449, Epoch accuracy:48.60%, Validation loss:1.196, Validation accuracy:58.67%
# Epoch 294: iteration 34/35
# Epoch 294 --- loss:1.447, Epoch accuracy:48.33%, Validation loss:1.166, Validation accuracy:59.67%
# Epoch 295: iteration 34/35
# Epoch 295 --- loss:1.435, Epoch accuracy:50.35%, Validation loss:1.160, Validation accuracy:59.67%
# Epoch 296: iteration 34/35
# Epoch 296 --- loss:1.426, Epoch accuracy:50.00%, Validation loss:1.171, Validation accuracy:59.00%
# Epoch 297: iteration 34/35
# Epoch 297 --- loss:1.439, Epoch accuracy:47.89%, Validation loss:1.170, Validation accuracy:58.00%
# Epoch 298: iteration 34/35
# Epoch 298 --- loss:1.444, Epoch accuracy:49.47%, Validation loss:1.153, Validation accuracy:60.00%
# Epoch 299: iteration 34/35
# Epoch 299 --- loss:1.404, Epoch accuracy:51.67%, Validation loss:1.163, Validation accuracy:59.00%
# Epoch 300: iteration 34/35
# Epoch 300 --- loss:1.406, Epoch accuracy:51.58%, Validation loss:1.154, Validation accuracy:58.67%
# Epoch 301: iteration 34/35
# Epoch 301 --- loss:1.389, Epoch accuracy:52.72%, Validation loss:1.152, Validation accuracy:59.67%
# Epoch 302: iteration 34/35
# Epoch 302 --- loss:1.392, Epoch accuracy:51.49%, Validation loss:1.149, Validation accuracy:59.67%
# Epoch 303: iteration 34/35
# Epoch 303 --- loss:1.379, Epoch accuracy:50.96%, Validation loss:1.169, Validation accuracy:58.67%
# Epoch 304: iteration 34/35
# Epoch 304 --- loss:1.384, Epoch accuracy:52.54%, Validation loss:1.145, Validation accuracy:59.33%
# Epoch 305: iteration 34/35
# Epoch 305 --- loss:1.395, Epoch accuracy:50.79%, Validation loss:1.159, Validation accuracy:60.67%
# Epoch 306: iteration 34/35
# Epoch 306 --- loss:1.364, Epoch accuracy:53.95%, Validation loss:1.120, Validation accuracy:62.33%
# Epoch 307: iteration 34/35
# Epoch 307 --- loss:1.372, Epoch accuracy:51.40%, Validation loss:1.140, Validation accuracy:61.00%
# Epoch 308: iteration 34/35
# Epoch 308 --- loss:1.379, Epoch accuracy:50.96%, Validation loss:1.116, Validation accuracy:62.33%
# Epoch 309: iteration 34/35
# Epoch 309 --- loss:1.363, Epoch accuracy:53.68%, Validation loss:1.124, Validation accuracy:60.33%
# Epoch 310: iteration 34/35
# Epoch 310 --- loss:1.371, Epoch accuracy:55.88%, Validation loss:1.124, Validation accuracy:59.67%
# Epoch 311: iteration 34/35
# Epoch 311 --- loss:1.352, Epoch accuracy:54.21%, Validation loss:1.131, Validation accuracy:59.67%
# Epoch 312: iteration 34/35
# Epoch 312 --- loss:1.360, Epoch accuracy:54.12%, Validation loss:1.126, Validation accuracy:59.67%
# Epoch 313: iteration 34/35
# Epoch 313 --- loss:1.356, Epoch accuracy:53.42%, Validation loss:1.110, Validation accuracy:60.33%
# Epoch 314: iteration 34/35
# Epoch 314 --- loss:1.334, Epoch accuracy:55.00%, Validation loss:1.101, Validation accuracy:60.00%
# Epoch 315: iteration 34/35
# Epoch 315 --- loss:1.342, Epoch accuracy:55.61%, Validation loss:1.117, Validation accuracy:60.33%
# Epoch 316: iteration 34/35
# Epoch 316 --- loss:1.339, Epoch accuracy:53.86%, Validation loss:1.111, Validation accuracy:58.67%
# Epoch 317: iteration 34/35
# Epoch 317 --- loss:1.344, Epoch accuracy:53.86%, Validation loss:1.108, Validation accuracy:60.33%
# Epoch 318: iteration 34/35
# Epoch 318 --- loss:1.338, Epoch accuracy:54.21%, Validation loss:1.120, Validation accuracy:58.67%
# Epoch 319: iteration 34/35
# Epoch 319 --- loss:1.331, Epoch accuracy:54.04%, Validation loss:1.101, Validation accuracy:61.00%
# Epoch 320: iteration 34/35
# Epoch 320 --- loss:1.317, Epoch accuracy:55.26%, Validation loss:1.086, Validation accuracy:60.33%
# Epoch 321: iteration 34/35
# Epoch 321 --- loss:1.284, Epoch accuracy:58.51%, Validation loss:1.076, Validation accuracy:60.00%
# Epoch 322: iteration 34/35
# Epoch 322 --- loss:1.319, Epoch accuracy:56.23%, Validation loss:1.092, Validation accuracy:59.67%
# Epoch 323: iteration 34/35
# Epoch 323 --- loss:1.317, Epoch accuracy:55.70%, Validation loss:1.097, Validation accuracy:62.00%
# Epoch 324: iteration 34/35
# Epoch 324 --- loss:1.314, Epoch accuracy:54.91%, Validation loss:1.078, Validation accuracy:60.67%
# Epoch 325: iteration 34/35
# Epoch 325 --- loss:1.331, Epoch accuracy:56.67%, Validation loss:1.069, Validation accuracy:61.00%
# Epoch 326: iteration 34/35
# Epoch 326 --- loss:1.320, Epoch accuracy:53.33%, Validation loss:1.063, Validation accuracy:61.67%
# Epoch 327: iteration 34/35
# Epoch 327 --- loss:1.281, Epoch accuracy:58.42%, Validation loss:1.074, Validation accuracy:61.33%
# Epoch 328: iteration 34/35
# Epoch 328 --- loss:1.282, Epoch accuracy:57.81%, Validation loss:1.068, Validation accuracy:62.67%
# Epoch 329: iteration 34/35
# Epoch 329 --- loss:1.274, Epoch accuracy:58.16%, Validation loss:1.075, Validation accuracy:61.00%
# Epoch 330: iteration 34/35
# Epoch 330 --- loss:1.302, Epoch accuracy:55.26%, Validation loss:1.074, Validation accuracy:62.00%
# Epoch 331: iteration 34/35
# Epoch 331 --- loss:1.275, Epoch accuracy:58.33%, Validation loss:1.054, Validation accuracy:61.67%
# Epoch 332: iteration 34/35
# Epoch 332 --- loss:1.300, Epoch accuracy:55.61%, Validation loss:1.063, Validation accuracy:61.67%
# Epoch 333: iteration 34/35
# Epoch 333 --- loss:1.234, Epoch accuracy:61.23%, Validation loss:1.075, Validation accuracy:61.33%
# Epoch 334: iteration 34/35
# Epoch 334 --- loss:1.252, Epoch accuracy:57.63%, Validation loss:1.057, Validation accuracy:61.33%
# Epoch 335: iteration 34/35
# Epoch 335 --- loss:1.256, Epoch accuracy:57.37%, Validation loss:1.056, Validation accuracy:60.67%
# Epoch 336: iteration 34/35
# Epoch 336 --- loss:1.274, Epoch accuracy:58.77%, Validation loss:1.071, Validation accuracy:60.67%
# Epoch 337: iteration 34/35
# Epoch 337 --- loss:1.254, Epoch accuracy:60.18%, Validation loss:1.055, Validation accuracy:61.33%
# Epoch 338: iteration 34/35
# Epoch 338 --- loss:1.268, Epoch accuracy:59.30%, Validation loss:1.067, Validation accuracy:62.00%
# Epoch 339: iteration 34/35
# Epoch 339 --- loss:1.234, Epoch accuracy:60.09%, Validation loss:1.073, Validation accuracy:62.33%
# Epoch 340: iteration 34/35
# Epoch 340 --- loss:1.235, Epoch accuracy:57.81%, Validation loss:1.075, Validation accuracy:61.67%
# Epoch 341: iteration 34/35
# Epoch 341 --- loss:1.227, Epoch accuracy:58.51%, Validation loss:1.065, Validation accuracy:62.33%
# Epoch 342: iteration 34/35
# Epoch 342 --- loss:1.261, Epoch accuracy:56.93%, Validation loss:1.060, Validation accuracy:61.00%
# Epoch 343: iteration 34/35
# Epoch 343 --- loss:1.223, Epoch accuracy:59.04%, Validation loss:1.054, Validation accuracy:62.00%
# Epoch 344: iteration 34/35
# Epoch 344 --- loss:1.197, Epoch accuracy:61.67%, Validation loss:1.059, Validation accuracy:62.00%
# Epoch 345: iteration 34/35
# Epoch 345 --- loss:1.195, Epoch accuracy:60.70%, Validation loss:1.048, Validation accuracy:62.67%
# Epoch 346: iteration 34/35
# Epoch 346 --- loss:1.231, Epoch accuracy:61.05%, Validation loss:1.042, Validation accuracy:62.33%
# Epoch 347: iteration 34/35
# Epoch 347 --- loss:1.212, Epoch accuracy:61.49%, Validation loss:1.046, Validation accuracy:61.67%
# Epoch 348: iteration 34/35
# Epoch 348 --- loss:1.192, Epoch accuracy:62.11%, Validation loss:1.041, Validation accuracy:61.00%
# Epoch 349: iteration 34/35
# Epoch 349 --- loss:1.196, Epoch accuracy:60.35%, Validation loss:1.039, Validation accuracy:62.33%
# Epoch 350: iteration 34/35
# Epoch 350 --- loss:1.192, Epoch accuracy:60.61%, Validation loss:1.056, Validation accuracy:60.67%
# Epoch 351: iteration 34/35
# Epoch 351 --- loss:1.172, Epoch accuracy:62.98%, Validation loss:1.031, Validation accuracy:61.00%
# Epoch 352: iteration 34/35
# Epoch 352 --- loss:1.199, Epoch accuracy:59.74%, Validation loss:1.038, Validation accuracy:62.67%
# Epoch 353: iteration 34/35
# Epoch 353 --- loss:1.179, Epoch accuracy:62.72%, Validation loss:1.028, Validation accuracy:62.33%
# Epoch 354: iteration 34/35
# Epoch 354 --- loss:1.184, Epoch accuracy:61.49%, Validation loss:1.023, Validation accuracy:62.33%
# Epoch 355: iteration 34/35
# Epoch 355 --- loss:1.167, Epoch accuracy:62.72%, Validation loss:1.091, Validation accuracy:59.33%
# Epoch 356: iteration 34/35
# Epoch 356 --- loss:1.155, Epoch accuracy:63.16%, Validation loss:1.052, Validation accuracy:62.67%
# Epoch 357: iteration 34/35
# Epoch 357 --- loss:1.147, Epoch accuracy:63.25%, Validation loss:1.024, Validation accuracy:62.33%
# Epoch 358: iteration 34/35
# Epoch 358 --- loss:1.139, Epoch accuracy:64.82%, Validation loss:1.049, Validation accuracy:62.00%
# Epoch 359: iteration 34/35
# Epoch 359 --- loss:1.165, Epoch accuracy:61.58%, Validation loss:1.055, Validation accuracy:62.67%
# Epoch 360: iteration 34/35
# Epoch 360 --- loss:1.147, Epoch accuracy:62.37%, Validation loss:1.032, Validation accuracy:62.00%
# Epoch 361: iteration 34/35
# Epoch 361 --- loss:1.160, Epoch accuracy:62.37%, Validation loss:1.039, Validation accuracy:61.00%
# Epoch 362: iteration 34/35
# Epoch 362 --- loss:1.145, Epoch accuracy:62.54%, Validation loss:1.021, Validation accuracy:64.00%
# Epoch 363: iteration 34/35
# Epoch 363 --- loss:1.148, Epoch accuracy:63.77%, Validation loss:1.008, Validation accuracy:62.33%
# Epoch 364: iteration 34/35
# Epoch 364 --- loss:1.121, Epoch accuracy:64.21%, Validation loss:1.045, Validation accuracy:62.67%
# Epoch 365: iteration 34/35
# Epoch 365 --- loss:1.119, Epoch accuracy:65.00%, Validation loss:1.025, Validation accuracy:62.00%
# Epoch 366: iteration 34/35
# Epoch 366 --- loss:1.110, Epoch accuracy:65.61%, Validation loss:1.039, Validation accuracy:61.33%
# Epoch 367: iteration 34/35
# Epoch 367 --- loss:1.098, Epoch accuracy:67.54%, Validation loss:1.031, Validation accuracy:61.67%
# Epoch 368: iteration 34/35
# Epoch 368 --- loss:1.111, Epoch accuracy:65.79%, Validation loss:0.997, Validation accuracy:64.00%
# Epoch 369: iteration 34/35
# Epoch 369 --- loss:1.108, Epoch accuracy:64.91%, Validation loss:1.020, Validation accuracy:59.33%
# Epoch 370: iteration 34/35
# Epoch 370 --- loss:1.111, Epoch accuracy:64.47%, Validation loss:1.004, Validation accuracy:61.00%
# Epoch 371: iteration 34/35
# Epoch 371 --- loss:1.123, Epoch accuracy:63.95%, Validation loss:1.003, Validation accuracy:61.67%
# Epoch 372: iteration 34/35
# Epoch 372 --- loss:1.083, Epoch accuracy:67.28%, Validation loss:0.998, Validation accuracy:62.33%
# Epoch 373: iteration 34/35
# Epoch 373 --- loss:1.108, Epoch accuracy:64.39%, Validation loss:1.001, Validation accuracy:63.00%
# Epoch 374: iteration 34/35
# Epoch 374 --- loss:1.097, Epoch accuracy:65.88%, Validation loss:0.993, Validation accuracy:63.67%
# Epoch 375: iteration 34/35
# Epoch 375 --- loss:1.089, Epoch accuracy:66.23%, Validation loss:1.040, Validation accuracy:60.00%
# Epoch 376: iteration 34/35
# Epoch 376 --- loss:1.067, Epoch accuracy:66.32%, Validation loss:0.990, Validation accuracy:61.67%
# Epoch 377: iteration 34/35
# Epoch 377 --- loss:1.087, Epoch accuracy:65.35%, Validation loss:1.033, Validation accuracy:61.33%
# Epoch 378: iteration 34/35
# Epoch 378 --- loss:1.078, Epoch accuracy:68.16%, Validation loss:1.023, Validation accuracy:63.00%
# Epoch 379: iteration 34/35
# Epoch 379 --- loss:1.058, Epoch accuracy:67.28%, Validation loss:0.958, Validation accuracy:63.33%
# Epoch 380: iteration 34/35
# Epoch 380 --- loss:1.068, Epoch accuracy:66.67%, Validation loss:1.008, Validation accuracy:63.00%
# Epoch 381: iteration 34/35
# ...
# Epoch 374: iteration 36/37
# Epoch 374 --- loss:1.179, Epoch accuracy:60.42%, Validation loss:1.370, Validation accuracy:57.08%
# Epoch 375: iteration 36/37
# Epoch 375 --- loss:1.168, Epoch accuracy:60.25%, Validation loss:1.336, Validation accuracy:58.75%
# Epoch 376: iteration 36/37
# Epoch 376 --- loss:1.153, Epoch accuracy:62.42%, Validation loss:1.354, Validation accuracy:58.75%
# Epoch 377: iteration 36/37
# Epoch 377 --- loss:1.157, Epoch accuracy:62.58%, Validation loss:1.361, Validation accuracy:57.92%
# Epoch 378: iteration 36/37
# Epoch 378 --- loss:1.131, Epoch accuracy:63.17%, Validation loss:1.366, Validation accuracy:57.08%
# Epoch 379: iteration 36/37
# Epoch 379 --- loss:1.140, Epoch accuracy:64.42%, Validation loss:1.383, Validation accuracy:57.50%
# Epoch 380: iteration 36/37
# Epoch 380 --- loss:1.138, Epoch accuracy:61.75%, Validation loss:1.392, Validation accuracy:59.17%
# Epoch 381: iteration 36/37
# Epoch 381 --- loss:1.123, Epoch accuracy:64.75%, Validation loss:1.347, Validation accuracy:58.33%
# Epoch 382: iteration 36/37
# Epoch 382 --- loss:1.114, Epoch accuracy:65.17%, Validation loss:1.343, Validation accuracy:58.75%
# Epoch 383: iteration 36/37
# Epoch 383 --- loss:1.134, Epoch accuracy:63.17%, Validation loss:1.359, Validation accuracy:59.17%
# Epoch 384: iteration 36/37
# Epoch 384 --- loss:1.132, Epoch accuracy:63.58%, Validation loss:1.351, Validation accuracy:59.17%
# Epoch 385: iteration 36/37
# Epoch 385 --- loss:1.096, Epoch accuracy:64.75%, Validation loss:1.325, Validation accuracy:59.17%
# Epoch 386: iteration 36/37
# Epoch 386 --- loss:1.120, Epoch accuracy:62.33%, Validation loss:1.353, Validation accuracy:57.92%
# Epoch 387: iteration 36/37
# Epoch 387 --- loss:1.105, Epoch accuracy:64.67%, Validation loss:1.348, Validation accuracy:60.00%
# Epoch 388: iteration 36/37
# Epoch 388 --- loss:1.109, Epoch accuracy:64.00%, Validation loss:1.382, Validation accuracy:57.92%
# Epoch 389: iteration 36/37
# Epoch 389 --- loss:1.085, Epoch accuracy:64.92%, Validation loss:1.363, Validation accuracy:60.00%
# Epoch 390: iteration 36/37
# Epoch 390 --- loss:1.094, Epoch accuracy:63.50%, Validation loss:1.338, Validation accuracy:60.42%
# Epoch 391: iteration 36/37
# Epoch 391 --- loss:1.091, Epoch accuracy:64.00%, Validation loss:1.337, Validation accuracy:59.58%
# Epoch 392: iteration 36/37
# Epoch 392 --- loss:1.101, Epoch accuracy:65.00%, Validation loss:1.360, Validation accuracy:59.58%
# Epoch 393: iteration 36/37
# Epoch 393 --- loss:1.074, Epoch accuracy:66.25%, Validation loss:1.350, Validation accuracy:59.58%
# Epoch 394: iteration 36/37
# Epoch 394 --- loss:1.079, Epoch accuracy:64.83%, Validation loss:1.333, Validation accuracy:60.00%
# Epoch 395: iteration 36/37
# Epoch 395 --- loss:1.073, Epoch accuracy:66.08%, Validation loss:1.349, Validation accuracy:60.00%
# Epoch 396: iteration 36/37
# Epoch 396 --- loss:1.079, Epoch accuracy:66.42%, Validation loss:1.355, Validation accuracy:58.75%
# Epoch 397: iteration 36/37
# Epoch 397 --- loss:1.057, Epoch accuracy:66.58%, Validation loss:1.334, Validation accuracy:59.58%
# Epoch 398: iteration 36/37
# Epoch 398 --- loss:1.069, Epoch accuracy:66.00%, Validation loss:1.335, Validation accuracy:60.83%
# Epoch 399: iteration 36/37
# Epoch 399 --- loss:1.063, Epoch accuracy:67.42%, Validation loss:1.346, Validation accuracy:59.58%
# Epoch 400: iteration 36/37
# Epoch 400 --- loss:1.074, Epoch accuracy:64.92%, Validation loss:1.341, Validation accuracy:60.83%
# Epoch 401: iteration 36/37
# Epoch 401 --- loss:1.045, Epoch accuracy:67.42%, Validation loss:1.335, Validation accuracy:57.92%
# Epoch 402: iteration 36/37
# Epoch 402 --- loss:1.033, Epoch accuracy:66.25%, Validation loss:1.351, Validation accuracy:60.00%
# Epoch 403: iteration 36/37
# Epoch 403 --- loss:1.051, Epoch accuracy:65.50%, Validation loss:1.359, Validation accuracy:60.00%
# Epoch 404: iteration 36/37
# Epoch 404 --- loss:1.050, Epoch accuracy:66.08%, Validation loss:1.367, Validation accuracy:60.83%
# Epoch 405: iteration 36/37
# Epoch 405 --- loss:1.049, Epoch accuracy:66.58%, Validation loss:1.356, Validation accuracy:59.58%
# Epoch 406: iteration 36/37
# Epoch 406 --- loss:1.027, Epoch accuracy:66.58%, Validation loss:1.349, Validation accuracy:58.75%
# Epoch 407: iteration 36/37
# Epoch 407 --- loss:1.008, Epoch accuracy:67.00%, Validation loss:1.357, Validation accuracy:59.17%
# Epoch 408: iteration 36/37
# Epoch 408 --- loss:1.013, Epoch accuracy:68.67%, Validation loss:1.346, Validation accuracy:60.42%
# Epoch 409: iteration 36/37
# Epoch 409 --- loss:0.994, Epoch accuracy:69.67%, Validation loss:1.341, Validation accuracy:57.92%
# Epoch 410: iteration 36/37
# Epoch 410 --- loss:1.017, Epoch accuracy:66.50%, Validation loss:1.335, Validation accuracy:59.58%
# Epoch 411: iteration 36/37
# Epoch 411 --- loss:1.033, Epoch accuracy:66.67%, Validation loss:1.325, Validation accuracy:58.75%
# Epoch 412: iteration 36/37
# Epoch 412 --- loss:0.990, Epoch accuracy:69.42%, Validation loss:1.374, Validation accuracy:58.75%
# Epoch 413: iteration 36/37
# Epoch 413 --- loss:0.989, Epoch accuracy:68.42%, Validation loss:1.351, Validation accuracy:57.50%
# Epoch 414: iteration 36/37
# Epoch 414 --- loss:1.004, Epoch accuracy:68.58%, Validation loss:1.333, Validation accuracy:59.17%
# Epoch 415: iteration 36/37
# Epoch 415 --- loss:0.986, Epoch accuracy:70.00%, Validation loss:1.328, Validation accuracy:60.42%
# Epoch 416: iteration 36/37
# Epoch 416 --- loss:0.978, Epoch accuracy:69.00%, Validation loss:1.348, Validation accuracy:59.58%
# Epoch 417: iteration 36/37
# Epoch 417 --- loss:0.968, Epoch accuracy:71.00%, Validation loss:1.320, Validation accuracy:60.83%
# Epoch 418: iteration 36/37
# Epoch 418 --- loss:0.959, Epoch accuracy:71.58%, Validation loss:1.321, Validation accuracy:58.33%
# Epoch 419: iteration 36/37
# Epoch 419 --- loss:0.965, Epoch accuracy:70.58%, Validation loss:1.322, Validation accuracy:58.75%
# Epoch 420: iteration 36/37
# Epoch 420 --- loss:0.985, Epoch accuracy:69.50%, Validation loss:1.361, Validation accuracy:58.33%
# Epoch 421: iteration 36/37
# Epoch 421 --- loss:0.979, Epoch accuracy:68.08%, Validation loss:1.346, Validation accuracy:60.00%
# Epoch 422: iteration 36/37
# Epoch 422 --- loss:0.964, Epoch accuracy:69.25%, Validation loss:1.342, Validation accuracy:59.17%
# Epoch 423: iteration 36/37
# Epoch 423 --- loss:0.949, Epoch accuracy:71.17%, Validation loss:1.339, Validation accuracy:58.33%
# Epoch 424: iteration 36/37
# Epoch 424 --- loss:0.984, Epoch accuracy:70.92%, Validation loss:1.345, Validation accuracy:60.42%
# Epoch 425: iteration 36/37
# Epoch 425 --- loss:0.973, Epoch accuracy:70.00%, Validation loss:1.363, Validation accuracy:59.58%
# Epoch 426: iteration 36/37
# Epoch 426 --- loss:0.925, Epoch accuracy:72.25%, Validation loss:1.329, Validation accuracy:58.33%
# Epoch 427: iteration 36/37
# Epoch 427 --- loss:0.945, Epoch accuracy:71.42%, Validation loss:1.323, Validation accuracy:59.58%
# Epoch 428: iteration 36/37
# Epoch 428 --- loss:0.933, Epoch accuracy:72.33%, Validation loss:1.323, Validation accuracy:58.33%
# Epoch 429: iteration 36/37
# Epoch 429 --- loss:0.947, Epoch accuracy:71.50%, Validation loss:1.344, Validation accuracy:58.33%
# Epoch 430: iteration 36/37
# Epoch 430 --- loss:0.953, Epoch accuracy:70.75%, Validation loss:1.321, Validation accuracy:59.17%
# Epoch 431: iteration 36/37
# Epoch 431 --- loss:0.915, Epoch accuracy:71.08%, Validation loss:1.325, Validation accuracy:59.58%
# Epoch 432: iteration 36/37
# Epoch 432 --- loss:0.916, Epoch accuracy:72.67%, Validation loss:1.334, Validation accuracy:58.75%
# Epoch 433: iteration 36/37
# Epoch 433 --- loss:0.906, Epoch accuracy:72.92%, Validation loss:1.327, Validation accuracy:58.75%
# Epoch 434: iteration 36/37
# Epoch 434 --- loss:0.921, Epoch accuracy:72.58%, Validation loss:1.348, Validation accuracy:60.00%
# Epoch 435: iteration 36/37
# Epoch 435 --- loss:0.915, Epoch accuracy:71.67%, Validation loss:1.323, Validation accuracy:58.33%
# Epoch 436: iteration 36/37
# Epoch 436 --- loss:0.912, Epoch accuracy:71.25%, Validation loss:1.334, Validation accuracy:59.17%
# Epoch 437: iteration 36/37
# Epoch 437 --- loss:0.901, Epoch accuracy:72.83%, Validation loss:1.329, Validation accuracy:58.33%
# Epoch 438: iteration 36/37
# Epoch 438 --- loss:0.905, Epoch accuracy:72.75%, Validation loss:1.340, Validation accuracy:57.50%
# Epoch 439: iteration 36/37
# Epoch 439 --- loss:0.904, Epoch accuracy:73.92%, Validation loss:1.358, Validation accuracy:57.92%
# Epoch 440: iteration 36/37
# Epoch 440 --- loss:0.913, Epoch accuracy:72.17%, Validation loss:1.325, Validation accuracy:59.58%
# Epoch 441: iteration 36/37
# Epoch 441 --- loss:0.902, Epoch accuracy:72.00%, Validation loss:1.353, Validation accuracy:60.42%
# Epoch 442: iteration 36/37
# Epoch 442 --- loss:0.873, Epoch accuracy:74.42%, Validation loss:1.327, Validation accuracy:58.75%
# Epoch 443: iteration 36/37
# Epoch 443 --- loss:0.887, Epoch accuracy:73.00%, Validation loss:1.347, Validation accuracy:59.58%
# Epoch 444: iteration 36/37
# Epoch 444 --- loss:0.891, Epoch accuracy:72.58%, Validation loss:1.355, Validation accuracy:57.92%
# Epoch 445: iteration 36/37
# Epoch 445 --- loss:0.860, Epoch accuracy:75.00%, Validation loss:1.338, Validation accuracy:58.75%
# Epoch 446: iteration 36/37
# Epoch 446 --- loss:0.893, Epoch accuracy:73.50%, Validation loss:1.357, Validation accuracy:59.17%
# Epoch 447: iteration 36/37
# Epoch 447 --- loss:0.865, Epoch accuracy:75.25%, Validation loss:1.347, Validation accuracy:57.92%
# Epoch 448: iteration 36/37
# Epoch 448 --- loss:0.874, Epoch accuracy:73.75%, Validation loss:1.331, Validation accuracy:58.75%
# Epoch 449: iteration 36/37
# Epoch 449 --- loss:0.870, Epoch accuracy:74.08%, Validation loss:1.354, Validation accuracy:57.92%
# Epoch 450: iteration 36/37
# Epoch 450 --- loss:0.862, Epoch accuracy:73.33%, Validation loss:1.325, Validation accuracy:57.92%
# Epoch 451: iteration 36/37
# Epoch 451 --- loss:0.853, Epoch accuracy:75.25%, Validation loss:1.357, Validation accuracy:57.92%
# Epoch 452: iteration 36/37
# Epoch 452 --- loss:0.867, Epoch accuracy:74.33%, Validation loss:1.369, Validation accuracy:58.75%
# Epoch 453: iteration 36/37
# Epoch 453 --- loss:0.845, Epoch accuracy:75.58%, Validation loss:1.344, Validation accuracy:57.50%
# Epoch 454: iteration 36/37
# Epoch 454 --- loss:0.844, Epoch accuracy:75.33%, Validation loss:1.361, Validation accuracy:57.50%
# Epoch 455: iteration 36/37
# Epoch 455 --- loss:0.834, Epoch accuracy:74.92%, Validation loss:1.348, Validation accuracy:58.33%
# Epoch 456: iteration 36/37
# Epoch 456 --- loss:0.830, Epoch accuracy:76.00%, Validation loss:1.314, Validation accuracy:57.92%
# Epoch 457: iteration 36/37
# Epoch 457 --- loss:0.820, Epoch accuracy:75.75%, Validation loss:1.327, Validation accuracy:57.92%
# Epoch 458: iteration 36/37
# Epoch 458 --- loss:0.813, Epoch accuracy:77.25%, Validation loss:1.340, Validation accuracy:59.17%
# Epoch 459: iteration 36/37
# Epoch 459 --- loss:0.807, Epoch accuracy:78.25%, Validation loss:1.358, Validation accuracy:57.92%
# Epoch 460: iteration 36/37
# Epoch 460 --- loss:0.825, Epoch accuracy:76.25%, Validation loss:1.344, Validation accuracy:57.08%
# Epoch 461: iteration 36/37
# Epoch 461 --- loss:0.819, Epoch accuracy:76.92%, Validation loss:1.358, Validation accuracy:57.50%
# Epoch 462: iteration 36/37
# Epoch 462 --- loss:0.794, Epoch accuracy:78.00%, Validation loss:1.370, Validation accuracy:57.08%
# Epoch 463: iteration 36/37
# Epoch 463 --- loss:0.793, Epoch accuracy:76.92%, Validation loss:1.335, Validation accuracy:58.33%
# Epoch 464: iteration 36/37
# Epoch 464 --- loss:0.797, Epoch accuracy:78.33%, Validation loss:1.352, Validation accuracy:57.92%
# Epoch 465: iteration 36/37
# Epoch 465 --- loss:0.796, Epoch accuracy:76.67%, Validation loss:1.325, Validation accuracy:60.00%
# Epoch 466: iteration 36/37
# Epoch 466 --- loss:0.784, Epoch accuracy:77.25%, Validation loss:1.326, Validation accuracy:59.58%
# Epoch 467: iteration 36/37
# Epoch 467 --- loss:0.824, Epoch accuracy:76.08%, Validation loss:1.322, Validation accuracy:58.75%
# Epoch 468: iteration 36/37
# Epoch 468 --- loss:0.777, Epoch accuracy:78.75%, Validation loss:1.385, Validation accuracy:57.50%
# Epoch 469: iteration 36/37
# Epoch 469 --- loss:0.782, Epoch accuracy:77.75%, Validation loss:1.360, Validation accuracy:59.17%
# Epoch 470: iteration 36/37
# Epoch 470 --- loss:0.787, Epoch accuracy:79.08%, Validation loss:1.362, Validation accuracy:56.67%
# Epoch 471: iteration 36/37
# Epoch 471 --- loss:0.783, Epoch accuracy:79.25%, Validation loss:1.355, Validation accuracy:57.08%
# Epoch 472: iteration 36/37
# Epoch 472 --- loss:0.779, Epoch accuracy:77.42%, Validation loss:1.348, Validation accuracy:59.17%
# Epoch 473: iteration 36/37
# Epoch 473 --- loss:0.763, Epoch accuracy:78.08%, Validation loss:1.326, Validation accuracy:58.75%
# Epoch 474: iteration 36/37
# Epoch 474 --- loss:0.774, Epoch accuracy:77.67%, Validation loss:1.363, Validation accuracy:56.67%
# Epoch 475: iteration 36/37
# Epoch 475 --- loss:0.760, Epoch accuracy:79.33%, Validation loss:1.377, Validation accuracy:57.08%
# Epoch 476: iteration 36/37
# Epoch 476 --- loss:0.771, Epoch accuracy:78.17%, Validation loss:1.360, Validation accuracy:58.33%
# Epoch 477: iteration 36/37
# Epoch 477 --- loss:0.752, Epoch accuracy:78.08%, Validation loss:1.362, Validation accuracy:57.92%
# Epoch 478: iteration 36/37
# Epoch 478 --- loss:0.755, Epoch accuracy:78.92%, Validation loss:1.338, Validation accuracy:57.50%
# Epoch 479: iteration 36/37
# Epoch 479 --- loss:0.751, Epoch accuracy:79.75%, Validation loss:1.346, Validation accuracy:58.75%
# Epoch 480: iteration 36/37
# Epoch 480 --- loss:0.737, Epoch accuracy:79.75%, Validation loss:1.314, Validation accuracy:58.75%
# Epoch 481: iteration 36/37
# Epoch 481 --- loss:0.731, Epoch accuracy:80.17%, Validation loss:1.356, Validation accuracy:57.92%
# Epoch 482: iteration 36/37
# Epoch 482 --- loss:0.736, Epoch accuracy:79.92%, Validation loss:1.336, Validation accuracy:60.00%
# Epoch 483: iteration 36/37
# Epoch 483 --- loss:0.733, Epoch accuracy:79.58%, Validation loss:1.393, Validation accuracy:54.58%
# Epoch 484: iteration 36/37
# Epoch 484 --- loss:0.730, Epoch accuracy:81.08%, Validation loss:1.324, Validation accuracy:60.00%
# Epoch 485: iteration 36/37
# Epoch 485 --- loss:0.719, Epoch accuracy:79.17%, Validation loss:1.348, Validation accuracy:59.17%
# Epoch 486: iteration 36/37
# Epoch 486 --- loss:0.726, Epoch accuracy:80.17%, Validation loss:1.369, Validation accuracy:57.08%
# Epoch 487: iteration 36/37
# Epoch 487 --- loss:0.711, Epoch accuracy:80.50%, Validation loss:1.333, Validation accuracy:58.33%
# Epoch 488: iteration 36/37
# Epoch 488 --- loss:0.719, Epoch accuracy:79.50%, Validation loss:1.324, Validation accuracy:58.75%
# Epoch 489: iteration 36/37
# Epoch 489 --- loss:0.740, Epoch accuracy:80.92%, Validation loss:1.377, Validation accuracy:57.92%
# Epoch 490: iteration 36/37
# Epoch 490 --- loss:0.719, Epoch accuracy:80.08%, Validation loss:1.401, Validation accuracy:56.67%
# Epoch 491: iteration 36/37
# Epoch 491 --- loss:0.716, Epoch accuracy:80.67%, Validation loss:1.394, Validation accuracy:57.92%
# Epoch 492: iteration 36/37
# Epoch 492 --- loss:0.734, Epoch accuracy:79.92%, Validation loss:1.358, Validation accuracy:58.33%
# Epoch 493: iteration 36/37
# Epoch 493 --- loss:0.701, Epoch accuracy:79.33%, Validation loss:1.391, Validation accuracy:56.67%
# Epoch 494: iteration 36/37
# Epoch 494 --- loss:0.686, Epoch accuracy:81.00%, Validation loss:1.355, Validation accuracy:57.50%
# Epoch 495: iteration 36/37
# Epoch 495 --- loss:0.675, Epoch accuracy:82.83%, Validation loss:1.362, Validation accuracy:58.33%
# Epoch 496: iteration 36/37
# Epoch 496 --- loss:0.690, Epoch accuracy:82.00%, Validation loss:1.388, Validation accuracy:57.50%
# Epoch 497: iteration 36/37
# Epoch 497 --- loss:0.682, Epoch accuracy:81.17%, Validation loss:1.371, Validation accuracy:57.92%
# Epoch 498: iteration 36/37
# Epoch 498 --- loss:0.677, Epoch accuracy:81.83%, Validation loss:1.346, Validation accuracy:57.92%
# Epoch 499: iteration 36/37
# Epoch 499 --- loss:0.671, Epoch accuracy:82.33%, Validation loss:1.368, Validation accuracy:57.92%
#
#
# [*] done !
# [*] Best training loss - 0.6713422934214276
# [*] Best validation loss - 1.313903570175171

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
from sklearn.metrics import classification_report

device = 'cuda'
model = Model(num_emotions=len(emotions_dict)).to('cuda')

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur_fold_path = os.path.join(fold_path, 'fold'+str(fold)+'.npy')
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    X_test_tensor = torch.tensor(X_test,device=device).float()
    # X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(y_test,dtype=torch.long,device=device)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    
    print("="*40)
    print(f'[*] Fold-{fold}')
    print(f'Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor.cpu().numpy()
    
    print(classification_report(emotions_groundtruth, predicted_emotions))
    
    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
    print("="*40)
# Out:
# ========================================
# [*] Fold-0
# Test accuracy is 64.67%
#               precision    recall  f1-score   support
#
#            0       0.50      0.10      0.17        20
#            1       0.67      0.88      0.76        40
#            2       0.68      0.47      0.56        40
#            3       0.39      0.23      0.29        40
#            4       0.59      0.93      0.72        40
#            5       0.63      0.82      0.72        40
#            6       0.62      0.65      0.63        40
#            7       0.92      0.82      0.87        40
#
#     accuracy                           0.65       300
#    macro avg       0.63      0.61      0.59       300
# weighted avg       0.63      0.65      0.62       300
# ========================================
# ========================================
# [*] Fold-1
# Test accuracy is 51.33%
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        20
#            1       0.51      0.80      0.62        40
#            2       0.36      0.12      0.19        40
#            3       0.37      0.17      0.24        40
#            4       0.68      0.65      0.67        40
#            5       0.54      0.62      0.58        40
#            6       0.46      0.65      0.54        40
#            7       0.57      0.82      0.67        40
#
#     accuracy                           0.51       300
#    macro avg       0.44      0.48      0.44       300
# weighted avg       0.47      0.51      0.47       300
# ========================================
# ========================================
# [*] Fold-2
# Test accuracy is 62.67%
#               precision    recall  f1-score   support
#
#            0       0.80      0.20      0.32        20
#            1       0.53      0.97      0.68        40
#            2       0.49      0.45      0.47        40
#            3       0.54      0.17      0.26        40
#            4       0.60      0.85      0.70        40
#            5       0.57      0.70      0.63        40
#            6       0.89      0.62      0.74        40
#            7       0.89      0.82      0.86        40
#
#     accuracy                           0.63       300
#    macro avg       0.66      0.60      0.58       300
# weighted avg       0.65      0.63      0.60       300
# ========================================
# ========================================
# [*] Fold-3
# Test accuracy is 57.33%
#               precision    recall  f1-score   support
#
#            0       1.00      0.10      0.18        20
#            1       0.49      0.93      0.64        40
#            2       0.50      0.30      0.37        40
#            3       0.47      0.23      0.31        40
#            4       0.63      0.65      0.64        40
#            5       0.67      0.45      0.54        40
#            6       0.60      0.72      0.66        40
#            7       0.61      0.97      0.75        40
#
#     accuracy                           0.57       300
#    macro avg       0.62      0.54      0.51       300
# weighted avg       0.60      0.57      0.53       300
# ========================================
# ========================================
# [*] Fold-4
# Test accuracy is 58.75%
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        16
#            1       0.52      0.78      0.62        32
#            2       0.70      0.44      0.54        32
#            3       0.24      0.34      0.29        32
#            4       0.78      0.78      0.78        32
#            5       0.53      0.59      0.56        32
#            6       0.77      0.75      0.76        32
#            7       0.85      0.72      0.78        32
#
#     accuracy                           0.59       240
#    macro avg       0.55      0.55      0.54       240
# weighted avg       0.59      0.59      0.58       240
# ========================================

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 64.67%
# [*] Worst fold acc : 51.33%
# [*] Average fold acc : 58.95%
