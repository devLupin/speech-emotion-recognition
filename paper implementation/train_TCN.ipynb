# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange
import torch.nn.functional as F
from torchinfo import summary
from tqdm.auto import tqdm

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(f'Device : {device}')
print(f'Count of using GPUs : {torch.cuda.device_count()}')
print(f'Current cuda device : {torch.cuda.current_device()}\n')
# Out:
# Device : cuda
# Count of using GPUs : 1
# Current cuda device : 0

# %%
class _LayerNorm(nn.Module):
    """Layer Normalization base class."""

    def __init__(self, channel_size):
        super(_LayerNorm, self).__init__()
        self.channel_size = channel_size
        self.gamma = nn.Parameter(torch.ones(channel_size),
                                  requires_grad=True)
        self.beta = nn.Parameter(torch.zeros(channel_size),
                                 requires_grad=True)

    def apply_gain_and_bias(self, normed_x):
        """ Assumes input of size `[batch, chanel, *]`. """
        return (self.gamma * normed_x.transpose(1, -1) +
                self.beta).transpose(1, -1)


EPS = 1e-8


class GlobLN(_LayerNorm):
    """Global Layer Normalization (globLN)."""

    def forward(self, x):
        """ Applies forward pass.
        Works for any input size > 2D.
        Args:
            x (:class:`torch.Tensor`): Shape `[batch, chan, *]`
        Returns:
            :class:`torch.Tensor`: gLN_x `[batch, chan, *]`
        """
        dims = list(range(1, len(x.shape)))
        mean = x.mean(dim=dims, keepdim=True)
        var = torch.pow(x - mean, 2).mean(dim=dims, keepdim=True)
        return self.apply_gain_and_bias((x - mean) / (var + EPS).sqrt())


class Conv1DBlock(nn.Module):
    """One dimensional convolutional block, as proposed in [1].
    Args:
        in_chan (int): Number of input channels.
        hid_chan (int): Number of hidden channels in the depth-wise
            convolution.
        skip_out_chan (int): Number of channels in the skip convolution.
            If 0 or None, `Conv1DBlock` won't have any skip connections.
            Corresponds to the the block in v1 or the paper. The `forward`
            return res instead of [res, skip] in this case.
        kernel_size (int): Size of the depth-wise convolutional kernel.
        padding (int): Padding of the depth-wise convolution.
        dilation (int): Dilation of the depth-wise convolution.
        norm_type (str, optional): Type of normalization to use. To choose from
            -  ``'gLN'``: global Layernorm
            -  ``'cLN'``: channelwise Layernorm
            -  ``'cgLN'``: cumulative global Layernorm
    References:
        [1] : "Conv-TasNet: Surpassing ideal time-frequency magnitude masking
        for speech separation" TASLP 2019 Yi Luo, Nima Mesgarani
        https://arxiv.org/abs/1809.07454
    """

    def __init__(self, in_chan, hid_chan, kernel_size, padding,
                 dilation, ):
        super(Conv1DBlock, self).__init__()
        conv_norm = GlobLN
        in_conv1d = nn.Conv1d(in_chan, hid_chan, 1)
        depth_conv1d = nn.Conv1d(hid_chan, hid_chan, kernel_size,
                                 padding=padding, dilation=dilation,
                                 groups=hid_chan)
        self.shared_block = nn.Sequential(in_conv1d, nn.PReLU(),
                                          conv_norm(hid_chan), depth_conv1d,
                                          nn.PReLU(), conv_norm(hid_chan))
        self.res_conv = nn.Conv1d(hid_chan, in_chan, 1)

    def forward(self, x):
        """ Input shape [batch, feats, seq]"""
        shared_out = self.shared_block(x)
        res_out = self.res_conv(shared_out)
        return res_out


class TCN(nn.Module):
    # n blocks --> receptive field increases , n_repeats increases capacity mostly
    def __init__(self, in_chan=35000, n_src=1, out_chan=8, n_blocks=5, n_repeats=2, 
                 bn_chan=64, hid_chan=128, kernel_size=3, dropout_prob=0.2 ):
        super(TCN, self).__init__()
        self.in_chan = in_chan
        self.n_src = n_src
        out_chan = out_chan if out_chan else in_chan
        self.out_chan = out_chan
        self.n_blocks = n_blocks
        self.n_repeats = n_repeats
        self.bn_chan = bn_chan
        self.hid_chan = hid_chan
        self.kernel_size = kernel_size

        self.dropout = nn.Dropout(p=dropout_prob)

        layer_norm = GlobLN(in_chan)
        bottleneck_conv = nn.Conv1d(in_chan, bn_chan, 1)
        self.bottleneck = nn.Sequential(layer_norm, bottleneck_conv)
        # Succession of Conv1DBlock with exponentially increasing dilation.
        self.TCN = nn.ModuleList()
        for r in range(n_repeats):       #ripetizioni 2
            for x in range(n_blocks):     #5 layers convoluzionali
                padding = (kernel_size - 1) * 2 ** x // 2
                self.TCN.append(Conv1DBlock(bn_chan, hid_chan,
                                            kernel_size, padding=padding,
                                            dilation=2 ** x))

        out_conv = nn.Linear(bn_chan, n_src * out_chan)
        self.out = nn.Sequential(nn.PReLU(), out_conv)
        
        self.softmax_out = nn.Softmax(dim=1)

    # self.out = nn.Linear(bn_chan, n_src*out_chan)
    # self.out = nn.Linear(800, n_src*out_chan)

    # Get activation function.
    def forward(self, mixture_w):
        output = self.dropout(self.bottleneck(mixture_w))
        for i in range(len(self.TCN)):
            residual = self.TCN[i](output)
            output = output + residual
        output = self.dropout(output)

        output_logits = self.out(self.dropout(output.mean(-1)))
        output_softmax = self.softmax_out(output_logits)
        
        return output_logits, output_softmax

# %%
from torchinfo import summary

emotions_dict = {
    '0': 'surprised',
    '1': 'neutral',
    '2': 'calm',
    '3': 'happy',
    '4': 'sad',
    '5': 'angry',
    '6': 'fearful',
    '7': 'disgust'
}

model = TCN().to('cuda')
sub_name = 'TCN'
data_name = 'RAVDESS'

EARLY_CNT=500
minibatch = 32
num_epochs = 500
print(summary(model, input_size=(minibatch, 35000, 1)))

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# TCN                                      [32, 8]                   --
# ├─Dropout: 1-5                           [32, 64]                  --
# ├─Sequential: 1-2                        [32, 64, 1]               --
# │    └─GlobLN: 2-1                       [32, 35000, 1]            70,000
# │    └─Conv1d: 2-2                       [32, 64, 1]               2,240,064
# ├─Dropout: 1-3                           [32, 64, 1]               --
# ├─ModuleList: 1                          --                        --
# │    └─Conv1DBlock: 2-3                  [32, 64, 1]               --
# │    │    └─Sequential: 3-1              [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-2                  [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-4                  [32, 64, 1]               --
# │    │    └─Sequential: 3-3              [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-4                  [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-5                  [32, 64, 1]               --
# │    │    └─Sequential: 3-5              [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-6                  [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-6                  [32, 64, 1]               --
# │    │    └─Sequential: 3-7              [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-8                  [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-7                  [32, 64, 1]               --
# │    │    └─Sequential: 3-9              [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-10                 [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-8                  [32, 64, 1]               --
# │    │    └─Sequential: 3-11             [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-12                 [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-9                  [32, 64, 1]               --
# │    │    └─Sequential: 3-13             [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-14                 [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-10                 [32, 64, 1]               --
# │    │    └─Sequential: 3-15             [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-16                 [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-11                 [32, 64, 1]               --
# │    │    └─Sequential: 3-17             [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-18                 [32, 64, 1]               8,256
# │    └─Conv1DBlock: 2-12                 [32, 64, 1]               --
# │    │    └─Sequential: 3-19             [32, 128, 1]              9,346
# │    │    └─Conv1d: 3-20                 [32, 64, 1]               8,256
# ├─Dropout: 1-4                           [32, 64, 1]               --
# ├─Dropout: 1-5                           [32, 64]                  --
# ├─Sequential: 1-6                        [32, 8]                   --
# │    └─PReLU: 2-13                       [32, 64]                  1
# │    └─Linear: 2-14                      [32, 8]                   520
# ├─Softmax: 1-7                           [32, 8]                   --
# ==========================================================================================
# Total params: 2,486,605
# Trainable params: 2,486,605
# Non-trainable params: 0
# Total mult-adds (M): 77.17
# ==========================================================================================
# Input size (MB): 4.48
# Forward/backward pass size (MB): 11.12
# Params size (MB): 9.95
# Estimated Total Size (MB): 25.55
# ==========================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

npy_path = './via_wav2vec'
all_npy = os.listdir(npy_path)

print(f'[*] model training - {sub_name}')
for fold in all_npy:
    npy = os.path.join(npy_path, fold)
    
    with open(npy, 'rb') as f:
        X_train = np.load(f)
        y_train = np.load(f)
        X_test = np.load(f)
        y_test = np.load(f)
        
    X_train = np.expand_dims(X_train, axis=-1)
    X_test = np.expand_dims(X_test, axis=-1)
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - TCN
# 0.npy:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 70/71
# Epoch 0 --- loss:2.207, Epoch accuracy:13.33%, Validation loss:2.103, Validation accuracy:14.17%
# Epoch 1: iteration 70/71
# Epoch 1 --- loss:1.720, Epoch accuracy:34.56%, Validation loss:2.162, Validation accuracy:14.00%
# Epoch 2: iteration 70/71
# Epoch 2 --- loss:1.435, Epoch accuracy:46.49%, Validation loss:2.279, Validation accuracy:14.33%
# Epoch 3: iteration 70/71
# Epoch 3 --- loss:1.230, Epoch accuracy:51.93%, Validation loss:2.401, Validation accuracy:13.17%
# Epoch 4: iteration 70/71
# Epoch 4 --- loss:1.145, Epoch accuracy:55.44%, Validation loss:2.536, Validation accuracy:13.33%
# Epoch 5: iteration 70/71
# Epoch 5 --- loss:1.094, Epoch accuracy:56.23%, Validation loss:2.614, Validation accuracy:13.00%
# Epoch 6: iteration 70/71
# Epoch 6 --- loss:1.086, Epoch accuracy:55.48%, Validation loss:2.685, Validation accuracy:13.83%
# Epoch 7: iteration 70/71
# Epoch 7 --- loss:1.066, Epoch accuracy:56.14%, Validation loss:2.773, Validation accuracy:13.50%
# Epoch 8: iteration 70/71
# Epoch 8 --- loss:1.059, Epoch accuracy:56.23%, Validation loss:2.831, Validation accuracy:14.00%
# Epoch 9: iteration 70/71
# Epoch 9 --- loss:1.052, Epoch accuracy:56.75%, Validation loss:2.880, Validation accuracy:14.00%
# Epoch 10: iteration 70/71
# Epoch 10 --- loss:1.053, Epoch accuracy:56.62%, Validation loss:2.914, Validation accuracy:14.67%
# Epoch 11: iteration 70/71
# Epoch 11 --- loss:1.053, Epoch accuracy:56.27%, Validation loss:2.952, Validation accuracy:13.50%
# Epoch 12: iteration 70/71
# Epoch 12 --- loss:1.048, Epoch accuracy:56.23%, Validation loss:2.992, Validation accuracy:14.17%
# Epoch 13: iteration 70/71
# Epoch 13 --- loss:1.044, Epoch accuracy:56.89%, Validation loss:3.004, Validation accuracy:14.50%
# Epoch 14: iteration 70/71
# Epoch 14 --- loss:1.046, Epoch accuracy:56.67%, Validation loss:3.042, Validation accuracy:14.33%
# Epoch 15: iteration 70/71
# Epoch 15 --- loss:1.042, Epoch accuracy:56.49%, Validation loss:3.065, Validation accuracy:14.00%
# Epoch 16: iteration 70/71
# Epoch 16 --- loss:1.046, Epoch accuracy:55.75%, Validation loss:3.107, Validation accuracy:14.00%
# Epoch 17: iteration 70/71
# Epoch 17 --- loss:1.040, Epoch accuracy:56.05%, Validation loss:3.149, Validation accuracy:14.00%
# Epoch 18: iteration 70/71
# Epoch 18 --- loss:1.043, Epoch accuracy:56.58%, Validation loss:3.154, Validation accuracy:14.17%
# Epoch 19: iteration 70/71
# Epoch 19 --- loss:1.039, Epoch accuracy:56.05%, Validation loss:3.141, Validation accuracy:14.33%
# Epoch 20: iteration 70/71
# Epoch 20 --- loss:1.039, Epoch accuracy:55.92%, Validation loss:3.174, Validation accuracy:14.00%
# Epoch 21: iteration 70/71
# Epoch 21 --- loss:1.041, Epoch accuracy:56.23%, Validation loss:3.184, Validation accuracy:14.17%
# Epoch 22: iteration 70/71
# Epoch 22 --- loss:1.037, Epoch accuracy:57.68%, Validation loss:3.216, Validation accuracy:14.50%
# Epoch 23: iteration 70/71
# Epoch 23 --- loss:1.038, Epoch accuracy:56.89%, Validation loss:3.213, Validation accuracy:14.17%
# Epoch 24: iteration 70/71
# Epoch 24 --- loss:1.036, Epoch accuracy:56.97%, Validation loss:3.250, Validation accuracy:14.50%
# Epoch 25: iteration 13/71
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [27], line 23
#      20 X_test = np.expand_dims(X_test, axis=-1)
#      22 pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
# ---> 23 train_losses, valid_losses = train(model, num_epochs, X_train, y_train, X_test, y_test, pkl_name, fold)
#      25 plt.title('Loss Curve')
#      26 plt.ylabel('Loss', fontsize=16)
#
# Cell In [25], line 65, in train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold)
#      62 Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
#      64 # Pass input tensors thru 1 training step (fwd+backwards pass)
# ---> 65 loss, acc = train_step(X_tensor, Y_tensor)
#      67 # aggregate batch accuracy to measure progress of entire epoch
#      68 epoch_acc += acc * actual_batch_size / train_size
#
# Cell In [12], line 7, in make_train_step.<locals>.train_step(X, Y)
#       4 def train_step(X, Y):
#       5
#       6     # forward pass
# ----> 7     output_logits, output_softmax = model(X)
#       8     predictions = torch.argmax(output_softmax, dim=1)
#       9     accuracy = torch.sum(Y == predictions)/float(len(Y))
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# Cell In [10], line 122, in TCN.forward(self, mixture_w)
#     120 output = self.dropout(self.bottleneck(mixture_w))
#     121 for i in range(len(self.TCN)):
# --> 122     residual = self.TCN[i](output)
#     123     output = output + residual
#     124 output = self.dropout(output)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# Cell In [10], line 76, in Conv1DBlock.forward(self, x)
#      74 def forward(self, x):
#      75     """ Input shape [batch, feats, seq]"""
# ---> 76     shared_out = self.shared_block(x)
#      77     res_out = self.res_conv(shared_out)
#      78     return res_out
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\container.py:119, in Sequential.forward(self, input)
#     117 def forward(self, input):
#     118     for module in self:
# --> 119         input = module(input)
#     120     return input
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\module.py:889, in Module._call_impl(self, *input, **kwargs)
#     887     result = self._slow_forward(*input, **kwargs)
#     888 else:
# --> 889     result = self.forward(*input, **kwargs)
#     890 for hook in itertools.chain(
#     891         _global_forward_hooks.values(),
#     892         self._forward_hooks.values()):
#     893     hook_result = hook(self, input, result)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\modules\activation.py:1048, in PReLU.forward(self, input)
#    1047 def forward(self, input: Tensor) -> Tensor:
# -> 1048     return F.prelu(input, self.weight)
#
# File ~\miniconda3\envs\ser\lib\site-packages\torch\nn\functional.py:1403, in prelu(input, weight)
#    1401 if has_torch_function_unary(input):
#    1402     return handle_torch_function(prelu, (input,), input, weight)
# -> 1403 return torch.prelu(input, weight)
#
# KeyboardInterrupt:

# %%
import csv
import cv2
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(cur_fold_path):
    X_train, y_train, X_test, y_test = [], [], [], []
    
    train_f = open(os.path.join(cur_fold_path, 'train.csv'), 'r')
    test_f = open(os.path.join(cur_fold_path, 'test.csv'), 'r')
    
    train_reader = csv.reader(train_f)
    for r in train_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_train.append(image)
        y_train.append(int(r[1]))
        
    test_reader = csv.reader(test_f)
    for r in test_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_test.append(image)
        y_test.append(int(r[1]))
    
    return np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

# %%
all_fold_dataset = []

for fold in tqdm(range(5), desc='load melspectrogram fold dataset'):
    cur_fold_path = os.path.join('melspectrogram_fold', str(fold))
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    all_fold_dataset.append([X_train, y_train, X_test, y_test])
# Out:
# load melspectrogram fold dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'melspectrogram_fold'

for fold in range(5):
    cur = all_fold_dataset[fold]
    
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - resnet_18_finetune
# 0:   0%|          | 0/500 [00:00<?, ?it/s]
# Epoch 0: iteration 7/8
# Epoch 0 --- loss:1.978, Epoch accuracy:11.93%, Validation loss:2.255, Validation accuracy:13.67%
# Epoch 1: iteration 7/8
# Epoch 1 --- loss:1.952, Epoch accuracy:12.98%, Validation loss:2.353, Validation accuracy:14.67%
# Epoch 2: iteration 7/8
# Epoch 2 --- loss:1.934, Epoch accuracy:13.42%, Validation loss:2.447, Validation accuracy:14.00%
# Epoch 3: iteration 7/8
# Epoch 3 --- loss:1.928, Epoch accuracy:13.07%, Validation loss:2.492, Validation accuracy:14.00%
# Epoch 4: iteration 7/8
# Epoch 4 --- loss:1.910, Epoch accuracy:14.56%, Validation loss:2.418, Validation accuracy:14.00%
# Epoch 5: iteration 7/8
# Epoch 5 --- loss:1.890, Epoch accuracy:15.61%, Validation loss:2.286, Validation accuracy:14.00%
# Epoch 6: iteration 7/8
# Epoch 6 --- loss:1.877, Epoch accuracy:15.88%, Validation loss:2.216, Validation accuracy:15.00%
# Epoch 7: iteration 7/8
# Epoch 7 --- loss:1.863, Epoch accuracy:16.32%, Validation loss:2.178, Validation accuracy:15.00%
# Epoch 8: iteration 7/8
# Epoch 8 --- loss:1.848, Epoch accuracy:16.14%, Validation loss:2.160, Validation accuracy:15.33%
# Epoch 9: iteration 7/8
# Epoch 9 --- loss:1.828, Epoch accuracy:16.93%, Validation loss:2.145, Validation accuracy:15.67%
# Epoch 10: iteration 7/8
# Epoch 10 --- loss:1.813, Epoch accuracy:18.16%, Validation loss:2.135, Validation accuracy:15.67%
# Epoch 11: iteration 7/8
# Epoch 11 --- loss:1.801, Epoch accuracy:17.72%, Validation loss:2.125, Validation accuracy:15.67%
# Epoch 12: iteration 7/8
# Epoch 12 --- loss:1.786, Epoch accuracy:19.04%, Validation loss:2.115, Validation accuracy:15.67%
# Epoch 13: iteration 7/8
# Epoch 13 --- loss:1.786, Epoch accuracy:18.68%, Validation loss:2.106, Validation accuracy:16.33%
# Epoch 14: iteration 7/8
# Epoch 14 --- loss:1.767, Epoch accuracy:19.65%, Validation loss:2.097, Validation accuracy:16.00%
# Epoch 15: iteration 7/8
# Epoch 15 --- loss:1.745, Epoch accuracy:20.70%, Validation loss:2.088, Validation accuracy:16.33%
# Epoch 16: iteration 7/8
# Epoch 16 --- loss:1.743, Epoch accuracy:21.40%, Validation loss:2.079, Validation accuracy:16.33%
# Epoch 17: iteration 7/8
# Epoch 17 --- loss:1.720, Epoch accuracy:23.42%, Validation loss:2.071, Validation accuracy:16.67%
# Epoch 18: iteration 7/8
# Epoch 18 --- loss:1.708, Epoch accuracy:23.07%, Validation loss:2.062, Validation accuracy:17.00%
# Epoch 19: iteration 7/8
# Epoch 19 --- loss:1.699, Epoch accuracy:23.51%, Validation loss:2.054, Validation accuracy:18.00%
# Epoch 20: iteration 7/8
# Epoch 20 --- loss:1.682, Epoch accuracy:24.21%, Validation loss:2.045, Validation accuracy:18.67%
# Epoch 21: iteration 7/8
# Epoch 21 --- loss:1.664, Epoch accuracy:26.32%, Validation loss:2.037, Validation accuracy:19.33%
# Epoch 22: iteration 7/8
# Epoch 22 --- loss:1.658, Epoch accuracy:25.79%, Validation loss:2.028, Validation accuracy:20.33%
# Epoch 23: iteration 7/8
# Epoch 23 --- loss:1.646, Epoch accuracy:27.63%, Validation loss:2.020, Validation accuracy:20.33%
# Epoch 24: iteration 7/8
# Epoch 24 --- loss:1.632, Epoch accuracy:27.89%, Validation loss:2.014, Validation accuracy:20.33%
# Epoch 25: iteration 7/8
# Epoch 25 --- loss:1.620, Epoch accuracy:29.47%, Validation loss:2.006, Validation accuracy:20.67%
# Epoch 26: iteration 7/8
# Epoch 26 --- loss:1.605, Epoch accuracy:29.21%, Validation loss:2.000, Validation accuracy:21.33%
# Epoch 27: iteration 7/8
# Epoch 27 --- loss:1.589, Epoch accuracy:30.79%, Validation loss:1.992, Validation accuracy:22.00%
# Epoch 28: iteration 7/8
# Epoch 28 --- loss:1.582, Epoch accuracy:31.05%, Validation loss:1.985, Validation accuracy:22.33%
# Epoch 29: iteration 7/8
# Epoch 29 --- loss:1.569, Epoch accuracy:31.93%, Validation loss:1.978, Validation accuracy:22.67%
# Epoch 30: iteration 7/8
# Epoch 30 --- loss:1.551, Epoch accuracy:34.30%, Validation loss:1.970, Validation accuracy:23.00%
# Epoch 31: iteration 7/8
# Epoch 31 --- loss:1.537, Epoch accuracy:34.47%, Validation loss:1.963, Validation accuracy:23.67%
# Epoch 32: iteration 7/8
# Epoch 32 --- loss:1.533, Epoch accuracy:35.09%, Validation loss:1.956, Validation accuracy:23.67%
# Epoch 33: iteration 7/8
# Epoch 33 --- loss:1.511, Epoch accuracy:37.72%, Validation loss:1.949, Validation accuracy:23.33%
# Epoch 34: iteration 7/8
# Epoch 34 --- loss:1.511, Epoch accuracy:35.53%, Validation loss:1.941, Validation accuracy:24.00%
# Epoch 35: iteration 7/8
# Epoch 35 --- loss:1.495, Epoch accuracy:38.68%, Validation loss:1.934, Validation accuracy:24.67%
# Epoch 36: iteration 7/8
# Epoch 36 --- loss:1.483, Epoch accuracy:39.47%, Validation loss:1.927, Validation accuracy:25.33%
# Epoch 37: iteration 7/8
# Epoch 37 --- loss:1.475, Epoch accuracy:39.82%, Validation loss:1.921, Validation accuracy:26.00%
# Epoch 38: iteration 7/8
# Epoch 38 --- loss:1.462, Epoch accuracy:41.67%, Validation loss:1.915, Validation accuracy:25.67%
# Epoch 39: iteration 7/8
# Epoch 39 --- loss:1.454, Epoch accuracy:42.63%, Validation loss:1.908, Validation accuracy:26.33%
# Epoch 40: iteration 7/8
# Epoch 40 --- loss:1.438, Epoch accuracy:44.56%, Validation loss:1.901, Validation accuracy:27.33%
# Epoch 41: iteration 7/8
# Epoch 41 --- loss:1.427, Epoch accuracy:44.65%, Validation loss:1.895, Validation accuracy:27.67%
# Epoch 42: iteration 7/8
# Epoch 42 --- loss:1.416, Epoch accuracy:46.14%, Validation loss:1.889, Validation accuracy:27.67%
# Epoch 43: iteration 7/8
# Epoch 43 --- loss:1.406, Epoch accuracy:47.11%, Validation loss:1.882, Validation accuracy:28.00%
# Epoch 44: iteration 7/8
# Epoch 44 --- loss:1.397, Epoch accuracy:47.19%, Validation loss:1.876, Validation accuracy:29.67%
# Epoch 45: iteration 7/8
# Epoch 45 --- loss:1.380, Epoch accuracy:48.95%, Validation loss:1.870, Validation accuracy:29.67%
# Epoch 46: iteration 7/8
# Epoch 46 --- loss:1.373, Epoch accuracy:50.18%, Validation loss:1.865, Validation accuracy:30.33%
# Epoch 47: iteration 7/8
# Epoch 47 --- loss:1.356, Epoch accuracy:51.67%, Validation loss:1.859, Validation accuracy:31.00%
# Epoch 48: iteration 7/8
# Epoch 48 --- loss:1.358, Epoch accuracy:51.58%, Validation loss:1.853, Validation accuracy:31.67%
# Epoch 49: iteration 7/8
# Epoch 49 --- loss:1.348, Epoch accuracy:52.19%, Validation loss:1.847, Validation accuracy:31.33%
# Epoch 50: iteration 7/8
# Epoch 50 --- loss:1.334, Epoch accuracy:52.81%, Validation loss:1.841, Validation accuracy:31.00%
# Epoch 51: iteration 7/8
# Epoch 51 --- loss:1.318, Epoch accuracy:53.60%, Validation loss:1.836, Validation accuracy:30.67%
# Epoch 52: iteration 7/8
# Epoch 52 --- loss:1.317, Epoch accuracy:54.39%, Validation loss:1.830, Validation accuracy:31.67%
# Epoch 53: iteration 7/8
# Epoch 53 --- loss:1.301, Epoch accuracy:55.35%, Validation loss:1.824, Validation accuracy:32.00%
# Epoch 54: iteration 7/8
# Epoch 54 --- loss:1.292, Epoch accuracy:56.58%, Validation loss:1.818, Validation accuracy:33.00%
# Epoch 55: iteration 7/8
# Epoch 55 --- loss:1.281, Epoch accuracy:57.54%, Validation loss:1.814, Validation accuracy:33.67%
# Epoch 56: iteration 7/8
# Epoch 56 --- loss:1.273, Epoch accuracy:57.81%, Validation loss:1.808, Validation accuracy:33.67%
# Epoch 57: iteration 7/8
# Epoch 57 --- loss:1.258, Epoch accuracy:59.65%, Validation loss:1.803, Validation accuracy:34.33%
# Epoch 58: iteration 7/8
# Epoch 58 --- loss:1.252, Epoch accuracy:59.82%, Validation loss:1.798, Validation accuracy:34.67%
# Epoch 59: iteration 7/8
# Epoch 59 --- loss:1.238, Epoch accuracy:60.96%, Validation loss:1.792, Validation accuracy:35.33%
# Epoch 60: iteration 7/8
# Epoch 60 --- loss:1.229, Epoch accuracy:61.05%, Validation loss:1.787, Validation accuracy:36.67%
# Epoch 61: iteration 7/8
# Epoch 61 --- loss:1.218, Epoch accuracy:62.11%, Validation loss:1.782, Validation accuracy:35.67%
# Epoch 62: iteration 7/8
# Epoch 62 --- loss:1.216, Epoch accuracy:62.46%, Validation loss:1.777, Validation accuracy:36.33%
# Epoch 63: iteration 7/8
# Epoch 63 --- loss:1.197, Epoch accuracy:63.25%, Validation loss:1.773, Validation accuracy:37.33%
# Epoch 64: iteration 7/8
# Epoch 64 --- loss:1.197, Epoch accuracy:62.98%, Validation loss:1.768, Validation accuracy:37.00%
# Epoch 65: iteration 7/8
# Epoch 65 --- loss:1.183, Epoch accuracy:63.60%, Validation loss:1.762, Validation accuracy:36.33%
# Epoch 66: iteration 7/8
# Epoch 66 --- loss:1.179, Epoch accuracy:63.33%, Validation loss:1.758, Validation accuracy:37.67%
# Epoch 67: iteration 7/8
# Epoch 67 --- loss:1.167, Epoch accuracy:63.42%, Validation loss:1.752, Validation accuracy:36.33%
# Epoch 68: iteration 7/8
# Epoch 68 --- loss:1.165, Epoch accuracy:64.74%, Validation loss:1.748, Validation accuracy:37.33%
# Epoch 69: iteration 7/8
# Epoch 69 --- loss:1.146, Epoch accuracy:66.23%, Validation loss:1.743, Validation accuracy:37.33%
# Epoch 70: iteration 7/8
# Epoch 70 --- loss:1.132, Epoch accuracy:67.19%, Validation loss:1.738, Validation accuracy:37.67%
# Epoch 71: iteration 7/8
# Epoch 71 --- loss:1.136, Epoch accuracy:66.32%, Validation loss:1.734, Validation accuracy:37.67%
# Epoch 72: iteration 7/8
# Epoch 72 --- loss:1.123, Epoch accuracy:66.84%, Validation loss:1.730, Validation accuracy:38.33%
# Epoch 73: iteration 7/8
# Epoch 73 --- loss:1.111, Epoch accuracy:67.72%, Validation loss:1.726, Validation accuracy:37.67%
# Epoch 74: iteration 7/8
# Epoch 74 --- loss:1.101, Epoch accuracy:67.98%, Validation loss:1.721, Validation accuracy:38.00%
# Epoch 75: iteration 7/8
# Epoch 75 --- loss:1.091, Epoch accuracy:69.47%, Validation loss:1.717, Validation accuracy:37.67%
# Epoch 76: iteration 7/8
# Epoch 76 --- loss:1.092, Epoch accuracy:69.30%, Validation loss:1.712, Validation accuracy:38.00%
# Epoch 77: iteration 7/8
# Epoch 77 --- loss:1.071, Epoch accuracy:70.00%, Validation loss:1.709, Validation accuracy:38.00%
# Epoch 78: iteration 7/8
# Epoch 78 --- loss:1.076, Epoch accuracy:69.21%, Validation loss:1.703, Validation accuracy:38.67%
# Epoch 79: iteration 7/8
# Epoch 79 --- loss:1.056, Epoch accuracy:71.05%, Validation loss:1.699, Validation accuracy:38.00%
# Epoch 80: iteration 7/8
# Epoch 80 --- loss:1.050, Epoch accuracy:70.44%, Validation loss:1.694, Validation accuracy:38.67%
# Epoch 81: iteration 7/8
# Epoch 81 --- loss:1.030, Epoch accuracy:73.33%, Validation loss:1.690, Validation accuracy:38.67%
# Epoch 82: iteration 7/8
# Epoch 82 --- loss:1.034, Epoch accuracy:71.93%, Validation loss:1.686, Validation accuracy:39.67%
# Epoch 83: iteration 7/8
# Epoch 83 --- loss:1.024, Epoch accuracy:72.72%, Validation loss:1.683, Validation accuracy:40.33%
# Epoch 84: iteration 7/8
# Epoch 84 --- loss:1.024, Epoch accuracy:71.23%, Validation loss:1.679, Validation accuracy:40.00%
# Epoch 85: iteration 7/8
# Epoch 85 --- loss:1.014, Epoch accuracy:72.11%, Validation loss:1.675, Validation accuracy:40.00%
# Epoch 86: iteration 7/8
# Epoch 86 --- loss:1.001, Epoch accuracy:72.02%, Validation loss:1.670, Validation accuracy:41.00%
# Epoch 87: iteration 7/8
# Epoch 87 --- loss:0.998, Epoch accuracy:73.25%, Validation loss:1.667, Validation accuracy:40.67%
# Epoch 88: iteration 7/8
# Epoch 88 --- loss:0.987, Epoch accuracy:74.65%, Validation loss:1.663, Validation accuracy:40.67%
# Epoch 89: iteration 7/8
# Epoch 89 --- loss:0.980, Epoch accuracy:73.07%, Validation loss:1.660, Validation accuracy:41.33%
# Epoch 90: iteration 7/8
# Epoch 90 --- loss:0.975, Epoch accuracy:74.12%, Validation loss:1.656, Validation accuracy:40.67%
# Epoch 91: iteration 7/8
# Epoch 91 --- loss:0.956, Epoch accuracy:75.09%, Validation loss:1.653, Validation accuracy:41.33%
# Epoch 92: iteration 7/8
# Epoch 92 --- loss:0.960, Epoch accuracy:75.44%, Validation loss:1.649, Validation accuracy:41.33%
# Epoch 93: iteration 7/8
# Epoch 93 --- loss:0.948, Epoch accuracy:75.70%, Validation loss:1.645, Validation accuracy:41.67%
# Epoch 94: iteration 7/8
# Epoch 94 --- loss:0.938, Epoch accuracy:75.88%, Validation loss:1.641, Validation accuracy:42.00%
# Epoch 95: iteration 7/8
# Epoch 95 --- loss:0.930, Epoch accuracy:77.02%, Validation loss:1.639, Validation accuracy:42.33%
# Epoch 96: iteration 7/8
# Epoch 96 --- loss:0.921, Epoch accuracy:76.49%, Validation loss:1.634, Validation accuracy:42.33%
# Epoch 97: iteration 7/8
# Epoch 97 --- loss:0.922, Epoch accuracy:76.23%, Validation loss:1.631, Validation accuracy:42.33%
# Epoch 98: iteration 7/8
# Epoch 98 --- loss:0.910, Epoch accuracy:77.63%, Validation loss:1.628, Validation accuracy:43.00%
# Epoch 99: iteration 7/8
# Epoch 99 --- loss:0.906, Epoch accuracy:77.72%, Validation loss:1.624, Validation accuracy:43.00%
# Epoch 100: iteration 7/8
# Epoch 100 --- loss:0.897, Epoch accuracy:78.25%, Validation loss:1.622, Validation accuracy:43.00%
# Epoch 101: iteration 7/8
# Epoch 101 --- loss:0.886, Epoch accuracy:78.77%, Validation loss:1.619, Validation accuracy:43.67%
# Epoch 102: iteration 7/8
# Epoch 102 --- loss:0.886, Epoch accuracy:78.86%, Validation loss:1.615, Validation accuracy:43.00%
# Epoch 103: iteration 7/8
# Epoch 103 --- loss:0.870, Epoch accuracy:78.60%, Validation loss:1.611, Validation accuracy:42.33%
# Epoch 104: iteration 7/8
# Epoch 104 --- loss:0.868, Epoch accuracy:79.21%, Validation loss:1.609, Validation accuracy:43.33%
# Epoch 105: iteration 7/8
# Epoch 105 --- loss:0.859, Epoch accuracy:79.74%, Validation loss:1.606, Validation accuracy:43.67%
# Epoch 106: iteration 7/8
# Epoch 106 --- loss:0.857, Epoch accuracy:79.82%, Validation loss:1.602, Validation accuracy:43.67%
# Epoch 107: iteration 7/8
# Epoch 107 --- loss:0.842, Epoch accuracy:80.18%, Validation loss:1.599, Validation accuracy:43.67%
# Epoch 108: iteration 7/8
# Epoch 108 --- loss:0.841, Epoch accuracy:79.65%, Validation loss:1.597, Validation accuracy:44.67%
# Epoch 109: iteration 7/8
# Epoch 109 --- loss:0.831, Epoch accuracy:80.26%, Validation loss:1.594, Validation accuracy:45.33%
# Epoch 110: iteration 7/8
# Epoch 110 --- loss:0.831, Epoch accuracy:79.74%, Validation loss:1.591, Validation accuracy:43.67%
# Epoch 111: iteration 7/8
# Epoch 111 --- loss:0.821, Epoch accuracy:80.96%, Validation loss:1.588, Validation accuracy:43.67%
# Epoch 112: iteration 7/8
# Epoch 112 --- loss:0.815, Epoch accuracy:80.79%, Validation loss:1.586, Validation accuracy:44.33%
# Epoch 113: iteration 7/8
# Epoch 113 --- loss:0.809, Epoch accuracy:81.32%, Validation loss:1.582, Validation accuracy:45.00%
# Epoch 114: iteration 7/8
# Epoch 114 --- loss:0.796, Epoch accuracy:81.40%, Validation loss:1.579, Validation accuracy:45.00%
# Epoch 115: iteration 7/8
# Epoch 115 --- loss:0.793, Epoch accuracy:81.49%, Validation loss:1.576, Validation accuracy:44.67%
# Epoch 116: iteration 7/8
# Epoch 116 --- loss:0.783, Epoch accuracy:82.02%, Validation loss:1.573, Validation accuracy:44.33%
# Epoch 117: iteration 7/8
# Epoch 117 --- loss:0.773, Epoch accuracy:82.63%, Validation loss:1.571, Validation accuracy:45.33%
# Epoch 118: iteration 7/8
# Epoch 118 --- loss:0.773, Epoch accuracy:82.46%, Validation loss:1.568, Validation accuracy:45.00%
# Epoch 119: iteration 7/8
# Epoch 119 --- loss:0.761, Epoch accuracy:82.28%, Validation loss:1.565, Validation accuracy:45.33%
# Epoch 120: iteration 7/8
# Epoch 120 --- loss:0.761, Epoch accuracy:82.02%, Validation loss:1.563, Validation accuracy:45.00%
# Epoch 121: iteration 7/8
# Epoch 121 --- loss:0.745, Epoch accuracy:82.98%, Validation loss:1.561, Validation accuracy:45.67%
# Epoch 122: iteration 7/8
# Epoch 122 --- loss:0.742, Epoch accuracy:82.11%, Validation loss:1.559, Validation accuracy:45.67%
# Epoch 123: iteration 7/8
# Epoch 123 --- loss:0.737, Epoch accuracy:83.07%, Validation loss:1.557, Validation accuracy:45.67%
# Epoch 124: iteration 7/8
# Epoch 124 --- loss:0.731, Epoch accuracy:83.33%, Validation loss:1.554, Validation accuracy:46.00%
# Epoch 125: iteration 7/8
# Epoch 125 --- loss:0.737, Epoch accuracy:82.89%, Validation loss:1.550, Validation accuracy:46.33%
# Epoch 126: iteration 7/8
# Epoch 126 --- loss:0.727, Epoch accuracy:83.25%, Validation loss:1.549, Validation accuracy:45.67%
# Epoch 127: iteration 7/8
# Epoch 127 --- loss:0.718, Epoch accuracy:83.42%, Validation loss:1.546, Validation accuracy:46.00%
# Epoch 128: iteration 7/8
# Epoch 128 --- loss:0.715, Epoch accuracy:83.86%, Validation loss:1.544, Validation accuracy:47.33%
# Epoch 129: iteration 7/8
# Epoch 129 --- loss:0.702, Epoch accuracy:83.25%, Validation loss:1.542, Validation accuracy:47.00%
# Epoch 130: iteration 7/8
# Epoch 130 --- loss:0.697, Epoch accuracy:84.12%, Validation loss:1.538, Validation accuracy:47.33%
# Epoch 131: iteration 7/8
# Epoch 131 --- loss:0.692, Epoch accuracy:84.56%, Validation loss:1.537, Validation accuracy:47.00%
# Epoch 132: iteration 7/8
# Epoch 132 --- loss:0.686, Epoch accuracy:84.82%, Validation loss:1.534, Validation accuracy:47.67%
# Epoch 133: iteration 7/8
# Epoch 133 --- loss:0.681, Epoch accuracy:84.74%, Validation loss:1.532, Validation accuracy:47.00%
# Epoch 134: iteration 7/8
# Epoch 134 --- loss:0.676, Epoch accuracy:84.56%, Validation loss:1.530, Validation accuracy:47.00%
# Epoch 135: iteration 7/8
# Epoch 135 --- loss:0.667, Epoch accuracy:84.82%, Validation loss:1.528, Validation accuracy:47.33%
# Epoch 136: iteration 7/8
# Epoch 136 --- loss:0.664, Epoch accuracy:84.74%, Validation loss:1.526, Validation accuracy:46.33%
# Epoch 137: iteration 7/8
# Epoch 137 --- loss:0.661, Epoch accuracy:84.91%, Validation loss:1.524, Validation accuracy:46.67%
# Epoch 138: iteration 7/8
# Epoch 138 --- loss:0.661, Epoch accuracy:84.65%, Validation loss:1.522, Validation accuracy:46.67%
# Epoch 139: iteration 7/8
# Epoch 139 --- loss:0.643, Epoch accuracy:85.18%, Validation loss:1.521, Validation accuracy:46.33%
# Epoch 140: iteration 7/8
# Epoch 140 --- loss:0.646, Epoch accuracy:85.18%, Validation loss:1.518, Validation accuracy:47.67%
# Epoch 141: iteration 7/8
# Epoch 141 --- loss:0.639, Epoch accuracy:85.88%, Validation loss:1.516, Validation accuracy:47.33%
# Epoch 142: iteration 7/8
# Epoch 142 --- loss:0.632, Epoch accuracy:85.61%, Validation loss:1.515, Validation accuracy:47.33%
# Epoch 143: iteration 7/8
# Epoch 143 --- loss:0.622, Epoch accuracy:86.14%, Validation loss:1.513, Validation accuracy:47.33%
# Epoch 144: iteration 7/8
# Epoch 144 --- loss:0.623, Epoch accuracy:85.70%, Validation loss:1.511, Validation accuracy:47.00%
# Epoch 145: iteration 7/8
# Epoch 145 --- loss:0.614, Epoch accuracy:85.88%, Validation loss:1.510, Validation accuracy:46.00%
# Epoch 146: iteration 7/8
# Epoch 146 --- loss:0.613, Epoch accuracy:86.32%, Validation loss:1.507, Validation accuracy:47.00%
# Epoch 147: iteration 7/8
# Epoch 147 --- loss:0.607, Epoch accuracy:86.32%, Validation loss:1.505, Validation accuracy:47.67%
# Epoch 148: iteration 7/8
# Epoch 148 --- loss:0.596, Epoch accuracy:86.40%, Validation loss:1.503, Validation accuracy:46.33%
# Epoch 149: iteration 7/8
# Epoch 149 --- loss:0.593, Epoch accuracy:86.67%, Validation loss:1.501, Validation accuracy:47.67%
# Epoch 150: iteration 7/8
# Epoch 150 --- loss:0.589, Epoch accuracy:86.84%, Validation loss:1.500, Validation accuracy:47.33%
# Epoch 151: iteration 7/8
# Epoch 151 --- loss:0.587, Epoch accuracy:86.05%, Validation loss:1.497, Validation accuracy:47.33%
# Epoch 152: iteration 7/8
# Epoch 152 --- loss:0.586, Epoch accuracy:86.84%, Validation loss:1.495, Validation accuracy:47.33%
# Epoch 153: iteration 7/8
# Epoch 153 --- loss:0.574, Epoch accuracy:86.58%, Validation loss:1.494, Validation accuracy:47.33%
# Epoch 154: iteration 7/8
# Epoch 154 --- loss:0.567, Epoch accuracy:87.11%, Validation loss:1.492, Validation accuracy:47.67%
# Epoch 155: iteration 7/8
# Epoch 155 --- loss:0.572, Epoch accuracy:86.67%, Validation loss:1.491, Validation accuracy:47.67%
# Epoch 156: iteration 7/8
# Epoch 156 --- loss:0.558, Epoch accuracy:87.37%, Validation loss:1.489, Validation accuracy:46.67%
# Epoch 157: iteration 7/8
# Epoch 157 --- loss:0.551, Epoch accuracy:87.28%, Validation loss:1.487, Validation accuracy:47.33%
# Epoch 158: iteration 7/8
# Epoch 158 --- loss:0.554, Epoch accuracy:86.93%, Validation loss:1.485, Validation accuracy:48.00%
# Epoch 159: iteration 7/8
# Epoch 159 --- loss:0.543, Epoch accuracy:87.54%, Validation loss:1.485, Validation accuracy:47.33%
# Epoch 160: iteration 7/8
# Epoch 160 --- loss:0.540, Epoch accuracy:87.02%, Validation loss:1.483, Validation accuracy:47.33%
# Epoch 161: iteration 7/8
# Epoch 161 --- loss:0.533, Epoch accuracy:86.93%, Validation loss:1.482, Validation accuracy:47.67%
# Epoch 162: iteration 7/8
# Epoch 162 --- loss:0.530, Epoch accuracy:87.37%, Validation loss:1.480, Validation accuracy:48.00%
# Epoch 163: iteration 7/8
# Epoch 163 --- loss:0.521, Epoch accuracy:87.37%, Validation loss:1.478, Validation accuracy:48.00%
# Epoch 164: iteration 7/8
# Epoch 164 --- loss:0.527, Epoch accuracy:87.37%, Validation loss:1.477, Validation accuracy:47.33%
# Epoch 165: iteration 7/8
# Epoch 165 --- loss:0.517, Epoch accuracy:87.37%, Validation loss:1.475, Validation accuracy:47.67%
# Epoch 166: iteration 7/8
# Epoch 166 --- loss:0.515, Epoch accuracy:87.72%, Validation loss:1.474, Validation accuracy:47.67%
# Epoch 167: iteration 7/8
# Epoch 167 --- loss:0.506, Epoch accuracy:87.54%, Validation loss:1.473, Validation accuracy:47.67%
# Epoch 168: iteration 7/8
# Epoch 168 --- loss:0.506, Epoch accuracy:87.63%, Validation loss:1.471, Validation accuracy:47.67%
# Epoch 169: iteration 7/8
# Epoch 169 --- loss:0.503, Epoch accuracy:87.89%, Validation loss:1.470, Validation accuracy:48.00%
# Epoch 170: iteration 7/8
# Epoch 170 --- loss:0.494, Epoch accuracy:88.25%, Validation loss:1.468, Validation accuracy:48.00%
# Epoch 171: iteration 7/8
# Epoch 171 --- loss:0.494, Epoch accuracy:87.81%, Validation loss:1.467, Validation accuracy:48.00%
# Epoch 172: iteration 7/8
# Epoch 172 --- loss:0.479, Epoch accuracy:88.25%, Validation loss:1.466, Validation accuracy:48.33%
# Epoch 173: iteration 7/8
# Epoch 173 --- loss:0.477, Epoch accuracy:88.07%, Validation loss:1.464, Validation accuracy:48.33%
# Epoch 174: iteration 7/8
# Epoch 174 --- loss:0.477, Epoch accuracy:88.25%, Validation loss:1.462, Validation accuracy:48.00%
# Epoch 175: iteration 7/8
# Epoch 175 --- loss:0.471, Epoch accuracy:88.33%, Validation loss:1.461, Validation accuracy:48.00%
# Epoch 176: iteration 7/8
# Epoch 176 --- loss:0.466, Epoch accuracy:88.51%, Validation loss:1.460, Validation accuracy:48.33%
# Epoch 177: iteration 7/8
# Epoch 177 --- loss:0.465, Epoch accuracy:88.60%, Validation loss:1.460, Validation accuracy:47.67%
# Epoch 178: iteration 7/8
# Epoch 178 --- loss:0.459, Epoch accuracy:88.51%, Validation loss:1.458, Validation accuracy:48.00%
# Epoch 179: iteration 7/8
# Epoch 179 --- loss:0.461, Epoch accuracy:88.07%, Validation loss:1.456, Validation accuracy:48.00%
# Epoch 180: iteration 7/8
# Epoch 180 --- loss:0.459, Epoch accuracy:88.68%, Validation loss:1.454, Validation accuracy:48.67%
# Epoch 181: iteration 7/8
# Epoch 181 --- loss:0.454, Epoch accuracy:88.42%, Validation loss:1.454, Validation accuracy:47.67%
# Epoch 182: iteration 7/8
# Epoch 182 --- loss:0.440, Epoch accuracy:88.51%, Validation loss:1.452, Validation accuracy:48.00%
# Epoch 183: iteration 7/8
# Epoch 183 --- loss:0.445, Epoch accuracy:88.51%, Validation loss:1.451, Validation accuracy:48.00%
# Epoch 184: iteration 7/8
# Epoch 184 --- loss:0.443, Epoch accuracy:88.68%, Validation loss:1.449, Validation accuracy:48.33%
# Epoch 185: iteration 7/8
# Epoch 185 --- loss:0.436, Epoch accuracy:88.86%, Validation loss:1.449, Validation accuracy:48.33%
# Epoch 186: iteration 7/8
# Epoch 186 --- loss:0.432, Epoch accuracy:88.68%, Validation loss:1.449, Validation accuracy:48.00%
# Epoch 187: iteration 7/8
# Epoch 187 --- loss:0.425, Epoch accuracy:89.04%, Validation loss:1.447, Validation accuracy:48.33%
# Epoch 188: iteration 7/8
# Epoch 188 --- loss:0.425, Epoch accuracy:88.86%, Validation loss:1.446, Validation accuracy:48.33%
# Epoch 189: iteration 7/8
# Epoch 189 --- loss:0.423, Epoch accuracy:88.60%, Validation loss:1.445, Validation accuracy:48.33%
# Epoch 190: iteration 7/8
# Epoch 190 --- loss:0.413, Epoch accuracy:88.86%, Validation loss:1.445, Validation accuracy:47.67%
# Epoch 191: iteration 7/8
# Epoch 191 --- loss:0.413, Epoch accuracy:88.77%, Validation loss:1.443, Validation accuracy:47.67%
# Epoch 192: iteration 7/8
# Epoch 192 --- loss:0.413, Epoch accuracy:88.68%, Validation loss:1.441, Validation accuracy:48.00%
# Epoch 193: iteration 7/8
# Epoch 193 --- loss:0.405, Epoch accuracy:89.21%, Validation loss:1.439, Validation accuracy:49.00%
# Epoch 194: iteration 7/8
# Epoch 194 --- loss:0.406, Epoch accuracy:89.30%, Validation loss:1.439, Validation accuracy:48.33%
# Epoch 195: iteration 7/8
# Epoch 195 --- loss:0.398, Epoch accuracy:89.21%, Validation loss:1.439, Validation accuracy:47.67%
# Epoch 196: iteration 7/8
# Epoch 196 --- loss:0.390, Epoch accuracy:88.95%, Validation loss:1.439, Validation accuracy:47.67%
# Epoch 197: iteration 7/8
# Epoch 197 --- loss:0.395, Epoch accuracy:89.04%, Validation loss:1.439, Validation accuracy:47.00%
# Epoch 198: iteration 7/8
# Epoch 198 --- loss:0.390, Epoch accuracy:89.04%, Validation loss:1.437, Validation accuracy:47.33%
# Epoch 199: iteration 7/8
# Epoch 199 --- loss:0.391, Epoch accuracy:88.86%, Validation loss:1.436, Validation accuracy:47.33%
# Epoch 200: iteration 7/8
# Epoch 200 --- loss:0.380, Epoch accuracy:89.21%, Validation loss:1.435, Validation accuracy:46.67%
# Epoch 201: iteration 7/8
# Epoch 201 --- loss:0.380, Epoch accuracy:89.30%, Validation loss:1.433, Validation accuracy:47.67%
# Epoch 202: iteration 7/8
# Epoch 202 --- loss:0.371, Epoch accuracy:89.47%, Validation loss:1.432, Validation accuracy:47.33%
# Epoch 203: iteration 7/8
# Epoch 203 --- loss:0.373, Epoch accuracy:89.30%, Validation loss:1.433, Validation accuracy:47.00%
# Epoch 204: iteration 7/8
# Epoch 204 --- loss:0.367, Epoch accuracy:89.39%, Validation loss:1.432, Validation accuracy:47.00%
# Epoch 205: iteration 7/8
# Epoch 205 --- loss:0.371, Epoch accuracy:89.21%, Validation loss:1.430, Validation accuracy:47.00%
# Epoch 206: iteration 7/8
# Epoch 206 --- loss:0.362, Epoch accuracy:89.39%, Validation loss:1.428, Validation accuracy:47.33%
# Epoch 207: iteration 7/8
# Epoch 207 --- loss:0.359, Epoch accuracy:89.39%, Validation loss:1.428, Validation accuracy:47.67%
# Epoch 208: iteration 7/8
# Epoch 208 --- loss:0.358, Epoch accuracy:89.47%, Validation loss:1.426, Validation accuracy:47.33%
# Epoch 209: iteration 7/8
# Epoch 209 --- loss:0.354, Epoch accuracy:89.30%, Validation loss:1.426, Validation accuracy:47.33%
# Epoch 210: iteration 7/8
# Epoch 210 --- loss:0.350, Epoch accuracy:89.39%, Validation loss:1.426, Validation accuracy:47.33%
# Epoch 211: iteration 7/8
# Epoch 211 --- loss:0.348, Epoch accuracy:89.30%, Validation loss:1.425, Validation accuracy:47.67%
# Epoch 212: iteration 7/8
# Epoch 212 --- loss:0.346, Epoch accuracy:89.39%, Validation loss:1.422, Validation accuracy:48.00%
# Epoch 213: iteration 7/8
# Epoch 213 --- loss:0.339, Epoch accuracy:89.30%, Validation loss:1.420, Validation accuracy:48.67%
# Epoch 214: iteration 7/8
# Epoch 214 --- loss:0.341, Epoch accuracy:89.39%, Validation loss:1.421, Validation accuracy:47.67%
# Epoch 215: iteration 7/8
# Epoch 215 --- loss:0.340, Epoch accuracy:89.30%, Validation loss:1.420, Validation accuracy:48.00%
# Epoch 216: iteration 7/8
# Epoch 216 --- loss:0.327, Epoch accuracy:89.47%, Validation loss:1.419, Validation accuracy:48.00%
# Epoch 217: iteration 7/8
# Epoch 217 --- loss:0.327, Epoch accuracy:89.56%, Validation loss:1.418, Validation accuracy:48.00%
# Epoch 218: iteration 7/8
# Epoch 218 --- loss:0.329, Epoch accuracy:89.30%, Validation loss:1.417, Validation accuracy:47.67%
# Epoch 219: iteration 7/8
# Epoch 219 --- loss:0.321, Epoch accuracy:89.47%, Validation loss:1.418, Validation accuracy:47.33%
# Epoch 220: iteration 7/8
# Epoch 220 --- loss:0.322, Epoch accuracy:89.47%, Validation loss:1.417, Validation accuracy:46.67%
# Epoch 221: iteration 7/8
# Epoch 221 --- loss:0.315, Epoch accuracy:89.30%, Validation loss:1.419, Validation accuracy:47.00%
# Epoch 222: iteration 7/8
# Epoch 222 --- loss:0.314, Epoch accuracy:89.47%, Validation loss:1.418, Validation accuracy:47.00%
# Epoch 223: iteration 7/8
# Epoch 223 --- loss:0.311, Epoch accuracy:89.39%, Validation loss:1.416, Validation accuracy:47.00%
# Epoch 224: iteration 7/8
# Epoch 224 --- loss:0.310, Epoch accuracy:89.65%, Validation loss:1.415, Validation accuracy:47.33%
# Epoch 225: iteration 7/8
# Epoch 225 --- loss:0.307, Epoch accuracy:89.56%, Validation loss:1.412, Validation accuracy:47.00%
# Epoch 226: iteration 7/8
# Epoch 226 --- loss:0.308, Epoch accuracy:89.56%, Validation loss:1.413, Validation accuracy:47.00%
# Epoch 227: iteration 7/8
# Epoch 227 --- loss:0.307, Epoch accuracy:89.65%, Validation loss:1.413, Validation accuracy:47.33%
# Epoch 228: iteration 7/8
# Epoch 228 --- loss:0.299, Epoch accuracy:89.56%, Validation loss:1.413, Validation accuracy:47.00%
# Epoch 229: iteration 7/8
# Epoch 229 --- loss:0.298, Epoch accuracy:89.74%, Validation loss:1.413, Validation accuracy:46.67%
# Epoch 230: iteration 7/8
# Epoch 230 --- loss:0.296, Epoch accuracy:89.65%, Validation loss:1.410, Validation accuracy:47.00%
# Epoch 231: iteration 7/8
# Epoch 231 --- loss:0.299, Epoch accuracy:89.74%, Validation loss:1.408, Validation accuracy:47.33%
# Epoch 232: iteration 7/8
# Epoch 232 --- loss:0.286, Epoch accuracy:89.56%, Validation loss:1.409, Validation accuracy:47.00%
# Epoch 233: iteration 7/8
# Epoch 233 --- loss:0.290, Epoch accuracy:89.47%, Validation loss:1.407, Validation accuracy:47.33%
# Epoch 234: iteration 7/8
# Epoch 234 --- loss:0.283, Epoch accuracy:89.65%, Validation loss:1.406, Validation accuracy:47.67%
# Epoch 235: iteration 7/8
# Epoch 235 --- loss:0.282, Epoch accuracy:89.65%, Validation loss:1.407, Validation accuracy:47.33%
# Epoch 236: iteration 7/8
# Epoch 236 --- loss:0.278, Epoch accuracy:89.56%, Validation loss:1.408, Validation accuracy:46.67%
# Epoch 237: iteration 7/8
# Epoch 237 --- loss:0.281, Epoch accuracy:89.65%, Validation loss:1.407, Validation accuracy:46.67%
# Epoch 238: iteration 7/8
# Epoch 238 --- loss:0.275, Epoch accuracy:89.65%, Validation loss:1.406, Validation accuracy:47.67%
# Epoch 239: iteration 7/8
# Epoch 239 --- loss:0.276, Epoch accuracy:89.56%, Validation loss:1.405, Validation accuracy:47.67%
# Epoch 240: iteration 7/8
# Epoch 240 --- loss:0.269, Epoch accuracy:89.65%, Validation loss:1.407, Validation accuracy:47.33%
# Epoch 241: iteration 7/8
# Epoch 241 --- loss:0.263, Epoch accuracy:89.65%, Validation loss:1.406, Validation accuracy:48.00%
# Epoch 242: iteration 7/8
# Epoch 242 --- loss:0.262, Epoch accuracy:89.74%, Validation loss:1.404, Validation accuracy:47.33%
# Epoch 243: iteration 7/8
# Epoch 243 --- loss:0.265, Epoch accuracy:89.74%, Validation loss:1.403, Validation accuracy:47.67%
# Epoch 244: iteration 7/8
# Epoch 244 --- loss:0.263, Epoch accuracy:89.74%, Validation loss:1.403, Validation accuracy:47.67%
# Epoch 245: iteration 7/8
# Epoch 245 --- loss:0.259, Epoch accuracy:89.65%, Validation loss:1.401, Validation accuracy:48.00%
# Epoch 246: iteration 7/8
# Epoch 246 --- loss:0.261, Epoch accuracy:89.65%, Validation loss:1.403, Validation accuracy:47.67%
# Epoch 247: iteration 7/8
# Epoch 247 --- loss:0.252, Epoch accuracy:89.65%, Validation loss:1.402, Validation accuracy:47.67%
# Epoch 248: iteration 7/8
# Epoch 248 --- loss:0.252, Epoch accuracy:89.56%, Validation loss:1.401, Validation accuracy:48.33%
# Epoch 249: iteration 7/8
# Epoch 249 --- loss:0.255, Epoch accuracy:89.65%, Validation loss:1.402, Validation accuracy:47.67%
# Epoch 250: iteration 7/8
# Epoch 250 --- loss:0.248, Epoch accuracy:89.65%, Validation loss:1.401, Validation accuracy:48.33%
# Epoch 251: iteration 7/8
# Epoch 251 --- loss:0.248, Epoch accuracy:89.74%, Validation loss:1.401, Validation accuracy:48.00%
# Epoch 252: iteration 7/8
# Epoch 252 --- loss:0.247, Epoch accuracy:89.74%, Validation loss:1.397, Validation accuracy:48.67%
# Epoch 253: iteration 7/8
# Epoch 253 --- loss:0.242, Epoch accuracy:89.65%, Validation loss:1.399, Validation accuracy:47.33%
# Epoch 254: iteration 7/8
# Epoch 254 --- loss:0.243, Epoch accuracy:89.74%, Validation loss:1.399, Validation accuracy:48.00%
# Epoch 255: iteration 7/8
# Epoch 255 --- loss:0.238, Epoch accuracy:89.74%, Validation loss:1.400, Validation accuracy:47.67%
# Epoch 256: iteration 7/8
# Epoch 256 --- loss:0.237, Epoch accuracy:89.74%, Validation loss:1.397, Validation accuracy:48.33%
# Epoch 257: iteration 7/8
# Epoch 257 --- loss:0.239, Epoch accuracy:89.65%, Validation loss:1.397, Validation accuracy:48.67%
# Epoch 258: iteration 7/8
# Epoch 258 --- loss:0.231, Epoch accuracy:89.65%, Validation loss:1.399, Validation accuracy:48.33%
# Epoch 259: iteration 7/8
# Epoch 259 --- loss:0.231, Epoch accuracy:89.65%, Validation loss:1.395, Validation accuracy:48.33%
# Epoch 260: iteration 7/8
# Epoch 260 --- loss:0.229, Epoch accuracy:89.65%, Validation loss:1.395, Validation accuracy:48.67%
# Epoch 261: iteration 7/8
# Epoch 261 --- loss:0.230, Epoch accuracy:89.74%, Validation loss:1.395, Validation accuracy:48.33%
# Epoch 262: iteration 7/8
# Epoch 262 --- loss:0.225, Epoch accuracy:89.65%, Validation loss:1.394, Validation accuracy:48.67%
# Epoch 263: iteration 7/8
# Epoch 263 --- loss:0.225, Epoch accuracy:89.74%, Validation loss:1.396, Validation accuracy:48.33%
# Epoch 264: iteration 7/8
# Epoch 264 --- loss:0.223, Epoch accuracy:89.65%, Validation loss:1.394, Validation accuracy:48.00%
# Epoch 265: iteration 7/8
# Epoch 265 --- loss:0.222, Epoch accuracy:89.74%, Validation loss:1.392, Validation accuracy:49.00%
# Epoch 266: iteration 7/8
# Epoch 266 --- loss:0.224, Epoch accuracy:89.74%, Validation loss:1.394, Validation accuracy:48.67%
# Epoch 267: iteration 7/8
# Epoch 267 --- loss:0.218, Epoch accuracy:89.65%, Validation loss:1.394, Validation accuracy:48.33%
# Epoch 268: iteration 7/8
# Epoch 268 --- loss:0.217, Epoch accuracy:89.65%, Validation loss:1.393, Validation accuracy:48.67%
# Epoch 269: iteration 7/8
# Epoch 269 --- loss:0.214, Epoch accuracy:89.65%, Validation loss:1.391, Validation accuracy:49.33%
# Epoch 270: iteration 7/8
# Epoch 270 --- loss:0.213, Epoch accuracy:89.65%, Validation loss:1.392, Validation accuracy:48.33%
# Epoch 271: iteration 7/8
# Epoch 271 --- loss:0.211, Epoch accuracy:89.82%, Validation loss:1.390, Validation accuracy:48.67%
# Epoch 272: iteration 7/8
# Epoch 272 --- loss:0.211, Epoch accuracy:89.74%, Validation loss:1.389, Validation accuracy:48.67%
# Epoch 273: iteration 7/8
# Epoch 273 --- loss:0.207, Epoch accuracy:89.82%, Validation loss:1.388, Validation accuracy:49.00%
# Epoch 274: iteration 7/8
# Epoch 274 --- loss:0.207, Epoch accuracy:89.82%, Validation loss:1.391, Validation accuracy:48.33%
# Epoch 275: iteration 7/8
# Epoch 275 --- loss:0.208, Epoch accuracy:89.74%, Validation loss:1.388, Validation accuracy:49.00%
# Epoch 276: iteration 7/8
# Epoch 276 --- loss:0.203, Epoch accuracy:89.82%, Validation loss:1.387, Validation accuracy:49.33%
# Epoch 277: iteration 7/8
# Epoch 277 --- loss:0.202, Epoch accuracy:89.74%, Validation loss:1.388, Validation accuracy:49.00%
# Epoch 278: iteration 7/8
# Epoch 278 --- loss:0.208, Epoch accuracy:89.74%, Validation loss:1.386, Validation accuracy:49.67%
# Epoch 279: iteration 7/8
# Epoch 279 --- loss:0.201, Epoch accuracy:89.74%, Validation loss:1.388, Validation accuracy:48.67%
# Epoch 280: iteration 7/8
# Epoch 280 --- loss:0.196, Epoch accuracy:89.82%, Validation loss:1.387, Validation accuracy:49.00%
# Epoch 281: iteration 7/8
# Epoch 281 --- loss:0.201, Epoch accuracy:89.74%, Validation loss:1.386, Validation accuracy:49.00%
# Epoch 282: iteration 7/8
# Epoch 282 --- loss:0.193, Epoch accuracy:89.82%, Validation loss:1.386, Validation accuracy:48.67%
# Epoch 283: iteration 7/8
# Epoch 283 --- loss:0.192, Epoch accuracy:89.74%, Validation loss:1.388, Validation accuracy:48.33%
# Epoch 284: iteration 7/8
# Epoch 284 --- loss:0.193, Epoch accuracy:89.82%, Validation loss:1.390, Validation accuracy:47.67%
# Epoch 285: iteration 7/8
# Epoch 285 --- loss:0.192, Epoch accuracy:89.74%, Validation loss:1.387, Validation accuracy:48.33%
# Epoch 286: iteration 7/8
# Epoch 286 --- loss:0.187, Epoch accuracy:89.82%, Validation loss:1.386, Validation accuracy:48.67%
# Epoch 287: iteration 7/8
# Epoch 287 --- loss:0.184, Epoch accuracy:89.82%, Validation loss:1.385, Validation accuracy:48.67%
# Epoch 288: iteration 7/8
# Epoch 288 --- loss:0.190, Epoch accuracy:89.82%, Validation loss:1.387, Validation accuracy:48.00%
# Epoch 289: iteration 7/8
# Epoch 289 --- loss:0.182, Epoch accuracy:89.82%, Validation loss:1.386, Validation accuracy:48.33%
# Epoch 290: iteration 7/8
# Epoch 290 --- loss:0.180, Epoch accuracy:89.74%, Validation loss:1.383, Validation accuracy:49.00%
# Epoch 291: iteration 7/8
# Epoch 291 --- loss:0.181, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:49.33%
# Epoch 292: iteration 7/8
# Epoch 292 --- loss:0.179, Epoch accuracy:89.82%, Validation loss:1.382, Validation accuracy:49.00%
# Epoch 293: iteration 7/8
# Epoch 293 --- loss:0.184, Epoch accuracy:89.82%, Validation loss:1.384, Validation accuracy:49.00%
# Epoch 294: iteration 7/8
# Epoch 294 --- loss:0.178, Epoch accuracy:89.74%, Validation loss:1.384, Validation accuracy:48.67%
# Epoch 295: iteration 7/8
# Epoch 295 --- loss:0.176, Epoch accuracy:89.74%, Validation loss:1.383, Validation accuracy:49.33%
# Epoch 296: iteration 7/8
# Epoch 296 --- loss:0.176, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:48.33%
# Epoch 297: iteration 7/8
# Epoch 297 --- loss:0.175, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:48.67%
# Epoch 298: iteration 7/8
# Epoch 298 --- loss:0.173, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:48.33%
# Epoch 299: iteration 7/8
# Epoch 299 --- loss:0.169, Epoch accuracy:89.82%, Validation loss:1.383, Validation accuracy:48.00%
# Epoch 300: iteration 7/8
# Epoch 300 --- loss:0.174, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:48.00%
# Epoch 301: iteration 7/8
# Epoch 301 --- loss:0.166, Epoch accuracy:89.82%, Validation loss:1.382, Validation accuracy:48.33%
# Epoch 302: iteration 7/8
# Epoch 302 --- loss:0.168, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:48.67%
# Epoch 303: iteration 7/8
# Epoch 303 --- loss:0.167, Epoch accuracy:89.82%, Validation loss:1.380, Validation accuracy:48.33%
# Epoch 304: iteration 7/8
# Epoch 304 --- loss:0.164, Epoch accuracy:89.82%, Validation loss:1.380, Validation accuracy:48.33%
# Epoch 305: iteration 7/8
# Epoch 305 --- loss:0.161, Epoch accuracy:89.82%, Validation loss:1.380, Validation accuracy:48.67%
# Epoch 306: iteration 7/8
# Epoch 306 --- loss:0.163, Epoch accuracy:89.82%, Validation loss:1.382, Validation accuracy:48.67%
# Epoch 307: iteration 7/8
# Epoch 307 --- loss:0.159, Epoch accuracy:89.82%, Validation loss:1.384, Validation accuracy:48.67%
# Epoch 308: iteration 7/8
# Epoch 308 --- loss:0.163, Epoch accuracy:89.82%, Validation loss:1.382, Validation accuracy:48.67%
# Epoch 309: iteration 7/8
# Epoch 309 --- loss:0.161, Epoch accuracy:89.82%, Validation loss:1.385, Validation accuracy:48.33%
# Epoch 310: iteration 7/8
# Epoch 310 --- loss:0.158, Epoch accuracy:89.82%, Validation loss:1.380, Validation accuracy:48.33%
# Epoch 311: iteration 7/8
# Epoch 311 --- loss:0.157, Epoch accuracy:89.82%, Validation loss:1.382, Validation accuracy:48.33%
# Epoch 312: iteration 7/8
# Epoch 312 --- loss:0.157, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:48.00%
# Epoch 313: iteration 7/8
# Epoch 313 --- loss:0.155, Epoch accuracy:89.82%, Validation loss:1.379, Validation accuracy:47.67%
# Epoch 314: iteration 7/8
# Epoch 314 --- loss:0.157, Epoch accuracy:89.82%, Validation loss:1.380, Validation accuracy:48.00%
# Epoch 315: iteration 7/8
# Epoch 315 --- loss:0.153, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:47.33%
# Epoch 316: iteration 7/8
# Epoch 316 --- loss:0.152, Epoch accuracy:89.82%, Validation loss:1.382, Validation accuracy:48.33%
# Epoch 317: iteration 7/8
# Epoch 317 --- loss:0.150, Epoch accuracy:89.82%, Validation loss:1.381, Validation accuracy:48.00%
# Epoch 318: iteration 7/8
# Epoch 318 --- loss:0.152, Epoch accuracy:89.82%, Validation loss:1.380, Validation accuracy:48.33%
# Epoch 319: iteration 7/8
# Epoch 319 --- loss:0.150, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:47.67%
# Epoch 320: iteration 7/8
# Epoch 320 --- loss:0.147, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:47.67%
# Epoch 321: iteration 7/8
# Epoch 321 --- loss:0.152, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:47.67%
# Epoch 322: iteration 7/8
# Epoch 322 --- loss:0.146, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:48.00%
# Epoch 323: iteration 7/8
# Epoch 323 --- loss:0.147, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:48.00%
# Epoch 324: iteration 7/8
# Epoch 324 --- loss:0.143, Epoch accuracy:89.82%, Validation loss:1.380, Validation accuracy:48.67%
# Epoch 325: iteration 7/8
# Epoch 325 --- loss:0.144, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:48.00%
# Epoch 326: iteration 7/8
# Epoch 326 --- loss:0.143, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:48.00%
# Epoch 327: iteration 7/8
# Epoch 327 --- loss:0.141, Epoch accuracy:89.82%, Validation loss:1.377, Validation accuracy:47.67%
# Epoch 328: iteration 7/8
# Epoch 328 --- loss:0.142, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:48.00%
# Epoch 329: iteration 7/8
# Epoch 329 --- loss:0.138, Epoch accuracy:89.82%, Validation loss:1.376, Validation accuracy:48.67%
# Epoch 330: iteration 7/8
# Epoch 330 --- loss:0.139, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:48.33%
# Epoch 331: iteration 7/8
# Epoch 331 --- loss:0.138, Epoch accuracy:89.82%, Validation loss:1.376, Validation accuracy:46.67%
# Epoch 332: iteration 7/8
# Epoch 332 --- loss:0.137, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:47.33%
# Epoch 333: iteration 7/8
# Epoch 333 --- loss:0.135, Epoch accuracy:89.82%, Validation loss:1.376, Validation accuracy:47.67%
# Epoch 334: iteration 7/8
# Epoch 334 --- loss:0.133, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:47.67%
# Epoch 335: iteration 7/8
# Epoch 335 --- loss:0.134, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:48.33%
# Epoch 336: iteration 7/8
# Epoch 336 --- loss:0.133, Epoch accuracy:89.82%, Validation loss:1.377, Validation accuracy:48.33%
# Epoch 337: iteration 7/8
# Epoch 337 --- loss:0.136, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:48.00%
# Epoch 338: iteration 7/8
# Epoch 338 --- loss:0.133, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:48.33%
# Epoch 339: iteration 7/8
# Epoch 339 --- loss:0.130, Epoch accuracy:89.82%, Validation loss:1.376, Validation accuracy:48.33%
# Epoch 340: iteration 7/8
# Epoch 340 --- loss:0.131, Epoch accuracy:89.82%, Validation loss:1.377, Validation accuracy:48.33%
# Epoch 341: iteration 7/8
# Epoch 341 --- loss:0.129, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:48.00%
# Epoch 342: iteration 7/8
# Epoch 342 --- loss:0.131, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:48.00%
# Epoch 343: iteration 7/8
# Epoch 343 --- loss:0.130, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:48.33%
# Epoch 344: iteration 7/8
# Epoch 344 --- loss:0.128, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:48.33%
# Epoch 345: iteration 7/8
# Epoch 345 --- loss:0.128, Epoch accuracy:89.82%, Validation loss:1.371, Validation accuracy:47.67%
# Epoch 346: iteration 7/8
# Epoch 346 --- loss:0.128, Epoch accuracy:89.82%, Validation loss:1.370, Validation accuracy:47.33%
# Epoch 347: iteration 7/8
# Epoch 347 --- loss:0.121, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:47.67%
# Epoch 348: iteration 7/8
# Epoch 348 --- loss:0.124, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:47.67%
# Epoch 349: iteration 7/8
# Epoch 349 --- loss:0.123, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:47.67%
# Epoch 350: iteration 7/8
# Epoch 350 --- loss:0.122, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:47.67%
# Epoch 351: iteration 7/8
# Epoch 351 --- loss:0.124, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:48.00%
# Epoch 352: iteration 7/8
# Epoch 352 --- loss:0.121, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:48.33%
# Epoch 353: iteration 7/8
# Epoch 353 --- loss:0.120, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:47.33%
# Epoch 354: iteration 7/8
# Epoch 354 --- loss:0.120, Epoch accuracy:89.82%, Validation loss:1.376, Validation accuracy:47.00%
# Epoch 355: iteration 7/8
# Epoch 355 --- loss:0.119, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:47.33%
# Epoch 356: iteration 7/8
# Epoch 356 --- loss:0.117, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:47.33%
# Epoch 357: iteration 7/8
# Epoch 357 --- loss:0.117, Epoch accuracy:89.82%, Validation loss:1.377, Validation accuracy:47.33%
# Epoch 358: iteration 7/8
# Epoch 358 --- loss:0.117, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:47.33%
# Epoch 359: iteration 7/8
# Epoch 359 --- loss:0.117, Epoch accuracy:89.82%, Validation loss:1.378, Validation accuracy:47.33%
# Epoch 360: iteration 7/8
# Epoch 360 --- loss:0.117, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:48.00%
# Epoch 361: iteration 7/8
# Epoch 361 --- loss:0.114, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:48.00%
# Epoch 362: iteration 7/8
# Epoch 362 --- loss:0.113, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:48.33%
# Epoch 363: iteration 7/8
# Epoch 363 --- loss:0.113, Epoch accuracy:89.82%, Validation loss:1.371, Validation accuracy:48.67%
# Epoch 364: iteration 7/8
# Epoch 364 --- loss:0.112, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:48.33%
# Epoch 365: iteration 7/8
# Epoch 365 --- loss:0.111, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:48.00%
# Epoch 366: iteration 7/8
# Epoch 366 --- loss:0.113, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:47.67%
# Epoch 367: iteration 7/8
# Epoch 367 --- loss:0.109, Epoch accuracy:89.82%, Validation loss:1.370, Validation accuracy:48.00%
# Epoch 368: iteration 7/8
# Epoch 368 --- loss:0.110, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:48.33%
# Epoch 369: iteration 7/8
# Epoch 369 --- loss:0.109, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:47.67%
# Epoch 370: iteration 7/8
# Epoch 370 --- loss:0.108, Epoch accuracy:89.82%, Validation loss:1.377, Validation accuracy:47.67%
# Epoch 371: iteration 7/8
# Epoch 371 --- loss:0.107, Epoch accuracy:89.82%, Validation loss:1.376, Validation accuracy:48.00%
# Epoch 372: iteration 7/8
# Epoch 372 --- loss:0.106, Epoch accuracy:89.82%, Validation loss:1.372, Validation accuracy:47.67%
# Epoch 373: iteration 7/8
# Epoch 373 --- loss:0.107, Epoch accuracy:89.82%, Validation loss:1.371, Validation accuracy:47.67%
# Epoch 374: iteration 7/8
# Epoch 374 --- loss:0.110, Epoch accuracy:89.82%, Validation loss:1.369, Validation accuracy:47.33%
# Epoch 375: iteration 7/8
# Epoch 375 --- loss:0.107, Epoch accuracy:89.82%, Validation loss:1.367, Validation accuracy:47.67%
# Epoch 376: iteration 7/8
# Epoch 376 --- loss:0.103, Epoch accuracy:89.82%, Validation loss:1.370, Validation accuracy:48.00%
# Epoch 377: iteration 7/8
# Epoch 377 --- loss:0.103, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:47.67%
# Epoch 378: iteration 7/8
# Epoch 378 --- loss:0.103, Epoch accuracy:89.82%, Validation loss:1.374, Validation accuracy:47.33%
# Epoch 379: iteration 7/8
# Epoch 379 --- loss:0.101, Epoch accuracy:89.82%, Validation loss:1.375, Validation accuracy:47.33%
# Epoch 380: iteration 7/8
# Epoch 380 --- loss:0.103, Epoch accuracy:89.82%, Validation loss:1.372, Validation accuracy:47.67%
# Epoch 381: iteration 7/8
# Epoch 381 --- loss:0.103, Epoch accuracy:89.82%, Validation loss:1.373, Validation accuracy:47.67%
# Epoch 382: iteration 7/8
# Epoch 382 --- loss:0.100, Epoch accuracy:89.82%, Validation loss:1.372, Validation accuracy:47.33%
# Epoch 383: iteration 7/8
# Epoch 383 --- loss:0.102, Epoch accuracy:89.82%, Validation loss:1.369, Validation accuracy:47.33%
# Epoch 384: iteration 7/8
# Epoch 384 --- loss:0.100, Epoch accuracy:89.82%, Validation loss:1.369, Validation accuracy:48.00%
# Epoch 385: iteration 7/8
# Epoch 385 --- loss:0.098, Epoch accuracy:89.82%, Validation loss:1.367, Validation accuracy:47.67%
# Epoch 386: iteration 7/8
# Epoch 386 --- loss:0.097, Epoch accuracy:89.82%, Validation loss:1.370, Validation accuracy:48.00%
# Epoch 387: iteration 7/8
# Epoch 387 --- loss:0.099, Epoch accuracy:89.82%, Validation loss:1.372, Validation accuracy:47.67%
# Epoch 388: iteration 7/8
# ...
# Epoch 373: iteration 8/9
# Epoch 373 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 374: iteration 8/9
# Epoch 374 --- loss:0.007, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 375: iteration 8/9
# Epoch 375 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 376: iteration 8/9
# Epoch 376 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 377: iteration 8/9
# Epoch 377 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 378: iteration 8/9
# Epoch 378 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 379: iteration 8/9
# Epoch 379 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 380: iteration 8/9
# Epoch 380 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 381: iteration 8/9
# Epoch 381 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 382: iteration 8/9
# Epoch 382 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 383: iteration 8/9
# Epoch 383 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 384: iteration 8/9
# Epoch 384 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 385: iteration 8/9
# Epoch 385 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 386: iteration 8/9
# Epoch 386 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 387: iteration 8/9
# Epoch 387 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 388: iteration 8/9
# Epoch 388 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 389: iteration 8/9
# Epoch 389 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 390: iteration 8/9
# Epoch 390 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 391: iteration 8/9
# Epoch 391 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 392: iteration 8/9
# Epoch 392 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 393: iteration 8/9
# Epoch 393 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 394: iteration 8/9
# Epoch 394 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 395: iteration 8/9
# Epoch 395 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 396: iteration 8/9
# Epoch 396 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 397: iteration 8/9
# Epoch 397 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 398: iteration 8/9
# Epoch 398 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 399: iteration 8/9
# Epoch 399 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 400: iteration 8/9
# Epoch 400 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 401: iteration 8/9
# Epoch 401 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 402: iteration 8/9
# Epoch 402 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 403: iteration 8/9
# Epoch 403 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 404: iteration 8/9
# Epoch 404 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 405: iteration 8/9
# Epoch 405 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 406: iteration 8/9
# Epoch 406 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 407: iteration 8/9
# Epoch 407 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 408: iteration 8/9
# Epoch 408 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 409: iteration 8/9
# Epoch 409 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 410: iteration 8/9
# Epoch 410 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 411: iteration 8/9
# Epoch 411 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 412: iteration 8/9
# Epoch 412 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 413: iteration 8/9
# Epoch 413 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 414: iteration 8/9
# Epoch 414 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 415: iteration 8/9
# Epoch 415 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 416: iteration 8/9
# Epoch 416 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 417: iteration 8/9
# Epoch 417 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 418: iteration 8/9
# Epoch 418 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 419: iteration 8/9
# Epoch 419 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 420: iteration 8/9
# Epoch 420 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 421: iteration 8/9
# Epoch 421 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 422: iteration 8/9
# Epoch 422 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 423: iteration 8/9
# Epoch 423 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 424: iteration 8/9
# Epoch 424 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 425: iteration 8/9
# Epoch 425 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 426: iteration 8/9
# Epoch 426 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 427: iteration 8/9
# Epoch 427 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 428: iteration 8/9
# Epoch 428 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 429: iteration 8/9
# Epoch 429 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 430: iteration 8/9
# Epoch 430 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 431: iteration 8/9
# Epoch 431 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 432: iteration 8/9
# Epoch 432 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 433: iteration 8/9
# Epoch 433 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 434: iteration 8/9
# Epoch 434 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 435: iteration 8/9
# Epoch 435 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 436: iteration 8/9
# Epoch 436 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 437: iteration 8/9
# Epoch 437 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 438: iteration 8/9
# Epoch 438 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 439: iteration 8/9
# Epoch 439 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 440: iteration 8/9
# Epoch 440 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 441: iteration 8/9
# Epoch 441 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 442: iteration 8/9
# Epoch 442 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 443: iteration 8/9
# Epoch 443 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 444: iteration 8/9
# Epoch 444 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 445: iteration 8/9
# Epoch 445 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 446: iteration 8/9
# Epoch 446 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 447: iteration 8/9
# Epoch 447 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 448: iteration 8/9
# Epoch 448 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 449: iteration 8/9
# Epoch 449 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 450: iteration 8/9
# Epoch 450 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 451: iteration 8/9
# Epoch 451 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 452: iteration 8/9
# Epoch 452 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 453: iteration 8/9
# Epoch 453 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 454: iteration 8/9
# Epoch 454 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 455: iteration 8/9
# Epoch 455 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 456: iteration 8/9
# Epoch 456 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 457: iteration 8/9
# Epoch 457 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 458: iteration 8/9
# Epoch 458 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 459: iteration 8/9
# Epoch 459 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 460: iteration 8/9
# Epoch 460 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 461: iteration 8/9
# Epoch 461 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 462: iteration 8/9
# Epoch 462 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 463: iteration 8/9
# Epoch 463 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 464: iteration 8/9
# Epoch 464 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 465: iteration 8/9
# Epoch 465 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 466: iteration 8/9
# Epoch 466 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 467: iteration 8/9
# Epoch 467 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 468: iteration 8/9
# Epoch 468 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 469: iteration 8/9
# Epoch 469 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 470: iteration 8/9
# Epoch 470 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 471: iteration 8/9
# Epoch 471 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 472: iteration 8/9
# Epoch 472 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 473: iteration 8/9
# Epoch 473 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 474: iteration 8/9
# Epoch 474 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 475: iteration 8/9
# Epoch 475 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 476: iteration 8/9
# Epoch 476 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 477: iteration 8/9
# Epoch 477 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 478: iteration 8/9
# Epoch 478 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 479: iteration 8/9
# Epoch 479 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 480: iteration 8/9
# Epoch 480 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 481: iteration 8/9
# Epoch 481 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 482: iteration 8/9
# Epoch 482 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 483: iteration 8/9
# Epoch 483 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 484: iteration 8/9
# Epoch 484 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 485: iteration 8/9
# Epoch 485 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 486: iteration 8/9
# Epoch 486 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 487: iteration 8/9
# Epoch 487 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 488: iteration 8/9
# Epoch 488 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 489: iteration 8/9
# Epoch 489 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 490: iteration 8/9
# Epoch 490 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 491: iteration 8/9
# Epoch 491 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 492: iteration 8/9
# Epoch 492 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 493: iteration 8/9
# Epoch 493 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 494: iteration 8/9
# Epoch 494 --- loss:0.005, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 495: iteration 8/9
# Epoch 495 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 496: iteration 8/9
# Epoch 496 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 497: iteration 8/9
# Epoch 497 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 498: iteration 8/9
# Epoch 498 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
# Epoch 499: iteration 8/9
# Epoch 499 --- loss:0.006, Epoch accuracy:96.00%, Validation loss:0.006, Validation accuracy:100.00%
#
#
# [*] done !
# [*] Best training loss - 0.0054652235905329385
# [*] Best validation loss - 0.005948780104517937

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
# Out:
# [*] 0 Test accuracy is 49.00%
# [*] 1 Test accuracy is 100.00%
# [*] 2 Test accuracy is 100.00%
# [*] 3 Test accuracy is 100.00%
# [*] 4 Test accuracy is 100.00%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 100.00%
# [*] Worst fold acc : 49.00%
# [*] Average fold acc : 89.80%

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
# Out:
# [*] 0 Test accuracy is 49.00%
#               precision    recall  f1-score   support
#
#            0       0.26      0.25      0.26        20
#            1       0.73      0.55      0.63        40
#            2       0.50      0.17      0.26        40
#            3       0.32      0.40      0.36        40
#            4       0.37      0.82      0.51        40
#            5       0.80      0.60      0.69        40
#            6       0.53      0.42      0.47        40
#            7       0.64      0.57      0.61        40
#
#     accuracy                           0.49       300
#    macro avg       0.52      0.47      0.47       300
# weighted avg       0.54      0.49      0.49       300
#
# [*] 1 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 2 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 3 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 4 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        32
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        32
#            4       1.00      1.00      1.00        32
#            5       1.00      1.00      1.00        32
#            6       1.00      1.00      1.00        32
#            7       1.00      1.00      1.00        32
#
#     accuracy                           1.00       240
#    macro avg       1.00      1.00      1.00       240
# weighted avg       1.00      1.00      1.00       240
