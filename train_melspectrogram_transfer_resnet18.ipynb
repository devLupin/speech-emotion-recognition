# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from einops import rearrange

class resnet18_transfer(nn.Module):
    def __init__(self, num_emotions) -> None:
        super().__init__()
    
        self.model_ft = models.resnet18(pretrained=True)
        
        num_ftrs = self.model_ft.fc.in_features
        self.model_ft.fc = nn.Linear(num_ftrs, num_emotions)
        
        self.softmax_out = nn.Softmax(dim=1)
    
    def forward(self, x):
        output_logits = self.model_ft(x)
        output_softmax = self.softmax_out(output_logits)
        
        return output_logits, output_softmax

# %%
import os
import torch
import numpy as np
from torchinfo import summary
from tqdm.auto import tqdm

os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

emotions_dict = {
    0: 'Neutral',
    1: 'Calm',
    2: 'Happy',
    3: 'Sad',
    4: 'Angry',
    5: 'Fear',
    6: 'Disgust',
    7: 'Surprise'
}

model = resnet18_transfer(num_emotions=len(emotions_dict)).to('cuda')
sub_name = 'vgg11_bn_transfer'
data_name = 'RAVDESS'
EARLY_CNT = 30

minibatch = 64
num_epochs = 150
optimizer = torch.optim.Adam(model.parameters(), lr=1e-6, betas=(0.9, 0.999), eps=1e-08, weight_decay=0., amsgrad=True)

print(summary(model, input_size=(minibatch, 3, 224, 224)))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# resnet18_transfer                             [64, 8]                   --
# ├─ResNet: 1-1                                 [64, 8]                   --
# │    └─Conv2d: 2-1                            [64, 64, 112, 112]        9,408
# │    └─BatchNorm2d: 2-2                       [64, 64, 112, 112]        128
# │    └─ReLU: 2-3                              [64, 64, 112, 112]        --
# │    └─MaxPool2d: 2-4                         [64, 64, 56, 56]          --
# │    └─Sequential: 2-5                        [64, 64, 56, 56]          --
# │    │    └─BasicBlock: 3-1                   [64, 64, 56, 56]          73,984
# │    │    └─BasicBlock: 3-2                   [64, 64, 56, 56]          73,984
# │    └─Sequential: 2-6                        [64, 128, 28, 28]         --
# │    │    └─BasicBlock: 3-3                   [64, 128, 28, 28]         230,144
# │    │    └─BasicBlock: 3-4                   [64, 128, 28, 28]         295,424
# │    └─Sequential: 2-7                        [64, 256, 14, 14]         --
# │    │    └─BasicBlock: 3-5                   [64, 256, 14, 14]         919,040
# │    │    └─BasicBlock: 3-6                   [64, 256, 14, 14]         1,180,672
# │    └─Sequential: 2-8                        [64, 512, 7, 7]           --
# │    │    └─BasicBlock: 3-7                   [64, 512, 7, 7]           3,673,088
# │    │    └─BasicBlock: 3-8                   [64, 512, 7, 7]           4,720,640
# │    └─AdaptiveAvgPool2d: 2-9                 [64, 512, 1, 1]           --
# │    └─Linear: 2-10                           [64, 8]                   4,104
# ├─Softmax: 1-2                                [64, 8]                   --
# ===============================================================================================
# Total params: 11,180,616
# Trainable params: 11,180,616
# Non-trainable params: 0
# Total mult-adds (G): 116.07
# ===============================================================================================
# Input size (MB): 38.54
# Forward/backward pass size (MB): 2543.33
# Params size (MB): 44.72
# Estimated Total Size (MB): 2626.58
# ===============================================================================================

# %%
def make_train_step(model, criterion, optimizer):

    # define the training step of the training phase
    def train_step(X, Y):

        # forward pass
        output_logits, output_softmax = model(X)
        predictions = torch.argmax(output_softmax, dim=1)
        accuracy = torch.sum(Y == predictions)/float(len(Y))

        # compute loss on logits because nn.CrossEntropyLoss implements log softmax
        loss = criterion(output_logits, Y)

        # compute gradients for the optimizer to use
        loss.backward()

        # update network parameters based on gradient stored (by calling loss.backward())
        optimizer.step()

        # zero out gradients for next pass
        # pytorch accumulates gradients from backwards passes (convenient for RNNs)
        optimizer.zero_grad()

        return loss.item(), accuracy*100
    return train_step

# %%
def make_validate_fnc(model, criterion):
    def validate(X, Y):

        # don't want to update any network parameters on validation passes: don't need gradient
        # wrap in torch.no_grad to save memory and compute in validation phase:
        with torch.no_grad():

            # set model to validation phase i.e. turn off dropout and batchnorm layers
            model.eval()
            
            # get the model's predictions on the validation set
            output_logits, output_softmax = model(X)
            predictions = torch.argmax(output_softmax, dim=1)

            # calculate the mean accuracy over the entire validation set
            accuracy = torch.sum(Y == predictions)/float(len(Y))

            # compute error from logits (nn.crossentropy implements softmax)
            loss = criterion(output_logits, Y)

        return loss.item(), accuracy*100, predictions
    return validate

# %%
def make_save_checkpoint():
    def save_checkpoint(optimizer, model, epoch, filename):
        checkpoint_dict = {
            'optimizer': optimizer.state_dict(),
            'model': model.state_dict(),
            'epoch': epoch
        }
        torch.save(checkpoint_dict, filename)
    return save_checkpoint


def load_checkpoint(optimizer, model, filename):
    checkpoint_dict = torch.load(filename)
    epoch = checkpoint_dict['epoch']
    model.load_state_dict(checkpoint_dict['model'])
    if optimizer is not None:
        optimizer.load_state_dict(checkpoint_dict['optimizer'])
    return epoch

# %%
def criterion(predictions, targets):
    return nn.CrossEntropyLoss()(input=predictions, target=targets)

# %%
from einops import rearrange

def train(model, num_epochs, X_train, Y_train, X_valid, Y_valid, pkl_name, fold):
    
    # instantiate lists to hold scalar performance metrics to plot later
    train_losses = []
    valid_losses = []

    # get training set size to calculate # iterations and minibatch indices
    train_size = X_train.shape[0]

    # instantiate the checkpoint save function
    save_checkpoint = make_save_checkpoint()

    # instantiate the training step function
    train_step = make_train_step(model, criterion, optimizer=optimizer)
    # instantiate the validation loop function
    validate = make_validate_fnc(model, criterion)

    cur_valid_loss = 0x3f3f3f
    early_stop_cnt = 0
    
    for epoch in tqdm(range(num_epochs), desc=f'{fold}'):

        if early_stop_cnt >= EARLY_CNT:
            break
        
        # set model to train phase
        model.train()

        # shuffle entire training set in each epoch to randomize minibatch order
        train_indices = np.random.permutation(train_size)

        # shuffle the training set for each epoch:
        X_train = X_train[train_indices, :, :, :]
        Y_train = Y_train[train_indices]

        # instantiate scalar values to keep track of progress after each epoch so we can stop training when appropriate
        epoch_acc = 0
        epoch_loss = 0
        num_iterations = int(train_size / minibatch)

        # create a loop for each minibatch of 32 samples:
        for i in range(num_iterations):

            # we have to track and update minibatch position for the current minibatch
            # if we take a random batch position from a set, we almost certainly will skip some of the data in that set
            # track minibatch position based on iteration number:
            batch_start = i * minibatch
            # ensure we don't go out of the bounds of our training set:
            batch_end = min(batch_start + minibatch, train_size)
            # ensure we don't have an index error
            actual_batch_size = batch_end-batch_start

            # get training minibatch with all channnels and 2D feature dims
            X = X_train[batch_start:batch_end, :, :, :]
            # get training minibatch labels
            Y = Y_train[batch_start:batch_end]
            
            # instantiate training tensors
            X_tensor = torch.tensor(X, device=device).float()
            X_tensor = X_tensor.permute(0, 3, 1, 2)
            Y_tensor = torch.tensor(Y, dtype=torch.long, device=device)
            
            # Pass input tensors thru 1 training step (fwd+backwards pass)
            loss, acc = train_step(X_tensor, Y_tensor)

            # aggregate batch accuracy to measure progress of entire epoch
            epoch_acc += acc * actual_batch_size / train_size
            epoch_loss += loss * actual_batch_size / train_size

            # keep track of the iteration to see if the model's too slow
            print('\r'+f'Epoch {epoch}: iteration {i}/{num_iterations}', end='')

        X_valid_tensor = torch.tensor(X_valid, device=device).float()
        X_valid_tensor = X_valid_tensor.permute(0, 3, 1, 2)
        Y_valid_tensor = torch.tensor(Y_valid, dtype=torch.long, device=device)
        
        # calculate validation metrics to keep track of progress; don't need predictions now
        valid_loss, valid_acc, _ = validate(X_valid_tensor, Y_valid_tensor)
        
        # accumulate scalar performance metrics at each epoch to track and plot later
        train_losses.append(epoch_loss)
        valid_losses.append(valid_loss)
        
        if cur_valid_loss > valid_loss:
            save_checkpoint(optimizer, model, epoch, pkl_name)
            cur_valid_loss = valid_loss
        else:
            early_stop_cnt += 1

        # keep track of each epoch's progress
        print(f'\nEpoch {epoch} --- loss:{epoch_loss:.3f}, Epoch accuracy:{epoch_acc:.2f}%, Validation loss:{valid_loss:.3f}, Validation accuracy:{valid_acc:.2f}%')

        
    print(f"\n\n[*] done !")
    print(f'[*] Best training loss - {min(train_losses)}')
    print(f'[*] Best validation loss - {min(valid_losses)}')
    
    return train_losses, valid_losses

# %%
import csv
import cv2
import numpy as np
from PIL import Image
from skimage.io import imread
from skimage.transform import resize

def get_fold_dataset(cur_fold_path):
    X_train, y_train, X_test, y_test = [], [], [], []
    
    train_f = open(os.path.join(cur_fold_path, 'train.csv'), 'r')
    test_f = open(os.path.join(cur_fold_path, 'test.csv'), 'r')
    
    train_reader = csv.reader(train_f)
    for r in train_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_train.append(image)
        y_train.append(int(r[1]))
        
    test_reader = csv.reader(test_f)
    for r in test_reader:
        image = imread(r[0])
        image = resize(image, (224,224,3))
        X_test.append(image)
        y_test.append(int(r[1]))
    
    return np.array(X_train), np.array(y_train), np.array(X_test), np.array(y_test)

# %%
all_fold_dataset = []

for fold in tqdm(range(5), desc='load melspectrogram fold dataset'):
    cur_fold_path = os.path.join('melspectrogram_fold', str(fold))
    X_train, y_train, X_test, y_test = get_fold_dataset(cur_fold_path)
    
    all_fold_dataset.append([X_train, y_train, X_test, y_test])
# Out:
# load melspectrogram fold dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

train_losses, valid_losses = [], []

print(f'[*] model training - {sub_name}')

fold_path = 'melspectrogram_fold'

for fold in range(5):
    cur = all_fold_dataset[fold]
    
    
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    train_losses, valid_losses = train(model, num_epochs, cur[0], cur[1], cur[2], cur[3], pkl_name, fold)
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(train_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
# Out:
# [*] model training - vgg11_bn_transfer
# 0:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:2.039, Epoch accuracy:15.00%, Validation loss:2.216, Validation accuracy:11.67%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:2.009, Epoch accuracy:17.11%, Validation loss:2.154, Validation accuracy:14.00%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:1.983, Epoch accuracy:18.68%, Validation loss:2.095, Validation accuracy:17.33%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:1.958, Epoch accuracy:21.14%, Validation loss:2.071, Validation accuracy:20.67%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:1.934, Epoch accuracy:21.67%, Validation loss:2.055, Validation accuracy:20.33%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:1.916, Epoch accuracy:22.63%, Validation loss:2.039, Validation accuracy:22.00%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:1.888, Epoch accuracy:23.95%, Validation loss:2.027, Validation accuracy:22.00%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:1.868, Epoch accuracy:25.61%, Validation loss:2.014, Validation accuracy:23.33%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:1.843, Epoch accuracy:27.72%, Validation loss:2.003, Validation accuracy:23.00%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:1.828, Epoch accuracy:27.63%, Validation loss:1.988, Validation accuracy:24.00%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:1.800, Epoch accuracy:29.82%, Validation loss:1.977, Validation accuracy:23.67%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:1.780, Epoch accuracy:30.61%, Validation loss:1.966, Validation accuracy:24.33%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:1.752, Epoch accuracy:32.37%, Validation loss:1.955, Validation accuracy:24.67%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:1.734, Epoch accuracy:33.07%, Validation loss:1.943, Validation accuracy:25.33%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:1.718, Epoch accuracy:34.30%, Validation loss:1.931, Validation accuracy:25.00%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:1.694, Epoch accuracy:36.40%, Validation loss:1.920, Validation accuracy:25.33%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:1.672, Epoch accuracy:35.96%, Validation loss:1.908, Validation accuracy:26.00%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:1.655, Epoch accuracy:38.77%, Validation loss:1.899, Validation accuracy:27.00%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:1.633, Epoch accuracy:41.67%, Validation loss:1.887, Validation accuracy:27.00%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:1.615, Epoch accuracy:41.32%, Validation loss:1.876, Validation accuracy:28.33%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:1.597, Epoch accuracy:43.33%, Validation loss:1.867, Validation accuracy:27.33%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:1.585, Epoch accuracy:44.39%, Validation loss:1.855, Validation accuracy:29.00%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:1.552, Epoch accuracy:46.05%, Validation loss:1.846, Validation accuracy:29.33%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:1.540, Epoch accuracy:46.32%, Validation loss:1.835, Validation accuracy:30.33%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:1.528, Epoch accuracy:48.60%, Validation loss:1.827, Validation accuracy:30.33%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:1.502, Epoch accuracy:49.04%, Validation loss:1.817, Validation accuracy:31.00%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:1.488, Epoch accuracy:50.53%, Validation loss:1.807, Validation accuracy:30.67%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:1.472, Epoch accuracy:52.02%, Validation loss:1.799, Validation accuracy:31.67%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:1.457, Epoch accuracy:52.46%, Validation loss:1.789, Validation accuracy:32.67%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:1.441, Epoch accuracy:53.51%, Validation loss:1.780, Validation accuracy:33.00%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:1.417, Epoch accuracy:55.35%, Validation loss:1.771, Validation accuracy:34.33%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:1.404, Epoch accuracy:55.70%, Validation loss:1.764, Validation accuracy:35.00%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:1.393, Epoch accuracy:56.93%, Validation loss:1.755, Validation accuracy:36.33%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:1.376, Epoch accuracy:57.72%, Validation loss:1.748, Validation accuracy:36.00%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:1.354, Epoch accuracy:59.30%, Validation loss:1.738, Validation accuracy:37.00%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:1.339, Epoch accuracy:59.65%, Validation loss:1.732, Validation accuracy:38.33%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:1.329, Epoch accuracy:60.88%, Validation loss:1.722, Validation accuracy:38.67%
# Epoch 37: iteration 16/17
# Epoch 37 --- loss:1.303, Epoch accuracy:63.25%, Validation loss:1.715, Validation accuracy:39.00%
# Epoch 38: iteration 16/17
# Epoch 38 --- loss:1.291, Epoch accuracy:64.56%, Validation loss:1.707, Validation accuracy:39.67%
# Epoch 39: iteration 16/17
# Epoch 39 --- loss:1.280, Epoch accuracy:64.82%, Validation loss:1.701, Validation accuracy:40.67%
# Epoch 40: iteration 16/17
# Epoch 40 --- loss:1.264, Epoch accuracy:64.91%, Validation loss:1.693, Validation accuracy:41.00%
# Epoch 41: iteration 16/17
# Epoch 41 --- loss:1.248, Epoch accuracy:66.32%, Validation loss:1.685, Validation accuracy:40.00%
# Epoch 42: iteration 16/17
# Epoch 42 --- loss:1.236, Epoch accuracy:67.19%, Validation loss:1.680, Validation accuracy:41.67%
# Epoch 43: iteration 16/17
# Epoch 43 --- loss:1.213, Epoch accuracy:68.33%, Validation loss:1.672, Validation accuracy:41.67%
# Epoch 44: iteration 16/17
# Epoch 44 --- loss:1.206, Epoch accuracy:68.51%, Validation loss:1.665, Validation accuracy:42.33%
# Epoch 45: iteration 16/17
# Epoch 45 --- loss:1.191, Epoch accuracy:69.74%, Validation loss:1.659, Validation accuracy:41.67%
# Epoch 46: iteration 16/17
# Epoch 46 --- loss:1.177, Epoch accuracy:69.82%, Validation loss:1.653, Validation accuracy:43.00%
# Epoch 47: iteration 16/17
# Epoch 47 --- loss:1.152, Epoch accuracy:71.40%, Validation loss:1.645, Validation accuracy:42.67%
# Epoch 48: iteration 16/17
# Epoch 48 --- loss:1.146, Epoch accuracy:71.32%, Validation loss:1.637, Validation accuracy:43.00%
# Epoch 49: iteration 16/17
# Epoch 49 --- loss:1.131, Epoch accuracy:71.75%, Validation loss:1.634, Validation accuracy:43.00%
# Epoch 50: iteration 16/17
# Epoch 50 --- loss:1.115, Epoch accuracy:73.77%, Validation loss:1.626, Validation accuracy:43.00%
# Epoch 51: iteration 16/17
# Epoch 51 --- loss:1.109, Epoch accuracy:73.95%, Validation loss:1.621, Validation accuracy:44.00%
# Epoch 52: iteration 16/17
# Epoch 52 --- loss:1.090, Epoch accuracy:75.09%, Validation loss:1.616, Validation accuracy:44.00%
# Epoch 53: iteration 16/17
# Epoch 53 --- loss:1.085, Epoch accuracy:73.77%, Validation loss:1.609, Validation accuracy:43.33%
# Epoch 54: iteration 16/17
# Epoch 54 --- loss:1.062, Epoch accuracy:76.67%, Validation loss:1.605, Validation accuracy:43.33%
# Epoch 55: iteration 16/17
# Epoch 55 --- loss:1.053, Epoch accuracy:76.93%, Validation loss:1.596, Validation accuracy:44.33%
# Epoch 56: iteration 16/17
# Epoch 56 --- loss:1.039, Epoch accuracy:78.25%, Validation loss:1.592, Validation accuracy:44.00%
# Epoch 57: iteration 16/17
# Epoch 57 --- loss:1.035, Epoch accuracy:77.54%, Validation loss:1.589, Validation accuracy:43.67%
# Epoch 58: iteration 16/17
# Epoch 58 --- loss:1.017, Epoch accuracy:78.16%, Validation loss:1.582, Validation accuracy:43.33%
# Epoch 59: iteration 16/17
# Epoch 59 --- loss:1.003, Epoch accuracy:79.21%, Validation loss:1.576, Validation accuracy:45.00%
# Epoch 60: iteration 16/17
# Epoch 60 --- loss:0.991, Epoch accuracy:79.91%, Validation loss:1.570, Validation accuracy:44.67%
# Epoch 61: iteration 16/17
# Epoch 61 --- loss:0.977, Epoch accuracy:80.88%, Validation loss:1.565, Validation accuracy:44.33%
# Epoch 62: iteration 16/17
# Epoch 62 --- loss:0.967, Epoch accuracy:80.09%, Validation loss:1.563, Validation accuracy:43.67%
# Epoch 63: iteration 16/17
# Epoch 63 --- loss:0.955, Epoch accuracy:81.23%, Validation loss:1.558, Validation accuracy:44.00%
# Epoch 64: iteration 16/17
# Epoch 64 --- loss:0.942, Epoch accuracy:80.79%, Validation loss:1.554, Validation accuracy:45.00%
# Epoch 65: iteration 16/17
# Epoch 65 --- loss:0.937, Epoch accuracy:81.49%, Validation loss:1.546, Validation accuracy:45.67%
# Epoch 66: iteration 16/17
# Epoch 66 --- loss:0.912, Epoch accuracy:83.25%, Validation loss:1.542, Validation accuracy:44.33%
# Epoch 67: iteration 16/17
# Epoch 67 --- loss:0.920, Epoch accuracy:82.81%, Validation loss:1.538, Validation accuracy:44.33%
# Epoch 68: iteration 16/17
# Epoch 68 --- loss:0.896, Epoch accuracy:83.60%, Validation loss:1.536, Validation accuracy:44.00%
# Epoch 69: iteration 16/17
# Epoch 69 --- loss:0.888, Epoch accuracy:83.86%, Validation loss:1.535, Validation accuracy:44.00%
# Epoch 70: iteration 16/17
# Epoch 70 --- loss:0.879, Epoch accuracy:84.04%, Validation loss:1.526, Validation accuracy:45.00%
# Epoch 71: iteration 16/17
# Epoch 71 --- loss:0.869, Epoch accuracy:84.21%, Validation loss:1.525, Validation accuracy:44.00%
# Epoch 72: iteration 16/17
# Epoch 72 --- loss:0.861, Epoch accuracy:84.74%, Validation loss:1.518, Validation accuracy:45.67%
# Epoch 73: iteration 16/17
# Epoch 73 --- loss:0.847, Epoch accuracy:85.35%, Validation loss:1.513, Validation accuracy:46.00%
# Epoch 74: iteration 16/17
# Epoch 74 --- loss:0.825, Epoch accuracy:86.32%, Validation loss:1.510, Validation accuracy:46.00%
# Epoch 75: iteration 16/17
# Epoch 75 --- loss:0.825, Epoch accuracy:86.14%, Validation loss:1.508, Validation accuracy:45.00%
# Epoch 76: iteration 16/17
# Epoch 76 --- loss:0.813, Epoch accuracy:86.58%, Validation loss:1.505, Validation accuracy:45.33%
# Epoch 77: iteration 16/17
# Epoch 77 --- loss:0.806, Epoch accuracy:86.84%, Validation loss:1.501, Validation accuracy:45.67%
# Epoch 78: iteration 16/17
# Epoch 78 --- loss:0.786, Epoch accuracy:87.28%, Validation loss:1.499, Validation accuracy:45.00%
# Epoch 79: iteration 16/17
# Epoch 79 --- loss:0.786, Epoch accuracy:87.37%, Validation loss:1.497, Validation accuracy:45.67%
# Epoch 80: iteration 16/17
# Epoch 80 --- loss:0.779, Epoch accuracy:87.72%, Validation loss:1.490, Validation accuracy:45.00%
# Epoch 81: iteration 16/17
# Epoch 81 --- loss:0.766, Epoch accuracy:87.11%, Validation loss:1.485, Validation accuracy:45.33%
# Epoch 82: iteration 16/17
# Epoch 82 --- loss:0.755, Epoch accuracy:88.42%, Validation loss:1.481, Validation accuracy:45.67%
# Epoch 83: iteration 16/17
# Epoch 83 --- loss:0.746, Epoch accuracy:88.51%, Validation loss:1.482, Validation accuracy:46.33%
# Epoch 84: iteration 16/17
# Epoch 84 --- loss:0.729, Epoch accuracy:89.39%, Validation loss:1.477, Validation accuracy:46.00%
# Epoch 85: iteration 16/17
# Epoch 85 --- loss:0.728, Epoch accuracy:88.95%, Validation loss:1.474, Validation accuracy:45.67%
# Epoch 86: iteration 16/17
# Epoch 86 --- loss:0.730, Epoch accuracy:88.60%, Validation loss:1.470, Validation accuracy:45.67%
# Epoch 87: iteration 16/17
# Epoch 87 --- loss:0.711, Epoch accuracy:89.56%, Validation loss:1.470, Validation accuracy:45.67%
# Epoch 88: iteration 16/17
# Epoch 88 --- loss:0.701, Epoch accuracy:89.65%, Validation loss:1.466, Validation accuracy:46.00%
# Epoch 89: iteration 16/17
# Epoch 89 --- loss:0.685, Epoch accuracy:89.91%, Validation loss:1.463, Validation accuracy:45.67%
# Epoch 90: iteration 16/17
# Epoch 90 --- loss:0.684, Epoch accuracy:90.61%, Validation loss:1.458, Validation accuracy:46.00%
# Epoch 91: iteration 16/17
# Epoch 91 --- loss:0.675, Epoch accuracy:90.88%, Validation loss:1.459, Validation accuracy:46.33%
# Epoch 92: iteration 16/17
# Epoch 92 --- loss:0.664, Epoch accuracy:91.32%, Validation loss:1.455, Validation accuracy:45.67%
# Epoch 93: iteration 16/17
# Epoch 93 --- loss:0.653, Epoch accuracy:90.70%, Validation loss:1.449, Validation accuracy:46.33%
# Epoch 94: iteration 16/17
# Epoch 94 --- loss:0.639, Epoch accuracy:91.93%, Validation loss:1.450, Validation accuracy:46.33%
# Epoch 95: iteration 16/17
# Epoch 95 --- loss:0.640, Epoch accuracy:91.32%, Validation loss:1.447, Validation accuracy:46.33%
# Epoch 96: iteration 16/17
# Epoch 96 --- loss:0.636, Epoch accuracy:91.93%, Validation loss:1.445, Validation accuracy:46.33%
# Epoch 97: iteration 16/17
# Epoch 97 --- loss:0.623, Epoch accuracy:91.40%, Validation loss:1.445, Validation accuracy:46.00%
# Epoch 98: iteration 16/17
# Epoch 98 --- loss:0.615, Epoch accuracy:91.84%, Validation loss:1.443, Validation accuracy:46.00%
# Epoch 99: iteration 16/17
# Epoch 99 --- loss:0.612, Epoch accuracy:92.37%, Validation loss:1.437, Validation accuracy:46.67%
# Epoch 100: iteration 16/17
# Epoch 100 --- loss:0.597, Epoch accuracy:91.84%, Validation loss:1.437, Validation accuracy:46.33%
# Epoch 101: iteration 16/17
# Epoch 101 --- loss:0.588, Epoch accuracy:92.11%, Validation loss:1.439, Validation accuracy:46.67%
# Epoch 102: iteration 16/17
# Epoch 102 --- loss:0.587, Epoch accuracy:92.63%, Validation loss:1.435, Validation accuracy:46.33%
# Epoch 103: iteration 16/17
# Epoch 103 --- loss:0.579, Epoch accuracy:92.11%, Validation loss:1.432, Validation accuracy:45.67%
# Epoch 104: iteration 16/17
# Epoch 104 --- loss:0.561, Epoch accuracy:92.19%, Validation loss:1.428, Validation accuracy:47.00%
# Epoch 105: iteration 16/17
# Epoch 105 --- loss:0.561, Epoch accuracy:92.37%, Validation loss:1.429, Validation accuracy:46.67%
# Epoch 106: iteration 16/17
# Epoch 106 --- loss:0.553, Epoch accuracy:93.16%, Validation loss:1.428, Validation accuracy:47.33%
# Epoch 107: iteration 16/17
# Epoch 107 --- loss:0.545, Epoch accuracy:93.07%, Validation loss:1.423, Validation accuracy:47.67%
# Epoch 108: iteration 16/17
# Epoch 108 --- loss:0.530, Epoch accuracy:93.42%, Validation loss:1.424, Validation accuracy:47.00%
# Epoch 109: iteration 16/17
# Epoch 109 --- loss:0.534, Epoch accuracy:93.51%, Validation loss:1.422, Validation accuracy:47.67%
# Epoch 110: iteration 16/17
# Epoch 110 --- loss:0.520, Epoch accuracy:93.16%, Validation loss:1.419, Validation accuracy:47.67%
# Epoch 111: iteration 16/17
# Epoch 111 --- loss:0.517, Epoch accuracy:93.51%, Validation loss:1.416, Validation accuracy:48.00%
# Epoch 112: iteration 16/17
# Epoch 112 --- loss:0.509, Epoch accuracy:93.68%, Validation loss:1.417, Validation accuracy:48.00%
# Epoch 113: iteration 16/17
# Epoch 113 --- loss:0.504, Epoch accuracy:93.86%, Validation loss:1.416, Validation accuracy:48.00%
# Epoch 114: iteration 16/17
# Epoch 114 --- loss:0.498, Epoch accuracy:94.04%, Validation loss:1.416, Validation accuracy:47.67%
# Epoch 115: iteration 16/17
# Epoch 115 --- loss:0.486, Epoch accuracy:93.77%, Validation loss:1.413, Validation accuracy:48.33%
# Epoch 116: iteration 16/17
# Epoch 116 --- loss:0.492, Epoch accuracy:94.04%, Validation loss:1.408, Validation accuracy:47.67%
# Epoch 117: iteration 16/17
# Epoch 117 --- loss:0.470, Epoch accuracy:94.30%, Validation loss:1.408, Validation accuracy:47.67%
# Epoch 118: iteration 16/17
# Epoch 118 --- loss:0.472, Epoch accuracy:94.04%, Validation loss:1.405, Validation accuracy:48.00%
# Epoch 119: iteration 16/17
# Epoch 119 --- loss:0.469, Epoch accuracy:94.30%, Validation loss:1.407, Validation accuracy:48.00%
# Epoch 120: iteration 16/17
# Epoch 120 --- loss:0.458, Epoch accuracy:94.30%, Validation loss:1.409, Validation accuracy:48.67%
# Epoch 121: iteration 16/17
# Epoch 121 --- loss:0.451, Epoch accuracy:94.39%, Validation loss:1.407, Validation accuracy:47.33%
# Epoch 122: iteration 16/17
# Epoch 122 --- loss:0.443, Epoch accuracy:94.47%, Validation loss:1.402, Validation accuracy:47.67%
# Epoch 123: iteration 16/17
# Epoch 123 --- loss:0.437, Epoch accuracy:94.30%, Validation loss:1.404, Validation accuracy:48.67%
# Epoch 124: iteration 16/17
# Epoch 124 --- loss:0.430, Epoch accuracy:94.74%, Validation loss:1.397, Validation accuracy:48.33%
# Epoch 125: iteration 16/17
# Epoch 125 --- loss:0.431, Epoch accuracy:94.30%, Validation loss:1.397, Validation accuracy:48.67%
# Epoch 126: iteration 16/17
# Epoch 126 --- loss:0.419, Epoch accuracy:94.39%, Validation loss:1.397, Validation accuracy:48.33%
# Epoch 127: iteration 16/17
# Epoch 127 --- loss:0.411, Epoch accuracy:94.91%, Validation loss:1.401, Validation accuracy:49.00%
# Epoch 128: iteration 16/17
# Epoch 128 --- loss:0.418, Epoch accuracy:94.47%, Validation loss:1.395, Validation accuracy:48.33%
# Epoch 129: iteration 16/17
# Epoch 129 --- loss:0.403, Epoch accuracy:94.65%, Validation loss:1.394, Validation accuracy:48.67%
# Epoch 130: iteration 16/17
# Epoch 130 --- loss:0.403, Epoch accuracy:94.65%, Validation loss:1.392, Validation accuracy:49.00%
# Epoch 131: iteration 16/17
# Epoch 131 --- loss:0.397, Epoch accuracy:94.47%, Validation loss:1.394, Validation accuracy:48.67%
# Epoch 132: iteration 16/17
# Epoch 132 --- loss:0.391, Epoch accuracy:94.91%, Validation loss:1.393, Validation accuracy:48.67%
# Epoch 133: iteration 16/17
# Epoch 133 --- loss:0.387, Epoch accuracy:94.91%, Validation loss:1.392, Validation accuracy:48.00%
# Epoch 134: iteration 16/17
# Epoch 134 --- loss:0.379, Epoch accuracy:94.56%, Validation loss:1.391, Validation accuracy:48.67%
# Epoch 135: iteration 16/17
# Epoch 135 --- loss:0.374, Epoch accuracy:94.91%, Validation loss:1.390, Validation accuracy:48.67%
# Epoch 136: iteration 16/17
# Epoch 136 --- loss:0.372, Epoch accuracy:95.09%, Validation loss:1.388, Validation accuracy:49.00%
# Epoch 137: iteration 16/17
# Epoch 137 --- loss:0.365, Epoch accuracy:95.00%, Validation loss:1.387, Validation accuracy:48.33%
# Epoch 138: iteration 16/17
# Epoch 138 --- loss:0.364, Epoch accuracy:94.82%, Validation loss:1.392, Validation accuracy:48.00%
# Epoch 139: iteration 16/17
# Epoch 139 --- loss:0.355, Epoch accuracy:95.00%, Validation loss:1.387, Validation accuracy:49.00%
# Epoch 140: iteration 16/17
# Epoch 140 --- loss:0.353, Epoch accuracy:95.00%, Validation loss:1.387, Validation accuracy:48.33%
# Epoch 141: iteration 16/17
# Epoch 141 --- loss:0.351, Epoch accuracy:95.09%, Validation loss:1.387, Validation accuracy:48.67%
# Epoch 142: iteration 16/17
# Epoch 142 --- loss:0.343, Epoch accuracy:95.09%, Validation loss:1.384, Validation accuracy:48.67%
# Epoch 143: iteration 16/17
# Epoch 143 --- loss:0.329, Epoch accuracy:95.18%, Validation loss:1.385, Validation accuracy:49.00%
# Epoch 144: iteration 16/17
# Epoch 144 --- loss:0.332, Epoch accuracy:95.18%, Validation loss:1.382, Validation accuracy:48.67%
# Epoch 145: iteration 16/17
# Epoch 145 --- loss:0.328, Epoch accuracy:95.35%, Validation loss:1.386, Validation accuracy:48.33%
# Epoch 146: iteration 16/17
# Epoch 146 --- loss:0.326, Epoch accuracy:94.91%, Validation loss:1.387, Validation accuracy:48.00%
# Epoch 147: iteration 16/17
# Epoch 147 --- loss:0.324, Epoch accuracy:95.09%, Validation loss:1.382, Validation accuracy:48.67%
# Epoch 148: iteration 16/17
# Epoch 148 --- loss:0.320, Epoch accuracy:95.09%, Validation loss:1.377, Validation accuracy:49.00%
# Epoch 149: iteration 16/17
# Epoch 149 --- loss:0.315, Epoch accuracy:95.18%, Validation loss:1.378, Validation accuracy:48.67%
#
#
# [*] done !
# [*] Best training loss - 0.3154893841659813
# [*] Best validation loss - 1.3773143291473389
# 1:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:0.575, Epoch accuracy:82.72%, Validation loss:0.263, Validation accuracy:100.00%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:0.570, Epoch accuracy:83.33%, Validation loss:0.265, Validation accuracy:100.00%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:0.559, Epoch accuracy:82.89%, Validation loss:0.265, Validation accuracy:100.00%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:0.553, Epoch accuracy:84.21%, Validation loss:0.265, Validation accuracy:100.00%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:0.535, Epoch accuracy:84.56%, Validation loss:0.265, Validation accuracy:100.00%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:0.524, Epoch accuracy:84.91%, Validation loss:0.266, Validation accuracy:100.00%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:0.515, Epoch accuracy:85.79%, Validation loss:0.265, Validation accuracy:100.00%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:0.499, Epoch accuracy:86.58%, Validation loss:0.265, Validation accuracy:100.00%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:0.492, Epoch accuracy:86.93%, Validation loss:0.266, Validation accuracy:100.00%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:0.489, Epoch accuracy:86.84%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:0.479, Epoch accuracy:87.37%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:0.463, Epoch accuracy:88.33%, Validation loss:0.267, Validation accuracy:100.00%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:0.454, Epoch accuracy:88.60%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:0.449, Epoch accuracy:87.89%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:0.444, Epoch accuracy:87.98%, Validation loss:0.270, Validation accuracy:100.00%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:0.430, Epoch accuracy:88.95%, Validation loss:0.269, Validation accuracy:100.00%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:0.426, Epoch accuracy:88.33%, Validation loss:0.269, Validation accuracy:100.00%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:0.417, Epoch accuracy:88.77%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:0.417, Epoch accuracy:90.18%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:0.410, Epoch accuracy:89.47%, Validation loss:0.267, Validation accuracy:100.00%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:0.394, Epoch accuracy:89.91%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:0.385, Epoch accuracy:90.44%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:0.387, Epoch accuracy:90.00%, Validation loss:0.266, Validation accuracy:100.00%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:0.381, Epoch accuracy:90.79%, Validation loss:0.268, Validation accuracy:100.00%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:0.367, Epoch accuracy:91.40%, Validation loss:0.267, Validation accuracy:100.00%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:0.369, Epoch accuracy:90.70%, Validation loss:0.268, Validation accuracy:99.67%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:0.365, Epoch accuracy:91.14%, Validation loss:0.269, Validation accuracy:99.33%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:0.354, Epoch accuracy:91.14%, Validation loss:0.267, Validation accuracy:99.67%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:0.346, Epoch accuracy:91.84%, Validation loss:0.267, Validation accuracy:99.67%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:0.346, Epoch accuracy:91.84%, Validation loss:0.269, Validation accuracy:99.33%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:0.338, Epoch accuracy:91.84%, Validation loss:0.269, Validation accuracy:99.33%
#
#
# [*] done !
# [*] Best training loss - 0.3381059663337574
# [*] Best validation loss - 0.26269230246543884
# 2:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:0.354, Epoch accuracy:92.37%, Validation loss:0.193, Validation accuracy:100.00%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:0.349, Epoch accuracy:92.02%, Validation loss:0.194, Validation accuracy:100.00%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:0.344, Epoch accuracy:92.11%, Validation loss:0.195, Validation accuracy:100.00%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:0.334, Epoch accuracy:92.37%, Validation loss:0.192, Validation accuracy:100.00%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:0.327, Epoch accuracy:92.89%, Validation loss:0.194, Validation accuracy:100.00%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:0.324, Epoch accuracy:92.89%, Validation loss:0.193, Validation accuracy:100.00%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:0.324, Epoch accuracy:92.37%, Validation loss:0.193, Validation accuracy:100.00%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:0.316, Epoch accuracy:92.81%, Validation loss:0.193, Validation accuracy:100.00%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:0.316, Epoch accuracy:92.63%, Validation loss:0.194, Validation accuracy:100.00%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:0.309, Epoch accuracy:92.98%, Validation loss:0.194, Validation accuracy:100.00%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:0.299, Epoch accuracy:93.25%, Validation loss:0.194, Validation accuracy:100.00%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:0.288, Epoch accuracy:93.51%, Validation loss:0.193, Validation accuracy:100.00%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:0.291, Epoch accuracy:93.60%, Validation loss:0.193, Validation accuracy:100.00%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:0.289, Epoch accuracy:93.68%, Validation loss:0.193, Validation accuracy:100.00%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:0.278, Epoch accuracy:93.95%, Validation loss:0.192, Validation accuracy:100.00%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:0.277, Epoch accuracy:94.47%, Validation loss:0.191, Validation accuracy:100.00%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:0.276, Epoch accuracy:94.21%, Validation loss:0.192, Validation accuracy:100.00%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:0.264, Epoch accuracy:94.04%, Validation loss:0.191, Validation accuracy:100.00%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:0.266, Epoch accuracy:94.04%, Validation loss:0.192, Validation accuracy:100.00%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:0.264, Epoch accuracy:94.21%, Validation loss:0.191, Validation accuracy:100.00%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:0.259, Epoch accuracy:94.21%, Validation loss:0.191, Validation accuracy:100.00%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:0.261, Epoch accuracy:94.30%, Validation loss:0.190, Validation accuracy:100.00%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:0.254, Epoch accuracy:94.39%, Validation loss:0.192, Validation accuracy:100.00%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:0.250, Epoch accuracy:94.21%, Validation loss:0.192, Validation accuracy:100.00%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:0.239, Epoch accuracy:94.82%, Validation loss:0.191, Validation accuracy:100.00%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:0.238, Epoch accuracy:94.74%, Validation loss:0.190, Validation accuracy:100.00%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:0.239, Epoch accuracy:94.82%, Validation loss:0.190, Validation accuracy:100.00%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:0.232, Epoch accuracy:94.74%, Validation loss:0.190, Validation accuracy:100.00%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:0.232, Epoch accuracy:94.74%, Validation loss:0.192, Validation accuracy:100.00%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:0.224, Epoch accuracy:94.74%, Validation loss:0.191, Validation accuracy:100.00%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:0.218, Epoch accuracy:95.00%, Validation loss:0.189, Validation accuracy:100.00%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:0.217, Epoch accuracy:95.00%, Validation loss:0.190, Validation accuracy:100.00%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:0.219, Epoch accuracy:95.09%, Validation loss:0.188, Validation accuracy:100.00%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:0.211, Epoch accuracy:95.00%, Validation loss:0.189, Validation accuracy:100.00%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:0.210, Epoch accuracy:95.00%, Validation loss:0.189, Validation accuracy:100.00%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:0.207, Epoch accuracy:94.91%, Validation loss:0.189, Validation accuracy:100.00%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:0.207, Epoch accuracy:95.18%, Validation loss:0.189, Validation accuracy:100.00%
# Epoch 37: iteration 16/17
# Epoch 37 --- loss:0.203, Epoch accuracy:95.26%, Validation loss:0.189, Validation accuracy:100.00%
# Epoch 38: iteration 16/17
# Epoch 38 --- loss:0.198, Epoch accuracy:95.26%, Validation loss:0.187, Validation accuracy:100.00%
# Epoch 39: iteration 16/17
# Epoch 39 --- loss:0.195, Epoch accuracy:95.35%, Validation loss:0.189, Validation accuracy:100.00%
#
#
# [*] done !
# [*] Best training loss - 0.1951989441587214
# [*] Best validation loss - 0.18705786764621735
# 3:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 16/17
# Epoch 0 --- loss:0.220, Epoch accuracy:95.18%, Validation loss:0.130, Validation accuracy:100.00%
# Epoch 1: iteration 16/17
# Epoch 1 --- loss:0.221, Epoch accuracy:94.91%, Validation loss:0.132, Validation accuracy:100.00%
# Epoch 2: iteration 16/17
# Epoch 2 --- loss:0.207, Epoch accuracy:95.18%, Validation loss:0.133, Validation accuracy:100.00%
# Epoch 3: iteration 16/17
# Epoch 3 --- loss:0.205, Epoch accuracy:95.26%, Validation loss:0.132, Validation accuracy:100.00%
# Epoch 4: iteration 16/17
# Epoch 4 --- loss:0.203, Epoch accuracy:95.26%, Validation loss:0.131, Validation accuracy:100.00%
# Epoch 5: iteration 16/17
# Epoch 5 --- loss:0.204, Epoch accuracy:95.35%, Validation loss:0.130, Validation accuracy:100.00%
# Epoch 6: iteration 16/17
# Epoch 6 --- loss:0.194, Epoch accuracy:95.44%, Validation loss:0.130, Validation accuracy:100.00%
# Epoch 7: iteration 16/17
# Epoch 7 --- loss:0.198, Epoch accuracy:95.35%, Validation loss:0.129, Validation accuracy:100.00%
# Epoch 8: iteration 16/17
# Epoch 8 --- loss:0.189, Epoch accuracy:95.44%, Validation loss:0.129, Validation accuracy:100.00%
# Epoch 9: iteration 16/17
# Epoch 9 --- loss:0.186, Epoch accuracy:95.44%, Validation loss:0.130, Validation accuracy:100.00%
# Epoch 10: iteration 16/17
# Epoch 10 --- loss:0.180, Epoch accuracy:95.26%, Validation loss:0.130, Validation accuracy:100.00%
# Epoch 11: iteration 16/17
# Epoch 11 --- loss:0.182, Epoch accuracy:95.44%, Validation loss:0.128, Validation accuracy:100.00%
# Epoch 12: iteration 16/17
# Epoch 12 --- loss:0.182, Epoch accuracy:95.44%, Validation loss:0.129, Validation accuracy:100.00%
# Epoch 13: iteration 16/17
# Epoch 13 --- loss:0.181, Epoch accuracy:95.35%, Validation loss:0.127, Validation accuracy:100.00%
# Epoch 14: iteration 16/17
# Epoch 14 --- loss:0.176, Epoch accuracy:95.44%, Validation loss:0.128, Validation accuracy:100.00%
# Epoch 15: iteration 16/17
# Epoch 15 --- loss:0.178, Epoch accuracy:95.35%, Validation loss:0.128, Validation accuracy:100.00%
# Epoch 16: iteration 16/17
# Epoch 16 --- loss:0.175, Epoch accuracy:95.44%, Validation loss:0.128, Validation accuracy:100.00%
# Epoch 17: iteration 16/17
# Epoch 17 --- loss:0.169, Epoch accuracy:95.26%, Validation loss:0.127, Validation accuracy:100.00%
# Epoch 18: iteration 16/17
# Epoch 18 --- loss:0.168, Epoch accuracy:95.35%, Validation loss:0.128, Validation accuracy:100.00%
# Epoch 19: iteration 16/17
# Epoch 19 --- loss:0.167, Epoch accuracy:95.44%, Validation loss:0.127, Validation accuracy:100.00%
# Epoch 20: iteration 16/17
# Epoch 20 --- loss:0.165, Epoch accuracy:95.35%, Validation loss:0.127, Validation accuracy:100.00%
# Epoch 21: iteration 16/17
# Epoch 21 --- loss:0.166, Epoch accuracy:95.44%, Validation loss:0.128, Validation accuracy:100.00%
# Epoch 22: iteration 16/17
# Epoch 22 --- loss:0.159, Epoch accuracy:95.44%, Validation loss:0.127, Validation accuracy:100.00%
# Epoch 23: iteration 16/17
# Epoch 23 --- loss:0.159, Epoch accuracy:95.44%, Validation loss:0.127, Validation accuracy:100.00%
# Epoch 24: iteration 16/17
# Epoch 24 --- loss:0.164, Epoch accuracy:95.44%, Validation loss:0.128, Validation accuracy:100.00%
# Epoch 25: iteration 16/17
# Epoch 25 --- loss:0.158, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 26: iteration 16/17
# Epoch 26 --- loss:0.151, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 27: iteration 16/17
# Epoch 27 --- loss:0.151, Epoch accuracy:95.44%, Validation loss:0.127, Validation accuracy:100.00%
# Epoch 28: iteration 16/17
# Epoch 28 --- loss:0.148, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 29: iteration 16/17
# Epoch 29 --- loss:0.150, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 30: iteration 16/17
# Epoch 30 --- loss:0.143, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 31: iteration 16/17
# Epoch 31 --- loss:0.145, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 32: iteration 16/17
# Epoch 32 --- loss:0.140, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
# Epoch 33: iteration 16/17
# Epoch 33 --- loss:0.141, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
# Epoch 34: iteration 16/17
# Epoch 34 --- loss:0.140, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
# Epoch 35: iteration 16/17
# Epoch 35 --- loss:0.135, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 36: iteration 16/17
# Epoch 36 --- loss:0.136, Epoch accuracy:95.44%, Validation loss:0.126, Validation accuracy:100.00%
# Epoch 37: iteration 16/17
# Epoch 37 --- loss:0.129, Epoch accuracy:95.44%, Validation loss:0.124, Validation accuracy:100.00%
# Epoch 38: iteration 16/17
# Epoch 38 --- loss:0.138, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
# Epoch 39: iteration 16/17
# Epoch 39 --- loss:0.132, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
# Epoch 40: iteration 16/17
# Epoch 40 --- loss:0.138, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
# Epoch 41: iteration 16/17
# Epoch 41 --- loss:0.127, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
# Epoch 42: iteration 16/17
# Epoch 42 --- loss:0.131, Epoch accuracy:95.44%, Validation loss:0.124, Validation accuracy:99.67%
# Epoch 43: iteration 16/17
# Epoch 43 --- loss:0.130, Epoch accuracy:95.44%, Validation loss:0.124, Validation accuracy:100.00%
# Epoch 44: iteration 16/17
# Epoch 44 --- loss:0.125, Epoch accuracy:95.44%, Validation loss:0.125, Validation accuracy:100.00%
#
#
# [*] done !
# [*] Best training loss - 0.1253253648155614
# [*] Best validation loss - 0.12390618771314621
# 4:   0%|          | 0/150 [00:00<?, ?it/s]
# Epoch 0: iteration 17/18
# Epoch 0 --- loss:0.138, Epoch accuracy:95.92%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 1: iteration 17/18
# Epoch 1 --- loss:0.130, Epoch accuracy:96.00%, Validation loss:0.095, Validation accuracy:100.00%
# Epoch 2: iteration 17/18
# Epoch 2 --- loss:0.130, Epoch accuracy:95.83%, Validation loss:0.094, Validation accuracy:100.00%
# Epoch 3: iteration 17/18
# Epoch 3 --- loss:0.129, Epoch accuracy:95.92%, Validation loss:0.093, Validation accuracy:100.00%
# Epoch 4: iteration 17/18
# Epoch 4 --- loss:0.126, Epoch accuracy:95.92%, Validation loss:0.093, Validation accuracy:100.00%
# Epoch 5: iteration 17/18
# Epoch 5 --- loss:0.123, Epoch accuracy:96.00%, Validation loss:0.093, Validation accuracy:100.00%
# Epoch 6: iteration 17/18
# Epoch 6 --- loss:0.122, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 7: iteration 17/18
# Epoch 7 --- loss:0.119, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 8: iteration 17/18
# Epoch 8 --- loss:0.119, Epoch accuracy:95.92%, Validation loss:0.093, Validation accuracy:100.00%
# Epoch 9: iteration 17/18
# Epoch 9 --- loss:0.118, Epoch accuracy:96.00%, Validation loss:0.093, Validation accuracy:100.00%
# Epoch 10: iteration 17/18
# Epoch 10 --- loss:0.119, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 11: iteration 17/18
# Epoch 11 --- loss:0.115, Epoch accuracy:96.00%, Validation loss:0.093, Validation accuracy:100.00%
# Epoch 12: iteration 17/18
# Epoch 12 --- loss:0.113, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 13: iteration 17/18
# Epoch 13 --- loss:0.113, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 14: iteration 17/18
# Epoch 14 --- loss:0.111, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 15: iteration 17/18
# Epoch 15 --- loss:0.112, Epoch accuracy:96.00%, Validation loss:0.093, Validation accuracy:100.00%
# Epoch 16: iteration 17/18
# Epoch 16 --- loss:0.112, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 17: iteration 17/18
# Epoch 17 --- loss:0.111, Epoch accuracy:95.92%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 18: iteration 17/18
# Epoch 18 --- loss:0.110, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 19: iteration 17/18
# Epoch 19 --- loss:0.109, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 20: iteration 17/18
# Epoch 20 --- loss:0.105, Epoch accuracy:95.92%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 21: iteration 17/18
# Epoch 21 --- loss:0.104, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 22: iteration 17/18
# Epoch 22 --- loss:0.103, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 23: iteration 17/18
# Epoch 23 --- loss:0.103, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 24: iteration 17/18
# Epoch 24 --- loss:0.104, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 25: iteration 17/18
# Epoch 25 --- loss:0.103, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 26: iteration 17/18
# Epoch 26 --- loss:0.101, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 27: iteration 17/18
# Epoch 27 --- loss:0.096, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 28: iteration 17/18
# Epoch 28 --- loss:0.100, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 29: iteration 17/18
# Epoch 29 --- loss:0.099, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 30: iteration 17/18
# Epoch 30 --- loss:0.099, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 31: iteration 17/18
# Epoch 31 --- loss:0.096, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 32: iteration 17/18
# Epoch 32 --- loss:0.095, Epoch accuracy:96.00%, Validation loss:0.090, Validation accuracy:100.00%
# Epoch 33: iteration 17/18
# Epoch 33 --- loss:0.093, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 34: iteration 17/18
# Epoch 34 --- loss:0.093, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 35: iteration 17/18
# Epoch 35 --- loss:0.090, Epoch accuracy:96.00%, Validation loss:0.092, Validation accuracy:100.00%
# Epoch 36: iteration 17/18
# Epoch 36 --- loss:0.088, Epoch accuracy:96.00%, Validation loss:0.091, Validation accuracy:100.00%
# Epoch 37: iteration 17/18
# Epoch 37 --- loss:0.088, Epoch accuracy:96.00%, Validation loss:0.090, Validation accuracy:100.00%
# Epoch 38: iteration 17/18
# Epoch 38 --- loss:0.090, Epoch accuracy:96.00%, Validation loss:0.090, Validation accuracy:100.00%
# Epoch 39: iteration 17/18
# Epoch 39 --- loss:0.086, Epoch accuracy:96.00%, Validation loss:0.090, Validation accuracy:100.00%
#
#
# [*] done !
# [*] Best training loss - 0.08563810269037882
# [*] Best validation loss - 0.08990320563316345

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    # build confusion matrix and normalized confusion matrix
    conf_matrix = confusion_matrix(emotions_groundtruth, predicted_emotions)
    conf_matrix_norm = confusion_matrix(emotions_groundtruth, predicted_emotions,normalize='true')

    # set labels for matrix axes from emotions
    emotion_names = [emotion for emotion in emotions_dict.values()]

    # make a confusion matrix with labels using a DataFrame
    confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
    confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

    # plot confusion matrices
    plt.figure(figsize=(16,6))
    sn.set(font_scale=1.8) # emotion label and title size
    plt.subplot(1,2,1)
    plt.title('Confusion Matrix')
    sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 18}) #annot_kws is value font
    plt.subplot(1,2,2)
    plt.title('Normalized Confusion Matrix')
    sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font

    plt.show()
# Out:
# [*] 0 Test accuracy is 49.00%
# [*] 1 Test accuracy is 100.00%
# [*] 2 Test accuracy is 100.00%
# [*] 3 Test accuracy is 99.67%
# [*] 4 Test accuracy is 100.00%

# %%
def Average(lst):
    return sum(lst) / len(lst)

print('[*] K-Fold training done !')
print(f'[*] Best fold acc : {max(test_accs):.2f}%')
print(f'[*] Worst fold acc : {min(test_accs):.2f}%')
print(f'[*] Average fold acc : {Average(test_accs):.2f}%')
# Out:
# [*] K-Fold training done !
# [*] Best fold acc : 100.00%
# [*] Worst fold acc : 49.00%
# [*] Average fold acc : 89.73%

# %%
from sklearn.metrics import classification_report

device = torch.device('cpu')
model = model.to(device)

test_accs = []

for fold in range(5):
    pkl_name = f'./model/{data_name}-{sub_name}-{fold}.pkl'
    
    load_checkpoint(optimizer, model, pkl_name)
    
    validate = make_validate_fnc(model, criterion)
    
    cur = all_fold_dataset[fold]
    
    X_test_tensor = torch.tensor(cur[2]).float()
    X_test_tensor = X_test_tensor.permute(0, 3, 1, 2)
    y_test_tensor = torch.tensor(cur[3], dtype=torch.long)
    
    test_loss, test_acc, predicted_emotions = validate(X_test_tensor, y_test_tensor)
    print(f'[*] {fold} Test accuracy is {test_acc:.2f}%')
    test_accs.append(test_acc)
    
    predicted_emotions = predicted_emotions.cpu().numpy()
    # use labels from test set
    emotions_groundtruth = y_test_tensor

    print(classification_report(emotions_groundtruth, predicted_emotions))
# Out:
# [*] 0 Test accuracy is 49.00%
#               precision    recall  f1-score   support
#
#            0       0.25      0.15      0.19        20
#            1       0.62      0.53      0.57        40
#            2       0.57      0.20      0.30        40
#            3       0.24      0.23      0.23        40
#            4       0.43      0.82      0.56        40
#            5       0.66      0.68      0.67        40
#            6       0.48      0.50      0.49        40
#            7       0.62      0.65      0.63        40
#
#     accuracy                           0.49       300
#    macro avg       0.48      0.47      0.45       300
# weighted avg       0.50      0.49      0.47       300
#
# [*] 1 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 2 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       1.00      1.00      1.00        40
#            4       1.00      1.00      1.00        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 3 Test accuracy is 99.67%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        40
#            2       1.00      1.00      1.00        40
#            3       0.98      1.00      0.99        40
#            4       1.00      0.97      0.99        40
#            5       1.00      1.00      1.00        40
#            6       1.00      1.00      1.00        40
#            7       1.00      1.00      1.00        40
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300
#
# [*] 4 Test accuracy is 100.00%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        32
#            2       1.00      1.00      1.00        32
#            3       1.00      1.00      1.00        32
#            4       1.00      1.00      1.00        32
#            5       1.00      1.00      1.00        32
#            6       1.00      1.00      1.00        32
#            7       1.00      1.00      1.00        32
#
#     accuracy                           1.00       240
#    macro avg       1.00      1.00      1.00       240
# weighted avg       1.00      1.00      1.00       240
