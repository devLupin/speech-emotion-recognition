# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation, SpatialDropout2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'SAVEE'
CLASS_LABELS = Config.SAVEE_LABELS
k = 10

model_name = 'CTL_MTNet-forwardAndBackward-add_pyramid'
feature_name = 'mfcc'

learning_rate=0.001
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    self.conv = Sequential([
        Conv2D(filters=dim_capsule*n_channels, kernel_size=kernel_size, strides=strides, padding=padding, name='primarycap_conv2d'),
        Reshape(target_shape=[-1, dim_capsule], name='primarycap_reshape'),
        Lambda(function=PrimaryCapssquash, name='primarycap_squash')
    ])
    
  def call(self, inputs):
    x = self.conv(inputs)
    return x

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class CTL_MTNet(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.5),
      
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.25),
      
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.5)
    ])
    
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.5),
      
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.25),
      
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      SpatialDropout2D(0.5)
    ])
    
    self.primarycap = PrimaryCap()
    self.attention = Attention(use_scale=True)
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    
    
  def call(self, inputs):
    # (batch, 196, 39, 1)
    forward = inputs
    backward =tf.reverse(inputs, axis=[1])
    
    # (batch, 22, 3, 64)
    x1 = self.conv1(forward)
    x2 = self.conv2(backward)
    
    cap = x1 + x2
    
    # (batch, 120, 64)
    primarycaps = self.primarycap(cap)
    
    cap = primarycaps
    sa = self.attention([primarycaps, primarycaps, primarycaps])  # (batch, 120, 64)
    cap = self.lamb([cap, sa])  # (batch, 120, 64)
    
    capsule = self.capsule(cap)   # (batch, 6, 64)
    gap = self.gap(capsule)   # (batch, 64)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

x = np.expand_dims(x, axis=-1)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)
for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    now_time = datetime.now().strftime("%m-%d-%H%M%S")
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{feature_name}_{i}-fold_{now_time}.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = CTL_MTNet(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = CTL_MTNet(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    best_pred = model(x_test, training=False)
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(y_test, axis=1))
    predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.611, acc:23.438, val_loss:0.601, val_acc:28.125
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.592, acc:25.446, val_loss:0.578, val_acc:29.688
# Best loss:0.601, Best accuracy:28.125, Best F1-score:0.124
# 3/300 lr=0.00100 - loss:0.574, acc:30.134, val_loss:0.562, val_acc:32.812
# Best loss:0.578, Best accuracy:29.688, Best F1-score:0.154
# 4/300 lr=0.00100 - loss:0.556, acc:34.598, val_loss:0.546, val_acc:32.812
# Best loss:0.562, Best accuracy:32.812, Best F1-score:0.187
# 5/300 lr=0.00100 - loss:0.543, acc:36.161, val_loss:0.533, val_acc:34.375
# Best loss:0.562, Best accuracy:32.812, Best F1-score:0.187
# 6/300 lr=0.00100 - loss:0.525, acc:43.527, val_loss:0.525, val_acc:34.375
# Best loss:0.533, Best accuracy:34.375, Best F1-score:0.226
# 7/300 lr=0.00100 - loss:0.517, acc:40.848, val_loss:0.515, val_acc:35.938
# Best loss:0.533, Best accuracy:34.375, Best F1-score:0.226
# 8/300 lr=0.00100 - loss:0.505, acc:44.420, val_loss:0.526, val_acc:40.625
# Best loss:0.515, Best accuracy:35.938, Best F1-score:0.254
# 9/300 lr=0.00100 - loss:0.503, acc:43.527, val_loss:0.511, val_acc:48.438
# Best loss:0.526, Best accuracy:40.625, Best F1-score:0.343
# 10/300 lr=0.00100 - loss:0.492, acc:45.982, val_loss:0.514, val_acc:45.312
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 11/300 lr=0.00100 - loss:0.491, acc:44.420, val_loss:0.506, val_acc:48.438
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 12/300 lr=0.00100 - loss:0.487, acc:46.429, val_loss:0.504, val_acc:46.875
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 13/300 lr=0.00100 - loss:0.476, acc:47.321, val_loss:0.508, val_acc:45.312
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 14/300 lr=0.00100 - loss:0.478, acc:45.759, val_loss:0.489, val_acc:46.875
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 15/300 lr=0.00100 - loss:0.470, acc:46.875, val_loss:0.505, val_acc:43.750
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 16/300 lr=0.00100 - loss:0.464, acc:48.438, val_loss:0.491, val_acc:46.875
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 17/300 lr=0.00100 - loss:0.460, acc:50.670, val_loss:0.483, val_acc:48.438
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 18/300 lr=0.00100 - loss:0.467, acc:50.446, val_loss:0.503, val_acc:48.438
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 19/300 lr=0.00100 - loss:0.455, acc:52.232, val_loss:0.472, val_acc:48.438
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 20/300 lr=0.00100 - loss:0.449, acc:49.777, val_loss:0.473, val_acc:48.438
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 21/300 lr=0.00100 - loss:0.439, acc:55.804, val_loss:0.476, val_acc:45.312
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 22/300 lr=0.00100 - loss:0.446, acc:51.116, val_loss:0.471, val_acc:48.438
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 23/300 lr=0.00100 - loss:0.437, acc:52.232, val_loss:0.491, val_acc:42.188
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 24/300 lr=0.00100 - loss:0.436, acc:53.795, val_loss:0.472, val_acc:46.875
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 25/300 lr=0.00100 - loss:0.433, acc:53.795, val_loss:0.476, val_acc:50.000
# Best loss:0.511, Best accuracy:48.438, Best F1-score:0.390
# 26/300 lr=0.00100 - loss:0.427, acc:55.580, val_loss:0.491, val_acc:40.625
# Best loss:0.476, Best accuracy:50.000, Best F1-score:0.431
# 27/300 lr=0.00100 - loss:0.423, acc:53.348, val_loss:0.470, val_acc:53.125
# Best loss:0.476, Best accuracy:50.000, Best F1-score:0.431
# 28/300 lr=0.00100 - loss:0.425, acc:54.241, val_loss:0.480, val_acc:42.188
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 29/300 lr=0.00100 - loss:0.431, acc:53.571, val_loss:0.500, val_acc:31.250
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 30/300 lr=0.00100 - loss:0.426, acc:52.679, val_loss:0.474, val_acc:48.438
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 31/300 lr=0.00100 - loss:0.421, acc:54.911, val_loss:0.482, val_acc:45.312
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 32/300 lr=0.00100 - loss:0.413, acc:56.696, val_loss:0.469, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 33/300 lr=0.00100 - loss:0.408, acc:56.920, val_loss:0.472, val_acc:45.312
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 34/300 lr=0.00100 - loss:0.405, acc:56.920, val_loss:0.467, val_acc:43.750
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 35/300 lr=0.00100 - loss:0.398, acc:58.036, val_loss:0.464, val_acc:50.000
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 36/300 lr=0.00100 - loss:0.399, acc:56.250, val_loss:0.473, val_acc:45.312
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 37/300 lr=0.00100 - loss:0.396, acc:58.259, val_loss:0.475, val_acc:42.188
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 38/300 lr=0.00100 - loss:0.391, acc:60.268, val_loss:0.476, val_acc:40.625
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 39/300 lr=0.00100 - loss:0.387, acc:60.491, val_loss:0.471, val_acc:45.312
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 40/300 lr=0.00100 - loss:0.379, acc:62.946, val_loss:0.481, val_acc:42.188
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 41/300 lr=0.00100 - loss:0.379, acc:62.277, val_loss:0.465, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 42/300 lr=0.00100 - loss:0.389, acc:60.938, val_loss:0.468, val_acc:43.750
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 43/300 lr=0.00100 - loss:0.379, acc:58.705, val_loss:0.471, val_acc:39.062
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 44/300 lr=0.00100 - loss:0.380, acc:62.054, val_loss:0.460, val_acc:48.438
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 45/300 lr=0.00100 - loss:0.365, acc:63.839, val_loss:0.464, val_acc:39.062
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 46/300 lr=0.00100 - loss:0.372, acc:63.170, val_loss:0.472, val_acc:39.062
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 47/300 lr=0.00100 - loss:0.367, acc:64.286, val_loss:0.456, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 48/300 lr=0.00100 - loss:0.372, acc:60.938, val_loss:0.471, val_acc:40.625
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 49/300 lr=0.00100 - loss:0.369, acc:62.277, val_loss:0.478, val_acc:34.375
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 50/300 lr=0.00100 - loss:0.369, acc:60.938, val_loss:0.463, val_acc:45.312
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 51/300 lr=0.00100 - loss:0.361, acc:62.500, val_loss:0.464, val_acc:42.188
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 52/300 lr=0.00100 - loss:0.357, acc:64.062, val_loss:0.473, val_acc:39.062
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 53/300 lr=0.00100 - loss:0.364, acc:62.723, val_loss:0.467, val_acc:39.062
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 54/300 lr=0.00100 - loss:0.358, acc:63.839, val_loss:0.460, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 55/300 lr=0.00100 - loss:0.360, acc:62.500, val_loss:0.458, val_acc:42.188
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 56/300 lr=0.00100 - loss:0.363, acc:61.384, val_loss:0.447, val_acc:45.312
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 57/300 lr=0.00100 - loss:0.362, acc:63.170, val_loss:0.448, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 58/300 lr=0.00100 - loss:0.365, acc:61.607, val_loss:0.463, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 59/300 lr=0.00100 - loss:0.342, acc:69.643, val_loss:0.467, val_acc:39.062
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 60/300 lr=0.00100 - loss:0.346, acc:66.071, val_loss:0.453, val_acc:43.750
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 61/300 lr=0.00100 - loss:0.346, acc:64.955, val_loss:0.449, val_acc:50.000
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 62/300 lr=0.00086 - loss:0.342, acc:67.411, val_loss:0.465, val_acc:35.938
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 63/300 lr=0.00086 - loss:0.337, acc:68.750, val_loss:0.452, val_acc:35.938
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 64/300 lr=0.00086 - loss:0.346, acc:65.402, val_loss:0.445, val_acc:48.438
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 65/300 lr=0.00086 - loss:0.334, acc:67.634, val_loss:0.442, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 66/300 lr=0.00086 - loss:0.331, acc:69.866, val_loss:0.442, val_acc:43.750
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 67/300 lr=0.00086 - loss:0.336, acc:66.518, val_loss:0.436, val_acc:51.562
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 68/300 lr=0.00086 - loss:0.334, acc:68.080, val_loss:0.442, val_acc:39.062
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 69/300 lr=0.00086 - loss:0.324, acc:69.866, val_loss:0.437, val_acc:48.438
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 70/300 lr=0.00086 - loss:0.326, acc:69.643, val_loss:0.432, val_acc:53.125
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 71/300 lr=0.00086 - loss:0.329, acc:68.750, val_loss:0.443, val_acc:50.000
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 72/300 lr=0.00086 - loss:0.334, acc:67.634, val_loss:0.431, val_acc:51.562
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 73/300 lr=0.00086 - loss:0.326, acc:68.080, val_loss:0.431, val_acc:46.875
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 74/300 lr=0.00086 - loss:0.319, acc:68.304, val_loss:0.434, val_acc:50.000
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 75/300 lr=0.00086 - loss:0.319, acc:69.420, val_loss:0.446, val_acc:48.438
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 76/300 lr=0.00086 - loss:0.316, acc:70.089, val_loss:0.449, val_acc:45.312
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 77/300 lr=0.00086 - loss:0.310, acc:71.875, val_loss:0.424, val_acc:48.438
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 78/300 lr=0.00086 - loss:0.309, acc:70.759, val_loss:0.421, val_acc:51.562
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 79/300 lr=0.00086 - loss:0.314, acc:71.429, val_loss:0.423, val_acc:50.000
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 80/300 lr=0.00086 - loss:0.310, acc:71.652, val_loss:0.410, val_acc:54.688
# Best loss:0.470, Best accuracy:53.125, Best F1-score:0.475
# 81/300 lr=0.00086 - loss:0.316, acc:71.652, val_loss:0.425, val_acc:43.750
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 82/300 lr=0.00074 - loss:0.308, acc:71.429, val_loss:0.401, val_acc:54.688
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 83/300 lr=0.00074 - loss:0.300, acc:70.982, val_loss:0.437, val_acc:46.875
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 84/300 lr=0.00074 - loss:0.311, acc:72.098, val_loss:0.419, val_acc:54.688
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 85/300 lr=0.00074 - loss:0.300, acc:72.321, val_loss:0.405, val_acc:53.125
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 86/300 lr=0.00074 - loss:0.296, acc:76.562, val_loss:0.413, val_acc:43.750
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 87/300 lr=0.00074 - loss:0.300, acc:72.991, val_loss:0.423, val_acc:46.875
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 88/300 lr=0.00074 - loss:0.286, acc:76.562, val_loss:0.410, val_acc:53.125
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 89/300 lr=0.00074 - loss:0.303, acc:69.196, val_loss:0.422, val_acc:45.312
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 90/300 lr=0.00074 - loss:0.291, acc:75.670, val_loss:0.421, val_acc:48.438
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 91/300 lr=0.00074 - loss:0.297, acc:73.214, val_loss:0.419, val_acc:51.562
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 92/300 lr=0.00074 - loss:0.292, acc:76.786, val_loss:0.438, val_acc:48.438
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 93/300 lr=0.00074 - loss:0.298, acc:72.098, val_loss:0.400, val_acc:56.250
# Best loss:0.410, Best accuracy:54.688, Best F1-score:0.508
# 94/300 lr=0.00074 - loss:0.283, acc:76.786, val_loss:0.438, val_acc:40.625
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 95/300 lr=0.00074 - loss:0.281, acc:75.223, val_loss:0.404, val_acc:54.688
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 96/300 lr=0.00074 - loss:0.284, acc:73.884, val_loss:0.398, val_acc:46.875
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 97/300 lr=0.00074 - loss:0.289, acc:74.554, val_loss:0.400, val_acc:46.875
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 98/300 lr=0.00074 - loss:0.290, acc:73.884, val_loss:0.402, val_acc:50.000
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 99/300 lr=0.00074 - loss:0.271, acc:78.125, val_loss:0.420, val_acc:46.875
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 100/300 lr=0.00074 - loss:0.278, acc:76.339, val_loss:0.420, val_acc:45.312
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 101/300 lr=0.00074 - loss:0.267, acc:77.679, val_loss:0.400, val_acc:56.250
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 102/300 lr=0.00064 - loss:0.274, acc:76.339, val_loss:0.396, val_acc:53.125
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 103/300 lr=0.00064 - loss:0.269, acc:77.455, val_loss:0.398, val_acc:51.562
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 104/300 lr=0.00064 - loss:0.276, acc:76.562, val_loss:0.403, val_acc:50.000
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 105/300 lr=0.00064 - loss:0.270, acc:77.902, val_loss:0.431, val_acc:45.312
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 106/300 lr=0.00064 - loss:0.274, acc:75.670, val_loss:0.400, val_acc:53.125
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 107/300 lr=0.00064 - loss:0.260, acc:78.348, val_loss:0.392, val_acc:51.562
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 108/300 lr=0.00064 - loss:0.274, acc:75.223, val_loss:0.416, val_acc:51.562
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 109/300 lr=0.00064 - loss:0.270, acc:77.009, val_loss:0.402, val_acc:54.688
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 110/300 lr=0.00064 - loss:0.256, acc:78.795, val_loss:0.398, val_acc:50.000
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 111/300 lr=0.00064 - loss:0.265, acc:78.125, val_loss:0.401, val_acc:54.688
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 112/300 lr=0.00064 - loss:0.254, acc:80.134, val_loss:0.406, val_acc:53.125
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 113/300 lr=0.00064 - loss:0.256, acc:78.571, val_loss:0.407, val_acc:56.250
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 114/300 lr=0.00064 - loss:0.258, acc:79.464, val_loss:0.402, val_acc:51.562
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 115/300 lr=0.00064 - loss:0.254, acc:79.018, val_loss:0.392, val_acc:53.125
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 116/300 lr=0.00064 - loss:0.257, acc:81.027, val_loss:0.406, val_acc:54.688
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 117/300 lr=0.00064 - loss:0.244, acc:83.482, val_loss:0.421, val_acc:48.438
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 118/300 lr=0.00064 - loss:0.254, acc:77.455, val_loss:0.406, val_acc:56.250
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 119/300 lr=0.00064 - loss:0.261, acc:79.464, val_loss:0.416, val_acc:51.562
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 120/300 lr=0.00064 - loss:0.250, acc:82.812, val_loss:0.399, val_acc:53.125
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 121/300 lr=0.00064 - loss:0.254, acc:80.134, val_loss:0.442, val_acc:50.000
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 122/300 lr=0.00055 - loss:0.254, acc:79.464, val_loss:0.413, val_acc:51.562
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 123/300 lr=0.00055 - loss:0.259, acc:78.125, val_loss:0.384, val_acc:54.688
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 124/300 lr=0.00055 - loss:0.260, acc:77.902, val_loss:0.407, val_acc:51.562
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 125/300 lr=0.00055 - loss:0.255, acc:79.688, val_loss:0.411, val_acc:54.688
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 126/300 lr=0.00055 - loss:0.244, acc:79.688, val_loss:0.400, val_acc:57.812
# Best loss:0.400, Best accuracy:56.250, Best F1-score:0.526
# 127/300 lr=0.00055 - loss:0.248, acc:80.134, val_loss:0.425, val_acc:48.438
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 128/300 lr=0.00055 - loss:0.235, acc:81.920, val_loss:0.408, val_acc:51.562
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 129/300 lr=0.00055 - loss:0.237, acc:82.143, val_loss:0.388, val_acc:54.688
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 130/300 lr=0.00055 - loss:0.220, acc:85.491, val_loss:0.386, val_acc:54.688
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 131/300 lr=0.00055 - loss:0.242, acc:81.250, val_loss:0.404, val_acc:50.000
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 132/300 lr=0.00055 - loss:0.231, acc:83.259, val_loss:0.389, val_acc:53.125
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 133/300 lr=0.00055 - loss:0.234, acc:83.259, val_loss:0.394, val_acc:51.562
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 134/300 lr=0.00055 - loss:0.230, acc:83.482, val_loss:0.402, val_acc:50.000
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 135/300 lr=0.00055 - loss:0.233, acc:82.589, val_loss:0.380, val_acc:54.688
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 136/300 lr=0.00055 - loss:0.233, acc:80.357, val_loss:0.390, val_acc:54.688
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 137/300 lr=0.00055 - loss:0.233, acc:82.589, val_loss:0.407, val_acc:51.562
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 138/300 lr=0.00055 - loss:0.229, acc:83.482, val_loss:0.391, val_acc:53.125
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 139/300 lr=0.00055 - loss:0.237, acc:79.018, val_loss:0.386, val_acc:54.688
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 140/300 lr=0.00055 - loss:0.239, acc:81.250, val_loss:0.398, val_acc:51.562
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 141/300 lr=0.00055 - loss:0.222, acc:83.929, val_loss:0.394, val_acc:57.812
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 142/300 lr=0.00047 - loss:0.224, acc:84.598, val_loss:0.389, val_acc:57.812
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 143/300 lr=0.00047 - loss:0.220, acc:83.259, val_loss:0.400, val_acc:53.125
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 144/300 lr=0.00047 - loss:0.224, acc:83.482, val_loss:0.412, val_acc:50.000
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 145/300 lr=0.00047 - loss:0.222, acc:86.161, val_loss:0.397, val_acc:50.000
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 146/300 lr=0.00047 - loss:0.233, acc:82.143, val_loss:0.396, val_acc:51.562
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 147/300 lr=0.00047 - loss:0.232, acc:79.688, val_loss:0.385, val_acc:54.688
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 148/300 lr=0.00047 - loss:0.221, acc:83.036, val_loss:0.369, val_acc:57.812
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 149/300 lr=0.00047 - loss:0.227, acc:81.920, val_loss:0.402, val_acc:53.125
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 150/300 lr=0.00047 - loss:0.217, acc:85.268, val_loss:0.402, val_acc:53.125
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 151/300 lr=0.00047 - loss:0.228, acc:82.589, val_loss:0.359, val_acc:64.062
# Best loss:0.400, Best accuracy:57.812, Best F1-score:0.563
# 152/300 lr=0.00047 - loss:0.222, acc:83.482, val_loss:0.374, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 153/300 lr=0.00047 - loss:0.213, acc:84.598, val_loss:0.388, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 154/300 lr=0.00047 - loss:0.209, acc:87.054, val_loss:0.379, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 155/300 lr=0.00047 - loss:0.213, acc:86.161, val_loss:0.376, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 156/300 lr=0.00047 - loss:0.214, acc:85.938, val_loss:0.373, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 157/300 lr=0.00047 - loss:0.207, acc:86.384, val_loss:0.375, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 158/300 lr=0.00047 - loss:0.213, acc:86.607, val_loss:0.387, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 159/300 lr=0.00047 - loss:0.212, acc:85.045, val_loss:0.400, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 160/300 lr=0.00047 - loss:0.210, acc:85.938, val_loss:0.404, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 161/300 lr=0.00047 - loss:0.205, acc:85.938, val_loss:0.397, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 162/300 lr=0.00041 - loss:0.204, acc:85.714, val_loss:0.408, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 163/300 lr=0.00041 - loss:0.207, acc:85.938, val_loss:0.433, val_acc:48.438
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 164/300 lr=0.00041 - loss:0.217, acc:82.812, val_loss:0.410, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 165/300 lr=0.00041 - loss:0.216, acc:83.482, val_loss:0.392, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 166/300 lr=0.00041 - loss:0.210, acc:86.161, val_loss:0.370, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 167/300 lr=0.00041 - loss:0.204, acc:85.491, val_loss:0.383, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 168/300 lr=0.00041 - loss:0.201, acc:87.946, val_loss:0.416, val_acc:50.000
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 169/300 lr=0.00041 - loss:0.201, acc:86.607, val_loss:0.414, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 170/300 lr=0.00041 - loss:0.200, acc:89.062, val_loss:0.404, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 171/300 lr=0.00041 - loss:0.202, acc:87.500, val_loss:0.384, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 172/300 lr=0.00041 - loss:0.205, acc:87.054, val_loss:0.383, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 173/300 lr=0.00041 - loss:0.206, acc:85.268, val_loss:0.379, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 174/300 lr=0.00041 - loss:0.208, acc:87.277, val_loss:0.384, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 175/300 lr=0.00041 - loss:0.203, acc:87.277, val_loss:0.380, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 176/300 lr=0.00041 - loss:0.192, acc:86.384, val_loss:0.382, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 177/300 lr=0.00041 - loss:0.198, acc:86.161, val_loss:0.374, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 178/300 lr=0.00041 - loss:0.186, acc:88.839, val_loss:0.385, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 179/300 lr=0.00041 - loss:0.195, acc:86.830, val_loss:0.398, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 180/300 lr=0.00041 - loss:0.194, acc:87.946, val_loss:0.379, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 181/300 lr=0.00041 - loss:0.189, acc:89.286, val_loss:0.380, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 182/300 lr=0.00035 - loss:0.191, acc:88.393, val_loss:0.398, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 183/300 lr=0.00035 - loss:0.190, acc:85.938, val_loss:0.395, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 184/300 lr=0.00035 - loss:0.194, acc:88.393, val_loss:0.372, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 185/300 lr=0.00035 - loss:0.191, acc:88.616, val_loss:0.369, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 186/300 lr=0.00035 - loss:0.182, acc:88.393, val_loss:0.373, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 187/300 lr=0.00035 - loss:0.192, acc:87.723, val_loss:0.382, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 188/300 lr=0.00035 - loss:0.190, acc:87.054, val_loss:0.382, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 189/300 lr=0.00035 - loss:0.187, acc:89.955, val_loss:0.380, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 190/300 lr=0.00035 - loss:0.181, acc:89.955, val_loss:0.381, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 191/300 lr=0.00035 - loss:0.181, acc:89.509, val_loss:0.387, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 192/300 lr=0.00035 - loss:0.186, acc:88.170, val_loss:0.386, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 193/300 lr=0.00035 - loss:0.182, acc:89.062, val_loss:0.375, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 194/300 lr=0.00035 - loss:0.182, acc:89.955, val_loss:0.366, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 195/300 lr=0.00035 - loss:0.181, acc:89.286, val_loss:0.377, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 196/300 lr=0.00035 - loss:0.179, acc:89.286, val_loss:0.381, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 197/300 lr=0.00035 - loss:0.186, acc:90.179, val_loss:0.393, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 198/300 lr=0.00035 - loss:0.183, acc:90.179, val_loss:0.393, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 199/300 lr=0.00035 - loss:0.177, acc:91.295, val_loss:0.388, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 200/300 lr=0.00035 - loss:0.182, acc:89.509, val_loss:0.380, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 201/300 lr=0.00035 - loss:0.177, acc:91.741, val_loss:0.375, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 202/300 lr=0.00030 - loss:0.180, acc:91.071, val_loss:0.389, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 203/300 lr=0.00030 - loss:0.188, acc:88.170, val_loss:0.404, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 204/300 lr=0.00030 - loss:0.178, acc:89.732, val_loss:0.383, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 205/300 lr=0.00030 - loss:0.176, acc:91.295, val_loss:0.371, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 206/300 lr=0.00030 - loss:0.185, acc:88.616, val_loss:0.377, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 207/300 lr=0.00030 - loss:0.178, acc:91.518, val_loss:0.390, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 208/300 lr=0.00030 - loss:0.183, acc:89.732, val_loss:0.398, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 209/300 lr=0.00030 - loss:0.173, acc:90.848, val_loss:0.387, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 210/300 lr=0.00030 - loss:0.174, acc:91.741, val_loss:0.387, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 211/300 lr=0.00030 - loss:0.171, acc:91.964, val_loss:0.375, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 212/300 lr=0.00030 - loss:0.179, acc:91.071, val_loss:0.370, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 213/300 lr=0.00030 - loss:0.167, acc:92.634, val_loss:0.388, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 214/300 lr=0.00030 - loss:0.174, acc:91.071, val_loss:0.381, val_acc:59.375
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 215/300 lr=0.00030 - loss:0.171, acc:91.741, val_loss:0.357, val_acc:59.375
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 216/300 lr=0.00030 - loss:0.172, acc:91.741, val_loss:0.352, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 217/300 lr=0.00030 - loss:0.165, acc:91.295, val_loss:0.365, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 218/300 lr=0.00030 - loss:0.171, acc:90.848, val_loss:0.387, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 219/300 lr=0.00030 - loss:0.176, acc:89.509, val_loss:0.395, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 220/300 lr=0.00030 - loss:0.163, acc:91.964, val_loss:0.378, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 221/300 lr=0.00030 - loss:0.170, acc:90.179, val_loss:0.383, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 222/300 lr=0.00026 - loss:0.171, acc:92.188, val_loss:0.393, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 223/300 lr=0.00026 - loss:0.171, acc:90.625, val_loss:0.395, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 224/300 lr=0.00026 - loss:0.170, acc:90.848, val_loss:0.385, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 225/300 lr=0.00026 - loss:0.163, acc:93.304, val_loss:0.384, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 226/300 lr=0.00026 - loss:0.160, acc:92.857, val_loss:0.374, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 227/300 lr=0.00026 - loss:0.168, acc:91.518, val_loss:0.385, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 228/300 lr=0.00026 - loss:0.167, acc:92.411, val_loss:0.393, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 229/300 lr=0.00026 - loss:0.164, acc:94.196, val_loss:0.382, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 230/300 lr=0.00026 - loss:0.168, acc:92.857, val_loss:0.373, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 231/300 lr=0.00026 - loss:0.165, acc:91.741, val_loss:0.366, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 232/300 lr=0.00026 - loss:0.161, acc:93.304, val_loss:0.366, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 233/300 lr=0.00026 - loss:0.158, acc:93.080, val_loss:0.382, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 234/300 lr=0.00026 - loss:0.168, acc:91.518, val_loss:0.378, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 235/300 lr=0.00026 - loss:0.163, acc:92.634, val_loss:0.361, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 236/300 lr=0.00026 - loss:0.161, acc:93.973, val_loss:0.383, val_acc:59.375
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 237/300 lr=0.00026 - loss:0.159, acc:93.527, val_loss:0.408, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 238/300 lr=0.00026 - loss:0.168, acc:90.625, val_loss:0.414, val_acc:50.000
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 239/300 lr=0.00026 - loss:0.160, acc:94.196, val_loss:0.385, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 240/300 lr=0.00026 - loss:0.160, acc:92.634, val_loss:0.364, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 241/300 lr=0.00026 - loss:0.166, acc:91.295, val_loss:0.367, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 242/300 lr=0.00022 - loss:0.164, acc:92.411, val_loss:0.366, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 243/300 lr=0.00022 - loss:0.166, acc:93.080, val_loss:0.367, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 244/300 lr=0.00022 - loss:0.165, acc:91.964, val_loss:0.381, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 245/300 lr=0.00022 - loss:0.160, acc:94.420, val_loss:0.387, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 246/300 lr=0.00022 - loss:0.159, acc:93.527, val_loss:0.387, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 247/300 lr=0.00022 - loss:0.153, acc:93.973, val_loss:0.382, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 248/300 lr=0.00022 - loss:0.156, acc:93.080, val_loss:0.373, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 249/300 lr=0.00022 - loss:0.161, acc:93.080, val_loss:0.373, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 250/300 lr=0.00022 - loss:0.158, acc:92.634, val_loss:0.386, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 251/300 lr=0.00022 - loss:0.162, acc:92.634, val_loss:0.396, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 252/300 lr=0.00022 - loss:0.161, acc:92.857, val_loss:0.378, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 253/300 lr=0.00022 - loss:0.161, acc:92.634, val_loss:0.377, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 254/300 lr=0.00022 - loss:0.162, acc:91.518, val_loss:0.373, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 255/300 lr=0.00022 - loss:0.160, acc:92.411, val_loss:0.369, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 256/300 lr=0.00022 - loss:0.158, acc:93.750, val_loss:0.371, val_acc:57.812
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 257/300 lr=0.00022 - loss:0.155, acc:93.527, val_loss:0.384, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 258/300 lr=0.00022 - loss:0.162, acc:91.295, val_loss:0.388, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 259/300 lr=0.00022 - loss:0.157, acc:93.750, val_loss:0.381, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 260/300 lr=0.00022 - loss:0.164, acc:92.188, val_loss:0.370, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 261/300 lr=0.00022 - loss:0.161, acc:93.080, val_loss:0.380, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 262/300 lr=0.00019 - loss:0.148, acc:93.750, val_loss:0.404, val_acc:48.438
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 263/300 lr=0.00019 - loss:0.157, acc:93.973, val_loss:0.396, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 264/300 lr=0.00019 - loss:0.157, acc:92.857, val_loss:0.378, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 265/300 lr=0.00019 - loss:0.164, acc:92.188, val_loss:0.373, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 266/300 lr=0.00019 - loss:0.156, acc:93.080, val_loss:0.377, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 267/300 lr=0.00019 - loss:0.163, acc:91.964, val_loss:0.382, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 268/300 lr=0.00019 - loss:0.153, acc:92.857, val_loss:0.379, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 269/300 lr=0.00019 - loss:0.150, acc:95.312, val_loss:0.380, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 270/300 lr=0.00019 - loss:0.150, acc:94.420, val_loss:0.379, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 271/300 lr=0.00019 - loss:0.152, acc:95.312, val_loss:0.374, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 272/300 lr=0.00019 - loss:0.143, acc:96.205, val_loss:0.375, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 273/300 lr=0.00019 - loss:0.152, acc:94.196, val_loss:0.378, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 274/300 lr=0.00019 - loss:0.155, acc:93.527, val_loss:0.381, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 275/300 lr=0.00019 - loss:0.153, acc:93.973, val_loss:0.383, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 276/300 lr=0.00019 - loss:0.153, acc:93.750, val_loss:0.389, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 277/300 lr=0.00019 - loss:0.145, acc:95.089, val_loss:0.385, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 278/300 lr=0.00019 - loss:0.153, acc:93.750, val_loss:0.380, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 279/300 lr=0.00019 - loss:0.154, acc:93.527, val_loss:0.382, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 280/300 lr=0.00019 - loss:0.154, acc:93.527, val_loss:0.385, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 281/300 lr=0.00019 - loss:0.148, acc:95.312, val_loss:0.388, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 282/300 lr=0.00017 - loss:0.147, acc:94.643, val_loss:0.388, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 283/300 lr=0.00017 - loss:0.155, acc:93.527, val_loss:0.392, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 284/300 lr=0.00017 - loss:0.151, acc:94.420, val_loss:0.391, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 285/300 lr=0.00017 - loss:0.147, acc:94.643, val_loss:0.385, val_acc:50.000
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 286/300 lr=0.00017 - loss:0.159, acc:91.741, val_loss:0.380, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 287/300 lr=0.00017 - loss:0.145, acc:95.089, val_loss:0.372, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 288/300 lr=0.00017 - loss:0.156, acc:92.634, val_loss:0.370, val_acc:59.375
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 289/300 lr=0.00017 - loss:0.147, acc:94.866, val_loss:0.380, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 290/300 lr=0.00017 - loss:0.152, acc:92.857, val_loss:0.388, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 291/300 lr=0.00017 - loss:0.136, acc:96.875, val_loss:0.392, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 292/300 lr=0.00017 - loss:0.147, acc:95.089, val_loss:0.385, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 293/300 lr=0.00017 - loss:0.144, acc:94.196, val_loss:0.373, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 294/300 lr=0.00017 - loss:0.149, acc:93.527, val_loss:0.377, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 295/300 lr=0.00017 - loss:0.155, acc:93.750, val_loss:0.386, val_acc:56.250
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 296/300 lr=0.00017 - loss:0.148, acc:93.973, val_loss:0.395, val_acc:54.688
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 297/300 lr=0.00017 - loss:0.145, acc:95.089, val_loss:0.399, val_acc:50.000
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 298/300 lr=0.00017 - loss:0.150, acc:94.420, val_loss:0.390, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 299/300 lr=0.00017 - loss:0.144, acc:94.866, val_loss:0.387, val_acc:53.125
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# 300/300 lr=0.00017 - loss:0.147, acc:95.089, val_loss:0.387, val_acc:51.562
# Best loss:0.359, Best accuracy:64.062, Best F1-score:0.631
# [*] Done - acc:64.062
# A Jupyter Widget
# 1/300 lr=0.00100 - loss:0.613, acc:20.759, val_loss:0.610, val_acc:23.438
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.00100 - loss:0.593, acc:26.786, val_loss:0.594, val_acc:26.562
# Best loss:0.610, Best accuracy:23.438, Best F1-score:0.102
# 3/300 lr=0.00100 - loss:0.577, acc:30.357, val_loss:0.578, val_acc:28.125
# Best loss:0.594, Best accuracy:26.562, Best F1-score:0.141
# 4/300 lr=0.00100 - loss:0.562, acc:32.812, val_loss:0.566, val_acc:31.250
# Best loss:0.578, Best accuracy:28.125, Best F1-score:0.168
# 5/300 lr=0.00100 - loss:0.543, acc:38.839, val_loss:0.543, val_acc:34.375
# Best loss:0.566, Best accuracy:31.250, Best F1-score:0.201
# 6/300 lr=0.00100 - loss:0.533, acc:40.402, val_loss:0.530, val_acc:37.500
# Best loss:0.543, Best accuracy:34.375, Best F1-score:0.285
# 7/300 lr=0.00100 - loss:0.522, acc:41.071, val_loss:0.516, val_acc:40.625
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.284
# 8/300 lr=0.00100 - loss:0.514, acc:45.312, val_loss:0.504, val_acc:40.625
# Best loss:0.516, Best accuracy:40.625, Best F1-score:0.292
# 9/300 lr=0.00100 - loss:0.502, acc:45.089, val_loss:0.496, val_acc:42.188
# Best loss:0.516, Best accuracy:40.625, Best F1-score:0.292
# 10/300 lr=0.00100 - loss:0.497, acc:44.643, val_loss:0.491, val_acc:42.188
# Best loss:0.496, Best accuracy:42.188, Best F1-score:0.311
# 11/300 lr=0.00100 - loss:0.486, acc:46.652, val_loss:0.481, val_acc:43.750
# Best loss:0.496, Best accuracy:42.188, Best F1-score:0.311
# 12/300 lr=0.00100 - loss:0.479, acc:47.098, val_loss:0.473, val_acc:45.312
# Best loss:0.481, Best accuracy:43.750, Best F1-score:0.330
# 13/300 lr=0.00100 - loss:0.483, acc:45.759, val_loss:0.465, val_acc:48.438
# Best loss:0.473, Best accuracy:45.312, Best F1-score:0.365

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
