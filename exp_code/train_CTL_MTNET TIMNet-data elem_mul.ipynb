# %%
from silence_tensorflow import silence_tensorflow
silence_tensorflow()

from tensorflow.keras.layers import Layer, Lambda, Conv2D, Dropout,Dense,Activation,Input,GlobalAveragePooling1D, Concatenate, GlobalAveragePooling2D
from tensorflow.keras.layers import Reshape,Flatten,BatchNormalization,MaxPooling1D,AveragePooling2D,Reshape,Attention, ReLU, Activation
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import regularizers
from sklearn.model_selection import KFold
import keras.backend as K
from tensorflow.keras.optimizers import Adam
from tqdm.auto import tqdm
import os
from Config import Config
import numpy as np
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from sklearn.metrics import classification_report, confusion_matrix, f1_score
from datetime import datetime
import random
import matplotlib.pyplot as plt
from tensorflow.keras.losses import CategoricalCrossentropy, MeanSquaredError

import tensorflow as tf
tf.config.run_functions_eagerly(True)

import warnings
warnings.filterwarnings('always')

from utils import *
# Out:
#         <style>
#             .support_message_main_box {
#                 position: relative;
#                 display: table-cell;
#                 vertical-align: middle;
#                 width: 100%;
#                 height: 8em;
#                 padding: 1em;
#                 padding-left: 11em;
#                 background-color: #f7f7f7;
#                 border: 1px solid #cfcfcf;
#                 border-radius: 2px;
#             }
#             .support_message_main_box img {
#                 position: absolute;
#                 height: 9em;
#                 width: 9em;
#                 left: 0.5em;
#                 top: 0.5em;
#                 border-radius: 1em;
#             }
#         </style>
#         <div class="support_message_main_box">
#             <img src="https://avatars.githubusercontent.com/u/7738570?v=4" />
#             <p>
#             <b>Hi!</b><br/>
#             <span>I am the author of
#             <a href="https://github.com/LucaCappelletti94/silence_tensorflow" target="_blank">
#                 silence_tensorflow
#             </a>, which you use in this Notebook.
#             </span><br/>
#
#         <span>I hope my work has saved you some time!</span><br/>
#
#             <span>I love to code, but I also need coffee.</span>
#             <a href="https://github.com/sponsors/LucaCappelletti94" target="_blank">
#                 Please sponsor me on GitHub ❤️
#             </a><br/>
#             <i>Good luck in your coding 🍀!</i>
#             <br/>
#             <i>- Luca</i>
#             </p>
#         <div>

# %%
seed_everything(42)

# %%
DATA_ROOT = 'TIMNET-dataset'
DATA_PATH = 'RAVDESS'
CLASS_LABELS = Config.RAVDESS_LABELS
k = 10

model_name = 'CTL_MTNet-forwardAndBackward-res_conn'
feature_name = 'mfcc'

learning_rate=0.01
beta_1=0.975
beta_2=0.932
epsilon=1e-8

EPOCHS = 300
BATCH = 32

# %%
def PrimaryCapssquash(vectors, axis=-1):
    """
        The non-linear activation used in Capsule. It drives the length of a large vector to near 1 and small vector to 0
        :param vectors: some vectors to be squashed, N-dim tensor
        :param axis: the axis to squash
        :return: a Tensor with same shape as input vectors
    """
    s_squared_norm = K.sum(K.square(vectors), axis, keepdims=True)
    scale = s_squared_norm / (1 + s_squared_norm) / K.sqrt(s_squared_norm + K.epsilon())
    return scale * vectors

# %%
class PrimaryCap(tf.keras.Model):

  def __init__(self, dim_capsule=64, n_channels=6, kernel_size=3, strides=1, padding='valid'):
    super().__init__()
    
    
    self.conv = Sequential([
        Conv2D(filters=dim_capsule*n_channels, kernel_size=kernel_size, strides=strides, padding=padding, name='primarycap_conv2d'),
        Reshape(target_shape=[-1, dim_capsule], name='primarycap_reshape'),
        Lambda(function=PrimaryCapssquash, name='primarycap_squash')
    ])
    
  def call(self, inputs):
    x = self.conv(inputs)
    return x

# %%
def DigitCapssquash(Value, axis = -1):
    """
        Squash activation in PrimaryCaps
        :return: a Tensor with same shape as input vectors
    """
    Square_Vector = K.sum(K.square(Value), axis, keepdims=True)
    Proportion = Square_Vector / (1 + Square_Vector) / K.sqrt(Square_Vector + K.epsilon())
    Output = Proportion * Value
    return Output

# %%
def softmax(x, axis=-1):
    """
        softmax in Dynamic Routings
    """ 
    ex = K.exp(x - K.max(x, axis=axis, keepdims=True))
    return ex/K.sum(ex, axis=axis, keepdims=True)

# %%
class Capsule(tf.keras.layers.Layer):
    def __init__(self, num_capsule, dim_capsule, routings=3, share_weights=True, activation='squash', **kwargs):
        super(Capsule, self).__init__(**kwargs)
        self.num_capsule = num_capsule
        self.dim_capsule = dim_capsule
        self.routings = routings
        self.share_weights = share_weights
        self.activation = DigitCapssquash
        
    def get_config(self):
       config = {"num_capsule":self.num_capsule,
                 "dim_capsule":self.dim_capsule,
                 "routings":self.routings,
                 "share_weights":self.share_weights,
                 "activation":self.activation
                }
       base_config = super(Capsule, self).get_config()
       return dict(list(base_config.items()) + list(config.items()))
    
    def build(self, input_shape):
        super(Capsule, self).build(input_shape)
        input_dim_capsule = input_shape[-1]
        #input_dim_capsule = 8
        if self.share_weights:
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(1, input_dim_capsule,#input_dim_capsule = 16
                                            self.num_capsule * self.dim_capsule), #16*32
                                     initializer='glorot_uniform',
                                     trainable=True)
        else:
            input_num_capsule = input_shape[-2]
            self.W = self.add_weight(name='capsule_kernel',
                                     shape=(input_num_capsule,
                                            input_dim_capsule,
                                            self.num_capsule * self.dim_capsule),
                                     initializer='glorot_uniform',
                                     trainable=True)
    
    def call(self, u_vecs):
        if self.share_weights:
            u_hat_vecs = K.conv1d(u_vecs, self.W)
        else:
            u_hat_vecs = K.local_conv1d(u_vecs, self.W, [1], [1])

        batch_size = K.shape(u_vecs)[0]
        input_num_capsule = K.shape(u_vecs)[1]
        u_hat_vecs = K.reshape(u_hat_vecs, (batch_size, input_num_capsule,
                                            self.num_capsule, self.dim_capsule))
        u_hat_vecs = K.permute_dimensions(u_hat_vecs, (0, 2, 1, 3))

        b = K.zeros_like(u_hat_vecs[:,:,:,0])

        for i in range(self.routings): #Routings
            c = softmax(b, 1)

            o = tf.einsum('bin,binj->bij', c, u_hat_vecs)
            if K.backend() == 'theano':
                o = K.sum(o, axis=1)
            if i < self.routings - 1:
                o = K.l2_normalize(o, -1)
                b = tf.einsum('bij,binj->bin', o, u_hat_vecs)
                if K.backend() == 'theano':
                    b = K.sum(b, axis=1)

        return self.activation(o)

    def compute_output_shape(self, input_shape):
        return (None, self.num_capsule, self.dim_capsule)

# %%
class CTL_MTNet(tf.keras.Model):

  def __init__(self, num_classes):
    super().__init__()
    
    self.conv1 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      Dropout(0.5)
      ])
    self.conv2 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      Dropout(0.25)
    ])
    self.conv3 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      Dropout(0.5)
    ])
    
    self.conv4 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      Dropout(0.5)
      ])
    self.conv5 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      Dropout(0.25)
    ])
    self.conv6 = Sequential([
      Conv2D(filters=64, kernel_size=3),
      BatchNormalization(axis=1),
      Activation('elu'),
      AveragePooling2D(),
      Dropout(0.5)
    ])
    
    self.primarycap1 = PrimaryCap()
    self.primarycap2 = PrimaryCap()
    
    self.attention1 = Attention(use_scale=True)
    self.attention2 = Attention(use_scale=True)
    
    self.lamb = Lambda(lambda x: tf.multiply(x[0], x[1]))
    
    self.capsule = Capsule(6,64,3,True)
    self.gap = GlobalAveragePooling1D()
    self.dropout = Dropout(0.2)
    self.classifier = Dense(num_classes, activation='softmax')
    

  def call(self, inputs):
    forward = inputs
    backward =tf.reverse(inputs, axis=[1])
    
    x1 = self.conv1(forward)
    x1 = self.conv2(x1)
    x1 = self.conv3(x1)
    x2 = self.conv4(backward)
    x2 = self.conv5(x2)
    x2 = self.conv6(x2)
    
    primarycaps1 = self.primarycap1(x1)
    primarycaps2 = self.primarycap2(x2)
    
    cap1 = primarycaps1
    cap2 = primarycaps2
    
    sa1 = self.attention1([primarycaps1, primarycaps1, primarycaps1])
    sa2 = self.attention2([primarycaps2, primarycaps2, primarycaps2])
    
    cap1 = self.lamb([cap1, sa1])
    cap2 = self.lamb([cap2, sa2])
    
    capsule = self.capsule(cap1*cap2)
    gap = self.gap(capsule)
    drop = self.dropout(gap)
    
    output_softmax = self.classifier(drop)
    return output_softmax

# %%
def margin_loss(y_true, y_pred):
    """
        Margin Loss
        :param y_true: [None, n_classes]
        :param y_pred: [None, num_capsule]
        :return: a scalar loss value.
    """
    L = y_true * K.square(K.maximum(0., 0.9 - y_pred)) + \
        0.5 * (1 - y_true) * K.square(K.maximum(0., y_pred - 0.1))

    return K.mean(K.sum(L, 1))

# %%
@tf.function
def train_step(model, optimizer, x, labels):
    with tf.GradientTape() as tape:
        # 미분 계산
        predictions = model(x, training=True)
        loss1 = margin_loss(labels, predictions)
        loss2 = MeanSquaredError()(labels, predictions)
        
        loss = loss1*1. + loss2*0.392
        
    grad = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grad, model.trainable_variables))     # 신경망 파라미터 업데이트
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100

def test_step(model, x, labels):
    predictions = model(x)
    loss1 = margin_loss(labels, predictions)
    loss2 = MeanSquaredError()(labels, predictions)
    loss = loss1*1. + loss2*0.392
    
    acc = tf.keras.metrics.CategoricalAccuracy()
    acc.update_state(labels, predictions)
    accuracy = acc.result().numpy()
    
    return loss, accuracy*100, predictions

# %%
# Read data
with open(f'{DATA_ROOT}/{DATA_PATH}.npy', 'rb') as f:
    x = np.load(f)
    y = np.load(f)

x = np.expand_dims(x, axis=-1)
y = to_categorical(y,num_classes=len(CLASS_LABELS))

# %%
LEARNING_RATE_DECAY_PARAMETERS = -0.15
LEARNING_RATE_DECAY_STRATPOINT = 50
LEARNING_RATE_DECAY_STEP = 20


def scheduler(epoch, lr):
    if epoch < LEARNING_RATE_DECAY_STRATPOINT:
        return lr
    else:
        if epoch % LEARNING_RATE_DECAY_STEP == 0:
            lr = lr * tf.math.exp(LEARNING_RATE_DECAY_PARAMETERS)
    return lr

# %%
# Smooth label operation
def smooth_labels(labels, factor=0.1):
    """
        smooth the labels
        returned the smoothed labels
    """
    labels *= (1 - factor)
    labels += (factor / labels.shape[1])
    return labels

# %%
from discord_notice import start, end
# start()

# %%
import tensorflow_addons as tfa
from keras.models import load_model

emotions_groundtruth_list = np.array([])
predicted_emotions_list = np.array([])

fold_acc = []

kfold = KFold(n_splits=k, shuffle=True, random_state=98)
for i, (train, test) in tqdm(enumerate(kfold.split(x, y)), desc=f'Training {k}-Fold.....'):
    now_time = datetime.now().strftime("%m-%d-%H%M%S")
    
    save_path = f'Models/{DATA_PATH}'
    os.makedirs(save_path, exist_ok=True)
    h5_path = f'{save_path}/{model_name}_{feature_name}_{i}-fold_{now_time}.h5'
    
    x_train, y_train = x[train], y[train]
    y_train = smooth_labels(y[train], 0.1)
    
    x_test, y_test = x[test], y[test]
    
    shape = x_train.shape[1:]
    
    optimizer = Adam(learning_rate=learning_rate, beta_1=beta_1, beta_2=beta_2, epsilon=epsilon)
    
    model = CTL_MTNet(len(CLASS_LABELS))
    
    best_test_loss = 0x3f3f3f
    best_test_acc = -1
    best_test_f1 = -1
    
    epoch_losses = []
    valid_losses = []
    
    batch_train = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(2022).batch(BATCH)
    batch_test = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(BATCH)
    for epoch in tqdm(range(EPOCHS), desc=f'Fold-{i+1}'):

        train_loss, train_acc = [], []
        for features, labels in batch_train:
            loss, acc = train_step(model, optimizer, features, labels)
            train_loss.append(loss)
            train_acc.append(acc)
            
        test_loss, test_acc, f1s = [], [], []
        for features, labels in batch_test:
            loss, acc, pred = test_step(model, features, labels)
            test_loss.append(loss)
            test_acc.append(acc)
            
            f1_metric = tfa.metrics.F1Score(num_classes=len(CLASS_LABELS), average='weighted')
            f1_metric.update_state(labels, pred)
            f1 = f1_metric.result().numpy()
            f1s.append(f1)
            
        
        epoch_loss = sum(train_loss)/len(train_loss)
        epoch_acc = sum(train_acc)/len(train_acc)
        val_loss = sum(test_loss)/len(test_loss)
        val_acc = sum(test_acc)/len(test_acc)
        f1_score = sum(f1s)/len(f1s)
        
        epoch_losses.append(epoch_loss)
        valid_losses.append(val_loss)
        
        cur_lr = K.eval(optimizer.lr)
        print(f'{epoch+1}/{EPOCHS} lr={cur_lr:.5f} - loss:{epoch_loss:.3f}, acc:{epoch_acc:.3f}, val_loss:{val_loss:.3f}, val_acc:{val_acc:.3f}')
        print(f'Best loss:{best_test_loss:.3f}, Best accuracy:{best_test_acc:.3f}, Best F1-score:{best_test_f1:.3f}')
        
        set_lr = scheduler(epoch, K.eval(optimizer.lr))
        K.set_value(optimizer.learning_rate, set_lr)
        
        if best_test_acc < val_acc:
            best_test_acc = val_acc
            best_test_loss = val_loss
            best_test_f1 = f1_score
            model.save_weights(h5_path)
            
            
    model = CTL_MTNet(len(CLASS_LABELS))
    model.build(input_shape=x_train.shape)
    model.load_weights(h5_path)
    best_pred = model(x_test, training=False)
    emotions_groundtruth_list = np.append(emotions_groundtruth_list, np.argmax(y_test, axis=1))
    predicted_emotions_list = np.append(predicted_emotions_list, np.argmax(best_pred, axis=1))
    
    
    print(f'[*] Done - acc:{best_test_acc:.3f}')
    
    plt.title('Loss Curve')
    plt.ylabel('Loss', fontsize=16)
    plt.xlabel('Epoch', fontsize=16)
    plt.plot(epoch_losses[:],'b')
    plt.plot(valid_losses[:],'r')
    plt.legend(['Training loss','Validation loss'])
    plt.show()
    
    fold_acc.append(best_test_acc)
# Out:
# A Jupyter Widget
# A Jupyter Widget
# 1/300 lr=0.01000 - loss:0.635, acc:12.348, val_loss:0.634, val_acc:13.750
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.01000 - loss:0.622, acc:18.598, val_loss:0.620, val_acc:16.875
# Best loss:0.634, Best accuracy:13.750, Best F1-score:0.058
# 3/300 lr=0.01000 - loss:0.610, acc:22.027, val_loss:0.608, val_acc:17.500
# Best loss:0.620, Best accuracy:16.875, Best F1-score:0.067
# 4/300 lr=0.01000 - loss:0.602, acc:24.543, val_loss:0.608, val_acc:16.250
# Best loss:0.608, Best accuracy:17.500, Best F1-score:0.088
# 5/300 lr=0.01000 - loss:0.595, acc:24.695, val_loss:0.599, val_acc:18.125
# Best loss:0.608, Best accuracy:17.500, Best F1-score:0.088
# 6/300 lr=0.01000 - loss:0.589, acc:24.162, val_loss:0.595, val_acc:20.625
# Best loss:0.599, Best accuracy:18.125, Best F1-score:0.108
# 7/300 lr=0.01000 - loss:0.586, acc:24.771, val_loss:0.588, val_acc:24.375
# Best loss:0.595, Best accuracy:20.625, Best F1-score:0.116
# 8/300 lr=0.01000 - loss:0.583, acc:25.915, val_loss:0.589, val_acc:19.375
# Best loss:0.588, Best accuracy:24.375, Best F1-score:0.177
# 9/300 lr=0.01000 - loss:0.579, acc:25.534, val_loss:0.597, val_acc:19.375
# Best loss:0.588, Best accuracy:24.375, Best F1-score:0.177
# 10/300 lr=0.01000 - loss:0.573, acc:27.744, val_loss:0.584, val_acc:25.625
# Best loss:0.588, Best accuracy:24.375, Best F1-score:0.177
# 11/300 lr=0.01000 - loss:0.568, acc:28.430, val_loss:0.582, val_acc:24.375
# Best loss:0.584, Best accuracy:25.625, Best F1-score:0.184
# 12/300 lr=0.01000 - loss:0.571, acc:27.668, val_loss:0.575, val_acc:26.875
# Best loss:0.584, Best accuracy:25.625, Best F1-score:0.184
# 13/300 lr=0.01000 - loss:0.566, acc:29.268, val_loss:0.577, val_acc:31.875
# Best loss:0.575, Best accuracy:26.875, Best F1-score:0.215
# 14/300 lr=0.01000 - loss:0.560, acc:29.954, val_loss:0.577, val_acc:32.500
# Best loss:0.577, Best accuracy:31.875, Best F1-score:0.259
# 15/300 lr=0.01000 - loss:0.555, acc:29.268, val_loss:0.556, val_acc:32.500
# Best loss:0.577, Best accuracy:32.500, Best F1-score:0.290
# 16/300 lr=0.01000 - loss:0.549, acc:31.555, val_loss:0.554, val_acc:30.000
# Best loss:0.577, Best accuracy:32.500, Best F1-score:0.290
# 17/300 lr=0.01000 - loss:0.546, acc:31.402, val_loss:0.547, val_acc:30.000
# Best loss:0.577, Best accuracy:32.500, Best F1-score:0.290
# 18/300 lr=0.01000 - loss:0.539, acc:33.841, val_loss:0.556, val_acc:33.125
# Best loss:0.577, Best accuracy:32.500, Best F1-score:0.290
# 19/300 lr=0.01000 - loss:0.535, acc:33.689, val_loss:0.539, val_acc:31.875
# Best loss:0.556, Best accuracy:33.125, Best F1-score:0.278
# 20/300 lr=0.01000 - loss:0.531, acc:35.899, val_loss:0.541, val_acc:33.750
# Best loss:0.556, Best accuracy:33.125, Best F1-score:0.278
# 21/300 lr=0.01000 - loss:0.534, acc:34.604, val_loss:0.539, val_acc:33.750
# Best loss:0.541, Best accuracy:33.750, Best F1-score:0.311
# 22/300 lr=0.01000 - loss:0.525, acc:36.433, val_loss:0.553, val_acc:30.625
# Best loss:0.541, Best accuracy:33.750, Best F1-score:0.311
# 23/300 lr=0.01000 - loss:0.522, acc:37.119, val_loss:0.535, val_acc:34.375
# Best loss:0.541, Best accuracy:33.750, Best F1-score:0.311
# 24/300 lr=0.01000 - loss:0.523, acc:35.366, val_loss:0.529, val_acc:34.375
# Best loss:0.535, Best accuracy:34.375, Best F1-score:0.326
# 25/300 lr=0.01000 - loss:0.526, acc:36.204, val_loss:0.526, val_acc:32.500
# Best loss:0.535, Best accuracy:34.375, Best F1-score:0.326
# 26/300 lr=0.01000 - loss:0.510, acc:38.186, val_loss:0.522, val_acc:34.375
# Best loss:0.535, Best accuracy:34.375, Best F1-score:0.326
# 27/300 lr=0.01000 - loss:0.503, acc:41.311, val_loss:0.528, val_acc:32.500
# Best loss:0.535, Best accuracy:34.375, Best F1-score:0.326
# 28/300 lr=0.01000 - loss:0.497, acc:40.168, val_loss:0.516, val_acc:36.250
# Best loss:0.535, Best accuracy:34.375, Best F1-score:0.326
# 29/300 lr=0.01000 - loss:0.495, acc:40.930, val_loss:0.501, val_acc:41.250
# Best loss:0.516, Best accuracy:36.250, Best F1-score:0.325
# 30/300 lr=0.01000 - loss:0.497, acc:41.387, val_loss:0.512, val_acc:36.875
# Best loss:0.501, Best accuracy:41.250, Best F1-score:0.366
# 31/300 lr=0.01000 - loss:0.483, acc:45.427, val_loss:0.512, val_acc:34.375
# Best loss:0.501, Best accuracy:41.250, Best F1-score:0.366
# 32/300 lr=0.01000 - loss:0.478, acc:45.351, val_loss:0.488, val_acc:44.375
# Best loss:0.501, Best accuracy:41.250, Best F1-score:0.366
# 33/300 lr=0.01000 - loss:0.467, acc:45.960, val_loss:0.492, val_acc:37.500
# Best loss:0.488, Best accuracy:44.375, Best F1-score:0.419
# 34/300 lr=0.01000 - loss:0.462, acc:46.341, val_loss:0.473, val_acc:49.375
# Best loss:0.488, Best accuracy:44.375, Best F1-score:0.419
# 35/300 lr=0.01000 - loss:0.451, acc:49.238, val_loss:0.456, val_acc:48.750
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 36/300 lr=0.01000 - loss:0.447, acc:49.238, val_loss:0.460, val_acc:48.125
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 37/300 lr=0.01000 - loss:0.443, acc:52.058, val_loss:0.474, val_acc:41.875
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 38/300 lr=0.01000 - loss:0.442, acc:49.695, val_loss:0.454, val_acc:43.750
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 39/300 lr=0.01000 - loss:0.437, acc:51.372, val_loss:0.462, val_acc:46.250
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 40/300 lr=0.01000 - loss:0.427, acc:53.887, val_loss:0.449, val_acc:48.750
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 41/300 lr=0.01000 - loss:0.425, acc:54.192, val_loss:0.493, val_acc:41.875
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 42/300 lr=0.01000 - loss:0.437, acc:49.924, val_loss:0.437, val_acc:48.125
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 43/300 lr=0.01000 - loss:0.425, acc:52.744, val_loss:0.448, val_acc:44.375
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 44/300 lr=0.01000 - loss:0.419, acc:53.430, val_loss:0.468, val_acc:40.625
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 45/300 lr=0.01000 - loss:0.404, acc:56.250, val_loss:0.446, val_acc:48.125
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 46/300 lr=0.01000 - loss:0.404, acc:56.936, val_loss:0.462, val_acc:43.125
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 47/300 lr=0.01000 - loss:0.409, acc:55.030, val_loss:0.482, val_acc:38.125
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 48/300 lr=0.01000 - loss:0.402, acc:57.165, val_loss:0.448, val_acc:44.375
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 49/300 lr=0.01000 - loss:0.395, acc:57.698, val_loss:0.470, val_acc:45.625
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 50/300 lr=0.01000 - loss:0.392, acc:58.384, val_loss:0.447, val_acc:43.125
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 51/300 lr=0.01000 - loss:0.390, acc:59.375, val_loss:0.426, val_acc:50.000
# Best loss:0.473, Best accuracy:49.375, Best F1-score:0.475
# 52/300 lr=0.01000 - loss:0.396, acc:57.241, val_loss:0.423, val_acc:45.625
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.475
# 53/300 lr=0.01000 - loss:0.389, acc:59.909, val_loss:0.416, val_acc:51.875
# Best loss:0.426, Best accuracy:50.000, Best F1-score:0.475
# 54/300 lr=0.01000 - loss:0.386, acc:59.527, val_loss:0.429, val_acc:46.250
# Best loss:0.416, Best accuracy:51.875, Best F1-score:0.500
# 55/300 lr=0.01000 - loss:0.370, acc:61.357, val_loss:0.430, val_acc:48.750
# Best loss:0.416, Best accuracy:51.875, Best F1-score:0.500
# 56/300 lr=0.01000 - loss:0.366, acc:62.043, val_loss:0.442, val_acc:43.750
# Best loss:0.416, Best accuracy:51.875, Best F1-score:0.500
# 57/300 lr=0.01000 - loss:0.370, acc:61.509, val_loss:0.392, val_acc:53.125
# Best loss:0.416, Best accuracy:51.875, Best F1-score:0.500
# 58/300 lr=0.01000 - loss:0.367, acc:61.890, val_loss:0.431, val_acc:48.125
# Best loss:0.392, Best accuracy:53.125, Best F1-score:0.514
# 59/300 lr=0.01000 - loss:0.363, acc:61.662, val_loss:0.411, val_acc:54.375
# Best loss:0.392, Best accuracy:53.125, Best F1-score:0.514
# 60/300 lr=0.01000 - loss:0.363, acc:62.957, val_loss:0.402, val_acc:48.125
# Best loss:0.411, Best accuracy:54.375, Best F1-score:0.505
# 61/300 lr=0.01000 - loss:0.355, acc:63.796, val_loss:0.395, val_acc:55.625
# Best loss:0.411, Best accuracy:54.375, Best F1-score:0.505
# 62/300 lr=0.00861 - loss:0.342, acc:67.607, val_loss:0.414, val_acc:49.375
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 63/300 lr=0.00861 - loss:0.342, acc:66.082, val_loss:0.395, val_acc:50.000
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 64/300 lr=0.00861 - loss:0.339, acc:66.006, val_loss:0.388, val_acc:55.000
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 65/300 lr=0.00861 - loss:0.333, acc:67.988, val_loss:0.384, val_acc:53.125
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 66/300 lr=0.00861 - loss:0.334, acc:67.988, val_loss:0.387, val_acc:53.750
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 67/300 lr=0.00861 - loss:0.330, acc:68.445, val_loss:0.378, val_acc:55.000
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 68/300 lr=0.00861 - loss:0.328, acc:67.988, val_loss:0.386, val_acc:49.375
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 69/300 lr=0.00861 - loss:0.330, acc:68.598, val_loss:0.384, val_acc:54.375
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 70/300 lr=0.00861 - loss:0.319, acc:69.284, val_loss:0.403, val_acc:49.375
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 71/300 lr=0.00861 - loss:0.330, acc:68.064, val_loss:0.406, val_acc:53.750
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 72/300 lr=0.00861 - loss:0.319, acc:69.207, val_loss:0.395, val_acc:53.125
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 73/300 lr=0.00861 - loss:0.308, acc:71.494, val_loss:0.381, val_acc:57.500
# Best loss:0.395, Best accuracy:55.625, Best F1-score:0.548
# 74/300 lr=0.00861 - loss:0.315, acc:69.055, val_loss:0.366, val_acc:58.125
# Best loss:0.381, Best accuracy:57.500, Best F1-score:0.557
# 75/300 lr=0.00861 - loss:0.303, acc:73.247, val_loss:0.364, val_acc:57.500
# Best loss:0.366, Best accuracy:58.125, Best F1-score:0.559
# 76/300 lr=0.00861 - loss:0.298, acc:73.018, val_loss:0.351, val_acc:57.500
# Best loss:0.366, Best accuracy:58.125, Best F1-score:0.559
# 77/300 lr=0.00861 - loss:0.305, acc:72.409, val_loss:0.391, val_acc:54.375
# Best loss:0.366, Best accuracy:58.125, Best F1-score:0.559
# 78/300 lr=0.00861 - loss:0.298, acc:71.189, val_loss:0.365, val_acc:58.750
# Best loss:0.366, Best accuracy:58.125, Best F1-score:0.559
# 79/300 lr=0.00861 - loss:0.289, acc:74.466, val_loss:0.348, val_acc:60.625
# Best loss:0.365, Best accuracy:58.750, Best F1-score:0.568
# 80/300 lr=0.00861 - loss:0.291, acc:74.085, val_loss:0.369, val_acc:58.750
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 81/300 lr=0.00861 - loss:0.282, acc:74.924, val_loss:0.362, val_acc:60.625
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 82/300 lr=0.00741 - loss:0.286, acc:74.238, val_loss:0.370, val_acc:56.875
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 83/300 lr=0.00741 - loss:0.277, acc:75.305, val_loss:0.373, val_acc:56.875
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 84/300 lr=0.00741 - loss:0.280, acc:75.534, val_loss:0.357, val_acc:60.000
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 85/300 lr=0.00741 - loss:0.285, acc:75.686, val_loss:0.336, val_acc:60.625
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 86/300 lr=0.00741 - loss:0.273, acc:75.762, val_loss:0.365, val_acc:57.500
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 87/300 lr=0.00741 - loss:0.267, acc:77.363, val_loss:0.370, val_acc:60.625
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 88/300 lr=0.00741 - loss:0.266, acc:78.430, val_loss:0.367, val_acc:60.625
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 89/300 lr=0.00741 - loss:0.260, acc:77.134, val_loss:0.363, val_acc:61.875
# Best loss:0.348, Best accuracy:60.625, Best F1-score:0.602
# 90/300 lr=0.00741 - loss:0.255, acc:78.963, val_loss:0.347, val_acc:65.625
# Best loss:0.363, Best accuracy:61.875, Best F1-score:0.597
# 91/300 lr=0.00741 - loss:0.261, acc:79.040, val_loss:0.375, val_acc:58.125
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 92/300 lr=0.00741 - loss:0.259, acc:77.973, val_loss:0.338, val_acc:60.625
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 93/300 lr=0.00741 - loss:0.250, acc:80.030, val_loss:0.365, val_acc:56.875
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 94/300 lr=0.00741 - loss:0.256, acc:78.506, val_loss:0.375, val_acc:59.375
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 95/300 lr=0.00741 - loss:0.248, acc:80.259, val_loss:0.341, val_acc:64.375
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 96/300 lr=0.00741 - loss:0.235, acc:82.317, val_loss:0.352, val_acc:63.750
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 97/300 lr=0.00741 - loss:0.242, acc:79.878, val_loss:0.361, val_acc:62.500
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 98/300 lr=0.00741 - loss:0.247, acc:80.945, val_loss:0.344, val_acc:65.000
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 99/300 lr=0.00741 - loss:0.233, acc:82.317, val_loss:0.351, val_acc:63.750
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 100/300 lr=0.00741 - loss:0.225, acc:83.003, val_loss:0.349, val_acc:61.250
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 101/300 lr=0.00741 - loss:0.228, acc:82.165, val_loss:0.357, val_acc:63.125
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 102/300 lr=0.00638 - loss:0.228, acc:83.003, val_loss:0.373, val_acc:60.625
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 103/300 lr=0.00638 - loss:0.230, acc:82.088, val_loss:0.347, val_acc:60.000
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 104/300 lr=0.00638 - loss:0.223, acc:83.841, val_loss:0.366, val_acc:61.875
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 105/300 lr=0.00638 - loss:0.225, acc:81.936, val_loss:0.360, val_acc:63.125
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 106/300 lr=0.00638 - loss:0.218, acc:83.689, val_loss:0.356, val_acc:61.875
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 107/300 lr=0.00638 - loss:0.219, acc:83.079, val_loss:0.341, val_acc:64.375
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 108/300 lr=0.00638 - loss:0.210, acc:85.899, val_loss:0.356, val_acc:63.125
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 109/300 lr=0.00638 - loss:0.208, acc:85.137, val_loss:0.337, val_acc:65.000
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 110/300 lr=0.00638 - loss:0.215, acc:84.909, val_loss:0.355, val_acc:62.500
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 111/300 lr=0.00638 - loss:0.213, acc:84.985, val_loss:0.331, val_acc:66.250
# Best loss:0.347, Best accuracy:65.625, Best F1-score:0.643
# 112/300 lr=0.00638 - loss:0.203, acc:85.747, val_loss:0.335, val_acc:65.000
# Best loss:0.331, Best accuracy:66.250, Best F1-score:0.660
# 113/300 lr=0.00638 - loss:0.202, acc:86.814, val_loss:0.352, val_acc:64.375
# Best loss:0.331, Best accuracy:66.250, Best F1-score:0.660
# 114/300 lr=0.00638 - loss:0.203, acc:84.985, val_loss:0.357, val_acc:60.625
# Best loss:0.331, Best accuracy:66.250, Best F1-score:0.660
# 115/300 lr=0.00638 - loss:0.198, acc:87.271, val_loss:0.330, val_acc:67.500
# Best loss:0.331, Best accuracy:66.250, Best F1-score:0.660
# 116/300 lr=0.00638 - loss:0.202, acc:86.357, val_loss:0.347, val_acc:65.000
# Best loss:0.330, Best accuracy:67.500, Best F1-score:0.657
# 117/300 lr=0.00638 - loss:0.204, acc:86.052, val_loss:0.362, val_acc:62.500
# Best loss:0.330, Best accuracy:67.500, Best F1-score:0.657
# 118/300 lr=0.00638 - loss:0.202, acc:86.509, val_loss:0.335, val_acc:62.500
# Best loss:0.330, Best accuracy:67.500, Best F1-score:0.657
# 119/300 lr=0.00638 - loss:0.206, acc:85.899, val_loss:0.334, val_acc:66.875
# Best loss:0.330, Best accuracy:67.500, Best F1-score:0.657
# 120/300 lr=0.00638 - loss:0.201, acc:86.433, val_loss:0.358, val_acc:60.000
# Best loss:0.330, Best accuracy:67.500, Best F1-score:0.657
# 121/300 lr=0.00638 - loss:0.193, acc:87.576, val_loss:0.328, val_acc:68.125
# Best loss:0.330, Best accuracy:67.500, Best F1-score:0.657
# 122/300 lr=0.00549 - loss:0.185, acc:88.720, val_loss:0.323, val_acc:66.875
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 123/300 lr=0.00549 - loss:0.182, acc:89.101, val_loss:0.334, val_acc:65.000
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 124/300 lr=0.00549 - loss:0.186, acc:88.567, val_loss:0.323, val_acc:66.250
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 125/300 lr=0.00549 - loss:0.184, acc:88.643, val_loss:0.334, val_acc:62.500
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 126/300 lr=0.00549 - loss:0.183, acc:89.101, val_loss:0.349, val_acc:61.875
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 127/300 lr=0.00549 - loss:0.184, acc:89.405, val_loss:0.329, val_acc:66.250
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 128/300 lr=0.00549 - loss:0.189, acc:88.567, val_loss:0.327, val_acc:68.125
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 129/300 lr=0.00549 - loss:0.176, acc:90.625, val_loss:0.336, val_acc:65.000
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 130/300 lr=0.00549 - loss:0.173, acc:89.939, val_loss:0.326, val_acc:65.000
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 131/300 lr=0.00549 - loss:0.180, acc:89.405, val_loss:0.371, val_acc:59.375
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 132/300 lr=0.00549 - loss:0.179, acc:90.473, val_loss:0.369, val_acc:60.000
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 133/300 lr=0.00549 - loss:0.172, acc:90.625, val_loss:0.340, val_acc:65.625
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 134/300 lr=0.00549 - loss:0.168, acc:90.777, val_loss:0.351, val_acc:61.875
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 135/300 lr=0.00549 - loss:0.165, acc:91.159, val_loss:0.350, val_acc:61.250
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 136/300 lr=0.00549 - loss:0.169, acc:91.159, val_loss:0.343, val_acc:63.750
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 137/300 lr=0.00549 - loss:0.166, acc:90.930, val_loss:0.323, val_acc:63.750
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 138/300 lr=0.00549 - loss:0.170, acc:90.244, val_loss:0.321, val_acc:65.625
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 139/300 lr=0.00549 - loss:0.174, acc:89.939, val_loss:0.338, val_acc:64.375
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 140/300 lr=0.00549 - loss:0.162, acc:92.226, val_loss:0.316, val_acc:66.250
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 141/300 lr=0.00549 - loss:0.165, acc:91.616, val_loss:0.352, val_acc:60.625
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 142/300 lr=0.00472 - loss:0.168, acc:91.616, val_loss:0.340, val_acc:65.000
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 143/300 lr=0.00472 - loss:0.172, acc:90.168, val_loss:0.348, val_acc:61.875
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 144/300 lr=0.00472 - loss:0.166, acc:91.845, val_loss:0.334, val_acc:65.000
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 145/300 lr=0.00472 - loss:0.160, acc:91.921, val_loss:0.343, val_acc:61.250
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 146/300 lr=0.00472 - loss:0.161, acc:92.454, val_loss:0.325, val_acc:66.250
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 147/300 lr=0.00472 - loss:0.167, acc:91.006, val_loss:0.344, val_acc:63.125
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 148/300 lr=0.00472 - loss:0.165, acc:91.235, val_loss:0.353, val_acc:61.875
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 149/300 lr=0.00472 - loss:0.154, acc:93.445, val_loss:0.341, val_acc:61.875
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 150/300 lr=0.00472 - loss:0.157, acc:92.607, val_loss:0.333, val_acc:62.500
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 151/300 lr=0.00472 - loss:0.154, acc:93.598, val_loss:0.325, val_acc:68.750
# Best loss:0.328, Best accuracy:68.125, Best F1-score:0.664
# 152/300 lr=0.00472 - loss:0.157, acc:92.378, val_loss:0.341, val_acc:63.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 153/300 lr=0.00472 - loss:0.154, acc:93.293, val_loss:0.335, val_acc:63.125
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 154/300 lr=0.00472 - loss:0.157, acc:92.912, val_loss:0.338, val_acc:61.250
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 155/300 lr=0.00472 - loss:0.163, acc:91.692, val_loss:0.324, val_acc:66.875
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 156/300 lr=0.00472 - loss:0.157, acc:92.607, val_loss:0.339, val_acc:64.375
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 157/300 lr=0.00472 - loss:0.157, acc:92.530, val_loss:0.326, val_acc:65.000
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 158/300 lr=0.00472 - loss:0.148, acc:93.369, val_loss:0.336, val_acc:63.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 159/300 lr=0.00472 - loss:0.147, acc:94.588, val_loss:0.344, val_acc:61.875
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 160/300 lr=0.00472 - loss:0.146, acc:94.588, val_loss:0.317, val_acc:67.500
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 161/300 lr=0.00472 - loss:0.149, acc:94.360, val_loss:0.359, val_acc:60.000
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 162/300 lr=0.00407 - loss:0.150, acc:93.598, val_loss:0.325, val_acc:65.000
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 163/300 lr=0.00407 - loss:0.152, acc:92.683, val_loss:0.332, val_acc:65.625
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 164/300 lr=0.00407 - loss:0.150, acc:93.674, val_loss:0.328, val_acc:65.625
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 165/300 lr=0.00407 - loss:0.148, acc:93.979, val_loss:0.337, val_acc:64.375
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 166/300 lr=0.00407 - loss:0.149, acc:93.521, val_loss:0.341, val_acc:63.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 167/300 lr=0.00407 - loss:0.144, acc:94.207, val_loss:0.344, val_acc:65.625
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 168/300 lr=0.00407 - loss:0.145, acc:94.817, val_loss:0.342, val_acc:63.125
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 169/300 lr=0.00407 - loss:0.144, acc:94.360, val_loss:0.320, val_acc:65.000
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 170/300 lr=0.00407 - loss:0.154, acc:92.988, val_loss:0.334, val_acc:62.500
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 171/300 lr=0.00407 - loss:0.149, acc:93.369, val_loss:0.331, val_acc:63.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 172/300 lr=0.00407 - loss:0.140, acc:95.351, val_loss:0.314, val_acc:66.875
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 173/300 lr=0.00407 - loss:0.141, acc:95.046, val_loss:0.310, val_acc:68.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 174/300 lr=0.00407 - loss:0.141, acc:94.817, val_loss:0.310, val_acc:67.500
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 175/300 lr=0.00407 - loss:0.148, acc:93.902, val_loss:0.336, val_acc:63.125
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 176/300 lr=0.00407 - loss:0.143, acc:94.893, val_loss:0.330, val_acc:66.250
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 177/300 lr=0.00407 - loss:0.139, acc:95.046, val_loss:0.317, val_acc:68.125
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 178/300 lr=0.00407 - loss:0.138, acc:95.351, val_loss:0.306, val_acc:68.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 179/300 lr=0.00407 - loss:0.141, acc:95.122, val_loss:0.321, val_acc:66.250
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 180/300 lr=0.00407 - loss:0.139, acc:94.893, val_loss:0.336, val_acc:65.000
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 181/300 lr=0.00407 - loss:0.142, acc:94.817, val_loss:0.318, val_acc:68.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 182/300 lr=0.00350 - loss:0.135, acc:96.418, val_loss:0.325, val_acc:64.375
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 183/300 lr=0.00350 - loss:0.141, acc:94.970, val_loss:0.322, val_acc:66.250
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 184/300 lr=0.00350 - loss:0.139, acc:95.351, val_loss:0.329, val_acc:66.250
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 185/300 lr=0.00350 - loss:0.136, acc:95.351, val_loss:0.317, val_acc:68.125
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 186/300 lr=0.00350 - loss:0.137, acc:95.274, val_loss:0.312, val_acc:68.750
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 187/300 lr=0.00350 - loss:0.141, acc:94.741, val_loss:0.314, val_acc:67.500
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 188/300 lr=0.00350 - loss:0.139, acc:95.046, val_loss:0.309, val_acc:69.375
# Best loss:0.325, Best accuracy:68.750, Best F1-score:0.668
# 189/300 lr=0.00350 - loss:0.137, acc:95.732, val_loss:0.311, val_acc:66.875
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 190/300 lr=0.00350 - loss:0.137, acc:95.884, val_loss:0.347, val_acc:63.125
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 191/300 lr=0.00350 - loss:0.138, acc:95.122, val_loss:0.327, val_acc:63.750
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 192/300 lr=0.00350 - loss:0.133, acc:95.503, val_loss:0.328, val_acc:68.750
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 193/300 lr=0.00350 - loss:0.135, acc:96.113, val_loss:0.323, val_acc:68.125
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 194/300 lr=0.00350 - loss:0.133, acc:95.579, val_loss:0.327, val_acc:66.250
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 195/300 lr=0.00350 - loss:0.138, acc:94.970, val_loss:0.319, val_acc:67.500
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 196/300 lr=0.00350 - loss:0.138, acc:94.970, val_loss:0.332, val_acc:64.375
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 197/300 lr=0.00350 - loss:0.145, acc:93.674, val_loss:0.316, val_acc:68.750
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 198/300 lr=0.00350 - loss:0.132, acc:96.265, val_loss:0.314, val_acc:68.750
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 199/300 lr=0.00350 - loss:0.141, acc:94.970, val_loss:0.327, val_acc:66.875
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 200/300 lr=0.00350 - loss:0.136, acc:95.655, val_loss:0.337, val_acc:64.375
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 201/300 lr=0.00350 - loss:0.133, acc:96.265, val_loss:0.322, val_acc:67.500
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 202/300 lr=0.00301 - loss:0.132, acc:96.418, val_loss:0.309, val_acc:68.750
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 203/300 lr=0.00301 - loss:0.130, acc:96.723, val_loss:0.313, val_acc:67.500
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 204/300 lr=0.00301 - loss:0.129, acc:96.570, val_loss:0.311, val_acc:65.625
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 205/300 lr=0.00301 - loss:0.126, acc:96.875, val_loss:0.299, val_acc:67.500
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 206/300 lr=0.00301 - loss:0.128, acc:96.418, val_loss:0.289, val_acc:70.000
# Best loss:0.309, Best accuracy:69.375, Best F1-score:0.670
# 207/300 lr=0.00301 - loss:0.125, acc:97.561, val_loss:0.294, val_acc:71.875
# Best loss:0.289, Best accuracy:70.000, Best F1-score:0.688
# 208/300 lr=0.00301 - loss:0.127, acc:96.646, val_loss:0.306, val_acc:65.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 209/300 lr=0.00301 - loss:0.129, acc:96.646, val_loss:0.305, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 210/300 lr=0.00301 - loss:0.123, acc:97.485, val_loss:0.311, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 211/300 lr=0.00301 - loss:0.127, acc:96.799, val_loss:0.316, val_acc:67.500
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 212/300 lr=0.00301 - loss:0.125, acc:97.180, val_loss:0.300, val_acc:68.125
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 213/300 lr=0.00301 - loss:0.129, acc:96.799, val_loss:0.292, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 214/300 lr=0.00301 - loss:0.126, acc:96.875, val_loss:0.299, val_acc:68.125
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 215/300 lr=0.00301 - loss:0.128, acc:96.723, val_loss:0.316, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 216/300 lr=0.00301 - loss:0.127, acc:97.027, val_loss:0.311, val_acc:68.125
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 217/300 lr=0.00301 - loss:0.124, acc:97.485, val_loss:0.317, val_acc:66.875
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 218/300 lr=0.00301 - loss:0.127, acc:96.723, val_loss:0.317, val_acc:68.125
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 219/300 lr=0.00301 - loss:0.129, acc:97.027, val_loss:0.321, val_acc:68.125
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 220/300 lr=0.00301 - loss:0.124, acc:97.256, val_loss:0.306, val_acc:70.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 221/300 lr=0.00301 - loss:0.124, acc:96.875, val_loss:0.315, val_acc:67.500
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 222/300 lr=0.00259 - loss:0.125, acc:97.332, val_loss:0.314, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 223/300 lr=0.00259 - loss:0.124, acc:97.027, val_loss:0.311, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 224/300 lr=0.00259 - loss:0.122, acc:98.018, val_loss:0.300, val_acc:70.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 225/300 lr=0.00259 - loss:0.122, acc:98.018, val_loss:0.301, val_acc:70.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 226/300 lr=0.00259 - loss:0.130, acc:96.037, val_loss:0.310, val_acc:67.500
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 227/300 lr=0.00259 - loss:0.125, acc:96.570, val_loss:0.303, val_acc:69.375
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 228/300 lr=0.00259 - loss:0.124, acc:97.180, val_loss:0.305, val_acc:69.375
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 229/300 lr=0.00259 - loss:0.126, acc:97.332, val_loss:0.318, val_acc:66.875
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 230/300 lr=0.00259 - loss:0.125, acc:97.104, val_loss:0.293, val_acc:71.250
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 231/300 lr=0.00259 - loss:0.123, acc:97.713, val_loss:0.293, val_acc:69.375
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 232/300 lr=0.00259 - loss:0.124, acc:97.409, val_loss:0.303, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 233/300 lr=0.00259 - loss:0.123, acc:97.332, val_loss:0.287, val_acc:71.875
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 234/300 lr=0.00259 - loss:0.127, acc:96.494, val_loss:0.314, val_acc:66.875
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 235/300 lr=0.00259 - loss:0.120, acc:97.713, val_loss:0.301, val_acc:67.500
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 236/300 lr=0.00259 - loss:0.126, acc:96.951, val_loss:0.305, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 237/300 lr=0.00259 - loss:0.120, acc:97.790, val_loss:0.310, val_acc:68.125
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 238/300 lr=0.00259 - loss:0.119, acc:98.171, val_loss:0.300, val_acc:70.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 239/300 lr=0.00259 - loss:0.121, acc:97.942, val_loss:0.293, val_acc:71.250
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 240/300 lr=0.00259 - loss:0.123, acc:97.713, val_loss:0.294, val_acc:69.375
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 241/300 lr=0.00259 - loss:0.122, acc:97.713, val_loss:0.328, val_acc:66.875
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 242/300 lr=0.00223 - loss:0.123, acc:97.485, val_loss:0.300, val_acc:71.250
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 243/300 lr=0.00223 - loss:0.122, acc:97.790, val_loss:0.304, val_acc:70.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 244/300 lr=0.00223 - loss:0.125, acc:97.180, val_loss:0.300, val_acc:70.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 245/300 lr=0.00223 - loss:0.126, acc:97.256, val_loss:0.320, val_acc:65.625
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 246/300 lr=0.00223 - loss:0.124, acc:97.409, val_loss:0.303, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 247/300 lr=0.00223 - loss:0.121, acc:97.485, val_loss:0.311, val_acc:69.375
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 248/300 lr=0.00223 - loss:0.120, acc:98.095, val_loss:0.312, val_acc:68.750
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 249/300 lr=0.00223 - loss:0.118, acc:98.323, val_loss:0.299, val_acc:70.000
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 250/300 lr=0.00223 - loss:0.122, acc:97.485, val_loss:0.290, val_acc:70.000
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 251/300 lr=0.00223 - loss:0.120, acc:97.409, val_loss:0.285, val_acc:72.500
# Best loss:0.294, Best accuracy:71.875, Best F1-score:0.699
# 252/300 lr=0.00223 - loss:0.124, acc:97.256, val_loss:0.317, val_acc:65.625
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 253/300 lr=0.00223 - loss:0.120, acc:97.637, val_loss:0.293, val_acc:70.000
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 254/300 lr=0.00223 - loss:0.120, acc:97.713, val_loss:0.296, val_acc:70.000
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 255/300 lr=0.00223 - loss:0.120, acc:98.095, val_loss:0.300, val_acc:70.625
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 256/300 lr=0.00223 - loss:0.119, acc:98.095, val_loss:0.308, val_acc:68.750
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 257/300 lr=0.00223 - loss:0.120, acc:98.018, val_loss:0.292, val_acc:70.625
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 258/300 lr=0.00223 - loss:0.118, acc:98.171, val_loss:0.300, val_acc:70.000
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 259/300 lr=0.00223 - loss:0.123, acc:97.866, val_loss:0.319, val_acc:68.125
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 260/300 lr=0.00223 - loss:0.124, acc:96.341, val_loss:0.310, val_acc:68.750
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 261/300 lr=0.00223 - loss:0.122, acc:97.409, val_loss:0.302, val_acc:69.375
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 262/300 lr=0.00192 - loss:0.119, acc:98.095, val_loss:0.292, val_acc:69.375
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 263/300 lr=0.00192 - loss:0.120, acc:98.018, val_loss:0.308, val_acc:71.875
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 264/300 lr=0.00192 - loss:0.123, acc:97.409, val_loss:0.304, val_acc:68.125
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 265/300 lr=0.00192 - loss:0.121, acc:97.713, val_loss:0.307, val_acc:67.500
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 266/300 lr=0.00192 - loss:0.118, acc:98.095, val_loss:0.300, val_acc:69.375
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 267/300 lr=0.00192 - loss:0.117, acc:98.476, val_loss:0.288, val_acc:72.500
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 268/300 lr=0.00192 - loss:0.116, acc:98.476, val_loss:0.295, val_acc:71.250
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 269/300 lr=0.00192 - loss:0.119, acc:98.171, val_loss:0.291, val_acc:71.250
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 270/300 lr=0.00192 - loss:0.119, acc:97.942, val_loss:0.307, val_acc:66.875
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 271/300 lr=0.00192 - loss:0.119, acc:98.018, val_loss:0.296, val_acc:70.625
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 272/300 lr=0.00192 - loss:0.117, acc:98.247, val_loss:0.307, val_acc:70.000
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 273/300 lr=0.00192 - loss:0.119, acc:98.018, val_loss:0.290, val_acc:69.375
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 274/300 lr=0.00192 - loss:0.121, acc:97.104, val_loss:0.292, val_acc:71.875
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 275/300 lr=0.00192 - loss:0.119, acc:98.018, val_loss:0.301, val_acc:66.875
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 276/300 lr=0.00192 - loss:0.122, acc:97.485, val_loss:0.282, val_acc:73.125
# Best loss:0.285, Best accuracy:72.500, Best F1-score:0.711
# 277/300 lr=0.00192 - loss:0.118, acc:98.323, val_loss:0.300, val_acc:70.000
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 278/300 lr=0.00192 - loss:0.121, acc:97.637, val_loss:0.300, val_acc:68.750
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 279/300 lr=0.00192 - loss:0.118, acc:98.247, val_loss:0.287, val_acc:71.875
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 280/300 lr=0.00192 - loss:0.121, acc:97.637, val_loss:0.292, val_acc:73.125
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 281/300 lr=0.00192 - loss:0.119, acc:98.171, val_loss:0.282, val_acc:71.250
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 282/300 lr=0.00165 - loss:0.119, acc:97.866, val_loss:0.284, val_acc:71.250
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 283/300 lr=0.00165 - loss:0.118, acc:97.942, val_loss:0.289, val_acc:70.000
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 284/300 lr=0.00165 - loss:0.117, acc:98.476, val_loss:0.284, val_acc:71.875
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 285/300 lr=0.00165 - loss:0.119, acc:98.095, val_loss:0.294, val_acc:71.250
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 286/300 lr=0.00165 - loss:0.118, acc:98.171, val_loss:0.296, val_acc:69.375
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 287/300 lr=0.00165 - loss:0.117, acc:98.399, val_loss:0.283, val_acc:70.625
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 288/300 lr=0.00165 - loss:0.116, acc:98.552, val_loss:0.304, val_acc:68.750
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 289/300 lr=0.00165 - loss:0.119, acc:98.323, val_loss:0.278, val_acc:73.125
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 290/300 lr=0.00165 - loss:0.115, acc:98.552, val_loss:0.286, val_acc:71.875
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 291/300 lr=0.00165 - loss:0.116, acc:98.780, val_loss:0.298, val_acc:70.000
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 292/300 lr=0.00165 - loss:0.117, acc:98.095, val_loss:0.289, val_acc:72.500
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 293/300 lr=0.00165 - loss:0.120, acc:97.866, val_loss:0.292, val_acc:71.250
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 294/300 lr=0.00165 - loss:0.115, acc:98.476, val_loss:0.293, val_acc:70.625
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 295/300 lr=0.00165 - loss:0.115, acc:98.628, val_loss:0.288, val_acc:70.625
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 296/300 lr=0.00165 - loss:0.115, acc:98.476, val_loss:0.296, val_acc:70.625
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 297/300 lr=0.00165 - loss:0.118, acc:98.018, val_loss:0.303, val_acc:68.750
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 298/300 lr=0.00165 - loss:0.118, acc:97.866, val_loss:0.287, val_acc:71.250
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 299/300 lr=0.00165 - loss:0.115, acc:98.399, val_loss:0.286, val_acc:69.375
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# 300/300 lr=0.00165 - loss:0.116, acc:98.476, val_loss:0.288, val_acc:70.000
# Best loss:0.282, Best accuracy:73.125, Best F1-score:0.723
# [*] Done - acc:73.125
# A Jupyter Widget
# 1/300 lr=0.01000 - loss:0.636, acc:9.223, val_loss:0.646, val_acc:11.250
# Best loss:4144959.000, Best accuracy:-1.000, Best F1-score:-1.000
# 2/300 lr=0.01000 - loss:0.634, acc:13.491, val_loss:0.648, val_acc:10.625
# Best loss:0.646, Best accuracy:11.250, Best F1-score:0.024
# 3/300 lr=0.01000 - loss:0.626, acc:15.701, val_loss:0.640, val_acc:18.125
# Best loss:0.646, Best accuracy:11.250, Best F1-score:0.024
# 4/300 lr=0.01000 - loss:0.615, acc:19.436, val_loss:0.630, val_acc:23.125
# Best loss:0.640, Best accuracy:18.125, Best F1-score:0.081
# 5/300 lr=0.01000 - loss:0.608, acc:22.409, val_loss:0.624, val_acc:25.625
# Best loss:0.630, Best accuracy:23.125, Best F1-score:0.131
# 6/300 lr=0.01000 - loss:0.600, acc:23.247, val_loss:0.617, val_acc:25.625
# Best loss:0.624, Best accuracy:25.625, Best F1-score:0.180
# 7/300 lr=0.01000 - loss:0.594, acc:23.399, val_loss:0.604, val_acc:25.625
# Best loss:0.624, Best accuracy:25.625, Best F1-score:0.180
# 8/300 lr=0.01000 - loss:0.586, acc:25.000, val_loss:0.598, val_acc:25.000
# Best loss:0.624, Best accuracy:25.625, Best F1-score:0.180
# 9/300 lr=0.01000 - loss:0.583, acc:25.457, val_loss:0.600, val_acc:25.625
# Best loss:0.624, Best accuracy:25.625, Best F1-score:0.180
# 10/300 lr=0.01000 - loss:0.580, acc:26.677, val_loss:0.582, val_acc:26.250
# Best loss:0.624, Best accuracy:25.625, Best F1-score:0.180
# 11/300 lr=0.01000 - loss:0.574, acc:27.515, val_loss:0.598, val_acc:23.750
# Best loss:0.582, Best accuracy:26.250, Best F1-score:0.219
# 12/300 lr=0.01000 - loss:0.574, acc:26.677, val_loss:0.592, val_acc:25.000
# Best loss:0.582, Best accuracy:26.250, Best F1-score:0.219
# 13/300 lr=0.01000 - loss:0.568, acc:28.277, val_loss:0.598, val_acc:22.500
# Best loss:0.582, Best accuracy:26.250, Best F1-score:0.219
# 14/300 lr=0.01000 - loss:0.564, acc:29.497, val_loss:0.590, val_acc:24.375
# Best loss:0.582, Best accuracy:26.250, Best F1-score:0.219
# 15/300 lr=0.01000 - loss:0.561, acc:28.659, val_loss:0.572, val_acc:32.500
# Best loss:0.582, Best accuracy:26.250, Best F1-score:0.219
# 16/300 lr=0.01000 - loss:0.559, acc:30.335, val_loss:0.571, val_acc:30.625
# Best loss:0.572, Best accuracy:32.500, Best F1-score:0.263
# 17/300 lr=0.01000 - loss:0.557, acc:30.716, val_loss:0.564, val_acc:28.750
# Best loss:0.572, Best accuracy:32.500, Best F1-score:0.263
# 18/300 lr=0.01000 - loss:0.553, acc:31.479, val_loss:0.564, val_acc:28.125
# Best loss:0.572, Best accuracy:32.500, Best F1-score:0.263
# 19/300 lr=0.01000 - loss:0.551, acc:32.622, val_loss:0.564, val_acc:30.625
# Best loss:0.572, Best accuracy:32.500, Best F1-score:0.263
# 20/300 lr=0.01000 - loss:0.544, acc:33.384, val_loss:0.562, val_acc:33.750
# Best loss:0.572, Best accuracy:32.500, Best F1-score:0.263
# 21/300 lr=0.01000 - loss:0.543, acc:33.613, val_loss:0.548, val_acc:32.500
# Best loss:0.562, Best accuracy:33.750, Best F1-score:0.301
# 22/300 lr=0.01000 - loss:0.539, acc:34.756, val_loss:0.558, val_acc:32.500
# Best loss:0.562, Best accuracy:33.750, Best F1-score:0.301
# 23/300 lr=0.01000 - loss:0.540, acc:34.299, val_loss:0.567, val_acc:32.500
# Best loss:0.562, Best accuracy:33.750, Best F1-score:0.301
# 24/300 lr=0.01000 - loss:0.534, acc:34.451, val_loss:0.553, val_acc:31.875
# Best loss:0.562, Best accuracy:33.750, Best F1-score:0.301
# 25/300 lr=0.01000 - loss:0.538, acc:36.662, val_loss:0.546, val_acc:36.250
# Best loss:0.562, Best accuracy:33.750, Best F1-score:0.301
# 26/300 lr=0.01000 - loss:0.525, acc:38.720, val_loss:0.542, val_acc:33.125
# Best loss:0.546, Best accuracy:36.250, Best F1-score:0.322
# 27/300 lr=0.01000 - loss:0.519, acc:37.957, val_loss:0.527, val_acc:33.750
# Best loss:0.546, Best accuracy:36.250, Best F1-score:0.322
# 28/300 lr=0.01000 - loss:0.516, acc:38.796, val_loss:0.530, val_acc:37.500
# Best loss:0.546, Best accuracy:36.250, Best F1-score:0.322
# 29/300 lr=0.01000 - loss:0.511, acc:40.320, val_loss:0.539, val_acc:30.000
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.317
# 30/300 lr=0.01000 - loss:0.507, acc:41.921, val_loss:0.540, val_acc:31.875
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.317
# 31/300 lr=0.01000 - loss:0.506, acc:41.235, val_loss:0.529, val_acc:35.000
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.317
# 32/300 lr=0.01000 - loss:0.494, acc:43.445, val_loss:0.528, val_acc:33.750
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.317
# 33/300 lr=0.01000 - loss:0.494, acc:44.055, val_loss:0.537, val_acc:31.875
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.317
# 34/300 lr=0.01000 - loss:0.488, acc:43.369, val_loss:0.513, val_acc:37.500
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.317
# 35/300 lr=0.01000 - loss:0.489, acc:44.284, val_loss:0.516, val_acc:39.375
# Best loss:0.530, Best accuracy:37.500, Best F1-score:0.317
# 36/300 lr=0.01000 - loss:0.486, acc:44.665, val_loss:0.502, val_acc:37.500
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 37/300 lr=0.01000 - loss:0.468, acc:47.866, val_loss:0.505, val_acc:35.000
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 38/300 lr=0.01000 - loss:0.469, acc:47.866, val_loss:0.497, val_acc:38.750
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 39/300 lr=0.01000 - loss:0.463, acc:49.390, val_loss:0.505, val_acc:37.500
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 40/300 lr=0.01000 - loss:0.465, acc:49.771, val_loss:0.499, val_acc:36.875
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 41/300 lr=0.01000 - loss:0.457, acc:49.924, val_loss:0.487, val_acc:38.125
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 42/300 lr=0.01000 - loss:0.445, acc:50.457, val_loss:0.476, val_acc:38.750
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 43/300 lr=0.01000 - loss:0.444, acc:51.601, val_loss:0.484, val_acc:38.750
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 44/300 lr=0.01000 - loss:0.443, acc:52.591, val_loss:0.474, val_acc:38.750
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 45/300 lr=0.01000 - loss:0.439, acc:52.515, val_loss:0.477, val_acc:40.625
# Best loss:0.516, Best accuracy:39.375, Best F1-score:0.342
# 46/300 lr=0.01000 - loss:0.434, acc:53.582, val_loss:0.459, val_acc:43.125
# Best loss:0.477, Best accuracy:40.625, Best F1-score:0.368
# 47/300 lr=0.01000 - loss:0.437, acc:53.659, val_loss:0.448, val_acc:41.875
# Best loss:0.459, Best accuracy:43.125, Best F1-score:0.399
# 48/300 lr=0.01000 - loss:0.424, acc:54.345, val_loss:0.451, val_acc:39.375
# Best loss:0.459, Best accuracy:43.125, Best F1-score:0.399
# 49/300 lr=0.01000 - loss:0.418, acc:56.631, val_loss:0.455, val_acc:40.625
# Best loss:0.459, Best accuracy:43.125, Best F1-score:0.399
# 50/300 lr=0.01000 - loss:0.429, acc:54.649, val_loss:0.454, val_acc:44.375
# Best loss:0.459, Best accuracy:43.125, Best F1-score:0.399
# 51/300 lr=0.01000 - loss:0.423, acc:54.649, val_loss:0.446, val_acc:42.500
# Best loss:0.454, Best accuracy:44.375, Best F1-score:0.411
# 52/300 lr=0.01000 - loss:0.421, acc:54.116, val_loss:0.468, val_acc:45.000
# Best loss:0.454, Best accuracy:44.375, Best F1-score:0.411
# 53/300 lr=0.01000 - loss:0.413, acc:56.326, val_loss:0.448, val_acc:43.750
# Best loss:0.468, Best accuracy:45.000, Best F1-score:0.423
# 54/300 lr=0.01000 - loss:0.409, acc:57.317, val_loss:0.429, val_acc:47.500
# Best loss:0.468, Best accuracy:45.000, Best F1-score:0.423
# 55/300 lr=0.01000 - loss:0.404, acc:58.155, val_loss:0.441, val_acc:41.875
# Best loss:0.429, Best accuracy:47.500, Best F1-score:0.440
# 56/300 lr=0.01000 - loss:0.401, acc:58.384, val_loss:0.435, val_acc:46.250
# Best loss:0.429, Best accuracy:47.500, Best F1-score:0.440
# 57/300 lr=0.01000 - loss:0.404, acc:57.774, val_loss:0.438, val_acc:46.875
# Best loss:0.429, Best accuracy:47.500, Best F1-score:0.440
# 58/300 lr=0.01000 - loss:0.393, acc:59.985, val_loss:0.429, val_acc:43.125
# Best loss:0.429, Best accuracy:47.500, Best F1-score:0.440
# 59/300 lr=0.01000 - loss:0.398, acc:59.223, val_loss:0.407, val_acc:46.875
# Best loss:0.429, Best accuracy:47.500, Best F1-score:0.440
# 60/300 lr=0.01000 - loss:0.375, acc:62.652, val_loss:0.421, val_acc:46.250
# Best loss:0.429, Best accuracy:47.500, Best F1-score:0.440
# 61/300 lr=0.01000 - loss:0.374, acc:63.034, val_loss:0.411, val_acc:49.375
# Best loss:0.429, Best accuracy:47.500, Best F1-score:0.440

# %%
end()

# %%
print(f'max:{max(fold_acc)}, min:{min(fold_acc)}, average:{sum(fold_acc)/len(fold_acc)}')

# %%
import warnings
warnings.filterwarnings('always')

Report = classification_report(emotions_groundtruth_list, predicted_emotions_list)

os.makedirs(f'Results/{DATA_PATH}', exist_ok=True)
report_path = f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_nomalize.txt'

with open(report_path, "w") as f:
    f.write(Report)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

emotion_names = CLASS_LABELS


# build confusion matrix and normalized confusion matrix
conf_matrix = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list)
conf_matrix_norm = confusion_matrix(emotions_groundtruth_list, predicted_emotions_list,normalize='true')

# make a confusion matrix with labels using a DataFrame
confmatrix_df = pd.DataFrame(conf_matrix, index=emotion_names, columns=emotion_names)
confmatrix_df_norm = pd.DataFrame(conf_matrix_norm, index=emotion_names, columns=emotion_names)

# plot confusion matrices
plt.figure(figsize=(16,6))
sn.set(font_scale=1.8) # emotion label and title size
plt.subplot(1,2,1)
plt.title('Confusion Matrix')
sn.heatmap(confmatrix_df, annot=True, annot_kws={"size": 13}, fmt='g') #annot_kws is value font
plt.subplot(1,2,2)
plt.title('Normalized Confusion Matrix')
sn.heatmap(confmatrix_df_norm, annot=True, annot_kws={"size": 13}) #annot_kws is value font
plt.savefig(f'Results/{DATA_PATH}/{model_name}_{feature_name}_{k}-fold_confmatrix.pdf')
plt.show()

# %%
get_metric_calc(conf_matrix)
